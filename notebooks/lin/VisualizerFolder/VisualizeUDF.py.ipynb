# %%
import numpy as np

tmp = np.load('/orions4-zfs/projects/lins2/Lin_Virtual/CompletePointToMeshes/1.npz')
print(tmp.files)
tt = tmp['arr_0']
tt = tt.reshape([32,32,32])
# Out:
# ['arr_0']

# %%
print(tt)
# Out:
# [[[ 2.81036615  2.99211836  2.98876429 ...,  3.04813051  3.08410263
#     2.79639196]
#   [ 2.9834094   2.99568033  3.01197433 ...,  3.00552607  3.05858326
#     3.01984739]
#   [ 3.02607727  3.03625822  3.03353167 ...,  3.0121007   3.04077625
#     3.00814247]
#   ...,
#   [ 3.04537773  3.01761961  3.01094723 ...,  3.0199542   3.01610708
#     2.99298811]
#   [ 3.02576637  3.01756001  3.00821018 ...,  3.03416824  3.04448175
#     3.05227184]
#   [ 2.78055239  2.9630065   2.9897213  ...,  3.02657557  3.04076481
#     2.82916212]]
#
#  [[ 3.02562046  3.00049543  2.98848581 ...,  3.00037098  3.04397249
#     3.06863928]
#   [ 2.99110937  2.97600698  2.98023224 ...,  3.00709963  3.04303408
#     3.07465458]
#   [ 3.03390217  2.98324585  2.97973967 ...,  2.99786091  2.9937253
#     3.0149641 ]
#   ...,
#   [ 3.00165606  2.99363947  2.99353075 ...,  2.98345327  2.98375034
#     2.9792347 ]
#   [ 2.95322609  2.99065876  2.97113323 ...,  2.96795893  3.00537634
#     3.03057432]
# ...
