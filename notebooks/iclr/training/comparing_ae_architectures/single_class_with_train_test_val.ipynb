# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 1
setup_one_gpu(GPU)
# Out:
# Picking GPU 1

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out.basics import create_dir, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry, decoder_with_fc_only
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs          
from tf_lab.data_sets.shape_net import snc_category_to_synth_id, load_all_point_clouds_under_folder
from tf_lab.data_sets.shape_net import pc_loader as snc_loader

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_points = 2048
do_training = True
first_time_running = True
load_pretrained_model = False
load_epoch = None
seed = 42

# %%
max_training_epochs = 1000
loss = 'chamfer'
bneck_size = 512

class_name = raw_input('Give me the class type: ').lower()
syn_id = snc_category_to_synth_id()[class_name]

experiment_id = raw_input('Give me the experiment ID:').lower()

experiment_name = '_'.join([class_name, experiment_id, str(n_pc_points), 
                           'pts_bneck', str(bneck_size), loss
                           ])

top_data_dir = '/orions4-zfs/projects/optas/DATA/'
train_dir = osp.join(top_data_dir, 'OUT/iclr/nn_models/testing_ae_settings', experiment_name)
create_dir(train_dir)
# Out:
# Give me the class type: chair
# Give me the experiment ID:conv_arch_0
# '/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer'

# %%
train_split = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits', syn_id, '85_5_10/train.txt')
test_split = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits', syn_id, '85_5_10/test.txt')

top_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/centered/', str(n_pc_points))
splitter = Data_Splitter(top_pclouds_path, data_file_ending='.ply')

# %%
tr_files = splitter.load_splits(train_split)
pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(tr_files, n_threads=20, loader=snc_loader, verbose=True)
train_data = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)

test_files = splitter.load_splits(test_split)
pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(test_files, n_threads=20, loader=snc_loader, verbose=True)
test_data = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)
# Out:
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# 679 pclouds were loaded. They belong in 1 shape-classes.

# %%
encoder_args = { 'n_filters': [128, 128, 256, bneck_size],
                 'filter_sizes': [40, 20, 10, 10],
                 'strides': [1, 1, 2, 2],
                 'b_norm': False,
                }

decoder_args = {'layer_sizes': [1024, 2048, n_pc_points*3], 'b_norm': False}

# %%
if load_pretrained_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    if conf.train_dir != train_dir:
        conf.train_dir = train_dir
    conf.save(osp.join(train_dir, 'configuration'))
else:
    conf = Conf(
                n_input = [n_pc_points, 3],
                loss = loss,
                training_epochs = 1000,
                batch_size = 50,
                denoising = False,
                learning_rate = 0.0005,
                train_dir = train_dir,              
                loss_display_step = 1,                
                saver_step = 20,
                z_rotate = False,
                encoder = encoder_with_convs_and_symmetry,
                decoder = decoder_with_fc_only,
                encoder_args = encoder_args,
                decoder_args = decoder_args                
               )    
    conf.experiment_name = experiment_name
    conf.held_out_step = 5
    conf.save(osp.join(conf.train_dir, 'configuration'))

# %%
reset_tf_graph()
ae = PointNetAutoEncoder(conf.experiment_name, conf)

# %%
if load_pretrained_model:
    if load_epoch is None: # load last saved.
        saved_epochs = read_saved_epochs(conf.train_dir)
        load_epoch = saved_epochs[-1]        
    ae.restore_model(conf.train_dir, load_epoch, verbose=True)

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
    train_stats = ae.train(train_data, conf, log_file=fout, held_out_data=test_data)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.1729', 'loss=', '0.003919286')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '0.1727', 'loss=', '0.002156530')
# ('Epoch:', '0003', 'training time (minutes)=', '0.1739', 'loss=', '0.001803125')
# ('Epoch:', '0004', 'training time (minutes)=', '0.1753', 'loss=', '0.001627586')
# ('Epoch:', '0005', 'training time (minutes)=', '0.1761', 'loss=', '0.001463497')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001410941')
# ('Epoch:', '0006', 'training time (minutes)=', '0.1778', 'loss=', '0.001366869')
# ('Epoch:', '0007', 'training time (minutes)=', '0.1786', 'loss=', '0.001280301')
# ('Epoch:', '0008', 'training time (minutes)=', '0.1789', 'loss=', '0.001233863')
# ('Epoch:', '0009', 'training time (minutes)=', '0.1793', 'loss=', '0.001151946')
# ('Epoch:', '0010', 'training time (minutes)=', '0.1796', 'loss=', '0.001077127')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001154812')
# ('Epoch:', '0011', 'training time (minutes)=', '0.1790', 'loss=', '0.001045214')
# ('Epoch:', '0012', 'training time (minutes)=', '0.1792', 'loss=', '0.000996260')
# ('Epoch:', '0013', 'training time (minutes)=', '0.1791', 'loss=', '0.000956071')
# ('Epoch:', '0014', 'training time (minutes)=', '0.1790', 'loss=', '0.000933308')
# ('Epoch:', '0015', 'training time (minutes)=', '0.1794', 'loss=', '0.000903280')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001083477')
# ('Epoch:', '0016', 'training time (minutes)=', '0.1793', 'loss=', '0.000869556')
# ('Epoch:', '0017', 'training time (minutes)=', '0.1794', 'loss=', '0.000859898')
# ('Epoch:', '0018', 'training time (minutes)=', '0.1791', 'loss=', '0.000828698')
# ('Epoch:', '0019', 'training time (minutes)=', '0.1794', 'loss=', '0.000810445')
# ('Epoch:', '0020', 'training time (minutes)=', '0.1787', 'loss=', '0.000797086')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001014648')
# ('Epoch:', '0021', 'training time (minutes)=', '0.1790', 'loss=', '0.000788089')
# ('Epoch:', '0022', 'training time (minutes)=', '0.1794', 'loss=', '0.000769771')
# ('Epoch:', '0023', 'training time (minutes)=', '0.1792', 'loss=', '0.000751728')
# ('Epoch:', '0024', 'training time (minutes)=', '0.1794', 'loss=', '0.000719406')
# ('Epoch:', '0025', 'training time (minutes)=', '0.1792', 'loss=', '0.000712589')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000983102')
# ('Epoch:', '0026', 'training time (minutes)=', '0.1791', 'loss=', '0.000713071')
# ('Epoch:', '0027', 'training time (minutes)=', '0.1791', 'loss=', '0.000706100')
# ('Epoch:', '0028', 'training time (minutes)=', '0.1790', 'loss=', '0.000679159')
# ('Epoch:', '0029', 'training time (minutes)=', '0.1792', 'loss=', '0.000689985')
# ('Epoch:', '0030', 'training time (minutes)=', '0.1796', 'loss=', '0.000696730')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000989773')
# ('Epoch:', '0031', 'training time (minutes)=', '0.1789', 'loss=', '0.000660265')
# ('Epoch:', '0032', 'training time (minutes)=', '0.1799', 'loss=', '0.000665483')
# ('Epoch:', '0033', 'training time (minutes)=', '0.1792', 'loss=', '0.000640911')
# ('Epoch:', '0034', 'training time (minutes)=', '0.1793', 'loss=', '0.000620561')
# ('Epoch:', '0035', 'training time (minutes)=', '0.1796', 'loss=', '0.000629133')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001042012')
# ('Epoch:', '0036', 'training time (minutes)=', '0.1791', 'loss=', '0.000626625')
# ('Epoch:', '0037', 'training time (minutes)=', '0.1798', 'loss=', '0.000626570')
# ('Epoch:', '0038', 'training time (minutes)=', '0.1789', 'loss=', '0.000602524')
# ('Epoch:', '0039', 'training time (minutes)=', '0.1790', 'loss=', '0.000587782')
# ('Epoch:', '0040', 'training time (minutes)=', '0.1789', 'loss=', '0.000597898')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000982343')
# ('Epoch:', '0041', 'training time (minutes)=', '0.1790', 'loss=', '0.000601550')
# ('Epoch:', '0042', 'training time (minutes)=', '0.1790', 'loss=', '0.000595217')
# ('Epoch:', '0043', 'training time (minutes)=', '0.1787', 'loss=', '0.000601868')
# ('Epoch:', '0044', 'training time (minutes)=', '0.1790', 'loss=', '0.000578339')
# ('Epoch:', '0045', 'training time (minutes)=', '0.1790', 'loss=', '0.000583625')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000960322')
# ('Epoch:', '0046', 'training time (minutes)=', '0.1788', 'loss=', '0.000563732')
# ('Epoch:', '0047', 'training time (minutes)=', '0.1791', 'loss=', '0.000577312')
# ('Epoch:', '0048', 'training time (minutes)=', '0.1792', 'loss=', '0.000559462')
# ('Epoch:', '0049', 'training time (minutes)=', '0.1788', 'loss=', '0.000553188')
# ('Epoch:', '0050', 'training time (minutes)=', '0.1789', 'loss=', '0.000550222')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000986399')
# ('Epoch:', '0051', 'training time (minutes)=', '0.1787', 'loss=', '0.000543352')
# ('Epoch:', '0052', 'training time (minutes)=', '0.1790', 'loss=', '0.000530523')
# ('Epoch:', '0053', 'training time (minutes)=', '0.1788', 'loss=', '0.000529639')
# ('Epoch:', '0054', 'training time (minutes)=', '0.1790', 'loss=', '0.000518552')
# ('Epoch:', '0055', 'training time (minutes)=', '0.1791', 'loss=', '0.000513875')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000963277')
# ('Epoch:', '0056', 'training time (minutes)=', '0.1786', 'loss=', '0.000508063')
# ('Epoch:', '0057', 'training time (minutes)=', '0.1786', 'loss=', '0.000521609')
# ('Epoch:', '0058', 'training time (minutes)=', '0.1787', 'loss=', '0.000510127')
# ('Epoch:', '0059', 'training time (minutes)=', '0.1794', 'loss=', '0.000514950')
# ('Epoch:', '0060', 'training time (minutes)=', '0.1799', 'loss=', '0.000500914')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000947822')
# ('Epoch:', '0061', 'training time (minutes)=', '0.1789', 'loss=', '0.000502937')
# ('Epoch:', '0062', 'training time (minutes)=', '0.1788', 'loss=', '0.000501924')
# ('Epoch:', '0063', 'training time (minutes)=', '0.1785', 'loss=', '0.000503998')
# ('Epoch:', '0064', 'training time (minutes)=', '0.1784', 'loss=', '0.000514157')
# ('Epoch:', '0065', 'training time (minutes)=', '0.1793', 'loss=', '0.000492613')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000960329')
# ('Epoch:', '0066', 'training time (minutes)=', '0.1798', 'loss=', '0.000479762')
# ('Epoch:', '0067', 'training time (minutes)=', '0.1792', 'loss=', '0.000470968')
# ('Epoch:', '0068', 'training time (minutes)=', '0.1788', 'loss=', '0.000468769')
# ('Epoch:', '0069', 'training time (minutes)=', '0.1785', 'loss=', '0.000459317')
# ('Epoch:', '0070', 'training time (minutes)=', '0.1788', 'loss=', '0.000464115')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000960299')
# ('Epoch:', '0071', 'training time (minutes)=', '0.1786', 'loss=', '0.000465934')
# ('Epoch:', '0072', 'training time (minutes)=', '0.1789', 'loss=', '0.000457821')
# ('Epoch:', '0073', 'training time (minutes)=', '0.1785', 'loss=', '0.000464872')
# ('Epoch:', '0074', 'training time (minutes)=', '0.1784', 'loss=', '0.000463085')
# ('Epoch:', '0075', 'training time (minutes)=', '0.1784', 'loss=', '0.000463829')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000955995')
# ('Epoch:', '0076', 'training time (minutes)=', '0.1786', 'loss=', '0.000456612')
# ('Epoch:', '0077', 'training time (minutes)=', '0.1788', 'loss=', '0.000452837')
# ('Epoch:', '0078', 'training time (minutes)=', '0.1791', 'loss=', '0.000444440')
# ('Epoch:', '0079', 'training time (minutes)=', '0.1786', 'loss=', '0.000443672')
# ('Epoch:', '0080', 'training time (minutes)=', '0.1784', 'loss=', '0.000435524')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000943285')
# ('Epoch:', '0081', 'training time (minutes)=', '0.1793', 'loss=', '0.000434777')
# ('Epoch:', '0082', 'training time (minutes)=', '0.1787', 'loss=', '0.000423177')
# ('Epoch:', '0083', 'training time (minutes)=', '0.1782', 'loss=', '0.000421292')
# ('Epoch:', '0084', 'training time (minutes)=', '0.1785', 'loss=', '0.000419358')
# ('Epoch:', '0085', 'training time (minutes)=', '0.1785', 'loss=', '0.000429481')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000980967')
# ('Epoch:', '0086', 'training time (minutes)=', '0.1783', 'loss=', '0.000424310')
# ('Epoch:', '0087', 'training time (minutes)=', '0.1784', 'loss=', '0.000427937')
# ('Epoch:', '0088', 'training time (minutes)=', '0.1784', 'loss=', '0.000422139')
# ('Epoch:', '0089', 'training time (minutes)=', '0.1782', 'loss=', '0.000415060')
# ('Epoch:', '0090', 'training time (minutes)=', '0.1784', 'loss=', '0.000449347')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000957533')
# ('Epoch:', '0091', 'training time (minutes)=', '0.1783', 'loss=', '0.000422973')
# ('Epoch:', '0092', 'training time (minutes)=', '0.1783', 'loss=', '0.000413693')
# ('Epoch:', '0093', 'training time (minutes)=', '0.1788', 'loss=', '0.000402068')
# ('Epoch:', '0094', 'training time (minutes)=', '0.1785', 'loss=', '0.000404889')
# ('Epoch:', '0095', 'training time (minutes)=', '0.1790', 'loss=', '0.000398888')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000941080')
# ('Epoch:', '0096', 'training time (minutes)=', '0.1788', 'loss=', '0.000400034')
# ('Epoch:', '0097', 'training time (minutes)=', '0.1786', 'loss=', '0.000407292')
# ('Epoch:', '0098', 'training time (minutes)=', '0.1785', 'loss=', '0.000387999')
# ('Epoch:', '0099', 'training time (minutes)=', '0.1786', 'loss=', '0.000385884')
# ('Epoch:', '0100', 'training time (minutes)=', '0.1785', 'loss=', '0.000386750')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000960759')
# ('Epoch:', '0101', 'training time (minutes)=', '0.1786', 'loss=', '0.000381296')
# ('Epoch:', '0102', 'training time (minutes)=', '0.1788', 'loss=', '0.000385284')
# ('Epoch:', '0103', 'training time (minutes)=', '0.1782', 'loss=', '0.000384093')
# ('Epoch:', '0104', 'training time (minutes)=', '0.1784', 'loss=', '0.000376858')
# ('Epoch:', '0105', 'training time (minutes)=', '0.1785', 'loss=', '0.000384540')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000971587')
# ('Epoch:', '0106', 'training time (minutes)=', '0.1785', 'loss=', '0.000378055')
# ('Epoch:', '0107', 'training time (minutes)=', '0.1787', 'loss=', '0.000377578')
# ('Epoch:', '0108', 'training time (minutes)=', '0.1781', 'loss=', '0.000377933')
# ('Epoch:', '0109', 'training time (minutes)=', '0.1785', 'loss=', '0.000382185')
# ('Epoch:', '0110', 'training time (minutes)=', '0.1785', 'loss=', '0.000376543')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000953506')
# ('Epoch:', '0111', 'training time (minutes)=', '0.1783', 'loss=', '0.000375422')
# ('Epoch:', '0112', 'training time (minutes)=', '0.1782', 'loss=', '0.000361797')
# ('Epoch:', '0113', 'training time (minutes)=', '0.1786', 'loss=', '0.000356484')
# ('Epoch:', '0114', 'training time (minutes)=', '0.1784', 'loss=', '0.000354161')
# ('Epoch:', '0115', 'training time (minutes)=', '0.1781', 'loss=', '0.000355535')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000955788')
# ('Epoch:', '0116', 'training time (minutes)=', '0.1779', 'loss=', '0.000352582')
# ('Epoch:', '0117', 'training time (minutes)=', '0.1782', 'loss=', '0.000353014')
# ('Epoch:', '0118', 'training time (minutes)=', '0.1781', 'loss=', '0.000370228')
# ('Epoch:', '0119', 'training time (minutes)=', '0.1783', 'loss=', '0.000365185')
# ('Epoch:', '0120', 'training time (minutes)=', '0.1782', 'loss=', '0.000360304')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000953713')
# ('Epoch:', '0121', 'training time (minutes)=', '0.1781', 'loss=', '0.000349683')
# ('Epoch:', '0122', 'training time (minutes)=', '0.1785', 'loss=', '0.000347671')
# ('Epoch:', '0123', 'training time (minutes)=', '0.1788', 'loss=', '0.000352960')
# ('Epoch:', '0124', 'training time (minutes)=', '0.1787', 'loss=', '0.000355583')
# ('Epoch:', '0125', 'training time (minutes)=', '0.1787', 'loss=', '0.000346321')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000963766')
# ('Epoch:', '0126', 'training time (minutes)=', '0.1785', 'loss=', '0.000341403')
# ('Epoch:', '0127', 'training time (minutes)=', '0.1788', 'loss=', '0.000340658')
# ('Epoch:', '0128', 'training time (minutes)=', '0.1788', 'loss=', '0.000341908')
# ('Epoch:', '0129', 'training time (minutes)=', '0.1786', 'loss=', '0.000343659')
# ('Epoch:', '0130', 'training time (minutes)=', '0.1787', 'loss=', '0.000341935')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000971046')
# ('Epoch:', '0131', 'training time (minutes)=', '0.1783', 'loss=', '0.000347059')
# ('Epoch:', '0132', 'training time (minutes)=', '0.1781', 'loss=', '0.000338243')
# ('Epoch:', '0133', 'training time (minutes)=', '0.1780', 'loss=', '0.000336207')
# ('Epoch:', '0134', 'training time (minutes)=', '0.1784', 'loss=', '0.000331814')
# ('Epoch:', '0135', 'training time (minutes)=', '0.1780', 'loss=', '0.000335977')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000953823')
# ('Epoch:', '0136', 'training time (minutes)=', '0.1785', 'loss=', '0.000335079')
# ('Epoch:', '0137', 'training time (minutes)=', '0.1787', 'loss=', '0.000327217')
# ('Epoch:', '0138', 'training time (minutes)=', '0.1783', 'loss=', '0.000327089')
# ('Epoch:', '0139', 'training time (minutes)=', '0.1787', 'loss=', '0.000325533')
# ('Epoch:', '0140', 'training time (minutes)=', '0.1783', 'loss=', '0.000326514')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000956058')
# ('Epoch:', '0141', 'training time (minutes)=', '0.1785', 'loss=', '0.000329105')
# ('Epoch:', '0142', 'training time (minutes)=', '0.1785', 'loss=', '0.000330140')
# ('Epoch:', '0143', 'training time (minutes)=', '0.1783', 'loss=', '0.000323804')
# ('Epoch:', '0144', 'training time (minutes)=', '0.1785', 'loss=', '0.000328828')
# ('Epoch:', '0145', 'training time (minutes)=', '0.1783', 'loss=', '0.000326907')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000976382')
# ('Epoch:', '0146', 'training time (minutes)=', '0.1785', 'loss=', '0.000333434')
# ('Epoch:', '0147', 'training time (minutes)=', '0.1784', 'loss=', '0.000325818')
# ('Epoch:', '0148', 'training time (minutes)=', '0.1783', 'loss=', '0.000324847')
# ('Epoch:', '0149', 'training time (minutes)=', '0.1779', 'loss=', '0.000316727')
# ('Epoch:', '0150', 'training time (minutes)=', '0.1787', 'loss=', '0.000313030')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000972635')
# ('Epoch:', '0151', 'training time (minutes)=', '0.1781', 'loss=', '0.000308854')
# ('Epoch:', '0152', 'training time (minutes)=', '0.1785', 'loss=', '0.000311612')
# ('Epoch:', '0153', 'training time (minutes)=', '0.1781', 'loss=', '0.000313072')
# ('Epoch:', '0154', 'training time (minutes)=', '0.1778', 'loss=', '0.000312203')
# ('Epoch:', '0155', 'training time (minutes)=', '0.1781', 'loss=', '0.000316129')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000964992')
# ('Epoch:', '0156', 'training time (minutes)=', '0.1781', 'loss=', '0.000315178')
# ('Epoch:', '0157', 'training time (minutes)=', '0.1784', 'loss=', '0.000309831')
# ('Epoch:', '0158', 'training time (minutes)=', '0.1788', 'loss=', '0.000309116')
# ('Epoch:', '0159', 'training time (minutes)=', '0.1783', 'loss=', '0.000305863')
# ('Epoch:', '0160', 'training time (minutes)=', '0.1782', 'loss=', '0.000305281')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000957730')
# ('Epoch:', '0161', 'training time (minutes)=', '0.1787', 'loss=', '0.000308634')
# ('Epoch:', '0162', 'training time (minutes)=', '0.1780', 'loss=', '0.000308006')
# ('Epoch:', '0163', 'training time (minutes)=', '0.1780', 'loss=', '0.000307128')
# ('Epoch:', '0164', 'training time (minutes)=', '0.1777', 'loss=', '0.000304798')
# ('Epoch:', '0165', 'training time (minutes)=', '0.1782', 'loss=', '0.000305641')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000967491')
# ('Epoch:', '0166', 'training time (minutes)=', '0.1781', 'loss=', '0.000304147')
# ('Epoch:', '0167', 'training time (minutes)=', '0.1781', 'loss=', '0.000306414')
# ('Epoch:', '0168', 'training time (minutes)=', '0.1781', 'loss=', '0.000303510')
# ('Epoch:', '0169', 'training time (minutes)=', '0.1782', 'loss=', '0.000304303')
# ('Epoch:', '0170', 'training time (minutes)=', '0.1778', 'loss=', '0.000302818')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000976640')
# ('Epoch:', '0171', 'training time (minutes)=', '0.1777', 'loss=', '0.000300210')
# ('Epoch:', '0172', 'training time (minutes)=', '0.1779', 'loss=', '0.000302579')
# ('Epoch:', '0173', 'training time (minutes)=', '0.1781', 'loss=', '0.000300362')
# ('Epoch:', '0174', 'training time (minutes)=', '0.1777', 'loss=', '0.000297778')
# ('Epoch:', '0175', 'training time (minutes)=', '0.1781', 'loss=', '0.000295299')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000957753')
# ('Epoch:', '0176', 'training time (minutes)=', '0.1781', 'loss=', '0.000296585')
# ('Epoch:', '0177', 'training time (minutes)=', '0.1780', 'loss=', '0.000295573')
# ('Epoch:', '0178', 'training time (minutes)=', '0.1780', 'loss=', '0.000292989')
# ('Epoch:', '0179', 'training time (minutes)=', '0.1781', 'loss=', '0.000292423')
# ('Epoch:', '0180', 'training time (minutes)=', '0.1779', 'loss=', '0.000291839')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000972554')
# ('Epoch:', '0181', 'training time (minutes)=', '0.1780', 'loss=', '0.000289897')
# ('Epoch:', '0182', 'training time (minutes)=', '0.1781', 'loss=', '0.000292651')
# ('Epoch:', '0183', 'training time (minutes)=', '0.1782', 'loss=', '0.000287162')
# ('Epoch:', '0184', 'training time (minutes)=', '0.1785', 'loss=', '0.000290711')
# ('Epoch:', '0185', 'training time (minutes)=', '0.1778', 'loss=', '0.000292352')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000989015')
# ('Epoch:', '0186', 'training time (minutes)=', '0.1778', 'loss=', '0.000289694')
# ('Epoch:', '0187', 'training time (minutes)=', '0.1780', 'loss=', '0.000296292')
# ('Epoch:', '0188', 'training time (minutes)=', '0.1778', 'loss=', '0.000291302')
# ('Epoch:', '0189', 'training time (minutes)=', '0.1780', 'loss=', '0.000289925')
# ('Epoch:', '0190', 'training time (minutes)=', '0.1776', 'loss=', '0.000288084')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000960719')
# ('Epoch:', '0191', 'training time (minutes)=', '0.1775', 'loss=', '0.000288872')
# ('Epoch:', '0192', 'training time (minutes)=', '0.1777', 'loss=', '0.000286641')
# ('Epoch:', '0193', 'training time (minutes)=', '0.1774', 'loss=', '0.000288480')
# ('Epoch:', '0194', 'training time (minutes)=', '0.1778', 'loss=', '0.000286603')
# ('Epoch:', '0195', 'training time (minutes)=', '0.1784', 'loss=', '0.000284462')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000970454')
# ('Epoch:', '0196', 'training time (minutes)=', '0.1776', 'loss=', '0.000280539')
# ('Epoch:', '0197', 'training time (minutes)=', '0.1780', 'loss=', '0.000276429')
# ('Epoch:', '0198', 'training time (minutes)=', '0.1782', 'loss=', '0.000282973')
# ('Epoch:', '0199', 'training time (minutes)=', '0.1779', 'loss=', '0.000287513')
# ('Epoch:', '0200', 'training time (minutes)=', '0.1778', 'loss=', '0.000291312')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000964070')
# ('Epoch:', '0201', 'training time (minutes)=', '0.1779', 'loss=', '0.000283246')
# ('Epoch:', '0202', 'training time (minutes)=', '0.1778', 'loss=', '0.000284332')
# ('Epoch:', '0203', 'training time (minutes)=', '0.1781', 'loss=', '0.000279773')
# ('Epoch:', '0204', 'training time (minutes)=', '0.1781', 'loss=', '0.000281044')
# ('Epoch:', '0205', 'training time (minutes)=', '0.1781', 'loss=', '0.000281752')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000975147')
# ('Epoch:', '0206', 'training time (minutes)=', '0.1779', 'loss=', '0.000279258')
# ('Epoch:', '0207', 'training time (minutes)=', '0.1786', 'loss=', '0.000278139')
# ('Epoch:', '0208', 'training time (minutes)=', '0.1780', 'loss=', '0.000277745')
# ('Epoch:', '0209', 'training time (minutes)=', '0.1778', 'loss=', '0.000275550')
# ('Epoch:', '0210', 'training time (minutes)=', '0.1776', 'loss=', '0.000276080')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000985593')
# ('Epoch:', '0211', 'training time (minutes)=', '0.1775', 'loss=', '0.000276306')
# ('Epoch:', '0212', 'training time (minutes)=', '0.1781', 'loss=', '0.000274884')
# ('Epoch:', '0213', 'training time (minutes)=', '0.1777', 'loss=', '0.000273327')
# ('Epoch:', '0214', 'training time (minutes)=', '0.1779', 'loss=', '0.000276761')
# ('Epoch:', '0215', 'training time (minutes)=', '0.1775', 'loss=', '0.000275074')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000960877')
# ('Epoch:', '0216', 'training time (minutes)=', '0.1778', 'loss=', '0.000272108')
# ('Epoch:', '0217', 'training time (minutes)=', '0.1778', 'loss=', '0.000272657')
# ('Epoch:', '0218', 'training time (minutes)=', '0.1782', 'loss=', '0.000276748')
# ('Epoch:', '0219', 'training time (minutes)=', '0.1779', 'loss=', '0.000275892')
# ('Epoch:', '0220', 'training time (minutes)=', '0.1782', 'loss=', '0.000276624')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000980288')
# ('Epoch:', '0221', 'training time (minutes)=', '0.1778', 'loss=', '0.000273607')
# ('Epoch:', '0222', 'training time (minutes)=', '0.1784', 'loss=', '0.000272528')
# ('Epoch:', '0223', 'training time (minutes)=', '0.1779', 'loss=', '0.000269843')
# ('Epoch:', '0224', 'training time (minutes)=', '0.1780', 'loss=', '0.000270596')
# ('Epoch:', '0225', 'training time (minutes)=', '0.1782', 'loss=', '0.000270402')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000965899')
# ('Epoch:', '0226', 'training time (minutes)=', '0.1777', 'loss=', '0.000269520')
# ('Epoch:', '0227', 'training time (minutes)=', '0.1777', 'loss=', '0.000271091')
# ('Epoch:', '0228', 'training time (minutes)=', '0.1776', 'loss=', '0.000271499')
# ('Epoch:', '0229', 'training time (minutes)=', '0.1782', 'loss=', '0.000275125')
# ('Epoch:', '0230', 'training time (minutes)=', '0.1778', 'loss=', '0.000269439')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000986196')
# ('Epoch:', '0231', 'training time (minutes)=', '0.1777', 'loss=', '0.000270360')
# ('Epoch:', '0232', 'training time (minutes)=', '0.1783', 'loss=', '0.000270403')
# ('Epoch:', '0233', 'training time (minutes)=', '0.1778', 'loss=', '0.000272842')
# ('Epoch:', '0234', 'training time (minutes)=', '0.1781', 'loss=', '0.000270520')
# ('Epoch:', '0235', 'training time (minutes)=', '0.1777', 'loss=', '0.000265769')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000978295')
# ('Epoch:', '0236', 'training time (minutes)=', '0.1779', 'loss=', '0.000278826')
# ('Epoch:', '0237', 'training time (minutes)=', '0.1776', 'loss=', '0.000277427')
# ('Epoch:', '0238', 'training time (minutes)=', '0.1776', 'loss=', '0.000275122')
# ('Epoch:', '0239', 'training time (minutes)=', '0.1777', 'loss=', '0.000270641')
# ('Epoch:', '0240', 'training time (minutes)=', '0.1775', 'loss=', '0.000265209')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000986725')
# ('Epoch:', '0241', 'training time (minutes)=', '0.1778', 'loss=', '0.000259681')
# ('Epoch:', '0242', 'training time (minutes)=', '0.1778', 'loss=', '0.000259537')
# ('Epoch:', '0243', 'training time (minutes)=', '0.1781', 'loss=', '0.000260835')
# ('Epoch:', '0244', 'training time (minutes)=', '0.1783', 'loss=', '0.000261246')
# ('Epoch:', '0245', 'training time (minutes)=', '0.1783', 'loss=', '0.000260982')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000976367')
# ('Epoch:', '0246', 'training time (minutes)=', '0.1777', 'loss=', '0.000261386')
# ('Epoch:', '0247', 'training time (minutes)=', '0.1776', 'loss=', '0.000261239')
# ('Epoch:', '0248', 'training time (minutes)=', '0.1782', 'loss=', '0.000261074')
# ('Epoch:', '0249', 'training time (minutes)=', '0.1776', 'loss=', '0.000265006')
# ('Epoch:', '0250', 'training time (minutes)=', '0.1776', 'loss=', '0.000265422')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000976426')
# ('Epoch:', '0251', 'training time (minutes)=', '0.1775', 'loss=', '0.000262691')
# ('Epoch:', '0252', 'training time (minutes)=', '0.1786', 'loss=', '0.000261816')
# ('Epoch:', '0253', 'training time (minutes)=', '0.1779', 'loss=', '0.000258432')
# ('Epoch:', '0254', 'training time (minutes)=', '0.1780', 'loss=', '0.000263062')
# ('Epoch:', '0255', 'training time (minutes)=', '0.1779', 'loss=', '0.000262395')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000990965')
# ('Epoch:', '0256', 'training time (minutes)=', '0.1778', 'loss=', '0.000265400')
# ('Epoch:', '0257', 'training time (minutes)=', '0.1775', 'loss=', '0.000263516')
# ('Epoch:', '0258', 'training time (minutes)=', '0.1774', 'loss=', '0.000258737')
# ('Epoch:', '0259', 'training time (minutes)=', '0.1776', 'loss=', '0.000257496')
# ('Epoch:', '0260', 'training time (minutes)=', '0.1774', 'loss=', '0.000258023')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000971377')
# ('Epoch:', '0261', 'training time (minutes)=', '0.1777', 'loss=', '0.000264299')
# ('Epoch:', '0262', 'training time (minutes)=', '0.1777', 'loss=', '0.000260408')
# ('Epoch:', '0263', 'training time (minutes)=', '0.1780', 'loss=', '0.000260422')
# ('Epoch:', '0264', 'training time (minutes)=', '0.1778', 'loss=', '0.000256648')
# ('Epoch:', '0265', 'training time (minutes)=', '0.1773', 'loss=', '0.000258082')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000982077')
# ('Epoch:', '0266', 'training time (minutes)=', '0.1780', 'loss=', '0.000256323')
# ('Epoch:', '0267', 'training time (minutes)=', '0.1779', 'loss=', '0.000258599')
# ('Epoch:', '0268', 'training time (minutes)=', '0.1778', 'loss=', '0.000256006')
# ('Epoch:', '0269', 'training time (minutes)=', '0.1776', 'loss=', '0.000254089')
# ('Epoch:', '0270', 'training time (minutes)=', '0.1781', 'loss=', '0.000254859')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000996334')
# ('Epoch:', '0271', 'training time (minutes)=', '0.1780', 'loss=', '0.000258645')
# ('Epoch:', '0272', 'training time (minutes)=', '0.1778', 'loss=', '0.000262710')
# ('Epoch:', '0273', 'training time (minutes)=', '0.1775', 'loss=', '0.000258681')
# ('Epoch:', '0274', 'training time (minutes)=', '0.1771', 'loss=', '0.000249502')
# ('Epoch:', '0275', 'training time (minutes)=', '0.1777', 'loss=', '0.000251018')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000986540')
# ('Epoch:', '0276', 'training time (minutes)=', '0.1781', 'loss=', '0.000252600')
# ('Epoch:', '0277', 'training time (minutes)=', '0.1775', 'loss=', '0.000260534')
# ('Epoch:', '0278', 'training time (minutes)=', '0.1778', 'loss=', '0.000255770')
# ('Epoch:', '0279', 'training time (minutes)=', '0.1781', 'loss=', '0.000255028')
# ('Epoch:', '0280', 'training time (minutes)=', '0.1777', 'loss=', '0.000253394')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000978862')
# ('Epoch:', '0281', 'training time (minutes)=', '0.1777', 'loss=', '0.000252492')
# ('Epoch:', '0282', 'training time (minutes)=', '0.1777', 'loss=', '0.000251436')
# ('Epoch:', '0283', 'training time (minutes)=', '0.1776', 'loss=', '0.000249400')
# ('Epoch:', '0284', 'training time (minutes)=', '0.1772', 'loss=', '0.000252261')
# ('Epoch:', '0285', 'training time (minutes)=', '0.1777', 'loss=', '0.000252064')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000986268')
# ('Epoch:', '0286', 'training time (minutes)=', '0.1777', 'loss=', '0.000253416')
# ('Epoch:', '0287', 'training time (minutes)=', '0.1782', 'loss=', '0.000253007')
# ('Epoch:', '0288', 'training time (minutes)=', '0.1777', 'loss=', '0.000253081')
# ('Epoch:', '0289', 'training time (minutes)=', '0.1781', 'loss=', '0.000252042')
# ('Epoch:', '0290', 'training time (minutes)=', '0.1775', 'loss=', '0.000253845')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000984725')
# ('Epoch:', '0291', 'training time (minutes)=', '0.1780', 'loss=', '0.000255212')
# ('Epoch:', '0292', 'training time (minutes)=', '0.1771', 'loss=', '0.000258882')
# ('Epoch:', '0293', 'training time (minutes)=', '0.1773', 'loss=', '0.000252693')
# ('Epoch:', '0294', 'training time (minutes)=', '0.1777', 'loss=', '0.000251864')
# ('Epoch:', '0295', 'training time (minutes)=', '0.1781', 'loss=', '0.000249721')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000966475')
# ('Epoch:', '0296', 'training time (minutes)=', '0.1783', 'loss=', '0.000246942')
# ('Epoch:', '0297', 'training time (minutes)=', '0.1773', 'loss=', '0.000246630')
# ('Epoch:', '0298', 'training time (minutes)=', '0.1773', 'loss=', '0.000248813')
# ('Epoch:', '0299', 'training time (minutes)=', '0.1780', 'loss=', '0.000251395')
# ('Epoch:', '0300', 'training time (minutes)=', '0.1774', 'loss=', '0.000251566')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000986633')
# ('Epoch:', '0301', 'training time (minutes)=', '0.1772', 'loss=', '0.000250811')
# ('Epoch:', '0302', 'training time (minutes)=', '0.1781', 'loss=', '0.000249155')
# ('Epoch:', '0303', 'training time (minutes)=', '0.1783', 'loss=', '0.000250115')
# ('Epoch:', '0304', 'training time (minutes)=', '0.1787', 'loss=', '0.000247803')
# ('Epoch:', '0305', 'training time (minutes)=', '0.1783', 'loss=', '0.000254144')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000983613')
# ('Epoch:', '0306', 'training time (minutes)=', '0.1776', 'loss=', '0.000252030')
# ('Epoch:', '0307', 'training time (minutes)=', '0.1779', 'loss=', '0.000248667')
# ('Epoch:', '0308', 'training time (minutes)=', '0.1781', 'loss=', '0.000247966')
# ('Epoch:', '0309', 'training time (minutes)=', '0.1781', 'loss=', '0.000244797')
# ('Epoch:', '0310', 'training time (minutes)=', '0.1776', 'loss=', '0.000246449')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000972645')
# ('Epoch:', '0311', 'training time (minutes)=', '0.1780', 'loss=', '0.000244026')
# ('Epoch:', '0312', 'training time (minutes)=', '0.1779', 'loss=', '0.000245005')
# ('Epoch:', '0313', 'training time (minutes)=', '0.1775', 'loss=', '0.000244948')
# ('Epoch:', '0314', 'training time (minutes)=', '0.1775', 'loss=', '0.000248790')
# ('Epoch:', '0315', 'training time (minutes)=', '0.1774', 'loss=', '0.000248231')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000990868')
# ('Epoch:', '0316', 'training time (minutes)=', '0.1776', 'loss=', '0.000249256')
# ('Epoch:', '0317', 'training time (minutes)=', '0.1775', 'loss=', '0.000251947')
# ('Epoch:', '0318', 'training time (minutes)=', '0.1772', 'loss=', '0.000251178')
# ('Epoch:', '0319', 'training time (minutes)=', '0.1774', 'loss=', '0.000250641')
# ('Epoch:', '0320', 'training time (minutes)=', '0.1771', 'loss=', '0.000249074')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000980713')
# ('Epoch:', '0321', 'training time (minutes)=', '0.1780', 'loss=', '0.000245034')
# ('Epoch:', '0322', 'training time (minutes)=', '0.1774', 'loss=', '0.000239746')
# ('Epoch:', '0323', 'training time (minutes)=', '0.1775', 'loss=', '0.000239565')
# ('Epoch:', '0324', 'training time (minutes)=', '0.1773', 'loss=', '0.000240336')
# ('Epoch:', '0325', 'training time (minutes)=', '0.1772', 'loss=', '0.000244238')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000990407')
# ('Epoch:', '0326', 'training time (minutes)=', '0.1773', 'loss=', '0.000243957')
# ('Epoch:', '0327', 'training time (minutes)=', '0.1777', 'loss=', '0.000246441')
# ('Epoch:', '0328', 'training time (minutes)=', '0.1774', 'loss=', '0.000245512')
# ('Epoch:', '0329', 'training time (minutes)=', '0.1775', 'loss=', '0.000245335')
# ('Epoch:', '0330', 'training time (minutes)=', '0.1773', 'loss=', '0.000241768')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000977156')
# ('Epoch:', '0331', 'training time (minutes)=', '0.1775', 'loss=', '0.000243984')
# ('Epoch:', '0332', 'training time (minutes)=', '0.1778', 'loss=', '0.000242237')
# ('Epoch:', '0333', 'training time (minutes)=', '0.1776', 'loss=', '0.000240107')
# ('Epoch:', '0334', 'training time (minutes)=', '0.1774', 'loss=', '0.000240486')
# ('Epoch:', '0335', 'training time (minutes)=', '0.1771', 'loss=', '0.000243114')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.000983287')
# ('Epoch:', '0336', 'training time (minutes)=', '0.1772', 'loss=', '0.000246862')
# ('Epoch:', '0337', 'training time (minutes)=', '0.1771', 'loss=', '0.000244003')
# ('Epoch:', '0338', 'training time (minutes)=', '0.1773', 'loss=', '0.000243116')
# ('Epoch:', '0339', 'training time (minutes)=', '0.1775', 'loss=', '0.000243905')
# ('Epoch:', '0340', 'training time (minutes)=', '0.1774', 'loss=', '0.000240395')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000984423')
# ('Epoch:', '0341', 'training time (minutes)=', '0.1774', 'loss=', '0.000245873')
# ('Epoch:', '0342', 'training time (minutes)=', '0.1774', 'loss=', '0.000243573')
# ('Epoch:', '0343', 'training time (minutes)=', '0.1775', 'loss=', '0.000241612')
# ('Epoch:', '0344', 'training time (minutes)=', '0.1773', 'loss=', '0.000242704')
# ('Epoch:', '0345', 'training time (minutes)=', '0.1775', 'loss=', '0.000242682')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000978017')
# ('Epoch:', '0346', 'training time (minutes)=', '0.1771', 'loss=', '0.000238577')
# ('Epoch:', '0347', 'training time (minutes)=', '0.1774', 'loss=', '0.000246690')
# ('Epoch:', '0348', 'training time (minutes)=', '0.1773', 'loss=', '0.000248267')
# ('Epoch:', '0349', 'training time (minutes)=', '0.1776', 'loss=', '0.000242746')
# ('Epoch:', '0350', 'training time (minutes)=', '0.1774', 'loss=', '0.000238873')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000992151')
# ('Epoch:', '0351', 'training time (minutes)=', '0.1777', 'loss=', '0.000239794')
# ('Epoch:', '0352', 'training time (minutes)=', '0.1778', 'loss=', '0.000237244')
# ('Epoch:', '0353', 'training time (minutes)=', '0.1777', 'loss=', '0.000238014')
# ('Epoch:', '0354', 'training time (minutes)=', '0.1774', 'loss=', '0.000237749')
# ('Epoch:', '0355', 'training time (minutes)=', '0.1774', 'loss=', '0.000242380')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.000989649')
# ('Epoch:', '0356', 'training time (minutes)=', '0.1772', 'loss=', '0.000241320')
# ('Epoch:', '0357', 'training time (minutes)=', '0.1773', 'loss=', '0.000237628')
# ('Epoch:', '0358', 'training time (minutes)=', '0.1773', 'loss=', '0.000236698')
# ('Epoch:', '0359', 'training time (minutes)=', '0.1770', 'loss=', '0.000237931')
# ('Epoch:', '0360', 'training time (minutes)=', '0.1772', 'loss=', '0.000239513')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000985091')
# ('Epoch:', '0361', 'training time (minutes)=', '0.1776', 'loss=', '0.000242644')
# ('Epoch:', '0362', 'training time (minutes)=', '0.1774', 'loss=', '0.000241086')
# ('Epoch:', '0363', 'training time (minutes)=', '0.1777', 'loss=', '0.000241483')
# ('Epoch:', '0364', 'training time (minutes)=', '0.1775', 'loss=', '0.000239496')
# ('Epoch:', '0365', 'training time (minutes)=', '0.1776', 'loss=', '0.000239078')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000989968')
# ('Epoch:', '0366', 'training time (minutes)=', '0.1775', 'loss=', '0.000239956')
# ('Epoch:', '0367', 'training time (minutes)=', '0.1773', 'loss=', '0.000237670')
# ('Epoch:', '0368', 'training time (minutes)=', '0.1773', 'loss=', '0.000240668')
# ('Epoch:', '0369', 'training time (minutes)=', '0.1771', 'loss=', '0.000239844')
# ('Epoch:', '0370', 'training time (minutes)=', '0.1778', 'loss=', '0.000238227')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000997212')
# ('Epoch:', '0371', 'training time (minutes)=', '0.1772', 'loss=', '0.000236109')
# ('Epoch:', '0372', 'training time (minutes)=', '0.1771', 'loss=', '0.000235406')
# ('Epoch:', '0373', 'training time (minutes)=', '0.1773', 'loss=', '0.000234728')
# ('Epoch:', '0374', 'training time (minutes)=', '0.1772', 'loss=', '0.000234091')
# ('Epoch:', '0375', 'training time (minutes)=', '0.1775', 'loss=', '0.000235488')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000988132')
# ('Epoch:', '0376', 'training time (minutes)=', '0.1774', 'loss=', '0.000236152')
# ('Epoch:', '0377', 'training time (minutes)=', '0.1770', 'loss=', '0.000237756')
# ('Epoch:', '0378', 'training time (minutes)=', '0.1774', 'loss=', '0.000239266')
# ('Epoch:', '0379', 'training time (minutes)=', '0.1774', 'loss=', '0.000236730')
# ('Epoch:', '0380', 'training time (minutes)=', '0.1768', 'loss=', '0.000235379')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000983348')
# ('Epoch:', '0381', 'training time (minutes)=', '0.1772', 'loss=', '0.000236172')
# ('Epoch:', '0382', 'training time (minutes)=', '0.1773', 'loss=', '0.000236251')
# ('Epoch:', '0383', 'training time (minutes)=', '0.1768', 'loss=', '0.000237730')
# ('Epoch:', '0384', 'training time (minutes)=', '0.1774', 'loss=', '0.000239056')
# ('Epoch:', '0385', 'training time (minutes)=', '0.1770', 'loss=', '0.000240752')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000985285')
# ('Epoch:', '0386', 'training time (minutes)=', '0.1775', 'loss=', '0.000237403')
# ('Epoch:', '0387', 'training time (minutes)=', '0.1775', 'loss=', '0.000237723')
# ('Epoch:', '0388', 'training time (minutes)=', '0.1771', 'loss=', '0.000235238')
# ('Epoch:', '0389', 'training time (minutes)=', '0.1774', 'loss=', '0.000235295')
# ('Epoch:', '0390', 'training time (minutes)=', '0.1777', 'loss=', '0.000235720')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000999110')
# ('Epoch:', '0391', 'training time (minutes)=', '0.1772', 'loss=', '0.000240169')
# ('Epoch:', '0392', 'training time (minutes)=', '0.1772', 'loss=', '0.000241813')
# ('Epoch:', '0393', 'training time (minutes)=', '0.1777', 'loss=', '0.000238352')
# ('Epoch:', '0394', 'training time (minutes)=', '0.1770', 'loss=', '0.000235959')
# ('Epoch:', '0395', 'training time (minutes)=', '0.1775', 'loss=', '0.000234392')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000975914')
# ('Epoch:', '0396', 'training time (minutes)=', '0.1772', 'loss=', '0.000232740')
# ('Epoch:', '0397', 'training time (minutes)=', '0.1773', 'loss=', '0.000230483')
# ('Epoch:', '0398', 'training time (minutes)=', '0.1771', 'loss=', '0.000231067')
# ('Epoch:', '0399', 'training time (minutes)=', '0.1771', 'loss=', '0.000233109')
# ('Epoch:', '0400', 'training time (minutes)=', '0.1772', 'loss=', '0.000235627')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.000996559')
# ('Epoch:', '0401', 'training time (minutes)=', '0.1805', 'loss=', '0.000234957')
# ('Epoch:', '0402', 'training time (minutes)=', '0.1814', 'loss=', '0.000234356')
# ('Epoch:', '0403', 'training time (minutes)=', '0.1824', 'loss=', '0.000234373')
# ('Epoch:', '0404', 'training time (minutes)=', '0.1781', 'loss=', '0.000235710')
# ('Epoch:', '0405', 'training time (minutes)=', '0.1829', 'loss=', '0.000232417')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000995750')
# ('Epoch:', '0406', 'training time (minutes)=', '0.1807', 'loss=', '0.000234188')
# ('Epoch:', '0407', 'training time (minutes)=', '0.1830', 'loss=', '0.000232626')
# ('Epoch:', '0408', 'training time (minutes)=', '0.1808', 'loss=', '0.000234266')
# ('Epoch:', '0409', 'training time (minutes)=', '0.1889', 'loss=', '0.000233716')
# ('Epoch:', '0410', 'training time (minutes)=', '0.1803', 'loss=', '0.000230801')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000991348')
# ('Epoch:', '0411', 'training time (minutes)=', '0.1812', 'loss=', '0.000230801')
# ('Epoch:', '0412', 'training time (minutes)=', '0.1795', 'loss=', '0.000229890')
# ('Epoch:', '0413', 'training time (minutes)=', '0.1896', 'loss=', '0.000232542')
# ('Epoch:', '0414', 'training time (minutes)=', '0.1813', 'loss=', '0.000233183')
# ('Epoch:', '0415', 'training time (minutes)=', '0.1878', 'loss=', '0.000237219')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000993274')
# ('Epoch:', '0416', 'training time (minutes)=', '0.1880', 'loss=', '0.000234656')
# ('Epoch:', '0417', 'training time (minutes)=', '0.1820', 'loss=', '0.000234065')
# ('Epoch:', '0418', 'training time (minutes)=', '0.1794', 'loss=', '0.000236310')
# ('Epoch:', '0419', 'training time (minutes)=', '0.1829', 'loss=', '0.000232183')
# ('Epoch:', '0420', 'training time (minutes)=', '0.1817', 'loss=', '0.000232170')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000983719')
# ('Epoch:', '0421', 'training time (minutes)=', '0.1852', 'loss=', '0.000231682')
# ('Epoch:', '0422', 'training time (minutes)=', '0.1896', 'loss=', '0.000230868')
# ('Epoch:', '0423', 'training time (minutes)=', '0.1787', 'loss=', '0.000230512')
# ('Epoch:', '0424', 'training time (minutes)=', '0.1925', 'loss=', '0.000228030')
# ('Epoch:', '0425', 'training time (minutes)=', '0.1846', 'loss=', '0.000227580')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000979478')
# ('Epoch:', '0426', 'training time (minutes)=', '0.1870', 'loss=', '0.000229747')
# ('Epoch:', '0427', 'training time (minutes)=', '0.1869', 'loss=', '0.000231082')
# ('Epoch:', '0428', 'training time (minutes)=', '0.1882', 'loss=', '0.000229162')
# ('Epoch:', '0429', 'training time (minutes)=', '0.1851', 'loss=', '0.000230416')
# ('Epoch:', '0430', 'training time (minutes)=', '0.1788', 'loss=', '0.000230868')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000993434')
# ('Epoch:', '0431', 'training time (minutes)=', '0.1882', 'loss=', '0.000233684')
# ('Epoch:', '0432', 'training time (minutes)=', '0.1935', 'loss=', '0.000234385')
# ('Epoch:', '0433', 'training time (minutes)=', '0.1870', 'loss=', '0.000234386')
# ('Epoch:', '0434', 'training time (minutes)=', '0.1924', 'loss=', '0.000235433')
# ('Epoch:', '0435', 'training time (minutes)=', '0.1785', 'loss=', '0.000235100')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.000982820')
# ('Epoch:', '0436', 'training time (minutes)=', '0.1821', 'loss=', '0.000233175')
# ('Epoch:', '0437', 'training time (minutes)=', '0.1982', 'loss=', '0.000231420')
# ('Epoch:', '0438', 'training time (minutes)=', '0.1852', 'loss=', '0.000226919')
# ('Epoch:', '0439', 'training time (minutes)=', '0.1905', 'loss=', '0.000228040')
# ('Epoch:', '0440', 'training time (minutes)=', '0.1852', 'loss=', '0.000227700')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.000992782')
# ('Epoch:', '0441', 'training time (minutes)=', '0.1792', 'loss=', '0.000229843')
# ('Epoch:', '0442', 'training time (minutes)=', '0.1940', 'loss=', '0.000232260')
# ('Epoch:', '0443', 'training time (minutes)=', '0.1840', 'loss=', '0.000228802')
# ('Epoch:', '0444', 'training time (minutes)=', '0.1882', 'loss=', '0.000230966')
# ('Epoch:', '0445', 'training time (minutes)=', '0.1811', 'loss=', '0.000229447')
# ...
# ('Epoch:', '0854', 'training time (minutes)=', '0.1903', 'loss=', '0.000211391')
# ('Epoch:', '0855', 'training time (minutes)=', '0.1890', 'loss=', '0.000210605')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001025921')
# ('Epoch:', '0856', 'training time (minutes)=', '0.1866', 'loss=', '0.000212233')
# ('Epoch:', '0857', 'training time (minutes)=', '0.1954', 'loss=', '0.000209184')
# ('Epoch:', '0858', 'training time (minutes)=', '0.1900', 'loss=', '0.000212000')
# ('Epoch:', '0859', 'training time (minutes)=', '0.1855', 'loss=', '0.000211261')
# ('Epoch:', '0860', 'training time (minutes)=', '0.1819', 'loss=', '0.000212982')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-860 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001033098')
# ('Epoch:', '0861', 'training time (minutes)=', '0.1897', 'loss=', '0.000210556')
# ('Epoch:', '0862', 'training time (minutes)=', '0.1902', 'loss=', '0.000211958')
# ('Epoch:', '0863', 'training time (minutes)=', '0.1902', 'loss=', '0.000212922')
# ('Epoch:', '0864', 'training time (minutes)=', '0.1881', 'loss=', '0.000214324')
# ('Epoch:', '0865', 'training time (minutes)=', '0.1868', 'loss=', '0.000211657')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001028254')
# ('Epoch:', '0866', 'training time (minutes)=', '0.1958', 'loss=', '0.000209414')
# ('Epoch:', '0867', 'training time (minutes)=', '0.1887', 'loss=', '0.000207670')
# ('Epoch:', '0868', 'training time (minutes)=', '0.1918', 'loss=', '0.000208404')
# ('Epoch:', '0869', 'training time (minutes)=', '0.1908', 'loss=', '0.000207000')
# ('Epoch:', '0870', 'training time (minutes)=', '0.1891', 'loss=', '0.000206468')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001025014')
# ('Epoch:', '0871', 'training time (minutes)=', '0.1934', 'loss=', '0.000208347')
# ('Epoch:', '0872', 'training time (minutes)=', '0.1910', 'loss=', '0.000209838')
# ('Epoch:', '0873', 'training time (minutes)=', '0.1927', 'loss=', '0.000210918')
# ('Epoch:', '0874', 'training time (minutes)=', '0.1844', 'loss=', '0.000212947')
# ('Epoch:', '0875', 'training time (minutes)=', '0.1941', 'loss=', '0.000211882')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001028289')
# ('Epoch:', '0876', 'training time (minutes)=', '0.1866', 'loss=', '0.000211410')
# ('Epoch:', '0877', 'training time (minutes)=', '0.1860', 'loss=', '0.000209736')
# ('Epoch:', '0878', 'training time (minutes)=', '0.1894', 'loss=', '0.000208193')
# ('Epoch:', '0879', 'training time (minutes)=', '0.1971', 'loss=', '0.000211593')
# ('Epoch:', '0880', 'training time (minutes)=', '0.1873', 'loss=', '0.000210060')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-880 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001012449')
# ('Epoch:', '0881', 'training time (minutes)=', '0.1856', 'loss=', '0.000209456')
# ('Epoch:', '0882', 'training time (minutes)=', '0.1875', 'loss=', '0.000210901')
# ('Epoch:', '0883', 'training time (minutes)=', '0.1931', 'loss=', '0.000211440')
# ('Epoch:', '0884', 'training time (minutes)=', '0.1898', 'loss=', '0.000210142')
# ('Epoch:', '0885', 'training time (minutes)=', '0.1918', 'loss=', '0.000209998')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001022490')
# ('Epoch:', '0886', 'training time (minutes)=', '0.1993', 'loss=', '0.000209444')
# ('Epoch:', '0887', 'training time (minutes)=', '0.1945', 'loss=', '0.000210864')
# ('Epoch:', '0888', 'training time (minutes)=', '0.1896', 'loss=', '0.000210449')
# ('Epoch:', '0889', 'training time (minutes)=', '0.1905', 'loss=', '0.000210422')
# ('Epoch:', '0890', 'training time (minutes)=', '0.1901', 'loss=', '0.000210695')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.001021660')
# ('Epoch:', '0891', 'training time (minutes)=', '0.1913', 'loss=', '0.000225044')
# ('Epoch:', '0892', 'training time (minutes)=', '0.1833', 'loss=', '0.000218501')
# ('Epoch:', '0893', 'training time (minutes)=', '0.1941', 'loss=', '0.000213404')
# ('Epoch:', '0894', 'training time (minutes)=', '0.1882', 'loss=', '0.000209118')
# ('Epoch:', '0895', 'training time (minutes)=', '0.1839', 'loss=', '0.000208303')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001016075')
# ('Epoch:', '0896', 'training time (minutes)=', '0.1955', 'loss=', '0.000207931')
# ('Epoch:', '0897', 'training time (minutes)=', '0.1885', 'loss=', '0.000207645')
# ('Epoch:', '0898', 'training time (minutes)=', '0.1911', 'loss=', '0.000207246')
# ('Epoch:', '0899', 'training time (minutes)=', '0.1895', 'loss=', '0.000206166')
# ('Epoch:', '0900', 'training time (minutes)=', '0.1947', 'loss=', '0.000207065')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-900 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001021163')
# ('Epoch:', '0901', 'training time (minutes)=', '0.1877', 'loss=', '0.000209634')
# ('Epoch:', '0902', 'training time (minutes)=', '0.1930', 'loss=', '0.000210254')
# ('Epoch:', '0903', 'training time (minutes)=', '0.1887', 'loss=', '0.000209346')
# ('Epoch:', '0904', 'training time (minutes)=', '0.1910', 'loss=', '0.000211292')
# ('Epoch:', '0905', 'training time (minutes)=', '0.1859', 'loss=', '0.000213421')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001032284')
# ('Epoch:', '0906', 'training time (minutes)=', '0.1902', 'loss=', '0.000211048')
# ('Epoch:', '0907', 'training time (minutes)=', '0.1938', 'loss=', '0.000216951')
# ('Epoch:', '0908', 'training time (minutes)=', '0.1848', 'loss=', '0.000212839')
# ('Epoch:', '0909', 'training time (minutes)=', '0.1870', 'loss=', '0.000210925')
# ('Epoch:', '0910', 'training time (minutes)=', '0.1873', 'loss=', '0.000207003')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001022896')
# ('Epoch:', '0911', 'training time (minutes)=', '0.1862', 'loss=', '0.000206254')
# ('Epoch:', '0912', 'training time (minutes)=', '0.1942', 'loss=', '0.000207209')
# ('Epoch:', '0913', 'training time (minutes)=', '0.1861', 'loss=', '0.000205433')
# ('Epoch:', '0914', 'training time (minutes)=', '0.1873', 'loss=', '0.000206591')
# ('Epoch:', '0915', 'training time (minutes)=', '0.1881', 'loss=', '0.000207023')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001025088')
# ('Epoch:', '0916', 'training time (minutes)=', '0.1847', 'loss=', '0.000208320')
# ('Epoch:', '0917', 'training time (minutes)=', '0.1907', 'loss=', '0.000207658')
# ('Epoch:', '0918', 'training time (minutes)=', '0.1924', 'loss=', '0.000208166')
# ('Epoch:', '0919', 'training time (minutes)=', '0.1860', 'loss=', '0.000209392')
# ('Epoch:', '0920', 'training time (minutes)=', '0.1875', 'loss=', '0.000212030')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-920 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001015929')
# ('Epoch:', '0921', 'training time (minutes)=', '0.1877', 'loss=', '0.000209702')
# ('Epoch:', '0922', 'training time (minutes)=', '0.1855', 'loss=', '0.000212500')
# ('Epoch:', '0923', 'training time (minutes)=', '0.1882', 'loss=', '0.000213928')
# ('Epoch:', '0924', 'training time (minutes)=', '0.1878', 'loss=', '0.000210140')
# ('Epoch:', '0925', 'training time (minutes)=', '0.1920', 'loss=', '0.000207798')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001026796')
# ('Epoch:', '0926', 'training time (minutes)=', '0.1851', 'loss=', '0.000209675')
# ('Epoch:', '0927', 'training time (minutes)=', '0.1797', 'loss=', '0.000207552')
# ('Epoch:', '0928', 'training time (minutes)=', '0.1997', 'loss=', '0.000206069')
# ('Epoch:', '0929', 'training time (minutes)=', '0.1889', 'loss=', '0.000206398')
# ('Epoch:', '0930', 'training time (minutes)=', '0.1893', 'loss=', '0.000209432')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001015773')
# ('Epoch:', '0931', 'training time (minutes)=', '0.1873', 'loss=', '0.000208868')
# ('Epoch:', '0932', 'training time (minutes)=', '0.1838', 'loss=', '0.000210164')
# ('Epoch:', '0933', 'training time (minutes)=', '0.1875', 'loss=', '0.000211228')
# ('Epoch:', '0934', 'training time (minutes)=', '0.1860', 'loss=', '0.000211367')
# ('Epoch:', '0935', 'training time (minutes)=', '0.1907', 'loss=', '0.000209370')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001021223')
# ('Epoch:', '0936', 'training time (minutes)=', '0.1877', 'loss=', '0.000207729')
# ('Epoch:', '0937', 'training time (minutes)=', '0.1875', 'loss=', '0.000207793')
# ('Epoch:', '0938', 'training time (minutes)=', '0.1936', 'loss=', '0.000206600')
# ('Epoch:', '0939', 'training time (minutes)=', '0.1903', 'loss=', '0.000208317')
# ('Epoch:', '0940', 'training time (minutes)=', '0.1863', 'loss=', '0.000206860')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-940 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001025306')
# ('Epoch:', '0941', 'training time (minutes)=', '0.1884', 'loss=', '0.000207463')
# ('Epoch:', '0942', 'training time (minutes)=', '0.1943', 'loss=', '0.000208510')
# ('Epoch:', '0943', 'training time (minutes)=', '0.1853', 'loss=', '0.000208690')
# ('Epoch:', '0944', 'training time (minutes)=', '0.1851', 'loss=', '0.000207047')
# ('Epoch:', '0945', 'training time (minutes)=', '0.1890', 'loss=', '0.000208572')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001030524')
# ('Epoch:', '0946', 'training time (minutes)=', '0.1869', 'loss=', '0.000209588')
# ('Epoch:', '0947', 'training time (minutes)=', '0.1865', 'loss=', '0.000211898')
# ('Epoch:', '0948', 'training time (minutes)=', '0.1914', 'loss=', '0.000209831')
# ('Epoch:', '0949', 'training time (minutes)=', '0.1910', 'loss=', '0.000208374')
# ('Epoch:', '0950', 'training time (minutes)=', '0.1955', 'loss=', '0.000206509')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001019874')
# ('Epoch:', '0951', 'training time (minutes)=', '0.1886', 'loss=', '0.000207515')
# ('Epoch:', '0952', 'training time (minutes)=', '0.1885', 'loss=', '0.000209488')
# ('Epoch:', '0953', 'training time (minutes)=', '0.1886', 'loss=', '0.000209711')
# ('Epoch:', '0954', 'training time (minutes)=', '0.1870', 'loss=', '0.000208443')
# ('Epoch:', '0955', 'training time (minutes)=', '0.1857', 'loss=', '0.000206958')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001023761')
# ('Epoch:', '0956', 'training time (minutes)=', '0.1795', 'loss=', '0.000206796')
# ('Epoch:', '0957', 'training time (minutes)=', '0.1983', 'loss=', '0.000210312')
# ('Epoch:', '0958', 'training time (minutes)=', '0.1871', 'loss=', '0.000210445')
# ('Epoch:', '0959', 'training time (minutes)=', '0.1878', 'loss=', '0.000208608')
# ('Epoch:', '0960', 'training time (minutes)=', '0.1890', 'loss=', '0.000206852')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-960 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001037820')
# ('Epoch:', '0961', 'training time (minutes)=', '0.1817', 'loss=', '0.000208448')
# ('Epoch:', '0962', 'training time (minutes)=', '0.1824', 'loss=', '0.000205932')
# ('Epoch:', '0963', 'training time (minutes)=', '0.1882', 'loss=', '0.000207909')
# ('Epoch:', '0964', 'training time (minutes)=', '0.1850', 'loss=', '0.000206151')
# ('Epoch:', '0965', 'training time (minutes)=', '0.1876', 'loss=', '0.000207131')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001023043')
# ('Epoch:', '0966', 'training time (minutes)=', '0.1881', 'loss=', '0.000207275')
# ('Epoch:', '0967', 'training time (minutes)=', '0.1946', 'loss=', '0.000210644')
# ('Epoch:', '0968', 'training time (minutes)=', '0.1872', 'loss=', '0.000209895')
# ('Epoch:', '0969', 'training time (minutes)=', '0.1890', 'loss=', '0.000208573')
# ('Epoch:', '0970', 'training time (minutes)=', '0.1886', 'loss=', '0.000209249')
# ('Held Out Data :', 'forward time (minutes)=', '0.0060', 'loss=', '0.001026086')
# ('Epoch:', '0971', 'training time (minutes)=', '0.1916', 'loss=', '0.000207570')
# ('Epoch:', '0972', 'training time (minutes)=', '0.1826', 'loss=', '0.000207330')
# ('Epoch:', '0973', 'training time (minutes)=', '0.1909', 'loss=', '0.000208350')
# ('Epoch:', '0974', 'training time (minutes)=', '0.1944', 'loss=', '0.000208041')
# ('Epoch:', '0975', 'training time (minutes)=', '0.1875', 'loss=', '0.000207912')
# ('Held Out Data :', 'forward time (minutes)=', '0.0060', 'loss=', '0.001026996')
# ('Epoch:', '0976', 'training time (minutes)=', '0.1931', 'loss=', '0.000209775')
# ('Epoch:', '0977', 'training time (minutes)=', '0.1888', 'loss=', '0.000208935')
# ('Epoch:', '0978', 'training time (minutes)=', '0.1868', 'loss=', '0.000209219')
# ('Epoch:', '0979', 'training time (minutes)=', '0.1876', 'loss=', '0.000207599')
# ('Epoch:', '0980', 'training time (minutes)=', '0.1832', 'loss=', '0.000205707')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-980 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0059', 'loss=', '0.001024598')
# ('Epoch:', '0981', 'training time (minutes)=', '0.1800', 'loss=', '0.000205706')
# ('Epoch:', '0982', 'training time (minutes)=', '0.1886', 'loss=', '0.000204501')
# ('Epoch:', '0983', 'training time (minutes)=', '0.1955', 'loss=', '0.000206394')
# ('Epoch:', '0984', 'training time (minutes)=', '0.1933', 'loss=', '0.000208133')
# ('Epoch:', '0985', 'training time (minutes)=', '0.1811', 'loss=', '0.000208323')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001034665')
# ('Epoch:', '0986', 'training time (minutes)=', '0.1937', 'loss=', '0.000211093')
# ('Epoch:', '0987', 'training time (minutes)=', '0.1846', 'loss=', '0.000208087')
# ('Epoch:', '0988', 'training time (minutes)=', '0.1974', 'loss=', '0.000207381')
# ('Epoch:', '0989', 'training time (minutes)=', '0.1845', 'loss=', '0.000208959')
# ('Epoch:', '0990', 'training time (minutes)=', '0.1817', 'loss=', '0.000208811')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001029154')
# ('Epoch:', '0991', 'training time (minutes)=', '0.1935', 'loss=', '0.000209346')
# ('Epoch:', '0992', 'training time (minutes)=', '0.1926', 'loss=', '0.000208424')
# ('Epoch:', '0993', 'training time (minutes)=', '0.1863', 'loss=', '0.000207423')
# ('Epoch:', '0994', 'training time (minutes)=', '0.1911', 'loss=', '0.000207125')
# ('Epoch:', '0995', 'training time (minutes)=', '0.1864', 'loss=', '0.000207394')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.001020810')
# ('Epoch:', '0996', 'training time (minutes)=', '0.1892', 'loss=', '0.000207424')
# ('Epoch:', '0997', 'training time (minutes)=', '0.1875', 'loss=', '0.000206743')
# ('Epoch:', '0998', 'training time (minutes)=', '0.1821', 'loss=', '0.000205447')
# ('Epoch:', '0999', 'training time (minutes)=', '0.1881', 'loss=', '0.000207483')
# ('Epoch:', '1000', 'training time (minutes)=', '0.1845', 'loss=', '0.000209177')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_2048_pts_bneck_512_chamfer/models.ckpt-1000 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001038261')
