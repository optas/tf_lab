# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 3
setup_one_gpu(GPU)
# Out:
# Picking GPU 3

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out.basics import create_dir, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry, decoder_with_fc_only
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs          
from tf_lab.data_sets.shape_net import snc_category_to_synth_id, load_all_point_clouds_under_folder
from tf_lab.data_sets.shape_net import pc_loader as snc_loader

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_points = 2048
do_training = True
first_time_running = True
load_pretrained_model = False
load_epoch = None
seed = 42

# %%
max_training_epochs = 1000
loss = 'chamfer'
bneck_size = 512

class_name = raw_input('Give me the class type: ').lower()
syn_id = snc_category_to_synth_id()[class_name]

experiment_id = raw_input('Give me the experiment ID:').lower()

experiment_name = '_'.join([class_name, experiment_id, str(n_pc_points), 
                           'pts_bneck', str(bneck_size), loss
                           ])

top_data_dir = '/orions4-zfs/projects/optas/DATA/'
train_dir = osp.join(top_data_dir, 'OUT/iclr/nn_models/testing_ae_settings', experiment_name)
create_dir(train_dir)
# Out:
# Give me the class type: chair
# Give me the experiment ID:simply_add_bnorm
# '/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer'

# %%
train_split = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits', syn_id, '85_5_10/train.txt')
test_split = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits', syn_id, '85_5_10/test.txt')

top_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/centered/', str(n_pc_points))
splitter = Data_Splitter(top_pclouds_path, data_file_ending='.ply')

# %%
tr_files = splitter.load_splits(train_split)
pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(tr_files, n_threads=20, loader=snc_loader, verbose=True)
train_data = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)

test_files = splitter.load_splits(test_split)
pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(test_files, n_threads=20, loader=snc_loader, verbose=True)
test_data = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)
# Out:
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# 679 pclouds were loaded. They belong in 1 shape-classes.

# %%
encoder_args = { 'n_filters': [128, 128, 256, bneck_size],
                 'filter_sizes': [40, 20, 10, 10],
                 'strides': [1, 1, 2, 2],
                 'b_norm': True,
                }

decoder_args = {'layer_sizes': [1024, 2048, n_pc_points*3], 'b_norm': True}

# %%
if load_pretrained_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    if conf.train_dir != train_dir:
        conf.train_dir = train_dir
    conf.save(osp.join(train_dir, 'configuration'))
else:
    conf = Conf(
                n_input = [n_pc_points, 3],
                loss = loss,
                training_epochs = 1000,
                batch_size = 50,
                denoising = False,
                learning_rate = 0.0005,
                train_dir = train_dir,              
                loss_display_step = 1,                
                saver_step = 20,
                z_rotate = False,
                encoder = encoder_with_convs_and_symmetry,
                decoder = decoder_with_fc_only,
                encoder_args = encoder_args,
                decoder_args = decoder_args                
               )    
    conf.experiment_name = experiment_name
    conf.held_out_step = 5
    conf.save(osp.join(conf.train_dir, 'configuration'))

# %%
reset_tf_graph()
ae = PointNetAutoEncoder(conf.experiment_name, conf)

# %%
if load_pretrained_model:
    if load_epoch is None: # load last saved.
        saved_epochs = read_saved_epochs(conf.train_dir)
        load_epoch = saved_epochs[-1]        
    ae.restore_model(conf.train_dir, load_epoch, verbose=True)

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
    train_stats = ae.train(train_data, conf, log_file=fout, held_out_data=test_data)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.2177', 'loss=', '0.018027235')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '0.2155', 'loss=', '0.005466348')
# ('Epoch:', '0003', 'training time (minutes)=', '0.2201', 'loss=', '0.005321895')
# ('Epoch:', '0004', 'training time (minutes)=', '0.2203', 'loss=', '0.006628774')
# ('Epoch:', '0005', 'training time (minutes)=', '0.2260', 'loss=', '0.006283150')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.005291850')
# ('Epoch:', '0006', 'training time (minutes)=', '0.2284', 'loss=', '0.005507734')
# ('Epoch:', '0007', 'training time (minutes)=', '0.2221', 'loss=', '0.005766022')
# ('Epoch:', '0008', 'training time (minutes)=', '0.2237', 'loss=', '0.005258909')
# ('Epoch:', '0009', 'training time (minutes)=', '0.2220', 'loss=', '0.005198860')
# ('Epoch:', '0010', 'training time (minutes)=', '0.2219', 'loss=', '0.004975568')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.003213437')
# ('Epoch:', '0011', 'training time (minutes)=', '0.2296', 'loss=', '0.004154009')
# ('Epoch:', '0012', 'training time (minutes)=', '0.2218', 'loss=', '0.003156604')
# ('Epoch:', '0013', 'training time (minutes)=', '0.2195', 'loss=', '0.002874068')
# ('Epoch:', '0014', 'training time (minutes)=', '0.2297', 'loss=', '0.006138523')
# ('Epoch:', '0015', 'training time (minutes)=', '0.2210', 'loss=', '0.002948850')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.002433293')
# ('Epoch:', '0016', 'training time (minutes)=', '0.2210', 'loss=', '0.002624738')
# ('Epoch:', '0017', 'training time (minutes)=', '0.2255', 'loss=', '0.002475818')
# ('Epoch:', '0018', 'training time (minutes)=', '0.2249', 'loss=', '0.002178222')
# ('Epoch:', '0019', 'training time (minutes)=', '0.2179', 'loss=', '0.002349749')
# ('Epoch:', '0020', 'training time (minutes)=', '0.2181', 'loss=', '0.002265705')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001996979')
# ('Epoch:', '0021', 'training time (minutes)=', '0.2207', 'loss=', '0.002111422')
# ('Epoch:', '0022', 'training time (minutes)=', '0.2265', 'loss=', '0.002035403')
# ('Epoch:', '0023', 'training time (minutes)=', '0.2209', 'loss=', '0.001909510')
# ('Epoch:', '0024', 'training time (minutes)=', '0.2268', 'loss=', '0.001825084')
# ('Epoch:', '0025', 'training time (minutes)=', '0.2251', 'loss=', '0.002011761')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.001973748')
# ('Epoch:', '0026', 'training time (minutes)=', '0.2261', 'loss=', '0.001939230')
# ('Epoch:', '0027', 'training time (minutes)=', '0.2222', 'loss=', '0.001820400')
# ('Epoch:', '0028', 'training time (minutes)=', '0.2182', 'loss=', '0.001721087')
# ('Epoch:', '0029', 'training time (minutes)=', '0.2247', 'loss=', '0.001671755')
# ('Epoch:', '0030', 'training time (minutes)=', '0.2234', 'loss=', '0.001660111')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.001485417')
# ('Epoch:', '0031', 'training time (minutes)=', '0.2224', 'loss=', '0.001617688')
# ('Epoch:', '0032', 'training time (minutes)=', '0.2291', 'loss=', '0.001566126')
# ('Epoch:', '0033', 'training time (minutes)=', '0.2224', 'loss=', '0.001553699')
# ('Epoch:', '0034', 'training time (minutes)=', '0.2236', 'loss=', '0.001499947')
# ('Epoch:', '0035', 'training time (minutes)=', '0.2250', 'loss=', '0.001472696')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001592452')
# ('Epoch:', '0036', 'training time (minutes)=', '0.2194', 'loss=', '0.001559157')
# ('Epoch:', '0037', 'training time (minutes)=', '0.2233', 'loss=', '0.001437950')
# ('Epoch:', '0038', 'training time (minutes)=', '0.2192', 'loss=', '0.001392820')
# ('Epoch:', '0039', 'training time (minutes)=', '0.2319', 'loss=', '0.001471848')
# ('Epoch:', '0040', 'training time (minutes)=', '0.2243', 'loss=', '0.001466043')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001611396')
# ('Epoch:', '0041', 'training time (minutes)=', '0.2194', 'loss=', '0.001372776')
# ('Epoch:', '0042', 'training time (minutes)=', '0.2243', 'loss=', '0.001342796')
# ('Epoch:', '0043', 'training time (minutes)=', '0.2268', 'loss=', '0.001379852')
# ('Epoch:', '0044', 'training time (minutes)=', '0.2183', 'loss=', '0.001380441')
# ('Epoch:', '0045', 'training time (minutes)=', '0.2235', 'loss=', '0.001312062')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.001309961')
# ('Epoch:', '0046', 'training time (minutes)=', '0.2252', 'loss=', '0.009327877')
# ('Epoch:', '0047', 'training time (minutes)=', '0.2216', 'loss=', '0.002826384')
# ('Epoch:', '0048', 'training time (minutes)=', '0.2281', 'loss=', '0.002333695')
# ('Epoch:', '0049', 'training time (minutes)=', '0.2220', 'loss=', '0.002182512')
# ('Epoch:', '0050', 'training time (minutes)=', '0.2243', 'loss=', '0.002043936')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.001911929')
# ('Epoch:', '0051', 'training time (minutes)=', '0.2263', 'loss=', '0.001967573')
# ('Epoch:', '0052', 'training time (minutes)=', '0.2219', 'loss=', '0.001896187')
# ('Epoch:', '0053', 'training time (minutes)=', '0.2215', 'loss=', '0.001790408')
# ('Epoch:', '0054', 'training time (minutes)=', '0.2185', 'loss=', '0.001752588')
# ('Epoch:', '0055', 'training time (minutes)=', '0.2271', 'loss=', '0.001682239')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001635106')
# ('Epoch:', '0056', 'training time (minutes)=', '0.2184', 'loss=', '0.001655918')
# ('Epoch:', '0057', 'training time (minutes)=', '0.2231', 'loss=', '0.001630717')
# ('Epoch:', '0058', 'training time (minutes)=', '0.2282', 'loss=', '0.001572390')
# ('Epoch:', '0059', 'training time (minutes)=', '0.2248', 'loss=', '0.001526150')
# ('Epoch:', '0060', 'training time (minutes)=', '0.2243', 'loss=', '0.001504550')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001441206')
# ('Epoch:', '0061', 'training time (minutes)=', '0.2203', 'loss=', '0.001475383')
# ('Epoch:', '0062', 'training time (minutes)=', '0.2181', 'loss=', '0.001456905')
# ('Epoch:', '0063', 'training time (minutes)=', '0.2203', 'loss=', '0.001414257')
# ('Epoch:', '0064', 'training time (minutes)=', '0.2241', 'loss=', '0.001359607')
# ('Epoch:', '0065', 'training time (minutes)=', '0.2227', 'loss=', '0.001354014')
# ('Held Out Data :', 'forward time (minutes)=', '0.0070', 'loss=', '0.001433437')
# ('Epoch:', '0066', 'training time (minutes)=', '0.2270', 'loss=', '0.001347744')
# ('Epoch:', '0067', 'training time (minutes)=', '0.2310', 'loss=', '0.001318786')
# ('Epoch:', '0068', 'training time (minutes)=', '0.2175', 'loss=', '0.001299481')
# ('Epoch:', '0069', 'training time (minutes)=', '0.2201', 'loss=', '0.001285436')
# ('Epoch:', '0070', 'training time (minutes)=', '0.2195', 'loss=', '0.001242127')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001293984')
# ('Epoch:', '0071', 'training time (minutes)=', '0.2226', 'loss=', '0.001265066')
# ('Epoch:', '0072', 'training time (minutes)=', '0.2239', 'loss=', '0.001311160')
# ('Epoch:', '0073', 'training time (minutes)=', '0.2208', 'loss=', '0.001286272')
# ('Epoch:', '0074', 'training time (minutes)=', '0.2264', 'loss=', '0.001214341')
# ('Epoch:', '0075', 'training time (minutes)=', '0.2179', 'loss=', '0.001204795')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001333286')
# ('Epoch:', '0076', 'training time (minutes)=', '0.2196', 'loss=', '0.001189036')
# ('Epoch:', '0077', 'training time (minutes)=', '0.2240', 'loss=', '0.001161639')
# ('Epoch:', '0078', 'training time (minutes)=', '0.2272', 'loss=', '0.001163136')
# ('Epoch:', '0079', 'training time (minutes)=', '0.2255', 'loss=', '0.003171752')
# ('Epoch:', '0080', 'training time (minutes)=', '0.2208', 'loss=', '0.002499400')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.002783990')
# ('Epoch:', '0081', 'training time (minutes)=', '0.2186', 'loss=', '0.002178729')
# ('Epoch:', '0082', 'training time (minutes)=', '0.2215', 'loss=', '0.001786136')
# ('Epoch:', '0083', 'training time (minutes)=', '0.2234', 'loss=', '0.001665708')
# ('Epoch:', '0084', 'training time (minutes)=', '0.2235', 'loss=', '0.001565538')
# ('Epoch:', '0085', 'training time (minutes)=', '0.2192', 'loss=', '0.001554360')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001489200')
# ('Epoch:', '0086', 'training time (minutes)=', '0.2292', 'loss=', '0.001469631')
# ('Epoch:', '0087', 'training time (minutes)=', '0.2243', 'loss=', '0.001421300')
# ('Epoch:', '0088', 'training time (minutes)=', '0.2207', 'loss=', '0.001377986')
# ('Epoch:', '0089', 'training time (minutes)=', '0.2254', 'loss=', '0.001354841')
# ('Epoch:', '0090', 'training time (minutes)=', '0.2227', 'loss=', '0.001309519')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001324610')
# ('Epoch:', '0091', 'training time (minutes)=', '0.2230', 'loss=', '0.001287398')
# ('Epoch:', '0092', 'training time (minutes)=', '0.2260', 'loss=', '0.001264247')
# ('Epoch:', '0093', 'training time (minutes)=', '0.2234', 'loss=', '0.001243850')
# ('Epoch:', '0094', 'training time (minutes)=', '0.2219', 'loss=', '0.001242063')
# ('Epoch:', '0095', 'training time (minutes)=', '0.2204', 'loss=', '0.001193902')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001225800')
# ('Epoch:', '0096', 'training time (minutes)=', '0.2218', 'loss=', '0.001201690')
# ('Epoch:', '0097', 'training time (minutes)=', '0.2192', 'loss=', '0.001178726')
# ('Epoch:', '0098', 'training time (minutes)=', '0.2238', 'loss=', '0.001169762')
# ('Epoch:', '0099', 'training time (minutes)=', '0.2278', 'loss=', '0.001265359')
# ('Epoch:', '0100', 'training time (minutes)=', '0.2216', 'loss=', '0.001285183')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001215538')
# ('Epoch:', '0101', 'training time (minutes)=', '0.2182', 'loss=', '0.001196417')
# ('Epoch:', '0102', 'training time (minutes)=', '0.2236', 'loss=', '0.001189529')
# ('Epoch:', '0103', 'training time (minutes)=', '0.2246', 'loss=', '0.001143002')
# ('Epoch:', '0104', 'training time (minutes)=', '0.2264', 'loss=', '0.001127575')
# ('Epoch:', '0105', 'training time (minutes)=', '0.2194', 'loss=', '0.001107184')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001150350')
# ('Epoch:', '0106', 'training time (minutes)=', '0.2204', 'loss=', '0.001105483')
# ('Epoch:', '0107', 'training time (minutes)=', '0.2232', 'loss=', '0.001088502')
# ('Epoch:', '0108', 'training time (minutes)=', '0.2256', 'loss=', '0.001072493')
# ('Epoch:', '0109', 'training time (minutes)=', '0.2204', 'loss=', '0.001084931')
# ('Epoch:', '0110', 'training time (minutes)=', '0.2226', 'loss=', '0.001058212')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001094185')
# ('Epoch:', '0111', 'training time (minutes)=', '0.2199', 'loss=', '0.001113452')
# ('Epoch:', '0112', 'training time (minutes)=', '0.2279', 'loss=', '0.001108753')
# ('Epoch:', '0113', 'training time (minutes)=', '0.2246', 'loss=', '0.001065074')
# ('Epoch:', '0114', 'training time (minutes)=', '0.2215', 'loss=', '0.001047670')
# ('Epoch:', '0115', 'training time (minutes)=', '0.2231', 'loss=', '0.001015674')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001076547')
# ('Epoch:', '0116', 'training time (minutes)=', '0.2214', 'loss=', '0.001020178')
# ('Epoch:', '0117', 'training time (minutes)=', '0.2250', 'loss=', '0.000992414')
# ('Epoch:', '0118', 'training time (minutes)=', '0.2232', 'loss=', '0.000996825')
# ('Epoch:', '0119', 'training time (minutes)=', '0.2194', 'loss=', '0.000988132')
# ('Epoch:', '0120', 'training time (minutes)=', '0.2231', 'loss=', '0.001002529')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001024016')
# ('Epoch:', '0121', 'training time (minutes)=', '0.2227', 'loss=', '0.000986822')
# ('Epoch:', '0122', 'training time (minutes)=', '0.2248', 'loss=', '0.000967866')
# ('Epoch:', '0123', 'training time (minutes)=', '0.2222', 'loss=', '0.000975070')
# ('Epoch:', '0124', 'training time (minutes)=', '0.2203', 'loss=', '0.000969699')
# ('Epoch:', '0125', 'training time (minutes)=', '0.2218', 'loss=', '0.000953884')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001024475')
# ('Epoch:', '0126', 'training time (minutes)=', '0.2250', 'loss=', '0.000941429')
# ('Epoch:', '0127', 'training time (minutes)=', '0.2223', 'loss=', '0.000941144')
# ('Epoch:', '0128', 'training time (minutes)=', '0.2183', 'loss=', '0.000964526')
# ('Epoch:', '0129', 'training time (minutes)=', '0.2313', 'loss=', '0.000929508')
# ('Epoch:', '0130', 'training time (minutes)=', '0.2188', 'loss=', '0.000983269')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.001023331')
# ('Epoch:', '0131', 'training time (minutes)=', '0.2224', 'loss=', '0.000929745')
# ('Epoch:', '0132', 'training time (minutes)=', '0.2267', 'loss=', '0.000918465')
# ('Epoch:', '0133', 'training time (minutes)=', '0.2177', 'loss=', '0.000910880')
# ('Epoch:', '0134', 'training time (minutes)=', '0.2264', 'loss=', '0.000919523')
# ('Epoch:', '0135', 'training time (minutes)=', '0.2243', 'loss=', '0.000913147')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000942266')
# ('Epoch:', '0136', 'training time (minutes)=', '0.2187', 'loss=', '0.000907986')
# ('Epoch:', '0137', 'training time (minutes)=', '0.2211', 'loss=', '0.007346153')
# ('Epoch:', '0138', 'training time (minutes)=', '0.2257', 'loss=', '0.002299030')
# ('Epoch:', '0139', 'training time (minutes)=', '0.2181', 'loss=', '0.002053922')
# ('Epoch:', '0140', 'training time (minutes)=', '0.2179', 'loss=', '0.001913318')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.001831562')
# ('Epoch:', '0141', 'training time (minutes)=', '0.2265', 'loss=', '0.001798670')
# ('Epoch:', '0142', 'training time (minutes)=', '0.2219', 'loss=', '0.001689683')
# ('Epoch:', '0143', 'training time (minutes)=', '0.2220', 'loss=', '0.001620341')
# ('Epoch:', '0144', 'training time (minutes)=', '0.2171', 'loss=', '0.001574897')
# ('Epoch:', '0145', 'training time (minutes)=', '0.2181', 'loss=', '0.001519262')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001482887')
# ('Epoch:', '0146', 'training time (minutes)=', '0.2220', 'loss=', '0.001479387')
# ('Epoch:', '0147', 'training time (minutes)=', '0.2276', 'loss=', '0.001427435')
# ('Epoch:', '0148', 'training time (minutes)=', '0.2231', 'loss=', '0.001398469')
# ('Epoch:', '0149', 'training time (minutes)=', '0.2228', 'loss=', '0.001365307')
# ('Epoch:', '0150', 'training time (minutes)=', '0.2247', 'loss=', '0.001330669')
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.001295118')
# ('Epoch:', '0151', 'training time (minutes)=', '0.2189', 'loss=', '0.001322216')
# ('Epoch:', '0152', 'training time (minutes)=', '0.2252', 'loss=', '0.001292435')
# ('Epoch:', '0153', 'training time (minutes)=', '0.2217', 'loss=', '0.001270602')
# ('Epoch:', '0154', 'training time (minutes)=', '0.2194', 'loss=', '0.001241152')
# ('Epoch:', '0155', 'training time (minutes)=', '0.2228', 'loss=', '0.001222195')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001189613')
# ('Epoch:', '0156', 'training time (minutes)=', '0.2203', 'loss=', '0.001199992')
# ('Epoch:', '0157', 'training time (minutes)=', '0.2222', 'loss=', '0.001197345')
# ('Epoch:', '0158', 'training time (minutes)=', '0.2188', 'loss=', '0.001155882')
# ('Epoch:', '0159', 'training time (minutes)=', '0.2240', 'loss=', '0.001166335')
# ('Epoch:', '0160', 'training time (minutes)=', '0.2268', 'loss=', '0.001174997')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001183016')
# ('Epoch:', '0161', 'training time (minutes)=', '0.2173', 'loss=', '0.001130317')
# ('Epoch:', '0162', 'training time (minutes)=', '0.2232', 'loss=', '0.001136652')
# ('Epoch:', '0163', 'training time (minutes)=', '0.2179', 'loss=', '0.001102579')
# ('Epoch:', '0164', 'training time (minutes)=', '0.2229', 'loss=', '0.001098555')
# ('Epoch:', '0165', 'training time (minutes)=', '0.2217', 'loss=', '0.001101211')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001100845')
# ('Epoch:', '0166', 'training time (minutes)=', '0.2199', 'loss=', '0.001088427')
# ('Epoch:', '0167', 'training time (minutes)=', '0.2230', 'loss=', '0.001074430')
# ('Epoch:', '0168', 'training time (minutes)=', '0.2174', 'loss=', '0.001060033')
# ('Epoch:', '0169', 'training time (minutes)=', '0.2219', 'loss=', '0.001058279')
# ('Epoch:', '0170', 'training time (minutes)=', '0.2197', 'loss=', '0.001051113')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001101892')
# ('Epoch:', '0171', 'training time (minutes)=', '0.2243', 'loss=', '0.001030692')
# ('Epoch:', '0172', 'training time (minutes)=', '0.2229', 'loss=', '0.001025494')
# ('Epoch:', '0173', 'training time (minutes)=', '0.2198', 'loss=', '0.001011879')
# ('Epoch:', '0174', 'training time (minutes)=', '0.2200', 'loss=', '0.001010286')
# ('Epoch:', '0175', 'training time (minutes)=', '0.2280', 'loss=', '0.001002820')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001040196')
# ('Epoch:', '0176', 'training time (minutes)=', '0.2232', 'loss=', '0.001020471')
# ('Epoch:', '0177', 'training time (minutes)=', '0.2231', 'loss=', '0.000985865')
# ('Epoch:', '0178', 'training time (minutes)=', '0.2230', 'loss=', '0.000994767')
# ('Epoch:', '0179', 'training time (minutes)=', '0.2192', 'loss=', '0.000964925')
# ('Epoch:', '0180', 'training time (minutes)=', '0.2279', 'loss=', '0.000973544')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.001012254')
# ('Epoch:', '0181', 'training time (minutes)=', '0.2183', 'loss=', '0.000962038')
# ('Epoch:', '0182', 'training time (minutes)=', '0.2224', 'loss=', '0.000965185')
# ('Epoch:', '0183', 'training time (minutes)=', '0.2192', 'loss=', '0.000956760')
# ('Epoch:', '0184', 'training time (minutes)=', '0.2271', 'loss=', '0.000948680')
# ('Epoch:', '0185', 'training time (minutes)=', '0.2236', 'loss=', '0.000944185')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001002335')
# ('Epoch:', '0186', 'training time (minutes)=', '0.2254', 'loss=', '0.000943241')
# ('Epoch:', '0187', 'training time (minutes)=', '0.2285', 'loss=', '0.000960198')
# ('Epoch:', '0188', 'training time (minutes)=', '0.2220', 'loss=', '0.000987681')
# ('Epoch:', '0189', 'training time (minutes)=', '0.2225', 'loss=', '0.000947474')
# ('Epoch:', '0190', 'training time (minutes)=', '0.2236', 'loss=', '0.000938377')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000995104')
# ('Epoch:', '0191', 'training time (minutes)=', '0.2181', 'loss=', '0.000933295')
# ('Epoch:', '0192', 'training time (minutes)=', '0.2217', 'loss=', '0.000917884')
# ('Epoch:', '0193', 'training time (minutes)=', '0.2281', 'loss=', '0.000904766')
# ('Epoch:', '0194', 'training time (minutes)=', '0.2225', 'loss=', '0.000891832')
# ('Epoch:', '0195', 'training time (minutes)=', '0.2174', 'loss=', '0.000897438')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001014247')
# ('Epoch:', '0196', 'training time (minutes)=', '0.2233', 'loss=', '0.000908622')
# ('Epoch:', '0197', 'training time (minutes)=', '0.2291', 'loss=', '0.000896191')
# ('Epoch:', '0198', 'training time (minutes)=', '0.2217', 'loss=', '0.000881875')
# ('Epoch:', '0199', 'training time (minutes)=', '0.2208', 'loss=', '0.000896858')
# ('Epoch:', '0200', 'training time (minutes)=', '0.2247', 'loss=', '0.000886501')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000969663')
# ('Epoch:', '0201', 'training time (minutes)=', '0.2182', 'loss=', '0.000870032')
# ('Epoch:', '0202', 'training time (minutes)=', '0.2235', 'loss=', '0.000868514')
# ('Epoch:', '0203', 'training time (minutes)=', '0.2269', 'loss=', '0.000879522')
# ('Epoch:', '0204', 'training time (minutes)=', '0.2263', 'loss=', '0.000863114')
# ('Epoch:', '0205', 'training time (minutes)=', '0.2224', 'loss=', '0.000872126')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000917545')
# ('Epoch:', '0206', 'training time (minutes)=', '0.2248', 'loss=', '0.001418355')
# ('Epoch:', '0207', 'training time (minutes)=', '0.2210', 'loss=', '0.001550973')
# ('Epoch:', '0208', 'training time (minutes)=', '0.2265', 'loss=', '0.001261889')
# ('Epoch:', '0209', 'training time (minutes)=', '0.2239', 'loss=', '0.001166095')
# ('Epoch:', '0210', 'training time (minutes)=', '0.2214', 'loss=', '0.001117981')
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.001074687')
# ('Epoch:', '0211', 'training time (minutes)=', '0.2278', 'loss=', '0.001059647')
# ('Epoch:', '0212', 'training time (minutes)=', '0.2222', 'loss=', '0.001023681')
# ('Epoch:', '0213', 'training time (minutes)=', '0.2179', 'loss=', '0.001015472')
# ('Epoch:', '0214', 'training time (minutes)=', '0.2199', 'loss=', '0.000981407')
# ('Epoch:', '0215', 'training time (minutes)=', '0.2251', 'loss=', '0.000958510')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000974290')
# ('Epoch:', '0216', 'training time (minutes)=', '0.2186', 'loss=', '0.000966445')
# ('Epoch:', '0217', 'training time (minutes)=', '0.2213', 'loss=', '0.000947462')
# ('Epoch:', '0218', 'training time (minutes)=', '0.2252', 'loss=', '0.000930228')
# ('Epoch:', '0219', 'training time (minutes)=', '0.2207', 'loss=', '0.000913998')
# ('Epoch:', '0220', 'training time (minutes)=', '0.2184', 'loss=', '0.000917556')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000949850')
# ('Epoch:', '0221', 'training time (minutes)=', '0.2212', 'loss=', '0.000910767')
# ('Epoch:', '0222', 'training time (minutes)=', '0.2248', 'loss=', '0.000919624')
# ('Epoch:', '0223', 'training time (minutes)=', '0.2246', 'loss=', '0.000899456')
# ('Epoch:', '0224', 'training time (minutes)=', '0.2248', 'loss=', '0.000889417')
# ('Epoch:', '0225', 'training time (minutes)=', '0.2181', 'loss=', '0.000895390')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000922183')
# ('Epoch:', '0226', 'training time (minutes)=', '0.2177', 'loss=', '0.000884979')
# ('Epoch:', '0227', 'training time (minutes)=', '0.2220', 'loss=', '0.000869748')
# ('Epoch:', '0228', 'training time (minutes)=', '0.2246', 'loss=', '0.000871997')
# ('Epoch:', '0229', 'training time (minutes)=', '0.2183', 'loss=', '0.000871942')
# ('Epoch:', '0230', 'training time (minutes)=', '0.2228', 'loss=', '0.000866160')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000902030')
# ('Epoch:', '0231', 'training time (minutes)=', '0.2232', 'loss=', '0.000860653')
# ('Epoch:', '0232', 'training time (minutes)=', '0.2280', 'loss=', '0.000857280')
# ('Epoch:', '0233', 'training time (minutes)=', '0.2235', 'loss=', '0.000854366')
# ('Epoch:', '0234', 'training time (minutes)=', '0.2238', 'loss=', '0.000855339')
# ('Epoch:', '0235', 'training time (minutes)=', '0.2236', 'loss=', '0.000842552')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000916590')
# ('Epoch:', '0236', 'training time (minutes)=', '0.2239', 'loss=', '0.000841571')
# ('Epoch:', '0237', 'training time (minutes)=', '0.2203', 'loss=', '0.000835039')
# ('Epoch:', '0238', 'training time (minutes)=', '0.2233', 'loss=', '0.000833728')
# ('Epoch:', '0239', 'training time (minutes)=', '0.2260', 'loss=', '0.000833544')
# ('Epoch:', '0240', 'training time (minutes)=', '0.2274', 'loss=', '0.000823424')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000904934')
# ('Epoch:', '0241', 'training time (minutes)=', '0.2201', 'loss=', '0.000825334')
# ('Epoch:', '0242', 'training time (minutes)=', '0.2266', 'loss=', '0.000826865')
# ('Epoch:', '0243', 'training time (minutes)=', '0.2231', 'loss=', '0.000817745')
# ('Epoch:', '0244', 'training time (minutes)=', '0.2233', 'loss=', '0.000804150')
# ('Epoch:', '0245', 'training time (minutes)=', '0.2285', 'loss=', '0.000811869')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000923069')
# ('Epoch:', '0246', 'training time (minutes)=', '0.2193', 'loss=', '0.000859269')
# ('Epoch:', '0247', 'training time (minutes)=', '0.2219', 'loss=', '0.000830742')
# ('Epoch:', '0248', 'training time (minutes)=', '0.2249', 'loss=', '0.000916216')
# ('Epoch:', '0249', 'training time (minutes)=', '0.2285', 'loss=', '0.000877227')
# ('Epoch:', '0250', 'training time (minutes)=', '0.2213', 'loss=', '0.000844226')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.000907695')
# ('Epoch:', '0251', 'training time (minutes)=', '0.2194', 'loss=', '0.000827128')
# ('Epoch:', '0252', 'training time (minutes)=', '0.2289', 'loss=', '0.000807430')
# ('Epoch:', '0253', 'training time (minutes)=', '0.2241', 'loss=', '0.000801321')
# ('Epoch:', '0254', 'training time (minutes)=', '0.2239', 'loss=', '0.000806460')
# ('Epoch:', '0255', 'training time (minutes)=', '0.2272', 'loss=', '0.000799606')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000882014')
# ('Epoch:', '0256', 'training time (minutes)=', '0.2221', 'loss=', '0.000786656')
# ('Epoch:', '0257', 'training time (minutes)=', '0.2191', 'loss=', '0.000792549')
# ('Epoch:', '0258', 'training time (minutes)=', '0.2234', 'loss=', '0.000782209')
# ('Epoch:', '0259', 'training time (minutes)=', '0.2276', 'loss=', '0.000790768')
# ('Epoch:', '0260', 'training time (minutes)=', '0.2221', 'loss=', '0.000785078')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000876011')
# ('Epoch:', '0261', 'training time (minutes)=', '0.2228', 'loss=', '0.000782281')
# ('Epoch:', '0262', 'training time (minutes)=', '0.2237', 'loss=', '0.000775870')
# ('Epoch:', '0263', 'training time (minutes)=', '0.2272', 'loss=', '0.000765806')
# ('Epoch:', '0264', 'training time (minutes)=', '0.2212', 'loss=', '0.000765291')
# ('Epoch:', '0265', 'training time (minutes)=', '0.2211', 'loss=', '0.000775989')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000882060')
# ('Epoch:', '0266', 'training time (minutes)=', '0.2208', 'loss=', '0.000767968')
# ('Epoch:', '0267', 'training time (minutes)=', '0.2271', 'loss=', '0.000756267')
# ('Epoch:', '0268', 'training time (minutes)=', '0.2243', 'loss=', '0.000767218')
# ('Epoch:', '0269', 'training time (minutes)=', '0.2250', 'loss=', '0.000747749')
# ('Epoch:', '0270', 'training time (minutes)=', '0.2260', 'loss=', '0.000760108')
# ('Held Out Data :', 'forward time (minutes)=', '0.0070', 'loss=', '0.000862683')
# ('Epoch:', '0271', 'training time (minutes)=', '0.2223', 'loss=', '0.000783493')
# ('Epoch:', '0272', 'training time (minutes)=', '0.2178', 'loss=', '0.000752363')
# ('Epoch:', '0273', 'training time (minutes)=', '0.2231', 'loss=', '0.000746831')
# ('Epoch:', '0274', 'training time (minutes)=', '0.2211', 'loss=', '0.000755598')
# ('Epoch:', '0275', 'training time (minutes)=', '0.2264', 'loss=', '0.000761404')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000882968')
# ('Epoch:', '0276', 'training time (minutes)=', '0.2221', 'loss=', '0.000737748')
# ('Epoch:', '0277', 'training time (minutes)=', '0.2258', 'loss=', '0.000734864')
# ('Epoch:', '0278', 'training time (minutes)=', '0.2225', 'loss=', '0.000737721')
# ('Epoch:', '0279', 'training time (minutes)=', '0.2218', 'loss=', '0.000737281')
# ('Epoch:', '0280', 'training time (minutes)=', '0.2276', 'loss=', '0.000723869')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000846379')
# ('Epoch:', '0281', 'training time (minutes)=', '0.2191', 'loss=', '0.000750059')
# ('Epoch:', '0282', 'training time (minutes)=', '0.2255', 'loss=', '0.000747058')
# ('Epoch:', '0283', 'training time (minutes)=', '0.2179', 'loss=', '0.000729148')
# ('Epoch:', '0284', 'training time (minutes)=', '0.2185', 'loss=', '0.000743860')
# ('Epoch:', '0285', 'training time (minutes)=', '0.2250', 'loss=', '0.000724556')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000863827')
# ('Epoch:', '0286', 'training time (minutes)=', '0.2187', 'loss=', '0.000729062')
# ('Epoch:', '0287', 'training time (minutes)=', '0.2247', 'loss=', '0.000717167')
# ('Epoch:', '0288', 'training time (minutes)=', '0.2232', 'loss=', '0.000712627')
# ('Epoch:', '0289', 'training time (minutes)=', '0.2272', 'loss=', '0.000717010')
# ('Epoch:', '0290', 'training time (minutes)=', '0.2234', 'loss=', '0.000711737')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000872329')
# ('Epoch:', '0291', 'training time (minutes)=', '0.2240', 'loss=', '0.000708218')
# ('Epoch:', '0292', 'training time (minutes)=', '0.2227', 'loss=', '0.000710647')
# ('Epoch:', '0293', 'training time (minutes)=', '0.2229', 'loss=', '0.000726228')
# ('Epoch:', '0294', 'training time (minutes)=', '0.2231', 'loss=', '0.000728896')
# ('Epoch:', '0295', 'training time (minutes)=', '0.2185', 'loss=', '0.000718788')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000908655')
# ('Epoch:', '0296', 'training time (minutes)=', '0.2276', 'loss=', '0.000703341')
# ('Epoch:', '0297', 'training time (minutes)=', '0.2252', 'loss=', '0.000702756')
# ('Epoch:', '0298', 'training time (minutes)=', '0.2283', 'loss=', '0.000705587')
# ('Epoch:', '0299', 'training time (minutes)=', '0.2224', 'loss=', '0.000699701')
# ('Epoch:', '0300', 'training time (minutes)=', '0.2255', 'loss=', '0.000687977')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000826585')
# ('Epoch:', '0301', 'training time (minutes)=', '0.2187', 'loss=', '0.000702799')
# ('Epoch:', '0302', 'training time (minutes)=', '0.2262', 'loss=', '0.000689999')
# ('Epoch:', '0303', 'training time (minutes)=', '0.2176', 'loss=', '0.000691407')
# ('Epoch:', '0304', 'training time (minutes)=', '0.2211', 'loss=', '0.000702307')
# ('Epoch:', '0305', 'training time (minutes)=', '0.2247', 'loss=', '0.000711566')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000888023')
# ('Epoch:', '0306', 'training time (minutes)=', '0.2311', 'loss=', '0.000699265')
# ('Epoch:', '0307', 'training time (minutes)=', '0.2179', 'loss=', '0.000683061')
# ('Epoch:', '0308', 'training time (minutes)=', '0.2302', 'loss=', '0.000684525')
# ('Epoch:', '0309', 'training time (minutes)=', '0.2240', 'loss=', '0.000684183')
# ('Epoch:', '0310', 'training time (minutes)=', '0.2228', 'loss=', '0.000709227')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000944011')
# ('Epoch:', '0311', 'training time (minutes)=', '0.2194', 'loss=', '0.000730115')
# ('Epoch:', '0312', 'training time (minutes)=', '0.2201', 'loss=', '0.000696773')
# ('Epoch:', '0313', 'training time (minutes)=', '0.2256', 'loss=', '0.000683390')
# ('Epoch:', '0314', 'training time (minutes)=', '0.2298', 'loss=', '0.000674201')
# ('Epoch:', '0315', 'training time (minutes)=', '0.2239', 'loss=', '0.000677958')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000842030')
# ('Epoch:', '0316', 'training time (minutes)=', '0.2175', 'loss=', '0.000679549')
# ('Epoch:', '0317', 'training time (minutes)=', '0.2227', 'loss=', '0.000672047')
# ('Epoch:', '0318', 'training time (minutes)=', '0.2209', 'loss=', '0.000674074')
# ('Epoch:', '0319', 'training time (minutes)=', '0.2205', 'loss=', '0.000672966')
# ('Epoch:', '0320', 'training time (minutes)=', '0.2203', 'loss=', '0.000663651')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000832859')
# ('Epoch:', '0321', 'training time (minutes)=', '0.2194', 'loss=', '0.000680745')
# ('Epoch:', '0322', 'training time (minutes)=', '0.2237', 'loss=', '0.000664379')
# ('Epoch:', '0323', 'training time (minutes)=', '0.2201', 'loss=', '0.000664720')
# ('Epoch:', '0324', 'training time (minutes)=', '0.2278', 'loss=', '0.000658951')
# ('Epoch:', '0325', 'training time (minutes)=', '0.2183', 'loss=', '0.000662003')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000846735')
# ('Epoch:', '0326', 'training time (minutes)=', '0.2202', 'loss=', '0.000658887')
# ('Epoch:', '0327', 'training time (minutes)=', '0.2188', 'loss=', '0.000656807')
# ('Epoch:', '0328', 'training time (minutes)=', '0.2289', 'loss=', '0.000658263')
# ('Epoch:', '0329', 'training time (minutes)=', '0.2212', 'loss=', '0.000656422')
# ('Epoch:', '0330', 'training time (minutes)=', '0.2179', 'loss=', '0.000650195')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000853136')
# ('Epoch:', '0331', 'training time (minutes)=', '0.2198', 'loss=', '0.000649157')
# ('Epoch:', '0332', 'training time (minutes)=', '0.2261', 'loss=', '0.000647890')
# ('Epoch:', '0333', 'training time (minutes)=', '0.2219', 'loss=', '0.000650303')
# ('Epoch:', '0334', 'training time (minutes)=', '0.2240', 'loss=', '0.000637809')
# ('Epoch:', '0335', 'training time (minutes)=', '0.2209', 'loss=', '0.000690828')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000819104')
# ('Epoch:', '0336', 'training time (minutes)=', '0.2182', 'loss=', '0.000653573')
# ('Epoch:', '0337', 'training time (minutes)=', '0.2201', 'loss=', '0.000648859')
# ('Epoch:', '0338', 'training time (minutes)=', '0.2254', 'loss=', '0.000645261')
# ('Epoch:', '0339', 'training time (minutes)=', '0.2200', 'loss=', '0.000672671')
# ('Epoch:', '0340', 'training time (minutes)=', '0.2245', 'loss=', '0.000645572')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000860034')
# ('Epoch:', '0341', 'training time (minutes)=', '0.2215', 'loss=', '0.000684612')
# ('Epoch:', '0342', 'training time (minutes)=', '0.2245', 'loss=', '0.000647853')
# ('Epoch:', '0343', 'training time (minutes)=', '0.2205', 'loss=', '0.000659354')
# ('Epoch:', '0344', 'training time (minutes)=', '0.2216', 'loss=', '0.000631747')
# ('Epoch:', '0345', 'training time (minutes)=', '0.2235', 'loss=', '0.000658083')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000834248')
# ('Epoch:', '0346', 'training time (minutes)=', '0.2203', 'loss=', '0.000655193')
# ('Epoch:', '0347', 'training time (minutes)=', '0.2218', 'loss=', '0.000637159')
# ('Epoch:', '0348', 'training time (minutes)=', '0.2237', 'loss=', '0.000632633')
# ('Epoch:', '0349', 'training time (minutes)=', '0.2218', 'loss=', '0.000637282')
# ('Epoch:', '0350', 'training time (minutes)=', '0.2190', 'loss=', '0.000618670')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000800445')
# ('Epoch:', '0351', 'training time (minutes)=', '0.2179', 'loss=', '0.000622903')
# ('Epoch:', '0352', 'training time (minutes)=', '0.2196', 'loss=', '0.000627847')
# ('Epoch:', '0353', 'training time (minutes)=', '0.2245', 'loss=', '0.000626843')
# ('Epoch:', '0354', 'training time (minutes)=', '0.2233', 'loss=', '0.000625167')
# ('Epoch:', '0355', 'training time (minutes)=', '0.2176', 'loss=', '0.000628774')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000836656')
# ('Epoch:', '0356', 'training time (minutes)=', '0.2184', 'loss=', '0.000623765')
# ('Epoch:', '0357', 'training time (minutes)=', '0.2175', 'loss=', '0.000624821')
# ('Epoch:', '0358', 'training time (minutes)=', '0.2228', 'loss=', '0.000608969')
# ('Epoch:', '0359', 'training time (minutes)=', '0.2179', 'loss=', '0.000621191')
# ('Epoch:', '0360', 'training time (minutes)=', '0.2179', 'loss=', '0.000625391')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000814496')
# ('Epoch:', '0361', 'training time (minutes)=', '0.2184', 'loss=', '0.000623957')
# ('Epoch:', '0362', 'training time (minutes)=', '0.2234', 'loss=', '0.000623692')
# ('Epoch:', '0363', 'training time (minutes)=', '0.2197', 'loss=', '0.000651143')
# ('Epoch:', '0364', 'training time (minutes)=', '0.2221', 'loss=', '0.000619579')
# ('Epoch:', '0365', 'training time (minutes)=', '0.2234', 'loss=', '0.000607849')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000842610')
# ('Epoch:', '0366', 'training time (minutes)=', '0.2177', 'loss=', '0.000624404')
# ('Epoch:', '0367', 'training time (minutes)=', '0.2241', 'loss=', '0.000623534')
# ('Epoch:', '0368', 'training time (minutes)=', '0.2205', 'loss=', '0.000618698')
# ('Epoch:', '0369', 'training time (minutes)=', '0.2194', 'loss=', '0.000619008')
# ('Epoch:', '0370', 'training time (minutes)=', '0.2238', 'loss=', '0.000607259')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000810481')
# ('Epoch:', '0371', 'training time (minutes)=', '0.2182', 'loss=', '0.000605491')
# ('Epoch:', '0372', 'training time (minutes)=', '0.2272', 'loss=', '0.000607973')
# ('Epoch:', '0373', 'training time (minutes)=', '0.2171', 'loss=', '0.000682678')
# ('Epoch:', '0374', 'training time (minutes)=', '0.2271', 'loss=', '0.000637895')
# ('Epoch:', '0375', 'training time (minutes)=', '0.2181', 'loss=', '0.000619290')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000799361')
# ('Epoch:', '0376', 'training time (minutes)=', '0.2242', 'loss=', '0.000627429')
# ('Epoch:', '0377', 'training time (minutes)=', '0.2195', 'loss=', '0.000614406')
# ('Epoch:', '0378', 'training time (minutes)=', '0.2199', 'loss=', '0.000598365')
# ('Epoch:', '0379', 'training time (minutes)=', '0.2234', 'loss=', '0.000608171')
# ('Epoch:', '0380', 'training time (minutes)=', '0.2228', 'loss=', '0.000607029')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000841442')
# ('Epoch:', '0381', 'training time (minutes)=', '0.2186', 'loss=', '0.000604641')
# ('Epoch:', '0382', 'training time (minutes)=', '0.2242', 'loss=', '0.000597364')
# ('Epoch:', '0383', 'training time (minutes)=', '0.2228', 'loss=', '0.000652904')
# ('Epoch:', '0384', 'training time (minutes)=', '0.2262', 'loss=', '0.000632720')
# ('Epoch:', '0385', 'training time (minutes)=', '0.2206', 'loss=', '0.000598136')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000816386')
# ('Epoch:', '0386', 'training time (minutes)=', '0.2234', 'loss=', '0.000592565')
# ('Epoch:', '0387', 'training time (minutes)=', '0.2204', 'loss=', '0.000600898')
# ('Epoch:', '0388', 'training time (minutes)=', '0.2245', 'loss=', '0.000600554')
# ('Epoch:', '0389', 'training time (minutes)=', '0.2212', 'loss=', '0.000586461')
# ('Epoch:', '0390', 'training time (minutes)=', '0.2212', 'loss=', '0.000602851')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000817579')
# ('Epoch:', '0391', 'training time (minutes)=', '0.2196', 'loss=', '0.000581358')
# ('Epoch:', '0392', 'training time (minutes)=', '0.2326', 'loss=', '0.000585195')
# ('Epoch:', '0393', 'training time (minutes)=', '0.2238', 'loss=', '0.000588568')
# ('Epoch:', '0394', 'training time (minutes)=', '0.2242', 'loss=', '0.000589230')
# ('Epoch:', '0395', 'training time (minutes)=', '0.2191', 'loss=', '0.000591420')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000812106')
# ('Epoch:', '0396', 'training time (minutes)=', '0.2216', 'loss=', '0.000580028')
# ('Epoch:', '0397', 'training time (minutes)=', '0.2259', 'loss=', '0.000589877')
# ('Epoch:', '0398', 'training time (minutes)=', '0.2247', 'loss=', '0.000584779')
# ('Epoch:', '0399', 'training time (minutes)=', '0.2216', 'loss=', '0.000585020')
# ('Epoch:', '0400', 'training time (minutes)=', '0.2268', 'loss=', '0.000581828')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000801927')
# ('Epoch:', '0401', 'training time (minutes)=', '0.2179', 'loss=', '0.000692550')
# ('Epoch:', '0402', 'training time (minutes)=', '0.2259', 'loss=', '0.000621413')
# ('Epoch:', '0403', 'training time (minutes)=', '0.2175', 'loss=', '0.000606609')
# ('Epoch:', '0404', 'training time (minutes)=', '0.2300', 'loss=', '0.000639149')
# ('Epoch:', '0405', 'training time (minutes)=', '0.2218', 'loss=', '0.000606036')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000798431')
# ('Epoch:', '0406', 'training time (minutes)=', '0.2243', 'loss=', '0.000591391')
# ('Epoch:', '0407', 'training time (minutes)=', '0.2306', 'loss=', '0.000586309')
# ('Epoch:', '0408', 'training time (minutes)=', '0.2179', 'loss=', '0.000579854')
# ('Epoch:', '0409', 'training time (minutes)=', '0.2231', 'loss=', '0.000586814')
# ('Epoch:', '0410', 'training time (minutes)=', '0.2221', 'loss=', '0.000585868')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000800452')
# ('Epoch:', '0411', 'training time (minutes)=', '0.2311', 'loss=', '0.000580396')
# ('Epoch:', '0412', 'training time (minutes)=', '0.2252', 'loss=', '0.000582697')
# ('Epoch:', '0413', 'training time (minutes)=', '0.2232', 'loss=', '0.000582008')
# ('Epoch:', '0414', 'training time (minutes)=', '0.2257', 'loss=', '0.000579792')
# ('Epoch:', '0415', 'training time (minutes)=', '0.2190', 'loss=', '0.000572467')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000808428')
# ('Epoch:', '0416', 'training time (minutes)=', '0.2265', 'loss=', '0.000573334')
# ('Epoch:', '0417', 'training time (minutes)=', '0.2244', 'loss=', '0.000698468')
# ('Epoch:', '0418', 'training time (minutes)=', '0.2181', 'loss=', '0.000646661')
# ('Epoch:', '0419', 'training time (minutes)=', '0.2311', 'loss=', '0.000621261')
# ('Epoch:', '0420', 'training time (minutes)=', '0.2237', 'loss=', '0.000598099')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000801262')
# ('Epoch:', '0421', 'training time (minutes)=', '0.2172', 'loss=', '0.000584258')
# ('Epoch:', '0422', 'training time (minutes)=', '0.2179', 'loss=', '0.000578105')
# ('Epoch:', '0423', 'training time (minutes)=', '0.2237', 'loss=', '0.000584810')
# ('Epoch:', '0424', 'training time (minutes)=', '0.2214', 'loss=', '0.000570662')
# ('Epoch:', '0425', 'training time (minutes)=', '0.2175', 'loss=', '0.000572506')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000795317')
# ('Epoch:', '0426', 'training time (minutes)=', '0.2226', 'loss=', '0.000575811')
# ('Epoch:', '0427', 'training time (minutes)=', '0.2241', 'loss=', '0.000565727')
# ('Epoch:', '0428', 'training time (minutes)=', '0.2263', 'loss=', '0.000569406')
# ('Epoch:', '0429', 'training time (minutes)=', '0.2229', 'loss=', '0.000574788')
# ('Epoch:', '0430', 'training time (minutes)=', '0.2248', 'loss=', '0.000564627')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000812780')
# ('Epoch:', '0431', 'training time (minutes)=', '0.2243', 'loss=', '0.000565882')
# ('Epoch:', '0432', 'training time (minutes)=', '0.2216', 'loss=', '0.000571399')
# ('Epoch:', '0433', 'training time (minutes)=', '0.2242', 'loss=', '0.000565622')
# ('Epoch:', '0434', 'training time (minutes)=', '0.2192', 'loss=', '0.000570525')
# ('Epoch:', '0435', 'training time (minutes)=', '0.2191', 'loss=', '0.000579778')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000789087')
# ('Epoch:', '0436', 'training time (minutes)=', '0.2269', 'loss=', '0.000559838')
# ('Epoch:', '0437', 'training time (minutes)=', '0.2228', 'loss=', '0.000559782')
# ('Epoch:', '0438', 'training time (minutes)=', '0.2222', 'loss=', '0.000562791')
# ('Epoch:', '0439', 'training time (minutes)=', '0.2276', 'loss=', '0.000556344')
# ('Epoch:', '0440', 'training time (minutes)=', '0.2206', 'loss=', '0.000550583')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000780343')
# ('Epoch:', '0441', 'training time (minutes)=', '0.2202', 'loss=', '0.000542242')
# ('Epoch:', '0442', 'training time (minutes)=', '0.2197', 'loss=', '0.000557284')
# ('Epoch:', '0443', 'training time (minutes)=', '0.2187', 'loss=', '0.000554287')
# ('Epoch:', '0444', 'training time (minutes)=', '0.2244', 'loss=', '0.000552336')
# ...
# ('Epoch:', '0855', 'training time (minutes)=', '0.2204', 'loss=', '0.000445301')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000777543')
# ('Epoch:', '0856', 'training time (minutes)=', '0.2258', 'loss=', '0.000461586')
# ('Epoch:', '0857', 'training time (minutes)=', '0.2257', 'loss=', '0.000453595')
# ('Epoch:', '0858', 'training time (minutes)=', '0.2238', 'loss=', '0.000444511')
# ('Epoch:', '0859', 'training time (minutes)=', '0.2243', 'loss=', '0.000446570')
# ('Epoch:', '0860', 'training time (minutes)=', '0.2178', 'loss=', '0.000445428')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-860 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000784856')
# ('Epoch:', '0861', 'training time (minutes)=', '0.2204', 'loss=', '0.000447115')
# ('Epoch:', '0862', 'training time (minutes)=', '0.2171', 'loss=', '0.000447792')
# ('Epoch:', '0863', 'training time (minutes)=', '0.2272', 'loss=', '0.000441922')
# ('Epoch:', '0864', 'training time (minutes)=', '0.2201', 'loss=', '0.000445400')
# ('Epoch:', '0865', 'training time (minutes)=', '0.2248', 'loss=', '0.000450538')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000771707')
# ('Epoch:', '0866', 'training time (minutes)=', '0.2232', 'loss=', '0.000453040')
# ('Epoch:', '0867', 'training time (minutes)=', '0.2194', 'loss=', '0.000449831')
# ('Epoch:', '0868', 'training time (minutes)=', '0.2196', 'loss=', '0.000452020')
# ('Epoch:', '0869', 'training time (minutes)=', '0.2226', 'loss=', '0.000448465')
# ('Epoch:', '0870', 'training time (minutes)=', '0.2286', 'loss=', '0.000443777')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000774988')
# ('Epoch:', '0871', 'training time (minutes)=', '0.2234', 'loss=', '0.000446221')
# ('Epoch:', '0872', 'training time (minutes)=', '0.2196', 'loss=', '0.000438218')
# ('Epoch:', '0873', 'training time (minutes)=', '0.2210', 'loss=', '0.000440243')
# ('Epoch:', '0874', 'training time (minutes)=', '0.2277', 'loss=', '0.000439476')
# ('Epoch:', '0875', 'training time (minutes)=', '0.2231', 'loss=', '0.000446667')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000792831')
# ('Epoch:', '0876', 'training time (minutes)=', '0.2197', 'loss=', '0.000545785')
# ('Epoch:', '0877', 'training time (minutes)=', '0.2212', 'loss=', '0.000471656')
# ('Epoch:', '0878', 'training time (minutes)=', '0.2260', 'loss=', '0.000454562')
# ('Epoch:', '0879', 'training time (minutes)=', '0.2216', 'loss=', '0.000451188')
# ('Epoch:', '0880', 'training time (minutes)=', '0.2249', 'loss=', '0.000442748')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-880 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000759497')
# ('Epoch:', '0881', 'training time (minutes)=', '0.2175', 'loss=', '0.000448686')
# ('Epoch:', '0882', 'training time (minutes)=', '0.2233', 'loss=', '0.000448205')
# ('Epoch:', '0883', 'training time (minutes)=', '0.2170', 'loss=', '0.000447773')
# ('Epoch:', '0884', 'training time (minutes)=', '0.2213', 'loss=', '0.000443595')
# ('Epoch:', '0885', 'training time (minutes)=', '0.2213', 'loss=', '0.000444839')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000764236')
# ('Epoch:', '0886', 'training time (minutes)=', '0.2233', 'loss=', '0.000442813')
# ('Epoch:', '0887', 'training time (minutes)=', '0.2205', 'loss=', '0.000442045')
# ('Epoch:', '0888', 'training time (minutes)=', '0.2259', 'loss=', '0.000440945')
# ('Epoch:', '0889', 'training time (minutes)=', '0.2227', 'loss=', '0.000443122')
# ('Epoch:', '0890', 'training time (minutes)=', '0.2218', 'loss=', '0.000440174')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000770360')
# ('Epoch:', '0891', 'training time (minutes)=', '0.2193', 'loss=', '0.000434672')
# ('Epoch:', '0892', 'training time (minutes)=', '0.2264', 'loss=', '0.000442682')
# ('Epoch:', '0893', 'training time (minutes)=', '0.2222', 'loss=', '0.000456200')
# ('Epoch:', '0894', 'training time (minutes)=', '0.2156', 'loss=', '0.000442464')
# ('Epoch:', '0895', 'training time (minutes)=', '0.2204', 'loss=', '0.000446686')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000770644')
# ('Epoch:', '0896', 'training time (minutes)=', '0.2189', 'loss=', '0.000441878')
# ('Epoch:', '0897', 'training time (minutes)=', '0.2249', 'loss=', '0.000437105')
# ('Epoch:', '0898', 'training time (minutes)=', '0.2253', 'loss=', '0.000438331')
# ('Epoch:', '0899', 'training time (minutes)=', '0.2212', 'loss=', '0.000441494')
# ('Epoch:', '0900', 'training time (minutes)=', '0.2176', 'loss=', '0.000439852')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-900 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000767483')
# ('Epoch:', '0901', 'training time (minutes)=', '0.2194', 'loss=', '0.000445182')
# ('Epoch:', '0902', 'training time (minutes)=', '0.2220', 'loss=', '0.000446730')
# ('Epoch:', '0903', 'training time (minutes)=', '0.2200', 'loss=', '0.000442777')
# ('Epoch:', '0904', 'training time (minutes)=', '0.2242', 'loss=', '0.000439380')
# ('Epoch:', '0905', 'training time (minutes)=', '0.2217', 'loss=', '0.000437931')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000779518')
# ('Epoch:', '0906', 'training time (minutes)=', '0.2236', 'loss=', '0.000467108')
# ('Epoch:', '0907', 'training time (minutes)=', '0.2232', 'loss=', '0.000454998')
# ('Epoch:', '0908', 'training time (minutes)=', '0.2227', 'loss=', '0.000451961')
# ('Epoch:', '0909', 'training time (minutes)=', '0.2240', 'loss=', '0.000442699')
# ('Epoch:', '0910', 'training time (minutes)=', '0.2240', 'loss=', '0.000441789')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000752086')
# ('Epoch:', '0911', 'training time (minutes)=', '0.2200', 'loss=', '0.000438736')
# ('Epoch:', '0912', 'training time (minutes)=', '0.2284', 'loss=', '0.000441027')
# ('Epoch:', '0913', 'training time (minutes)=', '0.2243', 'loss=', '0.000437398')
# ('Epoch:', '0914', 'training time (minutes)=', '0.2210', 'loss=', '0.000438865')
# ('Epoch:', '0915', 'training time (minutes)=', '0.2247', 'loss=', '0.000437151')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000763471')
# ('Epoch:', '0916', 'training time (minutes)=', '0.2223', 'loss=', '0.000436085')
# ('Epoch:', '0917', 'training time (minutes)=', '0.2223', 'loss=', '0.000432932')
# ('Epoch:', '0918', 'training time (minutes)=', '0.2241', 'loss=', '0.000435275')
# ('Epoch:', '0919', 'training time (minutes)=', '0.2271', 'loss=', '0.000437594')
# ('Epoch:', '0920', 'training time (minutes)=', '0.2195', 'loss=', '0.000432806')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-920 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000775466')
# ('Epoch:', '0921', 'training time (minutes)=', '0.2201', 'loss=', '0.000435678')
# ('Epoch:', '0922', 'training time (minutes)=', '0.2179', 'loss=', '0.000433595')
# ('Epoch:', '0923', 'training time (minutes)=', '0.2233', 'loss=', '0.000444262')
# ('Epoch:', '0924', 'training time (minutes)=', '0.2261', 'loss=', '0.000460811')
# ('Epoch:', '0925', 'training time (minutes)=', '0.2219', 'loss=', '0.000448473')
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000768924')
# ('Epoch:', '0926', 'training time (minutes)=', '0.2227', 'loss=', '0.000435409')
# ('Epoch:', '0927', 'training time (minutes)=', '0.2231', 'loss=', '0.000434850')
# ('Epoch:', '0928', 'training time (minutes)=', '0.2218', 'loss=', '0.000434908')
# ('Epoch:', '0929', 'training time (minutes)=', '0.2274', 'loss=', '0.000432955')
# ('Epoch:', '0930', 'training time (minutes)=', '0.2262', 'loss=', '0.000429283')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000768893')
# ('Epoch:', '0931', 'training time (minutes)=', '0.2216', 'loss=', '0.000432818')
# ('Epoch:', '0932', 'training time (minutes)=', '0.2264', 'loss=', '0.000428821')
# ('Epoch:', '0933', 'training time (minutes)=', '0.2255', 'loss=', '0.000501309')
# ('Epoch:', '0934', 'training time (minutes)=', '0.2239', 'loss=', '0.000456170')
# ('Epoch:', '0935', 'training time (minutes)=', '0.2213', 'loss=', '0.000449179')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000768821')
# ('Epoch:', '0936', 'training time (minutes)=', '0.2252', 'loss=', '0.000440688')
# ('Epoch:', '0937', 'training time (minutes)=', '0.2254', 'loss=', '0.000434462')
# ('Epoch:', '0938', 'training time (minutes)=', '0.2189', 'loss=', '0.000433905')
# ('Epoch:', '0939', 'training time (minutes)=', '0.2224', 'loss=', '0.000435380')
# ('Epoch:', '0940', 'training time (minutes)=', '0.2183', 'loss=', '0.000441207')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-940 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000765743')
# ('Epoch:', '0941', 'training time (minutes)=', '0.2243', 'loss=', '0.000432159')
# ('Epoch:', '0942', 'training time (minutes)=', '0.2208', 'loss=', '0.000430919')
# ('Epoch:', '0943', 'training time (minutes)=', '0.2222', 'loss=', '0.000428487')
# ('Epoch:', '0944', 'training time (minutes)=', '0.2230', 'loss=', '0.000439307')
# ('Epoch:', '0945', 'training time (minutes)=', '0.2205', 'loss=', '0.000437747')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000780056')
# ('Epoch:', '0946', 'training time (minutes)=', '0.2278', 'loss=', '0.000434801')
# ('Epoch:', '0947', 'training time (minutes)=', '0.2213', 'loss=', '0.000431359')
# ('Epoch:', '0948', 'training time (minutes)=', '0.2251', 'loss=', '0.000430941')
# ('Epoch:', '0949', 'training time (minutes)=', '0.2247', 'loss=', '0.000434517')
# ('Epoch:', '0950', 'training time (minutes)=', '0.2219', 'loss=', '0.000436362')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000770538')
# ('Epoch:', '0951', 'training time (minutes)=', '0.2179', 'loss=', '0.000428681')
# ('Epoch:', '0952', 'training time (minutes)=', '0.2198', 'loss=', '0.000430928')
# ('Epoch:', '0953', 'training time (minutes)=', '0.2265', 'loss=', '0.000444364')
# ('Epoch:', '0954', 'training time (minutes)=', '0.2276', 'loss=', '0.000432142')
# ('Epoch:', '0955', 'training time (minutes)=', '0.2184', 'loss=', '0.000438328')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000794317')
# ('Epoch:', '0956', 'training time (minutes)=', '0.2233', 'loss=', '0.000436673')
# ('Epoch:', '0957', 'training time (minutes)=', '0.2219', 'loss=', '0.000432836')
# ('Epoch:', '0958', 'training time (minutes)=', '0.2188', 'loss=', '0.000432787')
# ('Epoch:', '0959', 'training time (minutes)=', '0.2202', 'loss=', '0.000430281')
# ('Epoch:', '0960', 'training time (minutes)=', '0.2235', 'loss=', '0.000430519')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-960 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0070', 'loss=', '0.000775539')
# ('Epoch:', '0961', 'training time (minutes)=', '0.2176', 'loss=', '0.000434655')
# ('Epoch:', '0962', 'training time (minutes)=', '0.2183', 'loss=', '0.000424775')
# ('Epoch:', '0963', 'training time (minutes)=', '0.2231', 'loss=', '0.000441694')
# ('Epoch:', '0964', 'training time (minutes)=', '0.2242', 'loss=', '0.000431003')
# ('Epoch:', '0965', 'training time (minutes)=', '0.2207', 'loss=', '0.000434303')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000771384')
# ('Epoch:', '0966', 'training time (minutes)=', '0.2231', 'loss=', '0.000429460')
# ('Epoch:', '0967', 'training time (minutes)=', '0.2196', 'loss=', '0.000425292')
# ('Epoch:', '0968', 'training time (minutes)=', '0.2212', 'loss=', '0.000425140')
# ('Epoch:', '0969', 'training time (minutes)=', '0.2268', 'loss=', '0.000661323')
# ('Epoch:', '0970', 'training time (minutes)=', '0.2199', 'loss=', '0.000504956')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000783965')
# ('Epoch:', '0971', 'training time (minutes)=', '0.2180', 'loss=', '0.000471221')
# ('Epoch:', '0972', 'training time (minutes)=', '0.2178', 'loss=', '0.000457239')
# ('Epoch:', '0973', 'training time (minutes)=', '0.2210', 'loss=', '0.000454828')
# ('Epoch:', '0974', 'training time (minutes)=', '0.2218', 'loss=', '0.000444437')
# ('Epoch:', '0975', 'training time (minutes)=', '0.2192', 'loss=', '0.000441445')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000782894')
# ('Epoch:', '0976', 'training time (minutes)=', '0.2249', 'loss=', '0.000439868')
# ('Epoch:', '0977', 'training time (minutes)=', '0.2172', 'loss=', '0.000441455')
# ('Epoch:', '0978', 'training time (minutes)=', '0.2244', 'loss=', '0.000434632')
# ('Epoch:', '0979', 'training time (minutes)=', '0.2221', 'loss=', '0.000439051')
# ('Epoch:', '0980', 'training time (minutes)=', '0.2208', 'loss=', '0.000428883')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-980 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000769538')
# ('Epoch:', '0981', 'training time (minutes)=', '0.2174', 'loss=', '0.000434383')
# ('Epoch:', '0982', 'training time (minutes)=', '0.2178', 'loss=', '0.000433703')
# ('Epoch:', '0983', 'training time (minutes)=', '0.2228', 'loss=', '0.000434611')
# ('Epoch:', '0984', 'training time (minutes)=', '0.2245', 'loss=', '0.000431283')
# ('Epoch:', '0985', 'training time (minutes)=', '0.2228', 'loss=', '0.000434462')
# ('Held Out Data :', 'forward time (minutes)=', '0.0071', 'loss=', '0.000766779')
# ('Epoch:', '0986', 'training time (minutes)=', '0.2259', 'loss=', '0.000430988')
# ('Epoch:', '0987', 'training time (minutes)=', '0.2216', 'loss=', '0.000426193')
# ('Epoch:', '0988', 'training time (minutes)=', '0.2207', 'loss=', '0.000426776')
# ('Epoch:', '0989', 'training time (minutes)=', '0.2195', 'loss=', '0.000429454')
# ('Epoch:', '0990', 'training time (minutes)=', '0.2280', 'loss=', '0.000432033')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000758639')
# ('Epoch:', '0991', 'training time (minutes)=', '0.2192', 'loss=', '0.000432340')
# ('Epoch:', '0992', 'training time (minutes)=', '0.2244', 'loss=', '0.000424020')
# ('Epoch:', '0993', 'training time (minutes)=', '0.2198', 'loss=', '0.000426744')
# ('Epoch:', '0994', 'training time (minutes)=', '0.2228', 'loss=', '0.000425350')
# ('Epoch:', '0995', 'training time (minutes)=', '0.2221', 'loss=', '0.000421509')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000767040')
# ('Epoch:', '0996', 'training time (minutes)=', '0.2261', 'loss=', '0.000423345')
# ('Epoch:', '0997', 'training time (minutes)=', '0.2202', 'loss=', '0.000417965')
# ('Epoch:', '0998', 'training time (minutes)=', '0.2241', 'loss=', '0.000423098')
# ('Epoch:', '0999', 'training time (minutes)=', '0.2282', 'loss=', '0.000428576')
# ('Epoch:', '1000', 'training time (minutes)=', '0.2212', 'loss=', '0.000425022')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_simply_add_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-1000 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000766971')
