# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 3
setup_one_gpu(GPU)
# Out:
# Picking GPU 3

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out.basics import create_dir, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry, decoder_with_fc_only
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs          
from tf_lab.data_sets.shape_net import snc_category_to_synth_id, load_all_point_clouds_under_folder
from tf_lab.data_sets.shape_net import pc_loader as snc_loader

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_points = 2048
do_training = True
first_time_running = True
load_pretrained_model = False
load_epoch = None
seed = 42

# %%
max_training_epochs = 1000
loss = 'chamfer'
bneck_size = 512

class_name = raw_input('Give me the class type: ').lower()
syn_id = snc_category_to_synth_id()[class_name]

experiment_id = raw_input('Give me the experiment ID:').lower()

experiment_name = '_'.join([class_name, experiment_id, str(n_pc_points), 
                           'pts_bneck', str(bneck_size), loss
                           ])

top_data_dir = '/orions4-zfs/projects/optas/DATA/'
train_dir = osp.join(top_data_dir, 'OUT/iclr/nn_models/testing_ae_settings', experiment_name)
create_dir(train_dir)
# Out:
# Give me the class type: chair
# Give me the experiment ID:conv_arch_0_dropout_w_bnorm
# '/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer'

# %%
train_split = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits', syn_id, '85_5_10/train.txt')
test_split = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits', syn_id, '85_5_10/test.txt')

top_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/centered/', str(n_pc_points))
splitter = Data_Splitter(top_pclouds_path, data_file_ending='.ply')

# %%
tr_files = splitter.load_splits(train_split)
pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(tr_files, n_threads=20, loader=snc_loader, verbose=True)
train_data = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)

test_files = splitter.load_splits(test_split)
pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(test_files, n_threads=20, loader=snc_loader, verbose=True)
test_data = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)
# Out:
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# 679 pclouds were loaded. They belong in 1 shape-classes.

# %%
encoder_args = { 'n_filters': [128, 128, 256, bneck_size],
                 'filter_sizes': [40, 20, 10, 10],
                 'strides': [1, 1, 2, 2],
                 'b_norm': True,
                }

decoder_args = {'layer_sizes': [1024, 2048, n_pc_points*3], 'b_norm': True}

# %%
if load_pretrained_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    if conf.train_dir != train_dir:
        conf.train_dir = train_dir
    conf.save(osp.join(train_dir, 'configuration'))
else:
    conf = Conf(
                n_input = [n_pc_points, 3],
                loss = loss,
                training_epochs = 1000,
                batch_size = 50,
                denoising = False,
                learning_rate = 0.0005,
                train_dir = train_dir,              
                loss_display_step = 1,                
                saver_step = 20,
                z_rotate = False,
                encoder = encoder_with_convs_and_symmetry,
                decoder = decoder_with_fc_only,
                encoder_args = encoder_args,
                decoder_args = decoder_args                
               )    
    conf.experiment_name = experiment_name
    conf.held_out_step = 5
    conf.save(osp.join(conf.train_dir, 'configuration'))

# %%
reset_tf_graph()
ae = PointNetAutoEncoder(conf.experiment_name, conf)

# %%
if load_pretrained_model:
    if load_epoch is None: # load last saved.
        saved_epochs = read_saved_epochs(conf.train_dir)
        load_epoch = saved_epochs[-1]        
    ae.restore_model(conf.train_dir, load_epoch, verbose=True)

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
    train_stats = ae.train(train_data, conf, log_file=fout, held_out_data=test_data)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.2103', 'loss=', '0.018220379')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '0.2095', 'loss=', '0.006343505')
# ('Epoch:', '0003', 'training time (minutes)=', '0.2112', 'loss=', '0.005729049')
# ('Epoch:', '0004', 'training time (minutes)=', '0.2129', 'loss=', '0.006067252')
# ('Epoch:', '0005', 'training time (minutes)=', '0.2134', 'loss=', '0.007095961')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.008862981')
# ('Epoch:', '0006', 'training time (minutes)=', '0.2150', 'loss=', '0.006925992')
# ('Epoch:', '0007', 'training time (minutes)=', '0.2179', 'loss=', '0.006707645')
# ('Epoch:', '0008', 'training time (minutes)=', '0.2197', 'loss=', '0.005693067')
# ('Epoch:', '0009', 'training time (minutes)=', '0.2262', 'loss=', '0.004479381')
# ('Epoch:', '0010', 'training time (minutes)=', '0.2190', 'loss=', '0.007552879')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.003687696')
# ('Epoch:', '0011', 'training time (minutes)=', '0.2229', 'loss=', '0.003208522')
# ('Epoch:', '0012', 'training time (minutes)=', '0.2266', 'loss=', '0.002721995')
# ('Epoch:', '0013', 'training time (minutes)=', '0.2232', 'loss=', '0.002429593')
# ('Epoch:', '0014', 'training time (minutes)=', '0.2188', 'loss=', '0.002929207')
# ('Epoch:', '0015', 'training time (minutes)=', '0.2274', 'loss=', '0.002959954')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.002341621')
# ('Epoch:', '0016', 'training time (minutes)=', '0.2226', 'loss=', '0.002369157')
# ('Epoch:', '0017', 'training time (minutes)=', '0.2244', 'loss=', '0.002644342')
# ('Epoch:', '0018', 'training time (minutes)=', '0.2229', 'loss=', '0.002259020')
# ('Epoch:', '0019', 'training time (minutes)=', '0.2239', 'loss=', '0.001979098')
# ('Epoch:', '0020', 'training time (minutes)=', '0.2278', 'loss=', '0.001987051')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001910866')
# ('Epoch:', '0021', 'training time (minutes)=', '0.2200', 'loss=', '0.001861061')
# ('Epoch:', '0022', 'training time (minutes)=', '0.2253', 'loss=', '0.001883910')
# ('Epoch:', '0023', 'training time (minutes)=', '0.2224', 'loss=', '0.001850051')
# ('Epoch:', '0024', 'training time (minutes)=', '0.2227', 'loss=', '0.001729908')
# ('Epoch:', '0025', 'training time (minutes)=', '0.2259', 'loss=', '0.003931086')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.003366802')
# ('Epoch:', '0026', 'training time (minutes)=', '0.2285', 'loss=', '0.002134311')
# ('Epoch:', '0027', 'training time (minutes)=', '0.2214', 'loss=', '0.001993407')
# ('Epoch:', '0028', 'training time (minutes)=', '0.2266', 'loss=', '0.001755078')
# ('Epoch:', '0029', 'training time (minutes)=', '0.2280', 'loss=', '0.001680600')
# ('Epoch:', '0030', 'training time (minutes)=', '0.2183', 'loss=', '0.001653634')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001848143')
# ('Epoch:', '0031', 'training time (minutes)=', '0.2230', 'loss=', '0.001610650')
# ('Epoch:', '0032', 'training time (minutes)=', '0.2269', 'loss=', '0.001595661')
# ('Epoch:', '0033', 'training time (minutes)=', '0.2269', 'loss=', '0.001525059')
# ('Epoch:', '0034', 'training time (minutes)=', '0.2275', 'loss=', '0.001481744')
# ('Epoch:', '0035', 'training time (minutes)=', '0.2188', 'loss=', '0.001451714')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001457929')
# ('Epoch:', '0036', 'training time (minutes)=', '0.2289', 'loss=', '0.001444404')
# ('Epoch:', '0037', 'training time (minutes)=', '0.2251', 'loss=', '0.001471423')
# ('Epoch:', '0038', 'training time (minutes)=', '0.2206', 'loss=', '0.001435530')
# ('Epoch:', '0039', 'training time (minutes)=', '0.2261', 'loss=', '0.001380038')
# ('Epoch:', '0040', 'training time (minutes)=', '0.2220', 'loss=', '0.001377719')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001502802')
# ('Epoch:', '0041', 'training time (minutes)=', '0.2249', 'loss=', '0.001370710')
# ('Epoch:', '0042', 'training time (minutes)=', '0.2190', 'loss=', '0.001360425')
# ('Epoch:', '0043', 'training time (minutes)=', '0.2285', 'loss=', '0.001308462')
# ('Epoch:', '0044', 'training time (minutes)=', '0.2247', 'loss=', '0.001326162')
# ('Epoch:', '0045', 'training time (minutes)=', '0.2281', 'loss=', '0.001291721')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001461676')
# ('Epoch:', '0046', 'training time (minutes)=', '0.2233', 'loss=', '0.001273781')
# ('Epoch:', '0047', 'training time (minutes)=', '0.2239', 'loss=', '0.001255383')
# ('Epoch:', '0048', 'training time (minutes)=', '0.2255', 'loss=', '0.001357631')
# ('Epoch:', '0049', 'training time (minutes)=', '0.2214', 'loss=', '0.002294151')
# ('Epoch:', '0050', 'training time (minutes)=', '0.2216', 'loss=', '0.001568085')
# ('Held Out Data :', 'forward time (minutes)=', '0.0070', 'loss=', '0.002482157')
# ('Epoch:', '0051', 'training time (minutes)=', '0.2237', 'loss=', '0.001437014')
# ('Epoch:', '0052', 'training time (minutes)=', '0.2237', 'loss=', '0.001386064')
# ('Epoch:', '0053', 'training time (minutes)=', '0.2283', 'loss=', '0.001305662')
# ('Epoch:', '0054', 'training time (minutes)=', '0.2240', 'loss=', '0.001281613')
# ('Epoch:', '0055', 'training time (minutes)=', '0.2257', 'loss=', '0.001247399')
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.001552737')
# ('Epoch:', '0056', 'training time (minutes)=', '0.2232', 'loss=', '0.001230713')
# ('Epoch:', '0057', 'training time (minutes)=', '0.2242', 'loss=', '0.001858713')
# ('Epoch:', '0058', 'training time (minutes)=', '0.2236', 'loss=', '0.001394889')
# ('Epoch:', '0059', 'training time (minutes)=', '0.2275', 'loss=', '0.001286532')
# ('Epoch:', '0060', 'training time (minutes)=', '0.2182', 'loss=', '0.001226942')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001370871')
# ('Epoch:', '0061', 'training time (minutes)=', '0.2239', 'loss=', '0.001247190')
# ('Epoch:', '0062', 'training time (minutes)=', '0.2240', 'loss=', '0.001179376')
# ('Epoch:', '0063', 'training time (minutes)=', '0.2230', 'loss=', '0.001153644')
# ('Epoch:', '0064', 'training time (minutes)=', '0.2213', 'loss=', '0.001164174')
# ('Epoch:', '0065', 'training time (minutes)=', '0.2229', 'loss=', '0.001139004')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001188190')
# ('Epoch:', '0066', 'training time (minutes)=', '0.2191', 'loss=', '0.001200957')
# ('Epoch:', '0067', 'training time (minutes)=', '0.2226', 'loss=', '0.001113477')
# ('Epoch:', '0068', 'training time (minutes)=', '0.2209', 'loss=', '0.001119786')
# ('Epoch:', '0069', 'training time (minutes)=', '0.2282', 'loss=', '0.001090591')
# ('Epoch:', '0070', 'training time (minutes)=', '0.2221', 'loss=', '0.001069757')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001085288')
# ('Epoch:', '0071', 'training time (minutes)=', '0.2245', 'loss=', '0.001087060')
# ('Epoch:', '0072', 'training time (minutes)=', '0.2250', 'loss=', '0.001090861')
# ('Epoch:', '0073', 'training time (minutes)=', '0.2212', 'loss=', '0.001072750')
# ('Epoch:', '0074', 'training time (minutes)=', '0.2232', 'loss=', '0.001071318')
# ('Epoch:', '0075', 'training time (minutes)=', '0.2245', 'loss=', '0.001076126')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001190640')
# ('Epoch:', '0076', 'training time (minutes)=', '0.2182', 'loss=', '0.001037080')
# ('Epoch:', '0077', 'training time (minutes)=', '0.2192', 'loss=', '0.001063325')
# ('Epoch:', '0078', 'training time (minutes)=', '0.2316', 'loss=', '0.001039769')
# ('Epoch:', '0079', 'training time (minutes)=', '0.2205', 'loss=', '0.001032188')
# ('Epoch:', '0080', 'training time (minutes)=', '0.2193', 'loss=', '0.001020324')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001036538')
# ('Epoch:', '0081', 'training time (minutes)=', '0.2193', 'loss=', '0.001009544')
# ('Epoch:', '0082', 'training time (minutes)=', '0.2271', 'loss=', '0.000974460')
# ('Epoch:', '0083', 'training time (minutes)=', '0.2196', 'loss=', '0.000994691')
# ('Epoch:', '0084', 'training time (minutes)=', '0.2226', 'loss=', '0.001042173')
# ('Epoch:', '0085', 'training time (minutes)=', '0.2248', 'loss=', '0.001109537')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001167471')
# ('Epoch:', '0086', 'training time (minutes)=', '0.2287', 'loss=', '0.001110541')
# ('Epoch:', '0087', 'training time (minutes)=', '0.2221', 'loss=', '0.001074339')
# ('Epoch:', '0088', 'training time (minutes)=', '0.2249', 'loss=', '0.000999905')
# ('Epoch:', '0089', 'training time (minutes)=', '0.2273', 'loss=', '0.000973930')
# ('Epoch:', '0090', 'training time (minutes)=', '0.2219', 'loss=', '0.000977630')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.001052651')
# ('Epoch:', '0091', 'training time (minutes)=', '0.2253', 'loss=', '0.000951031')
# ('Epoch:', '0092', 'training time (minutes)=', '0.2191', 'loss=', '0.000967367')
# ('Epoch:', '0093', 'training time (minutes)=', '0.2242', 'loss=', '0.000957363')
# ('Epoch:', '0094', 'training time (minutes)=', '0.2252', 'loss=', '0.000986045')
# ('Epoch:', '0095', 'training time (minutes)=', '0.2205', 'loss=', '0.000945549')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.001140159')
# ('Epoch:', '0096', 'training time (minutes)=', '0.2238', 'loss=', '0.000999990')
# ('Epoch:', '0097', 'training time (minutes)=', '0.2326', 'loss=', '0.000930952')
# ('Epoch:', '0098', 'training time (minutes)=', '0.2226', 'loss=', '0.000952661')
# ('Epoch:', '0099', 'training time (minutes)=', '0.2233', 'loss=', '0.000931641')
# ('Epoch:', '0100', 'training time (minutes)=', '0.2228', 'loss=', '0.000908396')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001010509')
# ('Epoch:', '0101', 'training time (minutes)=', '0.2183', 'loss=', '0.000905309')
# ('Epoch:', '0102', 'training time (minutes)=', '0.2316', 'loss=', '0.000927211')
# ('Epoch:', '0103', 'training time (minutes)=', '0.2261', 'loss=', '0.000910974')
# ('Epoch:', '0104', 'training time (minutes)=', '0.2246', 'loss=', '0.000899338')
# ('Epoch:', '0105', 'training time (minutes)=', '0.2263', 'loss=', '0.000935162')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.001011340')
# ('Epoch:', '0106', 'training time (minutes)=', '0.2261', 'loss=', '0.000897052')
# ('Epoch:', '0107', 'training time (minutes)=', '0.2291', 'loss=', '0.000986426')
# ('Epoch:', '0108', 'training time (minutes)=', '0.2192', 'loss=', '0.000950907')
# ('Epoch:', '0109', 'training time (minutes)=', '0.2354', 'loss=', '0.000903999')
# ('Epoch:', '0110', 'training time (minutes)=', '0.2252', 'loss=', '0.000893763')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001161809')
# ('Epoch:', '0111', 'training time (minutes)=', '0.2204', 'loss=', '0.000918670')
# ('Epoch:', '0112', 'training time (minutes)=', '0.2291', 'loss=', '0.000907573')
# ('Epoch:', '0113', 'training time (minutes)=', '0.2210', 'loss=', '0.000856916')
# ('Epoch:', '0114', 'training time (minutes)=', '0.2255', 'loss=', '0.000862813')
# ('Epoch:', '0115', 'training time (minutes)=', '0.2258', 'loss=', '0.000855986')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000907093')
# ('Epoch:', '0116', 'training time (minutes)=', '0.2221', 'loss=', '0.000872378')
# ('Epoch:', '0117', 'training time (minutes)=', '0.2224', 'loss=', '0.000844426')
# ('Epoch:', '0118', 'training time (minutes)=', '0.2218', 'loss=', '0.000872875')
# ('Epoch:', '0119', 'training time (minutes)=', '0.2221', 'loss=', '0.000842182')
# ('Epoch:', '0120', 'training time (minutes)=', '0.2310', 'loss=', '0.000832077')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000969918')
# ('Epoch:', '0121', 'training time (minutes)=', '0.2187', 'loss=', '0.000837992')
# ('Epoch:', '0122', 'training time (minutes)=', '0.2204', 'loss=', '0.000842961')
# ('Epoch:', '0123', 'training time (minutes)=', '0.2236', 'loss=', '0.000820104')
# ('Epoch:', '0124', 'training time (minutes)=', '0.2198', 'loss=', '0.000814422')
# ('Epoch:', '0125', 'training time (minutes)=', '0.2240', 'loss=', '0.000922692')
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.001094237')
# ('Epoch:', '0126', 'training time (minutes)=', '0.2257', 'loss=', '0.000847630')
# ('Epoch:', '0127', 'training time (minutes)=', '0.2265', 'loss=', '0.000854802')
# ('Epoch:', '0128', 'training time (minutes)=', '0.2225', 'loss=', '0.000813859')
# ('Epoch:', '0129', 'training time (minutes)=', '0.2235', 'loss=', '0.000817839')
# ('Epoch:', '0130', 'training time (minutes)=', '0.2293', 'loss=', '0.000805608')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000974581')
# ('Epoch:', '0131', 'training time (minutes)=', '0.2235', 'loss=', '0.000802760')
# ('Epoch:', '0132', 'training time (minutes)=', '0.2248', 'loss=', '0.000807508')
# ('Epoch:', '0133', 'training time (minutes)=', '0.2204', 'loss=', '0.000908759')
# ('Epoch:', '0134', 'training time (minutes)=', '0.2273', 'loss=', '0.000830918')
# ('Epoch:', '0135', 'training time (minutes)=', '0.2269', 'loss=', '0.000851483')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000895655')
# ('Epoch:', '0136', 'training time (minutes)=', '0.2228', 'loss=', '0.000791618')
# ('Epoch:', '0137', 'training time (minutes)=', '0.2284', 'loss=', '0.000787965')
# ('Epoch:', '0138', 'training time (minutes)=', '0.2231', 'loss=', '0.000800500')
# ('Epoch:', '0139', 'training time (minutes)=', '0.2195', 'loss=', '0.000825502')
# ('Epoch:', '0140', 'training time (minutes)=', '0.2340', 'loss=', '0.000804118')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000865727')
# ('Epoch:', '0141', 'training time (minutes)=', '0.2192', 'loss=', '0.000795132')
# ('Epoch:', '0142', 'training time (minutes)=', '0.2182', 'loss=', '0.000847095')
# ('Epoch:', '0143', 'training time (minutes)=', '0.2232', 'loss=', '0.000798805')
# ('Epoch:', '0144', 'training time (minutes)=', '0.2232', 'loss=', '0.000811507')
# ('Epoch:', '0145', 'training time (minutes)=', '0.2236', 'loss=', '0.000775854')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000909798')
# ('Epoch:', '0146', 'training time (minutes)=', '0.2265', 'loss=', '0.000792822')
# ('Epoch:', '0147', 'training time (minutes)=', '0.2258', 'loss=', '0.000774511')
# ('Epoch:', '0148', 'training time (minutes)=', '0.2215', 'loss=', '0.000765405')
# ('Epoch:', '0149', 'training time (minutes)=', '0.2280', 'loss=', '0.000750750')
# ('Epoch:', '0150', 'training time (minutes)=', '0.2239', 'loss=', '0.000838951')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001478815')
# ('Epoch:', '0151', 'training time (minutes)=', '0.2265', 'loss=', '0.000868977')
# ('Epoch:', '0152', 'training time (minutes)=', '0.2233', 'loss=', '0.000796036')
# ('Epoch:', '0153', 'training time (minutes)=', '0.2209', 'loss=', '0.000768485')
# ('Epoch:', '0154', 'training time (minutes)=', '0.2212', 'loss=', '0.000771551')
# ('Epoch:', '0155', 'training time (minutes)=', '0.2263', 'loss=', '0.000792312')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000887310')
# ('Epoch:', '0156', 'training time (minutes)=', '0.2239', 'loss=', '0.000748734')
# ('Epoch:', '0157', 'training time (minutes)=', '0.2275', 'loss=', '0.000771094')
# ('Epoch:', '0158', 'training time (minutes)=', '0.2251', 'loss=', '0.000750263')
# ('Epoch:', '0159', 'training time (minutes)=', '0.2226', 'loss=', '0.000744319')
# ('Epoch:', '0160', 'training time (minutes)=', '0.2185', 'loss=', '0.000747617')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000937361')
# ('Epoch:', '0161', 'training time (minutes)=', '0.2211', 'loss=', '0.000746611')
# ('Epoch:', '0162', 'training time (minutes)=', '0.2214', 'loss=', '0.000799209')
# ('Epoch:', '0163', 'training time (minutes)=', '0.2313', 'loss=', '0.000748152')
# ('Epoch:', '0164', 'training time (minutes)=', '0.2268', 'loss=', '0.000734319')
# ('Epoch:', '0165', 'training time (minutes)=', '0.2203', 'loss=', '0.000734128')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000990863')
# ('Epoch:', '0166', 'training time (minutes)=', '0.2217', 'loss=', '0.000735378')
# ('Epoch:', '0167', 'training time (minutes)=', '0.2267', 'loss=', '0.000733759')
# ('Epoch:', '0168', 'training time (minutes)=', '0.2227', 'loss=', '0.000718110')
# ('Epoch:', '0169', 'training time (minutes)=', '0.2220', 'loss=', '0.000727889')
# ('Epoch:', '0170', 'training time (minutes)=', '0.2303', 'loss=', '0.000735915')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000871308')
# ('Epoch:', '0171', 'training time (minutes)=', '0.2171', 'loss=', '0.000764563')
# ('Epoch:', '0172', 'training time (minutes)=', '0.2232', 'loss=', '0.000731385')
# ('Epoch:', '0173', 'training time (minutes)=', '0.2305', 'loss=', '0.000719526')
# ('Epoch:', '0174', 'training time (minutes)=', '0.2233', 'loss=', '0.000729487')
# ('Epoch:', '0175', 'training time (minutes)=', '0.2204', 'loss=', '0.000725041')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000885603')
# ('Epoch:', '0176', 'training time (minutes)=', '0.2223', 'loss=', '0.000710256')
# ('Epoch:', '0177', 'training time (minutes)=', '0.2278', 'loss=', '0.000714101')
# ('Epoch:', '0178', 'training time (minutes)=', '0.2273', 'loss=', '0.000695757')
# ('Epoch:', '0179', 'training time (minutes)=', '0.2234', 'loss=', '0.000697808')
# ('Epoch:', '0180', 'training time (minutes)=', '0.2253', 'loss=', '0.000728290')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000900915')
# ('Epoch:', '0181', 'training time (minutes)=', '0.2189', 'loss=', '0.000701613')
# ('Epoch:', '0182', 'training time (minutes)=', '0.2235', 'loss=', '0.000702011')
# ('Epoch:', '0183', 'training time (minutes)=', '0.2259', 'loss=', '0.000771256')
# ('Epoch:', '0184', 'training time (minutes)=', '0.2213', 'loss=', '0.000833763')
# ('Epoch:', '0185', 'training time (minutes)=', '0.2193', 'loss=', '0.000752308')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000902304')
# ('Epoch:', '0186', 'training time (minutes)=', '0.2231', 'loss=', '0.000715843')
# ('Epoch:', '0187', 'training time (minutes)=', '0.2292', 'loss=', '0.000720270')
# ('Epoch:', '0188', 'training time (minutes)=', '0.2233', 'loss=', '0.000704934')
# ('Epoch:', '0189', 'training time (minutes)=', '0.2193', 'loss=', '0.000698357')
# ('Epoch:', '0190', 'training time (minutes)=', '0.2208', 'loss=', '0.000690372')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000886283')
# ('Epoch:', '0191', 'training time (minutes)=', '0.2223', 'loss=', '0.000686407')
# ('Epoch:', '0192', 'training time (minutes)=', '0.2285', 'loss=', '0.000700858')
# ('Epoch:', '0193', 'training time (minutes)=', '0.2256', 'loss=', '0.000711193')
# ('Epoch:', '0194', 'training time (minutes)=', '0.2190', 'loss=', '0.000682141')
# ('Epoch:', '0195', 'training time (minutes)=', '0.2265', 'loss=', '0.000691676')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000927734')
# ('Epoch:', '0196', 'training time (minutes)=', '0.2239', 'loss=', '0.000687525')
# ('Epoch:', '0197', 'training time (minutes)=', '0.2237', 'loss=', '0.000679229')
# ('Epoch:', '0198', 'training time (minutes)=', '0.2232', 'loss=', '0.000682967')
# ('Epoch:', '0199', 'training time (minutes)=', '0.2261', 'loss=', '0.000667448')
# ('Epoch:', '0200', 'training time (minutes)=', '0.2235', 'loss=', '0.000672408')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000877309')
# ('Epoch:', '0201', 'training time (minutes)=', '0.2187', 'loss=', '0.000679481')
# ('Epoch:', '0202', 'training time (minutes)=', '0.2220', 'loss=', '0.000755319')
# ('Epoch:', '0203', 'training time (minutes)=', '0.2243', 'loss=', '0.000680880')
# ('Epoch:', '0204', 'training time (minutes)=', '0.2259', 'loss=', '0.000689809')
# ('Epoch:', '0205', 'training time (minutes)=', '0.2217', 'loss=', '0.000677905')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000863408')
# ('Epoch:', '0206', 'training time (minutes)=', '0.2233', 'loss=', '0.000671261')
# ('Epoch:', '0207', 'training time (minutes)=', '0.2248', 'loss=', '0.000722552')
# ('Epoch:', '0208', 'training time (minutes)=', '0.2271', 'loss=', '0.000767805')
# ('Epoch:', '0209', 'training time (minutes)=', '0.2205', 'loss=', '0.000683167')
# ('Epoch:', '0210', 'training time (minutes)=', '0.2237', 'loss=', '0.000696275')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000921959')
# ('Epoch:', '0211', 'training time (minutes)=', '0.2212', 'loss=', '0.000681039')
# ('Epoch:', '0212', 'training time (minutes)=', '0.2207', 'loss=', '0.000666535')
# ('Epoch:', '0213', 'training time (minutes)=', '0.2244', 'loss=', '0.000661632')
# ('Epoch:', '0214', 'training time (minutes)=', '0.2264', 'loss=', '0.000670175')
# ('Epoch:', '0215', 'training time (minutes)=', '0.2255', 'loss=', '0.000657737')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000837240')
# ('Epoch:', '0216', 'training time (minutes)=', '0.2184', 'loss=', '0.000656161')
# ('Epoch:', '0217', 'training time (minutes)=', '0.2225', 'loss=', '0.000654697')
# ('Epoch:', '0218', 'training time (minutes)=', '0.2193', 'loss=', '0.000657072')
# ('Epoch:', '0219', 'training time (minutes)=', '0.2244', 'loss=', '0.000653842')
# ('Epoch:', '0220', 'training time (minutes)=', '0.2226', 'loss=', '0.000646118')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000863783')
# ('Epoch:', '0221', 'training time (minutes)=', '0.2225', 'loss=', '0.000652053')
# ('Epoch:', '0222', 'training time (minutes)=', '0.2216', 'loss=', '0.000647170')
# ('Epoch:', '0223', 'training time (minutes)=', '0.2239', 'loss=', '0.000646608')
# ('Epoch:', '0224', 'training time (minutes)=', '0.2222', 'loss=', '0.000634005')
# ('Epoch:', '0225', 'training time (minutes)=', '0.2220', 'loss=', '0.000654058')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000865834')
# ('Epoch:', '0226', 'training time (minutes)=', '0.2307', 'loss=', '0.000659753')
# ('Epoch:', '0227', 'training time (minutes)=', '0.2224', 'loss=', '0.000645337')
# ('Epoch:', '0228', 'training time (minutes)=', '0.2240', 'loss=', '0.000649507')
# ('Epoch:', '0229', 'training time (minutes)=', '0.2273', 'loss=', '0.000633723')
# ('Epoch:', '0230', 'training time (minutes)=', '0.2239', 'loss=', '0.000638720')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000845386')
# ('Epoch:', '0231', 'training time (minutes)=', '0.2271', 'loss=', '0.000633730')
# ('Epoch:', '0232', 'training time (minutes)=', '0.2245', 'loss=', '0.000640254')
# ('Epoch:', '0233', 'training time (minutes)=', '0.2242', 'loss=', '0.000669281')
# ('Epoch:', '0234', 'training time (minutes)=', '0.2262', 'loss=', '0.000659150')
# ('Epoch:', '0235', 'training time (minutes)=', '0.2221', 'loss=', '0.000636588')
# ('Held Out Data :', 'forward time (minutes)=', '0.0071', 'loss=', '0.000841246')
# ('Epoch:', '0236', 'training time (minutes)=', '0.2205', 'loss=', '0.000638085')
# ('Epoch:', '0237', 'training time (minutes)=', '0.2208', 'loss=', '0.000629555')
# ('Epoch:', '0238', 'training time (minutes)=', '0.2226', 'loss=', '0.000614789')
# ('Epoch:', '0239', 'training time (minutes)=', '0.2255', 'loss=', '0.000644546')
# ('Epoch:', '0240', 'training time (minutes)=', '0.2240', 'loss=', '0.000621266')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000837969')
# ('Epoch:', '0241', 'training time (minutes)=', '0.2225', 'loss=', '0.000617772')
# ('Epoch:', '0242', 'training time (minutes)=', '0.2204', 'loss=', '0.000624512')
# ('Epoch:', '0243', 'training time (minutes)=', '0.2178', 'loss=', '0.000674422')
# ('Epoch:', '0244', 'training time (minutes)=', '0.2250', 'loss=', '0.000712673')
# ('Epoch:', '0245', 'training time (minutes)=', '0.2223', 'loss=', '0.000652600')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.000934966')
# ('Epoch:', '0246', 'training time (minutes)=', '0.2219', 'loss=', '0.000640593')
# ('Epoch:', '0247', 'training time (minutes)=', '0.2220', 'loss=', '0.000624241')
# ('Epoch:', '0248', 'training time (minutes)=', '0.2215', 'loss=', '0.000615895')
# ('Epoch:', '0249', 'training time (minutes)=', '0.2212', 'loss=', '0.000627975')
# ('Epoch:', '0250', 'training time (minutes)=', '0.2218', 'loss=', '0.000616210')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000860978')
# ('Epoch:', '0251', 'training time (minutes)=', '0.2216', 'loss=', '0.000635760')
# ('Epoch:', '0252', 'training time (minutes)=', '0.2217', 'loss=', '0.000629002')
# ('Epoch:', '0253', 'training time (minutes)=', '0.2221', 'loss=', '0.000612347')
# ('Epoch:', '0254', 'training time (minutes)=', '0.2223', 'loss=', '0.000630894')
# ('Epoch:', '0255', 'training time (minutes)=', '0.2212', 'loss=', '0.000620294')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000830935')
# ('Epoch:', '0256', 'training time (minutes)=', '0.2220', 'loss=', '0.000603594')
# ('Epoch:', '0257', 'training time (minutes)=', '0.2219', 'loss=', '0.000613691')
# ('Epoch:', '0258', 'training time (minutes)=', '0.2216', 'loss=', '0.000602027')
# ('Epoch:', '0259', 'training time (minutes)=', '0.2218', 'loss=', '0.000607002')
# ('Epoch:', '0260', 'training time (minutes)=', '0.2214', 'loss=', '0.000603650')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000808396')
# ('Epoch:', '0261', 'training time (minutes)=', '0.2209', 'loss=', '0.000597728')
# ('Epoch:', '0262', 'training time (minutes)=', '0.2211', 'loss=', '0.000598415')
# ('Epoch:', '0263', 'training time (minutes)=', '0.2212', 'loss=', '0.000595955')
# ('Epoch:', '0264', 'training time (minutes)=', '0.2222', 'loss=', '0.000813969')
# ('Epoch:', '0265', 'training time (minutes)=', '0.2221', 'loss=', '0.000987076')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000938403')
# ('Epoch:', '0266', 'training time (minutes)=', '0.2215', 'loss=', '0.000770505')
# ('Epoch:', '0267', 'training time (minutes)=', '0.2218', 'loss=', '0.000689557')
# ('Epoch:', '0268', 'training time (minutes)=', '0.2215', 'loss=', '0.000667800')
# ('Epoch:', '0269', 'training time (minutes)=', '0.2218', 'loss=', '0.000645291')
# ('Epoch:', '0270', 'training time (minutes)=', '0.2216', 'loss=', '0.000641412')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000815124')
# ('Epoch:', '0271', 'training time (minutes)=', '0.2213', 'loss=', '0.000641986')
# ('Epoch:', '0272', 'training time (minutes)=', '0.2220', 'loss=', '0.000642168')
# ('Epoch:', '0273', 'training time (minutes)=', '0.2217', 'loss=', '0.000621584')
# ('Epoch:', '0274', 'training time (minutes)=', '0.2216', 'loss=', '0.000612574')
# ('Epoch:', '0275', 'training time (minutes)=', '0.2221', 'loss=', '0.000602498')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000800716')
# ('Epoch:', '0276', 'training time (minutes)=', '0.2220', 'loss=', '0.000603763')
# ('Epoch:', '0277', 'training time (minutes)=', '0.2216', 'loss=', '0.000612643')
# ('Epoch:', '0278', 'training time (minutes)=', '0.2217', 'loss=', '0.000596793')
# ('Epoch:', '0279', 'training time (minutes)=', '0.2216', 'loss=', '0.000607133')
# ('Epoch:', '0280', 'training time (minutes)=', '0.2214', 'loss=', '0.000603136')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000861857')
# ('Epoch:', '0281', 'training time (minutes)=', '0.2208', 'loss=', '0.000598767')
# ('Epoch:', '0282', 'training time (minutes)=', '0.2218', 'loss=', '0.000593146')
# ('Epoch:', '0283', 'training time (minutes)=', '0.2216', 'loss=', '0.000592136')
# ('Epoch:', '0284', 'training time (minutes)=', '0.2212', 'loss=', '0.000593219')
# ('Epoch:', '0285', 'training time (minutes)=', '0.2215', 'loss=', '0.000586676')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000813172')
# ('Epoch:', '0286', 'training time (minutes)=', '0.2216', 'loss=', '0.000603716')
# ('Epoch:', '0287', 'training time (minutes)=', '0.2216', 'loss=', '0.000581532')
# ('Epoch:', '0288', 'training time (minutes)=', '0.2215', 'loss=', '0.000587718')
# ('Epoch:', '0289', 'training time (minutes)=', '0.2214', 'loss=', '0.000579005')
# ('Epoch:', '0290', 'training time (minutes)=', '0.2218', 'loss=', '0.000575266')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000791769')
# ('Epoch:', '0291', 'training time (minutes)=', '0.2212', 'loss=', '0.000583970')
# ('Epoch:', '0292', 'training time (minutes)=', '0.2219', 'loss=', '0.000578708')
# ('Epoch:', '0293', 'training time (minutes)=', '0.2215', 'loss=', '0.000584061')
# ('Epoch:', '0294', 'training time (minutes)=', '0.2219', 'loss=', '0.000589257')
# ('Epoch:', '0295', 'training time (minutes)=', '0.2213', 'loss=', '0.000606819')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000877280')
# ('Epoch:', '0296', 'training time (minutes)=', '0.2214', 'loss=', '0.000592327')
# ('Epoch:', '0297', 'training time (minutes)=', '0.2219', 'loss=', '0.000577076')
# ('Epoch:', '0298', 'training time (minutes)=', '0.2217', 'loss=', '0.000590044')
# ('Epoch:', '0299', 'training time (minutes)=', '0.2212', 'loss=', '0.000573083')
# ('Epoch:', '0300', 'training time (minutes)=', '0.2217', 'loss=', '0.000574058')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000829499')
# ('Epoch:', '0301', 'training time (minutes)=', '0.2207', 'loss=', '0.000579227')
# ('Epoch:', '0302', 'training time (minutes)=', '0.2205', 'loss=', '0.000571861')
# ('Epoch:', '0303', 'training time (minutes)=', '0.2208', 'loss=', '0.000576700')
# ('Epoch:', '0304', 'training time (minutes)=', '0.2217', 'loss=', '0.000568959')
# ('Epoch:', '0305', 'training time (minutes)=', '0.2214', 'loss=', '0.000567858')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000819888')
# ('Epoch:', '0306', 'training time (minutes)=', '0.2215', 'loss=', '0.000566512')
# ('Epoch:', '0307', 'training time (minutes)=', '0.2216', 'loss=', '0.000566297')
# ('Epoch:', '0308', 'training time (minutes)=', '0.2219', 'loss=', '0.000571557')
# ('Epoch:', '0309', 'training time (minutes)=', '0.2215', 'loss=', '0.000570493')
# ('Epoch:', '0310', 'training time (minutes)=', '0.2220', 'loss=', '0.000559753')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000826163')
# ('Epoch:', '0311', 'training time (minutes)=', '0.2218', 'loss=', '0.000571601')
# ('Epoch:', '0312', 'training time (minutes)=', '0.2214', 'loss=', '0.000565880')
# ('Epoch:', '0313', 'training time (minutes)=', '0.2219', 'loss=', '0.000563571')
# ('Epoch:', '0314', 'training time (minutes)=', '0.2218', 'loss=', '0.000562365')
# ('Epoch:', '0315', 'training time (minutes)=', '0.2215', 'loss=', '0.000562722')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000802265')
# ('Epoch:', '0316', 'training time (minutes)=', '0.2212', 'loss=', '0.000566591')
# ('Epoch:', '0317', 'training time (minutes)=', '0.2215', 'loss=', '0.000563696')
# ('Epoch:', '0318', 'training time (minutes)=', '0.2215', 'loss=', '0.000565098')
# ('Epoch:', '0319', 'training time (minutes)=', '0.2220', 'loss=', '0.000662204')
# ('Epoch:', '0320', 'training time (minutes)=', '0.2216', 'loss=', '0.000581386')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000816001')
# ('Epoch:', '0321', 'training time (minutes)=', '0.2210', 'loss=', '0.000576955')
# ('Epoch:', '0322', 'training time (minutes)=', '0.2215', 'loss=', '0.000560691')
# ('Epoch:', '0323', 'training time (minutes)=', '0.2211', 'loss=', '0.000566050')
# ('Epoch:', '0324', 'training time (minutes)=', '0.2211', 'loss=', '0.000554182')
# ('Epoch:', '0325', 'training time (minutes)=', '0.2216', 'loss=', '0.000930243')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001061035')
# ('Epoch:', '0326', 'training time (minutes)=', '0.2218', 'loss=', '0.000829993')
# ('Epoch:', '0327', 'training time (minutes)=', '0.2220', 'loss=', '0.000687441')
# ('Epoch:', '0328', 'training time (minutes)=', '0.2218', 'loss=', '0.000652596')
# ('Epoch:', '0329', 'training time (minutes)=', '0.2220', 'loss=', '0.000625523')
# ('Epoch:', '0330', 'training time (minutes)=', '0.2222', 'loss=', '0.000601574')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000807359')
# ('Epoch:', '0331', 'training time (minutes)=', '0.2212', 'loss=', '0.000597077')
# ('Epoch:', '0332', 'training time (minutes)=', '0.2217', 'loss=', '0.000592213')
# ('Epoch:', '0333', 'training time (minutes)=', '0.2214', 'loss=', '0.000576940')
# ('Epoch:', '0334', 'training time (minutes)=', '0.2216', 'loss=', '0.000587869')
# ('Epoch:', '0335', 'training time (minutes)=', '0.2213', 'loss=', '0.000579198')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000819271')
# ('Epoch:', '0336', 'training time (minutes)=', '0.2211', 'loss=', '0.000575040')
# ('Epoch:', '0337', 'training time (minutes)=', '0.2212', 'loss=', '0.000562902')
# ('Epoch:', '0338', 'training time (minutes)=', '0.2213', 'loss=', '0.000559997')
# ('Epoch:', '0339', 'training time (minutes)=', '0.2214', 'loss=', '0.000559847')
# ('Epoch:', '0340', 'training time (minutes)=', '0.2216', 'loss=', '0.000577489')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000826066')
# ('Epoch:', '0341', 'training time (minutes)=', '0.2211', 'loss=', '0.000559037')
# ('Epoch:', '0342', 'training time (minutes)=', '0.2212', 'loss=', '0.000545770')
# ('Epoch:', '0343', 'training time (minutes)=', '0.2214', 'loss=', '0.000561745')
# ('Epoch:', '0344', 'training time (minutes)=', '0.2216', 'loss=', '0.000550181')
# ('Epoch:', '0345', 'training time (minutes)=', '0.2218', 'loss=', '0.000544535')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000806536')
# ('Epoch:', '0346', 'training time (minutes)=', '0.2221', 'loss=', '0.000550732')
# ('Epoch:', '0347', 'training time (minutes)=', '0.2220', 'loss=', '0.000542993')
# ('Epoch:', '0348', 'training time (minutes)=', '0.2215', 'loss=', '0.000562869')
# ('Epoch:', '0349', 'training time (minutes)=', '0.2220', 'loss=', '0.000555532')
# ('Epoch:', '0350', 'training time (minutes)=', '0.2218', 'loss=', '0.000552665')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000805850')
# ('Epoch:', '0351', 'training time (minutes)=', '0.2216', 'loss=', '0.000544295')
# ('Epoch:', '0352', 'training time (minutes)=', '0.2220', 'loss=', '0.000538144')
# ('Epoch:', '0353', 'training time (minutes)=', '0.2222', 'loss=', '0.000536459')
# ('Epoch:', '0354', 'training time (minutes)=', '0.2217', 'loss=', '0.000598758')
# ('Epoch:', '0355', 'training time (minutes)=', '0.2215', 'loss=', '0.000570952')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000821957')
# ('Epoch:', '0356', 'training time (minutes)=', '0.2218', 'loss=', '0.000560150')
# ('Epoch:', '0357', 'training time (minutes)=', '0.2215', 'loss=', '0.000547316')
# ('Epoch:', '0358', 'training time (minutes)=', '0.2216', 'loss=', '0.000546383')
# ('Epoch:', '0359', 'training time (minutes)=', '0.2217', 'loss=', '0.000547930')
# ('Epoch:', '0360', 'training time (minutes)=', '0.2212', 'loss=', '0.000544168')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000799477')
# ('Epoch:', '0361', 'training time (minutes)=', '0.2210', 'loss=', '0.000541912')
# ('Epoch:', '0362', 'training time (minutes)=', '0.2210', 'loss=', '0.000538781')
# ('Epoch:', '0363', 'training time (minutes)=', '0.2212', 'loss=', '0.000536238')
# ('Epoch:', '0364', 'training time (minutes)=', '0.2215', 'loss=', '0.000536817')
# ('Epoch:', '0365', 'training time (minutes)=', '0.2214', 'loss=', '0.000532766')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000807570')
# ('Epoch:', '0366', 'training time (minutes)=', '0.2217', 'loss=', '0.000534642')
# ('Epoch:', '0367', 'training time (minutes)=', '0.2220', 'loss=', '0.000541976')
# ('Epoch:', '0368', 'training time (minutes)=', '0.2223', 'loss=', '0.000531878')
# ('Epoch:', '0369', 'training time (minutes)=', '0.2215', 'loss=', '0.000533280')
# ('Epoch:', '0370', 'training time (minutes)=', '0.2217', 'loss=', '0.000529645')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000820647')
# ('Epoch:', '0371', 'training time (minutes)=', '0.2219', 'loss=', '0.000539849')
# ('Epoch:', '0372', 'training time (minutes)=', '0.2213', 'loss=', '0.000537103')
# ('Epoch:', '0373', 'training time (minutes)=', '0.2214', 'loss=', '0.000546462')
# ('Epoch:', '0374', 'training time (minutes)=', '0.2219', 'loss=', '0.000579206')
# ('Epoch:', '0375', 'training time (minutes)=', '0.2214', 'loss=', '0.000536206')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000823833')
# ('Epoch:', '0376', 'training time (minutes)=', '0.2214', 'loss=', '0.000530068')
# ('Epoch:', '0377', 'training time (minutes)=', '0.2219', 'loss=', '0.000530120')
# ('Epoch:', '0378', 'training time (minutes)=', '0.2216', 'loss=', '0.000524130')
# ('Epoch:', '0379', 'training time (minutes)=', '0.2217', 'loss=', '0.000546328')
# ('Epoch:', '0380', 'training time (minutes)=', '0.2221', 'loss=', '0.000543692')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000834435')
# ('Epoch:', '0381', 'training time (minutes)=', '0.2209', 'loss=', '0.000531409')
# ('Epoch:', '0382', 'training time (minutes)=', '0.2213', 'loss=', '0.000526589')
# ('Epoch:', '0383', 'training time (minutes)=', '0.2214', 'loss=', '0.000522811')
# ('Epoch:', '0384', 'training time (minutes)=', '0.2215', 'loss=', '0.000518898')
# ('Epoch:', '0385', 'training time (minutes)=', '0.2212', 'loss=', '0.000530108')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000823831')
# ('Epoch:', '0386', 'training time (minutes)=', '0.2213', 'loss=', '0.000532249')
# ('Epoch:', '0387', 'training time (minutes)=', '0.2220', 'loss=', '0.000523308')
# ('Epoch:', '0388', 'training time (minutes)=', '0.2223', 'loss=', '0.000518188')
# ('Epoch:', '0389', 'training time (minutes)=', '0.2215', 'loss=', '0.000685189')
# ('Epoch:', '0390', 'training time (minutes)=', '0.2217', 'loss=', '0.000559733')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000796657')
# ('Epoch:', '0391', 'training time (minutes)=', '0.2213', 'loss=', '0.000543089')
# ('Epoch:', '0392', 'training time (minutes)=', '0.2221', 'loss=', '0.000529796')
# ('Epoch:', '0393', 'training time (minutes)=', '0.2216', 'loss=', '0.000517940')
# ('Epoch:', '0394', 'training time (minutes)=', '0.2224', 'loss=', '0.000530979')
# ('Epoch:', '0395', 'training time (minutes)=', '0.2215', 'loss=', '0.000519499')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000806284')
# ('Epoch:', '0396', 'training time (minutes)=', '0.2215', 'loss=', '0.000525491')
# ('Epoch:', '0397', 'training time (minutes)=', '0.2214', 'loss=', '0.000533086')
# ('Epoch:', '0398', 'training time (minutes)=', '0.2214', 'loss=', '0.000528909')
# ('Epoch:', '0399', 'training time (minutes)=', '0.2211', 'loss=', '0.000527614')
# ('Epoch:', '0400', 'training time (minutes)=', '0.2213', 'loss=', '0.000518251')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000812075')
# ('Epoch:', '0401', 'training time (minutes)=', '0.2206', 'loss=', '0.000527669')
# ('Epoch:', '0402', 'training time (minutes)=', '0.2206', 'loss=', '0.000541844')
# ('Epoch:', '0403', 'training time (minutes)=', '0.2210', 'loss=', '0.000526336')
# ('Epoch:', '0404', 'training time (minutes)=', '0.2213', 'loss=', '0.000516389')
# ('Epoch:', '0405', 'training time (minutes)=', '0.2216', 'loss=', '0.000513805')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000821000')
# ('Epoch:', '0406', 'training time (minutes)=', '0.2213', 'loss=', '0.000520203')
# ('Epoch:', '0407', 'training time (minutes)=', '0.2218', 'loss=', '0.000518856')
# ('Epoch:', '0408', 'training time (minutes)=', '0.2220', 'loss=', '0.000515987')
# ('Epoch:', '0409', 'training time (minutes)=', '0.2219', 'loss=', '0.000509008')
# ('Epoch:', '0410', 'training time (minutes)=', '0.2218', 'loss=', '0.000513024')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000798318')
# ('Epoch:', '0411', 'training time (minutes)=', '0.2216', 'loss=', '0.000511220')
# ('Epoch:', '0412', 'training time (minutes)=', '0.2214', 'loss=', '0.000509172')
# ('Epoch:', '0413', 'training time (minutes)=', '0.2216', 'loss=', '0.000507119')
# ('Epoch:', '0414', 'training time (minutes)=', '0.2215', 'loss=', '0.000510008')
# ('Epoch:', '0415', 'training time (minutes)=', '0.2219', 'loss=', '0.000510064')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000802341')
# ('Epoch:', '0416', 'training time (minutes)=', '0.2216', 'loss=', '0.000512721')
# ('Epoch:', '0417', 'training time (minutes)=', '0.2214', 'loss=', '0.000512297')
# ('Epoch:', '0418', 'training time (minutes)=', '0.2218', 'loss=', '0.000505483')
# ('Epoch:', '0419', 'training time (minutes)=', '0.2211', 'loss=', '0.000503749')
# ('Epoch:', '0420', 'training time (minutes)=', '0.2218', 'loss=', '0.000575135')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000793577')
# ('Epoch:', '0421', 'training time (minutes)=', '0.2212', 'loss=', '0.000527665')
# ('Epoch:', '0422', 'training time (minutes)=', '0.2213', 'loss=', '0.000511990')
# ('Epoch:', '0423', 'training time (minutes)=', '0.2211', 'loss=', '0.000508226')
# ('Epoch:', '0424', 'training time (minutes)=', '0.2214', 'loss=', '0.000507400')
# ('Epoch:', '0425', 'training time (minutes)=', '0.2212', 'loss=', '0.000503549')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000814055')
# ('Epoch:', '0426', 'training time (minutes)=', '0.2214', 'loss=', '0.000497092')
# ('Epoch:', '0427', 'training time (minutes)=', '0.2216', 'loss=', '0.000563136')
# ('Epoch:', '0428', 'training time (minutes)=', '0.2210', 'loss=', '0.000523422')
# ('Epoch:', '0429', 'training time (minutes)=', '0.2209', 'loss=', '0.000524245')
# ('Epoch:', '0430', 'training time (minutes)=', '0.2208', 'loss=', '0.000514291')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000816806')
# ('Epoch:', '0431', 'training time (minutes)=', '0.2210', 'loss=', '0.000515818')
# ('Epoch:', '0432', 'training time (minutes)=', '0.2214', 'loss=', '0.000502031')
# ('Epoch:', '0433', 'training time (minutes)=', '0.2217', 'loss=', '0.000505845')
# ('Epoch:', '0434', 'training time (minutes)=', '0.2216', 'loss=', '0.000501456')
# ('Epoch:', '0435', 'training time (minutes)=', '0.2214', 'loss=', '0.000498234')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000830955')
# ('Epoch:', '0436', 'training time (minutes)=', '0.2217', 'loss=', '0.000493078')
# ('Epoch:', '0437', 'training time (minutes)=', '0.2215', 'loss=', '0.000495184')
# ('Epoch:', '0438', 'training time (minutes)=', '0.2217', 'loss=', '0.000489767')
# ('Epoch:', '0439', 'training time (minutes)=', '0.2212', 'loss=', '0.000503979')
# ('Epoch:', '0440', 'training time (minutes)=', '0.2211', 'loss=', '0.000499558')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000842465')
# ('Epoch:', '0441', 'training time (minutes)=', '0.2206', 'loss=', '0.000498540')
# ...
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000800564')
# ('Epoch:', '0856', 'training time (minutes)=', '0.2310', 'loss=', '0.000408296')
# ('Epoch:', '0857', 'training time (minutes)=', '0.2241', 'loss=', '0.000408293')
# ('Epoch:', '0858', 'training time (minutes)=', '0.2294', 'loss=', '0.000404667')
# ('Epoch:', '0859', 'training time (minutes)=', '0.2282', 'loss=', '0.000404867')
# ('Epoch:', '0860', 'training time (minutes)=', '0.2246', 'loss=', '0.000409411')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-860 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000800366')
# ('Epoch:', '0861', 'training time (minutes)=', '0.2213', 'loss=', '0.000408015')
# ('Epoch:', '0862', 'training time (minutes)=', '0.2214', 'loss=', '0.000407894')
# ('Epoch:', '0863', 'training time (minutes)=', '0.2214', 'loss=', '0.000405241')
# ('Epoch:', '0864', 'training time (minutes)=', '0.2338', 'loss=', '0.000410240')
# ('Epoch:', '0865', 'training time (minutes)=', '0.2192', 'loss=', '0.000413517')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000808267')
# ('Epoch:', '0866', 'training time (minutes)=', '0.2273', 'loss=', '0.000415915')
# ('Epoch:', '0867', 'training time (minutes)=', '0.2289', 'loss=', '0.000411961')
# ('Epoch:', '0868', 'training time (minutes)=', '0.2315', 'loss=', '0.000417999')
# ('Epoch:', '0869', 'training time (minutes)=', '0.2262', 'loss=', '0.000406655')
# ('Epoch:', '0870', 'training time (minutes)=', '0.2342', 'loss=', '0.000404411')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000794140')
# ('Epoch:', '0871', 'training time (minutes)=', '0.2236', 'loss=', '0.000403459')
# ('Epoch:', '0872', 'training time (minutes)=', '0.2332', 'loss=', '0.000415197')
# ('Epoch:', '0873', 'training time (minutes)=', '0.2349', 'loss=', '0.000414740')
# ('Epoch:', '0874', 'training time (minutes)=', '0.2250', 'loss=', '0.000407877')
# ('Epoch:', '0875', 'training time (minutes)=', '0.2282', 'loss=', '0.000414712')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000804726')
# ('Epoch:', '0876', 'training time (minutes)=', '0.2305', 'loss=', '0.000410814')
# ('Epoch:', '0877', 'training time (minutes)=', '0.2259', 'loss=', '0.000403967')
# ('Epoch:', '0878', 'training time (minutes)=', '0.2269', 'loss=', '0.000405754')
# ('Epoch:', '0879', 'training time (minutes)=', '0.2293', 'loss=', '0.000407895')
# ('Epoch:', '0880', 'training time (minutes)=', '0.2316', 'loss=', '0.000405664')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-880 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000808681')
# ('Epoch:', '0881', 'training time (minutes)=', '0.2205', 'loss=', '0.000409965')
# ('Epoch:', '0882', 'training time (minutes)=', '0.2216', 'loss=', '0.000410761')
# ('Epoch:', '0883', 'training time (minutes)=', '0.2287', 'loss=', '0.000411584')
# ('Epoch:', '0884', 'training time (minutes)=', '0.2247', 'loss=', '0.000406480')
# ('Epoch:', '0885', 'training time (minutes)=', '0.2274', 'loss=', '0.000406568')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000801867')
# ('Epoch:', '0886', 'training time (minutes)=', '0.2306', 'loss=', '0.000400662')
# ('Epoch:', '0887', 'training time (minutes)=', '0.2205', 'loss=', '0.000401051')
# ('Epoch:', '0888', 'training time (minutes)=', '0.2194', 'loss=', '0.000403137')
# ('Epoch:', '0889', 'training time (minutes)=', '0.2265', 'loss=', '0.000412153')
# ('Epoch:', '0890', 'training time (minutes)=', '0.2232', 'loss=', '0.000411559')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000792752')
# ('Epoch:', '0891', 'training time (minutes)=', '0.2278', 'loss=', '0.000404824')
# ('Epoch:', '0892', 'training time (minutes)=', '0.2279', 'loss=', '0.000456937')
# ('Epoch:', '0893', 'training time (minutes)=', '0.2268', 'loss=', '0.000420912')
# ('Epoch:', '0894', 'training time (minutes)=', '0.2280', 'loss=', '0.000411474')
# ('Epoch:', '0895', 'training time (minutes)=', '0.2264', 'loss=', '0.000414524')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000789222')
# ('Epoch:', '0896', 'training time (minutes)=', '0.2217', 'loss=', '0.000406865')
# ('Epoch:', '0897', 'training time (minutes)=', '0.2271', 'loss=', '0.000401134')
# ('Epoch:', '0898', 'training time (minutes)=', '0.2290', 'loss=', '0.000400254')
# ('Epoch:', '0899', 'training time (minutes)=', '0.2294', 'loss=', '0.000406017')
# ('Epoch:', '0900', 'training time (minutes)=', '0.2254', 'loss=', '0.000406847')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-900 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000795980')
# ('Epoch:', '0901', 'training time (minutes)=', '0.2235', 'loss=', '0.000401661')
# ('Epoch:', '0902', 'training time (minutes)=', '0.2228', 'loss=', '0.000401909')
# ('Epoch:', '0903', 'training time (minutes)=', '0.2234', 'loss=', '0.000410454')
# ('Epoch:', '0904', 'training time (minutes)=', '0.2265', 'loss=', '0.000402653')
# ('Epoch:', '0905', 'training time (minutes)=', '0.2312', 'loss=', '0.000401765')
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000795983')
# ('Epoch:', '0906', 'training time (minutes)=', '0.2234', 'loss=', '0.000402763')
# ('Epoch:', '0907', 'training time (minutes)=', '0.2340', 'loss=', '0.000398941')
# ('Epoch:', '0908', 'training time (minutes)=', '0.2242', 'loss=', '0.000397421')
# ('Epoch:', '0909', 'training time (minutes)=', '0.2332', 'loss=', '0.000401117')
# ('Epoch:', '0910', 'training time (minutes)=', '0.2259', 'loss=', '0.000432933')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000875286')
# ('Epoch:', '0911', 'training time (minutes)=', '0.2248', 'loss=', '0.000425203')
# ('Epoch:', '0912', 'training time (minutes)=', '0.2316', 'loss=', '0.000407611')
# ('Epoch:', '0913', 'training time (minutes)=', '0.2246', 'loss=', '0.000408046')
# ('Epoch:', '0914', 'training time (minutes)=', '0.2225', 'loss=', '0.000408693')
# ('Epoch:', '0915', 'training time (minutes)=', '0.2292', 'loss=', '0.000399291')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000807980')
# ('Epoch:', '0916', 'training time (minutes)=', '0.2241', 'loss=', '0.000420680')
# ('Epoch:', '0917', 'training time (minutes)=', '0.2281', 'loss=', '0.000419862')
# ('Epoch:', '0918', 'training time (minutes)=', '0.2271', 'loss=', '0.000404693')
# ('Epoch:', '0919', 'training time (minutes)=', '0.2210', 'loss=', '0.000400956')
# ('Epoch:', '0920', 'training time (minutes)=', '0.2328', 'loss=', '0.000406452')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-920 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000797363')
# ('Epoch:', '0921', 'training time (minutes)=', '0.2212', 'loss=', '0.000398472')
# ('Epoch:', '0922', 'training time (minutes)=', '0.2260', 'loss=', '0.000400084')
# ('Epoch:', '0923', 'training time (minutes)=', '0.2279', 'loss=', '0.000413094')
# ('Epoch:', '0924', 'training time (minutes)=', '0.2268', 'loss=', '0.000407751')
# ('Epoch:', '0925', 'training time (minutes)=', '0.2237', 'loss=', '0.000406758')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000799197')
# ('Epoch:', '0926', 'training time (minutes)=', '0.2251', 'loss=', '0.000402904')
# ('Epoch:', '0927', 'training time (minutes)=', '0.2208', 'loss=', '0.000401365')
# ('Epoch:', '0928', 'training time (minutes)=', '0.2282', 'loss=', '0.000405076')
# ('Epoch:', '0929', 'training time (minutes)=', '0.2216', 'loss=', '0.000401292')
# ('Epoch:', '0930', 'training time (minutes)=', '0.2274', 'loss=', '0.000405831')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000785850')
# ('Epoch:', '0931', 'training time (minutes)=', '0.2247', 'loss=', '0.000398362')
# ('Epoch:', '0932', 'training time (minutes)=', '0.2260', 'loss=', '0.000402049')
# ('Epoch:', '0933', 'training time (minutes)=', '0.2243', 'loss=', '0.000403055')
# ('Epoch:', '0934', 'training time (minutes)=', '0.2292', 'loss=', '0.000418516')
# ('Epoch:', '0935', 'training time (minutes)=', '0.2239', 'loss=', '0.000398487')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000797823')
# ('Epoch:', '0936', 'training time (minutes)=', '0.2257', 'loss=', '0.000398213')
# ('Epoch:', '0937', 'training time (minutes)=', '0.2302', 'loss=', '0.000403444')
# ('Epoch:', '0938', 'training time (minutes)=', '0.2290', 'loss=', '0.000414572')
# ('Epoch:', '0939', 'training time (minutes)=', '0.2294', 'loss=', '0.000399514')
# ('Epoch:', '0940', 'training time (minutes)=', '0.2226', 'loss=', '0.000395467')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-940 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000796955')
# ('Epoch:', '0941', 'training time (minutes)=', '0.2213', 'loss=', '0.000396070')
# ('Epoch:', '0942', 'training time (minutes)=', '0.2254', 'loss=', '0.000418643')
# ('Epoch:', '0943', 'training time (minutes)=', '0.2287', 'loss=', '0.000406518')
# ('Epoch:', '0944', 'training time (minutes)=', '0.2278', 'loss=', '0.000397086')
# ('Epoch:', '0945', 'training time (minutes)=', '0.2288', 'loss=', '0.000395203')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000793652')
# ('Epoch:', '0946', 'training time (minutes)=', '0.2283', 'loss=', '0.000397934')
# ('Epoch:', '0947', 'training time (minutes)=', '0.2331', 'loss=', '0.000397734')
# ('Epoch:', '0948', 'training time (minutes)=', '0.2306', 'loss=', '0.000446013')
# ('Epoch:', '0949', 'training time (minutes)=', '0.2284', 'loss=', '0.000413848')
# ('Epoch:', '0950', 'training time (minutes)=', '0.2300', 'loss=', '0.000404028')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000798492')
# ('Epoch:', '0951', 'training time (minutes)=', '0.2274', 'loss=', '0.000404821')
# ('Epoch:', '0952', 'training time (minutes)=', '0.2209', 'loss=', '0.000396911')
# ('Epoch:', '0953', 'training time (minutes)=', '0.2277', 'loss=', '0.000401246')
# ('Epoch:', '0954', 'training time (minutes)=', '0.2249', 'loss=', '0.000395356')
# ('Epoch:', '0955', 'training time (minutes)=', '0.2265', 'loss=', '0.000402215')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.000813235')
# ('Epoch:', '0956', 'training time (minutes)=', '0.2286', 'loss=', '0.000404317')
# ('Epoch:', '0957', 'training time (minutes)=', '0.2285', 'loss=', '0.000400191')
# ('Epoch:', '0958', 'training time (minutes)=', '0.2229', 'loss=', '0.000394945')
# ('Epoch:', '0959', 'training time (minutes)=', '0.2268', 'loss=', '0.000403077')
# ('Epoch:', '0960', 'training time (minutes)=', '0.2227', 'loss=', '0.000395151')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-960 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0070', 'loss=', '0.000797477')
# ('Epoch:', '0961', 'training time (minutes)=', '0.2238', 'loss=', '0.000394391')
# ('Epoch:', '0962', 'training time (minutes)=', '0.2253', 'loss=', '0.000394101')
# ('Epoch:', '0963', 'training time (minutes)=', '0.2238', 'loss=', '0.000395152')
# ('Epoch:', '0964', 'training time (minutes)=', '0.2236', 'loss=', '0.000398169')
# ('Epoch:', '0965', 'training time (minutes)=', '0.2335', 'loss=', '0.000396150')
# ('Held Out Data :', 'forward time (minutes)=', '0.0070', 'loss=', '0.000789230')
# ('Epoch:', '0966', 'training time (minutes)=', '0.2240', 'loss=', '0.000395749')
# ('Epoch:', '0967', 'training time (minutes)=', '0.2276', 'loss=', '0.000394947')
# ('Epoch:', '0968', 'training time (minutes)=', '0.2328', 'loss=', '0.000413128')
# ('Epoch:', '0969', 'training time (minutes)=', '0.2308', 'loss=', '0.000406220')
# ('Epoch:', '0970', 'training time (minutes)=', '0.2299', 'loss=', '0.000402255')
# ('Held Out Data :', 'forward time (minutes)=', '0.0069', 'loss=', '0.000796430')
# ('Epoch:', '0971', 'training time (minutes)=', '0.2261', 'loss=', '0.000396135')
# ('Epoch:', '0972', 'training time (minutes)=', '0.2270', 'loss=', '0.000433194')
# ('Epoch:', '0973', 'training time (minutes)=', '0.2246', 'loss=', '0.000400504')
# ('Epoch:', '0974', 'training time (minutes)=', '0.2321', 'loss=', '0.000392708')
# ('Epoch:', '0975', 'training time (minutes)=', '0.2257', 'loss=', '0.000392239')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000807065')
# ('Epoch:', '0976', 'training time (minutes)=', '0.2236', 'loss=', '0.000395880')
# ('Epoch:', '0977', 'training time (minutes)=', '0.2231', 'loss=', '0.000399935')
# ('Epoch:', '0978', 'training time (minutes)=', '0.2274', 'loss=', '0.000389958')
# ('Epoch:', '0979', 'training time (minutes)=', '0.2234', 'loss=', '0.000471368')
# ('Epoch:', '0980', 'training time (minutes)=', '0.2290', 'loss=', '0.000435390')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-980 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.000798420')
# ('Epoch:', '0981', 'training time (minutes)=', '0.2235', 'loss=', '0.000409495')
# ('Epoch:', '0982', 'training time (minutes)=', '0.2262', 'loss=', '0.000399076')
# ('Epoch:', '0983', 'training time (minutes)=', '0.2213', 'loss=', '0.000400167')
# ('Epoch:', '0984', 'training time (minutes)=', '0.2220', 'loss=', '0.000395600')
# ('Epoch:', '0985', 'training time (minutes)=', '0.2255', 'loss=', '0.000394035')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000785911')
# ('Epoch:', '0986', 'training time (minutes)=', '0.2330', 'loss=', '0.000393668')
# ('Epoch:', '0987', 'training time (minutes)=', '0.2253', 'loss=', '0.000390793')
# ('Epoch:', '0988', 'training time (minutes)=', '0.2230', 'loss=', '0.000395945')
# ('Epoch:', '0989', 'training time (minutes)=', '0.2261', 'loss=', '0.000393615')
# ('Epoch:', '0990', 'training time (minutes)=', '0.2229', 'loss=', '0.000401515')
# ('Held Out Data :', 'forward time (minutes)=', '0.0070', 'loss=', '0.000788639')
# ('Epoch:', '0991', 'training time (minutes)=', '0.2261', 'loss=', '0.000395285')
# ('Epoch:', '0992', 'training time (minutes)=', '0.2316', 'loss=', '0.000393878')
# ('Epoch:', '0993', 'training time (minutes)=', '0.2268', 'loss=', '0.000394127')
# ('Epoch:', '0994', 'training time (minutes)=', '0.2292', 'loss=', '0.000394344')
# ('Epoch:', '0995', 'training time (minutes)=', '0.2250', 'loss=', '0.000389350')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000793201')
# ('Epoch:', '0996', 'training time (minutes)=', '0.2244', 'loss=', '0.000392843')
# ('Epoch:', '0997', 'training time (minutes)=', '0.2319', 'loss=', '0.000390060')
# ('Epoch:', '0998', 'training time (minutes)=', '0.2249', 'loss=', '0.000384762')
# ('Epoch:', '0999', 'training time (minutes)=', '0.2250', 'loss=', '0.000393744')
# ('Epoch:', '1000', 'training time (minutes)=', '0.2254', 'loss=', '0.000391478')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/testing_ae_settings/chair_conv_arch_0_dropout_w_bnorm_2048_pts_bneck_512_chamfer/models.ckpt-1000 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000793744')
