# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 0
setup_one_gpu(GPU)
# Out:
# Picking GPU 0

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from functools import partial

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter
from tf_lab.point_clouds.ae_templates import conv_architecture_ala_nips_17, default_train_params_ala_nips_17

from tf_lab.point_clouds.encoders_decoders import decoder_with_fc_only,\
encoder_with_convs_and_symmetry_new, decoder_with_convs_only

from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder

from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tflearn.layers.conv import avg_pool_1d
from pc_completions.evaluation import basic_comletion_measures

from tflearn.layers.conv import conv_1d, highway_conv_1d, avg_pool_1d, max_pool_1d
from tf_lab.fundamentals.layers import conv_1d_tranpose

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
exp_id = -1
n_pc_points = 2048
random_seed = 42
top_data_dir = '/orions4-zfs/projects/optas/DATA'
train_dir = osp.join(top_data_dir, 'OUT/iclr/nn_models/testing_ae_settings/ae_variants_2', str(exp_id))

# %%
def load_multiple_version_of_pcs():
#     versions = ['centered', 'centered_2nd_version', 'centered_3rd_version']
#     versions = ['fps_sampled_in_u_sphere']    
    versions = ['fps_sampled_in_u_sphere_fiedler_sorted']
    
    splits = {'train':None, 'val':None, 'test': None}
        
    for s in splits.keys():
        print 'Loading %s data.' % (s,)
        s_file = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/', s + '.txt')
        print s_file
        for i, v in enumerate(versions):
            top_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', v, str(n_pc_points))                
            splitter = Data_Splitter(top_pclouds_path, data_file_ending='.ply', random_seed=random_seed)
            pcs_in_split = splitter.load_splits(s_file)                
            pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(pcs_in_split, n_threads=20, loader=snc_loader, verbose=True)        
            if splits[s] is None:
                splits[s] = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)
            else:
                splits[s].merge(PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids))
    return splits

# %%
in_data  = load_multiple_version_of_pcs()
# Out:
# Loading test data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/test.txt
# 679 pclouds were loaded. They belong in 1 shape-classes.
# Loading train data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/train.txt
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# Loading val data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/val.txt
# 338 pclouds were loaded. They belong in 1 shape-classes.

# %%
do_training = True
load_pretrained_model = False
load_epoch = None
loss = 'chamfer'
training_epochs = 500
batch_size = 50
learning_rate = 0.0005

# %%
def enc_dec_templates():
    b_norm = True        
    encoder = encoder_with_convs_and_symmetry_new
    decoder = decoder_with_fc_only
    conv_op = conv_1d

    encoder_args = {'n_filters': [32, 64, 128, 256, 2048],
            'filter_sizes': [1, 1, 1, 1, 1],
            'strides': [1, 1, 1, 1, 1],
            'b_norm': b_norm,
            'pool': None,
            'pool_sizes': [2, None, 2, None, None],
            'verbose': True,
            'conv_op': conv_op
            }

    decoder_args= {'layer_sizes': [32, 256, 2048*3],
                   'verbose': True,
                   'b_norm': b_norm,
                   'non_linearity': tf.nn.relu
                  }
    return encoder, decoder, encoder_args, decoder_args

# %%
reset_tf_graph()
encoder, decoder, encoder_args, decoder_args = enc_dec_templates()
print encoder_args

# layer = tf.placeholder(tf.float32, [None, n_pc_points, 3])
# layer = encoder(layer, **encoder_args)
# layer = decoder(layer, **decoder_args)
# Out:
# {'filter_sizes': [1, 1, 1, 1, 1], 'n_filters': [32, 64, 128, 256, 2048], 'verbose': True, 'strides': [1, 1, 1, 1, 1], 'conv_op': <function conv_1d at 0x7f111cdc8320>, 'pool_sizes': [2, None, 2, None, None], 'b_norm': True, 'pool': None}

# %%
if load_pretrained_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    if conf.train_dir != train_dir:
        conf.train_dir = train_dir
#     conf.save(osp.join(train_dir, 'configuration'))
else:    
    conf = Conf(
                n_input = [n_pc_points, 3],
                loss = loss,
                training_epochs = training_epochs,
                batch_size = batch_size,
                denoising = False,
                learning_rate = learning_rate,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = None,
                z_rotate = False,
                encoder = encoder,
                decoder = decoder,
                encoder_args = encoder_args,
                decoder_args = decoder_args
               )

conf.experiment_name = 'experiment_' + str(exp_id)
conf.held_out_step = 5
reset_tf_graph()
ae = PointNetAutoEncoder(conf.experiment_name, conf)
print ae.trainable_parameters()
# Out:
# Building Encoder
# encoder_conv_layer_0 conv params =  128 bnorm params =  64
# Tensor("experiment_-1_1/Relu:0", shape=(?, 2048, 32), dtype=float32)
# output size: 65536
#
# encoder_conv_layer_1 conv params =  2112 bnorm params =  128
# Tensor("experiment_-1_1/Relu_1:0", shape=(?, 2048, 64), dtype=float32)
# output size: 131072
#
# encoder_conv_layer_2 conv params =  8320 bnorm params =  256
# Tensor("experiment_-1_1/Relu_2:0", shape=(?, 2048, 128), dtype=float32)
# output size: 262144
#
# encoder_conv_layer_3 conv params =  33024 bnorm params =  512
# Tensor("experiment_-1_1/Relu_3:0", shape=(?, 2048, 256), dtype=float32)
# output size: 524288
#
# encoder_conv_layer_4 conv params =  526336 bnorm params =  4096
# Tensor("experiment_-1_1/Relu_4:0", shape=(?, 2048, 2048), dtype=float32)
# output size: 4194304
#
# Tensor("experiment_-1_1/Max:0", shape=(?, 2048), dtype=float32)
# Building Decoder
# decoder_fc_0 FC params =  65568 bnorm params =  64
# Tensor("experiment_-1_1/Relu_5:0", shape=(?, 32), dtype=float32)
# output size: 32
#
# decoder_fc_1 FC params =  8448 bnorm params =  512
# Tensor("experiment_-1_1/Relu_6:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# decoder_fc_2 FC params =  1579008 Tensor("experiment_-1_1/decoder_fc_2/BiasAdd:0", shape=(?, 6144), dtype=float32)
# output size: 6144
#
# 2228576

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)     
    train_stats = ae.train(in_data['train'], conf, log_file=fout, held_out_data=in_data['test'])
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.3740', 'loss=', '0.004299455')
# ('Epoch:', '0002', 'training time (minutes)=', '0.3739', 'loss=', '0.002422854')
# ('Epoch:', '0003', 'training time (minutes)=', '0.4818', 'loss=', '0.002154136')
# ('Epoch:', '0004', 'training time (minutes)=', '0.3768', 'loss=', '0.001953543')
# ('Epoch:', '0005', 'training time (minutes)=', '0.3785', 'loss=', '0.001845632')
# ('Held Out Data :', 'forward time (minutes)=', '0.0100', 'loss=', '0.002162699')
# ('Epoch:', '0006', 'training time (minutes)=', '0.4939', 'loss=', '0.001757123')
# ('Epoch:', '0007', 'training time (minutes)=', '0.3824', 'loss=', '0.001736674')
# ('Epoch:', '0008', 'training time (minutes)=', '0.3811', 'loss=', '0.001657891')
# ('Epoch:', '0009', 'training time (minutes)=', '0.3839', 'loss=', '0.001657603')
# ('Epoch:', '0010', 'training time (minutes)=', '0.4960', 'loss=', '0.001555912')
# ('Held Out Data :', 'forward time (minutes)=', '0.0098', 'loss=', '0.001851783')
# ('Epoch:', '0011', 'training time (minutes)=', '0.3796', 'loss=', '0.001540134')
# ('Epoch:', '0012', 'training time (minutes)=', '0.3811', 'loss=', '0.001491682')
# ('Epoch:', '0013', 'training time (minutes)=', '0.4200', 'loss=', '0.001422253')
# ('Epoch:', '0014', 'training time (minutes)=', '0.4610', 'loss=', '0.001434077')
# ('Epoch:', '0015', 'training time (minutes)=', '0.3796', 'loss=', '0.001383177')
# ('Held Out Data :', 'forward time (minutes)=', '0.0097', 'loss=', '0.001418559')
# ('Epoch:', '0016', 'training time (minutes)=', '0.3813', 'loss=', '0.001355383')
# ('Epoch:', '0017', 'training time (minutes)=', '0.4995', 'loss=', '0.001347238')
# ('Epoch:', '0018', 'training time (minutes)=', '0.3832', 'loss=', '0.001346105')
# ('Epoch:', '0019', 'training time (minutes)=', '0.3807', 'loss=', '0.001296626')
# ('Epoch:', '0020', 'training time (minutes)=', '0.3857', 'loss=', '0.001259214')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.001363033')
# ('Epoch:', '0021', 'training time (minutes)=', '0.4941', 'loss=', '0.001226741')
# ('Epoch:', '0022', 'training time (minutes)=', '0.3816', 'loss=', '0.001244988')
# ('Epoch:', '0023', 'training time (minutes)=', '0.3812', 'loss=', '0.001204251')
# ('Epoch:', '0024', 'training time (minutes)=', '0.4979', 'loss=', '0.001213936')
# ('Epoch:', '0025', 'training time (minutes)=', '0.3836', 'loss=', '0.001179291')
# ('Held Out Data :', 'forward time (minutes)=', '0.0093', 'loss=', '0.001320814')
# ('Epoch:', '0026', 'training time (minutes)=', '0.3809', 'loss=', '0.001198935')
# ('Epoch:', '0027', 'training time (minutes)=', '0.3853', 'loss=', '0.001192427')
# ('Epoch:', '0028', 'training time (minutes)=', '0.4977', 'loss=', '0.001140597')
# ('Epoch:', '0029', 'training time (minutes)=', '0.3793', 'loss=', '0.001143770')
# ('Epoch:', '0030', 'training time (minutes)=', '0.3808', 'loss=', '0.001129365')
# ('Held Out Data :', 'forward time (minutes)=', '0.0092', 'loss=', '0.001395059')
# ('Epoch:', '0031', 'training time (minutes)=', '0.4349', 'loss=', '0.001087835')
# ('Epoch:', '0032', 'training time (minutes)=', '0.4421', 'loss=', '0.001084021')
# ('Epoch:', '0033', 'training time (minutes)=', '0.3806', 'loss=', '0.001094116')
# ('Epoch:', '0034', 'training time (minutes)=', '0.3805', 'loss=', '0.001067662')
# ('Epoch:', '0035', 'training time (minutes)=', '0.4940', 'loss=', '0.001058241')
# ('Held Out Data :', 'forward time (minutes)=', '0.0096', 'loss=', '0.001074515')
# ('Epoch:', '0036', 'training time (minutes)=', '0.3838', 'loss=', '0.001040074')
# ('Epoch:', '0037', 'training time (minutes)=', '0.3788', 'loss=', '0.001042076')
# ('Epoch:', '0038', 'training time (minutes)=', '0.3828', 'loss=', '0.001028995')
# ('Epoch:', '0039', 'training time (minutes)=', '0.4951', 'loss=', '0.001029363')
# ('Epoch:', '0040', 'training time (minutes)=', '0.3784', 'loss=', '0.001032524')
# ('Held Out Data :', 'forward time (minutes)=', '0.0092', 'loss=', '0.001206761')
# ('Epoch:', '0041', 'training time (minutes)=', '0.3793', 'loss=', '0.001009123')
# ('Epoch:', '0042', 'training time (minutes)=', '0.4472', 'loss=', '0.000987286')
# ('Epoch:', '0043', 'training time (minutes)=', '0.4283', 'loss=', '0.000983829')
# ('Epoch:', '0044', 'training time (minutes)=', '0.3782', 'loss=', '0.000983000')
# ('Epoch:', '0045', 'training time (minutes)=', '0.3800', 'loss=', '0.000969524')
# ('Held Out Data :', 'forward time (minutes)=', '0.0092', 'loss=', '0.001108353')
# ('Epoch:', '0046', 'training time (minutes)=', '0.4930', 'loss=', '0.000971727')
# ('Epoch:', '0047', 'training time (minutes)=', '0.3811', 'loss=', '0.000990400')
# ('Epoch:', '0048', 'training time (minutes)=', '0.3784', 'loss=', '0.000971965')
# ('Epoch:', '0049', 'training time (minutes)=', '0.3833', 'loss=', '0.000995717')
# ('Epoch:', '0050', 'training time (minutes)=', '0.4930', 'loss=', '0.000974901')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.001493504')
# ('Epoch:', '0051', 'training time (minutes)=', '0.3782', 'loss=', '0.000944865')
# ('Epoch:', '0052', 'training time (minutes)=', '0.3785', 'loss=', '0.000930804')
# ('Epoch:', '0053', 'training time (minutes)=', '0.4433', 'loss=', '0.000942150')
# ('Epoch:', '0054', 'training time (minutes)=', '0.4300', 'loss=', '0.000931275')
# ('Epoch:', '0055', 'training time (minutes)=', '0.3789', 'loss=', '0.000905104')
# ('Held Out Data :', 'forward time (minutes)=', '0.0098', 'loss=', '0.001050359')
# ('Epoch:', '0056', 'training time (minutes)=', '0.3811', 'loss=', '0.000926319')
# ('Epoch:', '0057', 'training time (minutes)=', '0.4957', 'loss=', '0.000905152')
# ('Epoch:', '0058', 'training time (minutes)=', '0.3794', 'loss=', '0.000896006')
# ('Epoch:', '0059', 'training time (minutes)=', '0.3793', 'loss=', '0.000895526')
# ('Epoch:', '0060', 'training time (minutes)=', '0.3846', 'loss=', '0.000899470')
# ('Held Out Data :', 'forward time (minutes)=', '0.0183', 'loss=', '0.000940744')
# ('Epoch:', '0061', 'training time (minutes)=', '0.4813', 'loss=', '0.000890330')
# ('Epoch:', '0062', 'training time (minutes)=', '0.3796', 'loss=', '0.000872726')
# ('Epoch:', '0063', 'training time (minutes)=', '0.3792', 'loss=', '0.000897044')
# ('Epoch:', '0064', 'training time (minutes)=', '0.4969', 'loss=', '0.000855796')
# ('Epoch:', '0065', 'training time (minutes)=', '0.3794', 'loss=', '0.000883734')
# ('Held Out Data :', 'forward time (minutes)=', '0.0093', 'loss=', '0.001019388')
# ('Epoch:', '0066', 'training time (minutes)=', '0.3786', 'loss=', '0.000869686')
# ('Epoch:', '0067', 'training time (minutes)=', '0.3807', 'loss=', '0.000866934')
# ('Epoch:', '0068', 'training time (minutes)=', '0.4933', 'loss=', '0.000858398')
# ('Epoch:', '0069', 'training time (minutes)=', '0.3782', 'loss=', '0.000843944')
# ('Epoch:', '0070', 'training time (minutes)=', '0.3779', 'loss=', '0.000833831')
# ('Held Out Data :', 'forward time (minutes)=', '0.0093', 'loss=', '0.001012706')
# ('Epoch:', '0071', 'training time (minutes)=', '0.3998', 'loss=', '0.000865961')
# ('Epoch:', '0072', 'training time (minutes)=', '0.4722', 'loss=', '0.000830943')
# ('Epoch:', '0073', 'training time (minutes)=', '0.3785', 'loss=', '0.000834773')
# ('Epoch:', '0074', 'training time (minutes)=', '0.3781', 'loss=', '0.000828047')
# ('Epoch:', '0075', 'training time (minutes)=', '0.4975', 'loss=', '0.000809180')
# ('Held Out Data :', 'forward time (minutes)=', '0.0092', 'loss=', '0.000928057')
# ('Epoch:', '0076', 'training time (minutes)=', '0.3789', 'loss=', '0.000817913')
# ('Epoch:', '0077', 'training time (minutes)=', '0.3775', 'loss=', '0.000813893')
# ('Epoch:', '0078', 'training time (minutes)=', '0.3822', 'loss=', '0.000839518')
# ('Epoch:', '0079', 'training time (minutes)=', '0.4935', 'loss=', '0.000808286')
# ('Epoch:', '0080', 'training time (minutes)=', '0.3773', 'loss=', '0.000815970')
# ('Held Out Data :', 'forward time (minutes)=', '0.0097', 'loss=', '0.000878341')
# ('Epoch:', '0081', 'training time (minutes)=', '0.3782', 'loss=', '0.000799594')
# ('Epoch:', '0082', 'training time (minutes)=', '0.3904', 'loss=', '0.000810661')
# ('Epoch:', '0083', 'training time (minutes)=', '0.4806', 'loss=', '0.000814060')
# ('Epoch:', '0084', 'training time (minutes)=', '0.3781', 'loss=', '0.000804009')
# ('Epoch:', '0085', 'training time (minutes)=', '0.3790', 'loss=', '0.000789880')
# ('Held Out Data :', 'forward time (minutes)=', '0.0101', 'loss=', '0.000960071')
# ('Epoch:', '0086', 'training time (minutes)=', '0.4956', 'loss=', '0.000791479')
# ('Epoch:', '0087', 'training time (minutes)=', '0.3768', 'loss=', '0.000775718')
# ('Epoch:', '0088', 'training time (minutes)=', '0.3773', 'loss=', '0.000781076')
# ('Epoch:', '0089', 'training time (minutes)=', '0.3821', 'loss=', '0.000790605')
# ('Epoch:', '0090', 'training time (minutes)=', '0.4917', 'loss=', '0.000776225')
# ('Held Out Data :', 'forward time (minutes)=', '0.0093', 'loss=', '0.001137110')
# ('Epoch:', '0091', 'training time (minutes)=', '0.3789', 'loss=', '0.000761446')
# ('Epoch:', '0092', 'training time (minutes)=', '0.3771', 'loss=', '0.000771388')
# ('Epoch:', '0093', 'training time (minutes)=', '0.4183', 'loss=', '0.000774663')
# ('Epoch:', '0094', 'training time (minutes)=', '0.4526', 'loss=', '0.000754423')
# ('Epoch:', '0095', 'training time (minutes)=', '0.3772', 'loss=', '0.000767032')
# ('Held Out Data :', 'forward time (minutes)=', '0.0096', 'loss=', '0.000787490')
# ('Epoch:', '0096', 'training time (minutes)=', '0.3784', 'loss=', '0.000764209')
# ('Epoch:', '0097', 'training time (minutes)=', '0.4945', 'loss=', '0.000769786')
# ('Epoch:', '0098', 'training time (minutes)=', '0.3774', 'loss=', '0.000745361')
# ('Epoch:', '0099', 'training time (minutes)=', '0.3781', 'loss=', '0.000767908')
# ('Epoch:', '0100', 'training time (minutes)=', '0.3815', 'loss=', '0.000752101')
# ('Held Out Data :', 'forward time (minutes)=', '0.0097', 'loss=', '0.001009714')
# ('Epoch:', '0101', 'training time (minutes)=', '0.4919', 'loss=', '0.000751654')
# ('Epoch:', '0102', 'training time (minutes)=', '0.3772', 'loss=', '0.000737558')
# ('Epoch:', '0103', 'training time (minutes)=', '0.3768', 'loss=', '0.000741325')
# ('Epoch:', '0104', 'training time (minutes)=', '0.4248', 'loss=', '0.000746228')
# ('Epoch:', '0105', 'training time (minutes)=', '0.4461', 'loss=', '0.000740215')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.001219910')
# ('Epoch:', '0106', 'training time (minutes)=', '0.3763', 'loss=', '0.000721384')
# ('Epoch:', '0107', 'training time (minutes)=', '0.3783', 'loss=', '0.000739963')
# ('Epoch:', '0108', 'training time (minutes)=', '0.4958', 'loss=', '0.000747778')
# ('Epoch:', '0109', 'training time (minutes)=', '0.3771', 'loss=', '0.000721931')
# ('Epoch:', '0110', 'training time (minutes)=', '0.3762', 'loss=', '0.000724209')
# ('Held Out Data :', 'forward time (minutes)=', '0.0093', 'loss=', '0.000966405')
# ('Epoch:', '0111', 'training time (minutes)=', '0.3816', 'loss=', '0.000727464')
# ('Epoch:', '0112', 'training time (minutes)=', '0.4922', 'loss=', '0.000732650')
# ('Epoch:', '0113', 'training time (minutes)=', '0.3753', 'loss=', '0.000714621')
# ('Epoch:', '0114', 'training time (minutes)=', '0.3762', 'loss=', '0.000731881')
# ('Epoch:', '0115', 'training time (minutes)=', '0.4352', 'loss=', '0.000724325')
# ('Held Out Data :', 'forward time (minutes)=', '0.0183', 'loss=', '0.001080619')
# ('Epoch:', '0116', 'training time (minutes)=', '0.4241', 'loss=', '0.000711734')
# ('Epoch:', '0117', 'training time (minutes)=', '0.3758', 'loss=', '0.000716692')
# ('Epoch:', '0118', 'training time (minutes)=', '0.3779', 'loss=', '0.000706937')
# ('Epoch:', '0119', 'training time (minutes)=', '0.4935', 'loss=', '0.000708156')
# ('Epoch:', '0120', 'training time (minutes)=', '0.3885', 'loss=', '0.000729048')
# ('Held Out Data :', 'forward time (minutes)=', '0.0102', 'loss=', '0.000827897')
# ('Epoch:', '0121', 'training time (minutes)=', '0.3898', 'loss=', '0.000694283')
# ('Epoch:', '0122', 'training time (minutes)=', '0.3934', 'loss=', '0.000700543')
# ('Epoch:', '0123', 'training time (minutes)=', '0.5084', 'loss=', '0.000691186')
# ('Epoch:', '0124', 'training time (minutes)=', '0.3883', 'loss=', '0.000693681')
# ('Epoch:', '0125', 'training time (minutes)=', '0.3883', 'loss=', '0.000682337')
# ('Held Out Data :', 'forward time (minutes)=', '0.0100', 'loss=', '0.000848804')
# ('Epoch:', '0126', 'training time (minutes)=', '0.5102', 'loss=', '0.000703185')
# ('Epoch:', '0127', 'training time (minutes)=', '0.3870', 'loss=', '0.000696930')
# ('Epoch:', '0128', 'training time (minutes)=', '0.3868', 'loss=', '0.000686895')
# ('Epoch:', '0129', 'training time (minutes)=', '0.3915', 'loss=', '0.000709484')
# ('Epoch:', '0130', 'training time (minutes)=', '0.5072', 'loss=', '0.000678071')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000777978')
# ('Epoch:', '0131', 'training time (minutes)=', '0.3865', 'loss=', '0.000683034')
# ('Epoch:', '0132', 'training time (minutes)=', '0.3860', 'loss=', '0.000686029')
# ('Epoch:', '0133', 'training time (minutes)=', '0.4870', 'loss=', '0.000686845')
# ('Epoch:', '0134', 'training time (minutes)=', '0.4079', 'loss=', '0.000698752')
# ('Epoch:', '0135', 'training time (minutes)=', '0.3870', 'loss=', '0.000673972')
# ('Held Out Data :', 'forward time (minutes)=', '0.0096', 'loss=', '0.001512109')
# ('Epoch:', '0136', 'training time (minutes)=', '0.3911', 'loss=', '0.000675409')
# ('Epoch:', '0137', 'training time (minutes)=', '0.5083', 'loss=', '0.000692856')
# ('Epoch:', '0138', 'training time (minutes)=', '0.3858', 'loss=', '0.000675384')
# ('Epoch:', '0139', 'training time (minutes)=', '0.3876', 'loss=', '0.000671888')
# ('Epoch:', '0140', 'training time (minutes)=', '0.4659', 'loss=', '0.000664764')
# ('Held Out Data :', 'forward time (minutes)=', '0.0179', 'loss=', '0.000855923')
# ('Epoch:', '0141', 'training time (minutes)=', '0.4228', 'loss=', '0.000687676')
# ('Epoch:', '0142', 'training time (minutes)=', '0.3882', 'loss=', '0.000671652')
# ('Epoch:', '0143', 'training time (minutes)=', '0.3896', 'loss=', '0.000679330')
# ('Epoch:', '0144', 'training time (minutes)=', '0.5089', 'loss=', '0.000667054')
# ('Epoch:', '0145', 'training time (minutes)=', '0.3881', 'loss=', '0.000660616')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000940799')
# ('Epoch:', '0146', 'training time (minutes)=', '0.3873', 'loss=', '0.000664409')
# ('Epoch:', '0147', 'training time (minutes)=', '0.4543', 'loss=', '0.000666446')
# ('Epoch:', '0148', 'training time (minutes)=', '0.4422', 'loss=', '0.000658191')
# ('Epoch:', '0149', 'training time (minutes)=', '0.3868', 'loss=', '0.000664440')
# ('Epoch:', '0150', 'training time (minutes)=', '0.3899', 'loss=', '0.000652521')
# ('Held Out Data :', 'forward time (minutes)=', '0.0100', 'loss=', '0.000770656')
# ('Epoch:', '0151', 'training time (minutes)=', '0.5102', 'loss=', '0.000671916')
# ('Epoch:', '0152', 'training time (minutes)=', '0.3874', 'loss=', '0.000704269')
# ('Epoch:', '0153', 'training time (minutes)=', '0.3875', 'loss=', '0.000704359')
# ('Epoch:', '0154', 'training time (minutes)=', '0.4210', 'loss=', '0.000676734')
# ('Epoch:', '0155', 'training time (minutes)=', '0.4767', 'loss=', '0.000658591')
# ('Held Out Data :', 'forward time (minutes)=', '0.0101', 'loss=', '0.000806945')
# ('Epoch:', '0156', 'training time (minutes)=', '0.3868', 'loss=', '0.000653238')
# ('Epoch:', '0157', 'training time (minutes)=', '0.3896', 'loss=', '0.000654796')
# ('Epoch:', '0158', 'training time (minutes)=', '0.5104', 'loss=', '0.000654571')
# ('Epoch:', '0159', 'training time (minutes)=', '0.3888', 'loss=', '0.000642229')
# ('Epoch:', '0160', 'training time (minutes)=', '0.3867', 'loss=', '0.000647620')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000883285')
# ('Epoch:', '0161', 'training time (minutes)=', '0.4296', 'loss=', '0.000648464')
# ('Epoch:', '0162', 'training time (minutes)=', '0.4676', 'loss=', '0.000637284')
# ('Epoch:', '0163', 'training time (minutes)=', '0.3870', 'loss=', '0.000635326')
# ('Epoch:', '0164', 'training time (minutes)=', '0.3894', 'loss=', '0.000643227')
# ('Epoch:', '0165', 'training time (minutes)=', '0.5095', 'loss=', '0.000650866')
# ('Held Out Data :', 'forward time (minutes)=', '0.0099', 'loss=', '0.000839534')
# ('Epoch:', '0166', 'training time (minutes)=', '0.3867', 'loss=', '0.000631981')
# ('Epoch:', '0167', 'training time (minutes)=', '0.3865', 'loss=', '0.000638946')
# ('Epoch:', '0168', 'training time (minutes)=', '0.4031', 'loss=', '0.000662552')
# ('Epoch:', '0169', 'training time (minutes)=', '0.4935', 'loss=', '0.000637917')
# ('Epoch:', '0170', 'training time (minutes)=', '0.3876', 'loss=', '0.000634297')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000765976')
# ('Epoch:', '0171', 'training time (minutes)=', '0.3893', 'loss=', '0.000632386')
# ('Epoch:', '0172', 'training time (minutes)=', '0.5090', 'loss=', '0.000639876')
# ('Epoch:', '0173', 'training time (minutes)=', '0.3870', 'loss=', '0.000641199')
# ('Epoch:', '0174', 'training time (minutes)=', '0.3868', 'loss=', '0.000623545')
# ('Epoch:', '0175', 'training time (minutes)=', '0.4002', 'loss=', '0.000624736')
# ('Held Out Data :', 'forward time (minutes)=', '0.0177', 'loss=', '0.000785745')
# ('Epoch:', '0176', 'training time (minutes)=', '0.4893', 'loss=', '0.000622195')
# ('Epoch:', '0177', 'training time (minutes)=', '0.3879', 'loss=', '0.000628682')
# ('Epoch:', '0178', 'training time (minutes)=', '0.3881', 'loss=', '0.000619542')
# ('Epoch:', '0179', 'training time (minutes)=', '0.5087', 'loss=', '0.000636177')
# ('Epoch:', '0180', 'training time (minutes)=', '0.3874', 'loss=', '0.000634768')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000886343')
# ('Epoch:', '0181', 'training time (minutes)=', '0.3870', 'loss=', '0.000626274')
# ('Epoch:', '0182', 'training time (minutes)=', '0.3925', 'loss=', '0.000616283')
# ('Epoch:', '0183', 'training time (minutes)=', '0.5046', 'loss=', '0.000621030')
# ('Epoch:', '0184', 'training time (minutes)=', '0.3876', 'loss=', '0.000639572')
# ('Epoch:', '0185', 'training time (minutes)=', '0.3881', 'loss=', '0.000698108')
# ('Held Out Data :', 'forward time (minutes)=', '0.0099', 'loss=', '0.000805492')
# ('Epoch:', '0186', 'training time (minutes)=', '0.5098', 'loss=', '0.000627756')
# ('Epoch:', '0187', 'training time (minutes)=', '0.3863', 'loss=', '0.000620341')
# ('Epoch:', '0188', 'training time (minutes)=', '0.3864', 'loss=', '0.000619901')
# ('Epoch:', '0189', 'training time (minutes)=', '0.3924', 'loss=', '0.000617245')
# ('Epoch:', '0190', 'training time (minutes)=', '0.5047', 'loss=', '0.000620240')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000801227')
# ('Epoch:', '0191', 'training time (minutes)=', '0.3864', 'loss=', '0.000622307')
# ('Epoch:', '0192', 'training time (minutes)=', '0.3876', 'loss=', '0.000604485')
# ('Epoch:', '0193', 'training time (minutes)=', '0.5101', 'loss=', '0.000605800')
# ('Epoch:', '0194', 'training time (minutes)=', '0.3867', 'loss=', '0.000613898')
# ('Epoch:', '0195', 'training time (minutes)=', '0.3870', 'loss=', '0.000616281')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000798798')
# ('Epoch:', '0196', 'training time (minutes)=', '0.3925', 'loss=', '0.000600923')
# ('Epoch:', '0197', 'training time (minutes)=', '0.5055', 'loss=', '0.000611878')
# ('Epoch:', '0198', 'training time (minutes)=', '0.3866', 'loss=', '0.000611189')
# ('Epoch:', '0199', 'training time (minutes)=', '0.3862', 'loss=', '0.000609842')
# ('Epoch:', '0200', 'training time (minutes)=', '0.5091', 'loss=', '0.000598353')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000793604')
# ('Epoch:', '0201', 'training time (minutes)=', '0.3867', 'loss=', '0.000611035')
# ('Epoch:', '0202', 'training time (minutes)=', '0.3868', 'loss=', '0.000604625')
# ('Epoch:', '0203', 'training time (minutes)=', '0.3901', 'loss=', '0.000613141')
# ('Epoch:', '0204', 'training time (minutes)=', '0.5058', 'loss=', '0.000605179')
# ('Epoch:', '0205', 'training time (minutes)=', '0.3860', 'loss=', '0.000599929')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000746992')
# ('Epoch:', '0206', 'training time (minutes)=', '0.3863', 'loss=', '0.000624737')
# ('Epoch:', '0207', 'training time (minutes)=', '0.4948', 'loss=', '0.000617707')
# ('Epoch:', '0208', 'training time (minutes)=', '0.3998', 'loss=', '0.000623739')
# ('Epoch:', '0209', 'training time (minutes)=', '0.3859', 'loss=', '0.000622489')
# ('Epoch:', '0210', 'training time (minutes)=', '0.3883', 'loss=', '0.000615901')
# ('Held Out Data :', 'forward time (minutes)=', '0.0100', 'loss=', '0.000991773')
# ('Epoch:', '0211', 'training time (minutes)=', '0.5058', 'loss=', '0.000617625')
# ('Epoch:', '0212', 'training time (minutes)=', '0.3789', 'loss=', '0.000600354')
# ('Epoch:', '0213', 'training time (minutes)=', '0.3789', 'loss=', '0.000596852')
# ('Epoch:', '0214', 'training time (minutes)=', '0.3787', 'loss=', '0.000597475')
# ('Epoch:', '0215', 'training time (minutes)=', '0.3788', 'loss=', '0.000611439')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000760871')
# ('Epoch:', '0216', 'training time (minutes)=', '0.3792', 'loss=', '0.000602513')
# ('Epoch:', '0217', 'training time (minutes)=', '0.3787', 'loss=', '0.000598734')
# ('Epoch:', '0218', 'training time (minutes)=', '0.3788', 'loss=', '0.000604298')
# ('Epoch:', '0219', 'training time (minutes)=', '0.3790', 'loss=', '0.000592334')
# ('Epoch:', '0220', 'training time (minutes)=', '0.3789', 'loss=', '0.000611660')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000776597')
# ('Epoch:', '0221', 'training time (minutes)=', '0.3791', 'loss=', '0.000591260')
# ('Epoch:', '0222', 'training time (minutes)=', '0.3782', 'loss=', '0.000581223')
# ('Epoch:', '0223', 'training time (minutes)=', '0.3793', 'loss=', '0.000586924')
# ('Epoch:', '0224', 'training time (minutes)=', '0.3790', 'loss=', '0.000603644')
# ('Epoch:', '0225', 'training time (minutes)=', '0.3788', 'loss=', '0.000593999')
# ('Held Out Data :', 'forward time (minutes)=', '0.0093', 'loss=', '0.000739805')
# ('Epoch:', '0226', 'training time (minutes)=', '0.3791', 'loss=', '0.000586907')
# ('Epoch:', '0227', 'training time (minutes)=', '0.3789', 'loss=', '0.000590868')
# ('Epoch:', '0228', 'training time (minutes)=', '0.4349', 'loss=', '0.000587555')
# ('Epoch:', '0229', 'training time (minutes)=', '0.4467', 'loss=', '0.000594600')
# ('Epoch:', '0230', 'training time (minutes)=', '0.3855', 'loss=', '0.000595704')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000752706')
# ('Epoch:', '0231', 'training time (minutes)=', '0.3856', 'loss=', '0.000583861')
# ('Epoch:', '0232', 'training time (minutes)=', '0.3854', 'loss=', '0.000586825')
# ('Epoch:', '0233', 'training time (minutes)=', '0.4601', 'loss=', '0.000578488')
# ('Epoch:', '0234', 'training time (minutes)=', '0.4290', 'loss=', '0.000580325')
# ('Epoch:', '0235', 'training time (minutes)=', '0.3859', 'loss=', '0.000578174')
# ('Held Out Data :', 'forward time (minutes)=', '0.0099', 'loss=', '0.000711118')
# ('Epoch:', '0236', 'training time (minutes)=', '0.3885', 'loss=', '0.000594568')
# ('Epoch:', '0237', 'training time (minutes)=', '0.5064', 'loss=', '0.000580561')
# ('Epoch:', '0238', 'training time (minutes)=', '0.3859', 'loss=', '0.000581605')
# ('Epoch:', '0239', 'training time (minutes)=', '0.3846', 'loss=', '0.000670370')
# ('Epoch:', '0240', 'training time (minutes)=', '0.3911', 'loss=', '0.000665637')
# ('Held Out Data :', 'forward time (minutes)=', '0.0112', 'loss=', '0.000786488')
# ('Epoch:', '0241', 'training time (minutes)=', '0.5013', 'loss=', '0.000625338')
# ('Epoch:', '0242', 'training time (minutes)=', '0.3849', 'loss=', '0.000618495')
# ('Epoch:', '0243', 'training time (minutes)=', '0.3859', 'loss=', '0.000594758')
# ('Epoch:', '0244', 'training time (minutes)=', '0.5096', 'loss=', '0.000592923')
# ('Epoch:', '0245', 'training time (minutes)=', '0.3849', 'loss=', '0.000604477')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000831008')
# ('Epoch:', '0246', 'training time (minutes)=', '0.3857', 'loss=', '0.000592931')
# ('Epoch:', '0247', 'training time (minutes)=', '0.3894', 'loss=', '0.000594810')
# ('Epoch:', '0248', 'training time (minutes)=', '0.5063', 'loss=', '0.000584289')
# ('Epoch:', '0249', 'training time (minutes)=', '0.3849', 'loss=', '0.000591592')
# ('Epoch:', '0250', 'training time (minutes)=', '0.3858', 'loss=', '0.000585860')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000728816')
# ('Epoch:', '0251', 'training time (minutes)=', '0.4741', 'loss=', '0.000586457')
# ('Epoch:', '0252', 'training time (minutes)=', '0.4167', 'loss=', '0.000579064')
# ('Epoch:', '0253', 'training time (minutes)=', '0.3851', 'loss=', '0.000604983')
# ('Epoch:', '0254', 'training time (minutes)=', '0.3880', 'loss=', '0.000582845')
# ('Epoch:', '0255', 'training time (minutes)=', '0.5074', 'loss=', '0.000575832')
# ('Held Out Data :', 'forward time (minutes)=', '0.0093', 'loss=', '0.000761284')
# ('Epoch:', '0256', 'training time (minutes)=', '0.3859', 'loss=', '0.000580284')
# ('Epoch:', '0257', 'training time (minutes)=', '0.3849', 'loss=', '0.000582352')
# ('Epoch:', '0258', 'training time (minutes)=', '0.4095', 'loss=', '0.000575657')
# ('Epoch:', '0259', 'training time (minutes)=', '0.4833', 'loss=', '0.000581401')
# ('Epoch:', '0260', 'training time (minutes)=', '0.3853', 'loss=', '0.000589552')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000818129')
# ('Epoch:', '0261', 'training time (minutes)=', '0.3876', 'loss=', '0.000583085')
# ('Epoch:', '0262', 'training time (minutes)=', '0.5075', 'loss=', '0.000573527')
# ('Epoch:', '0263', 'training time (minutes)=', '0.3859', 'loss=', '0.000565322')
# ('Epoch:', '0264', 'training time (minutes)=', '0.3860', 'loss=', '0.000574381')
# ('Epoch:', '0265', 'training time (minutes)=', '0.3904', 'loss=', '0.000571260')
# ('Held Out Data :', 'forward time (minutes)=', '0.0099', 'loss=', '0.000721172')
# ('Epoch:', '0266', 'training time (minutes)=', '0.5049', 'loss=', '0.000564760')
# ('Epoch:', '0267', 'training time (minutes)=', '0.3851', 'loss=', '0.000569264')
# ('Epoch:', '0268', 'training time (minutes)=', '0.3856', 'loss=', '0.000568717')
# ('Epoch:', '0269', 'training time (minutes)=', '0.4588', 'loss=', '0.000563124')
# ('Epoch:', '0270', 'training time (minutes)=', '0.4352', 'loss=', '0.000565006')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000692730')
# ('Epoch:', '0271', 'training time (minutes)=', '0.3858', 'loss=', '0.000564493')
# ('Epoch:', '0272', 'training time (minutes)=', '0.3877', 'loss=', '0.000559889')
# ('Epoch:', '0273', 'training time (minutes)=', '0.5073', 'loss=', '0.000575589')
# ('Epoch:', '0274', 'training time (minutes)=', '0.3854', 'loss=', '0.000564003')
# ('Epoch:', '0275', 'training time (minutes)=', '0.3853', 'loss=', '0.000563631')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000709753')
# ('Epoch:', '0276', 'training time (minutes)=', '0.4084', 'loss=', '0.000572330')
# ('Epoch:', '0277', 'training time (minutes)=', '0.4859', 'loss=', '0.000577617')
# ('Epoch:', '0278', 'training time (minutes)=', '0.3856', 'loss=', '0.000581560')
# ('Epoch:', '0279', 'training time (minutes)=', '0.3873', 'loss=', '0.000572723')
# ('Epoch:', '0280', 'training time (minutes)=', '0.5085', 'loss=', '0.000569846')
# ('Held Out Data :', 'forward time (minutes)=', '0.0099', 'loss=', '0.000691341')
# ('Epoch:', '0281', 'training time (minutes)=', '0.3852', 'loss=', '0.000560290')
# ('Epoch:', '0282', 'training time (minutes)=', '0.3882', 'loss=', '0.000558715')
# ('Epoch:', '0283', 'training time (minutes)=', '0.3901', 'loss=', '0.000572335')
# ('Epoch:', '0284', 'training time (minutes)=', '0.5064', 'loss=', '0.000558268')
# ('Epoch:', '0285', 'training time (minutes)=', '0.3854', 'loss=', '0.000599593')
# ('Held Out Data :', 'forward time (minutes)=', '0.0094', 'loss=', '0.000761655')
# ('Epoch:', '0286', 'training time (minutes)=', '0.3856', 'loss=', '0.000580480')
# ('Epoch:', '0287', 'training time (minutes)=', '0.4760', 'loss=', '0.000559781')
# ('Epoch:', '0288', 'training time (minutes)=', '0.4175', 'loss=', '0.000576385')
# ('Epoch:', '0289', 'training time (minutes)=', '0.3855', 'loss=', '0.000564956')
# ('Epoch:', '0290', 'training time (minutes)=', '0.3871', 'loss=', '0.000567248')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000863608')
# ('Epoch:', '0291', 'training time (minutes)=', '0.5076', 'loss=', '0.000583395')
# ('Epoch:', '0292', 'training time (minutes)=', '0.3860', 'loss=', '0.000554383')
# ('Epoch:', '0293', 'training time (minutes)=', '0.3860', 'loss=', '0.000558516')
# ('Epoch:', '0294', 'training time (minutes)=', '0.4144', 'loss=', '0.000551095')
# ('Epoch:', '0295', 'training time (minutes)=', '0.4465', 'loss=', '0.000567658')
# ('Held Out Data :', 'forward time (minutes)=', '0.0095', 'loss=', '0.000753923')
# ('Epoch:', '0296', 'training time (minutes)=', '0.3723', 'loss=', '0.000565559')
# ('Epoch:', '0297', 'training time (minutes)=', '0.3714', 'loss=', '0.000561720')
# ('Epoch:', '0298', 'training time (minutes)=', '0.4853', 'loss=', '0.000549596')
# ('Epoch:', '0299', 'training time (minutes)=', '0.3721', 'loss=', '0.000552008')
# ('Epoch:', '0300', 'training time (minutes)=', '0.3720', 'loss=', '0.000568725')
# ('Held Out Data :', 'forward time (minutes)=', '0.0092', 'loss=', '0.000805296')
# ('Epoch:', '0301', 'training time (minutes)=', '0.3741', 'loss=', '0.000562962')
# ('Epoch:', '0302', 'training time (minutes)=', '0.4830', 'loss=', '0.000555318')
# ('Epoch:', '0303', 'training time (minutes)=', '0.3721', 'loss=', '0.000551796')
# ('Epoch:', '0304', 'training time (minutes)=', '0.3726', 'loss=', '0.000550827')
# ('Epoch:', '0305', 'training time (minutes)=', '0.3770', 'loss=', '0.000555578')
# ('Held Out Data :', 'forward time (minutes)=', '0.0096', 'loss=', '0.000690106')
# ('Epoch:', '0306', 'training time (minutes)=', '0.4799', 'loss=', '0.000561078')
# ('Epoch:', '0307', 'training time (minutes)=', '0.3728', 'loss=', '0.000560711')
# ('Epoch:', '0308', 'training time (minutes)=', '0.3725', 'loss=', '0.000568420')
# ('Epoch:', '0309', 'training time (minutes)=', '0.4694', 'loss=', '0.000550434')
# ('Epoch:', '0310', 'training time (minutes)=', '0.3868', 'loss=', '0.000555535')
# ('Held Out Data :', 'forward time (minutes)=', '0.0091', 'loss=', '0.000773444')
# ('Epoch:', '0311', 'training time (minutes)=', '0.3722', 'loss=', '0.000551671')
# ('Epoch:', '0312', 'training time (minutes)=', '0.3738', 'loss=', '0.000547470')
# ('Epoch:', '0313', 'training time (minutes)=', '0.4854', 'loss=', '0.000549004')
# ('Epoch:', '0314', 'training time (minutes)=', '0.3721', 'loss=', '0.000548159')
# ('Epoch:', '0315', 'training time (minutes)=', '0.3742', 'loss=', '0.000550188')
# ('Held Out Data :', 'forward time (minutes)=', '0.0092', 'loss=', '0.000726131')
# ('Epoch:', '0316', 'training time (minutes)=', '0.3756', 'loss=', '0.000556983')
# ('Epoch:', '0317', 'training time (minutes)=', '0.4826', 'loss=', '0.000548890')
# ('Epoch:', '0318', 'training time (minutes)=', '0.3728', 'loss=', '0.000541991')
# ('Epoch:', '0319', 'training time (minutes)=', '0.3736', 'loss=', '0.000554690')
# ('Epoch:', '0320', 'training time (minutes)=', '0.3916', 'loss=', '0.000541894')
# ('Held Out Data :', 'forward time (minutes)=', '0.0180', 'loss=', '0.000758235')
# ('Epoch:', '0321', 'training time (minutes)=', '0.4546', 'loss=', '0.000543314')
# ('Epoch:', '0322', 'training time (minutes)=', '0.3722', 'loss=', '0.000553552')
# ('Epoch:', '0323', 'training time (minutes)=', '0.3726', 'loss=', '0.000549840')
# ('Epoch:', '0324', 'training time (minutes)=', '0.4765', 'loss=', '0.000548884')
# ('Epoch:', '0325', 'training time (minutes)=', '0.3785', 'loss=', '0.000544031')
# ('Held Out Data :', 'forward time (minutes)=', '0.0091', 'loss=', '0.000684137')
# ('Epoch:', '0326', 'training time (minutes)=', '0.3746', 'loss=', '0.000547647')
# ('Epoch:', '0327', 'training time (minutes)=', '0.3746', 'loss=', '0.000542348')
# ('Epoch:', '0328', 'training time (minutes)=', '0.4858', 'loss=', '0.000620745')
# ('Epoch:', '0329', 'training time (minutes)=', '0.3734', 'loss=', '0.000610590')
# ('Epoch:', '0330', 'training time (minutes)=', '0.3725', 'loss=', '0.000584832')
# ('Held Out Data :', 'forward time (minutes)=', '0.0091', 'loss=', '0.000798593')
# ('Epoch:', '0331', 'training time (minutes)=', '0.3755', 'loss=', '0.000600542')
# ('Epoch:', '0332', 'training time (minutes)=', '0.4826', 'loss=', '0.000562185')
# ('Epoch:', '0333', 'training time (minutes)=', '0.3725', 'loss=', '0.000561792')
# ('Epoch:', '0334', 'training time (minutes)=', '0.3732', 'loss=', '0.000556868')
# ('Epoch:', '0335', 'training time (minutes)=', '0.3802', 'loss=', '0.000554447')
# ('Held Out Data :', 'forward time (minutes)=', '0.0170', 'loss=', '0.000737996')
# ('Epoch:', '0336', 'training time (minutes)=', '0.4701', 'loss=', '0.000555570')
# ('Epoch:', '0337', 'training time (minutes)=', '0.3729', 'loss=', '0.000548796')
# ('Epoch:', '0338', 'training time (minutes)=', '0.3719', 'loss=', '0.000544224')
# ('Epoch:', '0339', 'training time (minutes)=', '0.4741', 'loss=', '0.000545014')
# ('Epoch:', '0340', 'training time (minutes)=', '0.3824', 'loss=', '0.000541903')
# ('Held Out Data :', 'forward time (minutes)=', '0.0098', 'loss=', '0.000653617')
# ('Epoch:', '0341', 'training time (minutes)=', '0.3725', 'loss=', '0.000538871')
# ('Epoch:', '0342', 'training time (minutes)=', '0.3744', 'loss=', '0.000549209')
# ('Epoch:', '0343', 'training time (minutes)=', '0.4835', 'loss=', '0.000550730')
# ('Epoch:', '0344', 'training time (minutes)=', '0.3719', 'loss=', '0.000532757')
# ('Epoch:', '0345', 'training time (minutes)=', '0.3721', 'loss=', '0.000533593')
# ('Held Out Data :', 'forward time (minutes)=', '0.0092', 'loss=', '0.000698429')
# ('Epoch:', '0346', 'training time (minutes)=', '0.3770', 'loss=', '0.000543558')
# ('Epoch:', '0347', 'training time (minutes)=', '0.4810', 'loss=', '0.000549654')
# ('Epoch:', '0348', 'training time (minutes)=', '0.3729', 'loss=', '0.000543381')
# ('Epoch:', '0349', 'training time (minutes)=', '0.3719', 'loss=', '0.000553615')
# ('Epoch:', '0350', 'training time (minutes)=', '0.4709', 'loss=', '0.000537900')
# ('Held Out Data :', 'forward time (minutes)=', '0.0185', 'loss=', '0.000744380')
# ('Epoch:', '0351', 'training time (minutes)=', '0.3770', 'loss=', '0.000539251')
# ('Epoch:', '0352', 'training time (minutes)=', '0.3727', 'loss=', '0.000538302')
# ('Epoch:', '0353', 'training time (minutes)=', '0.3738', 'loss=', '0.000571313')
# ('Epoch:', '0354', 'training time (minutes)=', '0.4830', 'loss=', '0.000539143')
# ('Epoch:', '0355', 'training time (minutes)=', '0.3724', 'loss=', '0.000548085')
# ('Held Out Data :', 'forward time (minutes)=', '0.0092', 'loss=', '0.000885833')
# ('Epoch:', '0356', 'training time (minutes)=', '0.3725', 'loss=', '0.000553160')
# ('Epoch:', '0357', 'training time (minutes)=', '0.3793', 'loss=', '0.000543678')
# ('Epoch:', '0358', 'training time (minutes)=', '0.4774', 'loss=', '0.000537537')
# ('Epoch:', '0359', 'training time (minutes)=', '0.3718', 'loss=', '0.000543793')
# ('Epoch:', '0360', 'training time (minutes)=', '0.3724', 'loss=', '0.000538879')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-d2353fb92c39> in <module>()
#       2     buf_size = 1 # flush each line
#       3     fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
# ----> 4     train_stats = ae.train(in_data['train'], conf, log_file=fout, held_out_data=in_data['test'])
#       5     fout.close()
#
# /orions4-zfs/projects/optas/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in train(self, train_data, configuration, log_file, held_out_data)
#     207 #                 tf.summary.scalar("Total Loss", loss_pl.assign(loss))
#     208             if held_out_data is not None and c.exists_and_is_not_none('held_out_step') and (epoch % c.held_out_step == 0):
# --> 209                 loss, duration = self._single_epoch_train(held_out_data, c, only_fw=True)
#     210                 print("Held Out Data :", 'forward time (minutes)=', "{:.4f}".format(duration / 60.0), "loss=", "{:.9f}".format(loss))
#     211                 if log_file is not None:
#
# /orions4-zfs/projects/optas/Git_Repos/tf_lab/point_clouds/point_net_ae.pyc in _single_epoch_train(self, train_data, configuration, only_fw)
#     147                 _, loss = fit(batch_i, original_data)
#     148             else:
# --> 149                 _, loss = fit(batch_i)
#     150
#     151             # Compute average loss
#
# /orions4-zfs/projects/optas/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in reconstruct(self, X, GT, compute_loss)
#     153
#     154         if GT is None:
# --> 155             return self.sess.run((self.x_reconstr, loss), feed_dict={self.x: X})
#     156         else:
#     157             return self.sess.run((self.x_reconstr, loss), feed_dict={self.x: X, self.gt: GT})
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
from tf_lab.point_clouds.convenience import reconstruct_pclouds
_, l_test = reconstruct_pclouds(ae, in_data['test'].point_clouds, batch_size=100)
_, l_train = reconstruct_pclouds(ae, in_data['train'].point_clouds, batch_size=100)
print l_test, l_train
# Out:
# 0.000749164663748 0.000654067897925
