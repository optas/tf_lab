# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet
from tf_lab.point_clouds.vae import VariationalAutoencoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.models.point_net_based_AE as pnAE
from tf_lab.fundamentals.utils import set_visible_GPUs

from general_tools.in_out.basics import create_dir, delete_files_in_directory
from geo_tool import Point_Cloud

from general_tools.in_out.basics import files_in_subdirs
from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
experiment_name = 'chamfer_full_shapes_all_SN_vae'

seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/1024/')

train_dir = osp.join(top_data_dir, 'OUT/models/variational')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/variational/chamfer_full_shapes_all_SN_vae'

# %%
full_file_names = pio.load_filenames_of_input_data(full_pclouds_path)
full_pclouds, full_model_names, class_ids = pio.load_crude_point_clouds(file_names=full_file_names, n_threads=11)
print '%d files containing complete point clouds were found.' % (len(full_pclouds), )
# Out:
# 52103 files containing complete point clouds were found.

# %%
train_data_, val_data_, test_data_ = pio.train_validate_test_split([full_pclouds, 
                                                                    full_model_names],
                                                                    train_perc=0.95,
                                                                    validate_perc=0.0,
                                                                    test_perc=0.05,                                                                   
                                                                    seed=seed)

train_data = PointCloudDataSet(train_data_[0], labels=train_data_[1])
test_data = PointCloudDataSet(test_data_[0], labels=test_data_[1])

# %%
def reset_graph():
    if 'sess' in globals() and sess:
        sess.close()
    tf.reset_default_graph()

set_visible_GPUs([0])

conf = Conf(n_input = [1024, 3],
            training_epochs = 1000,
            batch_size = 45,
            loss = 'chamfer',
            train_dir = train_dir,
            loss_display_step = 1,
            saver_step = 5,
            learning_rate = 0.00005,
            saver_max_to_keep = 500,
            gauss_augment = {'mu': 0, 'sigma': 0.02},
            encoder = pnAE.encoder,
            decoder = pnAE.decoder,
            spatial_trans = True,
            denoising = False,
            n_z = 1024,
            latent_vs_recon = 100,
            z_rotate = True
           )

reset_graph()

vae = VariationalAutoencoder(experiment_name, conf)
vae.train(train_data, conf)
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.9959', 'loss=', '13.434676707')
# ('Epoch:', '0002', 'training time (minutes)=', '1.9957', 'loss=', '0.008600579')
# ('Epoch:', '0003', 'training time (minutes)=', '2.0012', 'loss=', '0.008249746')
# ('Epoch:', '0004', 'training time (minutes)=', '2.0025', 'loss=', '0.008151806')
# ('Epoch:', '0005', 'training time (minutes)=', '2.0067', 'loss=', '0.008115648')
# ('Epoch:', '0006', 'training time (minutes)=', '2.0008', 'loss=', '0.008099382')
# ('Epoch:', '0007', 'training time (minutes)=', '2.0034', 'loss=', '0.008085662')
# ('Epoch:', '0008', 'training time (minutes)=', '2.0043', 'loss=', '0.008075480')
# ('Epoch:', '0009', 'training time (minutes)=', '2.0019', 'loss=', '0.008052266')
# ('Epoch:', '0010', 'training time (minutes)=', '2.0101', 'loss=', '0.008046586')
# ('Epoch:', '0011', 'training time (minutes)=', '1.9992', 'loss=', '0.008033528')
# ('Epoch:', '0012', 'training time (minutes)=', '2.0046', 'loss=', '0.008032869')
# ('Epoch:', '0013', 'training time (minutes)=', '2.0007', 'loss=', '0.008050027')
# ('Epoch:', '0014', 'training time (minutes)=', '2.0020', 'loss=', '0.008038901')
# ('Epoch:', '0015', 'training time (minutes)=', '2.0058', 'loss=', '0.008035916')
# ('Epoch:', '0016', 'training time (minutes)=', '2.0006', 'loss=', '0.007997811')
# ('Epoch:', '0017', 'training time (minutes)=', '2.0040', 'loss=', '0.008025212')
# ('Epoch:', '0018', 'training time (minutes)=', '2.0063', 'loss=', '0.008011914')
# ('Epoch:', '0019', 'training time (minutes)=', '2.0032', 'loss=', '0.007998660')
# ('Epoch:', '0020', 'training time (minutes)=', '2.0061', 'loss=', '0.007997648')
# ('Epoch:', '0021', 'training time (minutes)=', '2.0031', 'loss=', '0.008013190')
# ('Epoch:', '0022', 'training time (minutes)=', '2.0048', 'loss=', '0.008008622')
# ('Epoch:', '0023', 'training time (minutes)=', '2.0065', 'loss=', '0.008005836')
# ('Epoch:', '0024', 'training time (minutes)=', '2.0075', 'loss=', '0.007970647')
# ('Epoch:', '0025', 'training time (minutes)=', '2.0064', 'loss=', '0.008017402')
# ('Epoch:', '0026', 'training time (minutes)=', '2.0078', 'loss=', '0.007970365')
# ('Epoch:', '0027', 'training time (minutes)=', '2.0023', 'loss=', '0.007999518')
# ('Epoch:', '0028', 'training time (minutes)=', '2.0100', 'loss=', '0.007952238')
# ('Epoch:', '0029', 'training time (minutes)=', '2.0053', 'loss=', '0.008007922')
# ('Epoch:', '0030', 'training time (minutes)=', '2.0047', 'loss=', '0.007971463')
# ('Epoch:', '0031', 'training time (minutes)=', '1.9997', 'loss=', '0.007990983')
# ('Epoch:', '0032', 'training time (minutes)=', '2.0021', 'loss=', '0.007963447')
# ('Epoch:', '0033', 'training time (minutes)=', '2.0074', 'loss=', '0.007971253')
# ('Epoch:', '0034', 'training time (minutes)=', '2.0096', 'loss=', '0.007969511')
# ('Epoch:', '0035', 'training time (minutes)=', '2.0054', 'loss=', '0.007975388')
# ('Epoch:', '0036', 'training time (minutes)=', '2.0017', 'loss=', '0.007948512')
# ('Epoch:', '0037', 'training time (minutes)=', '2.0083', 'loss=', '0.007969607')
# ('Epoch:', '0038', 'training time (minutes)=', '2.0074', 'loss=', '0.007978446')
# ('Epoch:', '0039', 'training time (minutes)=', '2.0088', 'loss=', '0.007943165')
# ('Epoch:', '0040', 'training time (minutes)=', '2.0019', 'loss=', '0.007980773')
# ('Epoch:', '0041', 'training time (minutes)=', '2.0089', 'loss=', '0.007945359')
# ('Epoch:', '0042', 'training time (minutes)=', '2.0075', 'loss=', '0.007969927')
# ('Epoch:', '0043', 'training time (minutes)=', '2.0066', 'loss=', '0.007963140')
# ('Epoch:', '0044', 'training time (minutes)=', '2.0047', 'loss=', '0.007972696')
# ('Epoch:', '0045', 'training time (minutes)=', '2.0099', 'loss=', '0.007944644')
# ('Epoch:', '0046', 'training time (minutes)=', '2.0045', 'loss=', '0.007954020')
# ('Epoch:', '0047', 'training time (minutes)=', '2.0039', 'loss=', '0.007966534')
# ('Epoch:', '0048', 'training time (minutes)=', '2.0022', 'loss=', '0.007931970')
# ('Epoch:', '0049', 'training time (minutes)=', '2.0052', 'loss=', '0.007967131')
# ('Epoch:', '0050', 'training time (minutes)=', '2.0078', 'loss=', '0.007948194')
# ('Epoch:', '0051', 'training time (minutes)=', '2.0046', 'loss=', '0.007969701')
# ('Epoch:', '0052', 'training time (minutes)=', '2.0079', 'loss=', '0.007947212')
# ('Epoch:', '0053', 'training time (minutes)=', '2.0025', 'loss=', '0.007965559')
# ('Epoch:', '0054', 'training time (minutes)=', '2.0072', 'loss=', '0.007957557')
# ('Epoch:', '0055', 'training time (minutes)=', '2.0074', 'loss=', '0.007947893')
# ('Epoch:', '0056', 'training time (minutes)=', '2.0044', 'loss=', '0.007949543')
# ('Epoch:', '0057', 'training time (minutes)=', '2.0044', 'loss=', '0.007939782')
# ('Epoch:', '0058', 'training time (minutes)=', '2.0050', 'loss=', '0.007969556')
# ('Epoch:', '0059', 'training time (minutes)=', '2.0051', 'loss=', '0.007947206')
# ('Epoch:', '0060', 'training time (minutes)=', '2.0077', 'loss=', '0.007964120')
# ('Epoch:', '0061', 'training time (minutes)=', '1.9990', 'loss=', '0.007933104')
# ('Epoch:', '0062', 'training time (minutes)=', '2.0074', 'loss=', '0.007955261')
# ('Epoch:', '0063', 'training time (minutes)=', '2.0088', 'loss=', '0.007972070')
# ('Epoch:', '0064', 'training time (minutes)=', '2.0069', 'loss=', '0.007923803')
# ('Epoch:', '0065', 'training time (minutes)=', '2.0006', 'loss=', '0.007955683')
# ('Epoch:', '0066', 'training time (minutes)=', '2.0007', 'loss=', '0.007939508')
# ('Epoch:', '0067', 'training time (minutes)=', '2.0060', 'loss=', '0.007963698')
# ('Epoch:', '0068', 'training time (minutes)=', '2.0022', 'loss=', '0.007951555')
# ('Epoch:', '0069', 'training time (minutes)=', '2.0064', 'loss=', '0.007931456')
# ('Epoch:', '0070', 'training time (minutes)=', '2.0074', 'loss=', '0.007955413')
# ('Epoch:', '0071', 'training time (minutes)=', '2.0051', 'loss=', '0.007954359')
# ('Epoch:', '0072', 'training time (minutes)=', '2.0089', 'loss=', '0.007954812')
# ('Epoch:', '0073', 'training time (minutes)=', '2.0049', 'loss=', '0.007931136')
# ('Epoch:', '0074', 'training time (minutes)=', '2.0054', 'loss=', '0.007956998')
# ('Epoch:', '0075', 'training time (minutes)=', '2.0075', 'loss=', '0.007955007')
# ('Epoch:', '0076', 'training time (minutes)=', '2.0042', 'loss=', '0.007948649')
# ('Epoch:', '0077', 'training time (minutes)=', '2.0101', 'loss=', '0.007959800')
# ('Epoch:', '0078', 'training time (minutes)=', '2.0023', 'loss=', '0.007918874')
# ('Epoch:', '0079', 'training time (minutes)=', '2.0040', 'loss=', '0.007944595')
# ('Epoch:', '0080', 'training time (minutes)=', '2.0060', 'loss=', '0.007963114')
# ('Epoch:', '0081', 'training time (minutes)=', '2.0049', 'loss=', '0.007957448')
# ('Epoch:', '0082', 'training time (minutes)=', '2.0035', 'loss=', '0.007942409')
# ('Epoch:', '0083', 'training time (minutes)=', '2.0078', 'loss=', '0.007955200')
# ('Epoch:', '0084', 'training time (minutes)=', '2.0053', 'loss=', '0.007927421')
# ('Epoch:', '0085', 'training time (minutes)=', '2.0071', 'loss=', '0.007952815')
# ('Epoch:', '0086', 'training time (minutes)=', '2.0041', 'loss=', '0.007947000')
# ('Epoch:', '0087', 'training time (minutes)=', '1.9998', 'loss=', '0.007959514')
# ('Epoch:', '0088', 'training time (minutes)=', '2.0024', 'loss=', '0.007965648')
# ('Epoch:', '0089', 'training time (minutes)=', '2.0067', 'loss=', '0.007930560')
# ('Epoch:', '0090', 'training time (minutes)=', '2.0032', 'loss=', '0.007941450')
# ('Epoch:', '0091', 'training time (minutes)=', '2.0027', 'loss=', '0.007954084')
# ('Epoch:', '0092', 'training time (minutes)=', '2.0078', 'loss=', '0.007958876')
# ('Epoch:', '0093', 'training time (minutes)=', '2.0060', 'loss=', '0.007928941')
# ('Epoch:', '0094', 'training time (minutes)=', '2.0064', 'loss=', '0.007949908')
# ('Epoch:', '0095', 'training time (minutes)=', '2.0017', 'loss=', '0.007951532')
# ('Epoch:', '0096', 'training time (minutes)=', '2.0010', 'loss=', '0.007945877')
# ('Epoch:', '0097', 'training time (minutes)=', '2.0064', 'loss=', '0.007948305')
# ('Epoch:', '0098', 'training time (minutes)=', '2.0020', 'loss=', '0.007917121')
# ('Epoch:', '0099', 'training time (minutes)=', '2.0011', 'loss=', '0.007951262')
# ('Epoch:', '0100', 'training time (minutes)=', '2.0064', 'loss=', '0.007972390')
# ('Epoch:', '0101', 'training time (minutes)=', '1.9990', 'loss=', '0.007932055')
# ('Epoch:', '0102', 'training time (minutes)=', '2.0036', 'loss=', '0.007948544')
# ('Epoch:', '0103', 'training time (minutes)=', '2.0048', 'loss=', '0.007939457')
# ('Epoch:', '0104', 'training time (minutes)=', '2.0051', 'loss=', '0.007961848')
# ('Epoch:', '0105', 'training time (minutes)=', '2.0037', 'loss=', '0.007950207')
# ('Epoch:', '0106', 'training time (minutes)=', '1.9997', 'loss=', '0.007932118')
# ('Epoch:', '0107', 'training time (minutes)=', '2.0024', 'loss=', '0.007944694')
# ('Epoch:', '0108', 'training time (minutes)=', '2.0033', 'loss=', '0.007938958')
# ('Epoch:', '0109', 'training time (minutes)=', '2.0038', 'loss=', '0.007948167')
# ('Epoch:', '0110', 'training time (minutes)=', '2.0035', 'loss=', '0.007938503')
# ('Epoch:', '0111', 'training time (minutes)=', '1.9999', 'loss=', '0.007946432')
# ('Epoch:', '0112', 'training time (minutes)=', '2.0066', 'loss=', '0.007966671')
# ('Epoch:', '0113', 'training time (minutes)=', '2.0045', 'loss=', '0.007932004')
# ('Epoch:', '0114', 'training time (minutes)=', '2.0063', 'loss=', '0.007942766')
# ('Epoch:', '0115', 'training time (minutes)=', '2.0017', 'loss=', '0.007937537')
# ('Epoch:', '0116', 'training time (minutes)=', '2.0059', 'loss=', '0.007965115')
# ('Epoch:', '0117', 'training time (minutes)=', '2.0031', 'loss=', '0.007920034')
# ('Epoch:', '0118', 'training time (minutes)=', '2.0093', 'loss=', '0.007953974')
# ('Epoch:', '0119', 'training time (minutes)=', '2.0070', 'loss=', '0.007963295')
# ('Epoch:', '0120', 'training time (minutes)=', '2.0025', 'loss=', '0.007941738')
# ('Epoch:', '0121', 'training time (minutes)=', '2.0078', 'loss=', '0.007939238')
# ('Epoch:', '0122', 'training time (minutes)=', '2.0069', 'loss=', '0.007947410')
# ('Epoch:', '0123', 'training time (minutes)=', '2.0016', 'loss=', '0.007937160')
# ('Epoch:', '0124', 'training time (minutes)=', '2.0030', 'loss=', '0.007933396')
# ('Epoch:', '0125', 'training time (minutes)=', '2.0065', 'loss=', '0.007949425')
# ('Epoch:', '0126', 'training time (minutes)=', '2.0071', 'loss=', '0.007949162')
# ('Epoch:', '0127', 'training time (minutes)=', '2.0089', 'loss=', '0.007929486')
# ('Epoch:', '0128', 'training time (minutes)=', '2.0076', 'loss=', '0.007938699')
# ('Epoch:', '0129', 'training time (minutes)=', '2.0073', 'loss=', '0.007966818')
# ('Epoch:', '0130', 'training time (minutes)=', '2.0056', 'loss=', '0.007926909')
# ('Epoch:', '0131', 'training time (minutes)=', '2.0017', 'loss=', '0.007946898')
# ('Epoch:', '0132', 'training time (minutes)=', '2.0053', 'loss=', '0.007941653')
# ('Epoch:', '0133', 'training time (minutes)=', '2.0077', 'loss=', '0.007946829')
# ('Epoch:', '0134', 'training time (minutes)=', '2.0029', 'loss=', '0.007938163')
# ('Epoch:', '0135', 'training time (minutes)=', '2.0070', 'loss=', '0.007955630')
# ('Epoch:', '0136', 'training time (minutes)=', '2.0075', 'loss=', '0.007934699')
# ('Epoch:', '0137', 'training time (minutes)=', '2.0058', 'loss=', '0.007933133')
# ('Epoch:', '0138', 'training time (minutes)=', '2.0122', 'loss=', '0.007957889')
# ('Epoch:', '0139', 'training time (minutes)=', '2.0065', 'loss=', '0.007912721')
# ('Epoch:', '0140', 'training time (minutes)=', '2.0065', 'loss=', '0.007953841')
# ('Epoch:', '0141', 'training time (minutes)=', '2.0072', 'loss=', '0.007968806')
# ('Epoch:', '0142', 'training time (minutes)=', '2.0086', 'loss=', '0.007932427')
# ('Epoch:', '0143', 'training time (minutes)=', '2.0095', 'loss=', '0.007937866')
# ('Epoch:', '0144', 'training time (minutes)=', '2.0070', 'loss=', '0.007936000')
# ('Epoch:', '0145', 'training time (minutes)=', '2.0059', 'loss=', '0.007948245')
# ('Epoch:', '0146', 'training time (minutes)=', '2.0067', 'loss=', '0.007924726')
# ('Epoch:', '0147', 'training time (minutes)=', '2.0077', 'loss=', '0.007944893')
# ('Epoch:', '0148', 'training time (minutes)=', '2.0098', 'loss=', '0.007956332')
# ('Epoch:', '0149', 'training time (minutes)=', '2.0094', 'loss=', '0.007933785')
# ('Epoch:', '0150', 'training time (minutes)=', '2.0110', 'loss=', '0.007948089')
# ('Epoch:', '0151', 'training time (minutes)=', '2.0078', 'loss=', '0.007927938')
# ('Epoch:', '0152', 'training time (minutes)=', '2.0119', 'loss=', '0.007955681')
# ('Epoch:', '0153', 'training time (minutes)=', '2.0203', 'loss=', '0.007934259')
# ('Epoch:', '0154', 'training time (minutes)=', '2.0046', 'loss=', '0.007945469')
# ('Epoch:', '0155', 'training time (minutes)=', '2.0035', 'loss=', '0.007927068')
# ('Epoch:', '0156', 'training time (minutes)=', '1.9805', 'loss=', '0.007937552')
# ('Epoch:', '0157', 'training time (minutes)=', '1.9818', 'loss=', '0.007944055')
# ('Epoch:', '0158', 'training time (minutes)=', '1.9806', 'loss=', '0.007956470')
# ('Epoch:', '0159', 'training time (minutes)=', '1.9807', 'loss=', '0.007933022')
# ('Epoch:', '0160', 'training time (minutes)=', '1.9808', 'loss=', '0.007932892')
# ('Epoch:', '0161', 'training time (minutes)=', '1.9800', 'loss=', '0.007970021')
# ('Epoch:', '0162', 'training time (minutes)=', '1.9826', 'loss=', '0.007906607')
# ('Epoch:', '0163', 'training time (minutes)=', '1.9810', 'loss=', '0.007975725')
# ('Epoch:', '0164', 'training time (minutes)=', '1.9823', 'loss=', '0.007920622')
# ('Epoch:', '0165', 'training time (minutes)=', '1.9845', 'loss=', '0.007954465')
# ('Epoch:', '0166', 'training time (minutes)=', '1.9802', 'loss=', '0.007946236')
# ('Epoch:', '0167', 'training time (minutes)=', '1.9791', 'loss=', '0.007929117')
# ('Epoch:', '0168', 'training time (minutes)=', '1.9807', 'loss=', '0.007936092')
# ('Epoch:', '0169', 'training time (minutes)=', '1.9786', 'loss=', '0.007961056')
# ('Epoch:', '0170', 'training time (minutes)=', '1.9792', 'loss=', '0.007924952')
# ('Epoch:', '0171', 'training time (minutes)=', '1.9776', 'loss=', '0.007953211')
# ('Epoch:', '0172', 'training time (minutes)=', '1.9828', 'loss=', '0.007922549')
# ('Epoch:', '0173', 'training time (minutes)=', '1.9776', 'loss=', '0.007945093')
# ('Epoch:', '0174', 'training time (minutes)=', '1.9826', 'loss=', '0.007927905')
# ('Epoch:', '0175', 'training time (minutes)=', '1.9800', 'loss=', '0.007942918')
# ('Epoch:', '0176', 'training time (minutes)=', '1.9772', 'loss=', '0.007944351')
# ('Epoch:', '0177', 'training time (minutes)=', '1.9797', 'loss=', '0.007946548')
# ('Epoch:', '0178', 'training time (minutes)=', '1.9798', 'loss=', '0.007959717')
# ('Epoch:', '0179', 'training time (minutes)=', '1.9768', 'loss=', '0.007929160')
# ('Epoch:', '0180', 'training time (minutes)=', '1.9806', 'loss=', '0.007945306')
# ('Epoch:', '0181', 'training time (minutes)=', '1.9780', 'loss=', '0.007932189')
# ('Epoch:', '0182', 'training time (minutes)=', '1.9879', 'loss=', '0.007964722')
# ('Epoch:', '0183', 'training time (minutes)=', '1.9816', 'loss=', '0.007915662')
# ('Epoch:', '0184', 'training time (minutes)=', '1.9775', 'loss=', '0.007938312')
# ('Epoch:', '0185', 'training time (minutes)=', '1.9781', 'loss=', '0.007958035')
# ('Epoch:', '0186', 'training time (minutes)=', '1.9796', 'loss=', '0.007909641')
# ('Epoch:', '0187', 'training time (minutes)=', '1.9825', 'loss=', '0.007965754')
# ('Epoch:', '0188', 'training time (minutes)=', '1.9809', 'loss=', '0.007926587')
# ('Epoch:', '0189', 'training time (minutes)=', '1.9787', 'loss=', '0.007939951')
# ('Epoch:', '0190', 'training time (minutes)=', '1.9808', 'loss=', '0.007949669')
# ('Epoch:', '0191', 'training time (minutes)=', '1.9791', 'loss=', '0.007948040')
# ('Epoch:', '0192', 'training time (minutes)=', '1.9777', 'loss=', '0.007923100')
# ('Epoch:', '0193', 'training time (minutes)=', '1.9810', 'loss=', '0.007955753')
# ('Epoch:', '0194', 'training time (minutes)=', '1.9827', 'loss=', '0.007923430')
# ('Epoch:', '0195', 'training time (minutes)=', '1.9826', 'loss=', '0.007959161')
# ('Epoch:', '0196', 'training time (minutes)=', '1.9783', 'loss=', '0.007942314')
# ('Epoch:', '0197', 'training time (minutes)=', '1.9803', 'loss=', '0.007926923')
# ('Epoch:', '0198', 'training time (minutes)=', '1.9830', 'loss=', '0.007951405')
# ('Epoch:', '0199', 'training time (minutes)=', '1.9779', 'loss=', '0.007948149')
# ('Epoch:', '0200', 'training time (minutes)=', '1.9781', 'loss=', '0.007938994')
# ('Epoch:', '0201', 'training time (minutes)=', '1.9798', 'loss=', '0.007928695')
# ('Epoch:', '0202', 'training time (minutes)=', '1.9795', 'loss=', '0.007935513')
# ('Epoch:', '0203', 'training time (minutes)=', '1.9768', 'loss=', '0.007955992')
# ('Epoch:', '0204', 'training time (minutes)=', '1.9770', 'loss=', '0.007943834')
# ('Epoch:', '0205', 'training time (minutes)=', '1.9862', 'loss=', '0.007915688')
# ('Epoch:', '0206', 'training time (minutes)=', '1.9775', 'loss=', '0.007958095')
# ('Epoch:', '0207', 'training time (minutes)=', '1.9783', 'loss=', '0.007943456')
# ('Epoch:', '0208', 'training time (minutes)=', '1.9796', 'loss=', '0.007928155')
# ('Epoch:', '0209', 'training time (minutes)=', '1.9822', 'loss=', '0.007913808')
# ('Epoch:', '0210', 'training time (minutes)=', '1.9823', 'loss=', '0.007976251')
# ('Epoch:', '0211', 'training time (minutes)=', '1.9779', 'loss=', '0.007932476')
# ('Epoch:', '0212', 'training time (minutes)=', '1.9773', 'loss=', '0.007960630')
# ('Epoch:', '0213', 'training time (minutes)=', '1.9762', 'loss=', '0.007924896')
# ('Epoch:', '0214', 'training time (minutes)=', '1.9794', 'loss=', '0.007931855')
# ('Epoch:', '0215', 'training time (minutes)=', '1.9805', 'loss=', '0.007958006')
# ('Epoch:', '0216', 'training time (minutes)=', '1.9797', 'loss=', '0.007935117')
# ('Epoch:', '0217', 'training time (minutes)=', '1.9813', 'loss=', '0.007949396')
# ('Epoch:', '0218', 'training time (minutes)=', '1.9788', 'loss=', '0.007930996')
# ('Epoch:', '0219', 'training time (minutes)=', '1.9786', 'loss=', '0.007936786')
# ('Epoch:', '0220', 'training time (minutes)=', '1.9762', 'loss=', '0.007942930')
# ('Epoch:', '0221', 'training time (minutes)=', '1.9782', 'loss=', '0.007937159')
# ('Epoch:', '0222', 'training time (minutes)=', '1.9796', 'loss=', '0.007940616')
# ('Epoch:', '0223', 'training time (minutes)=', '1.9819', 'loss=', '0.007951220')
# ('Epoch:', '0224', 'training time (minutes)=', '1.9811', 'loss=', '0.007934902')
# ('Epoch:', '0225', 'training time (minutes)=', '1.9802', 'loss=', '0.007944230')
# ('Epoch:', '0226', 'training time (minutes)=', '1.9822', 'loss=', '0.007943982')
# ('Epoch:', '0227', 'training time (minutes)=', '1.9846', 'loss=', '0.007940826')
# ('Epoch:', '0228', 'training time (minutes)=', '1.9789', 'loss=', '0.007919514')
# ('Epoch:', '0229', 'training time (minutes)=', '1.9805', 'loss=', '0.007923823')
# ('Epoch:', '0230', 'training time (minutes)=', '1.9743', 'loss=', '0.007954405')
# ('Epoch:', '0231', 'training time (minutes)=', '1.9799', 'loss=', '0.007944025')
# ('Epoch:', '0232', 'training time (minutes)=', '1.9818', 'loss=', '0.007930536')
# ('Epoch:', '0233', 'training time (minutes)=', '1.9831', 'loss=', '0.007948047')
# ('Epoch:', '0234', 'training time (minutes)=', '1.9834', 'loss=', '0.007925255')
# ('Epoch:', '0235', 'training time (minutes)=', '1.9841', 'loss=', '0.007947689')
# ('Epoch:', '0236', 'training time (minutes)=', '1.9790', 'loss=', '0.007930834')
# ('Epoch:', '0237', 'training time (minutes)=', '1.9793', 'loss=', '0.007951708')
# ('Epoch:', '0238', 'training time (minutes)=', '1.9804', 'loss=', '0.007929724')
# ('Epoch:', '0239', 'training time (minutes)=', '1.9812', 'loss=', '0.007927301')
# ('Epoch:', '0240', 'training time (minutes)=', '1.9808', 'loss=', '0.007947650')
# ('Epoch:', '0241', 'training time (minutes)=', '1.9795', 'loss=', '0.007936477')
# ('Epoch:', '0242', 'training time (minutes)=', '1.9800', 'loss=', '0.007928276')
# ('Epoch:', '0243', 'training time (minutes)=', '1.9812', 'loss=', '0.007923139')
# ('Epoch:', '0244', 'training time (minutes)=', '1.9819', 'loss=', '0.007955646')
# ('Epoch:', '0245', 'training time (minutes)=', '1.9865', 'loss=', '0.007943045')
# ('Epoch:', '0246', 'training time (minutes)=', '1.9797', 'loss=', '0.007933090')
# ('Epoch:', '0247', 'training time (minutes)=', '1.9836', 'loss=', '0.007935383')
# ('Epoch:', '0248', 'training time (minutes)=', '1.9804', 'loss=', '0.007952333')
# ('Epoch:', '0249', 'training time (minutes)=', '1.9853', 'loss=', '0.007918605')
# ('Epoch:', '0250', 'training time (minutes)=', '1.9791', 'loss=', '0.007937491')
# ('Epoch:', '0251', 'training time (minutes)=', '1.9751', 'loss=', '0.007953008')
# ('Epoch:', '0252', 'training time (minutes)=', '1.9825', 'loss=', '0.007940096')
# ('Epoch:', '0253', 'training time (minutes)=', '1.9805', 'loss=', '0.007932678')
# ('Epoch:', '0254', 'training time (minutes)=', '1.9806', 'loss=', '0.007954084')
# ('Epoch:', '0255', 'training time (minutes)=', '1.9784', 'loss=', '0.007929037')
# ('Epoch:', '0256', 'training time (minutes)=', '1.9773', 'loss=', '0.007926233')
# ('Epoch:', '0257', 'training time (minutes)=', '1.9777', 'loss=', '0.007964662')
# ('Epoch:', '0258', 'training time (minutes)=', '1.9821', 'loss=', '0.007929407')
# ('Epoch:', '0259', 'training time (minutes)=', '1.9830', 'loss=', '0.007934305')
# ('Epoch:', '0260', 'training time (minutes)=', '1.9819', 'loss=', '0.007942048')
# ('Epoch:', '0261', 'training time (minutes)=', '1.9776', 'loss=', '0.007938461')
# ('Epoch:', '0262', 'training time (minutes)=', '1.9819', 'loss=', '0.007925971')
# ('Epoch:', '0263', 'training time (minutes)=', '1.9799', 'loss=', '0.007955977')
# ('Epoch:', '0264', 'training time (minutes)=', '1.9804', 'loss=', '0.007921541')
# ('Epoch:', '0265', 'training time (minutes)=', '1.9798', 'loss=', '0.007943729')
# ('Epoch:', '0266', 'training time (minutes)=', '1.9790', 'loss=', '0.007918787')
# ('Epoch:', '0267', 'training time (minutes)=', '1.9796', 'loss=', '0.007969641')
# ('Epoch:', '0268', 'training time (minutes)=', '1.9789', 'loss=', '0.007930266')
# ('Epoch:', '0269', 'training time (minutes)=', '1.9800', 'loss=', '0.007949251')
# ('Epoch:', '0270', 'training time (minutes)=', '1.9808', 'loss=', '0.007921944')
# ('Epoch:', '0271', 'training time (minutes)=', '1.9780', 'loss=', '0.007956312')
# ('Epoch:', '0272', 'training time (minutes)=', '1.9795', 'loss=', '0.007932364')
# ('Epoch:', '0273', 'training time (minutes)=', '1.9798', 'loss=', '0.007927379')
# ('Epoch:', '0274', 'training time (minutes)=', '1.9788', 'loss=', '0.007951882')
# ('Epoch:', '0275', 'training time (minutes)=', '1.9834', 'loss=', '0.007936897')
# ('Epoch:', '0276', 'training time (minutes)=', '1.9776', 'loss=', '0.007915472')
# ('Epoch:', '0277', 'training time (minutes)=', '1.9769', 'loss=', '0.007946343')
# ('Epoch:', '0278', 'training time (minutes)=', '1.9793', 'loss=', '0.007950618')
# ('Epoch:', '0279', 'training time (minutes)=', '1.9787', 'loss=', '0.007934116')
# ('Epoch:', '0280', 'training time (minutes)=', '1.9821', 'loss=', '0.007940355')
# ('Epoch:', '0281', 'training time (minutes)=', '1.9785', 'loss=', '0.007946342')
# ('Epoch:', '0282', 'training time (minutes)=', '1.9789', 'loss=', '0.007922470')
# ('Epoch:', '0283', 'training time (minutes)=', '1.9817', 'loss=', '0.007934646')
# ('Epoch:', '0284', 'training time (minutes)=', '1.9837', 'loss=', '0.007954357')
# ('Epoch:', '0285', 'training time (minutes)=', '1.9807', 'loss=', '0.007910385')
# ('Epoch:', '0286', 'training time (minutes)=', '1.9821', 'loss=', '0.007942077')
# ('Epoch:', '0287', 'training time (minutes)=', '1.9805', 'loss=', '0.007929160')
# ('Epoch:', '0288', 'training time (minutes)=', '1.9809', 'loss=', '0.007943597')
# ('Epoch:', '0289', 'training time (minutes)=', '1.9813', 'loss=', '0.007955979')
# ('Epoch:', '0290', 'training time (minutes)=', '1.9783', 'loss=', '0.007935506')
# ('Epoch:', '0291', 'training time (minutes)=', '1.9795', 'loss=', '0.007931059')
# ('Epoch:', '0292', 'training time (minutes)=', '1.9821', 'loss=', '0.007939092')
# ('Epoch:', '0293', 'training time (minutes)=', '1.9807', 'loss=', '0.007952399')
# ('Epoch:', '0294', 'training time (minutes)=', '1.9801', 'loss=', '0.007941850')
# ('Epoch:', '0295', 'training time (minutes)=', '1.9797', 'loss=', '0.007946636')
# ('Epoch:', '0296', 'training time (minutes)=', '1.9811', 'loss=', '0.007917793')
# ('Epoch:', '0297', 'training time (minutes)=', '1.9783', 'loss=', '0.007944531')
# ('Epoch:', '0298', 'training time (minutes)=', '1.9791', 'loss=', '0.007930743')
# ('Epoch:', '0299', 'training time (minutes)=', '1.9779', 'loss=', '0.007945499')
# ('Epoch:', '0300', 'training time (minutes)=', '1.9841', 'loss=', '0.007944842')
# ('Epoch:', '0301', 'training time (minutes)=', '1.9763', 'loss=', '0.007937752')
# ('Epoch:', '0302', 'training time (minutes)=', '1.9857', 'loss=', '0.007928706')
# ('Epoch:', '0303', 'training time (minutes)=', '1.9802', 'loss=', '0.007935102')
# ('Epoch:', '0304', 'training time (minutes)=', '1.9822', 'loss=', '0.007939456')
# ('Epoch:', '0305', 'training time (minutes)=', '1.9824', 'loss=', '0.007937113')
# ('Epoch:', '0306', 'training time (minutes)=', '1.9818', 'loss=', '0.007931406')
# ('Epoch:', '0307', 'training time (minutes)=', '1.9811', 'loss=', '0.007939184')
# ('Epoch:', '0308', 'training time (minutes)=', '1.9826', 'loss=', '0.007931170')
# ('Epoch:', '0309', 'training time (minutes)=', '1.9830', 'loss=', '0.007949731')
# ('Epoch:', '0310', 'training time (minutes)=', '1.9807', 'loss=', '0.007927474')
# ('Epoch:', '0311', 'training time (minutes)=', '1.9786', 'loss=', '0.007950590')
# ('Epoch:', '0312', 'training time (minutes)=', '1.9811', 'loss=', '0.007932863')
# ('Epoch:', '0313', 'training time (minutes)=', '1.9810', 'loss=', '0.007945664')
# ('Epoch:', '0314', 'training time (minutes)=', '1.9849', 'loss=', '0.007937417')
# ('Epoch:', '0315', 'training time (minutes)=', '1.9849', 'loss=', '0.007927638')
# ('Epoch:', '0316', 'training time (minutes)=', '1.9831', 'loss=', '0.007934795')
# ('Epoch:', '0317', 'training time (minutes)=', '1.9832', 'loss=', '0.007955310')
# ('Epoch:', '0318', 'training time (minutes)=', '1.9831', 'loss=', '0.007915313')
# ('Epoch:', '0319', 'training time (minutes)=', '1.9857', 'loss=', '0.007960688')
# ('Epoch:', '0320', 'training time (minutes)=', '1.9836', 'loss=', '0.007912207')
# ('Epoch:', '0321', 'training time (minutes)=', '1.9802', 'loss=', '0.007962831')
# ('Epoch:', '0322', 'training time (minutes)=', '1.9874', 'loss=', '0.007932963')
# ('Epoch:', '0323', 'training time (minutes)=', '1.9837', 'loss=', '0.007933723')
# ('Epoch:', '0324', 'training time (minutes)=', '1.9852', 'loss=', '0.007950776')
# ('Epoch:', '0325', 'training time (minutes)=', '1.9837', 'loss=', '0.007930504')
# ('Epoch:', '0326', 'training time (minutes)=', '1.9858', 'loss=', '0.007922341')
# ('Epoch:', '0327', 'training time (minutes)=', '1.9890', 'loss=', '0.007946023')
# ('Epoch:', '0328', 'training time (minutes)=', '1.9838', 'loss=', '0.007940572')
# ('Epoch:', '0329', 'training time (minutes)=', '1.9854', 'loss=', '0.007937939')
# ('Epoch:', '0330', 'training time (minutes)=', '1.9866', 'loss=', '0.007933211')
# ('Epoch:', '0331', 'training time (minutes)=', '1.9817', 'loss=', '0.007944391')
# ('Epoch:', '0332', 'training time (minutes)=', '1.9827', 'loss=', '0.007945829')
# ('Epoch:', '0333', 'training time (minutes)=', '1.9822', 'loss=', '0.007925489')
# ('Epoch:', '0334', 'training time (minutes)=', '1.9834', 'loss=', '0.007931972')
# ('Epoch:', '0335', 'training time (minutes)=', '1.9848', 'loss=', '0.007932629')
# ('Epoch:', '0336', 'training time (minutes)=', '1.9814', 'loss=', '0.007951309')
# ('Epoch:', '0337', 'training time (minutes)=', '1.9861', 'loss=', '0.007927469')
# ('Epoch:', '0338', 'training time (minutes)=', '1.9813', 'loss=', '0.007930758')
# ('Epoch:', '0339', 'training time (minutes)=', '1.9850', 'loss=', '0.007955128')
# ('Epoch:', '0340', 'training time (minutes)=', '1.9826', 'loss=', '0.007922209')
# ('Epoch:', '0341', 'training time (minutes)=', '1.9824', 'loss=', '0.007959160')
# ('Epoch:', '0342', 'training time (minutes)=', '1.9843', 'loss=', '0.007921019')
# ('Epoch:', '0343', 'training time (minutes)=', '1.9846', 'loss=', '0.007932242')
# ('Epoch:', '0344', 'training time (minutes)=', '1.9844', 'loss=', '0.007915323')
# ('Epoch:', '0345', 'training time (minutes)=', '1.9860', 'loss=', '0.007965419')
# ('Epoch:', '0346', 'training time (minutes)=', '1.9817', 'loss=', '0.007935717')
# ('Epoch:', '0347', 'training time (minutes)=', '1.9874', 'loss=', '0.007928309')
# ('Epoch:', '0348', 'training time (minutes)=', '1.9812', 'loss=', '0.007946174')
# ('Epoch:', '0349', 'training time (minutes)=', '1.9856', 'loss=', '0.007938370')
# ('Epoch:', '0350', 'training time (minutes)=', '1.9863', 'loss=', '0.007935190')
# ('Epoch:', '0351', 'training time (minutes)=', '1.9971', 'loss=', '0.007920169')
# ('Epoch:', '0352', 'training time (minutes)=', '1.9889', 'loss=', '0.007945007')
# ('Epoch:', '0353', 'training time (minutes)=', '1.9898', 'loss=', '0.007934633')
# ('Epoch:', '0354', 'training time (minutes)=', '1.9854', 'loss=', '0.007932583')
# ('Epoch:', '0355', 'training time (minutes)=', '1.9876', 'loss=', '0.007954838')
# ('Epoch:', '0356', 'training time (minutes)=', '1.9770', 'loss=', '0.007928161')
# ('Epoch:', '0357', 'training time (minutes)=', '1.9788', 'loss=', '0.007937722')
# ('Epoch:', '0358', 'training time (minutes)=', '1.9803', 'loss=', '0.007941633')
# ('Epoch:', '0359', 'training time (minutes)=', '1.9816', 'loss=', '0.007932606')
# ('Epoch:', '0360', 'training time (minutes)=', '1.9795', 'loss=', '0.007947664')
# ('Epoch:', '0361', 'training time (minutes)=', '1.9840', 'loss=', '0.007920949')
# ('Epoch:', '0362', 'training time (minutes)=', '1.9841', 'loss=', '0.007931354')
# ('Epoch:', '0363', 'training time (minutes)=', '1.9812', 'loss=', '0.007934929')
# ('Epoch:', '0364', 'training time (minutes)=', '1.9816', 'loss=', '0.007930529')
# ('Epoch:', '0365', 'training time (minutes)=', '1.9859', 'loss=', '0.007921965')
# ('Epoch:', '0366', 'training time (minutes)=', '1.9827', 'loss=', '0.007946829')
# ('Epoch:', '0367', 'training time (minutes)=', '2.0206', 'loss=', '0.007950107')
# ('Epoch:', '0368', 'training time (minutes)=', '1.9913', 'loss=', '0.007943653')
# ('Epoch:', '0369', 'training time (minutes)=', '2.0323', 'loss=', '0.007909979')
# ('Epoch:', '0370', 'training time (minutes)=', '2.0356', 'loss=', '0.007932665')
# ('Epoch:', '0371', 'training time (minutes)=', '1.9978', 'loss=', '0.007928411')
# ('Epoch:', '0372', 'training time (minutes)=', '2.0421', 'loss=', '0.007953662')
# ('Epoch:', '0373', 'training time (minutes)=', '2.0057', 'loss=', '0.007904062')
# ('Epoch:', '0374', 'training time (minutes)=', '2.0080', 'loss=', '0.007970303')
# ('Epoch:', '0375', 'training time (minutes)=', '1.9984', 'loss=', '0.007929421')
# ('Epoch:', '0376', 'training time (minutes)=', '2.0037', 'loss=', '0.007925724')
# ('Epoch:', '0377', 'training time (minutes)=', '1.9960', 'loss=', '0.007948574')
# ('Epoch:', '0378', 'training time (minutes)=', '1.9970', 'loss=', '0.007936395')
# ('Epoch:', '0379', 'training time (minutes)=', '1.9892', 'loss=', '0.007932369')
# ('Epoch:', '0380', 'training time (minutes)=', '1.9935', 'loss=', '0.007937006')
# ('Epoch:', '0381', 'training time (minutes)=', '1.9875', 'loss=', '0.007921957')
# ('Epoch:', '0382', 'training time (minutes)=', '1.9936', 'loss=', '0.007938641')
# ('Epoch:', '0383', 'training time (minutes)=', '1.9888', 'loss=', '0.007932730')
# ('Epoch:', '0384', 'training time (minutes)=', '1.9926', 'loss=', '0.007925296')
# ('Epoch:', '0385', 'training time (minutes)=', '1.9905', 'loss=', '0.007970019')
# ('Epoch:', '0386', 'training time (minutes)=', '1.9868', 'loss=', '0.007916754')
# ('Epoch:', '0387', 'training time (minutes)=', '1.9981', 'loss=', '0.007942556')
# ('Epoch:', '0388', 'training time (minutes)=', '1.9873', 'loss=', '0.007946164')
# ('Epoch:', '0389', 'training time (minutes)=', '1.9945', 'loss=', '0.007911650')
# ('Epoch:', '0390', 'training time (minutes)=', '2.0306', 'loss=', '0.007940582')
# ('Epoch:', '0391', 'training time (minutes)=', '2.0764', 'loss=', '0.007932484')
# ('Epoch:', '0392', 'training time (minutes)=', '2.0049', 'loss=', '0.007946667')
# ('Epoch:', '0393', 'training time (minutes)=', '2.0001', 'loss=', '0.007946693')
# ('Epoch:', '0394', 'training time (minutes)=', '1.9893', 'loss=', '0.007924885')
# ('Epoch:', '0395', 'training time (minutes)=', '1.9974', 'loss=', '0.007933279')
# ('Epoch:', '0396', 'training time (minutes)=', '1.9856', 'loss=', '0.007948096')
# ('Epoch:', '0397', 'training time (minutes)=', '1.9971', 'loss=', '0.007928799')
# ('Epoch:', '0398', 'training time (minutes)=', '1.9989', 'loss=', '0.007944632')
# ('Epoch:', '0399', 'training time (minutes)=', '2.0472', 'loss=', '0.007929505')
# ('Epoch:', '0400', 'training time (minutes)=', '1.9941', 'loss=', '0.007924999')
# ('Epoch:', '0401', 'training time (minutes)=', '2.0053', 'loss=', '0.007939172')
# ('Epoch:', '0402', 'training time (minutes)=', '1.9931', 'loss=', '0.007949758')
# ('Epoch:', '0403', 'training time (minutes)=', '1.9951', 'loss=', '0.007926890')
# ('Epoch:', '0404', 'training time (minutes)=', '2.0475', 'loss=', '0.007940336')
# ('Epoch:', '0405', 'training time (minutes)=', '2.0119', 'loss=', '0.007908099')
# ('Epoch:', '0406', 'training time (minutes)=', '1.9984', 'loss=', '0.007968148')
# ('Epoch:', '0407', 'training time (minutes)=', '1.9921', 'loss=', '0.007910126')
# ('Epoch:', '0408', 'training time (minutes)=', '2.0183', 'loss=', '0.007955707')
# ('Epoch:', '0409', 'training time (minutes)=', '2.0058', 'loss=', '0.007937545')
# ('Epoch:', '0410', 'training time (minutes)=', '2.0110', 'loss=', '0.007933362')
# ('Epoch:', '0411', 'training time (minutes)=', '2.0023', 'loss=', '0.007929387')
# ('Epoch:', '0412', 'training time (minutes)=', '1.9974', 'loss=', '0.007949037')
# ('Epoch:', '0413', 'training time (minutes)=', '1.9920', 'loss=', '0.007914210')
# ('Epoch:', '0414', 'training time (minutes)=', '1.9988', 'loss=', '0.007928162')
# ('Epoch:', '0415', 'training time (minutes)=', '1.9942', 'loss=', '0.007938879')
# ('Epoch:', '0416', 'training time (minutes)=', '2.0090', 'loss=', '0.007941589')
# ('Epoch:', '0417', 'training time (minutes)=', '2.0122', 'loss=', '0.007950111')
# ('Epoch:', '0418', 'training time (minutes)=', '2.0013', 'loss=', '0.007936418')
# ('Epoch:', '0419', 'training time (minutes)=', '1.9905', 'loss=', '0.007922272')
# ('Epoch:', '0420', 'training time (minutes)=', '1.9958', 'loss=', '0.007940017')
# ('Epoch:', '0421', 'training time (minutes)=', '1.9924', 'loss=', '0.007950508')
# ('Epoch:', '0422', 'training time (minutes)=', '1.9879', 'loss=', '0.007917357')
# ('Epoch:', '0423', 'training time (minutes)=', '1.9935', 'loss=', '0.007939885')
# ('Epoch:', '0424', 'training time (minutes)=', '1.9963', 'loss=', '0.007918896')
# ('Epoch:', '0425', 'training time (minutes)=', '2.0151', 'loss=', '0.007956616')
# ('Epoch:', '0426', 'training time (minutes)=', '2.0629', 'loss=', '0.007937406')
# ('Epoch:', '0427', 'training time (minutes)=', '2.0045', 'loss=', '0.007923111')
# ('Epoch:', '0428', 'training time (minutes)=', '1.9841', 'loss=', '0.007945705')
# ('Epoch:', '0429', 'training time (minutes)=', '1.9917', 'loss=', '0.007925656')
# ('Epoch:', '0430', 'training time (minutes)=', '1.9905', 'loss=', '0.007932853')
# ('Epoch:', '0431', 'training time (minutes)=', '2.0012', 'loss=', '0.007950532')
# ('Epoch:', '0432', 'training time (minutes)=', '1.9904', 'loss=', '0.007907398')
# ('Epoch:', '0433', 'training time (minutes)=', '1.9927', 'loss=', '0.007954740')
# ('Epoch:', '0434', 'training time (minutes)=', '1.9859', 'loss=', '0.007920973')
# ('Epoch:', '0435', 'training time (minutes)=', '1.9918', 'loss=', '0.007955557')
# ('Epoch:', '0436', 'training time (minutes)=', '1.9847', 'loss=', '0.007921909')
# ('Epoch:', '0437', 'training time (minutes)=', '1.9883', 'loss=', '0.007933679')
# ('Epoch:', '0438', 'training time (minutes)=', '1.9943', 'loss=', '0.007935623')
# ('Epoch:', '0439', 'training time (minutes)=', '2.0055', 'loss=', '0.007935354')
# ('Epoch:', '0440', 'training time (minutes)=', '2.0068', 'loss=', '0.007944670')
# ('Epoch:', '0441', 'training time (minutes)=', '1.9987', 'loss=', '0.007926257')
# ('Epoch:', '0442', 'training time (minutes)=', '2.0133', 'loss=', '0.007946997')
# ('Epoch:', '0443', 'training time (minutes)=', '2.0029', 'loss=', '0.007920356')
# ('Epoch:', '0444', 'training time (minutes)=', '2.0117', 'loss=', '0.007938460')
# ('Epoch:', '0445', 'training time (minutes)=', '2.0041', 'loss=', '0.007930815')
# ('Epoch:', '0446', 'training time (minutes)=', '2.0043', 'loss=', '0.007960099')
# ('Epoch:', '0447', 'training time (minutes)=', '2.0029', 'loss=', '0.007939465')
# ('Epoch:', '0448', 'training time (minutes)=', '2.0031', 'loss=', '0.007923516')
# ('Epoch:', '0449', 'training time (minutes)=', '2.0047', 'loss=', '0.007954658')
# ('Epoch:', '0450', 'training time (minutes)=', '1.9996', 'loss=', '0.007914325')
# ('Epoch:', '0451', 'training time (minutes)=', '2.0042', 'loss=', '0.007935374')
# ('Epoch:', '0452', 'training time (minutes)=', '2.0028', 'loss=', '0.007934278')
# ('Epoch:', '0453', 'training time (minutes)=', '2.0036', 'loss=', '0.007942678')
# ('Epoch:', '0454', 'training time (minutes)=', '2.0042', 'loss=', '0.007941109')
# ('Epoch:', '0455', 'training time (minutes)=', '2.0056', 'loss=', '0.007936323')
# ('Epoch:', '0456', 'training time (minutes)=', '1.9988', 'loss=', '0.007920437')
# ('Epoch:', '0457', 'training time (minutes)=', '2.0048', 'loss=', '0.007923394')
# ('Epoch:', '0458', 'training time (minutes)=', '2.0020', 'loss=', '0.007937000')
# ('Epoch:', '0459', 'training time (minutes)=', '2.0065', 'loss=', '0.007938577')
# ('Epoch:', '0460', 'training time (minutes)=', '1.9992', 'loss=', '0.007945064')
# ('Epoch:', '0461', 'training time (minutes)=', '2.0057', 'loss=', '0.007924726')
# ('Epoch:', '0462', 'training time (minutes)=', '2.0028', 'loss=', '0.007941504')
# ('Epoch:', '0463', 'training time (minutes)=', '1.9964', 'loss=', '0.007953249')
# ('Epoch:', '0464', 'training time (minutes)=', '1.9979', 'loss=', '0.007916414')
# ('Epoch:', '0465', 'training time (minutes)=', '2.0047', 'loss=', '0.007930619')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-2e9afdfb1e57> in <module>()
#      28
#      29 vae = VariationalAutoencoder(experiment_name, conf)
# ---> 30 vae.train(train_data, conf)
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in train(self, train_data, configuration)
#     117             create_dir(c.train_dir)
#     118
# --> 119         for _ in xrange(c.training_epochs):
#     120             loss, duration = self._single_epoch_train(train_data, c)
#     121             epoch = int(self.sess.run(self.epoch.assign_add(tf.constant(1.0))))
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/vae.py in _single_epoch_train(self, train_data, configuration)
#     162                 loss, _ = self.partial_fit(batch_i_tmp, original_data)
#     163             else:
# --> 164                 loss, _ = self.partial_fit(batch_i_tmp)
#     165
#     166             # Compute average loss
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in partial_fit(self, X, GT)
#      95             _, loss, recon = self.sess.run((self.optimizer, self.loss, self.x_reconstr), feed_dict={self.x: X, self.gt: GT})
#      96         else:
# ---> 97             _, loss, recon = self.sess.run((self.optimizer, self.loss, self.x_reconstr), feed_dict={self.x: X})
#      98         return loss, recon
#      99
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
