# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.stats import hmean

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


import tf_lab.autopredictors.scripts.virt_scan_data as vscan

from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch
        
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion, save_reconstructions
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
incomplete_n_samples = 2048
complete_n_samples = 4096

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]

GPU = 1
exp_counter = '8'
loss = 'chamfer'
do_training = True
load_model_conf = False
do_evaluation = True

experiment_name = exp_counter + '_' + class_type + '_' + str(incomplete_n_samples) + '_' \
                  + str(complete_n_samples) + 'pts_' + loss

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
complete_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/not_scaled', \
                             str(complete_n_samples), class_syn_id)
    
n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3] 

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/paper_vanilla_vscan')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

if loss == 'emd':
    max_training_epochs = 100
elif loss == 'chamfer':
    max_training_epochs = 100
    
max_evaluation_epochs = max_training_epochs
# Out:
# Give me the class type.
# cabinet

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
cmpl_file_names = pio.load_filenames_of_input_data(complete_pclouds_path, points_extension)
cmpl_pclouds, cmpl_model_names, syn_ids = pio.load_crude_point_clouds(file_names=cmpl_file_names, n_threads=30)
assert(len(np.unique(syn_ids)) == 1)
print '%d files containing complete point clouds were found.' % (len(cmpl_pclouds), )
# Out:
# 1572 files containing complete point clouds were found.

# %%
v_scan_top_dir = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)

if do_training or do_evaluation:
    train_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/train_models_with_scan_id.txt')
    
    train_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, train_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=30,
                                                      n_samples=incomplete_n_samples)
    
    train_data, val_data = vscan.make_validation_from_train_data(train_data, 0.10)
    
if do_evaluation:
    test_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/test_models_with_scan_id.txt')
    test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=30,
                                                      n_samples=incomplete_n_samples)
# Out:
# 7800 incomplete point clouds were loaded.
# 1632 incomplete point clouds were loaded.

# %%
if load_model_conf:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)],
                    'non_linearity': tf.nn.relu
                   }

    encoder_args = {'dropout_prob': 0.5}
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 2,
                learning_rate = 0.0005,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.consistent_io = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
set_visible_GPUs([GPU])
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
training_stats = []
if do_training:
    training_stats.append(ae.train(train_data, conf))
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.5177', 'loss=', '0.002930284')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '0.6153', 'loss=', '0.001142402')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-2 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0003', 'training time (minutes)=', '0.6026', 'loss=', '0.001016444')
# ('Epoch:', '0004', 'training time (minutes)=', '0.5718', 'loss=', '0.000941974')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-4 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0005', 'training time (minutes)=', '0.6618', 'loss=', '0.000891551')
# ('Epoch:', '0006', 'training time (minutes)=', '0.6550', 'loss=', '0.000843591')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-6 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0007', 'training time (minutes)=', '0.6682', 'loss=', '0.000852577')
# ('Epoch:', '0008', 'training time (minutes)=', '0.5132', 'loss=', '0.000807734')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-8 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0009', 'training time (minutes)=', '0.5213', 'loss=', '0.000781018')
# ('Epoch:', '0010', 'training time (minutes)=', '0.6300', 'loss=', '0.000761462')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '0.5756', 'loss=', '0.000746756')
# ('Epoch:', '0012', 'training time (minutes)=', '0.5875', 'loss=', '0.000731215')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-12 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0013', 'training time (minutes)=', '0.5969', 'loss=', '0.000721802')
# ('Epoch:', '0014', 'training time (minutes)=', '0.5823', 'loss=', '0.000715690')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-14 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0015', 'training time (minutes)=', '0.5818', 'loss=', '0.000704485')
# ('Epoch:', '0016', 'training time (minutes)=', '0.6575', 'loss=', '0.000693579')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-16 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0017', 'training time (minutes)=', '0.5658', 'loss=', '0.000681606')
# ('Epoch:', '0018', 'training time (minutes)=', '0.5415', 'loss=', '0.000677390')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-18 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0019', 'training time (minutes)=', '0.5141', 'loss=', '0.000654018')
# ('Epoch:', '0020', 'training time (minutes)=', '0.5112', 'loss=', '0.000650276')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '0.5104', 'loss=', '0.000637221')
# ('Epoch:', '0022', 'training time (minutes)=', '0.5119', 'loss=', '0.000638236')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-22 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0023', 'training time (minutes)=', '0.5109', 'loss=', '0.000627707')
# ('Epoch:', '0024', 'training time (minutes)=', '0.5102', 'loss=', '0.000627116')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-24 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0025', 'training time (minutes)=', '0.5213', 'loss=', '0.000622297')
# ('Epoch:', '0026', 'training time (minutes)=', '0.5377', 'loss=', '0.000603279')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-26 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0027', 'training time (minutes)=', '0.5784', 'loss=', '0.000606575')
# ('Epoch:', '0028', 'training time (minutes)=', '0.5893', 'loss=', '0.000598542')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-28 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0029', 'training time (minutes)=', '0.5412', 'loss=', '0.000589348')
# ('Epoch:', '0030', 'training time (minutes)=', '0.5168', 'loss=', '0.000583331')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '0.5404', 'loss=', '0.000595449')
# ('Epoch:', '0032', 'training time (minutes)=', '0.6967', 'loss=', '0.000589720')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-32 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0033', 'training time (minutes)=', '0.5844', 'loss=', '0.000578805')
# ('Epoch:', '0034', 'training time (minutes)=', '0.5113', 'loss=', '0.000563083')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-34 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0035', 'training time (minutes)=', '0.5093', 'loss=', '0.000560098')
# ('Epoch:', '0036', 'training time (minutes)=', '0.5100', 'loss=', '0.000557786')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-36 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0037', 'training time (minutes)=', '0.5098', 'loss=', '0.000559788')
# ('Epoch:', '0038', 'training time (minutes)=', '0.5116', 'loss=', '0.000556172')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-38 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0039', 'training time (minutes)=', '0.5127', 'loss=', '0.000539451')
# ('Epoch:', '0040', 'training time (minutes)=', '0.5128', 'loss=', '0.000534695')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '0.5119', 'loss=', '0.000536509')
# ('Epoch:', '0042', 'training time (minutes)=', '0.6548', 'loss=', '0.000536135')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-42 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0043', 'training time (minutes)=', '0.5479', 'loss=', '0.000533395')
# ('Epoch:', '0044', 'training time (minutes)=', '0.5136', 'loss=', '0.000524538')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-44 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0045', 'training time (minutes)=', '0.5125', 'loss=', '0.000517076')
# ('Epoch:', '0046', 'training time (minutes)=', '0.5134', 'loss=', '0.000516354')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-46 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0047', 'training time (minutes)=', '0.6502', 'loss=', '0.000507985')
# ('Epoch:', '0048', 'training time (minutes)=', '0.6581', 'loss=', '0.000504957')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-48 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0049', 'training time (minutes)=', '0.5751', 'loss=', '0.000505905')
# ('Epoch:', '0050', 'training time (minutes)=', '0.5134', 'loss=', '0.000510913')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '0.5636', 'loss=', '0.000496911')
# ('Epoch:', '0052', 'training time (minutes)=', '0.5105', 'loss=', '0.000494923')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-52 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0053', 'training time (minutes)=', '0.5097', 'loss=', '0.000491308')
# ('Epoch:', '0054', 'training time (minutes)=', '0.5326', 'loss=', '0.000487834')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-54 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0055', 'training time (minutes)=', '0.5372', 'loss=', '0.000484545')
# ('Epoch:', '0056', 'training time (minutes)=', '0.5101', 'loss=', '0.000483742')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-56 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0057', 'training time (minutes)=', '0.5098', 'loss=', '0.000474205')
# ('Epoch:', '0058', 'training time (minutes)=', '0.5075', 'loss=', '0.000477411')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-58 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0059', 'training time (minutes)=', '0.5101', 'loss=', '0.000475868')
# ('Epoch:', '0060', 'training time (minutes)=', '0.5085', 'loss=', '0.000475002')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '0.5098', 'loss=', '0.000467710')
# ('Epoch:', '0062', 'training time (minutes)=', '0.5082', 'loss=', '0.000460029')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0063', 'training time (minutes)=', '0.5102', 'loss=', '0.000460808')
# ('Epoch:', '0064', 'training time (minutes)=', '0.5414', 'loss=', '0.000454514')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0065', 'training time (minutes)=', '0.5504', 'loss=', '0.000454860')
# ('Epoch:', '0066', 'training time (minutes)=', '0.5109', 'loss=', '0.000453644')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0067', 'training time (minutes)=', '0.5203', 'loss=', '0.000447998')
# ('Epoch:', '0068', 'training time (minutes)=', '0.5093', 'loss=', '0.000443518')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0069', 'training time (minutes)=', '0.5088', 'loss=', '0.000446577')
# ('Epoch:', '0070', 'training time (minutes)=', '0.5095', 'loss=', '0.000438373')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '0.5114', 'loss=', '0.000429352')
# ('Epoch:', '0072', 'training time (minutes)=', '0.5106', 'loss=', '0.000432951')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0073', 'training time (minutes)=', '0.5124', 'loss=', '0.000432946')
# ('Epoch:', '0074', 'training time (minutes)=', '0.5093', 'loss=', '0.000426815')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0075', 'training time (minutes)=', '0.5083', 'loss=', '0.000427006')
# ('Epoch:', '0076', 'training time (minutes)=', '0.5093', 'loss=', '0.000421559')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0077', 'training time (minutes)=', '0.5104', 'loss=', '0.000423072')
# ('Epoch:', '0078', 'training time (minutes)=', '0.5115', 'loss=', '0.000416332')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0079', 'training time (minutes)=', '0.5756', 'loss=', '0.000415367')
# ('Epoch:', '0080', 'training time (minutes)=', '0.6204', 'loss=', '0.000407511')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '0.5528', 'loss=', '0.000404883')
# ('Epoch:', '0082', 'training time (minutes)=', '0.7284', 'loss=', '0.000405998')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0083', 'training time (minutes)=', '0.6314', 'loss=', '0.000411137')
# ('Epoch:', '0084', 'training time (minutes)=', '0.5123', 'loss=', '0.000403848')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0085', 'training time (minutes)=', '0.5115', 'loss=', '0.000401884')
# ('Epoch:', '0086', 'training time (minutes)=', '0.5103', 'loss=', '0.000395496')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0087', 'training time (minutes)=', '0.5103', 'loss=', '0.000394993')
# ('Epoch:', '0088', 'training time (minutes)=', '0.5097', 'loss=', '0.000396605')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0089', 'training time (minutes)=', '0.5086', 'loss=', '0.000389703')
# ('Epoch:', '0090', 'training time (minutes)=', '0.5109', 'loss=', '0.000389288')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '0.5112', 'loss=', '0.000390562')
# ('Epoch:', '0092', 'training time (minutes)=', '0.5145', 'loss=', '0.000380356')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-92 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0093', 'training time (minutes)=', '0.7631', 'loss=', '0.000380354')
# ('Epoch:', '0094', 'training time (minutes)=', '0.5435', 'loss=', '0.000390011')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-94 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0095', 'training time (minutes)=', '0.6246', 'loss=', '0.000381000')
# ('Epoch:', '0096', 'training time (minutes)=', '0.5632', 'loss=', '0.000374100')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-96 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0097', 'training time (minutes)=', '0.5542', 'loss=', '0.000368294')
# ('Epoch:', '0098', 'training time (minutes)=', '0.5097', 'loss=', '0.000374828')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-98 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0099', 'training time (minutes)=', '0.5108', 'loss=', '0.000368922')
# ('Epoch:', '0100', 'training time (minutes)=', '0.5126', 'loss=', '0.000369889')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/8_cabinet_2048_4096pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.

# %%
if do_evaluation:
    # Pick the epoch that minimizes the loss on the validation dataset.
    saved_epochs = np.array(read_saved_epochs(conf.train_dir))
    allowable_epochs = saved_epochs[saved_epochs <= max_evaluation_epochs]
    val_stats = eval_model(ae, conf, val_data, epochs=allowable_epochs, verbose=True)
    val_loss = np.min(val_stats[:,1])
    best_epoch = int(val_stats[np.argmin(val_stats[:,1]), 0])
    print 'Best epoch = %d.' % (best_epoch,) 
        
    ae.restore_model(conf.train_dir, best_epoch)
    top_save_dir = osp.join(conf.train_dir, 'output', 'epoch_' + str(best_epoch))
    save_dir = osp.join(top_save_dir, 'test_predictions')
    test_recon, test_loss, test_feed, test_ids, test_gt = ae.evaluate(test_data, conf)
    save_reconstructions(save_dir, test_recon, test_gt, test_feed, test_ids) # save ply files of test data.    
    train_loss = ae.evaluate(train_data, conf)[1]
    
    # Report Accuracy and Coverage of test data.
    n_examples = len(test_recon)
    pred_scores = np.zeros((n_examples, 2))
    for i in xrange(n_examples):
        gt = test_gt[i]
        pred = test_recon[i]    
        pred_scores[i, 0] = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=False)
        pred_scores[i, 1] = coverage_of_completion(gt, pred, thres=0.02, ret_dists=False)
    
    print 'Test Median-Accuracy-Coverage:', np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])
    
    with open(osp.join(top_save_dir, 'stats.txt'), 'w') as fout:
        fout.write('Best Validation Epoch = %d\n' % (best_epoch))
        fout.write('Validation loss = %f\n' % (val_loss))
        fout.write('Train loss = %f\n' % (train_loss))
        fout.write('Test loss = %f\n' % (test_loss))
        fout.write('Gen. Error (abs, per) = %f %f\n' % (abs(test_loss-train_loss),  abs(test_loss-train_loss) / train_loss ))
        fout.write('Test Median-Accuracy-Coverage = %f %f\n' % (np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])))
        fout.write('Test Median Harmonic Mean = %f' % (np.median(hmean(pred_scores, 1))))
# Out:
# Model restored in epoch 1.
# [ 0.00121307]
# Model restored in epoch 2.
# [ 0.00098725]
# Model restored in epoch 4.
# [ 0.00089588]
# Model restored in epoch 6.
# [ 0.00083262]
# Model restored in epoch 8.
# [ 0.00078957]
# Model restored in epoch 10.
# [ 0.00074328]
# Model restored in epoch 12.
# [ 0.00072524]
# Model restored in epoch 14.
# [ 0.00074393]
# Model restored in epoch 16.
# [ 0.00072543]
# Model restored in epoch 18.
# [ 0.0007348]
# Model restored in epoch 20.
# [ 0.00069372]
# Model restored in epoch 22.
# [ 0.00076039]
# Model restored in epoch 24.
# [ 0.00068141]
# Model restored in epoch 26.
# [ 0.00066163]
# Model restored in epoch 28.
# [ 0.00067283]
# Model restored in epoch 30.
# [ 0.00064819]
# Model restored in epoch 32.
# [ 0.00066618]
# Model restored in epoch 34.
# [ 0.00064348]
# Model restored in epoch 36.
# [ 0.00064835]
# Model restored in epoch 38.
# [ 0.00064049]
# Model restored in epoch 40.
# [ 0.00063463]
# Model restored in epoch 42.
# [ 0.00062541]
# Model restored in epoch 44.
# [ 0.00062893]
# Model restored in epoch 46.
# [ 0.00065016]
# Model restored in epoch 48.
# [ 0.00062048]
# Model restored in epoch 50.
# [ 0.00063789]
# Model restored in epoch 52.
# [ 0.00061579]
# Model restored in epoch 54.
# [ 0.0006195]
# Model restored in epoch 56.
# [ 0.00062499]
# Model restored in epoch 58.
# [ 0.00062097]
# Model restored in epoch 60.
# [ 0.000611]
# Model restored in epoch 62.
# [ 0.00062167]
# Model restored in epoch 64.
# [ 0.00061663]
# Model restored in epoch 66.
# [ 0.00060997]
# Model restored in epoch 68.
# [ 0.00061972]
# Model restored in epoch 70.
# [ 0.00060568]
# Model restored in epoch 72.
# [ 0.0006243]
# Model restored in epoch 74.
# [ 0.00062733]
# Model restored in epoch 76.
# [ 0.00061806]
# Model restored in epoch 78.
# [ 0.00060617]
# Model restored in epoch 80.
# [ 0.00061203]
# Model restored in epoch 82.
# [ 0.00061142]
# Model restored in epoch 84.
# [ 0.00061767]
# Model restored in epoch 86.
# [ 0.00060429]
# Model restored in epoch 88.
# [ 0.00062636]
# Model restored in epoch 90.
# [ 0.00059937]
# Model restored in epoch 92.
# [ 0.00060357]
# Model restored in epoch 94.
# [ 0.00061801]
# Model restored in epoch 96.
# [ 0.0006052]
# Model restored in epoch 98.
# [ 0.00063253]
# Model restored in epoch 100.
# [ 0.00061497]
# Best epoch = 90.
# Test Median-Accuracy-Coverage: 0.872192382812 0.8486328125
