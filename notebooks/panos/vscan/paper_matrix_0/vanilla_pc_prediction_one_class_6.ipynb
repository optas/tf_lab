# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


import tf_lab.autopredictors.scripts.virt_scan_data as vscan

from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch
        
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion, save_reconstructions
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
incomplete_n_samples = 2048
complete_n_samples = 4096

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]

GPU = 0
exp_counter = '7'
loss = 'emd'
do_training = True
load_model_conf = False
do_evaluation = True

experiment_name = exp_counter + '_' + class_type + '_' + str(incomplete_n_samples) + '_' \
                  + str(complete_n_samples) + 'pts_' + loss

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
complete_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/not_scaled', \
                             str(complete_n_samples), class_syn_id)
    
n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3] 

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/paper_vanilla_vscan')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

if loss == 'emd':
    max_training_epochs = 100
elif loss == 'chamfer':
    max_training_epochs = 200
    
max_evaluation_epochs = max_training_epochs
# Out:
# Give me the class type.
# sofa

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
cmpl_file_names = pio.load_filenames_of_input_data(complete_pclouds_path, points_extension)
cmpl_pclouds, cmpl_model_names, syn_ids = pio.load_crude_point_clouds(file_names=cmpl_file_names, n_threads=30)
assert(len(np.unique(syn_ids)) == 1)
print '%d files containing complete point clouds were found.' % (len(cmpl_pclouds), )
# Out:
# 3173 files containing complete point clouds were found.

# %%
v_scan_top_dir = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)

if do_training or do_evaluation:
    train_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/train_models_with_scan_id.txt')
    
    train_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, train_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=30,
                                                      n_samples=incomplete_n_samples)
    
    train_data, val_data = vscan.make_validation_from_train_data(train_data, 0.10)
    
if do_evaluation:
    test_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/test_models_with_scan_id.txt')
    test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=30,
                                                      n_samples=incomplete_n_samples)
# Out:
# 15600 incomplete point clouds were loaded.
# 3438 incomplete point clouds were loaded.

# %%
if load_model_conf:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)],
                    'non_linearity': tf.nn.relu
                   }

    encoder_args = {'dropout_prob': 0.5}
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 2,
                learning_rate = 0.0005,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.consistent_io = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
set_visible_GPUs([GPU])
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
training_stats = []
if do_training:
    training_stats.append(ae.train(train_data, conf))
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '2.5658', 'loss=', '295.930865097')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '2.5887', 'loss=', '232.686226600')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-2 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0003', 'training time (minutes)=', '2.5932', 'loss=', '222.087229156')
# ('Epoch:', '0004', 'training time (minutes)=', '2.5916', 'loss=', '214.734638105')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-4 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0005', 'training time (minutes)=', '2.5903', 'loss=', '210.343441881')
# ('Epoch:', '0006', 'training time (minutes)=', '2.5875', 'loss=', '206.548802948')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-6 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0007', 'training time (minutes)=', '2.5914', 'loss=', '203.890271487')
# ('Epoch:', '0008', 'training time (minutes)=', '2.5875', 'loss=', '201.714368057')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-8 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0009', 'training time (minutes)=', '2.5903', 'loss=', '199.546829387')
# ('Epoch:', '0010', 'training time (minutes)=', '2.5883', 'loss=', '197.291303689')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '2.5913', 'loss=', '195.853749902')
# ('Epoch:', '0012', 'training time (minutes)=', '2.5853', 'loss=', '194.346730859')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-12 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0013', 'training time (minutes)=', '2.5907', 'loss=', '193.620162528')
# ('Epoch:', '0014', 'training time (minutes)=', '2.5934', 'loss=', '191.656313814')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-14 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0015', 'training time (minutes)=', '2.5940', 'loss=', '190.906553813')
# ('Epoch:', '0016', 'training time (minutes)=', '2.5933', 'loss=', '189.046080453')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-16 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0017', 'training time (minutes)=', '2.5884', 'loss=', '188.278312465')
# ('Epoch:', '0018', 'training time (minutes)=', '2.5887', 'loss=', '187.404597800')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-18 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0019', 'training time (minutes)=', '2.5866', 'loss=', '185.951784842')
# ('Epoch:', '0020', 'training time (minutes)=', '2.5832', 'loss=', '185.381881441')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '2.5812', 'loss=', '184.196559961')
# ('Epoch:', '0022', 'training time (minutes)=', '2.5850', 'loss=', '182.565639278')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-22 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0023', 'training time (minutes)=', '2.5834', 'loss=', '182.524286979')
# ('Epoch:', '0024', 'training time (minutes)=', '2.5874', 'loss=', '181.274365343')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-24 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0025', 'training time (minutes)=', '2.5867', 'loss=', '181.321825354')
# ('Epoch:', '0026', 'training time (minutes)=', '2.5826', 'loss=', '179.710896519')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-26 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0027', 'training time (minutes)=', '2.5811', 'loss=', '178.322508785')
# ('Epoch:', '0028', 'training time (minutes)=', '2.5860', 'loss=', '178.368114853')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-28 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0029', 'training time (minutes)=', '2.5866', 'loss=', '177.045885577')
# ('Epoch:', '0030', 'training time (minutes)=', '2.5836', 'loss=', '175.807382911')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '2.5829', 'loss=', '175.182117844')
# ('Epoch:', '0032', 'training time (minutes)=', '2.5821', 'loss=', '174.648991067')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-32 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0033', 'training time (minutes)=', '2.5872', 'loss=', '174.241535459')
# ('Epoch:', '0034', 'training time (minutes)=', '2.5843', 'loss=', '173.127155031')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-34 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0035', 'training time (minutes)=', '2.5839', 'loss=', '172.170909773')
# ('Epoch:', '0036', 'training time (minutes)=', '2.5864', 'loss=', '171.302555629')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-36 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0037', 'training time (minutes)=', '2.5860', 'loss=', '170.752325058')
# ('Epoch:', '0038', 'training time (minutes)=', '2.5871', 'loss=', '170.301666914')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-38 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0039', 'training time (minutes)=', '2.5848', 'loss=', '169.755984715')
# ('Epoch:', '0040', 'training time (minutes)=', '2.5839', 'loss=', '168.951127679')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '2.5846', 'loss=', '167.837803704')
# ('Epoch:', '0042', 'training time (minutes)=', '2.5847', 'loss=', '167.013677597')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-42 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0043', 'training time (minutes)=', '2.5823', 'loss=', '166.847658375')
# ('Epoch:', '0044', 'training time (minutes)=', '2.5857', 'loss=', '166.467687879')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-44 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0045', 'training time (minutes)=', '2.5822', 'loss=', '165.552924347')
# ('Epoch:', '0046', 'training time (minutes)=', '2.5842', 'loss=', '164.752445875')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-46 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0047', 'training time (minutes)=', '2.5831', 'loss=', '164.690917860')
# ('Epoch:', '0048', 'training time (minutes)=', '2.5822', 'loss=', '163.335960388')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-48 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0049', 'training time (minutes)=', '2.5859', 'loss=', '162.937609264')
# ('Epoch:', '0050', 'training time (minutes)=', '2.5831', 'loss=', '162.814013563')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '2.5868', 'loss=', '162.306802804')
# ('Epoch:', '0052', 'training time (minutes)=', '2.5835', 'loss=', '161.206058775')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-52 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0053', 'training time (minutes)=', '2.5845', 'loss=', '161.122770309')
# ('Epoch:', '0054', 'training time (minutes)=', '2.5833', 'loss=', '160.616712570')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-54 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0055', 'training time (minutes)=', '2.5852', 'loss=', '159.815140261')
# ('Epoch:', '0056', 'training time (minutes)=', '2.5837', 'loss=', '159.673084858')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-56 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0057', 'training time (minutes)=', '2.5845', 'loss=', '159.146809878')
# ('Epoch:', '0058', 'training time (minutes)=', '2.5829', 'loss=', '158.488569532')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-58 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0059', 'training time (minutes)=', '2.5850', 'loss=', '157.666119603')
# ('Epoch:', '0060', 'training time (minutes)=', '2.5815', 'loss=', '157.869238881')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '2.5863', 'loss=', '156.973740441')
# ('Epoch:', '0062', 'training time (minutes)=', '2.5833', 'loss=', '156.681536811')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0063', 'training time (minutes)=', '2.5891', 'loss=', '156.128474753')
# ('Epoch:', '0064', 'training time (minutes)=', '2.5843', 'loss=', '155.882291085')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0065', 'training time (minutes)=', '2.5876', 'loss=', '155.263772692')
# ('Epoch:', '0066', 'training time (minutes)=', '2.5927', 'loss=', '155.313811820')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0067', 'training time (minutes)=', '2.6061', 'loss=', '154.750917108')
# ('Epoch:', '0068', 'training time (minutes)=', '2.5984', 'loss=', '154.227862658')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0069', 'training time (minutes)=', '2.6088', 'loss=', '153.712311608')
# ('Epoch:', '0070', 'training time (minutes)=', '2.6268', 'loss=', '153.718711690')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '2.6275', 'loss=', '153.378885869')
# ('Epoch:', '0072', 'training time (minutes)=', '2.6403', 'loss=', '152.689915085')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0073', 'training time (minutes)=', '2.6349', 'loss=', '152.707869230')
# ('Epoch:', '0074', 'training time (minutes)=', '2.6206', 'loss=', '152.126211602')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0075', 'training time (minutes)=', '2.6190', 'loss=', '151.398274067')
# ('Epoch:', '0076', 'training time (minutes)=', '2.6253', 'loss=', '151.031725311')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0077', 'training time (minutes)=', '2.6441', 'loss=', '150.999665342')
# ('Epoch:', '0078', 'training time (minutes)=', '2.6217', 'loss=', '150.755088316')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0079', 'training time (minutes)=', '2.6501', 'loss=', '150.292746026')
# ('Epoch:', '0080', 'training time (minutes)=', '2.6351', 'loss=', '150.128284400')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '2.6238', 'loss=', '149.582254900')
# ('Epoch:', '0082', 'training time (minutes)=', '2.6230', 'loss=', '149.783479364')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0083', 'training time (minutes)=', '2.6244', 'loss=', '149.060305350')
# ('Epoch:', '0084', 'training time (minutes)=', '2.6415', 'loss=', '148.829747445')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0085', 'training time (minutes)=', '2.6219', 'loss=', '148.179792186')
# ('Epoch:', '0086', 'training time (minutes)=', '2.6238', 'loss=', '148.480566297')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0087', 'training time (minutes)=', '2.6246', 'loss=', '147.881944493')
# ('Epoch:', '0088', 'training time (minutes)=', '2.6230', 'loss=', '147.512988281')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0089', 'training time (minutes)=', '2.6470', 'loss=', '147.190505164')
# ('Epoch:', '0090', 'training time (minutes)=', '2.6188', 'loss=', '146.866369520')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '2.6373', 'loss=', '146.857998112')
# ('Epoch:', '0092', 'training time (minutes)=', '2.6447', 'loss=', '146.626537323')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-92 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0093', 'training time (minutes)=', '2.6265', 'loss=', '146.401361520')
# ('Epoch:', '0094', 'training time (minutes)=', '2.6193', 'loss=', '145.859669168')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-94 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0095', 'training time (minutes)=', '2.6259', 'loss=', '145.776236616')
# ('Epoch:', '0096', 'training time (minutes)=', '2.6287', 'loss=', '145.976211493')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-96 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0097', 'training time (minutes)=', '2.6470', 'loss=', '145.308151082')
# ('Epoch:', '0098', 'training time (minutes)=', '2.6226', 'loss=', '145.145416805')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-98 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0099', 'training time (minutes)=', '2.6319', 'loss=', '144.616740581')
# ('Epoch:', '0100', 'training time (minutes)=', '2.6289', 'loss=', '144.468375015')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/7_sofa_2048_4096pts_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.

# %%
if do_evaluation:
    # Pick the epoch that minimizes the loss on the validation dataset.
#     n_epochs = 25 # Consider only 'n_epochs' equally spaced epochs from those that are saved.
    saved_epochs = np.array(read_saved_epochs(conf.train_dir))
    allowable_epochs = saved_epochs[saved_epochs <= max_evaluation_epochs]
#     allowable_epochs = select_first_last_and_k(allowable_epochs, n_epochs-2)
    val_stats = eval_model(ae, conf, val_data, epochs=allowable_epochs, verbose=True)
    val_loss = np.min(val_stats[:,1])
    best_epoch = int(val_stats[np.argmin(val_stats[:,1]), 0])
    print 'Best epoch = %d.' % (best_epoch,) 
        
    ae.restore_model(conf.train_dir, best_epoch)
    top_save_dir = osp.join(conf.train_dir, 'output', 'epoch_' + str(best_epoch))
    save_dir = osp.join(top_save_dir, 'test_predictions')
    test_recon, test_loss, test_feed, test_ids, test_gt = ae.evaluate(test_data, conf)
    save_reconstructions(save_dir, test_recon, test_gt, test_feed, test_ids) # save ply files of test data.    
    train_loss = ae.evaluate(train_data, conf)[1]
    
    # Report Accuracy and Coverage of test data.
    n_examples = len(test_recon)
    pred_scores = np.zeros((n_examples, 2))
    for i in xrange(n_examples):
        gt = test_gt[i]
        pred = test_recon[i]    
        pred_scores[i, 0] = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=False)
        pred_scores[i, 1] = coverage_of_completion(gt, pred, thres=0.02, ret_dists=False)
    
    print 'Test Median-Accuracy-Coverage:', np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])
    
    with open(osp.join(top_save_dir, 'stats.txt'), 'w') as fout:
        fout.write('Best Validation Epoch = %d\n' % (best_epoch))
        fout.write('Validation loss = %f\n' % (val_loss))
        fout.write('Train loss = %f\n' % (train_loss))
        fout.write('Test loss = %f\n' % (test_loss))
        fout.write('Gen. Error (abs, per) = %f %f\n' % (abs(test_loss-train_loss),  abs(test_loss-train_loss) / train_loss ))
        fout.write('Test Median-Accuracy-Coverage = %f %f\n' % (np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])))
# Out:
# Model restored in epoch 1.
# [ 244.97679441]
# Model restored in epoch 2.
# [ 229.90584193]
# Model restored in epoch 4.
# [ 221.04132735]
# Model restored in epoch 6.
# [ 210.03289922]
# Model restored in epoch 8.
# [ 212.38862228]
# Model restored in epoch 10.
# [ 206.90413676]
# Model restored in epoch 12.
# [ 199.17181152]
# Model restored in epoch 14.
# [ 200.77904002]
# Model restored in epoch 16.
# [ 198.23553134]
# Model restored in epoch 18.
# [ 198.17442429]
# Model restored in epoch 20.
# [ 202.55570994]
# Model restored in epoch 22.
# [ 197.55547255]
# Model restored in epoch 24.
# [ 195.4221703]
# Model restored in epoch 26.
# [ 192.85441951]
# Model restored in epoch 28.
# [ 193.11246901]
# Model restored in epoch 30.
# [ 191.85883458]
# Model restored in epoch 32.
# [ 200.31713662]
# Model restored in epoch 34.
# [ 193.0472149]
# Model restored in epoch 36.
# [ 191.73059718]
# Model restored in epoch 38.
# [ 190.96136064]
# Model restored in epoch 40.
# [ 193.69695976]
# Model restored in epoch 42.
# [ 191.37624408]
# Model restored in epoch 44.
# [ 189.80433978]
# Model restored in epoch 46.
# [ 190.92010968]
# Model restored in epoch 48.
# [ 190.05543919]
# Model restored in epoch 50.
# [ 190.59281667]
# Model restored in epoch 52.
# [ 189.88241968]
# Model restored in epoch 54.
# [ 189.99609473]
# Model restored in epoch 56.
# [ 191.82065915]
# Model restored in epoch 58.
# [ 191.29825905]
# Model restored in epoch 60.
# [ 189.545654]
# Model restored in epoch 62.
# [ 190.54315587]
# Model restored in epoch 64.
# [ 190.83226571]
# Model restored in epoch 66.
# [ 192.79893709]
# Model restored in epoch 68.
# [ 190.72221991]
# Model restored in epoch 70.
# [ 189.98130984]
# Model restored in epoch 72.
# [ 190.9597479]
# Model restored in epoch 74.
# [ 189.33036931]
# Model restored in epoch 76.
# [ 191.2444459]
# Model restored in epoch 78.
# [ 191.31854903]
# Model restored in epoch 80.
# [ 194.10590832]
# Model restored in epoch 82.
# [ 193.55299182]
# Model restored in epoch 84.
# [ 191.91216493]
# Model restored in epoch 86.
# [ 192.37645379]
# Model restored in epoch 88.
# [ 190.59786625]
# Model restored in epoch 90.
# [ 192.0338794]
# Model restored in epoch 92.
# [ 191.95774685]
# Model restored in epoch 94.
# [ 191.94672942]
# Model restored in epoch 96.
# [ 190.36529336]
# Model restored in epoch 98.
# [ 192.28795193]
# Model restored in epoch 100.
# [ 193.11765485]
# Best epoch = 74.
# Test Median-Accuracy-Coverage: 0.829345703125 0.851806640625
