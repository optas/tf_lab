# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


import tf_lab.autopredictors.scripts.virt_scan_data as vscan

from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch
        
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/point_clouds/point_cloud.py:20: UserWarning: Sklearn library is not installed.
#   warnings.warn('Sklearn library is not installed.')
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/autopredictors/evaluate.py:9: UserWarning: Sklearn library is not installed.
#   warnings.warn('Sklearn library is not installed.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
incomplete_n_samples = 2048
complete_n_samples = 4096

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]

GPU = 1
exp_counter = '5'
loss = 'emd'
do_training = True
first_time_running = True
load_model = False
do_test = False
do_plotting = False
training_epochs = 1000

experiment_name = exp_counter + '_' + class_type + '_' + str(incomplete_n_samples) + '_' + str(complete_n_samples) + 'pts_' + loss
top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
complete_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/', \
                             str(complete_n_samples), class_syn_id)
    
n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3] 

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/paper_vanilla_vscan')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# Give me the class type.
# sofa
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd'

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
cmpl_file_names = pio.load_filenames_of_input_data(complete_pclouds_path, points_extension)
cmpl_pclouds, cmpl_model_names, syn_ids = pio.load_crude_point_clouds(file_names=cmpl_file_names, n_threads=25)
assert(len(np.unique(syn_ids)) == 1)
print '%d files containing complete point clouds were found.' % (len(cmpl_pclouds), )
# Out:
# 3173 files containing complete point clouds were found.

# %%
v_scan_top_dir = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)
if do_training:    
    train_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/train_models_with_scan_id.txt')
    
    train_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, train_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=25,
                                                      n_samples=incomplete_n_samples)
    
    train_data, val_data = vscan.make_validation_from_train_data(train_data, 0.10)
# Out:
# 15600 incomplete point clouds were loaded.

# %%
if do_test:
    test_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/test_models_with_scan_id.txt')
    test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id, 
                                                      cmpl_pclouds, cmpl_model_names, n_threads=25,
                                                      n_samples=incomplete_n_samples, search_pattern=search_pattern)

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)],
                    'non_linearity': tf.nn.relu
                   }
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 5,
                learning_rate = 0.0005,
                gauss_augment = {'mu': 0, 'sigma': 0.02},
                encoder = enc_dec.encoder_with_convs_and_symmetry,                
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.consistent_io = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

# %%
reset_tf_graph()
set_visible_GPUs([GPU])
ae = PointNetAutoEncoder(experiment_name, conf)

if do_training:
    ae.train(train_data, conf)

if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    ae.restore_model(train_dir, saved_epochs[-1], verbose=True)
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '2.6578', 'loss=', '263.472440393')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '2.7329', 'loss=', '221.050296075')
# ('Epoch:', '0003', 'training time (minutes)=', '2.6963', 'loss=', '212.384736361')
# ('Epoch:', '0004', 'training time (minutes)=', '2.6881', 'loss=', '208.285724640')
# ('Epoch:', '0005', 'training time (minutes)=', '2.7197', 'loss=', '205.582844325')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-5 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0006', 'training time (minutes)=', '2.6914', 'loss=', '201.881881496')
# ('Epoch:', '0007', 'training time (minutes)=', '2.7612', 'loss=', '200.101896504')
# ('Epoch:', '0008', 'training time (minutes)=', '2.6916', 'loss=', '198.116070448')
# ('Epoch:', '0009', 'training time (minutes)=', '2.6858', 'loss=', '197.290841893')
# ('Epoch:', '0010', 'training time (minutes)=', '2.6917', 'loss=', '196.295732226')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '2.6998', 'loss=', '195.241807066')
# ('Epoch:', '0012', 'training time (minutes)=', '2.7026', 'loss=', '193.738033676')
# ('Epoch:', '0013', 'training time (minutes)=', '2.6921', 'loss=', '192.334675435')
# ('Epoch:', '0014', 'training time (minutes)=', '2.6993', 'loss=', '191.209713146')
# ('Epoch:', '0015', 'training time (minutes)=', '2.6926', 'loss=', '189.849731118')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-15 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0016', 'training time (minutes)=', '2.7157', 'loss=', '190.145455224')
# ('Epoch:', '0017', 'training time (minutes)=', '2.7228', 'loss=', '188.917423684')
# ('Epoch:', '0018', 'training time (minutes)=', '2.7043', 'loss=', '188.634816306')
# ('Epoch:', '0019', 'training time (minutes)=', '2.7085', 'loss=', '188.776351547')
# ('Epoch:', '0020', 'training time (minutes)=', '2.7176', 'loss=', '186.894956425')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '2.6963', 'loss=', '187.056827164')
# ('Epoch:', '0022', 'training time (minutes)=', '2.6938', 'loss=', '185.418630545')
# ('Epoch:', '0023', 'training time (minutes)=', '2.6923', 'loss=', '185.553222002')
# ('Epoch:', '0024', 'training time (minutes)=', '2.6908', 'loss=', '184.510281917')
# ('Epoch:', '0025', 'training time (minutes)=', '2.7099', 'loss=', '183.994759369')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-25 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0026', 'training time (minutes)=', '2.6971', 'loss=', '183.192760740')
# ('Epoch:', '0027', 'training time (minutes)=', '2.7009', 'loss=', '182.858378819')
# ('Epoch:', '0028', 'training time (minutes)=', '2.6961', 'loss=', '182.117975834')
# ('Epoch:', '0029', 'training time (minutes)=', '2.7037', 'loss=', '181.177631651')
# ('Epoch:', '0030', 'training time (minutes)=', '2.7152', 'loss=', '180.886275482')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '2.6908', 'loss=', '180.556655775')
# ('Epoch:', '0032', 'training time (minutes)=', '2.6922', 'loss=', '179.381288474')
# ('Epoch:', '0033', 'training time (minutes)=', '2.7052', 'loss=', '179.577429145')
# ('Epoch:', '0034', 'training time (minutes)=', '2.6918', 'loss=', '179.339520863')
# ('Epoch:', '0035', 'training time (minutes)=', '2.7126', 'loss=', '179.205402156')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-35 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0036', 'training time (minutes)=', '2.7024', 'loss=', '177.778830828')
# ('Epoch:', '0037', 'training time (minutes)=', '2.6894', 'loss=', '177.627428654')
# ('Epoch:', '0038', 'training time (minutes)=', '2.6876', 'loss=', '176.720469393')
# ('Epoch:', '0039', 'training time (minutes)=', '2.7069', 'loss=', '176.509542084')
# ('Epoch:', '0040', 'training time (minutes)=', '2.7120', 'loss=', '176.055907822')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '2.6900', 'loss=', '175.542055185')
# ('Epoch:', '0042', 'training time (minutes)=', '2.7103', 'loss=', '175.299122620')
# ('Epoch:', '0043', 'training time (minutes)=', '2.7025', 'loss=', '174.913951492')
# ('Epoch:', '0044', 'training time (minutes)=', '2.6858', 'loss=', '174.416651535')
# ('Epoch:', '0045', 'training time (minutes)=', '2.6912', 'loss=', '173.514743369')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-45 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0046', 'training time (minutes)=', '2.6905', 'loss=', '173.341667393')
# ('Epoch:', '0047', 'training time (minutes)=', '2.6863', 'loss=', '173.066714805')
# ('Epoch:', '0048', 'training time (minutes)=', '2.6928', 'loss=', '172.769846834')
# ('Epoch:', '0049', 'training time (minutes)=', '2.6978', 'loss=', '172.337725667')
# ('Epoch:', '0050', 'training time (minutes)=', '2.7543', 'loss=', '172.314664405')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '2.6913', 'loss=', '171.876889529')
# ('Epoch:', '0052', 'training time (minutes)=', '2.7132', 'loss=', '170.847359140')
# ('Epoch:', '0053', 'training time (minutes)=', '2.6834', 'loss=', '170.806013216')
# ('Epoch:', '0054', 'training time (minutes)=', '2.7184', 'loss=', '170.673302242')
# ('Epoch:', '0055', 'training time (minutes)=', '2.6965', 'loss=', '170.266263199')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-55 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0056', 'training time (minutes)=', '2.7065', 'loss=', '170.108323724')
# ('Epoch:', '0057', 'training time (minutes)=', '2.6977', 'loss=', '169.633977400')
# ('Epoch:', '0058', 'training time (minutes)=', '2.6884', 'loss=', '169.054623086')
# ('Epoch:', '0059', 'training time (minutes)=', '2.7025', 'loss=', '168.983534295')
# ('Epoch:', '0060', 'training time (minutes)=', '2.7201', 'loss=', '168.682547324')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '2.7109', 'loss=', '168.084560939')
# ('Epoch:', '0062', 'training time (minutes)=', '2.7067', 'loss=', '167.904810061')
# ('Epoch:', '0063', 'training time (minutes)=', '2.6885', 'loss=', '167.598227092')
# ('Epoch:', '0064', 'training time (minutes)=', '2.6955', 'loss=', '167.390291977')
# ('Epoch:', '0065', 'training time (minutes)=', '2.7090', 'loss=', '166.795558820')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-65 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0066', 'training time (minutes)=', '2.7357', 'loss=', '166.758136695')
# ('Epoch:', '0067', 'training time (minutes)=', '2.7324', 'loss=', '166.286857932')
# ('Epoch:', '0068', 'training time (minutes)=', '2.6970', 'loss=', '166.227020591')
# ('Epoch:', '0069', 'training time (minutes)=', '2.6958', 'loss=', '165.780532128')
# ('Epoch:', '0070', 'training time (minutes)=', '2.6865', 'loss=', '165.814248766')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '2.6812', 'loss=', '165.541840145')
# ('Epoch:', '0072', 'training time (minutes)=', '2.6805', 'loss=', '165.495171901')
# ('Epoch:', '0073', 'training time (minutes)=', '2.6896', 'loss=', '165.029505975')
# ('Epoch:', '0074', 'training time (minutes)=', '2.6832', 'loss=', '164.680085046')
# ('Epoch:', '0075', 'training time (minutes)=', '2.6826', 'loss=', '164.395859092')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-75 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0076', 'training time (minutes)=', '2.6850', 'loss=', '164.107497569')
# ('Epoch:', '0077', 'training time (minutes)=', '2.6836', 'loss=', '164.024913243')
# ('Epoch:', '0078', 'training time (minutes)=', '2.6923', 'loss=', '163.656480299')
# ('Epoch:', '0079', 'training time (minutes)=', '2.6810', 'loss=', '163.627869960')
# ('Epoch:', '0080', 'training time (minutes)=', '2.7033', 'loss=', '163.520032120')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '2.6953', 'loss=', '163.294005258')
# ('Epoch:', '0082', 'training time (minutes)=', '2.7048', 'loss=', '163.230598068')
# ('Epoch:', '0083', 'training time (minutes)=', '2.6910', 'loss=', '162.563795907')
# ('Epoch:', '0084', 'training time (minutes)=', '2.6909', 'loss=', '162.458119965')
# ('Epoch:', '0085', 'training time (minutes)=', '2.6953', 'loss=', '162.271364702')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-85 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0086', 'training time (minutes)=', '2.6913', 'loss=', '162.109786061')
# ('Epoch:', '0087', 'training time (minutes)=', '2.6950', 'loss=', '162.104461397')
# ('Epoch:', '0088', 'training time (minutes)=', '2.7132', 'loss=', '161.331080137')
# ('Epoch:', '0089', 'training time (minutes)=', '2.6951', 'loss=', '161.636963545')
# ('Epoch:', '0090', 'training time (minutes)=', '2.6900', 'loss=', '161.694144767')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '2.6994', 'loss=', '161.353337479')
# ('Epoch:', '0092', 'training time (minutes)=', '2.7096', 'loss=', '161.234544155')
# ('Epoch:', '0093', 'training time (minutes)=', '2.7193', 'loss=', '161.081656374')
# ('Epoch:', '0094', 'training time (minutes)=', '2.7101', 'loss=', '160.752774048')
# ('Epoch:', '0095', 'training time (minutes)=', '2.7103', 'loss=', '160.534151241')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-95 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0096', 'training time (minutes)=', '2.7295', 'loss=', '160.407062313')
# ('Epoch:', '0097', 'training time (minutes)=', '2.7210', 'loss=', '160.336797932')
# ('Epoch:', '0098', 'training time (minutes)=', '2.7144', 'loss=', '159.994445855')
# ('Epoch:', '0099', 'training time (minutes)=', '2.7129', 'loss=', '159.955117362')
# ('Epoch:', '0100', 'training time (minutes)=', '2.7198', 'loss=', '160.061451449')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '2.7196', 'loss=', '159.407600294')
# ('Epoch:', '0102', 'training time (minutes)=', '2.7157', 'loss=', '159.225884901')
# ('Epoch:', '0103', 'training time (minutes)=', '2.7133', 'loss=', '159.357722310')
# ('Epoch:', '0104', 'training time (minutes)=', '2.6975', 'loss=', '159.507781546')
# ('Epoch:', '0105', 'training time (minutes)=', '2.7012', 'loss=', '158.993100085')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-105 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0106', 'training time (minutes)=', '2.7647', 'loss=', '158.865630722')
# ('Epoch:', '0107', 'training time (minutes)=', '2.9833', 'loss=', '158.766568702')
# ('Epoch:', '0108', 'training time (minutes)=', '2.7004', 'loss=', '158.451632418')
# ('Epoch:', '0109', 'training time (minutes)=', '2.6912', 'loss=', '158.604180145')
# ('Epoch:', '0110', 'training time (minutes)=', '2.6986', 'loss=', '158.567914581')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '2.6694', 'loss=', '158.255516488')
# ('Epoch:', '0112', 'training time (minutes)=', '2.6786', 'loss=', '158.122295162')
# ('Epoch:', '0113', 'training time (minutes)=', '2.6822', 'loss=', '157.676696995')
# ('Epoch:', '0114', 'training time (minutes)=', '2.6892', 'loss=', '158.366865703')
# ('Epoch:', '0115', 'training time (minutes)=', '2.6913', 'loss=', '157.798421260')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-115 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0116', 'training time (minutes)=', '2.6891', 'loss=', '157.623943819')
# ('Epoch:', '0117', 'training time (minutes)=', '2.7189', 'loss=', '157.500348064')
# ('Epoch:', '0118', 'training time (minutes)=', '2.7198', 'loss=', '157.232901437')
# ('Epoch:', '0119', 'training time (minutes)=', '2.6957', 'loss=', '157.253647232')
# ('Epoch:', '0120', 'training time (minutes)=', '2.6869', 'loss=', '157.433087322')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '2.6776', 'loss=', '157.036314065')
# ('Epoch:', '0122', 'training time (minutes)=', '2.6953', 'loss=', '157.190657152')
# ('Epoch:', '0123', 'training time (minutes)=', '2.6865', 'loss=', '156.897935431')
# ('Epoch:', '0124', 'training time (minutes)=', '2.6818', 'loss=', '156.581869125')
# ('Epoch:', '0125', 'training time (minutes)=', '2.7270', 'loss=', '156.567909459')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-125 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0126', 'training time (minutes)=', '2.6899', 'loss=', '156.548133850')
# ('Epoch:', '0127', 'training time (minutes)=', '2.6923', 'loss=', '156.047747312')
# ('Epoch:', '0128', 'training time (minutes)=', '2.6884', 'loss=', '156.243786076')
# ('Epoch:', '0129', 'training time (minutes)=', '2.7084', 'loss=', '156.269222205')
# ('Epoch:', '0130', 'training time (minutes)=', '2.7324', 'loss=', '156.161347416')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '2.6860', 'loss=', '156.014585332')
# ('Epoch:', '0132', 'training time (minutes)=', '2.7002', 'loss=', '155.843950653')
# ('Epoch:', '0133', 'training time (minutes)=', '2.6760', 'loss=', '155.777871377')
# ('Epoch:', '0134', 'training time (minutes)=', '2.6755', 'loss=', '155.489539446')
# ('Epoch:', '0135', 'training time (minutes)=', '2.6788', 'loss=', '155.551003429')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-135 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0136', 'training time (minutes)=', '2.7438', 'loss=', '155.410289982')
# ('Epoch:', '0137', 'training time (minutes)=', '2.7031', 'loss=', '155.338640050')
# ('Epoch:', '0138', 'training time (minutes)=', '2.7272', 'loss=', '155.103493554')
# ('Epoch:', '0139', 'training time (minutes)=', '2.6939', 'loss=', '155.205350004')
# ('Epoch:', '0140', 'training time (minutes)=', '2.7473', 'loss=', '155.085233579')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '2.7415', 'loss=', '154.796595328')
# ('Epoch:', '0142', 'training time (minutes)=', '2.7157', 'loss=', '155.033463996')
# ('Epoch:', '0143', 'training time (minutes)=', '2.6850', 'loss=', '154.589463534')
# ('Epoch:', '0144', 'training time (minutes)=', '2.6864', 'loss=', '154.380338015')
# ('Epoch:', '0145', 'training time (minutes)=', '2.6787', 'loss=', '154.648513467')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-145 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0146', 'training time (minutes)=', '2.6803', 'loss=', '154.704613059')
# ('Epoch:', '0147', 'training time (minutes)=', '2.6900', 'loss=', '154.320283072')
# ('Epoch:', '0148', 'training time (minutes)=', '2.6902', 'loss=', '154.263351277')
# ('Epoch:', '0149', 'training time (minutes)=', '2.6899', 'loss=', '154.416984177')
# ('Epoch:', '0150', 'training time (minutes)=', '2.6959', 'loss=', '154.012585286')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '2.6884', 'loss=', '154.163434219')
# ('Epoch:', '0152', 'training time (minutes)=', '2.6910', 'loss=', '154.074816949')
# ('Epoch:', '0153', 'training time (minutes)=', '2.6941', 'loss=', '153.762781252')
# ('Epoch:', '0154', 'training time (minutes)=', '2.6939', 'loss=', '153.957073593')
# ('Epoch:', '0155', 'training time (minutes)=', '2.6910', 'loss=', '153.446469225')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-155 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0156', 'training time (minutes)=', '2.6881', 'loss=', '153.588566153')
# ('Epoch:', '0157', 'training time (minutes)=', '2.6930', 'loss=', '153.411864362')
# ('Epoch:', '0158', 'training time (minutes)=', '2.6887', 'loss=', '153.794415447')
# ('Epoch:', '0159', 'training time (minutes)=', '2.7269', 'loss=', '153.532874734')
# ('Epoch:', '0160', 'training time (minutes)=', '2.7402', 'loss=', '153.259472438')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '2.7334', 'loss=', '153.294087546')
# ('Epoch:', '0162', 'training time (minutes)=', '2.7389', 'loss=', '153.281323678')
# ('Epoch:', '0163', 'training time (minutes)=', '2.7147', 'loss=', '152.909852655')
# ('Epoch:', '0164', 'training time (minutes)=', '2.7103', 'loss=', '152.895217623')
# ('Epoch:', '0165', 'training time (minutes)=', '2.7205', 'loss=', '152.766387721')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-165 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0166', 'training time (minutes)=', '2.7210', 'loss=', '152.747312764')
# ('Epoch:', '0167', 'training time (minutes)=', '2.7259', 'loss=', '152.794529561')
# ('Epoch:', '0168', 'training time (minutes)=', '2.7209', 'loss=', '152.927785328')
# ('Epoch:', '0169', 'training time (minutes)=', '2.7110', 'loss=', '152.594428035')
# ('Epoch:', '0170', 'training time (minutes)=', '2.7081', 'loss=', '152.478826141')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '2.7319', 'loss=', '152.437006487')
# ('Epoch:', '0172', 'training time (minutes)=', '2.7342', 'loss=', '152.622996630')
# ('Epoch:', '0173', 'training time (minutes)=', '2.7132', 'loss=', '152.586154229')
# ('Epoch:', '0174', 'training time (minutes)=', '2.7275', 'loss=', '152.230947495')
# ('Epoch:', '0175', 'training time (minutes)=', '2.7319', 'loss=', '152.471010263')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-175 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0176', 'training time (minutes)=', '2.7079', 'loss=', '152.099365180')
# ('Epoch:', '0177', 'training time (minutes)=', '2.7207', 'loss=', '152.155230767')
# ('Epoch:', '0178', 'training time (minutes)=', '2.7413', 'loss=', '152.169545691')
# ('Epoch:', '0179', 'training time (minutes)=', '2.7300', 'loss=', '152.138755417')
# ('Epoch:', '0180', 'training time (minutes)=', '2.7487', 'loss=', '152.074160821')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '2.7629', 'loss=', '152.077517046')
# ('Epoch:', '0182', 'training time (minutes)=', '2.7314', 'loss=', '151.683878217')
# ('Epoch:', '0183', 'training time (minutes)=', '2.7440', 'loss=', '151.889654269')
# ('Epoch:', '0184', 'training time (minutes)=', '2.7309', 'loss=', '151.663797978')
# ('Epoch:', '0185', 'training time (minutes)=', '2.6881', 'loss=', '151.966385705')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-185 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0186', 'training time (minutes)=', '2.6869', 'loss=', '151.514922006')
# ('Epoch:', '0187', 'training time (minutes)=', '2.6908', 'loss=', '151.458023943')
# ('Epoch:', '0188', 'training time (minutes)=', '2.6889', 'loss=', '151.373121098')
# ('Epoch:', '0189', 'training time (minutes)=', '2.6854', 'loss=', '151.311581530')
# ('Epoch:', '0190', 'training time (minutes)=', '2.6900', 'loss=', '151.499895041')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '2.6876', 'loss=', '151.267568098')
# ('Epoch:', '0192', 'training time (minutes)=', '2.6859', 'loss=', '151.348568998')
# ('Epoch:', '0193', 'training time (minutes)=', '2.6865', 'loss=', '151.144349452')
# ('Epoch:', '0194', 'training time (minutes)=', '2.6878', 'loss=', '150.793599973')
# ('Epoch:', '0195', 'training time (minutes)=', '2.6850', 'loss=', '151.012358693')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-195 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0196', 'training time (minutes)=', '2.6817', 'loss=', '150.926294163')
# ('Epoch:', '0197', 'training time (minutes)=', '2.6841', 'loss=', '151.066322327')
# ('Epoch:', '0198', 'training time (minutes)=', '2.6879', 'loss=', '150.742864990')
# ('Epoch:', '0199', 'training time (minutes)=', '2.6852', 'loss=', '150.951095745')
# ('Epoch:', '0200', 'training time (minutes)=', '2.6884', 'loss=', '150.869460242')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '2.6893', 'loss=', '150.674893352')
# ('Epoch:', '0202', 'training time (minutes)=', '2.6931', 'loss=', '150.708052553')
# ('Epoch:', '0203', 'training time (minutes)=', '2.6842', 'loss=', '150.768976430')
# ('Epoch:', '0204', 'training time (minutes)=', '2.6848', 'loss=', '150.413454546')
# ('Epoch:', '0205', 'training time (minutes)=', '2.6848', 'loss=', '150.465285819')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-205 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0206', 'training time (minutes)=', '2.6801', 'loss=', '150.594125639')
# ('Epoch:', '0207', 'training time (minutes)=', '2.6837', 'loss=', '150.700045340')
# ('Epoch:', '0208', 'training time (minutes)=', '2.6858', 'loss=', '150.345957838')
# ('Epoch:', '0209', 'training time (minutes)=', '2.6967', 'loss=', '150.133523996')
# ('Epoch:', '0210', 'training time (minutes)=', '2.6924', 'loss=', '150.236628887')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '2.6810', 'loss=', '150.371831676')
# ('Epoch:', '0212', 'training time (minutes)=', '2.6877', 'loss=', '150.195311465')
# ('Epoch:', '0213', 'training time (minutes)=', '2.6810', 'loss=', '150.047495760')
# ('Epoch:', '0214', 'training time (minutes)=', '2.6828', 'loss=', '150.072126552')
# ('Epoch:', '0215', 'training time (minutes)=', '2.6869', 'loss=', '150.042444665')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-215 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0216', 'training time (minutes)=', '2.6873', 'loss=', '149.791285488')
# ('Epoch:', '0217', 'training time (minutes)=', '2.6927', 'loss=', '149.837188176')
# ('Epoch:', '0218', 'training time (minutes)=', '2.6927', 'loss=', '149.786298425')
# ('Epoch:', '0219', 'training time (minutes)=', '2.6798', 'loss=', '149.742120852')
# ('Epoch:', '0220', 'training time (minutes)=', '2.6779', 'loss=', '149.569851467')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '2.6765', 'loss=', '149.794957025')
# ('Epoch:', '0222', 'training time (minutes)=', '2.6769', 'loss=', '149.670267705')
# ('Epoch:', '0223', 'training time (minutes)=', '2.6854', 'loss=', '149.711108998')
# ('Epoch:', '0224', 'training time (minutes)=', '2.6793', 'loss=', '149.499585506')
# ('Epoch:', '0225', 'training time (minutes)=', '2.6799', 'loss=', '149.676006590')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-225 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0226', 'training time (minutes)=', '2.6788', 'loss=', '149.648671014')
# ('Epoch:', '0227', 'training time (minutes)=', '2.6795', 'loss=', '149.537627411')
# ('Epoch:', '0228', 'training time (minutes)=', '2.6915', 'loss=', '149.108803940')
# ('Epoch:', '0229', 'training time (minutes)=', '2.7096', 'loss=', '149.332154247')
# ('Epoch:', '0230', 'training time (minutes)=', '2.6925', 'loss=', '149.216408593')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '2.6812', 'loss=', '149.160209492')
# ('Epoch:', '0232', 'training time (minutes)=', '2.6931', 'loss=', '149.343399756')
# ('Epoch:', '0233', 'training time (minutes)=', '2.7302', 'loss=', '149.130839430')
# ('Epoch:', '0234', 'training time (minutes)=', '2.7139', 'loss=', '149.061303384')
# ('Epoch:', '0235', 'training time (minutes)=', '2.6882', 'loss=', '149.142741449')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-235 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0236', 'training time (minutes)=', '2.6850', 'loss=', '149.201291656')
# ('Epoch:', '0237', 'training time (minutes)=', '2.7115', 'loss=', '148.958574186')
# ('Epoch:', '0238', 'training time (minutes)=', '2.7071', 'loss=', '148.856097467')
# ('Epoch:', '0239', 'training time (minutes)=', '2.7985', 'loss=', '148.864217595')
# ('Epoch:', '0240', 'training time (minutes)=', '2.6985', 'loss=', '148.746513040')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '2.7439', 'loss=', '148.985715594')
# ('Epoch:', '0242', 'training time (minutes)=', '2.7665', 'loss=', '148.829161562')
# ('Epoch:', '0243', 'training time (minutes)=', '2.7142', 'loss=', '148.632257898')
# ('Epoch:', '0244', 'training time (minutes)=', '2.7039', 'loss=', '148.672827039')
# ('Epoch:', '0245', 'training time (minutes)=', '2.7124', 'loss=', '148.451497650')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-245 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0246', 'training time (minutes)=', '2.7004', 'loss=', '148.856658391')
# ('Epoch:', '0247', 'training time (minutes)=', '2.6875', 'loss=', '148.347473853')
# ('Epoch:', '0248', 'training time (minutes)=', '2.6733', 'loss=', '148.569748906')
# ('Epoch:', '0249', 'training time (minutes)=', '2.6838', 'loss=', '148.507638877')
# ('Epoch:', '0250', 'training time (minutes)=', '2.6823', 'loss=', '148.392614365')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/5_sofa_2048_4096pts_emd/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '2.7003', 'loss=', '148.370566177')
# ('Epoch:', '0252', 'training time (minutes)=', '2.6881', 'loss=', '148.505730329')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-55be8089fccc> in <module>()
#       4
#       5 if do_training:
# ----> 6     ae.train(train_data, conf)
#       7
#       8 if load_model:
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in train(self, train_data, configuration)
#     160         stats = []
#     161
# --> 162         if c.saver_step is not None:
#     163             create_dir(c.train_dir)
#     164
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/point_net_ae.pyc in _single_epoch_train(self, train_data, configuration)
#      94             else:
#      95                 loss, _ = self.partial_fit(batch_i)
# ---> 96
#      97             # Compute average loss
#      98             epoch_loss += loss
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in partial_fit(self, X, GT)
#     122         This can be useful when training for instance a de-noising auto-encoder.
#     123         Returns:
# --> 124             The loss of the mini-batch.
#     125             The reconstructed (output) point-clouds.
#     126         '''
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
