# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


import tf_lab.autopredictors.scripts.virt_scan_data as vscan

from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch
        
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion, save_reconstructions
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
GPU = 0
exp_counter = '10'
loss = 'chamfer'
do_training = True
load_model_conf = False
do_evaluation = True

incomplete_n_samples = 2048
complete_n_samples = 4096
val_percent = .10
dropout_keep_prob = .8
seed = 42

experiment_name = exp_counter + '_all_classes_' + str(incomplete_n_samples) + '_' \
                  + str(complete_n_samples) + 'pts_' + loss

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'

n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3] 

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/paper_vanilla_vscan')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

if loss == 'emd':
    max_training_epochs = 100
elif loss == 'chamfer':
    max_training_epochs = 300
    
max_evaluation_epochs = max_training_epochs

# %%
# Load Data of All Classes.
class_to_syn_id = shape_net_category_to_synth_id()
all_classes = vscan.all_classes
n_threads = 50

first = class_to_syn_id[all_classes[0]]
train_data, val_data, test_data = vscan.load_train_val_test_vscan_paper(first, n_threads,\
                                                                        complete_n_samples=complete_n_samples,\
                                                                        incomplete_n_samples=incomplete_n_samples,
                                                                        val_percent=val_percent)
for model_class in vscan.all_classes[1:]:
    class_syn_id = class_to_syn_id[model_class]
    curr_train, curr_val, curr_test = vscan.load_train_val_test_vscan_paper(class_syn_id, n_threads,\
                                                              complete_n_samples=complete_n_samples,\
                                                              incomplete_n_samples=incomplete_n_samples,\
                                                              val_percent=val_percent)
    train_data.merge(curr_train)
    test_data.merge(curr_test)
    val_data.merge(curr_val)

train_data.shuffle_data()
# Out:
# 4045 files containing complete point clouds were found.
# 19800 incomplete point clouds were loaded.
# 4470 incomplete point clouds were loaded.
# 1572 files containing complete point clouds were found.
# 7800 incomplete point clouds were loaded.
# 1632 incomplete point clouds were loaded.
# 7497 files containing complete point clouds were found.
# 29640 incomplete point clouds were loaded.
# 5922 incomplete point clouds were loaded.
# 6778 files containing complete point clouds were found.
# 30000 incomplete point clouds were loaded.
# 6000 incomplete point clouds were loaded.
# 2318 files containing complete point clouds were found.
# 11100 incomplete point clouds were loaded.
# 2808 incomplete point clouds were loaded.
# 3173 files containing complete point clouds were found.
# 15600 incomplete point clouds were loaded.
# 3438 incomplete point clouds were loaded.
# 8509 files containing complete point clouds were found.
# 30000 incomplete point clouds were loaded.
# 6000 incomplete point clouds were loaded.
# 1939 files containing complete point clouds were found.
# 9600 incomplete point clouds were loaded.
# 2034 incomplete point clouds were loaded.

# %%
print train_data.num_examples + val_data.num_examples
print test_data.num_examples
# Out:
# 153540
# 32304

# %%
tf.set_random_seed(seed)

if load_model_conf:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)],
                    'non_linearity': tf.nn.relu
                   }

    encoder_args = {'dropout_prob': dropout_keep_prob}
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 1,
                learning_rate = 0.0005,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.allow_gpu_growth = False
    conf.consistent_io = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
set_visible_GPUs([GPU])
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
training_stats = []
if do_training:
    training_stats.append(ae.train(train_data, conf))
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '4.9191', 'loss=', '0.001457086')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '6.1718', 'loss=', '0.000950261')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-2 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0003', 'training time (minutes)=', '4.8326', 'loss=', '0.000840659')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-3 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0004', 'training time (minutes)=', '5.5338', 'loss=', '0.000782550')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-4 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0005', 'training time (minutes)=', '5.5043', 'loss=', '0.000742934')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-5 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0006', 'training time (minutes)=', '4.8015', 'loss=', '0.000711440')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-6 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0007', 'training time (minutes)=', '4.3541', 'loss=', '0.000688094')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-7 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0008', 'training time (minutes)=', '4.7592', 'loss=', '0.000667039')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-8 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0009', 'training time (minutes)=', '4.9592', 'loss=', '0.000653889')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-9 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0010', 'training time (minutes)=', '4.9703', 'loss=', '0.000639570')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '4.3845', 'loss=', '0.000625138')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-11 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0012', 'training time (minutes)=', '4.9657', 'loss=', '0.000617142')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-12 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0013', 'training time (minutes)=', '4.6412', 'loss=', '0.000607398')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-13 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0014', 'training time (minutes)=', '4.8568', 'loss=', '0.000599229')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-14 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0015', 'training time (minutes)=', '4.6581', 'loss=', '0.000593064')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-15 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0016', 'training time (minutes)=', '4.3546', 'loss=', '0.000584500')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-16 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0017', 'training time (minutes)=', '4.7486', 'loss=', '0.000580725')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-17 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0018', 'training time (minutes)=', '4.3766', 'loss=', '0.000574073')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-18 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0019', 'training time (minutes)=', '4.6493', 'loss=', '0.000569953')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-19 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0020', 'training time (minutes)=', '4.6025', 'loss=', '0.000563660')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '4.5352', 'loss=', '0.000560296')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-21 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0022', 'training time (minutes)=', '4.5787', 'loss=', '0.000557512')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-22 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0023', 'training time (minutes)=', '4.5080', 'loss=', '0.000551653')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-23 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0024', 'training time (minutes)=', '4.8465', 'loss=', '0.000549326')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-24 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0025', 'training time (minutes)=', '4.5639', 'loss=', '0.000546354')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-25 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0026', 'training time (minutes)=', '4.5291', 'loss=', '0.000543680')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-26 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0027', 'training time (minutes)=', '4.5186', 'loss=', '0.000539173')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-27 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0028', 'training time (minutes)=', '4.8310', 'loss=', '0.000538074')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-28 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0029', 'training time (minutes)=', '4.7840', 'loss=', '0.000533152')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-29 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0030', 'training time (minutes)=', '4.7554', 'loss=', '0.000532310')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '4.5905', 'loss=', '0.000527571')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-31 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0032', 'training time (minutes)=', '4.5977', 'loss=', '0.000527796')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-32 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0033', 'training time (minutes)=', '4.8463', 'loss=', '0.000523963')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-33 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0034', 'training time (minutes)=', '4.6959', 'loss=', '0.000524352')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-34 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0035', 'training time (minutes)=', '4.6810', 'loss=', '0.000519896')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-35 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0036', 'training time (minutes)=', '4.4786', 'loss=', '0.000519196')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-36 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0037', 'training time (minutes)=', '4.7109', 'loss=', '0.000516529')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-37 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0038', 'training time (minutes)=', '4.7862', 'loss=', '0.000516343')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-38 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0039', 'training time (minutes)=', '4.6593', 'loss=', '0.000512213')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-39 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0040', 'training time (minutes)=', '4.5278', 'loss=', '0.000511860')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '4.7630', 'loss=', '0.000509222')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-41 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0042', 'training time (minutes)=', '4.5923', 'loss=', '0.000507734')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-42 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0043', 'training time (minutes)=', '4.7077', 'loss=', '0.000507499')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-43 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0044', 'training time (minutes)=', '4.5962', 'loss=', '0.000504348')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-44 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0045', 'training time (minutes)=', '4.4583', 'loss=', '0.000504733')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-45 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0046', 'training time (minutes)=', '4.5038', 'loss=', '0.000501314')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-46 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0047', 'training time (minutes)=', '4.6439', 'loss=', '0.000501063')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-47 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0048', 'training time (minutes)=', '4.7358', 'loss=', '0.000500605')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-48 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0049', 'training time (minutes)=', '4.8943', 'loss=', '0.000497312')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-49 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0050', 'training time (minutes)=', '4.5038', 'loss=', '0.000496296')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '4.7943', 'loss=', '0.000497515')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-51 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0052', 'training time (minutes)=', '4.3814', 'loss=', '0.000494537')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-52 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0053', 'training time (minutes)=', '4.5834', 'loss=', '0.000493749')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-53 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0054', 'training time (minutes)=', '4.6584', 'loss=', '0.000492779')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-54 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0055', 'training time (minutes)=', '4.3454', 'loss=', '0.000490433')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-55 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0056', 'training time (minutes)=', '4.1672', 'loss=', '0.000491498')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-56 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0057', 'training time (minutes)=', '4.7000', 'loss=', '0.000487813')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-57 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0058', 'training time (minutes)=', '4.4514', 'loss=', '0.000487452')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-58 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0059', 'training time (minutes)=', '4.3712', 'loss=', '0.000487133')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-59 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0060', 'training time (minutes)=', '4.2810', 'loss=', '0.000487201')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '4.2855', 'loss=', '0.000483965')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-61 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0062', 'training time (minutes)=', '4.4452', 'loss=', '0.000484393')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0063', 'training time (minutes)=', '4.6257', 'loss=', '0.000483551')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-63 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0064', 'training time (minutes)=', '4.6362', 'loss=', '0.000482043')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0065', 'training time (minutes)=', '4.6660', 'loss=', '0.000482144')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-65 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0066', 'training time (minutes)=', '4.3723', 'loss=', '0.000480166')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0067', 'training time (minutes)=', '4.4351', 'loss=', '0.000480002')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-67 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0068', 'training time (minutes)=', '4.6758', 'loss=', '0.000479338')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0069', 'training time (minutes)=', '4.7700', 'loss=', '0.000477393')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-69 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0070', 'training time (minutes)=', '4.5356', 'loss=', '0.000477474')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '4.6946', 'loss=', '0.000475916')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-71 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0072', 'training time (minutes)=', '4.7107', 'loss=', '0.000476182')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0073', 'training time (minutes)=', '4.4252', 'loss=', '0.000474772')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-73 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0074', 'training time (minutes)=', '4.7238', 'loss=', '0.000473119')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0075', 'training time (minutes)=', '4.8675', 'loss=', '0.000473600')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-75 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0076', 'training time (minutes)=', '4.8394', 'loss=', '0.000472769')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0077', 'training time (minutes)=', '4.7486', 'loss=', '0.000472556')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-77 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0078', 'training time (minutes)=', '4.6983', 'loss=', '0.000471076')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0079', 'training time (minutes)=', '4.7987', 'loss=', '0.000470906')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-79 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0080', 'training time (minutes)=', '4.7382', 'loss=', '0.000469617')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '4.8949', 'loss=', '0.000469929')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-81 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0082', 'training time (minutes)=', '4.8236', 'loss=', '0.000467579')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0083', 'training time (minutes)=', '4.8715', 'loss=', '0.000467763')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-83 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0084', 'training time (minutes)=', '4.7740', 'loss=', '0.000468458')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0085', 'training time (minutes)=', '4.4331', 'loss=', '0.000465749')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-85 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0086', 'training time (minutes)=', '4.3754', 'loss=', '0.000466981')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0087', 'training time (minutes)=', '4.6482', 'loss=', '0.000465174')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-87 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0088', 'training time (minutes)=', '4.6524', 'loss=', '0.000465514')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0089', 'training time (minutes)=', '4.5091', 'loss=', '0.000464469')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-89 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0090', 'training time (minutes)=', '4.4866', 'loss=', '0.000462821')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '4.6255', 'loss=', '0.000463983')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-91 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0092', 'training time (minutes)=', '4.6318', 'loss=', '0.000462055')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-92 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0093', 'training time (minutes)=', '4.5201', 'loss=', '0.000462002')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-93 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0094', 'training time (minutes)=', '4.4703', 'loss=', '0.000461879')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-94 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0095', 'training time (minutes)=', '4.4592', 'loss=', '0.000461409')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-95 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0096', 'training time (minutes)=', '4.5345', 'loss=', '0.000460376')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-96 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0097', 'training time (minutes)=', '4.4749', 'loss=', '0.000460106')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-97 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0098', 'training time (minutes)=', '4.6904', 'loss=', '0.000460101')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-98 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0099', 'training time (minutes)=', '4.5322', 'loss=', '0.000459195')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-99 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0100', 'training time (minutes)=', '4.6726', 'loss=', '0.000458361')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '4.5004', 'loss=', '0.000457502')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-101 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0102', 'training time (minutes)=', '4.4709', 'loss=', '0.000458533')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-102 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0103', 'training time (minutes)=', '4.3498', 'loss=', '0.000456992')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-103 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0104', 'training time (minutes)=', '4.5930', 'loss=', '0.000457092')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-104 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0105', 'training time (minutes)=', '4.4618', 'loss=', '0.000455572')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-105 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0106', 'training time (minutes)=', '4.4211', 'loss=', '0.000456164')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-106 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0107', 'training time (minutes)=', '4.4612', 'loss=', '0.000454945')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-107 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0108', 'training time (minutes)=', '4.4390', 'loss=', '0.000454847')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-108 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0109', 'training time (minutes)=', '4.5134', 'loss=', '0.000454681')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-109 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0110', 'training time (minutes)=', '4.6377', 'loss=', '0.000454892')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '4.3872', 'loss=', '0.000453452')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-111 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0112', 'training time (minutes)=', '4.4202', 'loss=', '0.000452863')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-112 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0113', 'training time (minutes)=', '4.7117', 'loss=', '0.000452764')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-113 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0114', 'training time (minutes)=', '4.4989', 'loss=', '0.000452268')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-114 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0115', 'training time (minutes)=', '4.5649', 'loss=', '0.000451996')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-115 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0116', 'training time (minutes)=', '4.3248', 'loss=', '0.000451766')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-116 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0117', 'training time (minutes)=', '4.3079', 'loss=', '0.000451405')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-117 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0118', 'training time (minutes)=', '4.2673', 'loss=', '0.000450985')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-118 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0119', 'training time (minutes)=', '4.5523', 'loss=', '0.000450475')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-119 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0120', 'training time (minutes)=', '4.4963', 'loss=', '0.000450060')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '4.4847', 'loss=', '0.000449450')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-121 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0122', 'training time (minutes)=', '4.5171', 'loss=', '0.000448455')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-122 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0123', 'training time (minutes)=', '4.4167', 'loss=', '0.000449283')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-123 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0124', 'training time (minutes)=', '4.3069', 'loss=', '0.000449833')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-124 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0125', 'training time (minutes)=', '4.2327', 'loss=', '0.000447424')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-125 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0126', 'training time (minutes)=', '4.4357', 'loss=', '0.000449136')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-126 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0127', 'training time (minutes)=', '4.4957', 'loss=', '0.000446706')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-127 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0128', 'training time (minutes)=', '4.4162', 'loss=', '0.000447804')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-128 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0129', 'training time (minutes)=', '4.4712', 'loss=', '0.000446356')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-129 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0130', 'training time (minutes)=', '4.4520', 'loss=', '0.000447070')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '4.6240', 'loss=', '0.000446620')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-131 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0132', 'training time (minutes)=', '4.4843', 'loss=', '0.000446156')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-132 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0133', 'training time (minutes)=', '4.5734', 'loss=', '0.000446606')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-133 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0134', 'training time (minutes)=', '4.5112', 'loss=', '0.000445732')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-134 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0135', 'training time (minutes)=', '4.4994', 'loss=', '0.000445122')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-135 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0136', 'training time (minutes)=', '4.3179', 'loss=', '0.000445000')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-136 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0137', 'training time (minutes)=', '4.3501', 'loss=', '0.000444084')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-137 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0138', 'training time (minutes)=', '4.4497', 'loss=', '0.000444492')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-138 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0139', 'training time (minutes)=', '4.3592', 'loss=', '0.000444370')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-139 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0140', 'training time (minutes)=', '4.4324', 'loss=', '0.000443696')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '4.2930', 'loss=', '0.000443231')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-141 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0142', 'training time (minutes)=', '4.4434', 'loss=', '0.000443322')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-142 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0143', 'training time (minutes)=', '4.4942', 'loss=', '0.000443436')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-143 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0144', 'training time (minutes)=', '4.2117', 'loss=', '0.000442999')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-144 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0145', 'training time (minutes)=', '4.4466', 'loss=', '0.000442220')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-145 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0146', 'training time (minutes)=', '4.5407', 'loss=', '0.000441287')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-146 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0147', 'training time (minutes)=', '4.3126', 'loss=', '0.000442465')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-147 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0148', 'training time (minutes)=', '4.3555', 'loss=', '0.000441802')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-148 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0149', 'training time (minutes)=', '4.3351', 'loss=', '0.000441133')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-149 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0150', 'training time (minutes)=', '4.3628', 'loss=', '0.000441274')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '4.6719', 'loss=', '0.000440892')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-151 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0152', 'training time (minutes)=', '4.6638', 'loss=', '0.000441228')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-152 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0153', 'training time (minutes)=', '4.3400', 'loss=', '0.000440065')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-153 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0154', 'training time (minutes)=', '4.4540', 'loss=', '0.000439119')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-154 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0155', 'training time (minutes)=', '4.4912', 'loss=', '0.000440186')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-155 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0156', 'training time (minutes)=', '4.6160', 'loss=', '0.000440734')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-156 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0157', 'training time (minutes)=', '4.5295', 'loss=', '0.000438702')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-157 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0158', 'training time (minutes)=', '4.0909', 'loss=', '0.000439432')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-158 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0159', 'training time (minutes)=', '4.5025', 'loss=', '0.000438210')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-159 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0160', 'training time (minutes)=', '4.3257', 'loss=', '0.000439165')
# ...
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-248 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0249', 'training time (minutes)=', '4.3740', 'loss=', '0.000424487')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-249 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0250', 'training time (minutes)=', '4.1975', 'loss=', '0.000423387')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '4.4278', 'loss=', '0.000424376')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-251 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0252', 'training time (minutes)=', '4.4490', 'loss=', '0.000422989')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-252 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0253', 'training time (minutes)=', '4.4375', 'loss=', '0.000423905')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-253 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0254', 'training time (minutes)=', '4.3603', 'loss=', '0.000423416')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-254 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0255', 'training time (minutes)=', '4.2934', 'loss=', '0.000423968')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-255 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0256', 'training time (minutes)=', '4.2682', 'loss=', '0.000423647')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-256 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0257', 'training time (minutes)=', '4.2693', 'loss=', '0.000423163')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-257 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0258', 'training time (minutes)=', '4.3287', 'loss=', '0.000422355')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-258 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0259', 'training time (minutes)=', '4.4137', 'loss=', '0.000424059')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-259 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0260', 'training time (minutes)=', '4.3692', 'loss=', '0.000422280')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '4.3043', 'loss=', '0.000423836')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-261 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0262', 'training time (minutes)=', '4.0461', 'loss=', '0.000421604')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-262 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0263', 'training time (minutes)=', '4.1000', 'loss=', '0.000422491')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-263 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0264', 'training time (minutes)=', '4.1073', 'loss=', '0.000422847')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-264 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0265', 'training time (minutes)=', '4.1252', 'loss=', '0.000422174')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-265 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0266', 'training time (minutes)=', '4.2400', 'loss=', '0.000422054')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-266 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0267', 'training time (minutes)=', '4.1772', 'loss=', '0.000422240')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-267 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0268', 'training time (minutes)=', '4.1926', 'loss=', '0.000422174')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-268 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0269', 'training time (minutes)=', '4.1686', 'loss=', '0.000421339')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-269 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0270', 'training time (minutes)=', '4.1521', 'loss=', '0.000422099')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '4.1259', 'loss=', '0.000422268')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-271 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0272', 'training time (minutes)=', '4.1560', 'loss=', '0.000421124')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-272 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0273', 'training time (minutes)=', '4.3483', 'loss=', '0.000421059')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-273 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0274', 'training time (minutes)=', '4.2904', 'loss=', '0.000421467')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-274 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0275', 'training time (minutes)=', '4.6978', 'loss=', '0.000420620')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-275 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0276', 'training time (minutes)=', '4.2727', 'loss=', '0.000422292')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-276 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0277', 'training time (minutes)=', '4.6214', 'loss=', '0.000421305')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-277 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0278', 'training time (minutes)=', '4.5290', 'loss=', '0.000420708')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-278 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0279', 'training time (minutes)=', '4.5636', 'loss=', '0.000421178')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-279 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0280', 'training time (minutes)=', '4.4003', 'loss=', '0.000420477')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '4.6193', 'loss=', '0.000420755')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-281 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0282', 'training time (minutes)=', '4.4745', 'loss=', '0.000421189')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-282 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0283', 'training time (minutes)=', '4.1465', 'loss=', '0.000420164')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-283 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0284', 'training time (minutes)=', '4.5751', 'loss=', '0.000420282')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-284 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0285', 'training time (minutes)=', '4.3903', 'loss=', '0.000420242')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-285 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0286', 'training time (minutes)=', '4.7718', 'loss=', '0.000420340')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-286 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0287', 'training time (minutes)=', '4.2169', 'loss=', '0.000419612')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-287 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0288', 'training time (minutes)=', '4.5990', 'loss=', '0.000420273')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-288 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0289', 'training time (minutes)=', '4.4052', 'loss=', '0.000419134')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-289 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0290', 'training time (minutes)=', '4.5845', 'loss=', '0.000420243')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '4.4474', 'loss=', '0.000419286')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-291 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0292', 'training time (minutes)=', '4.4688', 'loss=', '0.000420188')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-292 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0293', 'training time (minutes)=', '4.2568', 'loss=', '0.000419757')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-293 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0294', 'training time (minutes)=', '4.3154', 'loss=', '0.000418958')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-294 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0295', 'training time (minutes)=', '4.2758', 'loss=', '0.000419025')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-295 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0296', 'training time (minutes)=', '4.4997', 'loss=', '0.000420136')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-296 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0297', 'training time (minutes)=', '4.3665', 'loss=', '0.000419172')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-297 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0298', 'training time (minutes)=', '4.3652', 'loss=', '0.000417906')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-298 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0299', 'training time (minutes)=', '4.2884', 'loss=', '0.000419089')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-299 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0300', 'training time (minutes)=', '4.4660', 'loss=', '0.000418888')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/10_all_classes_2048_4096pts_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.

# %%
max_evaluation_epochs = max_training_epochs
if do_evaluation:
    # Pick the epoch that minimizes the loss on the validation dataset.
    saved_epochs = np.array(read_saved_epochs(conf.train_dir))
    allowable_epochs = saved_epochs[saved_epochs <= max_evaluation_epochs]
    val_stats = eval_model(ae, conf, val_data, epochs=allowable_epochs, verbose=True)
    val_loss = np.min(val_stats[:,1])
    best_epoch = int(val_stats[np.argmin(val_stats[:,1]), 0])
    print 'Best epoch = %d.' % (best_epoch,) 
        
    ae.restore_model(conf.train_dir, best_epoch)
    top_save_dir = osp.join(conf.train_dir, 'output', 'epoch_' + str(best_epoch))
    save_dir = osp.join(top_save_dir, 'test_predictions')
    test_recon, test_loss, test_feed, test_ids, test_gt = ae.evaluate(test_data, conf)
    save_reconstructions(save_dir, test_recon, test_gt, test_feed, test_ids) # save ply files of test data.    
    train_loss = ae.evaluate(train_data, conf)[1]
    
    # Report Accuracy and Coverage of test data.
    n_examples = len(test_recon)
    pred_scores = np.zeros((n_examples, 2))
    for i in xrange(n_examples):
        gt = test_gt[i]
        pred = test_recon[i] 
        pred_scores[i, 0] = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=False)
        pred_scores[i, 1] = coverage_of_completion(gt, pred, thres=0.02, ret_dists=False)
    
    print 'Test Median-Accuracy-Coverage:', np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])
    
    with open(osp.join(top_save_dir, 'stats.txt'), 'w') as fout:
        fout.write('Best Validation Epoch = %d\n' % (best_epoch))
        fout.write('Validation loss = %f\n' % (val_loss))
        fout.write('Train loss = %f\n' % (train_loss))
        fout.write('Test loss = %f\n' % (test_loss))
        fout.write('Gen. Error (abs, per) = %f %f\n' % (abs(test_loss-train_loss),  abs(test_loss-train_loss) / train_loss ))
        fout.write('Test Median-Accuracy-Coverage = %f %f\n' % (np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])))
# Out:
# Model restored in epoch 1.
# [ 0.00105974]
# Model restored in epoch 2.
# [ 0.00090758]
# Model restored in epoch 3.
# [ 0.00083697]
# Model restored in epoch 4.
# [ 0.00080065]
# Model restored in epoch 5.
# [ 0.00077722]
# Model restored in epoch 6.
# [ 0.00075342]
# Model restored in epoch 7.
# [ 0.00073846]
# Model restored in epoch 8.
# [ 0.00073338]
# Model restored in epoch 9.
# [ 0.00072334]
# Model restored in epoch 10.
# [ 0.00071684]
# Model restored in epoch 11.
# [ 0.00069801]
# Model restored in epoch 12.
# [ 0.00068979]
# Model restored in epoch 13.
# [ 0.00069581]
# Model restored in epoch 14.
# [ 0.00068981]
# Model restored in epoch 15.
# [ 0.00068638]
# Model restored in epoch 16.
# [ 0.00068726]
# Model restored in epoch 17.
# [ 0.00069022]
# Model restored in epoch 18.
# [ 0.00068035]
# Model restored in epoch 19.
# [ 0.00068022]
# Model restored in epoch 20.
# [ 0.00067488]
# Model restored in epoch 21.
# [ 0.0006694]
# Model restored in epoch 22.
# [ 0.00067676]
# Model restored in epoch 23.
# [ 0.00066693]
# Model restored in epoch 24.
# [ 0.00066468]
# Model restored in epoch 25.
# [ 0.00066491]
# Model restored in epoch 26.
# [ 0.00067732]
# Model restored in epoch 27.
# [ 0.00066444]
# Model restored in epoch 28.
# [ 0.00066922]
# Model restored in epoch 29.
# [ 0.00066017]
# Model restored in epoch 30.
# [ 0.00066828]
# Model restored in epoch 31.
# [ 0.00066498]
# Model restored in epoch 32.
# [ 0.00065937]
# Model restored in epoch 33.
# [ 0.0006577]
# Model restored in epoch 34.
# [ 0.00066165]
# Model restored in epoch 35.
# [ 0.00066111]
# Model restored in epoch 36.
# [ 0.00066865]
# Model restored in epoch 37.
# [ 0.0006705]
# Model restored in epoch 38.
# [ 0.00065864]
# Model restored in epoch 39.
# [ 0.00066037]
# Model restored in epoch 40.
# [ 0.00065912]
# Model restored in epoch 41.
# [ 0.00065729]
# Model restored in epoch 42.
# [ 0.0006728]
# Model restored in epoch 43.
# [ 0.00066106]
# Model restored in epoch 44.
# [ 0.00066118]
# Model restored in epoch 45.
# [ 0.00066113]
# Model restored in epoch 46.
# [ 0.00066538]
# Model restored in epoch 47.
# [ 0.00065664]
# Model restored in epoch 48.
# [ 0.0006551]
# Model restored in epoch 49.
# [ 0.00065851]
# Model restored in epoch 50.
# [ 0.00065592]
# Model restored in epoch 51.
# [ 0.00065691]
# Model restored in epoch 52.
# [ 0.0006569]
# Model restored in epoch 53.
# [ 0.00065173]
# Model restored in epoch 54.
# [ 0.00065085]
# Model restored in epoch 55.
# [ 0.00065814]
# Model restored in epoch 56.
# [ 0.00065178]
# Model restored in epoch 57.
# [ 0.0006577]
# Model restored in epoch 58.
# [ 0.00065469]
# Model restored in epoch 59.
# [ 0.00065247]
# Model restored in epoch 60.
# [ 0.00065583]
# Model restored in epoch 61.
# [ 0.00065175]
# Model restored in epoch 62.
# [ 0.00065436]
# Model restored in epoch 63.
# [ 0.00065591]
# Model restored in epoch 64.
# [ 0.00065601]
# Model restored in epoch 65.
# [ 0.00065909]
# Model restored in epoch 66.
# [ 0.00065426]
# Model restored in epoch 67.
# [ 0.0006528]
# Model restored in epoch 68.
# [ 0.00065723]
# Model restored in epoch 69.
# [ 0.00065474]
# Model restored in epoch 70.
# [ 0.00065831]
# Model restored in epoch 71.
# [ 0.00065903]
# Model restored in epoch 72.
# [ 0.00065846]
# Model restored in epoch 73.
# [ 0.00064484]
# Model restored in epoch 74.
# [ 0.0006561]
# Model restored in epoch 75.
# [ 0.00065194]
# Model restored in epoch 76.
# [ 0.00065201]
# Model restored in epoch 77.
# [ 0.0006558]
# Model restored in epoch 78.
# [ 0.00065444]
# Model restored in epoch 79.
# [ 0.00064692]
# Model restored in epoch 80.
# [ 0.00064782]
# Model restored in epoch 81.
# [ 0.00066065]
# Model restored in epoch 82.
# [ 0.00065404]
# Model restored in epoch 83.
# [ 0.00065382]
# Model restored in epoch 84.
# [ 0.00065333]
# Model restored in epoch 85.
# [ 0.00065357]
# Model restored in epoch 86.
# [ 0.00064881]
# Model restored in epoch 87.
# [ 0.00065573]
# Model restored in epoch 88.
# [ 0.00065503]
# Model restored in epoch 89.
# [ 0.00064909]
# Model restored in epoch 90.
# [ 0.00065199]
# Model restored in epoch 91.
# [ 0.00065358]
# Model restored in epoch 92.
# [ 0.00065553]
# Model restored in epoch 93.
# [ 0.00065535]
# Model restored in epoch 94.
# [ 0.00065226]
# Model restored in epoch 95.
# [ 0.00065254]
# Model restored in epoch 96.
# [ 0.00065203]
# Model restored in epoch 97.
# [ 0.00065493]
# Model restored in epoch 98.
# [ 0.00065207]
# Model restored in epoch 99.
# [ 0.00066497]
# Model restored in epoch 100.
# [ 0.00065655]
# Model restored in epoch 101.
# [ 0.00064949]
# Model restored in epoch 102.
# [ 0.00065028]
# Model restored in epoch 103.
# [ 0.00065738]
# Model restored in epoch 104.
# [ 0.00065658]
# Model restored in epoch 105.
# [ 0.00065062]
# Model restored in epoch 106.
# [ 0.0006549]
# Model restored in epoch 107.
# [ 0.00065788]
# Model restored in epoch 108.
# [ 0.00065841]
# Model restored in epoch 109.
# [ 0.00065135]
# Model restored in epoch 110.
# [ 0.00065257]
# Model restored in epoch 111.
# [ 0.00064903]
# Model restored in epoch 112.
# [ 0.00065741]
# Model restored in epoch 113.
# [ 0.00064997]
# Model restored in epoch 114.
# [ 0.00065035]
# Model restored in epoch 115.
# [ 0.00065437]
# Model restored in epoch 116.
# [ 0.00065108]
# Model restored in epoch 117.
# [ 0.00065155]
# Model restored in epoch 118.
# [ 0.00064973]
# Model restored in epoch 119.
# [ 0.00064983]
# Model restored in epoch 120.
# [ 0.00065808]
# Model restored in epoch 121.
# [ 0.00065449]
# Model restored in epoch 122.
# [ 0.00065878]
# Model restored in epoch 123.
# [ 0.00066137]
# Model restored in epoch 124.
# [ 0.0006541]
# Model restored in epoch 125.
# [ 0.00065146]
# Model restored in epoch 126.
# [ 0.00065253]
# Model restored in epoch 127.
# [ 0.00065335]
# Model restored in epoch 128.
# [ 0.00064935]
# Model restored in epoch 129.
# [ 0.00065138]
# Model restored in epoch 130.
# [ 0.00065297]
# Model restored in epoch 131.
# [ 0.00065647]
# Model restored in epoch 132.
# [ 0.00066013]
# Model restored in epoch 133.
# [ 0.00065777]
# Model restored in epoch 134.
# [ 0.00065308]
# Model restored in epoch 135.
# [ 0.00065306]
# Model restored in epoch 136.
# [ 0.00064984]
# Model restored in epoch 137.
# [ 0.00065399]
# Model restored in epoch 138.
# [ 0.00065042]
# Model restored in epoch 139.
# [ 0.00065408]
# Model restored in epoch 140.
# [ 0.00065468]
# Model restored in epoch 141.
# [ 0.00065669]
# Model restored in epoch 142.
# [ 0.00065975]
# Model restored in epoch 143.
# [ 0.00065875]
# Model restored in epoch 144.
# [ 0.00065068]
# Model restored in epoch 145.
# [ 0.00065735]
# Model restored in epoch 146.
# [ 0.00065667]
# Model restored in epoch 147.
# [ 0.0006551]
# Model restored in epoch 148.
# [ 0.00065485]
# Model restored in epoch 149.
# [ 0.00065255]
# Model restored in epoch 150.
# [ 0.00065621]
# Model restored in epoch 151.
# [ 0.00065266]
# Model restored in epoch 152.
# [ 0.00066249]
# Model restored in epoch 153.
# [ 0.00065904]
# Model restored in epoch 154.
# [ 0.00065486]
# Model restored in epoch 155.
# [ 0.00065513]
# Model restored in epoch 156.
# [ 0.00065499]
# Model restored in epoch 157.
# [ 0.00065299]
# Model restored in epoch 158.
# [ 0.0006603]
# Model restored in epoch 159.
# [ 0.00065842]
# Model restored in epoch 160.
# [ 0.00065797]
# Model restored in epoch 161.
# [ 0.00065482]
# Model restored in epoch 162.
# [ 0.00065745]
# Model restored in epoch 163.
# [ 0.00066118]
# Model restored in epoch 164.
# [ 0.00065942]
# Model restored in epoch 165.
# [ 0.00065353]
# Model restored in epoch 166.
# [ 0.00065688]
# Model restored in epoch 167.
# [ 0.00065787]
# Model restored in epoch 168.
# [ 0.00065304]
# Model restored in epoch 169.
# [ 0.0006538]
# Model restored in epoch 170.
# [ 0.00065868]
# Model restored in epoch 171.
# [ 0.00065692]
# Model restored in epoch 172.
# [ 0.0006588]
# Model restored in epoch 173.
# [ 0.0006559]
# Model restored in epoch 174.
# [ 0.00065912]
# Model restored in epoch 175.
# [ 0.00066161]
# Model restored in epoch 176.
# [ 0.00065867]
# Model restored in epoch 177.
# [ 0.00065862]
# Model restored in epoch 178.
# [ 0.00065498]
# Model restored in epoch 179.
# [ 0.00066066]
# Model restored in epoch 180.
# [ 0.00066117]
# Model restored in epoch 181.
# [ 0.00065662]
# Model restored in epoch 182.
# [ 0.00066258]
# Model restored in epoch 183.
# [ 0.00065837]
# Model restored in epoch 184.
# [ 0.00065706]
# Model restored in epoch 185.
# [ 0.00065963]
# Model restored in epoch 186.
# [ 0.00065735]
# Model restored in epoch 187.
# [ 0.00065545]
# Model restored in epoch 188.
# [ 0.0006538]
# Model restored in epoch 189.
# [ 0.00066559]
# Model restored in epoch 190.
# [ 0.00066276]
# Model restored in epoch 191.
# [ 0.00066355]
# Model restored in epoch 192.
# [ 0.00066175]
# Model restored in epoch 193.
# [ 0.00065901]
# Model restored in epoch 194.
# [ 0.00065948]
# Model restored in epoch 195.
# [ 0.00065865]
# Model restored in epoch 196.
# [ 0.00065577]
# Model restored in epoch 197.
# [ 0.00066012]
# Model restored in epoch 198.
# [ 0.000662]
# Model restored in epoch 199.
# [ 0.00066204]
# Model restored in epoch 200.
# [ 0.00066086]
# Model restored in epoch 201.
# [ 0.00066242]
# Model restored in epoch 202.
# [ 0.00066431]
# Model restored in epoch 203.
# [ 0.00065955]
# Model restored in epoch 204.
# [ 0.00066027]
# Model restored in epoch 205.
# [ 0.00066248]
# Model restored in epoch 206.
# [ 0.00066039]
# Model restored in epoch 207.
# [ 0.00066588]
# Model restored in epoch 208.
# [ 0.000658]
# Model restored in epoch 209.
# [ 0.00066106]
# Model restored in epoch 210.
# [ 0.00065885]
# Model restored in epoch 211.
# [ 0.00065973]
# Model restored in epoch 212.
# [ 0.00065962]
# Model restored in epoch 213.
# [ 0.00066247]
# Model restored in epoch 214.
# [ 0.00066231]
# Model restored in epoch 215.
# [ 0.00066427]
# Model restored in epoch 216.
# [ 0.00065929]
# Model restored in epoch 217.
# [ 0.00066039]
# Model restored in epoch 218.
# [ 0.00066138]
# Model restored in epoch 219.
# [ 0.0006564]
# Model restored in epoch 220.
# [ 0.00066038]
# Model restored in epoch 221.
# [ 0.00065911]
# Model restored in epoch 222.
# [ 0.00066356]
# Model restored in epoch 223.
# [ 0.00066166]
# Model restored in epoch 224.
# [ 0.00066471]
# Model restored in epoch 225.
# [ 0.00065862]
# Model restored in epoch 226.
# [ 0.00066255]
# Model restored in epoch 227.
# [ 0.00067066]
# Model restored in epoch 228.
# [ 0.00065753]
# Model restored in epoch 229.
# [ 0.00065738]
# Model restored in epoch 230.
# [ 0.00065901]
# Model restored in epoch 231.
# [ 0.00065769]
# Model restored in epoch 232.
# [ 0.00065709]
# Model restored in epoch 233.
# [ 0.00065796]
# Model restored in epoch 234.
# [ 0.00065927]
# Model restored in epoch 235.
# [ 0.00065982]
# Model restored in epoch 236.
# [ 0.00065987]
# Model restored in epoch 237.
# [ 0.00065754]
# Model restored in epoch 238.
# [ 0.00066285]
# Model restored in epoch 239.
# [ 0.00066096]
# Model restored in epoch 240.
# [ 0.00066322]
# Model restored in epoch 241.
# [ 0.00066063]
# Model restored in epoch 242.
# [ 0.00066135]
# Model restored in epoch 243.
# [ 0.00066261]
# Model restored in epoch 244.
# [ 0.00066276]
# Model restored in epoch 245.
# [ 0.00066166]
# Model restored in epoch 246.
# [ 0.00066258]
# Model restored in epoch 247.
# [ 0.00066556]
# Model restored in epoch 248.
# [ 0.00066063]
# Model restored in epoch 249.
# [ 0.00066293]
# Model restored in epoch 250.
# [ 0.00066418]
# Model restored in epoch 251.
# [ 0.00066576]
# Model restored in epoch 252.
# [ 0.00066724]
# Model restored in epoch 253.
# [ 0.00065943]
# Model restored in epoch 254.
# [ 0.00066307]
# Model restored in epoch 255.
# [ 0.00066292]
# Model restored in epoch 256.
# [ 0.00066144]
# Model restored in epoch 257.
# [ 0.00066031]
# Model restored in epoch 258.
# [ 0.00066599]
# Model restored in epoch 259.
# [ 0.00067005]
# Model restored in epoch 260.
# [ 0.00066479]
# Model restored in epoch 261.
# [ 0.00066379]
# Model restored in epoch 262.
# [ 0.00065923]
# Model restored in epoch 263.
# [ 0.00066245]
# Model restored in epoch 264.
# [ 0.00066399]
# Model restored in epoch 265.
# [ 0.00067122]
# Model restored in epoch 266.
# [ 0.00065777]
# Model restored in epoch 267.
# [ 0.00065991]
# Model restored in epoch 268.
# [ 0.00066189]
# Model restored in epoch 269.
# [ 0.00066663]
# Model restored in epoch 270.
# [ 0.00066426]
# Model restored in epoch 271.
# [ 0.00066192]
# Model restored in epoch 272.
# [ 0.00066484]
# Model restored in epoch 273.
# [ 0.00066559]
# Model restored in epoch 274.
# [ 0.00066338]
# Model restored in epoch 275.
# [ 0.00066657]
# Model restored in epoch 276.
# [ 0.00066176]
# Model restored in epoch 277.
# [ 0.00066042]
# Model restored in epoch 278.
# [ 0.00066634]
# Model restored in epoch 279.
# [ 0.00066326]
# Model restored in epoch 280.
# [ 0.00066022]
# Model restored in epoch 281.
# [ 0.00066199]
# Model restored in epoch 282.
# [ 0.00066339]
# Model restored in epoch 283.
# [ 0.00066481]
# Model restored in epoch 284.
# [ 0.00066231]
# Model restored in epoch 285.
# [ 0.00066373]
# Model restored in epoch 286.
# [ 0.00067093]
# Model restored in epoch 287.
# [ 0.00066656]
# Model restored in epoch 288.
# [ 0.00066629]
# Model restored in epoch 289.
# [ 0.00066405]
# Model restored in epoch 290.
# [ 0.00066803]
# Model restored in epoch 291.
# [ 0.0006687]
# Model restored in epoch 292.
# [ 0.00067071]
# Model restored in epoch 293.
# [ 0.00066435]
# Model restored in epoch 294.
# [ 0.00066419]
# Model restored in epoch 295.
# [ 0.0006608]
# Model restored in epoch 296.
# [ 0.00066734]
# Model restored in epoch 297.
# [ 0.00067328]
# Model restored in epoch 298.
# [ 0.00066756]
# Model restored in epoch 299.
# [ 0.0006687]
# Model restored in epoch 300.
# [ 0.000663]
# Best epoch = 73.
# Test Median-Accuracy-Coverage: 0.908203125 0.8271484375
