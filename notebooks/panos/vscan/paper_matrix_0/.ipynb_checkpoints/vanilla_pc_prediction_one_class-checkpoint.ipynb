# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


import tf_lab.autopredictors.scripts.virt_scan_data as vscan

from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch
        
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion, save_reconstructions
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
incomplete_n_samples = 2048
complete_n_samples = 4096

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]

GPU = 1
exp_counter = '1'
loss = 'emd'
do_training = True
load_model_conf = False
do_evaluation = True

experiment_name = exp_counter + '_' + class_type + '_' + str(incomplete_n_samples) + '_' \
                  + str(complete_n_samples) + 'pts_' + loss

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
complete_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/not_scaled', \
                             str(complete_n_samples), class_syn_id)
    
n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3] 

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/paper_vanilla_vscan')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

if loss == 'emd':
    max_training_epochs = 100
elif loss == 'chamfer':
    max_training_epochs = 200
    
max_evaluation_epochs = max_training_epochs
# Out:
# Give me the class type.
# airplane

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
cmpl_file_names = pio.load_filenames_of_input_data(complete_pclouds_path, points_extension)
cmpl_pclouds, cmpl_model_names, syn_ids = pio.load_crude_point_clouds(file_names=cmpl_file_names, n_threads=30)
assert(len(np.unique(syn_ids)) == 1)
print '%d files containing complete point clouds were found.' % (len(cmpl_pclouds), )
# Out:
# 4045 files containing complete point clouds were found.

# %%
v_scan_top_dir = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)

if do_training or do_evaluation:
    train_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/train_models_with_scan_id.txt')
    
    train_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, train_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=30,
                                                      n_samples=incomplete_n_samples)
    
    train_data, val_data = vscan.make_validation_from_train_data(train_data, 0.10)
    
if do_evaluation:
    test_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/test_models_with_scan_id.txt')
    test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=30,
                                                      n_samples=incomplete_n_samples)
# Out:
# 19800 incomplete point clouds were loaded.
# 4470 incomplete point clouds were loaded.

# %%
if load_model_conf:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)],
                    'non_linearity': tf.nn.relu
                   }

    encoder_args = {'dropout_prob': 0.5}
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 2,
                learning_rate = 0.0005,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.consistent_io = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
set_visible_GPUs([GPU])
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
training_stats = []
if do_training:
    training_stats.append(ae.train(train_data, conf))
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '3.1826', 'loss=', '213.018759953')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '3.2353', 'loss=', '168.420448432')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-2 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0003', 'training time (minutes)=', '3.2369', 'loss=', '156.721742651')
# ('Epoch:', '0004', 'training time (minutes)=', '3.2471', 'loss=', '148.982407431')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-4 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0005', 'training time (minutes)=', '3.2512', 'loss=', '143.089074810')
# ('Epoch:', '0006', 'training time (minutes)=', '3.2441', 'loss=', '139.254235450')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-6 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0007', 'training time (minutes)=', '3.2473', 'loss=', '135.086109483')
# ('Epoch:', '0008', 'training time (minutes)=', '3.2656', 'loss=', '132.647381107')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-8 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0009', 'training time (minutes)=', '3.2577', 'loss=', '129.779256199')
# ('Epoch:', '0010', 'training time (minutes)=', '3.2490', 'loss=', '128.111591253')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '3.2425', 'loss=', '126.114173289')
# ('Epoch:', '0012', 'training time (minutes)=', '3.2465', 'loss=', '124.372283571')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-12 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0013', 'training time (minutes)=', '3.2373', 'loss=', '121.631268941')
# ('Epoch:', '0014', 'training time (minutes)=', '3.2481', 'loss=', '120.563027778')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-14 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0015', 'training time (minutes)=', '3.2545', 'loss=', '118.941369925')
# ('Epoch:', '0016', 'training time (minutes)=', '3.2557', 'loss=', '117.941143400')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-16 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0017', 'training time (minutes)=', '3.2476', 'loss=', '116.775037680')
# ('Epoch:', '0018', 'training time (minutes)=', '3.2385', 'loss=', '115.395797622')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-18 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0019', 'training time (minutes)=', '3.2369', 'loss=', '114.008259741')
# ('Epoch:', '0020', 'training time (minutes)=', '3.2465', 'loss=', '112.943675759')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '3.2349', 'loss=', '111.959208306')
# ('Epoch:', '0022', 'training time (minutes)=', '3.2470', 'loss=', '110.805774282')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-22 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0023', 'training time (minutes)=', '3.2507', 'loss=', '110.034247173')
# ('Epoch:', '0024', 'training time (minutes)=', '3.2472', 'loss=', '109.639100128')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-24 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0025', 'training time (minutes)=', '3.2381', 'loss=', '107.821189366')
# ('Epoch:', '0026', 'training time (minutes)=', '3.2365', 'loss=', '107.374843983')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-26 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0027', 'training time (minutes)=', '3.2333', 'loss=', '106.488615379')
# ('Epoch:', '0028', 'training time (minutes)=', '3.2384', 'loss=', '105.884682730')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-28 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0029', 'training time (minutes)=', '3.2469', 'loss=', '105.068684760')
# ('Epoch:', '0030', 'training time (minutes)=', '3.2523', 'loss=', '104.037555566')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '3.2460', 'loss=', '103.822657017')
# ('Epoch:', '0032', 'training time (minutes)=', '3.2411', 'loss=', '102.728136020')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-32 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0033', 'training time (minutes)=', '3.2417', 'loss=', '102.095953652')
# ('Epoch:', '0034', 'training time (minutes)=', '3.2455', 'loss=', '101.927335868')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-34 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0035', 'training time (minutes)=', '3.2443', 'loss=', '101.219757552')
# ('Epoch:', '0036', 'training time (minutes)=', '3.2571', 'loss=', '100.520224646')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-36 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0037', 'training time (minutes)=', '3.2604', 'loss=', '100.705472496')
# ('Epoch:', '0038', 'training time (minutes)=', '3.2632', 'loss=', '99.468450653')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-38 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0039', 'training time (minutes)=', '3.2524', 'loss=', '98.758637268')
# ('Epoch:', '0040', 'training time (minutes)=', '3.2543', 'loss=', '98.581502079')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '3.2526', 'loss=', '98.060955883')
# ('Epoch:', '0042', 'training time (minutes)=', '3.2559', 'loss=', '97.593031122')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-42 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0043', 'training time (minutes)=', '3.2520', 'loss=', '97.335786305')
# ('Epoch:', '0044', 'training time (minutes)=', '3.2568', 'loss=', '96.824946607')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-44 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0045', 'training time (minutes)=', '3.2521', 'loss=', '96.235800668')
# ('Epoch:', '0046', 'training time (minutes)=', '3.2516', 'loss=', '96.033739154')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-46 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0047', 'training time (minutes)=', '3.2417', 'loss=', '95.803822400')
# ('Epoch:', '0048', 'training time (minutes)=', '3.2454', 'loss=', '95.093421957')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-48 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0049', 'training time (minutes)=', '3.2426', 'loss=', '95.148015526')
# ('Epoch:', '0050', 'training time (minutes)=', '3.2533', 'loss=', '94.686528324')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '3.2646', 'loss=', '94.409723646')
# ('Epoch:', '0052', 'training time (minutes)=', '3.2598', 'loss=', '94.251118649')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-52 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0053', 'training time (minutes)=', '3.2542', 'loss=', '93.646739788')
# ('Epoch:', '0054', 'training time (minutes)=', '3.2491', 'loss=', '93.637269631')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-54 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0055', 'training time (minutes)=', '3.2477', 'loss=', '92.981823075')
# ('Epoch:', '0056', 'training time (minutes)=', '3.2534', 'loss=', '92.664687232')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-56 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0057', 'training time (minutes)=', '3.2492', 'loss=', '92.581988967')
# ('Epoch:', '0058', 'training time (minutes)=', '3.2515', 'loss=', '92.451104732')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-58 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0059', 'training time (minutes)=', '3.2451', 'loss=', '91.633931171')
# ('Epoch:', '0060', 'training time (minutes)=', '3.2476', 'loss=', '91.797939365')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '3.2400', 'loss=', '91.363868778')
# ('Epoch:', '0062', 'training time (minutes)=', '3.2476', 'loss=', '91.178819678')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0063', 'training time (minutes)=', '3.2474', 'loss=', '91.438663783')
# ('Epoch:', '0064', 'training time (minutes)=', '3.2512', 'loss=', '90.982825783')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0065', 'training time (minutes)=', '3.2519', 'loss=', '90.426941347')
# ('Epoch:', '0066', 'training time (minutes)=', '3.2461', 'loss=', '90.171173760')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0067', 'training time (minutes)=', '3.2498', 'loss=', '90.066271128')
# ('Epoch:', '0068', 'training time (minutes)=', '3.2470', 'loss=', '90.297828246')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0069', 'training time (minutes)=', '3.2475', 'loss=', '89.691987756')
# ('Epoch:', '0070', 'training time (minutes)=', '3.2445', 'loss=', '89.702579455')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '3.2480', 'loss=', '89.646018618')
# ('Epoch:', '0072', 'training time (minutes)=', '3.2512', 'loss=', '89.009331735')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0073', 'training time (minutes)=', '3.2464', 'loss=', '89.286316261')
# ('Epoch:', '0074', 'training time (minutes)=', '3.2456', 'loss=', '88.577656328')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0075', 'training time (minutes)=', '3.2460', 'loss=', '88.506800855')
# ('Epoch:', '0076', 'training time (minutes)=', '3.2477', 'loss=', '88.502221847')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0077', 'training time (minutes)=', '3.2490', 'loss=', '88.412775233')
# ('Epoch:', '0078', 'training time (minutes)=', '3.2463', 'loss=', '88.328316121')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0079', 'training time (minutes)=', '3.2539', 'loss=', '87.836628603')
# ('Epoch:', '0080', 'training time (minutes)=', '3.2528', 'loss=', '87.514495550')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '3.2509', 'loss=', '87.989504311')
# ('Epoch:', '0082', 'training time (minutes)=', '3.2457', 'loss=', '87.225744162')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0083', 'training time (minutes)=', '3.2465', 'loss=', '87.253821534')
# ('Epoch:', '0084', 'training time (minutes)=', '3.2474', 'loss=', '87.135259307')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0085', 'training time (minutes)=', '3.2391', 'loss=', '87.243537646')
# ('Epoch:', '0086', 'training time (minutes)=', '3.2424', 'loss=', '87.221276015')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0087', 'training time (minutes)=', '3.2376', 'loss=', '86.809949811')
# ('Epoch:', '0088', 'training time (minutes)=', '3.2325', 'loss=', '86.660525161')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0089', 'training time (minutes)=', '3.2325', 'loss=', '86.410087093')
# ('Epoch:', '0090', 'training time (minutes)=', '3.2296', 'loss=', '86.499880309')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '3.2310', 'loss=', '86.172729364')
# ('Epoch:', '0092', 'training time (minutes)=', '3.2347', 'loss=', '86.322121995')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-92 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0093', 'training time (minutes)=', '3.2352', 'loss=', '86.012952590')
# ('Epoch:', '0094', 'training time (minutes)=', '3.2310', 'loss=', '85.991251528')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-94 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0095', 'training time (minutes)=', '3.2363', 'loss=', '85.962022803')
# ('Epoch:', '0096', 'training time (minutes)=', '3.2366', 'loss=', '85.833053589')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-96 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0097', 'training time (minutes)=', '3.2346', 'loss=', '85.307080558')
# ('Epoch:', '0098', 'training time (minutes)=', '3.2313', 'loss=', '85.394288460')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-98 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0099', 'training time (minutes)=', '3.2330', 'loss=', '85.423123778')
# ('Epoch:', '0100', 'training time (minutes)=', '3.2442', 'loss=', '85.316747215')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/1_airplane_2048_4096pts_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.

# %%
if do_evaluation:
    # Pick the epoch that minimizes the loss on the validation dataset.
#     n_epochs = 25 # Consider only 'n_epochs' equally spaced epochs from those that are saved.
    saved_epochs = np.array(read_saved_epochs(conf.train_dir))
    allowable_epochs = saved_epochs[saved_epochs <= max_evaluation_epochs]
#     allowable_epochs = select_first_last_and_k(allowable_epochs, n_epochs-2)
    val_stats = eval_model(ae, conf, val_data, epochs=allowable_epochs, verbose=True)
    val_loss = np.min(val_stats[:,1])
    best_epoch = int(val_stats[np.argmin(val_stats[:,1]), 0])
    print 'Best epoch = %d.' % (best_epoch,) 
        
    ae.restore_model(conf.train_dir, best_epoch)
    top_save_dir = osp.join(conf.train_dir, 'output', 'epoch_' + str(best_epoch))
    save_dir = osp.join(top_save_dir, 'test_predictions')
    test_recon, test_loss, test_feed, test_ids, test_gt = ae.evaluate(test_data, conf)
    save_reconstructions(save_dir, test_recon, test_gt, test_feed, test_ids) # save ply files of test data.    
    train_loss = ae.evaluate(train_data, conf)[1]
    
    # Report Accuracy and Coverage of test data.
    n_examples = len(test_recon)
    pred_scores = np.zeros((n_examples, 2))
    for i in xrange(n_examples):
        gt = test_gt[i]
        pred = test_recon[i]    
        pred_scores[i, 0] = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=False)
        pred_scores[i, 1] = coverage_of_completion(gt, pred, thres=0.02, ret_dists=False)
    
    print 'Test Median-Accuracy-Coverage:', np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])
    
    with open(osp.join(top_save_dir, 'stats.txt'), 'w') as fout:
        fout.write('Best Validation Epoch = %d\n' % (best_epoch))
        fout.write('Validation loss = %f\n' % (val_loss))
        fout.write('Train loss = %f\n' % (train_loss))
        fout.write('Test loss = %f\n' % (test_loss))
        fout.write('Gen. Error (abs, per) = %f %f\n' % (abs(test_loss-train_loss),  abs(test_loss-train_loss) / train_loss ))
        fout.write('Test Median-Accuracy-Coverage = %f %f\n' % (np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])))
# Out:
# Model restored in epoch 1.
# [ 185.59797591]
# Model restored in epoch 2.
# [ 172.99634775]
# Model restored in epoch 4.
# [ 151.40670946]
# Model restored in epoch 6.
# [ 158.41277213]
# Model restored in epoch 8.
# [ 144.86168744]
# Model restored in epoch 10.
# [ 147.35305262]
# Model restored in epoch 12.
# [ 139.62100532]
# Model restored in epoch 14.
# [ 141.98644399]
# Model restored in epoch 16.
# [ 137.31233543]
# Model restored in epoch 18.
# [ 145.99536719]
# Model restored in epoch 20.
# [ 135.93159704]
# Model restored in epoch 22.
# [ 140.1380505]
# Model restored in epoch 24.
# [ 135.62105491]
# Model restored in epoch 26.
# [ 134.61983698]
# Model restored in epoch 28.
# [ 138.17805269]
# Model restored in epoch 30.
# [ 134.54467793]
# Model restored in epoch 32.
# [ 133.40122246]
# Model restored in epoch 34.
# [ 132.74241253]
# Model restored in epoch 36.
# [ 136.8077606]
# Model restored in epoch 38.
# [ 135.14679679]
# Model restored in epoch 40.
# [ 139.86283639]
# Model restored in epoch 42.
# [ 137.01460455]
# Model restored in epoch 44.
# [ 135.76995642]
# Model restored in epoch 46.
# [ 133.94339995]
# Model restored in epoch 48.
# [ 139.18469088]
# Model restored in epoch 50.
# [ 135.06979054]
# Model restored in epoch 52.
# [ 134.95707086]
# Model restored in epoch 54.
# [ 132.56505831]
# Model restored in epoch 56.
# [ 135.12923809]
# Model restored in epoch 58.
# [ 134.38559376]
# Model restored in epoch 60.
# [ 134.85558504]
# Model restored in epoch 62.
# [ 134.73831435]
# Model restored in epoch 64.
# [ 135.04898584]
# Model restored in epoch 66.
# [ 133.87165755]
# Model restored in epoch 68.
# [ 134.72495358]
# Model restored in epoch 70.
# [ 134.61986087]
# Model restored in epoch 72.
# [ 134.49122435]
# Model restored in epoch 74.
# [ 133.367438]
# Model restored in epoch 76.
# [ 133.20880466]
# Model restored in epoch 78.
# [ 135.96932055]
# Model restored in epoch 80.
# [ 134.39732411]
# Model restored in epoch 82.
# [ 133.98924267]
# Model restored in epoch 84.
# [ 134.36413956]
# Model restored in epoch 86.
# [ 134.43709637]
# Model restored in epoch 88.
# [ 134.07707157]
# Model restored in epoch 90.
# [ 133.19623585]
# Model restored in epoch 92.
# [ 133.912282]
# Model restored in epoch 94.
# [ 134.5204388]
# Model restored in epoch 96.
# [ 133.1168802]
# Model restored in epoch 98.
# [ 134.31378632]
# Model restored in epoch 100.
# [ 134.94497607]
# Best epoch = 54.
# Test Median-Accuracy-Coverage: 0.993408203125 0.992431640625
