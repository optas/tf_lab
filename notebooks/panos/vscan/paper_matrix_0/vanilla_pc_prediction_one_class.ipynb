# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


import tf_lab.autopredictors.scripts.virt_scan_data as vscan

from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch
        
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion, save_reconstructions
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
incomplete_n_samples = 2048
complete_n_samples = 4096

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]

GPU = 1
exp_counter = '6'
loss = 'emd'
do_training = True
load_model_conf = False
do_evaluation = True

experiment_name = exp_counter + '_' + class_type + '_' + str(incomplete_n_samples) + '_' \
                  + str(complete_n_samples) + 'pts_' + loss

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
complete_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/not_scaled', \
                             str(complete_n_samples), class_syn_id)
    
n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3] 

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/paper_vanilla_vscan')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

if loss == 'emd':
    max_training_epochs = 100
elif loss == 'chamfer':
    max_training_epochs = 200
    
max_evaluation_epochs = max_training_epochs
# Out:
# Give me the class type.
# lamp

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
cmpl_file_names = pio.load_filenames_of_input_data(complete_pclouds_path, points_extension)
cmpl_pclouds, cmpl_model_names, syn_ids = pio.load_crude_point_clouds(file_names=cmpl_file_names, n_threads=30)
assert(len(np.unique(syn_ids)) == 1)
print '%d files containing complete point clouds were found.' % (len(cmpl_pclouds), )
# Out:
# 2318 files containing complete point clouds were found.

# %%
v_scan_top_dir = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)

if do_training or do_evaluation:
    train_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/train_models_with_scan_id.txt')
    
    train_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, train_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=30,
                                                      n_samples=incomplete_n_samples)
    
    train_data, val_data = vscan.make_validation_from_train_data(train_data, 0.10)
    
if do_evaluation:
    test_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/test_models_with_scan_id.txt')
    test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=30,
                                                      n_samples=incomplete_n_samples)
# Out:
# 11100 incomplete point clouds were loaded.
# 2808 incomplete point clouds were loaded.

# %%
if load_model_conf:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)],
                    'non_linearity': tf.nn.relu
                   }

    encoder_args = {'dropout_prob': 0.5}
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 2,
                learning_rate = 0.0005,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.consistent_io = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
set_visible_GPUs([GPU])
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
training_stats = []
if do_training:
    training_stats.append(ae.train(train_data, conf))
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.7700', 'loss=', '555.562606121')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '1.7927', 'loss=', '442.718499725')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-2 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0003', 'training time (minutes)=', '1.8081', 'loss=', '416.429425417')
# ('Epoch:', '0004', 'training time (minutes)=', '1.8118', 'loss=', '395.249332601')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-4 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0005', 'training time (minutes)=', '1.8090', 'loss=', '384.016941243')
# ('Epoch:', '0006', 'training time (minutes)=', '1.8060', 'loss=', '370.890957933')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-6 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0007', 'training time (minutes)=', '1.7981', 'loss=', '363.714743609')
# ('Epoch:', '0008', 'training time (minutes)=', '1.8062', 'loss=', '355.327280016')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-8 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0009', 'training time (minutes)=', '1.8048', 'loss=', '347.068610877')
# ('Epoch:', '0010', 'training time (minutes)=', '1.8168', 'loss=', '342.261688846')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '1.8180', 'loss=', '332.436133610')
# ('Epoch:', '0012', 'training time (minutes)=', '1.8233', 'loss=', '327.870276063')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-12 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0013', 'training time (minutes)=', '1.8203', 'loss=', '322.873625636')
# ('Epoch:', '0014', 'training time (minutes)=', '1.8232', 'loss=', '317.915861504')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-14 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0015', 'training time (minutes)=', '1.8186', 'loss=', '314.694189791')
# ('Epoch:', '0016', 'training time (minutes)=', '1.8330', 'loss=', '309.355356801')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-16 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0017', 'training time (minutes)=', '1.8420', 'loss=', '302.455228029')
# ('Epoch:', '0018', 'training time (minutes)=', '1.8408', 'loss=', '297.705710100')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-18 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0019', 'training time (minutes)=', '1.8407', 'loss=', '294.092897425')
# ('Epoch:', '0020', 'training time (minutes)=', '1.8402', 'loss=', '291.171326757')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '1.8436', 'loss=', '289.564799707')
# ('Epoch:', '0022', 'training time (minutes)=', '1.8407', 'loss=', '285.126587834')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-22 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0023', 'training time (minutes)=', '1.8429', 'loss=', '280.575698853')
# ('Epoch:', '0024', 'training time (minutes)=', '1.8419', 'loss=', '276.224389464')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-24 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0025', 'training time (minutes)=', '1.8412', 'loss=', '274.193091234')
# ('Epoch:', '0026', 'training time (minutes)=', '1.8415', 'loss=', '270.371691066')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-26 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0027', 'training time (minutes)=', '1.8405', 'loss=', '267.539654756')
# ('Epoch:', '0028', 'training time (minutes)=', '1.8383', 'loss=', '266.589105884')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-28 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0029', 'training time (minutes)=', '1.8428', 'loss=', '259.460547442')
# ('Epoch:', '0030', 'training time (minutes)=', '1.8380', 'loss=', '260.776983673')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '1.8432', 'loss=', '257.235564572')
# ('Epoch:', '0032', 'training time (minutes)=', '1.8421', 'loss=', '255.497635885')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-32 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0033', 'training time (minutes)=', '1.8421', 'loss=', '252.054837558')
# ('Epoch:', '0034', 'training time (minutes)=', '1.8430', 'loss=', '249.955132949')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-34 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0035', 'training time (minutes)=', '1.8399', 'loss=', '248.196426315')
# ('Epoch:', '0036', 'training time (minutes)=', '1.8405', 'loss=', '241.958537730')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-36 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0037', 'training time (minutes)=', '1.8409', 'loss=', '242.047538719')
# ('Epoch:', '0038', 'training time (minutes)=', '1.8435', 'loss=', '239.173622246')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-38 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0039', 'training time (minutes)=', '1.8398', 'loss=', '237.664244609')
# ('Epoch:', '0040', 'training time (minutes)=', '1.8398', 'loss=', '234.670308252')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '1.8413', 'loss=', '234.658014575')
# ('Epoch:', '0042', 'training time (minutes)=', '1.8429', 'loss=', '233.073311964')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-42 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0043', 'training time (minutes)=', '1.8426', 'loss=', '230.985860010')
# ('Epoch:', '0044', 'training time (minutes)=', '1.8400', 'loss=', '228.154619993')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-44 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0045', 'training time (minutes)=', '1.8409', 'loss=', '228.985903716')
# ('Epoch:', '0046', 'training time (minutes)=', '1.8414', 'loss=', '225.683229226')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-46 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0047', 'training time (minutes)=', '1.8393', 'loss=', '222.743149801')
# ('Epoch:', '0048', 'training time (minutes)=', '1.8383', 'loss=', '222.708187391')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-48 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0049', 'training time (minutes)=', '1.8400', 'loss=', '221.256695235')
# ('Epoch:', '0050', 'training time (minutes)=', '1.8394', 'loss=', '220.692070199')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '1.8347', 'loss=', '218.685874134')
# ('Epoch:', '0052', 'training time (minutes)=', '1.8370', 'loss=', '217.424088981')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-52 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0053', 'training time (minutes)=', '1.8351', 'loss=', '215.180963948')
# ('Epoch:', '0054', 'training time (minutes)=', '1.8342', 'loss=', '212.959170471')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-54 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0055', 'training time (minutes)=', '1.8337', 'loss=', '212.407295419')
# ('Epoch:', '0056', 'training time (minutes)=', '1.8078', 'loss=', '211.525161666')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-56 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0057', 'training time (minutes)=', '1.8121', 'loss=', '207.041592392')
# ('Epoch:', '0058', 'training time (minutes)=', '1.8119', 'loss=', '207.532726499')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-58 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0059', 'training time (minutes)=', '1.8103', 'loss=', '210.059795591')
# ('Epoch:', '0060', 'training time (minutes)=', '1.8097', 'loss=', '207.610435908')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '1.8080', 'loss=', '207.393802509')
# ('Epoch:', '0062', 'training time (minutes)=', '1.8100', 'loss=', '207.800975704')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0063', 'training time (minutes)=', '1.8080', 'loss=', '203.501097329')
# ('Epoch:', '0064', 'training time (minutes)=', '1.8098', 'loss=', '204.827502380')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0065', 'training time (minutes)=', '1.8096', 'loss=', '200.700110814')
# ('Epoch:', '0066', 'training time (minutes)=', '1.8089', 'loss=', '198.946389510')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0067', 'training time (minutes)=', '1.8086', 'loss=', '200.038627509')
# ('Epoch:', '0068', 'training time (minutes)=', '1.8135', 'loss=', '197.471968684')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0069', 'training time (minutes)=', '1.8075', 'loss=', '198.626112895')
# ('Epoch:', '0070', 'training time (minutes)=', '1.8135', 'loss=', '196.073138443')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '1.8081', 'loss=', '196.918395383')
# ('Epoch:', '0072', 'training time (minutes)=', '1.8091', 'loss=', '195.386418558')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0073', 'training time (minutes)=', '1.8093', 'loss=', '193.919186769')
# ('Epoch:', '0074', 'training time (minutes)=', '1.8104', 'loss=', '193.704942406')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0075', 'training time (minutes)=', '1.8078', 'loss=', '191.983547498')
# ('Epoch:', '0076', 'training time (minutes)=', '1.8107', 'loss=', '192.105047791')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0077', 'training time (minutes)=', '1.8110', 'loss=', '190.112933518')
# ('Epoch:', '0078', 'training time (minutes)=', '1.8123', 'loss=', '189.409802001')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0079', 'training time (minutes)=', '1.8134', 'loss=', '190.973404314')
# ('Epoch:', '0080', 'training time (minutes)=', '1.8139', 'loss=', '187.872238313')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '1.8111', 'loss=', '186.745614747')
# ('Epoch:', '0082', 'training time (minutes)=', '1.8158', 'loss=', '186.617510542')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0083', 'training time (minutes)=', '1.8119', 'loss=', '185.089251034')
# ('Epoch:', '0084', 'training time (minutes)=', '1.8131', 'loss=', '186.068551145')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0085', 'training time (minutes)=', '1.8102', 'loss=', '184.288850410')
# ('Epoch:', '0086', 'training time (minutes)=', '1.8114', 'loss=', '185.159125937')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0087', 'training time (minutes)=', '1.8107', 'loss=', '184.028014370')
# ('Epoch:', '0088', 'training time (minutes)=', '1.8132', 'loss=', '182.438044179')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0089', 'training time (minutes)=', '1.8112', 'loss=', '182.597126026')
# ('Epoch:', '0090', 'training time (minutes)=', '1.8119', 'loss=', '182.706710432')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '1.8088', 'loss=', '179.417670015')
# ('Epoch:', '0092', 'training time (minutes)=', '1.8100', 'loss=', '179.025216031')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-92 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0093', 'training time (minutes)=', '1.8101', 'loss=', '179.676189787')
# ('Epoch:', '0094', 'training time (minutes)=', '1.8125', 'loss=', '178.406522971')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-94 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0095', 'training time (minutes)=', '1.8123', 'loss=', '179.423528087')
# ('Epoch:', '0096', 'training time (minutes)=', '1.8132', 'loss=', '179.133084781')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-96 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0097', 'training time (minutes)=', '1.8107', 'loss=', '175.653518830')
# ('Epoch:', '0098', 'training time (minutes)=', '1.8144', 'loss=', '174.552942401')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-98 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0099', 'training time (minutes)=', '1.8089', 'loss=', '176.940820282')
# ('Epoch:', '0100', 'training time (minutes)=', '1.8135', 'loss=', '173.219445387')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/6_lamp_2048_4096pts_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.

# %%
if do_evaluation:
    # Pick the epoch that minimizes the loss on the validation dataset.
#     n_epochs = 25 # Consider only 'n_epochs' equally spaced epochs from those that are saved.
    saved_epochs = np.array(read_saved_epochs(conf.train_dir))
    allowable_epochs = saved_epochs[saved_epochs <= max_evaluation_epochs]
#     allowable_epochs = select_first_last_and_k(allowable_epochs, n_epochs-2)
    val_stats = eval_model(ae, conf, val_data, epochs=allowable_epochs, verbose=True)
    val_loss = np.min(val_stats[:,1])
    best_epoch = int(val_stats[np.argmin(val_stats[:,1]), 0])
    print 'Best epoch = %d.' % (best_epoch,) 
        
    ae.restore_model(conf.train_dir, best_epoch)
    top_save_dir = osp.join(conf.train_dir, 'output', 'epoch_' + str(best_epoch))
    save_dir = osp.join(top_save_dir, 'test_predictions')
    test_recon, test_loss, test_feed, test_ids, test_gt = ae.evaluate(test_data, conf)
    save_reconstructions(save_dir, test_recon, test_gt, test_feed, test_ids) # save ply files of test data.    
    train_loss = ae.evaluate(train_data, conf)[1]
    
    # Report Accuracy and Coverage of test data.
    n_examples = len(test_recon)
    pred_scores = np.zeros((n_examples, 2))
    for i in xrange(n_examples):
        gt = test_gt[i]
        pred = test_recon[i]    
        pred_scores[i, 0] = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=False)
        pred_scores[i, 1] = coverage_of_completion(gt, pred, thres=0.02, ret_dists=False)
    
    print 'Test Median-Accuracy-Coverage:', np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])
    
    with open(osp.join(top_save_dir, 'stats.txt'), 'w') as fout:
        fout.write('Best Validation Epoch = %d\n' % (best_epoch))
        fout.write('Validation loss = %f\n' % (val_loss))
        fout.write('Train loss = %f\n' % (train_loss))
        fout.write('Test loss = %f\n' % (test_loss))
        fout.write('Gen. Error (abs, per) = %f %f\n' % (abs(test_loss-train_loss),  abs(test_loss-train_loss) / train_loss ))
        fout.write('Test Median-Accuracy-Coverage = %f %f\n' % (np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])))
# Out:
# Model restored in epoch 1.
# [ 472.05158186]
# Model restored in epoch 2.
# [ 414.02691623]
# Model restored in epoch 4.
# [ 405.32931464]
# Model restored in epoch 6.
# [ 383.07080216]
# Model restored in epoch 8.
# [ 374.58091255]
# Model restored in epoch 10.
# [ 362.5153278]
# Model restored in epoch 12.
# [ 361.5226303]
# Model restored in epoch 14.
# [ 356.36160581]
# Model restored in epoch 16.
# [ 351.87781119]
# Model restored in epoch 18.
# [ 347.3749813]
# Model restored in epoch 20.
# [ 335.74712063]
# Model restored in epoch 22.
# [ 344.86806096]
# Model restored in epoch 24.
# [ 337.08872312]
# Model restored in epoch 26.
# [ 341.31356427]
# Model restored in epoch 28.
# [ 340.02104008]
# Model restored in epoch 30.
# [ 339.28111391]
# Model restored in epoch 32.
# [ 337.79376083]
# Model restored in epoch 34.
# [ 336.28551009]
# Model restored in epoch 36.
# [ 341.09880107]
# Model restored in epoch 38.
# [ 347.16082956]
# Model restored in epoch 40.
# [ 334.9994034]
# Model restored in epoch 42.
# [ 336.53241682]
# Model restored in epoch 44.
# [ 331.37973627]
# Model restored in epoch 46.
# [ 336.72620784]
# Model restored in epoch 48.
# [ 339.04092875]
# Model restored in epoch 50.
# [ 336.65771924]
# Model restored in epoch 52.
# [ 331.30813324]
# Model restored in epoch 54.
# [ 331.7406553]
# Model restored in epoch 56.
# [ 334.49093243]
# Model restored in epoch 58.
# [ 333.66280661]
# Model restored in epoch 60.
# [ 334.48566994]
# Model restored in epoch 62.
# [ 335.12855708]
# Model restored in epoch 64.
# [ 330.69715345]
# Model restored in epoch 66.
# [ 336.30386325]
# Model restored in epoch 68.
# [ 332.79149208]
# Model restored in epoch 70.
# [ 335.66032918]
# Model restored in epoch 72.
# [ 333.65625935]
# Model restored in epoch 74.
# [ 329.72626805]
# Model restored in epoch 76.
# [ 332.57613228]
# Model restored in epoch 78.
# [ 334.65755703]
# Model restored in epoch 80.
# [ 333.30916314]
# Model restored in epoch 82.
# [ 331.05985377]
# Model restored in epoch 84.
# [ 334.89236835]
# Model restored in epoch 86.
# [ 333.34973474]
# Model restored in epoch 88.
# [ 333.24736477]
# Model restored in epoch 90.
# [ 335.76453324]
# Model restored in epoch 92.
# [ 338.78426299]
# Model restored in epoch 94.
# [ 332.71987393]
# Model restored in epoch 96.
# [ 332.89506764]
# Model restored in epoch 98.
# [ 338.77056775]
# Model restored in epoch 100.
# [ 333.28559834]
# Best epoch = 74.
# Test Median-Accuracy-Coverage: 0.628295898438 0.831176757812
