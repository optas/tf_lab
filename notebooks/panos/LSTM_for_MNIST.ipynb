# %% [markdown]
# # The goal of this notebook is:
# To classify MNIST images using a reccurent neural network. To give a sequential flavor to a MNIST image
# we treat each row of pixels as an element of a sequence. Thus, sine a MNIST image 28x28 pixels it will produce
# a 28 long-sequence whose elements are comprised by 28 values.

# %%
import tensorflow as tf
from tensorflow.python.ops import rnn, rnn_cell
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data

# Import MINST data
mnist = input_data.read_data_sets("/Users/optas/DATA/MNIST/", one_hot=True)
# Out:
# Extracting /Users/optas/DATA/MNIST/train-images-idx3-ubyte.gz
# Extracting /Users/optas/DATA/MNIST/train-labels-idx1-ubyte.gz
# Extracting /Users/optas/DATA/MNIST/t10k-images-idx3-ubyte.gz
# Extracting /Users/optas/DATA/MNIST/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 100

# Network Parameters
n_input = 28 # MNIST data input (img shape: 28*28)
n_steps = 28 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
def RNN(x, weights, biases):
    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)
    
    # Permuting batch_size and n_steps
    x = tf.transpose(x, [1, 0, 2])
    # Reshaping to (n_steps*batch_size, n_input)
    x = tf.reshape(x, [-1, n_input])
    # Split to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.split(0, n_steps, x)

    # Define an lstm cell with tensorflow
    lstm_cell = rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

pred = RNN(x, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
display_step = 10   # Every display_step * batch_size examples show results.
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: test_data, y: test_label})
# Out:
# Iter 1000, Minibatch Loss= 1.717847, Training Accuracy= 0.48000
# Iter 2000, Minibatch Loss= 1.324344, Training Accuracy= 0.53000
# Iter 3000, Minibatch Loss= 1.160099, Training Accuracy= 0.57000
# Iter 4000, Minibatch Loss= 0.828457, Training Accuracy= 0.77000
# Iter 5000, Minibatch Loss= 0.771893, Training Accuracy= 0.75000
# Iter 6000, Minibatch Loss= 0.812535, Training Accuracy= 0.71000
# Iter 7000, Minibatch Loss= 0.504349, Training Accuracy= 0.83000
# Iter 8000, Minibatch Loss= 0.506688, Training Accuracy= 0.86000
# Iter 9000, Minibatch Loss= 0.867400, Training Accuracy= 0.78000
# Iter 10000, Minibatch Loss= 0.470656, Training Accuracy= 0.83000
# Iter 11000, Minibatch Loss= 0.513396, Training Accuracy= 0.83000
# Iter 12000, Minibatch Loss= 0.385232, Training Accuracy= 0.90000
# Iter 13000, Minibatch Loss= 0.342705, Training Accuracy= 0.88000
# Iter 14000, Minibatch Loss= 0.254422, Training Accuracy= 0.93000
# Iter 15000, Minibatch Loss= 0.301832, Training Accuracy= 0.92000
# Iter 16000, Minibatch Loss= 0.565481, Training Accuracy= 0.80000
# Iter 17000, Minibatch Loss= 0.191273, Training Accuracy= 0.94000
# Iter 18000, Minibatch Loss= 0.170658, Training Accuracy= 0.94000
# Iter 19000, Minibatch Loss= 0.405544, Training Accuracy= 0.89000
# Iter 20000, Minibatch Loss= 0.229538, Training Accuracy= 0.94000
# Iter 21000, Minibatch Loss= 0.228859, Training Accuracy= 0.90000
# Iter 22000, Minibatch Loss= 0.180319, Training Accuracy= 0.96000
# Iter 23000, Minibatch Loss= 0.106986, Training Accuracy= 0.97000
# Iter 24000, Minibatch Loss= 0.238969, Training Accuracy= 0.90000
# Iter 25000, Minibatch Loss= 0.401146, Training Accuracy= 0.85000
# Iter 26000, Minibatch Loss= 0.308696, Training Accuracy= 0.93000
# Iter 27000, Minibatch Loss= 0.156278, Training Accuracy= 0.94000
# Iter 28000, Minibatch Loss= 0.121600, Training Accuracy= 0.96000
# Iter 29000, Minibatch Loss= 0.118669, Training Accuracy= 0.96000
# Iter 30000, Minibatch Loss= 0.133668, Training Accuracy= 0.94000
# Iter 31000, Minibatch Loss= 0.208034, Training Accuracy= 0.90000
# Iter 32000, Minibatch Loss= 0.122913, Training Accuracy= 0.96000
# Iter 33000, Minibatch Loss= 0.269608, Training Accuracy= 0.88000
# Iter 34000, Minibatch Loss= 0.105686, Training Accuracy= 0.96000
# Iter 35000, Minibatch Loss= 0.276215, Training Accuracy= 0.92000
# Iter 36000, Minibatch Loss= 0.211448, Training Accuracy= 0.95000
# Iter 37000, Minibatch Loss= 0.160000, Training Accuracy= 0.94000
# Iter 38000, Minibatch Loss= 0.341569, Training Accuracy= 0.87000
# Iter 39000, Minibatch Loss= 0.160808, Training Accuracy= 0.96000
# Iter 40000, Minibatch Loss= 0.172284, Training Accuracy= 0.95000
# Iter 41000, Minibatch Loss= 0.136752, Training Accuracy= 0.95000
# Iter 42000, Minibatch Loss= 0.070189, Training Accuracy= 0.99000
# Iter 43000, Minibatch Loss= 0.205419, Training Accuracy= 0.93000
# Iter 44000, Minibatch Loss= 0.337268, Training Accuracy= 0.93000
# Iter 45000, Minibatch Loss= 0.163611, Training Accuracy= 0.95000
# Iter 46000, Minibatch Loss= 0.108215, Training Accuracy= 0.98000
# Iter 47000, Minibatch Loss= 0.218338, Training Accuracy= 0.91000
# Iter 48000, Minibatch Loss= 0.407501, Training Accuracy= 0.87000
# Iter 49000, Minibatch Loss= 0.223286, Training Accuracy= 0.93000
# Iter 50000, Minibatch Loss= 0.188599, Training Accuracy= 0.92000
# Iter 51000, Minibatch Loss= 0.050538, Training Accuracy= 0.99000
# Iter 52000, Minibatch Loss= 0.109420, Training Accuracy= 0.98000
# Iter 53000, Minibatch Loss= 0.067981, Training Accuracy= 0.98000
# Iter 54000, Minibatch Loss= 0.022806, Training Accuracy= 0.99000
# Iter 55000, Minibatch Loss= 0.142229, Training Accuracy= 0.98000
# Iter 56000, Minibatch Loss= 0.083265, Training Accuracy= 0.99000
# Iter 57000, Minibatch Loss= 0.090417, Training Accuracy= 0.96000
# Iter 58000, Minibatch Loss= 0.137056, Training Accuracy= 0.95000
# Iter 59000, Minibatch Loss= 0.192231, Training Accuracy= 0.94000
# Iter 60000, Minibatch Loss= 0.191588, Training Accuracy= 0.95000
# Iter 61000, Minibatch Loss= 0.052868, Training Accuracy= 0.99000
# Iter 62000, Minibatch Loss= 0.085378, Training Accuracy= 0.97000
# Iter 63000, Minibatch Loss= 0.050177, Training Accuracy= 0.98000
# Iter 64000, Minibatch Loss= 0.048452, Training Accuracy= 0.99000
# Iter 65000, Minibatch Loss= 0.099198, Training Accuracy= 0.97000
# Iter 66000, Minibatch Loss= 0.091860, Training Accuracy= 0.99000
# Iter 67000, Minibatch Loss= 0.072734, Training Accuracy= 0.99000
# Iter 68000, Minibatch Loss= 0.065759, Training Accuracy= 0.98000
# Iter 69000, Minibatch Loss= 0.151569, Training Accuracy= 0.96000
# Iter 70000, Minibatch Loss= 0.167653, Training Accuracy= 0.94000
# Iter 71000, Minibatch Loss= 0.062660, Training Accuracy= 0.99000
# Iter 72000, Minibatch Loss= 0.048379, Training Accuracy= 0.99000
# Iter 73000, Minibatch Loss= 0.031495, Training Accuracy= 0.99000
# Iter 74000, Minibatch Loss= 0.067252, Training Accuracy= 0.97000
# Iter 75000, Minibatch Loss= 0.073782, Training Accuracy= 0.97000
# Iter 76000, Minibatch Loss= 0.134073, Training Accuracy= 0.95000
# Iter 77000, Minibatch Loss= 0.234418, Training Accuracy= 0.94000
# Iter 78000, Minibatch Loss= 0.054998, Training Accuracy= 0.98000
# Iter 79000, Minibatch Loss= 0.136034, Training Accuracy= 0.93000
# Iter 80000, Minibatch Loss= 0.086108, Training Accuracy= 0.96000
# Iter 81000, Minibatch Loss= 0.081675, Training Accuracy= 0.98000
# Iter 82000, Minibatch Loss= 0.043402, Training Accuracy= 0.97000
# Iter 83000, Minibatch Loss= 0.093694, Training Accuracy= 0.97000
# Iter 84000, Minibatch Loss= 0.058507, Training Accuracy= 0.98000
# Iter 85000, Minibatch Loss= 0.120140, Training Accuracy= 0.95000
# Iter 86000, Minibatch Loss= 0.090186, Training Accuracy= 0.99000
# Iter 87000, Minibatch Loss= 0.070683, Training Accuracy= 0.98000
# Iter 88000, Minibatch Loss= 0.021103, Training Accuracy= 0.99000
# Iter 89000, Minibatch Loss= 0.051312, Training Accuracy= 0.99000
# Iter 90000, Minibatch Loss= 0.156349, Training Accuracy= 0.92000
# Iter 91000, Minibatch Loss= 0.097626, Training Accuracy= 0.98000
# Iter 92000, Minibatch Loss= 0.089223, Training Accuracy= 0.98000
# Iter 93000, Minibatch Loss= 0.041017, Training Accuracy= 0.98000
# Iter 94000, Minibatch Loss= 0.201441, Training Accuracy= 0.91000
# Iter 95000, Minibatch Loss= 0.069062, Training Accuracy= 0.98000
# Iter 96000, Minibatch Loss= 0.181141, Training Accuracy= 0.96000
# Iter 97000, Minibatch Loss= 0.035676, Training Accuracy= 0.98000
# Iter 98000, Minibatch Loss= 0.071416, Training Accuracy= 0.98000
# Iter 99000, Minibatch Loss= 0.100986, Training Accuracy= 0.98000
# Optimization Finished!
# Testing Accuracy: 0.992188
