# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.stats import hmean

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


import tf_lab.autopredictors.scripts.virt_scan_data as vscan

from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch
        
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion, save_reconstructions, \
                                           paper_pc_completion_experiment_id_best_epoch
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
GPU = 0

do_training = True
load_model_conf = False
do_evaluation = True
loss = 'chamfer'
max_training_epochs = 100
incomplete_n_samples = 2048
complete_n_samples = 4096


class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]
exp_counter, _ = paper_pc_completion_experiment_id_best_epoch(class_type, loss)

experiment_name = str(exp_counter) + '_' + class_type + '_' + str(incomplete_n_samples) + '_' \
                  + str(complete_n_samples) + 'pts_with_consistency_' + loss

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
complete_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/not_scaled', \
                             str(complete_n_samples), class_syn_id)
    
n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3]

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/paper_vanilla_vscan')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

max_evaluation_epochs = max_training_epochs
# Out:
# Give me the class type.
# chair

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
cmpl_file_names = pio.load_filenames_of_input_data(complete_pclouds_path, points_extension)
cmpl_pclouds, cmpl_model_names, syn_ids = pio.load_crude_point_clouds(file_names=cmpl_file_names, n_threads=30)
assert(len(np.unique(syn_ids)) == 1)
print '%d files containing complete point clouds were found.' % (len(cmpl_pclouds), )
# Out:
# 6778 files containing complete point clouds were found.

# %%
v_scan_top_dir = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)

if do_training or do_evaluation:
    train_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/train_models_with_scan_id.txt')
    
    train_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, train_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=40,
                                                      n_samples=incomplete_n_samples)
    
    train_data, val_data = vscan.make_validation_from_train_data(train_data, 0.10)
    
if do_evaluation:
    test_id_file = osp.join(top_data_dir, 'From_Matthias/train_test_models/test_models_with_scan_id.txt')
    test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id,
                                                      cmpl_pclouds, cmpl_model_names, n_threads=40,
                                                      n_samples=incomplete_n_samples)
# Out:
# 30000 incomplete point clouds were loaded.
# 6000 incomplete point clouds were loaded.

# %%
if load_model_conf:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)],
                    'non_linearity': tf.nn.relu
                   }

    encoder_args = {'dropout_prob': 0.5}
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 2,
                learning_rate = 0.0005,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.consistent_io = 'chamfer'
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
set_visible_GPUs([GPU])
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
if do_training:
    training_stats = []
    training_stats.append(ae.train(train_data, conf))    
    with open(osp.join(conf.train_dir, 'train_stats.txt'), 'a') as fout:
        np.savetxt(fout, np.array(training_stats)[0])
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.1578', 'loss=', '0.003881522')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '1.1635', 'loss=', '0.002433896')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-2 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0003', 'training time (minutes)=', '1.1208', 'loss=', '0.002105829')
# ('Epoch:', '0004', 'training time (minutes)=', '1.2790', 'loss=', '0.001909643')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-4 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0005', 'training time (minutes)=', '1.2022', 'loss=', '0.001798539')
# ('Epoch:', '0006', 'training time (minutes)=', '1.2035', 'loss=', '0.001715223')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-6 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0007', 'training time (minutes)=', '1.1121', 'loss=', '0.001648933')
# ('Epoch:', '0008', 'training time (minutes)=', '1.2237', 'loss=', '0.001603399')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-8 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0009', 'training time (minutes)=', '1.3912', 'loss=', '0.001560712')
# ('Epoch:', '0010', 'training time (minutes)=', '1.2901', 'loss=', '0.001520611')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '1.2340', 'loss=', '0.001484867')
# ('Epoch:', '0012', 'training time (minutes)=', '1.2941', 'loss=', '0.001454383')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-12 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0013', 'training time (minutes)=', '1.2447', 'loss=', '0.001431071')
# ('Epoch:', '0014', 'training time (minutes)=', '1.2473', 'loss=', '0.001403475')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-14 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0015', 'training time (minutes)=', '1.2329', 'loss=', '0.001387795')
# ('Epoch:', '0016', 'training time (minutes)=', '1.2243', 'loss=', '0.001355510')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-16 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0017', 'training time (minutes)=', '1.2149', 'loss=', '0.001347113')
# ('Epoch:', '0018', 'training time (minutes)=', '1.2446', 'loss=', '0.001331629')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-18 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0019', 'training time (minutes)=', '1.2253', 'loss=', '0.001309975')
# ('Epoch:', '0020', 'training time (minutes)=', '1.2506', 'loss=', '0.001302837')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '1.2026', 'loss=', '0.001290890')
# ('Epoch:', '0022', 'training time (minutes)=', '1.2085', 'loss=', '0.001268036')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-22 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0023', 'training time (minutes)=', '1.2055', 'loss=', '0.001261297')
# ('Epoch:', '0024', 'training time (minutes)=', '1.2539', 'loss=', '0.001256101')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-24 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0025', 'training time (minutes)=', '1.1982', 'loss=', '0.001239478')
# ('Epoch:', '0026', 'training time (minutes)=', '1.2613', 'loss=', '0.001231429')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-26 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0027', 'training time (minutes)=', '1.1616', 'loss=', '0.001222159')
# ('Epoch:', '0028', 'training time (minutes)=', '1.1543', 'loss=', '0.001211634')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-28 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0029', 'training time (minutes)=', '1.1418', 'loss=', '0.001209768')
# ('Epoch:', '0030', 'training time (minutes)=', '1.1449', 'loss=', '0.001192193')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '1.1942', 'loss=', '0.001193668')
# ('Epoch:', '0032', 'training time (minutes)=', '1.1940', 'loss=', '0.001182751')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-32 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0033', 'training time (minutes)=', '1.1331', 'loss=', '0.001178671')
# ('Epoch:', '0034', 'training time (minutes)=', '1.1400', 'loss=', '0.001169085')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-34 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0035', 'training time (minutes)=', '1.1448', 'loss=', '0.001161277')
# ('Epoch:', '0036', 'training time (minutes)=', '1.1555', 'loss=', '0.001163333')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-36 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0037', 'training time (minutes)=', '1.1509', 'loss=', '0.001152056')
# ('Epoch:', '0038', 'training time (minutes)=', '1.1422', 'loss=', '0.001150937')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-38 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0039', 'training time (minutes)=', '1.1419', 'loss=', '0.001141821')
# ('Epoch:', '0040', 'training time (minutes)=', '1.1407', 'loss=', '0.001137384')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '1.2009', 'loss=', '0.001133953')
# ('Epoch:', '0042', 'training time (minutes)=', '1.1486', 'loss=', '0.001126388')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-42 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0043', 'training time (minutes)=', '1.1406', 'loss=', '0.001122592')
# ('Epoch:', '0044', 'training time (minutes)=', '1.1434', 'loss=', '0.001123992')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-44 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0045', 'training time (minutes)=', '1.1439', 'loss=', '0.001113562')
# ('Epoch:', '0046', 'training time (minutes)=', '1.1799', 'loss=', '0.001120398')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-46 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0047', 'training time (minutes)=', '1.1956', 'loss=', '0.001108252')
# ('Epoch:', '0048', 'training time (minutes)=', '1.2305', 'loss=', '0.001108632')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-48 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0049', 'training time (minutes)=', '1.5497', 'loss=', '0.001099069')
# ('Epoch:', '0050', 'training time (minutes)=', '1.6282', 'loss=', '0.001101932')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '1.5578', 'loss=', '0.001098037')
# ('Epoch:', '0052', 'training time (minutes)=', '1.7229', 'loss=', '0.001092309')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-52 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0053', 'training time (minutes)=', '1.4790', 'loss=', '0.001086503')
# ('Epoch:', '0054', 'training time (minutes)=', '1.5186', 'loss=', '0.001081339')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-54 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0055', 'training time (minutes)=', '1.4355', 'loss=', '0.001079304')
# ('Epoch:', '0056', 'training time (minutes)=', '1.4731', 'loss=', '0.001075025')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-56 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0057', 'training time (minutes)=', '1.6514', 'loss=', '0.001074130')
# ('Epoch:', '0058', 'training time (minutes)=', '1.3204', 'loss=', '0.001075516')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-58 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0059', 'training time (minutes)=', '1.3030', 'loss=', '0.001072710')
# ('Epoch:', '0060', 'training time (minutes)=', '1.3812', 'loss=', '0.001065413')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '1.4150', 'loss=', '0.001063771')
# ('Epoch:', '0062', 'training time (minutes)=', '1.5627', 'loss=', '0.001064822')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0063', 'training time (minutes)=', '1.3916', 'loss=', '0.001053728')
# ('Epoch:', '0064', 'training time (minutes)=', '1.4400', 'loss=', '0.001056738')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0065', 'training time (minutes)=', '1.4243', 'loss=', '0.001057259')
# ('Epoch:', '0066', 'training time (minutes)=', '1.3849', 'loss=', '0.001056773')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0067', 'training time (minutes)=', '1.4600', 'loss=', '0.001052724')
# ('Epoch:', '0068', 'training time (minutes)=', '1.4151', 'loss=', '0.001049608')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0069', 'training time (minutes)=', '1.4285', 'loss=', '0.001045932')
# ('Epoch:', '0070', 'training time (minutes)=', '1.3957', 'loss=', '0.001045868')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '1.4090', 'loss=', '0.001043331')
# ('Epoch:', '0072', 'training time (minutes)=', '1.4090', 'loss=', '0.001035435')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0073', 'training time (minutes)=', '1.4222', 'loss=', '0.001040735')
# ('Epoch:', '0074', 'training time (minutes)=', '1.3754', 'loss=', '0.001037546')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0075', 'training time (minutes)=', '1.3707', 'loss=', '0.001037835')
# ('Epoch:', '0076', 'training time (minutes)=', '1.4367', 'loss=', '0.001030850')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0077', 'training time (minutes)=', '1.2405', 'loss=', '0.001028908')
# ('Epoch:', '0078', 'training time (minutes)=', '1.4121', 'loss=', '0.001031822')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0079', 'training time (minutes)=', '1.4295', 'loss=', '0.001023349')
# ('Epoch:', '0080', 'training time (minutes)=', '1.2948', 'loss=', '0.001023682')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '1.3663', 'loss=', '0.001015206')
# ('Epoch:', '0082', 'training time (minutes)=', '1.3071', 'loss=', '0.001025548')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0083', 'training time (minutes)=', '1.3898', 'loss=', '0.001017761')
# ('Epoch:', '0084', 'training time (minutes)=', '1.2658', 'loss=', '0.001013555')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0085', 'training time (minutes)=', '1.3271', 'loss=', '0.001013206')
# ('Epoch:', '0086', 'training time (minutes)=', '1.3431', 'loss=', '0.001019728')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0087', 'training time (minutes)=', '1.2840', 'loss=', '0.001010167')
# ('Epoch:', '0088', 'training time (minutes)=', '1.3743', 'loss=', '0.001009200')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0089', 'training time (minutes)=', '1.2859', 'loss=', '0.001003711')
# ('Epoch:', '0090', 'training time (minutes)=', '1.3466', 'loss=', '0.001008429')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '1.3678', 'loss=', '0.001013462')
# ('Epoch:', '0092', 'training time (minutes)=', '1.2903', 'loss=', '0.001008867')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-92 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0093', 'training time (minutes)=', '1.1950', 'loss=', '0.001018013')
# ('Epoch:', '0094', 'training time (minutes)=', '1.1544', 'loss=', '0.001010895')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-94 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0095', 'training time (minutes)=', '1.1210', 'loss=', '0.000995653')
# ('Epoch:', '0096', 'training time (minutes)=', '1.3670', 'loss=', '0.000995435')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-96 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0097', 'training time (minutes)=', '1.1202', 'loss=', '0.000998568')
# ('Epoch:', '0098', 'training time (minutes)=', '1.3188', 'loss=', '0.001005799')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-98 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0099', 'training time (minutes)=', '1.1804', 'loss=', '0.000992802')
# ('Epoch:', '0100', 'training time (minutes)=', '1.2548', 'loss=', '0.000997659')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/paper_vanilla_vscan/2_chair_2048_4096pts_with_consistency_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.

# %%
if do_evaluation:
   # Pick the epoch that minimizes the loss on the validation dataset.
    saved_epochs = np.array(read_saved_epochs(conf.train_dir))
    allowable_epochs = saved_epochs[saved_epochs <= max_evaluation_epochs]
    val_stats = eval_model(ae, conf, val_data, epochs=allowable_epochs, verbose=True)
    val_loss = np.min(val_stats[:,1])
    best_epoch = int(val_stats[np.argmin(val_stats[:,1]), 0])
    print 'Best epoch = %d.' % (best_epoch,) 
        
    ae.restore_model(conf.train_dir, best_epoch)
#     top_save_dir = osp.join(conf.train_dir, 'output', 'epoch_' + str(best_epoch))
#     save_dir = osp.join(top_save_dir, 'test_predictions')
#     test_recon, test_loss, test_feed, test_ids, test_gt = ae.evaluate(test_data, conf)
#     save_reconstructions(save_dir, test_recon, test_gt, test_feed, test_ids) # save ply files of test data.    
#     train_loss = ae.evaluate(train_data, conf)[1]

    test_gt, test_ids, test_feed = test_data.full_epoch_data()
    n_examples = len(test_feed)
    
    test_recon = np.zeros([n_examples] + ae.n_output)
    b = conf.batch_size
    for i in xrange(0, n_examples, b):
        test_recon[i:i + b] = ae.sess.run((ae.x_reconstr), feed_dict={ae.x: test_feed[i:i + b]})
            
    # Report Accuracy and Coverage of test data.    
    pred_scores = np.zeros((n_examples, 2))
    for i in xrange(n_examples):
        gt = test_gt[i]
        pred = test_recon[i]    
        pred_scores[i, 0] = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=False)
        pred_scores[i, 1] = coverage_of_completion(gt, pred, thres=0.02, ret_dists=False)
    
    print 'Test Median-Accuracy-Coverage:', np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])
    print 'Test Median H-Measure:',  np.median(hmean(pred_scores, 1))

    with open(osp.join(top_save_dir, 'stats.txt'), 'w') as fout:
        fout.write('Best Validation Epoch = %d\n' % (best_epoch))
        fout.write('Validation loss = %f\n' % (val_loss))
        fout.write('Train loss = %f\n' % (train_loss))
        fout.write('Test loss = %f\n' % (test_loss))
        fout.write('Gen. Error (abs, per) = %f %f\n' % (abs(test_loss-train_loss),  abs(test_loss-train_loss) / train_loss ))
        fout.write('Test Median-Accuracy-Coverage = %f %f\n' % (np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])))
        fout.write('Test Median Harmonic Mean = %f' % (np.median(hmean(pred_scores, 1))))
# Out:
# Model restored in epoch 1.
# [ 0.0026677]
# Model restored in epoch 2.
# [ 0.00227787]
# Model restored in epoch 4.
# [ 0.00191942]
# Model restored in epoch 6.
# [ 0.00176782]
# Model restored in epoch 8.
# [ 0.00168763]
# Model restored in epoch 10.
# [ 0.00162943]
# Model restored in epoch 12.
# [ 0.00156618]
# Model restored in epoch 14.
# [ 0.00155587]
# Model restored in epoch 16.
# [ 0.00149995]
# Model restored in epoch 18.
# [ 0.00148466]
# Model restored in epoch 20.
# [ 0.00149432]
# Model restored in epoch 22.
# [ 0.00142977]
# Model restored in epoch 24.
# [ 0.00144418]
# Model restored in epoch 26.
# [ 0.00142708]
# Model restored in epoch 28.
# [ 0.00141745]
# Model restored in epoch 30.
# [ 0.0013955]
# Model restored in epoch 32.
# [ 0.00143134]
# Model restored in epoch 34.
# [ 0.0013948]
# Model restored in epoch 36.
# [ 0.00138372]
# Model restored in epoch 38.
# [ 0.00137175]
# Model restored in epoch 40.
# [ 0.00137313]
# Model restored in epoch 42.
# [ 0.00136882]
# Model restored in epoch 44.
# [ 0.00136452]
# Model restored in epoch 46.
# [ 0.00134998]
# Model restored in epoch 48.
# [ 0.00135524]
# Model restored in epoch 50.
# [ 0.00135262]
# Model restored in epoch 52.
# [ 0.0013613]
# Model restored in epoch 54.
# [ 0.00134844]
# Model restored in epoch 56.
# [ 0.00134942]
# Model restored in epoch 58.
# [ 0.00134065]
# Model restored in epoch 60.
# [ 0.00134168]
# Model restored in epoch 62.
# [ 0.00134342]
# Model restored in epoch 64.
# [ 0.00132924]
# Model restored in epoch 66.
# [ 0.00132533]
# Model restored in epoch 68.
# [ 0.00132657]
# Model restored in epoch 70.
# [ 0.00134724]
# Model restored in epoch 72.
# [ 0.00133143]
# Model restored in epoch 74.
# [ 0.00139045]
# Model restored in epoch 76.
# [ 0.00132549]
# Model restored in epoch 78.
# [ 0.00130656]
# Model restored in epoch 80.
# [ 0.00131247]
# Model restored in epoch 82.
# [ 0.00130182]
# Model restored in epoch 84.
# [ 0.00131493]
# Model restored in epoch 86.
# [ 0.00130665]
# Model restored in epoch 88.
# [ 0.00131469]
# Model restored in epoch 90.
# [ 0.0013226]
# Model restored in epoch 92.
# [ 0.00130762]
# Model restored in epoch 94.
# [ 0.00130221]
# Model restored in epoch 96.
# [ 0.00129896]
# Model restored in epoch 98.
# [ 0.00132213]
# Model restored in epoch 100.
# [ 0.00132113]
# Best epoch = 96.
# Test Median-Accuracy-Coverage: 0.90576171875 0.7412109375
# Test Median H-Measure: 0.812426417083
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-15eb921a43d4> in <module>()
#      34     print 'Test Median H-Measure:',  np.median(hmean(pred_scores, 1))
#      35
# ---> 36     with open(osp.join(top_save_dir, 'stats.txt'), 'w') as fout:
#      37         fout.write('Best Validation Epoch = %d\n' % (best_epoch))
#      38         fout.write('Validation loss = %f\n' % (val_loss))
#
# NameError: name 'top_save_dir' is not defined

# %%
complete, idf, feed = test_data.next_batch(1)
print idf
pred = ae.sess.run(ae.x_reconstr, feed_dict={ae.x:feed})
Point_Cloud(points=np.squeeze(pred)).plot();
Point_Cloud(points=np.squeeze(complete)).plot();
Point_Cloud(points=np.squeeze(feed)).plot();
# Out:
# ['03001627.c1e8b1bd34874c83febad4f49b26ec52.__2__']

# %%
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
