# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 0
setup_one_gpu(GPU)
# Out:
# Picking GPU 0

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.stats import hmean

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension, \
                                                 shape_net_core_synth_id_to_category

from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch

from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion, save_reconstructions, \
                                           save_pc_prediction_stats
                                           
                                                  
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud


from tf_lab.autopredictors.scripts.virt_scan_data import load_partial_pointclouds
import tf_lab.autopredictors.scripts.virt_scan_data as vscan
from general_tools.simpletons import indices_in_iterable

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
class_type = raw_input('Give me the class type: ').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]

loss = 'chamfer'
incomplete_n_samples = 2048
complete_n_samples = 4096
max_training_epochs = 100

do_training = False
load_model = True
do_evaluation = False
do_detailed_plotting = False

experiment_id = int(raw_input('Give the experiment ID: '))


experiment_name = str(experiment_id) + '_' + class_type + '_' + str(incomplete_n_samples) + '_' \
                  + str(complete_n_samples) + 'pts_' + loss


top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'

complete_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/raw', \
                             str(complete_n_samples), class_syn_id)

partial_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Partial_PCs/Angela_synthetic', str(incomplete_n_samples))

n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3]

train_dir = osp.join(top_data_dir, 'OUT/iccv/nn_models/testing')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

max_evaluation_epochs = max_training_epochs
# Out:
# Give me the class type: chair
# Give the experiment ID: 3

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
cmpl_file_names = pio.load_filenames_of_input_data(complete_pclouds_path, points_extension)
cmpl_pclouds, cmpl_model_names, cmpl_syn_ids = pio.load_crude_point_clouds(file_names=cmpl_file_names, n_threads=40)
assert(len(np.unique(cmpl_syn_ids)) == 1)
print '%d files containing complete point clouds were found.' % (len(cmpl_pclouds), )
# Out:
# 6778 files containing complete point clouds were found.

# %%
train_list = '/orions4-zfs/projects/lins2/Panos_Space/DATA/Point_Clouds/Partial_PCs/Angela_synthetic/train_test_splits/train_models_with_scan_id.txt'
partial_pclouds, partial_model_ids, partial_syn_ids = load_partial_pointclouds(train_list, partial_pclouds_path, 
                                                                               50, class_restriction=class_syn_id)
partial_model_names = np.array([i[0] for i in partial_model_ids], dtype=object)
partial_scan_ids = np.array([i[1] for i in partial_model_ids], dtype=object)
partial_unames = np.array(partial_model_names + '.' + partial_scan_ids + '.' + partial_syn_ids, dtype=object)

matching_index = indices_in_iterable(cmpl_model_names, partial_model_names)
assert(np.alltrue(matching_index != -1))
full_pclouds_matched = cmpl_pclouds[matching_index]

train_data = PointCloudDataSet(full_pclouds_matched, noise=partial_pclouds, labels=partial_unames)
train_data, val_data = vscan.make_validation_from_train_data(train_data, 0.05)
# Out:
# 30000 partial point clouds were loaded.

# %%
test_list = '/orions4-zfs/projects/lins2/Panos_Space/DATA/Point_Clouds/Partial_PCs/Angela_synthetic/train_test_splits/test_models_small_with_scan_id.txt'
test_pclouds, test_model_ids, test_syn_ids = load_partial_pointclouds(test_list, partial_pclouds_path, 
                                                                               50, class_restriction=class_syn_id)
test_model_names = np.array([i[0] for i in test_model_ids], dtype=object)
test_scan_ids = np.array([i[1] for i in test_model_ids], dtype=object)
test_unames = np.array(test_model_names + '.' + test_scan_ids + '.' + test_syn_ids, dtype=object)
matching_index = indices_in_iterable(cmpl_model_names, test_model_names)
assert(np.alltrue(matching_index != -1))
test_data = PointCloudDataSet(cmpl_pclouds[matching_index], noise=test_pclouds, labels=test_unames)
# Out:
# 6000 partial point clouds were loaded.

# %%
pp = train_data.next_batch(1)
pinc = pp[2].reshape(incomplete_n_samples, 3)
pcom = pp[0].reshape(complete_n_samples, 3)

score1 = accuracy_of_completion(pinc, pcom, 0.02, ret_dists=False)
score2, c2 = coverage_of_completion(pcom, pinc, 0.02, ret_dists=True)
print score1, score2
Point_Cloud(points=pinc).plot();
Point_Cloud(points=pcom).plot(c=c2);
# Out:
# 0.99169921875 0.641357421875

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:    
    encoder_args = {'n_filters': [128, 256, 512, 512],
                    'filter_sizes': [1, 1, 1, 1],
                    'strides': [1, 1, 1, 1],
                    'dropout_prob': 0.5
                   }
    
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)]}
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 1,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
    ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.1699', 'loss=', '0.002873315')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '1.1372', 'loss=', '0.001947009')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-2 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0003', 'training time (minutes)=', '1.1255', 'loss=', '0.001681291')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-3 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0004', 'training time (minutes)=', '1.1977', 'loss=', '0.001601158')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-4 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0005', 'training time (minutes)=', '1.1408', 'loss=', '0.001506944')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-5 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0006', 'training time (minutes)=', '1.2598', 'loss=', '0.001483323')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-6 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0007', 'training time (minutes)=', '1.1501', 'loss=', '0.001439232')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-7 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0008', 'training time (minutes)=', '1.2331', 'loss=', '0.001432729')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-8 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0009', 'training time (minutes)=', '1.1499', 'loss=', '0.001393822')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-9 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0010', 'training time (minutes)=', '1.1888', 'loss=', '0.001350741')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '1.1276', 'loss=', '0.001350829')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-11 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0012', 'training time (minutes)=', '1.1739', 'loss=', '0.001321481')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-12 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0013', 'training time (minutes)=', '1.1144', 'loss=', '0.001285364')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-13 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0014', 'training time (minutes)=', '1.1621', 'loss=', '0.001285176')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-14 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0015', 'training time (minutes)=', '1.1251', 'loss=', '0.001274977')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-15 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0016', 'training time (minutes)=', '1.2038', 'loss=', '0.001247652')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-16 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0017', 'training time (minutes)=', '1.1823', 'loss=', '0.001232469')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-17 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0018', 'training time (minutes)=', '1.1348', 'loss=', '0.001201679')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-18 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0019', 'training time (minutes)=', '1.1197', 'loss=', '0.001225702')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-19 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0020', 'training time (minutes)=', '1.0996', 'loss=', '0.001215166')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '1.2100', 'loss=', '0.001213388')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-21 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0022', 'training time (minutes)=', '1.1282', 'loss=', '0.001202599')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-22 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0023', 'training time (minutes)=', '1.1793', 'loss=', '0.001190419')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-23 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0024', 'training time (minutes)=', '1.1856', 'loss=', '0.001195648')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-24 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0025', 'training time (minutes)=', '1.1950', 'loss=', '0.001180668')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-25 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0026', 'training time (minutes)=', '1.1207', 'loss=', '0.001160320')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-26 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0027', 'training time (minutes)=', '1.1116', 'loss=', '0.001157757')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-27 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0028', 'training time (minutes)=', '1.1670', 'loss=', '0.001162243')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-28 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0029', 'training time (minutes)=', '1.1175', 'loss=', '0.001153211')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-29 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0030', 'training time (minutes)=', '1.1636', 'loss=', '0.001130832')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '1.1578', 'loss=', '0.001147046')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-31 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0032', 'training time (minutes)=', '1.1927', 'loss=', '0.001128336')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-32 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0033', 'training time (minutes)=', '1.1801', 'loss=', '0.001120838')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-33 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0034', 'training time (minutes)=', '1.2024', 'loss=', '0.001117082')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-34 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0035', 'training time (minutes)=', '1.1742', 'loss=', '0.001132653')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-35 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0036', 'training time (minutes)=', '1.1734', 'loss=', '0.001116890')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-36 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0037', 'training time (minutes)=', '1.1281', 'loss=', '0.001123159')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-37 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0038', 'training time (minutes)=', '1.0975', 'loss=', '0.001099046')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-38 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0039', 'training time (minutes)=', '1.0890', 'loss=', '0.001112533')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-39 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0040', 'training time (minutes)=', '1.1924', 'loss=', '0.001088462')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '1.1895', 'loss=', '0.001092822')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-41 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0042', 'training time (minutes)=', '1.1672', 'loss=', '0.001102469')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-42 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0043', 'training time (minutes)=', '1.1852', 'loss=', '0.001099327')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-43 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0044', 'training time (minutes)=', '1.1398', 'loss=', '0.001068422')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-44 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0045', 'training time (minutes)=', '1.1295', 'loss=', '0.001081414')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-45 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0046', 'training time (minutes)=', '1.1501', 'loss=', '0.001072818')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-46 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0047', 'training time (minutes)=', '1.1093', 'loss=', '0.001075657')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-47 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0048', 'training time (minutes)=', '1.1447', 'loss=', '0.001064130')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-48 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0049', 'training time (minutes)=', '1.1247', 'loss=', '0.001072912')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-49 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0050', 'training time (minutes)=', '1.1509', 'loss=', '0.001052727')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '1.1400', 'loss=', '0.001053649')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-51 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0052', 'training time (minutes)=', '1.1020', 'loss=', '0.001064482')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-52 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0053', 'training time (minutes)=', '1.1486', 'loss=', '0.001053050')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-53 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0054', 'training time (minutes)=', '1.1737', 'loss=', '0.001065377')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-54 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0055', 'training time (minutes)=', '1.1237', 'loss=', '0.001057399')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-55 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0056', 'training time (minutes)=', '1.2612', 'loss=', '0.001057660')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-56 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0057', 'training time (minutes)=', '1.1987', 'loss=', '0.001053334')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-57 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0058', 'training time (minutes)=', '1.1131', 'loss=', '0.001040684')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-58 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0059', 'training time (minutes)=', '1.1051', 'loss=', '0.001041698')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-59 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0060', 'training time (minutes)=', '1.1114', 'loss=', '0.001038544')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '1.2335', 'loss=', '0.001057241')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-61 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0062', 'training time (minutes)=', '1.1948', 'loss=', '0.001045691')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0063', 'training time (minutes)=', '1.2492', 'loss=', '0.001022238')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-63 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0064', 'training time (minutes)=', '1.1753', 'loss=', '0.001047551')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0065', 'training time (minutes)=', '1.1597', 'loss=', '0.001041045')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-65 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0066', 'training time (minutes)=', '1.1643', 'loss=', '0.001036283')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0067', 'training time (minutes)=', '1.1097', 'loss=', '0.001031192')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-67 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0068', 'training time (minutes)=', '1.1939', 'loss=', '0.001022420')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0069', 'training time (minutes)=', '1.1020', 'loss=', '0.001016297')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-69 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0070', 'training time (minutes)=', '1.1444', 'loss=', '0.001026935')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '1.1331', 'loss=', '0.001024985')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-71 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0072', 'training time (minutes)=', '1.2040', 'loss=', '0.001012640')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0073', 'training time (minutes)=', '1.1889', 'loss=', '0.001029186')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-73 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0074', 'training time (minutes)=', '1.2032', 'loss=', '0.001028590')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0075', 'training time (minutes)=', '1.1751', 'loss=', '0.001013018')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-75 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0076', 'training time (minutes)=', '1.1925', 'loss=', '0.001008397')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0077', 'training time (minutes)=', '1.1893', 'loss=', '0.001004428')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-77 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0078', 'training time (minutes)=', '1.1887', 'loss=', '0.001001619')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0079', 'training time (minutes)=', '1.1504', 'loss=', '0.001022617')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-79 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0080', 'training time (minutes)=', '1.1911', 'loss=', '0.001009988')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '1.1972', 'loss=', '0.001020473')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-81 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0082', 'training time (minutes)=', '1.1724', 'loss=', '0.001002697')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0083', 'training time (minutes)=', '1.1501', 'loss=', '0.001005554')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-83 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0084', 'training time (minutes)=', '1.0917', 'loss=', '0.000992440')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0085', 'training time (minutes)=', '1.0918', 'loss=', '0.000991857')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-85 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0086', 'training time (minutes)=', '1.2324', 'loss=', '0.000999458')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0087', 'training time (minutes)=', '1.2206', 'loss=', '0.000999621')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-87 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0088', 'training time (minutes)=', '1.2675', 'loss=', '0.000979070')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0089', 'training time (minutes)=', '1.0950', 'loss=', '0.001009890')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-89 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0090', 'training time (minutes)=', '1.0892', 'loss=', '0.000995920')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '1.1512', 'loss=', '0.000989490')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-91 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0092', 'training time (minutes)=', '1.1621', 'loss=', '0.001002801')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-92 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0093', 'training time (minutes)=', '1.2251', 'loss=', '0.000983444')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-93 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0094', 'training time (minutes)=', '1.2417', 'loss=', '0.000992510')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-94 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0095', 'training time (minutes)=', '1.1953', 'loss=', '0.000991810')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-95 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0096', 'training time (minutes)=', '1.0953', 'loss=', '0.000980860')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-96 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0097', 'training time (minutes)=', '1.1562', 'loss=', '0.000989855')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-97 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0098', 'training time (minutes)=', '1.0983', 'loss=', '0.000999088')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-98 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0099', 'training time (minutes)=', '1.1274', 'loss=', '0.000990362')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-99 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0100', 'training time (minutes)=', '1.1529', 'loss=', '0.000989074')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '1.0964', 'loss=', '0.000985036')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-101 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0102', 'training time (minutes)=', '1.1808', 'loss=', '0.000989686')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-102 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0103', 'training time (minutes)=', '1.1485', 'loss=', '0.000973146')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-103 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0104', 'training time (minutes)=', '1.1086', 'loss=', '0.000971757')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-104 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0105', 'training time (minutes)=', '1.1528', 'loss=', '0.000991927')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-105 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0106', 'training time (minutes)=', '1.1558', 'loss=', '0.000978391')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-106 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0107', 'training time (minutes)=', '1.0896', 'loss=', '0.000973367')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-107 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0108', 'training time (minutes)=', '1.1008', 'loss=', '0.000962401')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-108 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0109', 'training time (minutes)=', '1.1444', 'loss=', '0.000974943')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-109 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0110', 'training time (minutes)=', '1.0913', 'loss=', '0.000975164')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '1.0961', 'loss=', '0.000963437')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-111 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0112', 'training time (minutes)=', '1.1475', 'loss=', '0.000973175')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-112 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0113', 'training time (minutes)=', '1.0956', 'loss=', '0.000970999')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-113 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0114', 'training time (minutes)=', '1.0822', 'loss=', '0.000978125')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-114 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0115', 'training time (minutes)=', '1.1646', 'loss=', '0.000974446')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-115 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0116', 'training time (minutes)=', '1.1448', 'loss=', '0.000971030')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-116 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0117', 'training time (minutes)=', '1.1026', 'loss=', '0.000969386')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-117 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0118', 'training time (minutes)=', '1.1196', 'loss=', '0.000969205')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-118 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0119', 'training time (minutes)=', '1.1276', 'loss=', '0.000957800')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-119 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0120', 'training time (minutes)=', '1.1323', 'loss=', '0.000946650')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '1.0864', 'loss=', '0.000967066')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-121 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0122', 'training time (minutes)=', '1.0853', 'loss=', '0.000957986')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-122 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0123', 'training time (minutes)=', '1.1597', 'loss=', '0.000970660')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-123 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0124', 'training time (minutes)=', '1.0844', 'loss=', '0.000951554')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-124 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0125', 'training time (minutes)=', '1.0804', 'loss=', '0.000960269')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-125 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0126', 'training time (minutes)=', '1.1366', 'loss=', '0.000956991')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-126 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0127', 'training time (minutes)=', '1.0844', 'loss=', '0.000965357')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-127 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0128', 'training time (minutes)=', '1.1396', 'loss=', '0.000965243')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-128 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0129', 'training time (minutes)=', '1.0945', 'loss=', '0.000941704')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-129 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0130', 'training time (minutes)=', '1.0952', 'loss=', '0.000958581')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '1.1301', 'loss=', '0.000956802')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-131 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0132', 'training time (minutes)=', '1.0795', 'loss=', '0.000956721')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-132 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0133', 'training time (minutes)=', '1.0814', 'loss=', '0.000952401')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-133 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0134', 'training time (minutes)=', '1.1540', 'loss=', '0.000953999')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-134 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0135', 'training time (minutes)=', '1.0834', 'loss=', '0.000964696')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-135 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0136', 'training time (minutes)=', '1.0897', 'loss=', '0.000950414')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-136 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0137', 'training time (minutes)=', '1.1652', 'loss=', '0.000958709')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-137 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0138', 'training time (minutes)=', '1.0901', 'loss=', '0.000950596')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-138 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0139', 'training time (minutes)=', '1.0904', 'loss=', '0.000945164')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-139 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0140', 'training time (minutes)=', '1.1345', 'loss=', '0.000955820')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '1.1375', 'loss=', '0.000946182')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-141 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0142', 'training time (minutes)=', '1.1416', 'loss=', '0.000945688')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-142 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0143', 'training time (minutes)=', '1.0912', 'loss=', '0.000946712')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-143 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0144', 'training time (minutes)=', '1.0819', 'loss=', '0.000941178')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-144 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0145', 'training time (minutes)=', '1.1303', 'loss=', '0.000947419')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-145 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0146', 'training time (minutes)=', '1.1117', 'loss=', '0.000951531')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-146 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0147', 'training time (minutes)=', '1.1259', 'loss=', '0.000948101')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-147 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0148', 'training time (minutes)=', '1.0810', 'loss=', '0.000949997')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-148 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0149', 'training time (minutes)=', '1.0821', 'loss=', '0.000957373')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-149 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0150', 'training time (minutes)=', '1.1440', 'loss=', '0.000944071')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '1.0836', 'loss=', '0.000944629')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-151 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0152', 'training time (minutes)=', '1.1255', 'loss=', '0.000950607')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-152 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0153', 'training time (minutes)=', '1.0960', 'loss=', '0.000937622')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-153 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0154', 'training time (minutes)=', '1.1251', 'loss=', '0.000939219')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-154 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0155', 'training time (minutes)=', '1.0868', 'loss=', '0.000940299')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-155 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0156', 'training time (minutes)=', '1.2290', 'loss=', '0.000950398')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-156 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0157', 'training time (minutes)=', '1.0912', 'loss=', '0.000946951')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-157 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0158', 'training time (minutes)=', '1.1186', 'loss=', '0.000941728')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-158 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0159', 'training time (minutes)=', '1.0798', 'loss=', '0.000941492')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-159 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0160', 'training time (minutes)=', '1.1228', 'loss=', '0.000928054')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '1.1805', 'loss=', '0.000937935')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-161 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0162', 'training time (minutes)=', '1.1212', 'loss=', '0.000944537')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-162 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0163', 'training time (minutes)=', '1.0869', 'loss=', '0.000938754')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-163 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0164', 'training time (minutes)=', '1.1197', 'loss=', '0.000952310')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-164 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0165', 'training time (minutes)=', '1.1256', 'loss=', '0.000937224')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-165 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0166', 'training time (minutes)=', '1.1205', 'loss=', '0.000947566')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-166 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0167', 'training time (minutes)=', '1.0813', 'loss=', '0.000929208')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-167 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0168', 'training time (minutes)=', '1.1178', 'loss=', '0.000930748')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-168 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0169', 'training time (minutes)=', '1.1134', 'loss=', '0.000935554')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-169 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0170', 'training time (minutes)=', '1.1202', 'loss=', '0.000937945')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '1.0800', 'loss=', '0.000930646')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-171 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0172', 'training time (minutes)=', '1.1158', 'loss=', '0.000938303')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-172 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0173', 'training time (minutes)=', '1.0909', 'loss=', '0.000919573')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-173 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0174', 'training time (minutes)=', '1.2183', 'loss=', '0.000934308')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-174 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0175', 'training time (minutes)=', '1.2407', 'loss=', '0.000933929')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-175 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0176', 'training time (minutes)=', '1.2453', 'loss=', '0.000926179')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-176 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0177', 'training time (minutes)=', '1.2316', 'loss=', '0.000942508')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-177 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0178', 'training time (minutes)=', '1.0843', 'loss=', '0.000931626')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-178 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0179', 'training time (minutes)=', '1.1241', 'loss=', '0.000926890')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-179 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0180', 'training time (minutes)=', '1.0775', 'loss=', '0.000913059')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '1.1941', 'loss=', '0.000930625')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-181 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0182', 'training time (minutes)=', '1.1701', 'loss=', '0.000915423')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-182 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0183', 'training time (minutes)=', '1.1205', 'loss=', '0.000920831')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-183 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0184', 'training time (minutes)=', '1.1265', 'loss=', '0.000930757')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-184 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0185', 'training time (minutes)=', '1.0821', 'loss=', '0.000919359')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-185 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0186', 'training time (minutes)=', '1.0827', 'loss=', '0.000929618')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-186 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0187', 'training time (minutes)=', '1.1327', 'loss=', '0.000925820')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-187 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0188', 'training time (minutes)=', '1.0890', 'loss=', '0.000898855')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-188 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0189', 'training time (minutes)=', '1.0777', 'loss=', '0.000925194')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-189 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0190', 'training time (minutes)=', '1.1589', 'loss=', '0.000917509')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '1.0869', 'loss=', '0.000919146')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-191 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0192', 'training time (minutes)=', '1.1280', 'loss=', '0.000917340')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-192 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0193', 'training time (minutes)=', '1.0837', 'loss=', '0.000929960')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-193 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0194', 'training time (minutes)=', '1.1678', 'loss=', '0.000915620')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-194 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0195', 'training time (minutes)=', '1.1970', 'loss=', '0.000912619')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-195 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0196', 'training time (minutes)=', '1.2173', 'loss=', '0.000910226')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-196 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0197', 'training time (minutes)=', '1.1709', 'loss=', '0.000923706')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-197 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0198', 'training time (minutes)=', '1.1439', 'loss=', '0.000914871')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-198 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0199', 'training time (minutes)=', '1.0838', 'loss=', '0.000910879')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-199 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0200', 'training time (minutes)=', '1.1251', 'loss=', '0.000930949')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/5_chair_2048_4096pts_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.

# %%
test_stats = eval_model(ae, conf, test_data, epochs=range(1,100,5), verbose=True)
train_stats = eval_model(ae, conf, train_data, epochs=range(1,100,5), verbose=True)

fig, ax = plt.subplots()
plt.plot(range(1, 100, 5), test_stats[:,1], '--b')
plt.plot(range(1, 100, 5), train_stats[:,1], 'r')    
plt.legend(['Test Loss', 'Train Loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
ax.set_xticks(range(1, 100, 5));
# Out:
# Model restored in epoch 1.
# [ 0.00204164]
# Model restored in epoch 6.
# [ 0.00160859]
# Model restored in epoch 11.
# [ 0.00141791]
# Model restored in epoch 16.
# [ 0.00126694]
# Model restored in epoch 21.
# [ 0.00121869]
# Model restored in epoch 26.
# [ 0.00116166]
# Model restored in epoch 31.
# [ 0.001273]
# Model restored in epoch 36.
# [ 0.00116595]
# Model restored in epoch 41.
# [ 0.00113918]
# Model restored in epoch 46.
# [ 0.0011395]
# Model restored in epoch 51.
# [ 0.00109618]
# Model restored in epoch 56.
# [ 0.00114928]
# Model restored in epoch 61.
# [ 0.00114104]
# Model restored in epoch 66.
# [ 0.00109909]
# Model restored in epoch 71.
# [ 0.00109086]
# Model restored in epoch 76.
# [ 0.00111257]
# Model restored in epoch 81.
# [ 0.00108371]
# Model restored in epoch 86.
# [ 0.001148]
# Model restored in epoch 91.
# [ 0.0010728]
# Model restored in epoch 96.
# [ 0.00111379]

# %%
best_epoch = 100
do_evaluation = True
if do_evaluation:    
#     Pick the epoch that minimizes the loss on the validation dataset.
#     saved_epochs = np.array(read_saved_epochs(conf.train_dir))
#     allowable_epochs = saved_epochs[saved_epochs <= max_evaluation_epochs]
#     val_stats = eval_model(ae, conf, val_data, epochs=allowable_epochs, verbose=True)
#     val_loss = np.min(val_stats[:,1])
#     best_epoch = int(val_stats[np.argmin(val_stats[:,1]), 0])
    print 'Best epoch = %d.' % (best_epoch, )
    ae.restore_model(conf.train_dir, best_epoch)
    top_save_dir = osp.join(conf.train_dir, 'output', 'epoch_' + str(best_epoch))
    test_recon, test_loss, test_feed, test_ids, test_gt = ae.evaluate(test_data, conf)
    save_dir = osp.join(top_save_dir, 'test_predictions')
#     save_reconstructions(save_dir, test_recon, test_gt, test_feed, test_ids) # save ply files of test data.    
#     train_loss = ae.evaluate(train_data, conf)[1]
    
    # Report Accuracy and Coverage of test data.
    n_examples = len(test_recon)
    pred_scores = np.zeros((n_examples, 2))
    for i in xrange(n_examples):
        gt = test_gt[i]
        pred = test_recon[i] 
        pred_scores[i, 0] = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=False)
        pred_scores[i, 1] = coverage_of_completion(gt, pred, thres=0.02, ret_dists=False)
                
    print 'Test Median Accuracy-Coverage:', np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])
    print 'Test Median H-Measure:', np.median(hmean(pred_scores, axis=1))

#     save_pc_prediction_stats(osp.join(top_save_dir, 'detailed_stats.txt'), test_ids, pred_scores)
    
#     with open(osp.join(top_save_dir, 'stats.txt'), 'a') as fout:
#         fout.write('Best Validation Epoch = %d\n' % (best_epoch))
#         fout.write('Validation loss = %f\n' % (val_loss))
#         fout.write('Train loss = %f\n' % (train_loss))
#         fout.write('Test loss = %f\n' % (test_loss))
#         fout.write('Gen. Error (abs, per) = %f %f\n' % (abs(test_loss-train_loss),  abs(test_loss-train_loss) / train_loss ))
#         fout.write('Test Median-Accuracy-Coverage = %f %f\n' % (np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])))
#         fout.write('Test Median Harmonic Mean = %f\n' % (np.median(hmean(pred_scores, 1))))
#         fout.write('Number of distinct Test Models = %d (test_files=%d)\n' % (n_test_models, test_data.num_examples))
# Out:
# Best epoch = 100.
# Test Median Accuracy-Coverage: 0.89501953125 0.7939453125
# Test Median H-Measure: 0.837636650588

# %%
n_best = 500
n_worst = 50

if do_detailed_plotting:
    plt.ioff()
    h_measure = hmean(pred_scores, axis=1)  
    sort_ind = np.argsort(h_measure)
    worst_n = sort_ind[:n_worst]
    best_n = sort_ind[-n_best:]    
    
    save_dir = osp.join(top_save_dir, str(n_best) +'_best_test_predictions')
    create_dir(save_dir)
    
    for i in xrange(n_best):
        good = best_n[i]
        gt = test_gt[good]
        pred = test_recon[good]   
        feed = test_feed[good]
        model_name = test_ids[good]

        ac_meas, ac_col = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=True)
        cov_meas, cov_col = coverage_of_completion(gt, pred, thres=0.02, ret_dists=True)
                    
        ac_col[ac_col <= 0.02] = 0.021
        cov_col[cov_col <= 0.02] = 0.021

        feed_fig = plot_3d_point_cloud_paper(Point_Cloud(points=feed), in_u_sphere=True, show=False);        
        feed_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.feed.png')); plt.close()

        c = ac_col
        pred_fig = plot_3d_point_cloud_paper(Point_Cloud(points=pred), c=c, in_u_sphere=True, show=False);
        pred_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.prediction.png')); plt.close()

        c = cov_col
        gt_fig = plot_3d_point_cloud_paper(Point_Cloud(points=gt), c=c, in_u_sphere=True, show=False);
        gt_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.gt.png')); plt.close()
        
    save_dir = osp.join(top_save_dir, str(n_worst) +'_worst_test_predictions')
    create_dir(save_dir)
    for i in xrange(n_worst):
        bad = worst_n[i]
        gt = test_gt[bad]
        pred = test_recon[bad]   
        feed = test_feed[bad]
        model_name = test_ids[bad]

        ac_meas, ac_col = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=True)
        cov_meas, cov_col = coverage_of_completion(gt, pred, thres=0.02, ret_dists=True)
                    
        ac_col[ac_col <= 0.02] = 0.021
        cov_col[cov_col <= 0.02] = 0.021

        feed_fig = plot_3d_point_cloud_paper(Point_Cloud(points=feed), in_u_sphere=True, show=False);        
        feed_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.feed.png')); plt.close()

        c = ac_col
        pred_fig = plot_3d_point_cloud_paper(Point_Cloud(points=pred), c=c, in_u_sphere=True, show=False);
        pred_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.prediction.png')); plt.close()

        c = cov_col
        gt_fig = plot_3d_point_cloud_paper(Point_Cloud(points=gt), c=c, in_u_sphere=True, show=False);
        gt_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.gt.png')); plt.close()
