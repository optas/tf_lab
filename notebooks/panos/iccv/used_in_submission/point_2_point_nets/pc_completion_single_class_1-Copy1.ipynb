# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 1
setup_one_gpu(GPU)
# Out:
# Picking GPU 1

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy.stats import hmean

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, points_extension, \
                                                 shape_net_core_synth_id_to_category

from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch

from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs, accuracy_of_completion, \
                                           coverage_of_completion, save_reconstructions, \
                                           save_pc_prediction_stats, \
                                           paper_pc_completion_experiment_id_best_epoch
                                           
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud


from tf_lab.autopredictors.scripts.virt_scan_data import load_partial_pointclouds
import tf_lab.autopredictors.scripts.virt_scan_data as vscan
from general_tools.simpletons import indices_in_iterable

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
loss = 'chamfer'

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]

incomplete_n_samples = 2048
complete_n_samples = 4096
max_training_epochs = 100

do_training = True
load_training_data = True
load_model_conf = False
do_evaluation = True
do_detailed_plotting = True

# experiment_id, best_epoch = paper_pc_completion_experiment_id_best_epoch(class_type, loss)

experiment_id = 3
experiment_name = str(experiment_id) + '_' + class_type + '_' + str(incomplete_n_samples) + '_' \
                  + str(complete_n_samples) + 'pts_' + loss


top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'

complete_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/raw', \
                             str(complete_n_samples), class_syn_id)

partial_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Partial_PCs/Angela_synthetic', str(incomplete_n_samples))

n_input = [incomplete_n_samples, 3]
n_output = [complete_n_samples, 3]

train_dir = osp.join(top_data_dir, 'OUT/iccv/nn_models/testing')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

max_evaluation_epochs = max_training_epochs
# Out:
# Give me the class type.
# chair

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
cmpl_file_names = pio.load_filenames_of_input_data(complete_pclouds_path, points_extension)
cmpl_pclouds, cmpl_model_names, cmpl_syn_ids = pio.load_crude_point_clouds(file_names=cmpl_file_names, n_threads=40)
assert(len(np.unique(cmpl_syn_ids)) == 1)
print '%d files containing complete point clouds were found.' % (len(cmpl_pclouds), )
# Out:
# 6778 files containing complete point clouds were found.

# %%
train_list = '/orions4-zfs/projects/lins2/Panos_Space/DATA/From_Matthias/train_test_splits/train_models_with_scan_id.txt'
partial_pclouds, partial_model_ids, partial_syn_ids = load_partial_pointclouds(train_list, partial_pclouds_path, 
                                                                               50, class_restriction=class_syn_id)
partial_model_names = np.array([i[0] for i in partial_model_ids], dtype=object)
partial_scan_ids = np.array([i[1] for i in partial_model_ids], dtype=object)
partial_unames = np.array(partial_model_names + '.' + partial_scan_ids + '.' + partial_syn_ids, dtype=object)

matching_index = indices_in_iterable(cmpl_model_names, partial_model_names)
assert(np.alltrue(matching_index != -1))
full_pclouds_matched = cmpl_pclouds[matching_index]
train_data = PointCloudDataSet(full_pclouds_matched, noise=partial_pclouds, labels=partial_unames)
# Out:
# 30000 partial point clouds were loaded.

# %%
test_list = '/orions4-zfs/projects/lins2/Panos_Space/DATA/From_Matthias/train_test_splits/test_models_small_with_scan_id.txt'
test_pclouds, test_model_ids, test_syn_ids = load_partial_pointclouds(test_list, partial_pclouds_path, 
                                                                               50, class_restriction=class_syn_id)
test_model_names = np.array([i[0] for i in test_model_ids], dtype=object)
test_scan_ids = np.array([i[1] for i in test_model_ids], dtype=object)
test_unames = np.array(test_model_names + '.' + test_scan_ids + '.' + test_syn_ids, dtype=object)
matching_index = indices_in_iterable(cmpl_model_names, test_model_names)
assert(np.alltrue(matching_index != -1))
test_data = PointCloudDataSet(cmpl_pclouds[matching_index], noise=test_pclouds, labels=test_unames)
# Out:
# 6000 partial point clouds were loaded.

# %%
pp = train_data.next_batch(1)
pinc = pp[2].reshape(incomplete_n_samples, 3)
pcom = pp[0].reshape(complete_n_samples, 3)

score1 = accuracy_of_completion(pinc, pcom, 0.02, ret_dists=False)
score2, c2 = coverage_of_completion(pcom, pinc, 0.02, ret_dists=True)
print score1, score2
Point_Cloud(points=pinc).plot();
Point_Cloud(points=pcom).plot(c=c2);
# Out:
# 0.99169921875 0.641357421875
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
train_data, val_data = vscan.make_validation_from_train_data(train_data, 0.05)

# %%
if load_model_conf:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:    
    encoder_args = {'n_filters': [64, 128, 1024],
                    'filter_sizes': [1, 1, 1],
                    'strides': [1, 1, 1],
                    'dropout_prob': 0.5
                   }
    
    decoder_args = {'layer_sizes': [1024, np.prod(n_output)]}
    
    conf = Conf(
                n_input = n_input,
                n_output = n_output,
                denoising = True,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 1,
                learning_rate = 0.0005,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )
    
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
    ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.8223', 'loss=', '0.001857002')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '0.8208', 'loss=', '0.001094603')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-2 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0003', 'training time (minutes)=', '0.8293', 'loss=', '0.000951953')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-3 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0004', 'training time (minutes)=', '0.8350', 'loss=', '0.000871567')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-4 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0005', 'training time (minutes)=', '0.8353', 'loss=', '0.000823987')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-5 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0006', 'training time (minutes)=', '0.8386', 'loss=', '0.000786381')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-6 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0007', 'training time (minutes)=', '0.8484', 'loss=', '0.000753208')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-7 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0008', 'training time (minutes)=', '0.8410', 'loss=', '0.000726372')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-8 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0009', 'training time (minutes)=', '0.8422', 'loss=', '0.000709060')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-9 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0010', 'training time (minutes)=', '0.8347', 'loss=', '0.000689940')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '0.8357', 'loss=', '0.000669390')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-11 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0012', 'training time (minutes)=', '0.9015', 'loss=', '0.000656506')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-12 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0013', 'training time (minutes)=', '0.8528', 'loss=', '0.000642585')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-13 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0014', 'training time (minutes)=', '0.8826', 'loss=', '0.000633434')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-14 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0015', 'training time (minutes)=', '0.8784', 'loss=', '0.000618188')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-15 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0016', 'training time (minutes)=', '0.9139', 'loss=', '0.000608786')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-16 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0017', 'training time (minutes)=', '0.8879', 'loss=', '0.000599427')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-17 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0018', 'training time (minutes)=', '0.8836', 'loss=', '0.000591972')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-18 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0019', 'training time (minutes)=', '0.8678', 'loss=', '0.000585415')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-19 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0020', 'training time (minutes)=', '0.8780', 'loss=', '0.000574740')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '0.8625', 'loss=', '0.000567011')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-21 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0022', 'training time (minutes)=', '0.8676', 'loss=', '0.000561472')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-22 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0023', 'training time (minutes)=', '0.8687', 'loss=', '0.000553769')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-23 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0024', 'training time (minutes)=', '0.8638', 'loss=', '0.000548494')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-24 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0025', 'training time (minutes)=', '0.8654', 'loss=', '0.000543853')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-25 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0026', 'training time (minutes)=', '0.8711', 'loss=', '0.000537308')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-26 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0027', 'training time (minutes)=', '0.8829', 'loss=', '0.000532366')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-27 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0028', 'training time (minutes)=', '0.8900', 'loss=', '0.000526896')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-28 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0029', 'training time (minutes)=', '0.8835', 'loss=', '0.000521265')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-29 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0030', 'training time (minutes)=', '0.8956', 'loss=', '0.000518170')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '0.9237', 'loss=', '0.000513517')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-31 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0032', 'training time (minutes)=', '0.8644', 'loss=', '0.000512265')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-32 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0033', 'training time (minutes)=', '0.8872', 'loss=', '0.000505420')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-33 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0034', 'training time (minutes)=', '0.9504', 'loss=', '0.000500661')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-34 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0035', 'training time (minutes)=', '0.9578', 'loss=', '0.000497579')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-35 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0036', 'training time (minutes)=', '0.9449', 'loss=', '0.000493479')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-36 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0037', 'training time (minutes)=', '0.8795', 'loss=', '0.000490534')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-37 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0038', 'training time (minutes)=', '0.9046', 'loss=', '0.000486609')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-38 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0039', 'training time (minutes)=', '0.9028', 'loss=', '0.000484997')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-39 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0040', 'training time (minutes)=', '0.9153', 'loss=', '0.000480956')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '0.8857', 'loss=', '0.000477999')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-41 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0042', 'training time (minutes)=', '0.8973', 'loss=', '0.000475230')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-42 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0043', 'training time (minutes)=', '0.8851', 'loss=', '0.000473528')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-43 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0044', 'training time (minutes)=', '0.8675', 'loss=', '0.000469617')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-44 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0045', 'training time (minutes)=', '0.8971', 'loss=', '0.000468556')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-45 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0046', 'training time (minutes)=', '0.9092', 'loss=', '0.000465248')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-46 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0047', 'training time (minutes)=', '0.8959', 'loss=', '0.000462250')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-47 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0048', 'training time (minutes)=', '0.9406', 'loss=', '0.000459641')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-48 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0049', 'training time (minutes)=', '0.8967', 'loss=', '0.000459392')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-49 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0050', 'training time (minutes)=', '0.8853', 'loss=', '0.000455184')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '0.8810', 'loss=', '0.000453936')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-51 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0052', 'training time (minutes)=', '0.8837', 'loss=', '0.000452908')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-52 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0053', 'training time (minutes)=', '0.9533', 'loss=', '0.000449220')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-53 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0054', 'training time (minutes)=', '0.9068', 'loss=', '0.000447159')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-54 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0055', 'training time (minutes)=', '0.8864', 'loss=', '0.000445250')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-55 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0056', 'training time (minutes)=', '0.9278', 'loss=', '0.000442841')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-56 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0057', 'training time (minutes)=', '0.9169', 'loss=', '0.000441982')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-57 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0058', 'training time (minutes)=', '0.9111', 'loss=', '0.000440614')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-58 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0059', 'training time (minutes)=', '0.8970', 'loss=', '0.000437563')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-59 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0060', 'training time (minutes)=', '0.8753', 'loss=', '0.000435415')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '0.8898', 'loss=', '0.000436177')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-61 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0062', 'training time (minutes)=', '0.8673', 'loss=', '0.000432609')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0063', 'training time (minutes)=', '0.8813', 'loss=', '0.000433174')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-63 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0064', 'training time (minutes)=', '0.8843', 'loss=', '0.000431052')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0065', 'training time (minutes)=', '0.8761', 'loss=', '0.000428766')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-65 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0066', 'training time (minutes)=', '0.8861', 'loss=', '0.000427629')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0067', 'training time (minutes)=', '0.9052', 'loss=', '0.000426340')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-67 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0068', 'training time (minutes)=', '0.8855', 'loss=', '0.000423937')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0069', 'training time (minutes)=', '0.8957', 'loss=', '0.000423853')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-69 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0070', 'training time (minutes)=', '0.8781', 'loss=', '0.000421771')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '0.8802', 'loss=', '0.000420101')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-71 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0072', 'training time (minutes)=', '0.8831', 'loss=', '0.000419397')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0073', 'training time (minutes)=', '0.8853', 'loss=', '0.000418560')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-73 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0074', 'training time (minutes)=', '0.8789', 'loss=', '0.000416581')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0075', 'training time (minutes)=', '0.8903', 'loss=', '0.000415954')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-75 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0076', 'training time (minutes)=', '0.8793', 'loss=', '0.000414005')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0077', 'training time (minutes)=', '0.8676', 'loss=', '0.000413595')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-77 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0078', 'training time (minutes)=', '0.9582', 'loss=', '0.000412556')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0079', 'training time (minutes)=', '0.9100', 'loss=', '0.000413140')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-79 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0080', 'training time (minutes)=', '0.9163', 'loss=', '0.000409520')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '0.8761', 'loss=', '0.000407722')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-81 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0082', 'training time (minutes)=', '0.8835', 'loss=', '0.000407851')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0083', 'training time (minutes)=', '0.8803', 'loss=', '0.000406971')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-83 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0084', 'training time (minutes)=', '0.8790', 'loss=', '0.000406657')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0085', 'training time (minutes)=', '0.8841', 'loss=', '0.000403774')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-85 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0086', 'training time (minutes)=', '0.8898', 'loss=', '0.000404058')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0087', 'training time (minutes)=', '0.9078', 'loss=', '0.000402161')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-87 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0088', 'training time (minutes)=', '0.8882', 'loss=', '0.000402140')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0089', 'training time (minutes)=', '0.8811', 'loss=', '0.000401937')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-89 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0090', 'training time (minutes)=', '0.8823', 'loss=', '0.000400908')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '0.9014', 'loss=', '0.000398659')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-91 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0092', 'training time (minutes)=', '0.8690', 'loss=', '0.000398956')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-92 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0093', 'training time (minutes)=', '0.8687', 'loss=', '0.000397226')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-93 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0094', 'training time (minutes)=', '1.0193', 'loss=', '0.000397645')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-94 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0095', 'training time (minutes)=', '0.8846', 'loss=', '0.000394844')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-95 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0096', 'training time (minutes)=', '0.8852', 'loss=', '0.000395923')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-96 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0097', 'training time (minutes)=', '0.8939', 'loss=', '0.000395265')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-97 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0098', 'training time (minutes)=', '0.8784', 'loss=', '0.000393119')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-98 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0099', 'training time (minutes)=', '0.8773', 'loss=', '0.000392333')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-99 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0100', 'training time (minutes)=', '0.9258', 'loss=', '0.000392062')
# yo
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iccv/nn_models/testing/3_chair_2048_4096pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.

# %%
val_stats = eval_model(ae, conf, val_data, epochs=range(1,100,5), verbose=True)
train_stats = eval_model(ae, conf, train_data, epochs=range(1,100,5), verbose=True)

fig, ax = plt.subplots()
plt.plot(range(1, 100, 5), val_stats[:,1], '--b')
plt.plot(range(1, 100, 5), train_stats[:,1], 'r')    
plt.legend(['Validation Loss', 'Train Loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
ax.set_xticks(range(1, 100, 5));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5b7cfb763996> in <module>()
# ----> 1 val_stats = eval_model(ae, conf, val_data, epochs=range(1,100,5), verbose=True)
#       2 train_stats = eval_model(ae, conf, train_data, epochs=range(1,100,5), verbose=True)
#       3
#       4 fig, ax = plt.subplots()
#       5 plt.plot(range(1, 100, 5), val_stats[:,1], '--b')
#
# NameError: name 'val_data' is not defined

# %%
best_epoch = 20
if do_evaluation:    
#     Pick the epoch that minimizes the loss on the validation dataset.
#     saved_epochs = np.array(read_saved_epochs(conf.train_dir))
#     allowable_epochs = saved_epochs[saved_epochs <= max_evaluation_epochs]
#     val_stats = eval_model(ae, conf, val_data, epochs=allowable_epochs, verbose=True)
#     val_loss = np.min(val_stats[:,1])
#     best_epoch = int(val_stats[np.argmin(val_stats[:,1]), 0])
    print 'Best epoch = %d.' % (best_epoch, )
    ae.restore_model(conf.train_dir, best_epoch)
    top_save_dir = osp.join(conf.train_dir, 'output', 'epoch_' + str(best_epoch))
    test_recon, test_loss, test_feed, test_ids, test_gt = ae.evaluate(test_data, conf)
    save_dir = osp.join(top_save_dir, 'test_predictions')
#     save_reconstructions(save_dir, test_recon, test_gt, test_feed, test_ids) # save ply files of test data.    
#     train_loss = ae.evaluate(train_data, conf)[1]
    
    # Report Accuracy and Coverage of test data.
#     n_examples = len(test_recon)
    pred_scores = np.zeros((n_examples, 2))
    for i in xrange(n_examples):
        gt = test_gt[i]
        pred = test_recon[i] 
        pred_scores[i, 0] = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=False)
        pred_scores[i, 1] = coverage_of_completion(gt, pred, thres=0.02, ret_dists=False)
                
    print 'Test Median Accuracy-Coverage:', np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])
    print 'Test Median H-Measure:', np.median(hmean(pred_scores, axis=1))

#     save_pc_prediction_stats(osp.join(top_save_dir, 'detailed_stats.txt'), test_ids, pred_scores)
    
#     with open(osp.join(top_save_dir, 'stats.txt'), 'a') as fout:
#         fout.write('Best Validation Epoch = %d\n' % (best_epoch))
#         fout.write('Validation loss = %f\n' % (val_loss))
#         fout.write('Train loss = %f\n' % (train_loss))
#         fout.write('Test loss = %f\n' % (test_loss))
#         fout.write('Gen. Error (abs, per) = %f %f\n' % (abs(test_loss-train_loss),  abs(test_loss-train_loss) / train_loss ))
#         fout.write('Test Median-Accuracy-Coverage = %f %f\n' % (np.median(pred_scores[:, 0]), np.median(pred_scores[:, 1])))
#         fout.write('Test Median Harmonic Mean = %f\n' % (np.median(hmean(pred_scores, 1))))
#         fout.write('Number of distinct Test Models = %d (test_files=%d)\n' % (n_test_models, test_data.num_examples))
# Out:
# Best epoch = 20.
# Test Median Accuracy-Coverage: 0.886840820312 0.72119140625
# Test Median H-Measure: 0.794919620573

# %%
n_best = 500
n_worst = 50

if do_detailed_plotting:
    plt.ioff()
    h_measure = hmean(pred_scores, axis=1)  
    sort_ind = np.argsort(h_measure)
    worst_n = sort_ind[:n_worst]
    best_n = sort_ind[-n_best:]    
    
    save_dir = osp.join(top_save_dir, str(n_best) +'_best_test_predictions')
    create_dir(save_dir)
    
    for i in xrange(n_best):
        good = best_n[i]
        gt = test_gt[good]
        pred = test_recon[good]   
        feed = test_feed[good]
        model_name = test_ids[good]

        ac_meas, ac_col = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=True)
        cov_meas, cov_col = coverage_of_completion(gt, pred, thres=0.02, ret_dists=True)
                    
        ac_col[ac_col <= 0.02] = 0.021
        cov_col[cov_col <= 0.02] = 0.021

        feed_fig = plot_3d_point_cloud_paper(Point_Cloud(points=feed), in_u_sphere=True, show=False);        
        feed_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.feed.png')); plt.close()

        c = ac_col
        pred_fig = plot_3d_point_cloud_paper(Point_Cloud(points=pred), c=c, in_u_sphere=True, show=False);
        pred_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.prediction.png')); plt.close()

        c = cov_col
        gt_fig = plot_3d_point_cloud_paper(Point_Cloud(points=gt), c=c, in_u_sphere=True, show=False);
        gt_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.gt.png')); plt.close()
        
    save_dir = osp.join(top_save_dir, str(n_worst) +'_worst_test_predictions')
    create_dir(save_dir)
    for i in xrange(n_worst):
        bad = worst_n[i]
        gt = test_gt[bad]
        pred = test_recon[bad]   
        feed = test_feed[bad]
        model_name = test_ids[bad]

        ac_meas, ac_col = accuracy_of_completion(pred, gt, thres=0.02, ret_dists=True)
        cov_meas, cov_col = coverage_of_completion(gt, pred, thres=0.02, ret_dists=True)
                    
        ac_col[ac_col <= 0.02] = 0.021
        cov_col[cov_col <= 0.02] = 0.021

        feed_fig = plot_3d_point_cloud_paper(Point_Cloud(points=feed), in_u_sphere=True, show=False);        
        feed_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.feed.png')); plt.close()

        c = ac_col
        pred_fig = plot_3d_point_cloud_paper(Point_Cloud(points=pred), c=c, in_u_sphere=True, show=False);
        pred_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.prediction.png')); plt.close()

        c = cov_col
        gt_fig = plot_3d_point_cloud_paper(Point_Cloud(points=gt), c=c, in_u_sphere=True, show=False);
        gt_fig.savefig(osp.join(save_dir, str(i) + '.' + model_name + '.gt.png')); plt.close()
