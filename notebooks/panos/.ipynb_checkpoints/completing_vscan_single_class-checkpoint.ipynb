# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, match_incomplete_to_complete_data
from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch, \
                                           plot_interpolations
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs
                                                  


from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
experiment_name = '1_virt_scan_emd_2fc_decoder_2048pts'
do_training = True
do_plotting = True
first_time_running = True
load_model = False

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]
# Out:
# Give me the class type.
# chair

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/2048/', class_syn_id)

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/1_virt_scan_emd_2fc_decoder_2048pts'

# %%
full_file_names = pio.load_filenames_of_input_data(full_pclouds_path)
full_pclouds, full_model_names, class_ids = pio.load_crude_point_clouds(file_names=full_file_names, n_threads=20)
print '%d files containing complete point clouds were found.' % (len(full_pclouds), )
# Out:
# 6778 files containing complete point clouds were found.

# %%
# Make dictionary with train
train_id_file = '/orions4-zfs/projects/lins2/Panos_Space/DATA/From_Matthias/shapenet_all-train.txt'
from collections import defaultdict
train_data_dict = defaultdict(dict)
with open(train_id_file, 'r') as f_in:
    for line in f_in:
        syn_id, model_id = line.split()
        if len(train_data_dict[syn_id]) == 0:
            train_data_dict[syn_id] = set()
        train_data_dict[syn_id].add(model_id)

# %%
import time

vscan_search_pattern = '.ply'
vscan_scan_pattern = '__?__.ply'
n_samples=2048

virtual_scan_data = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)

def _load_virtual_scan_incomplete_pcloud_temp(f_name):
    pc = Point_Cloud(ply_file=f_name)
    pc.permute_points([0, 2, 1])
    pc, _ = pc.sample(n_samples)
    pc.lex_sort()
    pc.center_in_unit_sphere()
    tokens = f_name.split('/')
    model_id = tokens[-1][:-len(vscan_scan_pattern)]
    scan_id = tokens[-1][-len(vscan_scan_pattern):-(len('.ply'))]
    class_id = tokens[-2]
    return pc.points, (model_id, scan_id), class_id



a = time.time()

noisy_pcloud_files = pio.load_filenames_of_input_data(virtual_scan_data, vscan_search_pattern)
keep = np.zeros([len(noisy_pcloud_files)], dtype=np.bool)

for i, f in enumerate(noisy_pcloud_files):    
    model_id = f.split('/')[-1][:-len(vscan_scan_pattern)]
    if model_id in train_data_dict[class_syn_id]:
        keep[i] = True

noisy_pcloud_files = np.array(noisy_pcloud_files, dtype=object)
noisy_pcloud_files = noisy_pcloud_files[keep]
noisy_pclouds, noisy_ids, class_ids = pio.load_crude_point_clouds(file_names=noisy_pcloud_files, n_threads=22,
                                                                  loader=_load_virtual_scan_incomplete_pcloud_temp)
    
print '%d files containing noisy point clouds were found.' % (len(noisy_pclouds), )

scan_ids = np.empty([len(noisy_ids)], dtype=object)
noisy_model_names = np.empty([len(noisy_ids)], dtype=object)
for i, item in enumerate(noisy_ids):
    noisy_model_names[i] = item[0]
    scan_ids[i] = item[1]

print time.time() - a
# Out:
# 0.0251309871674

# %%
# # Match incomplete to complete data.
mapping = match_incomplete_to_complete_data(full_model_names, noisy_model_names)
full_pclouds_matched = full_pclouds[mapping]

# %%
ids = noisy_model_names + '.' + scan_ids
train_data = PointCloudDataSet(full_pclouds_matched, noise=noisy_pclouds, labels=ids)

# %%
# TRY ME.
pp = train_data.next_batch(1)
Point_Cloud(points=pp[2].reshape(2048, 3)).plot();
Point_Cloud(points=pp[0].reshape(2048, 3)).plot();

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    n_input = [2048, 3]    
    decoder_args = {'layer_sizes': [1024, np.prod(n_input)], 
                    'non_linearity': tf.nn.tanh
                   }

    conf = Conf(
                n_input = n_input,
                denoising = True,
                training_epochs = 500,
                batch_size = 50,
                loss = 'emd',
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.00002,
                saver_max_to_keep = 50,
                gauss_augment = {'mu': 0, 'sigma': 0.01},
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args,
               )

    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

# %%
reset_tf_graph()
set_visible_GPUs([3])
ae = PointNetAutoEncoder(experiment_name, conf)

if do_training:
    ae.train(train_data, conf)

else:
    saved_epochs = read_saved_epochs(conf.train_dir)
    ae.restore_model(train_dir, saved_epochs[-1])
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '2.6998', 'loss=', '210.772935524')
# ('Epoch:', '0002', 'training time (minutes)=', '2.7101', 'loss=', '180.806267109')
# ('Epoch:', '0003', 'training time (minutes)=', '2.7174', 'loss=', '178.846869259')
# ('Epoch:', '0004', 'training time (minutes)=', '2.7311', 'loss=', '177.688477573')
# ('Epoch:', '0005', 'training time (minutes)=', '2.7979', 'loss=', '177.066676712')
# ('Epoch:', '0006', 'training time (minutes)=', '2.7700', 'loss=', '176.599605846')
# ('Epoch:', '0007', 'training time (minutes)=', '2.7548', 'loss=', '175.908050861')
# ('Epoch:', '0008', 'training time (minutes)=', '2.8352', 'loss=', '175.589590931')
# ('Epoch:', '0009', 'training time (minutes)=', '2.7429', 'loss=', '175.263842564')
# ('Epoch:', '0010', 'training time (minutes)=', '2.7436', 'loss=', '175.404801388')
# ('Epoch:', '0011', 'training time (minutes)=', '2.7336', 'loss=', '174.877454796')
# ('Epoch:', '0012', 'training time (minutes)=', '2.8244', 'loss=', '174.654765377')
# ('Epoch:', '0013', 'training time (minutes)=', '2.7532', 'loss=', '174.353082905')
# ('Epoch:', '0014', 'training time (minutes)=', '2.7678', 'loss=', '174.470022812')
# ('Epoch:', '0015', 'training time (minutes)=', '2.7647', 'loss=', '174.197377090')
# ('Epoch:', '0016', 'training time (minutes)=', '2.7331', 'loss=', '173.937607307')
# ('Epoch:', '0017', 'training time (minutes)=', '2.7432', 'loss=', '173.521294689')
# ('Epoch:', '0018', 'training time (minutes)=', '2.7243', 'loss=', '173.349630814')
# ('Epoch:', '0019', 'training time (minutes)=', '2.7298', 'loss=', '173.177171230')
# ('Epoch:', '0020', 'training time (minutes)=', '2.7051', 'loss=', '173.079649792')
# ('Epoch:', '0021', 'training time (minutes)=', '2.7110', 'loss=', '172.683390408')
# ('Epoch:', '0022', 'training time (minutes)=', '2.7545', 'loss=', '172.151015339')
# ('Epoch:', '0023', 'training time (minutes)=', '2.7188', 'loss=', '172.054315929')
# ('Epoch:', '0024', 'training time (minutes)=', '2.7235', 'loss=', '171.515097599')
# ('Epoch:', '0025', 'training time (minutes)=', '2.7084', 'loss=', '171.363256969')
# ('Epoch:', '0026', 'training time (minutes)=', '2.7057', 'loss=', '170.976111202')
# ('Epoch:', '0027', 'training time (minutes)=', '2.7589', 'loss=', '170.593432560')
# ('Epoch:', '0028', 'training time (minutes)=', '2.7296', 'loss=', '170.250959263')
# ('Epoch:', '0029', 'training time (minutes)=', '2.7369', 'loss=', '169.846392097')
# ('Epoch:', '0030', 'training time (minutes)=', '2.7508', 'loss=', '169.640098152')
# ('Epoch:', '0031', 'training time (minutes)=', '2.7299', 'loss=', '169.211730690')
# ('Epoch:', '0032', 'training time (minutes)=', '2.7216', 'loss=', '168.816967010')
# ('Epoch:', '0033', 'training time (minutes)=', '2.7110', 'loss=', '168.489030247')
# ('Epoch:', '0034', 'training time (minutes)=', '2.7101', 'loss=', '168.040896912')
# ('Epoch:', '0035', 'training time (minutes)=', '2.7505', 'loss=', '167.575375252')
# ('Epoch:', '0036', 'training time (minutes)=', '2.7308', 'loss=', '166.944739208')
# ('Epoch:', '0037', 'training time (minutes)=', '2.7223', 'loss=', '166.638081837')
# ('Epoch:', '0038', 'training time (minutes)=', '2.7144', 'loss=', '166.025237923')
# ('Epoch:', '0039', 'training time (minutes)=', '2.7114', 'loss=', '165.745396938')
# ('Epoch:', '0040', 'training time (minutes)=', '2.7552', 'loss=', '165.012144642')
# ('Epoch:', '0041', 'training time (minutes)=', '2.7277', 'loss=', '164.646672230')
# ('Epoch:', '0042', 'training time (minutes)=', '2.7222', 'loss=', '164.371685581')
# ('Epoch:', '0043', 'training time (minutes)=', '2.7104', 'loss=', '164.061669731')
# ('Epoch:', '0044', 'training time (minutes)=', '2.7106', 'loss=', '163.770544910')
# ('Epoch:', '0045', 'training time (minutes)=', '2.7570', 'loss=', '163.512155552')
# ('Epoch:', '0046', 'training time (minutes)=', '2.7244', 'loss=', '163.006554527')
# ('Epoch:', '0047', 'training time (minutes)=', '2.7268', 'loss=', '162.862301521')
# ('Epoch:', '0048', 'training time (minutes)=', '2.7115', 'loss=', '162.682584229')
# ('Epoch:', '0049', 'training time (minutes)=', '2.7115', 'loss=', '162.503848438')
# ('Epoch:', '0050', 'training time (minutes)=', '2.7567', 'loss=', '162.142846165')
# ('Epoch:', '0051', 'training time (minutes)=', '2.7311', 'loss=', '162.313697319')
# ('Epoch:', '0052', 'training time (minutes)=', '2.7599', 'loss=', '161.900364323')
# ('Epoch:', '0053', 'training time (minutes)=', '2.7263', 'loss=', '161.679901409')
# ('Epoch:', '0054', 'training time (minutes)=', '2.7292', 'loss=', '161.484289150')
# ('Epoch:', '0055', 'training time (minutes)=', '2.7161', 'loss=', '161.404716148')
# ('Epoch:', '0056', 'training time (minutes)=', '2.7151', 'loss=', '161.197954483')
# ('Epoch:', '0057', 'training time (minutes)=', '2.7132', 'loss=', '161.052499943')
# ('Epoch:', '0058', 'training time (minutes)=', '2.7470', 'loss=', '160.832358437')
# ('Epoch:', '0059', 'training time (minutes)=', '2.7285', 'loss=', '161.041181889')
# ('Epoch:', '0060', 'training time (minutes)=', '2.7286', 'loss=', '160.799426994')
# ('Epoch:', '0061', 'training time (minutes)=', '2.7117', 'loss=', '160.637469349')
# ('Epoch:', '0062', 'training time (minutes)=', '2.7103', 'loss=', '160.574534340')
# ('Epoch:', '0063', 'training time (minutes)=', '2.7124', 'loss=', '160.487165565')
# ('Epoch:', '0064', 'training time (minutes)=', '2.7388', 'loss=', '160.491683254')
# ('Epoch:', '0065', 'training time (minutes)=', '2.7259', 'loss=', '160.348081436')
# ('Epoch:', '0066', 'training time (minutes)=', '2.7441', 'loss=', '160.358391209')
# ('Epoch:', '0067', 'training time (minutes)=', '2.7278', 'loss=', '160.476727428')
# ('Epoch:', '0068', 'training time (minutes)=', '2.7236', 'loss=', '160.076905670')
# ('Epoch:', '0069', 'training time (minutes)=', '2.7231', 'loss=', '159.876189346')
# ('Epoch:', '0070', 'training time (minutes)=', '2.7556', 'loss=', '159.876366901')
# ('Epoch:', '0071', 'training time (minutes)=', '2.7225', 'loss=', '159.819345036')
# ('Epoch:', '0072', 'training time (minutes)=', '2.7262', 'loss=', '159.860156136')
# ('Epoch:', '0073', 'training time (minutes)=', '2.7140', 'loss=', '159.612878723')
# ('Epoch:', '0074', 'training time (minutes)=', '2.7129', 'loss=', '159.873672791')
# ('Epoch:', '0075', 'training time (minutes)=', '2.7122', 'loss=', '159.619044170')
# ('Epoch:', '0076', 'training time (minutes)=', '2.7390', 'loss=', '159.618001118')
# ('Epoch:', '0077', 'training time (minutes)=', '2.7297', 'loss=', '159.447435570')
# ('Epoch:', '0078', 'training time (minutes)=', '2.7266', 'loss=', '159.414955559')
# ('Epoch:', '0079', 'training time (minutes)=', '2.7113', 'loss=', '159.467661400')
# ('Epoch:', '0080', 'training time (minutes)=', '2.7166', 'loss=', '159.556061077')
# ('Epoch:', '0081', 'training time (minutes)=', '2.7098', 'loss=', '159.419798355')
# ('Epoch:', '0082', 'training time (minutes)=', '2.7451', 'loss=', '158.963583603')
# ('Epoch:', '0083', 'training time (minutes)=', '2.7227', 'loss=', '159.254925079')
# ('Epoch:', '0084', 'training time (minutes)=', '2.7221', 'loss=', '159.266028538')
# ('Epoch:', '0085', 'training time (minutes)=', '2.7099', 'loss=', '159.233969727')
# ('Epoch:', '0086', 'training time (minutes)=', '2.7098', 'loss=', '159.044578342')
# ('Epoch:', '0087', 'training time (minutes)=', '2.7519', 'loss=', '158.991360855')
# ('Epoch:', '0088', 'training time (minutes)=', '2.7220', 'loss=', '159.040375519')
# ('Epoch:', '0089', 'training time (minutes)=', '2.7249', 'loss=', '158.955099277')
# ('Epoch:', '0090', 'training time (minutes)=', '2.7585', 'loss=', '158.855531960')
# ('Epoch:', '0091', 'training time (minutes)=', '2.7571', 'loss=', '158.993637352')
# ('Epoch:', '0092', 'training time (minutes)=', '2.7232', 'loss=', '158.852818871')
# ('Epoch:', '0093', 'training time (minutes)=', '2.7207', 'loss=', '158.735294399')
# ('Epoch:', '0094', 'training time (minutes)=', '2.7107', 'loss=', '158.784076118')
# ('Epoch:', '0095', 'training time (minutes)=', '2.7098', 'loss=', '158.916847420')
# ('Epoch:', '0096', 'training time (minutes)=', '2.7481', 'loss=', '158.854097328')
# ('Epoch:', '0097', 'training time (minutes)=', '2.7238', 'loss=', '158.563968201')
# ('Epoch:', '0098', 'training time (minutes)=', '2.7181', 'loss=', '158.696968384')
# ('Epoch:', '0099', 'training time (minutes)=', '2.7067', 'loss=', '158.599219418')
# ('Epoch:', '0100', 'training time (minutes)=', '2.7092', 'loss=', '158.577324638')
# ('Epoch:', '0101', 'training time (minutes)=', '2.7579', 'loss=', '158.601245384')
# ('Epoch:', '0102', 'training time (minutes)=', '2.7221', 'loss=', '158.651037750')
# ('Epoch:', '0103', 'training time (minutes)=', '2.7260', 'loss=', '158.542604980')
# ('Epoch:', '0104', 'training time (minutes)=', '2.7538', 'loss=', '158.473261852')
# ('Epoch:', '0105', 'training time (minutes)=', '2.7231', 'loss=', '158.429787960')
# ('Epoch:', '0106', 'training time (minutes)=', '2.7177', 'loss=', '158.543640671')
# ('Epoch:', '0107', 'training time (minutes)=', '2.7085', 'loss=', '158.267263947')
# ('Epoch:', '0108', 'training time (minutes)=', '2.7138', 'loss=', '158.648061638')
# ('Epoch:', '0109', 'training time (minutes)=', '2.7599', 'loss=', '158.333800011')
# ('Epoch:', '0110', 'training time (minutes)=', '2.7223', 'loss=', '158.402844162')
# ('Epoch:', '0111', 'training time (minutes)=', '2.7270', 'loss=', '158.299967346')
# ('Epoch:', '0112', 'training time (minutes)=', '2.7151', 'loss=', '158.361017666')
# ('Epoch:', '0113', 'training time (minutes)=', '2.7093', 'loss=', '158.551773167')
# ('Epoch:', '0114', 'training time (minutes)=', '2.7040', 'loss=', '158.341193523')
# ('Epoch:', '0115', 'training time (minutes)=', '2.7445', 'loss=', '158.275541687')
# ('Epoch:', '0116', 'training time (minutes)=', '2.7249', 'loss=', '158.133965530')
# ('Epoch:', '0117', 'training time (minutes)=', '2.7205', 'loss=', '158.165160427')
# ('Epoch:', '0118', 'training time (minutes)=', '2.7075', 'loss=', '158.286945744')
# ('Epoch:', '0119', 'training time (minutes)=', '2.7112', 'loss=', '158.065635643')
# ('Epoch:', '0120', 'training time (minutes)=', '2.7045', 'loss=', '158.203419724')
# ('Epoch:', '0121', 'training time (minutes)=', '2.7533', 'loss=', '158.057620754')
# ('Epoch:', '0122', 'training time (minutes)=', '2.7252', 'loss=', '158.128939438')
# ('Epoch:', '0123', 'training time (minutes)=', '2.7335', 'loss=', '158.055631866')
# ('Epoch:', '0124', 'training time (minutes)=', '2.7072', 'loss=', '158.095784969')
# ('Epoch:', '0125', 'training time (minutes)=', '2.7024', 'loss=', '158.099455700')
# ('Epoch:', '0126', 'training time (minutes)=', '2.7496', 'loss=', '158.018665180')
# ('Epoch:', '0127', 'training time (minutes)=', '2.7184', 'loss=', '158.072855587')
# ('Epoch:', '0128', 'training time (minutes)=', '2.7241', 'loss=', '158.003754730')
# ('Epoch:', '0129', 'training time (minutes)=', '2.7117', 'loss=', '157.952978249')
# ('Epoch:', '0130', 'training time (minutes)=', '2.7137', 'loss=', '158.060975018')
# ('Epoch:', '0131', 'training time (minutes)=', '2.7127', 'loss=', '158.037378769')
# ('Epoch:', '0132', 'training time (minutes)=', '2.7505', 'loss=', '157.853226948')
# ('Epoch:', '0133', 'training time (minutes)=', '2.7303', 'loss=', '157.881677990')
# ('Epoch:', '0134', 'training time (minutes)=', '2.7263', 'loss=', '157.931000118')
# ('Epoch:', '0135', 'training time (minutes)=', '2.7219', 'loss=', '157.856545582')
# ('Epoch:', '0136', 'training time (minutes)=', '2.7199', 'loss=', '157.931369286')
# ('Epoch:', '0137', 'training time (minutes)=', '2.7196', 'loss=', '157.675612221')
# ('Epoch:', '0138', 'training time (minutes)=', '2.7449', 'loss=', '157.787317371')
# ('Epoch:', '0139', 'training time (minutes)=', '2.7257', 'loss=', '157.744372025')
# ('Epoch:', '0140', 'training time (minutes)=', '2.7326', 'loss=', '157.890389786')
# ('Epoch:', '0141', 'training time (minutes)=', '2.7361', 'loss=', '157.746265182')
# ('Epoch:', '0142', 'training time (minutes)=', '2.7556', 'loss=', '157.640676422')
# ('Epoch:', '0143', 'training time (minutes)=', '2.7297', 'loss=', '157.651070919')
# ('Epoch:', '0144', 'training time (minutes)=', '2.7365', 'loss=', '157.698670883')
# ('Epoch:', '0145', 'training time (minutes)=', '2.7122', 'loss=', '157.548109894')
# ('Epoch:', '0146', 'training time (minutes)=', '2.7148', 'loss=', '157.696393394')
# ('Epoch:', '0147', 'training time (minutes)=', '2.7063', 'loss=', '157.543260498')
# ('Epoch:', '0148', 'training time (minutes)=', '2.7487', 'loss=', '157.597092724')
# ('Epoch:', '0149', 'training time (minutes)=', '2.7257', 'loss=', '157.632447796')
# ('Epoch:', '0150', 'training time (minutes)=', '2.7281', 'loss=', '157.484309196')
# ('Epoch:', '0151', 'training time (minutes)=', '2.7147', 'loss=', '157.637692528')
# ('Epoch:', '0152', 'training time (minutes)=', '2.7161', 'loss=', '157.615902462')
# ('Epoch:', '0153', 'training time (minutes)=', '2.7069', 'loss=', '157.563732090')
# ('Epoch:', '0154', 'training time (minutes)=', '2.7099', 'loss=', '157.443275757')
# ('Epoch:', '0155', 'training time (minutes)=', '2.7593', 'loss=', '157.854448986')
# ('Epoch:', '0156', 'training time (minutes)=', '2.7211', 'loss=', '157.383567657')
# ('Epoch:', '0157', 'training time (minutes)=', '2.7302', 'loss=', '157.567630291')
# ('Epoch:', '0158', 'training time (minutes)=', '2.7134', 'loss=', '157.330975838')
# ('Epoch:', '0159', 'training time (minutes)=', '2.7083', 'loss=', '157.502522926')
# ('Epoch:', '0160', 'training time (minutes)=', '2.7058', 'loss=', '157.563607655')
# ('Epoch:', '0161', 'training time (minutes)=', '2.7445', 'loss=', '157.506171932')
# ('Epoch:', '0162', 'training time (minutes)=', '2.7217', 'loss=', '157.444881535')
# ('Epoch:', '0163', 'training time (minutes)=', '2.7329', 'loss=', '157.327674732')
# ('Epoch:', '0164', 'training time (minutes)=', '2.7164', 'loss=', '157.661987324')
# ('Epoch:', '0165', 'training time (minutes)=', '2.7154', 'loss=', '157.363467083')
# ('Epoch:', '0166', 'training time (minutes)=', '2.7042', 'loss=', '157.272179031')
# ('Epoch:', '0167', 'training time (minutes)=', '2.7494', 'loss=', '157.330732174')
# ('Epoch:', '0168', 'training time (minutes)=', '2.7232', 'loss=', '157.441127987')
# ('Epoch:', '0169', 'training time (minutes)=', '2.7348', 'loss=', '157.341401596')
# ('Epoch:', '0170', 'training time (minutes)=', '2.7222', 'loss=', '157.428527241')
# ('Epoch:', '0171', 'training time (minutes)=', '2.7132', 'loss=', '157.329432240')
# ('Epoch:', '0172', 'training time (minutes)=', '2.7114', 'loss=', '157.419006844')
# ('Epoch:', '0173', 'training time (minutes)=', '2.7538', 'loss=', '157.201382999')
# ('Epoch:', '0174', 'training time (minutes)=', '2.7203', 'loss=', '157.464540424')
# ('Epoch:', '0175', 'training time (minutes)=', '2.7233', 'loss=', '157.453884735')
# ('Epoch:', '0176', 'training time (minutes)=', '2.7091', 'loss=', '157.225212498')
# ('Epoch:', '0177', 'training time (minutes)=', '2.7101', 'loss=', '157.145483532')
# ('Epoch:', '0178', 'training time (minutes)=', '2.7070', 'loss=', '157.309616928')
# ('Epoch:', '0179', 'training time (minutes)=', '2.7405', 'loss=', '157.305023785')
# ('Epoch:', '0180', 'training time (minutes)=', '2.7287', 'loss=', '157.250092182')
# ('Epoch:', '0181', 'training time (minutes)=', '2.7543', 'loss=', '157.222333374')
# ('Epoch:', '0182', 'training time (minutes)=', '2.7230', 'loss=', '157.229244576')
# ('Epoch:', '0183', 'training time (minutes)=', '2.7334', 'loss=', '157.310490990')
# ('Epoch:', '0184', 'training time (minutes)=', '2.7145', 'loss=', '157.304875278')
# ('Epoch:', '0185', 'training time (minutes)=', '2.7153', 'loss=', '156.993700161')
# ('Epoch:', '0186', 'training time (minutes)=', '2.7541', 'loss=', '157.237734890')
# ('Epoch:', '0187', 'training time (minutes)=', '2.7280', 'loss=', '157.143341446')
# ('Epoch:', '0188', 'training time (minutes)=', '2.7533', 'loss=', '157.149176540')
# ('Epoch:', '0189', 'training time (minutes)=', '2.7181', 'loss=', '157.254941444')
# ('Epoch:', '0190', 'training time (minutes)=', '2.7301', 'loss=', '157.095379734')
# ('Epoch:', '0191', 'training time (minutes)=', '2.7101', 'loss=', '157.297945347')
# ('Epoch:', '0192', 'training time (minutes)=', '2.7511', 'loss=', '157.222232895')
# ('Epoch:', '0193', 'training time (minutes)=', '2.7288', 'loss=', '157.123462105')
# ('Epoch:', '0194', 'training time (minutes)=', '2.7302', 'loss=', '156.972339096')
# ('Epoch:', '0195', 'training time (minutes)=', '2.7649', 'loss=', '157.167004032')
# ('Epoch:', '0196', 'training time (minutes)=', '2.7161', 'loss=', '157.055808144')
# ('Epoch:', '0197', 'training time (minutes)=', '2.7264', 'loss=', '157.189397049')
# ('Epoch:', '0198', 'training time (minutes)=', '2.7103', 'loss=', '156.923651409')
# ('Epoch:', '0199', 'training time (minutes)=', '2.7105', 'loss=', '157.065514393')
# ('Epoch:', '0200', 'training time (minutes)=', '2.7078', 'loss=', '157.041118641')
# ('Epoch:', '0201', 'training time (minutes)=', '2.7511', 'loss=', '157.013240604')
# ('Epoch:', '0202', 'training time (minutes)=', '2.7230', 'loss=', '157.086756668')
# ('Epoch:', '0203', 'training time (minutes)=', '2.7196', 'loss=', '157.098219528')
# ('Epoch:', '0204', 'training time (minutes)=', '2.7060', 'loss=', '157.116344948')
# ('Epoch:', '0205', 'training time (minutes)=', '2.7078', 'loss=', '156.958530445')
# ('Epoch:', '0206', 'training time (minutes)=', '2.7087', 'loss=', '157.119031563')
# ('Epoch:', '0207', 'training time (minutes)=', '2.7405', 'loss=', '156.987754173')
# ('Epoch:', '0208', 'training time (minutes)=', '2.7191', 'loss=', '156.914998608')
# ('Epoch:', '0209', 'training time (minutes)=', '2.7294', 'loss=', '156.884147511')
# ('Epoch:', '0210', 'training time (minutes)=', '2.7131', 'loss=', '156.837621822')
# ('Epoch:', '0211', 'training time (minutes)=', '2.7075', 'loss=', '156.940399208')
# ('Epoch:', '0212', 'training time (minutes)=', '2.7041', 'loss=', '157.042049294')
# ('Epoch:', '0213', 'training time (minutes)=', '2.7347', 'loss=', '156.888011169')
# ('Epoch:', '0214', 'training time (minutes)=', '2.7313', 'loss=', '156.839920063')
# ('Epoch:', '0215', 'training time (minutes)=', '2.7346', 'loss=', '156.919161224')
# ('Epoch:', '0216', 'training time (minutes)=', '2.8217', 'loss=', '156.959663811')
# ('Epoch:', '0217', 'training time (minutes)=', '2.8096', 'loss=', '156.853685970')
# ('Epoch:', '0218', 'training time (minutes)=', '2.7925', 'loss=', '157.004887104')
# ('Epoch:', '0219', 'training time (minutes)=', '2.6913', 'loss=', '156.815936699')
# ('Epoch:', '0220', 'training time (minutes)=', '2.7661', 'loss=', '156.792986660')
# ('Epoch:', '0221', 'training time (minutes)=', '2.7104', 'loss=', '156.837455559')
# ('Epoch:', '0222', 'training time (minutes)=', '2.7867', 'loss=', '156.873548603')
# ('Epoch:', '0223', 'training time (minutes)=', '2.8325', 'loss=', '156.940357876')
# ('Epoch:', '0224', 'training time (minutes)=', '2.7508', 'loss=', '156.762934990')
# ('Epoch:', '0225', 'training time (minutes)=', '2.7172', 'loss=', '156.776037006')
# ('Epoch:', '0226', 'training time (minutes)=', '2.7442', 'loss=', '156.792578602')
# ('Epoch:', '0227', 'training time (minutes)=', '2.7452', 'loss=', '156.787501183')
# ('Epoch:', '0228', 'training time (minutes)=', '2.7678', 'loss=', '156.745778656')
# ('Epoch:', '0229', 'training time (minutes)=', '2.7469', 'loss=', '156.822859383')
# ('Epoch:', '0230', 'training time (minutes)=', '2.7490', 'loss=', '156.944502602')
# ('Epoch:', '0231', 'training time (minutes)=', '2.7378', 'loss=', '156.653501797')
# ('Epoch:', '0232', 'training time (minutes)=', '2.7880', 'loss=', '156.766176071')
# ('Epoch:', '0233', 'training time (minutes)=', '2.7399', 'loss=', '156.792184086')
# ('Epoch:', '0234', 'training time (minutes)=', '2.7541', 'loss=', '156.553802509')
# ('Epoch:', '0235', 'training time (minutes)=', '2.7291', 'loss=', '156.741002750')
# ('Epoch:', '0236', 'training time (minutes)=', '2.7385', 'loss=', '156.699731026')
# ('Epoch:', '0237', 'training time (minutes)=', '2.7988', 'loss=', '156.669456730')
# ('Epoch:', '0238', 'training time (minutes)=', '2.8538', 'loss=', '156.745635262')
# ('Epoch:', '0239', 'training time (minutes)=', '2.8145', 'loss=', '156.889586086')
# ('Epoch:', '0240', 'training time (minutes)=', '2.7922', 'loss=', '156.565692577')
# ('Epoch:', '0241', 'training time (minutes)=', '2.8328', 'loss=', '156.558762589')
# ('Epoch:', '0242', 'training time (minutes)=', '2.8508', 'loss=', '156.686794033')
# ('Epoch:', '0243', 'training time (minutes)=', '2.8005', 'loss=', '156.660817471')
# ('Epoch:', '0244', 'training time (minutes)=', '2.8381', 'loss=', '156.647712460')
# ('Epoch:', '0245', 'training time (minutes)=', '2.8075', 'loss=', '156.699750881')
# ('Epoch:', '0246', 'training time (minutes)=', '2.8183', 'loss=', '156.601155262')
# ('Epoch:', '0247', 'training time (minutes)=', '2.7988', 'loss=', '156.690984344')
# ('Epoch:', '0248', 'training time (minutes)=', '2.8403', 'loss=', '156.551589451')
# ('Epoch:', '0249', 'training time (minutes)=', '2.8228', 'loss=', '156.635742283')
# ('Epoch:', '0250', 'training time (minutes)=', '2.8170', 'loss=', '156.752359276')
# ('Epoch:', '0251', 'training time (minutes)=', '2.7918', 'loss=', '156.678626709')
# ('Epoch:', '0252', 'training time (minutes)=', '2.7737', 'loss=', '156.508447819')
# ('Epoch:', '0253', 'training time (minutes)=', '2.7500', 'loss=', '156.640008049')
# ('Epoch:', '0254', 'training time (minutes)=', '2.6994', 'loss=', '156.610485802')
# ('Epoch:', '0255', 'training time (minutes)=', '2.6828', 'loss=', '156.584585724')
# ('Epoch:', '0256', 'training time (minutes)=', '2.7306', 'loss=', '156.595083618')
# ('Epoch:', '0257', 'training time (minutes)=', '2.6920', 'loss=', '156.661280899')
# ('Epoch:', '0258', 'training time (minutes)=', '2.7184', 'loss=', '156.691684837')
# ('Epoch:', '0259', 'training time (minutes)=', '2.6993', 'loss=', '156.513960609')
# ('Epoch:', '0260', 'training time (minutes)=', '2.6881', 'loss=', '156.540558128')
# ('Epoch:', '0261', 'training time (minutes)=', '2.7516', 'loss=', '156.618195782')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-10a2b16b6321> in <module>()
#       4
#       5 if do_training:
# ----> 6     ae.train(train_data, conf)
#       7
#       8 else:
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in train(self, train_data, configuration)
#     149
#     150         for _ in xrange(c.training_epochs):
# --> 151             loss, duration = self._single_epoch_train(train_data, c)
#     152             epoch = int(self.sess.run(self.epoch.assign_add(tf.constant(1.0))))
#     153             stats.append((epoch, loss, duration))
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/point_net_ae.pyc in _single_epoch_train(self, train_data, configuration)
#      91
#      92             if self.is_denoising:
# ---> 93                 loss, _ = self.partial_fit(batch_i, original_data)
#      94             else:
#      95                 loss, _ = self.partial_fit(batch_i)
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in partial_fit(self, X, GT)
#     111         '''
#     112         if GT is not None:
# --> 113             _, loss, recon = self.sess.run((self.optimizer, self.loss, self.x_reconstr), feed_dict={self.x: X, self.gt: GT})
#     114         else:
#     115             _, loss, recon = self.sess.run((self.optimizer, self.loss, self.x_reconstr), feed_dict={self.x: X})
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
