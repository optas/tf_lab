# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

import tf_lab.point_clouds.in_out as pio
import tf_lab.models.point_net_based_AE as pnAE

from tf_lab.fundamentals.utils import set_visible_GPUs

from tf_lab.point_clouds.in_out import PointCloudDataSet
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, match_incomplete_to_complete_data

from tf_lab.autopredictors.evaluate.basics import eval_model, read_saved_epochs
from tf_lab.autopredictors.plotting.basics import plot_original_pclouds_vs_reconstructed,\
                                                  plot_train_val_test_curves, plot_reconstructions_at_epoch


from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from geo_tool import Point_Cloud
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/1024/')

experiment_name = 'blensor_all_sn_single_view_only_ae_simple_decoder'
train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/', experiment_name)

create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/blensor_all_sn_single_view_only_ae_simple_decoder'

# %% [markdown]
# ## Load complete pclouds and inclomplete from Blensor

# %%
full_file_names = pio.load_filenames_of_input_data(full_pclouds_path)
full_pclouds, full_model_names, full_syn_ids = pio.load_crude_point_clouds(file_names=full_file_names, n_threads=15)
print '%d files containing complete point clouds were found.' % (len(full_pclouds), )
# Out:
# 52103 files containing complete point clouds were found.
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:64: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')

# %%
blensor_data = osp.join(top_data_dir, 'Blensor_Incomplete_Pclouds')
noisy_pcloud_files = pio.load_filenames_of_input_data(blensor_data, pio.blensor_search_pattern)

noisy_pclouds, noisy_model_names, noisy_syn_ids = pio.load_crude_point_clouds(file_names=noisy_pcloud_files, 
                                                                n_threads=15,
                                                                loader=pio._load_blensor_incomplete_pcloud)


print '%d files containing noisy point clouds were found.' % (len(noisy_pclouds), )
# Out:
# 16683 files containing noisy point clouds were found.

# %%
# Match incomplete to complete data.
mapping = match_incomplete_to_complete_data(full_model_names, noisy_model_names)
full_pclouds_matched = full_pclouds[mapping]

# %%
train_data_, _, test_data_ = pio.train_validate_test_split([full_pclouds_matched,
                                                            noisy_pclouds, 
                                                            noisy_model_names],
                                                            train_perc=0.9,
                                                            validate_perc=0.0,
                                                            test_perc=0.1,
                                                            seed=seed)

train_data = PointCloudDataSet(train_data_[0], noise=train_data_[1], labels=train_data_[2])
test_data = PointCloudDataSet(test_data_[0], noise=test_data_[1], labels=test_data_[2])

# %%
# TRY ME.
pp = test_data.next_batch(1)
Point_Cloud(points=pp[2].reshape(1024, 3)).plot(in_u_sphere=True);
Point_Cloud(points=pp[0].reshape(1024, 3)).plot(in_u_sphere=True);

# %%
from tf_lab.point_clouds.various_encoders_decoders import decoder_only_with_fc
def reset_graph():
    if 'sess' in globals() and sess:
        sess.close()
    tf.reset_default_graph()

set_visible_GPUs([3])

conf = Conf(n_input = [1024, 3],
               training_epochs = 1000,
               batch_size = 40,
               loss = 'Chamfer',
               train_dir = train_dir,
               loss_display_step = 1,
               saver_step = 5,
               learning_rate = 0.0002,
               saver_max_to_keep = 200,
               gauss_augment = {'mu': 0, 'sigma': 0.02},
               encoder = pnAE.encoder,
               decoder = decoder_only_with_fc,
               spatial_trans = True,             
               denoising = True
              )

reset_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
ae.train(train_data, conf)
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.3038', 'loss=', '0.006308589')
# ('Epoch:', '0002', 'training time (minutes)=', '0.2997', 'loss=', '0.004640748')
# ('Epoch:', '0003', 'training time (minutes)=', '0.2989', 'loss=', '0.004238222')
# ('Epoch:', '0004', 'training time (minutes)=', '0.3000', 'loss=', '0.003874036')
# ('Epoch:', '0005', 'training time (minutes)=', '0.2980', 'loss=', '0.003615759')
# ('Epoch:', '0006', 'training time (minutes)=', '0.

# ('Epoch:', '0413', 'training time (minutes)=', '0.2991', 'loss=', '0.000857386')
# ('Epoch:', '0414', 'training time (minutes)=', '0.2996', 'loss=', '0.000890809')
# ('Epoch:', '0415', 'training time (minutes)=', '0.2986', 'loss=', '0.000846566')
# ('Epoch:', '0416', 'training time (minutes)=', '0.2995', 'loss=', '0.000841473')
# ('Epoch:', '0417', 'training time (minutes)=', '0.2993', 'loss=', '0.000848462')
# ('Epoch:', '0418', 'training time (minutes)=', '0.3011', 'loss=', '0.000849974')
# ('Epoch:', '0419', 'training time (minutes)=', '0.2992', 'loss=', '0.000850803')
# ('Epoch:', '0420', 'training time (minutes)=', '0.3000', 'loss=', '0.000851796')
# ('Epoch:', '0421', 'training time (minutes)=', '0.2999', 'loss=', '0.000978651')
# ('Epoch:', '0422', 'training time (minutes)=', '0.3002', 'loss=', '0.000853252')
# ('Epoch:', '0423', 'training time (minutes)=', '0.3004', 'loss=', '0.000863995')
# ('Epoch:', '0424', 'training time (minutes)=', '0.2993', 'loss=', '0.000835173')
# ('Epoch:', '0425', 'training time (minutes)=', '0.2995', 'loss=', '0.000835765')
# ('Epoch:', '0426', 'training time (minutes)=', '0.2979', 'loss=', '0.000839535')
# ('Epoch:', '0427', 'training time (minutes)=', '0.2999', 'loss=', '0.000840197')
# ('Epoch:', '0428', 'training time (minutes)=', '0.3006', 'loss=', '0.000835355')
# ('Epoch:', '0429', 'training time (minutes)=', '0.3007', 'loss=', '0.000847361')
# ('Epoch:', '0430', 'training time (minutes)=', '0.3010', 'loss=', '0.000872467')
# ('Epoch:', '0431', 'training time (minutes)=', '0.2987', 'loss=', '0.000871529')
# ('Epoch:', '0432', 'training time (minutes)=', '0.3001', 'loss=', '0.000833572')
# ('Epoch:', '0433', 'training time (minutes)=', '0.2996', 'loss=', '0.000839016')
# ('Epoch:', '0434', 'training time (minutes)=', '0.2986', 'loss=', '0.000845577')
# ('Epoch:', '0435', 'training time (minutes)=', '0.2990', 'loss=', '0.000841349')
# ('Epoch:', '0436', 'training time (minutes)=', '0.2987', 'loss=', '0.000897666')
# ('Epoch:', '0437', 'training time (minutes)=', '0.3001', 'loss=', '0.000880737')
# ('Epoch:', '0438', 'training time (minutes)=', '0.2992', 'loss=', '0.000834481')
# ('Epoch:', '0439', 'training time (minutes)=', '0.2995', 'loss=', '0.000829703')
# ('Epoch:', '0440', 'training time (minutes)=', '0.2995', 'loss=', '0.000835250')
# ('Epoch:', '0441', 'training time (minutes)=', '0.2988', 'loss=', '0.000835303')
# ('Epoch:', '0442', 'training time (minutes)=', '0.2992', 'loss=', '0.000838032')
# ('Epoch:', '0443', 'training time (minutes)=', '0.3011', 'loss=', '0.000834404')
# ('Epoch:', '0444', 'training time (minutes)=', '0.2959', 'loss=', '0.000845344')
# ('Epoch:', '0445', 'training time (minutes)=', '0.2993', 'loss=', '0.000834060')
# ('Epoch:', '0446', 'training time (minutes)=', '0.2984', 'loss=', '0.000891935')
# ('Epoch:', '0447', 'training time (minutes)=', '0.2992', 'loss=', '0.000888849')
# ('Epoch:', '0448', 'training time (minutes)=', '0.2981', 'loss=', '0.000829957')
# ('Epoch:', '0449', 'training time (minutes)=', '0.2993', 'loss=', '0.000824238')
# ('Epoch:', '0450', 'training time (minutes)=', '0.2987', 'loss=', '0.000824390')
# ('Epoch:', '0451', 'training time (minutes)=', '0.3007', 'loss=', '0.000848558')
# ('Epoch:', '0452', 'training time (minutes)=', '0.3001', 'loss=', '0.000870672')
# ('Epoch:', '0453', 'training time (minutes)=', '0.3007', 'loss=', '0.000848808')
# ('Epoch:', '0454', 'training time (minutes)=', '0.2995', 'loss=', '0.000821085')
# ('Epoch:', '0455', 'training time (minutes)=', '0.2990', 'loss=', '0.000870396')
# ('Epoch:', '0456', 'training time (minutes)=', '0.2986', 'loss=', '0.000826681')
# ('Epoch:', '0457', 'training time (minutes)=', '0.2999', 'loss=', '0.000822496')
# ('Epoch:', '0458', 'training time (minutes)=', '0.2979', 'loss=', '0.000822399')
# ('Epoch:', '0459', 'training time (minutes)=', '0.2991', 'loss=', '0.000827447')
# ('Epoch:', '0460', 'training time (minutes)=', '0.2981', 'loss=', '0.000922503')
# ('Epoch:', '0461', 'training time (minutes)=', '0.2985', 'loss=', '0.000835734')
# ('Epoch:', '0462', 'training time (minutes)=', '0.2977', 'loss=', '0.000817066')
# ('Epoch:', '0463', 'training time (minutes)=', '0.3015', 'loss=', '0.000814401')
# ('Epoch:', '0464', 'training time (minutes)=', '0.2975', 'loss=', '0.000818072')
# ('Epoch:', '0465', 'training time (minutes)=', '0.2993', 'loss=', '0.000818207')
# ('Epoch:', '0466', 'training time (minutes)=', '0.2975', 'loss=', '0.000823914')
# ('Epoch:', '0467', 'training time (minutes)=', '0.2999', 'loss=', '0.000867012')
# ('Epoch:', '0468', 'training time (minutes)=', '0.2989', 'loss=', '0.000831905')
# ('Epoch:', '0469', 'training time (minutes)=', '0.3003', 'loss=', '0.000829716')
# ('Epoch:', '0470', 'training time (minutes)=', '0.2986', 'loss=', '0.000863172')
# ('Epoch:', '0471', 'training time (minutes)=', '0.2990', 'loss=', '0.000940595')
# ('Epoch:', '0472', 'training time (minutes)=', '0.2985', 'loss=', '0.000865977')
# ('Epoch:', '0473', 'training time (minutes)=', '0.3008', 'loss=', '0.000809811')
# ('Epoch:', '0474', 'training time (minutes)=', '0.3001', 'loss=', '0.000804897')
# ('Epoch:', '0475', 'training time (minutes)=', '0.3008', 'loss=', '0.000864236')
# ('Epoch:', '0476', 'training time (minutes)=', '0.2982', 'loss=', '0.000814892')
# ('Epoch:', '0477', 'training time (minutes)=', '0.2991', 'loss=', '0.000808840')
# ('Epoch:', '0478', 'training time (minutes)=', '0.3024', 'loss=', '0.000810204')
# ('Epoch:', '0479', 'training time (minutes)=', '0.2998', 'loss=', '0.000882696')
# ('Epoch:', '0480', 'training time (minutes)=', '0.3007', 'loss=', '0.000884614')
# ('Epoch:', '0481', 'training time (minutes)=', '0.2970', 'loss=', '0.000810955')
# ('Epoch:', '0482', 'training time (minutes)=', '0.2931', 'loss=', '0.000804815')
# ('Epoch:', '0483', 'training time (minutes)=', '0.2907', 'loss=', '0.000808056')
# ('Epoch:', '0484', 'training time (minutes)=', '0.2975', 'loss=', '0.000818218')
# ('Epoch:', '0485', 'training time (minutes)=', '0.3011', 'loss=', '0.000812529')
# ('Epoch:', '0486', 'training time (minutes)=', '0.2997', 'loss=', '0.000885208')
# ('Epoch:', '0487', 'training time (minutes)=', '0.3009', 'loss=', '0.000818130')
# ('Epoch:', '0488', 'training time (minutes)=', '0.3007', 'loss=', '0.000826500')
# ('Epoch:', '0489', 'training time (minutes)=', '0.2968', 'loss=', '0.000852513')
# ('Epoch:', '0490', 'training time (minutes)=', '0.3012', 'loss=', '0.000806025')
# ('Epoch:', '0491', 'training time (minutes)=', '0.2999', 'loss=', '0.000806617')
# ('Epoch:', '0492', 'training time (minutes)=', '0.2991', 'loss=', '0.000811325')
# ('Epoch:', '0493', 'training time (minutes)=', '0.3031', 'loss=', '0.000811326')
# ('Epoch:', '0494', 'training time (minutes)=', '0.2999', 'loss=', '0.000811853')
# ('Epoch:', '0495', 'training time (minutes)=', '0.2987', 'loss=', '0.000813909')
# ('Epoch:', '0496', 'training time (minutes)=', '0.3009', 'loss=', '0.000810690')
# ('Epoch:', '0497', 'training time (minutes)=', '0.3011', 'loss=', '0.000827702')
# ('Epoch:', '0498', 'training time (minutes)=', '0.2998', 'loss=', '0.000814000')
# ('Epoch:', '0499', 'training time (minutes)=', '0.3002', 'loss=', '0.000866855')
# ('Epoch:', '0500', 'training time (minutes)=', '0.3008', 'loss=', '0.000827643')
# ('Epoch:', '0501', 'training time (minutes)=', '0.2990', 'loss=', '0.000812331')
# ('Epoch:', '0502', 'training time (minutes)=', '0.2986', 'loss=', '0.000812945')
# ('Epoch:', '0503', 'training time (minutes)=', '0.2985', 'loss=', '0.000806478')
# ('Epoch:', '0504', 'training time (minutes)=', '0.2972', 'loss=', '0.000821158')
# ('Epoch:', '0505', 'training time (minutes)=', '0.2984', 'loss=', '0.001002138')
# ('Epoch:', '0506', 'training time (minutes)=', '0.2997', 'loss=', '0.000834608')
# ('Epoch:', '0507', 'training time (minutes)=', '0.2995', 'loss=', '0.000796831')
# ('Epoch:', '0508', 'training time (minutes)=', '0.2982', 'loss=', '0.000789082')
# ('Epoch:', '0509', 'training time (minutes)=', '0.2991', 'loss=', '0.000794201')
# ('Epoch:', '0510', 'training time (minutes)=', '0.2993', 'loss=', '0.000793750')
# ('Epoch:', '0511', 'training time (minutes)=', '0.3005', 'loss=', '0.000801941')
# ('Epoch:', '0512', 'training time (minutes)=', '0.2995', 'loss=', '0.000800889')
# ('Epoch:', '0513', 'training time (minutes)=', '0.3011', 'loss=', '0.000814447')
# ('Epoch:', '0514', 'training time (minutes)=', '0.3001', 'loss=', '0.000801719')
# ('Epoch:', '0515', 'training time (minutes)=', '0.3011', 'loss=', '0.000806261')
# ('Epoch:', '0516', 'training time (minutes)=', '0.2986', 'loss=', '0.000818429')
# ('Epoch:', '0517', 'training time (minutes)=', '0.2996', 'loss=', '0.000820818')
# ('Epoch:', '0518', 'training time (minutes)=', '0.3009', 'loss=', '0.000804097')
# ('Epoch:', '0519', 'training time (minutes)=', '0.3011', 'loss=', '0.000811681')
# ('Epoch:', '0520', 'training time (minutes)=', '0.2980', 'loss=', '0.000924586')
# ('Epoch:', '0521', 'training time (minutes)=', '0.3017', 'loss=', '0.000807805')
# ('Epoch:', '0522', 'training time (minutes)=', '0.3010', 'loss=', '0.000799578')
# ('Epoch:', '0523', 'training time (minutes)=', '0.3002', 'loss=', '0.000797721')
# ('Epoch:', '0524', 'training time (minutes)=', '0.3013', 'loss=', '0.000796866')
# ('Epoch:', '0525', 'training time (minutes)=', '0.2991', 'loss=', '0.000793512')
# ('Epoch:', '0526', 'training time (minutes)=', '0.2991', 'loss=', '0.000800885')
# ('Epoch:', '0527', 'training time (minutes)=', '0.3001', 'loss=', '0.000802363')
# ('Epoch:', '0528', 'training time (minutes)=', '0.2996', 'loss=', '0.000800896')
# ('Epoch:', '0529', 'training time (minutes)=', '0.3006', 'loss=', '0.000826222')
# ('Epoch:', '0530', 'training time (minutes)=', '0.3011', 'loss=', '0.000800235')
# ('Epoch:', '0531', 'training time (minutes)=', '0.3000', 'loss=', '0.000800781')
# ('Epoch:', '0532', 'training time (minutes)=', '0.2976', 'loss=', '0.000805696')
# ('Epoch:', '0533', 'training time (minutes)=', '0.2998', 'loss=', '0.000801678')
# ('Epoch:', '0534', 'training time (minutes)=', '0.2990', 'loss=', '0.000833463')
# ('Epoch:', '0535', 'training time (minutes)=', '0.2985', 'loss=', '0.000817540')
# ('Epoch:', '0536', 'training time (minutes)=', '0.2986', 'loss=', '0.000827745')
# ('Epoch:', '0537', 'training time (minutes)=', '0.3008', 'loss=', '0.000791927')
# ('Epoch:', '0538', 'training time (minutes)=', '0.3018', 'loss=', '0.000789274')
# ('Epoch:', '0539', 'training time (minutes)=', '0.3017', 'loss=', '0.000790248')
# ('Epoch:', '0540', 'training time (minutes)=', '0.3000', 'loss=', '0.000792626')
# ('Epoch:', '0541', 'training time (minutes)=', '0.3010', 'loss=', '0.000799048')
# ('Epoch:', '0542', 'training time (minutes)=', '0.2977', 'loss=', '0.000810250')
# ('Epoch:', '0543', 'training time (minutes)=', '0.3005', 'loss=', '0.000797856')
# ('Epoch:', '0544', 'training time (minutes)=', '0.3010', 'loss=', '0.000794297')
# ('Epoch:', '0545', 'training time (minutes)=', '0.2982', 'loss=', '0.000802691')
# ('Epoch:', '0546', 'training time (minutes)=', '0.3003', 'loss=', '0.000791579')
# ('Epoch:', '0547', 'training time (minutes)=', '0.3014', 'loss=', '0.000794183')
# ('Epoch:', '0548', 'training time (minutes)=', '0.2995', 'loss=', '0.000792160')
# ('Epoch:', '0549', 'training time (minutes)=', '0.3015', 'loss=', '0.000800502')
# ('Epoch:', '0550', 'training time (minutes)=', '0.2998', 'loss=', '0.000790510')
# ('Epoch:', '0551', 'training time (minutes)=', '0.3005', 'loss=', '0.000790692')
# ('Epoch:', '0552', 'training time (minutes)=', '0.2999', 'loss=', '0.000795338')
# ('Epoch:', '0553', 'training time (minutes)=', '0.2993', 'loss=', '0.000791898')
# ('Epoch:', '0554', 'training time (minutes)=', '0.3011', 'loss=', '0.000950919')
# ('Epoch:', '0555', 'training time (minutes)=', '0.2986', 'loss=', '0.000837189')
# ('Epoch:', '0556', 'training time (minutes)=', '0.2992', 'loss=', '0.000783040')
# ('Epoch:', '0557', 'training time (minutes)=', '0.2994', 'loss=', '0.000778364')
# ('Epoch:', '0558', 'training time (minutes)=', '0.2993', 'loss=', '0.000778646')
# ('Epoch:', '0559', 'training time (minutes)=', '0.3002', 'loss=', '0.000783516')
# ('Epoch:', '0560', 'training time (minutes)=', '0.3009', 'loss=', '0.000783913')
# ('Epoch:', '0561', 'training time (minutes)=', '0.2998', 'loss=', '0.000787088')
# ('Epoch:', '0562', 'training time (minutes)=', '0.3013', 'loss=', '0.000816703')
# ('Epoch:', '0563', 'training time (minutes)=', '0.2999', 'loss=', '0.000821109')
# ('Epoch:', '0564', 'training time (minutes)=', '0.2991', 'loss=', '0.000785216')
# ('Epoch:', '0565', 'training time (minutes)=', '0.2990', 'loss=', '0.000783578')
# ('Epoch:', '0566', 'training time (minutes)=', '0.2997', 'loss=', '0.000783203')
# ('Epoch:', '0567', 'training time (minutes)=', '0.2990', 'loss=', '0.000807797')
# ('Epoch:', '0568', 'training time (minutes)=', '0.2988', 'loss=', '0.000789966')
# ('Epoch:', '0569', 'training time (minutes)=', '0.2990', 'loss=', '0.000784357')
# ('Epoch:', '0570', 'training time (minutes)=', '0.2983', 'loss=', '0.000781833')
# ('Epoch:', '0571', 'training time (minutes)=', '0.3003', 'loss=', '0.000813342')
# ('Epoch:', '0572', 'training time (minutes)=', '0.2983', 'loss=', '0.000838596')
# ('Epoch:', '0573', 'training time (minutes)=', '0.2999', 'loss=', '0.000780286')
# ('Epoch:', '0574', 'training time (minutes)=', '0.2995', 'loss=', '0.000781285')
# ('Epoch:', '0575', 'training time (minutes)=', '0.2994', 'loss=', '0.000779674')
# ('Epoch:', '0576', 'training time (minutes)=', '0.3008', 'loss=', '0.000777526')
# ('Epoch:', '0577', 'training time (minutes)=', '0.3009', 'loss=', '0.000784456')
# ('Epoch:', '0578', 'training time (minutes)=', '0.2998', 'loss=', '0.000781237')
# ('Epoch:', '0579', 'training time (minutes)=', '0.3011', 'loss=', '0.000782268')
# ('Epoch:', '0580', 'training time (minutes)=', '0.2957', 'loss=', '0.000779340')
# ('Epoch:', '0581', 'training time (minutes)=', '0.2998', 'loss=', '0.000783058')
# ('Epoch:', '0582', 'training time (minutes)=', '0.2987', 'loss=', '0.000778695')
# ('Epoch:', '0583', 'training time (minutes)=', '0.3000', 'loss=', '0.000779183')
# ('Epoch:', '0584', 'training time (minutes)=', '0.2997', 'loss=', '0.000783109')
# ('Epoch:', '0585', 'training time (minutes)=', '0.2992', 'loss=', '0.000910261')
# ('Epoch:', '0586', 'training time (minutes)=', '0.2988', 'loss=', '0.000869276')
# ('Epoch:', '0587', 'training time (minutes)=', '0.2994', 'loss=', '0.000817079')
# ('Epoch:', '0588', 'training time (minutes)=', '0.2997', 'loss=', '0.000774460')
# ('Epoch:', '0589', 'training time (minutes)=', '0.2985', 'loss=', '0.000765252')
# ('Epoch:', '0590', 'training time (minutes)=', '0.3006', 'loss=', '0.000768014')
# ('Epoch:', '0591', 'training time (minutes)=', '0.3001', 'loss=', '0.000771223')
# ('Epoch:', '0592', 'training time (minutes)=', '0.2995', 'loss=', '0.000772401')
# ...
#  (690, 0.00074921127486353119, 18.054785013198853),
#  (691, 0.00077889268333092331, 18.08942484855652),
#  (692, 0.00093121732585132121, 17.941437005996704),
#  (693, 0.00077688857028260824, 18.00941514968872),
#  (694, 0.00074062926213567452, 18.083496809005737),
#  (695, 0.00073734529688954358, 17.97351312637329),
#  (696, 0.00073749184686069686, 18.119359016418457),
#  (697, 0.00073883958626538512, 18.072149991989136),
#  (698, 0.0007433257712982595, 18.0385479927063),
#  (699, 0.00074474178565045197, 18.11424994468689),
#  (700, 0.00074892920845498641, 17.99331307411194),
#  (701, 0.00075723204187427959, 18.115552186965942),
#  (702, 0.00075904496495301523, 18.059789180755615),
#  (703, 0.00075143510413666571, 18.00851082801819),
#  (704, 0.00074707170513768986, 18.02167797088623),
#  (705, 0.0007445509649502734, 18.08448886871338),
#  (706, 0.00074709338648244739, 18.166781187057495),
#  (995, 0.00070587268332019445, 17.965226888656616),
#  (996, 0.00070137401437386868, 18.025537967681885),
#  (997, 0.00069813549223666387, 17.999864101409912),
#  (998, 0.00070610595773905511, 18.018386125564575),
#  (999, 0.00070390240817020332, 18.045636892318726),
#  (1000, 0.00069848970323801041, 17.974056005477905)]

# %% [markdown]
# # Evaluation

# %%
saved_epochs = read_saved_epochs(conf.train_dir)
epochs = saved_epochs[::len(saved_epochs)/10]
stats = eval_model(ae, conf, [train_data, test_data], epochs=epochs, verbose=False)

# %%
top_save_dir = osp.join(top_data_dir, 'OUT/model_evaluation/incomplete_pclouds/', experiment_name)
plot_train_val_test_curves(stats, top_save_dir, has_validation=False, best_epoch=None, show=True)

# %%
last_epoch = saved_epochs[-1]
save_dir = osp.join(top_save_dir, 'train_images_epoch_' + str(last_epoch))
plot_reconstructions_at_epoch(last_epoch, ae, train_data, conf, save_dir=save_dir, max_plot=500)

save_dir = osp.join(top_save_dir, 'test_images_epoch_' + str(last_epoch))
plot_reconstructions_at_epoch(last_epoch, ae, test_data, conf, save_dir=save_dir, max_plot=500)

# %% [markdown]
# # Explore Latent Space

# %%
ae.restore_model(conf.train_dir, saved_epochs[-1], verbose=True)
# Out:
# Model restored in epoch 1000.

# %%
batch_size = conf.batch_size
gt_feed, labels, feed = train_data.full_epoch_data();
latent_data = []
for b in pio.chunks(feed, batch_size):
    if len(b) == batch_size:
        latent_data.append(ae.transform(b.reshape([batch_size] + conf.n_input)))

latent_data = np.vstack(latent_data)
n_latent = len(latent_data)
labels = labels[:n_latent]

# %%
from tf_lab.autopredictors.scripts.helper import model_ids_to_class_ids        
c = model_ids_to_class_ids(noisy_model_names, noisy_syn_ids, labels)

# %%
from sklearn.manifold import TSNE
model = TSNE(n_components=2, random_state=seed, init='pca', verbose=True);
tsne_emb = model.fit_transform(latent_data)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15000
# [t-SNE] Computed conditional probabilities for sample 2000 / 15000
# [t-SNE] Computed conditional probabilities for sample 3000 / 15000
# [t-SNE] Computed conditional probabilities for sample 4000 / 15000
# [t-SNE] Computed conditional probabilities for sample 5000 / 15000
# [t-SNE] Computed conditional probabilities for sample 6000 / 15000
# [t-SNE] Computed conditional probabilities for sample 7000 / 15000
# [t-SNE] Computed conditional probabilities for sample 8000 / 15000
# [t-SNE] Computed conditional probabilities for sample 9000 / 15000
# [t-SNE] Computed conditional probabilities for sample 10000 / 15000
# [t-SNE] Computed conditional probabilities for sample 11000 / 15000
# [t-SNE] Computed conditional probabilities for sample 12000 / 15000
# [t-SNE] Computed conditional probabilities for sample 13000 / 15000
# [t-SNE] Computed conditional probabilities for sample 14000 / 15000
# [t-SNE] Computed conditional probabilities for sample 15000 / 15000
# [t-SNE] Mean sigma: 1.559979
# [t-SNE] Error after 100 iterations with early exaggeration: 20.506534
# [t-SNE] Error after 333 iterations: 3.340094

# %%
plt.scatter(tsne_emb[:,0], tsne_emb[:,1], c=c)
plt.colorbar()
plt.grid()
plt.suptitle('TSNE: Incomplete Blensor Train Data (16-Classes) - Color=class).')
