# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, match_incomplete_to_complete_data
from tf_lab.autopredictors.scripts import loading_virt_scan_data as vscan

from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch, \
                                           plot_interpolations
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs
                                                  


from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
n_points = '1024'

experiment_name = '3_virt_scan_chamfer_2fc_decoder_' + n_points + 'pts'
do_training = True
do_plotting = True
first_time_running = True
load_model = False

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]
# Out:
# Give me the class type.
# chair

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/' + n_points, class_syn_id)

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/3_virt_scan_chamfer_2fc_decoder_1024pts'

# %%
train_id_file = '/orions4-zfs/projects/lins2/Panos_Space/DATA/From_Matthias/shapenet_all-train.txt'
v_scan_top_dir = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)
search_pattern = '__0__.ply'

full_file_names = pio.load_filenames_of_input_data(full_pclouds_path)
full_pclouds, full_model_names, class_ids = pio.load_crude_point_clouds(file_names=full_file_names, n_threads=20)

print '%d files containing complete point clouds were found.' % (len(full_pclouds), )


incomplete_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, train_id_file, class_syn_id, 
                                                      full_pclouds, full_model_names, n_threads = 24,
                                                      n_samples = int(n_points), search_pattern=search_pattern)
train_data = incomplete_data
# Out:
# 6778 files containing complete point clouds were found.
# 5000 incomplete point clouds were loaded.

# %%
## TRY ME
pp = incomplete_data.next_batch(1);
Point_Cloud(points=pp[2].reshape(int(n_points), 3)).plot();
Point_Cloud(points=pp[0].reshape(int(n_points), 3)).plot();

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    n_input = [int(n_points), 3]    
    decoder_args = {'layer_sizes': [1024, np.prod(n_input)], 
                    'non_linearity': tf.nn.relu
                   }

    conf = Conf(
                n_input = n_input,
                denoising = True,
                training_epochs = 300,
                batch_size = 50,
                loss = 'chamfer',
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.00002,
                saver_max_to_keep = 50,
                gauss_augment = {'mu': 0, 'sigma': 0.01},
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args,
               )

    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

# %%
reset_tf_graph()
set_visible_GPUs([2])
ae = PointNetAutoEncoder(experiment_name, conf)

if do_training:
    ae.train(train_data, conf)

else:
    saved_epochs = read_saved_epochs(conf.train_dir)
    ae.restore_model(train_dir, saved_epochs[-1])
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.1973', 'loss=', '0.006638293')
# ('Epoch:', '0002', 'training time (minutes)=', '0.1940', 'loss=', '0.004139210')
# ('Epoch:', '0003', 'training time (minutes)=', '0.1934', 'loss=', '0.003887255')
# ('Epoch:', '0004', 'training time (minutes)=', '0.1939', 'loss=', '0.003707768')
# ('Epoch:', '0005', 'training time (minutes)=', '0.1934', 'loss=', '0.003577074')
# ('Epoch:', '0006', 'training time (minutes)=', '0.1931', 'loss=', '0.003462630')
# ('Epoch:', '0007', 'training time (minutes)=', '0.1951', 'loss=', '0.003378794')
# ('Epoch:', '0008', 'training time (minutes)=', '0.1955', 'loss=', '0.003291702')
# ('Epoch:', '0009', 'training time (minutes)=', '0.1958', 'loss=', '0.003225500')
# ('Epoch:', '0010', 'training time (minutes)=', '0.1954', 'loss=', '0.003162725')
# ('Epoch:', '0011', 'training time (minutes)=', '0.1946', 'loss=', '0.003105978')
# ('Epoch:', '0012', 'training time (minutes)=', '0.1957', 'loss=', '0.003058552')
# ('Epoch:', '0013', 'training time (minutes)=', '0.1952', 'loss=', '0.003011248')
# ('Epoch:', '0014', 'training time (minutes)=', '0.1948', 'loss=', '0.002972192')
# ('Epoch:', '0015', 'training time (minutes)=', '0.1943', 'loss=', '0.002937098')
# ('Epoch:', '0016', 'training time (minutes)=', '0.

# ('Epoch:', '0088', 'training time (minutes)=', '0.1947', 'loss=', '0.002152126')
# ('Epoch:', '0089', 'training time (minutes)=', '0.1952', 'loss=', '0.002145239')
# ('Epoch:', '0090', 'training time (minutes)=', '0.1954', 'loss=', '0.002146350')
# ('Epoch:', '0091', 'training time (minutes)=', '0.1950', 'loss=', '0.002140321')
# ('Epoch:', '0092', 'training time (minutes)=', '0.1954', 'loss=', '0.002138450')
# ('Epoch:', '0093', 'training time (minutes)=', '0.1944', 'loss=', '0.002126440')
# ('Epoch:', '0094', 'training time (minutes)=', '0.1930', 'loss=', '0.002127367')
# ('Epoch:', '0095', 'training time (minutes)=', '0.1929', 'loss=', '0.002128428')
# ('Epoch:', '0096', 'training time (minutes)=', '0.1929', 'loss=', '0.002118688')
# ('Epoch:', '0097', 'training time (minutes)=', '0.1936', 'loss=', '0.002120790')
# ('Epoch:', '0098', 'training time (minutes)=', '0.1935', 'loss=', '0.002113342')
# ('Epoch:', '0099', 'training time (minutes)=', '0.1936', 'loss=', '0.002109456')
# ('Epoch:', '0100', 'training time (minutes)=', '0.1961', 'loss=', '0.002105126')
# ('Epoch:', '0101', 'training time (minutes)=', '0.1948', 'loss=', '0.002104792')
# ('Epoch:', '0102', 'training time (minutes)=', '0.1963', 'loss=', '0.002100988')
# ('Epoch:', '0103', 'training time (minutes)=', '0.1952', 'loss=', '0.002095221')
# ('Epoch:', '0104', 'training time (minutes)=', '0.1951', 'loss=', '0.002093815')
# ('Epoch:', '0105', 'training time (minutes)=', '0.1956', 'loss=', '0.002091120')
# ('Epoch:', '0106', 'training time (minutes)=', '0.1957', 'loss=', '0.002087414')
# ('Epoch:', '0107', 'training time (minutes)=', '0.1964', 'loss=', '0.002091192')
# ('Epoch:', '0108', 'training time (minutes)=', '0.1960', 'loss=', '0.002083161')
# ('Epoch:', '0109', 'training time (minutes)=', '0.1964', 'loss=', '0.002076681')
# ('Epoch:', '0110', 'training time (minutes)=', '0.1959', 'loss=', '0.002071300')
# ('Epoch:', '0111', 'training time (minutes)=', '0.1962', 'loss=', '0.002068709')
# ('Epoch:', '0112', 'training time (minutes)=', '0.1957', 'loss=', '0.002067906')
# ('Epoch:', '0113', 'training time (minutes)=', '0.1961', 'loss=', '0.002065462')
# ('Epoch:', '0114', 'training time (minutes)=', '0.1965', 'loss=', '0.002064597')
# ('Epoch:', '0115', 'training time (minutes)=', '0.1967', 'loss=', '0.002054702')
# ('Epoch:', '0116', 'training time (minutes)=', '0.1959', 'loss=', '0.002056644')
# ('Epoch:', '0117', 'training time (minutes)=', '0.1959', 'loss=', '0.002055050')
# ('Epoch:', '0118', 'training time (minutes)=', '0.1951', 'loss=', '0.002050526')
# ('Epoch:', '0119', 'training time (minutes)=', '0.1953', 'loss=', '0.002046269')
# ('Epoch:', '0120', 'training time (minutes)=', '0.1963', 'loss=', '0.002042936')
# ('Epoch:', '0121', 'training time (minutes)=', '0.1960', 'loss=', '0.002044266')
# ('Epoch:', '0122', 'training time (minutes)=', '0.1955', 'loss=', '0.002038322')
# ('Epoch:', '0123', 'training time (minutes)=', '0.1950', 'loss=', '0.002035157')
# ('Epoch:', '0124', 'training time (minutes)=', '0.1951', 'loss=', '0.002031574')
# ('Epoch:', '0125', 'training time (minutes)=', '0.1960', 'loss=', '0.002035012')
# ('Epoch:', '0126', 'training time (minutes)=', '0.1958', 'loss=', '0.002027359')
# ('Epoch:', '0127', 'training time (minutes)=', '0.1955', 'loss=', '0.002024110')
# ('Epoch:', '0128', 'training time (minutes)=', '0.1951', 'loss=', '0.002021271')
# ('Epoch:', '0129', 'training time (minutes)=', '0.1958', 'loss=', '0.002019162')
# ('Epoch:', '0130', 'training time (minutes)=', '0.1958', 'loss=', '0.002017547')
# ('Epoch:', '0131', 'training time (minutes)=', '0.1952', 'loss=', '0.002017661')
# ('Epoch:', '0132', 'training time (minutes)=', '0.1951', 'loss=', '0.002006886')
# ('Epoch:', '0133', 'training time (minutes)=', '0.1956', 'loss=', '0.002007627')
# ('Epoch:', '0134', 'training time (minutes)=', '0.1957', 'loss=', '0.002001641')
# ('Epoch:', '0135', 'training time (minutes)=', '0.1955', 'loss=', '0.002004254')
# ('Epoch:', '0136', 'training time (minutes)=', '0.1954', 'loss=', '0.002000004')
# ('Epoch:', '0137', 'training time (minutes)=', '0.1957', 'loss=', '0.001996495')
# ('Epoch:', '0138', 'training time (minutes)=', '0.1952', 'loss=', '0.001996103')
# ('Epoch:', '0139', 'training time (minutes)=', '0.1954', 'loss=', '0.001997295')
# ('Epoch:', '0140', 'training time (minutes)=', '0.1957', 'loss=', '0.001992797')
# ('Epoch:', '0141', 'training time (minutes)=', '0.1955', 'loss=', '0.001988128')
# ('Epoch:', '0142', 'training time (minutes)=', '0.1950', 'loss=', '0.001979939')
# ('Epoch:', '0143', 'training time (minutes)=', '0.1955', 'loss=', '0.001984561')
# ('Epoch:', '0144', 'training time (minutes)=', '0.1956', 'loss=', '0.001981929')
# ('Epoch:', '0145', 'training time (minutes)=', '0.1960', 'loss=', '0.001984239')
# ('Epoch:', '0146', 'training time (minutes)=', '0.1959', 'loss=', '0.001978029')
# ('Epoch:', '0147', 'training time (minutes)=', '0.1947', 'loss=', '0.001971524')
# ('Epoch:', '0148', 'training time (minutes)=', '0.1950', 'loss=', '0.001972052')
# ('Epoch:', '0149', 'training time (minutes)=', '0.1951', 'loss=', '0.001969859')
# ('Epoch:', '0150', 'training time (minutes)=', '0.1960', 'loss=', '0.001970279')
# ('Epoch:', '0151', 'training time (minutes)=', '0.1955', 'loss=', '0.001965597')
# ('Epoch:', '0152', 'training time (minutes)=', '0.1957', 'loss=', '0.001959673')
# ('Epoch:', '0153', 'training time (minutes)=', '0.1959', 'loss=', '0.001961637')
# ('Epoch:', '0154', 'training time (minutes)=', '0.1962', 'loss=', '0.001957682')
# ('Epoch:', '0155', 'training time (minutes)=', '0.1959', 'loss=', '0.001956904')
# ('Epoch:', '0156', 'training time (minutes)=', '0.1959', 'loss=', '0.001950081')
# ('Epoch:', '0157', 'training time (minutes)=', '0.1958', 'loss=', '0.001952180')
# ('Epoch:', '0158', 'training time (minutes)=', '0.1960', 'loss=', '0.001943854')
# ('Epoch:', '0159', 'training time (minutes)=', '0.1957', 'loss=', '0.001949174')
# ('Epoch:', '0160', 'training time (minutes)=', '0.1957', 'loss=', '0.001953140')
# ('Epoch:', '0161', 'training time (minutes)=', '0.1951', 'loss=', '0.001940442')
# ('Epoch:', '0162', 'training time (minutes)=', '0.1951', 'loss=', '0.001941917')
# ('Epoch:', '0163', 'training time (minutes)=', '0.1961', 'loss=', '0.001934815')
# ('Epoch:', '0164', 'training time (minutes)=', '0.1958', 'loss=', '0.001937900')
# ('Epoch:', '0165', 'training time (minutes)=', '0.1965', 'loss=', '0.001933835')
# ('Epoch:', '0166', 'training time (minutes)=', '0.1955', 'loss=', '0.001931594')
# ('Epoch:', '0167', 'training time (minutes)=', '0.1951', 'loss=', '0.001928728')
# ('Epoch:', '0168', 'training time (minutes)=', '0.1957', 'loss=', '0.001937613')
# ('Epoch:', '0169', 'training time (minutes)=', '0.1957', 'loss=', '0.001932058')
# ('Epoch:', '0170', 'training time (minutes)=', '0.1968', 'loss=', '0.001925095')
# ('Epoch:', '0171', 'training time (minutes)=', '0.1959', 'loss=', '0.001919971')
# ('Epoch:', '0172', 'training time (minutes)=', '0.1966', 'loss=', '0.001916620')
# ('Epoch:', '0173', 'training time (minutes)=', '0.1958', 'loss=', '0.001918051')
# ('Epoch:', '0174', 'training time (minutes)=', '0.1958', 'loss=', '0.001917995')
# ('Epoch:', '0175', 'training time (minutes)=', '0.1957', 'loss=', '0.001917483')
# ('Epoch:', '0176', 'training time (minutes)=', '0.1960', 'loss=', '0.001913689')
# ('Epoch:', '0177', 'training time (minutes)=', '0.1957', 'loss=', '0.001912618')
# ('Epoch:', '0178', 'training time (minutes)=', '0.1956', 'loss=', '0.001907817')
# ('Epoch:', '0179', 'training time (minutes)=', '0.1964', 'loss=', '0.001907198')
# ('Epoch:', '0180', 'training time (minutes)=', '0.1957', 'loss=', '0.001903694')
# ('Epoch:', '0181', 'training time (minutes)=', '0.1961', 'loss=', '0.001903315')
# ('Epoch:', '0182', 'training time (minutes)=', '0.1954', 'loss=', '0.001902157')
# ('Epoch:', '0183', 'training time (minutes)=', '0.1956', 'loss=', '0.001893801')
# ('Epoch:', '0184', 'training time (minutes)=', '0.1958', 'loss=', '0.001895838')
# ('Epoch:', '0185', 'training time (minutes)=', '0.1955', 'loss=', '0.001898270')
# ('Epoch:', '0186', 'training time (minutes)=', '0.1958', 'loss=', '0.001891129')
# ('Epoch:', '0187', 'training time (minutes)=', '0.1951', 'loss=', '0.001894368')
# ('Epoch:', '0188', 'training time (minutes)=', '0.1960', 'loss=', '0.001888382')
# ('Epoch:', '0189', 'training time (minutes)=', '0.1951', 'loss=', '0.001888032')
# ('Epoch:', '0190', 'training time (minutes)=', '0.1953', 'loss=', '0.001888817')
# ('Epoch:', '0191', 'training time (minutes)=', '0.1958', 'loss=', '0.001876236')
# ('Epoch:', '0192', 'training time (minutes)=', '0.1959', 'loss=', '0.001883934')
# ('Epoch:', '0193', 'training time (minutes)=', '0.1954', 'loss=', '0.001880821')
# ('Epoch:', '0194', 'training time (minutes)=', '0.1962', 'loss=', '0.001877751')
# ('Epoch:', '0195', 'training time (minutes)=', '0.1953', 'loss=', '0.001875029')
# ('Epoch:', '0196', 'training time (minutes)=', '0.1974', 'loss=', '0.001876486')
# ('Epoch:', '0197', 'training time (minutes)=', '0.1957', 'loss=', '0.001875909')
# ('Epoch:', '0198', 'training time (minutes)=', '0.1956', 'loss=', '0.001871405')
# ('Epoch:', '0199', 'training time (minutes)=', '0.1955', 'loss=', '0.001872857')
# ('Epoch:', '0200', 'training time (minutes)=', '0.1957', 'loss=', '0.001865743')

# %%
test_id_file = '/orions4-zfs/projects/lins2/Panos_Space/DATA/From_Matthias/shapenet_all-test.txt'
test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id, 
                                                      full_pclouds, full_model_names, n_threads = 24,
                                                      n_samples = int(n_points), search_pattern=search_pattern)
# Out:
# 1000 incomplete point clouds were loaded.

# %%
if do_plotting:
    saved_epochs = read_saved_epochs(conf.train_dir)
    plot_epochs = select_first_last_and_k(saved_epochs, 13)
    stats = eval_model(ae, conf, [train_data, test_data], epochs=plot_epochs)
    top_save_dir = osp.join(conf.train_dir, 'model_evaluation')
    plot_train_val_test_curves(stats, top_save_dir, has_validation=False, best_epoch=None, show=True)
    last_epoch = saved_epochs[-1]
    save_dir = osp.join(top_save_dir, 'train_images_epoch_' + str(last_epoch))    
    plot_reconstructions_at_epoch(last_epoch, ae, train_data, conf, save_dir=save_dir, max_plot=100)    
    save_dir = osp.join(top_save_dir, 'test_images_epoch_' + str(last_epoch))
    plot_reconstructions_at_epoch(last_epoch, ae, test_data, conf, save_dir=save_dir, max_plot=100)
