# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs, reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id, match_incomplete_to_complete_data
from tf_lab.autopredictors.scripts import loading_virt_scan_data as vscan

from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch, \
                                           plot_interpolations
from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs
                                                  


from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_points = 4096

experiment_name = '5_virt_scan_emd_2fc_decoder_' + str(n_points) + 'pts'

do_training = False
do_plotting = True
first_time_running = False
load_model = True

class_type = raw_input('Give me the class type.\n').lower()
class_syn_id = shape_net_category_to_synth_id()[class_type]
# Out:
# Give me the class type.
# chair

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/', str(n_points), class_syn_id)

train_dir = osp.join(top_data_dir, 'OUT/models/incomplete_pclouds/')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts'

# %%
full_file_names = pio.load_filenames_of_input_data(full_pclouds_path)
full_pclouds, full_model_names, class_ids = pio.load_crude_point_clouds(file_names=full_file_names, n_threads=20)
print '%d files containing complete point clouds were found.' % (len(full_pclouds), )

    
v_scan_top_dir = osp.join(top_data_dir, 'From_Matthias/shapenet_dim32_sdf_pc', class_syn_id)    
search_pattern = '.ply'

if do_training:
    train_id_file = '/orions4-zfs/projects/lins2/Panos_Space/DATA/From_Matthias/shapenet_all-train.txt'
    train_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, train_id_file, class_syn_id, 
                                                      full_pclouds, full_model_names, n_threads = 24,
                                                      n_samples=n_points, search_pattern=search_pattern)
else:
    test_id_file = '/orions4-zfs/projects/lins2/Panos_Space/DATA/From_Matthias/shapenet_all-test.txt'
    test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id, 
                                                      full_pclouds, full_model_names, n_threads=24,
                                                      n_samples=n_points, search_pattern=search_pattern)

# %%
# TRY ME.
from tf_lab.autopredictors.evaluate import accuracy_of_completion, coverage_of_completion

pp = incomplete_data.next_batch(1)
pinc = pp[2].reshape(n_points, 3)
pcom = pp[0].reshape(n_points, 3)

# accuracy_of_completion(pred_pcloud, gt_pcloud, thres=0.02, ret_dists=False):
    
score1, c1 = accuracy_of_completion(pinc, pcom, 0.02, ret_dists=True)
print score1
score2, c2 = coverage_of_completion(pcom, pinc, 0.02, ret_dists=True)
print score2


Point_Cloud(points=pinc).plot(c=c1);
Point_Cloud(points=pcom).plot(c=c2);
# Out:
# 0.61865234375
# 0.21630859375

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
else:
    n_input = [n_points, 3]    
    decoder_args = {'layer_sizes': [1024, np.prod(n_input)], 
                    'non_linearity': tf.nn.relu
                   }

    conf = Conf(
                n_input = n_input,
                denoising = True,
                training_epochs = 400,
                batch_size = 50,
                loss = 'emd',
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.00002,
                gauss_augment = {'mu': 0, 'sigma': 0.01},
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args,
               )

    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

# %%
reset_tf_graph()
set_visible_GPUs([0])
ae = PointNetAutoEncoder(experiment_name, conf)

if do_training:
    ae.train(train_data, conf)

else:
    saved_epochs = read_saved_epochs(conf.train_dir)
    ae.restore_model(train_dir, saved_epochs[-1])
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '9.0329', 'loss=', '359.263345451')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '8.9991', 'loss=', '304.508469124')
# ('Epoch:', '0003', 'training time (minutes)=', '8.9954', 'loss=', '290.818340645')
# ('Epoch:', '0004', 'training time (minutes)=', '8.9669', 'loss=', '282.716747665')
# ('Epoch:', '0005', 'training time (minutes)=', '8.9270', 'loss=', '276.908346214')
# ('Epoch:', '0006', 'training time (minutes)=', '8.9368', 'loss=', '273.024113750')
# ('Epoch:', '0007', 'training time (minutes)=', '8.9631', 'loss=', '269.682469921')
# ('Epoch:', '0008', 'training time (minutes)=', '8.9208', 'loss=', '267.069789352')
# ('Epoch:', '0009', 'training time (minutes)=', '8.9512', 'loss=', '264.906142597')
# ('Epoch:', '0010', 'training time (minutes)=', '9.0139', 'loss=', '263.075682507')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '8.9159', 'loss=', '261.255913429')
# ('Epoch:', '0012', 'training time (minutes)=', '8.9000', 'loss=', '259.770565681')
# ('Epoch:', '0013', 'training time (minutes)=', '8.9509', 'loss=', '258.542584953')
# ('Epoch:', '0014', 'training time (minutes)=', '9.0563', 'loss=', '257.367223072')
# ('Epoch:', '0015', 'training time (minutes)=', '8.9823', 'loss=', '256.135613174')
# ('Epoch:', '0016', 'training time (minutes)=', '8.9633', 'loss=', '254.929670525')
# ('Epoch:', '0017', 'training time (minutes)=', '8.9110', 'loss=', '254.159363613')
# ('Epoch:', '0018', 'training time (minutes)=', '8.9801', 'loss=', '253.111558704')
# ('Epoch:', '0019', 'training time (minutes)=', '8.9215', 'loss=', '252.283647232')
# ('Epoch:', '0020', 'training time (minutes)=', '8.9593', 'loss=', '251.482068920')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '8.8825', 'loss=', '250.813752022')
# ('Epoch:', '0022', 'training time (minutes)=', '8.9393', 'loss=', '250.021072197')
# ('Epoch:', '0023', 'training time (minutes)=', '8.9409', 'loss=', '249.444203835')
# ('Epoch:', '0024', 'training time (minutes)=', '8.9403', 'loss=', '248.794657555')
# ('Epoch:', '0025', 'training time (minutes)=', '8.8859', 'loss=', '247.993036728')
# ('Epoch:', '0026', 'training time (minutes)=', '8.8850', 'loss=', '247.322611847')
# ('Epoch:', '0027', 'training time (minutes)=', '8.9403', 'loss=', '246.847886791')
# ('Epoch:', '0028', 'training time (minutes)=', '8.9647', 'loss=', '246.296511040')
# ('Epoch:', '0029', 'training time (minutes)=', '9.0127', 'loss=', '245.894272156')
# ('Epoch:', '0030', 'training time (minutes)=', '8.9711', 'loss=', '245.102596378')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '8.9698', 'loss=', '244.630676041')
# ('Epoch:', '0032', 'training time (minutes)=', '9.0374', 'loss=', '244.296099720')
# ('Epoch:', '0033', 'training time (minutes)=', '9.0221', 'loss=', '243.718884754')
# ('Epoch:', '0034', 'training time (minutes)=', '8.9826', 'loss=', '243.202607536')
# ('Epoch:', '0035', 'training time (minutes)=', '9.0464', 'loss=', '242.700974293')
# ('Epoch:', '0036', 'training time (minutes)=', '8.9821', 'loss=', '242.240866966')
# ('Epoch:', '0037', 'training time (minutes)=', '9.0963', 'loss=', '241.866748447')
# ('Epoch:', '0038', 'training time (minutes)=', '9.0452', 'loss=', '241.584993420')
# ('Epoch:', '0039', 'training time (minutes)=', '8.9880', 'loss=', '241.105604649')
# ('Epoch:', '0040', 'training time (minutes)=', '9.0311', 'loss=', '240.962877712')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '9.0894', 'loss=', '240.242890759')
# ('Epoch:', '0042', 'training time (minutes)=', '8.9972', 'loss=', '239.916346359')
# ('Epoch:', '0043', 'training time (minutes)=', '8.9916', 'loss=', '239.514815121')
# ('Epoch:', '0044', 'training time (minutes)=', '8.9569', 'loss=', '239.085887413')
# ('Epoch:', '0045', 'training time (minutes)=', '8.9872', 'loss=', '238.918036461')
# ('Epoch:', '0046', 'training time (minutes)=', '8.8794', 'loss=', '238.526294079')
# ('Epoch:', '0047', 'training time (minutes)=', '8.8896', 'loss=', '238.081370564')
# ('Epoch:', '0048', 'training time (minutes)=', '8.9512', 'loss=', '237.936622944')
# ('Epoch:', '0049', 'training time (minutes)=', '8.8914', 'loss=', '237.513280602')
# ('Epoch:', '0050', 'training time (minutes)=', '9.0494', 'loss=', '237.424764786')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '8.8888', 'loss=', '237.034805851')
# ('Epoch:', '0052', 'training time (minutes)=', '8.9338', 'loss=', '236.584715881')
# ('Epoch:', '0053', 'training time (minutes)=', '9.1561', 'loss=', '236.438800201')
# ('Epoch:', '0054', 'training time (minutes)=', '9.1202', 'loss=', '236.007768555')
# ('Epoch:', '0055', 'training time (minutes)=', '9.0694', 'loss=', '235.802041245')
# ('Epoch:', '0056', 'training time (minutes)=', '9.1511', 'loss=', '235.400623512')
# ('Epoch:', '0057', 'training time (minutes)=', '9.1401', 'loss=', '235.315117798')
# ('Epoch:', '0058', 'training time (minutes)=', '9.1127', 'loss=', '234.900450592')
# ('Epoch:', '0059', 'training time (minutes)=', '9.0282', 'loss=', '234.787789612')
# ('Epoch:', '0060', 'training time (minutes)=', '9.0619', 'loss=', '234.502660408')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '9.1312', 'loss=', '234.301609535')
# ('Epoch:', '0062', 'training time (minutes)=', '9.1364', 'loss=', '233.986935215')
# ('Epoch:', '0063', 'training time (minutes)=', '9.0758', 'loss=', '233.768587208')
# ('Epoch:', '0064', 'training time (minutes)=', '9.0473', 'loss=', '233.520003681')
# ('Epoch:', '0065', 'training time (minutes)=', '9.0493', 'loss=', '233.343485870')
# ('Epoch:', '0066', 'training time (minutes)=', '9.1358', 'loss=', '233.106171894')
# ('Epoch:', '0067', 'training time (minutes)=', '9.1526', 'loss=', '233.074051304')
# ('Epoch:', '0068', 'training time (minutes)=', '9.1109', 'loss=', '232.525059452')
# ('Epoch:', '0069', 'training time (minutes)=', '9.1319', 'loss=', '232.256925907')
# ('Epoch:', '0070', 'training time (minutes)=', '9.1525', 'loss=', '232.169391308')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '9.0931', 'loss=', '231.945122604')
# ('Epoch:', '0072', 'training time (minutes)=', '9.0983', 'loss=', '231.724729977')
# ('Epoch:', '0073', 'training time (minutes)=', '9.0750', 'loss=', '231.524320393')
# ('Epoch:', '0074', 'training time (minutes)=', '8.9925', 'loss=', '231.300936375')
# ('Epoch:', '0075', 'training time (minutes)=', '9.0402', 'loss=', '231.077275677')
# ('Epoch:', '0076', 'training time (minutes)=', '9.0367', 'loss=', '230.948994522')
# ('Epoch:', '0077', 'training time (minutes)=', '9.1244', 'loss=', '230.823448925')
# ('Epoch:', '0078', 'training time (minutes)=', '9.3110', 'loss=', '230.480292873')
# ('Epoch:', '0079', 'training time (minutes)=', '9.3600', 'loss=', '230.225499287')
# ('Epoch:', '0080', 'training time (minutes)=', '8.9742', 'loss=', '230.117209320')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/incomplete_pclouds/5_virt_scan_emd_2fc_decoder_4096pts/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '9.0756', 'loss=', '230.043930836')
# ('Epoch:', '0082', 'training time (minutes)=', '8.9303', 'loss=', '229.727916679')
# ('Epoch:', '0083', 'training time (minutes)=', '8.9014', 'loss=', '229.570697060')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-09933a4ff077> in <module>()
#       4
#       5 if do_training:
# ----> 6     ae.train(train_data, conf)
#       7
#       8 else:
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in train(self, train_data, configuration)
#     149
#     150         for _ in xrange(c.training_epochs):
# --> 151             loss, duration = self._single_epoch_train(train_data, c)
#     152             epoch = int(self.sess.run(self.epoch.assign_add(tf.constant(1.0))))
#     153             stats.append((epoch, loss, duration))
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/point_net_ae.pyc in _single_epoch_train(self, train_data, configuration)
#      91
#      92             if self.is_denoising:
# ---> 93                 loss, _ = self.partial_fit(batch_i, original_data)
#      94             else:
#      95                 loss, _ = self.partial_fit(batch_i)
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in partial_fit(self, X, GT)
#     111         '''
#     112         if GT is not None:
# --> 113             _, loss, recon = self.sess.run((self.optimizer, self.loss, self.x_reconstr), feed_dict={self.x: X, self.gt: GT})
#     114         else:
#     115             _, loss, recon = self.sess.run((self.optimizer, self.loss, self.x_reconstr), feed_dict={self.x: X})
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
test_id_file = '/orions4-zfs/projects/lins2/Panos_Space/DATA/From_Matthias/shapenet_all-test.txt'
test_data = vscan.load_single_class_incomplete_dataset(v_scan_top_dir, test_id_file, class_syn_id, 
                                                      full_pclouds, full_model_names, n_threads=24,
                                                      n_samples=n_points, search_pattern=search_pattern)
# Out:
# 8000 incomplete point clouds were loaded.

# %%
if do_plotting:
    saved_epochs = read_saved_epochs(conf.train_dir)
    plot_epochs = select_first_last_and_k(saved_epochs, 13)
    stats = eval_model(ae, conf, [train_data, test_data], epochs=plot_epochs)
    top_save_dir = osp.join(conf.train_dir, 'model_evaluation')
    plot_train_val_test_curves(stats, top_save_dir, has_validation=False, best_epoch=None, show=True)
    last_epoch = saved_epochs[-1]
    save_dir = osp.join(top_save_dir, 'train_images_epoch_' + str(last_epoch))
    plot_reconstructions_at_epoch(last_epoch, ae, train_data, conf, save_dir=save_dir, max_plot=100)    
    save_dir = osp.join(top_save_dir, 'test_images_epoch_' + str(last_epoch))
    plot_reconstructions_at_epoch(last_epoch, ae, test_data, conf, save_dir=save_dir, max_plot=100)
