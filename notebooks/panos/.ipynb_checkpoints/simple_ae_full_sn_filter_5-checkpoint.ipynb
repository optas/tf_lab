# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from tf_lab.fundamentals.utils import set_visible_GPUs
import tf_lab.point_clouds.in_out as pio
import tf_lab.models.point_net_based_AE as pnAE
from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id
from tf_lab.point_clouds.in_out import PointCloudDataSet
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.various_encoders_decoders as enc_dec

from tf_lab.autopredictors.evaluate.basics import eval_model, read_saved_epochs
from tf_lab.autopredictors.plotting.basics import plot_original_pclouds_vs_reconstructed,\
                                                  plot_train_val_test_curves, plot_reconstructions_at_epoch


from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from geo_tool import Point_Cloud
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
seed = 42
np.random.seed(seed)
tf.set_random_seed(seed)

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'ShapeNetPointClouds/from_manifold_meshes/1024/')

experiment_name = 'enc_filter_1_simple_decode_no_noise'
train_dir = osp.join(top_data_dir, 'OUT/models/vanilla_ae/full_SN')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/vanilla_ae/full_SN/enc_filter_1_simple_decode_no_noise'

# %%
full_file_names = pio.load_filenames_of_input_data(full_pclouds_path)
full_pclouds, full_model_names, class_ids = pio.load_crude_point_clouds(file_names=full_file_names, n_threads=15)
print '%d files containing complete point clouds were found.' % (len(full_pclouds), )
# Out:
# 52103 files containing complete point clouds were found.
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:64: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')

# %%
train_data_, val_data_, test_data_ = pio.train_validate_test_split([full_pclouds,                                                            
                                                            full_model_names],
                                                            train_perc=0.8,
                                                            validate_perc=0.1,
                                                            test_perc=0.1,
                                                            seed=seed)

train_data = PointCloudDataSet(train_data_[0], labels=train_data_[1])
val_data = PointCloudDataSet(val_data_[0], labels=val_data_[1])
test_data = PointCloudDataSet(test_data_[0], labels=test_data_[1])

# %%
def reset_graph():
    if 'sess' in globals() and sess:
        sess.close()
    tf.reset_default_graph()

set_visible_GPUs([1])

conf = Conf(n_input = [1024, 3],
               training_epochs = 200,
               batch_size = 80,
               loss = 'Chamfer',
               train_dir = train_dir,
               loss_display_step = 1,
               saver_step = 5,
               learning_rate = 0.00002,
               saver_max_to_keep = 200,
               encoder = pnAE.encoder,
               decoder = enc_dec.decoder_only_with_fc
               )

reset_graph()
ae = PointNetAutoEncoder(experiment_name, conf)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-d44663708f11> in <module>()
#      15                learning_rate = 0.00002,
#      16                saver_max_to_keep = 200,
# ---> 17                encoder = enc_dec.encoder,
#      18                decoder = enc_dec.decoder_only_with_fc
#      19                )
#
# AttributeError: 'module' object has no attribute 'encoder'

# %%
ae.train(train_data, conf)
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.2722', 'loss=', '73.380819369')
# ('Epoch:', '0002', 'training time (minutes)=', '1.2556', 'loss=', '1.151869319')
# ('Epoch:', '0003', 'training time (minutes)=', '1.2665', 'loss=', '0.568272905')
# ('Epoch:', '0004', 'training time (minutes)=', '1.3000', 'loss=', '0.349021448')
# ('Epoch:', '0005', 'training time (minutes)=', '1.3543', 'loss=', '0.231656591')
# ('Epoch:', '0006', 'training time (minutes)=', '1.3669', 'loss=', '0.165791863')
# ('Epoch:', '0007', 'training time (minutes)=', '1.3662', 'loss=', '0.124701308')
# ('Epoch:', '0008', 'training time (minutes)=', '1.3576', 'loss=', '0.096723764')
# ('Epoch:', '0009', 'training time (minutes)=', '1.3527', 'loss=', '0.077135976')
# ('Epoch:', '0010', 'training time (minutes)=', '1.2911', 'loss=', '0.062697205')
# ('Epoch:', '0011', 'training time (minutes)=', '1.3357', 'loss=', '0.051770765')
# ('Epoch:', '0012', 'training time (minutes)=', '1.3280', 'loss=', '0.043272135')
# ('Epoch:', '0013', 'training time (minutes)=', '1.3587', 'loss=', '0.036581580')
# ('Epoch:', '0014', 'training time (minutes)=', '1.3592', 'loss=', '0.031296194')
# ('Epoch:', '0015', 'training time (minutes)=', '1.3207', 'loss=', '0.027050792')
# ('Epoch:', '0016', 'training time (minutes)=', '1.3320', 'loss=', '0.023642099')
# ('Epoch:', '0017', 'training time (minutes)=', '1.3400', 'loss=', '0.020878195')
# ('Epoch:', '0018', 'training time (minutes)=', '1.3413', 'loss=', '0.018579365')
# ('Epoch:', '0019', 'training time (minutes)=', '1.3475', 'loss=', '0.016643229')
# ('Epoch:', '0020', 'training time (minutes)=', '1.3524', 'loss=', '0.015036654')
# ('Epoch:', '0021', 'training time (minutes)=', '1.3411', 'loss=', '0.013746163')
# ('Epoch:', '0022', 'training time (minutes)=', '1.3645', 'loss=', '0.012614135')
# ('Epoch:', '0023', 'training time (minutes)=', '1.4006', 'loss=', '0.011657324')
# ('Epoch:', '0024', 'training time (minutes)=', '1.3580', 'loss=', '0.010839669')
# ('Epoch:', '0025', 'training time (minutes)=', '1.3738', 'loss=', '0.010148333')
# ('Epoch:', '0026', 'training time (minutes)=', '1.3976', 'loss=', '0.009497149')
# ('Epoch:', '0027', 'training time (minutes)=', '1.3644', 'loss=', '0.008934764')
# ('Epoch:', '0028', 'training time (minutes)=', '1.3488', 'loss=', '0.008463252')
# ('Epoch:', '0029', 'training time (minutes)=', '1.3558', 'loss=', '0.008016622')
# ('Epoch:', '0030', 'training time (minutes)=', '1.3554', 'loss=', '0.007603237')
# ('Epoch:', '0031', 'training time (minutes)=', '1.3386', 'loss=', '0.007247018')
# ('Epoch:', '0032', 'training time (minutes)=', '1.3490', 'loss=', '0.006915782')
# ('Epoch:', '0033', 'training time (minutes)=', '1.3573', 'loss=', '0.006625184')
# ('Epoch:', '0034', 'training time (minutes)=', '1.3611', 'loss=', '0.006368986')
# ('Epoch:', '0035', 'training time (minutes)=', '1.3470', 'loss=', '0.006102162')
# ('Epoch:', '0036', 'training time (minutes)=', '1.3371', 'loss=', '0.005884438')
# ('Epoch:', '0037', 'training time (minutes)=', '1.3025', 'loss=', '0.005669882')
# ('Epoch:', '0038', 'training time (minutes)=', '1.2621', 'loss=', '0.005465399')
# ('Epoch:', '0039', 'training time (minutes)=', '1.2601', 'loss=', '0.005308460')
# ('Epoch:', '0040', 'training time (minutes)=', '1.2790', 'loss=', '0.005123665')
# ('Epoch:', '0041', 'training time (minutes)=', '1.2648', 'loss=', '0.004960747')
# ('Epoch:', '0042', 'training time (minutes)=', '1.2659', 'loss=', '0.004821439')
# ('Epoch:', '0043', 'training time (minutes)=', '1.2711', 'loss=', '0.004672117')
# ('Epoch:', '0044', 'training time (minutes)=', '1.2698', 'loss=', '0.004564669')
# ('Epoch:', '0045', 'training time (minutes)=', '1.2757', 'loss=', '0.004431726')
# ('Epoch:', '0046', 'training time (minutes)=', '1.2606', 'loss=', '0.004329514')
# ('Epoch:', '0047', 'training time (minutes)=', '1.2725', 'loss=', '0.004209870')
# ('Epoch:', '0048', 'training time (minutes)=', '1.2646', 'loss=', '0.004126535')
# ('Epoch:', '0049', 'training time (minutes)=', '1.2550', 'loss=', '0.004017389')
# ('Epoch:', '0050', 'training time (minutes)=', '1.2687', 'loss=', '0.003938918')
# ('Epoch:', '0051', 'training time (minutes)=', '1.2606', 'loss=', '0.003863225')
# ('Epoch:', '0052', 'training time (minutes)=', '1.2597', 'loss=', '0.003775817')
# ('Epoch:', '0053', 'training time (minutes)=', '1.2882', 'loss=', '0.003700838')
# ('Epoch:', '0054', 'training time (minutes)=', '1.2663', 'loss=', '0.003634383')
# ('Epoch:', '0055', 'training time (minutes)=', '1.2628', 'loss=', '0.003556057')
# ('Epoch:', '0056', 'training time (minutes)=', '1.2661', 'loss=', '0.003500582')
# ('Epoch:', '0057', 'training time (minutes)=', '1.2549', 'loss=', '0.003441799')
# ('Epoch:', '0058', 'training time (minutes)=', '1.2537', 'loss=', '0.003375871')
# ('Epoch:', '0059', 'training time (minutes)=', '1.2453', 'loss=', '0.003322693')
# ('Epoch:', '0060', 'training time (minutes)=', '1.2592', 'loss=', '0.003274103')
# ('Epoch:', '0061', 'training time (minutes)=', '1.2529', 'loss=', '0.003222806')
# ('Epoch:', '0062', 'training time (minutes)=', '1.2633', 'loss=', '0.003181402')
# ('Epoch:', '0063', 'training time (minutes)=', '1.2557', 'loss=', '0.003132587')
# ('Epoch:', '0064', 'training time (minutes)=', '1.2712', 'loss=', '0.003081656')
# ('Epoch:', '0065', 'training time (minutes)=', '1.2587', 'loss=', '0.003040063')
# ('Epoch:', '0066', 'training time (minutes)=', '1.2452', 'loss=', '0.003000725')
# ('Epoch:', '0067', 'training time (minutes)=', '1.2424', 'loss=', '0.002965218')
# ('Epoch:', '0068', 'training time (minutes)=', '1.2452', 'loss=', '0.002922345')
# ('Epoch:', '0069', 'training time (minutes)=', '1.2454', 'loss=', '0.002886978')
# ('Epoch:', '0070', 'training time (minutes)=', '1.2508', 'loss=', '0.002862788')
# ('Epoch:', '0071', 'training time (minutes)=', '1.2502', 'loss=', '0.002821837')
# ('Epoch:', '0072', 'training time (minutes)=', '1.2391', 'loss=', '0.002797487')
# ('Epoch:', '0073', 'training time (minutes)=', '1.2429', 'loss=', '0.002766932')
# ('Epoch:', '0074', 'training time (minutes)=', '1.2377', 'loss=', '0.002737429')
# ('Epoch:', '0075', 'training time (minutes)=', '1.2661', 'loss=', '0.002707344')
# ('Epoch:', '0076', 'training time (minutes)=', '1.2629', 'loss=', '0.002673818')
# ('Epoch:', '0077', 'training time (minutes)=', '1.2719', 'loss=', '0.002652844')
# ('Epoch:', '0078', 'training time (minutes)=', '1.2430', 'loss=', '0.002627375')
# ('Epoch:', '0079', 'training time (minutes)=', '1.2458', 'loss=', '0.002606005')
# ('Epoch:', '0080', 'training time (minutes)=', '1.2485', 'loss=', '0.002578101')
# ('Epoch:', '0081', 'training time (minutes)=', '1.2442', 'loss=', '0.002547646')
# ('Epoch:', '0082', 'training time (minutes)=', '1.2454', 'loss=', '0.002543038')
# ('Epoch:', '0083', 'training time (minutes)=', '1.2415', 'loss=', '0.002518507')
# ('Epoch:', '0084', 'training time (minutes)=', '1.2483', 'loss=', '0.002501213')
# ('Epoch:', '0085', 'training time (minutes)=', '1.2411', 'loss=', '0.002475147')
# ('Epoch:', '0086', 'training time (minutes)=', '1.2412', 'loss=', '0.002453512')
# ('Epoch:', '0087', 'training time (minutes)=', '1.2561', 'loss=', '0.002441358')
# ('Epoch:', '0088', 'training time (minutes)=', '1.2499', 'loss=', '0.002421221')
# ('Epoch:', '0089', 'training time (minutes)=', '1.2473', 'loss=', '0.002401875')
# ('Epoch:', '0090', 'training time (minutes)=', '1.2462', 'loss=', '0.002385801')
# ('Epoch:', '0091', 'training time (minutes)=', '1.2467', 'loss=', '0.002368017')
# ('Epoch:', '0092', 'training time (minutes)=', '1.2416', 'loss=', '0.002355064')
# ('Epoch:', '0093', 'training time (minutes)=', '1.2432', 'loss=', '0.002338949')
# ('Epoch:', '0094', 'training time (minutes)=', '1.2569', 'loss=', '0.002323133')
# ('Epoch:', '0095', 'training time (minutes)=', '1.2480', 'loss=', '0.002308499')
# ('Epoch:', '0096', 'training time (minutes)=', '1.2446', 'loss=', '0.002298672')
# ('Epoch:', '0097', 'training time (minutes)=', '1.2470', 'loss=', '0.002278296')
# ('Epoch:', '0098', 'training time (minutes)=', '1.2456', 'loss=', '0.002267276')
# ('Epoch:', '0099', 'training time (minutes)=', '1.2420', 'loss=', '0.002250014')
# ('Epoch:', '0100', 'training time (minutes)=', '1.5379', 'loss=', '0.002240764')
# ('Epoch:', '0101', 'training time (minutes)=', '1.9342', 'loss=', '0.002228918')
# ('Epoch:', '0102', 'training time (minutes)=', '1.9446', 'loss=', '0.002213561')
# ('Epoch:', '0103', 'training time (minutes)=', '1.9269', 'loss=', '0.002200322')
# ('Epoch:', '0104', 'training time (minutes)=', '1.9396', 'loss=', '0.002194177')
# ('Epoch:', '0105', 'training time (minutes)=', '1.9560', 'loss=', '0.002183284')
# ('Epoch:', '0106', 'training time (minutes)=', '1.9292', 'loss=', '0.002170094')
# ('Epoch:', '0107', 'training time (minutes)=', '1.9329', 'loss=', '0.002156705')
# ('Epoch:', '0108', 'training time (minutes)=', '1.9346', 'loss=', '0.002146733')
# ('Epoch:', '0109', 'training time (minutes)=', '1.9580', 'loss=', '0.002140842')
# ('Epoch:', '0110', 'training time (minutes)=', '1.9119', 'loss=', '0.002134065')
# ('Epoch:', '0111', 'training time (minutes)=', '1.9233', 'loss=', '0.002120849')
# ('Epoch:', '0112', 'training time (minutes)=', '1.9299', 'loss=', '0.002108119')
# ('Epoch:', '0113', 'training time (minutes)=', '1.9065', 'loss=', '0.002099050')
# ('Epoch:', '0114', 'training time (minutes)=', '1.9446', 'loss=', '0.002090703')
# ('Epoch:', '0115', 'training time (minutes)=', '1.9166', 'loss=', '0.002082608')
# ('Epoch:', '0116', 'training time (minutes)=', '1.9194', 'loss=', '0.002071199')
# ('Epoch:', '0117', 'training time (minutes)=', '1.9114', 'loss=', '0.002064510')
# ('Epoch:', '0118', 'training time (minutes)=', '1.9260', 'loss=', '0.002061322')
# ('Epoch:', '0119', 'training time (minutes)=', '1.9082', 'loss=', '0.002045553')
# ('Epoch:', '0120', 'training time (minutes)=', '1.9642', 'loss=', '0.002036011')
# ('Epoch:', '0121', 'training time (minutes)=', '1.9560', 'loss=', '0.002027597')
# ('Epoch:', '0122', 'training time (minutes)=', '1.9199', 'loss=', '0.002026610')
# ('Epoch:', '0123', 'training time (minutes)=', '1.9420', 'loss=', '0.002014613')
# ('Epoch:', '0124', 'training time (minutes)=', '1.9262', 'loss=', '0.002012183')
# ('Epoch:', '0125', 'training time (minutes)=', '1.9149', 'loss=', '0.001999988')
# ('Epoch:', '0126', 'training time (minutes)=', '1.9147', 'loss=', '0.001994375')
# ('Epoch:', '0127', 'training time (minutes)=', '1.9309', 'loss=', '0.001982955')
# ('Epoch:', '0128', 'training time (minutes)=', '1.9276', 'loss=', '0.001976419')
# ('Epoch:', '0129', 'training time (minutes)=', '1.9169', 'loss=', '0.001969354')
# ('Epoch:', '0130', 'training time (minutes)=', '1.9213', 'loss=', '0.001963422')
# ('Epoch:', '0131', 'training time (minutes)=', '1.9210', 'loss=', '0.001952720')
# ('Epoch:', '0132', 'training time (minutes)=', '1.9327', 'loss=', '0.001945625')
# ('Epoch:', '0133', 'training time (minutes)=', '1.8973', 'loss=', '0.001944317')
# ('Epoch:', '0134', 'training time (minutes)=', '1.9377', 'loss=', '0.001936115')
# ('Epoch:', '0135', 'training time (minutes)=', '1.9351', 'loss=', '0.001928546')
# ('Epoch:', '0136', 'training time (minutes)=', '1.9308', 'loss=', '0.001919915')
# ('Epoch:', '0137', 'training time (minutes)=', '1.9185', 'loss=', '0.001916667')
# ('Epoch:', '0138', 'training time (minutes)=', '1.9138', 'loss=', '0.001910086')
# ('Epoch:', '0139', 'training time (minutes)=', '1.9343', 'loss=', '0.001899008')
# ('Epoch:', '0140', 'training time (minutes)=', '1.9314', 'loss=', '0.001893711')
# ('Epoch:', '0141', 'training time (minutes)=', '1.9426', 'loss=', '0.001890344')
# ('Epoch:', '0142', 'training time (minutes)=', '1.9083', 'loss=', '0.001882089')
# ('Epoch:', '0143', 'training time (minutes)=', '1.9252', 'loss=', '0.001879185')
# ('Epoch:', '0144', 'training time (minutes)=', '1.9216', 'loss=', '0.001867516')
# ('Epoch:', '0145', 'training time (minutes)=', '1.9340', 'loss=', '0.001864307')
# ('Epoch:', '0146', 'training time (minutes)=', '1.9315', 'loss=', '0.001860367')
# ('Epoch:', '0147', 'training time (minutes)=', '1.9193', 'loss=', '0.001850698')
# ('Epoch:', '0148', 'training time (minutes)=', '1.9348', 'loss=', '0.001845298')
# ('Epoch:', '0149', 'training time (minutes)=', '1.9129', 'loss=', '0.001841773')
# ('Epoch:', '0150', 'training time (minutes)=', '1.9294', 'loss=', '0.001836126')
# ('Epoch:', '0151', 'training time (minutes)=', '1.9347', 'loss=', '0.001832294')
# ('Epoch:', '0152', 'training time (minutes)=', '1.9676', 'loss=', '0.001824177')
# ('Epoch:', '0153', 'training time (minutes)=', '1.9115', 'loss=', '0.001818832')
# ('Epoch:', '0154', 'training time (minutes)=', '2.0678', 'loss=', '0.001813666')
# ('Epoch:', '0155', 'training time (minutes)=', '2.3727', 'loss=', '0.001806642')
# ('Epoch:', '0156', 'training time (minutes)=', '2.4153', 'loss=', '0.001801530')
# ('Epoch:', '0157', 'training time (minutes)=', '1.9084', 'loss=', '0.001796489')
# ('Epoch:', '0158', 'training time (minutes)=', '2.1839', 'loss=', '0.001789374')
# ('Epoch:', '0159', 'training time (minutes)=', '3.0888', 'loss=', '0.001784359')
# ('Epoch:', '0160', 'training time (minutes)=', '1.9359', 'loss=', '0.001781009')
# ('Epoch:', '0161', 'training time (minutes)=', '1.9037', 'loss=', '0.001772481')
# ('Epoch:', '0162', 'training time (minutes)=', '1.9317', 'loss=', '0.001770817')
# ('Epoch:', '0163', 'training time (minutes)=', '1.8950', 'loss=', '0.001762003')
# ('Epoch:', '0164', 'training time (minutes)=', '1.9336', 'loss=', '0.001758853')
# ('Epoch:', '0165', 'training time (minutes)=', '1.9113', 'loss=', '0.001755331')
# ('Epoch:', '0166', 'training time (minutes)=', '1.9059', 'loss=', '0.001748722')
# ('Epoch:', '0167', 'training time (minutes)=', '1.9294', 'loss=', '0.001740457')
# ('Epoch:', '0168', 'training time (minutes)=', '1.9093', 'loss=', '0.001739035')
# ('Epoch:', '0169', 'training time (minutes)=', '1.9323', 'loss=', '0.001730990')
# ('Epoch:', '0170', 'training time (minutes)=', '1.9122', 'loss=', '0.001730750')
# ('Epoch:', '0171', 'training time (minutes)=', '1.9307', 'loss=', '0.001723058')
# ('Epoch:', '0172', 'training time (minutes)=', '1.9121', 'loss=', '0.001719943')
# ('Epoch:', '0173', 'training time (minutes)=', '1.9323', 'loss=', '0.001714607')
# ('Epoch:', '0174', 'training time (minutes)=', '1.9081', 'loss=', '0.001706583')
# ('Epoch:', '0175', 'training time (minutes)=', '1.9313', 'loss=', '0.001705349')
# ('Epoch:', '0176', 'training time (minutes)=', '1.9185', 'loss=', '0.001702061')
# ('Epoch:', '0177', 'training time (minutes)=', '1.9094', 'loss=', '0.001695401')
# ('Epoch:', '0178', 'training time (minutes)=', '1.9251', 'loss=', '0.001688377')
# ('Epoch:', '0179', 'training time (minutes)=', '1.9094', 'loss=', '0.001685052')
# ('Epoch:', '0180', 'training time (minutes)=', '1.9319', 'loss=', '0.001678969')
# ('Epoch:', '0181', 'training time (minutes)=', '1.9088', 'loss=', '0.001675250')
# ('Epoch:', '0182', 'training time (minutes)=', '1.9273', 'loss=', '0.001671593')
# ('Epoch:', '0183', 'training time (minutes)=', '1.9074', 'loss=', '0.001664629')
# ('Epoch:', '0184', 'training time (minutes)=', '1.9302', 'loss=', '0.001661444')
# ('Epoch:', '0185', 'training time (minutes)=', '1.9083', 'loss=', '0.001659432')
# ('Epoch:', '0186', 'training time (minutes)=', '1.9266', 'loss=', '0.001656612')
# ('Epoch:', '0187', 'training time (minutes)=', '1.9101', 'loss=', '0.001650463')
# ('Epoch:', '0188', 'training time (minutes)=', '1.9211', 'loss=', '0.001644554')
# ('Epoch:', '0189', 'training time (minutes)=', '1.9162', 'loss=', '0.001642586')
# ('Epoch:', '0190', 'training time (minutes)=', '1.9027', 'loss=', '0.001634845')
# ('Epoch:', '0191', 'training time (minutes)=', '1.9309', 'loss=', '0.001633055')
# ('Epoch:', '0192', 'training time (minutes)=', '1.9032', 'loss=', '0.001633225')
#  (170, 0.0017307498999522737, 114.7343201637268),
#  (171, 0.001723057594670487, 115.8445041179657),
#  (172, 0.001719942729117531, 114.72884798049927),
#  (173, 0.0017146074649700878, 115.93710803985596),
#  (174, 0.0017065830540355302, 114.48515391349792),
#  (175, 0.0017053492860189298, 115.87680315971375),
#  (176, 0.0017020611323491312, 115.10940194129944),
#  (177, 0.0016954008399575034, 114.5654399394989),
#  (178, 0.0016883767805207027, 115.50426197052002),
#  (179, 0.0016850516972741587, 114.56441688537598),
#  (180, 0.0016789686977380668, 115.91675400733948),
#  (181, 0.0016752501045605758, 114.53098201751709),
#  (182, 0.0016715930343110422, 115.63727712631226),
#  (183, 0.0016646287580523032, 114.44379210472107),
#  (184, 0.0016614436609902904, 115.80980396270752),
#  (185, 0.001659431595323096, 114.4968729019165),
#  (186, 0.0016566116417330939, 115.59415793418884),
#  (187, 0.0016504634650345469, 114.60806608200073),
#  (188, 0.0016445544816020897, 115.26737689971924),
#  (189, 0.0016425864207031001, 114.97065711021423),
#  (190, 0.0016348450370901578, 114.16480207443237),
#  (191, 0.0016330552813391453, 115.85492491722107),
#  (192, 0.0016332248618179171, 114.19437408447266),
#  (193, 0.0016261709618494774, 115.63064789772034),
#  (194, 0.0016227357599869971, 114.39218997955322),
#  (195, 0.0016188678358933547, 120.12507104873657),
#  (196, 0.001612944100785021, 116.35999202728271),
#  (197, 0.0016088889721394902, 115.96148896217346),
#  (198, 0.0016076331573847732, 116.00343084335327),
#  (199, 0.0016041399120941271, 114.27227401733398),
#  (200, 0.0015996307431364472, 115.99116015434265)]

# %%
saved_epochs = read_saved_epochs(conf.train_dir)
epochs = saved_epochs[::len(saved_epochs)/10]
stats = eval_model(ae, conf, [train_data, test_data, val_data], epochs=epochs, verbose=True)
# Out:
# Model restored in epoch 5.
# [ 0.00207236  0.00206381  0.0020587 ]
# Model restored in epoch 105.
# [ 0.00133248  0.00134782  0.00134744]
# Model restored in epoch 205.
# [ 0.00123548  0.0012542   0.00125345]
# Model restored in epoch 305.
# [ 0.00118832  0.00120968  0.00120962]
# Model restored in epoch 405.
# [ 0.00116001  0.00118209  0.0011806 ]
# Model restored in epoch 505.
# [ 0.00114046  0.00116347  0.00116377]
# Model restored in epoch 605.
# [ 0.00112597  0.00114997  0.00114977]
# Model restored in epoch 705.
# [ 0.00111522  0.00113998  0.00114075]
# Model restored in epoch 805.
# [ 0.00110638  0.00113268  0.00113281]
# Model restored in epoch 905.
# [ 0.00109887  0.00112606  0.00112581]

# %%
top_save_dir = osp.join(top_data_dir, 'OUT/model_evaluation/vanilla_ae/full_sn', experiment_name)
plot_train_val_test_curves(stats, top_save_dir, has_validation=True, best_epoch=None, show=True)

# %%
last_epoch = saved_epochs[-1]
save_dir = osp.join(top_save_dir, 'train_images_epoch_' + str(last_epoch))
plot_reconstructions_at_epoch(last_epoch, ae, train_data, conf, save_dir=save_dir, max_plot=250)

save_dir = osp.join(top_save_dir, 'test_images_epoch_' + str(last_epoch))
plot_reconstructions_at_epoch(last_epoch, ae, test_data, conf, save_dir=save_dir, max_plot=250)
