# %%
import numpy as np
import os.path as osp
from scipy.io import loadmat
from numpy.random import choice
from geo_tool import Point_Cloud
from general_tools.in_out.basics import create_dir

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
class_name = 'table'

# %%
mit_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/nips/mit_3dgan_synthetic_samples/isosurface_extracted/'

# %%
mit_data_file = osp.join(mit_data_dir, class_name + '.mat')

# %%
mit_data = loadmat(mit_data_file)
mit_data = np.squeeze(mit_data['point_sets_fs'])

print mit_data.shape
n_models = len(mit_data)
np.savez(mit_data_dir + class_name, mit_data)
# Out:
# (20, 2048, 3)

# %%
for i in range(len(mit_data)):
    pc = Point_Cloud(mit_data[i])
    pc.plot(in_u_sphere=True)
