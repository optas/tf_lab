# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 1
setup_one_gpu(GPU)
# Out:
# Picking GPU 1

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio

from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch


from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud

from tf_lab.nips.shape_net import pc_loader as sn_pc_loader
from tf_lab.nips.helper import load_shape_net_models_used_by_wu
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = True
load_model = False
z_rotate = True
seed = 42
max_training_epochs = 2000
loss = 'emd'
is_convolutional = True

# %%
if is_convolutional:
    arch_tag = 'convolutional_arch'
    
    encoder_args = {'n_filters': [128, 128, 256, 512],
                    'filter_sizes': [40, 20, 10, 10],
                    'strides': [1, 2, 2, 1]
                   }
        
else:
    arch_tag = 'mlp_arch'
    encoder_args = {'n_filters': [64, 128, 256, 512],
                    'filter_sizes' :[1, 1, 1, 1],
                    'strides': [1, 1, 1, 1]
                   }

# %%
experiment_name = 'wu_classes_rotated_' + arch_tag + '_' + str(n_pc_samples) +  'pts_' + loss
top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/centered/', str(n_pc_samples))
train_dir = osp.join(top_data_dir, 'OUT/models/nips/vanilla_ae/')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd'

# %%
full_pclouds, full_model_names, full_syn_ids = load_shape_net_models_used_by_wu(n_pc_samples, full_pclouds_path)
model_unames = full_model_names + '.' + full_syn_ids
train_data = PointCloudDataSet(full_pclouds, labels=model_unames)
# Out:
# airplane 02691156
# 4045 files containing complete point clouds were found.
# car 02958343
# 7497 files containing complete point clouds were found.
# chair 03001627
# 6778 files containing complete point clouds were found.
# sofa 04256520
# 3173 files containing complete point clouds were found.
# rifle 04090263
# 2372 files containing complete point clouds were found.
# boat 02858304
# 1137 files containing complete point clouds were found.
# table 04379243
# 8509 files containing complete point clouds were found.

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:
    n_input = [n_pc_samples, 3]
    
    decoder_args = {'layer_sizes': [1024, 2048, np.prod(n_input)] }
    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args,        
               )

    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)

# %%
if do_training:
    training_stats = []
    training_stats.append(ae.train(train_data, conf))    
    with open(osp.join(conf.train_dir, 'train_stats.txt'), 'a') as fout:
        np.savetxt(fout, np.array(training_stats)[0])
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '2.2727', 'loss=', '152.786504273')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '2.3132', 'loss=', '119.674164354')
# ('Epoch:', '0003', 'training time (minutes)=', '2.3201', 'loss=', '112.582312638')
# ('Epoch:', '0004', 'training time (minutes)=', '2.3195', 'loss=', '108.705492105')
# ('Epoch:', '0005', 'training time (minutes)=', '2.3196', 'loss=', '105.284985386')
# ('Epoch:', '0006', 'training time (minutes)=', '2.3172', 'loss=', '103.376937980')
# ('Epoch:', '0007', 'training time (minutes)=', '2.3186', 'loss=', '101.437930309')
# ('Epoch:', '0008', 'training time (minutes)=', '2.3203', 'loss=', '99.984751061')
# ('Epoch:', '0009', 'training time (minutes)=', '2.3246', 'loss=', '98.532885309')
# ('Epoch:', '0010', 'training time (minutes)=', '2.3113', 'loss=', '97.186561767')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '2.3171', 'loss=', '96.042553460')
# ('Epoch:', '0012', 'training time (minutes)=', '2.3148', 'loss=', '95.051395860')
# ('Epoch:', '0013', 'training time (minutes)=', '2.3181', 'loss=', '94.037851237')
# ('Epoch:', '0014', 'training time (minutes)=', '2.3140', 'loss=', '93.161212807')
# ('Epoch:', '0015', 'training time (minutes)=', '2.3118', 'loss=', '92.257684133')
# ('Epoch:', '0016', 'training time (minutes)=', '2.2959', 'loss=', '91.503473367')
# ('Epoch:', '0017', 'training time (minutes)=', '2.2967', 'loss=', '90.798620355')
# ('Epoch:', '0018', 'training time (minutes)=', '2.2991', 'loss=', '90.029583672')
# ('Epoch:', '0019', 'training time (minutes)=', '2.3062', 'loss=', '89.378176857')
# ('Epoch:', '0020', 'training time (minutes)=', '2.3129', 'loss=', '88.934566395')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '2.2938', 'loss=', '88.103467173')
# ('Epoch:', '0022', 'training time (minutes)=', '2.2928', 'loss=', '87.766920653')
# ('Epoch:', '0023', 'training time (minutes)=', '2.3011', 'loss=', '87.137685975')
# ('Epoch:', '0024', 'training time (minutes)=', '2.2934', 'loss=', '86.692774326')
# ('Epoch:', '0025', 'training time (minutes)=', '2.2968', 'loss=', '86.056697071')
# ('Epoch:', '0026', 'training time (minutes)=', '2.2948', 'loss=', '85.764160726')
# ('Epoch:', '0027', 'training time (minutes)=', '2.2951', 'loss=', '85.178715481')
# ('Epoch:', '0028', 'training time (minutes)=', '2.2937', 'loss=', '84.877365203')
# ('Epoch:', '0029', 'training time (minutes)=', '2.2942', 'loss=', '84.398979540')
# ('Epoch:', '0030', 'training time (minutes)=', '2.2939', 'loss=', '83.924211303')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '2.2939', 'loss=', '83.500831160')
# ('Epoch:', '0032', 'training time (minutes)=', '2.2939', 'loss=', '83.310047457')
# ('Epoch:', '0033', 'training time (minutes)=', '2.2922', 'loss=', '82.881733476')
# ('Epoch:', '0034', 'training time (minutes)=', '2.2945', 'loss=', '82.471240622')
# ('Epoch:', '0035', 'training time (minutes)=', '2.2923', 'loss=', '82.211600904')
# ('Epoch:', '0036', 'training time (minutes)=', '2.2950', 'loss=', '81.740615799')
# ('Epoch:', '0037', 'training time (minutes)=', '2.2898', 'loss=', '81.626852542')
# ('Epoch:', '0038', 'training time (minutes)=', '2.2904', 'loss=', '81.329563574')
# ('Epoch:', '0039', 'training time (minutes)=', '2.2948', 'loss=', '81.067579822')
# ('Epoch:', '0040', 'training time (minutes)=', '2.2905', 'loss=', '80.726529887')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '2.2932', 'loss=', '80.438901395')
# ('Epoch:', '0042', 'training time (minutes)=', '2.2943', 'loss=', '80.209289699')
# ('Epoch:', '0043', 'training time (minutes)=', '2.2940', 'loss=', '80.123103424')
# ('Epoch:', '0044', 'training time (minutes)=', '2.2918', 'loss=', '79.685983629')
# ('Epoch:', '0045', 'training time (minutes)=', '2.2947', 'loss=', '79.496324374')
# ('Epoch:', '0046', 'training time (minutes)=', '2.2938', 'loss=', '79.321618174')
# ('Epoch:', '0047', 'training time (minutes)=', '2.2967', 'loss=', '78.821482747')
# ('Epoch:', '0048', 'training time (minutes)=', '2.2972', 'loss=', '78.999685714')
# ('Epoch:', '0049', 'training time (minutes)=', '2.2944', 'loss=', '78.458904836')
# ('Epoch:', '0050', 'training time (minutes)=', '2.2938', 'loss=', '78.441059101')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '2.2974', 'loss=', '78.099161029')
# ('Epoch:', '0052', 'training time (minutes)=', '2.2925', 'loss=', '78.089552444')
# ('Epoch:', '0053', 'training time (minutes)=', '2.2947', 'loss=', '77.824494365')
# ('Epoch:', '0054', 'training time (minutes)=', '2.2957', 'loss=', '77.618128785')
# ('Epoch:', '0055', 'training time (minutes)=', '2.3019', 'loss=', '77.379108201')
# ('Epoch:', '0056', 'training time (minutes)=', '2.3061', 'loss=', '77.267749946')
# ('Epoch:', '0057', 'training time (minutes)=', '2.2995', 'loss=', '77.015048058')
# ('Epoch:', '0058', 'training time (minutes)=', '2.3011', 'loss=', '76.916902924')
# ('Epoch:', '0059', 'training time (minutes)=', '2.3080', 'loss=', '76.800949142')
# ('Epoch:', '0060', 'training time (minutes)=', '2.3142', 'loss=', '76.512729633')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '2.3178', 'loss=', '76.417174610')
# ('Epoch:', '0062', 'training time (minutes)=', '2.3198', 'loss=', '76.303367398')
# ('Epoch:', '0063', 'training time (minutes)=', '2.2966', 'loss=', '76.191585040')
# ('Epoch:', '0064', 'training time (minutes)=', '2.2990', 'loss=', '75.965642639')
# ('Epoch:', '0065', 'training time (minutes)=', '2.3089', 'loss=', '75.853629337')
# ('Epoch:', '0066', 'training time (minutes)=', '2.3073', 'loss=', '75.670703979')
# ('Epoch:', '0067', 'training time (minutes)=', '2.3091', 'loss=', '75.632538616')
# ('Epoch:', '0068', 'training time (minutes)=', '2.3002', 'loss=', '75.396851577')
# ('Epoch:', '0069', 'training time (minutes)=', '2.3051', 'loss=', '75.233085427')
# ('Epoch:', '0070', 'training time (minutes)=', '2.2999', 'loss=', '75.133786626')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '2.2944', 'loss=', '75.043605713')
# ('Epoch:', '0072', 'training time (minutes)=', '2.2997', 'loss=', '74.880561157')
# ('Epoch:', '0073', 'training time (minutes)=', '2.3061', 'loss=', '74.822657252')
# ('Epoch:', '0074', 'training time (minutes)=', '2.3063', 'loss=', '74.592800083')
# ('Epoch:', '0075', 'training time (minutes)=', '2.3062', 'loss=', '74.559100615')
# ('Epoch:', '0076', 'training time (minutes)=', '2.3029', 'loss=', '74.386614933')
# ('Epoch:', '0077', 'training time (minutes)=', '2.3055', 'loss=', '74.259385510')
# ('Epoch:', '0078', 'training time (minutes)=', '2.3095', 'loss=', '74.157235456')
# ('Epoch:', '0079', 'training time (minutes)=', '2.3064', 'loss=', '74.101756628')
# ('Epoch:', '0080', 'training time (minutes)=', '2.3031', 'loss=', '73.986142161')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '2.3032', 'loss=', '73.881086014')
# ('Epoch:', '0082', 'training time (minutes)=', '2.3097', 'loss=', '73.759600363')
# ('Epoch:', '0083', 'training time (minutes)=', '2.3086', 'loss=', '73.588387048')
# ('Epoch:', '0084', 'training time (minutes)=', '2.3094', 'loss=', '73.607307423')
# ('Epoch:', '0085', 'training time (minutes)=', '2.3137', 'loss=', '73.448999308')
# ('Epoch:', '0086', 'training time (minutes)=', '2.2995', 'loss=', '73.359941613')
# ('Epoch:', '0087', 'training time (minutes)=', '2.3051', 'loss=', '73.175126261')
# ('Epoch:', '0088', 'training time (minutes)=', '2.2987', 'loss=', '73.168550178')
# ('Epoch:', '0089', 'training time (minutes)=', '2.3048', 'loss=', '73.064744944')
# ('Epoch:', '0090', 'training time (minutes)=', '2.3051', 'loss=', '73.044520409')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '2.3064', 'loss=', '72.871823382')
# ('Epoch:', '0092', 'training time (minutes)=', '2.3120', 'loss=', '72.770952003')
# ('Epoch:', '0093', 'training time (minutes)=', '2.3035', 'loss=', '72.765105347')
# ('Epoch:', '0094', 'training time (minutes)=', '2.2930', 'loss=', '72.663199707')
# ('Epoch:', '0095', 'training time (minutes)=', '2.2992', 'loss=', '72.540944512')
# ('Epoch:', '0096', 'training time (minutes)=', '2.3062', 'loss=', '72.476361380')
# ('Epoch:', '0097', 'training time (minutes)=', '2.2965', 'loss=', '72.432621913')
# ('Epoch:', '0098', 'training time (minutes)=', '2.3097', 'loss=', '72.351013013')
# ('Epoch:', '0099', 'training time (minutes)=', '2.2954', 'loss=', '72.130248112')
# ('Epoch:', '0100', 'training time (minutes)=', '2.2923', 'loss=', '72.080712731')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '2.3002', 'loss=', '71.973179000')
# ('Epoch:', '0102', 'training time (minutes)=', '2.3093', 'loss=', '72.025026042')
# ('Epoch:', '0103', 'training time (minutes)=', '2.3131', 'loss=', '71.969768797')
# ('Epoch:', '0104', 'training time (minutes)=', '2.3073', 'loss=', '71.777426523')
# ('Epoch:', '0105', 'training time (minutes)=', '2.2982', 'loss=', '71.679554692')
# ('Epoch:', '0106', 'training time (minutes)=', '2.2978', 'loss=', '71.672281487')
# ('Epoch:', '0107', 'training time (minutes)=', '2.3013', 'loss=', '71.610398922')
# ('Epoch:', '0108', 'training time (minutes)=', '2.2972', 'loss=', '71.498623498')
# ('Epoch:', '0109', 'training time (minutes)=', '2.3054', 'loss=', '71.425726170')
# ('Epoch:', '0110', 'training time (minutes)=', '2.3137', 'loss=', '71.374766597')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '2.3010', 'loss=', '71.226668287')
# ('Epoch:', '0112', 'training time (minutes)=', '2.2969', 'loss=', '71.248646073')
# ('Epoch:', '0113', 'training time (minutes)=', '2.2952', 'loss=', '71.281916251')
# ('Epoch:', '0114', 'training time (minutes)=', '2.2961', 'loss=', '71.090452838')
# ('Epoch:', '0115', 'training time (minutes)=', '2.2959', 'loss=', '71.147620141')
# ('Epoch:', '0116', 'training time (minutes)=', '2.2974', 'loss=', '70.968673558')
# ('Epoch:', '0117', 'training time (minutes)=', '2.3048', 'loss=', '70.908017252')
# ('Epoch:', '0118', 'training time (minutes)=', '2.3077', 'loss=', '70.886869220')
# ('Epoch:', '0119', 'training time (minutes)=', '2.3137', 'loss=', '70.907621549')
# ('Epoch:', '0120', 'training time (minutes)=', '2.3128', 'loss=', '70.656591774')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '2.3046', 'loss=', '70.747133773')
# ('Epoch:', '0122', 'training time (minutes)=', '2.2940', 'loss=', '70.592565878')
# ('Epoch:', '0123', 'training time (minutes)=', '2.3128', 'loss=', '70.525484478')
# ('Epoch:', '0124', 'training time (minutes)=', '2.2931', 'loss=', '70.579539000')
# ('Epoch:', '0125', 'training time (minutes)=', '2.2991', 'loss=', '70.539057786')
# ('Epoch:', '0126', 'training time (minutes)=', '2.2990', 'loss=', '70.390613943')
# ('Epoch:', '0127', 'training time (minutes)=', '2.2926', 'loss=', '70.413750276')
# ('Epoch:', '0128', 'training time (minutes)=', '2.2928', 'loss=', '70.320583321')
# ('Epoch:', '0129', 'training time (minutes)=', '2.3037', 'loss=', '70.154264012')
# ('Epoch:', '0130', 'training time (minutes)=', '2.3099', 'loss=', '70.192906064')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '2.3020', 'loss=', '70.190735843')
# ('Epoch:', '0132', 'training time (minutes)=', '2.3134', 'loss=', '70.112305069')
# ('Epoch:', '0133', 'training time (minutes)=', '2.3098', 'loss=', '69.975587059')
# ('Epoch:', '0134', 'training time (minutes)=', '2.2989', 'loss=', '70.022060326')
# ('Epoch:', '0135', 'training time (minutes)=', '2.2990', 'loss=', '69.907893884')
# ('Epoch:', '0136', 'training time (minutes)=', '2.3001', 'loss=', '69.811132061')
# ('Epoch:', '0137', 'training time (minutes)=', '2.3051', 'loss=', '69.780577486')
# ('Epoch:', '0138', 'training time (minutes)=', '2.3026', 'loss=', '69.811338049')
# ('Epoch:', '0139', 'training time (minutes)=', '2.2924', 'loss=', '69.786805435')
# ('Epoch:', '0140', 'training time (minutes)=', '2.2967', 'loss=', '69.663373987')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '2.2936', 'loss=', '69.614972926')
# ('Epoch:', '0142', 'training time (minutes)=', '2.2924', 'loss=', '69.661967747')
# ('Epoch:', '0143', 'training time (minutes)=', '2.3028', 'loss=', '69.550857367')
# ('Epoch:', '0144', 'training time (minutes)=', '2.2931', 'loss=', '69.499135789')
# ('Epoch:', '0145', 'training time (minutes)=', '2.2960', 'loss=', '69.457608095')
# ('Epoch:', '0146', 'training time (minutes)=', '2.2993', 'loss=', '69.429104922')
# ('Epoch:', '0147', 'training time (minutes)=', '2.3001', 'loss=', '69.298471001')
# ('Epoch:', '0148', 'training time (minutes)=', '2.3037', 'loss=', '69.341667824')
# ('Epoch:', '0149', 'training time (minutes)=', '2.3048', 'loss=', '69.286557428')
# ('Epoch:', '0150', 'training time (minutes)=', '2.2973', 'loss=', '69.216193857')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '2.3099', 'loss=', '69.206769340')
# ('Epoch:', '0152', 'training time (minutes)=', '2.3133', 'loss=', '69.288085556')
# ('Epoch:', '0153', 'training time (minutes)=', '2.3092', 'loss=', '69.038181151')
# ('Epoch:', '0154', 'training time (minutes)=', '2.2957', 'loss=', '69.027096478')
# ('Epoch:', '0155', 'training time (minutes)=', '2.2960', 'loss=', '68.965683718')
# ('Epoch:', '0156', 'training time (minutes)=', '2.2925', 'loss=', '69.032372347')
# ('Epoch:', '0157', 'training time (minutes)=', '2.2961', 'loss=', '68.975531979')
# ('Epoch:', '0158', 'training time (minutes)=', '2.2923', 'loss=', '68.933370436')
# ('Epoch:', '0159', 'training time (minutes)=', '2.3034', 'loss=', '68.842628957')
# ('Epoch:', '0160', 'training time (minutes)=', '2.3068', 'loss=', '68.895844098')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '2.2952', 'loss=', '68.770573289')
# ('Epoch:', '0162', 'training time (minutes)=', '2.2930', 'loss=', '68.773718916')
# ('Epoch:', '0163', 'training time (minutes)=', '2.2992', 'loss=', '68.770934182')
# ('Epoch:', '0164', 'training time (minutes)=', '2.2992', 'loss=', '68.717835367')
# ('Epoch:', '0165', 'training time (minutes)=', '2.2926', 'loss=', '68.595420849')
# ('Epoch:', '0166', 'training time (minutes)=', '2.2925', 'loss=', '68.644360955')
# ('Epoch:', '0167', 'training time (minutes)=', '2.3008', 'loss=', '68.578579809')
# ('Epoch:', '0168', 'training time (minutes)=', '2.3124', 'loss=', '68.551908322')
# ('Epoch:', '0169', 'training time (minutes)=', '2.3098', 'loss=', '68.505205553')
# ('Epoch:', '0170', 'training time (minutes)=', '2.3065', 'loss=', '68.445771619')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '2.3006', 'loss=', '68.456978693')
# ('Epoch:', '0172', 'training time (minutes)=', '2.3130', 'loss=', '68.396394849')
# ('Epoch:', '0173', 'training time (minutes)=', '2.3059', 'loss=', '68.344469720')
# ('Epoch:', '0174', 'training time (minutes)=', '2.3022', 'loss=', '68.337322981')
# ('Epoch:', '0175', 'training time (minutes)=', '2.3003', 'loss=', '68.307853716')
# ('Epoch:', '0176', 'training time (minutes)=', '2.2987', 'loss=', '68.260503251')
# ('Epoch:', '0177', 'training time (minutes)=', '2.3064', 'loss=', '68.224159275')
# ('Epoch:', '0178', 'training time (minutes)=', '2.3000', 'loss=', '68.190122895')
# ('Epoch:', '0179', 'training time (minutes)=', '2.3159', 'loss=', '68.148134192')
# ('Epoch:', '0180', 'training time (minutes)=', '2.3033', 'loss=', '68.113891220')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '2.3036', 'loss=', '68.131664310')
# ('Epoch:', '0182', 'training time (minutes)=', '2.3012', 'loss=', '68.050426187')
# ('Epoch:', '0183', 'training time (minutes)=', '2.3002', 'loss=', '68.123781637')
# ('Epoch:', '0184', 'training time (minutes)=', '2.2957', 'loss=', '67.995816148')
# ('Epoch:', '0185', 'training time (minutes)=', '2.2995', 'loss=', '67.988052852')
# ('Epoch:', '0186', 'training time (minutes)=', '2.3092', 'loss=', '68.003362491')
# ('Epoch:', '0187', 'training time (minutes)=', '2.2993', 'loss=', '67.933872103')
# ('Epoch:', '0188', 'training time (minutes)=', '2.3036', 'loss=', '67.860948534')
# ('Epoch:', '0189', 'training time (minutes)=', '2.3034', 'loss=', '67.862943683')
# ('Epoch:', '0190', 'training time (minutes)=', '2.2995', 'loss=', '67.900911997')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '2.3020', 'loss=', '67.817584599')
# ('Epoch:', '0192', 'training time (minutes)=', '2.2998', 'loss=', '67.735316006')
# ('Epoch:', '0193', 'training time (minutes)=', '2.2985', 'loss=', '67.815718420')
# ('Epoch:', '0194', 'training time (minutes)=', '2.2961', 'loss=', '67.743234822')
# ('Epoch:', '0195', 'training time (minutes)=', '2.3067', 'loss=', '67.693295795')
# ('Epoch:', '0196', 'training time (minutes)=', '2.3052', 'loss=', '67.676846621')
# ('Epoch:', '0197', 'training time (minutes)=', '2.3027', 'loss=', '67.624558457')
# ('Epoch:', '0198', 'training time (minutes)=', '2.2991', 'loss=', '67.604757218')
# ('Epoch:', '0199', 'training time (minutes)=', '2.2990', 'loss=', '67.543412098')
# ('Epoch:', '0200', 'training time (minutes)=', '2.2956', 'loss=', '67.542157079')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '2.2940', 'loss=', '67.507735102')
# ('Epoch:', '0202', 'training time (minutes)=', '2.2998', 'loss=', '67.499773640')
# ('Epoch:', '0203', 'training time (minutes)=', '2.3055', 'loss=', '67.466648438')
# ('Epoch:', '0204', 'training time (minutes)=', '2.2978', 'loss=', '67.506554720')
# ('Epoch:', '0205', 'training time (minutes)=', '2.2975', 'loss=', '67.404093814')
# ('Epoch:', '0206', 'training time (minutes)=', '2.2928', 'loss=', '67.415734385')
# ('Epoch:', '0207', 'training time (minutes)=', '2.2925', 'loss=', '67.343870362')
# ('Epoch:', '0208', 'training time (minutes)=', '2.2923', 'loss=', '67.392470380')
# ('Epoch:', '0209', 'training time (minutes)=', '2.2970', 'loss=', '67.335892060')
# ('Epoch:', '0210', 'training time (minutes)=', '2.2983', 'loss=', '67.264510852')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '2.2915', 'loss=', '67.312914658')
# ('Epoch:', '0212', 'training time (minutes)=', '2.3065', 'loss=', '67.288348218')
# ('Epoch:', '0213', 'training time (minutes)=', '2.3059', 'loss=', '67.223403703')
# ('Epoch:', '0214', 'training time (minutes)=', '2.3004', 'loss=', '67.222243289')
# ('Epoch:', '0215', 'training time (minutes)=', '2.2960', 'loss=', '67.129370573')
# ('Epoch:', '0216', 'training time (minutes)=', '2.2960', 'loss=', '67.235497603')
# ('Epoch:', '0217', 'training time (minutes)=', '2.3001', 'loss=', '67.095301551')
# ('Epoch:', '0218', 'training time (minutes)=', '2.2981', 'loss=', '67.076728764')
# ('Epoch:', '0219', 'training time (minutes)=', '2.3033', 'loss=', '67.074102840')
# ('Epoch:', '0220', 'training time (minutes)=', '2.2960', 'loss=', '67.100652444')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '2.2922', 'loss=', '67.008898875')
# ('Epoch:', '0222', 'training time (minutes)=', '2.3001', 'loss=', '67.071234381')
# ('Epoch:', '0223', 'training time (minutes)=', '2.3092', 'loss=', '67.012122351')
# ('Epoch:', '0224', 'training time (minutes)=', '2.3003', 'loss=', '67.031241038')
# ('Epoch:', '0225', 'training time (minutes)=', '2.2951', 'loss=', '66.955857752')
# ('Epoch:', '0226', 'training time (minutes)=', '2.2986', 'loss=', '66.938870803')
# ('Epoch:', '0227', 'training time (minutes)=', '2.2934', 'loss=', '66.912531736')
# ('Epoch:', '0228', 'training time (minutes)=', '2.2992', 'loss=', '66.863163171')
# ('Epoch:', '0229', 'training time (minutes)=', '2.2999', 'loss=', '66.885730772')
# ('Epoch:', '0230', 'training time (minutes)=', '2.2982', 'loss=', '66.824306129')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '2.2955', 'loss=', '66.828856972')
# ('Epoch:', '0232', 'training time (minutes)=', '2.3022', 'loss=', '66.813293360')
# ('Epoch:', '0233', 'training time (minutes)=', '2.3102', 'loss=', '66.746304373')
# ('Epoch:', '0234', 'training time (minutes)=', '2.3052', 'loss=', '66.811378206')
# ('Epoch:', '0235', 'training time (minutes)=', '2.2984', 'loss=', '66.737131586')
# ('Epoch:', '0236', 'training time (minutes)=', '2.2926', 'loss=', '66.768771915')
# ('Epoch:', '0237', 'training time (minutes)=', '2.2953', 'loss=', '66.687673347')
# ('Epoch:', '0238', 'training time (minutes)=', '2.2926', 'loss=', '66.659382584')
# ('Epoch:', '0239', 'training time (minutes)=', '2.2958', 'loss=', '66.689125972')
# ('Epoch:', '0240', 'training time (minutes)=', '2.2925', 'loss=', '66.658223212')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '2.2932', 'loss=', '66.576487550')
# ('Epoch:', '0242', 'training time (minutes)=', '2.2934', 'loss=', '66.581518298')
# ('Epoch:', '0243', 'training time (minutes)=', '2.3190', 'loss=', '66.596468854')
# ('Epoch:', '0244', 'training time (minutes)=', '2.3118', 'loss=', '66.624410977')
# ('Epoch:', '0245', 'training time (minutes)=', '2.3026', 'loss=', '66.553371760')
# ('Epoch:', '0246', 'training time (minutes)=', '2.2991', 'loss=', '66.585154126')
# ('Epoch:', '0247', 'training time (minutes)=', '2.2962', 'loss=', '66.464918734')
# ('Epoch:', '0248', 'training time (minutes)=', '2.2997', 'loss=', '66.506655053')
# ('Epoch:', '0249', 'training time (minutes)=', '2.2990', 'loss=', '66.469241612')
# ('Epoch:', '0250', 'training time (minutes)=', '2.3057', 'loss=', '66.432292813')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '2.3032', 'loss=', '66.409228555')
# ('Epoch:', '0252', 'training time (minutes)=', '2.3035', 'loss=', '66.469736065')
# ('Epoch:', '0253', 'training time (minutes)=', '2.3085', 'loss=', '66.413283545')
# ('Epoch:', '0254', 'training time (minutes)=', '2.2961', 'loss=', '66.380979714')
# ('Epoch:', '0255', 'training time (minutes)=', '2.3064', 'loss=', '66.410562003')
# ('Epoch:', '0256', 'training time (minutes)=', '2.3108', 'loss=', '66.358381436')
# ('Epoch:', '0257', 'training time (minutes)=', '2.3021', 'loss=', '66.322487259')
# ('Epoch:', '0258', 'training time (minutes)=', '2.3053', 'loss=', '66.318219586')
# ('Epoch:', '0259', 'training time (minutes)=', '2.2966', 'loss=', '66.313551023')
# ('Epoch:', '0260', 'training time (minutes)=', '2.2951', 'loss=', '66.281669856')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '2.2934', 'loss=', '66.253168191')
# ('Epoch:', '0262', 'training time (minutes)=', '2.3010', 'loss=', '66.222098074')
# ('Epoch:', '0263', 'training time (minutes)=', '2.2928', 'loss=', '66.284310332')
# ('Epoch:', '0264', 'training time (minutes)=', '2.2993', 'loss=', '66.232419262')
# ('Epoch:', '0265', 'training time (minutes)=', '2.2969', 'loss=', '66.208425317')
# ('Epoch:', '0266', 'training time (minutes)=', '2.3022', 'loss=', '66.217596122')
# ('Epoch:', '0267', 'training time (minutes)=', '2.3063', 'loss=', '66.165352807')
# ('Epoch:', '0268', 'training time (minutes)=', '2.2992', 'loss=', '66.126669869')
# ('Epoch:', '0269', 'training time (minutes)=', '2.3021', 'loss=', '66.159633853')
# ('Epoch:', '0270', 'training time (minutes)=', '2.2989', 'loss=', '66.078975171')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '2.3031', 'loss=', '66.117685717')
# ('Epoch:', '0272', 'training time (minutes)=', '2.3118', 'loss=', '66.050297956')
# ('Epoch:', '0273', 'training time (minutes)=', '2.3079', 'loss=', '66.146589000')
# ('Epoch:', '0274', 'training time (minutes)=', '2.3136', 'loss=', '66.066398165')
# ('Epoch:', '0275', 'training time (minutes)=', '2.3045', 'loss=', '66.040506408')
# ('Epoch:', '0276', 'training time (minutes)=', '2.3094', 'loss=', '65.986199587')
# ('Epoch:', '0277', 'training time (minutes)=', '2.2970', 'loss=', '66.017723180')
# ('Epoch:', '0278', 'training time (minutes)=', '2.2963', 'loss=', '66.027853126')
# ('Epoch:', '0279', 'training time (minutes)=', '2.2960', 'loss=', '65.997166039')
# ('Epoch:', '0280', 'training time (minutes)=', '2.2953', 'loss=', '65.983835129')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '2.2938', 'loss=', '65.900589382')
# ('Epoch:', '0282', 'training time (minutes)=', '2.2974', 'loss=', '65.926152910')
# ('Epoch:', '0283', 'training time (minutes)=', '2.3056', 'loss=', '65.904516795')
# ('Epoch:', '0284', 'training time (minutes)=', '2.3027', 'loss=', '65.896075217')
# ('Epoch:', '0285', 'training time (minutes)=', '2.2952', 'loss=', '65.873447390')
# ('Epoch:', '0286', 'training time (minutes)=', '2.2997', 'loss=', '65.847191307')
# ('Epoch:', '0287', 'training time (minutes)=', '2.3022', 'loss=', '65.835924809')
# ('Epoch:', '0288', 'training time (minutes)=', '2.3057', 'loss=', '65.846214716')
# ('Epoch:', '0289', 'training time (minutes)=', '2.3039', 'loss=', '65.832577594')
# ('Epoch:', '0290', 'training time (minutes)=', '2.3024', 'loss=', '65.784671658')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '2.3074', 'loss=', '65.787365478')
# ('Epoch:', '0292', 'training time (minutes)=', '2.2994', 'loss=', '65.824150712')
# ('Epoch:', '0293', 'training time (minutes)=', '2.2988', 'loss=', '65.802848913')
# ('Epoch:', '0294', 'training time (minutes)=', '2.3031', 'loss=', '65.756488669')
# ('Epoch:', '0295', 'training time (minutes)=', '2.3029', 'loss=', '65.728088032')
# ('Epoch:', '0296', 'training time (minutes)=', '2.3052', 'loss=', '65.687564030')
# ('Epoch:', '0297', 'training time (minutes)=', '2.2939', 'loss=', '65.747592920')
# ('Epoch:', '0298', 'training time (minutes)=', '2.2982', 'loss=', '65.713358683')
# ('Epoch:', '0299', 'training time (minutes)=', '2.3065', 'loss=', '65.667390795')
# ('Epoch:', '0300', 'training time (minutes)=', '2.3034', 'loss=', '65.689252580')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '2.2934', 'loss=', '65.679991110')
# ('Epoch:', '0302', 'training time (minutes)=', '2.3040', 'loss=', '65.657413403')
# ('Epoch:', '0303', 'training time (minutes)=', '2.3043', 'loss=', '65.663601360')
# ('Epoch:', '0304', 'training time (minutes)=', '2.2926', 'loss=', '65.562635143')
# ('Epoch:', '0305', 'training time (minutes)=', '2.2928', 'loss=', '65.631208596')
# ('Epoch:', '0306', 'training time (minutes)=', '2.2923', 'loss=', '65.617671392')
# ('Epoch:', '0307', 'training time (minutes)=', '2.2934', 'loss=', '65.601220783')
# ('Epoch:', '0308', 'training time (minutes)=', '2.2958', 'loss=', '65.591704166')
# ('Epoch:', '0309', 'training time (minutes)=', '2.3060', 'loss=', '65.553340479')
# ('Epoch:', '0310', 'training time (minutes)=', '2.3107', 'loss=', '65.545072151')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '2.3078', 'loss=', '65.580946014')
# ('Epoch:', '0312', 'training time (minutes)=', '2.3091', 'loss=', '65.492406429')
# ('Epoch:', '0313', 'training time (minutes)=', '2.3068', 'loss=', '65.481650913')
# ('Epoch:', '0314', 'training time (minutes)=', '2.2954', 'loss=', '65.492135979')
# ('Epoch:', '0315', 'training time (minutes)=', '2.2923', 'loss=', '65.475541659')
# ('Epoch:', '0316', 'training time (minutes)=', '2.2927', 'loss=', '65.495847605')
# ('Epoch:', '0317', 'training time (minutes)=', '2.2958', 'loss=', '65.454942259')
# ('Epoch:', '0318', 'training time (minutes)=', '2.2995', 'loss=', '65.480570608')
# ('Epoch:', '0319', 'training time (minutes)=', '2.2992', 'loss=', '65.471004378')
# ('Epoch:', '0320', 'training time (minutes)=', '2.2959', 'loss=', '65.403112115')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '2.2944', 'loss=', '65.414477397')
# ('Epoch:', '0322', 'training time (minutes)=', '2.2926', 'loss=', '65.404813043')
# ('Epoch:', '0323', 'training time (minutes)=', '2.2952', 'loss=', '65.423946557')
# ('Epoch:', '0324', 'training time (minutes)=', '2.3037', 'loss=', '65.446468017')
# ('Epoch:', '0325', 'training time (minutes)=', '2.2919', 'loss=', '65.376189491')
# ('Epoch:', '0326', 'training time (minutes)=', '2.2961', 'loss=', '65.327207059')
# ('Epoch:', '0327', 'training time (minutes)=', '2.2922', 'loss=', '65.371316067')
# ('Epoch:', '0328', 'training time (minutes)=', '2.3057', 'loss=', '65.379906617')
# ('Epoch:', '0329', 'training time (minutes)=', '2.2967', 'loss=', '65.318152766')
# ('Epoch:', '0330', 'training time (minutes)=', '2.3054', 'loss=', '65.342983923')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '2.2996', 'loss=', '65.339356095')
# ('Epoch:', '0332', 'training time (minutes)=', '2.3034', 'loss=', '65.346999473')
# ('Epoch:', '0333', 'training time (minutes)=', '2.2986', 'loss=', '65.274935332')
# ('Epoch:', '0334', 'training time (minutes)=', '2.2959', 'loss=', '65.243574672')
# ('Epoch:', '0335', 'training time (minutes)=', '2.2927', 'loss=', '65.259698845')
# ('Epoch:', '0336', 'training time (minutes)=', '2.3061', 'loss=', '65.302875576')
# ('Epoch:', '0337', 'training time (minutes)=', '2.3125', 'loss=', '65.251308367')
# ('Epoch:', '0338', 'training time (minutes)=', '2.2999', 'loss=', '65.243952885')
# ('Epoch:', '0339', 'training time (minutes)=', '2.3039', 'loss=', '65.221412078')
# ('Epoch:', '0340', 'training time (minutes)=', '2.3006', 'loss=', '65.251816251')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '2.2924', 'loss=', '65.152866159')
# ('Epoch:', '0342', 'training time (minutes)=', '2.2991', 'loss=', '65.163169701')
# ('Epoch:', '0343', 'training time (minutes)=', '2.2963', 'loss=', '65.170214092')
# ('Epoch:', '0344', 'training time (minutes)=', '2.2922', 'loss=', '65.219123988')
# ('Epoch:', '0345', 'training time (minutes)=', '2.2961', 'loss=', '65.162054939')
# ('Epoch:', '0346', 'training time (minutes)=', '2.2923', 'loss=', '65.151906472')
# ('Epoch:', '0347', 'training time (minutes)=', '2.2960', 'loss=', '65.185096689')
# ('Epoch:', '0348', 'training time (minutes)=', '2.2924', 'loss=', '65.102886137')
# ('Epoch:', '0349', 'training time (minutes)=', '2.2926', 'loss=', '65.097297993')
# ('Epoch:', '0350', 'training time (minutes)=', '2.2925', 'loss=', '65.146522892')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '2.2960', 'loss=', '65.100154529')
# ('Epoch:', '0352', 'training time (minutes)=', '2.3025', 'loss=', '65.073159352')
# ('Epoch:', '0353', 'training time (minutes)=', '2.3020', 'loss=', '65.053905481')
# ('Epoch:', '0354', 'training time (minutes)=', '2.2960', 'loss=', '65.067314000')
# ('Epoch:', '0355', 'training time (minutes)=', '2.2958', 'loss=', '65.120201236')
# ('Epoch:', '0356', 'training time (minutes)=', '2.2923', 'loss=', '65.058844991')
# ('Epoch:', '0357', 'training time (minutes)=', '2.2962', 'loss=', '65.031848879')
# ('Epoch:', '0358', 'training time (minutes)=', '2.2991', 'loss=', '65.028705802')
# ('Epoch:', '0359', 'training time (minutes)=', '2.2966', 'loss=', '65.044367338')
# ('Epoch:', '0360', 'training time (minutes)=', '2.2987', 'loss=', '65.002382017')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_2048pts_emd/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0361', 'training time (minutes)=', '2.2948', 'loss=', '65.020073301')
# ('Epoch:', '0362', 'training time (minutes)=', '2.3003', 'loss=', '64.998381817')
# ('Epoch:', '0363', 'training time (minutes)=', '2.2947', 'loss=', '64.970761063')
# ('Epoch:', '0364', 'training time (minutes)=', '2.2956', 'loss=', '64.969696939')
# ('Epoch:', '0365', 'training time (minutes)=', '2.2962', 'loss=', '64.994134652')
# ('Epoch:', '0366', 'training time (minutes)=', '2.2923', 'loss=', '64.934246063')
# ('Epoch:', '0367', 'training time (minutes)=', '2.2957', 'loss=', '64.948151204')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4aeef0599ea8> in <module>()
#       1 if do_training:
#       2     training_stats = []
# ----> 3     training_stats.append(ae.train(train_data, conf))
#       4     with open(osp.join(conf.train_dir, 'train_stats.txt'), 'a') as fout:
#       5         np.savetxt(fout, np.array(training_stats)[0])
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in train(self, train_data, configuration)
#     175
#     176         for _ in xrange(c.training_epochs):
# --> 177             loss, duration = self._single_epoch_train(train_data, c)
#     178             epoch = int(self.sess.run(self.epoch.assign_add(tf.constant(1.0))))
#     179             stats.append((epoch, loss, duration))
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/point_net_ae.pyc in _single_epoch_train(self, train_data, configuration)
#     107                 loss, _ = self.partial_fit(batch_i, original_data)
#     108             else:
# --> 109                 loss, _ = self.partial_fit(batch_i)
#     110
#     111             # Compute average loss
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in partial_fit(self, X, GT)
#     129             _, loss, recon = self.sess.run((self.optimizer, self.loss, self.x_reconstr), feed_dict={self.x: X, self.gt: GT})
#     130         else:
# --> 131             _, loss, recon = self.sess.run((self.optimizer, self.loss, self.x_reconstr), feed_dict={self.x: X})
#     132         return loss, recon
#     133
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
