# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 0
setup_one_gpu(GPU)
# Out:
# Picking GPU 0

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio

from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch, \
                                           plot_interpolations


from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud

from tf_lab.nips.shape_net import pc_loader as sn_pc_loader
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
do_plotting = False
first_time_running = True
load_model = False
seed = 42
max_training_epochs = 1000
loss = 'emd'
experiment_name = 'usphere_scaled__three_fc_dec_' + str(n_pc_samples) +  'pts_' + loss

# %%
top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/centered/', str(n_pc_samples))
train_dir = osp.join(top_data_dir, 'OUT/models/nips/vanilla_ae/')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd'

# %%
full_file_names = pio.load_filenames_of_input_data(full_pclouds_path, '.ply')
full_pclouds, full_model_names, full_syn_ids = pio.load_crude_point_clouds(file_names=full_file_names,\
                                                                           n_threads=50, loader=sn_pc_loader)
print '%d files containing complete point clouds were found.' % (len(full_pclouds), )
# Out:
# 57449 files containing complete point clouds were found.
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:56: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')

# %%
### max dist = 0.5
### centered around zero.

pclouds = full_pclouds
pclouds = pclouds - np.expand_dims(np.mean(pclouds, axis=1), 1)

for i, pc in enumerate(pclouds):
    pc, _ = Point_Cloud(pc).center_axis()
    pclouds[i] = pc.points
    
    
dist = np.max(np.sqrt(np.sum(pclouds ** 2, axis=2)), 1)
dist = np.expand_dims(np.expand_dims(dist, 1), 2)
pclouds = pclouds / (dist * 2.0)

# %%
# np.random.seed(seed)
# tf.set_random_seed(seed)

# train_data_, val_data_, test_data_, r_indices = pio.train_validate_test_split(
#                                                             [full_pclouds, full_model_names],
#                                                             train_perc=0.85,
#                                                             validate_perc=0.05,
#                                                             test_perc=0.1,
#                                                             seed=seed)

# model_ids = np.vstack((full_model_names, full_syn_ids)).T

# if first_time_running:
#     write_model_ids_of_datasets(train_dir, model_ids, r_indices)

# train_data = PointCloudDataSet(train_data_[0], labels=train_data_[1])
# val_data = PointCloudDataSet(val_data_[0], labels=val_data_[1])
# test_data = PointCloudDataSet(test_data_[0], labels=test_data_[1])

model_unames = full_model_names + '.' + full_syn_ids
train_data = PointCloudDataSet(full_pclouds, labels=model_unames)

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:
    n_input = [n_pc_samples, 3]

#     encoder_args = {'dropout_prob': 0.8}
    
    decoder_args = {'layer_sizes': [1024, 2048, np.prod(n_input)],
                    'non_linearity': tf.nn.relu
                   }

    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = True,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args,        
               )

    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)

# %%
if do_training:
    training_stats = []
    training_stats.append(ae.train(train_data, conf))    
    with open(osp.join(conf.train_dir, 'train_stats.txt'), 'a') as fout:
        np.savetxt(fout, np.array(training_stats)[0])
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '4.1539', 'loss=', '175.043969118')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '4.0944', 'loss=', '139.915134928')
# ('Epoch:', '0003', 'training time (minutes)=', '4.1124', 'loss=', '129.559123116')
# ('Epoch:', '0004', 'training time (minutes)=', '4.3100', 'loss=', '123.965735485')
# ('Epoch:', '0005', 'training time (minutes)=', '4.2526', 'loss=', '124.034483913')
# ('Epoch:', '0006', 'training time (minutes)=', '4.0989', 'loss=', '118.376204873')
# ('Epoch:', '0007', 'training time (minutes)=', '4.0263', 'loss=', '115.875837798')
# ('Epoch:', '0008', 'training time (minutes)=', '4.0638', 'loss=', '113.944318014')
# ('Epoch:', '0009', 'training time (minutes)=', '4.1357', 'loss=', '112.747087957')
# ('Epoch:', '0010', 'training time (minutes)=', '4.0487', 'loss=', '110.973305965')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '4.0743', 'loss=', '110.122460914')
# ('Epoch:', '0012', 'training time (minutes)=', '4.0537', 'loss=', '108.777450468')
# ('Epoch:', '0013', 'training time (minutes)=', '4.0544', 'loss=', '107.246313793')
# ('Epoch:', '0014', 'training time (minutes)=', '3.9637', 'loss=', '106.742017759')
# ('Epoch:', '0015', 'training time (minutes)=', '3.9680', 'loss=', '107.046211356')
# ('Epoch:', '0016', 'training time (minutes)=', '3.9574', 'loss=', '105.828353397')
# ('Epoch:', '0017', 'training time (minutes)=', '4.2440', 'loss=', '104.883567278')
# ('Epoch:', '0018', 'training time (minutes)=', '3.9915', 'loss=', '104.050328909')
# ('Epoch:', '0019', 'training time (minutes)=', '4.1506', 'loss=', '104.046069388')
# ('Epoch:', '0020', 'training time (minutes)=', '4.1899', 'loss=', '103.575008027')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '3.9636', 'loss=', '102.467665955')
# ('Epoch:', '0022', 'training time (minutes)=', '4.1189', 'loss=', '102.818250231')
# ('Epoch:', '0023', 'training time (minutes)=', '4.0104', 'loss=', '102.109792935')
# ('Epoch:', '0024', 'training time (minutes)=', '4.0877', 'loss=', '101.470383342')
# ('Epoch:', '0025', 'training time (minutes)=', '3.9971', 'loss=', '101.441679905')
# ('Epoch:', '0026', 'training time (minutes)=', '3.9782', 'loss=', '100.710603216')
# ('Epoch:', '0027', 'training time (minutes)=', '4.1707', 'loss=', '101.054171040')
# ('Epoch:', '0028', 'training time (minutes)=', '4.0986', 'loss=', '99.589239174')
# ('Epoch:', '0029', 'training time (minutes)=', '3.9976', 'loss=', '100.540470396')
# ('Epoch:', '0030', 'training time (minutes)=', '4.0183', 'loss=', '99.892440198')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '4.1188', 'loss=', '99.614097150')
# ('Epoch:', '0032', 'training time (minutes)=', '4.0211', 'loss=', '99.168018261')
# ('Epoch:', '0033', 'training time (minutes)=', '4.0387', 'loss=', '98.594432611')
# ('Epoch:', '0034', 'training time (minutes)=', '4.0815', 'loss=', '99.250332676')
# ('Epoch:', '0035', 'training time (minutes)=', '3.9927', 'loss=', '98.552553376')
# ('Epoch:', '0036', 'training time (minutes)=', '4.0429', 'loss=', '97.969976119')
# ('Epoch:', '0037', 'training time (minutes)=', '4.0061', 'loss=', '97.695034512')
# ('Epoch:', '0038', 'training time (minutes)=', '4.0802', 'loss=', '97.842976773')
# ('Epoch:', '0039', 'training time (minutes)=', '4.0222', 'loss=', '97.885463529')
# ('Epoch:', '0040', 'training time (minutes)=', '4.0464', 'loss=', '97.947925794')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '4.0297', 'loss=', '97.065069504')
# ('Epoch:', '0042', 'training time (minutes)=', '4.0231', 'loss=', '97.173078630')
# ('Epoch:', '0043', 'training time (minutes)=', '3.9958', 'loss=', '97.068784807')
# ('Epoch:', '0044', 'training time (minutes)=', '4.0308', 'loss=', '96.294207430')
# ('Epoch:', '0045', 'training time (minutes)=', '4.0154', 'loss=', '96.657445276')
# ('Epoch:', '0046', 'training time (minutes)=', '4.0088', 'loss=', '96.838846260')
# ('Epoch:', '0047', 'training time (minutes)=', '4.0551', 'loss=', '96.156665250')
# ('Epoch:', '0048', 'training time (minutes)=', '4.0309', 'loss=', '96.023861829')
# ('Epoch:', '0049', 'training time (minutes)=', '4.0039', 'loss=', '95.813729177')
# ('Epoch:', '0050', 'training time (minutes)=', '4.0554', 'loss=', '96.100768531')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '3.9905', 'loss=', '96.482581401')
# ('Epoch:', '0052', 'training time (minutes)=', '4.0368', 'loss=', '95.089696798')
# ('Epoch:', '0053', 'training time (minutes)=', '4.0082', 'loss=', '95.517543713')
# ('Epoch:', '0054', 'training time (minutes)=', '4.0282', 'loss=', '94.963515245')
# ('Epoch:', '0055', 'training time (minutes)=', '4.0413', 'loss=', '95.385981131')
# ('Epoch:', '0056', 'training time (minutes)=', '4.0332', 'loss=', '95.587944529')
# ('Epoch:', '0057', 'training time (minutes)=', '4.0164', 'loss=', '94.650111607')
# ('Epoch:', '0058', 'training time (minutes)=', '4.0137', 'loss=', '94.809798789')
# ('Epoch:', '0059', 'training time (minutes)=', '4.0101', 'loss=', '94.726567332')
# ('Epoch:', '0060', 'training time (minutes)=', '4.0133', 'loss=', '94.717839278')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '4.0424', 'loss=', '94.715746943')
# ('Epoch:', '0062', 'training time (minutes)=', '4.0303', 'loss=', '94.214050977')
# ('Epoch:', '0063', 'training time (minutes)=', '4.0036', 'loss=', '94.108111159')
# ('Epoch:', '0064', 'training time (minutes)=', '4.0227', 'loss=', '94.285851994')
# ('Epoch:', '0065', 'training time (minutes)=', '4.0237', 'loss=', '94.250843274')
# ('Epoch:', '0066', 'training time (minutes)=', '3.9922', 'loss=', '93.369821110')
# ('Epoch:', '0067', 'training time (minutes)=', '4.0175', 'loss=', '93.553073524')
# ('Epoch:', '0068', 'training time (minutes)=', '4.0026', 'loss=', '94.145902408')
# ('Epoch:', '0069', 'training time (minutes)=', '4.0357', 'loss=', '93.491767584')
# ('Epoch:', '0070', 'training time (minutes)=', '4.0402', 'loss=', '93.603430479')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '4.0182', 'loss=', '93.284265565')
# ('Epoch:', '0072', 'training time (minutes)=', '4.0329', 'loss=', '93.242070839')
# ('Epoch:', '0073', 'training time (minutes)=', '4.0031', 'loss=', '93.390983037')
# ('Epoch:', '0074', 'training time (minutes)=', '3.9930', 'loss=', '93.163222536')
# ('Epoch:', '0075', 'training time (minutes)=', '4.0043', 'loss=', '93.684644712')
# ('Epoch:', '0076', 'training time (minutes)=', '4.0122', 'loss=', '93.119322847')
# ('Epoch:', '0077', 'training time (minutes)=', '4.0454', 'loss=', '92.865395669')
# ('Epoch:', '0078', 'training time (minutes)=', '4.0628', 'loss=', '92.196637503')
# ('Epoch:', '0079', 'training time (minutes)=', '4.0126', 'loss=', '92.961349334')
# ('Epoch:', '0080', 'training time (minutes)=', '4.0088', 'loss=', '92.619728241')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '4.0636', 'loss=', '92.302457484')
# ('Epoch:', '0082', 'training time (minutes)=', '4.0135', 'loss=', '92.604984622')
# ('Epoch:', '0083', 'training time (minutes)=', '4.0203', 'loss=', '92.527878206')
# ('Epoch:', '0084', 'training time (minutes)=', '4.0153', 'loss=', '93.090841533')
# ('Epoch:', '0085', 'training time (minutes)=', '4.0368', 'loss=', '92.079213059')
# ('Epoch:', '0086', 'training time (minutes)=', '4.0084', 'loss=', '92.262256376')
# ('Epoch:', '0087', 'training time (minutes)=', '3.9983', 'loss=', '91.862541132')
# ('Epoch:', '0088', 'training time (minutes)=', '3.9809', 'loss=', '91.841619644')
# ('Epoch:', '0089', 'training time (minutes)=', '4.0458', 'loss=', '91.753704450')
# ('Epoch:', '0090', 'training time (minutes)=', '3.9759', 'loss=', '92.061540404')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '3.9957', 'loss=', '91.485685329')
# ('Epoch:', '0092', 'training time (minutes)=', '3.9756', 'loss=', '91.865359037')
# ('Epoch:', '0093', 'training time (minutes)=', '3.9786', 'loss=', '91.595058049')
# ('Epoch:', '0094', 'training time (minutes)=', '3.9894', 'loss=', '91.558041602')
# ('Epoch:', '0095', 'training time (minutes)=', '3.9769', 'loss=', '91.787273354')
# ('Epoch:', '0096', 'training time (minutes)=', '3.9561', 'loss=', '90.890612486')
# ('Epoch:', '0097', 'training time (minutes)=', '3.9874', 'loss=', '91.645193067')
# ('Epoch:', '0098', 'training time (minutes)=', '3.9897', 'loss=', '91.269020871')
# ('Epoch:', '0099', 'training time (minutes)=', '3.9994', 'loss=', '90.895479734')
# ('Epoch:', '0100', 'training time (minutes)=', '3.9801', 'loss=', '91.487660139')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '3.9712', 'loss=', '90.857456699')
# ('Epoch:', '0102', 'training time (minutes)=', '3.9700', 'loss=', '91.012805786')
# ('Epoch:', '0103', 'training time (minutes)=', '3.9779', 'loss=', '91.511763696')
# ('Epoch:', '0104', 'training time (minutes)=', '3.9679', 'loss=', '91.346814657')
# ('Epoch:', '0105', 'training time (minutes)=', '3.9844', 'loss=', '91.196296453')
# ('Epoch:', '0106', 'training time (minutes)=', '4.0083', 'loss=', '90.959880796')
# ('Epoch:', '0107', 'training time (minutes)=', '4.0047', 'loss=', '91.091692536')
# ('Epoch:', '0108', 'training time (minutes)=', '4.0300', 'loss=', '90.585247246')
# ('Epoch:', '0109', 'training time (minutes)=', '4.0033', 'loss=', '91.081225724')
# ('Epoch:', '0110', 'training time (minutes)=', '4.0270', 'loss=', '90.807057131')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '4.0235', 'loss=', '90.580780401')
# ('Epoch:', '0112', 'training time (minutes)=', '4.0345', 'loss=', '90.246415042')
# ('Epoch:', '0113', 'training time (minutes)=', '4.0258', 'loss=', '90.363536609')
# ('Epoch:', '0114', 'training time (minutes)=', '4.0422', 'loss=', '90.565304759')
# ('Epoch:', '0115', 'training time (minutes)=', '4.0362', 'loss=', '90.596659132')
# ('Epoch:', '0116', 'training time (minutes)=', '4.0324', 'loss=', '90.470673199')
# ('Epoch:', '0117', 'training time (minutes)=', '3.9974', 'loss=', '90.024684786')
# ('Epoch:', '0118', 'training time (minutes)=', '4.0231', 'loss=', '90.129450761')
# ('Epoch:', '0119', 'training time (minutes)=', '4.0194', 'loss=', '90.309039651')
# ('Epoch:', '0120', 'training time (minutes)=', '4.0035', 'loss=', '90.403953984')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '4.0078', 'loss=', '89.955173732')
# ('Epoch:', '0122', 'training time (minutes)=', '4.0244', 'loss=', '90.218338936')
# ('Epoch:', '0123', 'training time (minutes)=', '4.0111', 'loss=', '90.336683785')
# ('Epoch:', '0124', 'training time (minutes)=', '4.0370', 'loss=', '89.690318031')
# ('Epoch:', '0125', 'training time (minutes)=', '4.0145', 'loss=', '90.358021467')
# ('Epoch:', '0126', 'training time (minutes)=', '4.0033', 'loss=', '89.613829164')
# ('Epoch:', '0127', 'training time (minutes)=', '4.0234', 'loss=', '89.586557940')
# ('Epoch:', '0128', 'training time (minutes)=', '4.0301', 'loss=', '89.952011069')
# ('Epoch:', '0129', 'training time (minutes)=', '4.0169', 'loss=', '89.866909805')
# ('Epoch:', '0130', 'training time (minutes)=', '4.0302', 'loss=', '89.812305623')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '4.0207', 'loss=', '90.076560941')
# ('Epoch:', '0132', 'training time (minutes)=', '4.0764', 'loss=', '90.277428976')
# ('Epoch:', '0133', 'training time (minutes)=', '4.0218', 'loss=', '89.345024714')
# ('Epoch:', '0134', 'training time (minutes)=', '4.0225', 'loss=', '89.534396368')
# ('Epoch:', '0135', 'training time (minutes)=', '4.0209', 'loss=', '89.470011867')
# ('Epoch:', '0136', 'training time (minutes)=', '4.0254', 'loss=', '89.763645897')
# ('Epoch:', '0137', 'training time (minutes)=', '4.0108', 'loss=', '89.373660829')
# ('Epoch:', '0138', 'training time (minutes)=', '4.0504', 'loss=', '89.376254205')
# ('Epoch:', '0139', 'training time (minutes)=', '4.0235', 'loss=', '89.573176281')
# ('Epoch:', '0140', 'training time (minutes)=', '4.0468', 'loss=', '89.492657538')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '4.0167', 'loss=', '89.212455278')
# ('Epoch:', '0142', 'training time (minutes)=', '4.0207', 'loss=', '89.279663126')
# ('Epoch:', '0143', 'training time (minutes)=', '4.0283', 'loss=', '89.139707233')
# ('Epoch:', '0144', 'training time (minutes)=', '4.0468', 'loss=', '88.918422260')
# ('Epoch:', '0145', 'training time (minutes)=', '4.0476', 'loss=', '89.215879952')
# ('Epoch:', '0146', 'training time (minutes)=', '4.0423', 'loss=', '88.956719688')
# ('Epoch:', '0147', 'training time (minutes)=', '4.0133', 'loss=', '88.938072590')
# ('Epoch:', '0148', 'training time (minutes)=', '4.0471', 'loss=', '89.130888078')
# ('Epoch:', '0149', 'training time (minutes)=', '4.0375', 'loss=', '88.787199692')
# ('Epoch:', '0150', 'training time (minutes)=', '4.0476', 'loss=', '89.750585224')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '4.0037', 'loss=', '89.101829848')
# ('Epoch:', '0152', 'training time (minutes)=', '4.0131', 'loss=', '89.122470842')
# ('Epoch:', '0153', 'training time (minutes)=', '4.0026', 'loss=', '88.505086188')
# ('Epoch:', '0154', 'training time (minutes)=', '4.0442', 'loss=', '89.205865980')
# ('Epoch:', '0155', 'training time (minutes)=', '4.0226', 'loss=', '88.416177085')
# ('Epoch:', '0156', 'training time (minutes)=', '4.0525', 'loss=', '89.246333597')
# ('Epoch:', '0157', 'training time (minutes)=', '4.0183', 'loss=', '89.105473582')
# ('Epoch:', '0158', 'training time (minutes)=', '4.0287', 'loss=', '88.311460807')
# ('Epoch:', '0159', 'training time (minutes)=', '4.0387', 'loss=', '88.709581103')
# ('Epoch:', '0160', 'training time (minutes)=', '4.0289', 'loss=', '88.635028155')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '4.0314', 'loss=', '88.777659745')
# ('Epoch:', '0162', 'training time (minutes)=', '4.0132', 'loss=', '88.427051704')
# ('Epoch:', '0163', 'training time (minutes)=', '4.0071', 'loss=', '88.554820224')
# ('Epoch:', '0164', 'training time (minutes)=', '4.0375', 'loss=', '88.674929449')
# ('Epoch:', '0165', 'training time (minutes)=', '4.0163', 'loss=', '88.411602725')
# ('Epoch:', '0166', 'training time (minutes)=', '4.0547', 'loss=', '88.783126133')
# ('Epoch:', '0167', 'training time (minutes)=', '4.0481', 'loss=', '88.605813967')
# ('Epoch:', '0168', 'training time (minutes)=', '4.0570', 'loss=', '88.518608558')
# ('Epoch:', '0169', 'training time (minutes)=', '4.0336', 'loss=', '88.569064170')
# ('Epoch:', '0170', 'training time (minutes)=', '4.0528', 'loss=', '88.371554159')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '4.0340', 'loss=', '88.451428789')
# ('Epoch:', '0172', 'training time (minutes)=', '4.0668', 'loss=', '88.412357430')
# ('Epoch:', '0173', 'training time (minutes)=', '4.0323', 'loss=', '88.293707439')
# ('Epoch:', '0174', 'training time (minutes)=', '4.0826', 'loss=', '87.990878148')
# ('Epoch:', '0175', 'training time (minutes)=', '4.0444', 'loss=', '88.356694059')
# ('Epoch:', '0176', 'training time (minutes)=', '4.0062', 'loss=', '88.077127716')
# ('Epoch:', '0177', 'training time (minutes)=', '4.0287', 'loss=', '88.030902484')
# ('Epoch:', '0178', 'training time (minutes)=', '4.0341', 'loss=', '87.944806966')
# ('Epoch:', '0179', 'training time (minutes)=', '4.0499', 'loss=', '88.800194943')
# ('Epoch:', '0180', 'training time (minutes)=', '4.0735', 'loss=', '88.112296487')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '4.0536', 'loss=', '87.928570511')
# ('Epoch:', '0182', 'training time (minutes)=', '4.0739', 'loss=', '87.696709311')
# ('Epoch:', '0183', 'training time (minutes)=', '4.0505', 'loss=', '87.982579414')
# ('Epoch:', '0184', 'training time (minutes)=', '4.0507', 'loss=', '88.489046017')
# ('Epoch:', '0185', 'training time (minutes)=', '4.0251', 'loss=', '88.223354433')
# ('Epoch:', '0186', 'training time (minutes)=', '4.0294', 'loss=', '87.998440925')
# ('Epoch:', '0187', 'training time (minutes)=', '4.1002', 'loss=', '87.670900052')
# ('Epoch:', '0188', 'training time (minutes)=', '4.0219', 'loss=', '87.877774016')
# ('Epoch:', '0189', 'training time (minutes)=', '4.0522', 'loss=', '88.112299391')
# ('Epoch:', '0190', 'training time (minutes)=', '4.0444', 'loss=', '87.478770107')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '4.0366', 'loss=', '87.522966418')
# ('Epoch:', '0192', 'training time (minutes)=', '4.0203', 'loss=', '87.997670935')
# ('Epoch:', '0193', 'training time (minutes)=', '4.0124', 'loss=', '87.868804101')
# ('Epoch:', '0194', 'training time (minutes)=', '4.0094', 'loss=', '88.026812783')
# ('Epoch:', '0195', 'training time (minutes)=', '4.0741', 'loss=', '87.718378466')
# ('Epoch:', '0196', 'training time (minutes)=', '4.0583', 'loss=', '87.629176794')
# ('Epoch:', '0197', 'training time (minutes)=', '4.1985', 'loss=', '87.638862630')
# ('Epoch:', '0198', 'training time (minutes)=', '4.0668', 'loss=', '87.191456512')
# ('Epoch:', '0199', 'training time (minutes)=', '4.0441', 'loss=', '87.464065033')
# ('Epoch:', '0200', 'training time (minutes)=', '4.0638', 'loss=', '87.796640210')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '4.0596', 'loss=', '87.942286561')
# ('Epoch:', '0202', 'training time (minutes)=', '4.0850', 'loss=', '87.613959382')
# ('Epoch:', '0203', 'training time (minutes)=', '4.0603', 'loss=', '87.418263392')
# ('Epoch:', '0204', 'training time (minutes)=', '4.0405', 'loss=', '87.572748231')
# ('Epoch:', '0205', 'training time (minutes)=', '4.0860', 'loss=', '87.194799962')
# ('Epoch:', '0206', 'training time (minutes)=', '4.0775', 'loss=', '87.193139046')
# ('Epoch:', '0207', 'training time (minutes)=', '4.1248', 'loss=', '87.522349002')
# ('Epoch:', '0208', 'training time (minutes)=', '4.0878', 'loss=', '87.207060904')
# ('Epoch:', '0209', 'training time (minutes)=', '4.1341', 'loss=', '87.579699041')
# ('Epoch:', '0210', 'training time (minutes)=', '4.0441', 'loss=', '87.241096636')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '4.1215', 'loss=', '87.171420094')
# ('Epoch:', '0212', 'training time (minutes)=', '4.0556', 'loss=', '87.337886305')
# ('Epoch:', '0213', 'training time (minutes)=', '4.0574', 'loss=', '87.282956751')
# ('Epoch:', '0214', 'training time (minutes)=', '4.0776', 'loss=', '87.489067988')
# ('Epoch:', '0215', 'training time (minutes)=', '4.0656', 'loss=', '87.337770535')
# ('Epoch:', '0216', 'training time (minutes)=', '4.0613', 'loss=', '87.173777098')
# ('Epoch:', '0217', 'training time (minutes)=', '4.1137', 'loss=', '87.290513540')
# ('Epoch:', '0218', 'training time (minutes)=', '4.0827', 'loss=', '87.526211217')
# ('Epoch:', '0219', 'training time (minutes)=', '4.1068', 'loss=', '86.980395553')
# ('Epoch:', '0220', 'training time (minutes)=', '4.0543', 'loss=', '87.256584181')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '4.0473', 'loss=', '86.966869979')
# ('Epoch:', '0222', 'training time (minutes)=', '4.0720', 'loss=', '86.998366798')
# ('Epoch:', '0223', 'training time (minutes)=', '4.0851', 'loss=', '86.633388067')
# ('Epoch:', '0224', 'training time (minutes)=', '4.0249', 'loss=', '87.107699198')
# ('Epoch:', '0225', 'training time (minutes)=', '4.0216', 'loss=', '86.957598736')
# ('Epoch:', '0226', 'training time (minutes)=', '4.0776', 'loss=', '87.369210413')
# ('Epoch:', '0227', 'training time (minutes)=', '4.0877', 'loss=', '87.289688117')
# ('Epoch:', '0228', 'training time (minutes)=', '4.0505', 'loss=', '86.898770369')
# ('Epoch:', '0229', 'training time (minutes)=', '4.0176', 'loss=', '86.906674960')
# ('Epoch:', '0230', 'training time (minutes)=', '4.0458', 'loss=', '87.054940360')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '4.0624', 'loss=', '87.154036359')
# ('Epoch:', '0232', 'training time (minutes)=', '4.1097', 'loss=', '86.593011942')
# ('Epoch:', '0233', 'training time (minutes)=', '4.1234', 'loss=', '86.579374466')
# ('Epoch:', '0234', 'training time (minutes)=', '4.1503', 'loss=', '87.019941476')
# ('Epoch:', '0235', 'training time (minutes)=', '4.1040', 'loss=', '87.163623723')
# ('Epoch:', '0236', 'training time (minutes)=', '4.1045', 'loss=', '86.829078010')
# ('Epoch:', '0237', 'training time (minutes)=', '4.0892', 'loss=', '86.488403327')
# ('Epoch:', '0238', 'training time (minutes)=', '4.0268', 'loss=', '87.143710917')
# ('Epoch:', '0239', 'training time (minutes)=', '4.0296', 'loss=', '86.953514917')
# ('Epoch:', '0240', 'training time (minutes)=', '4.0684', 'loss=', '86.828430043')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '4.0398', 'loss=', '86.957289427')
# ('Epoch:', '0242', 'training time (minutes)=', '4.1346', 'loss=', '86.666608026')
# ('Epoch:', '0243', 'training time (minutes)=', '4.0547', 'loss=', '86.722911635')
# ('Epoch:', '0244', 'training time (minutes)=', '4.1169', 'loss=', '86.886620126')
# ('Epoch:', '0245', 'training time (minutes)=', '4.1038', 'loss=', '86.413205452')
# ('Epoch:', '0246', 'training time (minutes)=', '4.1010', 'loss=', '86.972325249')
# ('Epoch:', '0247', 'training time (minutes)=', '3.9532', 'loss=', '86.754609005')
# ('Epoch:', '0248', 'training time (minutes)=', '4.0385', 'loss=', '86.497077144')
# ('Epoch:', '0249', 'training time (minutes)=', '4.0493', 'loss=', '86.870028506')
# ('Epoch:', '0250', 'training time (minutes)=', '3.9932', 'loss=', '86.916512386')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '3.9841', 'loss=', '86.741772196')
# ('Epoch:', '0252', 'training time (minutes)=', '3.9718', 'loss=', '86.324305305')
# ('Epoch:', '0253', 'training time (minutes)=', '3.9792', 'loss=', '86.659616869')
# ('Epoch:', '0254', 'training time (minutes)=', '4.1377', 'loss=', '86.803195069')
# ('Epoch:', '0255', 'training time (minutes)=', '4.2538', 'loss=', '86.725506400')
# ('Epoch:', '0256', 'training time (minutes)=', '4.2778', 'loss=', '86.305659032')
# ('Epoch:', '0257', 'training time (minutes)=', '4.3307', 'loss=', '86.482188627')
# ('Epoch:', '0258', 'training time (minutes)=', '4.3704', 'loss=', '86.793097546')
# ('Epoch:', '0259', 'training time (minutes)=', '4.6053', 'loss=', '86.020655370')
# ('Epoch:', '0260', 'training time (minutes)=', '4.6380', 'loss=', '86.856708640')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '4.3057', 'loss=', '86.311556753')
# ('Epoch:', '0262', 'training time (minutes)=', '4.3559', 'loss=', '86.623646567')
# ('Epoch:', '0263', 'training time (minutes)=', '4.3508', 'loss=', '86.336170961')
# ('Epoch:', '0264', 'training time (minutes)=', '4.3561', 'loss=', '86.366314486')
# ('Epoch:', '0265', 'training time (minutes)=', '4.2887', 'loss=', '86.308803266')
# ('Epoch:', '0266', 'training time (minutes)=', '4.3301', 'loss=', '86.486125135')
# ('Epoch:', '0267', 'training time (minutes)=', '4.2891', 'loss=', '86.367053055')
# ('Epoch:', '0268', 'training time (minutes)=', '4.3353', 'loss=', '86.448486813')
# ('Epoch:', '0269', 'training time (minutes)=', '4.3317', 'loss=', '86.421303168')
# ('Epoch:', '0270', 'training time (minutes)=', '4.4316', 'loss=', '85.805423690')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '4.3014', 'loss=', '86.291339436')
# ('Epoch:', '0272', 'training time (minutes)=', '4.2666', 'loss=', '86.447021358')
# ('Epoch:', '0273', 'training time (minutes)=', '4.0874', 'loss=', '86.520437706')
# ('Epoch:', '0274', 'training time (minutes)=', '4.1232', 'loss=', '86.148329253')
# ('Epoch:', '0275', 'training time (minutes)=', '4.0763', 'loss=', '85.900591216')
# ('Epoch:', '0276', 'training time (minutes)=', '4.0903', 'loss=', '86.340854469')
# ('Epoch:', '0277', 'training time (minutes)=', '4.0465', 'loss=', '86.199742606')
# ('Epoch:', '0278', 'training time (minutes)=', '4.1020', 'loss=', '86.353904897')
# ('Epoch:', '0279', 'training time (minutes)=', '4.0591', 'loss=', '86.109942327')
# ('Epoch:', '0280', 'training time (minutes)=', '4.0739', 'loss=', '86.344732497')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '4.0599', 'loss=', '86.378188615')
# ('Epoch:', '0282', 'training time (minutes)=', '4.0896', 'loss=', '86.470069938')
# ('Epoch:', '0283', 'training time (minutes)=', '4.1356', 'loss=', '86.435128813')
# ('Epoch:', '0284', 'training time (minutes)=', '4.0465', 'loss=', '86.198703613')
# ('Epoch:', '0285', 'training time (minutes)=', '4.1489', 'loss=', '86.234909995')
# ('Epoch:', '0286', 'training time (minutes)=', '4.0399', 'loss=', '85.834521510')
# ('Epoch:', '0287', 'training time (minutes)=', '4.0858', 'loss=', '86.241071110')
# ('Epoch:', '0288', 'training time (minutes)=', '4.0266', 'loss=', '85.925715377')
# ('Epoch:', '0289', 'training time (minutes)=', '4.0442', 'loss=', '86.161539842')
# ('Epoch:', '0290', 'training time (minutes)=', '4.0473', 'loss=', '86.210747935')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '4.2592', 'loss=', '86.001164067')
# ('Epoch:', '0292', 'training time (minutes)=', '4.0386', 'loss=', '85.908845629')
# ('Epoch:', '0293', 'training time (minutes)=', '4.1894', 'loss=', '86.358231269')
# ('Epoch:', '0294', 'training time (minutes)=', '4.0377', 'loss=', '86.082069237')
# ('Epoch:', '0295', 'training time (minutes)=', '4.3003', 'loss=', '85.942222356')
# ('Epoch:', '0296', 'training time (minutes)=', '4.0470', 'loss=', '85.851614749')
# ('Epoch:', '0297', 'training time (minutes)=', '4.2145', 'loss=', '86.051240143')
# ('Epoch:', '0298', 'training time (minutes)=', '4.0468', 'loss=', '86.029151398')
# ('Epoch:', '0299', 'training time (minutes)=', '4.0417', 'loss=', '85.991507467')
# ('Epoch:', '0300', 'training time (minutes)=', '4.0302', 'loss=', '86.126320417')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '4.0521', 'loss=', '86.179064482')
# ('Epoch:', '0302', 'training time (minutes)=', '4.0320', 'loss=', '85.863485642')
# ('Epoch:', '0303', 'training time (minutes)=', '4.0406', 'loss=', '85.926835861')
# ('Epoch:', '0304', 'training time (minutes)=', '4.0116', 'loss=', '85.746402687')
# ('Epoch:', '0305', 'training time (minutes)=', '4.1702', 'loss=', '85.750024516')
# ('Epoch:', '0306', 'training time (minutes)=', '4.0276', 'loss=', '85.922965591')
# ('Epoch:', '0307', 'training time (minutes)=', '4.1402', 'loss=', '85.750832508')
# ('Epoch:', '0308', 'training time (minutes)=', '4.0391', 'loss=', '85.798714827')
# ('Epoch:', '0309', 'training time (minutes)=', '4.0116', 'loss=', '85.623409225')
# ('Epoch:', '0310', 'training time (minutes)=', '4.0205', 'loss=', '86.143202725')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '4.0163', 'loss=', '85.905149466')
# ('Epoch:', '0312', 'training time (minutes)=', '4.0073', 'loss=', '86.060679878')
# ('Epoch:', '0313', 'training time (minutes)=', '4.0700', 'loss=', '85.782881647')
# ('Epoch:', '0314', 'training time (minutes)=', '3.9962', 'loss=', '85.856674985')
# ('Epoch:', '0315', 'training time (minutes)=', '4.1026', 'loss=', '85.891771430')
# ('Epoch:', '0316', 'training time (minutes)=', '4.0191', 'loss=', '85.596388441')
# ('Epoch:', '0317', 'training time (minutes)=', '4.1590', 'loss=', '85.582853450')
# ('Epoch:', '0318', 'training time (minutes)=', '4.1365', 'loss=', '85.537940979')
# ('Epoch:', '0319', 'training time (minutes)=', '4.1562', 'loss=', '86.044307357')
# ('Epoch:', '0320', 'training time (minutes)=', '4.0234', 'loss=', '85.570725471')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '4.0939', 'loss=', '85.531824823')
# ('Epoch:', '0322', 'training time (minutes)=', '4.2322', 'loss=', '85.497503095')
# ('Epoch:', '0323', 'training time (minutes)=', '4.1927', 'loss=', '85.687640871')
# ('Epoch:', '0324', 'training time (minutes)=', '4.1115', 'loss=', '85.589187695')
# ('Epoch:', '0325', 'training time (minutes)=', '4.0482', 'loss=', '85.670101093')
# ('Epoch:', '0326', 'training time (minutes)=', '4.0403', 'loss=', '85.607173355')
# ('Epoch:', '0327', 'training time (minutes)=', '4.0511', 'loss=', '85.945542970')
# ('Epoch:', '0328', 'training time (minutes)=', '4.0942', 'loss=', '85.602881461')
# ('Epoch:', '0329', 'training time (minutes)=', '4.1226', 'loss=', '85.823538584')
# ('Epoch:', '0330', 'training time (minutes)=', '4.0864', 'loss=', '85.696494644')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '4.0965', 'loss=', '85.657215278')
# ('Epoch:', '0332', 'training time (minutes)=', '4.1379', 'loss=', '85.617016703')
# ('Epoch:', '0333', 'training time (minutes)=', '4.0793', 'loss=', '85.158311831')
# ('Epoch:', '0334', 'training time (minutes)=', '4.1211', 'loss=', '85.421083550')
# ('Epoch:', '0335', 'training time (minutes)=', '3.9881', 'loss=', '85.750772084')
# ('Epoch:', '0336', 'training time (minutes)=', '4.1814', 'loss=', '85.366614850')
# ('Epoch:', '0337', 'training time (minutes)=', '4.1597', 'loss=', '85.180910868')
# ('Epoch:', '0338', 'training time (minutes)=', '4.0682', 'loss=', '85.188344783')
# ('Epoch:', '0339', 'training time (minutes)=', '4.0099', 'loss=', '85.317581217')
# ('Epoch:', '0340', 'training time (minutes)=', '4.0480', 'loss=', '85.793668873')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/usphere_scaled__three_fc_dec_2048pts_emd/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '4.1182', 'loss=', '85.423055589')
# ('Epoch:', '0342', 'training time (minutes)=', '4.0828', 'loss=', '85.616341428')
# ('Epoch:', '0343', 'training time (minutes)=', '4.0855', 'loss=', '85.281141673')
# ('Epoch:', '0344', 'training time (minutes)=', '4.0853', 'loss=', '85.426847132')
# ('Epoch:', '0345', 'training time (minutes)=', '4.0459', 'loss=', '85.420804406')
# ('Epoch:', '0346', 'training time (minutes)=', '4.0303', 'loss=', '85.450921939')
# ('Epoch:', '0347', 'training time (minutes)=', '4.0569', 'loss=', '85.495761785')
