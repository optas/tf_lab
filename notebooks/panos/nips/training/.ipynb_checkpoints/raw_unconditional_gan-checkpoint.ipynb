# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 1
setup_one_gpu(GPU)
# Out:
# Picking GPU 1

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio
from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets

from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec

from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id

from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch, \
                                           plot_interpolations

from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs
                                                  
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud

from tf_lab.point_clouds.gan import model_saver_id
from tf_lab.nips.shape_net import pc_loader as sn_pc_loader
from tf_lab.autopredictors.exploration import latent_embedding_of_entire_dataset
from tf_lab.point_clouds.raw_gan import RawGAN
from tf_lab.point_clouds.raw_wgan import RawWGAN
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
do_plotting = True
save_model = True
save_synthetics_sample = True
seed = 42

do_wgan = False
do_gan = True
assert(np.logical_xor(do_wgan, do_gan))

class_name = raw_input('Give me the class type.\n').lower()
syn_id = shape_net_category_to_synth_id()[class_name]
synthetic_data_out_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/NIPS/our_samples/'
experiment_name = '_raw_' + class_name +'_' + str(n_pc_samples) +  '_pts'
# Out:
# Give me the class type.
# chair

# %%
reset_tf_graph()
if do_gan:
    string_id = 'gan'
    experiment_name = string_id + experiment_name
    init_lr = 0.0005
    max_epochs = 30
    gan = RawGAN(experiment_name, learning_rate=init_lr, n_output=[n_pc_samples, 3])
else:
    assert(do_wgan)
    string_id = 'wgan'
    experiment_name = string_id + experiment_name
    init_lr = 0.00001
    max_epochs = 200
    clamp = 0.5
    gan = RawWGAN(experiment_name, [n_pc_samples, 3], learning_rate=init_lr, clamp=clamp)

# %%
top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
train_dir = osp.join(top_data_dir, 'OUT/models/nips/gan/raw_gan')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)

full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/centered/', str(n_pc_samples))
full_pclouds_path = osp.join(full_pclouds_path, syn_id)
full_file_names = pio.load_filenames_of_input_data(full_pclouds_path, '.ply')
full_pclouds, full_model_ids, full_syn_ids = pio.load_crude_point_clouds(file_names=full_file_names,\
                                                                           n_threads=50, loader=sn_pc_loader)
print '%d files containing complete point clouds were found.' % (len(full_pclouds), )
train_data = PointCloudDataSet(full_pclouds)
# Out:
# 6778 files containing complete point clouds were found.

# %%
if do_training:
    train_stats = []
    batch_size = 50
    noise_params = {'mu':0, 'sigma': 1}
    for _ in range(max_epochs):
        checkpoint_path = osp.join(train_dir, model_saver_id)
        loss, duration = gan._single_epoch_train(train_data, batch_size, noise_params)
        epoch = int(gan.sess.run(gan.epoch.assign_add(tf.constant(1.0))))
        print epoch, loss, duration
        if save_model:
            gan.saver.save(gan.sess, checkpoint_path, global_step=gan.epoch)
        train_stats.append((epoch,) + loss)
# Out:
# 61 (0.71432318069316725, 2.233670601579878) 27.9820268154
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-61 is not in all_model_checkpoint_paths. Manually adding it.
# 62 (0.71528564779846759, 2.2040768201704379) 28.4346249104
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-62 is not in all_model_checkpoint_paths. Manually adding it.
# 63 (0.73905396660168965, 2.1572354193086976) 27.9681549072
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-63 is not in all_model_checkpoint_paths. Manually adding it.
# 64 (0.70667226182089915, 2.2242455208743062) 28.1287090778
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-64 is not in all_model_checkpoint_paths. Manually adding it.
# 65 (0.68655502597490947, 2.2030699266327751) 28.4891109467
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-65 is not in all_model_checkpoint_paths. Manually adding it.
# 66 (0.73943667014439896, 2.207582077715132) 28.545445919
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-66 is not in all_model_checkpoint_paths. Manually adding it.
# 67 (0.70218195385403104, 2.2366833441787297) 28.8640220165
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-67 is not in all_model_checkpoint_paths. Manually adding it.
# 68 (0.67062720325258041, 2.348992296501442) 28.4284901619
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-68 is not in all_model_checkpoint_paths. Manually adding it.
# 69 (0.67737190855873952, 2.284521711314166) 28.4618098736
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-69 is not in all_model_checkpoint_paths. Manually adding it.
# 70 (0.67209306425518456, 2.4138711121347214) 28.8173179626
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# 71 (0.67720330467930545, 2.3968760631702564) 28.2878890038
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-71 is not in all_model_checkpoint_paths. Manually adding it.
# 72 (0.6935327808062236, 2.3205487816422075) 28.7673840523
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-72 is not in all_model_checkpoint_paths. Manually adding it.
# 73 (0.69451210807870933, 2.3211448113123576) 28.5608718395
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-73 is not in all_model_checkpoint_paths. Manually adding it.
# 74 (0.6854016429848141, 2.2956719892996329) 28.9416401386
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-74 is not in all_model_checkpoint_paths. Manually adding it.
# 75 (0.68259014023674858, 2.3672077748510572) 28.5721461773
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-75 is not in all_model_checkpoint_paths. Manually adding it.
# 76 (0.65390210482809275, 2.4018280214733547) 28.6498908997
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-76 is not in all_model_checkpoint_paths. Manually adding it.
# 77 (0.63978262676133046, 2.4027263711999964) 28.5731050968
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-77 is not in all_model_checkpoint_paths. Manually adding it.
# 78 (0.66457693223600034, 2.3526936014493307) 28.8381569386
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-78 is not in all_model_checkpoint_paths. Manually adding it.
# 79 (0.64303936251887572, 2.4171965391547592) 28.5914120674
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-79 is not in all_model_checkpoint_paths. Manually adding it.
# 80 (0.6286370244291094, 2.4748325683452466) 28.7105350494
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# 81 (0.68566659711025379, 2.4759491116912278) 28.6806819439
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-81 is not in all_model_checkpoint_paths. Manually adding it.
# 82 (0.61796869569354584, 2.4932634596471432) 28.5873541832
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-82 is not in all_model_checkpoint_paths. Manually adding it.
# 83 (0.60709345119970815, 2.4628480734648526) 28.9859249592
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-83 is not in all_model_checkpoint_paths. Manually adding it.
# 84 (0.59483579176443591, 2.4371345780513907) 28.9025480747
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-84 is not in all_model_checkpoint_paths. Manually adding it.
# 85 (0.69156341442355407, 2.4258792261282602) 28.5577318668
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-85 is not in all_model_checkpoint_paths. Manually adding it.
# 86 (0.68974485463566249, 2.2984769163308321) 28.6890640259
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-86 is not in all_model_checkpoint_paths. Manually adding it.
# 87 (0.68072233597437537, 2.3853260004961934) 28.4930050373
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-87 is not in all_model_checkpoint_paths. Manually adding it.
# 88 (0.64505022455144811, 2.4307026103690816) 28.5654010773
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-88 is not in all_model_checkpoint_paths. Manually adding it.
# 89 (0.58190771849067124, 2.5121116227573816) 28.5837609768
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-89 is not in all_model_checkpoint_paths. Manually adding it.
# 90 (0.64978641161212214, 2.5453296436203852) 28.571657896
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/gan/raw_gan/gan_raw_chair_2048_pts/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.

# %%
if do_plotting:
    x = range(len(train_stats))
    d_loss = [t[1] for t in train_stats]
    g_loss = [t[2] for t in train_stats]
    plt.plot(x, d_loss)
    plt.plot(x, g_loss)
    plt.legend(['d_loss', 'g_loss'], loc=0)
    plt.xlabel('Epochs.')
    plt.ylabel('Loss.')

# %%
if save_synthetics_sample:
    # Swap axis and put in U-sphere and save
    n_samples = 1000
    syn_data = gan.generate(n_samples, noise_params)
    syn_data_rot = np.empty_like(syn_data)
    for i, pc in enumerate(syn_data):
        syn_data_rot[i] = pc[:, [0, 2, 1]]
        pc = Point_Cloud(syn_data_rot[i]).center_in_unit_sphere()
        syn_data_rot[i] = pc.points
        
    save_out = osp.join(synthetic_data_out_dir, experiment_name + '_epoch_' + str(epoch))
    np.savez(save_out, syn_data_rot)

# %%
from tf_lab.nips.evaluate_gan import entropy_of_occupancy_grid
print entropy_of_occupancy_grid(syn_data, 32)
# Out:
# 0.049853024775

# %%
for i in range(10):
    Point_Cloud(gan.generate(1, noise_params)[0]).plot()

# %%
from tf_lab.nips.evaluate_gan import emd_distances
emd_distances(syn_data, 10, gan.sess)
# Out:
# 213.98326
