# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 1
setup_one_gpu(GPU)
# Out:
# Picking GPU 1

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio

from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch


from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud

from tf_lab.nips.shape_net import pc_loader as sn_pc_loader
from tf_lab.nips.helper import load_shape_net_models_used_by_wu
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/geo_tool/solids/mesh.py:26: UserWarning: Mayavi library was not found. Some graphics utilities will be disabled.
#   warnings.warn('Mayavi library was not found. Some graphics utilities will be disabled.')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = True
load_model = False
z_rotate = True
seed = 42
max_training_epochs = 2000
loss = 'emd'
is_convolutional = True

# %%
if is_convolutional:
    arch_tag = 'convolutional_arch'
    
    encoder_args = {'n_filters': [128, 128, 256, 512],
                    'filter_sizes': [40, 20, 10, 10],
                    'strides': [1, 2, 2, 1]
                   }
        
else:
    arch_tag = 'mlp_arch'
    encoder_args = {'n_filters': [64, 128, 256, 512],
                    'filter_sizes' :[1, 1, 1, 1],
                    'strides': [1, 1, 1, 1]
                   }

# %%
experiment_name = 'wu_classes_rotated_' + arch_tag + '_' + str(n_pc_samples) +  'pts_' + loss
top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/centered/', str(n_pc_samples))
train_dir = osp.join(top_data_dir, 'OUT/models/nips/vanilla_ae/')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd'

# %%
full_pclouds, full_model_names, full_syn_ids = load_shape_net_models_used_by_wu(n_pc_samples, full_pclouds_path)
model_unames = full_model_names + '.' + full_syn_ids
train_data = PointCloudDataSet(full_pclouds, labels=model_unames)
# Out:
# airplane 02691156
# 4045 files containing complete point clouds were found.
# car 02958343
# 7497 files containing complete point clouds were found.
# chair 03001627
# 6778 files containing complete point clouds were found.
# sofa 04256520
# 3173 files containing complete point clouds were found.
# rifle 04090263
# 2372 files containing complete point clouds were found.
# boat 02858304
# 1137 files containing complete point clouds were found.
# table 04379243
# 8509 files containing complete point clouds were found.

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:
    n_input = [n_pc_samples, 3]
    
    decoder_args = {'layer_sizes': [1024, 2048, np.prod(n_input)] }
    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args,        
               )

    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))
    
reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)

# %%
if do_training:
    training_stats = []
    training_stats.append(ae.train(train_data, conf))    
    with open(osp.join(conf.train_dir, 'train_stats.txt'), 'a') as fout:
        np.savetxt(fout, np.array(training_stats)[0])
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '2.3493', 'loss=', '256.680364717')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '3.4469', 'loss=', '163.137017765')
# ('Epoch:', '0003', 'training time (minutes)=', '4.8124', 'loss=', '149.441841854')
# ('Epoch:', '0004', 'training time (minutes)=', '4.7782', 'loss=', '141.182500982')
# ('Epoch:', '0005', 'training time (minutes)=', '4.8022', 'loss=', '137.008197306')
# ('Epoch:', '0006', 'training time (minutes)=', '4.7926', 'loss=', '130.079330786')
# ('Epoch:', '0007', 'training time (minutes)=', '4.7994', 'loss=', '128.697601785')
# ('Epoch:', '0008', 'training time (minutes)=', '4.7839', 'loss=', '127.789430601')
# ('Epoch:', '0009', 'training time (minutes)=', '4.7924', 'loss=', '122.802914281')
# ('Epoch:', '0010', 'training time (minutes)=', '4.7808', 'loss=', '122.031678806')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '4.7675', 'loss=', '118.303977534')
# ('Epoch:', '0012', 'training time (minutes)=', '4.7814', 'loss=', '116.268538028')
# ('Epoch:', '0013', 'training time (minutes)=', '4.7947', 'loss=', '115.623473347')
# ('Epoch:', '0014', 'training time (minutes)=', '4.7875', 'loss=', '113.503443237')
# ('Epoch:', '0015', 'training time (minutes)=', '4.7856', 'loss=', '111.490781995')
# ('Epoch:', '0016', 'training time (minutes)=', '4.7900', 'loss=', '112.657807683')
# ('Epoch:', '0017', 'training time (minutes)=', '4.7885', 'loss=', '110.779336480')
# ('Epoch:', '0018', 'training time (minutes)=', '4.7710', 'loss=', '107.650106948')
# ('Epoch:', '0019', 'training time (minutes)=', '4.7841', 'loss=', '109.179249220')
# ('Epoch:', '0020', 'training time (minutes)=', '4.7915', 'loss=', '106.685967141')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '4.8224', 'loss=', '107.842810662')
# ('Epoch:', '0022', 'training time (minutes)=', '4.6890', 'loss=', '105.351610326')
# ('Epoch:', '0023', 'training time (minutes)=', '4.8126', 'loss=', '105.446613756')
# ('Epoch:', '0024', 'training time (minutes)=', '5.0920', 'loss=', '104.156762274')
# ('Epoch:', '0025', 'training time (minutes)=', '4.8531', 'loss=', '105.668140548')
# ('Epoch:', '0026', 'training time (minutes)=', '4.9019', 'loss=', '102.131247905')
# ('Epoch:', '0027', 'training time (minutes)=', '4.7391', 'loss=', '103.482522925')
# ('Epoch:', '0028', 'training time (minutes)=', '4.7904', 'loss=', '101.823986987')
# ('Epoch:', '0029', 'training time (minutes)=', '4.7877', 'loss=', '102.732200623')
# ('Epoch:', '0030', 'training time (minutes)=', '4.7543', 'loss=', '101.520581954')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '4.7770', 'loss=', '101.826291201')
# ('Epoch:', '0032', 'training time (minutes)=', '4.7565', 'loss=', '100.764492559')
# ('Epoch:', '0033', 'training time (minutes)=', '4.7690', 'loss=', '100.266344179')
# ('Epoch:', '0034', 'training time (minutes)=', '4.6931', 'loss=', '99.777210475')
# ('Epoch:', '0035', 'training time (minutes)=', '4.7454', 'loss=', '99.883563460')
# ('Epoch:', '0036', 'training time (minutes)=', '4.6766', 'loss=', '99.921942765')
# ('Epoch:', '0037', 'training time (minutes)=', '4.7128', 'loss=', '99.534959571')
# ('Epoch:', '0038', 'training time (minutes)=', '4.6621', 'loss=', '100.018046251')
# ('Epoch:', '0039', 'training time (minutes)=', '4.6697', 'loss=', '97.879464095')
# ('Epoch:', '0040', 'training time (minutes)=', '4.7293', 'loss=', '98.035199908')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '4.6920', 'loss=', '99.103309221')
# ('Epoch:', '0042', 'training time (minutes)=', '4.6736', 'loss=', '97.221771867')
# ('Epoch:', '0043', 'training time (minutes)=', '4.6734', 'loss=', '96.560494061')
# ('Epoch:', '0044', 'training time (minutes)=', '4.6690', 'loss=', '96.329564200')
# ('Epoch:', '0045', 'training time (minutes)=', '4.6474', 'loss=', '98.802866067')
# ('Epoch:', '0046', 'training time (minutes)=', '4.6496', 'loss=', '96.655957737')
# ('Epoch:', '0047', 'training time (minutes)=', '4.6629', 'loss=', '97.040542500')
# ('Epoch:', '0048', 'training time (minutes)=', '4.6277', 'loss=', '96.261374550')
# ('Epoch:', '0049', 'training time (minutes)=', '4.5906', 'loss=', '96.480535889')
# ('Epoch:', '0050', 'training time (minutes)=', '4.5927', 'loss=', '94.836118009')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '4.6416', 'loss=', '96.358937209')
# ('Epoch:', '0052', 'training time (minutes)=', '4.6284', 'loss=', '94.907247071')
# ('Epoch:', '0053', 'training time (minutes)=', '4.6192', 'loss=', '95.108407764')
# ('Epoch:', '0054', 'training time (minutes)=', '4.6092', 'loss=', '95.082996687')
# ('Epoch:', '0055', 'training time (minutes)=', '4.5679', 'loss=', '93.961986815')
# ('Epoch:', '0056', 'training time (minutes)=', '4.5837', 'loss=', '94.353363982')
# ('Epoch:', '0057', 'training time (minutes)=', '4.5691', 'loss=', '94.626457431')
# ('Epoch:', '0058', 'training time (minutes)=', '4.5894', 'loss=', '94.289269860')
# ('Epoch:', '0059', 'training time (minutes)=', '4.6635', 'loss=', '93.589454583')
# ('Epoch:', '0060', 'training time (minutes)=', '4.5891', 'loss=', '92.876495976')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '4.5641', 'loss=', '93.660969862')
# ('Epoch:', '0062', 'training time (minutes)=', '4.5297', 'loss=', '93.844539859')
# ('Epoch:', '0063', 'training time (minutes)=', '4.4538', 'loss=', '92.568359421')
# ('Epoch:', '0064', 'training time (minutes)=', '2.4343', 'loss=', '92.996394644')
# ('Epoch:', '0065', 'training time (minutes)=', '2.4294', 'loss=', '92.964399765')
# ('Epoch:', '0066', 'training time (minutes)=', '2.4733', 'loss=', '92.081082916')
# ('Epoch:', '0067', 'training time (minutes)=', '2.4316', 'loss=', '92.767324863')
# ('Epoch:', '0068', 'training time (minutes)=', '2.5113', 'loss=', '91.137096929')
# ('Epoch:', '0069', 'training time (minutes)=', '2.5449', 'loss=', '92.505406269')
# ('Epoch:', '0070', 'training time (minutes)=', '2.5544', 'loss=', '92.039598789')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '2.5290', 'loss=', '91.130844743')
# ('Epoch:', '0072', 'training time (minutes)=', '2.5097', 'loss=', '92.264573533')
# ('Epoch:', '0073', 'training time (minutes)=', '2.4926', 'loss=', '91.756226537')
# ('Epoch:', '0074', 'training time (minutes)=', '2.4449', 'loss=', '91.329575701')
# ('Epoch:', '0075', 'training time (minutes)=', '2.5470', 'loss=', '91.385245753')
# ('Epoch:', '0076', 'training time (minutes)=', '2.5070', 'loss=', '90.679920458')
# ('Epoch:', '0077', 'training time (minutes)=', '2.4407', 'loss=', '90.541645665')
# ('Epoch:', '0078', 'training time (minutes)=', '2.4341', 'loss=', '89.683084015')
# ('Epoch:', '0079', 'training time (minutes)=', '2.4373', 'loss=', '90.433215036')
# ('Epoch:', '0080', 'training time (minutes)=', '2.4946', 'loss=', '90.027866796')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '2.4809', 'loss=', '90.702516095')
# ('Epoch:', '0082', 'training time (minutes)=', '2.5240', 'loss=', '90.252280119')
# ('Epoch:', '0083', 'training time (minutes)=', '2.4911', 'loss=', '90.234862199')
# ('Epoch:', '0084', 'training time (minutes)=', '2.4369', 'loss=', '89.586170322')
# ('Epoch:', '0085', 'training time (minutes)=', '2.5821', 'loss=', '89.397575914')
# ('Epoch:', '0086', 'training time (minutes)=', '2.4394', 'loss=', '88.200971939')
# ('Epoch:', '0087', 'training time (minutes)=', '2.5700', 'loss=', '90.829950782')
# ('Epoch:', '0088', 'training time (minutes)=', '2.6375', 'loss=', '88.768108920')
# ('Epoch:', '0089', 'training time (minutes)=', '2.4431', 'loss=', '88.743626062')
# ('Epoch:', '0090', 'training time (minutes)=', '2.4817', 'loss=', '88.952347166')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '2.4314', 'loss=', '88.827896551')
# ('Epoch:', '0092', 'training time (minutes)=', '2.4716', 'loss=', '89.799843313')
# ('Epoch:', '0093', 'training time (minutes)=', '2.4395', 'loss=', '88.194756761')
# ('Epoch:', '0094', 'training time (minutes)=', '2.4348', 'loss=', '88.210776064')
# ('Epoch:', '0095', 'training time (minutes)=', '2.5062', 'loss=', '89.771692430')
# ('Epoch:', '0096', 'training time (minutes)=', '2.4399', 'loss=', '87.955270625')
# ('Epoch:', '0097', 'training time (minutes)=', '2.4799', 'loss=', '87.560994954')
# ('Epoch:', '0098', 'training time (minutes)=', '2.4352', 'loss=', '87.607546803')
# ('Epoch:', '0099', 'training time (minutes)=', '2.4301', 'loss=', '88.283892765')
# ('Epoch:', '0100', 'training time (minutes)=', '2.5892', 'loss=', '88.083517707')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '2.4511', 'loss=', '88.013322210')
# ('Epoch:', '0102', 'training time (minutes)=', '2.5482', 'loss=', '87.547262727')
# ('Epoch:', '0103', 'training time (minutes)=', '2.5498', 'loss=', '89.478590131')
# ('Epoch:', '0104', 'training time (minutes)=', '2.6344', 'loss=', '86.529775973')
# ('Epoch:', '0105', 'training time (minutes)=', '2.5348', 'loss=', '87.215976334')
# ('Epoch:', '0106', 'training time (minutes)=', '2.5275', 'loss=', '87.487911942')
# ('Epoch:', '0107', 'training time (minutes)=', '2.4904', 'loss=', '87.687901682')
# ('Epoch:', '0108', 'training time (minutes)=', '2.4988', 'loss=', '87.287114032')
# ('Epoch:', '0109', 'training time (minutes)=', '2.6044', 'loss=', '86.784212357')
# ('Epoch:', '0110', 'training time (minutes)=', '2.4985', 'loss=', '86.686895832')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '2.4702', 'loss=', '87.415564067')
# ('Epoch:', '0112', 'training time (minutes)=', '2.4836', 'loss=', '85.974021860')
# ('Epoch:', '0113', 'training time (minutes)=', '2.4916', 'loss=', '86.617611301')
# ('Epoch:', '0114', 'training time (minutes)=', '2.4662', 'loss=', '86.713707602')
# ('Epoch:', '0115', 'training time (minutes)=', '2.4350', 'loss=', '86.155169228')
# ('Epoch:', '0116', 'training time (minutes)=', '2.4920', 'loss=', '87.188023889')
# ('Epoch:', '0117', 'training time (minutes)=', '2.5050', 'loss=', '85.715424569')
# ('Epoch:', '0118', 'training time (minutes)=', '2.4757', 'loss=', '86.035496868')
# ('Epoch:', '0119', 'training time (minutes)=', '2.4776', 'loss=', '86.208965803')
# ('Epoch:', '0120', 'training time (minutes)=', '2.4598', 'loss=', '86.455405819')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '2.4619', 'loss=', '85.702994048')
# ('Epoch:', '0122', 'training time (minutes)=', '2.5086', 'loss=', '85.305268473')
# ('Epoch:', '0123', 'training time (minutes)=', '2.4936', 'loss=', '85.804571305')
# ('Epoch:', '0124', 'training time (minutes)=', '2.4342', 'loss=', '86.133408720')
# ('Epoch:', '0125', 'training time (minutes)=', '2.4821', 'loss=', '85.999477609')
# ('Epoch:', '0126', 'training time (minutes)=', '2.4777', 'loss=', '84.793407235')
# ('Epoch:', '0127', 'training time (minutes)=', '2.5495', 'loss=', '85.662924172')
# ('Epoch:', '0128', 'training time (minutes)=', '2.4893', 'loss=', '86.630341783')
# ('Epoch:', '0129', 'training time (minutes)=', '2.5041', 'loss=', '84.866540801')
# ('Epoch:', '0130', 'training time (minutes)=', '2.4727', 'loss=', '84.428641965')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '2.4673', 'loss=', '84.517139167')
# ('Epoch:', '0132', 'training time (minutes)=', '2.4983', 'loss=', '84.410058594')
# ('Epoch:', '0133', 'training time (minutes)=', '2.4429', 'loss=', '84.983518202')
# ('Epoch:', '0134', 'training time (minutes)=', '2.4694', 'loss=', '84.861456128')
# ('Epoch:', '0135', 'training time (minutes)=', '2.4818', 'loss=', '83.894183708')
# ('Epoch:', '0136', 'training time (minutes)=', '2.4848', 'loss=', '85.247329541')
# ('Epoch:', '0137', 'training time (minutes)=', '2.5080', 'loss=', '84.945763722')
# ('Epoch:', '0138', 'training time (minutes)=', '2.4917', 'loss=', '84.675481916')
# ('Epoch:', '0139', 'training time (minutes)=', '2.4784', 'loss=', '84.753721915')
# ('Epoch:', '0140', 'training time (minutes)=', '2.4742', 'loss=', '83.908290960')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '2.4847', 'loss=', '84.433520064')
# ('Epoch:', '0142', 'training time (minutes)=', '2.4692', 'loss=', '84.151215101')
# ('Epoch:', '0143', 'training time (minutes)=', '2.4638', 'loss=', '84.911760455')
# ('Epoch:', '0144', 'training time (minutes)=', '2.4589', 'loss=', '84.159569003')
# ('Epoch:', '0145', 'training time (minutes)=', '2.4306', 'loss=', '84.023164003')
# ('Epoch:', '0146', 'training time (minutes)=', '2.4281', 'loss=', '84.318542737')
# ('Epoch:', '0147', 'training time (minutes)=', '2.4994', 'loss=', '84.664732782')
# ('Epoch:', '0148', 'training time (minutes)=', '2.4851', 'loss=', '83.327456904')
# ('Epoch:', '0149', 'training time (minutes)=', '2.5037', 'loss=', '84.198348037')
# ('Epoch:', '0150', 'training time (minutes)=', '2.4841', 'loss=', '84.079218856')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '2.4289', 'loss=', '83.531835027')
# ('Epoch:', '0152', 'training time (minutes)=', '2.5021', 'loss=', '83.719025831')
# ('Epoch:', '0153', 'training time (minutes)=', '2.4561', 'loss=', '84.654035864')
# ('Epoch:', '0154', 'training time (minutes)=', '2.4813', 'loss=', '83.255761730')
# ('Epoch:', '0155', 'training time (minutes)=', '2.5063', 'loss=', '82.645695609')
# ('Epoch:', '0156', 'training time (minutes)=', '2.4822', 'loss=', '83.610536188')
# ('Epoch:', '0157', 'training time (minutes)=', '2.5110', 'loss=', '84.908474794')
# ('Epoch:', '0158', 'training time (minutes)=', '2.5110', 'loss=', '83.088331672')
# ('Epoch:', '0159', 'training time (minutes)=', '2.5193', 'loss=', '83.398177679')
# ('Epoch:', '0160', 'training time (minutes)=', '2.5031', 'loss=', '83.133870355')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '2.5075', 'loss=', '82.219877773')
# ('Epoch:', '0162', 'training time (minutes)=', '2.5111', 'loss=', '83.831646615')
# ('Epoch:', '0163', 'training time (minutes)=', '2.4996', 'loss=', '82.434476579')
# ('Epoch:', '0164', 'training time (minutes)=', '2.5224', 'loss=', '83.070375727')
# ('Epoch:', '0165', 'training time (minutes)=', '2.5305', 'loss=', '82.576638526')
# ('Epoch:', '0166', 'training time (minutes)=', '2.5338', 'loss=', '83.173275028')
# ('Epoch:', '0167', 'training time (minutes)=', '2.5176', 'loss=', '82.683680469')
# ('Epoch:', '0168', 'training time (minutes)=', '2.5231', 'loss=', '82.505500588')
# ('Epoch:', '0169', 'training time (minutes)=', '2.5155', 'loss=', '82.551323506')
# ('Epoch:', '0170', 'training time (minutes)=', '2.4981', 'loss=', '83.389534469')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '2.4923', 'loss=', '82.029898088')
# ('Epoch:', '0172', 'training time (minutes)=', '2.5112', 'loss=', '82.687612289')
# ('Epoch:', '0173', 'training time (minutes)=', '2.5059', 'loss=', '82.639812692')
# ('Epoch:', '0174', 'training time (minutes)=', '2.5132', 'loss=', '82.380272487')
# ('Epoch:', '0175', 'training time (minutes)=', '2.5087', 'loss=', '81.813693300')
# ('Epoch:', '0176', 'training time (minutes)=', '2.5093', 'loss=', '81.942625501')
# ('Epoch:', '0177', 'training time (minutes)=', '2.5019', 'loss=', '82.821519829')
# ('Epoch:', '0178', 'training time (minutes)=', '2.5339', 'loss=', '82.326939477')
# ('Epoch:', '0179', 'training time (minutes)=', '2.5014', 'loss=', '82.316656090')
# ('Epoch:', '0180', 'training time (minutes)=', '2.5139', 'loss=', '82.974761866')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '2.5107', 'loss=', '82.488591112')
# ('Epoch:', '0182', 'training time (minutes)=', '2.5107', 'loss=', '81.572781588')
# ('Epoch:', '0183', 'training time (minutes)=', '2.5054', 'loss=', '82.331811398')
# ('Epoch:', '0184', 'training time (minutes)=', '2.4918', 'loss=', '81.390127649')
# ('Epoch:', '0185', 'training time (minutes)=', '2.5232', 'loss=', '82.194923042')
# ('Epoch:', '0186', 'training time (minutes)=', '2.4494', 'loss=', '82.816212031')
# ('Epoch:', '0187', 'training time (minutes)=', '2.4880', 'loss=', '81.907603944')
# ('Epoch:', '0188', 'training time (minutes)=', '2.4570', 'loss=', '81.617200612')
# ('Epoch:', '0189', 'training time (minutes)=', '2.4578', 'loss=', '81.118183740')
# ('Epoch:', '0190', 'training time (minutes)=', '2.4466', 'loss=', '81.757947666')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '2.4225', 'loss=', '81.004009543')
# ('Epoch:', '0192', 'training time (minutes)=', '2.4489', 'loss=', '81.659755690')
# ('Epoch:', '0193', 'training time (minutes)=', '2.4565', 'loss=', '82.261906433')
# ('Epoch:', '0194', 'training time (minutes)=', '2.4688', 'loss=', '81.628104782')
# ('Epoch:', '0195', 'training time (minutes)=', '2.4509', 'loss=', '82.098669303')
# ('Epoch:', '0196', 'training time (minutes)=', '2.4791', 'loss=', '81.188854924')
# ('Epoch:', '0197', 'training time (minutes)=', '2.4226', 'loss=', '82.060969498')
# ('Epoch:', '0198', 'training time (minutes)=', '2.4745', 'loss=', '81.678439701')
# ('Epoch:', '0199', 'training time (minutes)=', '2.4599', 'loss=', '81.331169926')
# ('Epoch:', '0200', 'training time (minutes)=', '2.4457', 'loss=', '81.515911188')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '2.4988', 'loss=', '81.027088991')
# ('Epoch:', '0202', 'training time (minutes)=', '2.4302', 'loss=', '81.044192010')
# ('Epoch:', '0203', 'training time (minutes)=', '2.4209', 'loss=', '81.750712893')
# ('Epoch:', '0204', 'training time (minutes)=', '2.4187', 'loss=', '80.782093834')
# ('Epoch:', '0205', 'training time (minutes)=', '2.4180', 'loss=', '81.532131337')
# ('Epoch:', '0206', 'training time (minutes)=', '2.4816', 'loss=', '80.802312003')
# ('Epoch:', '0207', 'training time (minutes)=', '2.4597', 'loss=', '81.163532382')
# ('Epoch:', '0208', 'training time (minutes)=', '2.4220', 'loss=', '81.385322679')
# ('Epoch:', '0209', 'training time (minutes)=', '2.4672', 'loss=', '80.408523007')
# ('Epoch:', '0210', 'training time (minutes)=', '2.4215', 'loss=', '80.961429419')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '2.4641', 'loss=', '81.200976335')
# ('Epoch:', '0212', 'training time (minutes)=', '2.4977', 'loss=', '80.687268698')
# ('Epoch:', '0213', 'training time (minutes)=', '2.4196', 'loss=', '81.446406549')
# ('Epoch:', '0214', 'training time (minutes)=', '2.4578', 'loss=', '79.803746722')
# ('Epoch:', '0215', 'training time (minutes)=', '2.4605', 'loss=', '80.501145189')
# ('Epoch:', '0216', 'training time (minutes)=', '2.4256', 'loss=', '81.263657180')
# ('Epoch:', '0217', 'training time (minutes)=', '2.4195', 'loss=', '80.528743920')
# ('Epoch:', '0218', 'training time (minutes)=', '2.4203', 'loss=', '80.322455551')
# ('Epoch:', '0219', 'training time (minutes)=', '2.3632', 'loss=', '81.000427833')
# ('Epoch:', '0220', 'training time (minutes)=', '2.4283', 'loss=', '80.220630828')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '2.3807', 'loss=', '80.095881163')
# ('Epoch:', '0222', 'training time (minutes)=', '2.4170', 'loss=', '80.819568116')
# ('Epoch:', '0223', 'training time (minutes)=', '2.3673', 'loss=', '80.242047575')
# ('Epoch:', '0224', 'training time (minutes)=', '2.4474', 'loss=', '80.343332701')
# ('Epoch:', '0225', 'training time (minutes)=', '2.4576', 'loss=', '80.850037077')
# ('Epoch:', '0226', 'training time (minutes)=', '2.4664', 'loss=', '79.983119019')
# ('Epoch:', '0227', 'training time (minutes)=', '2.3641', 'loss=', '79.429600662')
# ('Epoch:', '0228', 'training time (minutes)=', '2.3634', 'loss=', '80.301749380')
# ('Epoch:', '0229', 'training time (minutes)=', '2.4068', 'loss=', '79.657187123')
# ('Epoch:', '0230', 'training time (minutes)=', '2.4315', 'loss=', '79.387737821')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '2.4110', 'loss=', '79.970120057')
# ('Epoch:', '0232', 'training time (minutes)=', '2.4152', 'loss=', '79.494396654')
# ('Epoch:', '0233', 'training time (minutes)=', '2.3952', 'loss=', '80.841416834')
# ('Epoch:', '0234', 'training time (minutes)=', '2.4176', 'loss=', '79.537614839')
# ('Epoch:', '0235', 'training time (minutes)=', '2.4211', 'loss=', '79.732899805')
# ('Epoch:', '0236', 'training time (minutes)=', '2.4345', 'loss=', '79.871670527')
# ('Epoch:', '0237', 'training time (minutes)=', '2.4054', 'loss=', '80.164216067')
# ('Epoch:', '0238', 'training time (minutes)=', '2.4207', 'loss=', '79.829409984')
# ('Epoch:', '0239', 'training time (minutes)=', '2.4259', 'loss=', '79.898350542')
# ('Epoch:', '0240', 'training time (minutes)=', '2.4157', 'loss=', '79.888726533')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '2.3860', 'loss=', '79.351517481')
# ('Epoch:', '0242', 'training time (minutes)=', '2.4274', 'loss=', '79.967206209')
# ('Epoch:', '0243', 'training time (minutes)=', '2.4096', 'loss=', '80.442725361')
# ('Epoch:', '0244', 'training time (minutes)=', '2.4286', 'loss=', '79.031854618')
# ('Epoch:', '0245', 'training time (minutes)=', '2.4095', 'loss=', '79.832516758')
# ('Epoch:', '0246', 'training time (minutes)=', '2.4273', 'loss=', '79.266190560')
# ('Epoch:', '0247', 'training time (minutes)=', '2.4500', 'loss=', '79.178973355')
# ('Epoch:', '0248', 'training time (minutes)=', '2.4569', 'loss=', '78.566581339')
# ('Epoch:', '0249', 'training time (minutes)=', '2.4372', 'loss=', '80.088854240')
# ('Epoch:', '0250', 'training time (minutes)=', '2.4452', 'loss=', '79.181581953')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '2.4363', 'loss=', '79.529990028')
# ('Epoch:', '0252', 'training time (minutes)=', '2.4428', 'loss=', '79.118590278')
# ('Epoch:', '0253', 'training time (minutes)=', '2.4355', 'loss=', '79.212825752')
# ('Epoch:', '0254', 'training time (minutes)=', '2.4463', 'loss=', '79.702184000')
# ('Epoch:', '0255', 'training time (minutes)=', '2.4360', 'loss=', '79.468938252')
# ('Epoch:', '0256', 'training time (minutes)=', '2.4500', 'loss=', '78.629697828')
# ('Epoch:', '0257', 'training time (minutes)=', '2.4426', 'loss=', '78.713872118')
# ('Epoch:', '0258', 'training time (minutes)=', '2.4148', 'loss=', '79.638046390')
# ('Epoch:', '0259', 'training time (minutes)=', '2.4259', 'loss=', '79.316738482')
# ('Epoch:', '0260', 'training time (minutes)=', '2.4272', 'loss=', '79.325733225')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '2.4219', 'loss=', '78.914178347')
# ('Epoch:', '0262', 'training time (minutes)=', '2.4458', 'loss=', '79.642142151')
# ('Epoch:', '0263', 'training time (minutes)=', '2.4564', 'loss=', '79.967169098')
# ('Epoch:', '0264', 'training time (minutes)=', '2.4581', 'loss=', '78.209842676')
# ('Epoch:', '0265', 'training time (minutes)=', '2.4447', 'loss=', '79.725556371')
# ('Epoch:', '0266', 'training time (minutes)=', '2.4318', 'loss=', '78.979000877')
# ('Epoch:', '0267', 'training time (minutes)=', '2.4895', 'loss=', '79.128051382')
# ('Epoch:', '0268', 'training time (minutes)=', '2.5972', 'loss=', '78.990027966')
# ('Epoch:', '0269', 'training time (minutes)=', '2.5343', 'loss=', '79.299109820')
# ('Epoch:', '0270', 'training time (minutes)=', '2.4973', 'loss=', '78.552969537')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '2.4997', 'loss=', '78.942430701')
# ('Epoch:', '0272', 'training time (minutes)=', '2.4923', 'loss=', '78.477283575')
# ('Epoch:', '0273', 'training time (minutes)=', '2.5079', 'loss=', '78.974615814')
# ('Epoch:', '0274', 'training time (minutes)=', '2.4846', 'loss=', '78.595081603')
# ('Epoch:', '0275', 'training time (minutes)=', '2.4780', 'loss=', '79.460071809')
# ('Epoch:', '0276', 'training time (minutes)=', '2.4806', 'loss=', '78.292606137')
# ('Epoch:', '0277', 'training time (minutes)=', '2.4576', 'loss=', '78.853151145')
# ('Epoch:', '0278', 'training time (minutes)=', '2.4838', 'loss=', '78.773301190')
# ('Epoch:', '0279', 'training time (minutes)=', '2.4435', 'loss=', '78.004824954')
# ('Epoch:', '0280', 'training time (minutes)=', '2.4860', 'loss=', '78.126656194')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '2.4153', 'loss=', '78.285036150')
# ('Epoch:', '0282', 'training time (minutes)=', '2.4602', 'loss=', '78.645117296')
# ('Epoch:', '0283', 'training time (minutes)=', '2.4705', 'loss=', '78.554051636')
# ('Epoch:', '0284', 'training time (minutes)=', '2.4715', 'loss=', '79.041303714')
# ('Epoch:', '0285', 'training time (minutes)=', '2.4676', 'loss=', '77.805605669')
# ('Epoch:', '0286', 'training time (minutes)=', '2.4546', 'loss=', '79.231132547')
# ('Epoch:', '0287', 'training time (minutes)=', '2.4445', 'loss=', '77.885282625')
# ('Epoch:', '0288', 'training time (minutes)=', '2.4544', 'loss=', '78.538591994')
# ('Epoch:', '0289', 'training time (minutes)=', '2.4544', 'loss=', '77.591500274')
# ('Epoch:', '0290', 'training time (minutes)=', '2.4246', 'loss=', '78.614134729')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '2.4506', 'loss=', '78.777251104')
# ('Epoch:', '0292', 'training time (minutes)=', '2.4919', 'loss=', '77.962579112')
# ('Epoch:', '0293', 'training time (minutes)=', '2.4954', 'loss=', '77.854577289')
# ('Epoch:', '0294', 'training time (minutes)=', '2.5136', 'loss=', '78.432254154')
# ('Epoch:', '0295', 'training time (minutes)=', '2.4048', 'loss=', '77.435484832')
# ('Epoch:', '0296', 'training time (minutes)=', '2.3913', 'loss=', '78.150749486')
# ('Epoch:', '0297', 'training time (minutes)=', '2.3912', 'loss=', '78.182339950')
# ('Epoch:', '0298', 'training time (minutes)=', '2.3812', 'loss=', '77.705957441')
# ('Epoch:', '0299', 'training time (minutes)=', '2.3830', 'loss=', '78.245280052')
# ('Epoch:', '0300', 'training time (minutes)=', '2.3775', 'loss=', '78.487253684')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '2.3786', 'loss=', '78.581669064')
# ('Epoch:', '0302', 'training time (minutes)=', '2.3831', 'loss=', '77.225898059')
# ('Epoch:', '0303', 'training time (minutes)=', '2.3820', 'loss=', '78.594406709')
# ('Epoch:', '0304', 'training time (minutes)=', '2.3831', 'loss=', '77.848111822')
# ('Epoch:', '0305', 'training time (minutes)=', '2.3847', 'loss=', '77.320319919')
# ('Epoch:', '0306', 'training time (minutes)=', '2.3894', 'loss=', '78.823237946')
# ('Epoch:', '0307', 'training time (minutes)=', '2.3913', 'loss=', '77.311136627')
# ('Epoch:', '0308', 'training time (minutes)=', '2.3914', 'loss=', '78.093349525')
# ('Epoch:', '0309', 'training time (minutes)=', '2.3928', 'loss=', '77.646312053')
# ('Epoch:', '0310', 'training time (minutes)=', '2.3934', 'loss=', '78.542992401')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '2.3812', 'loss=', '78.063387976')
# ('Epoch:', '0312', 'training time (minutes)=', '2.3863', 'loss=', '77.902632807')
# ('Epoch:', '0313', 'training time (minutes)=', '2.3840', 'loss=', '78.953729504')
# ('Epoch:', '0314', 'training time (minutes)=', '2.3816', 'loss=', '77.186248216')
# ('Epoch:', '0315', 'training time (minutes)=', '2.3845', 'loss=', '77.405622306')
# ('Epoch:', '0316', 'training time (minutes)=', '2.3771', 'loss=', '78.012336685')
# ('Epoch:', '0317', 'training time (minutes)=', '2.3783', 'loss=', '77.723062999')
# ('Epoch:', '0318', 'training time (minutes)=', '2.3743', 'loss=', '78.109791884')
# ('Epoch:', '0319', 'training time (minutes)=', '2.3783', 'loss=', '78.790897107')
# ('Epoch:', '0320', 'training time (minutes)=', '2.3787', 'loss=', '77.563296122')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '2.3753', 'loss=', '78.232419945')
# ('Epoch:', '0322', 'training time (minutes)=', '2.3762', 'loss=', '76.972513353')
# ('Epoch:', '0323', 'training time (minutes)=', '2.3854', 'loss=', '77.798087391')
# ('Epoch:', '0324', 'training time (minutes)=', '2.3948', 'loss=', '77.660957359')
# ('Epoch:', '0325', 'training time (minutes)=', '2.4060', 'loss=', '77.352285727')
# ('Epoch:', '0326', 'training time (minutes)=', '2.4190', 'loss=', '78.064441379')
# ('Epoch:', '0327', 'training time (minutes)=', '2.4215', 'loss=', '77.685534235')
# ('Epoch:', '0328', 'training time (minutes)=', '2.4230', 'loss=', '77.417250397')
# ('Epoch:', '0329', 'training time (minutes)=', '2.4193', 'loss=', '77.476646042')
# ('Epoch:', '0330', 'training time (minutes)=', '2.4189', 'loss=', '77.010520747')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '2.4179', 'loss=', '77.783588290')
# ('Epoch:', '0332', 'training time (minutes)=', '2.4270', 'loss=', '77.437435105')
# ('Epoch:', '0333', 'training time (minutes)=', '2.4245', 'loss=', '77.861858920')
# ('Epoch:', '0334', 'training time (minutes)=', '2.4214', 'loss=', '77.145105032')
# ('Epoch:', '0335', 'training time (minutes)=', '2.4227', 'loss=', '77.042208777')
# ('Epoch:', '0336', 'training time (minutes)=', '2.4204', 'loss=', '77.651470845')
# ('Epoch:', '0337', 'training time (minutes)=', '2.4204', 'loss=', '77.208089658')
# ('Epoch:', '0338', 'training time (minutes)=', '2.4237', 'loss=', '78.348207445')
# ('Epoch:', '0339', 'training time (minutes)=', '2.4244', 'loss=', '78.180926519')
# ('Epoch:', '0340', 'training time (minutes)=', '2.4203', 'loss=', '77.146317405')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '2.4184', 'loss=', '77.164040517')
# ('Epoch:', '0342', 'training time (minutes)=', '2.4209', 'loss=', '77.775668819')
# ('Epoch:', '0343', 'training time (minutes)=', '2.4236', 'loss=', '77.184153110')
# ('Epoch:', '0344', 'training time (minutes)=', '2.4203', 'loss=', '77.293982247')
# ('Epoch:', '0345', 'training time (minutes)=', '2.4226', 'loss=', '76.902107928')
# ('Epoch:', '0346', 'training time (minutes)=', '2.4192', 'loss=', '76.990715380')
# ('Epoch:', '0347', 'training time (minutes)=', '2.4193', 'loss=', '77.358320105')
# ('Epoch:', '0348', 'training time (minutes)=', '2.4227', 'loss=', '76.961500276')
# ('Epoch:', '0349', 'training time (minutes)=', '2.4193', 'loss=', '77.571936257')
# ('Epoch:', '0350', 'training time (minutes)=', '2.4231', 'loss=', '76.856637078')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '2.4171', 'loss=', '77.525911121')
# ('Epoch:', '0352', 'training time (minutes)=', '2.4209', 'loss=', '77.330771711')
# ('Epoch:', '0353', 'training time (minutes)=', '2.4263', 'loss=', '77.106435263')
# ('Epoch:', '0354', 'training time (minutes)=', '2.4253', 'loss=', '77.026291822')
# ('Epoch:', '0355', 'training time (minutes)=', '2.4217', 'loss=', '77.038700508')
# ('Epoch:', '0356', 'training time (minutes)=', '2.4277', 'loss=', '76.769643459')
# ('Epoch:', '0357', 'training time (minutes)=', '2.4255', 'loss=', '77.257164713')
# ('Epoch:', '0358', 'training time (minutes)=', '2.4253', 'loss=', '76.764527762')
# ('Epoch:', '0359', 'training time (minutes)=', '2.4256', 'loss=', '76.954815048')
# ('Epoch:', '0360', 'training time (minutes)=', '2.4251', 'loss=', '77.015059981')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0361', 'training time (minutes)=', '2.4193', 'loss=', '77.352248138')
# ('Epoch:', '0362', 'training time (minutes)=', '2.4305', 'loss=', '76.950407245')
# ('Epoch:', '0363', 'training time (minutes)=', '2.4203', 'loss=', '76.783122003')
# ('Epoch:', '0364', 'training time (minutes)=', '2.4254', 'loss=', '76.474567909')
# ('Epoch:', '0365', 'training time (minutes)=', '2.4229', 'loss=', '77.562333451')
# ('Epoch:', '0366', 'training time (minutes)=', '2.4305', 'loss=', '76.414821158')
# ('Epoch:', '0367', 'training time (minutes)=', '2.4366', 'loss=', '77.504717420')
# ('Epoch:', '0368', 'training time (minutes)=', '2.4370', 'loss=', '76.474597635')
# ('Epoch:', '0369', 'training time (minutes)=', '2.4336', 'loss=', '76.540007651')
# ('Epoch:', '0370', 'training time (minutes)=', '2.4354', 'loss=', '76.585422789')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0371', 'training time (minutes)=', '2.4314', 'loss=', '76.602547113')
# ('Epoch:', '0372', 'training time (minutes)=', '2.4352', 'loss=', '77.212602222')
# ('Epoch:', '0373', 'training time (minutes)=', '2.4334', 'loss=', '76.156674115')
# ('Epoch:', '0374', 'training time (minutes)=', '2.4366', 'loss=', '77.143218983')
# ('Epoch:', '0375', 'training time (minutes)=', '2.4360', 'loss=', '76.928800606')
# ('Epoch:', '0376', 'training time (minutes)=', '2.4332', 'loss=', '77.001615701')
# ('Epoch:', '0377', 'training time (minutes)=', '2.4276', 'loss=', '76.911857502')
# ('Epoch:', '0378', 'training time (minutes)=', '2.4310', 'loss=', '76.609146363')
# ('Epoch:', '0379', 'training time (minutes)=', '2.4287', 'loss=', '76.591435498')
# ('Epoch:', '0380', 'training time (minutes)=', '2.4304', 'loss=', '76.604752760')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0381', 'training time (minutes)=', '2.4311', 'loss=', '77.075107722')
# ('Epoch:', '0382', 'training time (minutes)=', '2.4337', 'loss=', '76.813999688')
# ('Epoch:', '0383', 'training time (minutes)=', '2.4351', 'loss=', '76.702620572')
# ('Epoch:', '0384', 'training time (minutes)=', '2.4329', 'loss=', '76.472397414')
# ('Epoch:', '0385', 'training time (minutes)=', '2.4300', 'loss=', '76.533765366')
# ('Epoch:', '0386', 'training time (minutes)=', '2.4349', 'loss=', '76.212459342')
# ('Epoch:', '0387', 'training time (minutes)=', '2.4272', 'loss=', '76.370939443')
# ('Epoch:', '0388', 'training time (minutes)=', '2.4311', 'loss=', '76.181085319')
# ('Epoch:', '0389', 'training time (minutes)=', '2.4311', 'loss=', '76.912020646')
# ('Epoch:', '0390', 'training time (minutes)=', '2.4317', 'loss=', '76.676775838')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/models/nips/vanilla_ae/wu_classes_rotated_convolutional_arch_2048pts_emd/models.ckpt-390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0391', 'training time (minutes)=', '2.4324', 'loss=', '76.426852246')
# ('Epoch:', '0392', 'training time (minutes)=', '2.4391', 'loss=', '76.375513117')
# ('Epoch:', '0393', 'training time (minutes)=', '2.4374', 'loss=', '75.913071493')
# ('Epoch:', '0394', 'training time (minutes)=', '2.4360', 'loss=', '76.502079380')
# ('Epoch:', '0395', 'training time (minutes)=', '2.4340', 'loss=', '76.283541232')
