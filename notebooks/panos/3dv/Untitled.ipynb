# %%
import numpy as np
from tf_lab.nips.helper import pclouds_centered_and_half_sphere
from geo_tool import Point_Cloud

# %%
# %matplotlib inline

# %%
ref_file = '/orions4-zfs/projects/feixia/gan_data/gan.npz'

# %%
ref_data = np.load(ref_file)  # Load Ground-Truth Data.
ref_data = ref_data[ref_data.keys()[0]]
ref_data = pclouds_centered_and_half_sphere(ref_data)
# _, ref_grid_var = entropy_of_occupancy_grid(ref_data, voxel_resolution, in_sphere=cmp_in_sphere)

# %%
ref_data.shape[1]
# Out:
# 2500

# %%
Point_Cloud(ref_data[19]).plot()
