# %%
from general_tools.notebook import gpu_utils
GPU = 1
gpu_utils.setup_one_gpu(GPU)
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.WARN)
# Out:
# Picking GPU 1

# %%
import sys
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio

from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf

from tf_lab.in_out.basics import read_saved_epochs
                                                  
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.data_sets.model_net import pc_loader, classes_to_integers
from tf_lab.nips.helper import average_per_class, pclouds_with_zero_mean_in_unit_sphere

from sklearn.svm import LinearSVC
from general_tools.simpletons import sort_dict_by_key, sort_dict_by_val

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
put_in_usphere = True
model_net = '40'
loss = 'emd'

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/all_snc/'
experiment_name = 'no_conv_deeper_snc_rotated2048pts_' + loss

# %%
train_dir = osp.join(top_data_dir, experiment_name)
conf = Conf.load(osp.join(train_dir, 'configuration'))

if conf.train_dir != train_dir: # added to address moving training-folder to other location
    conf.train_dir = train_dir
    conf.save(osp.join(conf.train_dir, 'configuration'))

print conf
conf.n_output = conf.n_input
conf.allow_gpu_growth = True
# Out:
#               allow_gpu_growth: False
#                     batch_size: 50
#                  consistent_io: None
#                          debug: False
#                        decoder: decoder_with_fc_only
#                   decoder_args: {'b_norm': True, 'layer_sizes': [1024, 2048, 6144]}
#                        encoder: encoder_with_convs_and_symmetry_new
#                   encoder_args: {'filter_sizes': [1, 1, 1, 1], 'n_filters': [128, 128, 256, 512], 'b_norm': True, 'strides': [1, 1, 1, 1]}
#                experiment_name: no_conv_deeper_snc_rotated2048pts_emd
#                  gauss_augment: None
#                   is_denoising: False
#                latent_vs_recon: 1.0
#                  learning_rate: 0.0005
#                           loss: emd
#              loss_display_step: 1
#                        n_input: [2048, 3]
#                       n_output: [2048, 3]
#                            n_z: None
#              saver_max_to_keep: None
#                     saver_step: 10
#                      train_dir: /orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_emd
#                training_epochs: 2000
#                       z_rotate: True

# %%
reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)
saved_epochs = read_saved_epochs(conf.train_dir)
last_epoch = saved_epochs[-1]
last_epoch = 1000
ae.restore_model(conf.train_dir, last_epoch, verbose=True)
# Out:
# Model restored in epoch 1000.

# %%
model_net_dir = '/orions4-zfs/projects/optas/DATA/Point_Clouds/Model_Net_' + model_net + '/from_manifold/'
model_net_dir = osp.join(model_net_dir, str(n_pc_samples))

search_pattern = '(.*)train(.*)\.ply$'
train_pc_files = sorted([f for f in files_in_subdirs(model_net_dir, search_pattern)])

search_pattern = '(.*)test(.*)\.ply$'
test_pc_files = sorted([f for f in files_in_subdirs(model_net_dir, search_pattern)])

# %%
verbose = True
n_threads = 22

pc, model_names, labels = load_point_clouds_from_filenames(train_pc_files, n_threads, pc_loader, verbose)

if put_in_usphere:
    pc = pclouds_with_zero_mean_in_unit_sphere(pc)

train_data = PointCloudDataSet(pc, labels=labels, init_shuffle=False)

pc_, model_names_, labels_ = load_point_clouds_from_filenames(test_pc_files, n_threads, pc_loader, verbose)

if put_in_usphere:
    pc_ = pclouds_with_zero_mean_in_unit_sphere(pc_)

test_data = PointCloudDataSet(pc_, labels=labels_, init_shuffle=False)
# Out:
# 9843 pclouds were loaded. They belong in 40 shape-classes.
# 2468 pclouds were loaded. They belong in 40 shape-classes.

# %%
train_feed, train_latent, train_classes = ae.embedding_at_tensor(train_data, conf, tensor_name='bottleneck')
cids = classes_to_integers(int(model_net), train_classes)[1]

test_feed, test_latent, test_classes = ae.embedding_at_tensor(test_data, conf, tensor_name='bottleneck')
cids_ = classes_to_integers(int(model_net), test_classes)[1]

# %%
all_random_states = dict()
all_scores = dict()

intercept_scaling_space = [0.1, 0.2, 0.4, 0.5, 1, 2, 3, 4]

c_space = [0.01, 0.02, 0.05, 0.07, 0.08, 0.09,
           0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 
           0.45, 0.50]

dual_space = [False, True]

loss_space = ['hinge', 'squared_hinge']

# %%
for c in c_space:
    for intercept in intercept_scaling_space:
        for dual in dual_space:
            for loss in loss_space:
                try:
                    rs = np.random.get_state()
                    lsvc = LinearSVC(C=c, loss=loss, intercept_scaling=intercept, dual=dual, random_state=42)
                    lsvc.fit(train_latent, cids)
                    
                    print c, intercept, dual, loss
                    score = average_per_class(lsvc, test_latent, cids_)

                    print score
                    key = (c, intercept, dual, loss)
                    all_scores[key] = score
                    all_random_states[key] = rs
                except:
                    continue
# Out:
# 0.01 0.1 False squared_hinge
# 0.819005813953
# 0.01 0.1 True hinge
# 0.793389534884
# 0.01 0.1 True squared_hinge
# 0.817465116279
# 0.01 0.2 False squared_hinge
# 0.819005813953
# 0.01 0.2 True hinge
# 0.791308139535
# 0.01 0.2 True squared_hinge
# 0.818715116279
# 0.01 0.4 False squared_hinge
# 0.819005813953
# 0.01 0.4 True hinge
# 0.79376744186
# 0.01 0.4 True squared_hinge
# 0.819005813953
# 0.01 0.5 False squared_hinge
# 0.818715116279
# 0.01 0.5 True hinge
# 0.791808139535
# 0.01 0.5 True squared_hinge
# 0.818005813953
# 0.01 1 False squared_hinge
# 0.819005813953
# 0.01 1 True hinge
# 0.797598837209
# 0.01 1 True squared_hinge
# 0.817005813953
# 0.01 2 False squared_hinge
# 0.820005813953
# 0.01 2 True hinge
# 0.795139534884
# 0.01 2 True squared_hinge
# 0.818715116279
# 0.01 3 False squared_hinge
# 0.818755813953
# 0.01 3 True hinge
# 0.791639534884
# 0.01 3 True squared_hinge
# 0.820215116279
# 0.01 4 False squared_hinge
# 0.818755813953
# 0.01 4 True hinge
# 0.79526744186
# 0.01 4 True squared_hinge
# 0.819005813953
# 0.02 0.1 False squared_hinge
# 0.823296511628
# 0.02 0.1 True hinge
# 0.805593023256
# 0.02 0.1 True squared_hinge
# 0.822005813953
# 0.02 0.2 False squared_hinge
# 0.823005813953
# 0.02 0.2 True hinge
# 0.806052325581
# 0.02 0.2 True squared_hinge
# 0.824255813953
# 0.02 0.4 False squared_hinge
# 0.823255813953
# 0.02 0.4 True hinge
# 0.803302325581
# 0.02 0.4 True squared_hinge
# 0.820343023256
# 0.02 0.5 False squared_hinge
# 0.823796511628
# 0.02 0.5 True hinge
# 0.805261627907
# 0.02 0.5 True squared_hinge
# 0.822005813953
# 0.02 1 False squared_hinge
# 0.823296511628
# 0.02 1 True hinge
# 0.806343023256
# 0.02 1 True squared_hinge
# 0.820046511628
# 0.02 2 False squared_hinge
# 0.823005813953
# 0.02 2 True hinge
# 0.809093023256
# 0.02 2 True squared_hinge
# 0.818593023256
# 0.02 3 False squared_hinge
# 0.823005813953
# 0.02 3 True hinge
# 0.807093023256
# 0.02 3 True squared_hinge
# 0.820046511628
# 0.02 4 False squared_hinge
# 0.823837209302
# 0.02 4 True hinge
# 0.806302325581
# 0.02 4 True squared_hinge
# 0.822918604651
# 0.05 0.1 False squared_hinge
# 0.83275
# 0.05 0.1 True hinge
# 0.822755813953
# 0.05 0.1 True squared_hinge
# 0.834877906977
# 0.05 0.2 False squared_hinge
# 0.8315
# 0.05 0.2 True hinge
# 0.824343023256
# 0.05 0.2 True squared_hinge
# 0.835337209302
# 0.05 0.4 False squared_hinge
# 0.83125
# 0.05 0.4 True hinge
# 0.81913372093
# 0.05 0.4 True squared_hinge
# 0.825773255814
# 0.05 0.5 False squared_hinge
# 0.8315
# 0.05 0.5 True hinge
# 0.815593023256
# 0.05 0.5 True squared_hinge
# 0.826953488372
# 0.05 1 False squared_hinge
# 0.83275
# 0.05 1 True hinge
# 0.823093023256
# 0.05 1 True squared_hinge
# 0.80201744186
# 0.05 2 False squared_hinge
# 0.83125
# 0.05 2 True hinge
# 0.818302325581
# 0.05 2 True squared_hinge
# 0.837087209302
# 0.05 3 False squared_hinge
# 0.8315
# 0.05 3 True hinge
# 0.81863372093
# 0.05 3 True squared_hinge
# 0.828918604651
# 0.05 4 False squared_hinge
# 0.8325
# 0.05 4 True hinge
# 0.822424418605
# 0.05 4 True squared_hinge
# 0.812139534884
# 0.07 0.1 False squared_hinge
# 0.833668604651
# 0.07 0.1 True hinge
# 0.831331395349
# 0.07 0.1 True squared_hinge
# 0.823174418605
# 0.07 0.2 False squared_hinge
# 0.834418604651
# 0.07 0.2 True hinge
# 0.818273255814
# 0.07 0.2 True squared_hinge
# 0.817424418605
# 0.07 0.4 False squared_hinge
# 0.834168604651
# 0.07 0.4 True hinge
# 0.82888372093
# 0.07 0.4 True squared_hinge
# 0.825255813953
# 0.07 0.5 False squared_hinge
# 0.833918604651
# 0.07 0.5 True hinge
# 0.829796511628
# 0.07 0.5 True squared_hinge
# 0.828877906977
# 0.07 1 False squared_hinge
# 0.833418604651
# 0.07 1 True hinge
# 0.828377906977
# 0.07 1 True squared_hinge
# 0.83263372093
# 0.07 2 False squared_hinge
# 0.833918604651
# 0.07 2 True hinge
# 0.828674418605
# 0.07 2 True squared_hinge
# 0.834424418605
# 0.07 3 False squared_hinge
# 0.833918604651
# 0.07 3 True hinge
# 0.81988372093
# 0.07 3 True squared_hinge
# 0.826959302326
# 0.07 4 False squared_hinge
# 0.834168604651
# 0.07 4 True hinge
# 0.821546511628
# 0.07 4 True squared_hinge
# 0.824720930233
# 0.08 0.1 False squared_hinge
# 0.832959302326
# 0.08 0.1 True hinge
# 0.819540697674
# 0.08 0.1 True squared_hinge
# 0.820255813953
# 0.08 0.2 False squared_hinge
# 0.832959302326
# 0.08 0.2 True hinge
# 0.821715116279
# 0.08 0.2 True squared_hinge
# 0.827668604651
# 0.08 0.4 False squared_hinge
# 0.832959302326
# 0.08 0.4 True hinge
# 0.828174418605
# 0.08 0.4 True squared_hinge
# 0.820552325581
# 0.08 0.5 False squared_hinge
# 0.832959302326
# 0.08 0.5 True hinge
# 0.819622093023
# 0.08 0.5 True squared_hinge
# 0.820436046512
# 0.08 1 False squared_hinge
# 0.832959302326
# 0.08 1 True hinge
# 0.825430232558
# 0.08 1 True squared_hinge
# 0.78798255814
# 0.08 2 False squared_hinge
# 0.832959302326
# 0.08 2 True hinge
# 0.826255813953
# 0.08 2 True squared_hinge
# 0.81751744186
# 0.08 3 False squared_hinge
# 0.832709302326
# 0.08 3 True hinge
# 0.82213372093
# 0.08 3 True squared_hinge
# 0.822843023256
# 0.08 4 False squared_hinge
# 0.832959302326
# 0.08 4 True hinge
# 0.824924418605
# 0.08 4 True squared_hinge
# 0.816808139535
# 0.09 0.1 False squared_hinge
# 0.833959302326
# 0.09 0.1 True hinge
# 0.835709302326
# 0.09 0.1 True squared_hinge
# 0.830052325581
# 0.09 0.2 False squared_hinge
# 0.834459302326
# 0.09 0.2 True hinge
# 0.808784883721
# 0.09 0.2 True squared_hinge
# 0.830052325581
# 0.09 0.4 False squared_hinge
# 0.834459302326
# 0.09 0.4 True hinge
# 0.810180232558
# 0.09 0.4 True squared_hinge
# 0.820162790698
# 0.09 0.5 False squared_hinge
# 0.834168604651
# 0.09 0.5 True hinge
# 0.828
# 0.09 0.5 True squared_hinge
# 0.823994186047
# 0.09 1 False squared_hinge
# 0.834209302326
# 0.09 1 True hinge
# 0.823970930233
# 0.09 1 True squared_hinge
# 0.822308139535
# 0.09 2 False squared_hinge
# 0.834209302326
# 0.09 2 True hinge
# 0.825470930233
# 0.09 2 True squared_hinge
# 0.831168604651
# 0.09 3 False squared_hinge
# 0.834168604651
# 0.09 3 True hinge
# 0.83238372093
# 0.09 3 True squared_hinge
# 0.782168604651
# 0.09 4 False squared_hinge
# 0.833877906977
# 0.09 4 True hinge
# 0.831604651163
# 0.09 4 True squared_hinge
# 0.824470930233
# 0.1 0.1 False squared_hinge
# 0.834168604651
# 0.1 0.1 True hinge
# 0.810808139535
# 0.1 0.1 True squared_hinge
# 0.784238372093
# 0.1 0.2 False squared_hinge
# 0.833918604651
# 0.1 0.2 True hinge
# 0.819139534884
# 0.1 0.2 True squared_hinge
# 0.813523255814
# 0.1 0.4 False squared_hinge
# 0.834459302326
# 0.1 0.4 True hinge
# 0.82198255814
# 0.1 0.4 True squared_hinge
# 0.815191860465
# 0.1 0.5 False squared_hinge
# 0.834168604651
# 0.1 0.5 True hinge
# 0.819627906977
# 0.1 0.5 True squared_hinge
# 0.822377906977
# 0.1 1 False squared_hinge
# 0.834459302326
# 0.1 1 True hinge
# 0.821424418605
# 0.1 1 True squared_hinge
# 0.806191860465
# 0.1 2 False squared_hinge
# 0.834168604651
# 0.1 2 True hinge
# 0.821296511628
# 0.1 2 True squared_hinge
# 0.828308139535
# 0.1 3 False squared_hinge
# 0.834168604651
# 0.1 3 True hinge
# 0.828302325581
# 0.1 3 True squared_hinge
# 0.815936046512
# 0.1 4 False squared_hinge
# 0.834459302326
# 0.1 4 True hinge
# 0.812505813953
# 0.1 4 True squared_hinge
# 0.828837209302
# 0.15 0.1 False squared_hinge
# 0.828377906977
# 0.15 0.1 True hinge
# 0.822988372093
# 0.15 0.1 True squared_hinge
# 0.820424418605
# 0.15 0.2 False squared_hinge
# 0.828877906977
# 0.15 0.2 True hinge
# 0.810651162791
# 0.15 0.2 True squared_hinge
# 0.80388372093
# 0.15 0.4 False squared_hinge
# 0.828127906977
# 0.15 0.4 True hinge
# 0.790691860465
# 0.15 0.4 True squared_hinge
# 0.815180232558
# 0.15 0.5 False squared_hinge
# 0.828877906977
# 0.15 0.5 True hinge
# 0.801075581395
# 0.15 0.5 True squared_hinge
# 0.815854651163
# 0.15 1 False squared_hinge
# 0.828087209302
# 0.15 1 True hinge
# 0.821279069767
# 0.15 1 True squared_hinge
# 0.832802325581
# 0.15 2 False squared_hinge
# 0.828627906977
# 0.15 2 True hinge
# 0.812470930233
# 0.15 2 True squared_hinge
# 0.794773255814
# 0.15 3 False squared_hinge
# 0.828377906977
# 0.15 3 True hinge
# 0.805104651163
# 0.15 3 True squared_hinge
# 0.809436046512
# 0.15 4 False squared_hinge
# 0.827877906977
# 0.15 4 True hinge
# 0.798610465116
# 0.15 4 True squared_hinge
# 0.802877906977
# 0.2 0.1 False squared_hinge
# 0.827127906977
# 0.2 0.1 True hinge
# 0.811430232558
# 0.2 0.1 True squared_hinge
# 0.81263372093
# 0.2 0.2 False squared_hinge
# 0.827127906977
# 0.2 0.2 True hinge
# 0.810389534884
# 0.2 0.2 True squared_hinge
# 0.822087209302
# 0.2 0.4 False squared_hinge
# 0.827377906977
# 0.2 0.4 True hinge
# 0.758598837209
# 0.2 0.4 True squared_hinge
# 0.790965116279
# 0.2 0.5 False squared_hinge
# 0.827127906977
# 0.2 0.5 True hinge
# 0.822784883721
# 0.2 0.5 True squared_hinge
# 0.824005813953
# 0.2 1 False squared_hinge
# 0.827127906977
# 0.2 1 True hinge
# 0.797389534884
# 0.2 1 True squared_hinge
# 0.776715116279
# 0.2 2 False squared_hinge
# 0.827127906977
# 0.2 2 True hinge
# 0.825139534884
# 0.2 2 True squared_hinge
# 0.788343023256
# 0.2 3 False squared_hinge
# 0.827127906977
# 0.2 3 True hinge
# 0.82888372093
# 0.2 3 True squared_hinge
# 0.831215116279
# 0.2 4 False squared_hinge
# 0.828627906977
# 0.2 4 True hinge
# 0.719959302326
# 0.2 4 True squared_hinge
# 0.799313953488
# 0.25 0.1 False squared_hinge
# 0.825755813953
# 0.25 0.1 True hinge
# 0.817970930233
# 0.25 0.1 True squared_hinge
# 0.822220930233
# 0.25 0.2 False squared_hinge
# 0.825755813953
# 0.25 0.2 True hinge
# 0.813598837209
# 0.25 0.2 True squared_hinge
# 0.816098837209
# 0.25 0.4 False squared_hinge
# 0.826505813953
# 0.25 0.4 True hinge
# 0.81751744186
# 0.25 0.4 True squared_hinge
# 0.833703488372
# 0.25 0.5 False squared_hinge
# 0.826005813953
# 0.25 0.5 True hinge
# 0.786872093023
# 0.25 0.5 True squared_hinge
# 0.796255813953
# 0.25 1 False squared_hinge
# 0.826505813953
# 0.25 1 True hinge
# 0.825668604651
# 0.25 1 True squared_hinge
# 0.804924418605
# 0.25 2 False squared_hinge
# 0.825005813953
# 0.25 2 True hinge
# 0.749209302326
# 0.25 2 True squared_hinge
# 0.771930232558
# 0.25 3 False squared_hinge
# 0.826755813953
# 0.25 3 True hinge
# 0.801069767442
# 0.25 3 True squared_hinge
# 0.816093023256
# 0.25 4 False squared_hinge
# 0.826005813953
# 0.25 4 True hinge
# 0.826093023256
# 0.25 4 True squared_hinge
# 0.828046511628
# 0.3 0.1 False squared_hinge
# 0.819965116279
# 0.3 0.1 True hinge
# 0.794598837209
# 0.3 0.1 True squared_hinge
# 0.766476744186
# 0.3 0.2 False squared_hinge
# 0.822215116279
# 0.3 0.2 True hinge
# 0.820598837209
# 0.3 0.2 True squared_hinge
# 0.800627906977
# 0.3 0.4 False squared_hinge
# 0.821215116279
# 0.3 0.4 True hinge
# 0.793930232558
# 0.3 0.4 True squared_hinge
# 0.817715116279
# 0.3 0.5 False squared_hinge
# 0.821215116279
# 0.3 0.5 True hinge
# 0.788430232558
# 0.3 0.5 True squared_hinge
# 0.806343023256
# 0.3 1 False squared_hinge
# 0.822215116279
# 0.3 1 True hinge
# 0.789209302326
# 0.3 1 True squared_hinge
# 0.79963372093
# 0.3 2 False squared_hinge
# 0.820965116279
# 0.3 2 True hinge
# 0.79125
# 0.3 2 True squared_hinge
# 0.817180232558
# 0.3 3 False squared_hinge
# 0.821215116279
# 0.3 3 True hinge
# 0.824965116279
# 0.3 3 True squared_hinge
# 0.818005813953
# 0.3 4 False squared_hinge
# 0.821755813953
# 0.3 4 True hinge
# 0.783587209302
# 0.3 4 True squared_hinge
# 0.806093023256
# 0.35 0.1 False squared_hinge
# 0.818424418605
# 0.35 0.1 True hinge
# 0.820598837209
# 0.35 0.1 True squared_hinge
# 0.802203488372
# 0.35 0.2 False squared_hinge
# 0.818674418605
# 0.35 0.2 True hinge
# 0.829511627907
# 0.35 0.2 True squared_hinge
# 0.802005813953
# 0.35 0.4 False squared_hinge
# 0.818674418605
# 0.35 0.4 True hinge
# 0.793930232558
# 0.35 0.4 True squared_hinge
# 0.836331395349
# 0.35 0.5 False squared_hinge
# 0.818674418605
# 0.35 0.5 True hinge
# 0.788430232558
# 0.35 0.5 True squared_hinge
# 0.815162790698
# 0.35 1 False squared_hinge
# 0.818674418605
# 0.35 1 True hinge
# 0.781563953488
# 0.35 1 True squared_hinge
# 0.820912790698
# 0.35 2 False squared_hinge
# 0.818674418605
# 0.35 2 True hinge
# 0.71398255814
# 0.35 2 True squared_hinge
# 0.815918604651
# 0.35 3 False squared_hinge
# 0.819674418605
# 0.35 3 True hinge
# 0.766447674419
# 0.35 3 True squared_hinge
# 0.826691860465
# 0.35 4 False squared_hinge
# 0.818924418605
# 0.35 4 True hinge
# 0.825877906977
# 0.35 4 True squared_hinge
# 0.78026744186
# 0.4 0.1 False squared_hinge
# 0.820674418605
# 0.4 0.1 True hinge
# 0.826790697674
# 0.4 0.1 True squared_hinge
# 0.809
# 0.4 0.2 False squared_hinge
# 0.818674418605
# 0.4 0.2 True hinge
# 0.815093023256
# 0.4 0.2 True squared_hinge
# 0.814511627907
# 0.4 0.4 False squared_hinge
# 0.819924418605
# 0.4 0.4 True hinge
# 0.793930232558
# 0.4 0.4 True squared_hinge
# 0.821034883721
# 0.4 0.5 False squared_hinge
# 0.819174418605
# 0.4 0.5 True hinge
# 0.788430232558
# 0.4 0.5 True squared_hinge
# 0.822627906977
# 0.4 1 False squared_hinge
# 0.819174418605
# 0.4 1 True hinge
# 0.801720930233
# 0.4 1 True squared_hinge
# 0.812924418605
# 0.4 2 False squared_hinge
# 0.817424418605
# 0.4 2 True hinge
# 0.817651162791
# 0.4 2 True squared_hinge
# 0.82288372093
# 0.4 3 False squared_hinge
# 0.818424418605
# 0.4 3 True hinge
# 0.832703488372
# 0.4 3 True squared_hinge
# 0.815186046512
# 0.4 4 False squared_hinge
# 0.818674418605
# 0.4 4 True hinge
# 0.801848837209
# 0.4 4 True squared_hinge
# 0.821098837209
# 0.45 0.1 False squared_hinge
# 0.81888372093
# 0.45 0.1 True hinge
# 0.820598837209
# 0.45 0.1 True squared_hinge
# 0.816877906977
# 0.45 0.2 False squared_hinge
# 0.81663372093
# 0.45 0.2 True hinge
# 0.818802325581
# 0.45 0.2 True squared_hinge
# 0.787331395349
# 0.45 0.4 False squared_hinge
# 0.81913372093
# 0.45 0.4 True hinge
# 0.786151162791
# 0.45 0.4 True squared_hinge
# 0.809668604651
# 0.45 0.5 False squared_hinge
# 0.81638372093
# 0.45 0.5 True hinge
# 0.788430232558
# 0.45 0.5 True squared_hinge
# 0.814941860465
# 0.45 1 False squared_hinge
# 0.81788372093
# 0.45 1 True hinge
# 0.781563953488
# 0.45 1 True squared_hinge
# 0.819093023256
# 0.45 2 False squared_hinge
# 0.81738372093
# 0.45 2 True hinge
# 0.79125
# 0.45 2 True squared_hinge
# 0.805098837209
# 0.45 3 False squared_hinge
# 0.81888372093
# 0.45 3 True hinge
# 0.801552325581
# 0.45 3 True squared_hinge
# 0.821639534884
# 0.45 4 False squared_hinge
# 0.81638372093
# 0.45 4 True hinge
# 0.810918604651
# 0.45 4 True squared_hinge
# 0.816011627907
# 0.5 0.1 False squared_hinge
# 0.816093023256
# 0.5 0.1 True hinge
# 0.820598837209
# 0.5 0.1 True squared_hinge
# 0.799645348837
# 0.5 0.2 False squared_hinge
# 0.816093023256
# 0.5 0.2 True hinge
# 0.820598837209
# 0.5 0.2 True squared_hinge
# 0.818918604651
# 0.5 0.4 False squared_hinge
# 0.81738372093
# 0.5 0.4 True hinge
# 0.793930232558
# 0.5 0.4 True squared_hinge
# 0.790889534884
# 0.5 0.5 False squared_hinge
# 0.815593023256
# 0.5 0.5 True hinge
# 0.824052325581
# 0.5 0.5 True squared_hinge
# 0.831052325581
# 0.5 1 False squared_hinge
# 0.815843023256
# 0.5 1 True hinge
# 0.781563953488
# 0.5 1 True squared_hinge
# 0.822593023256
# 0.5 2 False squared_hinge
# 0.818593023256
# 0.5 2 True hinge
# 0.762540697674
# 0.5 2 True squared_hinge
# 0.81226744186
# 0.5 3 False squared_hinge
# 0.817343023256
# 0.5 3 True hinge
# 0.814889534884
# 0.5 3 True squared_hinge
# 0.791941860465
# 0.5 4 False squared_hinge
# 0.815843023256
# 0.5 4 True hinge
# 0.801848837209
# 0.5 4 True squared_hinge
# 0.823994186047

# %%
best_responses = sort_dict_by_val(all_scores, reverse=True)
best_responses
# Out:
# [((0.05, 2, True, 'squared_hinge'), 0.8370872093023255),
#  ((0.35, 0.4, True, 'squared_hinge'), 0.83633139534883727),
#  ((0.09, 0.1, True, 'hinge'), 0.83570930232558138),
#  ((0.05, 0.2, True, 'squared_hinge'), 0.83533720930232547),
#  ((0.05, 0.1, True, 'squared_hinge'), 0.83487790697674424),
#  ((0.1, 4, False, 'squared_hinge'), 0.8344593023255813),
#  ((0.1, 0.4, False, 'squared_hinge'), 0.8344593023255813),
#  ((0.09, 0.2, False, 'squared_hinge'), 0.8344593023255813),
#  ((0.1, 1, False, 'squared_hinge'), 0.8344593023255813),
#  ((0.09, 0.4, False, 'squared_hinge'), 0.8344593023255813),
#  ((0.07, 2, True, 'squared_hinge'), 0.83442441860465111),
#  ((0.07, 0.2, False, 'squared_hinge'), 0.83441860465116269),
#  ((0.09, 1, False, 'squared_hinge'), 0.83420930232558133),
#  ((0.09, 2, False, 'squared_hinge'), 0.83420930232558133),
#  ((0.1, 0.1, False, 'squared_hinge'), 0.83416860465116294),
#  ((0.1, 0.5, False, 'squared_hinge'), 0.83416860465116272),
#  ((0.09, 0.5, False, 'squared_hinge'), 0.83416860465116272),
#  ((0.09, 3, False, 'squared_hinge'), 0.83416860465116272),
#  ((0.07, 4, False, 'squared_hinge'), 0.83416860465116272),
#  ((0.1, 3, False, 'squared_hinge'), 0.83416860465116272),
#  ((0.1, 2, False, 'squared_hinge'), 0.83416860465116272),
#  ((0.07, 0.4, False, 'squared_hinge'), 0.83416860465116272),
#  ((0.09, 0.1, False, 'squared_hinge'), 0.83395930232558135),
#  ((0.07, 3, False, 'squared_hinge'), 0.83391860465116285),
#  ((0.1, 0.2, False, 'squared_hinge'), 0.83391860465116285),
#  ((0.07, 2, False, 'squared_hinge'), 0.83391860465116285),
#  ((0.07, 0.5, False, 'squared_hinge'), 0.83391860465116285),
#  ((0.09, 4, False, 'squared_hinge'), 0.83387790697674402),
#  ((0.25, 0.4, True, 'squared_hinge'), 0.83370348837209318),
#  ((0.07, 0.1, False, 'squared_hinge'), 0.83366860465116266),
#  ((0.07, 1, False, 'squared_hinge'), 0.83341860465116269),
#  ((0.08, 2, False, 'squared_hinge'), 0.83295930232558146),
#  ((0.08, 0.1, False, 'squared_hinge'), 0.83295930232558146),
#  ((0.08, 0.5, False, 'squared_hinge'), 0.83295930232558146),
#  ((0.08, 1, False, 'squared_hinge'), 0.83295930232558146),
#  ((0.08, 0.4, False, 'squared_hinge'), 0.83295930232558146),
#  ((0.08, 4, False, 'squared_hinge'), 0.83295930232558146),
#  ((0.08, 0.2, False, 'squared_hinge'), 0.83295930232558146),
#  ((0.15, 1, True, 'squared_hinge'), 0.83280232558139533),
#  ((0.05, 0.1, False, 'squared_hinge'), 0.8327500000000001),
#  ((0.05, 1, False, 'squared_hinge'), 0.8327500000000001),
#  ((0.08, 3, False, 'squared_hinge'), 0.83270930232558127),
#  ((0.4, 3, True, 'hinge'), 0.83270348837209285),
#  ((0.07, 1, True, 'squared_hinge'), 0.83263372093023269),
#  ((0.05, 4, False, 'squared_hinge'), 0.83249999999999991),
#  ((0.09, 3, True, 'hinge'), 0.83238372093023238),
#  ((0.09, 4, True, 'hinge'), 0.83160465116279059),
#  ((0.05, 3, False, 'squared_hinge'), 0.83149999999999991),
#  ((0.05, 0.5, False, 'squared_hinge'), 0.83149999999999991),
#  ((0.05, 0.2, False, 'squared_hinge'), 0.83149999999999991),
#  ((0.07, 0.1, True, 'hinge'), 0.83133139534883715),
#  ((0.05, 2, False, 'squared_hinge'), 0.83125000000000004),
#  ((0.05, 0.4, False, 'squared_hinge'), 0.83125000000000004),
#  ((0.2, 3, True, 'squared_hinge'), 0.83121511627906985),
#  ((0.09, 2, True, 'squared_hinge'), 0.83116860465116282),
#  ((0.5, 0.5, True, 'squared_hinge'), 0.83105232558139552),
#  ((0.09, 0.2, True, 'squared_hinge'), 0.8300523255813953),
#  ((0.09, 0.1, True, 'squared_hinge'), 0.8300523255813953),
#  ((0.07, 0.5, True, 'hinge'), 0.82979651162790691),
#  ((0.35, 0.2, True, 'hinge'), 0.82951162790697663),
#  ((0.05, 3, True, 'squared_hinge'), 0.82891860465116274),
#  ((0.2, 3, True, 'hinge'), 0.82888372093023255),
#  ((0.07, 0.4, True, 'hinge'), 0.82888372093023255),
#  ((0.15, 0.2, False, 'squared_hinge'), 0.82887790697674413),
#  ((0.07, 0.5, True, 'squared_hinge'), 0.82887790697674413),
#  ((0.15, 0.5, False, 'squared_hinge'), 0.82887790697674402),
#  ((0.1, 4, True, 'squared_hinge'), 0.82883720930232552),
#  ((0.07, 2, True, 'hinge'), 0.82867441860465119),
#  ((0.2, 4, False, 'squared_hinge'), 0.82862790697674416),
#  ((0.15, 2, False, 'squared_hinge'), 0.82862790697674416),
#  ((0.15, 0.1, False, 'squared_hinge'), 0.82837790697674407),
#  ((0.15, 3, False, 'squared_hinge'), 0.82837790697674407),
#  ((0.07, 1, True, 'hinge'), 0.82837790697674407),
#  ((0.1, 2, True, 'squared_hinge'), 0.82830813953488369),
#  ((0.1, 3, True, 'hinge'), 0.82830232558139549),
#  ((0.08, 0.4, True, 'hinge'), 0.82817441860465113),
#  ((0.15, 0.4, False, 'squared_hinge'), 0.8281279069767441),
#  ((0.15, 1, False, 'squared_hinge'), 0.82808720930232549),
#  ((0.25, 4, True, 'squared_hinge'), 0.8280465116279071),
#  ((0.09, 0.5, True, 'hinge'), 0.82799999999999996),
#  ((0.15, 4, False, 'squared_hinge'), 0.82787790697674413),
#  ((0.08, 0.2, True, 'squared_hinge'), 0.82766860465116276),
#  ((0.2, 0.4, False, 'squared_hinge'), 0.82737790697674407),
#  ((0.2, 2, False, 'squared_hinge'), 0.8271279069767441),
#  ((0.2, 3, False, 'squared_hinge'), 0.8271279069767441),
#  ((0.2, 0.1, False, 'squared_hinge'), 0.8271279069767441),
#  ((0.2, 1, False, 'squared_hinge'), 0.8271279069767441),
#  ((0.2, 0.5, False, 'squared_hinge'), 0.8271279069767441),
#  ((0.2, 0.2, False, 'squared_hinge'), 0.8271279069767441),
#  ((0.07, 3, True, 'squared_hinge'), 0.82695930232558135),
#  ((0.05, 0.5, True, 'squared_hinge'), 0.82695348837209315),
#  ((0.4, 0.1, True, 'hinge'), 0.8267906976744186),
#  ((0.25, 3, False, 'squared_hinge'), 0.82675581395348841),
#  ((0.35, 3, True, 'squared_hinge'), 0.82669186046511633),
#  ((0.25, 1, False, 'squared_hinge'), 0.82650581395348832),
#  ((0.25, 0.4, False, 'squared_hinge'), 0.82650581395348832),
#  ((0.08, 2, True, 'hinge'), 0.82625581395348835),
#  ((0.25, 4, True, 'hinge'), 0.82609302325581402),
#  ((0.25, 0.5, False, 'squared_hinge'), 0.82600581395348838),
#  ((0.25, 4, False, 'squared_hinge'), 0.82600581395348838),
#  ((0.35, 4, True, 'hinge'), 0.82587790697674424),
#  ((0.05, 0.4, True, 'squared_hinge'), 0.82577325581395333),
#  ((0.25, 0.1, False, 'squared_hinge'), 0.82575581395348829),
#  ((0.25, 0.2, False, 'squared_hinge'), 0.82575581395348829),
#  ((0.25, 1, True, 'hinge'), 0.82566860465116287),
#  ((0.09, 2, True, 'hinge'), 0.82547093023255813),
#  ((0.08, 1, True, 'hinge'), 0.82543023255813952),
#  ((0.07, 0.4, True, 'squared_hinge'), 0.82525581395348835),
#  ((0.2, 2, True, 'hinge'), 0.82513953488372083),
#  ((0.25, 2, False, 'squared_hinge'), 0.82500581395348838),
#  ((0.3, 3, True, 'hinge'), 0.82496511627906988),
#  ((0.08, 4, True, 'hinge'), 0.82492441860465104),
#  ((0.07, 4, True, 'squared_hinge'), 0.8247209302325581),
#  ((0.09, 4, True, 'squared_hinge'), 0.82447093023255813),
#  ((0.05, 0.2, True, 'hinge'), 0.82434302325581399),
#  ((0.02, 0.2, True, 'squared_hinge'), 0.82425581395348835),
#  ((0.5, 0.5, True, 'hinge'), 0.82405232558139541),
#  ((0.2, 0.5, True, 'squared_hinge'), 0.82400581395348849),
#  ((0.09, 0.5, True, 'squared_hinge'), 0.82399418604651165),
#  ((0.5, 4, True, 'squared_hinge'), 0.82399418604651165),
#  ((0.09, 1, True, 'hinge'), 0.82397093023255807),
#  ((0.02, 4, False, 'squared_hinge'), 0.82383720930232551),
#  ((0.02, 0.5, False, 'squared_hinge'), 0.8237965116279069),
#  ((0.02, 0.1, False, 'squared_hinge'), 0.82329651162790685),
#  ((0.02, 1, False, 'squared_hinge'), 0.82329651162790685),
#  ((0.02, 0.4, False, 'squared_hinge'), 0.82325581395348824),
#  ((0.07, 0.1, True, 'squared_hinge'), 0.82317441860465124),
#  ((0.05, 1, True, 'hinge'), 0.8230930232558139),
#  ((0.02, 3, False, 'squared_hinge'), 0.82300581395348826),
#  ((0.02, 0.2, False, 'squared_hinge'), 0.82300581395348826),
#  ((0.02, 2, False, 'squared_hinge'), 0.82300581395348826),
#  ((0.15, 0.1, True, 'hinge'), 0.82298837209302322),
#  ((0.02, 4, True, 'squared_hinge'), 0.82291860465116284),
#  ((0.4, 2, True, 'squared_hinge'), 0.82288372093023265),
#  ((0.08, 3, True, 'squared_hinge'), 0.82284302325581393),
#  ((0.2, 0.5, True, 'hinge'), 0.82278488372093028),
#  ((0.05, 0.1, True, 'hinge'), 0.82275581395348851),
#  ((0.4, 0.5, True, 'squared_hinge'), 0.82262790697674415),
#  ((0.5, 1, True, 'squared_hinge'), 0.82259302325581396),
#  ((0.05, 4, True, 'hinge'), 0.82242441860465121),
#  ((0.1, 0.5, True, 'squared_hinge'), 0.82237790697674418),
#  ((0.09, 1, True, 'squared_hinge'), 0.82230813953488369),
#  ((0.25, 0.1, True, 'squared_hinge'), 0.82222093023255804),
#  ((0.3, 1, False, 'squared_hinge'), 0.82221511627906985),
#  ((0.3, 0.2, False, 'squared_hinge'), 0.82221511627906985),
#  ((0.08, 3, True, 'hinge'), 0.82213372093023251),
#  ((0.2, 0.2, True, 'squared_hinge'), 0.82208720930232571),
#  ((0.02, 0.5, True, 'squared_hinge'), 0.82200581395348848),
#  ((0.02, 0.1, True, 'squared_hinge'), 0.82200581395348826),
#  ((0.1, 0.4, True, 'hinge'), 0.8219825581395348),
#  ((0.3, 4, False, 'squared_hinge'), 0.8217558139534884),
#  ((0.08, 0.2, True, 'hinge'), 0.82171511627906979),
#  ((0.45, 3, True, 'squared_hinge'), 0.82163953488372099),
#  ((0.07, 4, True, 'hinge'), 0.82154651162790704),
#  ((0.1, 1, True, 'hinge'), 0.8214244186046511),
#  ((0.1, 2, True, 'hinge'), 0.82129651162790684),
#  ((0.15, 1, True, 'hinge'), 0.82127906976744181),
#  ((0.3, 3, False, 'squared_hinge'), 0.82121511627906985),
#  ((0.3, 0.5, False, 'squared_hinge'), 0.82121511627906973),
#  ((0.3, 0.4, False, 'squared_hinge'), 0.82121511627906973),
#  ((0.4, 4, True, 'squared_hinge'), 0.82109883720930232),
#  ((0.4, 0.4, True, 'squared_hinge'), 0.82103488372093025),
#  ((0.3, 2, False, 'squared_hinge'), 0.82096511627906987),
#  ((0.35, 1, True, 'squared_hinge'), 0.82091279069767431),
#  ((0.4, 0.1, False, 'squared_hinge'), 0.82067441860465107),
#  ((0.35, 0.1, True, 'hinge'), 0.82059883720930249),
#  ((0.45, 0.1, True, 'hinge'), 0.82059883720930249),
#  ((0.5, 0.2, True, 'hinge'), 0.82059883720930249),
#  ((0.5, 0.1, True, 'hinge'), 0.82059883720930249),
#  ((0.3, 0.2, True, 'hinge'), 0.82059883720930249),
#  ((0.08, 0.4, True, 'squared_hinge'), 0.82055232558139546),
#  ((0.08, 0.5, True, 'squared_hinge'), 0.82043604651162794),
#  ((0.15, 0.1, True, 'squared_hinge'), 0.82042441860465121),
#  ((0.02, 0.4, True, 'squared_hinge'), 0.82034302325581387),
#  ((0.08, 0.1, True, 'squared_hinge'), 0.82025581395348834),
#  ((0.01, 3, True, 'squared_hinge'), 0.82021511627906973),
#  ((0.09, 0.4, True, 'squared_hinge'), 0.8201627906976745),
#  ((0.02, 1, True, 'squared_hinge'), 0.82004651162790698),
#  ((0.02, 3, True, 'squared_hinge'), 0.82004651162790698),
#  ((0.01, 2, False, 'squared_hinge'), 0.82000581395348837),
#  ((0.3, 0.1, False, 'squared_hinge'), 0.81996511627906976),
#  ((0.4, 0.4, False, 'squared_hinge'), 0.81992441860465104),
#  ((0.07, 3, True, 'hinge'), 0.81988372093023254),
#  ((0.35, 3, False, 'squared_hinge'), 0.81967441860465118),
#  ((0.1, 0.5, True, 'hinge'), 0.81962790697674426),
#  ((0.08, 0.5, True, 'hinge'), 0.81962209302325584),
#  ((0.08, 0.1, True, 'hinge'), 0.81954069767441862),
#  ((0.4, 1, False, 'squared_hinge'), 0.81917441860465112),
#  ((0.4, 0.5, False, 'squared_hinge'), 0.81917441860465112),
#  ((0.1, 0.2, True, 'hinge'), 0.81913953488372082),
#  ((0.05, 0.4, True, 'hinge'), 0.81913372093023251),
#  ((0.45, 0.4, False, 'squared_hinge'), 0.81913372093023251),
#  ((0.45, 1, True, 'squared_hinge'), 0.81909302325581401),
#  ((0.01, 0.4, False, 'squared_hinge'), 0.81900581395348837),
#  ((0.01, 0.2, False, 'squared_hinge'), 0.81900581395348837),
#  ((0.01, 1, False, 'squared_hinge'), 0.81900581395348837),
#  ((0.01, 0.4, True, 'squared_hinge'), 0.81900581395348837),
#  ((0.01, 4, True, 'squared_hinge'), 0.81900581395348837),
#  ((0.01, 0.1, False, 'squared_hinge'), 0.81900581395348837),
#  ((0.35, 4, False, 'squared_hinge'), 0.81892441860465115),
#  ((0.5, 0.2, True, 'squared_hinge'), 0.81891860465116295),
#  ((0.45, 3, False, 'squared_hinge'), 0.81888372093023265),
#  ((0.45, 0.1, False, 'squared_hinge'), 0.81888372093023265),
#  ((0.45, 0.2, True, 'hinge'), 0.81880232558139521),
#  ((0.01, 4, False, 'squared_hinge'), 0.81875581395348829),
#  ((0.01, 3, False, 'squared_hinge'), 0.81875581395348829),
#  ((0.01, 0.5, False, 'squared_hinge'), 0.81871511627906979),
#  ((0.01, 0.2, True, 'squared_hinge'), 0.81871511627906979),
#  ((0.01, 2, True, 'squared_hinge'), 0.81871511627906979),
#  ((0.35, 0.5, False, 'squared_hinge'), 0.81867441860465129),
#  ((0.35, 0.2, False, 'squared_hinge'), 0.81867441860465107),
#  ((0.4, 0.2, False, 'squared_hinge'), 0.81867441860465107),
#  ((0.35, 1, False, 'squared_hinge'), 0.81867441860465107),
#  ((0.35, 2, False, 'squared_hinge'), 0.81867441860465107),
#  ((0.35, 0.4, False, 'squared_hinge'), 0.81867441860465107),
#  ((0.4, 4, False, 'squared_hinge'), 0.81867441860465107),
#  ((0.05, 3, True, 'hinge'), 0.81863372093023246),
#  ((0.02, 2, True, 'squared_hinge'), 0.81859302325581385),
#  ((0.5, 2, False, 'squared_hinge'), 0.81859302325581385),
#  ((0.4, 3, False, 'squared_hinge'), 0.81842441860465109),
#  ((0.35, 0.1, False, 'squared_hinge'), 0.81842441860465109),
#  ((0.05, 2, True, 'hinge'), 0.81830232558139537),
#  ((0.07, 0.2, True, 'hinge'), 0.81827325581395338),
#  ((0.01, 0.5, True, 'squared_hinge'), 0.81800581395348837),
#  ((0.3, 3, True, 'squared_hinge'), 0.81800581395348826),
#  ((0.25, 0.1, True, 'hinge'), 0.81797093023255807),
#  ((0.45, 1, False, 'squared_hinge'), 0.81788372093023265),
#  ((0.3, 0.4, True, 'squared_hinge'), 0.81771511627906968),
#  ((0.4, 2, True, 'hinge'), 0.81765116279069761),
#  ((0.08, 2, True, 'squared_hinge'), 0.81751744186046515),
#  ((0.25, 0.4, True, 'hinge'), 0.81751744186046515),
#  ((0.01, 0.1, True, 'squared_hinge'), 0.81746511627906993),
#  ((0.4, 2, False, 'squared_hinge'), 0.81742441860465109),
#  ((0.07, 0.2, True, 'squared_hinge'), 0.81742441860465109),
#  ((0.45, 2, False, 'squared_hinge'), 0.81738372093023259),
#  ((0.5, 0.4, False, 'squared_hinge'), 0.81738372093023237),
#  ((0.5, 3, False, 'squared_hinge'), 0.81734302325581398),
#  ((0.3, 2, True, 'squared_hinge'), 0.81718023255813965),
#  ((0.01, 1, True, 'squared_hinge'), 0.81700581395348837),
#  ((0.45, 0.1, True, 'squared_hinge'), 0.81687790697674423),
#  ((0.08, 4, True, 'squared_hinge'), 0.81680813953488351),
#  ((0.45, 0.2, False, 'squared_hinge'), 0.81663372093023268),
#  ((0.45, 4, False, 'squared_hinge'), 0.81638372093023259),
#  ((0.45, 0.5, False, 'squared_hinge'), 0.81638372093023259),
#  ((0.25, 0.2, True, 'squared_hinge'), 0.81609883720930232),
#  ((0.5, 0.2, False, 'squared_hinge'), 0.81609302325581401),
#  ((0.25, 3, True, 'squared_hinge'), 0.81609302325581401),
#  ((0.5, 0.1, False, 'squared_hinge'), 0.81609302325581401),
#  ((0.45, 4, True, 'squared_hinge'), 0.8160116279069769),
#  ((0.1, 3, True, 'squared_hinge'), 0.81593604651162788),
#  ((0.35, 2, True, 'squared_hinge'), 0.81591860465116284),
#  ((0.15, 0.5, True, 'squared_hinge'), 0.81585465116279077),
#  ((0.5, 1, False, 'squared_hinge'), 0.81584302325581393),
#  ((0.5, 4, False, 'squared_hinge'), 0.81584302325581393),
#  ((0.5, 0.5, False, 'squared_hinge'), 0.81559302325581395),
#  ((0.05, 0.5, True, 'hinge'), 0.81559302325581373),
#  ((0.1, 0.4, True, 'squared_hinge'), 0.81519186046511616),
#  ((0.4, 3, True, 'squared_hinge'), 0.81518604651162785),
#  ((0.15, 0.4, True, 'squared_hinge'), 0.81518023255813965),
#  ((0.35, 0.5, True, 'squared_hinge'), 0.81516279069767439),
#  ((0.4, 0.2, True, 'hinge'), 0.8150930232558139),
#  ((0.45, 0.5, True, 'squared_hinge'), 0.81494186046511641),
#  ((0.5, 3, True, 'hinge'), 0.81488953488372096),
#  ((0.4, 0.2, True, 'squared_hinge'), 0.81451162790697662),
#  ((0.25, 0.2, True, 'hinge'), 0.81359883720930237),
#  ((0.1, 0.2, True, 'squared_hinge'), 0.81352325581395346),
#  ((0.4, 1, True, 'squared_hinge'), 0.81292441860465114),
#  ((0.2, 0.1, True, 'squared_hinge'), 0.81263372093023256),
#  ((0.1, 4, True, 'hinge'), 0.8125058139534882),
#  ((0.15, 2, True, 'hinge'), 0.81247093023255812),
#  ((0.5, 2, True, 'squared_hinge'), 0.81226744186046496),
#  ((0.05, 4, True, 'squared_hinge'), 0.81213953488372093),
#  ((0.2, 0.1, True, 'hinge'), 0.81143023255813951),
#  ((0.45, 4, True, 'hinge'), 0.81091860465116272),
#  ((0.1, 0.1, True, 'hinge'), 0.81080813953488362),
#  ((0.15, 0.2, True, 'hinge'), 0.81065116279069771),
#  ((0.2, 0.2, True, 'hinge'), 0.8103895348837209),
#  ((0.09, 0.4, True, 'hinge'), 0.81018023255813953),
#  ((0.45, 0.4, True, 'squared_hinge'), 0.80966860465116286),
#  ((0.15, 3, True, 'squared_hinge'), 0.80943604651162793),
#  ((0.02, 2, True, 'hinge'), 0.809093023255814),
#  ((0.4, 0.1, True, 'squared_hinge'), 0.80899999999999994),
#  ((0.09, 0.2, True, 'hinge'), 0.80878488372093016),
#  ((0.02, 3, True, 'hinge'), 0.807093023255814),
#  ((0.02, 1, True, 'hinge'), 0.80634302325581397),
#  ((0.3, 0.5, True, 'squared_hinge'), 0.80634302325581397),
#  ((0.02, 4, True, 'hinge'), 0.80630232558139525),
#  ((0.1, 1, True, 'squared_hinge'), 0.80619186046511615),
#  ((0.3, 4, True, 'squared_hinge'), 0.80609302325581389),
#  ((0.02, 0.2, True, 'hinge'), 0.8060523255813955),
#  ((0.02, 0.1, True, 'hinge'), 0.80559302325581394),
#  ((0.02, 0.5, True, 'hinge'), 0.80526162790697664),
#  ((0.15, 3, True, 'hinge'), 0.80510465116279062),
#  ((0.45, 2, True, 'squared_hinge'), 0.80509883720930231),
#  ((0.25, 1, True, 'squared_hinge'), 0.80492441860465114),
#  ((0.15, 0.2, True, 'squared_hinge'), 0.80388372093023253),
#  ((0.02, 0.4, True, 'hinge'), 0.80330232558139536),
#  ((0.15, 4, True, 'squared_hinge'), 0.80287790697674422),
#  ((0.35, 0.1, True, 'squared_hinge'), 0.8022034883720931),
#  ((0.05, 1, True, 'squared_hinge'), 0.80201744186046509),
#  ((0.35, 0.2, True, 'squared_hinge'), 0.80200581395348836),
#  ((0.5, 4, True, 'hinge'), 0.80184883720930222),
#  ((0.4, 4, True, 'hinge'), 0.80184883720930222),
#  ((0.4, 1, True, 'hinge'), 0.80172093023255808),
#  ((0.45, 3, True, 'hinge'), 0.80155232558139533),
#  ((0.15, 0.5, True, 'hinge'), 0.80107558139534873),
#  ((0.25, 3, True, 'hinge'), 0.80106976744186054),
#  ((0.3, 0.2, True, 'squared_hinge'), 0.80062790697674413),
#  ((0.5, 0.1, True, 'squared_hinge'), 0.79964534883720917),
#  ((0.3, 1, True, 'squared_hinge'), 0.79963372093023255),
#  ((0.2, 4, True, 'squared_hinge'), 0.79931395348837209),
#  ((0.15, 4, True, 'hinge'), 0.79861046511627909),
#  ((0.01, 1, True, 'hinge'), 0.79759883720930236),
#  ((0.2, 1, True, 'hinge'), 0.797389534883721),
#  ((0.25, 0.5, True, 'squared_hinge'), 0.79625581395348832),
#  ((0.01, 4, True, 'hinge'), 0.79526744186046516),
#  ((0.01, 2, True, 'hinge'), 0.79513953488372091),
#  ((0.15, 2, True, 'squared_hinge'), 0.79477325581395342),
#  ((0.3, 0.1, True, 'hinge'), 0.79459883720930224),
#  ((0.4, 0.4, True, 'hinge'), 0.79393023255813955),
#  ((0.5, 0.4, True, 'hinge'), 0.79393023255813955),
#  ((0.35, 0.4, True, 'hinge'), 0.79393023255813955),
#  ((0.3, 0.4, True, 'hinge'), 0.79393023255813955),
#  ((0.01, 0.4, True, 'hinge'), 0.79376744186046522),
#  ((0.01, 0.1, True, 'hinge'), 0.79338953488372099),
#  ((0.5, 3, True, 'squared_hinge'), 0.79194186046511628),
#  ((0.01, 0.5, True, 'hinge'), 0.79180813953488383),
#  ((0.01, 3, True, 'hinge'), 0.79163953488372096),
#  ((0.01, 0.2, True, 'hinge'), 0.79130813953488377),
#  ((0.3, 2, True, 'hinge'), 0.79125000000000001),
#  ((0.45, 2, True, 'hinge'), 0.79125000000000001),
#  ((0.2, 0.4, True, 'squared_hinge'), 0.79096511627906985),
#  ((0.5, 0.4, True, 'squared_hinge'), 0.79088953488372093),
#  ((0.15, 0.4, True, 'hinge'), 0.7906918604651163),
#  ((0.3, 1, True, 'hinge'), 0.7892093023255814),
#  ((0.35, 0.5, True, 'hinge'), 0.7884302325581396),
#  ((0.45, 0.5, True, 'hinge'), 0.7884302325581396),
#  ((0.3, 0.5, True, 'hinge'), 0.7884302325581396),
#  ((0.4, 0.5, True, 'hinge'), 0.7884302325581396),
#  ((0.2, 2, True, 'squared_hinge'), 0.78834302325581407),
#  ((0.08, 1, True, 'squared_hinge'), 0.78798255813953477),
#  ((0.45, 0.2, True, 'squared_hinge'), 0.78733139534883723),
#  ((0.25, 0.5, True, 'hinge'), 0.78687209302325578),
#  ((0.45, 0.4, True, 'hinge'), 0.78615116279069763),
#  ((0.1, 0.1, True, 'squared_hinge'), 0.78423837209302327),
#  ((0.3, 4, True, 'hinge'), 0.78358720930232562),
#  ((0.09, 3, True, 'squared_hinge'), 0.78216860465116278),
#  ((0.35, 1, True, 'hinge'), 0.78156395348837204),
#  ((0.45, 1, True, 'hinge'), 0.78156395348837204),
#  ((0.5, 1, True, 'hinge'), 0.78156395348837204),
#  ((0.35, 4, True, 'squared_hinge'), 0.78026744186046515),
#  ((0.2, 1, True, 'squared_hinge'), 0.77671511627906986),
#  ((0.25, 2, True, 'squared_hinge'), 0.77193023255813953),
#  ((0.3, 0.1, True, 'squared_hinge'), 0.76647674418604661),
#  ((0.35, 3, True, 'hinge'), 0.76644767441860462),
#  ((0.5, 2, True, 'hinge'), 0.76254069767441857),
#  ((0.2, 0.4, True, 'hinge'), 0.75859883720930232),
#  ((0.25, 2, True, 'hinge'), 0.74920930232558136),
#  ((0.2, 4, True, 'hinge'), 0.71995930232558147),
#  ((0.35, 2, True, 'hinge'), 0.71398255813953493)]

# %%
# New stuff for ICLR
# 1.  Chamfer
# encoder_args: {'filter_sizes': [1, 1, 1, 1, 1], 'strides': [1, 1, 1, 1, 1], 'n_filters': [64, 128, 128, 256, 512], 'dropout_prob': [0, 0, 0, 0, 0.5], 'b_norm': True}
# decoder_args: {'b_norm': True, 'layer_sizes': [512, 1024, 6144]}
# -> @ 980 epochs of training: best was on model-net40:
# 0.6 1 True hinge
# 0.840083537332
# -> @ 1620 epochs of training: best was on model-net40:
# 0.4 1 False squared_hinge
# 0.843783353733
# at @ 2000 epochs of training: best was on model-net40:
# (0.3, 0.2, False, 'squared_hinge'), 0.84087423500612002)


# FROM NIPS
# USING ALL ShapeNetCore DATA : ~57K models.
# Training at (max) 2K epochs.

# EMD, 2K, model_net_40
# 1.0 3 False squared_hinge
# 0.844814259486
# 1.0 3 True squared_hinge
# 0.844814259486

# EMD, 2K, model_net_10
# 0.4 2 True hinge
# 0.953279069767


# Chamfer, 2K model_net_40
# 0.3 4 False squared_hinge
# 0.856074051408
# 0.3 4 True squared_hinge
# 0.856074051408
# 0.6 1 False squared_hinge
# 0.856264075887
# 0.3 4 False squared_hinge
# 0.856074051408
# 0.6 1 False squared_hinge
# 0.856264075887
# 0.6 1 True squared_hinge
# 0.856264075887
# 0.7 1 False squared_hinge
# 0.856764075887

# Chamfer, 2K model_net_10
# 0.9 4 True hinge
# 0.950790697674
# 0.950790697674
# 0.8 0.5 False squared_hinge

# 1.0 4 True hinge
# 0.950790697674
# 1.0 3 True hinge
# 0.950790697674
# 0.9 4 True hinge
# 0.950790697674

# 0.7 4 True hinge
# 0.950790697674


# With WU 7 Classes:

# M10, CD, 2K epochs
# 0.4 4 True hinge
# 0.95176744186

# M40, CD, 2K epochs
# 1.0 1 True hinge
# 0.84410495716

# M10, EMD, ~2.5K epochs
# about 0.94

# M40, EMD, ~2.5K epochs
# about 0.83

# %%
# all_flower_pots = test_feed[np.array(cids_) == 15]
# for i in range(len(all_flower_pots)):
#     Point_Cloud(all_flower_pots[i]).plot()
    
# y_pred = lsvc.predict(test_latent)
# gt_labels = np.array(cids_)

# scores_per_class = []

# for c in np.unique(gt_labels):
#     if c == 15:
#         scores_per_class.append(0.5)    
#         continue
#     index_c = gt_labels == c
#     n_class = float(np.sum(index_c))
#     s = np.sum(gt_labels[index_c] == y_pred[index_c])
#     s /= n_class
#     scores_per_class.append(s)
# print np.mean(scores_per_class)
