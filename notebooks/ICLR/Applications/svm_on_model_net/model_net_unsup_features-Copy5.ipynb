# %%
from general_tools.notebook import gpu_utils
GPU = 2
gpu_utils.setup_one_gpu(GPU)
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.WARN)
# Out:
# Picking GPU 2

# %%
import sys
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio

from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf

from tf_lab.in_out.basics import read_saved_epochs
                                                  
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.data_sets.model_net import pc_loader, classes_to_integers
from tf_lab.nips.helper import average_per_class, pclouds_with_zero_mean_in_unit_sphere

from sklearn.svm import LinearSVC
from general_tools.simpletons import sort_dict_by_key, sort_dict_by_val

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
put_in_usphere = True
model_net = '10'
loss = 'emd'

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/all_snc/'
experiment_name = 'no_conv_deeper_snc_rotated2048pts_' + loss

# %%
train_dir = osp.join(top_data_dir, experiment_name)
conf = Conf.load(osp.join(train_dir, 'configuration'))

if conf.train_dir != train_dir: # added to address moving training-folder to other location
    conf.train_dir = train_dir
    conf.save(osp.join(conf.train_dir, 'configuration'))

print conf
conf.n_output = conf.n_input
conf.allow_gpu_growth = True
# Out:
#               allow_gpu_growth: False
#                     batch_size: 50
#                  consistent_io: None
#                          debug: False
#                        decoder: decoder_with_fc_only
#                   decoder_args: {'b_norm': True, 'layer_sizes': [1024, 2048, 6144]}
#                        encoder: encoder_with_convs_and_symmetry_new
#                   encoder_args: {'filter_sizes': [1, 1, 1, 1], 'n_filters': [128, 128, 256, 512], 'b_norm': True, 'strides': [1, 1, 1, 1]}
#                experiment_name: no_conv_deeper_snc_rotated2048pts_emd
#                  gauss_augment: None
#                   is_denoising: False
#                latent_vs_recon: 1.0
#                  learning_rate: 0.0005
#                           loss: emd
#              loss_display_step: 1
#                        n_input: [2048, 3]
#                       n_output: [2048, 3]
#                            n_z: None
#              saver_max_to_keep: None
#                     saver_step: 10
#                      train_dir: /orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_emd
#                training_epochs: 2000
#                       z_rotate: True

# %%
reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)
saved_epochs = read_saved_epochs(conf.train_dir)
last_epoch = saved_epochs[-1]
last_epoch = 1100
ae.restore_model(conf.train_dir, last_epoch, verbose=True)
# Out:
# Model restored in epoch 1100.

# %%
model_net_dir = '/orions4-zfs/projects/optas/DATA/Point_Clouds/Model_Net_' + model_net + '/from_manifold/'
model_net_dir = osp.join(model_net_dir, str(n_pc_samples))

search_pattern = '(.*)train(.*)\.ply$'
train_pc_files = sorted([f for f in files_in_subdirs(model_net_dir, search_pattern)])

search_pattern = '(.*)test(.*)\.ply$'
test_pc_files = sorted([f for f in files_in_subdirs(model_net_dir, search_pattern)])

# %%
verbose = True
n_threads = 22

pc, model_names, labels = load_point_clouds_from_filenames(train_pc_files, n_threads, pc_loader, verbose)

if put_in_usphere:
    pc = pclouds_with_zero_mean_in_unit_sphere(pc)

train_data = PointCloudDataSet(pc, labels=labels, init_shuffle=False)

pc_, model_names_, labels_ = load_point_clouds_from_filenames(test_pc_files, n_threads, pc_loader, verbose)

if put_in_usphere:
    pc_ = pclouds_with_zero_mean_in_unit_sphere(pc_)

test_data = PointCloudDataSet(pc_, labels=labels_, init_shuffle=False)
# Out:
# 3991 pclouds were loaded. They belong in 10 shape-classes.
# 908 pclouds were loaded. They belong in 10 shape-classes.

# %%
train_feed, train_latent, train_classes = ae.embedding_at_tensor(train_data, conf, tensor_name='bottleneck')
cids = classes_to_integers(int(model_net), train_classes)[1]

test_feed, test_latent, test_classes = ae.embedding_at_tensor(test_data, conf, tensor_name='bottleneck')
cids_ = classes_to_integers(int(model_net), test_classes)[1]

# %%
opt_params_for_m40_chamfer = [0.25, 0.4, False, 'squared_hinge']

# %%
all_random_states = dict()
all_scores = dict()

intercept_scaling_space = [0.1, 0.2, 0.4, 0.5, 1, 2, 3, 4]

c_space = [0.01, 0.02, 0.05, 0.07, 0.08, 0.09,
           0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 
           0.45, 0.50]

dual_space = [False, True]

loss_space = ['hinge', 'squared_hinge']

# %%
for c in c_space:
    for intercept in intercept_scaling_space:
        for dual in dual_space:
            for loss in loss_space:
                try:
                    rs = np.random.get_state()
                    lsvc = LinearSVC(C=c, loss=loss, intercept_scaling=intercept, dual=dual, random_state=42)
                    lsvc.fit(train_latent, cids)
                    
                    print c, intercept, dual, loss
                    score = average_per_class(lsvc, test_latent, cids_)

                    print score
                    key = (c, intercept, dual, loss)
                    all_scores[key] = score
                    all_random_states[key] = rs
                except:
                    continue
# Out:
# 0.01 0.1 False squared_hinge
# 0.94911627907
# 0.01 0.1 True hinge
# 0.947441860465
# 0.01 0.1 True squared_hinge
# 0.94911627907
# 0.01 0.2 False squared_hinge
# 0.94911627907
# 0.01 0.2 True hinge
# 0.945279069767
# 0.01 0.2 True squared_hinge
# 0.94911627907
# 0.01 0.4 False squared_hinge
# 0.94911627907
# 0.01 0.4 True hinge
# 0.946441860465
# 0.01 0.4 True squared_hinge
# 0.94911627907
# 0.01 0.5 False squared_hinge
# 0.94911627907
# 0.01 0.5 True hinge
# 0.946279069767
# 0.01 0.5 True squared_hinge
# 0.94911627907
# 0.01 1 False squared_hinge
# 0.94911627907
# 0.01 1 True hinge
# 0.947441860465
# 0.01 1 True squared_hinge
# 0.94911627907
# 0.01 2 False squared_hinge
# 0.94911627907
# 0.01 2 True hinge
# 0.947441860465
# 0.01 2 True squared_hinge
# 0.94911627907
# 0.01 3 False squared_hinge
# 0.94911627907
# 0.01 3 True hinge
# 0.947441860465
# 0.01 3 True squared_hinge
# 0.94911627907
# 0.01 4 False squared_hinge
# 0.94911627907
# 0.01 4 True hinge
# 0.946279069767
# 0.01 4 True squared_hinge
# 0.94911627907
# 0.02 0.1 False squared_hinge
# 0.954604651163
# 0.02 0.1 True hinge
# 0.950604651163
# 0.02 0.1 True squared_hinge
# 0.954604651163
# 0.02 0.2 False squared_hinge
# 0.954604651163
# 0.02 0.2 True hinge
# 0.950604651163
# 0.02 0.2 True squared_hinge
# 0.954604651163
# 0.02 0.4 False squared_hinge
# 0.954604651163
# 0.02 0.4 True hinge
# 0.950604651163
# 0.02 0.4 True squared_hinge
# 0.950441860465
# 0.02 0.5 False squared_hinge
# 0.954604651163
# 0.02 0.5 True hinge
# 0.949604651163
# 0.02 0.5 True squared_hinge
# 0.952279069767
# 0.02 1 False squared_hinge
# 0.954604651163
# 0.02 1 True hinge
# 0.95076744186
# 0.02 1 True squared_hinge
# 0.952441860465
# 0.02 2 False squared_hinge
# 0.954604651163
# 0.02 2 True hinge
# 0.95276744186
# 0.02 2 True squared_hinge
# 0.953441860465
# 0.02 3 False squared_hinge
# 0.954604651163
# 0.02 3 True hinge
# 0.94976744186
# 0.02 3 True squared_hinge
# 0.951441860465
# 0.02 4 False squared_hinge
# 0.954604651163
# 0.02 4 True hinge
# 0.95276744186
# 0.02 4 True squared_hinge
# 0.953441860465
# 0.05 0.1 False squared_hinge
# 0.953604651163
# 0.05 0.1 True hinge
# 0.945465116279
# 0.05 0.1 True squared_hinge
# 0.953604651163
# 0.05 0.2 False squared_hinge
# 0.952441860465
# 0.05 0.2 True hinge
# 0.941139534884
# 0.05 0.2 True squared_hinge
# 0.946627906977
# 0.05 0.4 False squared_hinge
# 0.953604651163
# 0.05 0.4 True hinge
# 0.952604651163
# 0.05 0.4 True squared_hinge
# 0.933837209302
# 0.05 0.5 False squared_hinge
# 0.953604651163
# 0.05 0.5 True hinge
# 0.94811627907
# 0.05 0.5 True squared_hinge
# 0.953604651163
# 0.05 1 False squared_hinge
# 0.953604651163
# 0.05 1 True hinge
# 0.951441860465
# 0.05 1 True squared_hinge
# 0.939651162791
# 0.05 2 False squared_hinge
# 0.953604651163
# 0.05 2 True hinge
# 0.94911627907
# 0.05 2 True squared_hinge
# 0.951441860465
# 0.05 3 False squared_hinge
# 0.953604651163
# 0.05 3 True hinge
# 0.953279069767
# 0.05 3 True squared_hinge
# 0.952441860465
# 0.05 4 False squared_hinge
# 0.953604651163
# 0.05 4 True hinge
# 0.951604651163
# 0.05 4 True squared_hinge
# 0.95476744186
# 0.07 0.1 False squared_hinge
# 0.95011627907
# 0.07 0.1 True hinge
# 0.951604651163
# 0.07 0.1 True squared_hinge
# 0.95476744186
# 0.07 0.2 False squared_hinge
# 0.95011627907
# 0.07 0.2 True hinge
# 0.94611627907
# 0.07 0.2 True squared_hinge
# 0.953604651163
# 0.07 0.4 False squared_hinge
# 0.95011627907
# 0.07 0.4 True hinge
# 0.952604651163
# 0.07 0.4 True squared_hinge
# 0.941976744186
# 0.07 0.5 False squared_hinge
# 0.95011627907
# 0.07 0.5 True hinge
# 0.95176744186
# 0.07 0.5 True squared_hinge
# 0.954604651163
# 0.07 1 False squared_hinge
# 0.95011627907
# 0.07 1 True hinge
# 0.951604651163
# 0.07 1 True squared_hinge
# 0.941976744186
# 0.07 2 False squared_hinge
# 0.95011627907
# 0.07 2 True hinge
# 0.946953488372
# 0.07 2 True squared_hinge
# 0.953279069767
# 0.07 3 False squared_hinge
# 0.95011627907
# 0.07 3 True hinge
# 0.947627906977
# 0.07 3 True squared_hinge
# 0.953604651163
# 0.07 4 False squared_hinge
# 0.95011627907
# 0.07 4 True hinge
# 0.95011627907
# 0.07 4 True squared_hinge
# 0.937488372093
# 0.08 0.1 False squared_hinge
# 0.95011627907
# 0.08 0.1 True hinge
# 0.948279069767
# 0.08 0.1 True squared_hinge
# 0.953604651163
# 0.08 0.2 False squared_hinge
# 0.95011627907
# 0.08 0.2 True hinge
# 0.944139534884
# 0.08 0.2 True squared_hinge
# 0.955930232558
# 0.08 0.4 False squared_hinge
# 0.95011627907
# 0.08 0.4 True hinge
# 0.957093023256
# 0.08 0.4 True squared_hinge
# 0.952604651163
# 0.08 0.5 False squared_hinge
# 0.95011627907
# 0.08 0.5 True hinge
# 0.953604651163
# 0.08 0.5 True squared_hinge
# 0.94611627907
# 0.08 1 False squared_hinge
# 0.95011627907
# 0.08 1 True hinge
# 0.942465116279
# 0.08 1 True squared_hinge
# 0.954930232558
# 0.08 2 False squared_hinge
# 0.95011627907
# 0.08 2 True hinge
# 0.943953488372
# 0.08 2 True squared_hinge
# 0.937488372093
# 0.08 3 False squared_hinge
# 0.95011627907
# 0.08 3 True hinge
# 0.944953488372
# 0.08 3 True squared_hinge
# 0.944790697674
# 0.08 4 False squared_hinge
# 0.948953488372
# 0.08 4 True hinge
# 0.95111627907
# 0.08 4 True squared_hinge
# 0.948953488372
# 0.09 0.1 False squared_hinge
# 0.946627906977
# 0.09 0.1 True hinge
# 0.938302325581
# 0.09 0.1 True squared_hinge
# 0.954604651163
# 0.09 0.2 False squared_hinge
# 0.947790697674
# 0.09 0.2 True hinge
# 0.950953488372
# 0.09 0.2 True squared_hinge
# 0.953604651163
# 0.09 0.4 False squared_hinge
# 0.946627906977
# 0.09 0.4 True hinge
# 0.951279069767
# 0.09 0.4 True squared_hinge
# 0.940813953488
# 0.09 0.5 False squared_hinge
# 0.946627906977
# 0.09 0.5 True hinge
# 0.953930232558
# 0.09 0.5 True squared_hinge
# 0.933837209302
# 0.09 1 False squared_hinge
# 0.946627906977
# 0.09 1 True hinge
# 0.944465116279
# 0.09 1 True squared_hinge
# 0.957093023256
# 0.09 2 False squared_hinge
# 0.946627906977
# 0.09 2 True hinge
# 0.940976744186
# 0.09 2 True squared_hinge
# 0.938651162791
# 0.09 3 False squared_hinge
# 0.946627906977
# 0.09 3 True hinge
# 0.951279069767
# 0.09 3 True squared_hinge
# 0.932837209302
# 0.09 4 False squared_hinge
# 0.946627906977
# 0.09 4 True hinge
# 0.933813953488
# 0.09 4 True squared_hinge
# 0.952441860465
# 0.1 0.1 False squared_hinge
# 0.945465116279
# 0.1 0.1 True hinge
# 0.952930232558
# 0.1 0.1 True squared_hinge
# 0.950279069767
# 0.1 0.2 False squared_hinge
# 0.945465116279
# 0.1 0.2 True hinge
# 0.933837209302
# 0.1 0.2 True squared_hinge
# 0.952604651163
# 0.1 0.4 False squared_hinge
# 0.945465116279
# 0.1 0.4 True hinge
# 0.943139534884
# 0.1 0.4 True squared_hinge
# 0.933
# 0.1 0.5 False squared_hinge
# 0.945465116279
# 0.1 0.5 True hinge
# 0.944627906977
# 0.1 0.5 True squared_hinge
# 0.945302325581
# 0.1 1 False squared_hinge
# 0.946627906977
# 0.1 1 True hinge
# 0.935837209302
# 0.1 1 True squared_hinge
# 0.946465116279
# 0.1 2 False squared_hinge
# 0.945465116279
# 0.1 2 True hinge
# 0.944627906977
# 0.1 2 True squared_hinge
# 0.930511627907
# 0.1 3 False squared_hinge
# 0.945465116279
# 0.1 3 True hinge
# 0.944139534884
# 0.1 3 True squared_hinge
# 0.939813953488
# 0.1 4 False squared_hinge
# 0.945465116279
# 0.1 4 True hinge
# 0.926860465116
# 0.1 4 True squared_hinge
# 0.933837209302
# 0.15 0.1 False squared_hinge
# 0.941976744186
# 0.15 0.1 True hinge
# 0.959093023256
# 0.15 0.1 True squared_hinge
# 0.935
# 0.15 0.2 False squared_hinge
# 0.943139534884
# 0.15 0.2 True hinge
# 0.932837209302
# 0.15 0.2 True squared_hinge
# 0.926348837209
# 0.15 0.4 False squared_hinge
# 0.941976744186
# 0.15 0.4 True hinge
# 0.947790697674
# 0.15 0.4 True squared_hinge
# 0.944627906977
# 0.15 0.5 False squared_hinge
# 0.944302325581
# 0.15 0.5 True hinge
# 0.942651162791
# 0.15 0.5 True squared_hinge
# 0.936651162791
# 0.15 1 False squared_hinge
# 0.941976744186
# 0.15 1 True hinge
# 0.943139534884
# 0.15 1 True squared_hinge
# 0.95011627907
# 0.15 2 False squared_hinge
# 0.943139534884
# 0.15 2 True hinge
# 0.91788372093
# 0.15 2 True squared_hinge
# 0.939651162791
# 0.15 3 False squared_hinge
# 0.943139534884
# 0.15 3 True hinge
# 0.947790697674
# 0.15 3 True squared_hinge
# 0.934837209302
# 0.15 4 False squared_hinge
# 0.941976744186
# 0.15 4 True hinge
# 0.918046511628
# 0.15 4 True squared_hinge
# 0.945790697674
# 0.2 0.1 False squared_hinge
# 0.943139534884
# 0.2 0.1 True hinge
# 0.928023255814
# 0.2 0.1 True squared_hinge
# 0.95676744186
# 0.2 0.2 False squared_hinge
# 0.939976744186
# 0.2 0.2 True hinge
# 0.948953488372
# 0.2 0.2 True squared_hinge
# 0.924534883721
# 0.2 0.4 False squared_hinge
# 0.939976744186
# 0.2 0.4 True hinge
# 0.955930232558
# 0.2 0.4 True squared_hinge
# 0.934488372093
# 0.2 0.5 False squared_hinge
# 0.941976744186
# 0.2 0.5 True hinge
# 0.945953488372
# 0.2 0.5 True squared_hinge
# 0.945302325581
# 0.2 1 False squared_hinge
# 0.939976744186
# 0.2 1 True hinge
# 0.931511627907
# 0.2 1 True squared_hinge
# 0.946953488372
# 0.2 2 False squared_hinge
# 0.941139534884
# 0.2 2 True hinge
# 0.943139534884
# 0.2 2 True squared_hinge
# 0.952441860465
# 0.2 3 False squared_hinge
# 0.939976744186
# 0.2 3 True hinge
# 0.944302325581
# 0.2 3 True squared_hinge
# 0.95376744186
# 0.2 4 False squared_hinge
# 0.941139534884
# 0.2 4 True hinge
# 0.953604651163
# 0.2 4 True squared_hinge
# 0.941813953488
# 0.25 0.1 False squared_hinge
# 0.940976744186
# 0.25 0.1 True hinge
# 0.934976744186
# 0.25 0.1 True squared_hinge
# 0.932488372093
# 0.25 0.2 False squared_hinge
# 0.940976744186
# 0.25 0.2 True hinge
# 0.948790697674
# 0.25 0.2 True squared_hinge
# 0.941976744186
# 0.25 0.4 False squared_hinge
# 0.939976744186
# 0.25 0.4 True hinge
# 0.940976744186
# 0.25 0.4 True squared_hinge
# 0.947790697674
# 0.25 0.5 False squared_hinge
# 0.942139534884
# 0.25 0.5 True hinge
# 0.933837209302
# 0.25 0.5 True squared_hinge
# 0.947302325581
# 0.25 1 False squared_hinge
# 0.942139534884
# 0.25 1 True hinge
# 0.917558139535
# 0.25 1 True squared_hinge
# 0.943465116279
# 0.25 2 False squared_hinge
# 0.942139534884
# 0.25 2 True hinge
# 0.938651162791
# 0.25 2 True squared_hinge
# 0.940325581395
# 0.25 3 False squared_hinge
# 0.942139534884
# 0.25 3 True hinge
# 0.936976744186
# 0.25 3 True squared_hinge
# 0.941651162791
# 0.25 4 False squared_hinge
# 0.942139534884
# 0.25 4 True hinge
# 0.952441860465
# 0.25 4 True squared_hinge
# 0.938488372093
# 0.3 0.1 False squared_hinge
# 0.941139534884
# 0.3 0.1 True hinge
# 0.929186046512
# 0.3 0.1 True squared_hinge
# 0.952441860465
# 0.3 0.2 False squared_hinge
# 0.941139534884
# 0.3 0.2 True hinge
# 0.934488372093
# 0.3 0.2 True squared_hinge
# 0.941813953488
# 0.3 0.4 False squared_hinge
# 0.939976744186
# 0.3 0.4 True hinge
# 0.95076744186
# 0.3 0.4 True squared_hinge
# 0.937651162791
# 0.3 0.5 False squared_hinge
# 0.941139534884
# 0.3 0.5 True hinge
# 0.923511627907
# 0.3 0.5 True squared_hinge
# 0.928837209302
# 0.3 1 False squared_hinge
# 0.940976744186
# 0.3 1 True hinge
# 0.922372093023
# 0.3 1 True squared_hinge
# 0.940813953488
# 0.3 2 False squared_hinge
# 0.939976744186
# 0.3 2 True hinge
# 0.940651162791
# 0.3 2 True squared_hinge
# 0.946627906977
# 0.3 3 False squared_hinge
# 0.939976744186
# 0.3 3 True hinge
# 0.95276744186
# 0.3 3 True squared_hinge
# 0.953604651163
# 0.3 4 False squared_hinge
# 0.939976744186
# 0.3 4 True hinge
# 0.887302325581
# 0.3 4 True squared_hinge
# 0.939302325581
# 0.35 0.1 False squared_hinge
# 0.939976744186
# 0.35 0.1 True hinge
# 0.943627906977
# 0.35 0.1 True squared_hinge
# 0.939976744186
# 0.35 0.2 False squared_hinge
# 0.941139534884
# 0.35 0.2 True hinge
# 0.949279069767
# 0.35 0.2 True squared_hinge
# 0.95376744186
# 0.35 0.4 False squared_hinge
# 0.939976744186
# 0.35 0.4 True hinge
# 0.928348837209
# 0.35 0.4 True squared_hinge
# 0.918720930233
# 0.35 0.5 False squared_hinge
# 0.941139534884
# 0.35 0.5 True hinge
# 0.934162790698
# 0.35 0.5 True squared_hinge
# 0.954604651163
# 0.35 1 False squared_hinge
# 0.941139534884
# 0.35 1 True hinge
# 0.947279069767
# 0.35 1 True squared_hinge
# 0.946627906977
# 0.35 2 False squared_hinge
# 0.939976744186
# 0.35 2 True hinge
# 0.945302325581
# 0.35 2 True squared_hinge
# 0.915069767442
# 0.35 3 False squared_hinge
# 0.939976744186
# 0.35 3 True hinge
# 0.950279069767
# 0.35 3 True squared_hinge
# 0.932674418605
# 0.35 4 False squared_hinge
# 0.941139534884
# 0.35 4 True hinge
# 0.91323255814
# 0.35 4 True squared_hinge
# 0.947465116279
# 0.4 0.1 False squared_hinge
# 0.939976744186
# 0.4 0.1 True hinge
# 0.948953488372
# 0.4 0.1 True squared_hinge
# 0.941976744186
# 0.4 0.2 False squared_hinge
# 0.939813953488
# 0.4 0.2 True hinge
# 0.919209302326
# 0.4 0.2 True squared_hinge
# 0.91988372093
# 0.4 0.4 False squared_hinge
# 0.938813953488
# 0.4 0.4 True hinge
# 0.919209302326
# 0.4 0.4 True squared_hinge
# 0.951604651163
# 0.4 0.5 False squared_hinge
# 0.938813953488
# 0.4 0.5 True hinge
# 0.932674418605
# 0.4 0.5 True squared_hinge
# 0.935
# 0.4 1 False squared_hinge
# 0.939976744186
# 0.4 1 True hinge
# 0.955930232558
# 0.4 1 True squared_hinge
# 0.932674418605
# 0.4 2 False squared_hinge
# 0.939976744186
# 0.4 2 True hinge
# 0.95276744186
# 0.4 2 True squared_hinge
# 0.941813953488
# 0.4 3 False squared_hinge
# 0.941139534884
# 0.4 3 True hinge
# 0.955604651163
# 0.4 3 True squared_hinge
# 0.952441860465
# 0.4 4 False squared_hinge
# 0.939976744186
# 0.4 4 True hinge
# 0.917558139535
# 0.4 4 True squared_hinge
# 0.95011627907
# 0.45 0.1 False squared_hinge
# 0.939976744186
# 0.45 0.1 True hinge
# 0.940813953488
# 0.45 0.1 True squared_hinge
# 0.942139534884
# 0.45 0.2 False squared_hinge
# 0.939976744186
# 0.45 0.2 True hinge
# 0.941976744186
# 0.45 0.2 True squared_hinge
# 0.95011627907
# 0.45 0.4 False squared_hinge
# 0.939976744186
# 0.45 0.4 True hinge
# 0.939488372093
# 0.45 0.4 True squared_hinge
# 0.952441860465
# 0.45 0.5 False squared_hinge
# 0.937651162791
# 0.45 0.5 True hinge
# 0.94811627907
# 0.45 0.5 True squared_hinge
# 0.936325581395
# 0.45 1 False squared_hinge
# 0.938813953488
# 0.45 1 True hinge
# 0.940813953488
# 0.45 1 True squared_hinge
# 0.926511627907
# 0.45 2 False squared_hinge
# 0.939976744186
# 0.45 2 True hinge
# 0.945953488372
# 0.45 2 True squared_hinge
# 0.946627906977
# 0.45 3 False squared_hinge
# 0.938813953488
# 0.45 3 True hinge
# 0.951279069767
# 0.45 3 True squared_hinge
# 0.929325581395
# 0.45 4 False squared_hinge
# 0.937813953488
# 0.45 4 True hinge
# 0.95111627907
# 0.45 4 True squared_hinge
# 0.953604651163
# 0.5 0.1 False squared_hinge
# 0.937651162791
# 0.5 0.1 True hinge
# 0.931511627907
# 0.5 0.1 True squared_hinge
# 0.930511627907
# 0.5 0.2 False squared_hinge
# 0.936651162791
# 0.5 0.2 True hinge
# 0.936813953488
# 0.5 0.2 True squared_hinge
# 0.933837209302
# 0.5 0.4 False squared_hinge
# 0.938813953488
# 0.5 0.4 True hinge
# 0.929186046512
# 0.5 0.4 True squared_hinge
# 0.926348837209
# 0.5 0.5 False squared_hinge
# 0.937651162791
# 0.5 0.5 True hinge
# 0.945953488372
# 0.5 0.5 True squared_hinge
# 0.950604651163
# 0.5 1 False squared_hinge
# 0.937813953488
# 0.5 1 True hinge
# 0.950604651163
# 0.5 1 True squared_hinge
# 0.946302325581
# 0.5 2 False squared_hinge
# 0.939976744186
# 0.5 2 True hinge
# 0.937325581395
# 0.5 2 True squared_hinge
# 0.905744186047
# 0.5 3 False squared_hinge
# 0.939976744186
# 0.5 3 True hinge
# 0.946790697674
# 0.5 3 True squared_hinge
# 0.945790697674
# 0.5 4 False squared_hinge
# 0.939976744186
# 0.5 4 True hinge
# 0.943302325581
# 0.5 4 True squared_hinge
# 0.931674418605

# %%
best_responses = sort_dict_by_val(all_scores, reverse=True)
best_responses
# Out:
# [((0.15, 0.1, True, 'hinge'), 0.95909302325581403),
#  ((0.08, 0.4, True, 'hinge'), 0.95709302325581402),
#  ((0.09, 1, True, 'squared_hinge'), 0.95709302325581391),
#  ((0.2, 0.1, True, 'squared_hinge'), 0.95676744186046514),
#  ((0.4, 1, True, 'hinge'), 0.95593023255813958),
#  ((0.2, 0.4, True, 'hinge'), 0.95593023255813958),
#  ((0.08, 0.2, True, 'squared_hinge'), 0.95593023255813958),
#  ((0.4, 3, True, 'hinge'), 0.9556046511627907),
#  ((0.08, 1, True, 'squared_hinge'), 0.95493023255813958),
#  ((0.07, 0.1, True, 'squared_hinge'), 0.95476744186046525),
#  ((0.05, 4, True, 'squared_hinge'), 0.95476744186046503),
#  ((0.02, 0.2, True, 'squared_hinge'), 0.9546046511627907),
#  ((0.35, 0.5, True, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 3, False, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 0.1, True, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 0.5, False, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 0.1, False, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 4, False, 'squared_hinge'), 0.9546046511627907),
#  ((0.07, 0.5, True, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 0.4, False, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 0.2, False, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 2, False, 'squared_hinge'), 0.9546046511627907),
#  ((0.02, 1, False, 'squared_hinge'), 0.9546046511627907),
#  ((0.09, 0.1, True, 'squared_hinge'), 0.9546046511627907),
#  ((0.09, 0.5, True, 'hinge'), 0.95393023255813958),
#  ((0.2, 3, True, 'squared_hinge'), 0.95376744186046525),
#  ((0.35, 0.2, True, 'squared_hinge'), 0.95376744186046503),
#  ((0.3, 3, True, 'squared_hinge'), 0.9536046511627907),
#  ((0.05, 0.1, False, 'squared_hinge'), 0.9536046511627907),
#  ((0.08, 0.1, True, 'squared_hinge'), 0.9536046511627907),
#  ((0.05, 1, False, 'squared_hinge'), 0.9536046511627907),
#  ((0.45, 4, True, 'squared_hinge'), 0.9536046511627907),
#  ((0.2, 4, True, 'hinge'), 0.9536046511627907),
#  ((0.05, 4, False, 'squared_hinge'), 0.9536046511627907),
#  ((0.05, 3, False, 'squared_hinge'), 0.9536046511627907),
#  ((0.09, 0.2, True, 'squared_hinge'), 0.9536046511627907),
#  ((0.05, 0.5, True, 'squared_hinge'), 0.9536046511627907),
#  ((0.05, 0.5, False, 'squared_hinge'), 0.9536046511627907),
#  ((0.05, 2, False, 'squared_hinge'), 0.9536046511627907),
#  ((0.05, 0.4, False, 'squared_hinge'), 0.9536046511627907),
#  ((0.07, 0.2, True, 'squared_hinge'), 0.9536046511627907),
#  ((0.07, 3, True, 'squared_hinge'), 0.9536046511627907),
#  ((0.05, 0.1, True, 'squared_hinge'), 0.9536046511627907),
#  ((0.08, 0.5, True, 'hinge'), 0.9536046511627907),
#  ((0.02, 4, True, 'squared_hinge'), 0.95344186046511636),
#  ((0.02, 2, True, 'squared_hinge'), 0.95344186046511636),
#  ((0.05, 3, True, 'hinge'), 0.95327906976744181),
#  ((0.07, 2, True, 'squared_hinge'), 0.95327906976744181),
#  ((0.1, 0.1, True, 'hinge'), 0.95293023255813958),
#  ((0.02, 4, True, 'hinge'), 0.95276744186046525),
#  ((0.3, 3, True, 'hinge'), 0.95276744186046525),
#  ((0.02, 2, True, 'hinge'), 0.95276744186046503),
#  ((0.4, 2, True, 'hinge'), 0.95276744186046503),
#  ((0.05, 0.4, True, 'hinge'), 0.95260465116279069),
#  ((0.1, 0.2, True, 'squared_hinge'), 0.95260465116279069),
#  ((0.07, 0.4, True, 'hinge'), 0.95260465116279069),
#  ((0.08, 0.4, True, 'squared_hinge'), 0.95260465116279069),
#  ((0.25, 4, True, 'hinge'), 0.95244186046511636),
#  ((0.02, 1, True, 'squared_hinge'), 0.95244186046511636),
#  ((0.05, 3, True, 'squared_hinge'), 0.95244186046511614),
#  ((0.05, 0.2, False, 'squared_hinge'), 0.95244186046511614),
#  ((0.4, 3, True, 'squared_hinge'), 0.95244186046511614),
#  ((0.3, 0.1, True, 'squared_hinge'), 0.95244186046511614),
#  ((0.09, 4, True, 'squared_hinge'), 0.95244186046511614),
#  ((0.2, 2, True, 'squared_hinge'), 0.95244186046511614),
#  ((0.45, 0.4, True, 'squared_hinge'), 0.95244186046511614),
#  ((0.02, 0.5, True, 'squared_hinge'), 0.95227906976744181),
#  ((0.07, 0.5, True, 'hinge'), 0.95176744186046514),
#  ((0.07, 0.1, True, 'hinge'), 0.95160465116279069),
#  ((0.07, 1, True, 'hinge'), 0.95160465116279069),
#  ((0.4, 0.4, True, 'squared_hinge'), 0.95160465116279069),
#  ((0.05, 4, True, 'hinge'), 0.95160465116279069),
#  ((0.02, 3, True, 'squared_hinge'), 0.95144186046511636),
#  ((0.05, 1, True, 'hinge'), 0.95144186046511625),
#  ((0.05, 2, True, 'squared_hinge'), 0.95144186046511625),
#  ((0.45, 3, True, 'hinge'), 0.95127906976744181),
#  ((0.09, 0.4, True, 'hinge'), 0.95127906976744181),
#  ((0.09, 3, True, 'hinge'), 0.95127906976744181),
#  ((0.08, 4, True, 'hinge'), 0.95111627906976748),
#  ((0.45, 4, True, 'hinge'), 0.95111627906976748),
#  ((0.09, 0.2, True, 'hinge'), 0.95095348837209293),
#  ((0.3, 0.4, True, 'hinge'), 0.95076744186046525),
#  ((0.02, 1, True, 'hinge'), 0.95076744186046513),
#  ((0.02, 0.1, True, 'hinge'), 0.9506046511627908),
#  ((0.02, 0.2, True, 'hinge'), 0.9506046511627908),
#  ((0.02, 0.4, True, 'hinge'), 0.9506046511627908),
#  ((0.5, 1, True, 'hinge'), 0.9506046511627908),
#  ((0.5, 0.5, True, 'squared_hinge'), 0.95060465116279058),
#  ((0.02, 0.4, True, 'squared_hinge'), 0.95044186046511625),
#  ((0.1, 0.1, True, 'squared_hinge'), 0.95027906976744192),
#  ((0.35, 3, True, 'hinge'), 0.95027906976744192),
#  ((0.15, 1, True, 'squared_hinge'), 0.95011627906976748),
#  ((0.07, 4, True, 'hinge'), 0.95011627906976748),
#  ((0.08, 2, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.07, 3, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.08, 0.1, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.08, 0.5, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.07, 1, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.07, 0.1, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.07, 4, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.08, 1, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.07, 0.4, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.07, 2, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.45, 0.2, True, 'squared_hinge'), 0.95011627906976737),
#  ((0.08, 3, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.07, 0.5, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.07, 0.2, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.08, 0.4, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.08, 0.2, False, 'squared_hinge'), 0.95011627906976737),
#  ((0.4, 4, True, 'squared_hinge'), 0.95011627906976737),
#  ((0.02, 3, True, 'hinge'), 0.94976744186046513),
#  ((0.02, 0.5, True, 'hinge'), 0.9496046511627908),
#  ((0.35, 0.2, True, 'hinge'), 0.94927906976744192),
#  ((0.01, 4, False, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 3, True, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 3, False, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 0.5, False, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 0.4, False, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 0.2, True, 'squared_hinge'), 0.94911627906976737),
#  ((0.05, 2, True, 'hinge'), 0.94911627906976737),
#  ((0.01, 0.2, False, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 1, False, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 1, True, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 0.5, True, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 0.1, True, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 0.4, True, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 4, True, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 2, False, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 0.1, False, 'squared_hinge'), 0.94911627906976737),
#  ((0.01, 2, True, 'squared_hinge'), 0.94911627906976737),
#  ((0.4, 0.1, True, 'hinge'), 0.94895348837209303),
#  ((0.08, 4, True, 'squared_hinge'), 0.94895348837209303),
#  ((0.2, 0.2, True, 'hinge'), 0.94895348837209303),
#  ((0.08, 4, False, 'squared_hinge'), 0.94895348837209303),
#  ((0.25, 0.2, True, 'hinge'), 0.9487906976744187),
#  ((0.08, 0.1, True, 'hinge'), 0.94827906976744192),
#  ((0.45, 0.5, True, 'hinge'), 0.94811627906976759),
#  ((0.05, 0.5, True, 'hinge'), 0.94811627906976736),
#  ((0.15, 0.4, True, 'hinge'), 0.9477906976744187),
#  ((0.25, 0.4, True, 'squared_hinge'), 0.9477906976744187),
#  ((0.09, 0.2, False, 'squared_hinge'), 0.94779069767441848),
#  ((0.15, 3, True, 'hinge'), 0.94779069767441848),
#  ((0.07, 3, True, 'hinge'), 0.94762790697674415),
#  ((0.35, 4, True, 'squared_hinge'), 0.94746511627906982),
#  ((0.01, 3, True, 'hinge'), 0.94744186046511625),
#  ((0.01, 1, True, 'hinge'), 0.94744186046511625),
#  ((0.01, 0.1, True, 'hinge'), 0.94744186046511625),
#  ((0.01, 2, True, 'hinge'), 0.94744186046511625),
#  ((0.25, 0.5, True, 'squared_hinge'), 0.94730232558139549),
#  ((0.35, 1, True, 'hinge'), 0.94727906976744192),
#  ((0.07, 2, True, 'hinge'), 0.94695348837209303),
#  ((0.2, 1, True, 'squared_hinge'), 0.94695348837209303),
#  ((0.5, 3, True, 'hinge'), 0.9467906976744187),
#  ((0.3, 2, True, 'squared_hinge'), 0.94662790697674415),
#  ((0.09, 4, False, 'squared_hinge'), 0.94662790697674415),
#  ((0.45, 2, True, 'squared_hinge'), 0.94662790697674415),
#  ((0.35, 1, True, 'squared_hinge'), 0.94662790697674415),
#  ((0.09, 0.5, False, 'squared_hinge'), 0.94662790697674415),
#  ((0.09, 1, False, 'squared_hinge'), 0.94662790697674415),
#  ((0.05, 0.2, True, 'squared_hinge'), 0.94662790697674415),
#  ((0.09, 3, False, 'squared_hinge'), 0.94662790697674415),
#  ((0.1, 1, False, 'squared_hinge'), 0.94662790697674415),
#  ((0.09, 0.1, False, 'squared_hinge'), 0.94662790697674415),
#  ((0.09, 2, False, 'squared_hinge'), 0.94662790697674415),
#  ((0.09, 0.4, False, 'squared_hinge'), 0.94662790697674415),
#  ((0.1, 1, True, 'squared_hinge'), 0.94646511627906982),
#  ((0.01, 0.4, True, 'hinge'), 0.94644186046511636),
#  ((0.5, 1, True, 'squared_hinge'), 0.94630232558139526),
#  ((0.01, 4, True, 'hinge'), 0.94627906976744192),
#  ((0.01, 0.5, True, 'hinge'), 0.94627906976744192),
#  ((0.07, 0.2, True, 'hinge'), 0.94611627906976747),
#  ((0.08, 0.5, True, 'squared_hinge'), 0.94611627906976747),
#  ((0.5, 0.5, True, 'hinge'), 0.94595348837209303),
#  ((0.2, 0.5, True, 'hinge'), 0.94595348837209303),
#  ((0.45, 2, True, 'hinge'), 0.94595348837209303),
#  ((0.15, 4, True, 'squared_hinge'), 0.94579069767441859),
#  ((0.5, 3, True, 'squared_hinge'), 0.94579069767441859),
#  ((0.05, 0.1, True, 'hinge'), 0.94546511627906982),
#  ((0.1, 4, False, 'squared_hinge'), 0.94546511627906971),
#  ((0.1, 0.1, False, 'squared_hinge'), 0.94546511627906971),
#  ((0.1, 0.4, False, 'squared_hinge'), 0.94546511627906971),
#  ((0.1, 0.5, False, 'squared_hinge'), 0.94546511627906971),
#  ((0.1, 3, False, 'squared_hinge'), 0.94546511627906971),
#  ((0.1, 2, False, 'squared_hinge'), 0.94546511627906971),
#  ((0.1, 0.2, False, 'squared_hinge'), 0.94546511627906971),
#  ((0.1, 0.5, True, 'squared_hinge'), 0.94530232558139549),
#  ((0.35, 2, True, 'hinge'), 0.94530232558139526),
#  ((0.2, 0.5, True, 'squared_hinge'), 0.94530232558139526),
#  ((0.01, 0.2, True, 'hinge'), 0.94527906976744203),
#  ((0.08, 3, True, 'hinge'), 0.94495348837209314),
#  ((0.08, 3, True, 'squared_hinge'), 0.94479069767441859),
#  ((0.1, 0.5, True, 'hinge'), 0.94462790697674426),
#  ((0.15, 0.4, True, 'squared_hinge'), 0.94462790697674426),
#  ((0.1, 2, True, 'hinge'), 0.94462790697674426),
#  ((0.09, 1, True, 'hinge'), 0.94446511627906971),
#  ((0.15, 0.5, False, 'squared_hinge'), 0.94430232558139537),
#  ((0.2, 3, True, 'hinge'), 0.94430232558139537),
#  ((0.1, 3, True, 'hinge'), 0.94413953488372093),
#  ((0.08, 0.2, True, 'hinge'), 0.94413953488372093),
#  ((0.08, 2, True, 'hinge'), 0.94395348837209314),
#  ((0.35, 0.1, True, 'hinge'), 0.94362790697674404),
#  ((0.25, 1, True, 'squared_hinge'), 0.9434651162790697),
#  ((0.5, 4, True, 'hinge'), 0.94330232558139537),
#  ((0.1, 0.4, True, 'hinge'), 0.94313953488372104),
#  ((0.15, 3, False, 'squared_hinge'), 0.94313953488372082),
#  ((0.15, 1, True, 'hinge'), 0.94313953488372082),
#  ((0.15, 0.2, False, 'squared_hinge'), 0.94313953488372082),
#  ((0.15, 2, False, 'squared_hinge'), 0.94313953488372082),
#  ((0.2, 2, True, 'hinge'), 0.94313953488372082),
#  ((0.2, 0.1, False, 'squared_hinge'), 0.94313953488372082),
#  ((0.15, 0.5, True, 'hinge'), 0.94265116279069772),
#  ((0.08, 1, True, 'hinge'), 0.94246511627906993),
#  ((0.25, 0.5, False, 'squared_hinge'), 0.94213953488372104),
#  ((0.25, 1, False, 'squared_hinge'), 0.94213953488372104),
#  ((0.25, 3, False, 'squared_hinge'), 0.94213953488372104),
#  ((0.25, 2, False, 'squared_hinge'), 0.94213953488372104),
#  ((0.45, 0.1, True, 'squared_hinge'), 0.94213953488372104),
#  ((0.25, 4, False, 'squared_hinge'), 0.94213953488372104),
#  ((0.4, 0.1, True, 'squared_hinge'), 0.94197674418604671),
#  ((0.15, 0.1, False, 'squared_hinge'), 0.94197674418604649),
#  ((0.07, 0.4, True, 'squared_hinge'), 0.94197674418604649),
#  ((0.15, 0.4, False, 'squared_hinge'), 0.94197674418604649),
#  ((0.15, 1, False, 'squared_hinge'), 0.94197674418604649),
#  ((0.15, 4, False, 'squared_hinge'), 0.94197674418604649),
#  ((0.25, 0.2, True, 'squared_hinge'), 0.94197674418604649),
#  ((0.2, 0.5, False, 'squared_hinge'), 0.94197674418604649),
#  ((0.45, 0.2, True, 'hinge'), 0.94197674418604649),
#  ((0.07, 1, True, 'squared_hinge'), 0.94197674418604649),
#  ((0.4, 2, True, 'squared_hinge'), 0.94181395348837216),
#  ((0.2, 4, True, 'squared_hinge'), 0.94181395348837216),
#  ((0.3, 0.2, True, 'squared_hinge'), 0.94181395348837216),
#  ((0.25, 3, True, 'squared_hinge'), 0.9416511627906976),
#  ((0.3, 0.1, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.35, 4, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.4, 3, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.35, 0.2, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.2, 2, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.2, 4, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.3, 0.5, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.35, 1, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.35, 0.5, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.05, 0.2, True, 'hinge'), 0.94113953488372082),
#  ((0.3, 0.2, False, 'squared_hinge'), 0.94113953488372082),
#  ((0.3, 1, False, 'squared_hinge'), 0.94097674418604649),
#  ((0.25, 0.4, True, 'hinge'), 0.94097674418604649),
#  ((0.25, 0.1, False, 'squared_hinge'), 0.94097674418604649),
#  ((0.25, 0.2, False, 'squared_hinge'), 0.94097674418604649),
#  ((0.09, 2, True, 'hinge'), 0.94097674418604649),
#  ((0.09, 0.4, True, 'squared_hinge'), 0.94081395348837216),
#  ((0.45, 1, True, 'hinge'), 0.94081395348837216),
#  ((0.45, 0.1, True, 'hinge'), 0.94081395348837193),
#  ((0.3, 1, True, 'squared_hinge'), 0.94081395348837193),
#  ((0.3, 2, True, 'hinge'), 0.9406511627906976),
#  ((0.25, 2, True, 'squared_hinge'), 0.94032558139534894),
#  ((0.45, 0.2, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.4, 2, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.4, 1, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.2, 3, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.35, 3, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.3, 2, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.45, 2, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.3, 0.4, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.25, 0.4, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.35, 0.1, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.35, 2, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.5, 2, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.3, 4, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.2, 1, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.3, 3, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.35, 0.1, True, 'squared_hinge'), 0.93997674418604649),
#  ((0.45, 0.1, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.4, 0.1, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.5, 4, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.5, 3, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.35, 0.4, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.2, 0.2, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.4, 4, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.2, 0.4, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.45, 0.4, False, 'squared_hinge'), 0.93997674418604649),
#  ((0.4, 0.2, False, 'squared_hinge'), 0.93981395348837216),
#  ((0.1, 3, True, 'squared_hinge'), 0.93981395348837216),
#  ((0.15, 2, True, 'squared_hinge'), 0.9396511627906976),
#  ((0.05, 1, True, 'squared_hinge'), 0.9396511627906976),
#  ((0.45, 0.4, True, 'hinge'), 0.93948837209302327),
#  ((0.3, 4, True, 'squared_hinge'), 0.93930232558139548),
#  ((0.45, 1, False, 'squared_hinge'), 0.93881395348837204),
#  ((0.4, 0.4, False, 'squared_hinge'), 0.93881395348837204),
#  ((0.45, 3, False, 'squared_hinge'), 0.93881395348837204),
#  ((0.4, 0.5, False, 'squared_hinge'), 0.93881395348837204),
#  ((0.5, 0.4, False, 'squared_hinge'), 0.93881395348837204),
#  ((0.25, 2, True, 'hinge'), 0.93865116279069771),
#  ((0.09, 2, True, 'squared_hinge'), 0.93865116279069771),
#  ((0.25, 4, True, 'squared_hinge'), 0.93848837209302327),
#  ((0.09, 0.1, True, 'hinge'), 0.93830232558139526),
#  ((0.5, 1, False, 'squared_hinge'), 0.93781395348837204),
#  ((0.45, 4, False, 'squared_hinge'), 0.93781395348837204),
#  ((0.5, 0.5, False, 'squared_hinge'), 0.93765116279069771),
#  ((0.3, 0.4, True, 'squared_hinge'), 0.93765116279069771),
#  ((0.45, 0.5, False, 'squared_hinge'), 0.93765116279069771),
#  ((0.5, 0.1, False, 'squared_hinge'), 0.93765116279069771),
#  ((0.08, 2, True, 'squared_hinge'), 0.93748837209302316),
#  ((0.07, 4, True, 'squared_hinge'), 0.93748837209302316),
#  ((0.5, 2, True, 'hinge'), 0.93732558139534883),
#  ((0.25, 3, True, 'hinge'), 0.93697674418604637),
#  ((0.5, 0.2, True, 'hinge'), 0.93681395348837204),
#  ((0.5, 0.2, False, 'squared_hinge'), 0.93665116279069771),
#  ((0.15, 0.5, True, 'squared_hinge'), 0.93665116279069771),
#  ((0.45, 0.5, True, 'squared_hinge'), 0.93632558139534883),
#  ((0.1, 1, True, 'hinge'), 0.93583720930232561),
#  ((0.15, 0.1, True, 'squared_hinge'), 0.93500000000000016),
#  ((0.4, 0.5, True, 'squared_hinge'), 0.93499999999999994),
#  ((0.25, 0.1, True, 'hinge'), 0.93497674418604659),
#  ((0.15, 3, True, 'squared_hinge'), 0.93483720930232561),
#  ((0.2, 0.4, True, 'squared_hinge'), 0.93448837209302327),
#  ((0.3, 0.2, True, 'hinge'), 0.93448837209302327),
#  ((0.35, 0.5, True, 'hinge'), 0.93416279069767438),
#  ((0.05, 0.4, True, 'squared_hinge'), 0.93383720930232561),
#  ((0.1, 4, True, 'squared_hinge'), 0.93383720930232561),
#  ((0.25, 0.5, True, 'hinge'), 0.93383720930232561),
#  ((0.1, 0.2, True, 'hinge'), 0.93383720930232561),
#  ((0.09, 0.5, True, 'squared_hinge'), 0.93383720930232561),
#  ((0.5, 0.2, True, 'squared_hinge'), 0.93383720930232561),
#  ((0.09, 4, True, 'hinge'), 0.93381395348837215),
#  ((0.1, 0.4, True, 'squared_hinge'), 0.93300000000000005),
#  ((0.09, 3, True, 'squared_hinge'), 0.93283720930232561),
#  ((0.15, 0.2, True, 'hinge'), 0.93283720930232561),
#  ((0.4, 1, True, 'squared_hinge'), 0.93267441860465117),
#  ((0.4, 0.5, True, 'hinge'), 0.93267441860465117),
#  ((0.35, 3, True, 'squared_hinge'), 0.93267441860465117),
#  ((0.25, 0.1, True, 'squared_hinge'), 0.93248837209302327),
#  ((0.5, 4, True, 'squared_hinge'), 0.93167441860465117),
#  ((0.2, 1, True, 'hinge'), 0.93151162790697684),
#  ((0.5, 0.1, True, 'hinge'), 0.93151162790697684),
#  ((0.5, 0.1, True, 'squared_hinge'), 0.93051162790697661),
#  ((0.1, 2, True, 'squared_hinge'), 0.93051162790697661),
#  ((0.45, 3, True, 'squared_hinge'), 0.92932558139534882),
#  ((0.5, 0.4, True, 'hinge'), 0.92918604651162795),
#  ((0.3, 0.1, True, 'hinge'), 0.92918604651162795),
#  ((0.3, 0.5, True, 'squared_hinge'), 0.92883720930232561),
#  ((0.35, 0.4, True, 'hinge'), 0.92834883720930228),
#  ((0.2, 0.1, True, 'hinge'), 0.9280232558139534),
#  ((0.1, 4, True, 'hinge'), 0.92686046511627906),
#  ((0.45, 1, True, 'squared_hinge'), 0.92651162790697672),
#  ((0.5, 0.4, True, 'squared_hinge'), 0.92634883720930239),
#  ((0.15, 0.2, True, 'squared_hinge'), 0.92634883720930239),
#  ((0.2, 0.2, True, 'squared_hinge'), 0.92453488372093029),
#  ((0.3, 0.5, True, 'hinge'), 0.92351162790697683),
#  ((0.3, 1, True, 'hinge'), 0.92237209302325573),
#  ((0.4, 0.2, True, 'squared_hinge'), 0.91988372093023263),
#  ((0.4, 0.2, True, 'hinge'), 0.91920930232558151),
#  ((0.4, 0.4, True, 'hinge'), 0.91920930232558129),
#  ((0.35, 0.4, True, 'squared_hinge'), 0.91872093023255808),
#  ((0.15, 4, True, 'hinge'), 0.91804651162790696),
#  ((0.15, 2, True, 'hinge'), 0.91788372093023263),
#  ((0.25, 1, True, 'hinge'), 0.91755813953488374),
#  ((0.4, 4, True, 'hinge'), 0.91755813953488374),
#  ((0.35, 2, True, 'squared_hinge'), 0.91506976744186053),
#  ((0.35, 4, True, 'hinge'), 0.91323255813953497),
#  ((0.5, 2, True, 'squared_hinge'), 0.90574418604651163),
#  ((0.3, 4, True, 'hinge'), 0.88730232558139532)]

# %%
c, intercept, dual, loss = best_responses[rank][0]
print c, intercept, dual, loss
# Out:
# 0.15 0.1 True hinge

# %%
rank = 0
c, intercept, dual, loss = best_responses[rank][0]
# c, intercept, dual, loss = [0.02, 3, False, "squared_hinge"]
for i in range(30):
    print c, intercept, dual, loss
    lsvc = LinearSVC(C=c, loss=loss, intercept_scaling=intercept, dual=dual, random_state=42)
    lsvc.fit(train_latent, cids)
    score = average_per_class(lsvc, test_latent, cids_)
    print score
# Out:
# 0.15 0.1 True hinge
# 0.95376744186
# 0.15 0.1 True hinge
# 0.947627906977
# 0.15 0.1 True hinge
# 0.947790697674
# 0.15 0.1 True hinge
# 0.950441860465
# 0.15 0.1 True hinge
# 0.890953488372
# 0.15 0.1 True hinge
# 0.948279069767
# 0.15 0.1 True hinge
# 0.935813953488
# 0.15 0.1 True hinge
# 0.944302325581
# 0.15 0.1 True hinge
# 0.955930232558
# 0.15 0.1 True hinge
# 0.948953488372
# 0.15 0.1 True hinge
# 0.936488372093
# 0.15 0.1 True hinge
# 0.942627906977
# 0.15 0.1 True hinge
# 0.946790697674
# 0.15 0.1 True hinge
# 0.945790697674
# 0.15 0.1 True hinge
# 0.94911627907
# 0.15 0.1 True hinge
# 0.914069767442
# 0.15 0.1 True hinge
# 0.933837209302
# 0.15 0.1 True hinge
# 0.929186046512
# 0.15 0.1 True hinge
# 0.952604651163
# 0.15 0.1 True hinge
# 0.943465116279
# 0.15 0.1 True hinge
# 0.946953488372
# 0.15 0.1 True hinge
# 0.951279069767
# 0.15 0.1 True hinge
# 0.95011627907
# 0.15 0.1 True hinge
# 0.935325581395
# 0.15 0.1 True hinge
# 0.923046511628
# 0.15 0.1 True hinge
# 0.951279069767
# 0.15 0.1 True hinge
# 0.943139534884
# 0.15 0.1 True hinge
# 0.953604651163
# 0.15 0.1 True hinge
# 0.94711627907
# 0.15 0.1 True hinge
# 0.944302325581

# %%
# Out:
# {(0.01, 0.1, False, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 0.1, True, 'hinge'): 0.94744186046511625,
#  (0.01, 0.1, True, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 0.2, False, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 0.2, True, 'hinge'): 0.94527906976744203,
#  (0.01, 0.2, True, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 0.4, False, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 0.4, True, 'hinge'): 0.94644186046511636,
#  (0.01, 0.4, True, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 0.5, False, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 0.5, True, 'hinge'): 0.94627906976744192,
#  (0.01, 0.5, True, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 1, False, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 1, True, 'hinge'): 0.94744186046511625,
#  (0.01, 1, True, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 2, False, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 2, True, 'hinge'): 0.94744186046511625,
#  (0.01, 2, True, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 3, False, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 3, True, 'hinge'): 0.94744186046511625,
#  (0.01, 3, True, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 4, False, 'squared_hinge'): 0.94911627906976737,
#  (0.01, 4, True, 'hinge'): 0.94627906976744192,
#  (0.01, 4, True, 'squared_hinge'): 0.94911627906976737,
#  (0.02, 0.1, False, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 0.1, True, 'hinge'): 0.9506046511627908,
#  (0.02, 0.1, True, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 0.2, False, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 0.2, True, 'hinge'): 0.9506046511627908,
#  (0.02, 0.2, True, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 0.4, False, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 0.4, True, 'hinge'): 0.9506046511627908,
#  (0.02, 0.4, True, 'squared_hinge'): 0.95044186046511625,
#  (0.02, 0.5, False, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 0.5, True, 'hinge'): 0.9496046511627908,
#  (0.02, 0.5, True, 'squared_hinge'): 0.95227906976744181,
#  (0.02, 1, False, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 1, True, 'hinge'): 0.95076744186046513,
#  (0.02, 1, True, 'squared_hinge'): 0.95244186046511636,
#  (0.02, 2, False, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 2, True, 'hinge'): 0.95276744186046503,
#  (0.02, 2, True, 'squared_hinge'): 0.95344186046511636,
#  (0.02, 3, False, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 3, True, 'hinge'): 0.94976744186046513,
#  (0.02, 3, True, 'squared_hinge'): 0.95144186046511636,
#  (0.02, 4, False, 'squared_hinge'): 0.9546046511627907,
#  (0.02, 4, True, 'hinge'): 0.95276744186046525,
#  (0.02, 4, True, 'squared_hinge'): 0.95344186046511636,
#  (0.05, 0.1, False, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 0.1, True, 'hinge'): 0.94546511627906982,
#  (0.05, 0.1, True, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 0.2, False, 'squared_hinge'): 0.95244186046511614,
#  (0.05, 0.2, True, 'hinge'): 0.94113953488372082,
#  (0.05, 0.2, True, 'squared_hinge'): 0.94662790697674415,
#  (0.05, 0.4, False, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 0.4, True, 'hinge'): 0.95260465116279069,
#  (0.05, 0.4, True, 'squared_hinge'): 0.93383720930232561,
#  (0.05, 0.5, False, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 0.5, True, 'hinge'): 0.94811627906976736,
#  (0.05, 0.5, True, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 1, False, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 1, True, 'hinge'): 0.95144186046511625,
#  (0.05, 1, True, 'squared_hinge'): 0.9396511627906976,
#  (0.05, 2, False, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 2, True, 'hinge'): 0.94911627906976737,
#  (0.05, 2, True, 'squared_hinge'): 0.95144186046511625,
#  (0.05, 3, False, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 3, True, 'hinge'): 0.95327906976744181,
#  (0.05, 3, True, 'squared_hinge'): 0.95244186046511614,
#  (0.05, 4, False, 'squared_hinge'): 0.9536046511627907,
#  (0.05, 4, True, 'hinge'): 0.95160465116279069,
#  (0.05, 4, True, 'squared_hinge'): 0.95476744186046503,
#  (0.07, 0.1, False, 'squared_hinge'): 0.95011627906976737,
#  (0.07, 0.1, True, 'hinge'): 0.95160465116279069,
#  (0.07, 0.1, True, 'squared_hinge'): 0.95476744186046525,
#  (0.07, 0.2, False, 'squared_hinge'): 0.95011627906976737,
#  (0.07, 0.2, True, 'hinge'): 0.94611627906976747,
#  (0.07, 0.2, True, 'squared_hinge'): 0.9536046511627907,
#  (0.07, 0.4, False, 'squared_hinge'): 0.95011627906976737,
#  (0.07, 0.4, True, 'hinge'): 0.95260465116279069,
#  (0.07, 0.4, True, 'squared_hinge'): 0.94197674418604649,
#  (0.07, 0.5, False, 'squared_hinge'): 0.95011627906976737,
#  (0.07, 0.5, True, 'hinge'): 0.95176744186046514,
#  (0.07, 0.5, True, 'squared_hinge'): 0.9546046511627907,
#  (0.07, 1, False, 'squared_hinge'): 0.95011627906976737,
#  (0.07, 1, True, 'hinge'): 0.95160465116279069,
#  (0.07, 1, True, 'squared_hinge'): 0.94197674418604649,
#  (0.07, 2, False, 'squared_hinge'): 0.95011627906976737,
#  (0.07, 2, True, 'hinge'): 0.94695348837209303,
#  (0.07, 2, True, 'squared_hinge'): 0.95327906976744181,
#  (0.07, 3, False, 'squared_hinge'): 0.95011627906976737,
#  (0.07, 3, True, 'hinge'): 0.94762790697674415,
#  (0.07, 3, True, 'squared_hinge'): 0.9536046511627907,
#  (0.07, 4, False, 'squared_hinge'): 0.95011627906976737,
#  (0.07, 4, True, 'hinge'): 0.95011627906976748,
#  (0.07, 4, True, 'squared_hinge'): 0.93748837209302316,
#  (0.08, 0.1, False, 'squared_hinge'): 0.95011627906976737,
#  (0.08, 0.1, True, 'hinge'): 0.94827906976744192,
#  (0.08, 0.1, True, 'squared_hinge'): 0.9536046511627907,
#  (0.08, 0.2, False, 'squared_hinge'): 0.95011627906976737,
#  (0.08, 0.2, True, 'hinge'): 0.94413953488372093,
#  (0.08, 0.2, True, 'squared_hinge'): 0.95593023255813958,
#  (0.08, 0.4, False, 'squared_hinge'): 0.95011627906976737,
#  (0.08, 0.4, True, 'hinge'): 0.95709302325581402,
#  (0.08, 0.4, True, 'squared_hinge'): 0.95260465116279069,
#  (0.08, 0.5, False, 'squared_hinge'): 0.95011627906976737,
#  (0.08, 0.5, True, 'hinge'): 0.9536046511627907,
#  (0.08, 0.5, True, 'squared_hinge'): 0.94611627906976747,
#  (0.08, 1, False, 'squared_hinge'): 0.95011627906976737,
#  (0.08, 1, True, 'hinge'): 0.94246511627906993,
#  (0.08, 1, True, 'squared_hinge'): 0.95493023255813958,
#  (0.08, 2, False, 'squared_hinge'): 0.95011627906976737,
#  (0.08, 2, True, 'hinge'): 0.94395348837209314,
#  (0.08, 2, True, 'squared_hinge'): 0.93748837209302316,
#  (0.08, 3, False, 'squared_hinge'): 0.95011627906976737,
#  (0.08, 3, True, 'hinge'): 0.94495348837209314,
#  (0.08, 3, True, 'squared_hinge'): 0.94479069767441859,
#  (0.08, 4, False, 'squared_hinge'): 0.94895348837209303,
#  (0.08, 4, True, 'hinge'): 0.95111627906976748,
#  (0.08, 4, True, 'squared_hinge'): 0.94895348837209303,
#  (0.09, 0.1, False, 'squared_hinge'): 0.94662790697674415,
#  (0.09, 0.1, True, 'hinge'): 0.93830232558139526,
#  (0.09, 0.1, True, 'squared_hinge'): 0.9546046511627907,
#  (0.09, 0.2, False, 'squared_hinge'): 0.94779069767441848,
#  (0.09, 0.2, True, 'hinge'): 0.95095348837209293,
#  (0.09, 0.2, True, 'squared_hinge'): 0.9536046511627907,
#  (0.09, 0.4, False, 'squared_hinge'): 0.94662790697674415,
#  (0.09, 0.4, True, 'hinge'): 0.95127906976744181,
#  (0.09, 0.4, True, 'squared_hinge'): 0.94081395348837216,
#  (0.09, 0.5, False, 'squared_hinge'): 0.94662790697674415,
#  (0.09, 0.5, True, 'hinge'): 0.95393023255813958,
#  (0.09, 0.5, True, 'squared_hinge'): 0.93383720930232561,
#  (0.09, 1, False, 'squared_hinge'): 0.94662790697674415,
#  (0.09, 1, True, 'hinge'): 0.94446511627906971,
#  (0.09, 1, True, 'squared_hinge'): 0.95709302325581391,
#  (0.09, 2, False, 'squared_hinge'): 0.94662790697674415,
#  (0.09, 2, True, 'hinge'): 0.94097674418604649,
#  (0.09, 2, True, 'squared_hinge'): 0.93865116279069771,
#  (0.09, 3, False, 'squared_hinge'): 0.94662790697674415,
#  (0.09, 3, True, 'hinge'): 0.95127906976744181,
#  (0.09, 3, True, 'squared_hinge'): 0.93283720930232561,
#  (0.09, 4, False, 'squared_hinge'): 0.94662790697674415,
#  (0.09, 4, True, 'hinge'): 0.93381395348837215,
#  (0.09, 4, True, 'squared_hinge'): 0.95244186046511614,
#  (0.1, 0.1, False, 'squared_hinge'): 0.94546511627906971,
#  (0.1, 0.1, True, 'hinge'): 0.95293023255813958,
#  (0.1, 0.1, True, 'squared_hinge'): 0.95027906976744192,
#  (0.1, 0.2, False, 'squared_hinge'): 0.94546511627906971,
#  (0.1, 0.2, True, 'hinge'): 0.93383720930232561,
#  (0.1, 0.2, True, 'squared_hinge'): 0.95260465116279069,
#  (0.1, 0.4, False, 'squared_hinge'): 0.94546511627906971,
#  (0.1, 0.4, True, 'hinge'): 0.94313953488372104,
#  (0.1, 0.4, True, 'squared_hinge'): 0.93300000000000005,
#  (0.1, 0.5, False, 'squared_hinge'): 0.94546511627906971,
#  (0.1, 0.5, True, 'hinge'): 0.94462790697674426,
#  (0.1, 0.5, True, 'squared_hinge'): 0.94530232558139549,
#  (0.1, 1, False, 'squared_hinge'): 0.94662790697674415,
#  (0.1, 1, True, 'hinge'): 0.93583720930232561,
#  (0.1, 1, True, 'squared_hinge'): 0.94646511627906982,
#  (0.1, 2, False, 'squared_hinge'): 0.94546511627906971,
#  (0.1, 2, True, 'hinge'): 0.94462790697674426,
#  (0.1, 2, True, 'squared_hinge'): 0.93051162790697661,
#  (0.1, 3, False, 'squared_hinge'): 0.94546511627906971,
#  (0.1, 3, True, 'hinge'): 0.94413953488372093,
#  (0.1, 3, True, 'squared_hinge'): 0.93981395348837216,
#  (0.1, 4, False, 'squared_hinge'): 0.94546511627906971,
#  (0.1, 4, True, 'hinge'): 0.92686046511627906,
#  (0.1, 4, True, 'squared_hinge'): 0.93383720930232561,
#  (0.15, 0.1, False, 'squared_hinge'): 0.94197674418604649,
#  (0.15, 0.1, True, 'hinge'): 0.95909302325581403,
#  (0.15, 0.1, True, 'squared_hinge'): 0.93500000000000016,
#  (0.15, 0.2, False, 'squared_hinge'): 0.94313953488372082,
#  (0.15, 0.2, True, 'hinge'): 0.93283720930232561,
#  (0.15, 0.2, True, 'squared_hinge'): 0.92634883720930239,
#  (0.15, 0.4, False, 'squared_hinge'): 0.94197674418604649,
#  (0.15, 0.4, True, 'hinge'): 0.9477906976744187,
#  (0.15, 0.4, True, 'squared_hinge'): 0.94462790697674426,
#  (0.15, 0.5, False, 'squared_hinge'): 0.94430232558139537,
#  (0.15, 0.5, True, 'hinge'): 0.94265116279069772,
#  (0.15, 0.5, True, 'squared_hinge'): 0.93665116279069771,
#  (0.15, 1, False, 'squared_hinge'): 0.94197674418604649,
#  (0.15, 1, True, 'hinge'): 0.94313953488372082,
#  (0.15, 1, True, 'squared_hinge'): 0.95011627906976748,
#  (0.15, 2, False, 'squared_hinge'): 0.94313953488372082,
#  (0.15, 2, True, 'hinge'): 0.91788372093023263,
#  (0.15, 2, True, 'squared_hinge'): 0.9396511627906976,
#  (0.15, 3, False, 'squared_hinge'): 0.94313953488372082,
#  (0.15, 3, True, 'hinge'): 0.94779069767441848,
#  (0.15, 3, True, 'squared_hinge'): 0.93483720930232561,
#  (0.15, 4, False, 'squared_hinge'): 0.94197674418604649,
#  (0.15, 4, True, 'hinge'): 0.91804651162790696,
#  (0.15, 4, True, 'squared_hinge'): 0.94579069767441859,
#  (0.2, 0.1, False, 'squared_hinge'): 0.94313953488372082,
#  (0.2, 0.1, True, 'hinge'): 0.9280232558139534,
#  (0.2, 0.1, True, 'squared_hinge'): 0.95676744186046514,
#  (0.2, 0.2, False, 'squared_hinge'): 0.93997674418604649,
#  (0.2, 0.2, True, 'hinge'): 0.94895348837209303,
#  (0.2, 0.2, True, 'squared_hinge'): 0.92453488372093029,
#  (0.2, 0.4, False, 'squared_hinge'): 0.93997674418604649,
#  (0.2, 0.4, True, 'hinge'): 0.95593023255813958,
#  (0.2, 0.4, True, 'squared_hinge'): 0.93448837209302327,
#  (0.2, 0.5, False, 'squared_hinge'): 0.94197674418604649,
#  (0.2, 0.5, True, 'hinge'): 0.94595348837209303,
#  (0.2, 0.5, True, 'squared_hinge'): 0.94530232558139526,
#  (0.2, 1, False, 'squared_hinge'): 0.93997674418604649,
#  (0.2, 1, True, 'hinge'): 0.93151162790697684,
#  (0.2, 1, True, 'squared_hinge'): 0.94695348837209303,
#  (0.2, 2, False, 'squared_hinge'): 0.94113953488372082,
#  (0.2, 2, True, 'hinge'): 0.94313953488372082,
#  (0.2, 2, True, 'squared_hinge'): 0.95244186046511614,
#  (0.2, 3, False, 'squared_hinge'): 0.93997674418604649,
#  (0.2, 3, True, 'hinge'): 0.94430232558139537,
#  (0.2, 3, True, 'squared_hinge'): 0.95376744186046525,
#  (0.2, 4, False, 'squared_hinge'): 0.94113953488372082,
#  (0.2, 4, True, 'hinge'): 0.9536046511627907,
#  (0.2, 4, True, 'squared_hinge'): 0.94181395348837216,
#  (0.25, 0.1, False, 'squared_hinge'): 0.94097674418604649,
#  (0.25, 0.1, True, 'hinge'): 0.93497674418604659,
#  (0.25, 0.1, True, 'squared_hinge'): 0.93248837209302327,
#  (0.25, 0.2, False, 'squared_hinge'): 0.94097674418604649,
#  (0.25, 0.2, True, 'hinge'): 0.9487906976744187,
#  (0.25, 0.2, True, 'squared_hinge'): 0.94197674418604649,
#  (0.25, 0.4, False, 'squared_hinge'): 0.93997674418604649,
#  (0.25, 0.4, True, 'hinge'): 0.94097674418604649,
#  (0.25, 0.4, True, 'squared_hinge'): 0.9477906976744187,
#  (0.25, 0.5, False, 'squared_hinge'): 0.94213953488372104,
#  (0.25, 0.5, True, 'hinge'): 0.93383720930232561,
#  (0.25, 0.5, True, 'squared_hinge'): 0.94730232558139549,
#  (0.25, 1, False, 'squared_hinge'): 0.94213953488372104,
#  (0.25, 1, True, 'hinge'): 0.91755813953488374,
#  (0.25, 1, True, 'squared_hinge'): 0.9434651162790697,
#  (0.25, 2, False, 'squared_hinge'): 0.94213953488372104,
#  (0.25, 2, True, 'hinge'): 0.93865116279069771,
#  (0.25, 2, True, 'squared_hinge'): 0.94032558139534894,
#  (0.25, 3, False, 'squared_hinge'): 0.94213953488372104,
#  (0.25, 3, True, 'hinge'): 0.93697674418604637,
#  (0.25, 3, True, 'squared_hinge'): 0.9416511627906976,
#  (0.25, 4, False, 'squared_hinge'): 0.94213953488372104,
#  (0.25, 4, True, 'hinge'): 0.95244186046511636,
#  (0.25, 4, True, 'squared_hinge'): 0.93848837209302327,
#  (0.3, 0.1, False, 'squared_hinge'): 0.94113953488372082,
#  (0.3, 0.1, True, 'hinge'): 0.92918604651162795,
#  (0.3, 0.1, True, 'squared_hinge'): 0.95244186046511614,
#  (0.3, 0.2, False, 'squared_hinge'): 0.94113953488372082,
#  (0.3, 0.2, True, 'hinge'): 0.93448837209302327,
#  (0.3, 0.2, True, 'squared_hinge'): 0.94181395348837216,
#  (0.3, 0.4, False, 'squared_hinge'): 0.93997674418604649,
#  (0.3, 0.4, True, 'hinge'): 0.95076744186046525,
#  (0.3, 0.4, True, 'squared_hinge'): 0.93765116279069771,
#  (0.3, 0.5, False, 'squared_hinge'): 0.94113953488372082,
#  (0.3, 0.5, True, 'hinge'): 0.92351162790697683,
#  (0.3, 0.5, True, 'squared_hinge'): 0.92883720930232561,
#  (0.3, 1, False, 'squared_hinge'): 0.94097674418604649,
#  (0.3, 1, True, 'hinge'): 0.92237209302325573,
#  (0.3, 1, True, 'squared_hinge'): 0.94081395348837193,
#  (0.3, 2, False, 'squared_hinge'): 0.93997674418604649,
#  (0.3, 2, True, 'hinge'): 0.9406511627906976,
#  (0.3, 2, True, 'squared_hinge'): 0.94662790697674415,
#  (0.3, 3, False, 'squared_hinge'): 0.93997674418604649,
#  (0.3, 3, True, 'hinge'): 0.95276744186046525,
#  (0.3, 3, True, 'squared_hinge'): 0.9536046511627907,
#  (0.3, 4, False, 'squared_hinge'): 0.93997674418604649,
#  (0.3, 4, True, 'hinge'): 0.88730232558139532,
#  (0.3, 4, True, 'squared_hinge'): 0.93930232558139548,
#  (0.35, 0.1, False, 'squared_hinge'): 0.93997674418604649,
#  (0.35, 0.1, True, 'hinge'): 0.94362790697674404,
#  (0.35, 0.1, True, 'squared_hinge'): 0.93997674418604649,
#  (0.35, 0.2, False, 'squared_hinge'): 0.94113953488372082,
#  (0.35, 0.2, True, 'hinge'): 0.94927906976744192,
#  (0.35, 0.2, True, 'squared_hinge'): 0.95376744186046503,
#  (0.35, 0.4, False, 'squared_hinge'): 0.93997674418604649,
#  (0.35, 0.4, True, 'hinge'): 0.92834883720930228,
#  (0.35, 0.4, True, 'squared_hinge'): 0.91872093023255808,
#  (0.35, 0.5, False, 'squared_hinge'): 0.94113953488372082,
#  (0.35, 0.5, True, 'hinge'): 0.93416279069767438,
#  (0.35, 0.5, True, 'squared_hinge'): 0.9546046511627907,
#  (0.35, 1, False, 'squared_hinge'): 0.94113953488372082,
#  (0.35, 1, True, 'hinge'): 0.94727906976744192,
#  (0.35, 1, True, 'squared_hinge'): 0.94662790697674415,
#  (0.35, 2, False, 'squared_hinge'): 0.93997674418604649,
#  (0.35, 2, True, 'hinge'): 0.94530232558139526,
#  (0.35, 2, True, 'squared_hinge'): 0.91506976744186053,
#  (0.35, 3, False, 'squared_hinge'): 0.93997674418604649,
#  (0.35, 3, True, 'hinge'): 0.95027906976744192,
#  (0.35, 3, True, 'squared_hinge'): 0.93267441860465117,
#  (0.35, 4, False, 'squared_hinge'): 0.94113953488372082,
#  (0.35, 4, True, 'hinge'): 0.91323255813953497,
#  (0.35, 4, True, 'squared_hinge'): 0.94746511627906982,
#  (0.4, 0.1, False, 'squared_hinge'): 0.93997674418604649,
#  (0.4, 0.1, True, 'hinge'): 0.94895348837209303,
#  (0.4, 0.1, True, 'squared_hinge'): 0.94197674418604671,
#  (0.4, 0.2, False, 'squared_hinge'): 0.93981395348837216,
#  (0.4, 0.2, True, 'hinge'): 0.91920930232558151,
#  (0.4, 0.2, True, 'squared_hinge'): 0.91988372093023263,
#  (0.4, 0.4, False, 'squared_hinge'): 0.93881395348837204,
#  (0.4, 0.4, True, 'hinge'): 0.91920930232558129,
#  (0.4, 0.4, True, 'squared_hinge'): 0.95160465116279069,
#  (0.4, 0.5, False, 'squared_hinge'): 0.93881395348837204,
#  (0.4, 0.5, True, 'hinge'): 0.93267441860465117,
#  (0.4, 0.5, True, 'squared_hinge'): 0.93499999999999994,
#  (0.4, 1, False, 'squared_hinge'): 0.93997674418604649,
#  (0.4, 1, True, 'hinge'): 0.95593023255813958,
#  (0.4, 1, True, 'squared_hinge'): 0.93267441860465117,
#  (0.4, 2, False, 'squared_hinge'): 0.93997674418604649,
#  (0.4, 2, True, 'hinge'): 0.95276744186046503,
#  (0.4, 2, True, 'squared_hinge'): 0.94181395348837216,
#  (0.4, 3, False, 'squared_hinge'): 0.94113953488372082,
#  (0.4, 3, True, 'hinge'): 0.9556046511627907,
#  (0.4, 3, True, 'squared_hinge'): 0.95244186046511614,
#  (0.4, 4, False, 'squared_hinge'): 0.93997674418604649,
#  (0.4, 4, True, 'hinge'): 0.91755813953488374,
#  (0.4, 4, True, 'squared_hinge'): 0.95011627906976737,
#  (0.45, 0.1, False, 'squared_hinge'): 0.93997674418604649,
#  (0.45, 0.1, True, 'hinge'): 0.94081395348837193,
#  (0.45, 0.1, True, 'squared_hinge'): 0.94213953488372104,
#  (0.45, 0.2, False, 'squared_hinge'): 0.93997674418604649,
#  (0.45, 0.2, True, 'hinge'): 0.94197674418604649,
#  (0.45, 0.2, True, 'squared_hinge'): 0.95011627906976737,
#  (0.45, 0.4, False, 'squared_hinge'): 0.93997674418604649,
#  (0.45, 0.4, True, 'hinge'): 0.93948837209302327,
#  (0.45, 0.4, True, 'squared_hinge'): 0.95244186046511614,
#  (0.45, 0.5, False, 'squared_hinge'): 0.93765116279069771,
#  (0.45, 0.5, True, 'hinge'): 0.94811627906976759,
#  (0.45, 0.5, True, 'squared_hinge'): 0.93632558139534883,
#  (0.45, 1, False, 'squared_hinge'): 0.93881395348837204,
#  (0.45, 1, True, 'hinge'): 0.94081395348837216,
#  (0.45, 1, True, 'squared_hinge'): 0.92651162790697672,
#  (0.45, 2, False, 'squared_hinge'): 0.93997674418604649,
#  (0.45, 2, True, 'hinge'): 0.94595348837209303,
#  (0.45, 2, True, 'squared_hinge'): 0.94662790697674415,
#  (0.45, 3, False, 'squared_hinge'): 0.93881395348837204,
#  (0.45, 3, True, 'hinge'): 0.95127906976744181,
#  (0.45, 3, True, 'squared_hinge'): 0.92932558139534882,
#  (0.45, 4, False, 'squared_hinge'): 0.93781395348837204,
#  (0.45, 4, True, 'hinge'): 0.95111627906976748,
#  (0.45, 4, True, 'squared_hinge'): 0.9536046511627907,
#  (0.5, 0.1, False, 'squared_hinge'): 0.93765116279069771,
#  (0.5, 0.1, True, 'hinge'): 0.93151162790697684,
#  (0.5, 0.1, True, 'squared_hinge'): 0.93051162790697661,
#  (0.5, 0.2, False, 'squared_hinge'): 0.93665116279069771,
#  (0.5, 0.2, True, 'hinge'): 0.93681395348837204,
#  (0.5, 0.2, True, 'squared_hinge'): 0.93383720930232561,
#  (0.5, 0.4, False, 'squared_hinge'): 0.93881395348837204,
#  (0.5, 0.4, True, 'hinge'): 0.92918604651162795,
#  (0.5, 0.4, True, 'squared_hinge'): 0.92634883720930239,
#  (0.5, 0.5, False, 'squared_hinge'): 0.93765116279069771,
#  (0.5, 0.5, True, 'hinge'): 0.94595348837209303,
#  (0.5, 0.5, True, 'squared_hinge'): 0.95060465116279058,
#  (0.5, 1, False, 'squared_hinge'): 0.93781395348837204,
#  (0.5, 1, True, 'hinge'): 0.9506046511627908,
#  (0.5, 1, True, 'squared_hinge'): 0.94630232558139526,
#  (0.5, 2, False, 'squared_hinge'): 0.93997674418604649,
#  (0.5, 2, True, 'hinge'): 0.93732558139534883,
#  (0.5, 2, True, 'squared_hinge'): 0.90574418604651163,
#  (0.5, 3, False, 'squared_hinge'): 0.93997674418604649,
#  (0.5, 3, True, 'hinge'): 0.9467906976744187,
#  (0.5, 3, True, 'squared_hinge'): 0.94579069767441859,
#  (0.5, 4, False, 'squared_hinge'): 0.93997674418604649,
#  (0.5, 4, True, 'hinge'): 0.94330232558139537,
#  (0.5, 4, True, 'squared_hinge'): 0.93167441860465117}

# %%
# New stuff for ICLR
# 1.  Chamfer
# encoder_args: {'filter_sizes': [1, 1, 1, 1, 1], 'strides': [1, 1, 1, 1, 1], 'n_filters': [64, 128, 128, 256, 512], 'dropout_prob': [0, 0, 0, 0, 0.5], 'b_norm': True}
# decoder_args: {'b_norm': True, 'layer_sizes': [512, 1024, 6144]}
# -> @ 980 epochs of training: best was on model-net40:
# 0.6 1 True hinge
# 0.840083537332
# -> @ 1620 epochs of training: best was on model-net40:
# 0.4 1 False squared_hinge
# 0.843783353733
# at @ 2000 epochs of training: best was on model-net40:
# (0.3, 0.2, False, 'squared_hinge'), 0.84087423500612002)


# FROM NIPS
# USING ALL ShapeNetCore DATA : ~57K models.
# Training at (max) 2K epochs.

# EMD, 2K, model_net_40
# 1.0 3 False squared_hinge
# 0.844814259486
# 1.0 3 True squared_hinge
# 0.844814259486

# EMD, 2K, model_net_10
# 0.4 2 True hinge
# 0.953279069767


# Chamfer, 2K model_net_40
# 0.3 4 False squared_hinge
# 0.856074051408
# 0.3 4 True squared_hinge
# 0.856074051408
# 0.6 1 False squared_hinge
# 0.856264075887
# 0.3 4 False squared_hinge
# 0.856074051408
# 0.6 1 False squared_hinge
# 0.856264075887
# 0.6 1 True squared_hinge
# 0.856264075887
# 0.7 1 False squared_hinge
# 0.856764075887

# Chamfer, 2K model_net_10
# 0.9 4 True hinge
# 0.950790697674
# 0.950790697674
# 0.8 0.5 False squared_hinge

# 1.0 4 True hinge
# 0.950790697674
# 1.0 3 True hinge
# 0.950790697674
# 0.9 4 True hinge
# 0.950790697674

# 0.7 4 True hinge
# 0.950790697674


# With WU 7 Classes:

# M10, CD, 2K epochs
# 0.4 4 True hinge
# 0.95176744186

# M40, CD, 2K epochs
# 1.0 1 True hinge
# 0.84410495716

# M10, EMD, ~2.5K epochs
# about 0.94

# M40, EMD, ~2.5K epochs
# about 0.83

# %%
# all_flower_pots = test_feed[np.array(cids_) == 15]
# for i in range(len(all_flower_pots)):
#     Point_Cloud(all_flower_pots[i]).plot()
    
# y_pred = lsvc.predict(test_latent)
# gt_labels = np.array(cids_)

# scores_per_class = []

# for c in np.unique(gt_labels):
#     if c == 15:
#         scores_per_class.append(0.5)    
#         continue
#     index_c = gt_labels == c
#     n_class = float(np.sum(index_c))
#     s = np.sum(gt_labels[index_c] == y_pred[index_c])
#     s /= n_class
#     scores_per_class.append(s)
# print np.mean(scores_per_class)
