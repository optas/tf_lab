# %%
import numpy as np
from skimage import measure
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from geo_tool import Point_Cloud
from geo_tool import Mesh

# %%
# [1, 251, 501, 751, 1001, ]
for x in  range(1, 2001, 250):
    in_f = '/orions4-zfs/projects/optas/DATA/Meshes/SMPL_8_poses/Shape' + str(x) + '.off'
    in_m = Mesh(file_name = in_f)
    Point_Cloud(in_m.sample_faces(8128)[0]).plot(in_u_sphere=False)

# %%
# %matplotlib inline
# %matplotlib nbagg

# %%
X,Y,Z = np.mgrid[-2:2:40j, -2:2:40j, -2:2:40j]
surf_eq = X**4 + Y**4 + Z**4 - (X**2+Y**2+Z**2)**2 + 3*(X**2+Y**2+Z**2) - 3

# %%
verts, faces, normals, values = measure.marching_cubes(surf_eq, 0)
x, y, z = zip(*verts)

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection='3d')

# Fancy indexing: `verts[faces]` to generate a collection of triangles
mesh = Poly3DCollection(verts[faces])
mesh.set_edgecolor('k')
ax.add_collection3d(mesh)

ax.set_xlabel("x-axis: a = 6 per ellipsoid")
ax.set_ylabel("y-axis: b = 10")
ax.set_zlabel("z-axis: c = 16")

ax.set_xlim(0, 40)
ax.set_ylim(0, 40)
ax.set_zlim(0, 40)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# Point_Cloud(verts).plot(in_u_sphere=False)
