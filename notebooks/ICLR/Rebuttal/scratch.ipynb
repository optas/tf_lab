# %%
from tf_lab.data_sets.shape_net import snc_category_to_synth_id

# %%
snc_category_to_synth_id()['car']
# Out:
# '02958343'

# %%
from geo_tool import Point_Cloud
import numpy as np

# %%
# %matplotlib inline

# %%
plt.close(f)

# %%
f = Point_Cloud(all_pcs[i]).plot(azim=55)

# %%
import matplotlib.pylab as plt

# %%
all_pcs = '/orions4-zfs/projects/optas/DATA/OUT/iclr/synthetic_samples/voxel_based/gmm/ae_chair_sn_vox_data_32_voxels_64_bneck/samples_with_lcc.npz'
all_pcs = np.load(all_pcs)
all_pcs = all_pcs[all_pcs.keys()[0]]

# %%
selected = [50, 8, 14, 4, 27, 23, 25, 29, 37, 45]

# %%
for i, s in enumerate(selected):
    np.savetxt('%d.txt'%(i,), all_pcs[s])
    f = Point_Cloud(all_pcs[s]).plot(azim=55);
    f.savefig('%d.pdf'%(i,))
