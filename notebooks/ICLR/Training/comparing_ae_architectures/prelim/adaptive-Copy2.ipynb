# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 2
setup_one_gpu(GPU)
# Out:
# Picking GPU 2

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from functools import partial

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter
from tf_lab.point_clouds.ae_templates import conv_architecture_ala_nips_17, default_train_params_ala_nips_17

from tf_lab.point_clouds.encoders_decoders import decoder_with_fc_only,\
encoder_with_convs_and_symmetry_new, decoder_with_convs_only

from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder

from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tflearn.layers.conv import avg_pool_1d
from pc_completions.evaluation import basic_comletion_measures

from tflearn.layers.conv import conv_1d, highway_conv_1d, avg_pool_1d, max_pool_1d
from tf_lab.fundamentals.layers import conv_1d_tranpose

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
exp_id = -1
n_pc_points = 2048
random_seed = 42
top_data_dir = '/orions4-zfs/projects/optas/DATA'
train_dir = osp.join(top_data_dir, 'OUT/iclr/nn_models/testing_ae_settings/ae_variants_2', str(exp_id))

# %%
def load_multiple_version_of_pcs():
#     versions = ['centered', 'centered_2nd_version', 'centered_3rd_version']
#     versions = ['fps_sampled_in_u_sphere']    
    versions = ['fps_sampled_in_u_sphere_fiedler_sorted']
    
    splits = {'train':None, 'val':None, 'test': None}
        
    for s in splits.keys():
        print 'Loading %s data.' % (s,)
        s_file = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/', s + '.txt')
        print s_file
        for i, v in enumerate(versions):
            top_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', v, str(n_pc_points))                
            splitter = Data_Splitter(top_pclouds_path, data_file_ending='.ply', random_seed=random_seed)
            pcs_in_split = splitter.load_splits(s_file)                
            pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(pcs_in_split, n_threads=20, loader=snc_loader, verbose=True)        
            if splits[s] is None:
                splits[s] = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)
            else:
                splits[s].merge(PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids))
    return splits

# %%
in_data  = load_multiple_version_of_pcs()
# Out:
# Loading test data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/test.txt
# 679 pclouds were loaded. They belong in 1 shape-classes.
# Loading train data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/train.txt
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# Loading val data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/val.txt
# 338 pclouds were loaded. They belong in 1 shape-classes.

# %%
do_training = True
load_pretrained_model = False
load_epoch = None
loss = 'chamfer'
training_epochs = 500
batch_size = 50
learning_rate = 0.0005

# %%
def enc_dec_templates():
    b_norm = True        
    encoder = encoder_with_convs_and_symmetry_new
    decoder = decoder_with_fc_only
    conv_op = conv_1d

    encoder_args = {'n_filters': [32, 64, 128, 256, 32],
            'filter_sizes': [2, 2, 2, 2, 2],
            'strides': [1, 1, 1, 1, 1],
            'b_norm': b_norm,
            'pool': None,
            'pool_sizes': [2, None, 2, None, None],
            'verbose': True,
            'conv_op': conv_op,
            'symmetry': None
            }

    decoder_args= {'layer_sizes': [32, 256, 2048*3],
                   'verbose': True,
                   'b_norm': b_norm,
                   'non_linearity': tf.nn.relu
                  }
    return encoder, decoder, encoder_args, decoder_args

# %%
reset_tf_graph()
encoder, decoder, encoder_args, decoder_args = enc_dec_templates()
print encoder_args

# layer = tf.placeholder(tf.float32, [None, n_pc_points, 3])
# layer = encoder(layer, **encoder_args)
# layer = decoder(layer, **decoder_args)
# Out:
# {'filter_sizes': [2, 2, 2, 2, 2], 'n_filters': [32, 64, 128, 256, 32], 'verbose': True, 'symmetry': None, 'strides': [1, 1, 1, 1, 1], 'conv_op': <function conv_1d at 0x7fbfbece5320>, 'pool_sizes': [2, None, 2, None, None], 'b_norm': True, 'pool': None}

# %%
if load_pretrained_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    if conf.train_dir != train_dir:
        conf.train_dir = train_dir
#     conf.save(osp.join(train_dir, 'configuration'))
else:    
    conf = Conf(
                n_input = [n_pc_points, 3],
                loss = loss,
                training_epochs = training_epochs,
                batch_size = batch_size,
                denoising = False,
                learning_rate = learning_rate,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = None,
                z_rotate = False,
                encoder = encoder,
                decoder = decoder,
                encoder_args = encoder_args,
                decoder_args = decoder_args
               )

conf.experiment_name = 'experiment_' + str(exp_id)
conf.held_out_step = 5
reset_tf_graph()
ae = PointNetAutoEncoder(conf.experiment_name, conf)
print ae.trainable_parameters()
# Out:
# Building Encoder
# encoder_conv_layer_0 conv params =  224 bnorm params =  64
# Tensor("experiment_-1_1/Relu:0", shape=(?, 2048, 32), dtype=float32)
# output size: 65536
#
# encoder_conv_layer_1 conv params =  4160 bnorm params =  128
# Tensor("experiment_-1_1/Relu_1:0", shape=(?, 2048, 64), dtype=float32)
# output size: 131072
#
# encoder_conv_layer_2 conv params =  16512 bnorm params =  256
# Tensor("experiment_-1_1/Relu_2:0", shape=(?, 2048, 128), dtype=float32)
# output size: 262144
#
# encoder_conv_layer_3 conv params =  65792 bnorm params =  512
# Tensor("experiment_-1_1/Relu_3:0", shape=(?, 2048, 256), dtype=float32)
# output size: 524288
#
# encoder_conv_layer_4 conv params =  16416 bnorm params =  64
# Tensor("experiment_-1_1/Relu_4:0", shape=(?, 2048, 32), dtype=float32)
# output size: 65536
#
# Building Decoder
# decoder_fc_0 FC params =  2097184 bnorm params =  64
# Tensor("experiment_-1_1/Relu_5:0", shape=(?, 32), dtype=float32)
# output size: 32
#
# decoder_fc_1 FC params =  8448 bnorm params =  512
# Tensor("experiment_-1_1/Relu_6:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# decoder_fc_2 FC params =  1579008 Tensor("experiment_-1_1/decoder_fc_2/BiasAdd:0", shape=(?, 6144), dtype=float32)
# output size: 6144
#
# 3789344

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)     
    train_stats = ae.train(in_data['train'], conf, log_file=fout, held_out_data=in_data['test'])
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.2165', 'loss=', '0.004514736')
# ('Epoch:', '0002', 'training time (minutes)=', '0.2126', 'loss=', '0.002780949')
# ('Epoch:', '0003', 'training time (minutes)=', '0.2276', 'loss=', '0.002481153')
# ('Epoch:', '0004', 'training time (minutes)=', '0.2156', 'loss=', '0.002305290')
# ('Epoch:', '0005', 'training time (minutes)=', '0.2195', 'loss=', '0.002083237')
# ('Held Out Data :', 'forward time (minutes)=', '0.0060', 'loss=', '0.002009234')
# ('Epoch:', '0006', 'training time (minutes)=', '0.2301', 'loss=', '0.002016362')
# ('Epoch:', '0007', 'training time (minutes)=', '0.2099', 'loss=', '0.001927310')
# ('Epoch:', '0008', 'training time (minutes)=', '0.2174', 'loss=', '0.001854744')
# ('Epoch:', '0009', 'training time (minutes)=', '0.1462', 'loss=', '0.001791328')
# ('Epoch:', '0010', 'training time (minutes)=', '0.1244', 'loss=', '0.001751778')
# ('Held Out Data :', 'forward time (minutes)=', '0.0035', 'loss=', '0.001843487')
# ('Epoch:', '0011', 'training time (minutes)=', '0.1235', 'loss=', '0.001760943')
# ('Epoch:', '0012', 'training time (minutes)=', '0.1287', 'loss=', '0.001656087')
# ('Epoch:', '0013', 'training time (minutes)=', '0.1270', 'loss=', '0.001594800')
# ('Epoch:', '0014', 'training time (minutes)=', '0.1250', 'loss=', '0.001582504')
# ('Epoch:', '0015', 'training time (minutes)=', '0.1275', 'loss=', '0.001504372')
# ('Held Out Data :', 'forward time (minutes)=', '0.0037', 'loss=', '0.001664386')
# ('Epoch:', '0016', 'training time (minutes)=', '0.1230', 'loss=', '0.001536392')
# ('Epoch:', '0017', 'training time (minutes)=', '0.1283', 'loss=', '0.001538071')
# ('Epoch:', '0018', 'training time (minutes)=', '0.1261', 'loss=', '0.001488913')
# ('Epoch:', '0019', 'training time (minutes)=', '0.1254', 'loss=', '0.001421344')
# ('Epoch:', '0020', 'training time (minutes)=', '0.1240', 'loss=', '0.001418335')
# ('Held Out Data :', 'forward time (minutes)=', '0.0037', 'loss=', '0.001613806')
# ('Epoch:', '0021', 'training time (minutes)=', '0.1972', 'loss=', '0.001406517')
# ('Epoch:', '0022', 'training time (minutes)=', '0.2540', 'loss=', '0.001359163')
# ('Epoch:', '0023', 'training time (minutes)=', '0.2509', 'loss=', '0.001317141')
# ('Epoch:', '0024', 'training time (minutes)=', '0.2522', 'loss=', '0.001310282')
# ('Epoch:', '0025', 'training time (minutes)=', '0.2289', 'loss=', '0.001287165')
# ('Held Out Data :', 'forward time (minutes)=', '0.0052', 'loss=', '0.001593585')
# ('Epoch:', '0026', 'training time (minutes)=', '0.2145', 'loss=', '0.001274011')
# ('Epoch:', '0027', 'training time (minutes)=', '0.2203', 'loss=', '0.001268980')
# ('Epoch:', '0028', 'training time (minutes)=', '0.2108', 'loss=', '0.001280933')
# ('Epoch:', '0029', 'training time (minutes)=', '0.2175', 'loss=', '0.001245945')
# ('Epoch:', '0030', 'training time (minutes)=', '0.2133', 'loss=', '0.001212649')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001505330')
# ('Epoch:', '0031', 'training time (minutes)=', '0.2179', 'loss=', '0.001199107')
# ('Epoch:', '0032', 'training time (minutes)=', '0.2208', 'loss=', '0.001209924')
# ('Epoch:', '0033', 'training time (minutes)=', '0.2187', 'loss=', '0.001171241')
# ('Epoch:', '0034', 'training time (minutes)=', '0.2168', 'loss=', '0.001154547')
# ('Epoch:', '0035', 'training time (minutes)=', '0.2173', 'loss=', '0.001158192')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.001500843')
# ('Epoch:', '0036', 'training time (minutes)=', '0.2219', 'loss=', '0.001168153')
# ('Epoch:', '0037', 'training time (minutes)=', '0.2111', 'loss=', '0.001135629')
# ('Epoch:', '0038', 'training time (minutes)=', '0.2113', 'loss=', '0.001149872')
# ('Epoch:', '0039', 'training time (minutes)=', '0.2137', 'loss=', '0.001104709')
# ('Epoch:', '0040', 'training time (minutes)=', '0.2220', 'loss=', '0.001096765')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001400158')
# ('Epoch:', '0041', 'training time (minutes)=', '0.2113', 'loss=', '0.001075687')
# ('Epoch:', '0042', 'training time (minutes)=', '0.2177', 'loss=', '0.001090682')
# ('Epoch:', '0043', 'training time (minutes)=', '0.2035', 'loss=', '0.001073794')
# ('Epoch:', '0044', 'training time (minutes)=', '0.2055', 'loss=', '0.001101274')
# ('Epoch:', '0045', 'training time (minutes)=', '0.2148', 'loss=', '0.001068674')
# ('Held Out Data :', 'forward time (minutes)=', '0.0053', 'loss=', '0.001412622')
# ('Epoch:', '0046', 'training time (minutes)=', '0.2182', 'loss=', '0.001048643')
# ('Epoch:', '0047', 'training time (minutes)=', '0.2156', 'loss=', '0.001051821')
# ('Epoch:', '0048', 'training time (minutes)=', '0.2189', 'loss=', '0.001078925')
# ('Epoch:', '0049', 'training time (minutes)=', '0.1240', 'loss=', '0.001028476')
# ('Epoch:', '0050', 'training time (minutes)=', '0.1268', 'loss=', '0.001028923')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001366919')
# ('Epoch:', '0051', 'training time (minutes)=', '0.1242', 'loss=', '0.001043619')
# ('Epoch:', '0052', 'training time (minutes)=', '0.1231', 'loss=', '0.001033065')
# ('Epoch:', '0053', 'training time (minutes)=', '0.1259', 'loss=', '0.001045080')
# ('Epoch:', '0054', 'training time (minutes)=', '0.1247', 'loss=', '0.001009854')
# ('Epoch:', '0055', 'training time (minutes)=', '0.1255', 'loss=', '0.001037350')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001417404')
# ('Epoch:', '0056', 'training time (minutes)=', '0.1254', 'loss=', '0.000989722')
# ('Epoch:', '0057', 'training time (minutes)=', '0.1245', 'loss=', '0.001015674')
# ('Epoch:', '0058', 'training time (minutes)=', '0.1237', 'loss=', '0.000990245')
# ('Epoch:', '0059', 'training time (minutes)=', '0.1277', 'loss=', '0.000999113')
# ('Epoch:', '0060', 'training time (minutes)=', '0.1252', 'loss=', '0.000981361')
# ('Held Out Data :', 'forward time (minutes)=', '0.0038', 'loss=', '0.001375760')
# ('Epoch:', '0061', 'training time (minutes)=', '0.2224', 'loss=', '0.000979802')
# ('Epoch:', '0062', 'training time (minutes)=', '0.2484', 'loss=', '0.000985483')
# ('Epoch:', '0063', 'training time (minutes)=', '0.2489', 'loss=', '0.000954306')
# ('Epoch:', '0064', 'training time (minutes)=', '0.2478', 'loss=', '0.000948710')
# ('Epoch:', '0065', 'training time (minutes)=', '0.2320', 'loss=', '0.000958156')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.001411109')
# ('Epoch:', '0066', 'training time (minutes)=', '0.2146', 'loss=', '0.000961037')
# ('Epoch:', '0067', 'training time (minutes)=', '0.2104', 'loss=', '0.000935170')
# ('Epoch:', '0068', 'training time (minutes)=', '0.2230', 'loss=', '0.000942972')
# ('Epoch:', '0069', 'training time (minutes)=', '0.2122', 'loss=', '0.000934692')
# ('Epoch:', '0070', 'training time (minutes)=', '0.2181', 'loss=', '0.000933297')
# ('Held Out Data :', 'forward time (minutes)=', '0.0052', 'loss=', '0.001389447')
# ('Epoch:', '0071', 'training time (minutes)=', '0.2167', 'loss=', '0.000923616')
# ('Epoch:', '0072', 'training time (minutes)=', '0.2118', 'loss=', '0.000929690')
# ('Epoch:', '0073', 'training time (minutes)=', '0.2154', 'loss=', '0.000919287')
# ('Epoch:', '0074', 'training time (minutes)=', '0.2183', 'loss=', '0.000898922')
# ('Epoch:', '0075', 'training time (minutes)=', '0.2142', 'loss=', '0.000925906')
# ('Held Out Data :', 'forward time (minutes)=', '0.0046', 'loss=', '0.001359690')
# ('Epoch:', '0076', 'training time (minutes)=', '0.2074', 'loss=', '0.000901561')
# ('Epoch:', '0077', 'training time (minutes)=', '0.2195', 'loss=', '0.000905035')
# ('Epoch:', '0078', 'training time (minutes)=', '0.2160', 'loss=', '0.000969673')
# ('Epoch:', '0079', 'training time (minutes)=', '0.2232', 'loss=', '0.000903844')
# ('Epoch:', '0080', 'training time (minutes)=', '0.2134', 'loss=', '0.000895135')
# ('Held Out Data :', 'forward time (minutes)=', '0.0047', 'loss=', '0.001363984')
# ('Epoch:', '0081', 'training time (minutes)=', '0.2198', 'loss=', '0.000893774')
# ('Epoch:', '0082', 'training time (minutes)=', '0.2115', 'loss=', '0.000885184')
# ('Epoch:', '0083', 'training time (minutes)=', '0.2123', 'loss=', '0.000896541')
# ('Epoch:', '0084', 'training time (minutes)=', '0.2132', 'loss=', '0.000875375')
# ('Epoch:', '0085', 'training time (minutes)=', '0.2149', 'loss=', '0.000866164')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001351020')
# ('Epoch:', '0086', 'training time (minutes)=', '0.2201', 'loss=', '0.000871756')
# ('Epoch:', '0087', 'training time (minutes)=', '0.2108', 'loss=', '0.000879457')
# ('Epoch:', '0088', 'training time (minutes)=', '0.1773', 'loss=', '0.000880290')
# ('Epoch:', '0089', 'training time (minutes)=', '0.1293', 'loss=', '0.000884671')
# ('Epoch:', '0090', 'training time (minutes)=', '0.1246', 'loss=', '0.000874576')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.001368942')
# ('Epoch:', '0091', 'training time (minutes)=', '0.1239', 'loss=', '0.000855927')
# ('Epoch:', '0092', 'training time (minutes)=', '0.1251', 'loss=', '0.000869359')
# ('Epoch:', '0093', 'training time (minutes)=', '0.1242', 'loss=', '0.000846923')
# ('Epoch:', '0094', 'training time (minutes)=', '0.1237', 'loss=', '0.000859892')
# ('Epoch:', '0095', 'training time (minutes)=', '0.1238', 'loss=', '0.000843437')
# ('Held Out Data :', 'forward time (minutes)=', '0.0037', 'loss=', '0.001338554')
# ('Epoch:', '0096', 'training time (minutes)=', '0.1251', 'loss=', '0.000853832')
# ('Epoch:', '0097', 'training time (minutes)=', '0.1246', 'loss=', '0.000848165')
# ('Epoch:', '0098', 'training time (minutes)=', '0.1259', 'loss=', '0.000862857')
# ('Epoch:', '0099', 'training time (minutes)=', '0.1232', 'loss=', '0.000831863')
# ('Epoch:', '0100', 'training time (minutes)=', '0.1421', 'loss=', '0.000830645')
# ('Held Out Data :', 'forward time (minutes)=', '0.0074', 'loss=', '0.001359061')
# ('Epoch:', '0101', 'training time (minutes)=', '0.2538', 'loss=', '0.000819560')
# ('Epoch:', '0102', 'training time (minutes)=', '0.2486', 'loss=', '0.000828386')
# ('Epoch:', '0103', 'training time (minutes)=', '0.2467', 'loss=', '0.000831633')
# ('Epoch:', '0104', 'training time (minutes)=', '0.2559', 'loss=', '0.000814351')
# ('Epoch:', '0105', 'training time (minutes)=', '0.2133', 'loss=', '0.000824335')
# ('Held Out Data :', 'forward time (minutes)=', '0.0050', 'loss=', '0.001350532')
# ('Epoch:', '0106', 'training time (minutes)=', '0.2064', 'loss=', '0.000824504')
# ('Epoch:', '0107', 'training time (minutes)=', '0.2182', 'loss=', '0.000816681')
# ('Epoch:', '0108', 'training time (minutes)=', '0.1896', 'loss=', '0.000823885')
# ('Epoch:', '0109', 'training time (minutes)=', '0.2131', 'loss=', '0.000809023')
# ('Epoch:', '0110', 'training time (minutes)=', '0.2161', 'loss=', '0.000808815')
# ('Held Out Data :', 'forward time (minutes)=', '0.0045', 'loss=', '0.001354914')
# ('Epoch:', '0111', 'training time (minutes)=', '0.2203', 'loss=', '0.000827018')
# ('Epoch:', '0112', 'training time (minutes)=', '0.2201', 'loss=', '0.000827080')
# ('Epoch:', '0113', 'training time (minutes)=', '0.1836', 'loss=', '0.000816202')
# ('Epoch:', '0114', 'training time (minutes)=', '0.2073', 'loss=', '0.000791994')
# ('Epoch:', '0115', 'training time (minutes)=', '0.2198', 'loss=', '0.000788328')
# ('Held Out Data :', 'forward time (minutes)=', '0.0052', 'loss=', '0.001381270')
# ('Epoch:', '0116', 'training time (minutes)=', '0.2163', 'loss=', '0.000809997')
# ('Epoch:', '0117', 'training time (minutes)=', '0.2180', 'loss=', '0.000794238')
# ('Epoch:', '0118', 'training time (minutes)=', '0.2238', 'loss=', '0.000798634')
# ('Epoch:', '0119', 'training time (minutes)=', '0.2175', 'loss=', '0.000800905')
# ('Epoch:', '0120', 'training time (minutes)=', '0.2225', 'loss=', '0.000783684')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.001360882')
# ('Epoch:', '0121', 'training time (minutes)=', '0.2203', 'loss=', '0.000780170')
# ('Epoch:', '0122', 'training time (minutes)=', '0.2182', 'loss=', '0.000789829')
# ('Epoch:', '0123', 'training time (minutes)=', '0.2169', 'loss=', '0.000784916')
# ('Epoch:', '0124', 'training time (minutes)=', '0.2274', 'loss=', '0.000782062')
# ('Epoch:', '0125', 'training time (minutes)=', '0.2107', 'loss=', '0.000798403')
# ('Held Out Data :', 'forward time (minutes)=', '0.0060', 'loss=', '0.001393747')
# ('Epoch:', '0126', 'training time (minutes)=', '0.2277', 'loss=', '0.000781021')
# ('Epoch:', '0127', 'training time (minutes)=', '0.2233', 'loss=', '0.000781107')
# ('Epoch:', '0128', 'training time (minutes)=', '0.1729', 'loss=', '0.000766594')
# ('Epoch:', '0129', 'training time (minutes)=', '0.1252', 'loss=', '0.000776577')
# ('Epoch:', '0130', 'training time (minutes)=', '0.1275', 'loss=', '0.000772753')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001414139')
# ('Epoch:', '0131', 'training time (minutes)=', '0.1239', 'loss=', '0.000781698')
# ('Epoch:', '0132', 'training time (minutes)=', '0.1247', 'loss=', '0.000774605')
# ('Epoch:', '0133', 'training time (minutes)=', '0.1238', 'loss=', '0.000757999')
# ('Epoch:', '0134', 'training time (minutes)=', '0.1307', 'loss=', '0.000765895')
# ('Epoch:', '0135', 'training time (minutes)=', '0.1255', 'loss=', '0.000771365')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.001394483')
# ('Epoch:', '0136', 'training time (minutes)=', '0.1258', 'loss=', '0.000779790')
# ('Epoch:', '0137', 'training time (minutes)=', '0.1262', 'loss=', '0.000770302')
# ('Epoch:', '0138', 'training time (minutes)=', '0.1258', 'loss=', '0.000755547')
# ('Epoch:', '0139', 'training time (minutes)=', '0.1264', 'loss=', '0.000764087')
# ('Epoch:', '0140', 'training time (minutes)=', '0.1370', 'loss=', '0.000753357')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001382833')
# ('Epoch:', '0141', 'training time (minutes)=', '0.2496', 'loss=', '0.000780673')
# ('Epoch:', '0142', 'training time (minutes)=', '0.2483', 'loss=', '0.000766322')
# ('Epoch:', '0143', 'training time (minutes)=', '0.2574', 'loss=', '0.000761195')
# ('Epoch:', '0144', 'training time (minutes)=', '0.2462', 'loss=', '0.000750879')
# ('Epoch:', '0145', 'training time (minutes)=', '0.2170', 'loss=', '0.000740437')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001401276')
# ('Epoch:', '0146', 'training time (minutes)=', '0.2208', 'loss=', '0.000772477')
# ('Epoch:', '0147', 'training time (minutes)=', '0.2175', 'loss=', '0.000749900')
# ('Epoch:', '0148', 'training time (minutes)=', '0.2150', 'loss=', '0.000744712')
# ('Epoch:', '0149', 'training time (minutes)=', '0.2170', 'loss=', '0.000734941')
# ('Epoch:', '0150', 'training time (minutes)=', '0.2107', 'loss=', '0.000757463')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001397082')
# ('Epoch:', '0151', 'training time (minutes)=', '0.2257', 'loss=', '0.000735986')
# ('Epoch:', '0152', 'training time (minutes)=', '0.2163', 'loss=', '0.000755487')
# ('Epoch:', '0153', 'training time (minutes)=', '0.2178', 'loss=', '0.000739237')
# ('Epoch:', '0154', 'training time (minutes)=', '0.1595', 'loss=', '0.000729404')
# ('Epoch:', '0155', 'training time (minutes)=', '0.2125', 'loss=', '0.000733342')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001400033')
# ('Epoch:', '0156', 'training time (minutes)=', '0.2201', 'loss=', '0.000740966')
# ('Epoch:', '0157', 'training time (minutes)=', '0.2171', 'loss=', '0.000734214')
# ('Epoch:', '0158', 'training time (minutes)=', '0.2237', 'loss=', '0.000812149')
# ('Epoch:', '0159', 'training time (minutes)=', '0.2149', 'loss=', '0.000752686')
# ('Epoch:', '0160', 'training time (minutes)=', '0.2236', 'loss=', '0.000757884')
# ('Held Out Data :', 'forward time (minutes)=', '0.0050', 'loss=', '0.001424224')
# ('Epoch:', '0161', 'training time (minutes)=', '0.2184', 'loss=', '0.000733877')
# ('Epoch:', '0162', 'training time (minutes)=', '0.2085', 'loss=', '0.000745669')
# ('Epoch:', '0163', 'training time (minutes)=', '0.2316', 'loss=', '0.000740178')
# ('Epoch:', '0164', 'training time (minutes)=', '0.2204', 'loss=', '0.000733817')
# ('Epoch:', '0165', 'training time (minutes)=', '0.2148', 'loss=', '0.000725579')
# ('Held Out Data :', 'forward time (minutes)=', '0.0047', 'loss=', '0.001387755')
# ('Epoch:', '0166', 'training time (minutes)=', '0.2166', 'loss=', '0.000721835')
# ('Epoch:', '0167', 'training time (minutes)=', '0.2257', 'loss=', '0.000726804')
# ('Epoch:', '0168', 'training time (minutes)=', '0.1554', 'loss=', '0.000723002')
# ('Epoch:', '0169', 'training time (minutes)=', '0.1259', 'loss=', '0.000725985')
# ('Epoch:', '0170', 'training time (minutes)=', '0.1234', 'loss=', '0.000732689')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.001395138')
# ('Epoch:', '0171', 'training time (minutes)=', '0.1305', 'loss=', '0.000717784')
# ('Epoch:', '0172', 'training time (minutes)=', '0.1257', 'loss=', '0.000729296')
# ('Epoch:', '0173', 'training time (minutes)=', '0.1249', 'loss=', '0.000712749')
# ('Epoch:', '0174', 'training time (minutes)=', '0.1261', 'loss=', '0.000720419')
# ('Epoch:', '0175', 'training time (minutes)=', '0.1240', 'loss=', '0.000705714')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.001398274')
# ('Epoch:', '0176', 'training time (minutes)=', '0.1242', 'loss=', '0.000723473')
# ('Epoch:', '0177', 'training time (minutes)=', '0.1239', 'loss=', '0.000709558')
# ('Epoch:', '0178', 'training time (minutes)=', '0.1270', 'loss=', '0.000730710')
# ('Epoch:', '0179', 'training time (minutes)=', '0.1273', 'loss=', '0.000719844')
# ('Epoch:', '0180', 'training time (minutes)=', '0.1764', 'loss=', '0.000725137')
# ('Held Out Data :', 'forward time (minutes)=', '0.0071', 'loss=', '0.001399790')
# ('Epoch:', '0181', 'training time (minutes)=', '0.2475', 'loss=', '0.000717491')
# ('Epoch:', '0182', 'training time (minutes)=', '0.2518', 'loss=', '0.000714693')
# ('Epoch:', '0183', 'training time (minutes)=', '0.2467', 'loss=', '0.000725862')
# ('Epoch:', '0184', 'training time (minutes)=', '0.2350', 'loss=', '0.000708124')
# ('Epoch:', '0185', 'training time (minutes)=', '0.2182', 'loss=', '0.000699057')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001403859')
# ('Epoch:', '0186', 'training time (minutes)=', '0.2254', 'loss=', '0.000722489')
# ('Epoch:', '0187', 'training time (minutes)=', '0.2163', 'loss=', '0.000716713')
# ('Epoch:', '0188', 'training time (minutes)=', '0.2159', 'loss=', '0.000707225')
# ('Epoch:', '0189', 'training time (minutes)=', '0.2155', 'loss=', '0.000698284')
# ('Epoch:', '0190', 'training time (minutes)=', '0.2144', 'loss=', '0.000704928')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001409203')
# ('Epoch:', '0191', 'training time (minutes)=', '0.2106', 'loss=', '0.000704886')
# ('Epoch:', '0192', 'training time (minutes)=', '0.2140', 'loss=', '0.000700194')
# ('Epoch:', '0193', 'training time (minutes)=', '0.2146', 'loss=', '0.000718908')
# ('Epoch:', '0194', 'training time (minutes)=', '0.2179', 'loss=', '0.000713549')
# ('Epoch:', '0195', 'training time (minutes)=', '0.2101', 'loss=', '0.000706412')
# ('Held Out Data :', 'forward time (minutes)=', '0.0056', 'loss=', '0.001427799')
# ('Epoch:', '0196', 'training time (minutes)=', '0.2108', 'loss=', '0.000704627')
# ('Epoch:', '0197', 'training time (minutes)=', '0.2242', 'loss=', '0.000704307')
# ('Epoch:', '0198', 'training time (minutes)=', '0.2210', 'loss=', '0.000695372')
# ('Epoch:', '0199', 'training time (minutes)=', '0.2188', 'loss=', '0.000709089')
# ('Epoch:', '0200', 'training time (minutes)=', '0.2143', 'loss=', '0.000707091')
# ('Held Out Data :', 'forward time (minutes)=', '0.0060', 'loss=', '0.001409379')
# ('Epoch:', '0201', 'training time (minutes)=', '0.2153', 'loss=', '0.000690918')
# ('Epoch:', '0202', 'training time (minutes)=', '0.2161', 'loss=', '0.000690189')
# ('Epoch:', '0203', 'training time (minutes)=', '0.2150', 'loss=', '0.000690129')
# ('Epoch:', '0204', 'training time (minutes)=', '0.2110', 'loss=', '0.000690040')
# ('Epoch:', '0205', 'training time (minutes)=', '0.2206', 'loss=', '0.000699474')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001442592')
# ('Epoch:', '0206', 'training time (minutes)=', '0.2202', 'loss=', '0.000719384')
# ('Epoch:', '0207', 'training time (minutes)=', '0.2007', 'loss=', '0.000696778')
# ('Epoch:', '0208', 'training time (minutes)=', '0.1267', 'loss=', '0.000700948')
# ('Epoch:', '0209', 'training time (minutes)=', '0.1255', 'loss=', '0.000689421')
# ('Epoch:', '0210', 'training time (minutes)=', '0.1248', 'loss=', '0.000679074')
# ('Held Out Data :', 'forward time (minutes)=', '0.0035', 'loss=', '0.001447279')
# ('Epoch:', '0211', 'training time (minutes)=', '0.1227', 'loss=', '0.000691156')
# ('Epoch:', '0212', 'training time (minutes)=', '0.1259', 'loss=', '0.000695126')
# ('Epoch:', '0213', 'training time (minutes)=', '0.1265', 'loss=', '0.000677979')
# ('Epoch:', '0214', 'training time (minutes)=', '0.1257', 'loss=', '0.000689282')
# ('Epoch:', '0215', 'training time (minutes)=', '0.1254', 'loss=', '0.000689029')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001418303')
# ('Epoch:', '0216', 'training time (minutes)=', '0.1239', 'loss=', '0.000689994')
# ('Epoch:', '0217', 'training time (minutes)=', '0.1303', 'loss=', '0.000670442')
# ('Epoch:', '0218', 'training time (minutes)=', '0.1230', 'loss=', '0.000685265')
# ('Epoch:', '0219', 'training time (minutes)=', '0.1245', 'loss=', '0.000671348')
# ('Epoch:', '0220', 'training time (minutes)=', '0.2432', 'loss=', '0.000690118')
# ('Held Out Data :', 'forward time (minutes)=', '0.0072', 'loss=', '0.001443239')
# ('Epoch:', '0221', 'training time (minutes)=', '0.2571', 'loss=', '0.000694717')
# ('Epoch:', '0222', 'training time (minutes)=', '0.2499', 'loss=', '0.000677657')
# ('Epoch:', '0223', 'training time (minutes)=', '0.2509', 'loss=', '0.000681317')
# ('Epoch:', '0224', 'training time (minutes)=', '0.2228', 'loss=', '0.000697261')
# ('Epoch:', '0225', 'training time (minutes)=', '0.2129', 'loss=', '0.000694813')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001455440')
# ('Epoch:', '0226', 'training time (minutes)=', '0.2332', 'loss=', '0.000675068')
# ('Epoch:', '0227', 'training time (minutes)=', '0.2194', 'loss=', '0.000680394')
# ('Epoch:', '0228', 'training time (minutes)=', '0.2077', 'loss=', '0.000678939')
# ('Epoch:', '0229', 'training time (minutes)=', '0.2139', 'loss=', '0.000669436')
# ('Epoch:', '0230', 'training time (minutes)=', '0.2122', 'loss=', '0.000686176')
# ('Held Out Data :', 'forward time (minutes)=', '0.0047', 'loss=', '0.001466383')
# ('Epoch:', '0231', 'training time (minutes)=', '0.2212', 'loss=', '0.000668801')
# ('Epoch:', '0232', 'training time (minutes)=', '0.2102', 'loss=', '0.000672367')
# ('Epoch:', '0233', 'training time (minutes)=', '0.2295', 'loss=', '0.000674406')
# ('Epoch:', '0234', 'training time (minutes)=', '0.2151', 'loss=', '0.000677685')
# ('Epoch:', '0235', 'training time (minutes)=', '0.2196', 'loss=', '0.000671201')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001435678')
# ('Epoch:', '0236', 'training time (minutes)=', '0.2143', 'loss=', '0.000670470')
# ('Epoch:', '0237', 'training time (minutes)=', '0.2164', 'loss=', '0.000666310')
# ('Epoch:', '0238', 'training time (minutes)=', '0.2246', 'loss=', '0.000677929')
# ('Epoch:', '0239', 'training time (minutes)=', '0.2114', 'loss=', '0.000678315')
# ('Epoch:', '0240', 'training time (minutes)=', '0.2190', 'loss=', '0.000669932')
# ('Held Out Data :', 'forward time (minutes)=', '0.0049', 'loss=', '0.001446266')
# ('Epoch:', '0241', 'training time (minutes)=', '0.2159', 'loss=', '0.000679029')
# ('Epoch:', '0242', 'training time (minutes)=', '0.2143', 'loss=', '0.000678726')
# ('Epoch:', '0243', 'training time (minutes)=', '0.2184', 'loss=', '0.000662429')
# ('Epoch:', '0244', 'training time (minutes)=', '0.2241', 'loss=', '0.000664672')
# ('Epoch:', '0245', 'training time (minutes)=', '0.2115', 'loss=', '0.000671979')
# ('Held Out Data :', 'forward time (minutes)=', '0.0060', 'loss=', '0.001455665')
# ('Epoch:', '0246', 'training time (minutes)=', '0.2242', 'loss=', '0.000683910')
# ('Epoch:', '0247', 'training time (minutes)=', '0.1287', 'loss=', '0.000672760')
# ('Epoch:', '0248', 'training time (minutes)=', '0.1255', 'loss=', '0.000666557')
# ('Epoch:', '0249', 'training time (minutes)=', '0.1227', 'loss=', '0.000678237')
# ('Epoch:', '0250', 'training time (minutes)=', '0.1267', 'loss=', '0.000674676')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001467910')
# ('Epoch:', '0251', 'training time (minutes)=', '0.1251', 'loss=', '0.000671090')
# ('Epoch:', '0252', 'training time (minutes)=', '0.1262', 'loss=', '0.000669087')
# ('Epoch:', '0253', 'training time (minutes)=', '0.1245', 'loss=', '0.000658490')
# ('Epoch:', '0254', 'training time (minutes)=', '0.1228', 'loss=', '0.000669923')
# ('Epoch:', '0255', 'training time (minutes)=', '0.1273', 'loss=', '0.000679788')
# ('Held Out Data :', 'forward time (minutes)=', '0.0037', 'loss=', '0.001446108')
# ('Epoch:', '0256', 'training time (minutes)=', '0.1240', 'loss=', '0.000668839')
# ('Epoch:', '0257', 'training time (minutes)=', '0.1236', 'loss=', '0.000665359')
# ('Epoch:', '0258', 'training time (minutes)=', '0.1318', 'loss=', '0.000653355')
# ('Epoch:', '0259', 'training time (minutes)=', '0.2178', 'loss=', '0.000659974')
# ('Epoch:', '0260', 'training time (minutes)=', '0.2502', 'loss=', '0.000665280')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001484068')
# ('Epoch:', '0261', 'training time (minutes)=', '0.2482', 'loss=', '0.000665964')
# ('Epoch:', '0262', 'training time (minutes)=', '0.2482', 'loss=', '0.000653222')
# ('Epoch:', '0263', 'training time (minutes)=', '0.2308', 'loss=', '0.000674620')
# ('Epoch:', '0264', 'training time (minutes)=', '0.2199', 'loss=', '0.000658813')
# ('Epoch:', '0265', 'training time (minutes)=', '0.2155', 'loss=', '0.000657931')
# ('Held Out Data :', 'forward time (minutes)=', '0.0053', 'loss=', '0.001447838')
# ('Epoch:', '0266', 'training time (minutes)=', '0.2222', 'loss=', '0.000666314')
# ('Epoch:', '0267', 'training time (minutes)=', '0.2069', 'loss=', '0.000667588')
# ('Epoch:', '0268', 'training time (minutes)=', '0.2084', 'loss=', '0.000658707')
# ('Epoch:', '0269', 'training time (minutes)=', '0.2265', 'loss=', '0.000662343')
# ('Epoch:', '0270', 'training time (minutes)=', '0.2146', 'loss=', '0.000656092')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001466879')
# ('Epoch:', '0271', 'training time (minutes)=', '0.2320', 'loss=', '0.000647216')
# ('Epoch:', '0272', 'training time (minutes)=', '0.2092', 'loss=', '0.000665840')
# ('Epoch:', '0273', 'training time (minutes)=', '0.2198', 'loss=', '0.000636186')
# ('Epoch:', '0274', 'training time (minutes)=', '0.2219', 'loss=', '0.000649075')
# ('Epoch:', '0275', 'training time (minutes)=', '0.2193', 'loss=', '0.000647245')
# ('Held Out Data :', 'forward time (minutes)=', '0.0050', 'loss=', '0.001480445')
# ('Epoch:', '0276', 'training time (minutes)=', '0.2177', 'loss=', '0.000636029')
# ('Epoch:', '0277', 'training time (minutes)=', '0.2204', 'loss=', '0.000653123')
# ('Epoch:', '0278', 'training time (minutes)=', '0.2171', 'loss=', '0.000667147')
# ('Epoch:', '0279', 'training time (minutes)=', '0.2191', 'loss=', '0.000650905')
# ('Epoch:', '0280', 'training time (minutes)=', '0.2198', 'loss=', '0.000655820')
# ('Held Out Data :', 'forward time (minutes)=', '0.0045', 'loss=', '0.001462765')
# ('Epoch:', '0281', 'training time (minutes)=', '0.2110', 'loss=', '0.000650901')
# ('Epoch:', '0282', 'training time (minutes)=', '0.2149', 'loss=', '0.000647446')
# ('Epoch:', '0283', 'training time (minutes)=', '0.2237', 'loss=', '0.000639321')
# ('Epoch:', '0284', 'training time (minutes)=', '0.2266', 'loss=', '0.000653587')
# ('Epoch:', '0285', 'training time (minutes)=', '0.2193', 'loss=', '0.000654349')
# ('Held Out Data :', 'forward time (minutes)=', '0.0054', 'loss=', '0.001487658')
# ('Epoch:', '0286', 'training time (minutes)=', '0.1330', 'loss=', '0.000634784')
# ('Epoch:', '0287', 'training time (minutes)=', '0.1253', 'loss=', '0.000647276')
# ('Epoch:', '0288', 'training time (minutes)=', '0.1243', 'loss=', '0.000636749')
# ('Epoch:', '0289', 'training time (minutes)=', '0.1234', 'loss=', '0.000638288')
# ('Epoch:', '0290', 'training time (minutes)=', '0.1238', 'loss=', '0.000656422')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001465036')
# ('Epoch:', '0291', 'training time (minutes)=', '0.1226', 'loss=', '0.000645131')
# ('Epoch:', '0292', 'training time (minutes)=', '0.1269', 'loss=', '0.000633795')
# ('Epoch:', '0293', 'training time (minutes)=', '0.1261', 'loss=', '0.000636809')
# ('Epoch:', '0294', 'training time (minutes)=', '0.1256', 'loss=', '0.000647701')
# ('Epoch:', '0295', 'training time (minutes)=', '0.1228', 'loss=', '0.000647613')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001479063')
# ('Epoch:', '0296', 'training time (minutes)=', '0.1293', 'loss=', '0.000648048')
# ('Epoch:', '0297', 'training time (minutes)=', '0.1242', 'loss=', '0.000646438')
# ('Epoch:', '0298', 'training time (minutes)=', '0.2429', 'loss=', '0.000638636')
# ('Epoch:', '0299', 'training time (minutes)=', '0.2433', 'loss=', '0.000643471')
# ('Epoch:', '0300', 'training time (minutes)=', '0.2227', 'loss=', '0.000640325')
# ('Held Out Data :', 'forward time (minutes)=', '0.0049', 'loss=', '0.001461499')
# ('Epoch:', '0301', 'training time (minutes)=', '0.2158', 'loss=', '0.000651034')
# ('Epoch:', '0302', 'training time (minutes)=', '0.2200', 'loss=', '0.000626421')
# ('Epoch:', '0303', 'training time (minutes)=', '0.2155', 'loss=', '0.000637517')
# ('Epoch:', '0304', 'training time (minutes)=', '0.2262', 'loss=', '0.000633817')
# ('Epoch:', '0305', 'training time (minutes)=', '0.2195', 'loss=', '0.000638454')
# ('Held Out Data :', 'forward time (minutes)=', '0.0057', 'loss=', '0.001486778')
# ('Epoch:', '0306', 'training time (minutes)=', '0.2170', 'loss=', '0.000634898')
# ('Epoch:', '0307', 'training time (minutes)=', '0.2226', 'loss=', '0.000648324')
# ('Epoch:', '0308', 'training time (minutes)=', '0.2155', 'loss=', '0.000657982')
# ('Epoch:', '0309', 'training time (minutes)=', '0.2181', 'loss=', '0.000635597')
# ('Epoch:', '0310', 'training time (minutes)=', '0.2260', 'loss=', '0.000631961')
# ('Held Out Data :', 'forward time (minutes)=', '0.0053', 'loss=', '0.001500717')
# ('Epoch:', '0311', 'training time (minutes)=', '0.2140', 'loss=', '0.000630554')
# ('Epoch:', '0312', 'training time (minutes)=', '0.2238', 'loss=', '0.000638306')
# ('Epoch:', '0313', 'training time (minutes)=', '0.2267', 'loss=', '0.000631120')
# ('Epoch:', '0314', 'training time (minutes)=', '0.1935', 'loss=', '0.000639066')
# ('Epoch:', '0315', 'training time (minutes)=', '0.2183', 'loss=', '0.000634073')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001491086')
# ('Epoch:', '0316', 'training time (minutes)=', '0.2150', 'loss=', '0.000639371')
# ('Epoch:', '0317', 'training time (minutes)=', '0.2170', 'loss=', '0.000639666')
# ('Epoch:', '0318', 'training time (minutes)=', '0.2154', 'loss=', '0.000631270')
# ('Epoch:', '0319', 'training time (minutes)=', '0.2180', 'loss=', '0.000631973')
# ('Epoch:', '0320', 'training time (minutes)=', '0.2219', 'loss=', '0.000631954')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001510551')
# ('Epoch:', '0321', 'training time (minutes)=', '0.2178', 'loss=', '0.000628057')
# ('Epoch:', '0322', 'training time (minutes)=', '0.2178', 'loss=', '0.000631591')
# ('Epoch:', '0323', 'training time (minutes)=', '0.2234', 'loss=', '0.000626461')
# ('Epoch:', '0324', 'training time (minutes)=', '0.2182', 'loss=', '0.000622906')
# ('Epoch:', '0325', 'training time (minutes)=', '0.1785', 'loss=', '0.000648397')
# ('Held Out Data :', 'forward time (minutes)=', '0.0039', 'loss=', '0.001536864')
# ('Epoch:', '0326', 'training time (minutes)=', '0.1245', 'loss=', '0.000640111')
# ('Epoch:', '0327', 'training time (minutes)=', '0.1260', 'loss=', '0.000636919')
# ('Epoch:', '0328', 'training time (minutes)=', '0.1240', 'loss=', '0.000621895')
# ('Epoch:', '0329', 'training time (minutes)=', '0.1260', 'loss=', '0.000627810')
# ('Epoch:', '0330', 'training time (minutes)=', '0.1241', 'loss=', '0.000635546')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001508082')
# ('Epoch:', '0331', 'training time (minutes)=', '0.1238', 'loss=', '0.000624614')
# ('Epoch:', '0332', 'training time (minutes)=', '0.1271', 'loss=', '0.000630115')
# ('Epoch:', '0333', 'training time (minutes)=', '0.1259', 'loss=', '0.000641308')
# ('Epoch:', '0334', 'training time (minutes)=', '0.1252', 'loss=', '0.000634404')
# ('Epoch:', '0335', 'training time (minutes)=', '0.1242', 'loss=', '0.000635175')
# ('Held Out Data :', 'forward time (minutes)=', '0.0039', 'loss=', '0.001515262')
# ('Epoch:', '0336', 'training time (minutes)=', '0.1245', 'loss=', '0.000624851')
# ('Epoch:', '0337', 'training time (minutes)=', '0.1958', 'loss=', '0.000633719')
# ('Epoch:', '0338', 'training time (minutes)=', '0.2485', 'loss=', '0.000622765')
# ('Epoch:', '0339', 'training time (minutes)=', '0.2487', 'loss=', '0.000622020')
# ('Epoch:', '0340', 'training time (minutes)=', '0.2487', 'loss=', '0.000632693')
# ('Held Out Data :', 'forward time (minutes)=', '0.0068', 'loss=', '0.001511157')
# ('Epoch:', '0341', 'training time (minutes)=', '0.2296', 'loss=', '0.000613876')
# ('Epoch:', '0342', 'training time (minutes)=', '0.2123', 'loss=', '0.000634813')
# ('Epoch:', '0343', 'training time (minutes)=', '0.2282', 'loss=', '0.000636691')
# ('Epoch:', '0344', 'training time (minutes)=', '0.2110', 'loss=', '0.000621679')
# ('Epoch:', '0345', 'training time (minutes)=', '0.2126', 'loss=', '0.000621361')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001507678')
# ('Epoch:', '0346', 'training time (minutes)=', '0.2102', 'loss=', '0.000630720')
# ('Epoch:', '0347', 'training time (minutes)=', '0.2241', 'loss=', '0.000618173')
# ('Epoch:', '0348', 'training time (minutes)=', '0.2165', 'loss=', '0.000644626')
# ('Epoch:', '0349', 'training time (minutes)=', '0.2174', 'loss=', '0.000623133')
# ('Epoch:', '0350', 'training time (minutes)=', '0.2196', 'loss=', '0.000615508')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.001504572')
# ('Epoch:', '0351', 'training time (minutes)=', '0.2192', 'loss=', '0.000622476')
# ('Epoch:', '0352', 'training time (minutes)=', '0.2211', 'loss=', '0.000618693')
# ('Epoch:', '0353', 'training time (minutes)=', '0.2188', 'loss=', '0.000625569')
# ('Epoch:', '0354', 'training time (minutes)=', '0.2165', 'loss=', '0.000629714')
# ('Epoch:', '0355', 'training time (minutes)=', '0.2149', 'loss=', '0.000613106')
# ('Held Out Data :', 'forward time (minutes)=', '0.0059', 'loss=', '0.001513522')
# ('Epoch:', '0356', 'training time (minutes)=', '0.2285', 'loss=', '0.000629459')
# ('Epoch:', '0357', 'training time (minutes)=', '0.2190', 'loss=', '0.000621527')
# ('Epoch:', '0358', 'training time (minutes)=', '0.2159', 'loss=', '0.000621415')
# ('Epoch:', '0359', 'training time (minutes)=', '0.2016', 'loss=', '0.000623170')
# ('Epoch:', '0360', 'training time (minutes)=', '0.2048', 'loss=', '0.000612867')
# ('Held Out Data :', 'forward time (minutes)=', '0.0052', 'loss=', '0.001526293')
# ('Epoch:', '0361', 'training time (minutes)=', '0.2185', 'loss=', '0.000634556')
# ('Epoch:', '0362', 'training time (minutes)=', '0.2178', 'loss=', '0.000625086')
# ('Epoch:', '0363', 'training time (minutes)=', '0.2210', 'loss=', '0.000610377')
# ('Epoch:', '0364', 'training time (minutes)=', '0.1697', 'loss=', '0.000635262')
# ('Epoch:', '0365', 'training time (minutes)=', '0.1235', 'loss=', '0.000626444')
# ('Held Out Data :', 'forward time (minutes)=', '0.0041', 'loss=', '0.001506697')
# ('Epoch:', '0366', 'training time (minutes)=', '0.1255', 'loss=', '0.000616689')
# ('Epoch:', '0367', 'training time (minutes)=', '0.1264', 'loss=', '0.000632755')
# ('Epoch:', '0368', 'training time (minutes)=', '0.1243', 'loss=', '0.000620298')
# ('Epoch:', '0369', 'training time (minutes)=', '0.1238', 'loss=', '0.000611957')
# ('Epoch:', '0370', 'training time (minutes)=', '0.1251', 'loss=', '0.000611855')
# ('Held Out Data :', 'forward time (minutes)=', '0.0037', 'loss=', '0.001511403')
# ('Epoch:', '0371', 'training time (minutes)=', '0.1255', 'loss=', '0.000613280')
# ('Epoch:', '0372', 'training time (minutes)=', '0.1251', 'loss=', '0.000602919')
# ('Epoch:', '0373', 'training time (minutes)=', '0.1249', 'loss=', '0.000615054')
# ('Epoch:', '0374', 'training time (minutes)=', '0.1233', 'loss=', '0.000622967')
# ('Epoch:', '0375', 'training time (minutes)=', '0.1245', 'loss=', '0.000611801')
# ('Held Out Data :', 'forward time (minutes)=', '0.0037', 'loss=', '0.001495718')
# ('Epoch:', '0376', 'training time (minutes)=', '0.1939', 'loss=', '0.000605322')
# ('Epoch:', '0377', 'training time (minutes)=', '0.2464', 'loss=', '0.000609585')
# ('Epoch:', '0378', 'training time (minutes)=', '0.2491', 'loss=', '0.000617411')
# ('Epoch:', '0379', 'training time (minutes)=', '0.2487', 'loss=', '0.000605662')
# ('Epoch:', '0380', 'training time (minutes)=', '0.2480', 'loss=', '0.000614283')
# ('Held Out Data :', 'forward time (minutes)=', '0.0054', 'loss=', '0.001539510')
# ('Epoch:', '0381', 'training time (minutes)=', '0.2240', 'loss=', '0.000613526')
# ('Epoch:', '0382', 'training time (minutes)=', '0.2104', 'loss=', '0.000612084')
# ('Epoch:', '0383', 'training time (minutes)=', '0.1977', 'loss=', '0.000607522')
# ('Epoch:', '0384', 'training time (minutes)=', '0.2101', 'loss=', '0.000603976')
# ('Epoch:', '0385', 'training time (minutes)=', '0.2127', 'loss=', '0.000618450')
# ('Held Out Data :', 'forward time (minutes)=', '0.0052', 'loss=', '0.001524401')
# ('Epoch:', '0386', 'training time (minutes)=', '0.2250', 'loss=', '0.000612954')
# ('Epoch:', '0387', 'training time (minutes)=', '0.2134', 'loss=', '0.000609437')
# ('Epoch:', '0388', 'training time (minutes)=', '0.2193', 'loss=', '0.000616888')
# ('Epoch:', '0389', 'training time (minutes)=', '0.2171', 'loss=', '0.000605278')
# ('Epoch:', '0390', 'training time (minutes)=', '0.2176', 'loss=', '0.000604728')
# ('Held Out Data :', 'forward time (minutes)=', '0.0051', 'loss=', '0.001557606')
# ('Epoch:', '0391', 'training time (minutes)=', '0.2186', 'loss=', '0.000605118')
# ('Epoch:', '0392', 'training time (minutes)=', '0.2227', 'loss=', '0.000619943')
# ('Epoch:', '0393', 'training time (minutes)=', '0.2159', 'loss=', '0.000611879')
# ('Epoch:', '0394', 'training time (minutes)=', '0.2220', 'loss=', '0.000612491')
# ('Epoch:', '0395', 'training time (minutes)=', '0.2229', 'loss=', '0.000601547')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001532800')
# ('Epoch:', '0396', 'training time (minutes)=', '0.2145', 'loss=', '0.000609633')
# ('Epoch:', '0397', 'training time (minutes)=', '0.2094', 'loss=', '0.000616542')
# ('Epoch:', '0398', 'training time (minutes)=', '0.2108', 'loss=', '0.000599993')
# ('Epoch:', '0399', 'training time (minutes)=', '0.2091', 'loss=', '0.000610134')
# ('Epoch:', '0400', 'training time (minutes)=', '0.2090', 'loss=', '0.000615927')
# ('Held Out Data :', 'forward time (minutes)=', '0.0045', 'loss=', '0.001551791')
# ('Epoch:', '0401', 'training time (minutes)=', '0.2104', 'loss=', '0.000611445')
# ('Epoch:', '0402', 'training time (minutes)=', '0.2084', 'loss=', '0.000605922')
# ('Epoch:', '0403', 'training time (minutes)=', '0.1883', 'loss=', '0.000599740')
# ('Epoch:', '0404', 'training time (minutes)=', '0.1236', 'loss=', '0.000610742')
# ('Epoch:', '0405', 'training time (minutes)=', '0.1232', 'loss=', '0.000610259')
# ('Held Out Data :', 'forward time (minutes)=', '0.0039', 'loss=', '0.001543729')
# ('Epoch:', '0406', 'training time (minutes)=', '0.1226', 'loss=', '0.000594895')
# ('Epoch:', '0407', 'training time (minutes)=', '0.1219', 'loss=', '0.000611088')
# ('Epoch:', '0408', 'training time (minutes)=', '0.1224', 'loss=', '0.000608398')
# ('Epoch:', '0409', 'training time (minutes)=', '0.1228', 'loss=', '0.000614305')
# ('Epoch:', '0410', 'training time (minutes)=', '0.1220', 'loss=', '0.000605799')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.001528490')
# ('Epoch:', '0411', 'training time (minutes)=', '0.1228', 'loss=', '0.000614785')
# ('Epoch:', '0412', 'training time (minutes)=', '0.1229', 'loss=', '0.000609681')
# ('Epoch:', '0413', 'training time (minutes)=', '0.1224', 'loss=', '0.000599629')
# ('Epoch:', '0414', 'training time (minutes)=', '0.1222', 'loss=', '0.000611017')
# ('Epoch:', '0415', 'training time (minutes)=', '0.1232', 'loss=', '0.000602677')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.001529079')
# ('Epoch:', '0416', 'training time (minutes)=', '0.2421', 'loss=', '0.000604513')
# ('Epoch:', '0417', 'training time (minutes)=', '0.2465', 'loss=', '0.000594396')
# ('Epoch:', '0418', 'training time (minutes)=', '0.2468', 'loss=', '0.000601609')
# ('Epoch:', '0419', 'training time (minutes)=', '0.2361', 'loss=', '0.000587732')
# ('Epoch:', '0420', 'training time (minutes)=', '0.2082', 'loss=', '0.000604425')
# ('Held Out Data :', 'forward time (minutes)=', '0.0049', 'loss=', '0.001540318')
# ('Epoch:', '0421', 'training time (minutes)=', '0.2106', 'loss=', '0.000605578')
# ('Epoch:', '0422', 'training time (minutes)=', '0.2121', 'loss=', '0.000599567')
# ('Epoch:', '0423', 'training time (minutes)=', '0.2056', 'loss=', '0.000600664')
# ('Epoch:', '0424', 'training time (minutes)=', '0.2060', 'loss=', '0.000605910')
# ('Epoch:', '0425', 'training time (minutes)=', '0.2085', 'loss=', '0.000603337')
# ('Held Out Data :', 'forward time (minutes)=', '0.0050', 'loss=', '0.001549867')
# ('Epoch:', '0426', 'training time (minutes)=', '0.2089', 'loss=', '0.000590300')
# ('Epoch:', '0427', 'training time (minutes)=', '0.1728', 'loss=', '0.000586796')
# ('Epoch:', '0428', 'training time (minutes)=', '0.2007', 'loss=', '0.000591293')
# ('Epoch:', '0429', 'training time (minutes)=', '0.2062', 'loss=', '0.000590467')
# ('Epoch:', '0430', 'training time (minutes)=', '0.2077', 'loss=', '0.000594627')
# ('Held Out Data :', 'forward time (minutes)=', '0.0052', 'loss=', '0.001540249')
# ('Epoch:', '0431', 'training time (minutes)=', '0.2056', 'loss=', '0.000613233')
# ('Epoch:', '0432', 'training time (minutes)=', '0.2076', 'loss=', '0.000605253')
# ('Epoch:', '0433', 'training time (minutes)=', '0.2088', 'loss=', '0.000599132')
# ('Epoch:', '0434', 'training time (minutes)=', '0.2107', 'loss=', '0.000600679')
# ('Epoch:', '0435', 'training time (minutes)=', '0.2077', 'loss=', '0.000595722')
# ('Held Out Data :', 'forward time (minutes)=', '0.0054', 'loss=', '0.001556681')
# ('Epoch:', '0436', 'training time (minutes)=', '0.2125', 'loss=', '0.000605255')
# ('Epoch:', '0437', 'training time (minutes)=', '0.2113', 'loss=', '0.000595065')
# ('Epoch:', '0438', 'training time (minutes)=', '0.2123', 'loss=', '0.000599122')
# ('Epoch:', '0439', 'training time (minutes)=', '0.2104', 'loss=', '0.000601000')
# ('Epoch:', '0440', 'training time (minutes)=', '0.2083', 'loss=', '0.000618384')
# ('Held Out Data :', 'forward time (minutes)=', '0.0052', 'loss=', '0.001619053')
# ('Epoch:', '0441', 'training time (minutes)=', '0.2093', 'loss=', '0.000628342')
# ('Epoch:', '0442', 'training time (minutes)=', '0.2067', 'loss=', '0.000603654')
# ('Epoch:', '0443', 'training time (minutes)=', '0.2127', 'loss=', '0.000600960')
# ('Epoch:', '0444', 'training time (minutes)=', '0.1537', 'loss=', '0.000591061')
# ('Epoch:', '0445', 'training time (minutes)=', '0.1213', 'loss=', '0.000589947')
# ('Held Out Data :', 'forward time (minutes)=', '0.0038', 'loss=', '0.001540804')
# ('Epoch:', '0446', 'training time (minutes)=', '0.1222', 'loss=', '0.000597140')
# ('Epoch:', '0447', 'training time (minutes)=', '0.1221', 'loss=', '0.000592419')
# ('Epoch:', '0448', 'training time (minutes)=', '0.1224', 'loss=', '0.000597451')
# ('Epoch:', '0449', 'training time (minutes)=', '0.1219', 'loss=', '0.000596081')
# ('Epoch:', '0450', 'training time (minutes)=', '0.1227', 'loss=', '0.000589448')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001547822')
# ('Epoch:', '0451', 'training time (minutes)=', '0.1225', 'loss=', '0.000593733')
# ('Epoch:', '0452', 'training time (minutes)=', '0.1221', 'loss=', '0.000596028')
# ('Epoch:', '0453', 'training time (minutes)=', '0.1221', 'loss=', '0.000587923')
# ('Epoch:', '0454', 'training time (minutes)=', '0.1221', 'loss=', '0.000585602')
# ('Epoch:', '0455', 'training time (minutes)=', '0.1223', 'loss=', '0.000588606')
# ('Held Out Data :', 'forward time (minutes)=', '0.0039', 'loss=', '0.001583799')
# ('Epoch:', '0456', 'training time (minutes)=', '0.1684', 'loss=', '0.000589279')
# ('Epoch:', '0457', 'training time (minutes)=', '0.2458', 'loss=', '0.000598707')
# ('Epoch:', '0458', 'training time (minutes)=', '0.2470', 'loss=', '0.000592657')
# ('Epoch:', '0459', 'training time (minutes)=', '0.2456', 'loss=', '0.000582521')
# ('Epoch:', '0460', 'training time (minutes)=', '0.2109', 'loss=', '0.000589413')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001600552')
# ('Epoch:', '0461', 'training time (minutes)=', '0.2094', 'loss=', '0.000588631')
# ('Epoch:', '0462', 'training time (minutes)=', '0.2064', 'loss=', '0.000589696')
# ('Epoch:', '0463', 'training time (minutes)=', '0.2098', 'loss=', '0.000592227')
# ('Epoch:', '0464', 'training time (minutes)=', '0.2093', 'loss=', '0.000603903')
# ('Epoch:', '0465', 'training time (minutes)=', '0.2092', 'loss=', '0.000594037')
# ('Held Out Data :', 'forward time (minutes)=', '0.0042', 'loss=', '0.001581301')
# ('Epoch:', '0466', 'training time (minutes)=', '0.2073', 'loss=', '0.000595981')
# ('Epoch:', '0467', 'training time (minutes)=', '0.2014', 'loss=', '0.000598377')
# ('Epoch:', '0468', 'training time (minutes)=', '0.2101', 'loss=', '0.000593452')
# ('Epoch:', '0469', 'training time (minutes)=', '0.2086', 'loss=', '0.000600154')
# ('Epoch:', '0470', 'training time (minutes)=', '0.2049', 'loss=', '0.000594526')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001569940')
# ('Epoch:', '0471', 'training time (minutes)=', '0.2090', 'loss=', '0.000591975')
# ('Epoch:', '0472', 'training time (minutes)=', '0.2073', 'loss=', '0.000588458')
# ('Epoch:', '0473', 'training time (minutes)=', '0.2031', 'loss=', '0.000583153')
# ('Epoch:', '0474', 'training time (minutes)=', '0.2103', 'loss=', '0.000586146')
# ('Epoch:', '0475', 'training time (minutes)=', '0.2110', 'loss=', '0.000589648')
# ('Held Out Data :', 'forward time (minutes)=', '0.0059', 'loss=', '0.001556307')
# ('Epoch:', '0476', 'training time (minutes)=', '0.2059', 'loss=', '0.000578513')
# ('Epoch:', '0477', 'training time (minutes)=', '0.1959', 'loss=', '0.000593016')
# ('Epoch:', '0478', 'training time (minutes)=', '0.2108', 'loss=', '0.000589801')
# ('Epoch:', '0479', 'training time (minutes)=', '0.2048', 'loss=', '0.000581989')
# ('Epoch:', '0480', 'training time (minutes)=', '0.2076', 'loss=', '0.000596947')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001558213')
# ('Epoch:', '0481', 'training time (minutes)=', '0.2088', 'loss=', '0.000589141')
# ('Epoch:', '0482', 'training time (minutes)=', '0.2088', 'loss=', '0.000580958')
# ('Epoch:', '0483', 'training time (minutes)=', '0.2100', 'loss=', '0.000588347')
# ('Epoch:', '0484', 'training time (minutes)=', '0.1994', 'loss=', '0.000607330')
# ('Epoch:', '0485', 'training time (minutes)=', '0.1215', 'loss=', '0.000584234')
# ('Held Out Data :', 'forward time (minutes)=', '0.0035', 'loss=', '0.001567296')
# ('Epoch:', '0486', 'training time (minutes)=', '0.1218', 'loss=', '0.000588961')
# ('Epoch:', '0487', 'training time (minutes)=', '0.1221', 'loss=', '0.000586501')
# ('Epoch:', '0488', 'training time (minutes)=', '0.1216', 'loss=', '0.000585615')
# ('Epoch:', '0489', 'training time (minutes)=', '0.1218', 'loss=', '0.000588747')
# ('Epoch:', '0490', 'training time (minutes)=', '0.1213', 'loss=', '0.000586431')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001564901')
# ('Epoch:', '0491', 'training time (minutes)=', '0.1223', 'loss=', '0.000586709')
# ('Epoch:', '0492', 'training time (minutes)=', '0.1224', 'loss=', '0.000583614')
# ('Epoch:', '0493', 'training time (minutes)=', '0.1213', 'loss=', '0.000584193')
# ('Epoch:', '0494', 'training time (minutes)=', '0.1226', 'loss=', '0.000575062')
# ('Epoch:', '0495', 'training time (minutes)=', '0.1216', 'loss=', '0.000577465')
# ('Held Out Data :', 'forward time (minutes)=', '0.0040', 'loss=', '0.001561007')
# ('Epoch:', '0496', 'training time (minutes)=', '0.1213', 'loss=', '0.000598079')
# ('Epoch:', '0497', 'training time (minutes)=', '0.2255', 'loss=', '0.000569919')
# ('Epoch:', '0498', 'training time (minutes)=', '0.2456', 'loss=', '0.000576688')
# ('Epoch:', '0499', 'training time (minutes)=', '0.2451', 'loss=', '0.000582874')
# ('Epoch:', '0500', 'training time (minutes)=', '0.2338', 'loss=', '0.000579562')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.001578965')

# %%
from tf_lab.point_clouds.convenience import reconstruct_pclouds
_, l_test = reconstruct_pclouds(ae, in_data['test'].point_clouds, batch_size=100)
_, l_train = reconstruct_pclouds(ae, in_data['train'].point_clouds, batch_size=100)
print l_test, l_train
# Out:
# 0.000749164663748 0.000654067897925

# %%
a = np.arange(16).reshape(1,4,4)
a.repeat(3, axis=2)
a = np.arange(16).reshape(1,4,4)
print a
a = a.reshape(-1)
a = np.tile(a, 3)
# print a
a = np.transpose(a.reshape(1, 3, 4, 4), [0,3,2,1])
print a
print a.shape

n_filters = 5
n_pc_points = 4
# group_size = 20
batch_size = 1

in_layer = tf.placeholder(tf.float32, [None, n_pc_points, 3])

filter_weights = tf.nn.sigmoid(conv_1d(in_layer, group_size, n_filters))

tf.while_loop()


# tf.while_loop


# filter_weights = tf.constant(np.arange(n_pc_points * n_filters, dtype='f4').reshape(batch_size, n_pc_points, n_filters))

# print sess.run(filter_weights)

# filter_weights = tf.reshape(filter_weights, [-1, n_pc_points*n_filters])

# filter_weights = tf.tile(filter_weights, [1,3]) # expand for x-y-z

# filter_weights = tf.transpose(tf.reshape(filter_weights, (1, n_pc_points, n_filters, 3) ), [0, 2, 3, 1])

# sess.run(filter_weights[0][0])
