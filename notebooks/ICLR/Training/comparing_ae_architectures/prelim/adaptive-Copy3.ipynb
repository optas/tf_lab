# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 0
setup_one_gpu(GPU)
# Out:
# Picking GPU 0

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from functools import partial

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter
from tf_lab.point_clouds.ae_templates import conv_architecture_ala_nips_17, default_train_params_ala_nips_17

from tf_lab.point_clouds.encoders_decoders import decoder_with_fc_only,\
encoder_with_convs_and_symmetry_new, decoder_with_convs_only

from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder

from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tflearn.layers.conv import avg_pool_1d
from pc_completions.evaluation import basic_comletion_measures

from tflearn.layers.conv import conv_1d, highway_conv_1d, avg_pool_1d, max_pool_1d
from tf_lab.fundamentals.layers import conv_1d_tranpose

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
exp_id = -1
n_pc_points = 2048
random_seed = 42
top_data_dir = '/orions4-zfs/projects/optas/DATA'
train_dir = osp.join(top_data_dir, 'OUT/iclr/nn_models/testing_ae_settings/ae_variants_2', str(exp_id))

# %%
def load_multiple_version_of_pcs():
#     versions = ['centered', 'centered_2nd_version', 'centered_3rd_version']
#     versions = ['fps_sampled_in_u_sphere']    
    versions = ['fps_sampled_in_u_sphere_fiedler_sorted']
    
    splits = {'train':None, 'val':None, 'test': None}
        
    for s in splits.keys():
        print 'Loading %s data.' % (s,)
        s_file = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/', s + '.txt')
        print s_file
        for i, v in enumerate(versions):
            top_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', v, str(n_pc_points))                
            splitter = Data_Splitter(top_pclouds_path, data_file_ending='.ply', random_seed=random_seed)
            pcs_in_split = splitter.load_splits(s_file)                
            pclouds, model_ids, syn_ids = load_point_clouds_from_filenames(pcs_in_split, n_threads=20, loader=snc_loader, verbose=True)        
            if splits[s] is None:
                splits[s] = PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids)
            else:
                splits[s].merge(PointCloudDataSet(pclouds, labels=syn_ids + '_' + model_ids))
    return splits

# %%
in_data  = load_multiple_version_of_pcs()
# Out:
# Loading test data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/test.txt
# 679 pclouds were loaded. They belong in 1 shape-classes.
# Loading train data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/train.txt
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# Loading val data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/val.txt
# 338 pclouds were loaded. They belong in 1 shape-classes.

# %%
do_training = True
load_pretrained_model = False
load_epoch = None
loss = 'chamfer'
training_epochs = 500
batch_size = 50
learning_rate = 0.0005

# %%
def enc_dec_templates():
    b_norm = True        
    encoder = encoder_with_convs_and_symmetry_new
    decoder = decoder_with_fc_only
    conv_op = conv_1d

    encoder_args = {'n_filters': [64, 64, 128, 256, 32],
            'filter_sizes': [9, 3, 3, 2, 2],
            'strides': [1, 1, 1, 1, 1],
            'b_norm': b_norm,
            'pool': None,
            'pool_sizes': [2, None, 2, None, None],
            'verbose': True,
            'conv_op': conv_op
            }

    decoder_args= {'layer_sizes': [64, 256, 2048*3],
                   'verbose': True,
                   'b_norm': b_norm,
                   'non_linearity': tf.nn.relu
                  }
    return encoder, decoder, encoder_args, decoder_args

# %%
reset_tf_graph()
encoder, decoder, encoder_args, decoder_args = enc_dec_templates()
print encoder_args

# layer = tf.placeholder(tf.float32, [None, n_pc_points, 3])
# layer = encoder(layer, **encoder_args)
# layer = decoder(layer, **decoder_args)
# Out:
# {'filter_sizes': [9, 3, 3, 2, 2], 'n_filters': [64, 64, 128, 256, 32], 'verbose': True, 'strides': [1, 1, 1, 1, 1], 'conv_op': <function conv_1d at 0x7f731ae25320>, 'pool_sizes': [2, None, 2, None, None], 'b_norm': True, 'pool': None}

# %%
if load_pretrained_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    if conf.train_dir != train_dir:
        conf.train_dir = train_dir
#     conf.save(osp.join(train_dir, 'configuration'))
else:    
    conf = Conf(
                n_input = [n_pc_points, 3],
                loss = loss,
                training_epochs = training_epochs,
                batch_size = batch_size,
                denoising = False,
                learning_rate = learning_rate,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = None,
                z_rotate = False,
                encoder = encoder,
                decoder = decoder,
                encoder_args = encoder_args,
                decoder_args = decoder_args
               )

conf.experiment_name = 'experiment_' + str(exp_id)
conf.held_out_step = 5
reset_tf_graph()
ae = PointNetAutoEncoder(conf.experiment_name, conf)
print ae.trainable_parameters()
# Out:
# Building Encoder
# encoder_conv_layer_0 conv params =  1792 bnorm params =  128
# Tensor("experiment_-1_1/Relu:0", shape=(?, 2048, 64), dtype=float32)
# output size: 131072
#
# encoder_conv_layer_1 conv params =  12352 bnorm params =  128
# Tensor("experiment_-1_1/Relu_1:0", shape=(?, 2048, 64), dtype=float32)
# output size: 131072
#
# encoder_conv_layer_2 conv params =  24704 bnorm params =  256
# Tensor("experiment_-1_1/Relu_2:0", shape=(?, 2048, 128), dtype=float32)
# output size: 262144
#
# encoder_conv_layer_3 conv params =  65792 bnorm params =  512
# Tensor("experiment_-1_1/Relu_3:0", shape=(?, 2048, 256), dtype=float32)
# output size: 524288
#
# encoder_conv_layer_4 conv params =  16416 bnorm params =  64
# Tensor("experiment_-1_1/Relu_4:0", shape=(?, 2048, 32), dtype=float32)
# output size: 65536
#
# Tensor("experiment_-1_1/Max:0", shape=(?, 32), dtype=float32)
# Building Decoder
# decoder_fc_0 FC params =  2112 bnorm params =  128
# Tensor("experiment_-1_1/Relu_5:0", shape=(?, 64), dtype=float32)
# output size: 64
#
# decoder_fc_1 FC params =  16640 bnorm params =  512
# Tensor("experiment_-1_1/Relu_6:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# decoder_fc_2 FC params =  1579008 Tensor("experiment_-1_1/decoder_fc_2/BiasAdd:0", shape=(?, 6144), dtype=float32)
# output size: 6144
#
# 1720544

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)     
    train_stats = ae.train(in_data['train'], conf, log_file=fout, held_out_data=in_data['test'])
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.2634', 'loss=', '0.005643821')
# ('Epoch:', '0002', 'training time (minutes)=', '0.2272', 'loss=', '0.002905588')
# ('Epoch:', '0003', 'training time (minutes)=', '0.2245', 'loss=', '0.002618216')
# ('Epoch:', '0004', 'training time (minutes)=', '0.2283', 'loss=', '0.002417696')
# ('Epoch:', '0005', 'training time (minutes)=', '0.2257', 'loss=', '0.002253566')
# ('Held Out Data :', 'forward time (minutes)=', '0.0070', 'loss=', '0.002106069')
# ('Epoch:', '0006', 'training time (minutes)=', '0.2127', 'loss=', '0.002119288')
# ('Epoch:', '0007', 'training time (minutes)=', '0.1220', 'loss=', '0.002017311')
# ('Epoch:', '0008', 'training time (minutes)=', '0.1195', 'loss=', '0.001982406')
# ('Epoch:', '0009', 'training time (minutes)=', '0.1197', 'loss=', '0.001920245')
# ('Epoch:', '0010', 'training time (minutes)=', '0.1199', 'loss=', '0.001829006')
# ('Held Out Data :', 'forward time (minutes)=', '0.0035', 'loss=', '0.001750006')
# ('Epoch:', '0011', 'training time (minutes)=', '0.1201', 'loss=', '0.001799267')
# ('Epoch:', '0012', 'training time (minutes)=', '0.1197', 'loss=', '0.001739359')
# ('Epoch:', '0013', 'training time (minutes)=', '0.1212', 'loss=', '0.001737588')
# ('Epoch:', '0014', 'training time (minutes)=', '0.1207', 'loss=', '0.001724924')
# ('Epoch:', '0015', 'training time (minutes)=', '0.2086', 'loss=', '0.001618156')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001549146')
# ('Epoch:', '0016', 'training time (minutes)=', '0.2214', 'loss=', '0.001607520')
# ('Epoch:', '0017', 'training time (minutes)=', '0.2185', 'loss=', '0.001584995')
# ('Epoch:', '0018', 'training time (minutes)=', '0.2175', 'loss=', '0.001541800')
# ('Epoch:', '0019', 'training time (minutes)=', '0.2225', 'loss=', '0.001515849')
# ('Epoch:', '0020', 'training time (minutes)=', '0.2201', 'loss=', '0.001515197')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001467387')
# ('Epoch:', '0021', 'training time (minutes)=', '0.2202', 'loss=', '0.001468149')
# ('Epoch:', '0022', 'training time (minutes)=', '0.2194', 'loss=', '0.001452034')
# ('Epoch:', '0023', 'training time (minutes)=', '0.2188', 'loss=', '0.001422055')
# ('Epoch:', '0024', 'training time (minutes)=', '0.2187', 'loss=', '0.001408338')
# ('Epoch:', '0025', 'training time (minutes)=', '0.2202', 'loss=', '0.001390293')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001393054')
# ('Epoch:', '0026', 'training time (minutes)=', '0.2198', 'loss=', '0.001375416')
# ('Epoch:', '0027', 'training time (minutes)=', '0.2200', 'loss=', '0.001365255')
# ('Epoch:', '0028', 'training time (minutes)=', '0.2189', 'loss=', '0.001355495')
# ('Epoch:', '0029', 'training time (minutes)=', '0.2187', 'loss=', '0.001431559')
# ('Epoch:', '0030', 'training time (minutes)=', '0.2202', 'loss=', '0.001355155')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001322137')
# ('Epoch:', '0031', 'training time (minutes)=', '0.2196', 'loss=', '0.001331021')
# ('Epoch:', '0032', 'training time (minutes)=', '0.2218', 'loss=', '0.001281487')
# ('Epoch:', '0033', 'training time (minutes)=', '0.2198', 'loss=', '0.001261674')
# ('Epoch:', '0034', 'training time (minutes)=', '0.2202', 'loss=', '0.001258642')
# ('Epoch:', '0035', 'training time (minutes)=', '0.2205', 'loss=', '0.001240774')
# ('Held Out Data :', 'forward time (minutes)=', '0.0060', 'loss=', '0.001314435')
# ('Epoch:', '0036', 'training time (minutes)=', '0.2204', 'loss=', '0.001219029')
# ('Epoch:', '0037', 'training time (minutes)=', '0.2189', 'loss=', '0.001227353')
# ('Epoch:', '0038', 'training time (minutes)=', '0.2211', 'loss=', '0.001233799')
# ('Epoch:', '0039', 'training time (minutes)=', '0.2192', 'loss=', '0.001208779')
# ('Epoch:', '0040', 'training time (minutes)=', '0.2213', 'loss=', '0.001201154')
# ('Held Out Data :', 'forward time (minutes)=', '0.0059', 'loss=', '0.001248510')
# ('Epoch:', '0041', 'training time (minutes)=', '0.2203', 'loss=', '0.001179836')
# ('Epoch:', '0042', 'training time (minutes)=', '0.2181', 'loss=', '0.001177537')
# ('Epoch:', '0043', 'training time (minutes)=', '0.2208', 'loss=', '0.001156810')
# ('Epoch:', '0044', 'training time (minutes)=', '0.2188', 'loss=', '0.001159089')
# ('Epoch:', '0045', 'training time (minutes)=', '0.2205', 'loss=', '0.001130015')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001189354')
# ('Epoch:', '0046', 'training time (minutes)=', '0.2201', 'loss=', '0.001130585')
# ('Epoch:', '0047', 'training time (minutes)=', '0.2174', 'loss=', '0.001130107')
# ('Epoch:', '0048', 'training time (minutes)=', '0.2211', 'loss=', '0.001118503')
# ('Epoch:', '0049', 'training time (minutes)=', '0.2177', 'loss=', '0.001131253')
# ('Epoch:', '0050', 'training time (minutes)=', '0.2190', 'loss=', '0.001097991')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001158319')
# ('Epoch:', '0051', 'training time (minutes)=', '0.2209', 'loss=', '0.001098865')
# ('Epoch:', '0052', 'training time (minutes)=', '0.2182', 'loss=', '0.001102295')
# ('Epoch:', '0053', 'training time (minutes)=', '0.2200', 'loss=', '0.001100582')
# ('Epoch:', '0054', 'training time (minutes)=', '0.2180', 'loss=', '0.001090616')
# ('Epoch:', '0055', 'training time (minutes)=', '0.2198', 'loss=', '0.001092372')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001128445')
# ('Epoch:', '0056', 'training time (minutes)=', '0.2210', 'loss=', '0.001072399')
# ('Epoch:', '0057', 'training time (minutes)=', '0.2188', 'loss=', '0.001065239')
# ('Epoch:', '0058', 'training time (minutes)=', '0.2197', 'loss=', '0.001064892')
# ('Epoch:', '0059', 'training time (minutes)=', '0.2212', 'loss=', '0.001042880')
# ('Epoch:', '0060', 'training time (minutes)=', '0.2189', 'loss=', '0.001048052')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001139496')
# ('Epoch:', '0061', 'training time (minutes)=', '0.2197', 'loss=', '0.001047329')
# ('Epoch:', '0062', 'training time (minutes)=', '0.2202', 'loss=', '0.001026619')
# ('Epoch:', '0063', 'training time (minutes)=', '0.2212', 'loss=', '0.001028033')
# ('Epoch:', '0064', 'training time (minutes)=', '0.2207', 'loss=', '0.001004996')
# ('Epoch:', '0065', 'training time (minutes)=', '0.2209', 'loss=', '0.001032804')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001135731')
# ('Epoch:', '0066', 'training time (minutes)=', '0.2184', 'loss=', '0.001008657')
# ('Epoch:', '0067', 'training time (minutes)=', '0.2219', 'loss=', '0.000997656')
# ('Epoch:', '0068', 'training time (minutes)=', '0.2196', 'loss=', '0.001011477')
# ('Epoch:', '0069', 'training time (minutes)=', '0.2201', 'loss=', '0.001013962')
# ('Epoch:', '0070', 'training time (minutes)=', '0.2197', 'loss=', '0.001003025')
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.001158207')
# ('Epoch:', '0071', 'training time (minutes)=', '0.2201', 'loss=', '0.001010769')
# ('Epoch:', '0072', 'training time (minutes)=', '0.2198', 'loss=', '0.000980965')
# ('Epoch:', '0073', 'training time (minutes)=', '0.2177', 'loss=', '0.000976792')
# ('Epoch:', '0074', 'training time (minutes)=', '0.2188', 'loss=', '0.000986454')
# ('Epoch:', '0075', 'training time (minutes)=', '0.2193', 'loss=', '0.000975516')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001104421')
# ('Epoch:', '0076', 'training time (minutes)=', '0.2193', 'loss=', '0.000974213')
# ('Epoch:', '0077', 'training time (minutes)=', '0.2197', 'loss=', '0.000964402')
# ('Epoch:', '0078', 'training time (minutes)=', '0.2204', 'loss=', '0.000955892')
# ('Epoch:', '0079', 'training time (minutes)=', '0.2209', 'loss=', '0.000959100')
# ('Epoch:', '0080', 'training time (minutes)=', '0.2216', 'loss=', '0.000953077')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001100023')
# ('Epoch:', '0081', 'training time (minutes)=', '0.2190', 'loss=', '0.000941033')
# ('Epoch:', '0082', 'training time (minutes)=', '0.2195', 'loss=', '0.000938188')
# ('Epoch:', '0083', 'training time (minutes)=', '0.2190', 'loss=', '0.000931663')
# ('Epoch:', '0084', 'training time (minutes)=', '0.2177', 'loss=', '0.000948911')
# ('Epoch:', '0085', 'training time (minutes)=', '0.2218', 'loss=', '0.000933645')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001055849')
# ('Epoch:', '0086', 'training time (minutes)=', '0.2195', 'loss=', '0.000925870')
# ('Epoch:', '0087', 'training time (minutes)=', '0.2199', 'loss=', '0.000960528')
# ('Epoch:', '0088', 'training time (minutes)=', '0.2193', 'loss=', '0.000924196')
# ('Epoch:', '0089', 'training time (minutes)=', '0.2200', 'loss=', '0.000929300')
# ('Epoch:', '0090', 'training time (minutes)=', '0.2200', 'loss=', '0.000908190')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001081253')
# ('Epoch:', '0091', 'training time (minutes)=', '0.2209', 'loss=', '0.000900317')
# ('Epoch:', '0092', 'training time (minutes)=', '0.2190', 'loss=', '0.000900066')
# ('Epoch:', '0093', 'training time (minutes)=', '0.2192', 'loss=', '0.000898038')
# ('Epoch:', '0094', 'training time (minutes)=', '0.2180', 'loss=', '0.000898979')
# ('Epoch:', '0095', 'training time (minutes)=', '0.2188', 'loss=', '0.000897607')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001045347')
# ('Epoch:', '0096', 'training time (minutes)=', '0.2206', 'loss=', '0.000889271')
# ('Epoch:', '0097', 'training time (minutes)=', '0.2185', 'loss=', '0.000904821')
# ('Epoch:', '0098', 'training time (minutes)=', '0.2200', 'loss=', '0.000888710')
# ('Epoch:', '0099', 'training time (minutes)=', '0.2204', 'loss=', '0.000897906')
# ('Epoch:', '0100', 'training time (minutes)=', '0.2199', 'loss=', '0.000909461')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001050148')
# ('Epoch:', '0101', 'training time (minutes)=', '0.2189', 'loss=', '0.000932661')
# ('Epoch:', '0102', 'training time (minutes)=', '0.2205', 'loss=', '0.000911971')
# ('Epoch:', '0103', 'training time (minutes)=', '0.2198', 'loss=', '0.000895149')
# ('Epoch:', '0104', 'training time (minutes)=', '0.2211', 'loss=', '0.000871386')
# ('Epoch:', '0105', 'training time (minutes)=', '0.2176', 'loss=', '0.000880265')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001043108')
# ('Epoch:', '0106', 'training time (minutes)=', '0.2219', 'loss=', '0.000867976')
# ('Epoch:', '0107', 'training time (minutes)=', '0.2211', 'loss=', '0.000867166')
# ('Epoch:', '0108', 'training time (minutes)=', '0.2183', 'loss=', '0.000873818')
# ('Epoch:', '0109', 'training time (minutes)=', '0.2212', 'loss=', '0.000868170')
# ('Epoch:', '0110', 'training time (minutes)=', '0.2208', 'loss=', '0.000860330')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001013707')
# ('Epoch:', '0111', 'training time (minutes)=', '0.2216', 'loss=', '0.000861047')
# ('Epoch:', '0112', 'training time (minutes)=', '0.2177', 'loss=', '0.000867780')
# ('Epoch:', '0113', 'training time (minutes)=', '0.2202', 'loss=', '0.000879959')
# ('Epoch:', '0114', 'training time (minutes)=', '0.2187', 'loss=', '0.000845498')
# ('Epoch:', '0115', 'training time (minutes)=', '0.2195', 'loss=', '0.000848392')
# ('Held Out Data :', 'forward time (minutes)=', '0.0066', 'loss=', '0.001035959')
# ('Epoch:', '0116', 'training time (minutes)=', '0.2198', 'loss=', '0.000849465')
# ('Epoch:', '0117', 'training time (minutes)=', '0.2183', 'loss=', '0.000863537')
# ('Epoch:', '0118', 'training time (minutes)=', '0.2207', 'loss=', '0.000844226')
# ('Epoch:', '0119', 'training time (minutes)=', '0.2206', 'loss=', '0.000852236')
# ('Epoch:', '0120', 'training time (minutes)=', '0.2196', 'loss=', '0.000852102')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001043214')
# ('Epoch:', '0121', 'training time (minutes)=', '0.2196', 'loss=', '0.000840582')
# ('Epoch:', '0122', 'training time (minutes)=', '0.2201', 'loss=', '0.000833129')
# ('Epoch:', '0123', 'training time (minutes)=', '0.2197', 'loss=', '0.000843037')
# ('Epoch:', '0124', 'training time (minutes)=', '0.2196', 'loss=', '0.000822115')
# ('Epoch:', '0125', 'training time (minutes)=', '0.2174', 'loss=', '0.000819844')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001016772')
# ('Epoch:', '0126', 'training time (minutes)=', '0.2197', 'loss=', '0.000818321')
# ('Epoch:', '0127', 'training time (minutes)=', '0.2201', 'loss=', '0.000828806')
# ('Epoch:', '0128', 'training time (minutes)=', '0.2147', 'loss=', '0.000821176')
# ('Epoch:', '0129', 'training time (minutes)=', '0.2200', 'loss=', '0.000816850')
# ('Epoch:', '0130', 'training time (minutes)=', '0.2186', 'loss=', '0.000829345')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.001020550')
# ('Epoch:', '0131', 'training time (minutes)=', '0.2197', 'loss=', '0.000830742')
# ('Epoch:', '0132', 'training time (minutes)=', '0.2207', 'loss=', '0.000824770')
# ('Epoch:', '0133', 'training time (minutes)=', '0.2188', 'loss=', '0.000816994')
# ('Epoch:', '0134', 'training time (minutes)=', '0.2178', 'loss=', '0.000822940')
# ('Epoch:', '0135', 'training time (minutes)=', '0.2242', 'loss=', '0.000798616')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001016760')
# ('Epoch:', '0136', 'training time (minutes)=', '0.2206', 'loss=', '0.000835132')
# ('Epoch:', '0137', 'training time (minutes)=', '0.2198', 'loss=', '0.000799802')
# ('Epoch:', '0138', 'training time (minutes)=', '0.2189', 'loss=', '0.000794370')
# ('Epoch:', '0139', 'training time (minutes)=', '0.2200', 'loss=', '0.000802716')
# ('Epoch:', '0140', 'training time (minutes)=', '0.2203', 'loss=', '0.000800721')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001049592')
# ('Epoch:', '0141', 'training time (minutes)=', '0.2196', 'loss=', '0.000790152')
# ('Epoch:', '0142', 'training time (minutes)=', '0.2172', 'loss=', '0.000800541')
# ('Epoch:', '0143', 'training time (minutes)=', '0.2233', 'loss=', '0.000795899')
# ('Epoch:', '0144', 'training time (minutes)=', '0.2177', 'loss=', '0.000796006')
# ('Epoch:', '0145', 'training time (minutes)=', '0.2214', 'loss=', '0.000794050')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.001029510')
# ('Epoch:', '0146', 'training time (minutes)=', '0.2200', 'loss=', '0.000789733')
# ('Epoch:', '0147', 'training time (minutes)=', '0.2207', 'loss=', '0.000811972')
# ('Epoch:', '0148', 'training time (minutes)=', '0.2213', 'loss=', '0.000794420')
# ('Epoch:', '0149', 'training time (minutes)=', '0.2207', 'loss=', '0.000784235')
# ('Epoch:', '0150', 'training time (minutes)=', '0.2214', 'loss=', '0.000796331')
# ('Held Out Data :', 'forward time (minutes)=', '0.0059', 'loss=', '0.001029386')
# ('Epoch:', '0151', 'training time (minutes)=', '0.2192', 'loss=', '0.000803312')
# ('Epoch:', '0152', 'training time (minutes)=', '0.2202', 'loss=', '0.000788849')
# ('Epoch:', '0153', 'training time (minutes)=', '0.2197', 'loss=', '0.000776558')
# ('Epoch:', '0154', 'training time (minutes)=', '0.2212', 'loss=', '0.000797310')
# ('Epoch:', '0155', 'training time (minutes)=', '0.2194', 'loss=', '0.000792013')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000993035')
# ('Epoch:', '0156', 'training time (minutes)=', '0.2204', 'loss=', '0.000779064')
# ('Epoch:', '0157', 'training time (minutes)=', '0.2220', 'loss=', '0.000777504')
# ('Epoch:', '0158', 'training time (minutes)=', '0.2211', 'loss=', '0.000764342')
# ('Epoch:', '0159', 'training time (minutes)=', '0.2192', 'loss=', '0.000770435')
# ('Epoch:', '0160', 'training time (minutes)=', '0.2187', 'loss=', '0.000766364')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000991797')
# ('Epoch:', '0161', 'training time (minutes)=', '0.2204', 'loss=', '0.000766328')
# ('Epoch:', '0162', 'training time (minutes)=', '0.2201', 'loss=', '0.000766473')
# ('Epoch:', '0163', 'training time (minutes)=', '0.2187', 'loss=', '0.000752818')
# ('Epoch:', '0164', 'training time (minutes)=', '0.2174', 'loss=', '0.000765300')
# ('Epoch:', '0165', 'training time (minutes)=', '0.2212', 'loss=', '0.000762643')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.001009379')
# ('Epoch:', '0166', 'training time (minutes)=', '0.2197', 'loss=', '0.000773313')
# ('Epoch:', '0167', 'training time (minutes)=', '0.2202', 'loss=', '0.000775117')
# ('Epoch:', '0168', 'training time (minutes)=', '0.2206', 'loss=', '0.000758925')
# ('Epoch:', '0169', 'training time (minutes)=', '0.2204', 'loss=', '0.000772161')
# ('Epoch:', '0170', 'training time (minutes)=', '0.2186', 'loss=', '0.000759102')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.000993790')
# ('Epoch:', '0171', 'training time (minutes)=', '0.2184', 'loss=', '0.000764512')
# ('Epoch:', '0172', 'training time (minutes)=', '0.2189', 'loss=', '0.000771464')
# ('Epoch:', '0173', 'training time (minutes)=', '0.2194', 'loss=', '0.000765992')
# ('Epoch:', '0174', 'training time (minutes)=', '0.2189', 'loss=', '0.000758020')
# ('Epoch:', '0175', 'training time (minutes)=', '0.2210', 'loss=', '0.000754116')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.000985950')
# ('Epoch:', '0176', 'training time (minutes)=', '0.2182', 'loss=', '0.000754088')
# ('Epoch:', '0177', 'training time (minutes)=', '0.2213', 'loss=', '0.000762304')
# ('Epoch:', '0178', 'training time (minutes)=', '0.2182', 'loss=', '0.000763287')
# ('Epoch:', '0179', 'training time (minutes)=', '0.2209', 'loss=', '0.000766503')
# ('Epoch:', '0180', 'training time (minutes)=', '0.2210', 'loss=', '0.000745294')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000988931')
# ('Epoch:', '0181', 'training time (minutes)=', '0.2202', 'loss=', '0.000753719')
# ('Epoch:', '0182', 'training time (minutes)=', '0.2200', 'loss=', '0.000753414')
# ('Epoch:', '0183', 'training time (minutes)=', '0.2212', 'loss=', '0.000732285')
# ('Epoch:', '0184', 'training time (minutes)=', '0.2196', 'loss=', '0.000747694')
# ('Epoch:', '0185', 'training time (minutes)=', '0.2206', 'loss=', '0.000740815')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000985855')
# ('Epoch:', '0186', 'training time (minutes)=', '0.2209', 'loss=', '0.000745901')
# ('Epoch:', '0187', 'training time (minutes)=', '0.2200', 'loss=', '0.000743211')
# ('Epoch:', '0188', 'training time (minutes)=', '0.2203', 'loss=', '0.000753089')
# ('Epoch:', '0189', 'training time (minutes)=', '0.2194', 'loss=', '0.000755048')
# ('Epoch:', '0190', 'training time (minutes)=', '0.2213', 'loss=', '0.000739660')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001002769')
# ('Epoch:', '0191', 'training time (minutes)=', '0.2209', 'loss=', '0.000740819')
# ('Epoch:', '0192', 'training time (minutes)=', '0.2208', 'loss=', '0.000748971')
# ('Epoch:', '0193', 'training time (minutes)=', '0.2210', 'loss=', '0.000735472')
# ('Epoch:', '0194', 'training time (minutes)=', '0.2197', 'loss=', '0.000742700')
# ('Epoch:', '0195', 'training time (minutes)=', '0.2212', 'loss=', '0.000752244')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000993382')
# ('Epoch:', '0196', 'training time (minutes)=', '0.2212', 'loss=', '0.000738587')
# ('Epoch:', '0197', 'training time (minutes)=', '0.2189', 'loss=', '0.000742558')
# ('Epoch:', '0198', 'training time (minutes)=', '0.2220', 'loss=', '0.000745730')
# ('Epoch:', '0199', 'training time (minutes)=', '0.2212', 'loss=', '0.000737497')
# ('Epoch:', '0200', 'training time (minutes)=', '0.2209', 'loss=', '0.000734011')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000985441')
# ('Epoch:', '0201', 'training time (minutes)=', '0.2197', 'loss=', '0.000742779')
# ('Epoch:', '0202', 'training time (minutes)=', '0.2215', 'loss=', '0.000739683')
# ('Epoch:', '0203', 'training time (minutes)=', '0.2205', 'loss=', '0.000720189')
# ('Epoch:', '0204', 'training time (minutes)=', '0.2209', 'loss=', '0.000739650')
# ('Epoch:', '0205', 'training time (minutes)=', '0.2197', 'loss=', '0.000732302')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000988833')
# ('Epoch:', '0206', 'training time (minutes)=', '0.2208', 'loss=', '0.000740527')
# ('Epoch:', '0207', 'training time (minutes)=', '0.2196', 'loss=', '0.000722438')
# ('Epoch:', '0208', 'training time (minutes)=', '0.2183', 'loss=', '0.000727333')
# ('Epoch:', '0209', 'training time (minutes)=', '0.2188', 'loss=', '0.000715177')
# ('Epoch:', '0210', 'training time (minutes)=', '0.2184', 'loss=', '0.000724954')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000984032')
# ('Epoch:', '0211', 'training time (minutes)=', '0.2210', 'loss=', '0.000707916')
# ('Epoch:', '0212', 'training time (minutes)=', '0.2212', 'loss=', '0.000714702')
# ('Epoch:', '0213', 'training time (minutes)=', '0.2210', 'loss=', '0.000738066')
# ('Epoch:', '0214', 'training time (minutes)=', '0.2207', 'loss=', '0.000711547')
# ('Epoch:', '0215', 'training time (minutes)=', '0.2211', 'loss=', '0.000721134')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000987579')
# ('Epoch:', '0216', 'training time (minutes)=', '0.2204', 'loss=', '0.000722229')
# ('Epoch:', '0217', 'training time (minutes)=', '0.2215', 'loss=', '0.000713649')
# ('Epoch:', '0218', 'training time (minutes)=', '0.2204', 'loss=', '0.000719107')
# ('Epoch:', '0219', 'training time (minutes)=', '0.2218', 'loss=', '0.000710543')
# ('Epoch:', '0220', 'training time (minutes)=', '0.2191', 'loss=', '0.000714094')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000989882')
# ('Epoch:', '0221', 'training time (minutes)=', '0.2231', 'loss=', '0.000707669')
# ('Epoch:', '0222', 'training time (minutes)=', '0.2208', 'loss=', '0.000710725')
# ('Epoch:', '0223', 'training time (minutes)=', '0.2212', 'loss=', '0.000705568')
# ('Epoch:', '0224', 'training time (minutes)=', '0.2204', 'loss=', '0.000721359')
# ('Epoch:', '0225', 'training time (minutes)=', '0.2218', 'loss=', '0.000713602')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000971521')
# ('Epoch:', '0226', 'training time (minutes)=', '0.2189', 'loss=', '0.000714675')
# ('Epoch:', '0227', 'training time (minutes)=', '0.2202', 'loss=', '0.000722240')
# ('Epoch:', '0228', 'training time (minutes)=', '0.2194', 'loss=', '0.000727525')
# ('Epoch:', '0229', 'training time (minutes)=', '0.2206', 'loss=', '0.000723347')
# ('Epoch:', '0230', 'training time (minutes)=', '0.2224', 'loss=', '0.000715668')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000986078')
# ('Epoch:', '0231', 'training time (minutes)=', '0.2199', 'loss=', '0.000713394')
# ('Epoch:', '0232', 'training time (minutes)=', '0.2202', 'loss=', '0.000715358')
# ('Epoch:', '0233', 'training time (minutes)=', '0.2199', 'loss=', '0.000702320')
# ('Epoch:', '0234', 'training time (minutes)=', '0.2188', 'loss=', '0.000693798')
# ('Epoch:', '0235', 'training time (minutes)=', '0.2209', 'loss=', '0.000704203')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000976122')
# ('Epoch:', '0236', 'training time (minutes)=', '0.2223', 'loss=', '0.000717122')
# ('Epoch:', '0237', 'training time (minutes)=', '0.2209', 'loss=', '0.000724318')
# ('Epoch:', '0238', 'training time (minutes)=', '0.2210', 'loss=', '0.000711997')
# ('Epoch:', '0239', 'training time (minutes)=', '0.2194', 'loss=', '0.000700835')
# ('Epoch:', '0240', 'training time (minutes)=', '0.2221', 'loss=', '0.000709203')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001008141')
# ('Epoch:', '0241', 'training time (minutes)=', '0.2190', 'loss=', '0.000704016')
# ('Epoch:', '0242', 'training time (minutes)=', '0.2209', 'loss=', '0.000712328')
# ('Epoch:', '0243', 'training time (minutes)=', '0.2213', 'loss=', '0.000692319')
# ('Epoch:', '0244', 'training time (minutes)=', '0.2193', 'loss=', '0.000698544')
# ('Epoch:', '0245', 'training time (minutes)=', '0.2206', 'loss=', '0.000702112')
# ('Held Out Data :', 'forward time (minutes)=', '0.0050', 'loss=', '0.000971975')
# ('Epoch:', '0246', 'training time (minutes)=', '0.2208', 'loss=', '0.000707449')
# ('Epoch:', '0247', 'training time (minutes)=', '0.2198', 'loss=', '0.000706759')
# ('Epoch:', '0248', 'training time (minutes)=', '0.2202', 'loss=', '0.000697000')
# ('Epoch:', '0249', 'training time (minutes)=', '0.2208', 'loss=', '0.000701500')
# ('Epoch:', '0250', 'training time (minutes)=', '0.2201', 'loss=', '0.000686383')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000982196')
# ('Epoch:', '0251', 'training time (minutes)=', '0.2218', 'loss=', '0.000687131')
# ('Epoch:', '0252', 'training time (minutes)=', '0.2199', 'loss=', '0.000706749')
# ('Epoch:', '0253', 'training time (minutes)=', '0.2209', 'loss=', '0.000689024')
# ('Epoch:', '0254', 'training time (minutes)=', '0.2209', 'loss=', '0.000698774')
# ('Epoch:', '0255', 'training time (minutes)=', '0.2211', 'loss=', '0.000715033')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.001013630')
# ('Epoch:', '0256', 'training time (minutes)=', '0.2196', 'loss=', '0.000712371')
# ('Epoch:', '0257', 'training time (minutes)=', '0.2202', 'loss=', '0.000693611')
# ('Epoch:', '0258', 'training time (minutes)=', '0.2180', 'loss=', '0.000698110')
# ('Epoch:', '0259', 'training time (minutes)=', '0.2215', 'loss=', '0.000691459')
# ('Epoch:', '0260', 'training time (minutes)=', '0.2218', 'loss=', '0.000690772')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000971662')
# ('Epoch:', '0261', 'training time (minutes)=', '0.2199', 'loss=', '0.000689051')
# ('Epoch:', '0262', 'training time (minutes)=', '0.2199', 'loss=', '0.000692100')
# ('Epoch:', '0263', 'training time (minutes)=', '0.2212', 'loss=', '0.000688073')
# ('Epoch:', '0264', 'training time (minutes)=', '0.2197', 'loss=', '0.000681878')
# ('Epoch:', '0265', 'training time (minutes)=', '0.2199', 'loss=', '0.000686769')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000966569')
# ('Epoch:', '0266', 'training time (minutes)=', '0.2196', 'loss=', '0.000696594')
# ('Epoch:', '0267', 'training time (minutes)=', '0.2193', 'loss=', '0.000687349')
# ('Epoch:', '0268', 'training time (minutes)=', '0.2237', 'loss=', '0.000702155')
# ('Epoch:', '0269', 'training time (minutes)=', '0.2193', 'loss=', '0.000716181')
# ('Epoch:', '0270', 'training time (minutes)=', '0.2218', 'loss=', '0.000697467')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000973353')
# ('Epoch:', '0271', 'training time (minutes)=', '0.2192', 'loss=', '0.000681764')
# ('Epoch:', '0272', 'training time (minutes)=', '0.2199', 'loss=', '0.000688798')
# ('Epoch:', '0273', 'training time (minutes)=', '0.2189', 'loss=', '0.000683814')
# ('Epoch:', '0274', 'training time (minutes)=', '0.2198', 'loss=', '0.000687575')
# ('Epoch:', '0275', 'training time (minutes)=', '0.2220', 'loss=', '0.000684864')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000977180')
# ('Epoch:', '0276', 'training time (minutes)=', '0.2191', 'loss=', '0.000672312')
# ('Epoch:', '0277', 'training time (minutes)=', '0.2196', 'loss=', '0.000675725')
# ('Epoch:', '0278', 'training time (minutes)=', '0.2203', 'loss=', '0.000689953')
# ('Epoch:', '0279', 'training time (minutes)=', '0.2181', 'loss=', '0.000682043')
# ('Epoch:', '0280', 'training time (minutes)=', '0.2203', 'loss=', '0.000679280')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000986211')
# ('Epoch:', '0281', 'training time (minutes)=', '0.2200', 'loss=', '0.000677242')
# ('Epoch:', '0282', 'training time (minutes)=', '0.2205', 'loss=', '0.000680886')
# ('Epoch:', '0283', 'training time (minutes)=', '0.2199', 'loss=', '0.000669437')
# ('Epoch:', '0284', 'training time (minutes)=', '0.2192', 'loss=', '0.000673613')
# ('Epoch:', '0285', 'training time (minutes)=', '0.2192', 'loss=', '0.000682866')
# ('Held Out Data :', 'forward time (minutes)=', '0.0055', 'loss=', '0.001002336')
# ('Epoch:', '0286', 'training time (minutes)=', '0.2191', 'loss=', '0.000681966')
# ('Epoch:', '0287', 'training time (minutes)=', '0.2199', 'loss=', '0.000682490')
# ('Epoch:', '0288', 'training time (minutes)=', '0.2209', 'loss=', '0.000670292')
# ('Epoch:', '0289', 'training time (minutes)=', '0.2201', 'loss=', '0.000678850')
# ('Epoch:', '0290', 'training time (minutes)=', '0.2201', 'loss=', '0.000688557')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000972476')
# ('Epoch:', '0291', 'training time (minutes)=', '0.2179', 'loss=', '0.000693249')
# ('Epoch:', '0292', 'training time (minutes)=', '0.2219', 'loss=', '0.000665461')
# ('Epoch:', '0293', 'training time (minutes)=', '0.2188', 'loss=', '0.000669593')
# ('Epoch:', '0294', 'training time (minutes)=', '0.2193', 'loss=', '0.000680746')
# ('Epoch:', '0295', 'training time (minutes)=', '0.2200', 'loss=', '0.000682671')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000980876')
# ('Epoch:', '0296', 'training time (minutes)=', '0.2211', 'loss=', '0.000680710')
# ('Epoch:', '0297', 'training time (minutes)=', '0.2175', 'loss=', '0.000681554')
# ('Epoch:', '0298', 'training time (minutes)=', '0.2206', 'loss=', '0.000665695')
# ('Epoch:', '0299', 'training time (minutes)=', '0.2188', 'loss=', '0.000670613')
# ('Epoch:', '0300', 'training time (minutes)=', '0.2215', 'loss=', '0.000672966')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.000974898')
# ('Epoch:', '0301', 'training time (minutes)=', '0.2207', 'loss=', '0.000670441')
# ('Epoch:', '0302', 'training time (minutes)=', '0.2198', 'loss=', '0.000664094')
# ('Epoch:', '0303', 'training time (minutes)=', '0.2187', 'loss=', '0.000670281')
# ('Epoch:', '0304', 'training time (minutes)=', '0.2198', 'loss=', '0.000667849')
# ('Epoch:', '0305', 'training time (minutes)=', '0.2191', 'loss=', '0.000664975')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000973718')
# ('Epoch:', '0306', 'training time (minutes)=', '0.2206', 'loss=', '0.000661914')
# ('Epoch:', '0307', 'training time (minutes)=', '0.2189', 'loss=', '0.000664674')
# ('Epoch:', '0308', 'training time (minutes)=', '0.2214', 'loss=', '0.000669061')
# ('Epoch:', '0309', 'training time (minutes)=', '0.2190', 'loss=', '0.000669433')
# ('Epoch:', '0310', 'training time (minutes)=', '0.2194', 'loss=', '0.000661160')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000957432')
# ('Epoch:', '0311', 'training time (minutes)=', '0.2172', 'loss=', '0.000671503')
# ('Epoch:', '0312', 'training time (minutes)=', '0.2195', 'loss=', '0.000677284')
# ('Epoch:', '0313', 'training time (minutes)=', '0.2191', 'loss=', '0.000677442')
# ('Epoch:', '0314', 'training time (minutes)=', '0.2226', 'loss=', '0.000659876')
# ('Epoch:', '0315', 'training time (minutes)=', '0.2182', 'loss=', '0.000669997')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000958502')
# ('Epoch:', '0316', 'training time (minutes)=', '0.2190', 'loss=', '0.000649545')
# ('Epoch:', '0317', 'training time (minutes)=', '0.2207', 'loss=', '0.000657528')
# ('Epoch:', '0318', 'training time (minutes)=', '0.2185', 'loss=', '0.000655736')
# ('Epoch:', '0319', 'training time (minutes)=', '0.2208', 'loss=', '0.000662840')
# ('Epoch:', '0320', 'training time (minutes)=', '0.2199', 'loss=', '0.000671983')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000955558')
# ('Epoch:', '0321', 'training time (minutes)=', '0.2209', 'loss=', '0.000668935')
# ('Epoch:', '0322', 'training time (minutes)=', '0.2204', 'loss=', '0.000673147')
# ('Epoch:', '0323', 'training time (minutes)=', '0.2193', 'loss=', '0.000660730')
# ('Epoch:', '0324', 'training time (minutes)=', '0.2172', 'loss=', '0.000668663')
# ('Epoch:', '0325', 'training time (minutes)=', '0.2207', 'loss=', '0.000664988')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000954162')
# ('Epoch:', '0326', 'training time (minutes)=', '0.2190', 'loss=', '0.000656243')
# ('Epoch:', '0327', 'training time (minutes)=', '0.2203', 'loss=', '0.000661847')
# ('Epoch:', '0328', 'training time (minutes)=', '0.2185', 'loss=', '0.000667114')
# ('Epoch:', '0329', 'training time (minutes)=', '0.2188', 'loss=', '0.000657548')
# ('Epoch:', '0330', 'training time (minutes)=', '0.2212', 'loss=', '0.000651502')
# ('Held Out Data :', 'forward time (minutes)=', '0.0058', 'loss=', '0.000963856')
# ('Epoch:', '0331', 'training time (minutes)=', '0.2198', 'loss=', '0.000661892')
# ('Epoch:', '0332', 'training time (minutes)=', '0.2206', 'loss=', '0.000651156')
# ('Epoch:', '0333', 'training time (minutes)=', '0.2187', 'loss=', '0.000648549')
# ('Epoch:', '0334', 'training time (minutes)=', '0.2188', 'loss=', '0.000651859')
# ('Epoch:', '0335', 'training time (minutes)=', '0.2174', 'loss=', '0.000645472')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000968732')
# ('Epoch:', '0336', 'training time (minutes)=', '0.2204', 'loss=', '0.000641192')
# ('Epoch:', '0337', 'training time (minutes)=', '0.2190', 'loss=', '0.000658625')
# ('Epoch:', '0338', 'training time (minutes)=', '0.2209', 'loss=', '0.000664306')
# ('Epoch:', '0339', 'training time (minutes)=', '0.2201', 'loss=', '0.000652822')
# ('Epoch:', '0340', 'training time (minutes)=', '0.2205', 'loss=', '0.000652373')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000980388')
# ('Epoch:', '0341', 'training time (minutes)=', '0.2185', 'loss=', '0.000653139')
# ('Epoch:', '0342', 'training time (minutes)=', '0.2205', 'loss=', '0.000645327')
# ('Epoch:', '0343', 'training time (minutes)=', '0.2181', 'loss=', '0.000652881')
# ('Epoch:', '0344', 'training time (minutes)=', '0.2207', 'loss=', '0.000646196')
# ('Epoch:', '0345', 'training time (minutes)=', '0.2215', 'loss=', '0.000667520')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000963482')
# ('Epoch:', '0346', 'training time (minutes)=', '0.2205', 'loss=', '0.000656940')
# ('Epoch:', '0347', 'training time (minutes)=', '0.2209', 'loss=', '0.000678050')
# ('Epoch:', '0348', 'training time (minutes)=', '0.2180', 'loss=', '0.000666375')
# ('Epoch:', '0349', 'training time (minutes)=', '0.2211', 'loss=', '0.000652162')
# ('Epoch:', '0350', 'training time (minutes)=', '0.2203', 'loss=', '0.000652754')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000980922')
# ('Epoch:', '0351', 'training time (minutes)=', '0.2206', 'loss=', '0.000649116')
# ('Epoch:', '0352', 'training time (minutes)=', '0.2204', 'loss=', '0.000652025')
# ('Epoch:', '0353', 'training time (minutes)=', '0.2198', 'loss=', '0.000653917')
# ('Epoch:', '0354', 'training time (minutes)=', '0.2193', 'loss=', '0.000655200')
# ('Epoch:', '0355', 'training time (minutes)=', '0.2200', 'loss=', '0.000650373')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000970521')
# ('Epoch:', '0356', 'training time (minutes)=', '0.2219', 'loss=', '0.000641194')
# ('Epoch:', '0357', 'training time (minutes)=', '0.2201', 'loss=', '0.000655652')
# ('Epoch:', '0358', 'training time (minutes)=', '0.2236', 'loss=', '0.000655782')
# ('Epoch:', '0359', 'training time (minutes)=', '0.2196', 'loss=', '0.000646931')
# ('Epoch:', '0360', 'training time (minutes)=', '0.2203', 'loss=', '0.000655833')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000970337')
# ('Epoch:', '0361', 'training time (minutes)=', '0.2206', 'loss=', '0.000640055')
# ('Epoch:', '0362', 'training time (minutes)=', '0.2199', 'loss=', '0.000652017')
# ('Epoch:', '0363', 'training time (minutes)=', '0.2216', 'loss=', '0.000650525')
# ('Epoch:', '0364', 'training time (minutes)=', '0.2198', 'loss=', '0.000648328')
# ('Epoch:', '0365', 'training time (minutes)=', '0.2226', 'loss=', '0.000657316')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000973234')
# ('Epoch:', '0366', 'training time (minutes)=', '0.2194', 'loss=', '0.000655928')
# ('Epoch:', '0367', 'training time (minutes)=', '0.2207', 'loss=', '0.000641902')
# ('Epoch:', '0368', 'training time (minutes)=', '0.2171', 'loss=', '0.000654210')
# ('Epoch:', '0369', 'training time (minutes)=', '0.2242', 'loss=', '0.000660668')
# ('Epoch:', '0370', 'training time (minutes)=', '0.2205', 'loss=', '0.000650335')
# ('Held Out Data :', 'forward time (minutes)=', '0.0067', 'loss=', '0.000977623')
# ('Epoch:', '0371', 'training time (minutes)=', '0.2217', 'loss=', '0.000638648')
# ('Epoch:', '0372', 'training time (minutes)=', '0.2187', 'loss=', '0.000653743')
# ('Epoch:', '0373', 'training time (minutes)=', '0.2219', 'loss=', '0.000641518')
# ('Epoch:', '0374', 'training time (minutes)=', '0.2207', 'loss=', '0.000643857')
# ('Epoch:', '0375', 'training time (minutes)=', '0.2198', 'loss=', '0.000646439')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000978762')
# ('Epoch:', '0376', 'training time (minutes)=', '0.2221', 'loss=', '0.000706122')
# ('Epoch:', '0377', 'training time (minutes)=', '0.2203', 'loss=', '0.000651665')
# ('Epoch:', '0378', 'training time (minutes)=', '0.2210', 'loss=', '0.000649334')
# ('Epoch:', '0379', 'training time (minutes)=', '0.2193', 'loss=', '0.000641778')
# ('Epoch:', '0380', 'training time (minutes)=', '0.2197', 'loss=', '0.000637504')
# ('Held Out Data :', 'forward time (minutes)=', '0.0063', 'loss=', '0.000963560')
# ('Epoch:', '0381', 'training time (minutes)=', '0.2213', 'loss=', '0.000635503')
# ('Epoch:', '0382', 'training time (minutes)=', '0.2205', 'loss=', '0.000637759')
# ('Epoch:', '0383', 'training time (minutes)=', '0.2201', 'loss=', '0.000634860')
# ('Epoch:', '0384', 'training time (minutes)=', '0.2190', 'loss=', '0.000630409')
# ('Epoch:', '0385', 'training time (minutes)=', '0.2194', 'loss=', '0.000633645')
# ('Held Out Data :', 'forward time (minutes)=', '0.0064', 'loss=', '0.000970067')
# ('Epoch:', '0386', 'training time (minutes)=', '0.2221', 'loss=', '0.000643470')
# ('Epoch:', '0387', 'training time (minutes)=', '0.2198', 'loss=', '0.000641580')
# ('Epoch:', '0388', 'training time (minutes)=', '0.2202', 'loss=', '0.000637867')
# ('Epoch:', '0389', 'training time (minutes)=', '0.2191', 'loss=', '0.000634841')
# ('Epoch:', '0390', 'training time (minutes)=', '0.2218', 'loss=', '0.000633429')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000976990')
# ('Epoch:', '0391', 'training time (minutes)=', '0.2189', 'loss=', '0.000632105')
# ('Epoch:', '0392', 'training time (minutes)=', '0.2212', 'loss=', '0.000647101')
# ('Epoch:', '0393', 'training time (minutes)=', '0.2180', 'loss=', '0.000636125')
# ('Epoch:', '0394', 'training time (minutes)=', '0.2195', 'loss=', '0.000631710')
# ('Epoch:', '0395', 'training time (minutes)=', '0.2228', 'loss=', '0.000639949')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000979212')
# ('Epoch:', '0396', 'training time (minutes)=', '0.2202', 'loss=', '0.000634548')
# ('Epoch:', '0397', 'training time (minutes)=', '0.2222', 'loss=', '0.000640361')
# ('Epoch:', '0398', 'training time (minutes)=', '0.2199', 'loss=', '0.000639155')
# ('Epoch:', '0399', 'training time (minutes)=', '0.2197', 'loss=', '0.000632943')
# ('Epoch:', '0400', 'training time (minutes)=', '0.2207', 'loss=', '0.000643100')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000980724')
# ('Epoch:', '0401', 'training time (minutes)=', '0.2211', 'loss=', '0.000635971')
# ('Epoch:', '0402', 'training time (minutes)=', '0.2196', 'loss=', '0.000640053')
# ('Epoch:', '0403', 'training time (minutes)=', '0.2202', 'loss=', '0.000633471')
# ('Epoch:', '0404', 'training time (minutes)=', '0.2203', 'loss=', '0.000639409')
# ('Epoch:', '0405', 'training time (minutes)=', '0.2211', 'loss=', '0.000644243')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000984712')
# ('Epoch:', '0406', 'training time (minutes)=', '0.2208', 'loss=', '0.000633310')
# ('Epoch:', '0407', 'training time (minutes)=', '0.2204', 'loss=', '0.000646627')
# ('Epoch:', '0408', 'training time (minutes)=', '0.2187', 'loss=', '0.000641641')
# ('Epoch:', '0409', 'training time (minutes)=', '0.2211', 'loss=', '0.000638500')
# ('Epoch:', '0410', 'training time (minutes)=', '0.2175', 'loss=', '0.000642527')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000970490')
# ('Epoch:', '0411', 'training time (minutes)=', '0.2220', 'loss=', '0.000630881')
# ('Epoch:', '0412', 'training time (minutes)=', '0.2219', 'loss=', '0.000629649')
# ('Epoch:', '0413', 'training time (minutes)=', '0.2200', 'loss=', '0.000627377')
# ('Epoch:', '0414', 'training time (minutes)=', '0.2205', 'loss=', '0.000620198')
# ('Epoch:', '0415', 'training time (minutes)=', '0.2241', 'loss=', '0.000636255')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000976210')
# ('Epoch:', '0416', 'training time (minutes)=', '0.2172', 'loss=', '0.000643936')
# ('Epoch:', '0417', 'training time (minutes)=', '0.2212', 'loss=', '0.000639707')
# ('Epoch:', '0418', 'training time (minutes)=', '0.2187', 'loss=', '0.000629194')
# ('Epoch:', '0419', 'training time (minutes)=', '0.2209', 'loss=', '0.000619331')
# ('Epoch:', '0420', 'training time (minutes)=', '0.2203', 'loss=', '0.000629107')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000984971')
# ('Epoch:', '0421', 'training time (minutes)=', '0.2219', 'loss=', '0.000628113')
# ('Epoch:', '0422', 'training time (minutes)=', '0.2208', 'loss=', '0.000623522')
# ('Epoch:', '0423', 'training time (minutes)=', '0.2184', 'loss=', '0.000615529')
# ('Epoch:', '0424', 'training time (minutes)=', '0.2191', 'loss=', '0.000626232')
# ('Epoch:', '0425', 'training time (minutes)=', '0.2229', 'loss=', '0.000621269')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.000990172')
# ('Epoch:', '0426', 'training time (minutes)=', '0.2210', 'loss=', '0.000623821')
# ('Epoch:', '0427', 'training time (minutes)=', '0.2216', 'loss=', '0.000623608')
# ('Epoch:', '0428', 'training time (minutes)=', '0.2210', 'loss=', '0.000630741')
# ('Epoch:', '0429', 'training time (minutes)=', '0.2195', 'loss=', '0.000626574')
# ('Epoch:', '0430', 'training time (minutes)=', '0.2216', 'loss=', '0.000627238')
# ('Held Out Data :', 'forward time (minutes)=', '0.0060', 'loss=', '0.000965531')
# ('Epoch:', '0431', 'training time (minutes)=', '0.2203', 'loss=', '0.000634598')
# ('Epoch:', '0432', 'training time (minutes)=', '0.2181', 'loss=', '0.000626034')
# ('Epoch:', '0433', 'training time (minutes)=', '0.2230', 'loss=', '0.000619394')
# ('Epoch:', '0434', 'training time (minutes)=', '0.2221', 'loss=', '0.000625131')
# ('Epoch:', '0435', 'training time (minutes)=', '0.2183', 'loss=', '0.000641163')
# ('Held Out Data :', 'forward time (minutes)=', '0.0062', 'loss=', '0.001009128')
# ('Epoch:', '0436', 'training time (minutes)=', '0.2211', 'loss=', '0.000642199')
# ('Epoch:', '0437', 'training time (minutes)=', '0.2210', 'loss=', '0.000627610')
# ('Epoch:', '0438', 'training time (minutes)=', '0.2209', 'loss=', '0.000629826')
# ('Epoch:', '0439', 'training time (minutes)=', '0.2210', 'loss=', '0.000629060')
# ('Epoch:', '0440', 'training time (minutes)=', '0.2222', 'loss=', '0.000628249')
# ('Held Out Data :', 'forward time (minutes)=', '0.0065', 'loss=', '0.000973800')
# ('Epoch:', '0441', 'training time (minutes)=', '0.2189', 'loss=', '0.000620437')
# ('Epoch:', '0442', 'training time (minutes)=', '0.2199', 'loss=', '0.000617525')
# ('Epoch:', '0443', 'training time (minutes)=', '0.2180', 'loss=', '0.000622658')
# ('Epoch:', '0444', 'training time (minutes)=', '0.2255', 'loss=', '0.000609281')
# ('Epoch:', '0445', 'training time (minutes)=', '0.2221', 'loss=', '0.000625896')
# ('Held Out Data :', 'forward time (minutes)=', '0.0061', 'loss=', '0.000978082')
# ('Epoch:', '0446', 'training time (minutes)=', '0.2205', 'loss=', '0.000620654')
# ('Epoch:', '0447', 'training time (minutes)=', '0.1319', 'loss=', '0.000607225')
# ('Epoch:', '0448', 'training time (minutes)=', '0.1191', 'loss=', '0.000615476')
# ('Epoch:', '0449', 'training time (minutes)=', '0.1195', 'loss=', '0.000636718')
# ('Epoch:', '0450', 'training time (minutes)=', '0.1212', 'loss=', '0.000643948')
# ('Held Out Data :', 'forward time (minutes)=', '0.0035', 'loss=', '0.000959656')
# ('Epoch:', '0451', 'training time (minutes)=', '0.1194', 'loss=', '0.000619643')
# ('Epoch:', '0452', 'training time (minutes)=', '0.1201', 'loss=', '0.000618977')
# ('Epoch:', '0453', 'training time (minutes)=', '0.1219', 'loss=', '0.000618446')
# ('Epoch:', '0454', 'training time (minutes)=', '0.1229', 'loss=', '0.000623848')
# ('Epoch:', '0455', 'training time (minutes)=', '0.1197', 'loss=', '0.000613276')
# ('Held Out Data :', 'forward time (minutes)=', '0.0035', 'loss=', '0.000966066')
# ('Epoch:', '0456', 'training time (minutes)=', '0.1193', 'loss=', '0.000615456')
# ('Epoch:', '0457', 'training time (minutes)=', '0.1225', 'loss=', '0.000613960')
# ('Epoch:', '0458', 'training time (minutes)=', '0.1222', 'loss=', '0.000623285')
# ('Epoch:', '0459', 'training time (minutes)=', '0.1198', 'loss=', '0.000616242')
# ('Epoch:', '0460', 'training time (minutes)=', '0.1197', 'loss=', '0.000609692')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.000968970')
# ('Epoch:', '0461', 'training time (minutes)=', '0.1185', 'loss=', '0.000629173')
# ('Epoch:', '0462', 'training time (minutes)=', '0.1212', 'loss=', '0.000614880')
# ('Epoch:', '0463', 'training time (minutes)=', '0.1227', 'loss=', '0.000607047')
# ('Epoch:', '0464', 'training time (minutes)=', '0.1199', 'loss=', '0.000606227')
# ('Epoch:', '0465', 'training time (minutes)=', '0.1225', 'loss=', '0.000601646')
# ('Held Out Data :', 'forward time (minutes)=', '0.0035', 'loss=', '0.000979968')
# ('Epoch:', '0466', 'training time (minutes)=', '0.1201', 'loss=', '0.000610981')
# ('Epoch:', '0467', 'training time (minutes)=', '0.1193', 'loss=', '0.000611731')
# ('Epoch:', '0468', 'training time (minutes)=', '0.1205', 'loss=', '0.000616225')
# ('Epoch:', '0469', 'training time (minutes)=', '0.1194', 'loss=', '0.000610685')
# ('Epoch:', '0470', 'training time (minutes)=', '0.1223', 'loss=', '0.000608334')
# ('Held Out Data :', 'forward time (minutes)=', '0.0037', 'loss=', '0.000976436')
# ('Epoch:', '0471', 'training time (minutes)=', '0.1202', 'loss=', '0.000620234')
# ('Epoch:', '0472', 'training time (minutes)=', '0.1194', 'loss=', '0.000621168')
# ('Epoch:', '0473', 'training time (minutes)=', '0.1209', 'loss=', '0.000617093')
# ('Epoch:', '0474', 'training time (minutes)=', '0.1209', 'loss=', '0.000621130')
# ('Epoch:', '0475', 'training time (minutes)=', '0.1211', 'loss=', '0.000610506')
# ('Held Out Data :', 'forward time (minutes)=', '0.0035', 'loss=', '0.000976907')
# ('Epoch:', '0476', 'training time (minutes)=', '0.1201', 'loss=', '0.000613194')
# ('Epoch:', '0477', 'training time (minutes)=', '0.1205', 'loss=', '0.000612714')
# ('Epoch:', '0478', 'training time (minutes)=', '0.1205', 'loss=', '0.000616698')
# ('Epoch:', '0479', 'training time (minutes)=', '0.1204', 'loss=', '0.000616576')
# ('Epoch:', '0480', 'training time (minutes)=', '0.1201', 'loss=', '0.000623774')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.000992791')
# ('Epoch:', '0481', 'training time (minutes)=', '0.1208', 'loss=', '0.000616251')
# ('Epoch:', '0482', 'training time (minutes)=', '0.1199', 'loss=', '0.000624439')
# ('Epoch:', '0483', 'training time (minutes)=', '0.1201', 'loss=', '0.000615948')
# ('Epoch:', '0484', 'training time (minutes)=', '0.1205', 'loss=', '0.000608322')
# ('Epoch:', '0485', 'training time (minutes)=', '0.1230', 'loss=', '0.000610190')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.000968155')
# ('Epoch:', '0486', 'training time (minutes)=', '0.1205', 'loss=', '0.000618322')
# ('Epoch:', '0487', 'training time (minutes)=', '0.1195', 'loss=', '0.000615976')
# ('Epoch:', '0488', 'training time (minutes)=', '0.1223', 'loss=', '0.000624929')
# ('Epoch:', '0489', 'training time (minutes)=', '0.1202', 'loss=', '0.000612800')
# ('Epoch:', '0490', 'training time (minutes)=', '0.1204', 'loss=', '0.000608699')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.000979669')
# ('Epoch:', '0491', 'training time (minutes)=', '0.1200', 'loss=', '0.000609413')
# ('Epoch:', '0492', 'training time (minutes)=', '0.1196', 'loss=', '0.000603933')
# ('Epoch:', '0493', 'training time (minutes)=', '0.1200', 'loss=', '0.000606422')
# ('Epoch:', '0494', 'training time (minutes)=', '0.1194', 'loss=', '0.000616371')
# ('Epoch:', '0495', 'training time (minutes)=', '0.1202', 'loss=', '0.000612589')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.000993705')
# ('Epoch:', '0496', 'training time (minutes)=', '0.1227', 'loss=', '0.000610367')
# ('Epoch:', '0497', 'training time (minutes)=', '0.1197', 'loss=', '0.000602796')
# ('Epoch:', '0498', 'training time (minutes)=', '0.1200', 'loss=', '0.000610473')
# ('Epoch:', '0499', 'training time (minutes)=', '0.1200', 'loss=', '0.000610258')
# ('Epoch:', '0500', 'training time (minutes)=', '0.1206', 'loss=', '0.000617064')
# ('Held Out Data :', 'forward time (minutes)=', '0.0036', 'loss=', '0.000976643')

# %%
from tf_lab.point_clouds.convenience import reconstruct_pclouds
_, l_test = reconstruct_pclouds(ae, in_data['test'].point_clouds, batch_size=100)
_, l_train = reconstruct_pclouds(ae, in_data['train'].point_clouds, batch_size=100)
print l_test, l_train
# Out:
# 0.000749164663748 0.000654067897925

# %%
a = np.arange(16).reshape(1,4,4)
a.repeat(3, axis=2)
a = np.arange(16).reshape(1,4,4)
print a
a = a.reshape(-1)
a = np.tile(a, 3)
# print a
a = np.transpose(a.reshape(1, 3, 4, 4), [0,3,2,1])
print a
print a.shape

n_filters = 5
n_pc_points = 4
# group_size = 20
batch_size = 1

in_layer = tf.placeholder(tf.float32, [None, n_pc_points, 3])

filter_weights = tf.nn.sigmoid(conv_1d(in_layer, group_size, n_filters))

tf.while_loop()


# tf.while_loop


# filter_weights = tf.constant(np.arange(n_pc_points * n_filters, dtype='f4').reshape(batch_size, n_pc_points, n_filters))

# print sess.run(filter_weights)

# filter_weights = tf.reshape(filter_weights, [-1, n_pc_points*n_filters])

# filter_weights = tf.tile(filter_weights, [1,3]) # expand for x-y-z

# filter_weights = tf.transpose(tf.reshape(filter_weights, (1, n_pc_points, n_filters, 3) ), [0, 2, 3, 1])

# sess.run(filter_weights[0][0])
