# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 0
setup_one_gpu(GPU)
# Out:
# Picking GPU 0

# %%
import sys
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from functools import partial

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter
from tf_lab.point_clouds.ae_templates import mlp_architecture_ala_iclr_18, default_train_params

from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder

from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id

from tf_lab.iclr.helper import load_multiple_version_of_pcs, find_best_validation_epoch_from_train_stats

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'
experiment_tag = 'mlp_with_split_1pc_usampled_bnorm_on_encoder_only'
loss = 'emd'

n_pc_points = 2048
random_seed = 42

# %%
class_name = raw_input('Give me the class type: ').lower()
syn_id = snc_category_to_synth_id()[class_name]
# Out:
# Give me the class type: chair

# %%
in_data  = load_multiple_version_of_pcs('uniform_one' ,syn_id, n_classes=1)
# Out:
# Loading test data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/test.txt
# 679 pclouds were loaded. They belong in 1 shape-classes.
# Loading train data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/train.txt
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# Loading val data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/val.txt
# 338 pclouds were loaded. They belong in 1 shape-classes.

# %%
bneck_list = bneck_list = [8, 16, 256, 512]
train_params = default_train_params()

for bneck in bneck_list:
    experiment_id = '_'.join(['ae', class_name, experiment_tag, str(n_pc_points), 'pts', str(bneck), 'bneck', loss])
    train_dir = osp.join(top_data_dir, 'OUT/iclr/nn_models/', experiment_id)
    create_dir(train_dir)
    
    reset_tf_graph()    
    encoder, decoder, enc_args, dec_args = mlp_architecture_ala_iclr_18(n_pc_points, bneck)    
    conf = Conf(n_input = [n_pc_points, 3],
                loss = loss,
                training_epochs = 500,
                batch_size = train_params['batch_size'],
                denoising = False,
                learning_rate = train_params['learning_rate'],
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = train_params['saver_step'],
                z_rotate = False,
                encoder = encoder,
                decoder = decoder,
                encoder_args = enc_args,
                decoder_args = dec_args
               )
    print conf
    conf.experiment_name = 'experiment_' + str(experiment_id)
    conf.held_out_step = 5
    conf.save(osp.join(train_dir, 'configuration'))
    ae = PointNetAutoEncoder(conf.experiment_name, conf)
    
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
    train_stats = ae.train(in_data['train'], conf, log_file=fout, held_out_data=in_data['test'])
    fout.close()
# Out:
#                     batch_size: 50
#                  consistent_io: None
#                          debug: False
#                        decoder: decoder_with_fc_only
#                   decoder_args: {'b_norm_finish': False, 'verbose': True, 'b_norm': False, 'layer_sizes': [256, 256, 6144]}
#                        encoder: encoder_with_convs_and_symmetry_new
#                   encoder_args: {'filter_sizes': [1], 'n_filters': [64, 128, 128, 256, 8], 'verbose': True, 'b_norm': True, 'strides': [1]}
#                  gauss_augment: None
#                   is_denoising: False
#                latent_vs_recon: 1.0
#                  learning_rate: 0.0005
#                           loss: emd
#              loss_display_step: 1
#                        n_input: [2048, 3]
#                       n_output: [2048, 3]
#                            n_z: None
#              saver_max_to_keep: None
#                     saver_step: 10
#                      train_dir: /orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd
#                training_epochs: 500
#                       z_rotate: False
#
# Building Encoder
# encoder_conv_layer_0 conv params =  256 bnorm params =  128
# Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/Relu:0", shape=(?, 2048, 64), dtype=float32)
# output size: 131072
#
# encoder_conv_layer_1 conv params =  8320 bnorm params =  256
# Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/Relu_1:0", shape=(?, 2048, 128), dtype=float32)
# output size: 262144
#
# encoder_conv_layer_2 conv params =  16512 bnorm params =  256
# Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/Relu_2:0", shape=(?, 2048, 128), dtype=float32)
# output size: 262144
#
# encoder_conv_layer_3 conv params =  33024 bnorm params =  512
# Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/Relu_3:0", shape=(?, 2048, 256), dtype=float32)
# output size: 524288
#
# encoder_conv_layer_4 conv params =  2056 bnorm params =  16
# Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/Relu_4:0", shape=(?, 2048, 8), dtype=float32)
# output size: 16384
#
# Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/Max:0", shape=(?, 8), dtype=float32)
# Building Decoder
# decoder_fc_0 FC params =  2304 Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/Relu_5:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# decoder_fc_1 FC params =  65792 Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/Relu_6:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# decoder_fc_2 FC params =  1579008 Tensor("experiment_ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd_2/decoder_fc_2/BiasAdd:0", shape=(?, 6144), dtype=float32)
# output size: 6144
#
# ('Epoch:', '0001', 'training time (minutes)=', '0.6421', 'loss=', '194.178180462')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '0.6340', 'loss=', '164.559200386')
# ('Epoch:', '0003', 'training time (minutes)=', '0.6345', 'loss=', '157.896813567')
# ('Epoch:', '0004', 'training time (minutes)=', '0.6321', 'loss=', '152.998075933')
# ('Epoch:', '0005', 'training time (minutes)=', '0.6338', 'loss=', '150.934741078')
# ('Held Out Data :', 'forward time (minutes)=', '0.0519', 'loss=', '146.964336689')
# ('Epoch:', '0006', 'training time (minutes)=', '0.6346', 'loss=', '149.173808090')
# ('Epoch:', '0007', 'training time (minutes)=', '0.6362', 'loss=', '146.979067595')
# ('Epoch:', '0008', 'training time (minutes)=', '0.6353', 'loss=', '147.369586182')
# ('Epoch:', '0009', 'training time (minutes)=', '0.6369', 'loss=', '145.726439766')
# ('Epoch:', '0010', 'training time (minutes)=', '0.5996', 'loss=', '144.390152508')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0522', 'loss=', '140.940203153')
# ('Epoch:', '0011', 'training time (minutes)=', '0.6345', 'loss=', '145.021012679')
# ('Epoch:', '0012', 'training time (minutes)=', '0.6353', 'loss=', '142.951019619')
# ('Epoch:', '0013', 'training time (minutes)=', '0.6351', 'loss=', '142.628731039')
# ('Epoch:', '0014', 'training time (minutes)=', '0.6375', 'loss=', '142.219506372')
# ('Epoch:', '0015', 'training time (minutes)=', '0.6349', 'loss=', '142.275403097')
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '144.276916504')
# ('Epoch:', '0016', 'training time (minutes)=', '0.6354', 'loss=', '141.237674083')
# ('Epoch:', '0017', 'training time (minutes)=', '0.6354', 'loss=', '141.243842349')
# ('Epoch:', '0018', 'training time (minutes)=', '0.6353', 'loss=', '140.312521362')
# ('Epoch:', '0019', 'training time (minutes)=', '0.6378', 'loss=', '140.673582923')
# ('Epoch:', '0020', 'training time (minutes)=', '0.6354', 'loss=', '139.702831169')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0512', 'loss=', '141.776038537')
# ('Epoch:', '0021', 'training time (minutes)=', '0.6369', 'loss=', '139.689836054')
# ('Epoch:', '0022', 'training time (minutes)=', '0.6040', 'loss=', '139.831019725')
# ('Epoch:', '0023', 'training time (minutes)=', '0.6345', 'loss=', '139.222602313')
# ('Epoch:', '0024', 'training time (minutes)=', '0.6348', 'loss=', '138.373471335')
# ('Epoch:', '0025', 'training time (minutes)=', '0.6380', 'loss=', '138.932400247')
# ('Held Out Data :', 'forward time (minutes)=', '0.0519', 'loss=', '141.717994103')
# ('Epoch:', '0026', 'training time (minutes)=', '0.6352', 'loss=', '137.975868756')
# ('Epoch:', '0027', 'training time (minutes)=', '0.6359', 'loss=', '138.287509421')
# ('Epoch:', '0028', 'training time (minutes)=', '0.6351', 'loss=', '136.984403992')
# ('Epoch:', '0029', 'training time (minutes)=', '0.6367', 'loss=', '136.490522103')
# ('Epoch:', '0030', 'training time (minutes)=', '0.6384', 'loss=', '136.984563148')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0513', 'loss=', '138.843400222')
# ('Epoch:', '0031', 'training time (minutes)=', '0.6373', 'loss=', '136.628153129')
# ('Epoch:', '0032', 'training time (minutes)=', '0.6352', 'loss=', '137.794588703')
# ('Epoch:', '0033', 'training time (minutes)=', '0.6370', 'loss=', '137.135008837')
# ('Epoch:', '0034', 'training time (minutes)=', '0.6050', 'loss=', '136.364999058')
# ('Epoch:', '0035', 'training time (minutes)=', '0.6352', 'loss=', '137.251771678')
# ('Held Out Data :', 'forward time (minutes)=', '0.0519', 'loss=', '140.631450947')
# ('Epoch:', '0036', 'training time (minutes)=', '0.6377', 'loss=', '136.128834932')
# ('Epoch:', '0037', 'training time (minutes)=', '0.6354', 'loss=', '135.657631517')
# ('Epoch:', '0038', 'training time (minutes)=', '0.6353', 'loss=', '135.246047708')
# ('Epoch:', '0039', 'training time (minutes)=', '0.6356', 'loss=', '135.323754949')
# ('Epoch:', '0040', 'training time (minutes)=', '0.6356', 'loss=', '136.063124483')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0513', 'loss=', '137.655018146')
# ('Epoch:', '0041', 'training time (minutes)=', '0.6355', 'loss=', '135.750450466')
# ('Epoch:', '0042', 'training time (minutes)=', '0.6389', 'loss=', '135.135649109')
# ('Epoch:', '0043', 'training time (minutes)=', '0.6350', 'loss=', '134.584866996')
# ('Epoch:', '0044', 'training time (minutes)=', '0.6357', 'loss=', '134.286452915')
# ('Epoch:', '0045', 'training time (minutes)=', '0.6359', 'loss=', '134.628761159')
# ('Held Out Data :', 'forward time (minutes)=', '0.0525', 'loss=', '138.771409255')
# ('Epoch:', '0046', 'training time (minutes)=', '0.6020', 'loss=', '134.528032386')
# ('Epoch:', '0047', 'training time (minutes)=', '0.6386', 'loss=', '133.759933206')
# ('Epoch:', '0048', 'training time (minutes)=', '0.6368', 'loss=', '135.038474838')
# ('Epoch:', '0049', 'training time (minutes)=', '0.6358', 'loss=', '134.151301707')
# ('Epoch:', '0050', 'training time (minutes)=', '0.6373', 'loss=', '133.872101095')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0518', 'loss=', '138.447687589')
# ('Epoch:', '0051', 'training time (minutes)=', '0.6364', 'loss=', '134.164039479')
# ('Epoch:', '0052', 'training time (minutes)=', '0.6354', 'loss=', '132.807334767')
# ('Epoch:', '0053', 'training time (minutes)=', '0.6392', 'loss=', '133.370143525')
# ('Epoch:', '0054', 'training time (minutes)=', '0.6383', 'loss=', '134.034678783')
# ('Epoch:', '0055', 'training time (minutes)=', '0.6364', 'loss=', '133.341086147')
# ('Held Out Data :', 'forward time (minutes)=', '0.0526', 'loss=', '136.509117713')
# ('Epoch:', '0056', 'training time (minutes)=', '0.6369', 'loss=', '132.909586566')
# ('Epoch:', '0057', 'training time (minutes)=', '0.6376', 'loss=', '133.081445578')
# ('Epoch:', '0058', 'training time (minutes)=', '0.6399', 'loss=', '132.332607103')
# ('Epoch:', '0059', 'training time (minutes)=', '0.6032', 'loss=', '133.031607984')
# ('Epoch:', '0060', 'training time (minutes)=', '0.6360', 'loss=', '132.046305383')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0519', 'loss=', '140.594336877')
# ('Epoch:', '0061', 'training time (minutes)=', '0.6375', 'loss=', '132.282120812')
# ('Epoch:', '0062', 'training time (minutes)=', '0.6375', 'loss=', '132.544160992')
# ('Epoch:', '0063', 'training time (minutes)=', '0.6377', 'loss=', '132.143816542')
# ('Epoch:', '0064', 'training time (minutes)=', '0.6394', 'loss=', '131.742767931')
# ('Epoch:', '0065', 'training time (minutes)=', '0.6370', 'loss=', '132.542799245')
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '136.561291034')
# ('Epoch:', '0066', 'training time (minutes)=', '0.6381', 'loss=', '131.680248824')
# ('Epoch:', '0067', 'training time (minutes)=', '0.6381', 'loss=', '131.853789288')
# ('Epoch:', '0068', 'training time (minutes)=', '0.6366', 'loss=', '131.488388393')
# ('Epoch:', '0069', 'training time (minutes)=', '0.6401', 'loss=', '131.675794519')
# ('Epoch:', '0070', 'training time (minutes)=', '0.6382', 'loss=', '131.472252688')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '139.851799598')
# ('Epoch:', '0071', 'training time (minutes)=', '0.6050', 'loss=', '131.977696095')
# ('Epoch:', '0072', 'training time (minutes)=', '0.6372', 'loss=', '130.884965117')
# ('Epoch:', '0073', 'training time (minutes)=', '0.6375', 'loss=', '131.355033476')
# ('Epoch:', '0074', 'training time (minutes)=', '0.6371', 'loss=', '130.620073003')
# ('Epoch:', '0075', 'training time (minutes)=', '0.6391', 'loss=', '130.171341141')
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '135.408273550')
# ('Epoch:', '0076', 'training time (minutes)=', '0.6372', 'loss=', '131.016884182')
# ('Epoch:', '0077', 'training time (minutes)=', '0.6360', 'loss=', '130.278193996')
# ('Epoch:', '0078', 'training time (minutes)=', '0.6373', 'loss=', '130.805381244')
# ('Epoch:', '0079', 'training time (minutes)=', '0.6386', 'loss=', '129.888443524')
# ('Epoch:', '0080', 'training time (minutes)=', '0.6390', 'loss=', '130.481544229')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0501', 'loss=', '136.072750385')
# ('Epoch:', '0081', 'training time (minutes)=', '0.6390', 'loss=', '130.460703576')
# ('Epoch:', '0082', 'training time (minutes)=', '0.6378', 'loss=', '130.420624443')
# ('Epoch:', '0083', 'training time (minutes)=', '0.6073', 'loss=', '130.230080447')
# ('Epoch:', '0084', 'training time (minutes)=', '0.6366', 'loss=', '129.968777068')
# ('Epoch:', '0085', 'training time (minutes)=', '0.6396', 'loss=', '130.628580773')
# ('Held Out Data :', 'forward time (minutes)=', '0.0489', 'loss=', '135.484738863')
# ('Epoch:', '0086', 'training time (minutes)=', '0.6393', 'loss=', '130.223252338')
# ('Epoch:', '0087', 'training time (minutes)=', '0.6357', 'loss=', '129.341889622')
# ('Epoch:', '0088', 'training time (minutes)=', '0.6369', 'loss=', '129.868663887')
# ('Epoch:', '0089', 'training time (minutes)=', '0.6360', 'loss=', '129.011383057')
# ('Epoch:', '0090', 'training time (minutes)=', '0.6371', 'loss=', '129.305383102')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '138.574645996')
# ('Epoch:', '0091', 'training time (minutes)=', '0.6372', 'loss=', '129.099986864')
# ('Epoch:', '0092', 'training time (minutes)=', '0.6390', 'loss=', '128.791847096')
# ('Epoch:', '0093', 'training time (minutes)=', '0.6365', 'loss=', '129.574858160')
# ('Epoch:', '0094', 'training time (minutes)=', '0.6378', 'loss=', '129.402819758')
# ('Epoch:', '0095', 'training time (minutes)=', '0.5998', 'loss=', '128.843594294')
# ('Held Out Data :', 'forward time (minutes)=', '0.0521', 'loss=', '138.898949256')
# ('Epoch:', '0096', 'training time (minutes)=', '0.6371', 'loss=', '128.993811168')
# ('Epoch:', '0097', 'training time (minutes)=', '0.6388', 'loss=', '128.999968885')
# ('Epoch:', '0098', 'training time (minutes)=', '0.6369', 'loss=', '129.417284294')
# ('Epoch:', '0099', 'training time (minutes)=', '0.6362', 'loss=', '128.557286005')
# ('Epoch:', '0100', 'training time (minutes)=', '0.6368', 'loss=', '128.749292987')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0519', 'loss=', '139.038588304')
# ('Epoch:', '0101', 'training time (minutes)=', '0.6362', 'loss=', '129.067987989')
# ('Epoch:', '0102', 'training time (minutes)=', '0.6394', 'loss=', '128.279900592')
# ('Epoch:', '0103', 'training time (minutes)=', '0.6369', 'loss=', '128.375407410')
# ('Epoch:', '0104', 'training time (minutes)=', '0.6376', 'loss=', '128.275647437')
# ('Epoch:', '0105', 'training time (minutes)=', '0.6367', 'loss=', '128.338881584')
# ('Held Out Data :', 'forward time (minutes)=', '0.0519', 'loss=', '136.232379033')
# ('Epoch:', '0106', 'training time (minutes)=', '0.6362', 'loss=', '128.535462819')
# ('Epoch:', '0107', 'training time (minutes)=', '0.6022', 'loss=', '127.875954072')
# ('Epoch:', '0108', 'training time (minutes)=', '0.6372', 'loss=', '128.438513847')
# ('Epoch:', '0109', 'training time (minutes)=', '0.6357', 'loss=', '128.262078393')
# ('Epoch:', '0110', 'training time (minutes)=', '0.6357', 'loss=', '127.987877091')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0518', 'loss=', '135.796792837')
# ('Epoch:', '0111', 'training time (minutes)=', '0.6366', 'loss=', '127.479346765')
# ('Epoch:', '0112', 'training time (minutes)=', '0.6350', 'loss=', '127.897266288')
# ('Epoch:', '0113', 'training time (minutes)=', '0.6372', 'loss=', '128.074016073')
# ('Epoch:', '0114', 'training time (minutes)=', '0.6368', 'loss=', '127.127163564')
# ('Epoch:', '0115', 'training time (minutes)=', '0.6358', 'loss=', '127.753927281')
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '137.330688477')
# ('Epoch:', '0116', 'training time (minutes)=', '0.6374', 'loss=', '128.041050455')
# ('Epoch:', '0117', 'training time (minutes)=', '0.6369', 'loss=', '127.538679571')
# ('Epoch:', '0118', 'training time (minutes)=', '0.6358', 'loss=', '127.568133943')
# ('Epoch:', '0119', 'training time (minutes)=', '0.6384', 'loss=', '127.203722946')
# ('Epoch:', '0120', 'training time (minutes)=', '0.6050', 'loss=', '127.523648934')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0522', 'loss=', '133.844100365')
# ('Epoch:', '0121', 'training time (minutes)=', '0.6356', 'loss=', '127.148624652')
# ('Epoch:', '0122', 'training time (minutes)=', '0.6360', 'loss=', '126.756853120')
# ('Epoch:', '0123', 'training time (minutes)=', '0.6364', 'loss=', '127.558630305')
# ('Epoch:', '0124', 'training time (minutes)=', '0.6358', 'loss=', '126.608990014')
# ('Epoch:', '0125', 'training time (minutes)=', '0.6377', 'loss=', '126.490434796')
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '135.730063805')
# ('Epoch:', '0126', 'training time (minutes)=', '0.6362', 'loss=', '126.793241219')
# ('Epoch:', '0127', 'training time (minutes)=', '0.6364', 'loss=', '126.867647121')
# ('Epoch:', '0128', 'training time (minutes)=', '0.6371', 'loss=', '126.111066006')
# ('Epoch:', '0129', 'training time (minutes)=', '0.6351', 'loss=', '126.502369823')
# ('Epoch:', '0130', 'training time (minutes)=', '0.6388', 'loss=', '126.606637507')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '138.231423011')
# ('Epoch:', '0131', 'training time (minutes)=', '0.6392', 'loss=', '126.293812495')
# ('Epoch:', '0132', 'training time (minutes)=', '0.6016', 'loss=', '126.636015585')
# ('Epoch:', '0133', 'training time (minutes)=', '0.6365', 'loss=', '125.988360662')
# ('Epoch:', '0134', 'training time (minutes)=', '0.6362', 'loss=', '126.279275911')
# ('Epoch:', '0135', 'training time (minutes)=', '0.6357', 'loss=', '125.947707400')
# ('Held Out Data :', 'forward time (minutes)=', '0.0513', 'loss=', '136.547988892')
# ('Epoch:', '0136', 'training time (minutes)=', '0.6385', 'loss=', '125.891743735')
# ('Epoch:', '0137', 'training time (minutes)=', '0.6359', 'loss=', '125.717432370')
# ('Epoch:', '0138', 'training time (minutes)=', '0.6369', 'loss=', '125.944968779')
# ('Epoch:', '0139', 'training time (minutes)=', '0.6355', 'loss=', '126.185966823')
# ('Epoch:', '0140', 'training time (minutes)=', '0.6368', 'loss=', '126.487297788')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '137.065227802')
# ('Epoch:', '0141', 'training time (minutes)=', '0.6347', 'loss=', '126.132172759')
# ('Epoch:', '0142', 'training time (minutes)=', '0.6389', 'loss=', '126.239768518')
# ('Epoch:', '0143', 'training time (minutes)=', '0.6357', 'loss=', '125.708488796')
# ('Epoch:', '0144', 'training time (minutes)=', '0.5991', 'loss=', '125.614516217')
# ('Epoch:', '0145', 'training time (minutes)=', '0.6360', 'loss=', '125.606373132')
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '135.382482675')
# ('Epoch:', '0146', 'training time (minutes)=', '0.6363', 'loss=', '125.659128206')
# ('Epoch:', '0147', 'training time (minutes)=', '0.6388', 'loss=', '125.703434753')
# ('Epoch:', '0148', 'training time (minutes)=', '0.6354', 'loss=', '125.529870274')
# ('Epoch:', '0149', 'training time (minutes)=', '0.6351', 'loss=', '125.780121579')
# ('Epoch:', '0150', 'training time (minutes)=', '0.6357', 'loss=', '125.177070817')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '134.536981436')
# ('Epoch:', '0151', 'training time (minutes)=', '0.6369', 'loss=', '125.421311221')
# ('Epoch:', '0152', 'training time (minutes)=', '0.6362', 'loss=', '125.932470703')
# ('Epoch:', '0153', 'training time (minutes)=', '0.6393', 'loss=', '125.165187670')
# ('Epoch:', '0154', 'training time (minutes)=', '0.6364', 'loss=', '125.056875942')
# ('Epoch:', '0155', 'training time (minutes)=', '0.6351', 'loss=', '124.873808952')
# ('Held Out Data :', 'forward time (minutes)=', '0.0512', 'loss=', '133.823313786')
# ('Epoch:', '0156', 'training time (minutes)=', '0.5972', 'loss=', '124.952780881')
# ('Epoch:', '0157', 'training time (minutes)=', '0.6344', 'loss=', '125.132792465')
# ('Epoch:', '0158', 'training time (minutes)=', '0.6377', 'loss=', '125.214229153')
# ('Epoch:', '0159', 'training time (minutes)=', '0.6350', 'loss=', '125.269894011')
# ('Epoch:', '0160', 'training time (minutes)=', '0.6364', 'loss=', '125.039692887')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '134.230437059')
# ('Epoch:', '0161', 'training time (minutes)=', '0.6363', 'loss=', '124.684901030')
# ('Epoch:', '0162', 'training time (minutes)=', '0.6352', 'loss=', '124.456695424')
# ('Epoch:', '0163', 'training time (minutes)=', '0.6364', 'loss=', '124.523086747')
# ('Epoch:', '0164', 'training time (minutes)=', '0.6369', 'loss=', '124.473544577')
# ('Epoch:', '0165', 'training time (minutes)=', '0.6352', 'loss=', '124.792256297')
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '136.218023447')
# ('Epoch:', '0166', 'training time (minutes)=', '0.6353', 'loss=', '125.307380942')
# ('Epoch:', '0167', 'training time (minutes)=', '0.6358', 'loss=', '124.816172923')
# ('Epoch:', '0168', 'training time (minutes)=', '0.6022', 'loss=', '124.541792165')
# ('Epoch:', '0169', 'training time (minutes)=', '0.6375', 'loss=', '124.787535029')
# ('Epoch:', '0170', 'training time (minutes)=', '0.6349', 'loss=', '124.560871887')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0518', 'loss=', '136.718120868')
# ('Epoch:', '0171', 'training time (minutes)=', '0.6357', 'loss=', '124.209056556')
# ('Epoch:', '0172', 'training time (minutes)=', '0.6358', 'loss=', '123.883156553')
# ('Epoch:', '0173', 'training time (minutes)=', '0.6362', 'loss=', '124.641862886')
# ('Epoch:', '0174', 'training time (minutes)=', '0.6364', 'loss=', '124.678433427')
# ('Epoch:', '0175', 'training time (minutes)=', '0.6371', 'loss=', '124.285452536')
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '135.626038185')
# ('Epoch:', '0176', 'training time (minutes)=', '0.6358', 'loss=', '124.019378927')
# ('Epoch:', '0177', 'training time (minutes)=', '0.6339', 'loss=', '124.015276503')
# ('Epoch:', '0178', 'training time (minutes)=', '0.6349', 'loss=', '123.529905236')
# ('Epoch:', '0179', 'training time (minutes)=', '0.6351', 'loss=', '123.701361416')
# ('Epoch:', '0180', 'training time (minutes)=', '0.6376', 'loss=', '123.892690377')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0267', 'loss=', '134.653624901')
# ('Epoch:', '0181', 'training time (minutes)=', '0.6357', 'loss=', '123.627666772')
# ('Epoch:', '0182', 'training time (minutes)=', '0.6352', 'loss=', '124.000736933')
# ('Epoch:', '0183', 'training time (minutes)=', '0.6353', 'loss=', '123.794163646')
# ('Epoch:', '0184', 'training time (minutes)=', '0.6348', 'loss=', '123.844366853')
# ('Epoch:', '0185', 'training time (minutes)=', '0.6356', 'loss=', '123.462417005')
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '135.518733098')
# ('Epoch:', '0186', 'training time (minutes)=', '0.6366', 'loss=', '124.442425139')
# ('Epoch:', '0187', 'training time (minutes)=', '0.6358', 'loss=', '124.071368143')
# ('Epoch:', '0188', 'training time (minutes)=', '0.6360', 'loss=', '123.580153092')
# ('Epoch:', '0189', 'training time (minutes)=', '0.6365', 'loss=', '123.761106010')
# ('Epoch:', '0190', 'training time (minutes)=', '0.6364', 'loss=', '123.280994117')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0518', 'loss=', '137.813622108')
# ('Epoch:', '0191', 'training time (minutes)=', '0.6356', 'loss=', '123.545836540')
# ('Epoch:', '0192', 'training time (minutes)=', '0.6383', 'loss=', '123.790435459')
# ('Epoch:', '0193', 'training time (minutes)=', '0.6016', 'loss=', '123.748679518')
# ('Epoch:', '0194', 'training time (minutes)=', '0.6355', 'loss=', '123.233875839')
# ('Epoch:', '0195', 'training time (minutes)=', '0.6358', 'loss=', '123.354586858')
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '134.648907588')
# ('Epoch:', '0196', 'training time (minutes)=', '0.6349', 'loss=', '123.443979214')
# ('Epoch:', '0197', 'training time (minutes)=', '0.6381', 'loss=', '123.055368307')
# ('Epoch:', '0198', 'training time (minutes)=', '0.6353', 'loss=', '123.471948043')
# ('Epoch:', '0199', 'training time (minutes)=', '0.6355', 'loss=', '123.377251003')
# ('Epoch:', '0200', 'training time (minutes)=', '0.6353', 'loss=', '123.355975010')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '132.939548786')
# ('Epoch:', '0201', 'training time (minutes)=', '0.6365', 'loss=', '123.611709794')
# ('Epoch:', '0202', 'training time (minutes)=', '0.6347', 'loss=', '123.588622317')
# ('Epoch:', '0203', 'training time (minutes)=', '0.6377', 'loss=', '123.335414389')
# ('Epoch:', '0204', 'training time (minutes)=', '0.6352', 'loss=', '123.651584061')
# ('Epoch:', '0205', 'training time (minutes)=', '0.5995', 'loss=', '123.078955144')
# ('Held Out Data :', 'forward time (minutes)=', '0.0518', 'loss=', '135.382247925')
# ('Epoch:', '0206', 'training time (minutes)=', '0.6346', 'loss=', '123.229512621')
# ('Epoch:', '0207', 'training time (minutes)=', '0.6343', 'loss=', '122.774507008')
# ('Epoch:', '0208', 'training time (minutes)=', '0.6378', 'loss=', '123.454554350')
# ('Epoch:', '0209', 'training time (minutes)=', '0.6363', 'loss=', '122.798636594')
# ('Epoch:', '0210', 'training time (minutes)=', '0.6351', 'loss=', '122.496178204')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0513', 'loss=', '134.020792448')
# ('Epoch:', '0211', 'training time (minutes)=', '0.6346', 'loss=', '122.786808047')
# ('Epoch:', '0212', 'training time (minutes)=', '0.6357', 'loss=', '123.025320965')
# ('Epoch:', '0213', 'training time (minutes)=', '0.6347', 'loss=', '122.632651155')
# ('Epoch:', '0214', 'training time (minutes)=', '0.6374', 'loss=', '122.778540769')
# ('Epoch:', '0215', 'training time (minutes)=', '0.6349', 'loss=', '122.707858608')
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '133.987781231')
# ('Epoch:', '0216', 'training time (minutes)=', '0.6339', 'loss=', '122.515240545')
# ('Epoch:', '0217', 'training time (minutes)=', '0.5991', 'loss=', '122.720470462')
# ('Epoch:', '0218', 'training time (minutes)=', '0.6357', 'loss=', '122.276629572')
# ('Epoch:', '0219', 'training time (minutes)=', '0.6377', 'loss=', '121.993839562')
# ('Epoch:', '0220', 'training time (minutes)=', '0.6366', 'loss=', '122.576526874')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '133.609477703')
# ('Epoch:', '0221', 'training time (minutes)=', '0.6361', 'loss=', '122.168597677')
# ('Epoch:', '0222', 'training time (minutes)=', '0.6351', 'loss=', '122.726096112')
# ('Epoch:', '0223', 'training time (minutes)=', '0.6353', 'loss=', '122.860495924')
# ('Epoch:', '0224', 'training time (minutes)=', '0.6349', 'loss=', '122.347298398')
# ('Epoch:', '0225', 'training time (minutes)=', '0.6368', 'loss=', '122.911577042')
# ('Held Out Data :', 'forward time (minutes)=', '0.0515', 'loss=', '134.441020672')
# ('Epoch:', '0226', 'training time (minutes)=', '0.6347', 'loss=', '122.151275701')
# ('Epoch:', '0227', 'training time (minutes)=', '0.6351', 'loss=', '122.081856769')
# ('Epoch:', '0228', 'training time (minutes)=', '0.6334', 'loss=', '121.777108632')
# ('Epoch:', '0229', 'training time (minutes)=', '0.5987', 'loss=', '122.146757308')
# ('Epoch:', '0230', 'training time (minutes)=', '0.6363', 'loss=', '121.950274725')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '134.299764780')
# ('Epoch:', '0231', 'training time (minutes)=', '0.6341', 'loss=', '121.432228088')
# ('Epoch:', '0232', 'training time (minutes)=', '0.6336', 'loss=', '121.625623222')
# ('Epoch:', '0233', 'training time (minutes)=', '0.6356', 'loss=', '122.177196868')
# ('Epoch:', '0234', 'training time (minutes)=', '0.6349', 'loss=', '121.900310085')
# ('Epoch:', '0235', 'training time (minutes)=', '0.6364', 'loss=', '122.164791737')
# ('Held Out Data :', 'forward time (minutes)=', '0.0504', 'loss=', '134.006786053')
# ('Epoch:', '0236', 'training time (minutes)=', '0.6381', 'loss=', '122.190344968')
# ('Epoch:', '0237', 'training time (minutes)=', '0.6350', 'loss=', '121.588934260')
# ('Epoch:', '0238', 'training time (minutes)=', '0.6352', 'loss=', '121.714749411')
# ('Epoch:', '0239', 'training time (minutes)=', '0.6355', 'loss=', '121.681721298')
# ('Epoch:', '0240', 'training time (minutes)=', '0.6337', 'loss=', '121.965623408')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '133.433865474')
# ('Epoch:', '0241', 'training time (minutes)=', '0.6071', 'loss=', '122.069418866')
# ('Epoch:', '0242', 'training time (minutes)=', '0.6304', 'loss=', '122.358064336')
# ('Epoch:', '0243', 'training time (minutes)=', '0.6352', 'loss=', '121.197323011')
# ('Epoch:', '0244', 'training time (minutes)=', '0.6354', 'loss=', '121.273571844')
# ('Epoch:', '0245', 'training time (minutes)=', '0.6353', 'loss=', '121.609456668')
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '133.644905090')
# ('Epoch:', '0246', 'training time (minutes)=', '0.6360', 'loss=', '121.672304767')
# ('Epoch:', '0247', 'training time (minutes)=', '0.6374', 'loss=', '121.526913784')
# ('Epoch:', '0248', 'training time (minutes)=', '0.6347', 'loss=', '121.584720446')
# ('Epoch:', '0249', 'training time (minutes)=', '0.6355', 'loss=', '121.418308225')
# ('Epoch:', '0250', 'training time (minutes)=', '0.6360', 'loss=', '121.828446894')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '134.115389897')
# ('Epoch:', '0251', 'training time (minutes)=', '0.6350', 'loss=', '121.280741352')
# ('Epoch:', '0252', 'training time (minutes)=', '0.6343', 'loss=', '121.556830829')
# ('Epoch:', '0253', 'training time (minutes)=', '0.6378', 'loss=', '121.624614284')
# ('Epoch:', '0254', 'training time (minutes)=', '0.6001', 'loss=', '121.314864383')
# ('Epoch:', '0255', 'training time (minutes)=', '0.6355', 'loss=', '121.404881287')
# ('Held Out Data :', 'forward time (minutes)=', '0.0518', 'loss=', '135.283025888')
# ('Epoch:', '0256', 'training time (minutes)=', '0.6350', 'loss=', '121.017941881')
# ('Epoch:', '0257', 'training time (minutes)=', '0.6351', 'loss=', '121.265029111')
# ('Epoch:', '0258', 'training time (minutes)=', '0.6376', 'loss=', '121.180533633')
# ('Epoch:', '0259', 'training time (minutes)=', '0.6356', 'loss=', '121.289619711')
# ('Epoch:', '0260', 'training time (minutes)=', '0.6344', 'loss=', '121.183199742')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '133.826815092')
# ('Epoch:', '0261', 'training time (minutes)=', '0.6348', 'loss=', '121.320557569')
# ('Epoch:', '0262', 'training time (minutes)=', '0.6348', 'loss=', '120.933883932')
# ('Epoch:', '0263', 'training time (minutes)=', '0.6364', 'loss=', '120.977799789')
# ('Epoch:', '0264', 'training time (minutes)=', '0.6375', 'loss=', '121.525491466')
# ('Epoch:', '0265', 'training time (minutes)=', '0.6358', 'loss=', '120.931149093')
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '137.064035269')
# ('Epoch:', '0266', 'training time (minutes)=', '0.5913', 'loss=', '120.890858327')
# ('Epoch:', '0267', 'training time (minutes)=', '0.6352', 'loss=', '121.838609977')
# ('Epoch:', '0268', 'training time (minutes)=', '0.6377', 'loss=', '120.898756276')
# ('Epoch:', '0269', 'training time (minutes)=', '0.6347', 'loss=', '121.215245852')
# ('Epoch:', '0270', 'training time (minutes)=', '0.6360', 'loss=', '120.987944429')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0521', 'loss=', '136.336543743')
# ('Epoch:', '0271', 'training time (minutes)=', '0.6339', 'loss=', '120.700718755')
# ('Epoch:', '0272', 'training time (minutes)=', '0.6342', 'loss=', '120.937830917')
# ('Epoch:', '0273', 'training time (minutes)=', '0.6337', 'loss=', '120.498607138')
# ('Epoch:', '0274', 'training time (minutes)=', '0.6376', 'loss=', '120.985643271')
# ('Epoch:', '0275', 'training time (minutes)=', '0.6350', 'loss=', '120.587750709')
# ('Held Out Data :', 'forward time (minutes)=', '0.0521', 'loss=', '134.705815242')
# ('Epoch:', '0276', 'training time (minutes)=', '0.6347', 'loss=', '120.474968487')
# ('Epoch:', '0277', 'training time (minutes)=', '0.6360', 'loss=', '120.649083942')
# ('Epoch:', '0278', 'training time (minutes)=', '0.6020', 'loss=', '120.545330014')
# ('Epoch:', '0279', 'training time (minutes)=', '0.6387', 'loss=', '120.621154055')
# ('Epoch:', '0280', 'training time (minutes)=', '0.6357', 'loss=', '120.958541339')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0515', 'loss=', '134.727105948')
# ('Epoch:', '0281', 'training time (minutes)=', '0.6351', 'loss=', '120.651711107')
# ('Epoch:', '0282', 'training time (minutes)=', '0.6352', 'loss=', '120.502354497')
# ('Epoch:', '0283', 'training time (minutes)=', '0.6353', 'loss=', '120.343125584')
# ('Epoch:', '0284', 'training time (minutes)=', '0.6357', 'loss=', '120.246268762')
# ('Epoch:', '0285', 'training time (minutes)=', '0.6377', 'loss=', '121.339035432')
# ('Held Out Data :', 'forward time (minutes)=', '0.0493', 'loss=', '134.965579106')
# ('Epoch:', '0286', 'training time (minutes)=', '0.6387', 'loss=', '120.057225766')
# ('Epoch:', '0287', 'training time (minutes)=', '0.6337', 'loss=', '120.150872670')
# ('Epoch:', '0288', 'training time (minutes)=', '0.6345', 'loss=', '120.531623641')
# ('Epoch:', '0289', 'training time (minutes)=', '0.6351', 'loss=', '119.980837283')
# ('Epoch:', '0290', 'training time (minutes)=', '0.5980', 'loss=', '120.343096194')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0515', 'loss=', '132.940773597')
# ('Epoch:', '0291', 'training time (minutes)=', '0.6369', 'loss=', '120.721225772')
# ('Epoch:', '0292', 'training time (minutes)=', '0.6356', 'loss=', '120.583510623')
# ('Epoch:', '0293', 'training time (minutes)=', '0.6349', 'loss=', '120.355354309')
# ('Epoch:', '0294', 'training time (minutes)=', '0.6334', 'loss=', '120.424952698')
# ('Epoch:', '0295', 'training time (minutes)=', '0.6345', 'loss=', '119.783486076')
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '136.103580181')
# ('Epoch:', '0296', 'training time (minutes)=', '0.6348', 'loss=', '120.275716234')
# ('Epoch:', '0297', 'training time (minutes)=', '0.6372', 'loss=', '120.097947295')
# ('Epoch:', '0298', 'training time (minutes)=', '0.6348', 'loss=', '120.414389303')
# ('Epoch:', '0299', 'training time (minutes)=', '0.6349', 'loss=', '120.125044715')
# ('Epoch:', '0300', 'training time (minutes)=', '0.6347', 'loss=', '120.603754856')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '132.590852004')
# ('Epoch:', '0301', 'training time (minutes)=', '0.6349', 'loss=', '119.959270046')
# ('Epoch:', '0302', 'training time (minutes)=', '0.6142', 'loss=', '120.162749780')
# ('Epoch:', '0303', 'training time (minutes)=', '0.6248', 'loss=', '119.927318407')
# ('Epoch:', '0304', 'training time (minutes)=', '0.6344', 'loss=', '120.129112841')
# ('Epoch:', '0305', 'training time (minutes)=', '0.6353', 'loss=', '120.166006934')
# ('Held Out Data :', 'forward time (minutes)=', '0.0523', 'loss=', '135.491708609')
# ('Epoch:', '0306', 'training time (minutes)=', '0.6348', 'loss=', '119.957849917')
# ('Epoch:', '0307', 'training time (minutes)=', '0.6340', 'loss=', '119.877632738')
# ('Epoch:', '0308', 'training time (minutes)=', '0.6371', 'loss=', '119.857392684')
# ('Epoch:', '0309', 'training time (minutes)=', '0.6343', 'loss=', '119.673644024')
# ('Epoch:', '0310', 'training time (minutes)=', '0.6359', 'loss=', '119.426223556')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '133.234998263')
# ('Epoch:', '0311', 'training time (minutes)=', '0.6347', 'loss=', '120.297590305')
# ('Epoch:', '0312', 'training time (minutes)=', '0.6346', 'loss=', '120.148982106')
# ('Epoch:', '0313', 'training time (minutes)=', '0.6345', 'loss=', '119.647575577')
# ('Epoch:', '0314', 'training time (minutes)=', '0.6365', 'loss=', '119.417486307')
# ('Epoch:', '0315', 'training time (minutes)=', '0.5945', 'loss=', '119.761370584')
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '134.301669194')
# ('Epoch:', '0316', 'training time (minutes)=', '0.6341', 'loss=', '119.851852351')
# ('Epoch:', '0317', 'training time (minutes)=', '0.6346', 'loss=', '119.738658142')
# ('Epoch:', '0318', 'training time (minutes)=', '0.6345', 'loss=', '119.644718800')
# ('Epoch:', '0319', 'training time (minutes)=', '0.6356', 'loss=', '119.380728946')
# ('Epoch:', '0320', 'training time (minutes)=', '0.6342', 'loss=', '119.877318274')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '135.974703275')
# ('Epoch:', '0321', 'training time (minutes)=', '0.6334', 'loss=', '119.736784761')
# ('Epoch:', '0322', 'training time (minutes)=', '0.6341', 'loss=', '119.646066682')
# ('Epoch:', '0323', 'training time (minutes)=', '0.6342', 'loss=', '119.443657120')
# ('Epoch:', '0324', 'training time (minutes)=', '0.6337', 'loss=', '119.851705535')
# ('Epoch:', '0325', 'training time (minutes)=', '0.6369', 'loss=', '119.449549070')
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '136.457605215')
# ('Epoch:', '0326', 'training time (minutes)=', '0.6344', 'loss=', '119.652093108')
# ('Epoch:', '0327', 'training time (minutes)=', '0.5965', 'loss=', '119.149830893')
# ('Epoch:', '0328', 'training time (minutes)=', '0.6319', 'loss=', '119.455548494')
# ('Epoch:', '0329', 'training time (minutes)=', '0.6367', 'loss=', '119.681240513')
# ('Epoch:', '0330', 'training time (minutes)=', '0.6340', 'loss=', '119.282703632')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0518', 'loss=', '133.719706609')
# ('Epoch:', '0331', 'training time (minutes)=', '0.6341', 'loss=', '119.501007876')
# ('Epoch:', '0332', 'training time (minutes)=', '0.6332', 'loss=', '119.436249376')
# ('Epoch:', '0333', 'training time (minutes)=', '0.6338', 'loss=', '119.395342553')
# ('Epoch:', '0334', 'training time (minutes)=', '0.6338', 'loss=', '119.592544290')
# ('Epoch:', '0335', 'training time (minutes)=', '0.6367', 'loss=', '119.033460932')
# ('Held Out Data :', 'forward time (minutes)=', '0.0491', 'loss=', '134.169012216')
# ('Epoch:', '0336', 'training time (minutes)=', '0.6375', 'loss=', '118.975802148')
# ('Epoch:', '0337', 'training time (minutes)=', '0.6341', 'loss=', '119.468675365')
# ('Epoch:', '0338', 'training time (minutes)=', '0.6358', 'loss=', '119.367351764')
# ('Epoch:', '0339', 'training time (minutes)=', '0.5992', 'loss=', '118.886092476')
# ('Epoch:', '0340', 'training time (minutes)=', '0.6367', 'loss=', '118.606896376')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0515', 'loss=', '134.946900588')
# ('Epoch:', '0341', 'training time (minutes)=', '0.6358', 'loss=', '119.678739266')
# ('Epoch:', '0342', 'training time (minutes)=', '0.6351', 'loss=', '119.254330975')
# ('Epoch:', '0343', 'training time (minutes)=', '0.6341', 'loss=', '119.021116240')
# ('Epoch:', '0344', 'training time (minutes)=', '0.6339', 'loss=', '119.524399202')
# ('Epoch:', '0345', 'training time (minutes)=', '0.6335', 'loss=', '119.267247805')
# ('Held Out Data :', 'forward time (minutes)=', '0.0516', 'loss=', '136.213425269')
# ('Epoch:', '0346', 'training time (minutes)=', '0.6329', 'loss=', '119.716668170')
# ('Epoch:', '0347', 'training time (minutes)=', '0.6369', 'loss=', '119.249802697')
# ('Epoch:', '0348', 'training time (minutes)=', '0.6340', 'loss=', '118.762641310')
# ('Epoch:', '0349', 'training time (minutes)=', '0.6334', 'loss=', '118.951623535')
# ('Epoch:', '0350', 'training time (minutes)=', '0.6344', 'loss=', '118.925098452')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '132.862314078')
# ('Epoch:', '0351', 'training time (minutes)=', '0.5887', 'loss=', '118.609892804')
# ('Epoch:', '0352', 'training time (minutes)=', '0.6359', 'loss=', '119.071654477')
# ('Epoch:', '0353', 'training time (minutes)=', '0.6331', 'loss=', '118.585338427')
# ('Epoch:', '0354', 'training time (minutes)=', '0.6337', 'loss=', '118.604060895')
# ('Epoch:', '0355', 'training time (minutes)=', '0.6338', 'loss=', '119.148864613')
# ('Held Out Data :', 'forward time (minutes)=', '0.0511', 'loss=', '132.901137132')
# ('Epoch:', '0356', 'training time (minutes)=', '0.6335', 'loss=', '118.548401012')
# ('Epoch:', '0357', 'training time (minutes)=', '0.6348', 'loss=', '118.504392607')
# ('Epoch:', '0358', 'training time (minutes)=', '0.6355', 'loss=', '118.599684077')
# ('Epoch:', '0359', 'training time (minutes)=', '0.6340', 'loss=', '118.891866336')
# ('Epoch:', '0360', 'training time (minutes)=', '0.6345', 'loss=', '118.642777020')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_8_bneck_emd/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0514', 'loss=', '136.458782489')
# ('Epoch:', '0361', 'training time (minutes)=', '0.6344', 'loss=', '118.572430221')
# ('Epoch:', '0362', 'training time (minutes)=', '0.6346', 'loss=', '118.592467731')
# ('Epoch:', '0363', 'training time (minutes)=', '0.6286', 'loss=', '118.525580099')
# ('Epoch:', '0364', 'training time (minutes)=', '0.6072', 'loss=', '118.885636305')
# ('Epoch:', '0365', 'training time (minutes)=', '0.6339', 'loss=', '119.242291392')
# ('Held Out Data :', 'forward time (minutes)=', '0.0517', 'loss=', '132.721928523')
# ('Epoch:', '0366', 'training time (minutes)=', '0.6342', 'loss=', '118.504270537')
# ('Epoch:', '0367', 'training time (minutes)=', '0.6347', 'loss=', '118.459520887')
# ('Epoch:', '0368', 'training time (minutes)=', '0.6342', 'loss=', '118.430169412')
# ('Epoch:', '0369', 'training time (minutes)=', '0.6378', 'loss=', '118.501326453')
# ...
# ('Held Out Data :', 'forward time (minutes)=', '0.0533', 'loss=', '104.484849783')
# ('Epoch:', '0131', 'training time (minutes)=', '0.7065', 'loss=', '98.744396376')
# ('Epoch:', '0132', 'training time (minutes)=', '0.7069', 'loss=', '97.773148313')
# ('Epoch:', '0133', 'training time (minutes)=', '0.7071', 'loss=', '98.834128206')
# ('Epoch:', '0134', 'training time (minutes)=', '0.7069', 'loss=', '98.687771407')
# ('Epoch:', '0135', 'training time (minutes)=', '0.7057', 'loss=', '97.591488382')
# ('Held Out Data :', 'forward time (minutes)=', '0.0502', 'loss=', '105.597557068')
# ('Epoch:', '0136', 'training time (minutes)=', '0.7060', 'loss=', '98.069585585')
# ('Epoch:', '0137', 'training time (minutes)=', '0.6731', 'loss=', '97.815214804')
# ('Epoch:', '0138', 'training time (minutes)=', '0.7052', 'loss=', '98.294247503')
# ('Epoch:', '0139', 'training time (minutes)=', '0.7057', 'loss=', '98.570447972')
# ('Epoch:', '0140', 'training time (minutes)=', '0.7075', 'loss=', '98.056899825')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0525', 'loss=', '106.657919664')
# ('Epoch:', '0141', 'training time (minutes)=', '0.7049', 'loss=', '97.754047228')
# ('Epoch:', '0142', 'training time (minutes)=', '0.7058', 'loss=', '97.384579136')
# ('Epoch:', '0143', 'training time (minutes)=', '0.7052', 'loss=', '97.450029124')
# ('Epoch:', '0144', 'training time (minutes)=', '0.7061', 'loss=', '96.863608783')
# ('Epoch:', '0145', 'training time (minutes)=', '0.7074', 'loss=', '96.795693638')
# ('Held Out Data :', 'forward time (minutes)=', '0.0529', 'loss=', '107.915393536')
# ('Epoch:', '0146', 'training time (minutes)=', '0.7046', 'loss=', '97.769497880')
# ('Epoch:', '0147', 'training time (minutes)=', '0.6703', 'loss=', '98.232108871')
# ('Epoch:', '0148', 'training time (minutes)=', '0.7071', 'loss=', '97.160429382')
# ('Epoch:', '0149', 'training time (minutes)=', '0.7082', 'loss=', '96.808680261')
# ('Epoch:', '0150', 'training time (minutes)=', '0.7071', 'loss=', '97.566587697')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0534', 'loss=', '106.140327454')
# ('Epoch:', '0151', 'training time (minutes)=', '0.7047', 'loss=', '97.258929178')
# ('Epoch:', '0152', 'training time (minutes)=', '0.7058', 'loss=', '96.998457668')
# ('Epoch:', '0153', 'training time (minutes)=', '0.7075', 'loss=', '97.400414774')
# ('Epoch:', '0154', 'training time (minutes)=', '0.7079', 'loss=', '97.145414933')
# ('Epoch:', '0155', 'training time (minutes)=', '0.7077', 'loss=', '96.822221839')
# ('Held Out Data :', 'forward time (minutes)=', '0.0527', 'loss=', '105.339160626')
# ('Epoch:', '0156', 'training time (minutes)=', '0.6715', 'loss=', '96.539668407')
# ('Epoch:', '0157', 'training time (minutes)=', '0.7073', 'loss=', '96.626362676')
# ('Epoch:', '0158', 'training time (minutes)=', '0.7075', 'loss=', '96.549510525')
# ('Epoch:', '0159', 'training time (minutes)=', '0.7065', 'loss=', '96.645933068')
# ('Epoch:', '0160', 'training time (minutes)=', '0.7056', 'loss=', '96.779691945')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0532', 'loss=', '104.150686411')
# ('Epoch:', '0161', 'training time (minutes)=', '0.7067', 'loss=', '97.178128782')
# ('Epoch:', '0162', 'training time (minutes)=', '0.7070', 'loss=', '96.329872728')
# ('Epoch:', '0163', 'training time (minutes)=', '0.7074', 'loss=', '96.819691799')
# ('Epoch:', '0164', 'training time (minutes)=', '0.7092', 'loss=', '96.488970549')
# ('Epoch:', '0165', 'training time (minutes)=', '0.7077', 'loss=', '96.095261814')
# ('Held Out Data :', 'forward time (minutes)=', '0.0525', 'loss=', '104.888102605')
# ('Epoch:', '0166', 'training time (minutes)=', '0.6695', 'loss=', '96.381421164')
# ('Epoch:', '0167', 'training time (minutes)=', '0.7086', 'loss=', '95.763673335')
# ('Epoch:', '0168', 'training time (minutes)=', '0.7087', 'loss=', '95.597621022')
# ('Epoch:', '0169', 'training time (minutes)=', '0.7054', 'loss=', '97.119689145')
# ('Epoch:', '0170', 'training time (minutes)=', '0.7089', 'loss=', '96.420197595')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0530', 'loss=', '104.614894574')
# ('Epoch:', '0171', 'training time (minutes)=', '0.7078', 'loss=', '95.960092827')
# ('Epoch:', '0172', 'training time (minutes)=', '0.7081', 'loss=', '96.201431208')
# ('Epoch:', '0173', 'training time (minutes)=', '0.7087', 'loss=', '96.813936648')
# ('Epoch:', '0174', 'training time (minutes)=', '0.7058', 'loss=', '96.041339178')
# ('Epoch:', '0175', 'training time (minutes)=', '0.6687', 'loss=', '96.431755199')
# ('Held Out Data :', 'forward time (minutes)=', '0.0527', 'loss=', '105.855073195')
# ('Epoch:', '0176', 'training time (minutes)=', '0.7063', 'loss=', '95.619256260')
# ('Epoch:', '0177', 'training time (minutes)=', '0.7071', 'loss=', '95.354750194')
# ('Epoch:', '0178', 'training time (minutes)=', '0.7058', 'loss=', '95.836779785')
# ('Epoch:', '0179', 'training time (minutes)=', '0.7054', 'loss=', '95.706942417')
# ('Epoch:', '0180', 'training time (minutes)=', '0.7053', 'loss=', '95.070589746')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0527', 'loss=', '101.730043851')
# ('Epoch:', '0181', 'training time (minutes)=', '0.7054', 'loss=', '95.886552761')
# ('Epoch:', '0182', 'training time (minutes)=', '0.7055', 'loss=', '95.493466452')
# ('Epoch:', '0183', 'training time (minutes)=', '0.7022', 'loss=', '94.884803109')
# ('Epoch:', '0184', 'training time (minutes)=', '0.6771', 'loss=', '95.796678029')
# ('Epoch:', '0185', 'training time (minutes)=', '0.7063', 'loss=', '95.694089674')
# ('Held Out Data :', 'forward time (minutes)=', '0.0498', 'loss=', '103.648768498')
# ('Epoch:', '0186', 'training time (minutes)=', '0.7037', 'loss=', '95.340661090')
# ('Epoch:', '0187', 'training time (minutes)=', '0.7050', 'loss=', '94.978328804')
# ('Epoch:', '0188', 'training time (minutes)=', '0.7051', 'loss=', '95.312297058')
# ('Epoch:', '0189', 'training time (minutes)=', '0.7043', 'loss=', '95.772189530')
# ('Epoch:', '0190', 'training time (minutes)=', '0.7037', 'loss=', '94.940565623')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0527', 'loss=', '107.263619056')
# ('Epoch:', '0191', 'training time (minutes)=', '0.7051', 'loss=', '94.748095902')
# ('Epoch:', '0192', 'training time (minutes)=', '0.7050', 'loss=', '94.902237469')
# ('Epoch:', '0193', 'training time (minutes)=', '0.7075', 'loss=', '95.707639213')
# ('Epoch:', '0194', 'training time (minutes)=', '0.6655', 'loss=', '95.305295662')
# ('Epoch:', '0195', 'training time (minutes)=', '0.7061', 'loss=', '95.290745611')
# ('Held Out Data :', 'forward time (minutes)=', '0.0528', 'loss=', '107.070896442')
# ('Epoch:', '0196', 'training time (minutes)=', '0.7074', 'loss=', '94.933894083')
# ('Epoch:', '0197', 'training time (minutes)=', '0.7068', 'loss=', '96.040521638')
# ('Epoch:', '0198', 'training time (minutes)=', '0.7083', 'loss=', '94.978829359')
# ('Epoch:', '0199', 'training time (minutes)=', '0.7081', 'loss=', '94.908819978')
# ('Epoch:', '0200', 'training time (minutes)=', '0.7068', 'loss=', '95.008467765')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0527', 'loss=', '103.238319397')
# ('Epoch:', '0201', 'training time (minutes)=', '0.7081', 'loss=', '94.820210200')
# ('Epoch:', '0202', 'training time (minutes)=', '0.7089', 'loss=', '94.809217171')
# ('Epoch:', '0203', 'training time (minutes)=', '0.6703', 'loss=', '94.368430030')
# ('Epoch:', '0204', 'training time (minutes)=', '0.7082', 'loss=', '94.362462450')
# ('Epoch:', '0205', 'training time (minutes)=', '0.7093', 'loss=', '94.329721268')
# ('Held Out Data :', 'forward time (minutes)=', '0.0531', 'loss=', '103.821364770')
# ('Epoch:', '0206', 'training time (minutes)=', '0.7082', 'loss=', '95.246742846')
# ('Epoch:', '0207', 'training time (minutes)=', '0.7075', 'loss=', '95.494369308')
# ('Epoch:', '0208', 'training time (minutes)=', '0.7071', 'loss=', '94.606900754')
# ('Epoch:', '0209', 'training time (minutes)=', '0.7077', 'loss=', '94.604825293')
# ('Epoch:', '0210', 'training time (minutes)=', '0.7087', 'loss=', '94.278601671')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0529', 'loss=', '103.022860014')
# ('Epoch:', '0211', 'training time (minutes)=', '0.7096', 'loss=', '94.919969575')
# ('Epoch:', '0212', 'training time (minutes)=', '0.7076', 'loss=', '94.188712079')
# ('Epoch:', '0213', 'training time (minutes)=', '0.6735', 'loss=', '94.362916764')
# ('Epoch:', '0214', 'training time (minutes)=', '0.7082', 'loss=', '94.268937152')
# ('Epoch:', '0215', 'training time (minutes)=', '0.7076', 'loss=', '94.418658447')
# ('Held Out Data :', 'forward time (minutes)=', '0.0502', 'loss=', '105.528513982')
# ('Epoch:', '0216', 'training time (minutes)=', '0.7072', 'loss=', '94.023765365')
# ('Epoch:', '0217', 'training time (minutes)=', '0.7075', 'loss=', '94.352661863')
# ('Epoch:', '0218', 'training time (minutes)=', '0.7076', 'loss=', '94.662848099')
# ('Epoch:', '0219', 'training time (minutes)=', '0.7079', 'loss=', '94.720393637')
# ('Epoch:', '0220', 'training time (minutes)=', '0.7082', 'loss=', '95.087564684')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0530', 'loss=', '104.877525916')
# ('Epoch:', '0221', 'training time (minutes)=', '0.7065', 'loss=', '93.976015108')
# ('Epoch:', '0222', 'training time (minutes)=', '0.6722', 'loss=', '94.724831357')
# ('Epoch:', '0223', 'training time (minutes)=', '0.7080', 'loss=', '93.711102162')
# ('Epoch:', '0224', 'training time (minutes)=', '0.7073', 'loss=', '93.765122521')
# ('Epoch:', '0225', 'training time (minutes)=', '0.7083', 'loss=', '95.089735678')
# ('Held Out Data :', 'forward time (minutes)=', '0.0527', 'loss=', '104.860582792')
# ('Epoch:', '0226', 'training time (minutes)=', '0.7062', 'loss=', '94.467948516')
# ('Epoch:', '0227', 'training time (minutes)=', '0.7078', 'loss=', '93.796326944')
# ('Epoch:', '0228', 'training time (minutes)=', '0.7069', 'loss=', '93.548049330')
# ('Epoch:', '0229', 'training time (minutes)=', '0.7084', 'loss=', '93.876830192')
# ('Epoch:', '0230', 'training time (minutes)=', '0.7080', 'loss=', '94.105520829')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0529', 'loss=', '105.336535527')
# ('Epoch:', '0231', 'training time (minutes)=', '0.6711', 'loss=', '93.850373840')
# ('Epoch:', '0232', 'training time (minutes)=', '0.7056', 'loss=', '93.594513802')
# ('Epoch:', '0233', 'training time (minutes)=', '0.7075', 'loss=', '94.558530061')
# ('Epoch:', '0234', 'training time (minutes)=', '0.7086', 'loss=', '93.551008805')
# ('Epoch:', '0235', 'training time (minutes)=', '0.7067', 'loss=', '93.619248365')
# ('Held Out Data :', 'forward time (minutes)=', '0.0530', 'loss=', '104.336558415')
# ('Epoch:', '0236', 'training time (minutes)=', '0.7082', 'loss=', '93.576746136')
# ('Epoch:', '0237', 'training time (minutes)=', '0.7092', 'loss=', '93.493104686')
# ('Epoch:', '0238', 'training time (minutes)=', '0.7066', 'loss=', '94.185867376')
# ('Epoch:', '0239', 'training time (minutes)=', '0.7085', 'loss=', '93.346883293')
# ('Epoch:', '0240', 'training time (minutes)=', '0.7079', 'loss=', '93.795992777')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0526', 'loss=', '105.864832951')
# ('Epoch:', '0241', 'training time (minutes)=', '0.6685', 'loss=', '93.702809806')
# ('Epoch:', '0242', 'training time (minutes)=', '0.7079', 'loss=', '93.974574412')
# ('Epoch:', '0243', 'training time (minutes)=', '0.7074', 'loss=', '93.791718856')
# ('Epoch:', '0244', 'training time (minutes)=', '0.7065', 'loss=', '94.092733765')
# ('Epoch:', '0245', 'training time (minutes)=', '0.7070', 'loss=', '93.594766235')
# ('Held Out Data :', 'forward time (minutes)=', '0.0531', 'loss=', '101.821885329')
# ('Epoch:', '0246', 'training time (minutes)=', '0.7063', 'loss=', '93.827523737')
# ('Epoch:', '0247', 'training time (minutes)=', '0.7064', 'loss=', '93.759779225')
# ('Epoch:', '0248', 'training time (minutes)=', '0.7073', 'loss=', '93.755003556')
# ('Epoch:', '0249', 'training time (minutes)=', '0.7074', 'loss=', '93.457787887')
# ('Epoch:', '0250', 'training time (minutes)=', '0.6725', 'loss=', '93.790598728')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0529', 'loss=', '104.234441904')
# ('Epoch:', '0251', 'training time (minutes)=', '0.7067', 'loss=', '93.276273910')
# ('Epoch:', '0252', 'training time (minutes)=', '0.7077', 'loss=', '93.187450177')
# ('Epoch:', '0253', 'training time (minutes)=', '0.7079', 'loss=', '93.450356989')
# ('Epoch:', '0254', 'training time (minutes)=', '0.7088', 'loss=', '93.151312720')
# ('Epoch:', '0255', 'training time (minutes)=', '0.7082', 'loss=', '93.221557285')
# ('Held Out Data :', 'forward time (minutes)=', '0.0523', 'loss=', '103.822947575')
# ('Epoch:', '0256', 'training time (minutes)=', '0.7074', 'loss=', '92.710908707')
# ('Epoch:', '0257', 'training time (minutes)=', '0.7082', 'loss=', '93.354490529')
# ('Epoch:', '0258', 'training time (minutes)=', '0.7079', 'loss=', '93.635914678')
# ('Epoch:', '0259', 'training time (minutes)=', '0.7069', 'loss=', '93.366138757')
# ('Epoch:', '0260', 'training time (minutes)=', '0.6715', 'loss=', '93.588658606')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_1pc_usampled_bnorm_on_encoder_only_2048_pts_256_bneck_emd/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0533', 'loss=', '107.747532184')
# ('Epoch:', '0261', 'training time (minutes)=', '0.7078', 'loss=', '93.300333438')
# ('Epoch:', '0262', 'training time (minutes)=', '0.7074', 'loss=', '93.267291591')
