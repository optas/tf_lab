# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 2
setup_one_gpu(GPU)
# Out:
# Picking GPU 2

# %%
import sys
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt
from functools import partial

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter
from tf_lab.point_clouds.ae_templates import mlp_architecture_ala_iclr_18, default_train_params

from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder

from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id

from tf_lab.iclr.helper import load_multiple_version_of_pcs, find_best_validation_epoch_from_train_stats

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'
experiment_tag = 'mlp_with_split_3pc_usampled_bnorm_on_encoder_only'
loss = 'emd'

n_pc_points = 2048
random_seed = 42

# %%
class_name = raw_input('Give me the class type: ').lower()
syn_id = snc_category_to_synth_id()[class_name]
# Out:
# Give me the class type: chair

# %%
in_data  = load_multiple_version_of_pcs('uniform_all' ,syn_id, n_classes=1)
# Out:
# Loading test data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/test.txt
# 679 pclouds were loaded. They belong in 1 shape-classes.
# 679 pclouds were loaded. They belong in 1 shape-classes.
# 679 pclouds were loaded. They belong in 1 shape-classes.
# Loading train data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/train.txt
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# 5761 pclouds were loaded. They belong in 1 shape-classes.
# Loading val data.
# /orions4-zfs/projects/optas/DATA/Point_Clouds/Shape_Net/Splits/single_class_splits/03001627/85_5_10/val.txt
# 338 pclouds were loaded. They belong in 1 shape-classes.
# 338 pclouds were loaded. They belong in 1 shape-classes.
# 338 pclouds were loaded. They belong in 1 shape-classes.

# %%
bneck_list = bneck_list = [512]
train_params = default_train_params()

for bneck in bneck_list:
    experiment_id = '_'.join(['ae', class_name, experiment_tag, str(n_pc_points), 'pts', str(bneck), 'bneck', loss])
    train_dir = osp.join(top_data_dir, 'OUT/iclr/nn_models/', experiment_id)
    create_dir(train_dir)
    
    reset_tf_graph()
    
    encoder, decoder, enc_args, dec_args = mlp_architecture_ala_iclr_18(n_pc_points, bneck)
    
    dec_args['b_norm'] = False
    dec_args['b_norm_finish'] = False
    
    conf = Conf(n_input = [n_pc_points, 3],
                loss = loss,
                training_epochs = 500,
                batch_size = train_params['batch_size'],
                denoising = False,
                learning_rate = train_params['learning_rate'],
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = train_params['saver_step'],
                z_rotate = False,
                encoder = encoder,
                decoder = decoder,
                encoder_args = enc_args,
                decoder_args = dec_args
               )
    print conf
    conf.experiment_name = 'experiment_' + str(experiment_id)
    conf.held_out_step = 5
    conf.save(osp.join(train_dir, 'configuration'))
    ae = PointNetAutoEncoder(conf.experiment_name, conf)
    
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
    train_stats = ae.train(in_data['train'], conf, log_file=fout, held_out_data=in_data['test'])
    fout.close()
# Out:
#                     batch_size: 50
#                  consistent_io: None
#                          debug: False
#                        decoder: decoder_with_fc_only
#                   decoder_args: {'b_norm_finish': False, 'verbose': True, 'b_norm': False, 'layer_sizes': [256, 256, 6144]}
#                        encoder: encoder_with_convs_and_symmetry_new
#                   encoder_args: {'filter_sizes': [1], 'n_filters': [64, 128, 128, 256, 512], 'verbose': True, 'b_norm': True, 'strides': [1]}
#                  gauss_augment: None
#                   is_denoising: False
#                latent_vs_recon: 1.0
#                  learning_rate: 0.0005
#                           loss: emd
#              loss_display_step: 1
#                        n_input: [2048, 3]
#                       n_output: [2048, 3]
#                            n_z: None
#              saver_max_to_keep: None
#                     saver_step: 10
#                      train_dir: /orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd
#                training_epochs: 500
#                       z_rotate: False
#
# Building Encoder
# encoder_conv_layer_0 conv params =  256 bnorm params =  128
# Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/Relu:0", shape=(?, 2048, 64), dtype=float32)
# output size: 131072
#
# encoder_conv_layer_1 conv params =  8320 bnorm params =  256
# Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/Relu_1:0", shape=(?, 2048, 128), dtype=float32)
# output size: 262144
#
# encoder_conv_layer_2 conv params =  16512 bnorm params =  256
# Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/Relu_2:0", shape=(?, 2048, 128), dtype=float32)
# output size: 262144
#
# encoder_conv_layer_3 conv params =  33024 bnorm params =  512
# Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/Relu_3:0", shape=(?, 2048, 256), dtype=float32)
# output size: 524288
#
# encoder_conv_layer_4 conv params =  131584 bnorm params =  1024
# Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/Relu_4:0", shape=(?, 2048, 512), dtype=float32)
# output size: 1048576
#
# Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/Max:0", shape=(?, 512), dtype=float32)
# Building Decoder
# decoder_fc_0 FC params =  131328 Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/Relu_5:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# decoder_fc_1 FC params =  65792 Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/Relu_6:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# decoder_fc_2 FC params =  1579008 Tensor("experiment_ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd_2/decoder_fc_2/BiasAdd:0", shape=(?, 6144), dtype=float32)
# output size: 6144
#
# ('Epoch:', '0001', 'training time (minutes)=', '1.1253', 'loss=', '165.565686124')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '1.1322', 'loss=', '135.304529649')
# ('Epoch:', '0003', 'training time (minutes)=', '1.1336', 'loss=', '127.812851704')
# ('Epoch:', '0004', 'training time (minutes)=', '1.1334', 'loss=', '124.551448347')
# ('Epoch:', '0005', 'training time (minutes)=', '1.1326', 'loss=', '120.359385969')
# ('Held Out Data :', 'forward time (minutes)=', '0.0798', 'loss=', '120.223319817')
# ('Epoch:', '0006', 'training time (minutes)=', '1.1309', 'loss=', '119.696302176')
# ('Epoch:', '0007', 'training time (minutes)=', '1.1309', 'loss=', '117.532258097')
# ('Epoch:', '0008', 'training time (minutes)=', '1.1313', 'loss=', '115.860234512')
# ('Epoch:', '0009', 'training time (minutes)=', '1.1587', 'loss=', '115.584856514')
# ('Epoch:', '0010', 'training time (minutes)=', '1.1520', 'loss=', '114.804460144')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0796', 'loss=', '118.311232376')
# ('Epoch:', '0011', 'training time (minutes)=', '1.1583', 'loss=', '113.591973214')
# ('Epoch:', '0012', 'training time (minutes)=', '1.1734', 'loss=', '112.942506541')
# ('Epoch:', '0013', 'training time (minutes)=', '1.1766', 'loss=', '112.866096585')
# ('Epoch:', '0014', 'training time (minutes)=', '1.1782', 'loss=', '111.733991496')
# ('Epoch:', '0015', 'training time (minutes)=', '1.1820', 'loss=', '110.367315010')
# ('Held Out Data :', 'forward time (minutes)=', '0.0833', 'loss=', '111.036422539')
# ('Epoch:', '0016', 'training time (minutes)=', '1.1822', 'loss=', '109.717893650')
# ('Epoch:', '0017', 'training time (minutes)=', '1.1797', 'loss=', '109.336432194')
# ('Epoch:', '0018', 'training time (minutes)=', '1.1807', 'loss=', '109.139580193')
# ('Epoch:', '0019', 'training time (minutes)=', '1.2034', 'loss=', '108.103738293')
# ('Epoch:', '0020', 'training time (minutes)=', '1.1842', 'loss=', '108.415867128')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0824', 'loss=', '109.138561249')
# ('Epoch:', '0021', 'training time (minutes)=', '1.2010', 'loss=', '107.525004091')
# ('Epoch:', '0022', 'training time (minutes)=', '1.1867', 'loss=', '107.160606716')
# ('Epoch:', '0023', 'training time (minutes)=', '1.2186', 'loss=', '107.054391192')
# ('Epoch:', '0024', 'training time (minutes)=', '1.1961', 'loss=', '106.156088500')
# ('Epoch:', '0025', 'training time (minutes)=', '1.3029', 'loss=', '105.654394841')
# ('Held Out Data :', 'forward time (minutes)=', '0.0815', 'loss=', '114.252268600')
# ('Epoch:', '0026', 'training time (minutes)=', '1.1845', 'loss=', '105.505411629')
# ('Epoch:', '0027', 'training time (minutes)=', '1.1797', 'loss=', '105.029299551')
# ('Epoch:', '0028', 'training time (minutes)=', '1.1836', 'loss=', '104.734603130')
# ('Epoch:', '0029', 'training time (minutes)=', '1.1792', 'loss=', '103.982024240')
# ('Epoch:', '0030', 'training time (minutes)=', '1.2393', 'loss=', '103.784035547')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0818', 'loss=', '111.317380524')
# ('Epoch:', '0031', 'training time (minutes)=', '1.1846', 'loss=', '103.773607846')
# ('Epoch:', '0032', 'training time (minutes)=', '1.2519', 'loss=', '103.468001789')
# ('Epoch:', '0033', 'training time (minutes)=', '1.1832', 'loss=', '103.077481499')
# ('Epoch:', '0034', 'training time (minutes)=', '1.2047', 'loss=', '102.758924379')
# ('Epoch:', '0035', 'training time (minutes)=', '1.1822', 'loss=', '102.532945760')
# ('Held Out Data :', 'forward time (minutes)=', '0.0821', 'loss=', '108.712175560')
# ('Epoch:', '0036', 'training time (minutes)=', '1.1814', 'loss=', '102.513363625')
# ('Epoch:', '0037', 'training time (minutes)=', '1.1828', 'loss=', '102.242832748')
# ('Epoch:', '0038', 'training time (minutes)=', '1.1802', 'loss=', '102.021371460')
# ('Epoch:', '0039', 'training time (minutes)=', '1.1797', 'loss=', '101.898462998')
# ('Epoch:', '0040', 'training time (minutes)=', '1.1803', 'loss=', '101.434739796')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0813', 'loss=', '104.438972092')
# ('Epoch:', '0041', 'training time (minutes)=', '1.1802', 'loss=', '101.093821871')
# ('Epoch:', '0042', 'training time (minutes)=', '1.1808', 'loss=', '101.433941849')
# ('Epoch:', '0043', 'training time (minutes)=', '1.1805', 'loss=', '101.035610210')
# ('Epoch:', '0044', 'training time (minutes)=', '1.1831', 'loss=', '100.813710685')
# ('Epoch:', '0045', 'training time (minutes)=', '1.1806', 'loss=', '101.112915371')
# ('Held Out Data :', 'forward time (minutes)=', '0.0814', 'loss=', '105.685655022')
# ('Epoch:', '0046', 'training time (minutes)=', '1.1770', 'loss=', '100.290744195')
# ('Epoch:', '0047', 'training time (minutes)=', '1.1797', 'loss=', '100.391320005')
# ('Epoch:', '0048', 'training time (minutes)=', '1.1796', 'loss=', '100.366939755')
# ('Epoch:', '0049', 'training time (minutes)=', '1.1804', 'loss=', '99.753344572')
# ('Epoch:', '0050', 'training time (minutes)=', '1.1799', 'loss=', '99.468548053')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0806', 'loss=', '106.738978386')
# ('Epoch:', '0051', 'training time (minutes)=', '1.1744', 'loss=', '99.987715945')
# ('Epoch:', '0052', 'training time (minutes)=', '1.1803', 'loss=', '99.633871703')
# ('Epoch:', '0053', 'training time (minutes)=', '1.1807', 'loss=', '99.335191787')
# ('Epoch:', '0054', 'training time (minutes)=', '1.1826', 'loss=', '98.874409131')
# ('Epoch:', '0055', 'training time (minutes)=', '1.1774', 'loss=', '98.862695246')
# ('Held Out Data :', 'forward time (minutes)=', '0.0880', 'loss=', '104.621651077')
# ('Epoch:', '0056', 'training time (minutes)=', '1.1805', 'loss=', '99.201320416')
# ('Epoch:', '0057', 'training time (minutes)=', '1.1799', 'loss=', '98.935253176')
# ('Epoch:', '0058', 'training time (minutes)=', '1.1800', 'loss=', '98.498789757')
# ('Epoch:', '0059', 'training time (minutes)=', '1.1812', 'loss=', '98.400754801')
# ('Epoch:', '0060', 'training time (minutes)=', '1.1787', 'loss=', '98.127902354')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0826', 'loss=', '104.568786621')
# ('Epoch:', '0061', 'training time (minutes)=', '1.1783', 'loss=', '98.195809561')
# ('Epoch:', '0062', 'training time (minutes)=', '1.1812', 'loss=', '98.349997811')
# ('Epoch:', '0063', 'training time (minutes)=', '1.1822', 'loss=', '97.822859148')
# ('Epoch:', '0064', 'training time (minutes)=', '1.1809', 'loss=', '97.288948125')
# ('Epoch:', '0065', 'training time (minutes)=', '1.1803', 'loss=', '97.655837902')
# ('Held Out Data :', 'forward time (minutes)=', '0.0805', 'loss=', '105.729236794')
# ('Epoch:', '0066', 'training time (minutes)=', '1.1816', 'loss=', '97.293361719')
# ('Epoch:', '0067', 'training time (minutes)=', '1.1822', 'loss=', '97.215522324')
# ('Epoch:', '0068', 'training time (minutes)=', '1.1811', 'loss=', '97.749133478')
# ('Epoch:', '0069', 'training time (minutes)=', '1.1794', 'loss=', '97.715376503')
# ('Epoch:', '0070', 'training time (minutes)=', '1.1808', 'loss=', '96.930156166')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0805', 'loss=', '103.925876427')
# ('Epoch:', '0071', 'training time (minutes)=', '1.1827', 'loss=', '97.120082888')
# ('Epoch:', '0072', 'training time (minutes)=', '1.1778', 'loss=', '97.337799868')
# ('Epoch:', '0073', 'training time (minutes)=', '1.1786', 'loss=', '96.762236266')
# ('Epoch:', '0074', 'training time (minutes)=', '1.1813', 'loss=', '96.673070493')
# ('Epoch:', '0075', 'training time (minutes)=', '1.1753', 'loss=', '96.850161500')
# ('Held Out Data :', 'forward time (minutes)=', '0.0832', 'loss=', '101.624450111')
# ('Epoch:', '0076', 'training time (minutes)=', '1.1799', 'loss=', '96.381379081')
# ('Epoch:', '0077', 'training time (minutes)=', '1.1835', 'loss=', '96.387937861')
# ('Epoch:', '0078', 'training time (minutes)=', '1.1831', 'loss=', '96.528895149')
# ('Epoch:', '0079', 'training time (minutes)=', '1.1841', 'loss=', '96.328344815')
# ('Epoch:', '0080', 'training time (minutes)=', '1.1788', 'loss=', '96.295735589')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0805', 'loss=', '103.297747040')
# ('Epoch:', '0081', 'training time (minutes)=', '1.1805', 'loss=', '96.015069514')
# ('Epoch:', '0082', 'training time (minutes)=', '1.1791', 'loss=', '96.041327988')
# ('Epoch:', '0083', 'training time (minutes)=', '1.1802', 'loss=', '96.033108078')
# ('Epoch:', '0084', 'training time (minutes)=', '1.1822', 'loss=', '95.663956684')
# ('Epoch:', '0085', 'training time (minutes)=', '1.1766', 'loss=', '95.518247676')
# ('Held Out Data :', 'forward time (minutes)=', '0.0803', 'loss=', '102.599967575')
# ('Epoch:', '0086', 'training time (minutes)=', '1.1795', 'loss=', '96.037524281')
# ('Epoch:', '0087', 'training time (minutes)=', '1.1811', 'loss=', '95.096245188')
# ('Epoch:', '0088', 'training time (minutes)=', '1.1754', 'loss=', '95.539500980')
# ('Epoch:', '0089', 'training time (minutes)=', '1.1832', 'loss=', '95.431183989')
# ('Epoch:', '0090', 'training time (minutes)=', '1.1799', 'loss=', '95.559710030')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0810', 'loss=', '102.114640045')
# ('Epoch:', '0091', 'training time (minutes)=', '1.1799', 'loss=', '95.127662305')
# ('Epoch:', '0092', 'training time (minutes)=', '1.1802', 'loss=', '94.994581737')
# ('Epoch:', '0093', 'training time (minutes)=', '1.1796', 'loss=', '95.048231042')
# ('Epoch:', '0094', 'training time (minutes)=', '1.1835', 'loss=', '95.025818557')
# ('Epoch:', '0095', 'training time (minutes)=', '1.1803', 'loss=', '95.093875785')
# ('Held Out Data :', 'forward time (minutes)=', '0.0836', 'loss=', '105.227815628')
# ('Epoch:', '0096', 'training time (minutes)=', '1.1749', 'loss=', '94.752453237')
# ('Epoch:', '0097', 'training time (minutes)=', '1.1795', 'loss=', '94.842880802')
# ('Epoch:', '0098', 'training time (minutes)=', '1.1805', 'loss=', '95.338397969')
# ('Epoch:', '0099', 'training time (minutes)=', '1.1799', 'loss=', '94.659733537')
# ('Epoch:', '0100', 'training time (minutes)=', '1.1794', 'loss=', '94.311129451')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0806', 'loss=', '103.576345444')
# ('Epoch:', '0101', 'training time (minutes)=', '1.1751', 'loss=', '94.460122946')
# ('Epoch:', '0102', 'training time (minutes)=', '1.2414', 'loss=', '94.352719957')
# ('Epoch:', '0103', 'training time (minutes)=', '1.1848', 'loss=', '94.387043032')
# ('Epoch:', '0104', 'training time (minutes)=', '1.1797', 'loss=', '94.307566789')
# ('Epoch:', '0105', 'training time (minutes)=', '1.1786', 'loss=', '94.296333003')
# ('Held Out Data :', 'forward time (minutes)=', '0.0820', 'loss=', '101.670076752')
# ('Epoch:', '0106', 'training time (minutes)=', '1.1807', 'loss=', '94.488770195')
# ('Epoch:', '0107', 'training time (minutes)=', '1.1780', 'loss=', '94.052433202')
# ('Epoch:', '0108', 'training time (minutes)=', '1.1743', 'loss=', '94.125224017')
# ('Epoch:', '0109', 'training time (minutes)=', '1.1792', 'loss=', '94.011915389')
# ('Epoch:', '0110', 'training time (minutes)=', '1.1766', 'loss=', '94.081139186')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0834', 'loss=', '101.340868950')
# ('Epoch:', '0111', 'training time (minutes)=', '1.1809', 'loss=', '93.889972256')
# ('Epoch:', '0112', 'training time (minutes)=', '1.1760', 'loss=', '93.909137847')
# ('Epoch:', '0113', 'training time (minutes)=', '1.1799', 'loss=', '93.572179092')
# ('Epoch:', '0114', 'training time (minutes)=', '1.1832', 'loss=', '93.889005224')
# ('Epoch:', '0115', 'training time (minutes)=', '1.1834', 'loss=', '93.590180704')
# ('Held Out Data :', 'forward time (minutes)=', '0.0843', 'loss=', '101.331184387')
# ('Epoch:', '0116', 'training time (minutes)=', '1.1759', 'loss=', '93.628030418')
# ('Epoch:', '0117', 'training time (minutes)=', '1.1770', 'loss=', '93.576775438')
# ('Epoch:', '0118', 'training time (minutes)=', '1.1806', 'loss=', '94.153032894')
# ('Epoch:', '0119', 'training time (minutes)=', '1.1723', 'loss=', '93.605010257')
# ('Epoch:', '0120', 'training time (minutes)=', '1.1897', 'loss=', '93.529801565')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0804', 'loss=', '100.336044121')
# ('Epoch:', '0121', 'training time (minutes)=', '1.1908', 'loss=', '93.498072616')
# ('Epoch:', '0122', 'training time (minutes)=', '1.1835', 'loss=', '93.445793705')
# ('Epoch:', '0123', 'training time (minutes)=', '1.1751', 'loss=', '93.305409528')
# ('Epoch:', '0124', 'training time (minutes)=', '1.1799', 'loss=', '93.033648637')
# ('Epoch:', '0125', 'training time (minutes)=', '1.1744', 'loss=', '93.331344582')
# ('Held Out Data :', 'forward time (minutes)=', '0.0813', 'loss=', '100.113356018')
# ('Epoch:', '0126', 'training time (minutes)=', '1.1898', 'loss=', '92.771540965')
# ('Epoch:', '0127', 'training time (minutes)=', '1.1794', 'loss=', '93.199327596')
# ('Epoch:', '0128', 'training time (minutes)=', '1.1974', 'loss=', '93.131672823')
# ('Epoch:', '0129', 'training time (minutes)=', '1.1803', 'loss=', '92.601200159')
# ('Epoch:', '0130', 'training time (minutes)=', '1.1859', 'loss=', '93.012529744')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0808', 'loss=', '100.257681656')
# ('Epoch:', '0131', 'training time (minutes)=', '1.1703', 'loss=', '92.767943562')
# ('Epoch:', '0132', 'training time (minutes)=', '1.1770', 'loss=', '93.200463204')
# ('Epoch:', '0133', 'training time (minutes)=', '1.1764', 'loss=', '93.183341317')
# ('Epoch:', '0134', 'training time (minutes)=', '1.1791', 'loss=', '92.546828096')
# ('Epoch:', '0135', 'training time (minutes)=', '1.1841', 'loss=', '93.066904792')
# ('Held Out Data :', 'forward time (minutes)=', '0.0902', 'loss=', '101.770422935')
# ('Epoch:', '0136', 'training time (minutes)=', '1.1778', 'loss=', '92.791097138')
# ('Epoch:', '0137', 'training time (minutes)=', '1.1853', 'loss=', '92.640072875')
# ('Epoch:', '0138', 'training time (minutes)=', '1.1794', 'loss=', '92.687130693')
# ('Epoch:', '0139', 'training time (minutes)=', '1.1829', 'loss=', '92.251695849')
# ('Epoch:', '0140', 'training time (minutes)=', '1.1876', 'loss=', '92.251339412')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0817', 'loss=', '100.722338867')
# ('Epoch:', '0141', 'training time (minutes)=', '1.1870', 'loss=', '92.225884767')
# ('Epoch:', '0142', 'training time (minutes)=', '1.1827', 'loss=', '92.297418832')
# ('Epoch:', '0143', 'training time (minutes)=', '1.1802', 'loss=', '92.161356343')
# ('Epoch:', '0144', 'training time (minutes)=', '1.1861', 'loss=', '92.198637036')
# ('Epoch:', '0145', 'training time (minutes)=', '1.2070', 'loss=', '92.125511988')
# ('Held Out Data :', 'forward time (minutes)=', '0.0811', 'loss=', '99.908671951')
# ('Epoch:', '0146', 'training time (minutes)=', '1.2081', 'loss=', '92.170074463')
# ('Epoch:', '0147', 'training time (minutes)=', '1.2206', 'loss=', '92.225627977')
# ('Epoch:', '0148', 'training time (minutes)=', '1.1871', 'loss=', '92.161654796')
# ('Epoch:', '0149', 'training time (minutes)=', '1.1897', 'loss=', '92.142925450')
# ('Epoch:', '0150', 'training time (minutes)=', '1.2044', 'loss=', '92.095429971')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0809', 'loss=', '100.930620003')
# ('Epoch:', '0151', 'training time (minutes)=', '1.1774', 'loss=', '91.666162507')
# ('Epoch:', '0152', 'training time (minutes)=', '1.1837', 'loss=', '91.929445991')
# ('Epoch:', '0153', 'training time (minutes)=', '1.1801', 'loss=', '91.941130420')
# ('Epoch:', '0154', 'training time (minutes)=', '1.1933', 'loss=', '91.997151273')
# ('Epoch:', '0155', 'training time (minutes)=', '1.1930', 'loss=', '91.824493054')
# ('Held Out Data :', 'forward time (minutes)=', '0.0808', 'loss=', '99.391893196')
# ('Epoch:', '0156', 'training time (minutes)=', '1.1919', 'loss=', '91.778055606')
# ('Epoch:', '0157', 'training time (minutes)=', '1.1803', 'loss=', '91.606066209')
# ('Epoch:', '0158', 'training time (minutes)=', '1.1993', 'loss=', '91.935900061')
# ('Epoch:', '0159', 'training time (minutes)=', '1.1828', 'loss=', '91.937428903')
# ('Epoch:', '0160', 'training time (minutes)=', '1.2186', 'loss=', '91.712561345')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0834', 'loss=', '99.092766762')
# ('Epoch:', '0161', 'training time (minutes)=', '1.2054', 'loss=', '91.663991867')
# ('Epoch:', '0162', 'training time (minutes)=', '1.1788', 'loss=', '91.457731429')
# ('Epoch:', '0163', 'training time (minutes)=', '1.1866', 'loss=', '91.795353190')
# ('Epoch:', '0164', 'training time (minutes)=', '1.1730', 'loss=', '91.315361753')
# ('Epoch:', '0165', 'training time (minutes)=', '1.1791', 'loss=', '91.441838604')
# ('Held Out Data :', 'forward time (minutes)=', '0.0807', 'loss=', '99.764122009')
# ('Epoch:', '0166', 'training time (minutes)=', '1.1712', 'loss=', '91.353340635')
# ('Epoch:', '0167', 'training time (minutes)=', '1.1697', 'loss=', '91.547266089')
# ('Epoch:', '0168', 'training time (minutes)=', '1.1696', 'loss=', '91.395824333')
# ('Epoch:', '0169', 'training time (minutes)=', '1.1660', 'loss=', '91.065298042')
# ('Epoch:', '0170', 'training time (minutes)=', '1.1668', 'loss=', '90.941130331')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0803', 'loss=', '99.306755257')
# ('Epoch:', '0171', 'training time (minutes)=', '1.1676', 'loss=', '91.074398406')
# ('Epoch:', '0172', 'training time (minutes)=', '1.1682', 'loss=', '91.196053016')
# ('Epoch:', '0173', 'training time (minutes)=', '1.1695', 'loss=', '91.154745771')
# ('Epoch:', '0174', 'training time (minutes)=', '1.1694', 'loss=', '90.906232441')
# ('Epoch:', '0175', 'training time (minutes)=', '1.1664', 'loss=', '91.581400553')
# ('Held Out Data :', 'forward time (minutes)=', '0.0810', 'loss=', '99.597735214')
# ('Epoch:', '0176', 'training time (minutes)=', '1.1671', 'loss=', '91.043767094')
# ('Epoch:', '0177', 'training time (minutes)=', '1.1666', 'loss=', '91.032800779')
# ('Epoch:', '0178', 'training time (minutes)=', '1.1689', 'loss=', '91.017534295')
# ('Epoch:', '0179', 'training time (minutes)=', '1.1658', 'loss=', '90.997277633')
# ('Epoch:', '0180', 'training time (minutes)=', '1.1663', 'loss=', '90.744527137')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0796', 'loss=', '99.556441879')
# ('Epoch:', '0181', 'training time (minutes)=', '1.1669', 'loss=', '90.600255662')
# ('Epoch:', '0182', 'training time (minutes)=', '1.1681', 'loss=', '90.766611116')
# ('Epoch:', '0183', 'training time (minutes)=', '1.2015', 'loss=', '90.824010125')
# ('Epoch:', '0184', 'training time (minutes)=', '1.1662', 'loss=', '91.006978751')
# ('Epoch:', '0185', 'training time (minutes)=', '1.1969', 'loss=', '90.898504838')
# ('Held Out Data :', 'forward time (minutes)=', '0.0811', 'loss=', '98.938047409')
# ('Epoch:', '0186', 'training time (minutes)=', '1.1673', 'loss=', '90.414563652')
# ('Epoch:', '0187', 'training time (minutes)=', '1.1652', 'loss=', '90.429983034')
# ('Epoch:', '0188', 'training time (minutes)=', '1.1606', 'loss=', '90.639992158')
# ('Epoch:', '0189', 'training time (minutes)=', '1.1628', 'loss=', '90.757684282')
# ('Epoch:', '0190', 'training time (minutes)=', '1.1642', 'loss=', '90.608020174')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0802', 'loss=', '100.181843376')
# ('Epoch:', '0191', 'training time (minutes)=', '1.1641', 'loss=', '90.531373862')
# ('Epoch:', '0192', 'training time (minutes)=', '1.1652', 'loss=', '90.256112118')
# ('Epoch:', '0193', 'training time (minutes)=', '1.1874', 'loss=', '90.203822172')
# ('Epoch:', '0194', 'training time (minutes)=', '1.1720', 'loss=', '90.164208056')
# ('Epoch:', '0195', 'training time (minutes)=', '1.1801', 'loss=', '90.493514395')
# ('Held Out Data :', 'forward time (minutes)=', '0.0809', 'loss=', '100.545487976')
# ('Epoch:', '0196', 'training time (minutes)=', '1.1741', 'loss=', '90.490563346')
# ('Epoch:', '0197', 'training time (minutes)=', '1.1913', 'loss=', '90.307532932')
# ('Epoch:', '0198', 'training time (minutes)=', '1.1683', 'loss=', '90.424897103')
# ('Epoch:', '0199', 'training time (minutes)=', '1.1665', 'loss=', '90.007407346')
# ('Epoch:', '0200', 'training time (minutes)=', '1.1653', 'loss=', '90.106847813')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0802', 'loss=', '98.205226517')
# ('Epoch:', '0201', 'training time (minutes)=', '1.1649', 'loss=', '90.527628514')
# ('Epoch:', '0202', 'training time (minutes)=', '1.1667', 'loss=', '89.765051999')
# ('Epoch:', '0203', 'training time (minutes)=', '1.1721', 'loss=', '89.896534397')
# ('Epoch:', '0204', 'training time (minutes)=', '1.1664', 'loss=', '90.128535904')
# ('Epoch:', '0205', 'training time (minutes)=', '1.1763', 'loss=', '90.263088613')
# ('Held Out Data :', 'forward time (minutes)=', '0.0802', 'loss=', '100.361364174')
# ('Epoch:', '0206', 'training time (minutes)=', '1.1691', 'loss=', '90.391048863')
# ('Epoch:', '0207', 'training time (minutes)=', '1.1856', 'loss=', '89.748712379')
# ('Epoch:', '0208', 'training time (minutes)=', '1.1626', 'loss=', '90.098425934')
# ('Epoch:', '0209', 'training time (minutes)=', '1.1611', 'loss=', '89.759800919')
# ('Epoch:', '0210', 'training time (minutes)=', '1.1619', 'loss=', '89.832324949')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0800', 'loss=', '98.518937111')
# ('Epoch:', '0211', 'training time (minutes)=', '1.1612', 'loss=', '89.654102314')
# ('Epoch:', '0212', 'training time (minutes)=', '1.1692', 'loss=', '89.913870173')
# ('Epoch:', '0213', 'training time (minutes)=', '1.1621', 'loss=', '89.743147057')
# ('Epoch:', '0214', 'training time (minutes)=', '1.1717', 'loss=', '89.442584759')
# ('Epoch:', '0215', 'training time (minutes)=', '1.1613', 'loss=', '89.801257125')
# ('Held Out Data :', 'forward time (minutes)=', '0.0801', 'loss=', '99.062574196')
# ('Epoch:', '0216', 'training time (minutes)=', '1.1680', 'loss=', '89.825890096')
# ('Epoch:', '0217', 'training time (minutes)=', '1.1557', 'loss=', '89.628390746')
# ('Epoch:', '0218', 'training time (minutes)=', '1.1551', 'loss=', '89.521856999')
# ('Epoch:', '0219', 'training time (minutes)=', '1.1556', 'loss=', '89.864423116')
# ('Epoch:', '0220', 'training time (minutes)=', '1.1559', 'loss=', '89.478213744')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '96.886434174')
# ('Epoch:', '0221', 'training time (minutes)=', '1.1541', 'loss=', '89.420011614')
# ('Epoch:', '0222', 'training time (minutes)=', '1.1555', 'loss=', '89.428908904')
# ('Epoch:', '0223', 'training time (minutes)=', '1.1543', 'loss=', '89.484759721')
# ('Epoch:', '0224', 'training time (minutes)=', '1.1554', 'loss=', '89.228288910')
# ('Epoch:', '0225', 'training time (minutes)=', '1.1555', 'loss=', '89.614296645')
# ('Held Out Data :', 'forward time (minutes)=', '0.0829', 'loss=', '99.148362541')
# ('Epoch:', '0226', 'training time (minutes)=', '1.1519', 'loss=', '89.446568851')
# ('Epoch:', '0227', 'training time (minutes)=', '1.1552', 'loss=', '89.367041768')
# ('Epoch:', '0228', 'training time (minutes)=', '1.1558', 'loss=', '89.308131431')
# ('Epoch:', '0229', 'training time (minutes)=', '1.1540', 'loss=', '89.346313609')
# ('Epoch:', '0230', 'training time (minutes)=', '1.1533', 'loss=', '89.389353390')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0794', 'loss=', '99.665268707')
# ('Epoch:', '0231', 'training time (minutes)=', '1.1511', 'loss=', '89.353228185')
# ('Epoch:', '0232', 'training time (minutes)=', '1.1503', 'loss=', '89.029022814')
# ('Epoch:', '0233', 'training time (minutes)=', '1.1523', 'loss=', '89.186444180')
# ('Epoch:', '0234', 'training time (minutes)=', '1.1505', 'loss=', '89.441420204')
# ('Epoch:', '0235', 'training time (minutes)=', '1.1541', 'loss=', '89.098802804')
# ('Held Out Data :', 'forward time (minutes)=', '0.0807', 'loss=', '99.871784401')
# ('Epoch:', '0236', 'training time (minutes)=', '1.1508', 'loss=', '88.976321035')
# ('Epoch:', '0237', 'training time (minutes)=', '1.1527', 'loss=', '89.092189424')
# ('Epoch:', '0238', 'training time (minutes)=', '1.1546', 'loss=', '88.997507864')
# ('Epoch:', '0239', 'training time (minutes)=', '1.1540', 'loss=', '88.838453851')
# ('Epoch:', '0240', 'training time (minutes)=', '1.1574', 'loss=', '89.389532670')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0795', 'loss=', '97.836020660')
# ('Epoch:', '0241', 'training time (minutes)=', '1.2032', 'loss=', '88.802817325')
# ('Epoch:', '0242', 'training time (minutes)=', '1.1619', 'loss=', '88.917865499')
# ('Epoch:', '0243', 'training time (minutes)=', '1.1671', 'loss=', '88.679169143')
# ('Epoch:', '0244', 'training time (minutes)=', '1.1687', 'loss=', '88.861724057')
# ('Epoch:', '0245', 'training time (minutes)=', '1.1873', 'loss=', '88.591504747')
# ('Held Out Data :', 'forward time (minutes)=', '0.0810', 'loss=', '98.944092178')
# ('Epoch:', '0246', 'training time (minutes)=', '1.1637', 'loss=', '89.069533019')
# ('Epoch:', '0247', 'training time (minutes)=', '1.1780', 'loss=', '88.710853046')
# ('Epoch:', '0248', 'training time (minutes)=', '1.1690', 'loss=', '88.828193443')
# ('Epoch:', '0249', 'training time (minutes)=', '1.1717', 'loss=', '88.612961103')
# ('Epoch:', '0250', 'training time (minutes)=', '1.1742', 'loss=', '89.081285626')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0799', 'loss=', '101.052091599')
# ('Epoch:', '0251', 'training time (minutes)=', '1.1870', 'loss=', '88.873582326')
# ('Epoch:', '0252', 'training time (minutes)=', '1.1757', 'loss=', '88.612560858')
# ('Epoch:', '0253', 'training time (minutes)=', '1.1697', 'loss=', '88.701352017')
# ('Epoch:', '0254', 'training time (minutes)=', '1.1679', 'loss=', '88.406899848')
# ('Epoch:', '0255', 'training time (minutes)=', '1.1914', 'loss=', '88.634013964')
# ('Held Out Data :', 'forward time (minutes)=', '0.0806', 'loss=', '96.976368904')
# ('Epoch:', '0256', 'training time (minutes)=', '1.1987', 'loss=', '88.524880230')
# ('Epoch:', '0257', 'training time (minutes)=', '1.1806', 'loss=', '88.791624628')
# ('Epoch:', '0258', 'training time (minutes)=', '1.1827', 'loss=', '88.377235457')
# ('Epoch:', '0259', 'training time (minutes)=', '1.1804', 'loss=', '88.444639344')
# ('Epoch:', '0260', 'training time (minutes)=', '1.1705', 'loss=', '88.481240336')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0803', 'loss=', '97.249889565')
# ('Epoch:', '0261', 'training time (minutes)=', '1.1954', 'loss=', '88.537479058')
# ('Epoch:', '0262', 'training time (minutes)=', '1.1697', 'loss=', '88.612631203')
# ('Epoch:', '0263', 'training time (minutes)=', '1.1817', 'loss=', '88.361138208')
# ('Epoch:', '0264', 'training time (minutes)=', '1.1785', 'loss=', '88.583691760')
# ('Epoch:', '0265', 'training time (minutes)=', '1.1691', 'loss=', '88.400301328')
# ('Held Out Data :', 'forward time (minutes)=', '0.0824', 'loss=', '95.527776909')
# ('Epoch:', '0266', 'training time (minutes)=', '1.1795', 'loss=', '88.261563641')
# ('Epoch:', '0267', 'training time (minutes)=', '1.1828', 'loss=', '88.788745161')
# ('Epoch:', '0268', 'training time (minutes)=', '1.1801', 'loss=', '88.186869900')
# ('Epoch:', '0269', 'training time (minutes)=', '1.1762', 'loss=', '88.154278012')
# ('Epoch:', '0270', 'training time (minutes)=', '1.1895', 'loss=', '88.122347337')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0801', 'loss=', '96.758819008')
# ('Epoch:', '0271', 'training time (minutes)=', '1.2222', 'loss=', '88.407495692')
# ('Epoch:', '0272', 'training time (minutes)=', '1.1823', 'loss=', '88.475071827')
# ('Epoch:', '0273', 'training time (minutes)=', '1.1933', 'loss=', '88.254576686')
# ('Epoch:', '0274', 'training time (minutes)=', '1.2075', 'loss=', '88.380319722')
# ('Epoch:', '0275', 'training time (minutes)=', '1.1828', 'loss=', '88.281239673')
# ('Held Out Data :', 'forward time (minutes)=', '0.0939', 'loss=', '95.859276772')
# ('Epoch:', '0276', 'training time (minutes)=', '1.1919', 'loss=', '88.094297525')
# ('Epoch:', '0277', 'training time (minutes)=', '1.1803', 'loss=', '88.037347456')
# ('Epoch:', '0278', 'training time (minutes)=', '1.1754', 'loss=', '88.296454521')
# ('Epoch:', '0279', 'training time (minutes)=', '1.1841', 'loss=', '87.929304372')
# ('Epoch:', '0280', 'training time (minutes)=', '1.1692', 'loss=', '88.147633207')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0802', 'loss=', '96.861378479')
# ('Epoch:', '0281', 'training time (minutes)=', '1.1829', 'loss=', '88.032981784')
# ('Epoch:', '0282', 'training time (minutes)=', '1.1666', 'loss=', '88.084729645')
# ('Epoch:', '0283', 'training time (minutes)=', '1.1750', 'loss=', '88.052620023')
# ('Epoch:', '0284', 'training time (minutes)=', '1.1736', 'loss=', '87.923225226')
# ('Epoch:', '0285', 'training time (minutes)=', '1.1805', 'loss=', '87.998244775')
# ('Held Out Data :', 'forward time (minutes)=', '0.0805', 'loss=', '98.477998924')
# ('Epoch:', '0286', 'training time (minutes)=', '1.1980', 'loss=', '87.862855353')
# ('Epoch:', '0287', 'training time (minutes)=', '1.1697', 'loss=', '87.987759001')
# ('Epoch:', '0288', 'training time (minutes)=', '1.2102', 'loss=', '87.955616738')
# ('Epoch:', '0289', 'training time (minutes)=', '1.1963', 'loss=', '88.158280060')
# ('Epoch:', '0290', 'training time (minutes)=', '1.1729', 'loss=', '87.874278082')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0802', 'loss=', '96.328305054')
# ('Epoch:', '0291', 'training time (minutes)=', '1.1674', 'loss=', '87.831251570')
# ('Epoch:', '0292', 'training time (minutes)=', '1.1729', 'loss=', '87.959137007')
# ('Epoch:', '0293', 'training time (minutes)=', '1.1722', 'loss=', '87.825374261')
# ('Epoch:', '0294', 'training time (minutes)=', '1.1670', 'loss=', '87.924435270')
# ('Epoch:', '0295', 'training time (minutes)=', '1.1680', 'loss=', '87.934574337')
# ('Held Out Data :', 'forward time (minutes)=', '0.0809', 'loss=', '95.758961105')
# ('Epoch:', '0296', 'training time (minutes)=', '1.1646', 'loss=', '87.519004158')
# ('Epoch:', '0297', 'training time (minutes)=', '1.1649', 'loss=', '87.695071632')
# ('Epoch:', '0298', 'training time (minutes)=', '1.1636', 'loss=', '87.624811919')
# ('Epoch:', '0299', 'training time (minutes)=', '1.1627', 'loss=', '87.623743317')
# ('Epoch:', '0300', 'training time (minutes)=', '1.1630', 'loss=', '87.408123425')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0800', 'loss=', '96.498153114')
# ('Epoch:', '0301', 'training time (minutes)=', '1.1595', 'loss=', '87.696748197')
# ('Epoch:', '0302', 'training time (minutes)=', '1.1629', 'loss=', '87.506399028')
# ('Epoch:', '0303', 'training time (minutes)=', '1.1858', 'loss=', '87.758322807')
# ('Epoch:', '0304', 'training time (minutes)=', '1.1625', 'loss=', '87.622434356')
# ('Epoch:', '0305', 'training time (minutes)=', '1.1611', 'loss=', '87.689086693')
# ('Held Out Data :', 'forward time (minutes)=', '0.0811', 'loss=', '96.440119743')
# ('Epoch:', '0306', 'training time (minutes)=', '1.1586', 'loss=', '87.567048490')
# ('Epoch:', '0307', 'training time (minutes)=', '1.1595', 'loss=', '87.334323983')
# ('Epoch:', '0308', 'training time (minutes)=', '1.1590', 'loss=', '87.456720944')
# ('Epoch:', '0309', 'training time (minutes)=', '1.1576', 'loss=', '87.408052925')
# ('Epoch:', '0310', 'training time (minutes)=', '1.1612', 'loss=', '87.178370445')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0794', 'loss=', '96.687164688')
# ('Epoch:', '0311', 'training time (minutes)=', '1.1569', 'loss=', '87.705103910')
# ('Epoch:', '0312', 'training time (minutes)=', '1.1612', 'loss=', '87.632107367')
# ('Epoch:', '0313', 'training time (minutes)=', '1.1578', 'loss=', '87.556304246')
# ('Epoch:', '0314', 'training time (minutes)=', '1.1616', 'loss=', '87.516758617')
# ('Epoch:', '0315', 'training time (minutes)=', '1.1571', 'loss=', '87.409383647')
# ('Held Out Data :', 'forward time (minutes)=', '0.0820', 'loss=', '96.555367470')
# ('Epoch:', '0316', 'training time (minutes)=', '1.1600', 'loss=', '87.464528711')
# ('Epoch:', '0317', 'training time (minutes)=', '1.1662', 'loss=', '87.318890690')
# ('Epoch:', '0318', 'training time (minutes)=', '1.1603', 'loss=', '87.449919593')
# ('Epoch:', '0319', 'training time (minutes)=', '1.1622', 'loss=', '87.340560427')
# ('Epoch:', '0320', 'training time (minutes)=', '1.1605', 'loss=', '87.761426511')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0796', 'loss=', '96.640412521')
# ('Epoch:', '0321', 'training time (minutes)=', '1.1588', 'loss=', '87.425889123')
# ('Epoch:', '0322', 'training time (minutes)=', '1.1560', 'loss=', '87.315552598')
# ('Epoch:', '0323', 'training time (minutes)=', '1.1898', 'loss=', '87.240435061')
# ('Epoch:', '0324', 'training time (minutes)=', '1.1761', 'loss=', '87.391915341')
# ('Epoch:', '0325', 'training time (minutes)=', '1.1764', 'loss=', '87.234286013')
# ('Held Out Data :', 'forward time (minutes)=', '0.0803', 'loss=', '95.937661934')
# ('Epoch:', '0326', 'training time (minutes)=', '1.1908', 'loss=', '86.929488937')
# ('Epoch:', '0327', 'training time (minutes)=', '1.1567', 'loss=', '86.998597032')
# ('Epoch:', '0328', 'training time (minutes)=', '1.1569', 'loss=', '87.267896127')
# ('Epoch:', '0329', 'training time (minutes)=', '1.1583', 'loss=', '87.150310328')
# ('Epoch:', '0330', 'training time (minutes)=', '1.1575', 'loss=', '87.284174247')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0796', 'loss=', '95.794900513')
# ('Epoch:', '0331', 'training time (minutes)=', '1.1556', 'loss=', '87.009000585')
# ('Epoch:', '0332', 'training time (minutes)=', '1.1619', 'loss=', '87.011232901')
# ('Epoch:', '0333', 'training time (minutes)=', '1.1590', 'loss=', '87.029330643')
# ('Epoch:', '0334', 'training time (minutes)=', '1.1601', 'loss=', '87.043996175')
# ('Epoch:', '0335', 'training time (minutes)=', '1.1613', 'loss=', '87.043202497')
# ('Held Out Data :', 'forward time (minutes)=', '0.0807', 'loss=', '96.378903198')
# ('Epoch:', '0336', 'training time (minutes)=', '1.1649', 'loss=', '87.032428222')
# ('Epoch:', '0337', 'training time (minutes)=', '1.1602', 'loss=', '87.175871564')
# ('Epoch:', '0338', 'training time (minutes)=', '1.1612', 'loss=', '87.071342778')
# ('Epoch:', '0339', 'training time (minutes)=', '1.1598', 'loss=', '86.986938742')
# ('Epoch:', '0340', 'training time (minutes)=', '1.1622', 'loss=', '86.856354865')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '95.940030670')
# ('Epoch:', '0341', 'training time (minutes)=', '1.1593', 'loss=', '86.913800270')
# ('Epoch:', '0342', 'training time (minutes)=', '1.1608', 'loss=', '86.920105290')
# ('Epoch:', '0343', 'training time (minutes)=', '1.1608', 'loss=', '87.009256070')
# ('Epoch:', '0344', 'training time (minutes)=', '1.1595', 'loss=', '86.717312047')
# ('Epoch:', '0345', 'training time (minutes)=', '1.1622', 'loss=', '86.711568484')
# ('Held Out Data :', 'forward time (minutes)=', '0.0818', 'loss=', '95.352404213')
# ('Epoch:', '0346', 'training time (minutes)=', '1.1592', 'loss=', '87.244456128')
# ('Epoch:', '0347', 'training time (minutes)=', '1.1623', 'loss=', '86.806512230')
# ('Epoch:', '0348', 'training time (minutes)=', '1.1604', 'loss=', '87.012725255')
# ('Epoch:', '0349', 'training time (minutes)=', '1.1624', 'loss=', '86.756923200')
# ('Epoch:', '0350', 'training time (minutes)=', '1.1621', 'loss=', '86.750675544')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0801', 'loss=', '96.349645615')
# ('Epoch:', '0351', 'training time (minutes)=', '1.1602', 'loss=', '86.736929719')
# ('Epoch:', '0352', 'training time (minutes)=', '1.1626', 'loss=', '87.146082604')
# ('Epoch:', '0353', 'training time (minutes)=', '1.1612', 'loss=', '86.690318320')
# ('Epoch:', '0354', 'training time (minutes)=', '1.1623', 'loss=', '87.001077138')
# ('Epoch:', '0355', 'training time (minutes)=', '1.1615', 'loss=', '86.845934970')
# ('Held Out Data :', 'forward time (minutes)=', '0.0815', 'loss=', '96.257169533')
# ('Epoch:', '0356', 'training time (minutes)=', '1.1581', 'loss=', '86.658678779')
# ('Epoch:', '0357', 'training time (minutes)=', '1.1621', 'loss=', '86.579529494')
# ('Epoch:', '0358', 'training time (minutes)=', '1.1610', 'loss=', '86.668257760')
# ('Epoch:', '0359', 'training time (minutes)=', '1.1603', 'loss=', '86.669497880')
# ('Epoch:', '0360', 'training time (minutes)=', '1.1622', 'loss=', '86.750387573')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0795', 'loss=', '95.905268288')
# ('Epoch:', '0361', 'training time (minutes)=', '1.1581', 'loss=', '86.498945573')
# ('Epoch:', '0362', 'training time (minutes)=', '1.1613', 'loss=', '86.537729700')
# ('Epoch:', '0363', 'training time (minutes)=', '1.1597', 'loss=', '86.623554993')
# ('Epoch:', '0364', 'training time (minutes)=', '1.1618', 'loss=', '86.641556604')
# ('Epoch:', '0365', 'training time (minutes)=', '1.1766', 'loss=', '86.691964567')
# ('Held Out Data :', 'forward time (minutes)=', '0.0804', 'loss=', '96.126930237')
# ('Epoch:', '0366', 'training time (minutes)=', '1.1603', 'loss=', '86.617646856')
# ('Epoch:', '0367', 'training time (minutes)=', '1.1614', 'loss=', '86.481685119')
# ('Epoch:', '0368', 'training time (minutes)=', '1.1617', 'loss=', '86.378262882')
# ('Epoch:', '0369', 'training time (minutes)=', '1.1617', 'loss=', '86.560585663')
# ('Epoch:', '0370', 'training time (minutes)=', '1.1595', 'loss=', '86.423979165')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0800', 'loss=', '96.683154678')
# ('Epoch:', '0371', 'training time (minutes)=', '1.1609', 'loss=', '86.630673174')
# ('Epoch:', '0372', 'training time (minutes)=', '1.1596', 'loss=', '86.577547201')
# ('Epoch:', '0373', 'training time (minutes)=', '1.1623', 'loss=', '86.544720083')
# ('Epoch:', '0374', 'training time (minutes)=', '1.1596', 'loss=', '86.453367106')
# ('Epoch:', '0375', 'training time (minutes)=', '1.1608', 'loss=', '86.510665097')
# ('Held Out Data :', 'forward time (minutes)=', '0.0806', 'loss=', '96.942647171')
# ('Epoch:', '0376', 'training time (minutes)=', '1.1609', 'loss=', '86.262489429')
# ('Epoch:', '0377', 'training time (minutes)=', '1.1580', 'loss=', '86.503213037')
# ('Epoch:', '0378', 'training time (minutes)=', '1.1321', 'loss=', '86.499667580')
# ('Epoch:', '0379', 'training time (minutes)=', '1.1312', 'loss=', '86.580256078')
# ('Epoch:', '0380', 'training time (minutes)=', '1.1311', 'loss=', '86.357684658')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0796', 'loss=', '95.933928680')
# ('Epoch:', '0381', 'training time (minutes)=', '1.1309', 'loss=', '86.327304829')
# ('Epoch:', '0382', 'training time (minutes)=', '1.1317', 'loss=', '86.291358793')
# ('Epoch:', '0383', 'training time (minutes)=', '1.1310', 'loss=', '86.237006743')
# ('Epoch:', '0384', 'training time (minutes)=', '1.1312', 'loss=', '86.262140843')
# ('Epoch:', '0385', 'training time (minutes)=', '1.1307', 'loss=', '86.235663174')
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '95.782314491')
# ('Epoch:', '0386', 'training time (minutes)=', '1.1312', 'loss=', '86.311362026')
# ('Epoch:', '0387', 'training time (minutes)=', '1.1309', 'loss=', '86.300608317')
# ('Epoch:', '0388', 'training time (minutes)=', '1.1302', 'loss=', '86.523728191')
# ('Epoch:', '0389', 'training time (minutes)=', '1.1312', 'loss=', '86.206419019')
# ('Epoch:', '0390', 'training time (minutes)=', '1.1296', 'loss=', '86.384291231')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0798', 'loss=', '96.924978638')
# ('Epoch:', '0391', 'training time (minutes)=', '1.1301', 'loss=', '86.360144220')
# ('Epoch:', '0392', 'training time (minutes)=', '1.1306', 'loss=', '86.229884537')
# ('Epoch:', '0393', 'training time (minutes)=', '1.1315', 'loss=', '86.297029622')
# ('Epoch:', '0394', 'training time (minutes)=', '1.1316', 'loss=', '86.119989743')
# ('Epoch:', '0395', 'training time (minutes)=', '1.1310', 'loss=', '86.080772732')
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '96.321520042')
# ('Epoch:', '0396', 'training time (minutes)=', '1.1309', 'loss=', '86.077349566')
# ('Epoch:', '0397', 'training time (minutes)=', '1.1325', 'loss=', '86.058613586')
# ('Epoch:', '0398', 'training time (minutes)=', '1.1330', 'loss=', '86.228293090')
# ('Epoch:', '0399', 'training time (minutes)=', '1.1314', 'loss=', '86.457008738')
# ('Epoch:', '0400', 'training time (minutes)=', '1.1311', 'loss=', '85.969010527')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0796', 'loss=', '95.367711830')
# ('Epoch:', '0401', 'training time (minutes)=', '1.1315', 'loss=', '86.164636805')
# ('Epoch:', '0402', 'training time (minutes)=', '1.1319', 'loss=', '86.270477184')
# ('Epoch:', '0403', 'training time (minutes)=', '1.1313', 'loss=', '86.054815541')
# ('Epoch:', '0404', 'training time (minutes)=', '1.1306', 'loss=', '86.247074956')
# ('Epoch:', '0405', 'training time (minutes)=', '1.1311', 'loss=', '86.186977132')
# ('Held Out Data :', 'forward time (minutes)=', '0.0798', 'loss=', '96.315551186')
# ('Epoch:', '0406', 'training time (minutes)=', '1.1307', 'loss=', '86.286550903')
# ('Epoch:', '0407', 'training time (minutes)=', '1.1296', 'loss=', '85.982249185')
# ('Epoch:', '0408', 'training time (minutes)=', '1.1307', 'loss=', '86.090185458')
# ('Epoch:', '0409', 'training time (minutes)=', '1.1312', 'loss=', '86.033518982')
# ('Epoch:', '0410', 'training time (minutes)=', '1.1304', 'loss=', '86.284562838')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '95.340991974')
# ('Epoch:', '0411', 'training time (minutes)=', '1.1298', 'loss=', '86.123320295')
# ('Epoch:', '0412', 'training time (minutes)=', '1.1304', 'loss=', '86.257965729')
# ('Epoch:', '0413', 'training time (minutes)=', '1.1309', 'loss=', '86.067733632')
# ('Epoch:', '0414', 'training time (minutes)=', '1.1308', 'loss=', '85.777350428')
# ('Epoch:', '0415', 'training time (minutes)=', '1.1299', 'loss=', '86.158675528')
# ('Held Out Data :', 'forward time (minutes)=', '0.0798', 'loss=', '95.445120811')
# ('Epoch:', '0416', 'training time (minutes)=', '1.1298', 'loss=', '86.072222923')
# ('Epoch:', '0417', 'training time (minutes)=', '1.1311', 'loss=', '85.879504019')
# ('Epoch:', '0418', 'training time (minutes)=', '1.1312', 'loss=', '85.722398023')
# ('Epoch:', '0419', 'training time (minutes)=', '1.1307', 'loss=', '85.972160848')
# ('Epoch:', '0420', 'training time (minutes)=', '1.1307', 'loss=', '85.950016143')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0798', 'loss=', '96.251074409')
# ('Epoch:', '0421', 'training time (minutes)=', '1.1303', 'loss=', '85.971701603')
# ('Epoch:', '0422', 'training time (minutes)=', '1.1315', 'loss=', '86.232140339')
# ('Epoch:', '0423', 'training time (minutes)=', '1.1302', 'loss=', '86.160770516')
# ('Epoch:', '0424', 'training time (minutes)=', '1.1303', 'loss=', '85.717627440')
# ('Epoch:', '0425', 'training time (minutes)=', '1.1307', 'loss=', '85.801177293')
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '95.720155334')
# ('Epoch:', '0426', 'training time (minutes)=', '1.1301', 'loss=', '85.760977637')
# ('Epoch:', '0427', 'training time (minutes)=', '1.1309', 'loss=', '85.874098604')
# ('Epoch:', '0428', 'training time (minutes)=', '1.1309', 'loss=', '85.870680104')
# ('Epoch:', '0429', 'training time (minutes)=', '1.1297', 'loss=', '86.052561553')
# ('Epoch:', '0430', 'training time (minutes)=', '1.1292', 'loss=', '85.996215776')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0796', 'loss=', '95.542958260')
# ('Epoch:', '0431', 'training time (minutes)=', '1.1300', 'loss=', '85.691624760')
# ('Epoch:', '0432', 'training time (minutes)=', '1.1296', 'loss=', '85.842663043')
# ('Epoch:', '0433', 'training time (minutes)=', '1.1313', 'loss=', '85.931751395')
# ('Epoch:', '0434', 'training time (minutes)=', '1.1306', 'loss=', '85.618757939')
# ('Epoch:', '0435', 'training time (minutes)=', '1.1306', 'loss=', '85.782496798')
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '95.559956169')
# ('Epoch:', '0436', 'training time (minutes)=', '1.1298', 'loss=', '85.782343480')
# ('Epoch:', '0437', 'training time (minutes)=', '1.1292', 'loss=', '85.852668652')
# ('Epoch:', '0438', 'training time (minutes)=', '1.1300', 'loss=', '85.826061216')
# ('Epoch:', '0439', 'training time (minutes)=', '1.1302', 'loss=', '85.770258143')
# ('Epoch:', '0440', 'training time (minutes)=', '1.1303', 'loss=', '85.620790940')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0801', 'loss=', '95.460934258')
# ('Epoch:', '0441', 'training time (minutes)=', '1.1366', 'loss=', '85.740559498')
# ('Epoch:', '0442', 'training time (minutes)=', '1.1425', 'loss=', '85.689245274')
# ('Epoch:', '0443', 'training time (minutes)=', '1.1498', 'loss=', '85.625571232')
# ('Epoch:', '0444', 'training time (minutes)=', '1.1523', 'loss=', '85.732536183')
# ('Epoch:', '0445', 'training time (minutes)=', '1.1556', 'loss=', '85.679410144')
# ('Held Out Data :', 'forward time (minutes)=', '0.0803', 'loss=', '96.366643715')
# ('Epoch:', '0446', 'training time (minutes)=', '1.1575', 'loss=', '85.675485849')
# ('Epoch:', '0447', 'training time (minutes)=', '1.1593', 'loss=', '85.667542875')
# ('Epoch:', '0448', 'training time (minutes)=', '1.1599', 'loss=', '85.625658627')
# ('Epoch:', '0449', 'training time (minutes)=', '1.1614', 'loss=', '85.539351378')
# ('Epoch:', '0450', 'training time (minutes)=', '1.1598', 'loss=', '85.646610824')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0804', 'loss=', '96.144542694')
# ('Epoch:', '0451', 'training time (minutes)=', '1.1609', 'loss=', '85.535768039')
# ('Epoch:', '0452', 'training time (minutes)=', '1.1625', 'loss=', '85.604376575')
# ('Epoch:', '0453', 'training time (minutes)=', '1.1632', 'loss=', '85.784717527')
# ('Epoch:', '0454', 'training time (minutes)=', '1.1633', 'loss=', '85.764986475')
# ('Epoch:', '0455', 'training time (minutes)=', '1.1650', 'loss=', '85.737678329')
# ('Held Out Data :', 'forward time (minutes)=', '0.0818', 'loss=', '95.774593544')
# ('Epoch:', '0456', 'training time (minutes)=', '1.1632', 'loss=', '85.770443305')
# ('Epoch:', '0457', 'training time (minutes)=', '1.1644', 'loss=', '85.492502406')
# ('Epoch:', '0458', 'training time (minutes)=', '1.1619', 'loss=', '85.540271814')
# ('Epoch:', '0459', 'training time (minutes)=', '1.1646', 'loss=', '85.507331804')
# ('Epoch:', '0460', 'training time (minutes)=', '1.1620', 'loss=', '85.429370427')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0804', 'loss=', '96.063842392')
# ('Epoch:', '0461', 'training time (minutes)=', '1.1614', 'loss=', '85.340260403')
# ('Epoch:', '0462', 'training time (minutes)=', '1.1647', 'loss=', '85.404918748')
# ('Epoch:', '0463', 'training time (minutes)=', '1.1656', 'loss=', '85.755365565')
# ('Epoch:', '0464', 'training time (minutes)=', '1.1952', 'loss=', '85.596178071')
# ('Epoch:', '0465', 'training time (minutes)=', '1.1657', 'loss=', '85.675789233')
# ('Held Out Data :', 'forward time (minutes)=', '0.0804', 'loss=', '95.891861916')
# ('Epoch:', '0466', 'training time (minutes)=', '1.2100', 'loss=', '85.552892956')
# ('Epoch:', '0467', 'training time (minutes)=', '1.1637', 'loss=', '85.269548366')
# ('Epoch:', '0468', 'training time (minutes)=', '1.1803', 'loss=', '85.643616276')
# ('Epoch:', '0469', 'training time (minutes)=', '1.1640', 'loss=', '85.393966255')
# ('Epoch:', '0470', 'training time (minutes)=', '1.1622', 'loss=', '85.368435979')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-470 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '97.163567543')
# ('Epoch:', '0471', 'training time (minutes)=', '1.1608', 'loss=', '85.391122680')
# ('Epoch:', '0472', 'training time (minutes)=', '1.1617', 'loss=', '85.412552764')
# ('Epoch:', '0473', 'training time (minutes)=', '1.1624', 'loss=', '85.496945190')
# ('Epoch:', '0474', 'training time (minutes)=', '1.1632', 'loss=', '85.455637194')
# ('Epoch:', '0475', 'training time (minutes)=', '1.1727', 'loss=', '85.589437159')
# ('Held Out Data :', 'forward time (minutes)=', '0.0817', 'loss=', '95.276432037')
# ('Epoch:', '0476', 'training time (minutes)=', '1.1863', 'loss=', '85.175554093')
# ('Epoch:', '0477', 'training time (minutes)=', '1.1626', 'loss=', '85.486005501')
# ('Epoch:', '0478', 'training time (minutes)=', '1.2336', 'loss=', '85.284849128')
# ('Epoch:', '0479', 'training time (minutes)=', '1.1598', 'loss=', '85.418577089')
# ('Epoch:', '0480', 'training time (minutes)=', '1.1635', 'loss=', '85.405653403')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-480 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0802', 'loss=', '95.353612518')
# ('Epoch:', '0481', 'training time (minutes)=', '1.1603', 'loss=', '85.465238289')
# ('Epoch:', '0482', 'training time (minutes)=', '1.1647', 'loss=', '85.204674077')
# ('Epoch:', '0483', 'training time (minutes)=', '1.2216', 'loss=', '85.382195558')
# ('Epoch:', '0484', 'training time (minutes)=', '1.1644', 'loss=', '85.233575749')
# ('Epoch:', '0485', 'training time (minutes)=', '1.1610', 'loss=', '85.387825056')
# ('Held Out Data :', 'forward time (minutes)=', '0.0813', 'loss=', '94.368301201')
# ('Epoch:', '0486', 'training time (minutes)=', '1.1629', 'loss=', '85.350039584')
# ('Epoch:', '0487', 'training time (minutes)=', '1.1629', 'loss=', '85.138605090')
# ('Epoch:', '0488', 'training time (minutes)=', '1.1655', 'loss=', '85.450406127')
# ('Epoch:', '0489', 'training time (minutes)=', '1.1610', 'loss=', '85.078985441')
# ('Epoch:', '0490', 'training time (minutes)=', '1.1641', 'loss=', '85.435884183')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-490 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0800', 'loss=', '95.747721672')
# ('Epoch:', '0491', 'training time (minutes)=', '1.1604', 'loss=', '85.455406432')
# ('Epoch:', '0492', 'training time (minutes)=', '1.1669', 'loss=', '85.182042285')
# ('Epoch:', '0493', 'training time (minutes)=', '1.1763', 'loss=', '85.315457286')
# ('Epoch:', '0494', 'training time (minutes)=', '1.1620', 'loss=', '85.009346362')
# ('Epoch:', '0495', 'training time (minutes)=', '1.1634', 'loss=', '85.124460347')
# ('Held Out Data :', 'forward time (minutes)=', '0.0808', 'loss=', '95.399424934')
# ('Epoch:', '0496', 'training time (minutes)=', '1.1616', 'loss=', '85.047248862')
# ('Epoch:', '0497', 'training time (minutes)=', '1.1648', 'loss=', '85.410209236')
# ('Epoch:', '0498', 'training time (minutes)=', '1.1624', 'loss=', '85.302951227')
# ('Epoch:', '0499', 'training time (minutes)=', '1.2957', 'loss=', '85.296174157')
# ('Epoch:', '0500', 'training time (minutes)=', '1.1639', 'loss=', '85.185793559')
# INFO:tensorflow:/orions4-zfs/projects/optas/DATA/OUT/iclr/nn_models/ae_chair_mlp_with_split_3pc_usampled_bnorm_on_encoder_only_2048_pts_512_bneck_emd/models.ckpt-500 is not in all_model_checkpoint_paths. Manually adding it.
# ('Held Out Data :', 'forward time (minutes)=', '0.0797', 'loss=', '94.589117622')
