# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 2
setup_one_gpu(GPU)
# Out:
# Picking GPU 2

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs

from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry, decoder_with_fc_only
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tf_lab.iclr.helper import load_multiple_version_of_pcs

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = False
load_model = True
seed = 42
max_training_epochs = 2000
loss = 'chamfer'
z_rotate = True
experiment_name = 'all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code' + str(n_pc_samples) +  'pts_' + loss

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'

# %%
n_threads = 25
verbose = True
version = 'centered'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', version, str(n_pc_samples))
full_file_names = [f for f in files_in_subdirs(full_pclouds_path, '.ply')]
pclouds, _, _ = load_point_clouds_from_filenames(full_file_names, n_threads, snc_loader, verbose)
train_data = PointCloudDataSet(pclouds)
print train_data.num_examples
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:38: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')
# 57449 pclouds were loaded. They belong in 57 shape-classes.
# 57449

# %%
train_dir = osp.join('/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc', experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer'

# %%
n_input = [n_pc_samples, 3]

encoder_args = {'n_filters': [64, 128, 128, 256, 512],
                'filter_sizes': [1, 1, 1, 1, 1],
                'strides': [1, 1, 1, 1, 1],
                'b_norm': True
               }

decoder_args = {'layer_sizes': [512, 1024, np.prod(n_input)],
                'b_norm': False
               }

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = decoder_with_fc_only,
                decoder_args = decoder_args,            
               )
    conf.allow_gpu_growth = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)
# Out:
#               allow_gpu_growth: False
#                     batch_size: 50
#                  consistent_io: None
#                          debug: False
#                        decoder: decoder_with_fc_only
#                   decoder_args: {'b_norm': False, 'layer_sizes': [512, 1024, 6144]}
#                        encoder: encoder_with_convs_and_symmetry
#                   encoder_args: {'filter_sizes': [1, 1, 1, 1, 1], 'n_filters': [64, 128, 128, 256, 512], 'b_norm': True, 'strides': [1, 1, 1, 1, 1]}
#                experiment_name: all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer
#                  gauss_augment: None
#                   is_denoising: False
#                latent_vs_recon: 1.0
#                  learning_rate: 0.0005
#                           loss: chamfer
#              loss_display_step: 1
#                        n_input: [2048, 3]
#                       n_output: [2048, 3]
#                            n_z: None
#              saver_max_to_keep: None
#                     saver_step: 10
#                      train_dir: /orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer
#                training_epochs: 2000
#                       z_rotate: True
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/encoders_decoders.py:95: UserWarning: Using old architecture.
#   warnings.warn('Using old architecture.')

# %%
if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)
        
if load_model and do_training:
    conf.training_epochs -= last_epoch
    print conf.training_epochs
# Out:
# Model restored in epoch 1230.
# 770

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)    
    train_stats = ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '1231', 'training time (minutes)=', '1.9518', 'loss=', '0.000481043')
# ('Epoch:', '1232', 'training time (minutes)=', '2.0245', 'loss=', '0.000487127')
# ('Epoch:', '1233', 'training time (minutes)=', '2.0729', 'loss=', '0.000489595')
# ('Epoch:', '1234', 'training time (minutes)=', '2.1142', 'loss=', '0.000490053')
# ('Epoch:', '1235', 'training time (minutes)=', '2.0519', 'loss=', '0.000487704')
# ('Epoch:', '1236', 'training time (minutes)=', '2.0289', 'loss=', '0.000475727')
# ('Epoch:', '1237', 'training time (minutes)=', '2.0718', 'loss=', '0.000477899')
# ('Epoch:', '1238', 'training time (minutes)=', '2.0520', 'loss=', '0.000494582')
# ('Epoch:', '1239', 'training time (minutes)=', '2.0498', 'loss=', '0.000482288')
# ('Epoch:', '1240', 'training time (minutes)=', '2.0284', 'loss=', '0.000483075')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1241', 'training time (minutes)=', '2.0307', 'loss=', '0.000475207')
# ('Epoch:', '1242', 'training time (minutes)=', '2.0541', 'loss=', '0.000482920')
# ('Epoch:', '1243', 'training time (minutes)=', '2.0312', 'loss=', '0.000476528')
# ('Epoch:', '1244', 'training time (minutes)=', '2.0947', 'loss=', '0.000476235')
# ('Epoch:', '1245', 'training time (minutes)=', '2.0576', 'loss=', '0.000477603')
# ('Epoch:', '1246', 'training time (minutes)=', '2.0608', 'loss=', '0.000496814')
# ('Epoch:', '1247', 'training time (minutes)=', '2.0320', 'loss=', '0.000489441')
# ('Epoch:', '1248', 'training time (minutes)=', '2.0224', 'loss=', '0.000490243')
# ('Epoch:', '1249', 'training time (minutes)=', '2.0301', 'loss=', '0.000474982')
# ('Epoch:', '1250', 'training time (minutes)=', '2.0436', 'loss=', '0.000485943')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1251', 'training time (minutes)=', '2.0366', 'loss=', '0.000486604')
# ('Epoch:', '1252', 'training time (minutes)=', '2.0820', 'loss=', '0.000488559')
# ('Epoch:', '1253', 'training time (minutes)=', '2.0595', 'loss=', '0.000482087')
# ('Epoch:', '1254', 'training time (minutes)=', '2.0530', 'loss=', '0.000481533')
# ('Epoch:', '1255', 'training time (minutes)=', '2.0739', 'loss=', '0.000477544')
# ('Epoch:', '1256', 'training time (minutes)=', '2.0699', 'loss=', '0.000481570')
# ('Epoch:', '1257', 'training time (minutes)=', '2.0446', 'loss=', '0.000476021')
# ('Epoch:', '1258', 'training time (minutes)=', '2.0630', 'loss=', '0.000484571')
# ('Epoch:', '1259', 'training time (minutes)=', '2.0554', 'loss=', '0.000486325')
# ('Epoch:', '1260', 'training time (minutes)=', '2.0582', 'loss=', '0.000481082')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1261', 'training time (minutes)=', '2.0874', 'loss=', '0.000482032')
# ('Epoch:', '1262', 'training time (minutes)=', '2.0769', 'loss=', '0.000493927')
# ('Epoch:', '1263', 'training time (minutes)=', '2.0653', 'loss=', '0.000483499')
# ('Epoch:', '1264', 'training time (minutes)=', '2.0584', 'loss=', '0.000486651')
# ('Epoch:', '1265', 'training time (minutes)=', '2.0862', 'loss=', '0.000480134')
# ('Epoch:', '1266', 'training time (minutes)=', '2.0792', 'loss=', '0.000480082')
# ('Epoch:', '1267', 'training time (minutes)=', '2.0587', 'loss=', '0.000485180')
# ('Epoch:', '1268', 'training time (minutes)=', '2.0910', 'loss=', '0.000480886')
# ('Epoch:', '1269', 'training time (minutes)=', '2.0627', 'loss=', '0.000479983')
# ('Epoch:', '1270', 'training time (minutes)=', '2.0450', 'loss=', '0.000490192')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1271', 'training time (minutes)=', '2.0800', 'loss=', '0.000483581')
# ('Epoch:', '1272', 'training time (minutes)=', '2.0643', 'loss=', '0.000483751')
# ('Epoch:', '1273', 'training time (minutes)=', '2.0468', 'loss=', '0.000476584')
# ('Epoch:', '1274', 'training time (minutes)=', '2.0855', 'loss=', '0.000479884')
# ('Epoch:', '1275', 'training time (minutes)=', '2.0794', 'loss=', '0.000475166')
# ('Epoch:', '1276', 'training time (minutes)=', '2.0722', 'loss=', '0.000483620')
# ('Epoch:', '1277', 'training time (minutes)=', '2.1207', 'loss=', '0.000480962')
# ('Epoch:', '1278', 'training time (minutes)=', '2.0965', 'loss=', '0.000482474')
# ('Epoch:', '1279', 'training time (minutes)=', '2.0985', 'loss=', '0.000477226')
# ('Epoch:', '1280', 'training time (minutes)=', '2.1120', 'loss=', '0.000481497')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1281', 'training time (minutes)=', '2.1933', 'loss=', '0.000481530')
# ('Epoch:', '1282', 'training time (minutes)=', '2.2335', 'loss=', '0.000474102')
# ('Epoch:', '1283', 'training time (minutes)=', '2.1252', 'loss=', '0.000475395')
# ('Epoch:', '1284', 'training time (minutes)=', '2.2209', 'loss=', '0.000477332')
# ('Epoch:', '1285', 'training time (minutes)=', '2.1399', 'loss=', '0.000475028')
# ('Epoch:', '1286', 'training time (minutes)=', '2.2323', 'loss=', '0.000479893')
# ('Epoch:', '1287', 'training time (minutes)=', '2.2379', 'loss=', '0.000481869')
# ('Epoch:', '1288', 'training time (minutes)=', '2.2781', 'loss=', '0.000483031')
# ('Epoch:', '1289', 'training time (minutes)=', '2.2040', 'loss=', '0.000483137')
# ('Epoch:', '1290', 'training time (minutes)=', '2.0890', 'loss=', '0.000478877')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1291', 'training time (minutes)=', '2.0469', 'loss=', '0.000471241')
# ('Epoch:', '1292', 'training time (minutes)=', '2.0199', 'loss=', '0.000487233')
# ('Epoch:', '1293', 'training time (minutes)=', '2.0112', 'loss=', '0.000490656')
# ('Epoch:', '1294', 'training time (minutes)=', '2.0228', 'loss=', '0.000488136')
# ('Epoch:', '1295', 'training time (minutes)=', '2.0030', 'loss=', '0.000486267')
# ('Epoch:', '1296', 'training time (minutes)=', '2.0191', 'loss=', '0.000486914')
# ('Epoch:', '1297', 'training time (minutes)=', '2.0329', 'loss=', '0.000492003')
# ('Epoch:', '1298', 'training time (minutes)=', '2.0540', 'loss=', '0.000485134')
# ('Epoch:', '1299', 'training time (minutes)=', '2.0232', 'loss=', '0.000473981')
# ('Epoch:', '1300', 'training time (minutes)=', '1.9907', 'loss=', '0.000480679')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1301', 'training time (minutes)=', '1.9971', 'loss=', '0.000477647')
# ('Epoch:', '1302', 'training time (minutes)=', '2.0059', 'loss=', '0.000477039')
# ('Epoch:', '1303', 'training time (minutes)=', '1.9886', 'loss=', '0.000477238')
# ('Epoch:', '1304', 'training time (minutes)=', '1.9943', 'loss=', '0.000495147')
# ('Epoch:', '1305', 'training time (minutes)=', '1.9922', 'loss=', '0.000475963')
# ('Epoch:', '1306', 'training time (minutes)=', '1.9889', 'loss=', '0.000485936')
# ('Epoch:', '1307', 'training time (minutes)=', '2.0191', 'loss=', '0.000482027')
# ('Epoch:', '1308', 'training time (minutes)=', '2.0219', 'loss=', '0.000479107')
# ('Epoch:', '1309', 'training time (minutes)=', '1.9986', 'loss=', '0.000471854')
# ('Epoch:', '1310', 'training time (minutes)=', '2.0011', 'loss=', '0.000475990')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1311', 'training time (minutes)=', '2.0384', 'loss=', '0.000478886')
# ('Epoch:', '1312', 'training time (minutes)=', '2.0289', 'loss=', '0.000493702')
# ('Epoch:', '1313', 'training time (minutes)=', '2.0344', 'loss=', '0.000486930')
# ('Epoch:', '1314', 'training time (minutes)=', '2.0359', 'loss=', '0.000503406')
# ('Epoch:', '1315', 'training time (minutes)=', '2.0380', 'loss=', '0.000503443')
# ('Epoch:', '1316', 'training time (minutes)=', '2.0343', 'loss=', '0.000488338')
# ('Epoch:', '1317', 'training time (minutes)=', '2.1225', 'loss=', '0.000478139')
# ('Epoch:', '1318', 'training time (minutes)=', '2.0335', 'loss=', '0.000489315')
# ('Epoch:', '1319', 'training time (minutes)=', '2.0655', 'loss=', '0.000474943')
# ('Epoch:', '1320', 'training time (minutes)=', '2.1061', 'loss=', '0.000475226')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1321', 'training time (minutes)=', '2.0424', 'loss=', '0.000487272')
# ('Epoch:', '1322', 'training time (minutes)=', '2.0828', 'loss=', '0.000480281')
# ('Epoch:', '1323', 'training time (minutes)=', '2.1069', 'loss=', '0.000481114')
# ('Epoch:', '1324', 'training time (minutes)=', '2.0910', 'loss=', '0.000474798')
# ('Epoch:', '1325', 'training time (minutes)=', '2.1219', 'loss=', '0.000490327')
# ('Epoch:', '1326', 'training time (minutes)=', '2.1339', 'loss=', '0.000479674')
# ('Epoch:', '1327', 'training time (minutes)=', '2.0935', 'loss=', '0.000479406')
# ('Epoch:', '1328', 'training time (minutes)=', '2.0744', 'loss=', '0.000483410')
# ('Epoch:', '1329', 'training time (minutes)=', '2.1421', 'loss=', '0.000482736')
# ('Epoch:', '1330', 'training time (minutes)=', '2.0557', 'loss=', '0.000498358')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1331', 'training time (minutes)=', '2.1035', 'loss=', '0.000483000')
# ('Epoch:', '1332', 'training time (minutes)=', '2.1666', 'loss=', '0.000495342')
# ('Epoch:', '1333', 'training time (minutes)=', '2.1078', 'loss=', '0.000471374')
# ('Epoch:', '1334', 'training time (minutes)=', '2.0776', 'loss=', '0.000478409')
# ('Epoch:', '1335', 'training time (minutes)=', '2.0719', 'loss=', '0.000476235')
# ('Epoch:', '1336', 'training time (minutes)=', '2.0777', 'loss=', '0.000482753')
# ('Epoch:', '1337', 'training time (minutes)=', '2.0747', 'loss=', '0.000487694')
# ('Epoch:', '1338', 'training time (minutes)=', '2.1032', 'loss=', '0.000484859')
# ('Epoch:', '1339', 'training time (minutes)=', '2.0703', 'loss=', '0.000485597')
# ('Epoch:', '1340', 'training time (minutes)=', '2.0961', 'loss=', '0.000484023')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1341', 'training time (minutes)=', '2.0985', 'loss=', '0.000485099')
# ('Epoch:', '1342', 'training time (minutes)=', '2.0725', 'loss=', '0.000481614')
# ('Epoch:', '1343', 'training time (minutes)=', '2.0305', 'loss=', '0.000486816')
# ('Epoch:', '1344', 'training time (minutes)=', '2.0965', 'loss=', '0.000477411')
# ('Epoch:', '1345', 'training time (minutes)=', '2.0580', 'loss=', '0.000532432')
# ('Epoch:', '1346', 'training time (minutes)=', '2.0272', 'loss=', '0.000479926')
# ('Epoch:', '1347', 'training time (minutes)=', '2.0427', 'loss=', '0.000472902')
# ('Epoch:', '1348', 'training time (minutes)=', '2.0230', 'loss=', '0.000472803')
# ('Epoch:', '1349', 'training time (minutes)=', '2.0186', 'loss=', '0.000491746')
# ('Epoch:', '1350', 'training time (minutes)=', '2.0296', 'loss=', '0.000477183')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1351', 'training time (minutes)=', '2.0191', 'loss=', '0.000485077')
# ('Epoch:', '1352', 'training time (minutes)=', '2.0365', 'loss=', '0.000478344')
# ('Epoch:', '1353', 'training time (minutes)=', '2.0235', 'loss=', '0.000477138')
# ('Epoch:', '1354', 'training time (minutes)=', '2.1461', 'loss=', '0.000488096')
# ('Epoch:', '1355', 'training time (minutes)=', '2.0540', 'loss=', '0.000480178')
# ('Epoch:', '1356', 'training time (minutes)=', '2.0501', 'loss=', '0.000492638')
# ('Epoch:', '1357', 'training time (minutes)=', '2.0521', 'loss=', '0.000487394')
# ('Epoch:', '1358', 'training time (minutes)=', '2.2511', 'loss=', '0.000483682')
# ('Epoch:', '1359', 'training time (minutes)=', '2.1448', 'loss=', '0.000484803')
# ('Epoch:', '1360', 'training time (minutes)=', '2.2173', 'loss=', '0.000486807')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1361', 'training time (minutes)=', '2.1610', 'loss=', '0.000484056')
# ('Epoch:', '1362', 'training time (minutes)=', '2.2103', 'loss=', '0.000485958')
# ('Epoch:', '1363', 'training time (minutes)=', '2.2355', 'loss=', '0.000484552')
# ('Epoch:', '1364', 'training time (minutes)=', '2.1937', 'loss=', '0.000482655')
# ('Epoch:', '1365', 'training time (minutes)=', '2.1833', 'loss=', '0.000483771')
# ('Epoch:', '1366', 'training time (minutes)=', '2.2981', 'loss=', '0.000477388')
# ('Epoch:', '1367', 'training time (minutes)=', '2.0639', 'loss=', '0.000491752')
# ('Epoch:', '1368', 'training time (minutes)=', '2.1592', 'loss=', '0.000475093')
# ('Epoch:', '1369', 'training time (minutes)=', '2.0183', 'loss=', '0.000487444')
# ('Epoch:', '1370', 'training time (minutes)=', '2.0391', 'loss=', '0.000492716')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1371', 'training time (minutes)=', '2.0475', 'loss=', '0.000486767')
# ('Epoch:', '1372', 'training time (minutes)=', '2.0502', 'loss=', '0.000484521')
# ('Epoch:', '1373', 'training time (minutes)=', '2.0463', 'loss=', '0.000492250')
# ('Epoch:', '1374', 'training time (minutes)=', '2.0638', 'loss=', '0.000479967')
# ('Epoch:', '1375', 'training time (minutes)=', '2.0532', 'loss=', '0.000483421')
# ('Epoch:', '1376', 'training time (minutes)=', '2.0524', 'loss=', '0.000481423')
# ('Epoch:', '1377', 'training time (minutes)=', '2.0591', 'loss=', '0.000480857')
# ('Epoch:', '1378', 'training time (minutes)=', '2.0591', 'loss=', '0.000474055')
# ('Epoch:', '1379', 'training time (minutes)=', '2.0598', 'loss=', '0.000485201')
# ('Epoch:', '1380', 'training time (minutes)=', '2.1510', 'loss=', '0.000482734')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1381', 'training time (minutes)=', '2.0774', 'loss=', '0.000473341')
# ('Epoch:', '1382', 'training time (minutes)=', '2.1747', 'loss=', '0.000475358')
# ('Epoch:', '1383', 'training time (minutes)=', '2.2017', 'loss=', '0.000478656')
# ('Epoch:', '1384', 'training time (minutes)=', '2.1780', 'loss=', '0.000482054')
# ('Epoch:', '1385', 'training time (minutes)=', '2.0544', 'loss=', '0.000468860')
# ('Epoch:', '1386', 'training time (minutes)=', '2.0325', 'loss=', '0.000486737')
# ('Epoch:', '1387', 'training time (minutes)=', '2.0062', 'loss=', '0.000484458')
# ('Epoch:', '1388', 'training time (minutes)=', '2.0458', 'loss=', '0.000482725')
# ('Epoch:', '1389', 'training time (minutes)=', '2.0340', 'loss=', '0.000484887')
# ('Epoch:', '1390', 'training time (minutes)=', '2.0293', 'loss=', '0.000477566')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1391', 'training time (minutes)=', '2.0583', 'loss=', '0.000482220')
# ('Epoch:', '1392', 'training time (minutes)=', '2.0736', 'loss=', '0.000485739')
# ('Epoch:', '1393', 'training time (minutes)=', '2.1325', 'loss=', '0.000477473')
# ('Epoch:', '1394', 'training time (minutes)=', '2.2022', 'loss=', '0.000482991')
# ('Epoch:', '1395', 'training time (minutes)=', '2.2040', 'loss=', '0.000491060')
# ('Epoch:', '1396', 'training time (minutes)=', '2.0865', 'loss=', '0.000467811')
# ('Epoch:', '1397', 'training time (minutes)=', '2.0996', 'loss=', '0.000472150')
# ('Epoch:', '1398', 'training time (minutes)=', '2.0331', 'loss=', '0.000483384')
# ('Epoch:', '1399', 'training time (minutes)=', '2.0290', 'loss=', '0.000474055')
# ('Epoch:', '1400', 'training time (minutes)=', '2.1155', 'loss=', '0.000473735')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1401', 'training time (minutes)=', '2.0714', 'loss=', '0.000479796')
# ('Epoch:', '1402', 'training time (minutes)=', '2.0841', 'loss=', '0.000492802')
# ('Epoch:', '1403', 'training time (minutes)=', '2.0388', 'loss=', '0.000474435')
# ('Epoch:', '1404', 'training time (minutes)=', '2.0579', 'loss=', '0.000474552')
# ('Epoch:', '1405', 'training time (minutes)=', '2.0695', 'loss=', '0.000492500')
# ('Epoch:', '1406', 'training time (minutes)=', '2.0404', 'loss=', '0.000490258')
# ('Epoch:', '1407', 'training time (minutes)=', '2.0626', 'loss=', '0.000479296')
# ('Epoch:', '1408', 'training time (minutes)=', '2.1562', 'loss=', '0.000488780')
# ('Epoch:', '1409', 'training time (minutes)=', '2.0621', 'loss=', '0.000486602')
# ('Epoch:', '1410', 'training time (minutes)=', '2.0689', 'loss=', '0.000473522')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1411', 'training time (minutes)=', '2.1124', 'loss=', '0.000487547')
# ('Epoch:', '1412', 'training time (minutes)=', '2.0331', 'loss=', '0.000474095')
# ('Epoch:', '1413', 'training time (minutes)=', '2.0639', 'loss=', '0.000496874')
# ('Epoch:', '1414', 'training time (minutes)=', '2.0458', 'loss=', '0.000490597')
# ('Epoch:', '1415', 'training time (minutes)=', '2.0391', 'loss=', '0.000484645')
# ('Epoch:', '1416', 'training time (minutes)=', '2.0736', 'loss=', '0.000477565')
# ('Epoch:', '1417', 'training time (minutes)=', '2.0850', 'loss=', '0.000481993')
# ('Epoch:', '1418', 'training time (minutes)=', '2.1289', 'loss=', '0.000476630')
# ('Epoch:', '1419', 'training time (minutes)=', '2.1083', 'loss=', '0.000482927')
# ('Epoch:', '1420', 'training time (minutes)=', '2.1324', 'loss=', '0.000480639')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1421', 'training time (minutes)=', '2.0992', 'loss=', '0.000477935')
# ('Epoch:', '1422', 'training time (minutes)=', '2.0648', 'loss=', '0.000494010')
# ('Epoch:', '1423', 'training time (minutes)=', '2.0286', 'loss=', '0.000470367')
# ('Epoch:', '1424', 'training time (minutes)=', '2.0650', 'loss=', '0.000492383')
# ('Epoch:', '1425', 'training time (minutes)=', '2.0703', 'loss=', '0.000476947')
# ('Epoch:', '1426', 'training time (minutes)=', '2.1416', 'loss=', '0.000488814')
# ('Epoch:', '1427', 'training time (minutes)=', '2.0948', 'loss=', '0.000493344')
# ('Epoch:', '1428', 'training time (minutes)=', '2.1790', 'loss=', '0.000478882')
# ('Epoch:', '1429', 'training time (minutes)=', '2.1292', 'loss=', '0.000482220')
# ('Epoch:', '1430', 'training time (minutes)=', '2.1105', 'loss=', '0.000469943')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1431', 'training time (minutes)=', '2.1817', 'loss=', '0.000479707')
# ('Epoch:', '1432', 'training time (minutes)=', '2.1216', 'loss=', '0.000479444')
# ('Epoch:', '1433', 'training time (minutes)=', '2.1184', 'loss=', '0.000487170')
# ('Epoch:', '1434', 'training time (minutes)=', '2.0897', 'loss=', '0.000480294')
# ('Epoch:', '1435', 'training time (minutes)=', '2.1088', 'loss=', '0.000479941')
# ('Epoch:', '1436', 'training time (minutes)=', '2.1061', 'loss=', '0.000483279')
# ('Epoch:', '1437', 'training time (minutes)=', '2.0902', 'loss=', '0.000482848')
# ('Epoch:', '1438', 'training time (minutes)=', '2.0777', 'loss=', '0.000481021')
# ('Epoch:', '1439', 'training time (minutes)=', '2.1145', 'loss=', '0.000486298')
# ('Epoch:', '1440', 'training time (minutes)=', '2.0810', 'loss=', '0.000475754')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1441', 'training time (minutes)=', '2.1048', 'loss=', '0.000484731')
# ('Epoch:', '1442', 'training time (minutes)=', '2.1262', 'loss=', '0.000479892')
# ('Epoch:', '1443', 'training time (minutes)=', '2.1324', 'loss=', '0.000483120')
# ('Epoch:', '1444', 'training time (minutes)=', '2.1001', 'loss=', '0.000477977')
# ('Epoch:', '1445', 'training time (minutes)=', '2.1296', 'loss=', '0.000479259')
# ('Epoch:', '1446', 'training time (minutes)=', '2.0367', 'loss=', '0.000484749')
# ('Epoch:', '1447', 'training time (minutes)=', '2.0509', 'loss=', '0.000468491')
# ('Epoch:', '1448', 'training time (minutes)=', '2.1318', 'loss=', '0.000476155')
# ('Epoch:', '1449', 'training time (minutes)=', '2.1196', 'loss=', '0.000477518')
# ('Epoch:', '1450', 'training time (minutes)=', '2.0993', 'loss=', '0.000478812')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1451', 'training time (minutes)=', '2.0792', 'loss=', '0.000474849')
# ('Epoch:', '1452', 'training time (minutes)=', '2.1411', 'loss=', '0.000485928')
# ('Epoch:', '1453', 'training time (minutes)=', '2.1488', 'loss=', '0.000478051')
# ('Epoch:', '1454', 'training time (minutes)=', '2.0513', 'loss=', '0.000481126')
# ('Epoch:', '1455', 'training time (minutes)=', '2.1073', 'loss=', '0.000477456')
# ('Epoch:', '1456', 'training time (minutes)=', '2.0824', 'loss=', '0.000481304')
# ('Epoch:', '1457', 'training time (minutes)=', '2.0899', 'loss=', '0.000475107')
# ('Epoch:', '1458', 'training time (minutes)=', '2.0966', 'loss=', '0.000472889')
# ('Epoch:', '1459', 'training time (minutes)=', '2.0927', 'loss=', '0.000477219')
# ('Epoch:', '1460', 'training time (minutes)=', '2.1336', 'loss=', '0.000476726')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1461', 'training time (minutes)=', '2.1005', 'loss=', '0.000469794')
# ('Epoch:', '1462', 'training time (minutes)=', '2.1315', 'loss=', '0.000475074')
# ('Epoch:', '1463', 'training time (minutes)=', '2.0817', 'loss=', '0.000482138')
# ('Epoch:', '1464', 'training time (minutes)=', '2.1081', 'loss=', '0.000479033')
# ('Epoch:', '1465', 'training time (minutes)=', '2.1124', 'loss=', '0.000478848')
# ('Epoch:', '1466', 'training time (minutes)=', '2.1014', 'loss=', '0.000465810')
# ('Epoch:', '1467', 'training time (minutes)=', '2.0856', 'loss=', '0.000483866')
# ('Epoch:', '1468', 'training time (minutes)=', '2.0579', 'loss=', '0.000488531')
# ('Epoch:', '1469', 'training time (minutes)=', '2.0731', 'loss=', '0.000484971')
# ('Epoch:', '1470', 'training time (minutes)=', '2.0807', 'loss=', '0.000475683')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1470 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1471', 'training time (minutes)=', '2.1501', 'loss=', '0.000479287')
# ('Epoch:', '1472', 'training time (minutes)=', '2.0951', 'loss=', '0.000474271')
# ('Epoch:', '1473', 'training time (minutes)=', '2.1416', 'loss=', '0.000471845')
# ('Epoch:', '1474', 'training time (minutes)=', '2.1702', 'loss=', '0.000475964')
# ('Epoch:', '1475', 'training time (minutes)=', '2.1701', 'loss=', '0.000479934')
# ('Epoch:', '1476', 'training time (minutes)=', '2.0815', 'loss=', '0.000482337')
# ('Epoch:', '1477', 'training time (minutes)=', '2.0978', 'loss=', '0.000491905')
# ('Epoch:', '1478', 'training time (minutes)=', '2.0884', 'loss=', '0.000473929')
# ('Epoch:', '1479', 'training time (minutes)=', '2.0750', 'loss=', '0.000489366')
# ('Epoch:', '1480', 'training time (minutes)=', '2.0874', 'loss=', '0.000479297')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1480 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1481', 'training time (minutes)=', '2.0669', 'loss=', '0.000491327')
# ('Epoch:', '1482', 'training time (minutes)=', '2.0538', 'loss=', '0.000474981')
# ('Epoch:', '1483', 'training time (minutes)=', '2.0849', 'loss=', '0.000489718')
# ('Epoch:', '1484', 'training time (minutes)=', '2.1038', 'loss=', '0.000476080')
# ('Epoch:', '1485', 'training time (minutes)=', '2.0727', 'loss=', '0.000500834')
# ('Epoch:', '1486', 'training time (minutes)=', '2.0890', 'loss=', '0.000482369')
# ('Epoch:', '1487', 'training time (minutes)=', '2.0294', 'loss=', '0.000477364')
# ('Epoch:', '1488', 'training time (minutes)=', '2.1290', 'loss=', '0.000479721')
# ('Epoch:', '1489', 'training time (minutes)=', '2.1208', 'loss=', '0.000473600')
# ('Epoch:', '1490', 'training time (minutes)=', '2.0949', 'loss=', '0.000481594')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1490 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1491', 'training time (minutes)=', '2.1076', 'loss=', '0.000480593')
# ('Epoch:', '1492', 'training time (minutes)=', '2.1394', 'loss=', '0.000473422')
# ('Epoch:', '1493', 'training time (minutes)=', '2.1252', 'loss=', '0.000479447')
# ('Epoch:', '1494', 'training time (minutes)=', '2.1488', 'loss=', '0.000493275')
# ('Epoch:', '1495', 'training time (minutes)=', '2.0318', 'loss=', '0.000477239')
# ('Epoch:', '1496', 'training time (minutes)=', '2.0006', 'loss=', '0.000475287')
# ('Epoch:', '1497', 'training time (minutes)=', '2.0228', 'loss=', '0.000485126')
# ('Epoch:', '1498', 'training time (minutes)=', '2.0152', 'loss=', '0.000486320')
# ('Epoch:', '1499', 'training time (minutes)=', '2.0729', 'loss=', '0.000478909')
# ('Epoch:', '1500', 'training time (minutes)=', '2.0470', 'loss=', '0.000476797')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1500 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1501', 'training time (minutes)=', '2.0505', 'loss=', '0.000484172')
# ('Epoch:', '1502', 'training time (minutes)=', '2.0253', 'loss=', '0.000473167')
# ('Epoch:', '1503', 'training time (minutes)=', '2.0300', 'loss=', '0.000485519')
# ('Epoch:', '1504', 'training time (minutes)=', '1.9933', 'loss=', '0.000471483')
# ('Epoch:', '1505', 'training time (minutes)=', '2.0251', 'loss=', '0.000480610')
# ('Epoch:', '1506', 'training time (minutes)=', '2.0515', 'loss=', '0.000480093')
# ('Epoch:', '1507', 'training time (minutes)=', '2.0375', 'loss=', '0.000491866')
# ('Epoch:', '1508', 'training time (minutes)=', '2.0227', 'loss=', '0.000471649')
# ('Epoch:', '1509', 'training time (minutes)=', '2.0181', 'loss=', '0.000486739')
# ('Epoch:', '1510', 'training time (minutes)=', '2.0259', 'loss=', '0.000469523')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1510 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1511', 'training time (minutes)=', '2.0146', 'loss=', '0.000481826')
# ('Epoch:', '1512', 'training time (minutes)=', '2.0344', 'loss=', '0.000476438')
# ('Epoch:', '1513', 'training time (minutes)=', '2.0515', 'loss=', '0.000490248')
# ('Epoch:', '1514', 'training time (minutes)=', '2.0365', 'loss=', '0.000476909')
# ('Epoch:', '1515', 'training time (minutes)=', '2.0674', 'loss=', '0.000479626')
# ('Epoch:', '1516', 'training time (minutes)=', '2.0759', 'loss=', '0.000473851')
# ('Epoch:', '1517', 'training time (minutes)=', '2.0823', 'loss=', '0.000479341')
# ('Epoch:', '1518', 'training time (minutes)=', '2.0816', 'loss=', '0.000470183')
# ('Epoch:', '1519', 'training time (minutes)=', '2.0708', 'loss=', '0.000491348')
# ('Epoch:', '1520', 'training time (minutes)=', '2.0932', 'loss=', '0.000471014')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1520 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1521', 'training time (minutes)=', '2.0100', 'loss=', '0.000476474')
# ('Epoch:', '1522', 'training time (minutes)=', '2.0341', 'loss=', '0.000487206')
# ('Epoch:', '1523', 'training time (minutes)=', '2.0387', 'loss=', '0.000471029')
# ('Epoch:', '1524', 'training time (minutes)=', '2.0314', 'loss=', '0.000479658')
# ('Epoch:', '1525', 'training time (minutes)=', '2.0000', 'loss=', '0.000473726')
# ('Epoch:', '1526', 'training time (minutes)=', '2.0039', 'loss=', '0.000479276')
# ('Epoch:', '1527', 'training time (minutes)=', '2.0113', 'loss=', '0.000473327')
# ('Epoch:', '1528', 'training time (minutes)=', '2.0045', 'loss=', '0.000480664')
# ('Epoch:', '1529', 'training time (minutes)=', '1.9952', 'loss=', '0.000469732')
# ('Epoch:', '1530', 'training time (minutes)=', '2.0473', 'loss=', '0.000473787')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1530 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1531', 'training time (minutes)=', '2.0166', 'loss=', '0.000479614')
# ('Epoch:', '1532', 'training time (minutes)=', '2.0355', 'loss=', '0.000471498')
# ('Epoch:', '1533', 'training time (minutes)=', '2.0367', 'loss=', '0.000470362')
# ('Epoch:', '1534', 'training time (minutes)=', '2.0254', 'loss=', '0.000481624')
# ('Epoch:', '1535', 'training time (minutes)=', '2.0032', 'loss=', '0.000479045')
# ('Epoch:', '1536', 'training time (minutes)=', '2.0435', 'loss=', '0.000464735')
# ('Epoch:', '1537', 'training time (minutes)=', '2.0773', 'loss=', '0.000470823')
# ('Epoch:', '1538', 'training time (minutes)=', '2.0507', 'loss=', '0.000471995')
# ('Epoch:', '1539', 'training time (minutes)=', '2.0529', 'loss=', '0.000469345')
# ('Epoch:', '1540', 'training time (minutes)=', '2.0536', 'loss=', '0.000483899')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1540 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1541', 'training time (minutes)=', '2.0489', 'loss=', '0.000466683')
# ('Epoch:', '1542', 'training time (minutes)=', '2.0525', 'loss=', '0.000465243')
# ('Epoch:', '1543', 'training time (minutes)=', '2.0453', 'loss=', '0.000472923')
# ('Epoch:', '1544', 'training time (minutes)=', '2.1029', 'loss=', '0.000472208')
# ('Epoch:', '1545', 'training time (minutes)=', '2.1450', 'loss=', '0.000475078')
# ('Epoch:', '1546', 'training time (minutes)=', '2.1459', 'loss=', '0.000476162')
# ('Epoch:', '1547', 'training time (minutes)=', '2.0910', 'loss=', '0.000474918')
# ('Epoch:', '1548', 'training time (minutes)=', '2.0980', 'loss=', '0.000479712')
# ('Epoch:', '1549', 'training time (minutes)=', '2.0559', 'loss=', '0.000464443')
# ('Epoch:', '1550', 'training time (minutes)=', '2.1016', 'loss=', '0.000472473')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1550 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1551', 'training time (minutes)=', '2.0828', 'loss=', '0.000477132')
# ('Epoch:', '1552', 'training time (minutes)=', '2.0680', 'loss=', '0.000474205')
# ('Epoch:', '1553', 'training time (minutes)=', '2.0625', 'loss=', '0.000477161')
# ('Epoch:', '1554', 'training time (minutes)=', '2.0568', 'loss=', '0.000469024')
# ('Epoch:', '1555', 'training time (minutes)=', '2.0352', 'loss=', '0.000476421')
# ('Epoch:', '1556', 'training time (minutes)=', '2.0670', 'loss=', '0.000474413')
# ('Epoch:', '1557', 'training time (minutes)=', '2.0568', 'loss=', '0.000467230')
# ('Epoch:', '1558', 'training time (minutes)=', '2.0559', 'loss=', '0.000471207')
# ('Epoch:', '1559', 'training time (minutes)=', '2.0567', 'loss=', '0.000478129')
# ('Epoch:', '1560', 'training time (minutes)=', '2.0636', 'loss=', '0.000476457')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1560 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1561', 'training time (minutes)=', '2.0683', 'loss=', '0.000473248')
# ('Epoch:', '1562', 'training time (minutes)=', '2.0555', 'loss=', '0.000479627')
# ('Epoch:', '1563', 'training time (minutes)=', '2.0444', 'loss=', '0.000475973')
# ('Epoch:', '1564', 'training time (minutes)=', '2.0604', 'loss=', '0.000475651')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d32b23b54e3c> in <module>()
#       2     buf_size = 1 # flush each line
#       3     fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
# ----> 4     train_stats = ae.train(train_data, conf, log_file=fout)
#       5     fout.close()
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in train(self, train_data, configuration, log_file, held_out_data)
#     184
#     185         for _ in xrange(c.training_epochs):
# --> 186             loss, duration = self._single_epoch_train(train_data, c)
#     187             epoch = int(self.sess.run(self.epoch.assign_add(tf.constant(1.0))))
#     188             stats.append((epoch, loss, duration))
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/point_net_ae.pyc in _single_epoch_train(self, train_data, configuration, only_fw)
#     145                 _, loss = fit(batch_i, original_data)
#     146             else:
# --> 147                 _, loss = fit(batch_i)
#     148
#     149             # Compute average loss
#
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/autoencoder.pyc in partial_fit(self, X, GT)
#     132                 _, loss, recon = self.sess.run((self.train_step, self.loss, self.x_reconstr), feed_dict={self.x: X, self.gt: GT})
#     133             else:
# --> 134                 _, loss, recon = self.sess.run((self.train_step, self.loss, self.x_reconstr), feed_dict={self.x: X})
#     135
#     136             is_training(False, session=self.sess)
#
# /orions4-zfs/projects/lins2/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /orions4-zfs/projects/lins2/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /orions4-zfs/projects/lins2/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /orions4-zfs/projects/lins2/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /orions4-zfs/projects/lins2/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
