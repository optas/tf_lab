# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 1
setup_one_gpu(GPU)
# Out:
# Picking GPU 1

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs

from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry, decoder_with_fc_only
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tf_lab.iclr.helper import load_multiple_version_of_pcs

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = True
load_model = False
seed = 42
max_training_epochs = 2000
loss = 'chamfer'
z_rotate = True
experiment_name = 'all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code' + str(n_pc_samples) +  'pts_' + loss

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'

# %%
n_threads = 25
verbose = True
version = 'centered'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', version, str(n_pc_samples))
full_file_names = [f for f in files_in_subdirs(full_pclouds_path, '.ply')]
pclouds, _, _ = load_point_clouds_from_filenames(full_file_names, n_threads, snc_loader, verbose)
train_data = PointCloudDataSet(pclouds)
print train_data.num_examples
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:38: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')
# 57449 pclouds were loaded. They belong in 57 shape-classes.
# 57449

# %%
train_dir = osp.join('/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc', experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer'

# %%
n_input = [n_pc_samples, 3]

encoder_args = {'n_filters': [64, 128, 128, 256, 512],
                'filter_sizes': [1, 1, 1, 1, 1],
                'strides': [1, 1, 1, 1, 1],
                'b_norm': True
               }

decoder_args = {'layer_sizes': [512, 1024, np.prod(n_input)],
                'b_norm': False
               }

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = decoder_with_fc_only,
                decoder_args = decoder_args,            
               )
    conf.allow_gpu_growth = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/encoders_decoders.py:95: UserWarning: Using old architecture.
#   warnings.warn('Using old architecture.')

# %%
if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)
        
if load_model and do_training:
    conf.training_epochs -= last_epoch
    print conf.training_epochs

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)    
    train_stats = ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.8957', 'loss=', '0.003140577')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '2.0118', 'loss=', '0.001510645')
# ('Epoch:', '0003', 'training time (minutes)=', '2.0259', 'loss=', '0.001320519')
# ('Epoch:', '0004', 'training time (minutes)=', '2.0573', 'loss=', '0.001276196')
# ('Epoch:', '0005', 'training time (minutes)=', '2.0433', 'loss=', '0.001185598')
# ('Epoch:', '0006', 'training time (minutes)=', '1.9936', 'loss=', '0.001147591')
# ('Epoch:', '0007', 'training time (minutes)=', '2.0358', 'loss=', '0.001079893')
# ('Epoch:', '0008', 'training time (minutes)=', '2.0077', 'loss=', '0.001062443')
# ('Epoch:', '0009', 'training time (minutes)=', '2.0534', 'loss=', '0.001030205')
# ('Epoch:', '0010', 'training time (minutes)=', '1.9880', 'loss=', '0.000974104')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '2.0040', 'loss=', '0.000952661')
# ('Epoch:', '0012', 'training time (minutes)=', '2.0245', 'loss=', '0.000925649')
# ('Epoch:', '0013', 'training time (minutes)=', '2.0224', 'loss=', '0.000900051')
# ('Epoch:', '0014', 'training time (minutes)=', '2.0011', 'loss=', '0.000893605')
# ('Epoch:', '0015', 'training time (minutes)=', '1.9674', 'loss=', '0.000891380')
# ('Epoch:', '0016', 'training time (minutes)=', '2.0237', 'loss=', '0.000872946')
# ('Epoch:', '0017', 'training time (minutes)=', '2.0093', 'loss=', '0.000872195')
# ('Epoch:', '0018', 'training time (minutes)=', '2.0289', 'loss=', '0.000826105')
# ('Epoch:', '0019', 'training time (minutes)=', '2.0059', 'loss=', '0.000809694')
# ('Epoch:', '0020', 'training time (minutes)=', '2.0222', 'loss=', '0.000813623')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '2.0129', 'loss=', '0.000821047')
# ('Epoch:', '0022', 'training time (minutes)=', '2.0077', 'loss=', '0.000779454')
# ('Epoch:', '0023', 'training time (minutes)=', '2.0675', 'loss=', '0.000789590')
# ('Epoch:', '0024', 'training time (minutes)=', '2.0205', 'loss=', '0.000780135')
# ('Epoch:', '0025', 'training time (minutes)=', '2.0295', 'loss=', '0.000741270')
# ('Epoch:', '0026', 'training time (minutes)=', '2.0216', 'loss=', '0.000759651')
# ('Epoch:', '0027', 'training time (minutes)=', '1.9900', 'loss=', '0.000748507')
# ('Epoch:', '0028', 'training time (minutes)=', '2.0299', 'loss=', '0.000734153')
# ('Epoch:', '0029', 'training time (minutes)=', '2.0243', 'loss=', '0.000732042')
# ('Epoch:', '0030', 'training time (minutes)=', '2.0719', 'loss=', '0.000726146')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '2.0568', 'loss=', '0.000718081')
# ('Epoch:', '0032', 'training time (minutes)=', '2.0429', 'loss=', '0.000702708')
# ('Epoch:', '0033', 'training time (minutes)=', '2.0944', 'loss=', '0.000711272')
# ('Epoch:', '0034', 'training time (minutes)=', '2.0264', 'loss=', '0.000707263')
# ('Epoch:', '0035', 'training time (minutes)=', '2.0474', 'loss=', '0.000703659')
# ('Epoch:', '0036', 'training time (minutes)=', '2.0620', 'loss=', '0.000697415')
# ('Epoch:', '0037', 'training time (minutes)=', '2.0872', 'loss=', '0.000690437')
# ('Epoch:', '0038', 'training time (minutes)=', '2.0422', 'loss=', '0.000677492')
# ('Epoch:', '0039', 'training time (minutes)=', '2.0384', 'loss=', '0.000690044')
# ('Epoch:', '0040', 'training time (minutes)=', '2.0965', 'loss=', '0.000678242')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '2.0267', 'loss=', '0.000674924')
# ('Epoch:', '0042', 'training time (minutes)=', '2.0422', 'loss=', '0.000678733')
# ('Epoch:', '0043', 'training time (minutes)=', '2.0199', 'loss=', '0.000661336')
# ('Epoch:', '0044', 'training time (minutes)=', '2.0289', 'loss=', '0.000659450')
# ('Epoch:', '0045', 'training time (minutes)=', '2.0708', 'loss=', '0.000657996')
# ('Epoch:', '0046', 'training time (minutes)=', '2.0910', 'loss=', '0.000661226')
# ('Epoch:', '0047', 'training time (minutes)=', '2.0350', 'loss=', '0.000659350')
# ('Epoch:', '0048', 'training time (minutes)=', '2.0538', 'loss=', '0.000641631')
# ('Epoch:', '0049', 'training time (minutes)=', '2.0255', 'loss=', '0.000648357')
# ('Epoch:', '0050', 'training time (minutes)=', '2.0761', 'loss=', '0.000633099')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '2.0536', 'loss=', '0.000640840')
# ('Epoch:', '0052', 'training time (minutes)=', '2.0110', 'loss=', '0.000643756')
# ('Epoch:', '0053', 'training time (minutes)=', '2.0960', 'loss=', '0.000636067')
# ('Epoch:', '0054', 'training time (minutes)=', '2.0961', 'loss=', '0.000638008')
# ('Epoch:', '0055', 'training time (minutes)=', '2.0525', 'loss=', '0.000636317')
# ('Epoch:', '0056', 'training time (minutes)=', '2.0038', 'loss=', '0.000622729')
# ('Epoch:', '0057', 'training time (minutes)=', '2.0425', 'loss=', '0.000635474')
# ('Epoch:', '0058', 'training time (minutes)=', '2.0799', 'loss=', '0.000628610')
# ('Epoch:', '0059', 'training time (minutes)=', '2.0669', 'loss=', '0.000624797')
# ('Epoch:', '0060', 'training time (minutes)=', '2.0284', 'loss=', '0.000612413')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '2.0172', 'loss=', '0.000617917')
# ('Epoch:', '0062', 'training time (minutes)=', '2.0394', 'loss=', '0.000620073')
# ('Epoch:', '0063', 'training time (minutes)=', '2.0628', 'loss=', '0.000617438')
# ('Epoch:', '0064', 'training time (minutes)=', '2.0100', 'loss=', '0.000606017')
# ('Epoch:', '0065', 'training time (minutes)=', '2.0233', 'loss=', '0.000607201')
# ('Epoch:', '0066', 'training time (minutes)=', '2.0075', 'loss=', '0.000607374')
# ('Epoch:', '0067', 'training time (minutes)=', '2.0944', 'loss=', '0.000608666')
# ('Epoch:', '0068', 'training time (minutes)=', '2.0496', 'loss=', '0.000614768')
# ('Epoch:', '0069', 'training time (minutes)=', '2.0400', 'loss=', '0.000598169')
# ('Epoch:', '0070', 'training time (minutes)=', '2.0704', 'loss=', '0.000602992')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '2.0362', 'loss=', '0.000602972')
# ('Epoch:', '0072', 'training time (minutes)=', '2.0924', 'loss=', '0.000598010')
# ('Epoch:', '0073', 'training time (minutes)=', '2.0493', 'loss=', '0.000606582')
# ('Epoch:', '0074', 'training time (minutes)=', '2.0900', 'loss=', '0.000613947')
# ('Epoch:', '0075', 'training time (minutes)=', '2.1085', 'loss=', '0.000605337')
# ('Epoch:', '0076', 'training time (minutes)=', '2.0131', 'loss=', '0.000589014')
# ('Epoch:', '0077', 'training time (minutes)=', '2.0795', 'loss=', '0.000587447')
# ('Epoch:', '0078', 'training time (minutes)=', '2.0486', 'loss=', '0.000600522')
# ('Epoch:', '0079', 'training time (minutes)=', '2.0484', 'loss=', '0.000590183')
# ('Epoch:', '0080', 'training time (minutes)=', '2.0838', 'loss=', '0.000592995')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '2.0603', 'loss=', '0.000588381')
# ('Epoch:', '0082', 'training time (minutes)=', '2.1209', 'loss=', '0.000590512')
# ('Epoch:', '0083', 'training time (minutes)=', '2.0850', 'loss=', '0.000580621')
# ('Epoch:', '0084', 'training time (minutes)=', '2.0204', 'loss=', '0.000594378')
# ('Epoch:', '0085', 'training time (minutes)=', '2.0808', 'loss=', '0.000586121')
# ('Epoch:', '0086', 'training time (minutes)=', '2.0440', 'loss=', '0.000593174')
# ('Epoch:', '0087', 'training time (minutes)=', '2.0278', 'loss=', '0.000587424')
# ('Epoch:', '0088', 'training time (minutes)=', '2.0928', 'loss=', '0.000585274')
# ('Epoch:', '0089', 'training time (minutes)=', '2.0084', 'loss=', '0.000581334')
# ('Epoch:', '0090', 'training time (minutes)=', '2.0541', 'loss=', '0.000582638')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '2.0612', 'loss=', '0.000578780')
# ('Epoch:', '0092', 'training time (minutes)=', '2.0823', 'loss=', '0.000581917')
# ('Epoch:', '0093', 'training time (minutes)=', '2.1115', 'loss=', '0.000585026')
# ('Epoch:', '0094', 'training time (minutes)=', '2.0972', 'loss=', '0.000578900')
# ('Epoch:', '0095', 'training time (minutes)=', '2.0592', 'loss=', '0.000579559')
# ('Epoch:', '0096', 'training time (minutes)=', '2.1318', 'loss=', '0.000587547')
# ('Epoch:', '0097', 'training time (minutes)=', '2.0469', 'loss=', '0.000570933')
# ('Epoch:', '0098', 'training time (minutes)=', '2.0990', 'loss=', '0.000589235')
# ('Epoch:', '0099', 'training time (minutes)=', '2.1204', 'loss=', '0.000569348')
# ('Epoch:', '0100', 'training time (minutes)=', '2.0527', 'loss=', '0.000577832')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '2.0984', 'loss=', '0.000573269')
# ('Epoch:', '0102', 'training time (minutes)=', '2.0980', 'loss=', '0.000576458')
# ('Epoch:', '0103', 'training time (minutes)=', '2.0711', 'loss=', '0.000578646')
# ('Epoch:', '0104', 'training time (minutes)=', '2.0772', 'loss=', '0.000571128')
# ('Epoch:', '0105', 'training time (minutes)=', '2.0474', 'loss=', '0.000570665')
# ('Epoch:', '0106', 'training time (minutes)=', '2.0445', 'loss=', '0.000563901')
# ('Epoch:', '0107', 'training time (minutes)=', '2.0223', 'loss=', '0.000567903')
# ('Epoch:', '0108', 'training time (minutes)=', '2.0684', 'loss=', '0.000563501')
# ('Epoch:', '0109', 'training time (minutes)=', '2.0657', 'loss=', '0.000567145')
# ('Epoch:', '0110', 'training time (minutes)=', '2.0607', 'loss=', '0.000570892')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '2.0519', 'loss=', '0.000564437')
# ('Epoch:', '0112', 'training time (minutes)=', '2.0468', 'loss=', '0.000566137')
# ('Epoch:', '0113', 'training time (minutes)=', '2.1051', 'loss=', '0.000565603')
# ('Epoch:', '0114', 'training time (minutes)=', '2.0711', 'loss=', '0.000574006')
# ('Epoch:', '0115', 'training time (minutes)=', '2.1315', 'loss=', '0.000564776')
# ('Epoch:', '0116', 'training time (minutes)=', '2.0473', 'loss=', '0.000561158')
# ('Epoch:', '0117', 'training time (minutes)=', '2.0758', 'loss=', '0.000557108')
# ('Epoch:', '0118', 'training time (minutes)=', '2.0628', 'loss=', '0.000558403')
# ('Epoch:', '0119', 'training time (minutes)=', '2.0662', 'loss=', '0.000563233')
# ('Epoch:', '0120', 'training time (minutes)=', '2.1161', 'loss=', '0.000554271')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '2.1018', 'loss=', '0.000568920')
# ('Epoch:', '0122', 'training time (minutes)=', '2.0403', 'loss=', '0.000564678')
# ('Epoch:', '0123', 'training time (minutes)=', '2.0476', 'loss=', '0.000556376')
# ('Epoch:', '0124', 'training time (minutes)=', '2.0987', 'loss=', '0.000561832')
# ('Epoch:', '0125', 'training time (minutes)=', '2.0608', 'loss=', '0.000555572')
# ('Epoch:', '0126', 'training time (minutes)=', '2.0867', 'loss=', '0.000568179')
# ('Epoch:', '0127', 'training time (minutes)=', '2.1187', 'loss=', '0.000564338')
# ('Epoch:', '0128', 'training time (minutes)=', '2.1862', 'loss=', '0.000561625')
# ('Epoch:', '0129', 'training time (minutes)=', '2.0506', 'loss=', '0.000545324')
# ('Epoch:', '0130', 'training time (minutes)=', '2.0564', 'loss=', '0.000553255')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '2.0694', 'loss=', '0.000541196')
# ('Epoch:', '0132', 'training time (minutes)=', '2.0629', 'loss=', '0.000557753')
# ('Epoch:', '0133', 'training time (minutes)=', '2.0977', 'loss=', '0.000557509')
# ('Epoch:', '0134', 'training time (minutes)=', '2.0695', 'loss=', '0.000554444')
# ('Epoch:', '0135', 'training time (minutes)=', '2.0530', 'loss=', '0.000569371')
# ('Epoch:', '0136', 'training time (minutes)=', '2.0538', 'loss=', '0.000543251')
# ('Epoch:', '0137', 'training time (minutes)=', '2.0115', 'loss=', '0.000557983')
# ('Epoch:', '0138', 'training time (minutes)=', '2.0037', 'loss=', '0.000557349')
# ('Epoch:', '0139', 'training time (minutes)=', '2.0390', 'loss=', '0.000554007')
# ('Epoch:', '0140', 'training time (minutes)=', '2.0623', 'loss=', '0.000548833')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '2.0911', 'loss=', '0.000548776')
# ('Epoch:', '0142', 'training time (minutes)=', '2.0107', 'loss=', '0.000554970')
# ('Epoch:', '0143', 'training time (minutes)=', '2.0402', 'loss=', '0.000550257')
# ('Epoch:', '0144', 'training time (minutes)=', '2.0495', 'loss=', '0.000548790')
# ('Epoch:', '0145', 'training time (minutes)=', '2.0787', 'loss=', '0.000552226')
# ('Epoch:', '0146', 'training time (minutes)=', '2.0736', 'loss=', '0.000535798')
# ('Epoch:', '0147', 'training time (minutes)=', '2.0058', 'loss=', '0.000551874')
# ('Epoch:', '0148', 'training time (minutes)=', '2.0112', 'loss=', '0.000552065')
# ('Epoch:', '0149', 'training time (minutes)=', '2.0433', 'loss=', '0.000543100')
# ('Epoch:', '0150', 'training time (minutes)=', '2.0254', 'loss=', '0.000549582')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '2.0267', 'loss=', '0.000549186')
# ('Epoch:', '0152', 'training time (minutes)=', '1.9956', 'loss=', '0.000544283')
# ('Epoch:', '0153', 'training time (minutes)=', '2.0657', 'loss=', '0.000548717')
# ('Epoch:', '0154', 'training time (minutes)=', '2.0653', 'loss=', '0.000545360')
# ('Epoch:', '0155', 'training time (minutes)=', '2.0179', 'loss=', '0.000536664')
# ('Epoch:', '0156', 'training time (minutes)=', '2.0563', 'loss=', '0.000547020')
# ('Epoch:', '0157', 'training time (minutes)=', '2.0008', 'loss=', '0.000542774')
# ('Epoch:', '0158', 'training time (minutes)=', '2.0698', 'loss=', '0.000545288')
# ('Epoch:', '0159', 'training time (minutes)=', '2.0446', 'loss=', '0.000545660')
# ('Epoch:', '0160', 'training time (minutes)=', '2.0110', 'loss=', '0.000545557')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '2.0091', 'loss=', '0.000542512')
# ('Epoch:', '0162', 'training time (minutes)=', '2.0220', 'loss=', '0.000546809')
# ('Epoch:', '0163', 'training time (minutes)=', '2.0931', 'loss=', '0.000550078')
# ('Epoch:', '0164', 'training time (minutes)=', '2.0157', 'loss=', '0.000536423')
# ('Epoch:', '0165', 'training time (minutes)=', '2.0186', 'loss=', '0.000536044')
# ('Epoch:', '0166', 'training time (minutes)=', '2.0428', 'loss=', '0.000542608')
# ('Epoch:', '0167', 'training time (minutes)=', '2.1028', 'loss=', '0.000547159')
# ('Epoch:', '0168', 'training time (minutes)=', '1.9898', 'loss=', '0.000539878')
# ('Epoch:', '0169', 'training time (minutes)=', '2.0299', 'loss=', '0.000538071')
# ('Epoch:', '0170', 'training time (minutes)=', '2.0771', 'loss=', '0.000534352')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '2.1555', 'loss=', '0.000541908')
# ('Epoch:', '0172', 'training time (minutes)=', '2.0957', 'loss=', '0.000549047')
# ('Epoch:', '0173', 'training time (minutes)=', '2.0780', 'loss=', '0.000540599')
# ('Epoch:', '0174', 'training time (minutes)=', '2.1125', 'loss=', '0.000538761')
# ('Epoch:', '0175', 'training time (minutes)=', '2.0569', 'loss=', '0.000548620')
# ('Epoch:', '0176', 'training time (minutes)=', '2.1215', 'loss=', '0.000533775')
# ('Epoch:', '0177', 'training time (minutes)=', '2.0562', 'loss=', '0.000539034')
# ('Epoch:', '0178', 'training time (minutes)=', '2.0770', 'loss=', '0.000550834')
# ('Epoch:', '0179', 'training time (minutes)=', '2.1200', 'loss=', '0.000544652')
# ('Epoch:', '0180', 'training time (minutes)=', '2.1610', 'loss=', '0.000538037')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '2.1129', 'loss=', '0.000534742')
# ('Epoch:', '0182', 'training time (minutes)=', '2.1591', 'loss=', '0.000543815')
# ('Epoch:', '0183', 'training time (minutes)=', '2.1337', 'loss=', '0.000528193')
# ('Epoch:', '0184', 'training time (minutes)=', '2.0658', 'loss=', '0.000541848')
# ('Epoch:', '0185', 'training time (minutes)=', '2.0831', 'loss=', '0.000543325')
# ('Epoch:', '0186', 'training time (minutes)=', '2.1067', 'loss=', '0.000534887')
# ('Epoch:', '0187', 'training time (minutes)=', '2.1273', 'loss=', '0.000534601')
# ('Epoch:', '0188', 'training time (minutes)=', '2.1704', 'loss=', '0.000535009')
# ('Epoch:', '0189', 'training time (minutes)=', '2.1212', 'loss=', '0.000533405')
# ('Epoch:', '0190', 'training time (minutes)=', '2.1636', 'loss=', '0.000537726')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '2.1134', 'loss=', '0.000539415')
# ('Epoch:', '0192', 'training time (minutes)=', '2.1360', 'loss=', '0.000528332')
# ('Epoch:', '0193', 'training time (minutes)=', '2.1262', 'loss=', '0.000534910')
# ('Epoch:', '0194', 'training time (minutes)=', '2.1359', 'loss=', '0.000541715')
# ('Epoch:', '0195', 'training time (minutes)=', '2.0646', 'loss=', '0.000529114')
# ('Epoch:', '0196', 'training time (minutes)=', '2.1989', 'loss=', '0.000544772')
# ('Epoch:', '0197', 'training time (minutes)=', '2.1682', 'loss=', '0.000529737')
# ('Epoch:', '0198', 'training time (minutes)=', '2.1490', 'loss=', '0.000530879')
# ('Epoch:', '0199', 'training time (minutes)=', '2.1129', 'loss=', '0.000532802')
# ('Epoch:', '0200', 'training time (minutes)=', '2.1276', 'loss=', '0.000536056')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '2.1207', 'loss=', '0.000530213')
# ('Epoch:', '0202', 'training time (minutes)=', '2.1443', 'loss=', '0.000540030')
# ('Epoch:', '0203', 'training time (minutes)=', '2.1019', 'loss=', '0.000535682')
# ('Epoch:', '0204', 'training time (minutes)=', '2.0716', 'loss=', '0.000529424')
# ('Epoch:', '0205', 'training time (minutes)=', '2.1646', 'loss=', '0.000525313')
# ('Epoch:', '0206', 'training time (minutes)=', '2.1199', 'loss=', '0.000533275')
# ('Epoch:', '0207', 'training time (minutes)=', '2.1334', 'loss=', '0.000541397')
# ('Epoch:', '0208', 'training time (minutes)=', '2.1512', 'loss=', '0.000533767')
# ('Epoch:', '0209', 'training time (minutes)=', '2.1571', 'loss=', '0.000541800')
# ('Epoch:', '0210', 'training time (minutes)=', '2.0844', 'loss=', '0.000532237')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '2.1148', 'loss=', '0.000534861')
# ('Epoch:', '0212', 'training time (minutes)=', '2.1201', 'loss=', '0.000530003')
# ('Epoch:', '0213', 'training time (minutes)=', '2.1140', 'loss=', '0.000531539')
# ('Epoch:', '0214', 'training time (minutes)=', '2.0445', 'loss=', '0.000530958')
# ('Epoch:', '0215', 'training time (minutes)=', '2.0375', 'loss=', '0.000536290')
# ('Epoch:', '0216', 'training time (minutes)=', '2.0201', 'loss=', '0.000530798')
# ('Epoch:', '0217', 'training time (minutes)=', '2.0464', 'loss=', '0.000527120')
# ('Epoch:', '0218', 'training time (minutes)=', '2.0035', 'loss=', '0.000528751')
# ('Epoch:', '0219', 'training time (minutes)=', '2.0368', 'loss=', '0.000531886')
# ('Epoch:', '0220', 'training time (minutes)=', '2.0398', 'loss=', '0.000531013')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '2.0831', 'loss=', '0.000526884')
# ('Epoch:', '0222', 'training time (minutes)=', '2.0280', 'loss=', '0.000526669')
# ('Epoch:', '0223', 'training time (minutes)=', '2.0218', 'loss=', '0.000516075')
# ('Epoch:', '0224', 'training time (minutes)=', '2.0549', 'loss=', '0.000526630')
# ('Epoch:', '0225', 'training time (minutes)=', '2.0212', 'loss=', '0.000528749')
# ('Epoch:', '0226', 'training time (minutes)=', '2.0406', 'loss=', '0.000534111')
# ('Epoch:', '0227', 'training time (minutes)=', '2.0484', 'loss=', '0.000530842')
# ('Epoch:', '0228', 'training time (minutes)=', '2.0365', 'loss=', '0.000520546')
# ('Epoch:', '0229', 'training time (minutes)=', '2.0137', 'loss=', '0.000523532')
# ('Epoch:', '0230', 'training time (minutes)=', '2.0109', 'loss=', '0.000531169')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '2.0057', 'loss=', '0.000536635')
# ('Epoch:', '0232', 'training time (minutes)=', '2.0285', 'loss=', '0.000527082')
# ('Epoch:', '0233', 'training time (minutes)=', '2.0823', 'loss=', '0.000523294')
# ('Epoch:', '0234', 'training time (minutes)=', '2.0214', 'loss=', '0.000519905')
# ('Epoch:', '0235', 'training time (minutes)=', '2.0760', 'loss=', '0.000525938')
# ('Epoch:', '0236', 'training time (minutes)=', '2.0390', 'loss=', '0.000530044')
# ('Epoch:', '0237', 'training time (minutes)=', '2.1187', 'loss=', '0.000518627')
# ('Epoch:', '0238', 'training time (minutes)=', '2.0501', 'loss=', '0.000522180')
# ('Epoch:', '0239', 'training time (minutes)=', '2.0130', 'loss=', '0.000532425')
# ('Epoch:', '0240', 'training time (minutes)=', '2.1166', 'loss=', '0.000526603')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '2.1126', 'loss=', '0.000524722')
# ('Epoch:', '0242', 'training time (minutes)=', '2.0741', 'loss=', '0.000520034')
# ('Epoch:', '0243', 'training time (minutes)=', '2.0861', 'loss=', '0.000520988')
# ('Epoch:', '0244', 'training time (minutes)=', '2.0324', 'loss=', '0.000518645')
# ('Epoch:', '0245', 'training time (minutes)=', '2.1032', 'loss=', '0.000528660')
# ('Epoch:', '0246', 'training time (minutes)=', '2.0880', 'loss=', '0.000515510')
# ('Epoch:', '0247', 'training time (minutes)=', '2.0485', 'loss=', '0.000525181')
# ('Epoch:', '0248', 'training time (minutes)=', '2.0739', 'loss=', '0.000526707')
# ('Epoch:', '0249', 'training time (minutes)=', '2.0022', 'loss=', '0.000519688')
# ('Epoch:', '0250', 'training time (minutes)=', '2.1031', 'loss=', '0.000525671')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '2.0904', 'loss=', '0.000515225')
# ('Epoch:', '0252', 'training time (minutes)=', '2.0986', 'loss=', '0.000527727')
# ('Epoch:', '0253', 'training time (minutes)=', '2.1217', 'loss=', '0.000515600')
# ('Epoch:', '0254', 'training time (minutes)=', '2.0200', 'loss=', '0.000512678')
# ('Epoch:', '0255', 'training time (minutes)=', '2.1207', 'loss=', '0.000520905')
# ('Epoch:', '0256', 'training time (minutes)=', '2.0623', 'loss=', '0.000519237')
# ('Epoch:', '0257', 'training time (minutes)=', '2.0693', 'loss=', '0.000515809')
# ('Epoch:', '0258', 'training time (minutes)=', '2.1075', 'loss=', '0.000523347')
# ('Epoch:', '0259', 'training time (minutes)=', '2.0985', 'loss=', '0.000514825')
# ('Epoch:', '0260', 'training time (minutes)=', '1.9876', 'loss=', '0.000522276')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '2.0269', 'loss=', '0.000519621')
# ('Epoch:', '0262', 'training time (minutes)=', '2.0192', 'loss=', '0.000502830')
# ('Epoch:', '0263', 'training time (minutes)=', '2.0404', 'loss=', '0.000520335')
# ('Epoch:', '0264', 'training time (minutes)=', '2.0641', 'loss=', '0.000518444')
# ('Epoch:', '0265', 'training time (minutes)=', '2.0155', 'loss=', '0.000521202')
# ('Epoch:', '0266', 'training time (minutes)=', '2.0127', 'loss=', '0.000522133')
# ('Epoch:', '0267', 'training time (minutes)=', '2.0009', 'loss=', '0.000519088')
# ('Epoch:', '0268', 'training time (minutes)=', '2.0246', 'loss=', '0.000514280')
# ('Epoch:', '0269', 'training time (minutes)=', '1.9843', 'loss=', '0.000514621')
# ('Epoch:', '0270', 'training time (minutes)=', '2.0043', 'loss=', '0.000523633')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '1.9778', 'loss=', '0.000521973')
# ('Epoch:', '0272', 'training time (minutes)=', '2.0115', 'loss=', '0.000516505')
# ('Epoch:', '0273', 'training time (minutes)=', '2.0457', 'loss=', '0.000518737')
# ('Epoch:', '0274', 'training time (minutes)=', '1.9872', 'loss=', '0.000516307')
# ('Epoch:', '0275', 'training time (minutes)=', '2.0945', 'loss=', '0.000520232')
# ('Epoch:', '0276', 'training time (minutes)=', '2.0760', 'loss=', '0.000521128')
# ('Epoch:', '0277', 'training time (minutes)=', '2.0832', 'loss=', '0.000517235')
# ('Epoch:', '0278', 'training time (minutes)=', '1.9908', 'loss=', '0.000519567')
# ('Epoch:', '0279', 'training time (minutes)=', '2.0317', 'loss=', '0.000515550')
# ('Epoch:', '0280', 'training time (minutes)=', '2.0040', 'loss=', '0.000519104')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '1.9886', 'loss=', '0.000514514')
# ('Epoch:', '0282', 'training time (minutes)=', '2.0582', 'loss=', '0.000526390')
# ('Epoch:', '0283', 'training time (minutes)=', '2.0063', 'loss=', '0.000509229')
# ('Epoch:', '0284', 'training time (minutes)=', '2.0412', 'loss=', '0.000519174')
# ('Epoch:', '0285', 'training time (minutes)=', '2.0105', 'loss=', '0.000510493')
# ('Epoch:', '0286', 'training time (minutes)=', '1.9911', 'loss=', '0.000522255')
# ('Epoch:', '0287', 'training time (minutes)=', '1.9666', 'loss=', '0.000514595')
# ('Epoch:', '0288', 'training time (minutes)=', '1.9761', 'loss=', '0.000510086')
# ('Epoch:', '0289', 'training time (minutes)=', '1.9762', 'loss=', '0.000517939')
# ('Epoch:', '0290', 'training time (minutes)=', '1.9996', 'loss=', '0.000502796')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '2.0214', 'loss=', '0.000516667')
# ('Epoch:', '0292', 'training time (minutes)=', '2.0097', 'loss=', '0.000513369')
# ('Epoch:', '0293', 'training time (minutes)=', '2.0006', 'loss=', '0.000507053')
# ('Epoch:', '0294', 'training time (minutes)=', '1.9937', 'loss=', '0.000500877')
# ('Epoch:', '0295', 'training time (minutes)=', '2.0100', 'loss=', '0.000504964')
# ('Epoch:', '0296', 'training time (minutes)=', '1.9844', 'loss=', '0.000523992')
# ('Epoch:', '0297', 'training time (minutes)=', '1.9876', 'loss=', '0.000512829')
# ('Epoch:', '0298', 'training time (minutes)=', '2.0114', 'loss=', '0.000523198')
# ('Epoch:', '0299', 'training time (minutes)=', '1.9934', 'loss=', '0.000514130')
# ('Epoch:', '0300', 'training time (minutes)=', '2.0247', 'loss=', '0.000509715')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '2.0335', 'loss=', '0.000524711')
# ('Epoch:', '0302', 'training time (minutes)=', '1.9701', 'loss=', '0.000516384')
# ('Epoch:', '0303', 'training time (minutes)=', '1.9881', 'loss=', '0.000514693')
# ('Epoch:', '0304', 'training time (minutes)=', '1.9464', 'loss=', '0.000512594')
# ('Epoch:', '0305', 'training time (minutes)=', '1.9683', 'loss=', '0.000511417')
# ('Epoch:', '0306', 'training time (minutes)=', '1.9856', 'loss=', '0.000509470')
# ('Epoch:', '0307', 'training time (minutes)=', '1.9884', 'loss=', '0.000508415')
# ('Epoch:', '0308', 'training time (minutes)=', '1.9526', 'loss=', '0.000512455')
# ('Epoch:', '0309', 'training time (minutes)=', '1.9662', 'loss=', '0.000508987')
# ('Epoch:', '0310', 'training time (minutes)=', '1.9877', 'loss=', '0.000531924')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '1.9830', 'loss=', '0.000504870')
# ('Epoch:', '0312', 'training time (minutes)=', '1.9803', 'loss=', '0.000504710')
# ('Epoch:', '0313', 'training time (minutes)=', '1.9709', 'loss=', '0.000519690')
# ('Epoch:', '0314', 'training time (minutes)=', '1.9530', 'loss=', '0.000515393')
# ('Epoch:', '0315', 'training time (minutes)=', '1.9955', 'loss=', '0.000514531')
# ('Epoch:', '0316', 'training time (minutes)=', '1.9722', 'loss=', '0.000518655')
# ('Epoch:', '0317', 'training time (minutes)=', '1.9717', 'loss=', '0.000508378')
# ('Epoch:', '0318', 'training time (minutes)=', '1.9837', 'loss=', '0.000513832')
# ('Epoch:', '0319', 'training time (minutes)=', '2.0005', 'loss=', '0.000507684')
# ('Epoch:', '0320', 'training time (minutes)=', '1.9835', 'loss=', '0.000515666')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '1.9422', 'loss=', '0.000508208')
# ('Epoch:', '0322', 'training time (minutes)=', '1.9609', 'loss=', '0.000505764')
# ('Epoch:', '0323', 'training time (minutes)=', '2.0007', 'loss=', '0.000512349')
# ('Epoch:', '0324', 'training time (minutes)=', '2.1469', 'loss=', '0.000520364')
# ('Epoch:', '0325', 'training time (minutes)=', '2.0330', 'loss=', '0.000506455')
# ('Epoch:', '0326', 'training time (minutes)=', '2.0261', 'loss=', '0.000501698')
# ('Epoch:', '0327', 'training time (minutes)=', '2.0669', 'loss=', '0.000517952')
# ('Epoch:', '0328', 'training time (minutes)=', '1.9831', 'loss=', '0.000511962')
# ('Epoch:', '0329', 'training time (minutes)=', '2.0191', 'loss=', '0.000514597')
# ('Epoch:', '0330', 'training time (minutes)=', '1.9808', 'loss=', '0.000515165')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '2.0662', 'loss=', '0.000512397')
# ('Epoch:', '0332', 'training time (minutes)=', '2.0410', 'loss=', '0.000518835')
# ('Epoch:', '0333', 'training time (minutes)=', '2.0071', 'loss=', '0.000513461')
# ('Epoch:', '0334', 'training time (minutes)=', '2.0206', 'loss=', '0.000498782')
# ('Epoch:', '0335', 'training time (minutes)=', '1.9686', 'loss=', '0.000505401')
# ('Epoch:', '0336', 'training time (minutes)=', '2.0254', 'loss=', '0.000507066')
# ('Epoch:', '0337', 'training time (minutes)=', '2.0178', 'loss=', '0.000504066')
# ('Epoch:', '0338', 'training time (minutes)=', '2.0657', 'loss=', '0.000514025')
# ('Epoch:', '0339', 'training time (minutes)=', '2.0160', 'loss=', '0.000505551')
# ('Epoch:', '0340', 'training time (minutes)=', '2.0315', 'loss=', '0.000505842')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '2.0076', 'loss=', '0.000506900')
# ('Epoch:', '0342', 'training time (minutes)=', '2.0615', 'loss=', '0.000511882')
# ('Epoch:', '0343', 'training time (minutes)=', '2.0265', 'loss=', '0.000503815')
# ('Epoch:', '0344', 'training time (minutes)=', '2.0601', 'loss=', '0.000516270')
# ('Epoch:', '0345', 'training time (minutes)=', '2.0151', 'loss=', '0.000509704')
# ('Epoch:', '0346', 'training time (minutes)=', '2.0271', 'loss=', '0.000500918')
# ('Epoch:', '0347', 'training time (minutes)=', '2.0246', 'loss=', '0.000516968')
# ('Epoch:', '0348', 'training time (minutes)=', '2.0262', 'loss=', '0.000509162')
# ('Epoch:', '0349', 'training time (minutes)=', '2.0292', 'loss=', '0.000504480')
# ('Epoch:', '0350', 'training time (minutes)=', '1.9855', 'loss=', '0.000501683')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_bnorm_on_encoder_old_code2048pts_chamfer/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '2.0322', 'loss=', '0.000514095')
# ('Epoch:', '0352', 'training time (minutes)=', '2.0602', 'loss=', '0.000514369')
