# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 3
setup_one_gpu(GPU)
# Out:
# Picking GPU 3

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs

from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry_new, decoder_with_fc_only
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tf_lab.iclr.helper import load_multiple_version_of_pcs

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = True
load_model = False
seed = 42
max_training_epochs = 2000
loss = 'chamfer'
z_rotate = True
experiment_name = 'all_snc_rotated_deeper_wider_mlp_arch_1_pc' + str(n_pc_samples) +  'pts_' + loss

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'

# %%
n_threads = 25
verbose = True
version = 'centered'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', version, str(n_pc_samples))
full_file_names = [f for f in files_in_subdirs(full_pclouds_path, '.ply')]
pclouds, _, _ = load_point_clouds_from_filenames(full_file_names, n_threads, snc_loader, verbose)
train_data = PointCloudDataSet(pclouds)
print train_data.num_examples
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:38: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')
# 57449 pclouds were loaded. They belong in 57 shape-classes.
# 57449

# %%
train_dir = osp.join('/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc', experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer'

# %%
n_input = [n_pc_samples, 3]

encoder_args = {'n_filters': [64, 128, 128, 256, 512],
                'filter_sizes': [1, 1, 1, 1, 1],
                'strides': [1, 1, 1, 1, 1],
                'b_norm': False
               }

decoder_args = {'layer_sizes': [1024, 2048, np.prod(n_input)],
                'b_norm': False
               }

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = encoder_with_convs_and_symmetry_new,
                encoder_args = encoder_args,
                decoder = decoder_with_fc_only,
                decoder_args = decoder_args,            
               )
    conf.allow_gpu_growth = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)
        
if load_model and do_training:
    conf.training_epochs -= last_epoch
    print conf.training_epochs

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)    
    train_stats = ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.1430', 'loss=', '0.002615140')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '1.1636', 'loss=', '0.001233718')
# ('Epoch:', '0003', 'training time (minutes)=', '1.1837', 'loss=', '0.001000779')
# ('Epoch:', '0004', 'training time (minutes)=', '1.1865', 'loss=', '0.000859198')
# ('Epoch:', '0005', 'training time (minutes)=', '1.1854', 'loss=', '0.000822197')
# ('Epoch:', '0006', 'training time (minutes)=', '1.1826', 'loss=', '0.000787105')
# ('Epoch:', '0007', 'training time (minutes)=', '1.1800', 'loss=', '0.000754458')
# ('Epoch:', '0008', 'training time (minutes)=', '1.1780', 'loss=', '0.000727640')
# ('Epoch:', '0009', 'training time (minutes)=', '1.1777', 'loss=', '0.000682714')
# ('Epoch:', '0010', 'training time (minutes)=', '1.1842', 'loss=', '0.000684519')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '1.1871', 'loss=', '0.000653704')
# ('Epoch:', '0012', 'training time (minutes)=', '1.1862', 'loss=', '0.000645012')
# ('Epoch:', '0013', 'training time (minutes)=', '1.1883', 'loss=', '0.000639788')
# ('Epoch:', '0014', 'training time (minutes)=', '1.1862', 'loss=', '0.000618370')
# ('Epoch:', '0015', 'training time (minutes)=', '1.1864', 'loss=', '0.000619706')
# ('Epoch:', '0016', 'training time (minutes)=', '1.1791', 'loss=', '0.000593326')
# ('Epoch:', '0017', 'training time (minutes)=', '1.1804', 'loss=', '0.000611833')
# ('Epoch:', '0018', 'training time (minutes)=', '1.1762', 'loss=', '0.000584341')
# ('Epoch:', '0019', 'training time (minutes)=', '1.1763', 'loss=', '0.000583078')
# ('Epoch:', '0020', 'training time (minutes)=', '1.1812', 'loss=', '0.000567747')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '1.1800', 'loss=', '0.000573275')
# ('Epoch:', '0022', 'training time (minutes)=', '1.1809', 'loss=', '0.000578188')
# ('Epoch:', '0023', 'training time (minutes)=', '1.1866', 'loss=', '0.000558819')
# ('Epoch:', '0024', 'training time (minutes)=', '1.1783', 'loss=', '0.000549859')
# ('Epoch:', '0025', 'training time (minutes)=', '1.1759', 'loss=', '0.000558895')
# ('Epoch:', '0026', 'training time (minutes)=', '1.1534', 'loss=', '0.000548834')
# ('Epoch:', '0027', 'training time (minutes)=', '1.1540', 'loss=', '0.000543883')
# ('Epoch:', '0028', 'training time (minutes)=', '1.1592', 'loss=', '0.000543322')
# ('Epoch:', '0029', 'training time (minutes)=', '1.1534', 'loss=', '0.000534409')
# ('Epoch:', '0030', 'training time (minutes)=', '1.1585', 'loss=', '0.000538315')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '1.1568', 'loss=', '0.000518814')
# ('Epoch:', '0032', 'training time (minutes)=', '1.1572', 'loss=', '0.000521648')
# ('Epoch:', '0033', 'training time (minutes)=', '1.1542', 'loss=', '0.000527432')
# ('Epoch:', '0034', 'training time (minutes)=', '1.1578', 'loss=', '0.000526322')
# ('Epoch:', '0035', 'training time (minutes)=', '1.1619', 'loss=', '0.000515930')
# ('Epoch:', '0036', 'training time (minutes)=', '1.1615', 'loss=', '0.000518022')
# ('Epoch:', '0037', 'training time (minutes)=', '1.1574', 'loss=', '0.000514518')
# ('Epoch:', '0038', 'training time (minutes)=', '1.1560', 'loss=', '0.000511044')
# ('Epoch:', '0039', 'training time (minutes)=', '1.1562', 'loss=', '0.000511870')
# ('Epoch:', '0040', 'training time (minutes)=', '1.1594', 'loss=', '0.000508021')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '1.1570', 'loss=', '0.000513687')
# ('Epoch:', '0042', 'training time (minutes)=', '1.1594', 'loss=', '0.000513160')
# ('Epoch:', '0043', 'training time (minutes)=', '1.1585', 'loss=', '0.000497264')
# ('Epoch:', '0044', 'training time (minutes)=', '1.1514', 'loss=', '0.000506073')
# ('Epoch:', '0045', 'training time (minutes)=', '1.1585', 'loss=', '0.000499138')
# ('Epoch:', '0046', 'training time (minutes)=', '1.1575', 'loss=', '0.000504512')
# ('Epoch:', '0047', 'training time (minutes)=', '1.1546', 'loss=', '0.000495014')
# ('Epoch:', '0048', 'training time (minutes)=', '1.1526', 'loss=', '0.000491316')
# ('Epoch:', '0049', 'training time (minutes)=', '1.1605', 'loss=', '0.000501369')
# ('Epoch:', '0050', 'training time (minutes)=', '1.1585', 'loss=', '0.000490142')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '1.1557', 'loss=', '0.000486968')
# ('Epoch:', '0052', 'training time (minutes)=', '1.1616', 'loss=', '0.000492075')
# ('Epoch:', '0053', 'training time (minutes)=', '1.1639', 'loss=', '0.000491421')
# ('Epoch:', '0054', 'training time (minutes)=', '1.1679', 'loss=', '0.000489059')
# ('Epoch:', '0055', 'training time (minutes)=', '1.1642', 'loss=', '0.000493177')
# ('Epoch:', '0056', 'training time (minutes)=', '1.1580', 'loss=', '0.000490064')
# ('Epoch:', '0057', 'training time (minutes)=', '1.1668', 'loss=', '0.000481860')
# ('Epoch:', '0058', 'training time (minutes)=', '1.1626', 'loss=', '0.000486926')
# ('Epoch:', '0059', 'training time (minutes)=', '1.1554', 'loss=', '0.000489677')
# ('Epoch:', '0060', 'training time (minutes)=', '1.1573', 'loss=', '0.000484992')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '1.1592', 'loss=', '0.000480546')
# ('Epoch:', '0062', 'training time (minutes)=', '1.1533', 'loss=', '0.000481212')
# ('Epoch:', '0063', 'training time (minutes)=', '1.1538', 'loss=', '0.000481848')
# ('Epoch:', '0064', 'training time (minutes)=', '1.1547', 'loss=', '0.000476672')
# ('Epoch:', '0065', 'training time (minutes)=', '1.1548', 'loss=', '0.000475238')
# ('Epoch:', '0066', 'training time (minutes)=', '1.1616', 'loss=', '0.000480948')
# ('Epoch:', '0067', 'training time (minutes)=', '1.1553', 'loss=', '0.000473432')
# ('Epoch:', '0068', 'training time (minutes)=', '1.1603', 'loss=', '0.000471898')
# ('Epoch:', '0069', 'training time (minutes)=', '1.1581', 'loss=', '0.000470493')
# ('Epoch:', '0070', 'training time (minutes)=', '1.1505', 'loss=', '0.000476470')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '1.1575', 'loss=', '0.000471534')
# ('Epoch:', '0072', 'training time (minutes)=', '1.1480', 'loss=', '0.000472149')
# ('Epoch:', '0073', 'training time (minutes)=', '1.1579', 'loss=', '0.000473303')
# ('Epoch:', '0074', 'training time (minutes)=', '1.1418', 'loss=', '0.000481701')
# ('Epoch:', '0075', 'training time (minutes)=', '1.1519', 'loss=', '0.000462599')
# ('Epoch:', '0076', 'training time (minutes)=', '1.1499', 'loss=', '0.000475471')
# ('Epoch:', '0077', 'training time (minutes)=', '1.1597', 'loss=', '0.000467951')
# ('Epoch:', '0078', 'training time (minutes)=', '1.1572', 'loss=', '0.000475746')
# ('Epoch:', '0079', 'training time (minutes)=', '1.1518', 'loss=', '0.000465130')
# ('Epoch:', '0080', 'training time (minutes)=', '1.1529', 'loss=', '0.000470600')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '1.1608', 'loss=', '0.000474184')
# ('Epoch:', '0082', 'training time (minutes)=', '1.1613', 'loss=', '0.000463365')
# ('Epoch:', '0083', 'training time (minutes)=', '1.1578', 'loss=', '0.000472682')
# ('Epoch:', '0084', 'training time (minutes)=', '1.1558', 'loss=', '0.000470453')
# ('Epoch:', '0085', 'training time (minutes)=', '1.1567', 'loss=', '0.000464675')
# ('Epoch:', '0086', 'training time (minutes)=', '1.1518', 'loss=', '0.000464393')
# ('Epoch:', '0087', 'training time (minutes)=', '1.1543', 'loss=', '0.000465725')
# ('Epoch:', '0088', 'training time (minutes)=', '1.1557', 'loss=', '0.000455990')
# ('Epoch:', '0089', 'training time (minutes)=', '1.1532', 'loss=', '0.000467059')
# ('Epoch:', '0090', 'training time (minutes)=', '1.1545', 'loss=', '0.000453844')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '1.1580', 'loss=', '0.000463275')
# ('Epoch:', '0092', 'training time (minutes)=', '1.1545', 'loss=', '0.000457659')
# ('Epoch:', '0093', 'training time (minutes)=', '1.1527', 'loss=', '0.000457266')
# ('Epoch:', '0094', 'training time (minutes)=', '1.1466', 'loss=', '0.000454306')
# ('Epoch:', '0095', 'training time (minutes)=', '1.1469', 'loss=', '0.000459421')
# ('Epoch:', '0096', 'training time (minutes)=', '1.1485', 'loss=', '0.000463362')
# ('Epoch:', '0097', 'training time (minutes)=', '1.1500', 'loss=', '0.000458139')
# ('Epoch:', '0098', 'training time (minutes)=', '1.1583', 'loss=', '0.000451602')
# ('Epoch:', '0099', 'training time (minutes)=', '1.1539', 'loss=', '0.000457331')
# ('Epoch:', '0100', 'training time (minutes)=', '1.1462', 'loss=', '0.000453346')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '1.1451', 'loss=', '0.000453487')
# ('Epoch:', '0102', 'training time (minutes)=', '1.1350', 'loss=', '0.000452715')
# ('Epoch:', '0103', 'training time (minutes)=', '1.1552', 'loss=', '0.000453028')
# ('Epoch:', '0104', 'training time (minutes)=', '1.1473', 'loss=', '0.000463288')
# ('Epoch:', '0105', 'training time (minutes)=', '1.1581', 'loss=', '0.000449131')
# ('Epoch:', '0106', 'training time (minutes)=', '1.1593', 'loss=', '0.000458355')
# ('Epoch:', '0107', 'training time (minutes)=', '1.1584', 'loss=', '0.000450948')
# ('Epoch:', '0108', 'training time (minutes)=', '1.1522', 'loss=', '0.000443272')
# ('Epoch:', '0109', 'training time (minutes)=', '1.1489', 'loss=', '0.000451508')
# ('Epoch:', '0110', 'training time (minutes)=', '1.1568', 'loss=', '0.000457351')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '1.1550', 'loss=', '0.000447024')
# ('Epoch:', '0112', 'training time (minutes)=', '1.1478', 'loss=', '0.000453382')
# ('Epoch:', '0113', 'training time (minutes)=', '1.1488', 'loss=', '0.000449917')
# ('Epoch:', '0114', 'training time (minutes)=', '1.1506', 'loss=', '0.000453052')
# ('Epoch:', '0115', 'training time (minutes)=', '1.1578', 'loss=', '0.000453822')
# ('Epoch:', '0116', 'training time (minutes)=', '1.1590', 'loss=', '0.000450259')
# ('Epoch:', '0117', 'training time (minutes)=', '1.1530', 'loss=', '0.000449309')
# ('Epoch:', '0118', 'training time (minutes)=', '1.1414', 'loss=', '0.000447495')
# ('Epoch:', '0119', 'training time (minutes)=', '1.1549', 'loss=', '0.000441461')
# ('Epoch:', '0120', 'training time (minutes)=', '1.1405', 'loss=', '0.000446533')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '1.1549', 'loss=', '0.000447773')
# ('Epoch:', '0122', 'training time (minutes)=', '1.1578', 'loss=', '0.000447424')
# ('Epoch:', '0123', 'training time (minutes)=', '1.1570', 'loss=', '0.000448948')
# ('Epoch:', '0124', 'training time (minutes)=', '1.1517', 'loss=', '0.000447448')
# ('Epoch:', '0125', 'training time (minutes)=', '1.1556', 'loss=', '0.000447158')
# ('Epoch:', '0126', 'training time (minutes)=', '1.1533', 'loss=', '0.000446831')
# ('Epoch:', '0127', 'training time (minutes)=', '1.1481', 'loss=', '0.000449739')
# ('Epoch:', '0128', 'training time (minutes)=', '1.1519', 'loss=', '0.000447211')
# ('Epoch:', '0129', 'training time (minutes)=', '1.1465', 'loss=', '0.000443126')
# ('Epoch:', '0130', 'training time (minutes)=', '1.1449', 'loss=', '0.000435084')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '1.1509', 'loss=', '0.000445787')
# ('Epoch:', '0132', 'training time (minutes)=', '1.1514', 'loss=', '0.000440305')
# ('Epoch:', '0133', 'training time (minutes)=', '1.1489', 'loss=', '0.000443916')
# ('Epoch:', '0134', 'training time (minutes)=', '1.1539', 'loss=', '0.000442540')
# ('Epoch:', '0135', 'training time (minutes)=', '1.1447', 'loss=', '0.000430596')
# ('Epoch:', '0136', 'training time (minutes)=', '1.1500', 'loss=', '0.000435137')
# ('Epoch:', '0137', 'training time (minutes)=', '1.1499', 'loss=', '0.000445484')
# ('Epoch:', '0138', 'training time (minutes)=', '1.1491', 'loss=', '0.000447776')
# ('Epoch:', '0139', 'training time (minutes)=', '1.1527', 'loss=', '0.000442813')
# ('Epoch:', '0140', 'training time (minutes)=', '1.1459', 'loss=', '0.000438227')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '1.1448', 'loss=', '0.000440066')
# ('Epoch:', '0142', 'training time (minutes)=', '1.1539', 'loss=', '0.000434554')
# ('Epoch:', '0143', 'training time (minutes)=', '1.1497', 'loss=', '0.000445965')
# ('Epoch:', '0144', 'training time (minutes)=', '1.1523', 'loss=', '0.000445915')
# ('Epoch:', '0145', 'training time (minutes)=', '1.1528', 'loss=', '0.000447090')
# ('Epoch:', '0146', 'training time (minutes)=', '1.1550', 'loss=', '0.000442557')
# ('Epoch:', '0147', 'training time (minutes)=', '1.1516', 'loss=', '0.000443514')
# ('Epoch:', '0148', 'training time (minutes)=', '1.1623', 'loss=', '0.000438436')
# ('Epoch:', '0149', 'training time (minutes)=', '1.1563', 'loss=', '0.000443251')
# ('Epoch:', '0150', 'training time (minutes)=', '1.1589', 'loss=', '0.000438395')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '1.1587', 'loss=', '0.000434196')
# ('Epoch:', '0152', 'training time (minutes)=', '1.1549', 'loss=', '0.000435300')
# ('Epoch:', '0153', 'training time (minutes)=', '1.1581', 'loss=', '0.000438672')
# ('Epoch:', '0154', 'training time (minutes)=', '1.1557', 'loss=', '0.000434974')
# ('Epoch:', '0155', 'training time (minutes)=', '1.1546', 'loss=', '0.000440586')
# ('Epoch:', '0156', 'training time (minutes)=', '1.1576', 'loss=', '0.000437160')
# ('Epoch:', '0157', 'training time (minutes)=', '1.1521', 'loss=', '0.000441468')
# ('Epoch:', '0158', 'training time (minutes)=', '1.1565', 'loss=', '0.000442780')
# ('Epoch:', '0159', 'training time (minutes)=', '1.1572', 'loss=', '0.000440945')
# ('Epoch:', '0160', 'training time (minutes)=', '1.1567', 'loss=', '0.000438686')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '1.1587', 'loss=', '0.000434415')
# ('Epoch:', '0162', 'training time (minutes)=', '1.1553', 'loss=', '0.000438954')
# ('Epoch:', '0163', 'training time (minutes)=', '1.1520', 'loss=', '0.000438032')
# ('Epoch:', '0164', 'training time (minutes)=', '1.1512', 'loss=', '0.000422508')
# ('Epoch:', '0165', 'training time (minutes)=', '1.1506', 'loss=', '0.000428686')
# ('Epoch:', '0166', 'training time (minutes)=', '1.1545', 'loss=', '0.000433017')
# ('Epoch:', '0167', 'training time (minutes)=', '1.1560', 'loss=', '0.000443694')
# ('Epoch:', '0168', 'training time (minutes)=', '1.1518', 'loss=', '0.000432098')
# ('Epoch:', '0169', 'training time (minutes)=', '1.1532', 'loss=', '0.000423076')
# ('Epoch:', '0170', 'training time (minutes)=', '1.1573', 'loss=', '0.000440220')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '1.1566', 'loss=', '0.000430898')
# ('Epoch:', '0172', 'training time (minutes)=', '1.1544', 'loss=', '0.000429673')
# ('Epoch:', '0173', 'training time (minutes)=', '1.1553', 'loss=', '0.000432131')
# ('Epoch:', '0174', 'training time (minutes)=', '1.1568', 'loss=', '0.000425994')
# ('Epoch:', '0175', 'training time (minutes)=', '1.1482', 'loss=', '0.000430392')
# ('Epoch:', '0176', 'training time (minutes)=', '1.1520', 'loss=', '0.000428976')
# ('Epoch:', '0177', 'training time (minutes)=', '1.1492', 'loss=', '0.000430180')
# ('Epoch:', '0178', 'training time (minutes)=', '1.1529', 'loss=', '0.000432760')
# ('Epoch:', '0179', 'training time (minutes)=', '1.1483', 'loss=', '0.000427306')
# ('Epoch:', '0180', 'training time (minutes)=', '1.1559', 'loss=', '0.000428447')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '1.1510', 'loss=', '0.000434993')
# ('Epoch:', '0182', 'training time (minutes)=', '1.1404', 'loss=', '0.000424050')
# ('Epoch:', '0183', 'training time (minutes)=', '1.1529', 'loss=', '0.000428707')
# ('Epoch:', '0184', 'training time (minutes)=', '1.1560', 'loss=', '0.000429084')
# ('Epoch:', '0185', 'training time (minutes)=', '1.1551', 'loss=', '0.000429444')
# ('Epoch:', '0186', 'training time (minutes)=', '1.1510', 'loss=', '0.000429283')
# ('Epoch:', '0187', 'training time (minutes)=', '1.1551', 'loss=', '0.000432374')
# ('Epoch:', '0188', 'training time (minutes)=', '1.1492', 'loss=', '0.000425626')
# ('Epoch:', '0189', 'training time (minutes)=', '1.1518', 'loss=', '0.000428042')
# ('Epoch:', '0190', 'training time (minutes)=', '1.1560', 'loss=', '0.000422920')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '1.1549', 'loss=', '0.000425829')
# ('Epoch:', '0192', 'training time (minutes)=', '1.1557', 'loss=', '0.000425677')
# ('Epoch:', '0193', 'training time (minutes)=', '1.1561', 'loss=', '0.000431120')
# ('Epoch:', '0194', 'training time (minutes)=', '1.1530', 'loss=', '0.000421376')
# ('Epoch:', '0195', 'training time (minutes)=', '1.1513', 'loss=', '0.000433583')
# ('Epoch:', '0196', 'training time (minutes)=', '1.1493', 'loss=', '0.000425732')
# ('Epoch:', '0197', 'training time (minutes)=', '1.1525', 'loss=', '0.000427136')
# ('Epoch:', '0198', 'training time (minutes)=', '1.1559', 'loss=', '0.000428390')
# ('Epoch:', '0199', 'training time (minutes)=', '1.1552', 'loss=', '0.000424764')
# ('Epoch:', '0200', 'training time (minutes)=', '1.1571', 'loss=', '0.000429464')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '1.1555', 'loss=', '0.000422682')
# ('Epoch:', '0202', 'training time (minutes)=', '1.1462', 'loss=', '0.000420310')
# ('Epoch:', '0203', 'training time (minutes)=', '1.1450', 'loss=', '0.000420861')
# ('Epoch:', '0204', 'training time (minutes)=', '1.1526', 'loss=', '0.000426258')
# ('Epoch:', '0205', 'training time (minutes)=', '1.1575', 'loss=', '0.000421422')
# ('Epoch:', '0206', 'training time (minutes)=', '1.1560', 'loss=', '0.000426944')
# ('Epoch:', '0207', 'training time (minutes)=', '1.1567', 'loss=', '0.000422533')
# ('Epoch:', '0208', 'training time (minutes)=', '1.1564', 'loss=', '0.000424649')
# ('Epoch:', '0209', 'training time (minutes)=', '1.1448', 'loss=', '0.000422866')
# ('Epoch:', '0210', 'training time (minutes)=', '1.1439', 'loss=', '0.000430936')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '1.1490', 'loss=', '0.000426270')
# ('Epoch:', '0212', 'training time (minutes)=', '1.1523', 'loss=', '0.000426758')
# ('Epoch:', '0213', 'training time (minutes)=', '1.1467', 'loss=', '0.000419898')
# ('Epoch:', '0214', 'training time (minutes)=', '1.1570', 'loss=', '0.000417644')
# ('Epoch:', '0215', 'training time (minutes)=', '1.1518', 'loss=', '0.000420527')
# ('Epoch:', '0216', 'training time (minutes)=', '1.1572', 'loss=', '0.000426836')
# ('Epoch:', '0217', 'training time (minutes)=', '1.1587', 'loss=', '0.000423488')
# ('Epoch:', '0218', 'training time (minutes)=', '1.1548', 'loss=', '0.000421502')
# ('Epoch:', '0219', 'training time (minutes)=', '1.1375', 'loss=', '0.000429385')
# ('Epoch:', '0220', 'training time (minutes)=', '1.1590', 'loss=', '0.000419861')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '1.1515', 'loss=', '0.000419125')
# ('Epoch:', '0222', 'training time (minutes)=', '1.1546', 'loss=', '0.000422440')
# ('Epoch:', '0223', 'training time (minutes)=', '1.1572', 'loss=', '0.000418869')
# ('Epoch:', '0224', 'training time (minutes)=', '1.1660', 'loss=', '0.000417853')
# ('Epoch:', '0225', 'training time (minutes)=', '1.1487', 'loss=', '0.000419735')
# ('Epoch:', '0226', 'training time (minutes)=', '1.1650', 'loss=', '0.000420197')
# ('Epoch:', '0227', 'training time (minutes)=', '1.1655', 'loss=', '0.000421140')
# ('Epoch:', '0228', 'training time (minutes)=', '1.1694', 'loss=', '0.000422226')
# ('Epoch:', '0229', 'training time (minutes)=', '1.1598', 'loss=', '0.000419409')
# ('Epoch:', '0230', 'training time (minutes)=', '1.1622', 'loss=', '0.000426579')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '1.1629', 'loss=', '0.000420442')
# ('Epoch:', '0232', 'training time (minutes)=', '1.1706', 'loss=', '0.000421670')
# ('Epoch:', '0233', 'training time (minutes)=', '1.1711', 'loss=', '0.000418930')
# ('Epoch:', '0234', 'training time (minutes)=', '1.1670', 'loss=', '0.000419273')
# ('Epoch:', '0235', 'training time (minutes)=', '1.1497', 'loss=', '0.000423575')
# ('Epoch:', '0236', 'training time (minutes)=', '1.1659', 'loss=', '0.000419427')
# ('Epoch:', '0237', 'training time (minutes)=', '1.1657', 'loss=', '0.000419720')
# ('Epoch:', '0238', 'training time (minutes)=', '1.1640', 'loss=', '0.000422098')
# ('Epoch:', '0239', 'training time (minutes)=', '1.1658', 'loss=', '0.000418597')
# ('Epoch:', '0240', 'training time (minutes)=', '1.1653', 'loss=', '0.000419410')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '1.1610', 'loss=', '0.000419662')
# ('Epoch:', '0242', 'training time (minutes)=', '1.1514', 'loss=', '0.000420887')
# ('Epoch:', '0243', 'training time (minutes)=', '1.1509', 'loss=', '0.000415900')
# ('Epoch:', '0244', 'training time (minutes)=', '1.1601', 'loss=', '0.000413494')
# ('Epoch:', '0245', 'training time (minutes)=', '1.1612', 'loss=', '0.000417433')
# ('Epoch:', '0246', 'training time (minutes)=', '1.1631', 'loss=', '0.000420180')
# ('Epoch:', '0247', 'training time (minutes)=', '1.1629', 'loss=', '0.000411827')
# ('Epoch:', '0248', 'training time (minutes)=', '1.1555', 'loss=', '0.000416254')
# ('Epoch:', '0249', 'training time (minutes)=', '1.1607', 'loss=', '0.000413234')
# ('Epoch:', '0250', 'training time (minutes)=', '1.1455', 'loss=', '0.000417700')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '1.1576', 'loss=', '0.000420120')
# ('Epoch:', '0252', 'training time (minutes)=', '1.1553', 'loss=', '0.000421017')
# ('Epoch:', '0253', 'training time (minutes)=', '1.1658', 'loss=', '0.000416421')
# ('Epoch:', '0254', 'training time (minutes)=', '1.1678', 'loss=', '0.000415931')
# ('Epoch:', '0255', 'training time (minutes)=', '1.1472', 'loss=', '0.000418704')
# ('Epoch:', '0256', 'training time (minutes)=', '1.1687', 'loss=', '0.000415504')
# ('Epoch:', '0257', 'training time (minutes)=', '1.1683', 'loss=', '0.000423086')
# ('Epoch:', '0258', 'training time (minutes)=', '1.1559', 'loss=', '0.000409026')
# ('Epoch:', '0259', 'training time (minutes)=', '1.1621', 'loss=', '0.000417145')
# ('Epoch:', '0260', 'training time (minutes)=', '1.1692', 'loss=', '0.000416337')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '1.1646', 'loss=', '0.000422774')
# ('Epoch:', '0262', 'training time (minutes)=', '1.1676', 'loss=', '0.000413939')
# ('Epoch:', '0263', 'training time (minutes)=', '1.1592', 'loss=', '0.000411585')
# ('Epoch:', '0264', 'training time (minutes)=', '1.1615', 'loss=', '0.000413264')
# ('Epoch:', '0265', 'training time (minutes)=', '1.1575', 'loss=', '0.000422069')
# ('Epoch:', '0266', 'training time (minutes)=', '1.1683', 'loss=', '0.000421688')
# ('Epoch:', '0267', 'training time (minutes)=', '1.1666', 'loss=', '0.000417105')
# ('Epoch:', '0268', 'training time (minutes)=', '1.1744', 'loss=', '0.000410728')
# ('Epoch:', '0269', 'training time (minutes)=', '1.1607', 'loss=', '0.000415884')
# ('Epoch:', '0270', 'training time (minutes)=', '1.1660', 'loss=', '0.000416308')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '1.1601', 'loss=', '0.000417537')
# ('Epoch:', '0272', 'training time (minutes)=', '1.1630', 'loss=', '0.000410738')
# ('Epoch:', '0273', 'training time (minutes)=', '1.1641', 'loss=', '0.000415714')
# ('Epoch:', '0274', 'training time (minutes)=', '1.1657', 'loss=', '0.000414042')
# ('Epoch:', '0275', 'training time (minutes)=', '1.1637', 'loss=', '0.000413097')
# ('Epoch:', '0276', 'training time (minutes)=', '1.1606', 'loss=', '0.000422835')
# ('Epoch:', '0277', 'training time (minutes)=', '1.1582', 'loss=', '0.000413539')
# ('Epoch:', '0278', 'training time (minutes)=', '1.1596', 'loss=', '0.000416089')
# ('Epoch:', '0279', 'training time (minutes)=', '1.1594', 'loss=', '0.000416078')
# ('Epoch:', '0280', 'training time (minutes)=', '1.1561', 'loss=', '0.000413728')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '1.1561', 'loss=', '0.000407427')
# ('Epoch:', '0282', 'training time (minutes)=', '1.1577', 'loss=', '0.000414685')
# ('Epoch:', '0283', 'training time (minutes)=', '1.1468', 'loss=', '0.000416375')
# ('Epoch:', '0284', 'training time (minutes)=', '1.1576', 'loss=', '0.000412074')
# ('Epoch:', '0285', 'training time (minutes)=', '1.1580', 'loss=', '0.000407723')
# ('Epoch:', '0286', 'training time (minutes)=', '1.1542', 'loss=', '0.000410218')
# ('Epoch:', '0287', 'training time (minutes)=', '1.1532', 'loss=', '0.000416668')
# ('Epoch:', '0288', 'training time (minutes)=', '1.1569', 'loss=', '0.000415583')
# ('Epoch:', '0289', 'training time (minutes)=', '1.1574', 'loss=', '0.000409133')
# ('Epoch:', '0290', 'training time (minutes)=', '1.1468', 'loss=', '0.000406953')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '1.1506', 'loss=', '0.000411678')
# ('Epoch:', '0292', 'training time (minutes)=', '1.1573', 'loss=', '0.000409618')
# ('Epoch:', '0293', 'training time (minutes)=', '1.1555', 'loss=', '0.000409557')
# ('Epoch:', '0294', 'training time (minutes)=', '1.1584', 'loss=', '0.000405440')
# ('Epoch:', '0295', 'training time (minutes)=', '1.1560', 'loss=', '0.000399261')
# ('Epoch:', '0296', 'training time (minutes)=', '1.1577', 'loss=', '0.000413399')
# ('Epoch:', '0297', 'training time (minutes)=', '1.1435', 'loss=', '0.000416099')
# ('Epoch:', '0298', 'training time (minutes)=', '1.1528', 'loss=', '0.000408899')
# ('Epoch:', '0299', 'training time (minutes)=', '1.1497', 'loss=', '0.000411555')
# ('Epoch:', '0300', 'training time (minutes)=', '1.1453', 'loss=', '0.000406482')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '1.1562', 'loss=', '0.000405809')
# ('Epoch:', '0302', 'training time (minutes)=', '1.1565', 'loss=', '0.000410305')
# ('Epoch:', '0303', 'training time (minutes)=', '1.1572', 'loss=', '0.000407784')
# ('Epoch:', '0304', 'training time (minutes)=', '1.1433', 'loss=', '0.000406111')
# ('Epoch:', '0305', 'training time (minutes)=', '1.1487', 'loss=', '0.000403250')
# ('Epoch:', '0306', 'training time (minutes)=', '1.1557', 'loss=', '0.000411254')
# ('Epoch:', '0307', 'training time (minutes)=', '1.1553', 'loss=', '0.000408656')
# ('Epoch:', '0308', 'training time (minutes)=', '1.1465', 'loss=', '0.000410551')
# ('Epoch:', '0309', 'training time (minutes)=', '1.1501', 'loss=', '0.000407498')
# ('Epoch:', '0310', 'training time (minutes)=', '1.1472', 'loss=', '0.000400615')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '1.1564', 'loss=', '0.000404902')
# ('Epoch:', '0312', 'training time (minutes)=', '1.1488', 'loss=', '0.000405874')
# ('Epoch:', '0313', 'training time (minutes)=', '1.1511', 'loss=', '0.000414130')
# ('Epoch:', '0314', 'training time (minutes)=', '1.1560', 'loss=', '0.000407869')
# ('Epoch:', '0315', 'training time (minutes)=', '1.1572', 'loss=', '0.000406305')
# ('Epoch:', '0316', 'training time (minutes)=', '1.1629', 'loss=', '0.000403109')
# ('Epoch:', '0317', 'training time (minutes)=', '1.1515', 'loss=', '0.000406711')
# ('Epoch:', '0318', 'training time (minutes)=', '1.1582', 'loss=', '0.000409392')
# ('Epoch:', '0319', 'training time (minutes)=', '1.1589', 'loss=', '0.000413081')
# ('Epoch:', '0320', 'training time (minutes)=', '1.1588', 'loss=', '0.000412185')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '1.1724', 'loss=', '0.000404319')
# ('Epoch:', '0322', 'training time (minutes)=', '1.1591', 'loss=', '0.000409280')
# ('Epoch:', '0323', 'training time (minutes)=', '1.1567', 'loss=', '0.000408060')
# ('Epoch:', '0324', 'training time (minutes)=', '1.1578', 'loss=', '0.000409660')
# ('Epoch:', '0325', 'training time (minutes)=', '1.1516', 'loss=', '0.000412146')
# ('Epoch:', '0326', 'training time (minutes)=', '1.1569', 'loss=', '0.000415673')
# ('Epoch:', '0327', 'training time (minutes)=', '1.1553', 'loss=', '0.000402316')
# ('Epoch:', '0328', 'training time (minutes)=', '1.1619', 'loss=', '0.000411923')
# ('Epoch:', '0329', 'training time (minutes)=', '1.1560', 'loss=', '0.000409994')
# ('Epoch:', '0330', 'training time (minutes)=', '1.1602', 'loss=', '0.000405245')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '1.1500', 'loss=', '0.000401975')
# ('Epoch:', '0332', 'training time (minutes)=', '1.1551', 'loss=', '0.000409307')
# ('Epoch:', '0333', 'training time (minutes)=', '1.1522', 'loss=', '0.000407022')
# ('Epoch:', '0334', 'training time (minutes)=', '1.1558', 'loss=', '0.000402516')
# ('Epoch:', '0335', 'training time (minutes)=', '1.1585', 'loss=', '0.000404769')
# ('Epoch:', '0336', 'training time (minutes)=', '1.1524', 'loss=', '0.000408394')
# ('Epoch:', '0337', 'training time (minutes)=', '1.1620', 'loss=', '0.000403095')
# ('Epoch:', '0338', 'training time (minutes)=', '1.1709', 'loss=', '0.000408837')
# ('Epoch:', '0339', 'training time (minutes)=', '1.1629', 'loss=', '0.000403455')
# ('Epoch:', '0340', 'training time (minutes)=', '1.1602', 'loss=', '0.000408878')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '1.1668', 'loss=', '0.000402186')
# ('Epoch:', '0342', 'training time (minutes)=', '1.1680', 'loss=', '0.000401781')
# ('Epoch:', '0343', 'training time (minutes)=', '1.1648', 'loss=', '0.000406263')
# ('Epoch:', '0344', 'training time (minutes)=', '1.1656', 'loss=', '0.000410263')
# ('Epoch:', '0345', 'training time (minutes)=', '1.1539', 'loss=', '0.000405818')
# ('Epoch:', '0346', 'training time (minutes)=', '1.1529', 'loss=', '0.000405934')
# ('Epoch:', '0347', 'training time (minutes)=', '1.1496', 'loss=', '0.000404785')
# ('Epoch:', '0348', 'training time (minutes)=', '1.1532', 'loss=', '0.000396571')
# ('Epoch:', '0349', 'training time (minutes)=', '1.1533', 'loss=', '0.000403351')
# ('Epoch:', '0350', 'training time (minutes)=', '1.1559', 'loss=', '0.000409075')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '1.1398', 'loss=', '0.000401282')
# ('Epoch:', '0352', 'training time (minutes)=', '1.1554', 'loss=', '0.000410326')
# ('Epoch:', '0353', 'training time (minutes)=', '1.1542', 'loss=', '0.000403781')
# ('Epoch:', '0354', 'training time (minutes)=', '1.1605', 'loss=', '0.000405681')
# ('Epoch:', '0355', 'training time (minutes)=', '1.1593', 'loss=', '0.000406987')
# ('Epoch:', '0356', 'training time (minutes)=', '1.1597', 'loss=', '0.000406763')
# ('Epoch:', '0357', 'training time (minutes)=', '1.1521', 'loss=', '0.000411214')
# ('Epoch:', '0358', 'training time (minutes)=', '1.1546', 'loss=', '0.000410348')
# ('Epoch:', '0359', 'training time (minutes)=', '1.1523', 'loss=', '0.000406064')
# ('Epoch:', '0360', 'training time (minutes)=', '1.1581', 'loss=', '0.000409756')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0361', 'training time (minutes)=', '1.1594', 'loss=', '0.000403549')
# ('Epoch:', '0362', 'training time (minutes)=', '1.2065', 'loss=', '0.000404815')
# ('Epoch:', '0363', 'training time (minutes)=', '1.1479', 'loss=', '0.000398494')
# ('Epoch:', '0364', 'training time (minutes)=', '1.1550', 'loss=', '0.000409619')
# ('Epoch:', '0365', 'training time (minutes)=', '1.1583', 'loss=', '0.000408643')
# ('Epoch:', '0366', 'training time (minutes)=', '1.1530', 'loss=', '0.000399585')
# ('Epoch:', '0367', 'training time (minutes)=', '1.1579', 'loss=', '0.000400156')
# ('Epoch:', '0368', 'training time (minutes)=', '1.1578', 'loss=', '0.000404059')
# ('Epoch:', '0369', 'training time (minutes)=', '1.1578', 'loss=', '0.000407647')
# ('Epoch:', '0370', 'training time (minutes)=', '1.1585', 'loss=', '0.000411004')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0371', 'training time (minutes)=', '1.1550', 'loss=', '0.000398859')
# ('Epoch:', '0372', 'training time (minutes)=', '1.1543', 'loss=', '0.000406676')
# ('Epoch:', '0373', 'training time (minutes)=', '1.1608', 'loss=', '0.000410587')
# ('Epoch:', '0374', 'training time (minutes)=', '1.1608', 'loss=', '0.000403016')
# ('Epoch:', '0375', 'training time (minutes)=', '1.1580', 'loss=', '0.000410511')
# ('Epoch:', '0376', 'training time (minutes)=', '1.1591', 'loss=', '0.000403459')
# ('Epoch:', '0377', 'training time (minutes)=', '1.1603', 'loss=', '0.000407348')
# ('Epoch:', '0378', 'training time (minutes)=', '1.1573', 'loss=', '0.000403809')
# ('Epoch:', '0379', 'training time (minutes)=', '1.1591', 'loss=', '0.000407574')
# ('Epoch:', '0380', 'training time (minutes)=', '1.1517', 'loss=', '0.000405672')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0381', 'training time (minutes)=', '1.1590', 'loss=', '0.000399237')
# ('Epoch:', '0382', 'training time (minutes)=', '1.1603', 'loss=', '0.000401199')
# ('Epoch:', '0383', 'training time (minutes)=', '1.1595', 'loss=', '0.000406376')
# ('Epoch:', '0384', 'training time (minutes)=', '1.1598', 'loss=', '0.000397044')
# ('Epoch:', '0385', 'training time (minutes)=', '1.1532', 'loss=', '0.000407233')
# ('Epoch:', '0386', 'training time (minutes)=', '1.1581', 'loss=', '0.000399670')
# ('Epoch:', '0387', 'training time (minutes)=', '1.1603', 'loss=', '0.000398484')
# ('Epoch:', '0388', 'training time (minutes)=', '1.1573', 'loss=', '0.000406270')
# ('Epoch:', '0389', 'training time (minutes)=', '1.1567', 'loss=', '0.000402908')
# ('Epoch:', '0390', 'training time (minutes)=', '1.1609', 'loss=', '0.000404180')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0391', 'training time (minutes)=', '1.1558', 'loss=', '0.000411150')
# ('Epoch:', '0392', 'training time (minutes)=', '1.1547', 'loss=', '0.000403358')
# ('Epoch:', '0393', 'training time (minutes)=', '1.1520', 'loss=', '0.000399838')
# ('Epoch:', '0394', 'training time (minutes)=', '1.1541', 'loss=', '0.000398738')
# ('Epoch:', '0395', 'training time (minutes)=', '1.1453', 'loss=', '0.000406797')
# ('Epoch:', '0396', 'training time (minutes)=', '1.1515', 'loss=', '0.000410900')
# ('Epoch:', '0397', 'training time (minutes)=', '1.1491', 'loss=', '0.000409448')
# ('Epoch:', '0398', 'training time (minutes)=', '1.1507', 'loss=', '0.000407493')
# ('Epoch:', '0399', 'training time (minutes)=', '1.1429', 'loss=', '0.000404140')
# ('Epoch:', '0400', 'training time (minutes)=', '1.1505', 'loss=', '0.000402797')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0401', 'training time (minutes)=', '1.1505', 'loss=', '0.000405375')
# ('Epoch:', '0402', 'training time (minutes)=', '1.1536', 'loss=', '0.000407812')
# ('Epoch:', '0403', 'training time (minutes)=', '1.1409', 'loss=', '0.000402091')
# ('Epoch:', '0404', 'training time (minutes)=', '1.1539', 'loss=', '0.000401466')
# ('Epoch:', '0405', 'training time (minutes)=', '1.1532', 'loss=', '0.000401750')
# ('Epoch:', '0406', 'training time (minutes)=', '1.1540', 'loss=', '0.000404806')
# ('Epoch:', '0407', 'training time (minutes)=', '1.1397', 'loss=', '0.000406107')
# ('Epoch:', '0408', 'training time (minutes)=', '1.1516', 'loss=', '0.000398242')
# ('Epoch:', '0409', 'training time (minutes)=', '1.1519', 'loss=', '0.000399288')
# ('Epoch:', '0410', 'training time (minutes)=', '1.1539', 'loss=', '0.000397271')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0411', 'training time (minutes)=', '1.1572', 'loss=', '0.000403374')
# ('Epoch:', '0412', 'training time (minutes)=', '1.1499', 'loss=', '0.000405644')
# ('Epoch:', '0413', 'training time (minutes)=', '1.1522', 'loss=', '0.000396659')
# ('Epoch:', '0414', 'training time (minutes)=', '1.1535', 'loss=', '0.000410977')
# ('Epoch:', '0415', 'training time (minutes)=', '1.1584', 'loss=', '0.000400493')
# ('Epoch:', '0416', 'training time (minutes)=', '1.1609', 'loss=', '0.000400114')
# ('Epoch:', '0417', 'training time (minutes)=', '1.1593', 'loss=', '0.000404670')
# ('Epoch:', '0418', 'training time (minutes)=', '1.1545', 'loss=', '0.000400411')
# ('Epoch:', '0419', 'training time (minutes)=', '1.1600', 'loss=', '0.000403824')
# ('Epoch:', '0420', 'training time (minutes)=', '1.1522', 'loss=', '0.000401831')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0421', 'training time (minutes)=', '1.1499', 'loss=', '0.000397765')
# ('Epoch:', '0422', 'training time (minutes)=', '1.1595', 'loss=', '0.000411262')
# ('Epoch:', '0423', 'training time (minutes)=', '1.1479', 'loss=', '0.000415840')
# ('Epoch:', '0424', 'training time (minutes)=', '1.1532', 'loss=', '0.000404755')
# ('Epoch:', '0425', 'training time (minutes)=', '1.1595', 'loss=', '0.000406997')
# ('Epoch:', '0426', 'training time (minutes)=', '1.1540', 'loss=', '0.000406993')
# ('Epoch:', '0427', 'training time (minutes)=', '1.1530', 'loss=', '0.000404132')
# ('Epoch:', '0428', 'training time (minutes)=', '1.1598', 'loss=', '0.000402183')
# ('Epoch:', '0429', 'training time (minutes)=', '1.1572', 'loss=', '0.000396838')
# ('Epoch:', '0430', 'training time (minutes)=', '1.1586', 'loss=', '0.000400975')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0431', 'training time (minutes)=', '1.1607', 'loss=', '0.000400099')
# ('Epoch:', '0432', 'training time (minutes)=', '1.1583', 'loss=', '0.000401844')
# ('Epoch:', '0433', 'training time (minutes)=', '1.1558', 'loss=', '0.000402347')
# ('Epoch:', '0434', 'training time (minutes)=', '1.1554', 'loss=', '0.000398703')
# ('Epoch:', '0435', 'training time (minutes)=', '1.1607', 'loss=', '0.000401484')
# ('Epoch:', '0436', 'training time (minutes)=', '1.1614', 'loss=', '0.000397339')
# ('Epoch:', '0437', 'training time (minutes)=', '1.1629', 'loss=', '0.000396026')
# ('Epoch:', '0438', 'training time (minutes)=', '1.1688', 'loss=', '0.000398622')
# ('Epoch:', '0439', 'training time (minutes)=', '1.1636', 'loss=', '0.000392283')
# ('Epoch:', '0440', 'training time (minutes)=', '1.1630', 'loss=', '0.000401212')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0441', 'training time (minutes)=', '1.1584', 'loss=', '0.000394552')
# ('Epoch:', '0442', 'training time (minutes)=', '1.1593', 'loss=', '0.000405736')
# ('Epoch:', '0443', 'training time (minutes)=', '1.1654', 'loss=', '0.000404013')
# ('Epoch:', '0444', 'training time (minutes)=', '1.1669', 'loss=', '0.000395414')
# ('Epoch:', '0445', 'training time (minutes)=', '1.1619', 'loss=', '0.000399238')
# ('Epoch:', '0446', 'training time (minutes)=', '1.1540', 'loss=', '0.000399563')
# ('Epoch:', '0447', 'training time (minutes)=', '1.1592', 'loss=', '0.000402183')
# ('Epoch:', '0448', 'training time (minutes)=', '1.1585', 'loss=', '0.000403119')
# ('Epoch:', '0449', 'training time (minutes)=', '1.1544', 'loss=', '0.000398561')
# ('Epoch:', '0450', 'training time (minutes)=', '1.1565', 'loss=', '0.000400303')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0451', 'training time (minutes)=', '1.1597', 'loss=', '0.000396318')
# ('Epoch:', '0452', 'training time (minutes)=', '1.1585', 'loss=', '0.000398009')
# ('Epoch:', '0453', 'training time (minutes)=', '1.1456', 'loss=', '0.000403888')
# ('Epoch:', '0454', 'training time (minutes)=', '1.1595', 'loss=', '0.000396839')
# ('Epoch:', '0455', 'training time (minutes)=', '1.1527', 'loss=', '0.000398186')
# ('Epoch:', '0456', 'training time (minutes)=', '1.1613', 'loss=', '0.000402181')
# ('Epoch:', '0457', 'training time (minutes)=', '1.1621', 'loss=', '0.000390921')
# ('Epoch:', '0458', 'training time (minutes)=', '1.1558', 'loss=', '0.000394943')
# ('Epoch:', '0459', 'training time (minutes)=', '1.1522', 'loss=', '0.000400962')
# ('Epoch:', '0460', 'training time (minutes)=', '1.1559', 'loss=', '0.000404943')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0461', 'training time (minutes)=', '1.1645', 'loss=', '0.000397643')
# ('Epoch:', '0462', 'training time (minutes)=', '1.1580', 'loss=', '0.000397367')
# ('Epoch:', '0463', 'training time (minutes)=', '1.1659', 'loss=', '0.000404913')
# ('Epoch:', '0464', 'training time (minutes)=', '1.1569', 'loss=', '0.000397199')
# ('Epoch:', '0465', 'training time (minutes)=', '1.1776', 'loss=', '0.000394593')
# ...
# ('Epoch:', '1024', 'training time (minutes)=', '1.1936', 'loss=', '0.000404429')
# ('Epoch:', '1025', 'training time (minutes)=', '1.2183', 'loss=', '0.000397037')
# ('Epoch:', '1026', 'training time (minutes)=', '1.1999', 'loss=', '0.000400996')
# ('Epoch:', '1027', 'training time (minutes)=', '1.1947', 'loss=', '0.000398726')
# ('Epoch:', '1028', 'training time (minutes)=', '1.1833', 'loss=', '0.000392859')
# ('Epoch:', '1029', 'training time (minutes)=', '1.2038', 'loss=', '0.000399590')
# ('Epoch:', '1030', 'training time (minutes)=', '1.1903', 'loss=', '0.000393047')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1030 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1031', 'training time (minutes)=', '1.1902', 'loss=', '0.000396659')
# ('Epoch:', '1032', 'training time (minutes)=', '1.2164', 'loss=', '0.000400232')
# ('Epoch:', '1033', 'training time (minutes)=', '1.1886', 'loss=', '0.000399495')
# ('Epoch:', '1034', 'training time (minutes)=', '1.1871', 'loss=', '0.000400132')
# ('Epoch:', '1035', 'training time (minutes)=', '1.2070', 'loss=', '0.000391322')
# ('Epoch:', '1036', 'training time (minutes)=', '1.2015', 'loss=', '0.000402402')
# ('Epoch:', '1037', 'training time (minutes)=', '1.1833', 'loss=', '0.000400990')
# ('Epoch:', '1038', 'training time (minutes)=', '1.2143', 'loss=', '0.000389271')
# ('Epoch:', '1039', 'training time (minutes)=', '1.2166', 'loss=', '0.000402610')
# ('Epoch:', '1040', 'training time (minutes)=', '1.2627', 'loss=', '0.000394369')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1040 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1041', 'training time (minutes)=', '1.1923', 'loss=', '0.000393557')
# ('Epoch:', '1042', 'training time (minutes)=', '1.2064', 'loss=', '0.000401520')
# ('Epoch:', '1043', 'training time (minutes)=', '1.2033', 'loss=', '0.000403929')
# ('Epoch:', '1044', 'training time (minutes)=', '1.1976', 'loss=', '0.000412763')
# ('Epoch:', '1045', 'training time (minutes)=', '1.1974', 'loss=', '0.000403262')
# ('Epoch:', '1046', 'training time (minutes)=', '1.1754', 'loss=', '0.000399077')
# ('Epoch:', '1047', 'training time (minutes)=', '1.2101', 'loss=', '0.000400244')
# ('Epoch:', '1048', 'training time (minutes)=', '1.2105', 'loss=', '0.000403809')
# ('Epoch:', '1049', 'training time (minutes)=', '1.2148', 'loss=', '0.000403671')
# ('Epoch:', '1050', 'training time (minutes)=', '1.2144', 'loss=', '0.000394801')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1050 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1051', 'training time (minutes)=', '1.1984', 'loss=', '0.000400647')
# ('Epoch:', '1052', 'training time (minutes)=', '1.1885', 'loss=', '0.000396913')
# ('Epoch:', '1053', 'training time (minutes)=', '1.2007', 'loss=', '0.000402325')
# ('Epoch:', '1054', 'training time (minutes)=', '1.2038', 'loss=', '0.000401255')
# ('Epoch:', '1055', 'training time (minutes)=', '1.2109', 'loss=', '0.000391599')
# ('Epoch:', '1056', 'training time (minutes)=', '1.1778', 'loss=', '0.000393981')
# ('Epoch:', '1057', 'training time (minutes)=', '1.1997', 'loss=', '0.000401836')
# ('Epoch:', '1058', 'training time (minutes)=', '1.2012', 'loss=', '0.000399861')
# ('Epoch:', '1059', 'training time (minutes)=', '1.2157', 'loss=', '0.000402513')
# ('Epoch:', '1060', 'training time (minutes)=', '1.1896', 'loss=', '0.000395427')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1060 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1061', 'training time (minutes)=', '1.1751', 'loss=', '0.000399652')
# ('Epoch:', '1062', 'training time (minutes)=', '1.1904', 'loss=', '0.000397761')
# ('Epoch:', '1063', 'training time (minutes)=', '1.2289', 'loss=', '0.000403059')
# ('Epoch:', '1064', 'training time (minutes)=', '1.1761', 'loss=', '0.000400676')
# ('Epoch:', '1065', 'training time (minutes)=', '1.2053', 'loss=', '0.000404295')
# ('Epoch:', '1066', 'training time (minutes)=', '1.1699', 'loss=', '0.000396508')
# ('Epoch:', '1067', 'training time (minutes)=', '1.1793', 'loss=', '0.000394930')
# ('Epoch:', '1068', 'training time (minutes)=', '1.2243', 'loss=', '0.000385785')
# ('Epoch:', '1069', 'training time (minutes)=', '1.2047', 'loss=', '0.000400905')
# ('Epoch:', '1070', 'training time (minutes)=', '1.1889', 'loss=', '0.000393650')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1070 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1071', 'training time (minutes)=', '1.1944', 'loss=', '0.000394742')
# ('Epoch:', '1072', 'training time (minutes)=', '1.1994', 'loss=', '0.000391890')
# ('Epoch:', '1073', 'training time (minutes)=', '1.2190', 'loss=', '0.000398543')
# ('Epoch:', '1074', 'training time (minutes)=', '1.2044', 'loss=', '0.000401744')
# ('Epoch:', '1075', 'training time (minutes)=', '1.2118', 'loss=', '0.000399224')
# ('Epoch:', '1076', 'training time (minutes)=', '1.2242', 'loss=', '0.000400084')
# ('Epoch:', '1077', 'training time (minutes)=', '1.2246', 'loss=', '0.000399423')
# ('Epoch:', '1078', 'training time (minutes)=', '1.2127', 'loss=', '0.000396429')
# ('Epoch:', '1079', 'training time (minutes)=', '1.2097', 'loss=', '0.000395978')
# ('Epoch:', '1080', 'training time (minutes)=', '1.2448', 'loss=', '0.000393239')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1080 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1081', 'training time (minutes)=', '1.1921', 'loss=', '0.000400963')
# ('Epoch:', '1082', 'training time (minutes)=', '1.1813', 'loss=', '0.000403062')
# ('Epoch:', '1083', 'training time (minutes)=', '1.2323', 'loss=', '0.000406474')
# ('Epoch:', '1084', 'training time (minutes)=', '1.2417', 'loss=', '0.000412555')
# ('Epoch:', '1085', 'training time (minutes)=', '1.1860', 'loss=', '0.000422609')
# ('Epoch:', '1086', 'training time (minutes)=', '1.2068', 'loss=', '0.000414483')
# ('Epoch:', '1087', 'training time (minutes)=', '1.2005', 'loss=', '0.000410486')
# ('Epoch:', '1088', 'training time (minutes)=', '1.2032', 'loss=', '0.000408176')
# ('Epoch:', '1089', 'training time (minutes)=', '1.2146', 'loss=', '0.000408320')
# ('Epoch:', '1090', 'training time (minutes)=', '1.1994', 'loss=', '0.000412401')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1090 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1091', 'training time (minutes)=', '1.1738', 'loss=', '0.000404060')
# ('Epoch:', '1092', 'training time (minutes)=', '1.2008', 'loss=', '0.000408533')
# ('Epoch:', '1093', 'training time (minutes)=', '1.1727', 'loss=', '0.000407220')
# ('Epoch:', '1094', 'training time (minutes)=', '1.1807', 'loss=', '0.000413766')
# ('Epoch:', '1095', 'training time (minutes)=', '1.1895', 'loss=', '0.000406741')
# ('Epoch:', '1096', 'training time (minutes)=', '1.2101', 'loss=', '0.000407487')
# ('Epoch:', '1097', 'training time (minutes)=', '1.2440', 'loss=', '0.000412273')
# ('Epoch:', '1098', 'training time (minutes)=', '1.2090', 'loss=', '0.000431886')
# ('Epoch:', '1099', 'training time (minutes)=', '1.1865', 'loss=', '0.000436571')
# ('Epoch:', '1100', 'training time (minutes)=', '1.2049', 'loss=', '0.000446163')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1101', 'training time (minutes)=', '1.1855', 'loss=', '0.000449889')
# ('Epoch:', '1102', 'training time (minutes)=', '1.2013', 'loss=', '0.000433114')
# ('Epoch:', '1103', 'training time (minutes)=', '1.1719', 'loss=', '0.000421660')
# ('Epoch:', '1104', 'training time (minutes)=', '1.1782', 'loss=', '0.000428003')
# ('Epoch:', '1105', 'training time (minutes)=', '1.2035', 'loss=', '0.000432893')
# ('Epoch:', '1106', 'training time (minutes)=', '1.1779', 'loss=', '0.000432399')
# ('Epoch:', '1107', 'training time (minutes)=', '1.1950', 'loss=', '0.000429529')
# ('Epoch:', '1108', 'training time (minutes)=', '1.1775', 'loss=', '0.000426866')
# ('Epoch:', '1109', 'training time (minutes)=', '1.1939', 'loss=', '0.000431933')
# ('Epoch:', '1110', 'training time (minutes)=', '1.1789', 'loss=', '0.000429563')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1111', 'training time (minutes)=', '1.2050', 'loss=', '0.000426447')
# ('Epoch:', '1112', 'training time (minutes)=', '1.2097', 'loss=', '0.000429467')
# ('Epoch:', '1113', 'training time (minutes)=', '1.2012', 'loss=', '0.000433060')
# ('Epoch:', '1114', 'training time (minutes)=', '1.1764', 'loss=', '0.000439884')
# ('Epoch:', '1115', 'training time (minutes)=', '1.1841', 'loss=', '0.000421210')
# ('Epoch:', '1116', 'training time (minutes)=', '1.2123', 'loss=', '0.000419792')
# ('Epoch:', '1117', 'training time (minutes)=', '1.2043', 'loss=', '0.000412289')
# ('Epoch:', '1118', 'training time (minutes)=', '1.2088', 'loss=', '0.000425446')
# ('Epoch:', '1119', 'training time (minutes)=', '1.2132', 'loss=', '0.000426313')
# ('Epoch:', '1120', 'training time (minutes)=', '1.1949', 'loss=', '0.000421845')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1121', 'training time (minutes)=', '1.2185', 'loss=', '0.000431469')
# ('Epoch:', '1122', 'training time (minutes)=', '1.2203', 'loss=', '0.000420658')
# ('Epoch:', '1123', 'training time (minutes)=', '1.2028', 'loss=', '0.000434551')
# ('Epoch:', '1124', 'training time (minutes)=', '1.2312', 'loss=', '0.000423396')
# ('Epoch:', '1125', 'training time (minutes)=', '1.2336', 'loss=', '0.000446218')
# ('Epoch:', '1126', 'training time (minutes)=', '1.2355', 'loss=', '0.000421983')
# ('Epoch:', '1127', 'training time (minutes)=', '1.2278', 'loss=', '0.000419867')
# ('Epoch:', '1128', 'training time (minutes)=', '1.2449', 'loss=', '0.000424734')
# ('Epoch:', '1129', 'training time (minutes)=', '1.2246', 'loss=', '0.000461264')
# ('Epoch:', '1130', 'training time (minutes)=', '1.1947', 'loss=', '0.000441328')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1131', 'training time (minutes)=', '1.2181', 'loss=', '0.000448276')
# ('Epoch:', '1132', 'training time (minutes)=', '1.2361', 'loss=', '0.000436913')
# ('Epoch:', '1133', 'training time (minutes)=', '1.2296', 'loss=', '0.000443742')
# ('Epoch:', '1134', 'training time (minutes)=', '1.2141', 'loss=', '0.000429933')
# ('Epoch:', '1135', 'training time (minutes)=', '1.1877', 'loss=', '0.000427796')
# ('Epoch:', '1136', 'training time (minutes)=', '1.2334', 'loss=', '0.000434102')
# ('Epoch:', '1137', 'training time (minutes)=', '1.2258', 'loss=', '0.000427809')
# ('Epoch:', '1138', 'training time (minutes)=', '1.2309', 'loss=', '0.000434147')
# ('Epoch:', '1139', 'training time (minutes)=', '1.2329', 'loss=', '0.000422459')
# ('Epoch:', '1140', 'training time (minutes)=', '1.2255', 'loss=', '0.000435225')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1141', 'training time (minutes)=', '1.2136', 'loss=', '0.000426860')
# ('Epoch:', '1142', 'training time (minutes)=', '1.2107', 'loss=', '0.000425647')
# ('Epoch:', '1143', 'training time (minutes)=', '1.2021', 'loss=', '0.000416921')
# ('Epoch:', '1144', 'training time (minutes)=', '1.1968', 'loss=', '0.000427507')
# ('Epoch:', '1145', 'training time (minutes)=', '1.2025', 'loss=', '0.000425230')
# ('Epoch:', '1146', 'training time (minutes)=', '1.1899', 'loss=', '0.000420038')
# ('Epoch:', '1147', 'training time (minutes)=', '1.2024', 'loss=', '0.000429128')
# ('Epoch:', '1148', 'training time (minutes)=', '1.2326', 'loss=', '0.000415962')
# ('Epoch:', '1149', 'training time (minutes)=', '1.2003', 'loss=', '0.000413001')
# ('Epoch:', '1150', 'training time (minutes)=', '1.2030', 'loss=', '0.000422345')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1151', 'training time (minutes)=', '1.1944', 'loss=', '0.000406994')
# ('Epoch:', '1152', 'training time (minutes)=', '1.1983', 'loss=', '0.000414290')
# ('Epoch:', '1153', 'training time (minutes)=', '1.2172', 'loss=', '0.000407354')
# ('Epoch:', '1154', 'training time (minutes)=', '1.2057', 'loss=', '0.000415870')
# ('Epoch:', '1155', 'training time (minutes)=', '1.1996', 'loss=', '0.000419423')
# ('Epoch:', '1156', 'training time (minutes)=', '1.2030', 'loss=', '0.000414608')
# ('Epoch:', '1157', 'training time (minutes)=', '1.1899', 'loss=', '0.000415625')
# ('Epoch:', '1158', 'training time (minutes)=', '1.1958', 'loss=', '0.000416501')
# ('Epoch:', '1159', 'training time (minutes)=', '1.2001', 'loss=', '0.000419936')
# ('Epoch:', '1160', 'training time (minutes)=', '1.2114', 'loss=', '0.000411104')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1161', 'training time (minutes)=', '1.2121', 'loss=', '0.000412095')
# ('Epoch:', '1162', 'training time (minutes)=', '1.2125', 'loss=', '0.000407877')
# ('Epoch:', '1163', 'training time (minutes)=', '1.1857', 'loss=', '0.000407799')
# ('Epoch:', '1164', 'training time (minutes)=', '1.1930', 'loss=', '0.000405209')
# ('Epoch:', '1165', 'training time (minutes)=', '1.2035', 'loss=', '0.000409142')
# ('Epoch:', '1166', 'training time (minutes)=', '1.1951', 'loss=', '0.000405176')
# ('Epoch:', '1167', 'training time (minutes)=', '1.2147', 'loss=', '0.000411735')
# ('Epoch:', '1168', 'training time (minutes)=', '1.2064', 'loss=', '0.000413072')
# ('Epoch:', '1169', 'training time (minutes)=', '1.1966', 'loss=', '0.000407918')
# ('Epoch:', '1170', 'training time (minutes)=', '1.1941', 'loss=', '0.000405788')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_wider_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1171', 'training time (minutes)=', '1.1948', 'loss=', '0.000410823')
# ('Epoch:', '1172', 'training time (minutes)=', '1.1941', 'loss=', '0.000404196')
# ('Epoch:', '1173', 'training time (minutes)=', '1.1947', 'loss=', '0.000413721')
# ('Epoch:', '1174', 'training time (minutes)=', '1.1869', 'loss=', '0.000398925')
# ('Epoch:', '1175', 'training time (minutes)=', '1.1978', 'loss=', '0.000410375')
# ('Epoch:', '1176', 'training time (minutes)=', '1.1901', 'loss=', '0.000414769')
# ('Epoch:', '1177', 'training time (minutes)=', '1.2073', 'loss=', '0.000407903')
# ('Epoch:', '1178', 'training time (minutes)=', '1.1879', 'loss=', '0.000403901')
# ('Epoch:', '1179', 'training time (minutes)=', '1.2081', 'loss=', '0.000403866')
