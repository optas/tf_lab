# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 0
setup_one_gpu(GPU)
# Out:
# Picking GPU 0

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs

from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry, decoder_with_fc_only
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tf_lab.iclr.helper import load_multiple_version_of_pcs

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = True
load_model = False
seed = 42
max_training_epochs = 2000
loss = 'chamfer'
z_rotate = True
experiment_name = 'all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code' + str(n_pc_samples) +  'pts_' + loss

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'

# %%
n_threads = 25
verbose = True
version = 'centered'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', version, str(n_pc_samples))
full_file_names = [f for f in files_in_subdirs(full_pclouds_path, '.ply')]
pclouds, _, _ = load_point_clouds_from_filenames(full_file_names, n_threads, snc_loader, verbose)
train_data = PointCloudDataSet(pclouds)
print train_data.num_examples
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:38: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')
# 57449 pclouds were loaded. They belong in 57 shape-classes.
# 57449

# %%
train_dir = osp.join('/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc', experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer'

# %%
n_input = [n_pc_samples, 3]

encoder_args = {'n_filters': [64, 128, 128, 256, 512],
                'filter_sizes': [1, 1, 1, 1, 1],
                'strides': [1, 1, 1, 1, 1],
                'b_norm': False
               }

decoder_args = {'layer_sizes': [512, 1024, np.prod(n_input)],
                'b_norm': False
               }

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = decoder_with_fc_only,
                decoder_args = decoder_args,            
               )
    conf.allow_gpu_growth = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/encoders_decoders.py:95: UserWarning: Using old architecture.
#   warnings.warn('Using old architecture.')

# %%
if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)
        
if load_model and do_training:
    conf.training_epochs -= last_epoch
    print conf.training_epochs

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)    
    train_stats = ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.1392', 'loss=', '0.002539619')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '1.2651', 'loss=', '0.001164714')
# ('Epoch:', '0003', 'training time (minutes)=', '1.2297', 'loss=', '0.000963228')
# ('Epoch:', '0004', 'training time (minutes)=', '1.2348', 'loss=', '0.000900690')
# ('Epoch:', '0005', 'training time (minutes)=', '1.2331', 'loss=', '0.000837381')
# ('Epoch:', '0006', 'training time (minutes)=', '1.2614', 'loss=', '0.000803429')
# ('Epoch:', '0007', 'training time (minutes)=', '1.2557', 'loss=', '0.000744514')
# ('Epoch:', '0008', 'training time (minutes)=', '1.2232', 'loss=', '0.000747441')
# ('Epoch:', '0009', 'training time (minutes)=', '1.2358', 'loss=', '0.000713168')
# ('Epoch:', '0010', 'training time (minutes)=', '1.2033', 'loss=', '0.000702970')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '1.2208', 'loss=', '0.000665478')
# ('Epoch:', '0012', 'training time (minutes)=', '1.1983', 'loss=', '0.000670110')
# ('Epoch:', '0013', 'training time (minutes)=', '1.2890', 'loss=', '0.000650000')
# ('Epoch:', '0014', 'training time (minutes)=', '1.1618', 'loss=', '0.000638497')
# ('Epoch:', '0015', 'training time (minutes)=', '1.2106', 'loss=', '0.000618214')
# ('Epoch:', '0016', 'training time (minutes)=', '1.1810', 'loss=', '0.000619537')
# ('Epoch:', '0017', 'training time (minutes)=', '1.2212', 'loss=', '0.000608610')
# ('Epoch:', '0018', 'training time (minutes)=', '1.2108', 'loss=', '0.000618893')
# ('Epoch:', '0019', 'training time (minutes)=', '1.2011', 'loss=', '0.000594845')
# ('Epoch:', '0020', 'training time (minutes)=', '1.2710', 'loss=', '0.000597661')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '1.2225', 'loss=', '0.000591869')
# ('Epoch:', '0022', 'training time (minutes)=', '1.2292', 'loss=', '0.000576947')
# ('Epoch:', '0023', 'training time (minutes)=', '1.2874', 'loss=', '0.000573224')
# ('Epoch:', '0024', 'training time (minutes)=', '1.2186', 'loss=', '0.000567184')
# ('Epoch:', '0025', 'training time (minutes)=', '1.2450', 'loss=', '0.000562890')
# ('Epoch:', '0026', 'training time (minutes)=', '1.2533', 'loss=', '0.000564346')
# ('Epoch:', '0027', 'training time (minutes)=', '1.2220', 'loss=', '0.000563367')
# ('Epoch:', '0028', 'training time (minutes)=', '1.1867', 'loss=', '0.000556915')
# ('Epoch:', '0029', 'training time (minutes)=', '1.2828', 'loss=', '0.000555533')
# ('Epoch:', '0030', 'training time (minutes)=', '1.1729', 'loss=', '0.000555072')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '1.2047', 'loss=', '0.000548058')
# ('Epoch:', '0032', 'training time (minutes)=', '1.2702', 'loss=', '0.000541177')
# ('Epoch:', '0033', 'training time (minutes)=', '1.2949', 'loss=', '0.000538711')
# ('Epoch:', '0034', 'training time (minutes)=', '1.2577', 'loss=', '0.000542729')
# ('Epoch:', '0035', 'training time (minutes)=', '1.2224', 'loss=', '0.000539194')
# ('Epoch:', '0036', 'training time (minutes)=', '1.1975', 'loss=', '0.000533717')
# ('Epoch:', '0037', 'training time (minutes)=', '1.2475', 'loss=', '0.000533979')
# ('Epoch:', '0038', 'training time (minutes)=', '1.2245', 'loss=', '0.000524588')
# ('Epoch:', '0039', 'training time (minutes)=', '1.2580', 'loss=', '0.000531287')
# ('Epoch:', '0040', 'training time (minutes)=', '1.2913', 'loss=', '0.000517245')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '1.2265', 'loss=', '0.000523543')
# ('Epoch:', '0042', 'training time (minutes)=', '1.2632', 'loss=', '0.000526461')
# ('Epoch:', '0043', 'training time (minutes)=', '1.3078', 'loss=', '0.000522057')
# ('Epoch:', '0044', 'training time (minutes)=', '1.2326', 'loss=', '0.000525638')
# ('Epoch:', '0045', 'training time (minutes)=', '1.2260', 'loss=', '0.000517463')
# ('Epoch:', '0046', 'training time (minutes)=', '1.2599', 'loss=', '0.000516983')
# ('Epoch:', '0047', 'training time (minutes)=', '1.2647', 'loss=', '0.000511862')
# ('Epoch:', '0048', 'training time (minutes)=', '1.2591', 'loss=', '0.000519325')
# ('Epoch:', '0049', 'training time (minutes)=', '1.2436', 'loss=', '0.000510365')
# ('Epoch:', '0050', 'training time (minutes)=', '1.2128', 'loss=', '0.000510260')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '1.2886', 'loss=', '0.000506828')
# ('Epoch:', '0052', 'training time (minutes)=', '1.2824', 'loss=', '0.000507313')
# ('Epoch:', '0053', 'training time (minutes)=', '1.2452', 'loss=', '0.000502055')
# ('Epoch:', '0054', 'training time (minutes)=', '1.2556', 'loss=', '0.000509959')
# ('Epoch:', '0055', 'training time (minutes)=', '1.2780', 'loss=', '0.000510707')
# ('Epoch:', '0056', 'training time (minutes)=', '1.1853', 'loss=', '0.000489630')
# ('Epoch:', '0057', 'training time (minutes)=', '1.2444', 'loss=', '0.000500791')
# ('Epoch:', '0058', 'training time (minutes)=', '1.2609', 'loss=', '0.000504636')
# ('Epoch:', '0059', 'training time (minutes)=', '1.2489', 'loss=', '0.000496283')
# ('Epoch:', '0060', 'training time (minutes)=', '1.3025', 'loss=', '0.000486303')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '1.2347', 'loss=', '0.000489891')
# ('Epoch:', '0062', 'training time (minutes)=', '1.2961', 'loss=', '0.000491547')
# ('Epoch:', '0063', 'training time (minutes)=', '1.2342', 'loss=', '0.000497262')
# ('Epoch:', '0064', 'training time (minutes)=', '1.2626', 'loss=', '0.000492459')
# ('Epoch:', '0065', 'training time (minutes)=', '1.1892', 'loss=', '0.000491265')
# ('Epoch:', '0066', 'training time (minutes)=', '1.2428', 'loss=', '0.000487208')
# ('Epoch:', '0067', 'training time (minutes)=', '1.2580', 'loss=', '0.000501186')
# ('Epoch:', '0068', 'training time (minutes)=', '1.2271', 'loss=', '0.000490493')
# ('Epoch:', '0069', 'training time (minutes)=', '1.2899', 'loss=', '0.000487555')
# ('Epoch:', '0070', 'training time (minutes)=', '1.2524', 'loss=', '0.000492342')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '1.2748', 'loss=', '0.000487788')
# ('Epoch:', '0072', 'training time (minutes)=', '1.2447', 'loss=', '0.000492417')
# ('Epoch:', '0073', 'training time (minutes)=', '1.2496', 'loss=', '0.000486992')
# ('Epoch:', '0074', 'training time (minutes)=', '1.2162', 'loss=', '0.000489261')
# ('Epoch:', '0075', 'training time (minutes)=', '1.2889', 'loss=', '0.000485153')
# ('Epoch:', '0076', 'training time (minutes)=', '1.2473', 'loss=', '0.000475162')
# ('Epoch:', '0077', 'training time (minutes)=', '1.2902', 'loss=', '0.000488373')
# ('Epoch:', '0078', 'training time (minutes)=', '1.3105', 'loss=', '0.000488379')
# ('Epoch:', '0079', 'training time (minutes)=', '1.2675', 'loss=', '0.000478220')
# ('Epoch:', '0080', 'training time (minutes)=', '1.2624', 'loss=', '0.000480006')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '1.2172', 'loss=', '0.000479846')
# ('Epoch:', '0082', 'training time (minutes)=', '1.1642', 'loss=', '0.000477463')
# ('Epoch:', '0083', 'training time (minutes)=', '1.3458', 'loss=', '0.000476000')
# ('Epoch:', '0084', 'training time (minutes)=', '1.2218', 'loss=', '0.000481953')
# ('Epoch:', '0085', 'training time (minutes)=', '1.2629', 'loss=', '0.000478356')
# ('Epoch:', '0086', 'training time (minutes)=', '1.1997', 'loss=', '0.000475083')
# ('Epoch:', '0087', 'training time (minutes)=', '1.1786', 'loss=', '0.000469277')
# ('Epoch:', '0088', 'training time (minutes)=', '1.2878', 'loss=', '0.000481602')
# ('Epoch:', '0089', 'training time (minutes)=', '1.2928', 'loss=', '0.000474665')
# ('Epoch:', '0090', 'training time (minutes)=', '1.2592', 'loss=', '0.000476757')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '1.3018', 'loss=', '0.000472657')
# ('Epoch:', '0092', 'training time (minutes)=', '1.2824', 'loss=', '0.000477955')
# ('Epoch:', '0093', 'training time (minutes)=', '1.2134', 'loss=', '0.000476395')
# ('Epoch:', '0094', 'training time (minutes)=', '1.2829', 'loss=', '0.000472912')
# ('Epoch:', '0095', 'training time (minutes)=', '1.2478', 'loss=', '0.000473170')
# ('Epoch:', '0096', 'training time (minutes)=', '1.3017', 'loss=', '0.000465913')
# ('Epoch:', '0097', 'training time (minutes)=', '1.2781', 'loss=', '0.000475892')
# ('Epoch:', '0098', 'training time (minutes)=', '1.2584', 'loss=', '0.000477297')
# ('Epoch:', '0099', 'training time (minutes)=', '1.2307', 'loss=', '0.000476102')
# ('Epoch:', '0100', 'training time (minutes)=', '1.2907', 'loss=', '0.000470472')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '1.2911', 'loss=', '0.000463456')
# ('Epoch:', '0102', 'training time (minutes)=', '1.2483', 'loss=', '0.000462495')
# ('Epoch:', '0103', 'training time (minutes)=', '1.2530', 'loss=', '0.000463891')
# ('Epoch:', '0104', 'training time (minutes)=', '1.2884', 'loss=', '0.000468607')
# ('Epoch:', '0105', 'training time (minutes)=', '1.2742', 'loss=', '0.000474740')
# ('Epoch:', '0106', 'training time (minutes)=', '1.2136', 'loss=', '0.000468200')
# ('Epoch:', '0107', 'training time (minutes)=', '1.2615', 'loss=', '0.000462344')
# ('Epoch:', '0108', 'training time (minutes)=', '1.1630', 'loss=', '0.000469382')
# ('Epoch:', '0109', 'training time (minutes)=', '1.2185', 'loss=', '0.000467445')
# ('Epoch:', '0110', 'training time (minutes)=', '1.2765', 'loss=', '0.000476208')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '1.3124', 'loss=', '0.000465373')
# ('Epoch:', '0112', 'training time (minutes)=', '1.2820', 'loss=', '0.000463838')
# ('Epoch:', '0113', 'training time (minutes)=', '1.2782', 'loss=', '0.000465321')
# ('Epoch:', '0114', 'training time (minutes)=', '1.2644', 'loss=', '0.000470232')
# ('Epoch:', '0115', 'training time (minutes)=', '1.2775', 'loss=', '0.000463609')
# ('Epoch:', '0116', 'training time (minutes)=', '1.3022', 'loss=', '0.000461298')
# ('Epoch:', '0117', 'training time (minutes)=', '1.2513', 'loss=', '0.000458621')
# ('Epoch:', '0118', 'training time (minutes)=', '1.2840', 'loss=', '0.000456528')
# ('Epoch:', '0119', 'training time (minutes)=', '1.2874', 'loss=', '0.000460899')
# ('Epoch:', '0120', 'training time (minutes)=', '1.2382', 'loss=', '0.000459773')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '1.3110', 'loss=', '0.000466285')
# ('Epoch:', '0122', 'training time (minutes)=', '1.2834', 'loss=', '0.000456191')
# ('Epoch:', '0123', 'training time (minutes)=', '1.2139', 'loss=', '0.000461468')
# ('Epoch:', '0124', 'training time (minutes)=', '1.2497', 'loss=', '0.000462351')
# ('Epoch:', '0125', 'training time (minutes)=', '1.2349', 'loss=', '0.000460048')
# ('Epoch:', '0126', 'training time (minutes)=', '1.2753', 'loss=', '0.000457679')
# ('Epoch:', '0127', 'training time (minutes)=', '1.2099', 'loss=', '0.000462366')
# ('Epoch:', '0128', 'training time (minutes)=', '1.2977', 'loss=', '0.000460369')
# ('Epoch:', '0129', 'training time (minutes)=', '1.2229', 'loss=', '0.000461032')
# ('Epoch:', '0130', 'training time (minutes)=', '1.2881', 'loss=', '0.000460256')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '1.3058', 'loss=', '0.000462121')
# ('Epoch:', '0132', 'training time (minutes)=', '1.3049', 'loss=', '0.000462986')
# ('Epoch:', '0133', 'training time (minutes)=', '1.2361', 'loss=', '0.000450745')
# ('Epoch:', '0134', 'training time (minutes)=', '1.3034', 'loss=', '0.000456117')
# ('Epoch:', '0135', 'training time (minutes)=', '1.2877', 'loss=', '0.000455767')
# ('Epoch:', '0136', 'training time (minutes)=', '1.3150', 'loss=', '0.000454089')
# ('Epoch:', '0137', 'training time (minutes)=', '1.2493', 'loss=', '0.000451958')
# ('Epoch:', '0138', 'training time (minutes)=', '1.2070', 'loss=', '0.000464572')
# ('Epoch:', '0139', 'training time (minutes)=', '1.2829', 'loss=', '0.000448075')
# ('Epoch:', '0140', 'training time (minutes)=', '1.2984', 'loss=', '0.000459345')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '1.3135', 'loss=', '0.000465723')
# ('Epoch:', '0142', 'training time (minutes)=', '1.2744', 'loss=', '0.000452327')
# ('Epoch:', '0143', 'training time (minutes)=', '1.3230', 'loss=', '0.000454441')
# ('Epoch:', '0144', 'training time (minutes)=', '1.2952', 'loss=', '0.000457729')
# ('Epoch:', '0145', 'training time (minutes)=', '1.3060', 'loss=', '0.000453389')
# ('Epoch:', '0146', 'training time (minutes)=', '1.2579', 'loss=', '0.000452995')
# ('Epoch:', '0147', 'training time (minutes)=', '1.2603', 'loss=', '0.000454496')
# ('Epoch:', '0148', 'training time (minutes)=', '1.3031', 'loss=', '0.000457345')
# ('Epoch:', '0149', 'training time (minutes)=', '1.2869', 'loss=', '0.000451249')
# ('Epoch:', '0150', 'training time (minutes)=', '1.2640', 'loss=', '0.000457731')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '1.2740', 'loss=', '0.000449382')
# ('Epoch:', '0152', 'training time (minutes)=', '1.2647', 'loss=', '0.000454798')
# ('Epoch:', '0153', 'training time (minutes)=', '1.3271', 'loss=', '0.000451226')
# ('Epoch:', '0154', 'training time (minutes)=', '1.2790', 'loss=', '0.000452779')
# ('Epoch:', '0155', 'training time (minutes)=', '1.2720', 'loss=', '0.000446528')
# ('Epoch:', '0156', 'training time (minutes)=', '1.2416', 'loss=', '0.000448844')
# ('Epoch:', '0157', 'training time (minutes)=', '1.2647', 'loss=', '0.000447028')
# ('Epoch:', '0158', 'training time (minutes)=', '1.2881', 'loss=', '0.000448457')
# ('Epoch:', '0159', 'training time (minutes)=', '1.2608', 'loss=', '0.000453579')
# ('Epoch:', '0160', 'training time (minutes)=', '1.2987', 'loss=', '0.000447302')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '1.3008', 'loss=', '0.000442143')
# ('Epoch:', '0162', 'training time (minutes)=', '1.2571', 'loss=', '0.000446933')
# ('Epoch:', '0163', 'training time (minutes)=', '1.3163', 'loss=', '0.000456932')
# ('Epoch:', '0164', 'training time (minutes)=', '1.3088', 'loss=', '0.000445394')
# ('Epoch:', '0165', 'training time (minutes)=', '1.2865', 'loss=', '0.000450856')
# ('Epoch:', '0166', 'training time (minutes)=', '1.3075', 'loss=', '0.000446847')
# ('Epoch:', '0167', 'training time (minutes)=', '1.3064', 'loss=', '0.000449704')
# ('Epoch:', '0168', 'training time (minutes)=', '1.3406', 'loss=', '0.000448065')
# ('Epoch:', '0169', 'training time (minutes)=', '1.3114', 'loss=', '0.000449303')
# ('Epoch:', '0170', 'training time (minutes)=', '1.2983', 'loss=', '0.000448547')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '1.2692', 'loss=', '0.000442331')
# ('Epoch:', '0172', 'training time (minutes)=', '1.2516', 'loss=', '0.000443522')
# ('Epoch:', '0173', 'training time (minutes)=', '1.2828', 'loss=', '0.000443107')
# ('Epoch:', '0174', 'training time (minutes)=', '1.2553', 'loss=', '0.000448395')
# ('Epoch:', '0175', 'training time (minutes)=', '1.2843', 'loss=', '0.000447191')
# ('Epoch:', '0176', 'training time (minutes)=', '1.3045', 'loss=', '0.000441648')
# ('Epoch:', '0177', 'training time (minutes)=', '1.2259', 'loss=', '0.000458119')
# ('Epoch:', '0178', 'training time (minutes)=', '1.2340', 'loss=', '0.000439656')
# ('Epoch:', '0179', 'training time (minutes)=', '1.2680', 'loss=', '0.000446763')
# ('Epoch:', '0180', 'training time (minutes)=', '1.2716', 'loss=', '0.000447849')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '1.2295', 'loss=', '0.000450629')
# ('Epoch:', '0182', 'training time (minutes)=', '1.2553', 'loss=', '0.000449208')
# ('Epoch:', '0183', 'training time (minutes)=', '1.3094', 'loss=', '0.000447126')
# ('Epoch:', '0184', 'training time (minutes)=', '1.2358', 'loss=', '0.000450021')
# ('Epoch:', '0185', 'training time (minutes)=', '1.2289', 'loss=', '0.000441267')
# ('Epoch:', '0186', 'training time (minutes)=', '1.3074', 'loss=', '0.000446346')
# ('Epoch:', '0187', 'training time (minutes)=', '1.2396', 'loss=', '0.000443130')
# ('Epoch:', '0188', 'training time (minutes)=', '1.3233', 'loss=', '0.000440326')
# ('Epoch:', '0189', 'training time (minutes)=', '1.3244', 'loss=', '0.000448410')
# ('Epoch:', '0190', 'training time (minutes)=', '1.3220', 'loss=', '0.000439718')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '1.3080', 'loss=', '0.000443713')
# ('Epoch:', '0192', 'training time (minutes)=', '1.1961', 'loss=', '0.000439029')
# ('Epoch:', '0193', 'training time (minutes)=', '1.2434', 'loss=', '0.000440688')
# ('Epoch:', '0194', 'training time (minutes)=', '1.2852', 'loss=', '0.000445990')
# ('Epoch:', '0195', 'training time (minutes)=', '1.2916', 'loss=', '0.000443587')
# ('Epoch:', '0196', 'training time (minutes)=', '1.2302', 'loss=', '0.000439146')
# ('Epoch:', '0197', 'training time (minutes)=', '1.3065', 'loss=', '0.000446256')
# ('Epoch:', '0198', 'training time (minutes)=', '1.3068', 'loss=', '0.000443884')
# ('Epoch:', '0199', 'training time (minutes)=', '1.2420', 'loss=', '0.000437975')
# ('Epoch:', '0200', 'training time (minutes)=', '1.2606', 'loss=', '0.000443292')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '1.2935', 'loss=', '0.000449061')
# ('Epoch:', '0202', 'training time (minutes)=', '1.2562', 'loss=', '0.000442611')
# ('Epoch:', '0203', 'training time (minutes)=', '1.2335', 'loss=', '0.000444368')
# ('Epoch:', '0204', 'training time (minutes)=', '1.2298', 'loss=', '0.000450159')
# ('Epoch:', '0205', 'training time (minutes)=', '1.3087', 'loss=', '0.000446448')
# ('Epoch:', '0206', 'training time (minutes)=', '1.2416', 'loss=', '0.000435570')
# ('Epoch:', '0207', 'training time (minutes)=', '1.3472', 'loss=', '0.000436430')
# ('Epoch:', '0208', 'training time (minutes)=', '1.2900', 'loss=', '0.000443482')
# ('Epoch:', '0209', 'training time (minutes)=', '1.3267', 'loss=', '0.000442956')
# ('Epoch:', '0210', 'training time (minutes)=', '1.2567', 'loss=', '0.000440736')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '1.2849', 'loss=', '0.000440472')
# ('Epoch:', '0212', 'training time (minutes)=', '1.2718', 'loss=', '0.000437886')
# ('Epoch:', '0213', 'training time (minutes)=', '1.3185', 'loss=', '0.000433756')
# ('Epoch:', '0214', 'training time (minutes)=', '1.2662', 'loss=', '0.000443217')
# ('Epoch:', '0215', 'training time (minutes)=', '1.3124', 'loss=', '0.000441392')
# ('Epoch:', '0216', 'training time (minutes)=', '1.3069', 'loss=', '0.000436188')
# ('Epoch:', '0217', 'training time (minutes)=', '1.2883', 'loss=', '0.000436851')
# ('Epoch:', '0218', 'training time (minutes)=', '1.3068', 'loss=', '0.000442096')
# ('Epoch:', '0219', 'training time (minutes)=', '1.3303', 'loss=', '0.000439270')
# ('Epoch:', '0220', 'training time (minutes)=', '1.2548', 'loss=', '0.000438378')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '1.2771', 'loss=', '0.000437468')
# ('Epoch:', '0222', 'training time (minutes)=', '1.2701', 'loss=', '0.000437903')
# ('Epoch:', '0223', 'training time (minutes)=', '1.2488', 'loss=', '0.000435783')
# ('Epoch:', '0224', 'training time (minutes)=', '1.2064', 'loss=', '0.000438219')
# ('Epoch:', '0225', 'training time (minutes)=', '1.2449', 'loss=', '0.000436420')
# ('Epoch:', '0226', 'training time (minutes)=', '1.2077', 'loss=', '0.000442376')
# ('Epoch:', '0227', 'training time (minutes)=', '1.2528', 'loss=', '0.000432143')
# ('Epoch:', '0228', 'training time (minutes)=', '1.2693', 'loss=', '0.000432269')
# ('Epoch:', '0229', 'training time (minutes)=', '1.2657', 'loss=', '0.000436797')
# ('Epoch:', '0230', 'training time (minutes)=', '1.2159', 'loss=', '0.000438649')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '1.3201', 'loss=', '0.000433709')
# ('Epoch:', '0232', 'training time (minutes)=', '1.2791', 'loss=', '0.000439328')
# ('Epoch:', '0233', 'training time (minutes)=', '1.2425', 'loss=', '0.000435524')
# ('Epoch:', '0234', 'training time (minutes)=', '1.2657', 'loss=', '0.000432213')
# ('Epoch:', '0235', 'training time (minutes)=', '1.2478', 'loss=', '0.000434770')
# ('Epoch:', '0236', 'training time (minutes)=', '1.2926', 'loss=', '0.000437516')
# ('Epoch:', '0237', 'training time (minutes)=', '1.2707', 'loss=', '0.000441465')
# ('Epoch:', '0238', 'training time (minutes)=', '1.2362', 'loss=', '0.000437402')
# ('Epoch:', '0239', 'training time (minutes)=', '1.1969', 'loss=', '0.000441513')
# ('Epoch:', '0240', 'training time (minutes)=', '1.2194', 'loss=', '0.000433339')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '1.2009', 'loss=', '0.000435600')
# ('Epoch:', '0242', 'training time (minutes)=', '1.2231', 'loss=', '0.000434738')
# ('Epoch:', '0243', 'training time (minutes)=', '1.3165', 'loss=', '0.000429171')
# ('Epoch:', '0244', 'training time (minutes)=', '1.2864', 'loss=', '0.000436982')
# ('Epoch:', '0245', 'training time (minutes)=', '1.2214', 'loss=', '0.000433068')
# ('Epoch:', '0246', 'training time (minutes)=', '1.2361', 'loss=', '0.000436942')
# ('Epoch:', '0247', 'training time (minutes)=', '1.2238', 'loss=', '0.000437206')
# ('Epoch:', '0248', 'training time (minutes)=', '1.2054', 'loss=', '0.000436373')
# ('Epoch:', '0249', 'training time (minutes)=', '1.2164', 'loss=', '0.000435532')
# ('Epoch:', '0250', 'training time (minutes)=', '1.3718', 'loss=', '0.000434471')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '1.2257', 'loss=', '0.000431491')
# ('Epoch:', '0252', 'training time (minutes)=', '1.2936', 'loss=', '0.000432496')
# ('Epoch:', '0253', 'training time (minutes)=', '1.2076', 'loss=', '0.000429043')
# ('Epoch:', '0254', 'training time (minutes)=', '1.1954', 'loss=', '0.000437705')
# ('Epoch:', '0255', 'training time (minutes)=', '1.2426', 'loss=', '0.000430144')
# ('Epoch:', '0256', 'training time (minutes)=', '1.3443', 'loss=', '0.000432572')
# ('Epoch:', '0257', 'training time (minutes)=', '1.2419', 'loss=', '0.000434521')
# ('Epoch:', '0258', 'training time (minutes)=', '1.2155', 'loss=', '0.000435651')
# ('Epoch:', '0259', 'training time (minutes)=', '1.2399', 'loss=', '0.000430574')
# ('Epoch:', '0260', 'training time (minutes)=', '1.2869', 'loss=', '0.000426949')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '1.2479', 'loss=', '0.000431231')
# ('Epoch:', '0262', 'training time (minutes)=', '1.2211', 'loss=', '0.000432508')
# ('Epoch:', '0263', 'training time (minutes)=', '1.2657', 'loss=', '0.000435292')
# ('Epoch:', '0264', 'training time (minutes)=', '1.2131', 'loss=', '0.000430799')
# ('Epoch:', '0265', 'training time (minutes)=', '1.3017', 'loss=', '0.000435279')
# ('Epoch:', '0266', 'training time (minutes)=', '1.2631', 'loss=', '0.000431805')
# ('Epoch:', '0267', 'training time (minutes)=', '1.2640', 'loss=', '0.000431712')
# ('Epoch:', '0268', 'training time (minutes)=', '1.2870', 'loss=', '0.000434478')
# ('Epoch:', '0269', 'training time (minutes)=', '1.3314', 'loss=', '0.000432588')
# ('Epoch:', '0270', 'training time (minutes)=', '1.2476', 'loss=', '0.000426938')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '1.2158', 'loss=', '0.000441002')
# ('Epoch:', '0272', 'training time (minutes)=', '1.2382', 'loss=', '0.000431174')
# ('Epoch:', '0273', 'training time (minutes)=', '1.2612', 'loss=', '0.000437639')
# ('Epoch:', '0274', 'training time (minutes)=', '1.2762', 'loss=', '0.000429591')
# ('Epoch:', '0275', 'training time (minutes)=', '1.2102', 'loss=', '0.000432391')
# ('Epoch:', '0276', 'training time (minutes)=', '1.2566', 'loss=', '0.000430021')
# ('Epoch:', '0277', 'training time (minutes)=', '1.2172', 'loss=', '0.000440857')
# ('Epoch:', '0278', 'training time (minutes)=', '1.2869', 'loss=', '0.000429436')
# ('Epoch:', '0279', 'training time (minutes)=', '1.2902', 'loss=', '0.000432413')
# ('Epoch:', '0280', 'training time (minutes)=', '1.3215', 'loss=', '0.000427573')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '1.2994', 'loss=', '0.000426755')
# ('Epoch:', '0282', 'training time (minutes)=', '1.2860', 'loss=', '0.000430696')
# ('Epoch:', '0283', 'training time (minutes)=', '1.3556', 'loss=', '0.000427540')
# ('Epoch:', '0284', 'training time (minutes)=', '1.3013', 'loss=', '0.000430509')
# ('Epoch:', '0285', 'training time (minutes)=', '1.2697', 'loss=', '0.000426687')
# ('Epoch:', '0286', 'training time (minutes)=', '1.2741', 'loss=', '0.000429838')
# ('Epoch:', '0287', 'training time (minutes)=', '1.2978', 'loss=', '0.000425091')
# ('Epoch:', '0288', 'training time (minutes)=', '1.3058', 'loss=', '0.000436068')
# ('Epoch:', '0289', 'training time (minutes)=', '1.3061', 'loss=', '0.000428325')
# ('Epoch:', '0290', 'training time (minutes)=', '1.2316', 'loss=', '0.000424398')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '1.2576', 'loss=', '0.000430165')
# ('Epoch:', '0292', 'training time (minutes)=', '1.3032', 'loss=', '0.000433000')
# ('Epoch:', '0293', 'training time (minutes)=', '1.2079', 'loss=', '0.000427248')
# ('Epoch:', '0294', 'training time (minutes)=', '1.2276', 'loss=', '0.000427836')
# ('Epoch:', '0295', 'training time (minutes)=', '1.2270', 'loss=', '0.000431006')
# ('Epoch:', '0296', 'training time (minutes)=', '1.2474', 'loss=', '0.000428170')
# ('Epoch:', '0297', 'training time (minutes)=', '1.2552', 'loss=', '0.000431879')
# ('Epoch:', '0298', 'training time (minutes)=', '1.3020', 'loss=', '0.000433088')
# ('Epoch:', '0299', 'training time (minutes)=', '1.2858', 'loss=', '0.000425782')
# ('Epoch:', '0300', 'training time (minutes)=', '1.2960', 'loss=', '0.000431201')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '1.2827', 'loss=', '0.000431174')
# ('Epoch:', '0302', 'training time (minutes)=', '1.2317', 'loss=', '0.000425052')
# ('Epoch:', '0303', 'training time (minutes)=', '1.2243', 'loss=', '0.000427140')
# ('Epoch:', '0304', 'training time (minutes)=', '1.2221', 'loss=', '0.000428645')
# ('Epoch:', '0305', 'training time (minutes)=', '1.2374', 'loss=', '0.000424437')
# ('Epoch:', '0306', 'training time (minutes)=', '1.2428', 'loss=', '0.000428367')
# ('Epoch:', '0307', 'training time (minutes)=', '1.2451', 'loss=', '0.000427017')
# ('Epoch:', '0308', 'training time (minutes)=', '1.3420', 'loss=', '0.000425887')
# ('Epoch:', '0309', 'training time (minutes)=', '1.2540', 'loss=', '0.000426298')
# ('Epoch:', '0310', 'training time (minutes)=', '1.2671', 'loss=', '0.000421329')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '1.2366', 'loss=', '0.000427614')
# ('Epoch:', '0312', 'training time (minutes)=', '1.2349', 'loss=', '0.000422019')
# ('Epoch:', '0313', 'training time (minutes)=', '1.2945', 'loss=', '0.000424211')
# ('Epoch:', '0314', 'training time (minutes)=', '1.3039', 'loss=', '0.000426811')
# ('Epoch:', '0315', 'training time (minutes)=', '1.2778', 'loss=', '0.000425284')
# ('Epoch:', '0316', 'training time (minutes)=', '1.2953', 'loss=', '0.000428457')
# ('Epoch:', '0317', 'training time (minutes)=', '1.2821', 'loss=', '0.000427652')
# ('Epoch:', '0318', 'training time (minutes)=', '1.3323', 'loss=', '0.000427380')
# ('Epoch:', '0319', 'training time (minutes)=', '1.3019', 'loss=', '0.000425858')
# ('Epoch:', '0320', 'training time (minutes)=', '1.2151', 'loss=', '0.000419245')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '1.2802', 'loss=', '0.000426552')
# ('Epoch:', '0322', 'training time (minutes)=', '1.3394', 'loss=', '0.000423227')
# ('Epoch:', '0323', 'training time (minutes)=', '1.2806', 'loss=', '0.000420289')
# ('Epoch:', '0324', 'training time (minutes)=', '1.2844', 'loss=', '0.000427999')
# ('Epoch:', '0325', 'training time (minutes)=', '1.2780', 'loss=', '0.000424964')
# ('Epoch:', '0326', 'training time (minutes)=', '1.2618', 'loss=', '0.000422764')
# ('Epoch:', '0327', 'training time (minutes)=', '1.2199', 'loss=', '0.000426800')
# ('Epoch:', '0328', 'training time (minutes)=', '1.2944', 'loss=', '0.000423314')
# ('Epoch:', '0329', 'training time (minutes)=', '1.2245', 'loss=', '0.000428569')
# ('Epoch:', '0330', 'training time (minutes)=', '1.3347', 'loss=', '0.000431893')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '1.2263', 'loss=', '0.000427203')
# ('Epoch:', '0332', 'training time (minutes)=', '1.2635', 'loss=', '0.000427177')
# ('Epoch:', '0333', 'training time (minutes)=', '1.2641', 'loss=', '0.000423132')
# ('Epoch:', '0334', 'training time (minutes)=', '1.2267', 'loss=', '0.000422891')
# ('Epoch:', '0335', 'training time (minutes)=', '1.2715', 'loss=', '0.000424461')
# ('Epoch:', '0336', 'training time (minutes)=', '1.3037', 'loss=', '0.000422051')
# ('Epoch:', '0337', 'training time (minutes)=', '1.2886', 'loss=', '0.000418785')
# ('Epoch:', '0338', 'training time (minutes)=', '1.3205', 'loss=', '0.000420111')
# ('Epoch:', '0339', 'training time (minutes)=', '1.2669', 'loss=', '0.000420610')
# ('Epoch:', '0340', 'training time (minutes)=', '1.2600', 'loss=', '0.000421923')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '1.2684', 'loss=', '0.000425974')
# ('Epoch:', '0342', 'training time (minutes)=', '1.2301', 'loss=', '0.000418324')
# ('Epoch:', '0343', 'training time (minutes)=', '1.2444', 'loss=', '0.000422822')
# ('Epoch:', '0344', 'training time (minutes)=', '1.2634', 'loss=', '0.000428720')
# ('Epoch:', '0345', 'training time (minutes)=', '1.2751', 'loss=', '0.000422813')
# ('Epoch:', '0346', 'training time (minutes)=', '1.2912', 'loss=', '0.000425501')
# ('Epoch:', '0347', 'training time (minutes)=', '1.2211', 'loss=', '0.000421424')
# ('Epoch:', '0348', 'training time (minutes)=', '1.2491', 'loss=', '0.000422178')
# ('Epoch:', '0349', 'training time (minutes)=', '1.2427', 'loss=', '0.000422090')
# ('Epoch:', '0350', 'training time (minutes)=', '1.2213', 'loss=', '0.000420551')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '1.2263', 'loss=', '0.000420199')
# ('Epoch:', '0352', 'training time (minutes)=', '1.2241', 'loss=', '0.000418737')
# ('Epoch:', '0353', 'training time (minutes)=', '1.2796', 'loss=', '0.000422738')
# ('Epoch:', '0354', 'training time (minutes)=', '1.2706', 'loss=', '0.000429295')
# ('Epoch:', '0355', 'training time (minutes)=', '1.2621', 'loss=', '0.000423430')
# ('Epoch:', '0356', 'training time (minutes)=', '1.2961', 'loss=', '0.000420688')
# ('Epoch:', '0357', 'training time (minutes)=', '1.2484', 'loss=', '0.000419063')
# ('Epoch:', '0358', 'training time (minutes)=', '1.2756', 'loss=', '0.000421619')
# ('Epoch:', '0359', 'training time (minutes)=', '1.2640', 'loss=', '0.000420154')
# ('Epoch:', '0360', 'training time (minutes)=', '1.2787', 'loss=', '0.000427261')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0361', 'training time (minutes)=', '1.3076', 'loss=', '0.000421015')
# ('Epoch:', '0362', 'training time (minutes)=', '1.2962', 'loss=', '0.000421098')
# ('Epoch:', '0363', 'training time (minutes)=', '1.2572', 'loss=', '0.000420458')
# ('Epoch:', '0364', 'training time (minutes)=', '1.2471', 'loss=', '0.000419533')
# ('Epoch:', '0365', 'training time (minutes)=', '1.2606', 'loss=', '0.000420284')
# ('Epoch:', '0366', 'training time (minutes)=', '1.2438', 'loss=', '0.000420002')
# ('Epoch:', '0367', 'training time (minutes)=', '1.2493', 'loss=', '0.000421203')
# ('Epoch:', '0368', 'training time (minutes)=', '1.2722', 'loss=', '0.000413143')
# ('Epoch:', '0369', 'training time (minutes)=', '1.2600', 'loss=', '0.000426278')
# ('Epoch:', '0370', 'training time (minutes)=', '1.2292', 'loss=', '0.000420986')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0371', 'training time (minutes)=', '1.2516', 'loss=', '0.000420887')
# ('Epoch:', '0372', 'training time (minutes)=', '1.2500', 'loss=', '0.000424046')
# ('Epoch:', '0373', 'training time (minutes)=', '1.2606', 'loss=', '0.000418016')
# ('Epoch:', '0374', 'training time (minutes)=', '1.2178', 'loss=', '0.000419831')
# ('Epoch:', '0375', 'training time (minutes)=', '1.2682', 'loss=', '0.000431671')
# ('Epoch:', '0376', 'training time (minutes)=', '1.2750', 'loss=', '0.000419910')
# ('Epoch:', '0377', 'training time (minutes)=', '1.2313', 'loss=', '0.000418252')
# ('Epoch:', '0378', 'training time (minutes)=', '1.2194', 'loss=', '0.000429565')
# ('Epoch:', '0379', 'training time (minutes)=', '1.2487', 'loss=', '0.000419440')
# ('Epoch:', '0380', 'training time (minutes)=', '1.2317', 'loss=', '0.000416935')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0381', 'training time (minutes)=', '1.2808', 'loss=', '0.000418977')
# ('Epoch:', '0382', 'training time (minutes)=', '1.2606', 'loss=', '0.000418423')
# ('Epoch:', '0383', 'training time (minutes)=', '1.2499', 'loss=', '0.000421142')
# ('Epoch:', '0384', 'training time (minutes)=', '1.2902', 'loss=', '0.000423403')
# ('Epoch:', '0385', 'training time (minutes)=', '1.2564', 'loss=', '0.000421561')
# ('Epoch:', '0386', 'training time (minutes)=', '1.2483', 'loss=', '0.000421611')
# ('Epoch:', '0387', 'training time (minutes)=', '1.2727', 'loss=', '0.000422148')
# ('Epoch:', '0388', 'training time (minutes)=', '1.2764', 'loss=', '0.000420574')
# ('Epoch:', '0389', 'training time (minutes)=', '1.2881', 'loss=', '0.000417465')
# ('Epoch:', '0390', 'training time (minutes)=', '1.2637', 'loss=', '0.000422962')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0391', 'training time (minutes)=', '1.2676', 'loss=', '0.000417259')
# ('Epoch:', '0392', 'training time (minutes)=', '1.2795', 'loss=', '0.000426538')
# ('Epoch:', '0393', 'training time (minutes)=', '1.2542', 'loss=', '0.000419924')
# ('Epoch:', '0394', 'training time (minutes)=', '1.2618', 'loss=', '0.000429809')
# ('Epoch:', '0395', 'training time (minutes)=', '1.2313', 'loss=', '0.000421551')
# ('Epoch:', '0396', 'training time (minutes)=', '1.2371', 'loss=', '0.000420758')
# ('Epoch:', '0397', 'training time (minutes)=', '1.3106', 'loss=', '0.000419545')
# ('Epoch:', '0398', 'training time (minutes)=', '1.2782', 'loss=', '0.000427458')
# ('Epoch:', '0399', 'training time (minutes)=', '1.2199', 'loss=', '0.000420189')
# ('Epoch:', '0400', 'training time (minutes)=', '1.2611', 'loss=', '0.000415096')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0401', 'training time (minutes)=', '1.2470', 'loss=', '0.000419747')
# ('Epoch:', '0402', 'training time (minutes)=', '1.3010', 'loss=', '0.000420469')
# ('Epoch:', '0403', 'training time (minutes)=', '1.2794', 'loss=', '0.000426981')
# ('Epoch:', '0404', 'training time (minutes)=', '1.2337', 'loss=', '0.000422837')
# ('Epoch:', '0405', 'training time (minutes)=', '1.2715', 'loss=', '0.000425624')
# ('Epoch:', '0406', 'training time (minutes)=', '1.2909', 'loss=', '0.000420399')
# ('Epoch:', '0407', 'training time (minutes)=', '1.2668', 'loss=', '0.000422765')
# ('Epoch:', '0408', 'training time (minutes)=', '1.3067', 'loss=', '0.000421341')
# ('Epoch:', '0409', 'training time (minutes)=', '1.2543', 'loss=', '0.000422474')
# ('Epoch:', '0410', 'training time (minutes)=', '1.3113', 'loss=', '0.000423268')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0411', 'training time (minutes)=', '1.2704', 'loss=', '0.000419403')
# ('Epoch:', '0412', 'training time (minutes)=', '1.2988', 'loss=', '0.000422522')
# ('Epoch:', '0413', 'training time (minutes)=', '1.2704', 'loss=', '0.000414605')
# ('Epoch:', '0414', 'training time (minutes)=', '1.3176', 'loss=', '0.000419817')
# ('Epoch:', '0415', 'training time (minutes)=', '1.3157', 'loss=', '0.000416713')
# ('Epoch:', '0416', 'training time (minutes)=', '1.2817', 'loss=', '0.000416040')
# ('Epoch:', '0417', 'training time (minutes)=', '1.2936', 'loss=', '0.000412785')
# ('Epoch:', '0418', 'training time (minutes)=', '1.2830', 'loss=', '0.000427535')
# ('Epoch:', '0419', 'training time (minutes)=', '1.2496', 'loss=', '0.000419525')
# ('Epoch:', '0420', 'training time (minutes)=', '1.2653', 'loss=', '0.000415927')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0421', 'training time (minutes)=', '1.2257', 'loss=', '0.000418104')
# ('Epoch:', '0422', 'training time (minutes)=', '1.2803', 'loss=', '0.000414962')
# ('Epoch:', '0423', 'training time (minutes)=', '1.3079', 'loss=', '0.000415444')
# ('Epoch:', '0424', 'training time (minutes)=', '1.2938', 'loss=', '0.000418799')
# ('Epoch:', '0425', 'training time (minutes)=', '1.2431', 'loss=', '0.000424465')
# ('Epoch:', '0426', 'training time (minutes)=', '1.1993', 'loss=', '0.000414935')
# ('Epoch:', '0427', 'training time (minutes)=', '1.2383', 'loss=', '0.000422069')
# ('Epoch:', '0428', 'training time (minutes)=', '1.2582', 'loss=', '0.000414595')
# ('Epoch:', '0429', 'training time (minutes)=', '1.2052', 'loss=', '0.000424901')
# ('Epoch:', '0430', 'training time (minutes)=', '1.2077', 'loss=', '0.000421641')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0431', 'training time (minutes)=', '1.2078', 'loss=', '0.000419581')
# ('Epoch:', '0432', 'training time (minutes)=', '1.2042', 'loss=', '0.000418327')
# ('Epoch:', '0433', 'training time (minutes)=', '1.2412', 'loss=', '0.000420402')
# ('Epoch:', '0434', 'training time (minutes)=', '1.2191', 'loss=', '0.000415074')
# ('Epoch:', '0435', 'training time (minutes)=', '1.2220', 'loss=', '0.000417554')
# ('Epoch:', '0436', 'training time (minutes)=', '1.2164', 'loss=', '0.000421151')
# ('Epoch:', '0437', 'training time (minutes)=', '1.2304', 'loss=', '0.000421281')
# ('Epoch:', '0438', 'training time (minutes)=', '1.2360', 'loss=', '0.000425273')
# ('Epoch:', '0439', 'training time (minutes)=', '1.1863', 'loss=', '0.000419579')
# ('Epoch:', '0440', 'training time (minutes)=', '1.2173', 'loss=', '0.000413546')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0441', 'training time (minutes)=', '1.1837', 'loss=', '0.000421178')
# ('Epoch:', '0442', 'training time (minutes)=', '1.2239', 'loss=', '0.000420385')
# ('Epoch:', '0443', 'training time (minutes)=', '1.2524', 'loss=', '0.000423572')
# ('Epoch:', '0444', 'training time (minutes)=', '1.2411', 'loss=', '0.000424911')
# ('Epoch:', '0445', 'training time (minutes)=', '1.2437', 'loss=', '0.000418289')
# ('Epoch:', '0446', 'training time (minutes)=', '1.2526', 'loss=', '0.000413156')
# ('Epoch:', '0447', 'training time (minutes)=', '1.2627', 'loss=', '0.000418725')
# ('Epoch:', '0448', 'training time (minutes)=', '1.2560', 'loss=', '0.000418358')
# ('Epoch:', '0449', 'training time (minutes)=', '1.2440', 'loss=', '0.000417346')
# ('Epoch:', '0450', 'training time (minutes)=', '1.1888', 'loss=', '0.000418499')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0451', 'training time (minutes)=', '1.3061', 'loss=', '0.000419336')
# ('Epoch:', '0452', 'training time (minutes)=', '1.3064', 'loss=', '0.000415356')
# ('Epoch:', '0453', 'training time (minutes)=', '1.2494', 'loss=', '0.000418412')
# ('Epoch:', '0454', 'training time (minutes)=', '1.2693', 'loss=', '0.000415120')
# ('Epoch:', '0455', 'training time (minutes)=', '1.2200', 'loss=', '0.000415923')
# ('Epoch:', '0456', 'training time (minutes)=', '1.2365', 'loss=', '0.000420744')
# ('Epoch:', '0457', 'training time (minutes)=', '1.2684', 'loss=', '0.000408732')
# ('Epoch:', '0458', 'training time (minutes)=', '1.2629', 'loss=', '0.000417419')
# ('Epoch:', '0459', 'training time (minutes)=', '1.3075', 'loss=', '0.000418100')
# ('Epoch:', '0460', 'training time (minutes)=', '1.2765', 'loss=', '0.000417905')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0461', 'training time (minutes)=', '1.2673', 'loss=', '0.000418906')
# ('Epoch:', '0462', 'training time (minutes)=', '1.2987', 'loss=', '0.000420937')
# ('Epoch:', '0463', 'training time (minutes)=', '1.2904', 'loss=', '0.000417811')
# ('Epoch:', '0464', 'training time (minutes)=', '1.2972', 'loss=', '0.000414018')
# ('Epoch:', '0465', 'training time (minutes)=', '1.3055', 'loss=', '0.000424859')
# ('Epoch:', '0466', 'training time (minutes)=', '1.2948', 'loss=', '0.000423448')
# ('Epoch:', '0467', 'training time (minutes)=', '1.2746', 'loss=', '0.000411334')
# ('Epoch:', '0468', 'training time (minutes)=', '1.2872', 'loss=', '0.000417883')
# ('Epoch:', '0469', 'training time (minutes)=', '1.2424', 'loss=', '0.000417978')
# ('Epoch:', '0470', 'training time (minutes)=', '1.2496', 'loss=', '0.000417340')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-470 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0471', 'training time (minutes)=', '1.2337', 'loss=', '0.000417979')
# ('Epoch:', '0472', 'training time (minutes)=', '1.2334', 'loss=', '0.000419088')
# ('Epoch:', '0473', 'training time (minutes)=', '1.2587', 'loss=', '0.000420864')
# ('Epoch:', '0474', 'training time (minutes)=', '1.2535', 'loss=', '0.000416038')
# ('Epoch:', '0475', 'training time (minutes)=', '1.3001', 'loss=', '0.000425996')
# ('Epoch:', '0476', 'training time (minutes)=', '1.2601', 'loss=', '0.000422894')
# ('Epoch:', '0477', 'training time (minutes)=', '1.2234', 'loss=', '0.000428300')
# ('Epoch:', '0478', 'training time (minutes)=', '1.3030', 'loss=', '0.000425618')
# ('Epoch:', '0479', 'training time (minutes)=', '1.2961', 'loss=', '0.000414896')
# ('Epoch:', '0480', 'training time (minutes)=', '1.3086', 'loss=', '0.000421473')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-480 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0481', 'training time (minutes)=', '1.2755', 'loss=', '0.000414003')
# ('Epoch:', '0482', 'training time (minutes)=', '1.3005', 'loss=', '0.000421976')
# ('Epoch:', '0483', 'training time (minutes)=', '1.2998', 'loss=', '0.000417925')
# ('Epoch:', '0484', 'training time (minutes)=', '1.2929', 'loss=', '0.000416989')
# ('Epoch:', '0485', 'training time (minutes)=', '1.2673', 'loss=', '0.000423734')
# ('Epoch:', '0486', 'training time (minutes)=', '1.2850', 'loss=', '0.000415427')
# ('Epoch:', '0487', 'training time (minutes)=', '1.2451', 'loss=', '0.000423713')
# ('Epoch:', '0488', 'training time (minutes)=', '1.2515', 'loss=', '0.000417917')
# ('Epoch:', '0489', 'training time (minutes)=', '1.3003', 'loss=', '0.000417726')
# ('Epoch:', '0490', 'training time (minutes)=', '1.3077', 'loss=', '0.000422308')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-490 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0491', 'training time (minutes)=', '1.2537', 'loss=', '0.000423951')
# ('Epoch:', '0492', 'training time (minutes)=', '1.2976', 'loss=', '0.000413984')
# ('Epoch:', '0493', 'training time (minutes)=', '1.2997', 'loss=', '0.000424501')
# ('Epoch:', '0494', 'training time (minutes)=', '1.3142', 'loss=', '0.000427922')
# ('Epoch:', '0495', 'training time (minutes)=', '1.2881', 'loss=', '0.000415565')
# ('Epoch:', '0496', 'training time (minutes)=', '1.2672', 'loss=', '0.000425689')
# ('Epoch:', '0497', 'training time (minutes)=', '1.2537', 'loss=', '0.000422519')
# ('Epoch:', '0498', 'training time (minutes)=', '1.2980', 'loss=', '0.000432753')
# ('Epoch:', '0499', 'training time (minutes)=', '1.2917', 'loss=', '0.000422672')
# ('Epoch:', '0500', 'training time (minutes)=', '1.2894', 'loss=', '0.000415305')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-500 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0501', 'training time (minutes)=', '1.3235', 'loss=', '0.000415819')
# ('Epoch:', '0502', 'training time (minutes)=', '1.2588', 'loss=', '0.000420511')
# ('Epoch:', '0503', 'training time (minutes)=', '1.2933', 'loss=', '0.000421205')
# ('Epoch:', '0504', 'training time (minutes)=', '1.2376', 'loss=', '0.000422403')
# ('Epoch:', '0505', 'training time (minutes)=', '1.2978', 'loss=', '0.000420789')
# ('Epoch:', '0506', 'training time (minutes)=', '1.2730', 'loss=', '0.000409551')
# ('Epoch:', '0507', 'training time (minutes)=', '1.2844', 'loss=', '0.000417788')
# ('Epoch:', '0508', 'training time (minutes)=', '1.2521', 'loss=', '0.000413001')
# ('Epoch:', '0509', 'training time (minutes)=', '1.2668', 'loss=', '0.000420131')
# ('Epoch:', '0510', 'training time (minutes)=', '1.2724', 'loss=', '0.000415662')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-510 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0511', 'training time (minutes)=', '1.2600', 'loss=', '0.000417221')
# ('Epoch:', '0512', 'training time (minutes)=', '1.2266', 'loss=', '0.000420641')
# ('Epoch:', '0513', 'training time (minutes)=', '1.2854', 'loss=', '0.000421410')
# ('Epoch:', '0514', 'training time (minutes)=', '1.2594', 'loss=', '0.000411830')
# ('Epoch:', '0515', 'training time (minutes)=', '1.2306', 'loss=', '0.000408615')
# ('Epoch:', '0516', 'training time (minutes)=', '1.2609', 'loss=', '0.000425619')
# ('Epoch:', '0517', 'training time (minutes)=', '1.2473', 'loss=', '0.000414971')
# ('Epoch:', '0518', 'training time (minutes)=', '1.2793', 'loss=', '0.000413582')
# ('Epoch:', '0519', 'training time (minutes)=', '1.2783', 'loss=', '0.000418777')
# ('Epoch:', '0520', 'training time (minutes)=', '1.2546', 'loss=', '0.000418193')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-520 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0521', 'training time (minutes)=', '1.2352', 'loss=', '0.000419289')
# ('Epoch:', '0522', 'training time (minutes)=', '1.2192', 'loss=', '0.000412392')
# ('Epoch:', '0523', 'training time (minutes)=', '1.2654', 'loss=', '0.000417712')
# ('Epoch:', '0524', 'training time (minutes)=', '1.2361', 'loss=', '0.000416410')
# ('Epoch:', '0525', 'training time (minutes)=', '1.2379', 'loss=', '0.000415208')
# ('Epoch:', '0526', 'training time (minutes)=', '1.2285', 'loss=', '0.000420782')
# ('Epoch:', '0527', 'training time (minutes)=', '1.2257', 'loss=', '0.000417478')
# ('Epoch:', '0528', 'training time (minutes)=', '1.3242', 'loss=', '0.000413429')
# ('Epoch:', '0529', 'training time (minutes)=', '1.2782', 'loss=', '0.000416269')
# ('Epoch:', '0530', 'training time (minutes)=', '1.2595', 'loss=', '0.000413633')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-530 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0531', 'training time (minutes)=', '1.2659', 'loss=', '0.000415043')
# ('Epoch:', '0532', 'training time (minutes)=', '1.2411', 'loss=', '0.000418799')
# ('Epoch:', '0533', 'training time (minutes)=', '1.2373', 'loss=', '0.000416948')
# ('Epoch:', '0534', 'training time (minutes)=', '1.1978', 'loss=', '0.000415755')
# ('Epoch:', '0535', 'training time (minutes)=', '1.3131', 'loss=', '0.000420067')
# ('Epoch:', '0536', 'training time (minutes)=', '1.2851', 'loss=', '0.000421117')
# ('Epoch:', '0537', 'training time (minutes)=', '1.2282', 'loss=', '0.000415810')
# ('Epoch:', '0538', 'training time (minutes)=', '1.2632', 'loss=', '0.000420613')
# ('Epoch:', '0539', 'training time (minutes)=', '1.2354', 'loss=', '0.000421131')
# ('Epoch:', '0540', 'training time (minutes)=', '1.2607', 'loss=', '0.000427799')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-540 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0541', 'training time (minutes)=', '1.2904', 'loss=', '0.000417088')
# ('Epoch:', '0542', 'training time (minutes)=', '1.2589', 'loss=', '0.000420163')
# ('Epoch:', '0543', 'training time (minutes)=', '1.2561', 'loss=', '0.000419867')
# ('Epoch:', '0544', 'training time (minutes)=', '1.3083', 'loss=', '0.000410816')
# ('Epoch:', '0545', 'training time (minutes)=', '1.2586', 'loss=', '0.000418604')
# ('Epoch:', '0546', 'training time (minutes)=', '1.2806', 'loss=', '0.000423702')
# ('Epoch:', '0547', 'training time (minutes)=', '1.2616', 'loss=', '0.000414922')
# ('Epoch:', '0548', 'training time (minutes)=', '1.3069', 'loss=', '0.000408621')
# ('Epoch:', '0549', 'training time (minutes)=', '1.2948', 'loss=', '0.000424124')
# ('Epoch:', '0550', 'training time (minutes)=', '1.2590', 'loss=', '0.000412616')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-550 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0551', 'training time (minutes)=', '1.2627', 'loss=', '0.000409607')
# ('Epoch:', '0552', 'training time (minutes)=', '1.2688', 'loss=', '0.000413789')
# ('Epoch:', '0553', 'training time (minutes)=', '1.2840', 'loss=', '0.000415155')
# ('Epoch:', '0554', 'training time (minutes)=', '1.2361', 'loss=', '0.000422404')
# ('Epoch:', '0555', 'training time (minutes)=', '1.2660', 'loss=', '0.000414320')
# ('Epoch:', '0556', 'training time (minutes)=', '1.2617', 'loss=', '0.000413679')
# ('Epoch:', '0557', 'training time (minutes)=', '1.2714', 'loss=', '0.000416136')
# ('Epoch:', '0558', 'training time (minutes)=', '1.2795', 'loss=', '0.000424627')
# ('Epoch:', '0559', 'training time (minutes)=', '1.2479', 'loss=', '0.000415744')
# ('Epoch:', '0560', 'training time (minutes)=', '1.2665', 'loss=', '0.000405253')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-560 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0561', 'training time (minutes)=', '1.2561', 'loss=', '0.000406633')
# ('Epoch:', '0562', 'training time (minutes)=', '1.2832', 'loss=', '0.000413626')
# ('Epoch:', '0563', 'training time (minutes)=', '1.2442', 'loss=', '0.000416926')
# ('Epoch:', '0564', 'training time (minutes)=', '1.2634', 'loss=', '0.000408186')
# ('Epoch:', '0565', 'training time (minutes)=', '1.2910', 'loss=', '0.000409553')
# ('Epoch:', '0566', 'training time (minutes)=', '1.2716', 'loss=', '0.000426177')
# ('Epoch:', '0567', 'training time (minutes)=', '1.2988', 'loss=', '0.000418253')
# ('Epoch:', '0568', 'training time (minutes)=', '1.2157', 'loss=', '0.000413408')
# ('Epoch:', '0569', 'training time (minutes)=', '1.2295', 'loss=', '0.000425319')
# ('Epoch:', '0570', 'training time (minutes)=', '1.2796', 'loss=', '0.000424342')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-570 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0571', 'training time (minutes)=', '1.2687', 'loss=', '0.000420967')
# ('Epoch:', '0572', 'training time (minutes)=', '1.2638', 'loss=', '0.000414057')
# ('Epoch:', '0573', 'training time (minutes)=', '1.2392', 'loss=', '0.000426156')
# ('Epoch:', '0574', 'training time (minutes)=', '1.2951', 'loss=', '0.000417039')
