# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 2
setup_one_gpu(GPU)
# Out:
# Picking GPU 2

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs

from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry_new, decoder_with_fc_only
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tf_lab.iclr.helper import load_multiple_version_of_pcs

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = True
load_model = False
seed = 42
max_training_epochs = 2000
loss = 'chamfer'
z_rotate = True
experiment_name = 'all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm' + str(n_pc_samples) +  'pts_' + loss

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'

# %%
n_threads = 25
verbose = True
version = 'centered'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', version, str(n_pc_samples))
full_file_names = [f for f in files_in_subdirs(full_pclouds_path, '.ply')]
pclouds, _, _ = load_point_clouds_from_filenames(full_file_names, n_threads, snc_loader, verbose)
train_data = PointCloudDataSet(pclouds)
print train_data.num_examples
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:38: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')
# 57449 pclouds were loaded. They belong in 57 shape-classes.
# 57449

# %%
train_dir = osp.join('/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc', experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer'

# %%
n_input = [n_pc_samples, 3]

encoder_args = {'n_filters': [64, 128, 128, 256, 512],
                'filter_sizes': [1, 1, 1, 1, 1],
                'strides': [1, 1, 1, 1, 1],
                'b_norm': False
               }

decoder_args = {'layer_sizes': [512, 1024, np.prod(n_input)],
                'b_norm': False
               }

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = encoder_with_convs_and_symmetry_new,
                encoder_args = encoder_args,
                decoder = decoder_with_fc_only,
                decoder_args = decoder_args,            
               )
    conf.allow_gpu_growth = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)
        
if load_model and do_training:
    conf.training_epochs -= last_epoch
    print conf.training_epochs

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)    
    train_stats = ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.1396', 'loss=', '0.002491967')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '1.1305', 'loss=', '0.001144335')
# ('Epoch:', '0003', 'training time (minutes)=', '1.1496', 'loss=', '0.000992449')
# ('Epoch:', '0004', 'training time (minutes)=', '1.1516', 'loss=', '0.000881270')
# ('Epoch:', '0005', 'training time (minutes)=', '1.1439', 'loss=', '0.000829865')
# ('Epoch:', '0006', 'training time (minutes)=', '1.1526', 'loss=', '0.000804002')
# ('Epoch:', '0007', 'training time (minutes)=', '1.1554', 'loss=', '0.000750410')
# ('Epoch:', '0008', 'training time (minutes)=', '1.1524', 'loss=', '0.000749933')
# ('Epoch:', '0009', 'training time (minutes)=', '1.1532', 'loss=', '0.000707480')
# ('Epoch:', '0010', 'training time (minutes)=', '1.1531', 'loss=', '0.000683991')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '1.1441', 'loss=', '0.000680190')
# ('Epoch:', '0012', 'training time (minutes)=', '1.1535', 'loss=', '0.000651904')
# ('Epoch:', '0013', 'training time (minutes)=', '1.1542', 'loss=', '0.000651809')
# ('Epoch:', '0014', 'training time (minutes)=', '1.1537', 'loss=', '0.000633931')
# ('Epoch:', '0015', 'training time (minutes)=', '1.1514', 'loss=', '0.000643379')
# ('Epoch:', '0016', 'training time (minutes)=', '1.1510', 'loss=', '0.000631659')
# ('Epoch:', '0017', 'training time (minutes)=', '1.1510', 'loss=', '0.000620876')
# ('Epoch:', '0018', 'training time (minutes)=', '1.1528', 'loss=', '0.000600379')
# ('Epoch:', '0019', 'training time (minutes)=', '1.1359', 'loss=', '0.000599768')
# ('Epoch:', '0020', 'training time (minutes)=', '1.1510', 'loss=', '0.000599113')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '1.1473', 'loss=', '0.000595877')
# ('Epoch:', '0022', 'training time (minutes)=', '1.1428', 'loss=', '0.000584013')
# ('Epoch:', '0023', 'training time (minutes)=', '1.1443', 'loss=', '0.000570624')
# ('Epoch:', '0024', 'training time (minutes)=', '1.1550', 'loss=', '0.000578591')
# ('Epoch:', '0025', 'training time (minutes)=', '1.1530', 'loss=', '0.000579424')
# ('Epoch:', '0026', 'training time (minutes)=', '1.1529', 'loss=', '0.000556906')
# ('Epoch:', '0027', 'training time (minutes)=', '1.1537', 'loss=', '0.000564454')
# ('Epoch:', '0028', 'training time (minutes)=', '1.1523', 'loss=', '0.000561611')
# ('Epoch:', '0029', 'training time (minutes)=', '1.1520', 'loss=', '0.000569061')
# ('Epoch:', '0030', 'training time (minutes)=', '1.1517', 'loss=', '0.000548246')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '1.1548', 'loss=', '0.000551582')
# ('Epoch:', '0032', 'training time (minutes)=', '1.1504', 'loss=', '0.000544891')
# ('Epoch:', '0033', 'training time (minutes)=', '1.1481', 'loss=', '0.000535007')
# ('Epoch:', '0034', 'training time (minutes)=', '1.1512', 'loss=', '0.000540372')
# ('Epoch:', '0035', 'training time (minutes)=', '1.1520', 'loss=', '0.000544313')
# ('Epoch:', '0036', 'training time (minutes)=', '1.1485', 'loss=', '0.000537851')
# ('Epoch:', '0037', 'training time (minutes)=', '1.1524', 'loss=', '0.000518016')
# ('Epoch:', '0038', 'training time (minutes)=', '1.1507', 'loss=', '0.000530288')
# ('Epoch:', '0039', 'training time (minutes)=', '1.1532', 'loss=', '0.000529655')
# ('Epoch:', '0040', 'training time (minutes)=', '1.1528', 'loss=', '0.000527134')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '1.1557', 'loss=', '0.000531721')
# ('Epoch:', '0042', 'training time (minutes)=', '1.1551', 'loss=', '0.000514437')
# ('Epoch:', '0043', 'training time (minutes)=', '1.1524', 'loss=', '0.000528497')
# ('Epoch:', '0044', 'training time (minutes)=', '1.1630', 'loss=', '0.000517342')
# ('Epoch:', '0045', 'training time (minutes)=', '1.1620', 'loss=', '0.000527018')
# ('Epoch:', '0046', 'training time (minutes)=', '1.1785', 'loss=', '0.000523957')
# ('Epoch:', '0047', 'training time (minutes)=', '1.1832', 'loss=', '0.000514448')
# ('Epoch:', '0048', 'training time (minutes)=', '1.1832', 'loss=', '0.000515312')
# ('Epoch:', '0049', 'training time (minutes)=', '1.1873', 'loss=', '0.000513222')
# ('Epoch:', '0050', 'training time (minutes)=', '1.1840', 'loss=', '0.000514981')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '1.1893', 'loss=', '0.000512307')
# ('Epoch:', '0052', 'training time (minutes)=', '1.1931', 'loss=', '0.000512938')
# ('Epoch:', '0053', 'training time (minutes)=', '1.1913', 'loss=', '0.000499876')
# ('Epoch:', '0054', 'training time (minutes)=', '1.1917', 'loss=', '0.000507529')
# ('Epoch:', '0055', 'training time (minutes)=', '1.1882', 'loss=', '0.000511771')
# ('Epoch:', '0056', 'training time (minutes)=', '1.1968', 'loss=', '0.000508837')
# ('Epoch:', '0057', 'training time (minutes)=', '1.1878', 'loss=', '0.000502960')
# ('Epoch:', '0058', 'training time (minutes)=', '1.1885', 'loss=', '0.000509256')
# ('Epoch:', '0059', 'training time (minutes)=', '1.1757', 'loss=', '0.000499506')
# ('Epoch:', '0060', 'training time (minutes)=', '1.1766', 'loss=', '0.000509171')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '1.1666', 'loss=', '0.000499486')
# ('Epoch:', '0062', 'training time (minutes)=', '1.1671', 'loss=', '0.000497627')
# ('Epoch:', '0063', 'training time (minutes)=', '1.1663', 'loss=', '0.000493638')
# ('Epoch:', '0064', 'training time (minutes)=', '1.1680', 'loss=', '0.000501131')
# ('Epoch:', '0065', 'training time (minutes)=', '1.1694', 'loss=', '0.000494135')
# ('Epoch:', '0066', 'training time (minutes)=', '1.1686', 'loss=', '0.000491111')
# ('Epoch:', '0067', 'training time (minutes)=', '1.1687', 'loss=', '0.000492995')
# ('Epoch:', '0068', 'training time (minutes)=', '1.1632', 'loss=', '0.000497257')
# ('Epoch:', '0069', 'training time (minutes)=', '1.1760', 'loss=', '0.000491966')
# ('Epoch:', '0070', 'training time (minutes)=', '1.1801', 'loss=', '0.000487896')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '1.1790', 'loss=', '0.000491343')
# ('Epoch:', '0072', 'training time (minutes)=', '1.1733', 'loss=', '0.000481903')
# ('Epoch:', '0073', 'training time (minutes)=', '1.1715', 'loss=', '0.000489321')
# ('Epoch:', '0074', 'training time (minutes)=', '1.1711', 'loss=', '0.000495254')
# ('Epoch:', '0075', 'training time (minutes)=', '1.1767', 'loss=', '0.000489771')
# ('Epoch:', '0076', 'training time (minutes)=', '1.1668', 'loss=', '0.000481737')
# ('Epoch:', '0077', 'training time (minutes)=', '1.1733', 'loss=', '0.000487235')
# ('Epoch:', '0078', 'training time (minutes)=', '1.1695', 'loss=', '0.000478118')
# ('Epoch:', '0079', 'training time (minutes)=', '1.1727', 'loss=', '0.000483393')
# ('Epoch:', '0080', 'training time (minutes)=', '1.1731', 'loss=', '0.000491779')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '1.1703', 'loss=', '0.000480298')
# ('Epoch:', '0082', 'training time (minutes)=', '1.1774', 'loss=', '0.000474729')
# ('Epoch:', '0083', 'training time (minutes)=', '1.1731', 'loss=', '0.000485484')
# ('Epoch:', '0084', 'training time (minutes)=', '1.1702', 'loss=', '0.000483473')
# ('Epoch:', '0085', 'training time (minutes)=', '1.1791', 'loss=', '0.000478576')
# ('Epoch:', '0086', 'training time (minutes)=', '1.1740', 'loss=', '0.000482737')
# ('Epoch:', '0087', 'training time (minutes)=', '1.1771', 'loss=', '0.000484508')
# ('Epoch:', '0088', 'training time (minutes)=', '1.1665', 'loss=', '0.000487059')
# ('Epoch:', '0089', 'training time (minutes)=', '1.1682', 'loss=', '0.000475360')
# ('Epoch:', '0090', 'training time (minutes)=', '1.1666', 'loss=', '0.000474481')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '1.1737', 'loss=', '0.000475515')
# ('Epoch:', '0092', 'training time (minutes)=', '1.1607', 'loss=', '0.000476574')
# ('Epoch:', '0093', 'training time (minutes)=', '1.1670', 'loss=', '0.000473541')
# ('Epoch:', '0094', 'training time (minutes)=', '1.1499', 'loss=', '0.000474555')
# ('Epoch:', '0095', 'training time (minutes)=', '1.1522', 'loss=', '0.000478245')
# ('Epoch:', '0096', 'training time (minutes)=', '1.1555', 'loss=', '0.000473124')
# ('Epoch:', '0097', 'training time (minutes)=', '1.1489', 'loss=', '0.000475006')
# ('Epoch:', '0098', 'training time (minutes)=', '1.1485', 'loss=', '0.000470012')
# ('Epoch:', '0099', 'training time (minutes)=', '1.1479', 'loss=', '0.000472077')
# ('Epoch:', '0100', 'training time (minutes)=', '1.1545', 'loss=', '0.000473824')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '1.1507', 'loss=', '0.000476965')
# ('Epoch:', '0102', 'training time (minutes)=', '1.1500', 'loss=', '0.000470323')
# ('Epoch:', '0103', 'training time (minutes)=', '1.1516', 'loss=', '0.000474184')
# ('Epoch:', '0104', 'training time (minutes)=', '1.1474', 'loss=', '0.000468290')
# ('Epoch:', '0105', 'training time (minutes)=', '1.1514', 'loss=', '0.000467883')
# ('Epoch:', '0106', 'training time (minutes)=', '1.1505', 'loss=', '0.000466630')
# ('Epoch:', '0107', 'training time (minutes)=', '1.1546', 'loss=', '0.000462497')
# ('Epoch:', '0108', 'training time (minutes)=', '1.1483', 'loss=', '0.000470596')
# ('Epoch:', '0109', 'training time (minutes)=', '1.1462', 'loss=', '0.000469790')
# ('Epoch:', '0110', 'training time (minutes)=', '1.1519', 'loss=', '0.000469261')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '1.1561', 'loss=', '0.000459164')
# ('Epoch:', '0112', 'training time (minutes)=', '1.1469', 'loss=', '0.000465247')
# ('Epoch:', '0113', 'training time (minutes)=', '1.1437', 'loss=', '0.000471460')
# ('Epoch:', '0114', 'training time (minutes)=', '1.1458', 'loss=', '0.000468499')
# ('Epoch:', '0115', 'training time (minutes)=', '1.1480', 'loss=', '0.000466180')
# ('Epoch:', '0116', 'training time (minutes)=', '1.1462', 'loss=', '0.000470531')
# ('Epoch:', '0117', 'training time (minutes)=', '1.1524', 'loss=', '0.000464101')
# ('Epoch:', '0118', 'training time (minutes)=', '1.1501', 'loss=', '0.000464009')
# ('Epoch:', '0119', 'training time (minutes)=', '1.1515', 'loss=', '0.000464540')
# ('Epoch:', '0120', 'training time (minutes)=', '1.1509', 'loss=', '0.000456952')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '1.1528', 'loss=', '0.000459902')
# ('Epoch:', '0122', 'training time (minutes)=', '1.1531', 'loss=', '0.000463412')
# ('Epoch:', '0123', 'training time (minutes)=', '1.1526', 'loss=', '0.000456066')
# ('Epoch:', '0124', 'training time (minutes)=', '1.1545', 'loss=', '0.000460380')
# ('Epoch:', '0125', 'training time (minutes)=', '1.1527', 'loss=', '0.000466709')
# ('Epoch:', '0126', 'training time (minutes)=', '1.1521', 'loss=', '0.000451863')
# ('Epoch:', '0127', 'training time (minutes)=', '1.1533', 'loss=', '0.000452663')
# ('Epoch:', '0128', 'training time (minutes)=', '1.1564', 'loss=', '0.000461729')
# ('Epoch:', '0129', 'training time (minutes)=', '1.1525', 'loss=', '0.000466393')
# ('Epoch:', '0130', 'training time (minutes)=', '1.1569', 'loss=', '0.000455035')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '1.1459', 'loss=', '0.000452685')
# ('Epoch:', '0132', 'training time (minutes)=', '1.1528', 'loss=', '0.000456413')
# ('Epoch:', '0133', 'training time (minutes)=', '1.1558', 'loss=', '0.000465152')
# ('Epoch:', '0134', 'training time (minutes)=', '1.1504', 'loss=', '0.000455739')
# ('Epoch:', '0135', 'training time (minutes)=', '1.1515', 'loss=', '0.000458316')
# ('Epoch:', '0136', 'training time (minutes)=', '1.1532', 'loss=', '0.000455391')
# ('Epoch:', '0137', 'training time (minutes)=', '1.1584', 'loss=', '0.000460825')
# ('Epoch:', '0138', 'training time (minutes)=', '1.1527', 'loss=', '0.000463612')
# ('Epoch:', '0139', 'training time (minutes)=', '1.1631', 'loss=', '0.000449934')
# ('Epoch:', '0140', 'training time (minutes)=', '1.1607', 'loss=', '0.000454795')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '1.1551', 'loss=', '0.000451325')
# ('Epoch:', '0142', 'training time (minutes)=', '1.1565', 'loss=', '0.000458540')
# ('Epoch:', '0143', 'training time (minutes)=', '1.1589', 'loss=', '0.000456394')
# ('Epoch:', '0144', 'training time (minutes)=', '1.1553', 'loss=', '0.000455011')
# ('Epoch:', '0145', 'training time (minutes)=', '1.1679', 'loss=', '0.000453499')
# ('Epoch:', '0146', 'training time (minutes)=', '1.1644', 'loss=', '0.000450228')
# ('Epoch:', '0147', 'training time (minutes)=', '1.1570', 'loss=', '0.000456669')
# ('Epoch:', '0148', 'training time (minutes)=', '1.1584', 'loss=', '0.000453308')
# ('Epoch:', '0149', 'training time (minutes)=', '1.1600', 'loss=', '0.000453641')
# ('Epoch:', '0150', 'training time (minutes)=', '1.1518', 'loss=', '0.000452526')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '1.1521', 'loss=', '0.000451610')
# ('Epoch:', '0152', 'training time (minutes)=', '1.1532', 'loss=', '0.000450264')
# ('Epoch:', '0153', 'training time (minutes)=', '1.1403', 'loss=', '0.000451121')
# ('Epoch:', '0154', 'training time (minutes)=', '1.1460', 'loss=', '0.000446485')
# ('Epoch:', '0155', 'training time (minutes)=', '1.1471', 'loss=', '0.000453588')
# ('Epoch:', '0156', 'training time (minutes)=', '1.1526', 'loss=', '0.000449288')
# ('Epoch:', '0157', 'training time (minutes)=', '1.1519', 'loss=', '0.000443438')
# ('Epoch:', '0158', 'training time (minutes)=', '1.1544', 'loss=', '0.000449153')
# ('Epoch:', '0159', 'training time (minutes)=', '1.1502', 'loss=', '0.000446289')
# ('Epoch:', '0160', 'training time (minutes)=', '1.1465', 'loss=', '0.000452062')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '1.1535', 'loss=', '0.000447972')
# ('Epoch:', '0162', 'training time (minutes)=', '1.1447', 'loss=', '0.000449706')
# ('Epoch:', '0163', 'training time (minutes)=', '1.1514', 'loss=', '0.000442347')
# ('Epoch:', '0164', 'training time (minutes)=', '1.1549', 'loss=', '0.000439561')
# ('Epoch:', '0165', 'training time (minutes)=', '1.1501', 'loss=', '0.000451452')
# ('Epoch:', '0166', 'training time (minutes)=', '1.1538', 'loss=', '0.000440872')
# ('Epoch:', '0167', 'training time (minutes)=', '1.1508', 'loss=', '0.000441756')
# ('Epoch:', '0168', 'training time (minutes)=', '1.1579', 'loss=', '0.000452582')
# ('Epoch:', '0169', 'training time (minutes)=', '1.1536', 'loss=', '0.000447036')
# ('Epoch:', '0170', 'training time (minutes)=', '1.1556', 'loss=', '0.000447369')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '1.1571', 'loss=', '0.000443299')
# ('Epoch:', '0172', 'training time (minutes)=', '1.1576', 'loss=', '0.000438592')
# ('Epoch:', '0173', 'training time (minutes)=', '1.1630', 'loss=', '0.000443375')
# ('Epoch:', '0174', 'training time (minutes)=', '1.1502', 'loss=', '0.000442416')
# ('Epoch:', '0175', 'training time (minutes)=', '1.1597', 'loss=', '0.000446850')
# ('Epoch:', '0176', 'training time (minutes)=', '1.1556', 'loss=', '0.000444563')
# ('Epoch:', '0177', 'training time (minutes)=', '1.1466', 'loss=', '0.000443708')
# ('Epoch:', '0178', 'training time (minutes)=', '1.1507', 'loss=', '0.000442682')
# ('Epoch:', '0179', 'training time (minutes)=', '1.1600', 'loss=', '0.000434991')
# ('Epoch:', '0180', 'training time (minutes)=', '1.1565', 'loss=', '0.000447552')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '1.1583', 'loss=', '0.000438629')
# ('Epoch:', '0182', 'training time (minutes)=', '1.1634', 'loss=', '0.000436106')
# ('Epoch:', '0183', 'training time (minutes)=', '1.1448', 'loss=', '0.000440585')
# ('Epoch:', '0184', 'training time (minutes)=', '1.1566', 'loss=', '0.000449222')
# ('Epoch:', '0185', 'training time (minutes)=', '1.1555', 'loss=', '0.000434312')
# ('Epoch:', '0186', 'training time (minutes)=', '1.1461', 'loss=', '0.000437852')
# ('Epoch:', '0187', 'training time (minutes)=', '1.1543', 'loss=', '0.000440365')
# ('Epoch:', '0188', 'training time (minutes)=', '1.1571', 'loss=', '0.000438427')
# ('Epoch:', '0189', 'training time (minutes)=', '1.1543', 'loss=', '0.000438061')
# ('Epoch:', '0190', 'training time (minutes)=', '1.1545', 'loss=', '0.000437642')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '1.1542', 'loss=', '0.000437160')
# ('Epoch:', '0192', 'training time (minutes)=', '1.1550', 'loss=', '0.000437881')
# ('Epoch:', '0193', 'training time (minutes)=', '1.1550', 'loss=', '0.000438385')
# ('Epoch:', '0194', 'training time (minutes)=', '1.1486', 'loss=', '0.000439712')
# ('Epoch:', '0195', 'training time (minutes)=', '1.1499', 'loss=', '0.000443254')
# ('Epoch:', '0196', 'training time (minutes)=', '1.1519', 'loss=', '0.000433938')
# ('Epoch:', '0197', 'training time (minutes)=', '1.1501', 'loss=', '0.000435638')
# ('Epoch:', '0198', 'training time (minutes)=', '1.1489', 'loss=', '0.000436448')
# ('Epoch:', '0199', 'training time (minutes)=', '1.1532', 'loss=', '0.000431637')
# ('Epoch:', '0200', 'training time (minutes)=', '1.1470', 'loss=', '0.000435959')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '1.1460', 'loss=', '0.000427539')
# ('Epoch:', '0202', 'training time (minutes)=', '1.1499', 'loss=', '0.000434759')
# ('Epoch:', '0203', 'training time (minutes)=', '1.1466', 'loss=', '0.000436973')
# ('Epoch:', '0204', 'training time (minutes)=', '1.1510', 'loss=', '0.000434257')
# ('Epoch:', '0205', 'training time (minutes)=', '1.1524', 'loss=', '0.000439611')
# ('Epoch:', '0206', 'training time (minutes)=', '1.1494', 'loss=', '0.000435194')
# ('Epoch:', '0207', 'training time (minutes)=', '1.1431', 'loss=', '0.000424852')
# ('Epoch:', '0208', 'training time (minutes)=', '1.1492', 'loss=', '0.000438572')
# ('Epoch:', '0209', 'training time (minutes)=', '1.1565', 'loss=', '0.000438761')
# ('Epoch:', '0210', 'training time (minutes)=', '1.1523', 'loss=', '0.000429680')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '1.1529', 'loss=', '0.000438892')
# ('Epoch:', '0212', 'training time (minutes)=', '1.1554', 'loss=', '0.000435063')
# ('Epoch:', '0213', 'training time (minutes)=', '1.1541', 'loss=', '0.000436298')
# ('Epoch:', '0214', 'training time (minutes)=', '1.1508', 'loss=', '0.000435050')
# ('Epoch:', '0215', 'training time (minutes)=', '1.1489', 'loss=', '0.000439899')
# ('Epoch:', '0216', 'training time (minutes)=', '1.1494', 'loss=', '0.000444205')
# ('Epoch:', '0217', 'training time (minutes)=', '1.1484', 'loss=', '0.000430314')
# ('Epoch:', '0218', 'training time (minutes)=', '1.1506', 'loss=', '0.000436725')
# ('Epoch:', '0219', 'training time (minutes)=', '1.1493', 'loss=', '0.000431047')
# ('Epoch:', '0220', 'training time (minutes)=', '1.1453', 'loss=', '0.000432728')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '1.1526', 'loss=', '0.000432881')
# ('Epoch:', '0222', 'training time (minutes)=', '1.1528', 'loss=', '0.000437028')
# ('Epoch:', '0223', 'training time (minutes)=', '1.1447', 'loss=', '0.000435720')
# ('Epoch:', '0224', 'training time (minutes)=', '1.1474', 'loss=', '0.000430876')
# ('Epoch:', '0225', 'training time (minutes)=', '1.1508', 'loss=', '0.000423329')
# ('Epoch:', '0226', 'training time (minutes)=', '1.1423', 'loss=', '0.000425750')
# ('Epoch:', '0227', 'training time (minutes)=', '1.1479', 'loss=', '0.000431642')
# ('Epoch:', '0228', 'training time (minutes)=', '1.1454', 'loss=', '0.000432237')
# ('Epoch:', '0229', 'training time (minutes)=', '1.1477', 'loss=', '0.000429795')
# ('Epoch:', '0230', 'training time (minutes)=', '1.1504', 'loss=', '0.000426773')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '1.1535', 'loss=', '0.000425020')
# ('Epoch:', '0232', 'training time (minutes)=', '1.1508', 'loss=', '0.000422741')
# ('Epoch:', '0233', 'training time (minutes)=', '1.1519', 'loss=', '0.000425521')
# ('Epoch:', '0234', 'training time (minutes)=', '1.1413', 'loss=', '0.000428253')
# ('Epoch:', '0235', 'training time (minutes)=', '1.1471', 'loss=', '0.000427627')
# ('Epoch:', '0236', 'training time (minutes)=', '1.1532', 'loss=', '0.000421935')
# ('Epoch:', '0237', 'training time (minutes)=', '1.1424', 'loss=', '0.000427048')
# ('Epoch:', '0238', 'training time (minutes)=', '1.1414', 'loss=', '0.000430667')
# ('Epoch:', '0239', 'training time (minutes)=', '1.1479', 'loss=', '0.000432109')
# ('Epoch:', '0240', 'training time (minutes)=', '1.1457', 'loss=', '0.000427838')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '1.1501', 'loss=', '0.000417373')
# ('Epoch:', '0242', 'training time (minutes)=', '1.1464', 'loss=', '0.000431416')
# ('Epoch:', '0243', 'training time (minutes)=', '1.1425', 'loss=', '0.000422311')
# ('Epoch:', '0244', 'training time (minutes)=', '1.1464', 'loss=', '0.000430513')
# ('Epoch:', '0245', 'training time (minutes)=', '1.1493', 'loss=', '0.000427671')
# ('Epoch:', '0246', 'training time (minutes)=', '1.1517', 'loss=', '0.000431240')
# ('Epoch:', '0247', 'training time (minutes)=', '1.1522', 'loss=', '0.000426262')
# ('Epoch:', '0248', 'training time (minutes)=', '1.1489', 'loss=', '0.000422036')
# ('Epoch:', '0249', 'training time (minutes)=', '1.1485', 'loss=', '0.000421988')
# ('Epoch:', '0250', 'training time (minutes)=', '1.1525', 'loss=', '0.000421792')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '1.1509', 'loss=', '0.000423955')
# ('Epoch:', '0252', 'training time (minutes)=', '1.1508', 'loss=', '0.000430059')
# ('Epoch:', '0253', 'training time (minutes)=', '1.1499', 'loss=', '0.000428490')
# ('Epoch:', '0254', 'training time (minutes)=', '1.1428', 'loss=', '0.000421288')
# ('Epoch:', '0255', 'training time (minutes)=', '1.1471', 'loss=', '0.000427623')
# ('Epoch:', '0256', 'training time (minutes)=', '1.1403', 'loss=', '0.000424752')
# ('Epoch:', '0257', 'training time (minutes)=', '1.1373', 'loss=', '0.000428605')
# ('Epoch:', '0258', 'training time (minutes)=', '1.1527', 'loss=', '0.000422796')
# ('Epoch:', '0259', 'training time (minutes)=', '1.1530', 'loss=', '0.000424709')
# ('Epoch:', '0260', 'training time (minutes)=', '1.1514', 'loss=', '0.000429753')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '1.1486', 'loss=', '0.000421627')
# ('Epoch:', '0262', 'training time (minutes)=', '1.1506', 'loss=', '0.000426060')
# ('Epoch:', '0263', 'training time (minutes)=', '1.1452', 'loss=', '0.000425291')
# ('Epoch:', '0264', 'training time (minutes)=', '1.1442', 'loss=', '0.000424970')
# ('Epoch:', '0265', 'training time (minutes)=', '1.1483', 'loss=', '0.000426961')
# ('Epoch:', '0266', 'training time (minutes)=', '1.1488', 'loss=', '0.000423411')
# ('Epoch:', '0267', 'training time (minutes)=', '1.1472', 'loss=', '0.000424233')
# ('Epoch:', '0268', 'training time (minutes)=', '1.1450', 'loss=', '0.000418803')
# ('Epoch:', '0269', 'training time (minutes)=', '1.1447', 'loss=', '0.000417660')
# ('Epoch:', '0270', 'training time (minutes)=', '1.1456', 'loss=', '0.000421767')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '1.1470', 'loss=', '0.000420436')
# ('Epoch:', '0272', 'training time (minutes)=', '1.1431', 'loss=', '0.000430392')
# ('Epoch:', '0273', 'training time (minutes)=', '1.1476', 'loss=', '0.000424429')
# ('Epoch:', '0274', 'training time (minutes)=', '1.1448', 'loss=', '0.000420648')
# ('Epoch:', '0275', 'training time (minutes)=', '1.1392', 'loss=', '0.000421437')
# ('Epoch:', '0276', 'training time (minutes)=', '1.1500', 'loss=', '0.000420927')
# ('Epoch:', '0277', 'training time (minutes)=', '1.1416', 'loss=', '0.000424755')
# ('Epoch:', '0278', 'training time (minutes)=', '1.1493', 'loss=', '0.000422003')
# ('Epoch:', '0279', 'training time (minutes)=', '1.1484', 'loss=', '0.000417521')
# ('Epoch:', '0280', 'training time (minutes)=', '1.1516', 'loss=', '0.000418635')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '1.1440', 'loss=', '0.000414492')
# ('Epoch:', '0282', 'training time (minutes)=', '1.1483', 'loss=', '0.000419137')
# ('Epoch:', '0283', 'training time (minutes)=', '1.1445', 'loss=', '0.000418169')
# ('Epoch:', '0284', 'training time (minutes)=', '1.1446', 'loss=', '0.000421700')
# ('Epoch:', '0285', 'training time (minutes)=', '1.1443', 'loss=', '0.000417270')
# ('Epoch:', '0286', 'training time (minutes)=', '1.1442', 'loss=', '0.000411852')
# ('Epoch:', '0287', 'training time (minutes)=', '1.1453', 'loss=', '0.000416294')
# ('Epoch:', '0288', 'training time (minutes)=', '1.1516', 'loss=', '0.000411684')
# ('Epoch:', '0289', 'training time (minutes)=', '1.1482', 'loss=', '0.000420993')
# ('Epoch:', '0290', 'training time (minutes)=', '1.1540', 'loss=', '0.000415808')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '1.1489', 'loss=', '0.000417933')
# ('Epoch:', '0292', 'training time (minutes)=', '1.1477', 'loss=', '0.000418868')
# ('Epoch:', '0293', 'training time (minutes)=', '1.1497', 'loss=', '0.000413831')
# ('Epoch:', '0294', 'training time (minutes)=', '1.1504', 'loss=', '0.000430350')
# ('Epoch:', '0295', 'training time (minutes)=', '1.1535', 'loss=', '0.000415797')
# ('Epoch:', '0296', 'training time (minutes)=', '1.1531', 'loss=', '0.000421088')
# ('Epoch:', '0297', 'training time (minutes)=', '1.1511', 'loss=', '0.000424224')
# ('Epoch:', '0298', 'training time (minutes)=', '1.1474', 'loss=', '0.000424675')
# ('Epoch:', '0299', 'training time (minutes)=', '1.1537', 'loss=', '0.000418046')
# ('Epoch:', '0300', 'training time (minutes)=', '1.1522', 'loss=', '0.000411360')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '1.1564', 'loss=', '0.000413174')
# ('Epoch:', '0302', 'training time (minutes)=', '1.1554', 'loss=', '0.000416236')
# ('Epoch:', '0303', 'training time (minutes)=', '1.1411', 'loss=', '0.000422111')
# ('Epoch:', '0304', 'training time (minutes)=', '1.1505', 'loss=', '0.000422615')
# ('Epoch:', '0305', 'training time (minutes)=', '1.1510', 'loss=', '0.000409605')
# ('Epoch:', '0306', 'training time (minutes)=', '1.1539', 'loss=', '0.000406050')
# ('Epoch:', '0307', 'training time (minutes)=', '1.1506', 'loss=', '0.000419314')
# ('Epoch:', '0308', 'training time (minutes)=', '1.1527', 'loss=', '0.000426136')
# ('Epoch:', '0309', 'training time (minutes)=', '1.1478', 'loss=', '0.000414313')
# ('Epoch:', '0310', 'training time (minutes)=', '1.1434', 'loss=', '0.000419991')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '1.1468', 'loss=', '0.000411444')
# ('Epoch:', '0312', 'training time (minutes)=', '1.1462', 'loss=', '0.000418145')
# ('Epoch:', '0313', 'training time (minutes)=', '1.1515', 'loss=', '0.000419303')
# ('Epoch:', '0314', 'training time (minutes)=', '1.1508', 'loss=', '0.000419613')
# ('Epoch:', '0315', 'training time (minutes)=', '1.1533', 'loss=', '0.000417048')
# ('Epoch:', '0316', 'training time (minutes)=', '1.1553', 'loss=', '0.000415367')
# ('Epoch:', '0317', 'training time (minutes)=', '1.1444', 'loss=', '0.000412684')
# ('Epoch:', '0318', 'training time (minutes)=', '1.1475', 'loss=', '0.000412752')
# ('Epoch:', '0319', 'training time (minutes)=', '1.1416', 'loss=', '0.000418556')
# ('Epoch:', '0320', 'training time (minutes)=', '1.1492', 'loss=', '0.000415542')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '1.1590', 'loss=', '0.000409453')
# ('Epoch:', '0322', 'training time (minutes)=', '1.1541', 'loss=', '0.000412850')
# ('Epoch:', '0323', 'training time (minutes)=', '1.1553', 'loss=', '0.000416127')
# ('Epoch:', '0324', 'training time (minutes)=', '1.1543', 'loss=', '0.000420358')
# ('Epoch:', '0325', 'training time (minutes)=', '1.1475', 'loss=', '0.000414377')
# ('Epoch:', '0326', 'training time (minutes)=', '1.1574', 'loss=', '0.000417610')
# ('Epoch:', '0327', 'training time (minutes)=', '1.1542', 'loss=', '0.000414651')
# ('Epoch:', '0328', 'training time (minutes)=', '1.1531', 'loss=', '0.000419933')
# ('Epoch:', '0329', 'training time (minutes)=', '1.1601', 'loss=', '0.000406391')
# ('Epoch:', '0330', 'training time (minutes)=', '1.1553', 'loss=', '0.000415509')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '1.1560', 'loss=', '0.000409986')
# ('Epoch:', '0332', 'training time (minutes)=', '1.1539', 'loss=', '0.000415559')
# ('Epoch:', '0333', 'training time (minutes)=', '1.1579', 'loss=', '0.000406607')
# ('Epoch:', '0334', 'training time (minutes)=', '1.1521', 'loss=', '0.000412385')
# ('Epoch:', '0335', 'training time (minutes)=', '1.1575', 'loss=', '0.000414391')
# ('Epoch:', '0336', 'training time (minutes)=', '1.1544', 'loss=', '0.000423654')
# ('Epoch:', '0337', 'training time (minutes)=', '1.1540', 'loss=', '0.000411235')
# ('Epoch:', '0338', 'training time (minutes)=', '1.1468', 'loss=', '0.000412891')
# ('Epoch:', '0339', 'training time (minutes)=', '1.1551', 'loss=', '0.000415804')
# ('Epoch:', '0340', 'training time (minutes)=', '1.1544', 'loss=', '0.000417116')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '1.1515', 'loss=', '0.000408926')
# ('Epoch:', '0342', 'training time (minutes)=', '1.1516', 'loss=', '0.000411734')
# ('Epoch:', '0343', 'training time (minutes)=', '1.1476', 'loss=', '0.000412552')
# ('Epoch:', '0344', 'training time (minutes)=', '1.1482', 'loss=', '0.000423179')
# ('Epoch:', '0345', 'training time (minutes)=', '1.1511', 'loss=', '0.000415088')
# ('Epoch:', '0346', 'training time (minutes)=', '1.1512', 'loss=', '0.000410496')
# ('Epoch:', '0347', 'training time (minutes)=', '1.1415', 'loss=', '0.000414820')
# ('Epoch:', '0348', 'training time (minutes)=', '1.1458', 'loss=', '0.000413077')
# ('Epoch:', '0349', 'training time (minutes)=', '1.1501', 'loss=', '0.000411312')
# ('Epoch:', '0350', 'training time (minutes)=', '1.1530', 'loss=', '0.000415030')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '1.1463', 'loss=', '0.000411901')
# ('Epoch:', '0352', 'training time (minutes)=', '1.1450', 'loss=', '0.000412027')
# ('Epoch:', '0353', 'training time (minutes)=', '1.1475', 'loss=', '0.000413256')
# ('Epoch:', '0354', 'training time (minutes)=', '1.1621', 'loss=', '0.000412755')
# ('Epoch:', '0355', 'training time (minutes)=', '1.1631', 'loss=', '0.000412974')
# ('Epoch:', '0356', 'training time (minutes)=', '1.1560', 'loss=', '0.000410675')
# ('Epoch:', '0357', 'training time (minutes)=', '1.1644', 'loss=', '0.000410341')
# ('Epoch:', '0358', 'training time (minutes)=', '1.1628', 'loss=', '0.000408857')
# ('Epoch:', '0359', 'training time (minutes)=', '1.1493', 'loss=', '0.000411837')
# ('Epoch:', '0360', 'training time (minutes)=', '1.1582', 'loss=', '0.000413324')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0361', 'training time (minutes)=', '1.1611', 'loss=', '0.000411916')
# ('Epoch:', '0362', 'training time (minutes)=', '1.1555', 'loss=', '0.000407500')
# ('Epoch:', '0363', 'training time (minutes)=', '1.1600', 'loss=', '0.000415397')
# ('Epoch:', '0364', 'training time (minutes)=', '1.1641', 'loss=', '0.000418841')
# ('Epoch:', '0365', 'training time (minutes)=', '1.1531', 'loss=', '0.000414662')
# ('Epoch:', '0366', 'training time (minutes)=', '1.1615', 'loss=', '0.000411824')
# ('Epoch:', '0367', 'training time (minutes)=', '1.1602', 'loss=', '0.000417092')
# ('Epoch:', '0368', 'training time (minutes)=', '1.1525', 'loss=', '0.000416555')
# ('Epoch:', '0369', 'training time (minutes)=', '1.1609', 'loss=', '0.000410672')
# ('Epoch:', '0370', 'training time (minutes)=', '1.1551', 'loss=', '0.000416648')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0371', 'training time (minutes)=', '1.1602', 'loss=', '0.000413436')
# ('Epoch:', '0372', 'training time (minutes)=', '1.1685', 'loss=', '0.000409983')
# ('Epoch:', '0373', 'training time (minutes)=', '1.1627', 'loss=', '0.000412316')
# ('Epoch:', '0374', 'training time (minutes)=', '1.1587', 'loss=', '0.000412168')
# ('Epoch:', '0375', 'training time (minutes)=', '1.1636', 'loss=', '0.000413719')
# ('Epoch:', '0376', 'training time (minutes)=', '1.1584', 'loss=', '0.000405805')
# ('Epoch:', '0377', 'training time (minutes)=', '1.1590', 'loss=', '0.000416632')
# ('Epoch:', '0378', 'training time (minutes)=', '1.1655', 'loss=', '0.000406876')
# ('Epoch:', '0379', 'training time (minutes)=', '1.1612', 'loss=', '0.000416180')
# ('Epoch:', '0380', 'training time (minutes)=', '1.1582', 'loss=', '0.000415734')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0381', 'training time (minutes)=', '1.1648', 'loss=', '0.000406765')
# ('Epoch:', '0382', 'training time (minutes)=', '1.1600', 'loss=', '0.000401474')
# ('Epoch:', '0383', 'training time (minutes)=', '1.1603', 'loss=', '0.000410930')
# ('Epoch:', '0384', 'training time (minutes)=', '1.1567', 'loss=', '0.000406427')
# ('Epoch:', '0385', 'training time (minutes)=', '1.1459', 'loss=', '0.000408833')
# ('Epoch:', '0386', 'training time (minutes)=', '1.1598', 'loss=', '0.000405534')
# ('Epoch:', '0387', 'training time (minutes)=', '1.1539', 'loss=', '0.000413814')
# ('Epoch:', '0388', 'training time (minutes)=', '1.1513', 'loss=', '0.000410898')
# ('Epoch:', '0389', 'training time (minutes)=', '1.1556', 'loss=', '0.000405807')
# ('Epoch:', '0390', 'training time (minutes)=', '1.1506', 'loss=', '0.000409662')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0391', 'training time (minutes)=', '1.1683', 'loss=', '0.000409650')
# ('Epoch:', '0392', 'training time (minutes)=', '1.1462', 'loss=', '0.000415854')
# ('Epoch:', '0393', 'training time (minutes)=', '1.1518', 'loss=', '0.000408959')
# ('Epoch:', '0394', 'training time (minutes)=', '1.1495', 'loss=', '0.000406770')
# ('Epoch:', '0395', 'training time (minutes)=', '1.1485', 'loss=', '0.000413557')
# ('Epoch:', '0396', 'training time (minutes)=', '1.1503', 'loss=', '0.000407149')
# ('Epoch:', '0397', 'training time (minutes)=', '1.1569', 'loss=', '0.000409165')
# ('Epoch:', '0398', 'training time (minutes)=', '1.1528', 'loss=', '0.000407638')
# ('Epoch:', '0399', 'training time (minutes)=', '1.1501', 'loss=', '0.000408286')
# ('Epoch:', '0400', 'training time (minutes)=', '1.1492', 'loss=', '0.000411609')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0401', 'training time (minutes)=', '1.1440', 'loss=', '0.000399646')
# ('Epoch:', '0402', 'training time (minutes)=', '1.1455', 'loss=', '0.000408765')
# ('Epoch:', '0403', 'training time (minutes)=', '1.1521', 'loss=', '0.000405685')
# ('Epoch:', '0404', 'training time (minutes)=', '1.1531', 'loss=', '0.000413389')
# ('Epoch:', '0405', 'training time (minutes)=', '1.1529', 'loss=', '0.000408675')
# ('Epoch:', '0406', 'training time (minutes)=', '1.1517', 'loss=', '0.000406302')
# ('Epoch:', '0407', 'training time (minutes)=', '1.1495', 'loss=', '0.000412441')
# ('Epoch:', '0408', 'training time (minutes)=', '1.1535', 'loss=', '0.000407578')
# ('Epoch:', '0409', 'training time (minutes)=', '1.1557', 'loss=', '0.000409252')
# ('Epoch:', '0410', 'training time (minutes)=', '1.1560', 'loss=', '0.000412656')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0411', 'training time (minutes)=', '1.1590', 'loss=', '0.000407486')
# ('Epoch:', '0412', 'training time (minutes)=', '1.1563', 'loss=', '0.000405452')
# ('Epoch:', '0413', 'training time (minutes)=', '1.1656', 'loss=', '0.000413185')
# ('Epoch:', '0414', 'training time (minutes)=', '1.1665', 'loss=', '0.000404106')
# ('Epoch:', '0415', 'training time (minutes)=', '1.1623', 'loss=', '0.000412727')
# ('Epoch:', '0416', 'training time (minutes)=', '1.1509', 'loss=', '0.000412339')
# ('Epoch:', '0417', 'training time (minutes)=', '1.1476', 'loss=', '0.000419543')
# ('Epoch:', '0418', 'training time (minutes)=', '1.1493', 'loss=', '0.000412657')
# ('Epoch:', '0419', 'training time (minutes)=', '1.1459', 'loss=', '0.000411579')
# ('Epoch:', '0420', 'training time (minutes)=', '1.1501', 'loss=', '0.000407406')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0421', 'training time (minutes)=', '1.1631', 'loss=', '0.000413869')
# ('Epoch:', '0422', 'training time (minutes)=', '1.1421', 'loss=', '0.000442699')
# ('Epoch:', '0423', 'training time (minutes)=', '1.1388', 'loss=', '0.000415179')
# ('Epoch:', '0424', 'training time (minutes)=', '1.1533', 'loss=', '0.000421289')
# ('Epoch:', '0425', 'training time (minutes)=', '1.1515', 'loss=', '0.000413663')
# ('Epoch:', '0426', 'training time (minutes)=', '1.1552', 'loss=', '0.000412153')
# ('Epoch:', '0427', 'training time (minutes)=', '1.1527', 'loss=', '0.000405950')
# ('Epoch:', '0428', 'training time (minutes)=', '1.1503', 'loss=', '0.000410659')
# ('Epoch:', '0429', 'training time (minutes)=', '1.1574', 'loss=', '0.000409903')
# ('Epoch:', '0430', 'training time (minutes)=', '1.1463', 'loss=', '0.000406863')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0431', 'training time (minutes)=', '1.1915', 'loss=', '0.000412005')
# ('Epoch:', '0432', 'training time (minutes)=', '1.1316', 'loss=', '0.000405017')
# ('Epoch:', '0433', 'training time (minutes)=', '1.1310', 'loss=', '0.000405905')
# ('Epoch:', '0434', 'training time (minutes)=', '1.1525', 'loss=', '0.000405835')
# ('Epoch:', '0435', 'training time (minutes)=', '1.1484', 'loss=', '0.000407451')
# ('Epoch:', '0436', 'training time (minutes)=', '1.1435', 'loss=', '0.000405744')
# ('Epoch:', '0437', 'training time (minutes)=', '1.1475', 'loss=', '0.000415134')
# ('Epoch:', '0438', 'training time (minutes)=', '1.1517', 'loss=', '0.000402935')
# ('Epoch:', '0439', 'training time (minutes)=', '1.1476', 'loss=', '0.000411467')
# ('Epoch:', '0440', 'training time (minutes)=', '1.1495', 'loss=', '0.000406139')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0441', 'training time (minutes)=', '1.1502', 'loss=', '0.000407860')
# ('Epoch:', '0442', 'training time (minutes)=', '1.1501', 'loss=', '0.000404634')
# ('Epoch:', '0443', 'training time (minutes)=', '1.1415', 'loss=', '0.000403181')
# ('Epoch:', '0444', 'training time (minutes)=', '1.1433', 'loss=', '0.000411759')
# ('Epoch:', '0445', 'training time (minutes)=', '1.1444', 'loss=', '0.000407623')
# ('Epoch:', '0446', 'training time (minutes)=', '1.1402', 'loss=', '0.000409510')
# ('Epoch:', '0447', 'training time (minutes)=', '1.1455', 'loss=', '0.000401592')
# ('Epoch:', '0448', 'training time (minutes)=', '1.1517', 'loss=', '0.000404241')
# ('Epoch:', '0449', 'training time (minutes)=', '1.1547', 'loss=', '0.000416627')
# ('Epoch:', '0450', 'training time (minutes)=', '1.1471', 'loss=', '0.000414471')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0451', 'training time (minutes)=', '1.1474', 'loss=', '0.000415288')
# ('Epoch:', '0452', 'training time (minutes)=', '1.1399', 'loss=', '0.000403136')
# ('Epoch:', '0453', 'training time (minutes)=', '1.1492', 'loss=', '0.000405539')
# ('Epoch:', '0454', 'training time (minutes)=', '1.1476', 'loss=', '0.000405772')
# ('Epoch:', '0455', 'training time (minutes)=', '1.1402', 'loss=', '0.000410308')
# ('Epoch:', '0456', 'training time (minutes)=', '1.1468', 'loss=', '0.000416424')
# ('Epoch:', '0457', 'training time (minutes)=', '1.1487', 'loss=', '0.000413409')
# ('Epoch:', '0458', 'training time (minutes)=', '1.1522', 'loss=', '0.000409483')
# ('Epoch:', '0459', 'training time (minutes)=', '1.1508', 'loss=', '0.000407357')
# ('Epoch:', '0460', 'training time (minutes)=', '1.1458', 'loss=', '0.000408891')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0461', 'training time (minutes)=', '1.1357', 'loss=', '0.000409616')
# ('Epoch:', '0462', 'training time (minutes)=', '1.1404', 'loss=', '0.000404300')
# ('Epoch:', '0463', 'training time (minutes)=', '1.1408', 'loss=', '0.000409500')
# ('Epoch:', '0464', 'training time (minutes)=', '1.1405', 'loss=', '0.000413075')
# ('Epoch:', '0465', 'training time (minutes)=', '1.1450', 'loss=', '0.000407975')
# ('Epoch:', '0466', 'training time (minutes)=', '1.1361', 'loss=', '0.000404681')
# ('Epoch:', '0467', 'training time (minutes)=', '1.1452', 'loss=', '0.000411315')
# ('Epoch:', '0468', 'training time (minutes)=', '1.1422', 'loss=', '0.000404993')
# ...
# ('Epoch:', '0690', 'training time (minutes)=', '1.1669', 'loss=', '0.000398239')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-690 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0691', 'training time (minutes)=', '1.1662', 'loss=', '0.000400291')
# ('Epoch:', '0692', 'training time (minutes)=', '1.1686', 'loss=', '0.000403394')
# ('Epoch:', '0693', 'training time (minutes)=', '1.1707', 'loss=', '0.000397241')
# ('Epoch:', '0694', 'training time (minutes)=', '1.1691', 'loss=', '0.000397526')
# ('Epoch:', '0695', 'training time (minutes)=', '1.1677', 'loss=', '0.000403854')
# ('Epoch:', '0696', 'training time (minutes)=', '1.4089', 'loss=', '0.000390010')
# ('Epoch:', '0697', 'training time (minutes)=', '1.1711', 'loss=', '0.000403720')
# ('Epoch:', '0698', 'training time (minutes)=', '1.1780', 'loss=', '0.000399456')
# ('Epoch:', '0699', 'training time (minutes)=', '1.1740', 'loss=', '0.000395170')
# ('Epoch:', '0700', 'training time (minutes)=', '1.3231', 'loss=', '0.000400204')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-700 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0701', 'training time (minutes)=', '1.1817', 'loss=', '0.000393287')
# ('Epoch:', '0702', 'training time (minutes)=', '1.1967', 'loss=', '0.000398640')
# ('Epoch:', '0703', 'training time (minutes)=', '1.5394', 'loss=', '0.000397346')
# ('Epoch:', '0704', 'training time (minutes)=', '1.1672', 'loss=', '0.000401554')
# ('Epoch:', '0705', 'training time (minutes)=', '1.1653', 'loss=', '0.000402515')
# ('Epoch:', '0706', 'training time (minutes)=', '1.3743', 'loss=', '0.000403843')
# ('Epoch:', '0707', 'training time (minutes)=', '1.1783', 'loss=', '0.000400427')
# ('Epoch:', '0708', 'training time (minutes)=', '1.1631', 'loss=', '0.000399327')
# ('Epoch:', '0709', 'training time (minutes)=', '1.1944', 'loss=', '0.000401109')
# ('Epoch:', '0710', 'training time (minutes)=', '1.1738', 'loss=', '0.000401517')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-710 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0711', 'training time (minutes)=', '1.1807', 'loss=', '0.000399795')
# ('Epoch:', '0712', 'training time (minutes)=', '1.3087', 'loss=', '0.000401347')
# ('Epoch:', '0713', 'training time (minutes)=', '1.1651', 'loss=', '0.000404956')
# ('Epoch:', '0714', 'training time (minutes)=', '1.1810', 'loss=', '0.000402683')
# ('Epoch:', '0715', 'training time (minutes)=', '1.1747', 'loss=', '0.000406915')
# ('Epoch:', '0716', 'training time (minutes)=', '1.1660', 'loss=', '0.000397697')
# ('Epoch:', '0717', 'training time (minutes)=', '1.1616', 'loss=', '0.000402157')
# ('Epoch:', '0718', 'training time (minutes)=', '1.1785', 'loss=', '0.000396321')
# ('Epoch:', '0719', 'training time (minutes)=', '1.1659', 'loss=', '0.000402993')
# ('Epoch:', '0720', 'training time (minutes)=', '1.2736', 'loss=', '0.000401781')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-720 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0721', 'training time (minutes)=', '1.1744', 'loss=', '0.000400239')
# ('Epoch:', '0722', 'training time (minutes)=', '1.1597', 'loss=', '0.000403346')
# ('Epoch:', '0723', 'training time (minutes)=', '1.1694', 'loss=', '0.000398230')
# ('Epoch:', '0724', 'training time (minutes)=', '1.1612', 'loss=', '0.000403326')
# ('Epoch:', '0725', 'training time (minutes)=', '1.1643', 'loss=', '0.000398391')
# ('Epoch:', '0726', 'training time (minutes)=', '1.1658', 'loss=', '0.000396723')
# ('Epoch:', '0727', 'training time (minutes)=', '1.1662', 'loss=', '0.000401756')
# ('Epoch:', '0728', 'training time (minutes)=', '1.1483', 'loss=', '0.000396691')
# ('Epoch:', '0729', 'training time (minutes)=', '1.1462', 'loss=', '0.000395187')
# ('Epoch:', '0730', 'training time (minutes)=', '1.1451', 'loss=', '0.000403074')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-730 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0731', 'training time (minutes)=', '1.1460', 'loss=', '0.000402374')
# ('Epoch:', '0732', 'training time (minutes)=', '1.1482', 'loss=', '0.000399888')
# ('Epoch:', '0733', 'training time (minutes)=', '1.1962', 'loss=', '0.000405369')
# ('Epoch:', '0734', 'training time (minutes)=', '1.1561', 'loss=', '0.000393066')
# ('Epoch:', '0735', 'training time (minutes)=', '1.1407', 'loss=', '0.000400496')
# ('Epoch:', '0736', 'training time (minutes)=', '1.1427', 'loss=', '0.000400901')
# ('Epoch:', '0737', 'training time (minutes)=', '1.1452', 'loss=', '0.000402380')
# ('Epoch:', '0738', 'training time (minutes)=', '1.1491', 'loss=', '0.000404932')
# ('Epoch:', '0739', 'training time (minutes)=', '1.1490', 'loss=', '0.000405962')
# ('Epoch:', '0740', 'training time (minutes)=', '1.1411', 'loss=', '0.000412875')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-740 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0741', 'training time (minutes)=', '1.1444', 'loss=', '0.000406101')
# ('Epoch:', '0742', 'training time (minutes)=', '1.1538', 'loss=', '0.000406234')
# ('Epoch:', '0743', 'training time (minutes)=', '1.1382', 'loss=', '0.000414803')
# ('Epoch:', '0744', 'training time (minutes)=', '1.1453', 'loss=', '0.000422913')
# ('Epoch:', '0745', 'training time (minutes)=', '1.1531', 'loss=', '0.000423590')
# ('Epoch:', '0746', 'training time (minutes)=', '1.1449', 'loss=', '0.000423930')
# ('Epoch:', '0747', 'training time (minutes)=', '1.1393', 'loss=', '0.000417844')
# ('Epoch:', '0748', 'training time (minutes)=', '1.1493', 'loss=', '0.000410163')
# ('Epoch:', '0749', 'training time (minutes)=', '1.1492', 'loss=', '0.000406900')
# ('Epoch:', '0750', 'training time (minutes)=', '1.1462', 'loss=', '0.000415918')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-750 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0751', 'training time (minutes)=', '1.1779', 'loss=', '0.000407283')
# ('Epoch:', '0752', 'training time (minutes)=', '1.1502', 'loss=', '0.000407042')
# ('Epoch:', '0753', 'training time (minutes)=', '1.1428', 'loss=', '0.000403761')
# ('Epoch:', '0754', 'training time (minutes)=', '1.1545', 'loss=', '0.000410026')
# ('Epoch:', '0755', 'training time (minutes)=', '1.1464', 'loss=', '0.000406992')
# ('Epoch:', '0756', 'training time (minutes)=', '1.1436', 'loss=', '0.000410945')
# ('Epoch:', '0757', 'training time (minutes)=', '1.1961', 'loss=', '0.000401417')
# ('Epoch:', '0758', 'training time (minutes)=', '1.1440', 'loss=', '0.000411134')
# ('Epoch:', '0759', 'training time (minutes)=', '1.1542', 'loss=', '0.000404126')
# ('Epoch:', '0760', 'training time (minutes)=', '1.1594', 'loss=', '0.000408835')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-760 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0761', 'training time (minutes)=', '1.1488', 'loss=', '0.000400697')
# ('Epoch:', '0762', 'training time (minutes)=', '1.1504', 'loss=', '0.000417264')
# ('Epoch:', '0763', 'training time (minutes)=', '1.1628', 'loss=', '0.000396194')
# ('Epoch:', '0764', 'training time (minutes)=', '1.1630', 'loss=', '0.000404978')
# ('Epoch:', '0765', 'training time (minutes)=', '1.1508', 'loss=', '0.000401980')
# ('Epoch:', '0766', 'training time (minutes)=', '1.1455', 'loss=', '0.000401519')
# ('Epoch:', '0767', 'training time (minutes)=', '1.1468', 'loss=', '0.000401186')
# ('Epoch:', '0768', 'training time (minutes)=', '1.1453', 'loss=', '0.000395655')
# ('Epoch:', '0769', 'training time (minutes)=', '1.1549', 'loss=', '0.000405658')
# ('Epoch:', '0770', 'training time (minutes)=', '1.1535', 'loss=', '0.000406673')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-770 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0771', 'training time (minutes)=', '1.1531', 'loss=', '0.000414080')
# ('Epoch:', '0772', 'training time (minutes)=', '1.1508', 'loss=', '0.000398615')
# ('Epoch:', '0773', 'training time (minutes)=', '1.1571', 'loss=', '0.000400196')
# ('Epoch:', '0774', 'training time (minutes)=', '1.1572', 'loss=', '0.000402211')
# ('Epoch:', '0775', 'training time (minutes)=', '1.1617', 'loss=', '0.000401353')
# ('Epoch:', '0776', 'training time (minutes)=', '1.1594', 'loss=', '0.000407164')
# ('Epoch:', '0777', 'training time (minutes)=', '1.1539', 'loss=', '0.000404436')
# ('Epoch:', '0778', 'training time (minutes)=', '1.1558', 'loss=', '0.000395869')
# ('Epoch:', '0779', 'training time (minutes)=', '1.1487', 'loss=', '0.000402787')
# ('Epoch:', '0780', 'training time (minutes)=', '1.1560', 'loss=', '0.000405812')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-780 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0781', 'training time (minutes)=', '1.1474', 'loss=', '0.000396524')
# ('Epoch:', '0782', 'training time (minutes)=', '1.1580', 'loss=', '0.000401603')
# ('Epoch:', '0783', 'training time (minutes)=', '1.1565', 'loss=', '0.000400266')
# ('Epoch:', '0784', 'training time (minutes)=', '1.1522', 'loss=', '0.000401328')
# ('Epoch:', '0785', 'training time (minutes)=', '1.1602', 'loss=', '0.000398126')
# ('Epoch:', '0786', 'training time (minutes)=', '1.1499', 'loss=', '0.000405449')
# ('Epoch:', '0787', 'training time (minutes)=', '1.1432', 'loss=', '0.000401687')
# ('Epoch:', '0788', 'training time (minutes)=', '1.1419', 'loss=', '0.000400228')
# ('Epoch:', '0789', 'training time (minutes)=', '1.1352', 'loss=', '0.000401838')
# ('Epoch:', '0790', 'training time (minutes)=', '1.1471', 'loss=', '0.000400147')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-790 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0791', 'training time (minutes)=', '1.1363', 'loss=', '0.000397769')
# ('Epoch:', '0792', 'training time (minutes)=', '1.1418', 'loss=', '0.000393233')
# ('Epoch:', '0793', 'training time (minutes)=', '1.1440', 'loss=', '0.000401788')
# ('Epoch:', '0794', 'training time (minutes)=', '1.1481', 'loss=', '0.000397454')
# ('Epoch:', '0795', 'training time (minutes)=', '1.1447', 'loss=', '0.000401403')
# ('Epoch:', '0796', 'training time (minutes)=', '1.1369', 'loss=', '0.000399300')
# ('Epoch:', '0797', 'training time (minutes)=', '1.1417', 'loss=', '0.000402978')
# ('Epoch:', '0798', 'training time (minutes)=', '1.1417', 'loss=', '0.000400238')
# ('Epoch:', '0799', 'training time (minutes)=', '1.1411', 'loss=', '0.000400315')
# ('Epoch:', '0800', 'training time (minutes)=', '1.1314', 'loss=', '0.000395979')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-800 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0801', 'training time (minutes)=', '1.1378', 'loss=', '0.000397200')
# ('Epoch:', '0802', 'training time (minutes)=', '1.1392', 'loss=', '0.000402664')
# ('Epoch:', '0803', 'training time (minutes)=', '1.1389', 'loss=', '0.000399193')
# ('Epoch:', '0804', 'training time (minutes)=', '1.1399', 'loss=', '0.000397141')
# ('Epoch:', '0805', 'training time (minutes)=', '1.1397', 'loss=', '0.000392683')
# ('Epoch:', '0806', 'training time (minutes)=', '1.1433', 'loss=', '0.000401156')
# ('Epoch:', '0807', 'training time (minutes)=', '1.1378', 'loss=', '0.000398095')
# ('Epoch:', '0808', 'training time (minutes)=', '1.1506', 'loss=', '0.000397822')
# ('Epoch:', '0809', 'training time (minutes)=', '1.1463', 'loss=', '0.000399750')
# ('Epoch:', '0810', 'training time (minutes)=', '1.1372', 'loss=', '0.000407410')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-810 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0811', 'training time (minutes)=', '1.1491', 'loss=', '0.000398474')
# ('Epoch:', '0812', 'training time (minutes)=', '1.1407', 'loss=', '0.000398479')
# ('Epoch:', '0813', 'training time (minutes)=', '1.1470', 'loss=', '0.000393916')
# ('Epoch:', '0814', 'training time (minutes)=', '1.1486', 'loss=', '0.000395040')
# ('Epoch:', '0815', 'training time (minutes)=', '1.1446', 'loss=', '0.000405758')
# ('Epoch:', '0816', 'training time (minutes)=', '1.1517', 'loss=', '0.000392323')
# ('Epoch:', '0817', 'training time (minutes)=', '1.1486', 'loss=', '0.000400332')
# ('Epoch:', '0818', 'training time (minutes)=', '1.1426', 'loss=', '0.000392662')
# ('Epoch:', '0819', 'training time (minutes)=', '1.1469', 'loss=', '0.000396345')
# ('Epoch:', '0820', 'training time (minutes)=', '1.1336', 'loss=', '0.000398730')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-820 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0821', 'training time (minutes)=', '1.1463', 'loss=', '0.000399928')
# ('Epoch:', '0822', 'training time (minutes)=', '1.1432', 'loss=', '0.000394865')
# ('Epoch:', '0823', 'training time (minutes)=', '1.1467', 'loss=', '0.000398811')
# ('Epoch:', '0824', 'training time (minutes)=', '1.1469', 'loss=', '0.000388898')
# ('Epoch:', '0825', 'training time (minutes)=', '1.1482', 'loss=', '0.000398583')
# ('Epoch:', '0826', 'training time (minutes)=', '1.1508', 'loss=', '0.000397124')
# ('Epoch:', '0827', 'training time (minutes)=', '1.1492', 'loss=', '0.000401118')
# ('Epoch:', '0828', 'training time (minutes)=', '1.1525', 'loss=', '0.000399533')
# ('Epoch:', '0829', 'training time (minutes)=', '1.1521', 'loss=', '0.000400134')
# ('Epoch:', '0830', 'training time (minutes)=', '1.1627', 'loss=', '0.000399480')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-830 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0831', 'training time (minutes)=', '1.1611', 'loss=', '0.000392782')
# ('Epoch:', '0832', 'training time (minutes)=', '1.1500', 'loss=', '0.000394372')
# ('Epoch:', '0833', 'training time (minutes)=', '1.1458', 'loss=', '0.000395126')
# ('Epoch:', '0834', 'training time (minutes)=', '1.1544', 'loss=', '0.000404671')
# ('Epoch:', '0835', 'training time (minutes)=', '1.1419', 'loss=', '0.000394446')
# ('Epoch:', '0836', 'training time (minutes)=', '1.1313', 'loss=', '0.000395146')
# ('Epoch:', '0837', 'training time (minutes)=', '1.1553', 'loss=', '0.000405327')
# ('Epoch:', '0838', 'training time (minutes)=', '1.1447', 'loss=', '0.000393947')
# ('Epoch:', '0839', 'training time (minutes)=', '1.1434', 'loss=', '0.000398691')
# ('Epoch:', '0840', 'training time (minutes)=', '1.1440', 'loss=', '0.000399132')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc2048pts_chamfer/models.ckpt-840 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0841', 'training time (minutes)=', '1.1392', 'loss=', '0.000398434')
# ('Epoch:', '0842', 'training time (minutes)=', '1.1471', 'loss=', '0.000398094')
# ('Epoch:', '0843', 'training time (minutes)=', '1.1452', 'loss=', '0.000397666')
# ('Epoch:', '0844', 'training time (minutes)=', '1.1437', 'loss=', '0.000400875')
