# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 3
setup_one_gpu(GPU)
# Out:
# Picking GPU 3

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs

from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry_new, decoder_with_fc_only
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tf_lab.iclr.helper import load_multiple_version_of_pcs

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = True
load_model = False
seed = 42
max_training_epochs = 2000
loss = 'chamfer'
z_rotate = True
experiment_name = 'no_conv_deeper_snc_rotated' + str(n_pc_samples) +  'pts_' + loss

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'

# %%
n_threads = 25
verbose = True
version = 'centered'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', version, str(n_pc_samples))
full_file_names = [f for f in files_in_subdirs(full_pclouds_path, '.ply')]
pclouds, _, _ = load_point_clouds_from_filenames(full_file_names, n_threads, snc_loader, verbose)
train_data = PointCloudDataSet(pclouds)
print train_data.num_examples
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:38: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')
# 57449 pclouds were loaded. They belong in 57 shape-classes.
# 57449

# %%
train_dir = osp.join('/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc', experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer'

# %%
n_input = [n_pc_samples, 3]

encoder_args = {'n_filters': [128, 128, 256, 512],
                'filter_sizes': [1, 1, 1, 1],
                'strides': [1, 1, 1, 1],
                'b_norm': True
               }

decoder_args = {'layer_sizes': [1024, 2048, np.prod(n_input)],
                'b_norm': True
               }

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = encoder_with_convs_and_symmetry_new,
                encoder_args = encoder_args,
                decoder = decoder_with_fc_only,
                decoder_args = decoder_args,            
               )
    conf.allow_gpu_growth = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

# %%
if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)
        
if load_model and do_training:
    conf.training_epochs -= last_epoch
    print conf.training_epochs

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)    
    train_stats = ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '1.8505', 'loss=', '0.011135107')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '1.9266', 'loss=', '0.003201924')
# ('Epoch:', '0003', 'training time (minutes)=', '1.9186', 'loss=', '0.002325044')
# ('Epoch:', '0004', 'training time (minutes)=', '1.8706', 'loss=', '0.001838495')
# ('Epoch:', '0005', 'training time (minutes)=', '1.8951', 'loss=', '0.001630203')
# ('Epoch:', '0006', 'training time (minutes)=', '1.8524', 'loss=', '0.001622526')
# ('Epoch:', '0007', 'training time (minutes)=', '1.8646', 'loss=', '0.001321518')
# ('Epoch:', '0008', 'training time (minutes)=', '1.9204', 'loss=', '0.001231751')
# ('Epoch:', '0009', 'training time (minutes)=', '1.9460', 'loss=', '0.001159816')
# ('Epoch:', '0010', 'training time (minutes)=', '1.8773', 'loss=', '0.001090781')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '1.9280', 'loss=', '0.001049953')
# ('Epoch:', '0012', 'training time (minutes)=', '1.9241', 'loss=', '0.001056925')
# ('Epoch:', '0013', 'training time (minutes)=', '1.9390', 'loss=', '0.000961224')
# ('Epoch:', '0014', 'training time (minutes)=', '1.9076', 'loss=', '0.000930219')
# ('Epoch:', '0015', 'training time (minutes)=', '1.9513', 'loss=', '0.000903154')
# ('Epoch:', '0016', 'training time (minutes)=', '1.9436', 'loss=', '0.000894455')
# ('Epoch:', '0017', 'training time (minutes)=', '1.9643', 'loss=', '0.000867075')
# ('Epoch:', '0018', 'training time (minutes)=', '1.9497', 'loss=', '0.000847578')
# ('Epoch:', '0019', 'training time (minutes)=', '1.9934', 'loss=', '0.000842099')
# ('Epoch:', '0020', 'training time (minutes)=', '1.9394', 'loss=', '0.000831696')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '1.9900', 'loss=', '0.000793188')
# ('Epoch:', '0022', 'training time (minutes)=', '1.9907', 'loss=', '0.000852827')
# ('Epoch:', '0023', 'training time (minutes)=', '1.9920', 'loss=', '0.000781026')
# ('Epoch:', '0024', 'training time (minutes)=', '1.9487', 'loss=', '0.000789520')
# ('Epoch:', '0025', 'training time (minutes)=', '1.9719', 'loss=', '0.000767573')
# ('Epoch:', '0026', 'training time (minutes)=', '1.9872', 'loss=', '0.000742938')
# ('Epoch:', '0027', 'training time (minutes)=', '1.9733', 'loss=', '0.000757566')
# ('Epoch:', '0028', 'training time (minutes)=', '1.9876', 'loss=', '0.000731544')
# ('Epoch:', '0029', 'training time (minutes)=', '1.9679', 'loss=', '0.000719443')
# ('Epoch:', '0030', 'training time (minutes)=', '1.9723', 'loss=', '0.000728784')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '1.9773', 'loss=', '0.000728962')
# ('Epoch:', '0032', 'training time (minutes)=', '1.9849', 'loss=', '0.000710278')
# ('Epoch:', '0033', 'training time (minutes)=', '1.9904', 'loss=', '0.000700544')
# ('Epoch:', '0034', 'training time (minutes)=', '1.9857', 'loss=', '0.000708737')
# ('Epoch:', '0035', 'training time (minutes)=', '1.9700', 'loss=', '0.000690940')
# ('Epoch:', '0036', 'training time (minutes)=', '1.9807', 'loss=', '0.000685124')
# ('Epoch:', '0037', 'training time (minutes)=', '1.9856', 'loss=', '0.000667857')
# ('Epoch:', '0038', 'training time (minutes)=', '1.9879', 'loss=', '0.000674017')
# ('Epoch:', '0039', 'training time (minutes)=', '2.0036', 'loss=', '0.000681221')
# ('Epoch:', '0040', 'training time (minutes)=', '1.9708', 'loss=', '0.000666400')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '2.0004', 'loss=', '0.000675970')
# ('Epoch:', '0042', 'training time (minutes)=', '1.9733', 'loss=', '0.000658981')
# ('Epoch:', '0043', 'training time (minutes)=', '1.9801', 'loss=', '0.000650851')
# ('Epoch:', '0044', 'training time (minutes)=', '1.9941', 'loss=', '0.000647962')
# ('Epoch:', '0045', 'training time (minutes)=', '1.9785', 'loss=', '0.000646645')
# ('Epoch:', '0046', 'training time (minutes)=', '2.0153', 'loss=', '0.000644171')
# ('Epoch:', '0047', 'training time (minutes)=', '1.9821', 'loss=', '0.000641885')
# ('Epoch:', '0048', 'training time (minutes)=', '2.0025', 'loss=', '0.000634848')
# ('Epoch:', '0049', 'training time (minutes)=', '2.0160', 'loss=', '0.000626668')
# ('Epoch:', '0050', 'training time (minutes)=', '1.9788', 'loss=', '0.000639211')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '2.0156', 'loss=', '0.000626274')
# ('Epoch:', '0052', 'training time (minutes)=', '1.9951', 'loss=', '0.000624010')
# ('Epoch:', '0053', 'training time (minutes)=', '2.0012', 'loss=', '0.000617744')
# ('Epoch:', '0054', 'training time (minutes)=', '1.9611', 'loss=', '0.000629160')
# ('Epoch:', '0055', 'training time (minutes)=', '1.9995', 'loss=', '0.000620776')
# ('Epoch:', '0056', 'training time (minutes)=', '1.9746', 'loss=', '0.000608768')
# ('Epoch:', '0057', 'training time (minutes)=', '1.9839', 'loss=', '0.000629545')
# ('Epoch:', '0058', 'training time (minutes)=', '2.0085', 'loss=', '0.000626487')
# ('Epoch:', '0059', 'training time (minutes)=', '1.9867', 'loss=', '0.000598023')
# ('Epoch:', '0060', 'training time (minutes)=', '1.9577', 'loss=', '0.000597110')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '1.9806', 'loss=', '0.000594318')
# ('Epoch:', '0062', 'training time (minutes)=', '1.9918', 'loss=', '0.000603862')
# ('Epoch:', '0063', 'training time (minutes)=', '1.9696', 'loss=', '0.000599372')
# ('Epoch:', '0064', 'training time (minutes)=', '2.0041', 'loss=', '0.000585513')
# ('Epoch:', '0065', 'training time (minutes)=', '1.9702', 'loss=', '0.000590631')
# ('Epoch:', '0066', 'training time (minutes)=', '1.9728', 'loss=', '0.000589339')
# ('Epoch:', '0067', 'training time (minutes)=', '1.9733', 'loss=', '0.000596516')
# ('Epoch:', '0068', 'training time (minutes)=', '1.9978', 'loss=', '0.000583467')
# ('Epoch:', '0069', 'training time (minutes)=', '1.9713', 'loss=', '0.000569271')
# ('Epoch:', '0070', 'training time (minutes)=', '1.9964', 'loss=', '0.000571583')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '1.9584', 'loss=', '0.000575815')
# ('Epoch:', '0072', 'training time (minutes)=', '1.9650', 'loss=', '0.000609490')
# ('Epoch:', '0073', 'training time (minutes)=', '1.9895', 'loss=', '0.000573184')
# ('Epoch:', '0074', 'training time (minutes)=', '1.9717', 'loss=', '0.000567944')
# ('Epoch:', '0075', 'training time (minutes)=', '1.9589', 'loss=', '0.000576728')
# ('Epoch:', '0076', 'training time (minutes)=', '1.9945', 'loss=', '0.000579496')
# ('Epoch:', '0077', 'training time (minutes)=', '1.9589', 'loss=', '0.000566155')
# ('Epoch:', '0078', 'training time (minutes)=', '1.9489', 'loss=', '0.000566008')
# ('Epoch:', '0079', 'training time (minutes)=', '1.9580', 'loss=', '0.000563009')
# ('Epoch:', '0080', 'training time (minutes)=', '2.0047', 'loss=', '0.000563975')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '1.9804', 'loss=', '0.000563314')
# ('Epoch:', '0082', 'training time (minutes)=', '1.9903', 'loss=', '0.000570681')
# ('Epoch:', '0083', 'training time (minutes)=', '1.9797', 'loss=', '0.000561146')
# ('Epoch:', '0084', 'training time (minutes)=', '1.9616', 'loss=', '0.000560816')
# ('Epoch:', '0085', 'training time (minutes)=', '1.9917', 'loss=', '0.000561448')
# ('Epoch:', '0086', 'training time (minutes)=', '1.9964', 'loss=', '0.000553385')
# ('Epoch:', '0087', 'training time (minutes)=', '1.9682', 'loss=', '0.000557958')
# ('Epoch:', '0088', 'training time (minutes)=', '1.9786', 'loss=', '0.000550493')
# ('Epoch:', '0089', 'training time (minutes)=', '1.9828', 'loss=', '0.000576660')
# ('Epoch:', '0090', 'training time (minutes)=', '1.9994', 'loss=', '0.000573633')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '2.0104', 'loss=', '0.000545882')
# ('Epoch:', '0092', 'training time (minutes)=', '2.0002', 'loss=', '0.000547571')
# ('Epoch:', '0093', 'training time (minutes)=', '2.0031', 'loss=', '0.000544669')
# ('Epoch:', '0094', 'training time (minutes)=', '2.0044', 'loss=', '0.000547056')
# ('Epoch:', '0095', 'training time (minutes)=', '1.9895', 'loss=', '0.000548621')
# ('Epoch:', '0096', 'training time (minutes)=', '1.9840', 'loss=', '0.000541000')
# ('Epoch:', '0097', 'training time (minutes)=', '1.9926', 'loss=', '0.000551763')
# ('Epoch:', '0098', 'training time (minutes)=', '1.9720', 'loss=', '0.000547286')
# ('Epoch:', '0099', 'training time (minutes)=', '1.9984', 'loss=', '0.000549116')
# ('Epoch:', '0100', 'training time (minutes)=', '1.9975', 'loss=', '0.000536326')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '1.9958', 'loss=', '0.000544381')
# ('Epoch:', '0102', 'training time (minutes)=', '1.9765', 'loss=', '0.000547497')
# ('Epoch:', '0103', 'training time (minutes)=', '1.9717', 'loss=', '0.000534529')
# ('Epoch:', '0104', 'training time (minutes)=', '2.0074', 'loss=', '0.000528578')
# ('Epoch:', '0105', 'training time (minutes)=', '1.9704', 'loss=', '0.000528315')
# ('Epoch:', '0106', 'training time (minutes)=', '1.9889', 'loss=', '0.000525756')
# ('Epoch:', '0107', 'training time (minutes)=', '1.9892', 'loss=', '0.000528185')
# ('Epoch:', '0108', 'training time (minutes)=', '1.9857', 'loss=', '0.000526400')
# ('Epoch:', '0109', 'training time (minutes)=', '2.0138', 'loss=', '0.000555787')
# ('Epoch:', '0110', 'training time (minutes)=', '1.9814', 'loss=', '0.000540094')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '2.0114', 'loss=', '0.000534218')
# ('Epoch:', '0112', 'training time (minutes)=', '1.9818', 'loss=', '0.000525938')
# ('Epoch:', '0113', 'training time (minutes)=', '1.9676', 'loss=', '0.000529895')
# ('Epoch:', '0114', 'training time (minutes)=', '1.9871', 'loss=', '0.000528073')
# ('Epoch:', '0115', 'training time (minutes)=', '1.9800', 'loss=', '0.000525253')
# ('Epoch:', '0116', 'training time (minutes)=', '2.0105', 'loss=', '0.000529266')
# ('Epoch:', '0117', 'training time (minutes)=', '1.9984', 'loss=', '0.000530652')
# ('Epoch:', '0118', 'training time (minutes)=', '2.0012', 'loss=', '0.000514673')
# ('Epoch:', '0119', 'training time (minutes)=', '1.9816', 'loss=', '0.000513119')
# ('Epoch:', '0120', 'training time (minutes)=', '1.9788', 'loss=', '0.000517942')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '1.9874', 'loss=', '0.000517975')
# ('Epoch:', '0122', 'training time (minutes)=', '2.0094', 'loss=', '0.000513642')
# ('Epoch:', '0123', 'training time (minutes)=', '1.9896', 'loss=', '0.000519663')
# ('Epoch:', '0124', 'training time (minutes)=', '1.9816', 'loss=', '0.000510998')
# ('Epoch:', '0125', 'training time (minutes)=', '2.0128', 'loss=', '0.000519627')
# ('Epoch:', '0126', 'training time (minutes)=', '1.9737', 'loss=', '0.000517277')
# ('Epoch:', '0127', 'training time (minutes)=', '1.9576', 'loss=', '0.000505653')
# ('Epoch:', '0128', 'training time (minutes)=', '1.9959', 'loss=', '0.000521033')
# ('Epoch:', '0129', 'training time (minutes)=', '1.9903', 'loss=', '0.000510873')
# ('Epoch:', '0130', 'training time (minutes)=', '1.9935', 'loss=', '0.000514577')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '1.9904', 'loss=', '0.000514111')
# ('Epoch:', '0132', 'training time (minutes)=', '1.9519', 'loss=', '0.000513327')
# ('Epoch:', '0133', 'training time (minutes)=', '1.9820', 'loss=', '0.000504760')
# ('Epoch:', '0134', 'training time (minutes)=', '1.9821', 'loss=', '0.000517125')
# ('Epoch:', '0135', 'training time (minutes)=', '1.9850', 'loss=', '0.000510617')
# ('Epoch:', '0136', 'training time (minutes)=', '1.9723', 'loss=', '0.000510244')
# ('Epoch:', '0137', 'training time (minutes)=', '1.9932', 'loss=', '0.000516270')
# ('Epoch:', '0138', 'training time (minutes)=', '1.9693', 'loss=', '0.000505538')
# ('Epoch:', '0139', 'training time (minutes)=', '1.9759', 'loss=', '0.000503772')
# ('Epoch:', '0140', 'training time (minutes)=', '1.9961', 'loss=', '0.000507325')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '1.9872', 'loss=', '0.000509173')
# ('Epoch:', '0142', 'training time (minutes)=', '1.9791', 'loss=', '0.000501991')
# ('Epoch:', '0143', 'training time (minutes)=', '1.9878', 'loss=', '0.000495473')
# ('Epoch:', '0144', 'training time (minutes)=', '1.9766', 'loss=', '0.000508531')
# ('Epoch:', '0145', 'training time (minutes)=', '1.9718', 'loss=', '0.000505752')
# ('Epoch:', '0146', 'training time (minutes)=', '1.9527', 'loss=', '0.000501732')
# ('Epoch:', '0147', 'training time (minutes)=', '2.0103', 'loss=', '0.000497750')
# ('Epoch:', '0148', 'training time (minutes)=', '1.9581', 'loss=', '0.000502163')
# ('Epoch:', '0149', 'training time (minutes)=', '1.9563', 'loss=', '0.000505485')
# ('Epoch:', '0150', 'training time (minutes)=', '1.9630', 'loss=', '0.000497958')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '1.9511', 'loss=', '0.000500571')
# ('Epoch:', '0152', 'training time (minutes)=', '1.9845', 'loss=', '0.000526263')
# ('Epoch:', '0153', 'training time (minutes)=', '1.9704', 'loss=', '0.000492431')
# ('Epoch:', '0154', 'training time (minutes)=', '1.9897', 'loss=', '0.000487940')
# ('Epoch:', '0155', 'training time (minutes)=', '1.9629', 'loss=', '0.000496355')
# ('Epoch:', '0156', 'training time (minutes)=', '1.9725', 'loss=', '0.000504675')
# ('Epoch:', '0157', 'training time (minutes)=', '2.0028', 'loss=', '0.000487714')
# ('Epoch:', '0158', 'training time (minutes)=', '1.9572', 'loss=', '0.000493987')
# ('Epoch:', '0159', 'training time (minutes)=', '1.9934', 'loss=', '0.000493623')
# ('Epoch:', '0160', 'training time (minutes)=', '1.9899', 'loss=', '0.000497240')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '1.9822', 'loss=', '0.000494638')
# ('Epoch:', '0162', 'training time (minutes)=', '1.9997', 'loss=', '0.000489781')
# ('Epoch:', '0163', 'training time (minutes)=', '1.9777', 'loss=', '0.000507577')
# ('Epoch:', '0164', 'training time (minutes)=', '1.9587', 'loss=', '0.000477760')
# ('Epoch:', '0165', 'training time (minutes)=', '1.9781', 'loss=', '0.000491753')
# ('Epoch:', '0166', 'training time (minutes)=', '1.9736', 'loss=', '0.000483615')
# ('Epoch:', '0167', 'training time (minutes)=', '1.9639', 'loss=', '0.000485543')
# ('Epoch:', '0168', 'training time (minutes)=', '1.9644', 'loss=', '0.000492584')
# ('Epoch:', '0169', 'training time (minutes)=', '1.9892', 'loss=', '0.000488765')
# ('Epoch:', '0170', 'training time (minutes)=', '1.9460', 'loss=', '0.000484357')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '1.9747', 'loss=', '0.000482398')
# ('Epoch:', '0172', 'training time (minutes)=', '1.9841', 'loss=', '0.000479856')
# ('Epoch:', '0173', 'training time (minutes)=', '1.9564', 'loss=', '0.000490652')
# ('Epoch:', '0174', 'training time (minutes)=', '1.9824', 'loss=', '0.000492184')
# ('Epoch:', '0175', 'training time (minutes)=', '1.9526', 'loss=', '0.000482440')
# ('Epoch:', '0176', 'training time (minutes)=', '1.9303', 'loss=', '0.000478207')
# ('Epoch:', '0177', 'training time (minutes)=', '1.9521', 'loss=', '0.000485912')
# ('Epoch:', '0178', 'training time (minutes)=', '1.9447', 'loss=', '0.000495106')
# ('Epoch:', '0179', 'training time (minutes)=', '1.9690', 'loss=', '0.000486645')
# ('Epoch:', '0180', 'training time (minutes)=', '1.9528', 'loss=', '0.000483003')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '1.9667', 'loss=', '0.000501334')
# ('Epoch:', '0182', 'training time (minutes)=', '1.9531', 'loss=', '0.000476232')
# ('Epoch:', '0183', 'training time (minutes)=', '2.0001', 'loss=', '0.000481978')
# ('Epoch:', '0184', 'training time (minutes)=', '1.9508', 'loss=', '0.000483598')
# ('Epoch:', '0185', 'training time (minutes)=', '1.9758', 'loss=', '0.000482287')
# ('Epoch:', '0186', 'training time (minutes)=', '1.9679', 'loss=', '0.000477376')
# ('Epoch:', '0187', 'training time (minutes)=', '1.9702', 'loss=', '0.000482610')
# ('Epoch:', '0188', 'training time (minutes)=', '1.9792', 'loss=', '0.000482345')
# ('Epoch:', '0189', 'training time (minutes)=', '1.9478', 'loss=', '0.000471529')
# ('Epoch:', '0190', 'training time (minutes)=', '1.9730', 'loss=', '0.000482120')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '1.9677', 'loss=', '0.000473823')
# ('Epoch:', '0192', 'training time (minutes)=', '1.9721', 'loss=', '0.000482518')
# ('Epoch:', '0193', 'training time (minutes)=', '1.9321', 'loss=', '0.000482770')
# ('Epoch:', '0194', 'training time (minutes)=', '1.9667', 'loss=', '0.000477516')
# ('Epoch:', '0195', 'training time (minutes)=', '1.9783', 'loss=', '0.000479958')
# ('Epoch:', '0196', 'training time (minutes)=', '1.9824', 'loss=', '0.000472823')
# ('Epoch:', '0197', 'training time (minutes)=', '1.9834', 'loss=', '0.000472233')
# ('Epoch:', '0198', 'training time (minutes)=', '1.9564', 'loss=', '0.000474482')
# ('Epoch:', '0199', 'training time (minutes)=', '1.9723', 'loss=', '0.000472392')
# ('Epoch:', '0200', 'training time (minutes)=', '1.9970', 'loss=', '0.000478853')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '1.9526', 'loss=', '0.000474932')
# ('Epoch:', '0202', 'training time (minutes)=', '1.9855', 'loss=', '0.000473791')
# ('Epoch:', '0203', 'training time (minutes)=', '1.9635', 'loss=', '0.000575464')
# ('Epoch:', '0204', 'training time (minutes)=', '1.9562', 'loss=', '0.000483687')
# ('Epoch:', '0205', 'training time (minutes)=', '1.9862', 'loss=', '0.000465639')
# ('Epoch:', '0206', 'training time (minutes)=', '1.9717', 'loss=', '0.000466542')
# ('Epoch:', '0207', 'training time (minutes)=', '1.9621', 'loss=', '0.000475207')
# ('Epoch:', '0208', 'training time (minutes)=', '1.9861', 'loss=', '0.000459657')
# ('Epoch:', '0209', 'training time (minutes)=', '1.9444', 'loss=', '0.000474109')
# ('Epoch:', '0210', 'training time (minutes)=', '1.9877', 'loss=', '0.000474198')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '1.9443', 'loss=', '0.000466950')
# ('Epoch:', '0212', 'training time (minutes)=', '1.9742', 'loss=', '0.000459389')
# ('Epoch:', '0213', 'training time (minutes)=', '1.9704', 'loss=', '0.000466485')
# ('Epoch:', '0214', 'training time (minutes)=', '1.9762', 'loss=', '0.000469291')
# ('Epoch:', '0215', 'training time (minutes)=', '1.9552', 'loss=', '0.000470113')
# ('Epoch:', '0216', 'training time (minutes)=', '1.9528', 'loss=', '0.000462518')
# ('Epoch:', '0217', 'training time (minutes)=', '1.9853', 'loss=', '0.000468318')
# ('Epoch:', '0218', 'training time (minutes)=', '1.9509', 'loss=', '0.000463254')
# ('Epoch:', '0219', 'training time (minutes)=', '1.9871', 'loss=', '0.000469852')
# ('Epoch:', '0220', 'training time (minutes)=', '1.9605', 'loss=', '0.000480410')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '1.9695', 'loss=', '0.000465292')
# ('Epoch:', '0222', 'training time (minutes)=', '1.9552', 'loss=', '0.000466260')
# ('Epoch:', '0223', 'training time (minutes)=', '1.9361', 'loss=', '0.000461548')
# ('Epoch:', '0224', 'training time (minutes)=', '1.9832', 'loss=', '0.000466930')
# ('Epoch:', '0225', 'training time (minutes)=', '1.9628', 'loss=', '0.000463643')
# ('Epoch:', '0226', 'training time (minutes)=', '1.9813', 'loss=', '0.000466623')
# ('Epoch:', '0227', 'training time (minutes)=', '1.9714', 'loss=', '0.000459244')
# ('Epoch:', '0228', 'training time (minutes)=', '1.9478', 'loss=', '0.000464004')
# ('Epoch:', '0229', 'training time (minutes)=', '1.9957', 'loss=', '0.000532215')
# ('Epoch:', '0230', 'training time (minutes)=', '1.9650', 'loss=', '0.000460668')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '1.9873', 'loss=', '0.000461543')
# ('Epoch:', '0232', 'training time (minutes)=', '1.9489', 'loss=', '0.000467489')
# ('Epoch:', '0233', 'training time (minutes)=', '1.9713', 'loss=', '0.000461480')
# ('Epoch:', '0234', 'training time (minutes)=', '1.9639', 'loss=', '0.000465148')
# ('Epoch:', '0235', 'training time (minutes)=', '1.9587', 'loss=', '0.000467762')
# ('Epoch:', '0236', 'training time (minutes)=', '1.9640', 'loss=', '0.000463444')
# ('Epoch:', '0237', 'training time (minutes)=', '1.9444', 'loss=', '0.000456741')
# ('Epoch:', '0238', 'training time (minutes)=', '1.9426', 'loss=', '0.000460248')
# ('Epoch:', '0239', 'training time (minutes)=', '1.9617', 'loss=', '0.000461321')
# ('Epoch:', '0240', 'training time (minutes)=', '1.9798', 'loss=', '0.000463577')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '1.9552', 'loss=', '0.000461428')
# ('Epoch:', '0242', 'training time (minutes)=', '1.9475', 'loss=', '0.000459373')
# ('Epoch:', '0243', 'training time (minutes)=', '1.9523', 'loss=', '0.000460010')
# ('Epoch:', '0244', 'training time (minutes)=', '1.9970', 'loss=', '0.000459063')
# ('Epoch:', '0245', 'training time (minutes)=', '1.9769', 'loss=', '0.000461744')
# ('Epoch:', '0246', 'training time (minutes)=', '1.9337', 'loss=', '0.000453409')
# ('Epoch:', '0247', 'training time (minutes)=', '1.9378', 'loss=', '0.000454177')
# ('Epoch:', '0248', 'training time (minutes)=', '1.9532', 'loss=', '0.000457266')
# ('Epoch:', '0249', 'training time (minutes)=', '1.9822', 'loss=', '0.000456162')
# ('Epoch:', '0250', 'training time (minutes)=', '1.9673', 'loss=', '0.000460891')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '1.9537', 'loss=', '0.000456146')
# ('Epoch:', '0252', 'training time (minutes)=', '1.9563', 'loss=', '0.000458395')
# ('Epoch:', '0253', 'training time (minutes)=', '1.9334', 'loss=', '0.000453257')
# ('Epoch:', '0254', 'training time (minutes)=', '1.9567', 'loss=', '0.000459739')
# ('Epoch:', '0255', 'training time (minutes)=', '1.9443', 'loss=', '0.000451702')
# ('Epoch:', '0256', 'training time (minutes)=', '1.9817', 'loss=', '0.000451751')
# ('Epoch:', '0257', 'training time (minutes)=', '1.9443', 'loss=', '0.000461215')
# ('Epoch:', '0258', 'training time (minutes)=', '1.9421', 'loss=', '0.000456519')
# ('Epoch:', '0259', 'training time (minutes)=', '1.9351', 'loss=', '0.000456138')
# ('Epoch:', '0260', 'training time (minutes)=', '1.9660', 'loss=', '0.000460641')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '1.9454', 'loss=', '0.000452327')
# ('Epoch:', '0262', 'training time (minutes)=', '1.9407', 'loss=', '0.000450529')
# ('Epoch:', '0263', 'training time (minutes)=', '1.9657', 'loss=', '0.000453417')
# ('Epoch:', '0264', 'training time (minutes)=', '2.0497', 'loss=', '0.000449061')
# ('Epoch:', '0265', 'training time (minutes)=', '1.9587', 'loss=', '0.000451241')
# ('Epoch:', '0266', 'training time (minutes)=', '1.9624', 'loss=', '0.000460617')
# ('Epoch:', '0267', 'training time (minutes)=', '1.9375', 'loss=', '0.000453856')
# ('Epoch:', '0268', 'training time (minutes)=', '1.9751', 'loss=', '0.000450834')
# ('Epoch:', '0269', 'training time (minutes)=', '1.9450', 'loss=', '0.000450706')
# ('Epoch:', '0270', 'training time (minutes)=', '1.9627', 'loss=', '0.000456549')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '1.9273', 'loss=', '0.000448798')
# ('Epoch:', '0272', 'training time (minutes)=', '1.9563', 'loss=', '0.000449287')
# ('Epoch:', '0273', 'training time (minutes)=', '1.9375', 'loss=', '0.000447773')
# ('Epoch:', '0274', 'training time (minutes)=', '1.9745', 'loss=', '0.000454240')
# ('Epoch:', '0275', 'training time (minutes)=', '1.9373', 'loss=', '0.000449609')
# ('Epoch:', '0276', 'training time (minutes)=', '1.9764', 'loss=', '0.000458487')
# ('Epoch:', '0277', 'training time (minutes)=', '1.9644', 'loss=', '0.000457425')
# ('Epoch:', '0278', 'training time (minutes)=', '1.9665', 'loss=', '0.000453982')
# ('Epoch:', '0279', 'training time (minutes)=', '1.9769', 'loss=', '0.000442919')
# ('Epoch:', '0280', 'training time (minutes)=', '1.9498', 'loss=', '0.000446764')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '1.9775', 'loss=', '0.000451415')
# ('Epoch:', '0282', 'training time (minutes)=', '1.9724', 'loss=', '0.000445443')
# ('Epoch:', '0283', 'training time (minutes)=', '1.9667', 'loss=', '0.000442548')
# ('Epoch:', '0284', 'training time (minutes)=', '1.9700', 'loss=', '0.000447218')
# ('Epoch:', '0285', 'training time (minutes)=', '1.9758', 'loss=', '0.000459190')
# ('Epoch:', '0286', 'training time (minutes)=', '1.9609', 'loss=', '0.000451865')
# ('Epoch:', '0287', 'training time (minutes)=', '2.0085', 'loss=', '0.000445840')
# ('Epoch:', '0288', 'training time (minutes)=', '1.9597', 'loss=', '0.000436942')
# ('Epoch:', '0289', 'training time (minutes)=', '1.9606', 'loss=', '0.000451642')
# ('Epoch:', '0290', 'training time (minutes)=', '1.9427', 'loss=', '0.000451193')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '1.9929', 'loss=', '0.000448802')
# ('Epoch:', '0292', 'training time (minutes)=', '1.9716', 'loss=', '0.000439751')
# ('Epoch:', '0293', 'training time (minutes)=', '1.9616', 'loss=', '0.000445132')
# ('Epoch:', '0294', 'training time (minutes)=', '1.9792', 'loss=', '0.000438317')
# ('Epoch:', '0295', 'training time (minutes)=', '1.9431', 'loss=', '0.000447165')
# ('Epoch:', '0296', 'training time (minutes)=', '1.9665', 'loss=', '0.000442910')
# ('Epoch:', '0297', 'training time (minutes)=', '1.9720', 'loss=', '0.000448558')
# ('Epoch:', '0298', 'training time (minutes)=', '1.9558', 'loss=', '0.000442819')
# ('Epoch:', '0299', 'training time (minutes)=', '1.9489', 'loss=', '0.000442135')
# ('Epoch:', '0300', 'training time (minutes)=', '1.9823', 'loss=', '0.000443906')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '1.9662', 'loss=', '0.000455173')
# ('Epoch:', '0302', 'training time (minutes)=', '1.9742', 'loss=', '0.000453064')
# ('Epoch:', '0303', 'training time (minutes)=', '1.9518', 'loss=', '0.000444629')
# ('Epoch:', '0304', 'training time (minutes)=', '2.0072', 'loss=', '0.000453043')
# ('Epoch:', '0305', 'training time (minutes)=', '1.9597', 'loss=', '0.000441270')
# ('Epoch:', '0306', 'training time (minutes)=', '1.9885', 'loss=', '0.000443463')
# ('Epoch:', '0307', 'training time (minutes)=', '1.9632', 'loss=', '0.000445747')
# ('Epoch:', '0308', 'training time (minutes)=', '2.0110', 'loss=', '0.000435317')
# ('Epoch:', '0309', 'training time (minutes)=', '1.9761', 'loss=', '0.000438945')
# ('Epoch:', '0310', 'training time (minutes)=', '1.9508', 'loss=', '0.000437976')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '1.9711', 'loss=', '0.000438036')
# ('Epoch:', '0312', 'training time (minutes)=', '1.9324', 'loss=', '0.000449399')
# ('Epoch:', '0313', 'training time (minutes)=', '1.9638', 'loss=', '0.000445501')
# ('Epoch:', '0314', 'training time (minutes)=', '1.9465', 'loss=', '0.000445094')
# ('Epoch:', '0315', 'training time (minutes)=', '1.9246', 'loss=', '0.000441649')
# ('Epoch:', '0316', 'training time (minutes)=', '1.9689', 'loss=', '0.000442808')
# ('Epoch:', '0317', 'training time (minutes)=', '1.9122', 'loss=', '0.000443674')
# ('Epoch:', '0318', 'training time (minutes)=', '1.9624', 'loss=', '0.000445919')
# ('Epoch:', '0319', 'training time (minutes)=', '1.9327', 'loss=', '0.000434191')
# ('Epoch:', '0320', 'training time (minutes)=', '1.9486', 'loss=', '0.000448451')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '1.9677', 'loss=', '0.000446180')
# ('Epoch:', '0322', 'training time (minutes)=', '1.9496', 'loss=', '0.000435737')
# ('Epoch:', '0323', 'training time (minutes)=', '1.9577', 'loss=', '0.000443062')
# ('Epoch:', '0324', 'training time (minutes)=', '1.9250', 'loss=', '0.000443714')
# ('Epoch:', '0325', 'training time (minutes)=', '1.9295', 'loss=', '0.000439179')
# ('Epoch:', '0326', 'training time (minutes)=', '1.9659', 'loss=', '0.000441379')
# ('Epoch:', '0327', 'training time (minutes)=', '1.9249', 'loss=', '0.000438066')
# ('Epoch:', '0328', 'training time (minutes)=', '1.9693', 'loss=', '0.000432002')
# ('Epoch:', '0329', 'training time (minutes)=', '1.9377', 'loss=', '0.000438747')
# ('Epoch:', '0330', 'training time (minutes)=', '1.9723', 'loss=', '0.000435693')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '1.9322', 'loss=', '0.000445461')
# ('Epoch:', '0332', 'training time (minutes)=', '1.9493', 'loss=', '0.000437881')
# ('Epoch:', '0333', 'training time (minutes)=', '1.9494', 'loss=', '0.000440420')
# ('Epoch:', '0334', 'training time (minutes)=', '1.9310', 'loss=', '0.000438474')
# ('Epoch:', '0335', 'training time (minutes)=', '1.9536', 'loss=', '0.000444867')
# ('Epoch:', '0336', 'training time (minutes)=', '1.9438', 'loss=', '0.000439117')
# ('Epoch:', '0337', 'training time (minutes)=', '1.9324', 'loss=', '0.000445263')
# ('Epoch:', '0338', 'training time (minutes)=', '1.9384', 'loss=', '0.000436261')
# ('Epoch:', '0339', 'training time (minutes)=', '1.9293', 'loss=', '0.000434996')
# ('Epoch:', '0340', 'training time (minutes)=', '1.9553', 'loss=', '0.000435337')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '1.9410', 'loss=', '0.000428179')
# ('Epoch:', '0342', 'training time (minutes)=', '1.9477', 'loss=', '0.000436490')
# ('Epoch:', '0343', 'training time (minutes)=', '1.9355', 'loss=', '0.000438642')
# ('Epoch:', '0344', 'training time (minutes)=', '1.9447', 'loss=', '0.000433250')
# ('Epoch:', '0345', 'training time (minutes)=', '1.9614', 'loss=', '0.000436104')
# ('Epoch:', '0346', 'training time (minutes)=', '1.9317', 'loss=', '0.000434240')
# ('Epoch:', '0347', 'training time (minutes)=', '1.9430', 'loss=', '0.000439929')
# ('Epoch:', '0348', 'training time (minutes)=', '1.9638', 'loss=', '0.000441320')
# ('Epoch:', '0349', 'training time (minutes)=', '1.9706', 'loss=', '0.000433739')
# ('Epoch:', '0350', 'training time (minutes)=', '1.9744', 'loss=', '0.000430998')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '1.9580', 'loss=', '0.000431418')
# ('Epoch:', '0352', 'training time (minutes)=', '1.9689', 'loss=', '0.000435737')
# ('Epoch:', '0353', 'training time (minutes)=', '1.9687', 'loss=', '0.000436037')
# ('Epoch:', '0354', 'training time (minutes)=', '1.9618', 'loss=', '0.000433211')
# ('Epoch:', '0355', 'training time (minutes)=', '1.9744', 'loss=', '0.000432441')
# ('Epoch:', '0356', 'training time (minutes)=', '1.9682', 'loss=', '0.000441192')
# ('Epoch:', '0357', 'training time (minutes)=', '1.9586', 'loss=', '0.000430941')
# ('Epoch:', '0358', 'training time (minutes)=', '1.9520', 'loss=', '0.000440482')
# ('Epoch:', '0359', 'training time (minutes)=', '1.9727', 'loss=', '0.000430019')
# ('Epoch:', '0360', 'training time (minutes)=', '1.9713', 'loss=', '0.000432429')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0361', 'training time (minutes)=', '1.9467', 'loss=', '0.000430811')
# ('Epoch:', '0362', 'training time (minutes)=', '1.9680', 'loss=', '0.000424881')
# ('Epoch:', '0363', 'training time (minutes)=', '1.9822', 'loss=', '0.000428379')
# ('Epoch:', '0364', 'training time (minutes)=', '1.9582', 'loss=', '0.000433217')
# ('Epoch:', '0365', 'training time (minutes)=', '1.9320', 'loss=', '0.000436229')
# ('Epoch:', '0366', 'training time (minutes)=', '1.9672', 'loss=', '0.000437163')
# ('Epoch:', '0367', 'training time (minutes)=', '1.9324', 'loss=', '0.000433955')
# ('Epoch:', '0368', 'training time (minutes)=', '1.9807', 'loss=', '0.000435602')
# ('Epoch:', '0369', 'training time (minutes)=', '1.9709', 'loss=', '0.000437860')
# ('Epoch:', '0370', 'training time (minutes)=', '1.9496', 'loss=', '0.000437890')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0371', 'training time (minutes)=', '1.9623', 'loss=', '0.000432694')
# ('Epoch:', '0372', 'training time (minutes)=', '1.9806', 'loss=', '0.000429620')
# ('Epoch:', '0373', 'training time (minutes)=', '1.9884', 'loss=', '0.000427982')
# ('Epoch:', '0374', 'training time (minutes)=', '1.9577', 'loss=', '0.000438417')
# ('Epoch:', '0375', 'training time (minutes)=', '1.9507', 'loss=', '0.000425197')
# ('Epoch:', '0376', 'training time (minutes)=', '1.9820', 'loss=', '0.000431470')
# ('Epoch:', '0377', 'training time (minutes)=', '1.9414', 'loss=', '0.000434430')
# ('Epoch:', '0378', 'training time (minutes)=', '1.9553', 'loss=', '0.000436488')
# ('Epoch:', '0379', 'training time (minutes)=', '1.9561', 'loss=', '0.000429905')
# ('Epoch:', '0380', 'training time (minutes)=', '1.9473', 'loss=', '0.000433171')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0381', 'training time (minutes)=', '1.9682', 'loss=', '0.000434627')
# ('Epoch:', '0382', 'training time (minutes)=', '1.9525', 'loss=', '0.000427653')
# ('Epoch:', '0383', 'training time (minutes)=', '1.9544', 'loss=', '0.000436341')
# ('Epoch:', '0384', 'training time (minutes)=', '1.9430', 'loss=', '0.000430622')
# ('Epoch:', '0385', 'training time (minutes)=', '1.9590', 'loss=', '0.000426664')
# ('Epoch:', '0386', 'training time (minutes)=', '1.9769', 'loss=', '0.000432453')
# ('Epoch:', '0387', 'training time (minutes)=', '1.9478', 'loss=', '0.000424239')
# ('Epoch:', '0388', 'training time (minutes)=', '1.9575', 'loss=', '0.000425541')
# ('Epoch:', '0389', 'training time (minutes)=', '1.9491', 'loss=', '0.000428293')
# ('Epoch:', '0390', 'training time (minutes)=', '1.9535', 'loss=', '0.000428068')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0391', 'training time (minutes)=', '1.9739', 'loss=', '0.000426094')
# ('Epoch:', '0392', 'training time (minutes)=', '1.9654', 'loss=', '0.000428866')
# ('Epoch:', '0393', 'training time (minutes)=', '1.9584', 'loss=', '0.000435389')
# ('Epoch:', '0394', 'training time (minutes)=', '1.9305', 'loss=', '0.000419741')
# ('Epoch:', '0395', 'training time (minutes)=', '1.9573', 'loss=', '0.000426443')
# ('Epoch:', '0396', 'training time (minutes)=', '1.9745', 'loss=', '0.000429279')
# ('Epoch:', '0397', 'training time (minutes)=', '1.9518', 'loss=', '0.000430764')
# ('Epoch:', '0398', 'training time (minutes)=', '1.9595', 'loss=', '0.000426418')
# ('Epoch:', '0399', 'training time (minutes)=', '1.9677', 'loss=', '0.000426186')
# ('Epoch:', '0400', 'training time (minutes)=', '1.9709', 'loss=', '0.000433632')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0401', 'training time (minutes)=', '1.9719', 'loss=', '0.000427786')
# ('Epoch:', '0402', 'training time (minutes)=', '1.9575', 'loss=', '0.000426005')
# ('Epoch:', '0403', 'training time (minutes)=', '1.9707', 'loss=', '0.000430066')
# ('Epoch:', '0404', 'training time (minutes)=', '1.9666', 'loss=', '0.000422367')
# ('Epoch:', '0405', 'training time (minutes)=', '1.9558', 'loss=', '0.000428529')
# ('Epoch:', '0406', 'training time (minutes)=', '1.9614', 'loss=', '0.000434857')
# ('Epoch:', '0407', 'training time (minutes)=', '1.9469', 'loss=', '0.000420592')
# ('Epoch:', '0408', 'training time (minutes)=', '1.9749', 'loss=', '0.000428287')
# ('Epoch:', '0409', 'training time (minutes)=', '1.9881', 'loss=', '0.000431053')
# ('Epoch:', '0410', 'training time (minutes)=', '1.9485', 'loss=', '0.000425697')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0411', 'training time (minutes)=', '1.9710', 'loss=', '0.000427995')
# ('Epoch:', '0412', 'training time (minutes)=', '1.9650', 'loss=', '0.000424602')
# ('Epoch:', '0413', 'training time (minutes)=', '1.9782', 'loss=', '0.000422307')
# ('Epoch:', '0414', 'training time (minutes)=', '1.9687', 'loss=', '0.000418033')
# ('Epoch:', '0415', 'training time (minutes)=', '1.9460', 'loss=', '0.000438804')
# ('Epoch:', '0416', 'training time (minutes)=', '1.9853', 'loss=', '0.000432319')
# ('Epoch:', '0417', 'training time (minutes)=', '1.9594', 'loss=', '0.000418595')
# ('Epoch:', '0418', 'training time (minutes)=', '1.9771', 'loss=', '0.000423426')
# ('Epoch:', '0419', 'training time (minutes)=', '1.9639', 'loss=', '0.000422761')
# ('Epoch:', '0420', 'training time (minutes)=', '1.9726', 'loss=', '0.000422071')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0421', 'training time (minutes)=', '1.9585', 'loss=', '0.000426835')
# ('Epoch:', '0422', 'training time (minutes)=', '1.9484', 'loss=', '0.000424927')
# ('Epoch:', '0423', 'training time (minutes)=', '1.9646', 'loss=', '0.000423001')
# ('Epoch:', '0424', 'training time (minutes)=', '1.9726', 'loss=', '0.000425951')
# ('Epoch:', '0425', 'training time (minutes)=', '1.9808', 'loss=', '0.000432399')
# ('Epoch:', '0426', 'training time (minutes)=', '1.9438', 'loss=', '0.000427451')
# ('Epoch:', '0427', 'training time (minutes)=', '1.9823', 'loss=', '0.000425851')
# ('Epoch:', '0428', 'training time (minutes)=', '1.9696', 'loss=', '0.000420201')
# ('Epoch:', '0429', 'training time (minutes)=', '1.9696', 'loss=', '0.000432549')
# ('Epoch:', '0430', 'training time (minutes)=', '1.9726', 'loss=', '0.000422134')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0431', 'training time (minutes)=', '1.9562', 'loss=', '0.000425988')
# ('Epoch:', '0432', 'training time (minutes)=', '1.9386', 'loss=', '0.000426670')
# ('Epoch:', '0433', 'training time (minutes)=', '1.9359', 'loss=', '0.000423273')
# ('Epoch:', '0434', 'training time (minutes)=', '1.9605', 'loss=', '0.000420079')
# ('Epoch:', '0435', 'training time (minutes)=', '1.9794', 'loss=', '0.000418039')
# ('Epoch:', '0436', 'training time (minutes)=', '1.9619', 'loss=', '0.000427776')
# ('Epoch:', '0437', 'training time (minutes)=', '1.9777', 'loss=', '0.000413983')
# ('Epoch:', '0438', 'training time (minutes)=', '1.9519', 'loss=', '0.000429884')
# ('Epoch:', '0439', 'training time (minutes)=', '1.9600', 'loss=', '0.000421313')
# ('Epoch:', '0440', 'training time (minutes)=', '1.9776', 'loss=', '0.000418497')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0441', 'training time (minutes)=', '1.9553', 'loss=', '0.000425271')
# ('Epoch:', '0442', 'training time (minutes)=', '1.9713', 'loss=', '0.000419939')
# ('Epoch:', '0443', 'training time (minutes)=', '1.9330', 'loss=', '0.000427753')
# ('Epoch:', '0444', 'training time (minutes)=', '1.9422', 'loss=', '0.000421504')
# ('Epoch:', '0445', 'training time (minutes)=', '1.9760', 'loss=', '0.000414810')
# ('Epoch:', '0446', 'training time (minutes)=', '1.9490', 'loss=', '0.000421726')
# ('Epoch:', '0447', 'training time (minutes)=', '1.9423', 'loss=', '0.000423352')
# ('Epoch:', '0448', 'training time (minutes)=', '1.9719', 'loss=', '0.000417404')
# ('Epoch:', '0449', 'training time (minutes)=', '1.9879', 'loss=', '0.000420218')
# ('Epoch:', '0450', 'training time (minutes)=', '1.9544', 'loss=', '0.000416772')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0451', 'training time (minutes)=', '1.9643', 'loss=', '0.000426267')
# ('Epoch:', '0452', 'training time (minutes)=', '1.9813', 'loss=', '0.000417924')
# ('Epoch:', '0453', 'training time (minutes)=', '1.9714', 'loss=', '0.000416666')
# ('Epoch:', '0454', 'training time (minutes)=', '1.9739', 'loss=', '0.000414003')
# ('Epoch:', '0455', 'training time (minutes)=', '1.9699', 'loss=', '0.000422133')
# ('Epoch:', '0456', 'training time (minutes)=', '1.9536', 'loss=', '0.000447191')
# ('Epoch:', '0457', 'training time (minutes)=', '1.9728', 'loss=', '0.000422528')
# ('Epoch:', '0458', 'training time (minutes)=', '1.9348', 'loss=', '0.000422557')
# ('Epoch:', '0459', 'training time (minutes)=', '1.9645', 'loss=', '0.000411461')
# ('Epoch:', '0460', 'training time (minutes)=', '1.9697', 'loss=', '0.000423822')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0461', 'training time (minutes)=', '1.9714', 'loss=', '0.000419607')
# ('Epoch:', '0462', 'training time (minutes)=', '1.9735', 'loss=', '0.000417184')
# ('Epoch:', '0463', 'training time (minutes)=', '1.9705', 'loss=', '0.000420401')
# ('Epoch:', '0464', 'training time (minutes)=', '1.9682', 'loss=', '0.000420785')
# ('Epoch:', '0465', 'training time (minutes)=', '1.9488', 'loss=', '0.000420974')
# ('Epoch:', '0466', 'training time (minutes)=', '1.9528', 'loss=', '0.000410099')
# ('Epoch:', '0467', 'training time (minutes)=', '1.9657', 'loss=', '0.000418740')
# ('Epoch:', '0468', 'training time (minutes)=', '1.9366', 'loss=', '0.000410511')
# ('Epoch:', '0469', 'training time (minutes)=', '1.9738', 'loss=', '0.000415336')
# ('Epoch:', '0470', 'training time (minutes)=', '1.9539', 'loss=', '0.000423494')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-470 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0471', 'training time (minutes)=', '1.9566', 'loss=', '0.000424349')
# ...
# ('Epoch:', '1796', 'training time (minutes)=', '2.8825', 'loss=', '0.000359991')
# ('Epoch:', '1797', 'training time (minutes)=', '2.7003', 'loss=', '0.000367408')
# ('Epoch:', '1798', 'training time (minutes)=', '2.9533', 'loss=', '0.000365773')
# ('Epoch:', '1799', 'training time (minutes)=', '3.2204', 'loss=', '0.000363328')
# ('Epoch:', '1800', 'training time (minutes)=', '2.9416', 'loss=', '0.000368990')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1800 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1801', 'training time (minutes)=', '2.9322', 'loss=', '0.000366221')
# ('Epoch:', '1802', 'training time (minutes)=', '2.6282', 'loss=', '0.000361279')
# ('Epoch:', '1803', 'training time (minutes)=', '3.2648', 'loss=', '0.000368667')
# ('Epoch:', '1804', 'training time (minutes)=', '2.7287', 'loss=', '0.000364539')
# ('Epoch:', '1805', 'training time (minutes)=', '3.2628', 'loss=', '0.000369718')
# ('Epoch:', '1806', 'training time (minutes)=', '2.9669', 'loss=', '0.000364696')
# ('Epoch:', '1807', 'training time (minutes)=', '3.2761', 'loss=', '0.000369116')
# ('Epoch:', '1808', 'training time (minutes)=', '3.0476', 'loss=', '0.000367975')
# ('Epoch:', '1809', 'training time (minutes)=', '4.0451', 'loss=', '0.000358434')
# ('Epoch:', '1810', 'training time (minutes)=', '2.6804', 'loss=', '0.000363134')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1810 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1811', 'training time (minutes)=', '3.3917', 'loss=', '0.000360128')
# ('Epoch:', '1812', 'training time (minutes)=', '2.7856', 'loss=', '0.000375339')
# ('Epoch:', '1813', 'training time (minutes)=', '3.4535', 'loss=', '0.000366830')
# ('Epoch:', '1814', 'training time (minutes)=', '2.7579', 'loss=', '0.000361855')
# ('Epoch:', '1815', 'training time (minutes)=', '3.2809', 'loss=', '0.000367587')
# ('Epoch:', '1816', 'training time (minutes)=', '2.9974', 'loss=', '0.000362825')
# ('Epoch:', '1817', 'training time (minutes)=', '3.1345', 'loss=', '0.000363857')
# ('Epoch:', '1818', 'training time (minutes)=', '2.8239', 'loss=', '0.000368871')
# ('Epoch:', '1819', 'training time (minutes)=', '3.2087', 'loss=', '0.000360619')
# ('Epoch:', '1820', 'training time (minutes)=', '2.8206', 'loss=', '0.000358403')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1820 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1821', 'training time (minutes)=', '3.3337', 'loss=', '0.000370322')
# ('Epoch:', '1822', 'training time (minutes)=', '2.8035', 'loss=', '0.000363350')
# ('Epoch:', '1823', 'training time (minutes)=', '3.5586', 'loss=', '0.000367519')
# ('Epoch:', '1824', 'training time (minutes)=', '2.9410', 'loss=', '0.000365513')
# ('Epoch:', '1825', 'training time (minutes)=', '2.6809', 'loss=', '0.000361974')
# ('Epoch:', '1826', 'training time (minutes)=', '2.7413', 'loss=', '0.000365529')
# ('Epoch:', '1827', 'training time (minutes)=', '2.9939', 'loss=', '0.000369442')
# ('Epoch:', '1828', 'training time (minutes)=', '2.7384', 'loss=', '0.000361646')
# ('Epoch:', '1829', 'training time (minutes)=', '3.0158', 'loss=', '0.000368980')
# ('Epoch:', '1830', 'training time (minutes)=', '3.0772', 'loss=', '0.000361501')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1830 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1831', 'training time (minutes)=', '2.8236', 'loss=', '0.000363106')
# ('Epoch:', '1832', 'training time (minutes)=', '2.5306', 'loss=', '0.000364183')
# ('Epoch:', '1833', 'training time (minutes)=', '3.0101', 'loss=', '0.000365346')
# ('Epoch:', '1834', 'training time (minutes)=', '2.5691', 'loss=', '0.000361735')
# ('Epoch:', '1835', 'training time (minutes)=', '2.9030', 'loss=', '0.000365292')
# ('Epoch:', '1836', 'training time (minutes)=', '2.6393', 'loss=', '0.000364334')
# ('Epoch:', '1837', 'training time (minutes)=', '2.7517', 'loss=', '0.000366308')
# ('Epoch:', '1838', 'training time (minutes)=', '2.4135', 'loss=', '0.000362859')
# ('Epoch:', '1839', 'training time (minutes)=', '2.7613', 'loss=', '0.000363275')
# ('Epoch:', '1840', 'training time (minutes)=', '2.6594', 'loss=', '0.000363812')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1840 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1841', 'training time (minutes)=', '3.0088', 'loss=', '0.000361165')
# ('Epoch:', '1842', 'training time (minutes)=', '2.6080', 'loss=', '0.000358480')
# ('Epoch:', '1843', 'training time (minutes)=', '2.9359', 'loss=', '0.000365618')
# ('Epoch:', '1844', 'training time (minutes)=', '2.5974', 'loss=', '0.000360514')
# ('Epoch:', '1845', 'training time (minutes)=', '2.7495', 'loss=', '0.000355069')
# ('Epoch:', '1846', 'training time (minutes)=', '2.6905', 'loss=', '0.000365051')
# ('Epoch:', '1847', 'training time (minutes)=', '2.6703', 'loss=', '0.000363152')
# ('Epoch:', '1848', 'training time (minutes)=', '2.8250', 'loss=', '0.000363092')
# ('Epoch:', '1849', 'training time (minutes)=', '2.8458', 'loss=', '0.000366090')
# ('Epoch:', '1850', 'training time (minutes)=', '2.9375', 'loss=', '0.000369725')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1850 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1851', 'training time (minutes)=', '2.7177', 'loss=', '0.000361323')
# ('Epoch:', '1852', 'training time (minutes)=', '2.8607', 'loss=', '0.000361777')
# ('Epoch:', '1853', 'training time (minutes)=', '2.6646', 'loss=', '0.000367143')
# ('Epoch:', '1854', 'training time (minutes)=', '2.7038', 'loss=', '0.000362819')
# ('Epoch:', '1855', 'training time (minutes)=', '2.8777', 'loss=', '0.000357120')
# ('Epoch:', '1856', 'training time (minutes)=', '2.6862', 'loss=', '0.000379741')
# ('Epoch:', '1857', 'training time (minutes)=', '2.9494', 'loss=', '0.000358330')
# ('Epoch:', '1858', 'training time (minutes)=', '2.7527', 'loss=', '0.000368258')
# ('Epoch:', '1859', 'training time (minutes)=', '2.8886', 'loss=', '0.000367215')
# ('Epoch:', '1860', 'training time (minutes)=', '2.6717', 'loss=', '0.000363599')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1860 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1861', 'training time (minutes)=', '2.8954', 'loss=', '0.000363566')
# ('Epoch:', '1862', 'training time (minutes)=', '2.6962', 'loss=', '0.000364221')
# ('Epoch:', '1863', 'training time (minutes)=', '2.7616', 'loss=', '0.000368222')
# ('Epoch:', '1864', 'training time (minutes)=', '2.7291', 'loss=', '0.000359273')
# ('Epoch:', '1865', 'training time (minutes)=', '2.8319', 'loss=', '0.000359462')
# ('Epoch:', '1866', 'training time (minutes)=', '2.7439', 'loss=', '0.000363738')
# ('Epoch:', '1867', 'training time (minutes)=', '2.7041', 'loss=', '0.000366163')
# ('Epoch:', '1868', 'training time (minutes)=', '2.4773', 'loss=', '0.000362892')
# ('Epoch:', '1869', 'training time (minutes)=', '2.5204', 'loss=', '0.000359294')
# ('Epoch:', '1870', 'training time (minutes)=', '2.7234', 'loss=', '0.000363114')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1870 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1871', 'training time (minutes)=', '2.4999', 'loss=', '0.000363427')
# ('Epoch:', '1872', 'training time (minutes)=', '2.6339', 'loss=', '0.000366452')
# ('Epoch:', '1873', 'training time (minutes)=', '2.6680', 'loss=', '0.000368228')
# ('Epoch:', '1874', 'training time (minutes)=', '2.5474', 'loss=', '0.000360292')
# ('Epoch:', '1875', 'training time (minutes)=', '2.5097', 'loss=', '0.000362556')
# ('Epoch:', '1876', 'training time (minutes)=', '2.4174', 'loss=', '0.000363080')
# ('Epoch:', '1877', 'training time (minutes)=', '2.7208', 'loss=', '0.000366022')
# ('Epoch:', '1878', 'training time (minutes)=', '2.4558', 'loss=', '0.000364030')
# ('Epoch:', '1879', 'training time (minutes)=', '2.3850', 'loss=', '0.000363876')
# ('Epoch:', '1880', 'training time (minutes)=', '2.8191', 'loss=', '0.000360685')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1880 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1881', 'training time (minutes)=', '2.5424', 'loss=', '0.000358433')
# ('Epoch:', '1882', 'training time (minutes)=', '2.5256', 'loss=', '0.000357355')
# ('Epoch:', '1883', 'training time (minutes)=', '2.5171', 'loss=', '0.000366767')
# ('Epoch:', '1884', 'training time (minutes)=', '2.5586', 'loss=', '0.000367382')
# ('Epoch:', '1885', 'training time (minutes)=', '2.5894', 'loss=', '0.000364707')
# ('Epoch:', '1886', 'training time (minutes)=', '2.3242', 'loss=', '0.000366152')
# ('Epoch:', '1887', 'training time (minutes)=', '2.5897', 'loss=', '0.000364338')
# ('Epoch:', '1888', 'training time (minutes)=', '2.4575', 'loss=', '0.000358715')
# ('Epoch:', '1889', 'training time (minutes)=', '2.5570', 'loss=', '0.000364089')
# ('Epoch:', '1890', 'training time (minutes)=', '2.5758', 'loss=', '0.000367465')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1890 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1891', 'training time (minutes)=', '2.4467', 'loss=', '0.000364124')
# ('Epoch:', '1892', 'training time (minutes)=', '2.5037', 'loss=', '0.000365753')
# ('Epoch:', '1893', 'training time (minutes)=', '2.6600', 'loss=', '0.000359564')
# ('Epoch:', '1894', 'training time (minutes)=', '2.4938', 'loss=', '0.000360377')
# ('Epoch:', '1895', 'training time (minutes)=', '2.7140', 'loss=', '0.000366399')
# ('Epoch:', '1896', 'training time (minutes)=', '3.1146', 'loss=', '0.000366975')
# ('Epoch:', '1897', 'training time (minutes)=', '2.8558', 'loss=', '0.000362068')
# ('Epoch:', '1898', 'training time (minutes)=', '2.3941', 'loss=', '0.000364220')
# ('Epoch:', '1899', 'training time (minutes)=', '2.6085', 'loss=', '0.000367022')
# ('Epoch:', '1900', 'training time (minutes)=', '2.6349', 'loss=', '0.000370790')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1900 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1901', 'training time (minutes)=', '2.5886', 'loss=', '0.000368041')
# ('Epoch:', '1902', 'training time (minutes)=', '2.3841', 'loss=', '0.000361012')
# ('Epoch:', '1903', 'training time (minutes)=', '2.5117', 'loss=', '0.000364229')
# ('Epoch:', '1904', 'training time (minutes)=', '2.4786', 'loss=', '0.000363696')
# ('Epoch:', '1905', 'training time (minutes)=', '2.5201', 'loss=', '0.000364772')
# ('Epoch:', '1906', 'training time (minutes)=', '2.4305', 'loss=', '0.000367164')
# ('Epoch:', '1907', 'training time (minutes)=', '2.5105', 'loss=', '0.000363784')
# ('Epoch:', '1908', 'training time (minutes)=', '2.3714', 'loss=', '0.000361326')
# ('Epoch:', '1909', 'training time (minutes)=', '2.4471', 'loss=', '0.000368799')
# ('Epoch:', '1910', 'training time (minutes)=', '2.1990', 'loss=', '0.000360347')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1910 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1911', 'training time (minutes)=', '2.2630', 'loss=', '0.000360262')
# ('Epoch:', '1912', 'training time (minutes)=', '2.1689', 'loss=', '0.000365279')
# ('Epoch:', '1913', 'training time (minutes)=', '2.2672', 'loss=', '0.000363778')
# ('Epoch:', '1914', 'training time (minutes)=', '2.2798', 'loss=', '0.000364958')
# ('Epoch:', '1915', 'training time (minutes)=', '2.2990', 'loss=', '0.000361108')
# ('Epoch:', '1916', 'training time (minutes)=', '2.2387', 'loss=', '0.000358652')
# ('Epoch:', '1917', 'training time (minutes)=', '2.3113', 'loss=', '0.000363533')
# ('Epoch:', '1918', 'training time (minutes)=', '2.2602', 'loss=', '0.000357483')
# ('Epoch:', '1919', 'training time (minutes)=', '2.2705', 'loss=', '0.000360098')
# ('Epoch:', '1920', 'training time (minutes)=', '1.9963', 'loss=', '0.000368524')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1920 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1921', 'training time (minutes)=', '2.1530', 'loss=', '0.000363516')
# ('Epoch:', '1922', 'training time (minutes)=', '2.1628', 'loss=', '0.000363768')
# ('Epoch:', '1923', 'training time (minutes)=', '2.2656', 'loss=', '0.000360380')
# ('Epoch:', '1924', 'training time (minutes)=', '2.1172', 'loss=', '0.000355640')
# ('Epoch:', '1925', 'training time (minutes)=', '2.3285', 'loss=', '0.000364448')
# ('Epoch:', '1926', 'training time (minutes)=', '2.4879', 'loss=', '0.000362314')
# ('Epoch:', '1927', 'training time (minutes)=', '2.3059', 'loss=', '0.000362510')
# ('Epoch:', '1928', 'training time (minutes)=', '2.1280', 'loss=', '0.000362673')
# ('Epoch:', '1929', 'training time (minutes)=', '2.0446', 'loss=', '0.000364047')
# ('Epoch:', '1930', 'training time (minutes)=', '2.2887', 'loss=', '0.000363902')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1930 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1931', 'training time (minutes)=', '2.0602', 'loss=', '0.000366641')
# ('Epoch:', '1932', 'training time (minutes)=', '2.0229', 'loss=', '0.000366855')
# ('Epoch:', '1933', 'training time (minutes)=', '2.0361', 'loss=', '0.000364586')
# ('Epoch:', '1934', 'training time (minutes)=', '2.0296', 'loss=', '0.000359953')
# ('Epoch:', '1935', 'training time (minutes)=', '1.9905', 'loss=', '0.000362298')
# ('Epoch:', '1936', 'training time (minutes)=', '2.1466', 'loss=', '0.000363449')
# ('Epoch:', '1937', 'training time (minutes)=', '2.0903', 'loss=', '0.000366296')
# ('Epoch:', '1938', 'training time (minutes)=', '1.9866', 'loss=', '0.000365180')
# ('Epoch:', '1939', 'training time (minutes)=', '1.9752', 'loss=', '0.000369815')
# ('Epoch:', '1940', 'training time (minutes)=', '2.5009', 'loss=', '0.000370789')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1940 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1941', 'training time (minutes)=', '2.0817', 'loss=', '0.000357812')
# ('Epoch:', '1942', 'training time (minutes)=', '2.1927', 'loss=', '0.000361108')
# ('Epoch:', '1943', 'training time (minutes)=', '2.4878', 'loss=', '0.000363153')
# ('Epoch:', '1944', 'training time (minutes)=', '2.1898', 'loss=', '0.000362153')
# ('Epoch:', '1945', 'training time (minutes)=', '2.2708', 'loss=', '0.000358794')
# ('Epoch:', '1946', 'training time (minutes)=', '2.4171', 'loss=', '0.000360659')
# ('Epoch:', '1947', 'training time (minutes)=', '2.0410', 'loss=', '0.000366138')
# ('Epoch:', '1948', 'training time (minutes)=', '2.0552', 'loss=', '0.000386225')
# ('Epoch:', '1949', 'training time (minutes)=', '2.0803', 'loss=', '0.000363509')
# ('Epoch:', '1950', 'training time (minutes)=', '2.2055', 'loss=', '0.000368325')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/no_conv_deeper_snc_rotated2048pts_chamfer/models.ckpt-1950 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1951', 'training time (minutes)=', '2.2005', 'loss=', '0.000359534')
# ('Epoch:', '1952', 'training time (minutes)=', '2.2408', 'loss=', '0.000359080')
