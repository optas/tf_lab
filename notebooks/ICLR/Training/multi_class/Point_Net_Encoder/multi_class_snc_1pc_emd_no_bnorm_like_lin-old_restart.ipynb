# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 0
setup_one_gpu(GPU)
# Out:
# Picking GPU 0

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph
from general_tools.in_out import create_dir
from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs

from geo_tool import Point_Cloud

from tf_lab.in_out.basics import Data_Splitter, read_saved_epochs

from tf_lab.point_clouds.encoders_decoders import encoder_with_convs_and_symmetry, decoder_with_fc_only
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
from tf_lab.point_clouds.in_out import load_point_clouds_from_filenames, PointCloudDataSet
from tf_lab.data_sets.shape_net import pc_loader as snc_loader
from tf_lab.data_sets.shape_net import snc_category_to_synth_id
from tf_lab.iclr.helper import load_multiple_version_of_pcs

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = False
load_model = True
seed = 42
max_training_epochs = 2000
loss = 'chamfer'
z_rotate = True
experiment_name = 'all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code' + str(n_pc_samples) +  'pts_' + loss

# %%
top_data_dir = '/orions4-zfs/projects/optas/DATA/'

# %%
n_threads = 25
verbose = True
version = 'centered'
full_pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/', version, str(n_pc_samples))
full_file_names = [f for f in files_in_subdirs(full_pclouds_path, '.ply')]
pclouds, _, _ = load_point_clouds_from_filenames(full_file_names, n_threads, snc_loader, verbose)
train_data = PointCloudDataSet(pclouds)
print train_data.num_examples
# Out:
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/in_out.py:38: UserWarning: Point clouds with the same model name were loaded.
#   warnings.warn('Point clouds with the same model name were loaded.')
# 57449 pclouds were loaded. They belong in 57 shape-classes.
# 57449

# %%
train_dir = osp.join('/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc', experiment_name)
create_dir(train_dir)
# Out:
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer'

# %%
n_input = [n_pc_samples, 3]

encoder_args = {'n_filters': [64, 128, 128, 256, 512],
                'filter_sizes': [1, 1, 1, 1, 1],
                'strides': [1, 1, 1, 1, 1],
                'b_norm': False
               }

decoder_args = {'layer_sizes': [512, 1024, np.prod(n_input)],
                'b_norm': False
               }

# %%
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
else:    
    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = z_rotate,
                encoder = encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = decoder_with_fc_only,
                decoder_args = decoder_args,            
               )
    conf.allow_gpu_growth = False
    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))

reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)
# Out:
#               allow_gpu_growth: False
#                     batch_size: 50
#                  consistent_io: None
#                          debug: False
#                        decoder: decoder_with_fc_only
#                   decoder_args: {'b_norm': False, 'layer_sizes': [512, 1024, 6144]}
#                        encoder: encoder_with_convs_and_symmetry
#                   encoder_args: {'filter_sizes': [1, 1, 1, 1, 1], 'n_filters': [64, 128, 128, 256, 512], 'b_norm': False, 'strides': [1, 1, 1, 1, 1]}
#                experiment_name: all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer
#                  gauss_augment: None
#                   is_denoising: False
#                latent_vs_recon: 1.0
#                  learning_rate: 0.0005
#                           loss: chamfer
#              loss_display_step: 1
#                        n_input: [2048, 3]
#                       n_output: [2048, 3]
#                            n_z: None
#              saver_max_to_keep: None
#                     saver_step: 10
#                      train_dir: /orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer
#                training_epochs: 2000
#                       z_rotate: True
# /orions4-zfs/projects/lins2/Panos_Space/Git_Repos/tf_lab/point_clouds/encoders_decoders.py:95: UserWarning: Using old architecture.
#   warnings.warn('Using old architecture.')

# %%
if load_model:
    saved_epochs = read_saved_epochs(conf.train_dir)
    last_epoch = saved_epochs[-1]
    ae.restore_model(conf.train_dir, last_epoch, verbose=True)
        
if load_model and do_training:
    conf.training_epochs -= last_epoch
    print conf.training_epochs
# Out:
# Model restored in epoch 1170.
# 830

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)    
    train_stats = ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '1171', 'training time (minutes)=', '1.1574', 'loss=', '0.000394532')
# ('Epoch:', '1172', 'training time (minutes)=', '1.6560', 'loss=', '0.000401854')
# ('Epoch:', '1173', 'training time (minutes)=', '1.4846', 'loss=', '0.000398825')
# ('Epoch:', '1174', 'training time (minutes)=', '1.2150', 'loss=', '0.000404067')
# ('Epoch:', '1175', 'training time (minutes)=', '1.4394', 'loss=', '0.000405562')
# ('Epoch:', '1176', 'training time (minutes)=', '1.4350', 'loss=', '0.000401474')
# ('Epoch:', '1177', 'training time (minutes)=', '1.2787', 'loss=', '0.000402022')
# ('Epoch:', '1178', 'training time (minutes)=', '1.4402', 'loss=', '0.000402691')
# ('Epoch:', '1179', 'training time (minutes)=', '1.4993', 'loss=', '0.000399904')
# ('Epoch:', '1180', 'training time (minutes)=', '1.3619', 'loss=', '0.000395972')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1181', 'training time (minutes)=', '1.2372', 'loss=', '0.000394857')
# ('Epoch:', '1182', 'training time (minutes)=', '1.7108', 'loss=', '0.000397280')
# ('Epoch:', '1183', 'training time (minutes)=', '1.2852', 'loss=', '0.000408174')
# ('Epoch:', '1184', 'training time (minutes)=', '1.3286', 'loss=', '0.000402024')
# ('Epoch:', '1185', 'training time (minutes)=', '1.4048', 'loss=', '0.000403908')
# ('Epoch:', '1186', 'training time (minutes)=', '1.2573', 'loss=', '0.000400744')
# ('Epoch:', '1187', 'training time (minutes)=', '1.2615', 'loss=', '0.000396958')
# ('Epoch:', '1188', 'training time (minutes)=', '1.6437', 'loss=', '0.000404260')
# ('Epoch:', '1189', 'training time (minutes)=', '1.3380', 'loss=', '0.000403368')
# ('Epoch:', '1190', 'training time (minutes)=', '1.4230', 'loss=', '0.000405525')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1191', 'training time (minutes)=', '1.6015', 'loss=', '0.000406020')
# ('Epoch:', '1192', 'training time (minutes)=', '1.3745', 'loss=', '0.000413939')
# ('Epoch:', '1193', 'training time (minutes)=', '1.6906', 'loss=', '0.000404677')
# ('Epoch:', '1194', 'training time (minutes)=', '1.4218', 'loss=', '0.000405504')
# ('Epoch:', '1195', 'training time (minutes)=', '1.3849', 'loss=', '0.000407188')
# ('Epoch:', '1196', 'training time (minutes)=', '1.3529', 'loss=', '0.000411954')
# ('Epoch:', '1197', 'training time (minutes)=', '1.5617', 'loss=', '0.000415231')
# ('Epoch:', '1198', 'training time (minutes)=', '1.3706', 'loss=', '0.000409590')
# ('Epoch:', '1199', 'training time (minutes)=', '1.2373', 'loss=', '0.000414345')
# ('Epoch:', '1200', 'training time (minutes)=', '1.4460', 'loss=', '0.000415990')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1201', 'training time (minutes)=', '1.5048', 'loss=', '0.000408133')
# ('Epoch:', '1202', 'training time (minutes)=', '1.2396', 'loss=', '0.000412422')
# ('Epoch:', '1203', 'training time (minutes)=', '1.2490', 'loss=', '0.000412018')
# ('Epoch:', '1204', 'training time (minutes)=', '1.4489', 'loss=', '0.000402829')
# ('Epoch:', '1205', 'training time (minutes)=', '1.4936', 'loss=', '0.000406006')
# ('Epoch:', '1206', 'training time (minutes)=', '1.3282', 'loss=', '0.000406385')
# ('Epoch:', '1207', 'training time (minutes)=', '1.6423', 'loss=', '0.000408568')
# ('Epoch:', '1208', 'training time (minutes)=', '1.4653', 'loss=', '0.000403213')
# ('Epoch:', '1209', 'training time (minutes)=', '1.6185', 'loss=', '0.000405441')
# ('Epoch:', '1210', 'training time (minutes)=', '1.5145', 'loss=', '0.000407036')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1211', 'training time (minutes)=', '1.3966', 'loss=', '0.000405510')
# ('Epoch:', '1212', 'training time (minutes)=', '1.3376', 'loss=', '0.000404320')
# ('Epoch:', '1213', 'training time (minutes)=', '1.2116', 'loss=', '0.000412732')
# ('Epoch:', '1214', 'training time (minutes)=', '1.5668', 'loss=', '0.000404831')
# ('Epoch:', '1215', 'training time (minutes)=', '1.3650', 'loss=', '0.000402371')
# ('Epoch:', '1216', 'training time (minutes)=', '1.4831', 'loss=', '0.000411171')
# ('Epoch:', '1217', 'training time (minutes)=', '1.3407', 'loss=', '0.000398829')
# ('Epoch:', '1218', 'training time (minutes)=', '1.2974', 'loss=', '0.000407775')
# ('Epoch:', '1219', 'training time (minutes)=', '1.2117', 'loss=', '0.000402202')
# ('Epoch:', '1220', 'training time (minutes)=', '1.2344', 'loss=', '0.000406646')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1221', 'training time (minutes)=', '1.1962', 'loss=', '0.000400054')
# ('Epoch:', '1222', 'training time (minutes)=', '1.3293', 'loss=', '0.000400419')
# ('Epoch:', '1223', 'training time (minutes)=', '1.2887', 'loss=', '0.000401033')
# ('Epoch:', '1224', 'training time (minutes)=', '1.3217', 'loss=', '0.000406941')
# ('Epoch:', '1225', 'training time (minutes)=', '1.5241', 'loss=', '0.000406263')
# ('Epoch:', '1226', 'training time (minutes)=', '1.4208', 'loss=', '0.000406691')
# ('Epoch:', '1227', 'training time (minutes)=', '1.3996', 'loss=', '0.000403426')
# ('Epoch:', '1228', 'training time (minutes)=', '1.3283', 'loss=', '0.000402260')
# ('Epoch:', '1229', 'training time (minutes)=', '1.6584', 'loss=', '0.000397193')
# ('Epoch:', '1230', 'training time (minutes)=', '1.5532', 'loss=', '0.000409703')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1231', 'training time (minutes)=', '1.3361', 'loss=', '0.000405956')
# ('Epoch:', '1232', 'training time (minutes)=', '1.6334', 'loss=', '0.000400454')
# ('Epoch:', '1233', 'training time (minutes)=', '1.4196', 'loss=', '0.000406070')
# ('Epoch:', '1234', 'training time (minutes)=', '1.6509', 'loss=', '0.000399277')
# ('Epoch:', '1235', 'training time (minutes)=', '1.2828', 'loss=', '0.000396110')
# ('Epoch:', '1236', 'training time (minutes)=', '1.2351', 'loss=', '0.000404475')
# ('Epoch:', '1237', 'training time (minutes)=', '1.1897', 'loss=', '0.000401376')
# ('Epoch:', '1238', 'training time (minutes)=', '1.6201', 'loss=', '0.000406774')
# ('Epoch:', '1239', 'training time (minutes)=', '1.2157', 'loss=', '0.000404273')
# ('Epoch:', '1240', 'training time (minutes)=', '1.4839', 'loss=', '0.000404494')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1241', 'training time (minutes)=', '1.5244', 'loss=', '0.000398801')
# ('Epoch:', '1242', 'training time (minutes)=', '1.4229', 'loss=', '0.000401715')
# ('Epoch:', '1243', 'training time (minutes)=', '1.3378', 'loss=', '0.000395130')
# ('Epoch:', '1244', 'training time (minutes)=', '1.3094', 'loss=', '0.000404981')
# ('Epoch:', '1245', 'training time (minutes)=', '1.2222', 'loss=', '0.000407970')
# ('Epoch:', '1246', 'training time (minutes)=', '1.3948', 'loss=', '0.000402057')
# ('Epoch:', '1247', 'training time (minutes)=', '1.5442', 'loss=', '0.000407883')
# ('Epoch:', '1248', 'training time (minutes)=', '1.3427', 'loss=', '0.000405289')
# ('Epoch:', '1249', 'training time (minutes)=', '1.2779', 'loss=', '0.000403917')
# ('Epoch:', '1250', 'training time (minutes)=', '1.3955', 'loss=', '0.000408315')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1251', 'training time (minutes)=', '1.3559', 'loss=', '0.000403308')
# ('Epoch:', '1252', 'training time (minutes)=', '1.2067', 'loss=', '0.000405125')
# ('Epoch:', '1253', 'training time (minutes)=', '1.4249', 'loss=', '0.000402207')
# ('Epoch:', '1254', 'training time (minutes)=', '1.2939', 'loss=', '0.000402817')
# ('Epoch:', '1255', 'training time (minutes)=', '1.4158', 'loss=', '0.000404192')
# ('Epoch:', '1256', 'training time (minutes)=', '1.4886', 'loss=', '0.000399510')
# ('Epoch:', '1257', 'training time (minutes)=', '1.3015', 'loss=', '0.000404621')
# ('Epoch:', '1258', 'training time (minutes)=', '1.2719', 'loss=', '0.000402788')
# ('Epoch:', '1259', 'training time (minutes)=', '1.2079', 'loss=', '0.000402269')
# ('Epoch:', '1260', 'training time (minutes)=', '1.1818', 'loss=', '0.000399219')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1261', 'training time (minutes)=', '1.5067', 'loss=', '0.000405245')
# ('Epoch:', '1262', 'training time (minutes)=', '1.5715', 'loss=', '0.000407734')
# ('Epoch:', '1263', 'training time (minutes)=', '1.4726', 'loss=', '0.000412368')
# ('Epoch:', '1264', 'training time (minutes)=', '1.4381', 'loss=', '0.000407269')
# ('Epoch:', '1265', 'training time (minutes)=', '1.4221', 'loss=', '0.000401562')
# ('Epoch:', '1266', 'training time (minutes)=', '1.5636', 'loss=', '0.000407167')
# ('Epoch:', '1267', 'training time (minutes)=', '1.5176', 'loss=', '0.000415969')
# ('Epoch:', '1268', 'training time (minutes)=', '1.4260', 'loss=', '0.000415101')
# ('Epoch:', '1269', 'training time (minutes)=', '1.2150', 'loss=', '0.000405214')
# ('Epoch:', '1270', 'training time (minutes)=', '1.3048', 'loss=', '0.000413045')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1271', 'training time (minutes)=', '1.2013', 'loss=', '0.000422996')
# ('Epoch:', '1272', 'training time (minutes)=', '1.7188', 'loss=', '0.000425549')
# ('Epoch:', '1273', 'training time (minutes)=', '1.4752', 'loss=', '0.000422264')
# ('Epoch:', '1274', 'training time (minutes)=', '1.4921', 'loss=', '0.000415103')
# ('Epoch:', '1275', 'training time (minutes)=', '1.5004', 'loss=', '0.000410853')
# ('Epoch:', '1276', 'training time (minutes)=', '1.4532', 'loss=', '0.000413715')
# ('Epoch:', '1277', 'training time (minutes)=', '1.3846', 'loss=', '0.000424473')
# ('Epoch:', '1278', 'training time (minutes)=', '1.4590', 'loss=', '0.000424984')
# ('Epoch:', '1279', 'training time (minutes)=', '1.4131', 'loss=', '0.000419465')
# ('Epoch:', '1280', 'training time (minutes)=', '1.4265', 'loss=', '0.000414376')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1281', 'training time (minutes)=', '1.3212', 'loss=', '0.000425613')
# ('Epoch:', '1282', 'training time (minutes)=', '1.5302', 'loss=', '0.000423508')
# ('Epoch:', '1283', 'training time (minutes)=', '1.4899', 'loss=', '0.000412167')
# ('Epoch:', '1284', 'training time (minutes)=', '1.3476', 'loss=', '0.000412351')
# ('Epoch:', '1285', 'training time (minutes)=', '1.4276', 'loss=', '0.000413527')
# ('Epoch:', '1286', 'training time (minutes)=', '1.4961', 'loss=', '0.000414163')
# ('Epoch:', '1287', 'training time (minutes)=', '1.4928', 'loss=', '0.000413520')
# ('Epoch:', '1288', 'training time (minutes)=', '1.3738', 'loss=', '0.000428195')
# ('Epoch:', '1289', 'training time (minutes)=', '1.5594', 'loss=', '0.000414485')
# ('Epoch:', '1290', 'training time (minutes)=', '1.3644', 'loss=', '0.000416058')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1291', 'training time (minutes)=', '1.3219', 'loss=', '0.000412608')
# ('Epoch:', '1292', 'training time (minutes)=', '1.3588', 'loss=', '0.000417621')
# ('Epoch:', '1293', 'training time (minutes)=', '1.2015', 'loss=', '0.000412260')
# ('Epoch:', '1294', 'training time (minutes)=', '1.2758', 'loss=', '0.000416948')
# ('Epoch:', '1295', 'training time (minutes)=', '1.3434', 'loss=', '0.000410312')
# ('Epoch:', '1296', 'training time (minutes)=', '1.1928', 'loss=', '0.000424428')
# ('Epoch:', '1297', 'training time (minutes)=', '1.5008', 'loss=', '0.000419297')
# ('Epoch:', '1298', 'training time (minutes)=', '1.5327', 'loss=', '0.000413490')
# ('Epoch:', '1299', 'training time (minutes)=', '1.2979', 'loss=', '0.000414621')
# ('Epoch:', '1300', 'training time (minutes)=', '1.4144', 'loss=', '0.000413782')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1301', 'training time (minutes)=', '1.3743', 'loss=', '0.000414719')
# ('Epoch:', '1302', 'training time (minutes)=', '1.2666', 'loss=', '0.000407173')
# ('Epoch:', '1303', 'training time (minutes)=', '1.2735', 'loss=', '0.000416778')
# ('Epoch:', '1304', 'training time (minutes)=', '1.2741', 'loss=', '0.000407748')
# ('Epoch:', '1305', 'training time (minutes)=', '1.2372', 'loss=', '0.000402875')
# ('Epoch:', '1306', 'training time (minutes)=', '1.2494', 'loss=', '0.000414840')
# ('Epoch:', '1307', 'training time (minutes)=', '1.2516', 'loss=', '0.000410438')
# ('Epoch:', '1308', 'training time (minutes)=', '1.3070', 'loss=', '0.000407938')
# ('Epoch:', '1309', 'training time (minutes)=', '1.2372', 'loss=', '0.000412082')
# ('Epoch:', '1310', 'training time (minutes)=', '1.2409', 'loss=', '0.000408040')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1311', 'training time (minutes)=', '1.2183', 'loss=', '0.000411379')
# ('Epoch:', '1312', 'training time (minutes)=', '1.3174', 'loss=', '0.000407264')
# ('Epoch:', '1313', 'training time (minutes)=', '1.2483', 'loss=', '0.000404168')
# ('Epoch:', '1314', 'training time (minutes)=', '1.2578', 'loss=', '0.000414011')
# ('Epoch:', '1315', 'training time (minutes)=', '1.2411', 'loss=', '0.000412156')
# ('Epoch:', '1316', 'training time (minutes)=', '1.2643', 'loss=', '0.000406128')
# ('Epoch:', '1317', 'training time (minutes)=', '1.2766', 'loss=', '0.000408631')
# ('Epoch:', '1318', 'training time (minutes)=', '1.3112', 'loss=', '0.000413199')
# ('Epoch:', '1319', 'training time (minutes)=', '1.2170', 'loss=', '0.000406958')
# ('Epoch:', '1320', 'training time (minutes)=', '1.2560', 'loss=', '0.000414447')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1321', 'training time (minutes)=', '1.2594', 'loss=', '0.000412063')
# ('Epoch:', '1322', 'training time (minutes)=', '1.2207', 'loss=', '0.000413437')
# ('Epoch:', '1323', 'training time (minutes)=', '1.2784', 'loss=', '0.000419340')
# ('Epoch:', '1324', 'training time (minutes)=', '1.2606', 'loss=', '0.000408673')
# ('Epoch:', '1325', 'training time (minutes)=', '1.2493', 'loss=', '0.000399816')
# ('Epoch:', '1326', 'training time (minutes)=', '1.2971', 'loss=', '0.000404808')
# ('Epoch:', '1327', 'training time (minutes)=', '1.2420', 'loss=', '0.000415695')
# ('Epoch:', '1328', 'training time (minutes)=', '1.2679', 'loss=', '0.000408059')
# ('Epoch:', '1329', 'training time (minutes)=', '1.2320', 'loss=', '0.000413267')
# ('Epoch:', '1330', 'training time (minutes)=', '1.2337', 'loss=', '0.000410601')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1331', 'training time (minutes)=', '1.2557', 'loss=', '0.000413396')
# ('Epoch:', '1332', 'training time (minutes)=', '1.2341', 'loss=', '0.000405745')
# ('Epoch:', '1333', 'training time (minutes)=', '1.2293', 'loss=', '0.000405941')
# ('Epoch:', '1334', 'training time (minutes)=', '1.1917', 'loss=', '0.000408363')
# ('Epoch:', '1335', 'training time (minutes)=', '1.2748', 'loss=', '0.000412755')
# ('Epoch:', '1336', 'training time (minutes)=', '1.2948', 'loss=', '0.000411646')
# ('Epoch:', '1337', 'training time (minutes)=', '1.2144', 'loss=', '0.000403787')
# ('Epoch:', '1338', 'training time (minutes)=', '1.2396', 'loss=', '0.000412944')
# ('Epoch:', '1339', 'training time (minutes)=', '1.2769', 'loss=', '0.000402456')
# ('Epoch:', '1340', 'training time (minutes)=', '1.2926', 'loss=', '0.000417022')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1341', 'training time (minutes)=', '1.2734', 'loss=', '0.000400775')
# ('Epoch:', '1342', 'training time (minutes)=', '1.2380', 'loss=', '0.000404888')
# ('Epoch:', '1343', 'training time (minutes)=', '1.2068', 'loss=', '0.000403705')
# ('Epoch:', '1344', 'training time (minutes)=', '1.2271', 'loss=', '0.000417839')
# ('Epoch:', '1345', 'training time (minutes)=', '1.3142', 'loss=', '0.000406626')
# ('Epoch:', '1346', 'training time (minutes)=', '1.1949', 'loss=', '0.000409064')
# ('Epoch:', '1347', 'training time (minutes)=', '1.2551', 'loss=', '0.000412500')
# ('Epoch:', '1348', 'training time (minutes)=', '1.2310', 'loss=', '0.000404825')
# ('Epoch:', '1349', 'training time (minutes)=', '1.2543', 'loss=', '0.000407105')
# ('Epoch:', '1350', 'training time (minutes)=', '1.2521', 'loss=', '0.000408292')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1351', 'training time (minutes)=', '1.2465', 'loss=', '0.000400080')
# ('Epoch:', '1352', 'training time (minutes)=', '1.2237', 'loss=', '0.000406173')
# ('Epoch:', '1353', 'training time (minutes)=', '1.2330', 'loss=', '0.000430361')
# ('Epoch:', '1354', 'training time (minutes)=', '1.2229', 'loss=', '0.000414070')
# ('Epoch:', '1355', 'training time (minutes)=', '1.2172', 'loss=', '0.000414855')
# ('Epoch:', '1356', 'training time (minutes)=', '1.2220', 'loss=', '0.000410030')
# ('Epoch:', '1357', 'training time (minutes)=', '1.2178', 'loss=', '0.000401709')
# ('Epoch:', '1358', 'training time (minutes)=', '1.2503', 'loss=', '0.000414684')
# ('Epoch:', '1359', 'training time (minutes)=', '1.2382', 'loss=', '0.000411495')
# ('Epoch:', '1360', 'training time (minutes)=', '1.2463', 'loss=', '0.000412623')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1361', 'training time (minutes)=', '1.2170', 'loss=', '0.000412079')
# ('Epoch:', '1362', 'training time (minutes)=', '1.2322', 'loss=', '0.000452566')
# ('Epoch:', '1363', 'training time (minutes)=', '1.2546', 'loss=', '0.000472667')
# ('Epoch:', '1364', 'training time (minutes)=', '1.2362', 'loss=', '0.000442841')
# ('Epoch:', '1365', 'training time (minutes)=', '1.2305', 'loss=', '0.000453399')
# ('Epoch:', '1366', 'training time (minutes)=', '1.2596', 'loss=', '0.000449658')
# ('Epoch:', '1367', 'training time (minutes)=', '1.2335', 'loss=', '0.000433636')
# ('Epoch:', '1368', 'training time (minutes)=', '1.2259', 'loss=', '0.000443836')
# ('Epoch:', '1369', 'training time (minutes)=', '1.2414', 'loss=', '0.000429753')
# ('Epoch:', '1370', 'training time (minutes)=', '1.2410', 'loss=', '0.000430564')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1371', 'training time (minutes)=', '1.2354', 'loss=', '0.000434489')
# ('Epoch:', '1372', 'training time (minutes)=', '1.2532', 'loss=', '0.000428820')
# ('Epoch:', '1373', 'training time (minutes)=', '1.2576', 'loss=', '0.000428105')
# ('Epoch:', '1374', 'training time (minutes)=', '1.2394', 'loss=', '0.000432708')
# ('Epoch:', '1375', 'training time (minutes)=', '1.2459', 'loss=', '0.000455328')
# ('Epoch:', '1376', 'training time (minutes)=', '1.2573', 'loss=', '0.000436662')
# ('Epoch:', '1377', 'training time (minutes)=', '1.2525', 'loss=', '0.000429151')
# ('Epoch:', '1378', 'training time (minutes)=', '1.2539', 'loss=', '0.000421075')
# ('Epoch:', '1379', 'training time (minutes)=', '1.2519', 'loss=', '0.000427352')
# ('Epoch:', '1380', 'training time (minutes)=', '1.2810', 'loss=', '0.000419650')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1381', 'training time (minutes)=', '1.2665', 'loss=', '0.000419416')
# ('Epoch:', '1382', 'training time (minutes)=', '1.2597', 'loss=', '0.000419827')
# ('Epoch:', '1383', 'training time (minutes)=', '1.2579', 'loss=', '0.000412505')
# ('Epoch:', '1384', 'training time (minutes)=', '1.2372', 'loss=', '0.000430463')
# ('Epoch:', '1385', 'training time (minutes)=', '1.2519', 'loss=', '0.000425829')
# ('Epoch:', '1386', 'training time (minutes)=', '1.2820', 'loss=', '0.000421326')
# ('Epoch:', '1387', 'training time (minutes)=', '1.2815', 'loss=', '0.000425998')
# ('Epoch:', '1388', 'training time (minutes)=', '1.2745', 'loss=', '0.000422349')
# ('Epoch:', '1389', 'training time (minutes)=', '1.2423', 'loss=', '0.000428308')
# ('Epoch:', '1390', 'training time (minutes)=', '1.2262', 'loss=', '0.000433891')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1391', 'training time (minutes)=', '1.2316', 'loss=', '0.000429943')
# ('Epoch:', '1392', 'training time (minutes)=', '1.2184', 'loss=', '0.000445515')
# ('Epoch:', '1393', 'training time (minutes)=', '1.2614', 'loss=', '0.000441507')
# ('Epoch:', '1394', 'training time (minutes)=', '1.2203', 'loss=', '0.000432133')
# ('Epoch:', '1395', 'training time (minutes)=', '1.2343', 'loss=', '0.000428764')
# ('Epoch:', '1396', 'training time (minutes)=', '1.2445', 'loss=', '0.000425810')
# ('Epoch:', '1397', 'training time (minutes)=', '1.3123', 'loss=', '0.000427002')
# ('Epoch:', '1398', 'training time (minutes)=', '1.2544', 'loss=', '0.000439981')
# ('Epoch:', '1399', 'training time (minutes)=', '1.2302', 'loss=', '0.000423131')
# ('Epoch:', '1400', 'training time (minutes)=', '1.2125', 'loss=', '0.000427439')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1401', 'training time (minutes)=', '1.2020', 'loss=', '0.000424174')
# ('Epoch:', '1402', 'training time (minutes)=', '1.2205', 'loss=', '0.000416714')
# ('Epoch:', '1403', 'training time (minutes)=', '1.2816', 'loss=', '0.000424582')
# ('Epoch:', '1404', 'training time (minutes)=', '1.2418', 'loss=', '0.000423371')
# ('Epoch:', '1405', 'training time (minutes)=', '1.2413', 'loss=', '0.000460312')
# ('Epoch:', '1406', 'training time (minutes)=', '1.2352', 'loss=', '0.000431489')
# ('Epoch:', '1407', 'training time (minutes)=', '1.2491', 'loss=', '0.000437138')
# ('Epoch:', '1408', 'training time (minutes)=', '1.2218', 'loss=', '0.000429623')
# ('Epoch:', '1409', 'training time (minutes)=', '1.2104', 'loss=', '0.000431296')
# ('Epoch:', '1410', 'training time (minutes)=', '1.2150', 'loss=', '0.000432627')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1411', 'training time (minutes)=', '1.2525', 'loss=', '0.000436168')
# ('Epoch:', '1412', 'training time (minutes)=', '1.2350', 'loss=', '0.000425583')
# ('Epoch:', '1413', 'training time (minutes)=', '1.2660', 'loss=', '0.000426170')
# ('Epoch:', '1414', 'training time (minutes)=', '1.2843', 'loss=', '0.000422780')
# ('Epoch:', '1415', 'training time (minutes)=', '1.2231', 'loss=', '0.000431218')
# ('Epoch:', '1416', 'training time (minutes)=', '1.2953', 'loss=', '0.000433272')
# ('Epoch:', '1417', 'training time (minutes)=', '1.2203', 'loss=', '0.000426178')
# ('Epoch:', '1418', 'training time (minutes)=', '1.1965', 'loss=', '0.000427572')
# ('Epoch:', '1419', 'training time (minutes)=', '1.2389', 'loss=', '0.000418279')
# ('Epoch:', '1420', 'training time (minutes)=', '1.2006', 'loss=', '0.000423802')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1421', 'training time (minutes)=', '1.2272', 'loss=', '0.000433481')
# ('Epoch:', '1422', 'training time (minutes)=', '1.2173', 'loss=', '0.000431566')
# ('Epoch:', '1423', 'training time (minutes)=', '1.2596', 'loss=', '0.000424699')
# ('Epoch:', '1424', 'training time (minutes)=', '1.2073', 'loss=', '0.000417450')
# ('Epoch:', '1425', 'training time (minutes)=', '1.2021', 'loss=', '0.000418027')
# ('Epoch:', '1426', 'training time (minutes)=', '1.2410', 'loss=', '0.000418154')
# ('Epoch:', '1427', 'training time (minutes)=', '1.2607', 'loss=', '0.000416952')
# ('Epoch:', '1428', 'training time (minutes)=', '1.2713', 'loss=', '0.000422265')
# ('Epoch:', '1429', 'training time (minutes)=', '1.2227', 'loss=', '0.000434417')
# ('Epoch:', '1430', 'training time (minutes)=', '1.2158', 'loss=', '0.000424433')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1431', 'training time (minutes)=', '1.2350', 'loss=', '0.000436190')
# ('Epoch:', '1432', 'training time (minutes)=', '1.2696', 'loss=', '0.000420735')
# ('Epoch:', '1433', 'training time (minutes)=', '1.2575', 'loss=', '0.000418187')
# ('Epoch:', '1434', 'training time (minutes)=', '1.2283', 'loss=', '0.000423926')
# ('Epoch:', '1435', 'training time (minutes)=', '1.2153', 'loss=', '0.000410935')
# ('Epoch:', '1436', 'training time (minutes)=', '1.1871', 'loss=', '0.000437462')
# ('Epoch:', '1437', 'training time (minutes)=', '1.2684', 'loss=', '0.000425044')
# ('Epoch:', '1438', 'training time (minutes)=', '1.2850', 'loss=', '0.000432481')
# ('Epoch:', '1439', 'training time (minutes)=', '1.1817', 'loss=', '0.000424664')
# ('Epoch:', '1440', 'training time (minutes)=', '1.1998', 'loss=', '0.000426723')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1441', 'training time (minutes)=', '1.2223', 'loss=', '0.000408987')
# ('Epoch:', '1442', 'training time (minutes)=', '1.2220', 'loss=', '0.000422857')
# ('Epoch:', '1443', 'training time (minutes)=', '1.1712', 'loss=', '0.000430430')
# ('Epoch:', '1444', 'training time (minutes)=', '1.2190', 'loss=', '0.000423360')
# ('Epoch:', '1445', 'training time (minutes)=', '1.2068', 'loss=', '0.000427441')
# ('Epoch:', '1446', 'training time (minutes)=', '1.2428', 'loss=', '0.000426569')
# ('Epoch:', '1447', 'training time (minutes)=', '1.1673', 'loss=', '0.000422999')
# ('Epoch:', '1448', 'training time (minutes)=', '1.2015', 'loss=', '0.000422494')
# ('Epoch:', '1449', 'training time (minutes)=', '1.2067', 'loss=', '0.000420992')
# ('Epoch:', '1450', 'training time (minutes)=', '1.1993', 'loss=', '0.000432497')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1451', 'training time (minutes)=', '1.2176', 'loss=', '0.000421701')
# ('Epoch:', '1452', 'training time (minutes)=', '1.1799', 'loss=', '0.000417397')
# ('Epoch:', '1453', 'training time (minutes)=', '1.2476', 'loss=', '0.000433695')
# ('Epoch:', '1454', 'training time (minutes)=', '1.2263', 'loss=', '0.000430368')
# ('Epoch:', '1455', 'training time (minutes)=', '1.2132', 'loss=', '0.000434688')
# ('Epoch:', '1456', 'training time (minutes)=', '1.1798', 'loss=', '0.000436817')
# ('Epoch:', '1457', 'training time (minutes)=', '1.2112', 'loss=', '0.000440064')
# ('Epoch:', '1458', 'training time (minutes)=', '1.2247', 'loss=', '0.000481613')
# ('Epoch:', '1459', 'training time (minutes)=', '1.2299', 'loss=', '0.000426250')
# ('Epoch:', '1460', 'training time (minutes)=', '1.2373', 'loss=', '0.000424803')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1461', 'training time (minutes)=', '1.2212', 'loss=', '0.000464781')
# ('Epoch:', '1462', 'training time (minutes)=', '1.2070', 'loss=', '0.000452578')
# ('Epoch:', '1463', 'training time (minutes)=', '1.2092', 'loss=', '0.000457791')
# ('Epoch:', '1464', 'training time (minutes)=', '1.2270', 'loss=', '0.000450263')
# ('Epoch:', '1465', 'training time (minutes)=', '1.2224', 'loss=', '0.000449118')
# ('Epoch:', '1466', 'training time (minutes)=', '1.2548', 'loss=', '0.000437648')
# ('Epoch:', '1467', 'training time (minutes)=', '1.2150', 'loss=', '0.000431796')
# ('Epoch:', '1468', 'training time (minutes)=', '1.2318', 'loss=', '0.000430597')
# ('Epoch:', '1469', 'training time (minutes)=', '1.2046', 'loss=', '0.000443896')
# ('Epoch:', '1470', 'training time (minutes)=', '1.1938', 'loss=', '0.000442071')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1470 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1471', 'training time (minutes)=', '1.1917', 'loss=', '0.000443062')
# ('Epoch:', '1472', 'training time (minutes)=', '1.2143', 'loss=', '0.000446286')
# ('Epoch:', '1473', 'training time (minutes)=', '1.2176', 'loss=', '0.000430163')
# ('Epoch:', '1474', 'training time (minutes)=', '1.2205', 'loss=', '0.000440403')
# ('Epoch:', '1475', 'training time (minutes)=', '1.2026', 'loss=', '0.000440580')
# ('Epoch:', '1476', 'training time (minutes)=', '1.2330', 'loss=', '0.000441327')
# ('Epoch:', '1477', 'training time (minutes)=', '1.2552', 'loss=', '0.000436763')
# ('Epoch:', '1478', 'training time (minutes)=', '1.2576', 'loss=', '0.000446922')
# ('Epoch:', '1479', 'training time (minutes)=', '1.2030', 'loss=', '0.000457523')
# ('Epoch:', '1480', 'training time (minutes)=', '1.2613', 'loss=', '0.000444023')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1480 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1481', 'training time (minutes)=', '1.1843', 'loss=', '0.000446634')
# ('Epoch:', '1482', 'training time (minutes)=', '1.2442', 'loss=', '0.000439638')
# ('Epoch:', '1483', 'training time (minutes)=', '1.2390', 'loss=', '0.000429986')
# ('Epoch:', '1484', 'training time (minutes)=', '1.2137', 'loss=', '0.000434898')
# ('Epoch:', '1485', 'training time (minutes)=', '1.2137', 'loss=', '0.000476245')
# ('Epoch:', '1486', 'training time (minutes)=', '1.2179', 'loss=', '0.000458959')
# ('Epoch:', '1487', 'training time (minutes)=', '1.2106', 'loss=', '0.000447542')
# ('Epoch:', '1488', 'training time (minutes)=', '1.2345', 'loss=', '0.000447183')
# ('Epoch:', '1489', 'training time (minutes)=', '1.2136', 'loss=', '0.000441789')
# ('Epoch:', '1490', 'training time (minutes)=', '1.2217', 'loss=', '0.000442069')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1490 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1491', 'training time (minutes)=', '1.2116', 'loss=', '0.000443662')
# ('Epoch:', '1492', 'training time (minutes)=', '1.2410', 'loss=', '0.000432383')
# ('Epoch:', '1493', 'training time (minutes)=', '1.2209', 'loss=', '0.000436274')
# ('Epoch:', '1494', 'training time (minutes)=', '1.1786', 'loss=', '0.000432893')
# ('Epoch:', '1495', 'training time (minutes)=', '1.2197', 'loss=', '0.000442518')
# ('Epoch:', '1496', 'training time (minutes)=', '1.2061', 'loss=', '0.000436927')
# ('Epoch:', '1497', 'training time (minutes)=', '1.1933', 'loss=', '0.000435835')
# ('Epoch:', '1498', 'training time (minutes)=', '1.2397', 'loss=', '0.000438375')
# ('Epoch:', '1499', 'training time (minutes)=', '1.2246', 'loss=', '0.000432173')
# ('Epoch:', '1500', 'training time (minutes)=', '1.2268', 'loss=', '0.000432182')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1500 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1501', 'training time (minutes)=', '1.2044', 'loss=', '0.000431290')
# ('Epoch:', '1502', 'training time (minutes)=', '1.2116', 'loss=', '0.000430655')
# ('Epoch:', '1503', 'training time (minutes)=', '1.2185', 'loss=', '0.000434890')
# ('Epoch:', '1504', 'training time (minutes)=', '1.2047', 'loss=', '0.000435595')
# ('Epoch:', '1505', 'training time (minutes)=', '1.2992', 'loss=', '0.000437952')
# ('Epoch:', '1506', 'training time (minutes)=', '1.2089', 'loss=', '0.000428681')
# ('Epoch:', '1507', 'training time (minutes)=', '1.2453', 'loss=', '0.000431875')
# ('Epoch:', '1508', 'training time (minutes)=', '1.2063', 'loss=', '0.000431484')
# ('Epoch:', '1509', 'training time (minutes)=', '1.2242', 'loss=', '0.000424815')
# ('Epoch:', '1510', 'training time (minutes)=', '1.2356', 'loss=', '0.000422714')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1510 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1511', 'training time (minutes)=', '1.2198', 'loss=', '0.000424492')
# ('Epoch:', '1512', 'training time (minutes)=', '1.2400', 'loss=', '0.000425195')
# ('Epoch:', '1513', 'training time (minutes)=', '1.2275', 'loss=', '0.000426519')
# ('Epoch:', '1514', 'training time (minutes)=', '1.2168', 'loss=', '0.000424422')
# ('Epoch:', '1515', 'training time (minutes)=', '1.2333', 'loss=', '0.000424009')
# ('Epoch:', '1516', 'training time (minutes)=', '1.2285', 'loss=', '0.000430207')
# ('Epoch:', '1517', 'training time (minutes)=', '1.2356', 'loss=', '0.000422776')
# ('Epoch:', '1518', 'training time (minutes)=', '1.2169', 'loss=', '0.000422899')
# ('Epoch:', '1519', 'training time (minutes)=', '1.2180', 'loss=', '0.000431431')
# ('Epoch:', '1520', 'training time (minutes)=', '1.2409', 'loss=', '0.000423403')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1520 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1521', 'training time (minutes)=', '1.2442', 'loss=', '0.000426004')
# ('Epoch:', '1522', 'training time (minutes)=', '1.2445', 'loss=', '0.000428478')
# ('Epoch:', '1523', 'training time (minutes)=', '1.2218', 'loss=', '0.000420830')
# ('Epoch:', '1524', 'training time (minutes)=', '1.2419', 'loss=', '0.000428975')
# ('Epoch:', '1525', 'training time (minutes)=', '1.2143', 'loss=', '0.000423118')
# ('Epoch:', '1526', 'training time (minutes)=', '1.2399', 'loss=', '0.000420437')
# ('Epoch:', '1527', 'training time (minutes)=', '1.2455', 'loss=', '0.000428693')
# ('Epoch:', '1528', 'training time (minutes)=', '1.1930', 'loss=', '0.000424029')
# ('Epoch:', '1529', 'training time (minutes)=', '1.2192', 'loss=', '0.000424287')
# ('Epoch:', '1530', 'training time (minutes)=', '1.2162', 'loss=', '0.000417212')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1530 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1531', 'training time (minutes)=', '1.2090', 'loss=', '0.000419254')
# ('Epoch:', '1532', 'training time (minutes)=', '1.2170', 'loss=', '0.000431892')
# ('Epoch:', '1533', 'training time (minutes)=', '1.1909', 'loss=', '0.000424762')
# ('Epoch:', '1534', 'training time (minutes)=', '1.2276', 'loss=', '0.000421202')
# ('Epoch:', '1535', 'training time (minutes)=', '1.2380', 'loss=', '0.000421575')
# ('Epoch:', '1536', 'training time (minutes)=', '1.2344', 'loss=', '0.000414764')
# ('Epoch:', '1537', 'training time (minutes)=', '1.2281', 'loss=', '0.000421784')
# ('Epoch:', '1538', 'training time (minutes)=', '1.2020', 'loss=', '0.000417989')
# ('Epoch:', '1539', 'training time (minutes)=', '1.2359', 'loss=', '0.000416902')
# ('Epoch:', '1540', 'training time (minutes)=', '1.2052', 'loss=', '0.000424619')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1540 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1541', 'training time (minutes)=', '1.2151', 'loss=', '0.000425228')
# ('Epoch:', '1542', 'training time (minutes)=', '1.2086', 'loss=', '0.000414959')
# ('Epoch:', '1543', 'training time (minutes)=', '1.2577', 'loss=', '0.000428092')
# ('Epoch:', '1544', 'training time (minutes)=', '1.2311', 'loss=', '0.000425572')
# ('Epoch:', '1545', 'training time (minutes)=', '1.2105', 'loss=', '0.000422636')
# ('Epoch:', '1546', 'training time (minutes)=', '1.1983', 'loss=', '0.000417986')
# ('Epoch:', '1547', 'training time (minutes)=', '1.2270', 'loss=', '0.000414633')
# ('Epoch:', '1548', 'training time (minutes)=', '1.2317', 'loss=', '0.000423340')
# ('Epoch:', '1549', 'training time (minutes)=', '1.2859', 'loss=', '0.000416972')
# ('Epoch:', '1550', 'training time (minutes)=', '1.1972', 'loss=', '0.000421886')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1550 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1551', 'training time (minutes)=', '1.1875', 'loss=', '0.000409868')
# ('Epoch:', '1552', 'training time (minutes)=', '1.1954', 'loss=', '0.000414123')
# ('Epoch:', '1553', 'training time (minutes)=', '1.2990', 'loss=', '0.000422126')
# ('Epoch:', '1554', 'training time (minutes)=', '1.2333', 'loss=', '0.000421156')
# ('Epoch:', '1555', 'training time (minutes)=', '1.2076', 'loss=', '0.000417369')
# ('Epoch:', '1556', 'training time (minutes)=', '1.2325', 'loss=', '0.000419020')
# ('Epoch:', '1557', 'training time (minutes)=', '1.2146', 'loss=', '0.000418860')
# ('Epoch:', '1558', 'training time (minutes)=', '1.2095', 'loss=', '0.000413824')
# ('Epoch:', '1559', 'training time (minutes)=', '1.1909', 'loss=', '0.000422306')
# ('Epoch:', '1560', 'training time (minutes)=', '1.2479', 'loss=', '0.000419030')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1560 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1561', 'training time (minutes)=', '1.2142', 'loss=', '0.000416037')
# ('Epoch:', '1562', 'training time (minutes)=', '1.2765', 'loss=', '0.000423282')
# ('Epoch:', '1563', 'training time (minutes)=', '1.1969', 'loss=', '0.000415330')
# ('Epoch:', '1564', 'training time (minutes)=', '1.2357', 'loss=', '0.000413459')
# ('Epoch:', '1565', 'training time (minutes)=', '1.1854', 'loss=', '0.000415966')
# ('Epoch:', '1566', 'training time (minutes)=', '1.2234', 'loss=', '0.000417715')
# ('Epoch:', '1567', 'training time (minutes)=', '1.2702', 'loss=', '0.000420113')
# ('Epoch:', '1568', 'training time (minutes)=', '1.2230', 'loss=', '0.000412779')
# ('Epoch:', '1569', 'training time (minutes)=', '1.2482', 'loss=', '0.000414632')
# ('Epoch:', '1570', 'training time (minutes)=', '1.1995', 'loss=', '0.000414255')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1570 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1571', 'training time (minutes)=', '1.2836', 'loss=', '0.000413990')
# ('Epoch:', '1572', 'training time (minutes)=', '1.2081', 'loss=', '0.000422770')
# ('Epoch:', '1573', 'training time (minutes)=', '1.2372', 'loss=', '0.000417100')
# ('Epoch:', '1574', 'training time (minutes)=', '1.3099', 'loss=', '0.000429643')
# ('Epoch:', '1575', 'training time (minutes)=', '1.4522', 'loss=', '0.000412317')
# ('Epoch:', '1576', 'training time (minutes)=', '1.4880', 'loss=', '0.000419776')
# ('Epoch:', '1577', 'training time (minutes)=', '1.4840', 'loss=', '0.000415729')
# ('Epoch:', '1578', 'training time (minutes)=', '1.4750', 'loss=', '0.000423672')
# ('Epoch:', '1579', 'training time (minutes)=', '1.6019', 'loss=', '0.000421058')
# ('Epoch:', '1580', 'training time (minutes)=', '1.6361', 'loss=', '0.000419947')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1580 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1581', 'training time (minutes)=', '1.4963', 'loss=', '0.000419704')
# ('Epoch:', '1582', 'training time (minutes)=', '1.2650', 'loss=', '0.000414588')
# ('Epoch:', '1583', 'training time (minutes)=', '1.2813', 'loss=', '0.000406618')
# ('Epoch:', '1584', 'training time (minutes)=', '1.2224', 'loss=', '0.000411797')
# ('Epoch:', '1585', 'training time (minutes)=', '1.2457', 'loss=', '0.000416243')
# ('Epoch:', '1586', 'training time (minutes)=', '1.3100', 'loss=', '0.000412710')
# ('Epoch:', '1587', 'training time (minutes)=', '1.2240', 'loss=', '0.000420882')
# ('Epoch:', '1588', 'training time (minutes)=', '1.2911', 'loss=', '0.000415157')
# ('Epoch:', '1589', 'training time (minutes)=', '1.2971', 'loss=', '0.000413164')
# ('Epoch:', '1590', 'training time (minutes)=', '1.3394', 'loss=', '0.000416374')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1590 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1591', 'training time (minutes)=', '1.2431', 'loss=', '0.000417420')
# ('Epoch:', '1592', 'training time (minutes)=', '1.2153', 'loss=', '0.000420473')
# ('Epoch:', '1593', 'training time (minutes)=', '1.3016', 'loss=', '0.000412100')
# ('Epoch:', '1594', 'training time (minutes)=', '1.2454', 'loss=', '0.000419682')
# ('Epoch:', '1595', 'training time (minutes)=', '1.3624', 'loss=', '0.000410502')
# ('Epoch:', '1596', 'training time (minutes)=', '1.3038', 'loss=', '0.000411599')
# ('Epoch:', '1597', 'training time (minutes)=', '1.3095', 'loss=', '0.000421986')
# ('Epoch:', '1598', 'training time (minutes)=', '1.2833', 'loss=', '0.000407320')
# ('Epoch:', '1599', 'training time (minutes)=', '1.2597', 'loss=', '0.000409178')
# ('Epoch:', '1600', 'training time (minutes)=', '1.2774', 'loss=', '0.000418919')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1600 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1601', 'training time (minutes)=', '1.2731', 'loss=', '0.000410615')
# ('Epoch:', '1602', 'training time (minutes)=', '1.2983', 'loss=', '0.000411598')
# ('Epoch:', '1603', 'training time (minutes)=', '1.3213', 'loss=', '0.000408671')
# ('Epoch:', '1604', 'training time (minutes)=', '1.2471', 'loss=', '0.000417267')
# ('Epoch:', '1605', 'training time (minutes)=', '1.2950', 'loss=', '0.000409970')
# ('Epoch:', '1606', 'training time (minutes)=', '1.3048', 'loss=', '0.000410484')
# ('Epoch:', '1607', 'training time (minutes)=', '1.2498', 'loss=', '0.000410288')
# ('Epoch:', '1608', 'training time (minutes)=', '1.3457', 'loss=', '0.000417718')
# ('Epoch:', '1609', 'training time (minutes)=', '1.2949', 'loss=', '0.000408101')
# ('Epoch:', '1610', 'training time (minutes)=', '1.2916', 'loss=', '0.000411471')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1610 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1611', 'training time (minutes)=', '1.2922', 'loss=', '0.000413503')
# ('Epoch:', '1612', 'training time (minutes)=', '1.2775', 'loss=', '0.000409802')
# ('Epoch:', '1613', 'training time (minutes)=', '1.3139', 'loss=', '0.000413373')
# ('Epoch:', '1614', 'training time (minutes)=', '1.3083', 'loss=', '0.000412301')
# ('Epoch:', '1615', 'training time (minutes)=', '1.2454', 'loss=', '0.000410780')
# ('Epoch:', '1616', 'training time (minutes)=', '1.2674', 'loss=', '0.000410018')
# ('Epoch:', '1617', 'training time (minutes)=', '1.2964', 'loss=', '0.000407969')
# ('Epoch:', '1618', 'training time (minutes)=', '1.2904', 'loss=', '0.000415868')
# ('Epoch:', '1619', 'training time (minutes)=', '1.3082', 'loss=', '0.000418342')
# ('Epoch:', '1620', 'training time (minutes)=', '1.2420', 'loss=', '0.000411535')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1620 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1621', 'training time (minutes)=', '1.3102', 'loss=', '0.000410600')
# ('Epoch:', '1622', 'training time (minutes)=', '1.3442', 'loss=', '0.000404873')
# ('Epoch:', '1623', 'training time (minutes)=', '1.2801', 'loss=', '0.000415816')
# ('Epoch:', '1624', 'training time (minutes)=', '1.3167', 'loss=', '0.000410543')
# ('Epoch:', '1625', 'training time (minutes)=', '1.2665', 'loss=', '0.000413529')
# ('Epoch:', '1626', 'training time (minutes)=', '1.3503', 'loss=', '0.000419289')
# ('Epoch:', '1627', 'training time (minutes)=', '1.2712', 'loss=', '0.000410777')
# ('Epoch:', '1628', 'training time (minutes)=', '1.2761', 'loss=', '0.000409207')
# ('Epoch:', '1629', 'training time (minutes)=', '1.4253', 'loss=', '0.000411447')
# ('Epoch:', '1630', 'training time (minutes)=', '1.4574', 'loss=', '0.000411684')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1630 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1631', 'training time (minutes)=', '1.5714', 'loss=', '0.000405533')
# ('Epoch:', '1632', 'training time (minutes)=', '1.6711', 'loss=', '0.000410215')
# ('Epoch:', '1633', 'training time (minutes)=', '1.8742', 'loss=', '0.000407203')
# ('Epoch:', '1634', 'training time (minutes)=', '1.2645', 'loss=', '0.000407329')
# ('Epoch:', '1635', 'training time (minutes)=', '1.6878', 'loss=', '0.000413627')
# ('Epoch:', '1636', 'training time (minutes)=', '1.4050', 'loss=', '0.000407636')
# ('Epoch:', '1637', 'training time (minutes)=', '1.2554', 'loss=', '0.000424133')
# ('Epoch:', '1638', 'training time (minutes)=', '1.4439', 'loss=', '0.000405146')
# ('Epoch:', '1639', 'training time (minutes)=', '1.3282', 'loss=', '0.000412050')
# ('Epoch:', '1640', 'training time (minutes)=', '1.3049', 'loss=', '0.000407083')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1640 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1641', 'training time (minutes)=', '1.2785', 'loss=', '0.000418902')
# ('Epoch:', '1642', 'training time (minutes)=', '1.3087', 'loss=', '0.000406212')
# ('Epoch:', '1643', 'training time (minutes)=', '1.3782', 'loss=', '0.000418036')
# ('Epoch:', '1644', 'training time (minutes)=', '1.4323', 'loss=', '0.000402930')
# ('Epoch:', '1645', 'training time (minutes)=', '1.4418', 'loss=', '0.000409696')
# ('Epoch:', '1646', 'training time (minutes)=', '1.3856', 'loss=', '0.000422280')
# ('Epoch:', '1647', 'training time (minutes)=', '1.4225', 'loss=', '0.000412101')
# ('Epoch:', '1648', 'training time (minutes)=', '1.6089', 'loss=', '0.000408481')
# ('Epoch:', '1649', 'training time (minutes)=', '1.5128', 'loss=', '0.000406443')
# ('Epoch:', '1650', 'training time (minutes)=', '1.3335', 'loss=', '0.000407235')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1650 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1651', 'training time (minutes)=', '1.4200', 'loss=', '0.000409474')
# ('Epoch:', '1652', 'training time (minutes)=', '1.3745', 'loss=', '0.000411317')
# ('Epoch:', '1653', 'training time (minutes)=', '1.2667', 'loss=', '0.000417880')
# ('Epoch:', '1654', 'training time (minutes)=', '1.2419', 'loss=', '0.000403840')
# ('Epoch:', '1655', 'training time (minutes)=', '1.1924', 'loss=', '0.000411665')
# ('Epoch:', '1656', 'training time (minutes)=', '1.1844', 'loss=', '0.000416212')
# ('Epoch:', '1657', 'training time (minutes)=', '1.1870', 'loss=', '0.000409507')
# ('Epoch:', '1658', 'training time (minutes)=', '1.3532', 'loss=', '0.000405588')
# ('Epoch:', '1659', 'training time (minutes)=', '1.3589', 'loss=', '0.000405458')
# ('Epoch:', '1660', 'training time (minutes)=', '1.4477', 'loss=', '0.000406437')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1660 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1661', 'training time (minutes)=', '1.2777', 'loss=', '0.000408305')
# ('Epoch:', '1662', 'training time (minutes)=', '1.2496', 'loss=', '0.000415146')
# ('Epoch:', '1663', 'training time (minutes)=', '1.3596', 'loss=', '0.000414493')
# ('Epoch:', '1664', 'training time (minutes)=', '1.2728', 'loss=', '0.000404773')
# ('Epoch:', '1665', 'training time (minutes)=', '1.2833', 'loss=', '0.000415900')
# ('Epoch:', '1666', 'training time (minutes)=', '1.2400', 'loss=', '0.000412160')
# ('Epoch:', '1667', 'training time (minutes)=', '1.2502', 'loss=', '0.000408481')
# ('Epoch:', '1668', 'training time (minutes)=', '1.2744', 'loss=', '0.000411353')
# ('Epoch:', '1669', 'training time (minutes)=', '1.3775', 'loss=', '0.000401676')
# ('Epoch:', '1670', 'training time (minutes)=', '1.3761', 'loss=', '0.000408738')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1670 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1671', 'training time (minutes)=', '1.4196', 'loss=', '0.000406226')
# ('Epoch:', '1672', 'training time (minutes)=', '1.2497', 'loss=', '0.000411434')
# ('Epoch:', '1673', 'training time (minutes)=', '1.5600', 'loss=', '0.000411372')
# ('Epoch:', '1674', 'training time (minutes)=', '1.5891', 'loss=', '0.000405619')
# ('Epoch:', '1675', 'training time (minutes)=', '1.4194', 'loss=', '0.000413058')
# ('Epoch:', '1676', 'training time (minutes)=', '1.2542', 'loss=', '0.000414830')
# ('Epoch:', '1677', 'training time (minutes)=', '1.4175', 'loss=', '0.000417455')
# ('Epoch:', '1678', 'training time (minutes)=', '1.2839', 'loss=', '0.000406338')
# ('Epoch:', '1679', 'training time (minutes)=', '1.5411', 'loss=', '0.000406940')
# ('Epoch:', '1680', 'training time (minutes)=', '1.2830', 'loss=', '0.000412671')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/iclr/nn_models/all_snc/all_snc_rotated_deeper_mlp_arch_1_pc_no_bnorm_old_code2048pts_chamfer/models.ckpt-1680 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '1681', 'training time (minutes)=', '1.3931', 'loss=', '0.000410105')
# ('Epoch:', '1682', 'training time (minutes)=', '1.3461', 'loss=', '0.000406236')
# ('Epoch:', '1683', 'training time (minutes)=', '1.4943', 'loss=', '0.000411761')
# ('Epoch:', '1684', 'training time (minutes)=', '1.2713', 'loss=', '0.000415010')
