# %%
from general_tools.notebook.gpu_utils import setup_one_gpu
GPU = 0
setup_one_gpu(GPU)
# Out:
# Picking GPU 0

# %%
import sys
import time
import numpy as np
import os.path as osp
import tensorflow as tf
import matplotlib.pyplot as plt

from general_tools.notebook.tf import reset_tf_graph

import tf_lab.point_clouds.in_out as pio

from tf_lab.point_clouds.in_out import PointCloudDataSet, write_model_ids_of_datasets
from tf_lab.point_clouds.point_net_ae import PointNetAutoEncoder
from tf_lab.point_clouds.autoencoder import Configuration as Conf
import tf_lab.point_clouds.encoders_decoders as enc_dec


from tf_lab.autopredictors.scripts.helper import shape_net_category_to_synth_id


from tf_lab.autopredictors.plotting import plot_original_pclouds_vs_reconstructed, \
                                           plot_train_val_test_curves, plot_reconstructions_at_epoch


from tf_lab.autopredictors.evaluate import eval_model, read_saved_epochs
                                                  

from general_tools.in_out.basics import create_dir, delete_files_in_directory, files_in_subdirs
from general_tools.simpletons import select_first_last_and_k
from geo_tool import Point_Cloud

from tf_lab.nips.data_sets.shape_net import pc_loader as sn_pc_loader

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
n_pc_samples = 2048
do_training = True
first_time_running = True
load_model = False
load_epoch = None
seed = 42

max_training_epochs = 1000
loss = 'emd'

class_name = raw_input('Give me the class type: ').lower()
syn_id = shape_net_category_to_synth_id()[class_name]

arch_type = raw_input('MLP or Conv:').lower()
if arch_type == 'mlp':
    arch_tag = 'mlp_arch'
elif arch_type == 'conv':
    arch_tag = 'conv_arch'
else:
    assert(False)

experiment_id = raw_input('Give me the experimen ID:').lower()

experiment_name = 'ae_farm_' + class_name + '_' + arch_tag + '_' + experiment_id +'_' + str(n_pc_samples) +  'pts_' + loss

top_data_dir = '/orions4-zfs/projects/lins2/Panos_Space/DATA/'
train_dir = osp.join(top_data_dir, 'OUT/icml/nn_models/ae_farming')
train_dir = osp.join(train_dir, experiment_name)
create_dir(train_dir)
# Out:
# Give me the class type: chair
# MLP or Conv:mlp
# Give me the experimen ID:6
# '/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd'

# %%
# Load Raw Point-Clouds of class
pclouds_path = osp.join(top_data_dir, 'Point_Clouds/Shape_Net/Core/from_manifold_meshes/centered/', str(n_pc_samples))
pclouds_path = osp.join(pclouds_path, syn_id)
file_names = pio.load_filenames_of_input_data(pclouds_path, '.ply')
pclouds, model_ids, syn_ids = pio.load_crude_point_clouds(file_names=file_names, n_threads=50, loader=sn_pc_loader)
print '%d files containing complete point clouds were found.' % (len(pclouds), )
train_data = PointCloudDataSet(pclouds)
# Out:
# 6778 files containing complete point clouds were found.

# %%
bneck = 4
if n_pc_samples == 2048:
    encoder_args = {'n_filters': [128, 128, 256, bneck],
                    'filter_sizes' :[40, 20, 10, 10],
                    'strides': [1, 2, 2, 1]}
    
    if arch_type == 'mlp':
        encoder_args = {'n_filters': [128, 128, 256, bneck],
                        'filter_sizes' :[1, 1, 1, 1],
                        'strides': [1, 1, 1, 1]}
        
    
else:
    assert(False)
    
if load_model:
    conf = Conf.load(osp.join(train_dir, 'configuration'))
    print conf
    
    
else:
    n_input = [n_pc_samples, 3]
    decoder_args = {'layer_sizes': [1024, 2048, np.prod(n_input)]}

    conf = Conf(
                n_input = n_input,
                training_epochs = max_training_epochs,
                batch_size = 50,
                loss = loss,
                denoising = False,
                train_dir = train_dir,
                loss_display_step = 1,
                saver_step = 10,
                learning_rate = 0.0005,
                z_rotate = False,
                encoder = enc_dec.encoder_with_convs_and_symmetry,
                encoder_args = encoder_args,
                decoder = enc_dec.decoder_with_fc_only,
                decoder_args = decoder_args
               )

    conf.experiment_name = experiment_name
    conf.save(osp.join(conf.train_dir, 'configuration'))    
    
reset_tf_graph()
ae = PointNetAutoEncoder(experiment_name, conf)

if load_model:
    if load_epoch is None: # load last saved.
        saved_epochs = read_saved_epochs(conf.train_dir)
        load_epoch = saved_epochs[-1]
        
        
    ae.restore_model(conf.train_dir, load_epoch, verbose=True)

# %%
if do_training:
    buf_size = 1 # flush each line
    fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
    train_stats = ae.train(train_data, conf, log_file=fout)
    fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.4078', 'loss=', '239.345044623')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '0.3831', 'loss=', '186.980924479')
# ('Epoch:', '0003', 'training time (minutes)=', '0.3964', 'loss=', '180.748539677')
# ('Epoch:', '0004', 'training time (minutes)=', '0.3858', 'loss=', '173.315419176')
# ('Epoch:', '0005', 'training time (minutes)=', '0.4009', 'loss=', '170.290263649')
# ('Epoch:', '0006', 'training time (minutes)=', '0.3990', 'loss=', '169.831295437')
# ('Epoch:', '0007', 'training time (minutes)=', '0.3927', 'loss=', '167.676005272')
# ('Epoch:', '0008', 'training time (minutes)=', '0.3851', 'loss=', '166.095913018')
# ('Epoch:', '0009', 'training time (minutes)=', '0.3839', 'loss=', '165.495183535')
# ('Epoch:', '0010', 'training time (minutes)=', '0.3946', 'loss=', '164.746735636')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '0.3886', 'loss=', '163.767117875')
# ('Epoch:', '0012', 'training time (minutes)=', '0.3943', 'loss=', '163.307609502')
# ('Epoch:', '0013', 'training time (minutes)=', '0.3982', 'loss=', '162.016645983')
# ('Epoch:', '0014', 'training time (minutes)=', '0.3864', 'loss=', '162.738281476')
# ('Epoch:', '0015', 'training time (minutes)=', '0.3931', 'loss=', '162.244173403')
# ('Epoch:', '0016', 'training time (minutes)=', '0.3826', 'loss=', '161.358706778')
# ('Epoch:', '0017', 'training time (minutes)=', '0.3904', 'loss=', '161.142786662')
# ('Epoch:', '0018', 'training time (minutes)=', '0.3929', 'loss=', '161.254727286')
# ('Epoch:', '0019', 'training time (minutes)=', '0.3917', 'loss=', '160.826454671')
# ('Epoch:', '0020', 'training time (minutes)=', '0.3891', 'loss=', '160.404399731')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '0.3840', 'loss=', '160.477712900')
# ('Epoch:', '0022', 'training time (minutes)=', '0.3917', 'loss=', '160.073408113')
# ('Epoch:', '0023', 'training time (minutes)=', '0.3922', 'loss=', '159.855567424')
# ('Epoch:', '0024', 'training time (minutes)=', '0.3881', 'loss=', '159.567430962')
# ('Epoch:', '0025', 'training time (minutes)=', '0.3956', 'loss=', '159.375085223')
# ('Epoch:', '0026', 'training time (minutes)=', '0.3938', 'loss=', '159.404297101')
# ('Epoch:', '0027', 'training time (minutes)=', '0.4024', 'loss=', '159.032186551')
# ('Epoch:', '0028', 'training time (minutes)=', '0.3951', 'loss=', '159.044813594')
# ('Epoch:', '0029', 'training time (minutes)=', '0.3963', 'loss=', '158.653350830')
# ('Epoch:', '0030', 'training time (minutes)=', '0.3844', 'loss=', '158.877618747')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '0.3931', 'loss=', '158.254707732')
# ('Epoch:', '0032', 'training time (minutes)=', '0.4032', 'loss=', '157.877927766')
# ('Epoch:', '0033', 'training time (minutes)=', '0.3909', 'loss=', '157.589253517')
# ('Epoch:', '0034', 'training time (minutes)=', '0.3854', 'loss=', '158.265799628')
# ('Epoch:', '0035', 'training time (minutes)=', '0.3945', 'loss=', '157.734534709')
# ('Epoch:', '0036', 'training time (minutes)=', '0.3953', 'loss=', '157.370270228')
# ('Epoch:', '0037', 'training time (minutes)=', '0.4014', 'loss=', '157.441971164')
# ('Epoch:', '0038', 'training time (minutes)=', '0.3937', 'loss=', '157.057361066')
# ('Epoch:', '0039', 'training time (minutes)=', '0.3917', 'loss=', '156.983764535')
# ('Epoch:', '0040', 'training time (minutes)=', '0.3926', 'loss=', '156.697411318')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '0.3894', 'loss=', '156.962182391')
# ('Epoch:', '0042', 'training time (minutes)=', '0.3931', 'loss=', '156.733928426')
# ('Epoch:', '0043', 'training time (minutes)=', '0.4084', 'loss=', '156.424684313')
# ('Epoch:', '0044', 'training time (minutes)=', '0.3985', 'loss=', '156.954498517')
# ('Epoch:', '0045', 'training time (minutes)=', '0.3977', 'loss=', '156.234575625')
# ('Epoch:', '0046', 'training time (minutes)=', '0.3878', 'loss=', '156.482842000')
# ('Epoch:', '0047', 'training time (minutes)=', '0.3825', 'loss=', '156.124699571')
# ('Epoch:', '0048', 'training time (minutes)=', '0.3999', 'loss=', '155.489403845')
# ('Epoch:', '0049', 'training time (minutes)=', '0.3895', 'loss=', '155.781821922')
# ('Epoch:', '0050', 'training time (minutes)=', '0.3867', 'loss=', '156.419761827')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '0.3819', 'loss=', '155.423116726')
# ('Epoch:', '0052', 'training time (minutes)=', '0.3945', 'loss=', '155.440899545')
# ('Epoch:', '0053', 'training time (minutes)=', '0.4038', 'loss=', '154.988081529')
# ('Epoch:', '0054', 'training time (minutes)=', '0.3901', 'loss=', '155.181674533')
# ('Epoch:', '0055', 'training time (minutes)=', '0.3966', 'loss=', '155.179943396')
# ('Epoch:', '0056', 'training time (minutes)=', '0.3990', 'loss=', '155.128602883')
# ('Epoch:', '0057', 'training time (minutes)=', '0.3922', 'loss=', '154.747054489')
# ('Epoch:', '0058', 'training time (minutes)=', '0.3902', 'loss=', '154.776757812')
# ('Epoch:', '0059', 'training time (minutes)=', '0.3870', 'loss=', '154.647450200')
# ('Epoch:', '0060', 'training time (minutes)=', '0.4024', 'loss=', '154.049627233')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '0.4011', 'loss=', '154.293711231')
# ('Epoch:', '0062', 'training time (minutes)=', '0.3910', 'loss=', '153.758490329')
# ('Epoch:', '0063', 'training time (minutes)=', '0.3918', 'loss=', '154.355668358')
# ('Epoch:', '0064', 'training time (minutes)=', '0.3924', 'loss=', '153.761002152')
# ('Epoch:', '0065', 'training time (minutes)=', '0.4077', 'loss=', '153.652715047')
# ('Epoch:', '0066', 'training time (minutes)=', '0.4014', 'loss=', '153.717387108')
# ('Epoch:', '0067', 'training time (minutes)=', '0.3991', 'loss=', '153.094607544')
# ('Epoch:', '0068', 'training time (minutes)=', '0.3862', 'loss=', '153.695567491')
# ('Epoch:', '0069', 'training time (minutes)=', '0.3906', 'loss=', '154.348537417')
# ('Epoch:', '0070', 'training time (minutes)=', '0.3982', 'loss=', '154.185251872')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '0.3893', 'loss=', '153.104435334')
# ('Epoch:', '0072', 'training time (minutes)=', '0.3891', 'loss=', '153.075991143')
# ('Epoch:', '0073', 'training time (minutes)=', '0.4002', 'loss=', '152.611099243')
# ('Epoch:', '0074', 'training time (minutes)=', '0.4019', 'loss=', '152.701011488')
# ('Epoch:', '0075', 'training time (minutes)=', '0.3928', 'loss=', '152.944402963')
# ('Epoch:', '0076', 'training time (minutes)=', '0.4095', 'loss=', '152.382181238')
# ('Epoch:', '0077', 'training time (minutes)=', '0.3981', 'loss=', '151.931440904')
# ('Epoch:', '0078', 'training time (minutes)=', '0.3881', 'loss=', '151.583525707')
# ('Epoch:', '0079', 'training time (minutes)=', '0.3858', 'loss=', '151.442590445')
# ('Epoch:', '0080', 'training time (minutes)=', '0.3914', 'loss=', '151.828173715')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '0.3937', 'loss=', '151.717257690')
# ('Epoch:', '0082', 'training time (minutes)=', '0.4047', 'loss=', '151.174099392')
# ('Epoch:', '0083', 'training time (minutes)=', '0.3940', 'loss=', '151.698490962')
# ('Epoch:', '0084', 'training time (minutes)=', '0.3968', 'loss=', '151.080448631')
# ('Epoch:', '0085', 'training time (minutes)=', '0.3941', 'loss=', '150.814645951')
# ('Epoch:', '0086', 'training time (minutes)=', '0.4040', 'loss=', '150.775334224')
# ('Epoch:', '0087', 'training time (minutes)=', '0.3884', 'loss=', '150.700003956')
# ('Epoch:', '0088', 'training time (minutes)=', '0.3975', 'loss=', '150.598818066')
# ('Epoch:', '0089', 'training time (minutes)=', '0.3848', 'loss=', '150.221189824')
# ('Epoch:', '0090', 'training time (minutes)=', '0.3869', 'loss=', '150.259324589')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '0.3931', 'loss=', '150.224649726')
# ('Epoch:', '0092', 'training time (minutes)=', '0.3906', 'loss=', '149.884706624')
# ('Epoch:', '0093', 'training time (minutes)=', '0.3890', 'loss=', '149.567686745')
# ('Epoch:', '0094', 'training time (minutes)=', '0.3850', 'loss=', '149.612091743')
# ('Epoch:', '0095', 'training time (minutes)=', '0.3935', 'loss=', '149.736341462')
# ('Epoch:', '0096', 'training time (minutes)=', '0.3822', 'loss=', '149.677765797')
# ('Epoch:', '0097', 'training time (minutes)=', '0.3934', 'loss=', '148.868801315')
# ('Epoch:', '0098', 'training time (minutes)=', '0.3906', 'loss=', '149.275687211')
# ('Epoch:', '0099', 'training time (minutes)=', '0.3974', 'loss=', '149.383032001')
# ('Epoch:', '0100', 'training time (minutes)=', '0.3861', 'loss=', '149.639574630')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '0.3938', 'loss=', '149.737379060')
# ('Epoch:', '0102', 'training time (minutes)=', '0.3917', 'loss=', '149.530593194')
# ('Epoch:', '0103', 'training time (minutes)=', '0.3864', 'loss=', '149.054520897')
# ('Epoch:', '0104', 'training time (minutes)=', '0.3819', 'loss=', '148.520977444')
# ('Epoch:', '0105', 'training time (minutes)=', '0.3838', 'loss=', '147.990023239')
# ('Epoch:', '0106', 'training time (minutes)=', '0.3850', 'loss=', '148.358343732')
# ('Epoch:', '0107', 'training time (minutes)=', '0.4059', 'loss=', '148.003318730')
# ('Epoch:', '0108', 'training time (minutes)=', '0.3902', 'loss=', '148.021641936')
# ('Epoch:', '0109', 'training time (minutes)=', '0.3944', 'loss=', '148.141620212')
# ('Epoch:', '0110', 'training time (minutes)=', '0.3891', 'loss=', '148.179543615')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '0.3884', 'loss=', '147.757906426')
# ('Epoch:', '0112', 'training time (minutes)=', '0.3831', 'loss=', '147.333399907')
# ('Epoch:', '0113', 'training time (minutes)=', '0.3892', 'loss=', '148.244707009')
# ('Epoch:', '0114', 'training time (minutes)=', '0.3989', 'loss=', '147.365638563')
# ('Epoch:', '0115', 'training time (minutes)=', '0.3991', 'loss=', '146.765162263')
# ('Epoch:', '0116', 'training time (minutes)=', '0.3857', 'loss=', '147.100659180')
# ('Epoch:', '0117', 'training time (minutes)=', '0.3984', 'loss=', '146.815852073')
# ('Epoch:', '0118', 'training time (minutes)=', '0.3939', 'loss=', '146.701332375')
# ('Epoch:', '0119', 'training time (minutes)=', '0.3962', 'loss=', '147.412376347')
# ('Epoch:', '0120', 'training time (minutes)=', '0.3826', 'loss=', '146.775490768')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '0.3870', 'loss=', '146.280530689')
# ('Epoch:', '0122', 'training time (minutes)=', '0.3817', 'loss=', '145.717465662')
# ('Epoch:', '0123', 'training time (minutes)=', '0.3932', 'loss=', '145.799629268')
# ('Epoch:', '0124', 'training time (minutes)=', '0.3853', 'loss=', '146.471464030')
# ('Epoch:', '0125', 'training time (minutes)=', '0.4005', 'loss=', '146.153084310')
# ('Epoch:', '0126', 'training time (minutes)=', '0.3867', 'loss=', '145.635117481')
# ('Epoch:', '0127', 'training time (minutes)=', '0.3943', 'loss=', '146.787330910')
# ('Epoch:', '0128', 'training time (minutes)=', '0.3917', 'loss=', '146.937245913')
# ('Epoch:', '0129', 'training time (minutes)=', '0.3858', 'loss=', '145.442972028')
# ('Epoch:', '0130', 'training time (minutes)=', '0.3811', 'loss=', '144.836595323')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '0.3841', 'loss=', '144.767740829')
# ('Epoch:', '0132', 'training time (minutes)=', '0.3862', 'loss=', '144.911718185')
# ('Epoch:', '0133', 'training time (minutes)=', '0.3889', 'loss=', '144.844530911')
# ('Epoch:', '0134', 'training time (minutes)=', '0.3910', 'loss=', '144.814322012')
# ('Epoch:', '0135', 'training time (minutes)=', '0.3906', 'loss=', '144.672326886')
# ('Epoch:', '0136', 'training time (minutes)=', '0.3825', 'loss=', '144.101178318')
# ('Epoch:', '0137', 'training time (minutes)=', '0.3932', 'loss=', '143.836566275')
# ('Epoch:', '0138', 'training time (minutes)=', '0.3974', 'loss=', '143.988455539')
# ('Epoch:', '0139', 'training time (minutes)=', '0.3993', 'loss=', '144.024208012')
# ('Epoch:', '0140', 'training time (minutes)=', '0.3883', 'loss=', '143.477578396')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '0.3868', 'loss=', '144.292987117')
# ('Epoch:', '0142', 'training time (minutes)=', '0.3970', 'loss=', '143.970260507')
# ('Epoch:', '0143', 'training time (minutes)=', '0.3951', 'loss=', '143.950853588')
# ('Epoch:', '0144', 'training time (minutes)=', '0.3925', 'loss=', '143.599899857')
# ('Epoch:', '0145', 'training time (minutes)=', '0.3881', 'loss=', '143.581231633')
# ('Epoch:', '0146', 'training time (minutes)=', '0.3857', 'loss=', '143.510942812')
# ('Epoch:', '0147', 'training time (minutes)=', '0.3841', 'loss=', '142.879638446')
# ('Epoch:', '0148', 'training time (minutes)=', '0.3884', 'loss=', '143.293447480')
# ('Epoch:', '0149', 'training time (minutes)=', '0.3876', 'loss=', '143.753743490')
# ('Epoch:', '0150', 'training time (minutes)=', '0.3896', 'loss=', '143.219327799')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '0.4051', 'loss=', '142.919090441')
# ('Epoch:', '0152', 'training time (minutes)=', '0.3888', 'loss=', '142.447578204')
# ('Epoch:', '0153', 'training time (minutes)=', '0.4029', 'loss=', '142.882356093')
# ('Epoch:', '0154', 'training time (minutes)=', '0.3841', 'loss=', '142.442488042')
# ('Epoch:', '0155', 'training time (minutes)=', '0.3822', 'loss=', '142.817156643')
# ('Epoch:', '0156', 'training time (minutes)=', '0.3917', 'loss=', '142.189323764')
# ('Epoch:', '0157', 'training time (minutes)=', '0.3871', 'loss=', '142.289805433')
# ('Epoch:', '0158', 'training time (minutes)=', '0.3956', 'loss=', '142.173367536')
# ('Epoch:', '0159', 'training time (minutes)=', '0.3899', 'loss=', '142.103057748')
# ('Epoch:', '0160', 'training time (minutes)=', '0.3931', 'loss=', '141.632682066')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '0.3926', 'loss=', '141.544704748')
# ('Epoch:', '0162', 'training time (minutes)=', '0.3875', 'loss=', '141.270347200')
# ('Epoch:', '0163', 'training time (minutes)=', '0.3937', 'loss=', '141.484945340')
# ('Epoch:', '0164', 'training time (minutes)=', '0.3988', 'loss=', '141.058330508')
# ('Epoch:', '0165', 'training time (minutes)=', '0.4052', 'loss=', '142.635300361')
# ('Epoch:', '0166', 'training time (minutes)=', '0.3920', 'loss=', '141.819323504')
# ('Epoch:', '0167', 'training time (minutes)=', '0.3868', 'loss=', '140.445246492')
# ('Epoch:', '0168', 'training time (minutes)=', '0.3969', 'loss=', '142.517171507')
# ('Epoch:', '0169', 'training time (minutes)=', '0.3924', 'loss=', '141.618231427')
# ('Epoch:', '0170', 'training time (minutes)=', '0.3886', 'loss=', '140.764499523')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '0.3848', 'loss=', '140.878355690')
# ('Epoch:', '0172', 'training time (minutes)=', '0.3972', 'loss=', '140.916133683')
# ('Epoch:', '0173', 'training time (minutes)=', '0.3944', 'loss=', '140.276906897')
# ('Epoch:', '0174', 'training time (minutes)=', '0.3878', 'loss=', '140.676567812')
# ('Epoch:', '0175', 'training time (minutes)=', '0.3918', 'loss=', '140.301257550')
# ('Epoch:', '0176', 'training time (minutes)=', '0.3955', 'loss=', '141.028973050')
# ('Epoch:', '0177', 'training time (minutes)=', '0.3919', 'loss=', '140.030386748')
# ('Epoch:', '0178', 'training time (minutes)=', '0.3875', 'loss=', '140.223041224')
# ('Epoch:', '0179', 'training time (minutes)=', '0.3842', 'loss=', '139.809685884')
# ('Epoch:', '0180', 'training time (minutes)=', '0.3917', 'loss=', '139.226489823')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '0.3850', 'loss=', '139.461885297')
# ('Epoch:', '0182', 'training time (minutes)=', '0.3814', 'loss=', '139.617365576')
# ('Epoch:', '0183', 'training time (minutes)=', '0.3937', 'loss=', '139.249249211')
# ('Epoch:', '0184', 'training time (minutes)=', '0.3847', 'loss=', '138.910073287')
# ('Epoch:', '0185', 'training time (minutes)=', '0.3868', 'loss=', '139.019219349')
# ('Epoch:', '0186', 'training time (minutes)=', '0.3898', 'loss=', '139.324748852')
# ('Epoch:', '0187', 'training time (minutes)=', '0.3912', 'loss=', '139.811312697')
# ('Epoch:', '0188', 'training time (minutes)=', '0.3916', 'loss=', '140.970257794')
# ('Epoch:', '0189', 'training time (minutes)=', '0.3924', 'loss=', '140.636857888')
# ('Epoch:', '0190', 'training time (minutes)=', '0.4001', 'loss=', '138.806662722')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '0.3900', 'loss=', '139.035830915')
# ('Epoch:', '0192', 'training time (minutes)=', '0.3862', 'loss=', '138.633320335')
# ('Epoch:', '0193', 'training time (minutes)=', '0.3888', 'loss=', '139.562808962')
# ('Epoch:', '0194', 'training time (minutes)=', '0.3952', 'loss=', '138.937867172')
# ('Epoch:', '0195', 'training time (minutes)=', '0.3922', 'loss=', '138.120552006')
# ('Epoch:', '0196', 'training time (minutes)=', '0.3999', 'loss=', '137.924679848')
# ('Epoch:', '0197', 'training time (minutes)=', '0.3851', 'loss=', '137.888774618')
# ('Epoch:', '0198', 'training time (minutes)=', '0.3897', 'loss=', '138.269233082')
# ('Epoch:', '0199', 'training time (minutes)=', '0.4083', 'loss=', '137.724397730')
# ('Epoch:', '0200', 'training time (minutes)=', '0.3799', 'loss=', '138.068253750')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '0.3855', 'loss=', '137.740080318')
# ('Epoch:', '0202', 'training time (minutes)=', '0.3826', 'loss=', '137.647737461')
# ('Epoch:', '0203', 'training time (minutes)=', '0.3798', 'loss=', '137.576418672')
# ('Epoch:', '0204', 'training time (minutes)=', '0.3904', 'loss=', '137.331368679')
# ('Epoch:', '0205', 'training time (minutes)=', '0.3702', 'loss=', '137.480853837')
# ('Epoch:', '0206', 'training time (minutes)=', '0.3729', 'loss=', '137.527638866')
# ('Epoch:', '0207', 'training time (minutes)=', '0.3924', 'loss=', '136.965835402')
# ('Epoch:', '0208', 'training time (minutes)=', '0.3769', 'loss=', '137.340231832')
# ('Epoch:', '0209', 'training time (minutes)=', '0.4062', 'loss=', '136.564439449')
# ('Epoch:', '0210', 'training time (minutes)=', '0.3904', 'loss=', '136.988604623')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '0.4113', 'loss=', '137.457479915')
# ('Epoch:', '0212', 'training time (minutes)=', '0.3736', 'loss=', '136.440444325')
# ('Epoch:', '0213', 'training time (minutes)=', '0.4067', 'loss=', '136.968480598')
# ('Epoch:', '0214', 'training time (minutes)=', '0.3774', 'loss=', '137.453042942')
# ('Epoch:', '0215', 'training time (minutes)=', '0.3880', 'loss=', '136.296765758')
# ('Epoch:', '0216', 'training time (minutes)=', '0.3882', 'loss=', '137.946762537')
# ('Epoch:', '0217', 'training time (minutes)=', '0.4173', 'loss=', '137.180162840')
# ('Epoch:', '0218', 'training time (minutes)=', '0.3905', 'loss=', '136.671873587')
# ('Epoch:', '0219', 'training time (minutes)=', '0.3914', 'loss=', '136.397440423')
# ('Epoch:', '0220', 'training time (minutes)=', '0.3805', 'loss=', '136.642772985')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '0.3777', 'loss=', '136.588167996')
# ('Epoch:', '0222', 'training time (minutes)=', '0.3991', 'loss=', '135.664189035')
# ('Epoch:', '0223', 'training time (minutes)=', '0.3812', 'loss=', '135.251213752')
# ('Epoch:', '0224', 'training time (minutes)=', '0.4008', 'loss=', '135.517517598')
# ('Epoch:', '0225', 'training time (minutes)=', '0.3776', 'loss=', '135.903931512')
# ('Epoch:', '0226', 'training time (minutes)=', '0.3733', 'loss=', '136.000655111')
# ('Epoch:', '0227', 'training time (minutes)=', '0.4257', 'loss=', '135.151259641')
# ('Epoch:', '0228', 'training time (minutes)=', '0.3823', 'loss=', '135.717187048')
# ('Epoch:', '0229', 'training time (minutes)=', '0.4079', 'loss=', '135.318729542')
# ('Epoch:', '0230', 'training time (minutes)=', '0.3732', 'loss=', '135.217266168')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '0.4082', 'loss=', '134.718483536')
# ('Epoch:', '0232', 'training time (minutes)=', '0.4254', 'loss=', '135.333381822')
# ('Epoch:', '0233', 'training time (minutes)=', '0.4043', 'loss=', '136.413819490')
# ('Epoch:', '0234', 'training time (minutes)=', '0.4433', 'loss=', '135.624037509')
# ('Epoch:', '0235', 'training time (minutes)=', '0.3807', 'loss=', '134.981669956')
# ('Epoch:', '0236', 'training time (minutes)=', '0.4173', 'loss=', '134.576305757')
# ('Epoch:', '0237', 'training time (minutes)=', '0.4242', 'loss=', '134.540245282')
# ('Epoch:', '0238', 'training time (minutes)=', '0.4129', 'loss=', '134.564611760')
# ('Epoch:', '0239', 'training time (minutes)=', '0.3763', 'loss=', '134.576221155')
# ('Epoch:', '0240', 'training time (minutes)=', '0.3932', 'loss=', '134.017803673')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '0.3928', 'loss=', '136.352820898')
# ('Epoch:', '0242', 'training time (minutes)=', '0.3806', 'loss=', '134.596657082')
# ('Epoch:', '0243', 'training time (minutes)=', '0.3794', 'loss=', '133.872313492')
# ('Epoch:', '0244', 'training time (minutes)=', '0.3807', 'loss=', '134.175556268')
# ('Epoch:', '0245', 'training time (minutes)=', '0.3902', 'loss=', '134.559704251')
# ('Epoch:', '0246', 'training time (minutes)=', '0.3790', 'loss=', '135.172968999')
# ('Epoch:', '0247', 'training time (minutes)=', '0.3799', 'loss=', '134.415940631')
# ('Epoch:', '0248', 'training time (minutes)=', '0.3954', 'loss=', '133.772737348')
# ('Epoch:', '0249', 'training time (minutes)=', '0.3766', 'loss=', '134.307057020')
# ('Epoch:', '0250', 'training time (minutes)=', '0.3828', 'loss=', '134.128033956')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '0.4357', 'loss=', '133.925363272')
# ('Epoch:', '0252', 'training time (minutes)=', '0.3864', 'loss=', '133.789578360')
# ('Epoch:', '0253', 'training time (minutes)=', '0.3792', 'loss=', '133.746104036')
# ('Epoch:', '0254', 'training time (minutes)=', '0.3793', 'loss=', '132.844849933')
# ('Epoch:', '0255', 'training time (minutes)=', '0.3863', 'loss=', '132.876797542')
# ('Epoch:', '0256', 'training time (minutes)=', '0.3802', 'loss=', '132.776545998')
# ('Epoch:', '0257', 'training time (minutes)=', '0.3897', 'loss=', '133.869476544')
# ('Epoch:', '0258', 'training time (minutes)=', '0.3848', 'loss=', '134.473856665')
# ('Epoch:', '0259', 'training time (minutes)=', '0.3784', 'loss=', '134.333349214')
# ('Epoch:', '0260', 'training time (minutes)=', '0.3767', 'loss=', '132.663992649')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '0.3910', 'loss=', '133.491469037')
# ('Epoch:', '0262', 'training time (minutes)=', '0.3983', 'loss=', '133.967449499')
# ('Epoch:', '0263', 'training time (minutes)=', '0.3823', 'loss=', '132.758706948')
# ('Epoch:', '0264', 'training time (minutes)=', '0.3841', 'loss=', '132.622232225')
# ('Epoch:', '0265', 'training time (minutes)=', '0.3853', 'loss=', '132.227614791')
# ('Epoch:', '0266', 'training time (minutes)=', '0.3844', 'loss=', '133.042487590')
# ('Epoch:', '0267', 'training time (minutes)=', '0.3766', 'loss=', '132.329781652')
# ('Epoch:', '0268', 'training time (minutes)=', '0.3889', 'loss=', '131.884357198')
# ('Epoch:', '0269', 'training time (minutes)=', '0.3738', 'loss=', '132.458234038')
# ('Epoch:', '0270', 'training time (minutes)=', '0.3828', 'loss=', '132.863974790')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '0.4166', 'loss=', '132.157628547')
# ('Epoch:', '0272', 'training time (minutes)=', '0.3822', 'loss=', '132.830426760')
# ('Epoch:', '0273', 'training time (minutes)=', '0.3798', 'loss=', '131.243913382')
# ('Epoch:', '0274', 'training time (minutes)=', '0.3802', 'loss=', '131.902795467')
# ('Epoch:', '0275', 'training time (minutes)=', '0.3794', 'loss=', '132.332774410')
# ('Epoch:', '0276', 'training time (minutes)=', '0.3841', 'loss=', '131.918212156')
# ('Epoch:', '0277', 'training time (minutes)=', '0.3796', 'loss=', '131.429252285')
# ('Epoch:', '0278', 'training time (minutes)=', '0.3778', 'loss=', '132.261390799')
# ('Epoch:', '0279', 'training time (minutes)=', '0.3788', 'loss=', '132.037309265')
# ('Epoch:', '0280', 'training time (minutes)=', '0.3797', 'loss=', '131.697057314')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '0.3792', 'loss=', '130.902007039')
# ('Epoch:', '0282', 'training time (minutes)=', '0.3801', 'loss=', '131.393612727')
# ('Epoch:', '0283', 'training time (minutes)=', '0.3903', 'loss=', '131.165941479')
# ('Epoch:', '0284', 'training time (minutes)=', '0.3767', 'loss=', '130.819284905')
# ('Epoch:', '0285', 'training time (minutes)=', '0.3773', 'loss=', '130.464308732')
# ('Epoch:', '0286', 'training time (minutes)=', '0.3754', 'loss=', '131.752625020')
# ('Epoch:', '0287', 'training time (minutes)=', '0.3761', 'loss=', '130.951033698')
# ('Epoch:', '0288', 'training time (minutes)=', '0.3764', 'loss=', '130.624655886')
# ('Epoch:', '0289', 'training time (minutes)=', '0.3747', 'loss=', '130.762713680')
# ('Epoch:', '0290', 'training time (minutes)=', '0.3795', 'loss=', '131.007794076')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '0.3907', 'loss=', '130.388571280')
# ('Epoch:', '0292', 'training time (minutes)=', '0.3733', 'loss=', '130.562960815')
# ('Epoch:', '0293', 'training time (minutes)=', '0.3798', 'loss=', '130.666437728')
# ('Epoch:', '0294', 'training time (minutes)=', '0.3763', 'loss=', '131.190075005')
# ('Epoch:', '0295', 'training time (minutes)=', '0.3719', 'loss=', '131.478487651')
# ('Epoch:', '0296', 'training time (minutes)=', '0.3952', 'loss=', '130.170981965')
# ('Epoch:', '0297', 'training time (minutes)=', '0.3933', 'loss=', '129.974652665')
# ('Epoch:', '0298', 'training time (minutes)=', '0.3779', 'loss=', '129.860612883')
# ('Epoch:', '0299', 'training time (minutes)=', '0.3803', 'loss=', '130.624004336')
# ('Epoch:', '0300', 'training time (minutes)=', '0.3795', 'loss=', '129.250462624')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '0.3778', 'loss=', '129.791720525')
# ('Epoch:', '0302', 'training time (minutes)=', '0.3792', 'loss=', '129.941135887')
# ('Epoch:', '0303', 'training time (minutes)=', '0.3906', 'loss=', '130.094160461')
# ('Epoch:', '0304', 'training time (minutes)=', '0.4102', 'loss=', '129.670228577')
# ('Epoch:', '0305', 'training time (minutes)=', '0.3785', 'loss=', '129.165091055')
# ('Epoch:', '0306', 'training time (minutes)=', '0.3766', 'loss=', '129.195843336')
# ('Epoch:', '0307', 'training time (minutes)=', '0.3871', 'loss=', '129.271623795')
# ('Epoch:', '0308', 'training time (minutes)=', '0.3846', 'loss=', '130.456963603')
# ('Epoch:', '0309', 'training time (minutes)=', '0.3780', 'loss=', '130.941168382')
# ('Epoch:', '0310', 'training time (minutes)=', '0.3801', 'loss=', '129.110647413')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '0.3750', 'loss=', '129.403530827')
# ('Epoch:', '0312', 'training time (minutes)=', '0.3829', 'loss=', '129.477060389')
# ('Epoch:', '0313', 'training time (minutes)=', '0.3793', 'loss=', '129.244264899')
# ('Epoch:', '0314', 'training time (minutes)=', '0.3778', 'loss=', '130.576023582')
# ('Epoch:', '0315', 'training time (minutes)=', '0.3796', 'loss=', '130.237801107')
# ('Epoch:', '0316', 'training time (minutes)=', '0.3776', 'loss=', '128.480546626')
# ('Epoch:', '0317', 'training time (minutes)=', '0.3862', 'loss=', '128.092862334')
# ('Epoch:', '0318', 'training time (minutes)=', '0.3778', 'loss=', '128.308726219')
# ('Epoch:', '0319', 'training time (minutes)=', '0.3760', 'loss=', '128.440920003')
# ('Epoch:', '0320', 'training time (minutes)=', '0.3810', 'loss=', '128.765213747')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '0.3853', 'loss=', '128.888769701')
# ('Epoch:', '0322', 'training time (minutes)=', '0.3807', 'loss=', '129.260855442')
# ('Epoch:', '0323', 'training time (minutes)=', '0.3858', 'loss=', '128.437419694')
# ('Epoch:', '0324', 'training time (minutes)=', '0.3831', 'loss=', '128.405674405')
# ('Epoch:', '0325', 'training time (minutes)=', '0.3955', 'loss=', '128.623818631')
# ('Epoch:', '0326', 'training time (minutes)=', '0.3837', 'loss=', '128.623481016')
# ('Epoch:', '0327', 'training time (minutes)=', '0.3850', 'loss=', '128.586137334')
# ('Epoch:', '0328', 'training time (minutes)=', '0.3848', 'loss=', '128.049573715')
# ('Epoch:', '0329', 'training time (minutes)=', '0.3977', 'loss=', '127.804927685')
# ('Epoch:', '0330', 'training time (minutes)=', '0.3811', 'loss=', '128.062644732')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '0.3820', 'loss=', '128.599259949')
# ('Epoch:', '0332', 'training time (minutes)=', '0.3877', 'loss=', '128.523821852')
# ('Epoch:', '0333', 'training time (minutes)=', '0.3827', 'loss=', '128.685455096')
# ('Epoch:', '0334', 'training time (minutes)=', '0.3862', 'loss=', '128.097879141')
# ('Epoch:', '0335', 'training time (minutes)=', '0.3845', 'loss=', '128.204681623')
# ('Epoch:', '0336', 'training time (minutes)=', '0.3826', 'loss=', '127.474198066')
# ('Epoch:', '0337', 'training time (minutes)=', '0.3835', 'loss=', '127.718394131')
# ('Epoch:', '0338', 'training time (minutes)=', '0.3940', 'loss=', '127.548022630')
# ('Epoch:', '0339', 'training time (minutes)=', '0.3804', 'loss=', '128.569302820')
# ('Epoch:', '0340', 'training time (minutes)=', '0.3833', 'loss=', '127.161127048')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '0.3853', 'loss=', '127.040774367')
# ('Epoch:', '0342', 'training time (minutes)=', '0.4018', 'loss=', '127.298069085')
# ('Epoch:', '0343', 'training time (minutes)=', '0.3814', 'loss=', '127.044729897')
# ('Epoch:', '0344', 'training time (minutes)=', '0.3818', 'loss=', '129.075264881')
# ('Epoch:', '0345', 'training time (minutes)=', '0.3839', 'loss=', '128.037050600')
# ('Epoch:', '0346', 'training time (minutes)=', '0.3823', 'loss=', '128.986860600')
# ('Epoch:', '0347', 'training time (minutes)=', '0.3827', 'loss=', '127.947090149')
# ('Epoch:', '0348', 'training time (minutes)=', '0.3992', 'loss=', '127.214572426')
# ('Epoch:', '0349', 'training time (minutes)=', '0.3874', 'loss=', '128.765436187')
# ('Epoch:', '0350', 'training time (minutes)=', '0.3917', 'loss=', '128.100908407')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '0.3760', 'loss=', '127.201793642')
# ('Epoch:', '0352', 'training time (minutes)=', '0.3785', 'loss=', '127.778418308')
# ('Epoch:', '0353', 'training time (minutes)=', '0.3747', 'loss=', '127.225453412')
# ('Epoch:', '0354', 'training time (minutes)=', '0.3798', 'loss=', '126.655608509')
# ('Epoch:', '0355', 'training time (minutes)=', '0.3764', 'loss=', '126.860172978')
# ('Epoch:', '0356', 'training time (minutes)=', '0.3850', 'loss=', '126.891667119')
# ('Epoch:', '0357', 'training time (minutes)=', '0.3760', 'loss=', '126.144055628')
# ('Epoch:', '0358', 'training time (minutes)=', '0.3762', 'loss=', '127.273671751')
# ('Epoch:', '0359', 'training time (minutes)=', '0.3782', 'loss=', '126.806051636')
# ('Epoch:', '0360', 'training time (minutes)=', '0.3784', 'loss=', '126.478510765')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0361', 'training time (minutes)=', '0.3821', 'loss=', '126.379193511')
# ('Epoch:', '0362', 'training time (minutes)=', '0.3742', 'loss=', '125.704281560')
# ('Epoch:', '0363', 'training time (minutes)=', '0.3792', 'loss=', '126.155234217')
# ('Epoch:', '0364', 'training time (minutes)=', '0.3774', 'loss=', '126.479108514')
# ('Epoch:', '0365', 'training time (minutes)=', '0.3969', 'loss=', '125.948749457')
# ('Epoch:', '0366', 'training time (minutes)=', '0.3838', 'loss=', '126.402897644')
# ('Epoch:', '0367', 'training time (minutes)=', '0.3814', 'loss=', '126.014351795')
# ('Epoch:', '0368', 'training time (minutes)=', '0.3822', 'loss=', '125.761857266')
# ('Epoch:', '0369', 'training time (minutes)=', '0.3978', 'loss=', '124.916382514')
# ('Epoch:', '0370', 'training time (minutes)=', '0.3824', 'loss=', '127.889037351')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0371', 'training time (minutes)=', '0.3788', 'loss=', '127.418643358')
# ('Epoch:', '0372', 'training time (minutes)=', '0.3802', 'loss=', '126.417234407')
# ('Epoch:', '0373', 'training time (minutes)=', '0.4022', 'loss=', '125.914826965')
# ('Epoch:', '0374', 'training time (minutes)=', '0.3797', 'loss=', '126.576954764')
# ('Epoch:', '0375', 'training time (minutes)=', '0.3829', 'loss=', '125.808388265')
# ('Epoch:', '0376', 'training time (minutes)=', '0.3833', 'loss=', '125.099890137')
# ('Epoch:', '0377', 'training time (minutes)=', '0.3952', 'loss=', '124.997286140')
# ('Epoch:', '0378', 'training time (minutes)=', '0.3874', 'loss=', '126.509915500')
# ('Epoch:', '0379', 'training time (minutes)=', '0.3831', 'loss=', '126.148550867')
# ('Epoch:', '0380', 'training time (minutes)=', '0.3813', 'loss=', '126.967380721')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0381', 'training time (minutes)=', '0.3797', 'loss=', '129.033921757')
# ('Epoch:', '0382', 'training time (minutes)=', '0.3812', 'loss=', '126.754134115')
# ('Epoch:', '0383', 'training time (minutes)=', '0.3824', 'loss=', '125.351848687')
# ('Epoch:', '0384', 'training time (minutes)=', '0.3843', 'loss=', '125.070131090')
# ('Epoch:', '0385', 'training time (minutes)=', '0.3845', 'loss=', '126.481719971')
# ('Epoch:', '0386', 'training time (minutes)=', '0.3837', 'loss=', '125.371874717')
# ('Epoch:', '0387', 'training time (minutes)=', '0.3853', 'loss=', '126.007265614')
# ('Epoch:', '0388', 'training time (minutes)=', '0.3843', 'loss=', '125.725693879')
# ('Epoch:', '0389', 'training time (minutes)=', '0.3856', 'loss=', '124.582856355')
# ('Epoch:', '0390', 'training time (minutes)=', '0.3983', 'loss=', '124.816751268')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0391', 'training time (minutes)=', '0.3759', 'loss=', '126.289757962')
# ('Epoch:', '0392', 'training time (minutes)=', '0.3770', 'loss=', '125.372803130')
# ('Epoch:', '0393', 'training time (minutes)=', '0.3794', 'loss=', '124.601634668')
# ('Epoch:', '0394', 'training time (minutes)=', '0.3844', 'loss=', '124.057328740')
# ('Epoch:', '0395', 'training time (minutes)=', '0.3827', 'loss=', '124.786027470')
# ('Epoch:', '0396', 'training time (minutes)=', '0.3768', 'loss=', '124.587733629')
# ('Epoch:', '0397', 'training time (minutes)=', '0.3785', 'loss=', '124.230636145')
# ('Epoch:', '0398', 'training time (minutes)=', '0.3904', 'loss=', '123.879666985')
# ('Epoch:', '0399', 'training time (minutes)=', '0.3803', 'loss=', '124.328081089')
# ('Epoch:', '0400', 'training time (minutes)=', '0.3751', 'loss=', '124.632069227')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0401', 'training time (minutes)=', '0.3739', 'loss=', '125.431201059')
# ('Epoch:', '0402', 'training time (minutes)=', '0.3797', 'loss=', '124.509270166')
# ('Epoch:', '0403', 'training time (minutes)=', '0.3902', 'loss=', '125.634430553')
# ('Epoch:', '0404', 'training time (minutes)=', '0.3812', 'loss=', '127.484010993')
# ('Epoch:', '0405', 'training time (minutes)=', '0.3781', 'loss=', '124.638701884')
# ('Epoch:', '0406', 'training time (minutes)=', '0.3805', 'loss=', '125.542520763')
# ('Epoch:', '0407', 'training time (minutes)=', '0.3840', 'loss=', '126.086443244')
# ('Epoch:', '0408', 'training time (minutes)=', '0.3815', 'loss=', '127.683974372')
# ('Epoch:', '0409', 'training time (minutes)=', '0.3794', 'loss=', '125.092978188')
# ('Epoch:', '0410', 'training time (minutes)=', '0.3768', 'loss=', '124.086654211')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0411', 'training time (minutes)=', '0.3736', 'loss=', '124.535302056')
# ('Epoch:', '0412', 'training time (minutes)=', '0.3813', 'loss=', '124.545412643')
# ('Epoch:', '0413', 'training time (minutes)=', '0.3795', 'loss=', '123.893021930')
# ('Epoch:', '0414', 'training time (minutes)=', '0.3748', 'loss=', '123.481430675')
# ('Epoch:', '0415', 'training time (minutes)=', '0.3778', 'loss=', '124.035954567')
# ('Epoch:', '0416', 'training time (minutes)=', '0.3867', 'loss=', '123.328550325')
# ('Epoch:', '0417', 'training time (minutes)=', '0.3765', 'loss=', '123.267455377')
# ('Epoch:', '0418', 'training time (minutes)=', '0.3776', 'loss=', '123.058985675')
# ('Epoch:', '0419', 'training time (minutes)=', '0.3757', 'loss=', '124.204346212')
# ('Epoch:', '0420', 'training time (minutes)=', '0.3888', 'loss=', '123.380299603')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0421', 'training time (minutes)=', '0.3737', 'loss=', '124.863502050')
# ('Epoch:', '0422', 'training time (minutes)=', '0.3779', 'loss=', '124.348238740')
# ('Epoch:', '0423', 'training time (minutes)=', '0.3790', 'loss=', '123.335432547')
# ('Epoch:', '0424', 'training time (minutes)=', '0.3843', 'loss=', '122.973447333')
# ('Epoch:', '0425', 'training time (minutes)=', '0.3909', 'loss=', '123.152481023')
# ('Epoch:', '0426', 'training time (minutes)=', '0.3831', 'loss=', '123.569925548')
# ('Epoch:', '0427', 'training time (minutes)=', '0.3768', 'loss=', '124.164795148')
# ('Epoch:', '0428', 'training time (minutes)=', '0.3811', 'loss=', '123.009812927')
# ('Epoch:', '0429', 'training time (minutes)=', '0.3827', 'loss=', '122.858209398')
# ('Epoch:', '0430', 'training time (minutes)=', '0.3770', 'loss=', '122.596445663')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0431', 'training time (minutes)=', '0.3739', 'loss=', '122.619975846')
# ('Epoch:', '0432', 'training time (minutes)=', '0.3751', 'loss=', '122.364334672')
# ('Epoch:', '0433', 'training time (minutes)=', '0.3796', 'loss=', '123.290743623')
# ('Epoch:', '0434', 'training time (minutes)=', '0.3846', 'loss=', '122.712787939')
# ('Epoch:', '0435', 'training time (minutes)=', '0.3763', 'loss=', '122.569239016')
# ('Epoch:', '0436', 'training time (minutes)=', '0.3798', 'loss=', '122.605620434')
# ('Epoch:', '0437', 'training time (minutes)=', '0.3893', 'loss=', '122.731538787')
# ('Epoch:', '0438', 'training time (minutes)=', '0.3768', 'loss=', '122.017991638')
# ('Epoch:', '0439', 'training time (minutes)=', '0.3789', 'loss=', '122.229428779')
# ('Epoch:', '0440', 'training time (minutes)=', '0.3843', 'loss=', '123.980656038')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0441', 'training time (minutes)=', '0.3800', 'loss=', '125.359490515')
# ('Epoch:', '0442', 'training time (minutes)=', '0.3806', 'loss=', '123.006626101')
# ('Epoch:', '0443', 'training time (minutes)=', '0.3886', 'loss=', '122.600809168')
# ('Epoch:', '0444', 'training time (minutes)=', '0.3798', 'loss=', '122.353597966')
# ('Epoch:', '0445', 'training time (minutes)=', '0.3854', 'loss=', '122.477502950')
# ('Epoch:', '0446', 'training time (minutes)=', '0.3792', 'loss=', '123.068718409')
# ('Epoch:', '0447', 'training time (minutes)=', '0.3787', 'loss=', '122.030513792')
# ('Epoch:', '0448', 'training time (minutes)=', '0.3786', 'loss=', '122.182691843')
# ('Epoch:', '0449', 'training time (minutes)=', '0.3876', 'loss=', '122.448938779')
# ('Epoch:', '0450', 'training time (minutes)=', '0.3765', 'loss=', '121.573773476')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0451', 'training time (minutes)=', '0.3784', 'loss=', '121.793972383')
# ('Epoch:', '0452', 'training time (minutes)=', '0.3811', 'loss=', '121.377303908')
# ('Epoch:', '0453', 'training time (minutes)=', '0.3760', 'loss=', '122.696112513')
# ('Epoch:', '0454', 'training time (minutes)=', '0.3804', 'loss=', '123.908971490')
# ('Epoch:', '0455', 'training time (minutes)=', '0.3811', 'loss=', '122.242900933')
# ('Epoch:', '0456', 'training time (minutes)=', '0.3883', 'loss=', '122.994295700')
# ('Epoch:', '0457', 'training time (minutes)=', '0.3876', 'loss=', '121.884915331')
# ('Epoch:', '0458', 'training time (minutes)=', '0.3821', 'loss=', '121.667881492')
# ('Epoch:', '0459', 'training time (minutes)=', '0.3785', 'loss=', '121.876502143')
# ('Epoch:', '0460', 'training time (minutes)=', '0.3928', 'loss=', '121.919191262')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0461', 'training time (minutes)=', '0.3787', 'loss=', '121.782897497')
# ('Epoch:', '0462', 'training time (minutes)=', '0.3759', 'loss=', '120.752903295')
# ('Epoch:', '0463', 'training time (minutes)=', '0.3782', 'loss=', '123.992962760')
# ('Epoch:', '0464', 'training time (minutes)=', '0.3940', 'loss=', '122.448371322')
# ('Epoch:', '0465', 'training time (minutes)=', '0.3825', 'loss=', '121.698813149')
# ('Epoch:', '0466', 'training time (minutes)=', '0.3784', 'loss=', '121.836945145')
# ('Epoch:', '0467', 'training time (minutes)=', '0.3804', 'loss=', '121.579063755')
# ('Epoch:', '0468', 'training time (minutes)=', '0.3910', 'loss=', '121.782804814')
# ('Epoch:', '0469', 'training time (minutes)=', '0.3857', 'loss=', '121.044612856')
# ('Epoch:', '0470', 'training time (minutes)=', '0.3682', 'loss=', '121.241336907')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-470 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0471', 'training time (minutes)=', '0.3860', 'loss=', '121.133206007')
# ('Epoch:', '0472', 'training time (minutes)=', '0.3819', 'loss=', '121.076985508')
# ('Epoch:', '0473', 'training time (minutes)=', '0.3854', 'loss=', '121.672342315')
# ('Epoch:', '0474', 'training time (minutes)=', '0.3828', 'loss=', '121.624252432')
# ('Epoch:', '0475', 'training time (minutes)=', '0.3775', 'loss=', '122.737981443')
# ('Epoch:', '0476', 'training time (minutes)=', '0.3842', 'loss=', '121.339139755')
# ('Epoch:', '0477', 'training time (minutes)=', '0.3891', 'loss=', '121.669342493')
# ('Epoch:', '0478', 'training time (minutes)=', '0.3792', 'loss=', '121.501496605')
# ('Epoch:', '0479', 'training time (minutes)=', '0.3741', 'loss=', '121.126846257')
# ('Epoch:', '0480', 'training time (minutes)=', '0.3891', 'loss=', '121.072871625')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-480 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0481', 'training time (minutes)=', '0.3773', 'loss=', '120.769865304')
# ('Epoch:', '0482', 'training time (minutes)=', '0.3851', 'loss=', '120.896537668')
# ('Epoch:', '0483', 'training time (minutes)=', '0.3777', 'loss=', '123.607275560')
# ('Epoch:', '0484', 'training time (minutes)=', '0.3801', 'loss=', '120.843480315')
# ('Epoch:', '0485', 'training time (minutes)=', '0.3767', 'loss=', '120.355989640')
# ('Epoch:', '0486', 'training time (minutes)=', '0.3816', 'loss=', '123.781596940')
# ('Epoch:', '0487', 'training time (minutes)=', '0.3907', 'loss=', '122.126434496')
# ('Epoch:', '0488', 'training time (minutes)=', '0.3892', 'loss=', '123.785062154')
# ('Epoch:', '0489', 'training time (minutes)=', '0.3846', 'loss=', '121.864921344')
# ('Epoch:', '0490', 'training time (minutes)=', '0.3790', 'loss=', '122.395146010')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-490 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0491', 'training time (minutes)=', '0.3809', 'loss=', '122.053808707')
# ('Epoch:', '0492', 'training time (minutes)=', '0.3787', 'loss=', '121.563848425')
# ('Epoch:', '0493', 'training time (minutes)=', '0.3866', 'loss=', '121.203726761')
# ('Epoch:', '0494', 'training time (minutes)=', '0.3832', 'loss=', '120.621470755')
# ('Epoch:', '0495', 'training time (minutes)=', '0.3788', 'loss=', '122.271681722')
# ('Epoch:', '0496', 'training time (minutes)=', '0.3810', 'loss=', '123.156071190')
# ('Epoch:', '0497', 'training time (minutes)=', '0.3943', 'loss=', '121.316173017')
# ('Epoch:', '0498', 'training time (minutes)=', '0.3811', 'loss=', '123.538303686')
# ('Epoch:', '0499', 'training time (minutes)=', '0.3810', 'loss=', '122.086682242')
# ('Epoch:', '0500', 'training time (minutes)=', '0.3813', 'loss=', '120.510590278')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-500 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0501', 'training time (minutes)=', '0.3898', 'loss=', '119.611171186')
# ('Epoch:', '0502', 'training time (minutes)=', '0.3783', 'loss=', '119.856287808')
# ('Epoch:', '0503', 'training time (minutes)=', '0.3765', 'loss=', '119.591690177')
# ('Epoch:', '0504', 'training time (minutes)=', '0.3803', 'loss=', '119.299975982')
# ('Epoch:', '0505', 'training time (minutes)=', '0.3888', 'loss=', '119.827553869')
# ('Epoch:', '0506', 'training time (minutes)=', '0.3798', 'loss=', '120.365343334')
# ('Epoch:', '0507', 'training time (minutes)=', '0.3795', 'loss=', '119.955139782')
# ('Epoch:', '0508', 'training time (minutes)=', '0.3838', 'loss=', '119.597161244')
# ('Epoch:', '0509', 'training time (minutes)=', '0.3756', 'loss=', '119.686480826')
# ('Epoch:', '0510', 'training time (minutes)=', '0.3918', 'loss=', '119.862686383')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-510 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0511', 'training time (minutes)=', '0.3807', 'loss=', '119.691098362')
# ('Epoch:', '0512', 'training time (minutes)=', '0.3809', 'loss=', '120.088597333')
# ('Epoch:', '0513', 'training time (minutes)=', '0.3762', 'loss=', '120.614989330')
# ('Epoch:', '0514', 'training time (minutes)=', '0.3881', 'loss=', '119.581724661')
# ('Epoch:', '0515', 'training time (minutes)=', '0.3775', 'loss=', '119.482174852')
# ('Epoch:', '0516', 'training time (minutes)=', '0.3822', 'loss=', '119.550604983')
# ('Epoch:', '0517', 'training time (minutes)=', '0.3856', 'loss=', '122.903585589')
# ('Epoch:', '0518', 'training time (minutes)=', '0.3802', 'loss=', '122.694275863')
# ('Epoch:', '0519', 'training time (minutes)=', '0.3793', 'loss=', '120.628750328')
# ('Epoch:', '0520', 'training time (minutes)=', '0.3804', 'loss=', '119.995784279')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-520 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0521', 'training time (minutes)=', '0.3751', 'loss=', '120.155279258')
# ('Epoch:', '0522', 'training time (minutes)=', '0.3793', 'loss=', '119.806810845')
# ('Epoch:', '0523', 'training time (minutes)=', '0.3821', 'loss=', '119.130649425')
# ('Epoch:', '0524', 'training time (minutes)=', '0.3801', 'loss=', '119.423302601')
# ('Epoch:', '0525', 'training time (minutes)=', '0.3862', 'loss=', '119.641278811')
# ('Epoch:', '0526', 'training time (minutes)=', '0.3811', 'loss=', '119.297194982')
# ('Epoch:', '0527', 'training time (minutes)=', '0.3824', 'loss=', '119.473566974')
# ('Epoch:', '0528', 'training time (minutes)=', '0.3784', 'loss=', '119.156323977')
# ('Epoch:', '0529', 'training time (minutes)=', '0.3857', 'loss=', '121.041849659')
# ('Epoch:', '0530', 'training time (minutes)=', '0.3732', 'loss=', '119.847516999')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-530 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0531', 'training time (minutes)=', '0.3850', 'loss=', '119.143897954')
# ('Epoch:', '0532', 'training time (minutes)=', '0.3786', 'loss=', '119.067663631')
# ('Epoch:', '0533', 'training time (minutes)=', '0.3847', 'loss=', '120.465138810')
# ('Epoch:', '0534', 'training time (minutes)=', '0.3826', 'loss=', '121.194834278')
# ('Epoch:', '0535', 'training time (minutes)=', '0.3738', 'loss=', '120.663643335')
# ('Epoch:', '0536', 'training time (minutes)=', '0.3784', 'loss=', '119.265191650')
# ('Epoch:', '0537', 'training time (minutes)=', '0.3856', 'loss=', '118.961882641')
# ('Epoch:', '0538', 'training time (minutes)=', '0.3692', 'loss=', '119.018823299')
# ('Epoch:', '0539', 'training time (minutes)=', '0.3811', 'loss=', '119.211382661')
# ('Epoch:', '0540', 'training time (minutes)=', '0.3925', 'loss=', '119.066089376')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-540 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0541', 'training time (minutes)=', '0.3724', 'loss=', '119.698300849')
# ('Epoch:', '0542', 'training time (minutes)=', '0.3824', 'loss=', '119.151259867')
# ('Epoch:', '0543', 'training time (minutes)=', '0.3769', 'loss=', '118.638411741')
# ('Epoch:', '0544', 'training time (minutes)=', '0.3824', 'loss=', '119.355593759')
# ('Epoch:', '0545', 'training time (minutes)=', '0.3768', 'loss=', '119.714676355')
# ('Epoch:', '0546', 'training time (minutes)=', '0.3884', 'loss=', '118.784279887')
# ('Epoch:', '0547', 'training time (minutes)=', '0.3835', 'loss=', '118.810973782')
# ('Epoch:', '0548', 'training time (minutes)=', '0.3869', 'loss=', '119.072301907')
# ('Epoch:', '0549', 'training time (minutes)=', '0.3779', 'loss=', '118.944267556')
# ('Epoch:', '0550', 'training time (minutes)=', '0.3800', 'loss=', '118.285057124')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-550 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0551', 'training time (minutes)=', '0.3807', 'loss=', '119.386180171')
# ('Epoch:', '0552', 'training time (minutes)=', '0.3806', 'loss=', '118.741710465')
# ('Epoch:', '0553', 'training time (minutes)=', '0.3779', 'loss=', '118.659642029')
# ('Epoch:', '0554', 'training time (minutes)=', '0.3759', 'loss=', '118.280130627')
# ('Epoch:', '0555', 'training time (minutes)=', '0.3881', 'loss=', '117.976319716')
# ('Epoch:', '0556', 'training time (minutes)=', '0.3882', 'loss=', '119.906423498')
# ('Epoch:', '0557', 'training time (minutes)=', '0.3762', 'loss=', '120.100551520')
# ('Epoch:', '0558', 'training time (minutes)=', '0.3811', 'loss=', '120.337812975')
# ('Epoch:', '0559', 'training time (minutes)=', '0.3780', 'loss=', '119.094289031')
# ('Epoch:', '0560', 'training time (minutes)=', '0.3809', 'loss=', '118.513087746')
# INFO:tensorflow:/orions4-zfs/projects/lins2/Panos_Space/DATA/OUT/icml/nn_models/ae_farming/ae_farm_chair_mlp_arch_6_2048pts_emd/models.ckpt-560 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0561', 'training time (minutes)=', '0.3806', 'loss=', '118.578161225')
# ('Epoch:', '0562', 'training time (minutes)=', '0.3805', 'loss=', '118.369876494')
# ('Epoch:', '0563', 'training time (minutes)=', '0.3816', 'loss=', '118.431326859')
# ('Epoch:', '0564', 'training time (minutes)=', '0.3879', 'loss=', '117.511481787')
# ('Epoch:', '0565', 'training time (minutes)=', '0.3797', 'loss=', '117.631841702')
# ('Epoch:', '0566', 'training time (minutes)=', '0.3771', 'loss=', '118.038373594')
# ('Epoch:', '0567', 'training time (minutes)=', '0.3776', 'loss=', '117.626244778')

# %%
# Plot Some feed-reconstruction pairs.
feed = train_data.next_batch(1)[0]
rec = ae.reconstruct(feed)[0]
Point_Cloud(feed[0]).plot();
Point_Cloud(rec[0]).plot();
