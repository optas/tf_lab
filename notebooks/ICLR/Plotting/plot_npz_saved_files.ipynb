# %%
from geo_tool import  Point_Cloud
import numpy as np

# %%
# %matplotlib inline

# %%
in_file = '/orions4-zfs/projects/optas/DATA/OUT/iclr/evaluations/decoded_gt_data/car/mlp_with_split_1pc_usampled_bnorm_on_encoder_only/emd_bneck_128/test.npz'

# %%
synthetic_data = np.load(in_file)  
synthetic_data = synthetic_data[synthetic_data.keys()[0]]

# %%
n_pclouds = synthetic_data.shape[0]

# %%
rid = np.random.randint(n_pclouds)
Point_Cloud(synthetic_data[rid]).plot()
